# %%
# Import
import sys
sys.path.append('../../')

from a_settings.messages import *  
from a_models.bets import *  

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # -------------------------------------------------- 
    space += "__" 
    # --------------------------------------------------  
    result = bt_col_football_fixtures(space)
    # --------------------------------------------------  
    total_rows = len(result)
    print(total_rows, flush=True)
    # --------------------------------------------------  
    for x in result:
        print(space + x, flush=True)
        # ---------------------------------------------- 
        result2 = bt_all_ARRAY(space)
        # ---------------------------------------------- 
        check = "False"
        # ---------------------------------------------- 
        for y in result2:
            check = y[5] in x 
            if(str(check) == "True"):
                print(space + "__" +  y[5], flush=True) 
        # ---------------------------------------------- 
        if(str(check) == "False"):
                print(space + "__------------------------------------- disini" , flush=True) 
        # ---------------------------------------------- 
        print("", flush=True) 
        # ---------------------------------------------- 
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 15:07:30
#   __main()
#   ______bt_col_football_fixtures()
# 788
#   ____pre_match_winner_home
#   ______bt_all_ARRAY()
#   ______match_winner_home
#
#   ____pre_match_winner_draw
#   ______bt_all_ARRAY()
#   ______match_winner_draw
#
#   ____pre_match_winner_away
#   ______bt_all_ARRAY()
#   ______match_winner_away
#
#   ____end_match_winner_home
#   ______bt_all_ARRAY()
#   ______match_winner_home
#
#   ____end_match_winner_draw
#   ______bt_all_ARRAY()
#   ______match_winner_draw
#
#   ____end_match_winner_away
#   ______bt_all_ARRAY()
#   ______match_winner_away
#
#   ____pre_homeaway_home
#   ______bt_all_ARRAY()
#   ______homeaway_home
#
#   ____pre_homeaway_away
#   ______bt_all_ARRAY()
#   ______homeaway_away
#
#   ____end_homeaway_home
#   ______bt_all_ARRAY()
#   ______homeaway_home
#
#   ____end_homeaway_away
#   ______bt_all_ARRAY()
#   ______homeaway_away
#
#   ____pre_first_half_winner_home
# ...
