# %%
# Import
from a_settings.messages import *   
from a_models.api_odds import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(0, space).strftime("%Y-%m-%d")
    date_raw       = get_today(0, space)  
    # -------------------------------------------------- 
    DICT = {
        'date_0' : date_0,
        'page' : 56,
        'counter_loop' : 0,
        'date_diff' : 0,
        'date_raw' : date_raw,
    }
    # --------------------------------------------------  
    PREP_ = "pre_"
    # -------------------------------------------------- 
    ao_controll_match_update(DICT, PREP_, space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 03:31:40
#   __main()
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-25 03:31:40.298923
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-25 03:31:40.302952
#   ______ao_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 14
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________ao_response_odds()
#   __________date_0 : 2023-03-25
#   __________page : 56
#   __________counter_loop : 0
#   __________date_diff : 0
#   __________date_raw : 2023-03-25 03:31:40.302952
#   ____________________________________________________________________________________
#   __________Total API Response(s) : 10
#
#   ____________1. Croatia,  First NL  #211 - 2022 / 1017328
#   ____________fixt date 2023-03-25 14:30:00+00:00
#   ____________fix local 2023-03-25 21:30:00
#   ____________local dat 2023-03-25 03:31:40
#   ____________Lebih
#   ______________league_rLeagues_id : 211
#   ______________league_rLeagues_name : Druga HNL
#   ______________bookmakersapi_rLeagues_id : 11
#   ______________bookmakers_rLeagues_name : 1xBet
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ______________11==11
#   __________________1 Match Winner
#   ____________________pre_match_winner_home = '1.51',
#   ____________________pre_match_winner_draw = '3.60',
#   ____________________pre_match_winner_away = '6.65',
#   __________________4 Asian Handicap
#   ____________________pre_asian_handicap_home_plus_0 = '1.16',
#   ____________________pre_asian_handicap_away_plus_0 = '4.40',
#   ______________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ______________2. Tunisia,  Ligue 2  #828 - 2022 / 1017447
#   ______________fixt date 2023-03-25 12:30:00+00:00
#   ______________fix local 2023-03-25 19:30:00
#   ______________local dat 2023-03-25 03:31:40
#   ______________Lebih
#   ______________gak ready BM
#   ______________good to Go 0
#
#   ______________3. Tunisia,  Ligue 2  #828 - 2022 / 1017448
#   ______________fixt date 2023-03-25 12:30:00+00:00
#   ______________fix local 2023-03-25 19:30:00
#   ______________local dat 2023-03-25 03:31:40
#   ______________Lebih
#   ______________gak ready BM
#   ______________good to Go 0
#
#   ______________4. Tunisia,  Ligue 2  #828 - 2022 / 1017449
#   ______________fixt date 2023-03-25 12:30:00+00:00
#   ______________fix local 2023-03-25 19:30:00
#   ______________local dat 2023-03-25 03:31:40
#   ______________Lebih
#   ______________gak ready BM
#   ______________good to Go 0
#
#   ______________5. Tunisia,  Ligue 2  #828 - 2022 / 1017450
#   ______________fixt date 2023-03-25 12:30:00+00:00
#   ______________fix local 2023-03-25 19:30:00
#   ______________local dat 2023-03-25 03:31:40
#   ______________Lebih
#   ______________gak ready BM
#   ______________good to Go 0
#
#   ______________6. Tunisia,  Ligue 2  #828 - 2022 / 1017451
#   ______________fixt date 2023-03-25 12:30:00+00:00
#   ______________fix local 2023-03-25 19:30:00
#   ______________local dat 2023-03-25 03:31:40
#   ______________Lebih
#   ______________gak ready BM
#   ______________good to Go 0
#
#   ______________7. Tunisia,  Ligue 2  #828 - 2022 / 1017452
#   ______________fixt date 2023-03-25 12:30:00+00:00
#   ______________fix local 2023-03-25 19:30:00
#   ______________local dat 2023-03-25 03:31:40
#   ______________Lebih
#   ______________gak ready BM
#   ______________good to Go 0
#
#   ______________8. World,  Friendlies Clubs  #667 - 2023 / 1017797
#   ______________fixt date 2023-03-25 13:00:00+00:00
#   ______________fix local 2023-03-25 20:00:00
#   ______________local dat 2023-03-25 03:31:40
#   ______________Lebih
#   ________________league_rLeagues_id : 667
#   ________________league_rLeagues_name : Friendlies Clubs
#   ________________bookmakersapi_rLeagues_id : 8
#   ________________bookmakers_rLeagues_name : Bet365
#   ______________Total fixtureapi_id Row(s) : 1
#   ______________good to Go 1
#   ________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ________________9. Nicaragua,  Primera Division  #396 - 2022 / 1017851
#   ________________fixt date 2023-03-25 23:00:00+00:00
#   ________________fix local 2023-03-26 06:00:00
#   ________________local dat 2023-03-25 03:31:40
#   ________________Lebih
#   ________________gak ready BM
#   ________________good to Go 0
#
#   ________________10. Senegal,  Ligue 1  #403 - 2022 / 1018007
#   ________________fixt date 2023-03-25 16:30:00+00:00
#   ________________fix local 2023-03-25 23:30:00
#   ________________local dat 2023-03-25 03:31:40
#   ________________Lebih
#   ________________gak ready BM
#   ________________good to Go 0
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API herlambangharyo@live.com counter is 13
#   ______________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-03-25
#   ______________page : 57
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-03-25 03:31:40.302952
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. Senegal,  Ligue 1  #403 - 2022 / 1018008
#   ________________fixt date 2023-03-25 16:30:00+00:00
#   ________________fix local 2023-03-25 23:30:00
#   ________________local dat 2023-03-25 03:31:40
#   ________________Lebih
#   ________________gak ready BM
#   ________________good to Go 0
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-25 03:31:47

# %%
# Import
from a_settings.messages import *   
from a_models.api_odds import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(1, space).strftime("%Y-%m-%d")
    date_raw       = get_today(1, space)  
    # -------------------------------------------------- 
    DICT = {
        'date_0' : date_0,
        'page' : 56,
        'counter_loop' : 0,
        'date_diff' : 1,
        'date_raw' : date_raw,
    }
    # --------------------------------------------------  
    PREP_ = "pre_"
    # -------------------------------------------------- 
    ao_controll_match_update(DICT, PREP_, space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 03:23:17
#   __main()
#   ______get_today()
#   ________date_diff : 1
#   ________today_raw : 2023-03-26 03:23:17.121976
#   ______get_today()
#   ________date_diff : 1
#   ________today_raw : 2023-03-26 03:23:17.121976
#   ______ao_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 26
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________ao_response_odds()
#   __________date_0 : 2023-03-26
#   __________page : 56
#   __________counter_loop : 0
#   __________date_diff : 1
#   __________date_raw : 2023-03-26 03:23:17.121976
#   ____________________________________________________________________________________
#   __________Total API Response(s) : 0
# # -------------------------------------------------- End at 2023-03-25 03:23:18

# %%
# Import
from a_settings.messages import *   
from a_models.football_fixtures import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(0, space).strftime("%Y-%m-%d")  
    date_raw         = get_today(0, space)
    # --------------------------------------------------   
    ff_gak_sempet_predates(date_0, date_raw, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 03:26:06
#   __main()
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-25 03:26:06.917774
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-25 03:26:06.917774
#   ______ff_gak_sempet_predates()
#   ________Select leagueapi_id, league_name, league_country, season, DATE(date),   (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id)  from football_fixtures  where date = '2023-03-25'  and deleted_at is null  and pre_odd_updated_at is null  group by leagueapi_id, league_name, league_country, season, DATE(date)  order by league_country, leagueapi_id asc
#   ________Total Row(s) : 9
#   __________[1/9] Austria - Regionalliga - Mitte -----#222 - 2022 - 2023-03-25 - 11
#   __________[2/9] Austria - Regionalliga - West -----#223 - 2022 - 2023-03-25 - 11
#   __________[3/9] Colombia - Primera B -----#240 - 2023 - 2023-03-25 - 8
#   __________[4/9] Israel - Liga Alef -----#496 - 2022 - 2023-03-25 - 11
#   __________[5/9] Poland - II Liga - East -----#109 - 2022 - 2023-03-25 - 8
#   __________[6/9] Poland - III Liga - Group 1 -----#780 - 2022 - 2023-03-25 - 11
#   __________[7/9] Poland - III Liga - Group 2 -----#781 - 2022 - 2023-03-25 - 11
#   __________[8/9] Poland - III Liga - Group 3 -----#782 - 2022 - 2023-03-25 - 11
#   __________[9/9] Poland - III Liga - Group 4 -----#783 - 2022 - 2023-03-25 - 11
#   __________Are you sure want to continue? :  yes
#   __________[1/9] Austria - Regionalliga - Mitte -----#222 - 2022 - 2023-03-25 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@live.com counter is 25
#   ________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-25 03:26:06.917774
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 222
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[2/9] Austria - Regionalliga - West -----#223 - 2022 - 2023-03-25 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@live.com counter is 24
#   ________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-25 03:26:06.917774
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 223
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[3/9] Colombia - Primera B -----#240 - 2023 - 2023-03-25 - 8
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@live.com counter is 23
#   ________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-25 03:26:06.917774
#   ________________bookmaker : 8
#   ________________season : 2023
#   ________________league : 240
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 2
#
#   __________________1. Colombia,  Primera B  #240 - 2023 / 989592
#   __________________fixt date 2023-03-25 20:00:00+00:00
#   __________________fix local 2023-03-26 03:00:00
#   __________________local dat 2023-03-25 03:26:06
#   __________________Lebih
#   ____________________league_rLeagues_id : 240
#   ____________________league_rLeagues_name : Primera B
#   ____________________bookmakersapi_rLeagues_id : 8
#   ____________________bookmakers_rLeagues_name : Bet365
#   __________________Total fixtureapi_id Row(s) : 1
#   __________________good to Go 1
#   ____________________8==8
#   ________________________1 Match Winner
#   __________________________pre_match_winner_home = '2.55',
#   __________________________pre_match_winner_draw = '3.00',
#   __________________________pre_match_winner_away = '2.63',
#   ________________________2 Home/Away
#   __________________________pre_homeaway_home = '1.83',
#   __________________________pre_homeaway_away = '1.83',
#   ________________________4 Asian Handicap
#   __________________________pre_asian_handicap_home_plus_0 = '1.83',
#   __________________________pre_asian_handicap_away_plus_0 = '1.98',
#   __________________________pre_asian_handicap_home_min_025 = '2.05',
#   __________________________pre_asian_handicap_away_min_025 = '1.75',
#   ________________________5 Goals Over/Under
#   __________________________pre_goals_overunder_over_25 = '2.50',
#   __________________________pre_goals_overunder_under_25 = '1.50',
#   ________________________7 HT/FT Double
#   ________________________10 Exact Score
#   ________________________31 Correct Score - First Half
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.50
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.25
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.50
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.75
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   ________________________12 Double Chance
#   __________________________pre_double_chance_home_draw = '1.40',
#   __________________________pre_double_chance_home_away = '1.30',
#   __________________________pre_double_chance_draw_away = '1.44',
#   ________________________13 First Half Winner
#   __________________________pre_first_half_winner_home = '3.40',
#   __________________________pre_first_half_winner_draw = '1.91',
#   __________________________pre_first_half_winner_away = '3.50',
#   ________________________14 Team To Score First
#   ____________________  ____________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.95
#   ____________________  ____________________bet_id: 14 --- bets_value: Draw --- bets_odd: 6.00
#   ____________________  ____________________bet_id: 14 --- bets_value: Away --- bets_odd: 2.25
#   ________________________19 Asian Handicap First Half
#   ________________________20 Double Chance - First Half
#   ________________________21 Odd/Even
#   ________________________22 Odd/Even - First Half
#   ____________________  ____________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.30
#   ____________________  ____________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.62
#   ________________________63 Odd/Even - Second Half
#   ____________________  ____________________bet_id: 63 --- bets_value: Odd --- bets_odd: 2.10
#   ____________________  ____________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.67
#   ________________________50 Goal Line
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.93
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 1.88
#   ________________________72 Goal Line (1st Half)
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.85
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 1.95
#   ____________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ____________________2. Colombia,  Primera B  #240 - 2023 / 989593
#   ____________________fixt date 2023-03-25 21:00:00+00:00
#   ____________________fix local 2023-03-26 04:00:00
#   ____________________local dat 2023-03-25 03:26:06
#   ____________________Lebih
#   ______________________league_rLeagues_id : 240
#   ______________________league_rLeagues_name : Primera B
#   ______________________bookmakersapi_rLeagues_id : 8
#   ______________________bookmakers_rLeagues_name : Bet365
#   ____________________Total fixtureapi_id Row(s) : 1
#   ____________________good to Go 1
#   ______________________8==8
#   __________________________1 Match Winner
#   ____________________________pre_match_winner_home = '2.00',
#   ____________________________pre_match_winner_draw = '3.40',
#   ____________________________pre_match_winner_away = '3.20',
#   __________________________2 Home/Away
#   ____________________________pre_homeaway_home = '1.53',
#   ____________________________pre_homeaway_away = '2.38',
#   __________________________4 Asian Handicap
#   ____________________________pre_asian_handicap_home_min_025 = '1.80',
#   ____________________________pre_asian_handicap_away_min_025 = '2.00',
#   __________________________5 Goals Over/Under
#   ____________________________pre_goals_overunder_over_25 = '2.00',
#   ____________________________pre_goals_overunder_under_25 = '1.80',
#   __________________________7 HT/FT Double
#   __________________________10 Exact Score
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   __________________________12 Double Chance
#   ____________________________pre_double_chance_home_draw = '1.29',
#   ____________________________pre_double_chance_home_away = '1.25',
#   ____________________________pre_double_chance_draw_away = '1.67',
#   __________________________13 First Half Winner
#   ____________________________pre_first_half_winner_home = '2.63',
#   ____________________________pre_first_half_winner_draw = '2.10',
#   ____________________________pre_first_half_winner_away = '3.75',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.67
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 2.50
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   __________________________63 Odd/Even - Second Half
#   ______________________  ______________________bet_id: 63 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.73
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.80
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.98
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.83
#   ______________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
#   __________[4/9] Israel - Liga Alef -----#496 - 2022 - 2023-03-25 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@live.com counter is 22
#   ________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-25 03:26:06.917774
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 496
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[5/9] Poland - II Liga - East -----#109 - 2022 - 2023-03-25 - 8
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@live.com counter is 21
#   ________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-25 03:26:06.917774
#   ________________bookmaker : 8
#   ________________season : 2022
#   ________________league : 109
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 5
#
#   __________________1. Poland,  II Liga - East  #109 - 2022 / 883977
#   __________________fixt date 2023-03-25 14:00:00+00:00
#   __________________fix local 2023-03-25 21:00:00
#   __________________local dat 2023-03-25 03:26:06
#   __________________Lebih
#   ____________________league_rLeagues_id : 109
#   ____________________league_rLeagues_name : II Liga - East
#   ____________________bookmakersapi_rLeagues_id : 8
#   ____________________bookmakers_rLeagues_name : Bet365
#   __________________Total fixtureapi_id Row(s) : 1
#   __________________good to Go 1
#   ____________________8==8
#   ________________________1 Match Winner
#   __________________________pre_match_winner_home = '2.70',
#   __________________________pre_match_winner_draw = '3.30',
#   __________________________pre_match_winner_away = '2.30',
#   ________________________2 Home/Away
#   __________________________pre_homeaway_home = '2.00',
#   __________________________pre_homeaway_away = '1.73',
#   ________________________3 Second Half Winner
#   __________________________pre_second_half_winner_home = '2.88',
#   __________________________pre_second_half_winner_draw = '2.50',
#   __________________________pre_second_half_winner_away = '2.63',
#   ________________________4 Asian Handicap
#   __________________________pre_asian_handicap_home_plus_0 = '2.05',
#   __________________________pre_asian_handicap_away_plus_0 = '1.75',
#   __________________________pre_asian_handicap_home_min_025 = '2.38',
#   __________________________pre_asian_handicap_away_min_025 = '1.55',
#   __________________________pre_asian_handicap_home_plus_025 = '1.75',
#   __________________________pre_asian_handicap_away_plus_025 = '2.05',
#   __________________________pre_asian_handicap_home_min_05 = '2.75',
#   __________________________pre_asian_handicap_away_min_05 = '1.43',
#   __________________________pre_asian_handicap_home_plus_05 = '1.58',
#   __________________________pre_asian_handicap_away_plus_05 = '2.35',
#   __________________________pre_asian_handicap_home_min_075 = '3.45',
#   __________________________pre_asian_handicap_away_min_075 = '1.30',
#   __________________________pre_asian_handicap_home_plus_075 = '1.43',
#   __________________________pre_asian_handicap_away_plus_075 = '2.75',
#   __________________________pre_asian_handicap_home_min_1 = '4.50',
#   __________________________pre_asian_handicap_away_min_1 = '1.19',
#   __________________________pre_asian_handicap_home_plus_1 = '1.28',
#   __________________________pre_asian_handicap_away_plus_1 = '3.55',
#   __________________________pre_asian_handicap_home_min_15 = '5.75',
#   __________________________pre_asian_handicap_away_min_15 = '1.14',
#   __________________________pre_asian_handicap_home_plus_15 = '1.20',
#   __________________________pre_asian_handicap_away_plus_15 = '4.40',
#   __________________________pre_asian_handicap_home_min_125 = '5.25',
#   __________________________pre_asian_handicap_away_min_125 = '1.16',
#   __________________________pre_asian_handicap_home_plus_125 = '1.23',
#   __________________________pre_asian_handicap_away_plus_125 = '4.10',
#   __________________________pre_asian_handicap_home_plus_175 = '1.13',
#   __________________________pre_asian_handicap_away_plus_175 = '5.90',
#   ________________________5 Goals Over/Under
#   __________________________pre_goals_overunder_over_35 = '3.00',
#   __________________________pre_goals_overunder_under_35 = '1.36',
#   __________________________pre_goals_overunder_over_15 = '1.25',
#   __________________________pre_goals_overunder_under_15 = '3.75',
#   __________________________pre_goals_overunder_over_45 = '5.50',
#   __________________________pre_goals_overunder_under_45 = '1.13',
#   __________________________pre_goals_overunder_over_25 = '1.85',
#   __________________________pre_goals_overunder_under_25 = '1.95',
#   __________________________pre_goals_overunder_over_05 = '1.02',
#   __________________________pre_goals_overunder_under_05 = '11.00',
#   __________________________pre_goals_overunder_over_55 = '9.00',
#   __________________________pre_goals_overunder_under_55 = '1.04',
#   __________________________pre_goals_overunder_over_65 = '15.00',
#   __________________________pre_goals_overunder_under_65 = '1.01',
#   __________________________pre_goals_overunder_over_75 = '21.00',
#   __________________________pre_goals_overunder_under_75 = '1.00',
#   ________________________6 Goals Over/Under First Half
#   __________________________pre_goals_overunder_first_half_over_35 = '21.00',
#   __________________________pre_goals_overunder_first_half_under_35 = '1.02',
#   __________________________pre_goals_overunder_first_half_over_15 = '2.75',
#   __________________________pre_goals_overunder_first_half_under_15 = '1.40',
#   __________________________pre_goals_overunder_first_half_over_25 = '7.00',
#   __________________________pre_goals_overunder_first_half_under_25 = '1.10',
#   __________________________pre_goals_overunder_first_half_over_05 = '1.36',
#   __________________________pre_goals_overunder_first_half_under_05 = '3.00',
#   ________________________26 Goals Over/Under - Second Half
#   __________________________pre_goals_overunder__second_half_over_35 = '11.00',
#   __________________________pre_goals_overunder__second_half_under_35 = '1.05',
#   __________________________pre_goals_overunder__second_half_over_15 = '2.00',
#   __________________________pre_goals_overunder__second_half_under_15 = '1.73',
#   __________________________pre_goals_overunder__second_half_over_25 = '4.00',
#   __________________________pre_goals_overunder__second_half_under_25 = '1.22',
#   __________________________pre_goals_overunder__second_half_over_05 = '1.20',
#   __________________________pre_goals_overunder__second_half_under_05 = '4.33',
#   ________________________7 HT/FT Double
#   ________________________27 Clean Sheet - Home
#   __________________________pre_clean_sheet__home_yes = '3.75',
#   __________________________pre_clean_sheet__home_no = '1.25',
#   ________________________28 Clean Sheet - Away
#   __________________________pre_clean_sheet__away_yes = '3.40',
#   __________________________pre_clean_sheet__away_no = '1.30',
#   ________________________8 Both Teams Score
#   __________________________pre_both_teams_score_yes = '1.67',
#   __________________________pre_both_teams_score_no = '2.10',
#   ________________________9 Handicap Result
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.36
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.17
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 9.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 12.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 8.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.11
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 23.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 23.00
#   ________________________10 Exact Score
#   ________________________11 Highest Scoring Half
#   ________________________31 Correct Score - First Half
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 151.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 151.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 7.50
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.50
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 126.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 21.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 151.00
#   ________________________12 Double Chance
#   __________________________pre_double_chance_home_draw = '1.50',
#   __________________________pre_double_chance_home_away = '1.25',
#   __________________________pre_double_chance_draw_away = '1.36',
#   ________________________13 First Half Winner
#   __________________________pre_first_half_winner_home = '3.25',
#   __________________________pre_first_half_winner_draw = '2.20',
#   __________________________pre_first_half_winner_away = '2.88',
#   ________________________14 Team To Score First
#   ____________________  ____________________bet_id: 14 --- bets_value: Home --- bets_odd: 2.20
#   ____________________  ____________________bet_id: 14 --- bets_value: Draw --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 14 --- bets_value: Away --- bets_odd: 1.80
#   ________________________15 Team To Score Last
#   ____________________  ____________________bet_id: 15 --- bets_value: Home --- bets_odd: 2.20
#   ____________________  ____________________bet_id: 15 --- bets_value: Draw --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 15 --- bets_value: Away --- bets_odd: 1.80
#   ________________________32 Win Both Halves
#   __________________________pre_win_both_halves_home = '10.00',
#   __________________________pre_win_both_halves_away = '8.00',
#   ________________________16 Total - Home
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 10.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.03
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.50
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.50
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.13
#   ________________________17 Total - Away
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.04
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.20
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.62
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 4.50
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.17
#   ________________________18 Handicap Result - First Half
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.33
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.40
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 9.50
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.75
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +2 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +2 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +2 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 12.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 126.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +3 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +3 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +3 --- bets_odd: 101.00
#   ________________________19 Asian Handicap First Half
#   ________________________20 Double Chance - First Half
#   ________________________34 Both Teams Score - First Half
#   ________________________35 Both Teams To Score - Second Half
#   ________________________36 Win To Nil
#   __________________________pre_win_to_nil_home = '5.00',
#   __________________________pre_win_to_nil_away = '4.33',
#   ________________________21 Odd/Even
#   ________________________22 Odd/Even - First Half
#   ____________________  ____________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.10
#   ____________________  ____________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   ________________________23 Home Odd/Even
#   ____________________  ____________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.00
#   ____________________  ____________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.73
#   ________________________60 Away Odd/Even
#   ____________________  ____________________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.91
#   ____________________  ____________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.80
#   ________________________39 To Win Either Half
#   __________________________pre_to_win_either_half_home = '1.83',
#   __________________________pre_to_win_either_half_away = '1.73',
#   ________________________40 Home Team Exact Goals Number
#   ________________________41 Away Team Exact Goals Number
#   ________________________24 Results/Both Teams Score
#   __________________________pre_results_both_teams_score_home_yes = '5.50',
#   __________________________pre_results_both_teams_score_draw_yes = '4.50',
#   __________________________pre_results_both_teams_score_away_yes = '4.50',
#   __________________________pre_results_both_teams_score_home_no = '5.00',
#   __________________________pre_results_both_teams_score_draw_no = '11.00',
#   __________________________pre_results_both_teams_score_away_no = '4.33',
#   ________________________25 Result/Total Goals
#   __________________________pre_result_total_goals_home_over_25 = '4.33',
#   __________________________pre_result_total_goals_draw_over_25 = '11.00',
#   __________________________pre_result_total_goals_away_over_25 = '3.75',
#   __________________________pre_result_total_goals_home_under_25 = '6.50',
#   __________________________pre_result_total_goals_draw_under_25 = '4.50',
#   __________________________pre_result_total_goals_away_under_25 = '5.50',
#   ________________________63 Odd/Even - Second Half
#   ____________________  ____________________bet_id: 63 --- bets_value: Odd --- bets_odd: 1.91
#   ____________________  ____________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.80
#   ________________________48 To Score In Both Halves By Teams
#   ________________________50 Goal Line
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.38
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.26
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 3.70
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 4.5 --- bets_odd: 5.75
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 4.5 --- bets_odd: 1.14
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 1.83
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.98
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.40
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.85
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 2.38
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.55
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.17
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.60
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 2.30
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 2.68
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.45
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.05
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.75
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.16
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 5.25
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 4.25 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 4.25 --- bets_odd: 1.15
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.33
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 3.30
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 3.55
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.28
#   ________________________72 Goal Line (1st Half)
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 2.75
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.43
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 2.5 --- bets_odd: 7.00
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 2.5 --- bets_odd: 1.10
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 5.75
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.14
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 6.25
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.12
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.30
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.60
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 3.55
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.28
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.83
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.98
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.53
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.43
#   ________________________73 Both Teams to Score 1st Half - 2nd Half
#   ____________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ____________________2. Poland,  II Liga - East  #109 - 2022 / 883978
#   ____________________fixt date 2023-03-25 13:00:00+00:00
#   ____________________fix local 2023-03-25 20:00:00
#   ____________________local dat 2023-03-25 03:26:06
#   ____________________Lebih
#   ______________________league_rLeagues_id : 109
#   ______________________league_rLeagues_name : II Liga - East
#   ______________________bookmakersapi_rLeagues_id : 8
#   ______________________bookmakers_rLeagues_name : Bet365
#   ____________________Total fixtureapi_id Row(s) : 1
#   ____________________good to Go 1
#   ______________________8==8
#   __________________________1 Match Winner
#   ____________________________pre_match_winner_home = '3.25',
#   ____________________________pre_match_winner_draw = '3.20',
#   ____________________________pre_match_winner_away = '2.00',
#   __________________________2 Home/Away
#   ____________________________pre_homeaway_home = '2.50',
#   ____________________________pre_homeaway_away = '1.50',
#   __________________________3 Second Half Winner
#   ____________________________pre_second_half_winner_home = '3.60',
#   ____________________________pre_second_half_winner_draw = '2.38',
#   ____________________________pre_second_half_winner_away = '2.40',
#   __________________________4 Asian Handicap
#   ____________________________pre_asian_handicap_home_plus_0 = '2.43',
#   ____________________________pre_asian_handicap_away_plus_0 = '1.53',
#   ____________________________pre_asian_handicap_home_min_025 = '2.85',
#   ____________________________pre_asian_handicap_away_min_025 = '1.40',
#   ____________________________pre_asian_handicap_home_plus_025 = '2.00',
#   ____________________________pre_asian_handicap_away_plus_025 = '1.80',
#   ____________________________pre_asian_handicap_home_min_05 = '3.30',
#   ____________________________pre_asian_handicap_away_min_05 = '1.33',
#   ____________________________pre_asian_handicap_home_plus_05 = '1.73',
#   ____________________________pre_asian_handicap_away_plus_05 = '2.08',
#   ____________________________pre_asian_handicap_home_min_075 = '4.25',
#   ____________________________pre_asian_handicap_away_min_075 = '1.21',
#   ____________________________pre_asian_handicap_home_plus_075 = '1.55',
#   ____________________________pre_asian_handicap_away_plus_075 = '2.38',
#   ____________________________pre_asian_handicap_home_min_1 = '6.60',
#   ____________________________pre_asian_handicap_away_min_1 = '1.11',
#   ____________________________pre_asian_handicap_home_plus_1 = '1.35',
#   ____________________________pre_asian_handicap_away_plus_1 = '3.10',
#   ____________________________pre_asian_handicap_home_plus_15 = '1.24',
#   ____________________________pre_asian_handicap_away_plus_15 = '3.90',
#   ____________________________pre_asian_handicap_home_plus_125 = '1.28',
#   ____________________________pre_asian_handicap_away_plus_125 = '3.55',
#   ____________________________pre_asian_handicap_home_plus_175 = '1.16',
#   ____________________________pre_asian_handicap_away_plus_175 = '5.25',
#   __________________________5 Goals Over/Under
#   ____________________________pre_goals_overunder_over_35 = '3.75',
#   ____________________________pre_goals_overunder_under_35 = '1.25',
#   ____________________________pre_goals_overunder_over_15 = '1.36',
#   ____________________________pre_goals_overunder_under_15 = '3.00',
#   ____________________________pre_goals_overunder_over_45 = '7.00',
#   ____________________________pre_goals_overunder_under_45 = '1.08',
#   ____________________________pre_goals_overunder_over_25 = '2.15',
#   ____________________________pre_goals_overunder_under_25 = '1.67',
#   ____________________________pre_goals_overunder_over_05 = '1.05',
#   ____________________________pre_goals_overunder_under_05 = '8.50',
#   ____________________________pre_goals_overunder_over_55 = '11.00',
#   ____________________________pre_goals_overunder_under_55 = '1.02',
#   ____________________________pre_goals_overunder_over_65 = '17.00',
#   ____________________________pre_goals_overunder_under_65 = '1.01',
#   __________________________6 Goals Over/Under First Half
#   ____________________________pre_goals_overunder_first_half_over_35 = '26.00',
#   ____________________________pre_goals_overunder_first_half_under_35 = '1.01',
#   ____________________________pre_goals_overunder_first_half_over_15 = '3.25',
#   ____________________________pre_goals_overunder_first_half_under_15 = '1.33',
#   ____________________________pre_goals_overunder_first_half_over_25 = '9.00',
#   ____________________________pre_goals_overunder_first_half_under_25 = '1.07',
#   ____________________________pre_goals_overunder_first_half_over_05 = '1.44',
#   ____________________________pre_goals_overunder_first_half_under_05 = '2.63',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________pre_goals_overunder__second_half_over_35 = '15.00',
#   ____________________________pre_goals_overunder__second_half_under_35 = '1.03',
#   ____________________________pre_goals_overunder__second_half_over_15 = '2.25',
#   ____________________________pre_goals_overunder__second_half_under_15 = '1.57',
#   ____________________________pre_goals_overunder__second_half_over_25 = '5.50',
#   ____________________________pre_goals_overunder__second_half_under_25 = '1.14',
#   ____________________________pre_goals_overunder__second_half_over_05 = '1.29',
#   ____________________________pre_goals_overunder__second_half_under_05 = '3.50',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________pre_clean_sheet__home_yes = '3.50',
#   ____________________________pre_clean_sheet__home_no = '1.29',
#   __________________________28 Clean Sheet - Away
#   ____________________________pre_clean_sheet__away_yes = '2.50',
#   ____________________________pre_clean_sheet__away_no = '1.50',
#   __________________________8 Both Teams Score
#   ____________________________pre_both_teams_score_yes = '1.91',
#   ____________________________pre_both_teams_score_no = '1.80',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.67
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.20
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.06
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 21.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.63
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 151.00
#   __________________________12 Double Chance
#   ____________________________pre_double_chance_home_draw = '1.67',
#   ____________________________pre_double_chance_home_away = '1.29',
#   ____________________________pre_double_chance_draw_away = '1.25',
#   __________________________13 First Half Winner
#   ____________________________pre_first_half_winner_home = '4.00',
#   ____________________________pre_first_half_winner_draw = '2.05',
#   ____________________________pre_first_half_winner_away = '2.75',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 1.67
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 1.67
#   __________________________32 Win Both Halves
#   ____________________________pre_win_both_halves_home = '15.00',
# ...
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.04
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.20
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.62
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 17.00
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 4.50
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.17
#   ________________________________17 Total - Away
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 15.00
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.01
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 3.40
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.30
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 8.00
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.06
#   ________________________________18 Handicap Result - First Half
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 8.50
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.40
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.50
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.22
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 15.00
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 4.75
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 29.00
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 11.00
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.06
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 101.00
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 41.00
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.01
#   ________________________________19 Asian Handicap First Half
#   ________________________________20 Double Chance - First Half
#   ________________________________34 Both Teams Score - First Half
#   ________________________________35 Both Teams To Score - Second Half
#   ________________________________36 Win To Nil
#   __________________________________pre_win_to_nil_home = '3.40',
#   __________________________________pre_win_to_nil_away = '6.00',
#   ________________________________21 Odd/Even
#   ________________________________22 Odd/Even - First Half
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.10
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   ________________________________60 Away Odd/Even
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.10
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.67
#   ________________________________39 To Win Either Half
#   __________________________________pre_to_win_either_half_home = '1.62',
#   __________________________________pre_to_win_either_half_away = '2.25',
#   ________________________________40 Home Team Exact Goals Number
#   ________________________________41 Away Team Exact Goals Number
#   ________________________________24 Results/Both Teams Score
#   __________________________________pre_results_both_teams_score_home_yes = '4.75',
#   __________________________________pre_results_both_teams_score_draw_yes = '4.33',
#   __________________________________pre_results_both_teams_score_away_yes = '8.00',
#   __________________________________pre_results_both_teams_score_home_no = '3.40',
#   __________________________________pre_results_both_teams_score_draw_no = '8.00',
#   __________________________________pre_results_both_teams_score_away_no = '6.00',
#   ________________________________25 Result/Total Goals
#   __________________________________pre_result_total_goals_home_over_25 = '3.60',
#   __________________________________pre_result_total_goals_draw_over_25 = '13.00',
#   __________________________________pre_result_total_goals_away_over_25 = '6.50',
#   __________________________________pre_result_total_goals_home_under_25 = '4.33',
#   __________________________________pre_result_total_goals_draw_under_25 = '3.75',
#   __________________________________pre_result_total_goals_away_under_25 = '7.00',
#   ________________________________63 Odd/Even - Second Half
#   ____________________________  ____________________________bet_id: 63 --- bets_value: Odd --- bets_odd: 2.00
#   ____________________________  ____________________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.73
#   ________________________________48 To Score In Both Halves By Teams
#   ________________________________50 Goal Line
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 3.70
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.26
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.35
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 3.10
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 2.10
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.70
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.58
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.35
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 3.00
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.38
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 6.80
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.11
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.85
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 1.95
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 3.45
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.30
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.43
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.53
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.23
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 4.10
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.45
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 2.68
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 4.50
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.19
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Over 1 --- bets_odd: 1.11
#   ____________________________  ____________________________bet_id: 50 --- bets_value: Under 1 --- bets_odd: 6.80
#   ________________________________72 Goal Line (1st Half)
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 3.10
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.35
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 7.00
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.10
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.60
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.48
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 4.15
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.22
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 2.08
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.73
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.65
#   ____________________________  ____________________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.20
#   ________________________________73 Both Teams to Score 1st Half - 2nd Half
#   ____________________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#   ______________________________ff_update_unfinished__
#   ____________________________  > No longer get supported
#   __________[6/9] Poland - III Liga - Group 1 -----#780 - 2022 - 2023-03-25 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@live.com counter is 20
#   ________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-25 03:26:06.917774
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 780
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[7/9] Poland - III Liga - Group 2 -----#781 - 2022 - 2023-03-25 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@live.com counter is 19
#   ________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-25 03:26:06.917774
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 781
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[8/9] Poland - III Liga - Group 3 -----#782 - 2022 - 2023-03-25 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@live.com counter is 18
#   ________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-25 03:26:06.917774
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 782
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[9/9] Poland - III Liga - Group 4 -----#783 - 2022 - 2023-03-25 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@live.com counter is 17
#   ________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-25 03:26:06.917774
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 783
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 1
#
#   __________________1. Poland,  III Liga - Group 4  #783 - 2022 / 968876
#   __________________fixt date 2023-03-25 11:00:00+00:00
#   __________________fix local 2023-03-25 18:00:00
#   __________________local dat 2023-03-25 03:26:06
#   __________________Lebih
#   ____________________league_rLeagues_id : 783
#   ____________________league_rLeagues_name : III Liga - Group 4
#   ____________________bookmakersapi_rLeagues_id : 11
#   ____________________bookmakers_rLeagues_name : 1xBet
#   __________________Total fixtureapi_id Row(s) : 1
#   __________________good to Go 1
#   ____________________11==11
#   ________________________1 Match Winner
#   __________________________pre_match_winner_home = '1.83',
#   __________________________pre_match_winner_draw = '4.08',
#   __________________________pre_match_winner_away = '3.14',
#   ________________________4 Asian Handicap
#   __________________________pre_asian_handicap_home_plus_0 = '1.51',
#   __________________________pre_asian_handicap_away_plus_0 = '2.55',
#   __________________________pre_asian_handicap_home_min_1 = '2.58',
#   __________________________pre_asian_handicap_away_min_1 = '1.42',
#   ________________________5 Goals Over/Under
#   __________________________pre_goals_overunder_over_35 = '2.00',
#   __________________________pre_goals_overunder_under_35 = '1.69',
#   __________________________pre_goals_overunder_over_25 = '1.35',
#   __________________________pre_goals_overunder_under_25 = '2.82',
#   __________________________pre_goals_overunder_over_30 = '1.56',
#   __________________________pre_goals_overunder_under_30 = '2.21',
#   __________________________pre_goals_overunder_over_40 = '2.77',
#   __________________________pre_goals_overunder_under_40 = '1.37',
#   ________________________12 Double Chance
#   __________________________pre_double_chance_home_draw = '1.26',
#   __________________________pre_double_chance_home_away = '1.14',
#   __________________________pre_double_chance_draw_away = '1.75',
#   ________________________21 Odd/Even
#   ____________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-25 03:26:46

# %%
# Import
from a_settings.messages import *   
from a_models.football_fixtures import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(1, space).strftime("%Y-%m-%d")  
    date_raw         = get_today(0, space)
    # --------------------------------------------------   
    ff_gak_sempet_predates(date_0, date_raw, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 21:15:44
#   __main()
#   ______get_today()
#   ________date_diff : 1
#   ________today_raw : 2023-03-25 21:15:44.879267
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-24 21:15:44.879267
#   ______ff_gak_sempet_predates()
#   ________Select leagueapi_id, league_name, league_country, season, DATE(date),   (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id)  from football_fixtures  where date = '2023-03-25'  and deleted_at is null  and pre_odd_updated_at is null  group by leagueapi_id, league_name, league_country, season, DATE(date)  order by league_country, leagueapi_id asc
#   ________Total Row(s) : 10
#   __________[1/10] Austria - Regionalliga - Mitte -----#222 - 2022 - 2023-03-25 - 11
#   __________[2/10] Austria - Regionalliga - West -----#223 - 2022 - 2023-03-25 - 11
#   __________[3/10] Colombia - Primera B -----#240 - 2023 - 2023-03-25 - 8
#   __________[4/10] Israel - Liga Alef -----#496 - 2022 - 2023-03-25 - 11
#   __________[5/10] Poland - II Liga - East -----#109 - 2022 - 2023-03-25 - 8
#   __________[6/10] Poland - III Liga - Group 1 -----#780 - 2022 - 2023-03-25 - 11
#   __________[7/10] Poland - III Liga - Group 2 -----#781 - 2022 - 2023-03-25 - 11
#   __________[8/10] Poland - III Liga - Group 3 -----#782 - 2022 - 2023-03-25 - 11
#   __________[9/10] Poland - III Liga - Group 4 -----#783 - 2022 - 2023-03-25 - 11
#   __________[10/10] World - CONCACAF Nations League -----#536 - 2022 - 2023-03-25 - 8
#   __________Are you sure want to continue? :  yes
#   __________[1/10] Austria - Regionalliga - Mitte -----#222 - 2022 - 2023-03-25 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API arya6792@gmail.com counter is 49
#   ________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-24 21:15:44.879267
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 222
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[2/10] Austria - Regionalliga - West -----#223 - 2022 - 2023-03-25 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API arya6792@gmail.com counter is 48
#   ________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-24 21:15:44.879267
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 223
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[3/10] Colombia - Primera B -----#240 - 2023 - 2023-03-25 - 8
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API arya6792@gmail.com counter is 47
#   ________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-24 21:15:44.879267
#   ________________bookmaker : 8
#   ________________season : 2023
#   ________________league : 240
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 2
#
#   __________________1. Colombia,  Primera B  #240 - 2023 / 989592
#   __________________fixt date 2023-03-25 20:00:00+00:00
#   __________________fix local 2023-03-26 03:00:00
#   __________________local dat 2023-03-24 21:15:44
#   __________________Lebih
#   ____________________league_rLeagues_id : 240
#   ____________________league_rLeagues_name : Primera B
#   ____________________bookmakersapi_rLeagues_id : 8
#   ____________________bookmakers_rLeagues_name : Bet365
#   __________________Total fixtureapi_id Row(s) : 1
#   __________________good to Go 1
#   ____________________8==8
#   ________________________1 Match Winner
#   __________________________pre_match_winner_home = '2.55',
#   __________________________pre_match_winner_draw = '3.00',
#   __________________________pre_match_winner_away = '2.63',
#   ________________________2 Home/Away
#   __________________________pre_homeaway_home = '1.83',
#   __________________________pre_homeaway_away = '1.83',
#   ________________________4 Asian Handicap
#   __________________________pre_asian_handicap_home_plus_0 = '1.83',
#   __________________________pre_asian_handicap_away_plus_0 = '1.98',
#   __________________________pre_asian_handicap_home_min_025 = '2.05',
#   __________________________pre_asian_handicap_away_min_025 = '1.75',
#   ________________________5 Goals Over/Under
#   __________________________pre_goals_overunder_over_25 = '2.50',
#   __________________________pre_goals_overunder_under_25 = '1.50',
#   ________________________7 HT/FT Double
#   ________________________10 Exact Score
#   ________________________31 Correct Score - First Half
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.50
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.25
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.50
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.75
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   ________________________12 Double Chance
#   __________________________pre_double_chance_home_draw = '1.40',
#   __________________________pre_double_chance_home_away = '1.30',
#   __________________________pre_double_chance_draw_away = '1.44',
#   ________________________13 First Half Winner
#   __________________________pre_first_half_winner_home = '3.40',
#   __________________________pre_first_half_winner_draw = '1.91',
#   __________________________pre_first_half_winner_away = '3.50',
#   ________________________14 Team To Score First
#   ____________________  ____________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.95
#   ____________________  ____________________bet_id: 14 --- bets_value: Draw --- bets_odd: 6.00
#   ____________________  ____________________bet_id: 14 --- bets_value: Away --- bets_odd: 2.25
#   ________________________19 Asian Handicap First Half
#   ________________________20 Double Chance - First Half
#   ________________________21 Odd/Even
#   ________________________22 Odd/Even - First Half
#   ____________________  ____________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.30
#   ____________________  ____________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.62
#   ________________________63 Odd/Even - Second Half
#   ____________________  ____________________bet_id: 63 --- bets_value: Odd --- bets_odd: 2.10
#   ____________________  ____________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.67
#   ________________________50 Goal Line
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.93
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 1.88
#   ________________________72 Goal Line (1st Half)
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.85
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 1.95
#   ____________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ____________________2. Colombia,  Primera B  #240 - 2023 / 989593
#   ____________________fixt date 2023-03-25 21:00:00+00:00
#   ____________________fix local 2023-03-26 04:00:00
#   ____________________local dat 2023-03-24 21:15:44
#   ____________________Lebih
#   ______________________league_rLeagues_id : 240
#   ______________________league_rLeagues_name : Primera B
#   ______________________bookmakersapi_rLeagues_id : 8
#   ______________________bookmakers_rLeagues_name : Bet365
#   ____________________Total fixtureapi_id Row(s) : 1
#   ____________________good to Go 1
#   ______________________8==8
#   __________________________1 Match Winner
#   ____________________________pre_match_winner_home = '2.00',
#   ____________________________pre_match_winner_draw = '3.40',
#   ____________________________pre_match_winner_away = '3.20',
#   __________________________2 Home/Away
#   ____________________________pre_homeaway_home = '1.53',
#   ____________________________pre_homeaway_away = '2.38',
#   __________________________4 Asian Handicap
#   ____________________________pre_asian_handicap_home_min_025 = '1.80',
#   ____________________________pre_asian_handicap_away_min_025 = '2.00',
#   __________________________5 Goals Over/Under
#   ____________________________pre_goals_overunder_over_25 = '2.00',
#   ____________________________pre_goals_overunder_under_25 = '1.80',
#   __________________________7 HT/FT Double
#   __________________________10 Exact Score
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   __________________________12 Double Chance
#   ____________________________pre_double_chance_home_draw = '1.29',
#   ____________________________pre_double_chance_home_away = '1.25',
#   ____________________________pre_double_chance_draw_away = '1.67',
#   __________________________13 First Half Winner
#   ____________________________pre_first_half_winner_home = '2.63',
#   ____________________________pre_first_half_winner_draw = '2.10',
#   ____________________________pre_first_half_winner_away = '3.75',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.67
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 2.50
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   __________________________63 Odd/Even - Second Half
#   ______________________  ______________________bet_id: 63 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.73
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.80
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.98
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.83
#   ______________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
#   __________[4/10] Israel - Liga Alef -----#496 - 2022 - 2023-03-25 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API arya6792@gmail.com counter is 46
#   ________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-24 21:15:44.879267
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 496
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[5/10] Poland - II Liga - East -----#109 - 2022 - 2023-03-25 - 8
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API arya6792@gmail.com counter is 45
#   ________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-25
#   ________________date_raw : 2023-03-24 21:15:44.879267
#   ________________bookmaker : 8
#   ________________season : 2022
#   ________________league : 109
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 5
#
#   __________________1. Poland,  II Liga - East  #109 - 2022 / 883977
#   __________________fixt date 2023-03-25 14:00:00+00:00
#   __________________fix local 2023-03-25 21:00:00
#   __________________local dat 2023-03-24 21:15:44
#   __________________Lebih
#   ____________________league_rLeagues_id : 109
#   ____________________league_rLeagues_name : II Liga - East
#   ____________________bookmakersapi_rLeagues_id : 8
#   ____________________bookmakers_rLeagues_name : Bet365
#   __________________Total fixtureapi_id Row(s) : 1
#   __________________good to Go 1
#   ____________________8==8
#   ________________________1 Match Winner
#   __________________________pre_match_winner_home = '2.70',
#   __________________________pre_match_winner_draw = '3.30',
#   __________________________pre_match_winner_away = '2.30',
#   ________________________2 Home/Away
#   __________________________pre_homeaway_home = '2.00',
#   __________________________pre_homeaway_away = '1.73',
#   ________________________3 Second Half Winner
#   __________________________pre_second_half_winner_home = '2.88',
#   __________________________pre_second_half_winner_draw = '2.50',
#   __________________________pre_second_half_winner_away = '2.63',
#   ________________________4 Asian Handicap
#   __________________________pre_asian_handicap_home_plus_0 = '2.05',
#   __________________________pre_asian_handicap_away_plus_0 = '1.75',
#   __________________________pre_asian_handicap_home_min_025 = '2.38',
#   __________________________pre_asian_handicap_away_min_025 = '1.55',
#   __________________________pre_asian_handicap_home_plus_025 = '1.75',
#   __________________________pre_asian_handicap_away_plus_025 = '2.05',
#   __________________________pre_asian_handicap_home_min_05 = '2.75',
#   __________________________pre_asian_handicap_away_min_05 = '1.43',
#   __________________________pre_asian_handicap_home_plus_05 = '1.58',
#   __________________________pre_asian_handicap_away_plus_05 = '2.35',
#   __________________________pre_asian_handicap_home_min_075 = '3.45',
#   __________________________pre_asian_handicap_away_min_075 = '1.30',
#   __________________________pre_asian_handicap_home_plus_075 = '1.43',
#   __________________________pre_asian_handicap_away_plus_075 = '2.75',
#   __________________________pre_asian_handicap_home_min_1 = '4.50',
#   __________________________pre_asian_handicap_away_min_1 = '1.19',
#   __________________________pre_asian_handicap_home_plus_1 = '1.28',
#   __________________________pre_asian_handicap_away_plus_1 = '3.55',
#   __________________________pre_asian_handicap_home_min_15 = '5.75',
#   __________________________pre_asian_handicap_away_min_15 = '1.14',
#   __________________________pre_asian_handicap_home_plus_15 = '1.20',
#   __________________________pre_asian_handicap_away_plus_15 = '4.40',
#   __________________________pre_asian_handicap_home_min_125 = '5.25',
#   __________________________pre_asian_handicap_away_min_125 = '1.16',
#   __________________________pre_asian_handicap_home_plus_125 = '1.23',
#   __________________________pre_asian_handicap_away_plus_125 = '4.10',
#   __________________________pre_asian_handicap_home_plus_175 = '1.13',
#   __________________________pre_asian_handicap_away_plus_175 = '5.90',
#   ________________________5 Goals Over/Under
#   __________________________pre_goals_overunder_over_35 = '3.00',
#   __________________________pre_goals_overunder_under_35 = '1.36',
#   __________________________pre_goals_overunder_over_15 = '1.25',
#   __________________________pre_goals_overunder_under_15 = '3.75',
#   __________________________pre_goals_overunder_over_45 = '5.50',
#   __________________________pre_goals_overunder_under_45 = '1.13',
#   __________________________pre_goals_overunder_over_25 = '1.85',
#   __________________________pre_goals_overunder_under_25 = '1.95',
#   __________________________pre_goals_overunder_over_05 = '1.02',
#   __________________________pre_goals_overunder_under_05 = '11.00',
#   __________________________pre_goals_overunder_over_55 = '9.00',
#   __________________________pre_goals_overunder_under_55 = '1.04',
#   __________________________pre_goals_overunder_over_65 = '15.00',
#   __________________________pre_goals_overunder_under_65 = '1.01',
#   __________________________pre_goals_overunder_over_75 = '21.00',
#   __________________________pre_goals_overunder_under_75 = '1.00',
#   ________________________6 Goals Over/Under First Half
#   __________________________pre_goals_overunder_first_half_over_35 = '21.00',
#   __________________________pre_goals_overunder_first_half_under_35 = '1.02',
#   __________________________pre_goals_overunder_first_half_over_15 = '2.75',
#   __________________________pre_goals_overunder_first_half_under_15 = '1.40',
#   __________________________pre_goals_overunder_first_half_over_25 = '7.00',
#   __________________________pre_goals_overunder_first_half_under_25 = '1.10',
#   __________________________pre_goals_overunder_first_half_over_05 = '1.36',
#   __________________________pre_goals_overunder_first_half_under_05 = '3.00',
#   ________________________26 Goals Over/Under - Second Half
#   __________________________pre_goals_overunder__second_half_over_35 = '11.00',
#   __________________________pre_goals_overunder__second_half_under_35 = '1.05',
#   __________________________pre_goals_overunder__second_half_over_15 = '2.00',
#   __________________________pre_goals_overunder__second_half_under_15 = '1.73',
#   __________________________pre_goals_overunder__second_half_over_25 = '4.00',
#   __________________________pre_goals_overunder__second_half_under_25 = '1.22',
#   __________________________pre_goals_overunder__second_half_over_05 = '1.20',
#   __________________________pre_goals_overunder__second_half_under_05 = '4.33',
#   ________________________7 HT/FT Double
#   ________________________27 Clean Sheet - Home
#   __________________________pre_clean_sheet__home_yes = '3.75',
#   __________________________pre_clean_sheet__home_no = '1.25',
#   ________________________28 Clean Sheet - Away
#   __________________________pre_clean_sheet__away_yes = '3.40',
#   __________________________pre_clean_sheet__away_no = '1.30',
#   ________________________8 Both Teams Score
#   __________________________pre_both_teams_score_yes = '1.67',
#   __________________________pre_both_teams_score_no = '2.10',
#   ________________________9 Handicap Result
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.36
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.17
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 9.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 12.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 8.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.11
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 23.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 23.00
#   ________________________10 Exact Score
#   ________________________11 Highest Scoring Half
#   ________________________31 Correct Score - First Half
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 151.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 151.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 7.50
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.50
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 126.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 21.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 151.00
#   ________________________12 Double Chance
#   __________________________pre_double_chance_home_draw = '1.50',
#   __________________________pre_double_chance_home_away = '1.25',
#   __________________________pre_double_chance_draw_away = '1.36',
#   ________________________13 First Half Winner
#   __________________________pre_first_half_winner_home = '3.25',
#   __________________________pre_first_half_winner_draw = '2.20',
#   __________________________pre_first_half_winner_away = '2.88',
#   ________________________14 Team To Score First
#   ____________________  ____________________bet_id: 14 --- bets_value: Home --- bets_odd: 2.20
#   ____________________  ____________________bet_id: 14 --- bets_value: Draw --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 14 --- bets_value: Away --- bets_odd: 1.80
#   ________________________15 Team To Score Last
#   ____________________  ____________________bet_id: 15 --- bets_value: Home --- bets_odd: 2.20
#   ____________________  ____________________bet_id: 15 --- bets_value: Draw --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 15 --- bets_value: Away --- bets_odd: 1.80
#   ________________________32 Win Both Halves
#   __________________________pre_win_both_halves_home = '10.00',
#   __________________________pre_win_both_halves_away = '8.00',
#   ________________________16 Total - Home
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 10.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.03
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.50
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.50
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.13
#   ________________________17 Total - Away
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.04
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.20
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.62
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 4.50
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.17
#   ________________________18 Handicap Result - First Half
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.33
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.40
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 9.50
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.75
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +2 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +2 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +2 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 12.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 126.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +3 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +3 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +3 --- bets_odd: 101.00
#   ________________________19 Asian Handicap First Half
#   ________________________20 Double Chance - First Half
#   ________________________34 Both Teams Score - First Half
#   ________________________35 Both Teams To Score - Second Half
#   ________________________36 Win To Nil
#   __________________________pre_win_to_nil_home = '5.00',
#   __________________________pre_win_to_nil_away = '4.33',
#   ________________________21 Odd/Even
#   ________________________22 Odd/Even - First Half
#   ____________________  ____________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.10
#   ____________________  ____________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   ________________________23 Home Odd/Even
#   ____________________  ____________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.00
#   ____________________  ____________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.73
#   ________________________60 Away Odd/Even
#   ____________________  ____________________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.91
#   ____________________  ____________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.80
#   ________________________39 To Win Either Half
#   __________________________pre_to_win_either_half_home = '1.83',
#   __________________________pre_to_win_either_half_away = '1.73',
#   ________________________40 Home Team Exact Goals Number
#   ________________________41 Away Team Exact Goals Number
#   ________________________24 Results/Both Teams Score
#   __________________________pre_results_both_teams_score_home_yes = '5.50',
#   __________________________pre_results_both_teams_score_draw_yes = '4.50',
#   __________________________pre_results_both_teams_score_away_yes = '4.50',
#   __________________________pre_results_both_teams_score_home_no = '5.00',
#   __________________________pre_results_both_teams_score_draw_no = '11.00',
#   __________________________pre_results_both_teams_score_away_no = '4.33',
#   ________________________25 Result/Total Goals
#   __________________________pre_result_total_goals_home_over_25 = '4.33',
#   __________________________pre_result_total_goals_draw_over_25 = '11.00',
#   __________________________pre_result_total_goals_away_over_25 = '3.75',
#   __________________________pre_result_total_goals_home_under_25 = '6.50',
#   __________________________pre_result_total_goals_draw_under_25 = '4.50',
#   __________________________pre_result_total_goals_away_under_25 = '5.50',
#   ________________________63 Odd/Even - Second Half
#   ____________________  ____________________bet_id: 63 --- bets_value: Odd --- bets_odd: 1.91
#   ____________________  ____________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.80
#   ________________________48 To Score In Both Halves By Teams
#   ________________________50 Goal Line
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.38
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.26
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 3.70
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 4.5 --- bets_odd: 5.75
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 4.5 --- bets_odd: 1.14
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 1.83
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.98
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.40
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.85
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 2.38
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.55
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.17
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.60
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 2.30
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 2.68
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.45
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.05
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.75
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.16
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 5.25
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 4.25 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 4.25 --- bets_odd: 1.15
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.33
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 3.30
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 3.55
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.28
#   ________________________72 Goal Line (1st Half)
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 2.75
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.43
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 2.5 --- bets_odd: 7.00
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 2.5 --- bets_odd: 1.10
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 5.75
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.14
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 6.25
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.12
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.30
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.60
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 3.55
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.28
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.83
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.98
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.53
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.43
#   ________________________73 Both Teams to Score 1st Half - 2nd Half
#   ____________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ____________________2. Poland,  II Liga - East  #109 - 2022 / 883978
#   ____________________fixt date 2023-03-25 13:00:00+00:00
#   ____________________fix local 2023-03-25 20:00:00
#   ____________________local dat 2023-03-24 21:15:44
#   ____________________Lebih
#   ______________________league_rLeagues_id : 109
#   ______________________league_rLeagues_name : II Liga - East
#   ______________________bookmakersapi_rLeagues_id : 8
#   ______________________bookmakers_rLeagues_name : Bet365
#   ____________________Total fixtureapi_id Row(s) : 1
#   ____________________good to Go 1
#   ______________________8==8
#   __________________________1 Match Winner
#   ____________________________pre_match_winner_home = '3.25',
#   ____________________________pre_match_winner_draw = '3.20',
#   ____________________________pre_match_winner_away = '2.00',
#   __________________________2 Home/Away
#   ____________________________pre_homeaway_home = '2.50',
#   ____________________________pre_homeaway_away = '1.50',
#   __________________________3 Second Half Winner
#   ____________________________pre_second_half_winner_home = '3.60',
#   ____________________________pre_second_half_winner_draw = '2.38',
#   ____________________________pre_second_half_winner_away = '2.40',
#   __________________________4 Asian Handicap
#   ____________________________pre_asian_handicap_home_plus_0 = '2.43',
#   ____________________________pre_asian_handicap_away_plus_0 = '1.53',
#   ____________________________pre_asian_handicap_home_min_025 = '2.85',
#   ____________________________pre_asian_handicap_away_min_025 = '1.40',
#   ____________________________pre_asian_handicap_home_plus_025 = '2.00',
#   ____________________________pre_asian_handicap_away_plus_025 = '1.80',
#   ____________________________pre_asian_handicap_home_min_05 = '3.30',
#   ____________________________pre_asian_handicap_away_min_05 = '1.33',
#   ____________________________pre_asian_handicap_home_plus_05 = '1.73',
#   ____________________________pre_asian_handicap_away_plus_05 = '2.08',
#   ____________________________pre_asian_handicap_home_min_075 = '4.25',
#   ____________________________pre_asian_handicap_away_min_075 = '1.21',
#   ____________________________pre_asian_handicap_home_plus_075 = '1.55',
#   ____________________________pre_asian_handicap_away_plus_075 = '2.38',
#   ____________________________pre_asian_handicap_home_min_1 = '6.60',
#   ____________________________pre_asian_handicap_away_min_1 = '1.11',
#   ____________________________pre_asian_handicap_home_plus_1 = '1.35',
#   ____________________________pre_asian_handicap_away_plus_1 = '3.10',
#   ____________________________pre_asian_handicap_home_plus_15 = '1.24',
#   ____________________________pre_asian_handicap_away_plus_15 = '3.90',
#   ____________________________pre_asian_handicap_home_plus_125 = '1.28',
#   ____________________________pre_asian_handicap_away_plus_125 = '3.55',
#   ____________________________pre_asian_handicap_home_plus_175 = '1.16',
#   ____________________________pre_asian_handicap_away_plus_175 = '5.25',
#   __________________________5 Goals Over/Under
#   ____________________________pre_goals_overunder_over_35 = '3.75',
#   ____________________________pre_goals_overunder_under_35 = '1.25',
#   ____________________________pre_goals_overunder_over_15 = '1.36',
#   ____________________________pre_goals_overunder_under_15 = '3.00',
#   ____________________________pre_goals_overunder_over_45 = '7.00',
#   ____________________________pre_goals_overunder_under_45 = '1.08',
#   ____________________________pre_goals_overunder_over_25 = '2.15',
#   ____________________________pre_goals_overunder_under_25 = '1.67',
#   ____________________________pre_goals_overunder_over_05 = '1.05',
#   ____________________________pre_goals_overunder_under_05 = '8.50',
#   ____________________________pre_goals_overunder_over_55 = '11.00',
#   ____________________________pre_goals_overunder_under_55 = '1.02',
#   ____________________________pre_goals_overunder_over_65 = '17.00',
#   ____________________________pre_goals_overunder_under_65 = '1.01',
#   __________________________6 Goals Over/Under First Half
#   ____________________________pre_goals_overunder_first_half_over_35 = '26.00',
#   ____________________________pre_goals_overunder_first_half_under_35 = '1.01',
#   ____________________________pre_goals_overunder_first_half_over_15 = '3.25',
#   ____________________________pre_goals_overunder_first_half_under_15 = '1.33',
#   ____________________________pre_goals_overunder_first_half_over_25 = '9.00',
#   ____________________________pre_goals_overunder_first_half_under_25 = '1.07',
#   ____________________________pre_goals_overunder_first_half_over_05 = '1.44',
#   ____________________________pre_goals_overunder_first_half_under_05 = '2.63',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________pre_goals_overunder__second_half_over_35 = '15.00',
#   ____________________________pre_goals_overunder__second_half_under_35 = '1.03',
#   ____________________________pre_goals_overunder__second_half_over_15 = '2.25',
#   ____________________________pre_goals_overunder__second_half_under_15 = '1.57',
#   ____________________________pre_goals_overunder__second_half_over_25 = '5.50',
#   ____________________________pre_goals_overunder__second_half_under_25 = '1.14',
#   ____________________________pre_goals_overunder__second_half_over_05 = '1.29',
#   ____________________________pre_goals_overunder__second_half_under_05 = '3.50',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________pre_clean_sheet__home_yes = '3.50',
#   ____________________________pre_clean_sheet__home_no = '1.29',
#   __________________________28 Clean Sheet - Away
#   ____________________________pre_clean_sheet__away_yes = '2.50',
#   ____________________________pre_clean_sheet__away_no = '1.50',
#   __________________________8 Both Teams Score
#   ____________________________pre_both_teams_score_yes = '1.91',
#   ____________________________pre_both_teams_score_no = '1.80',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.67
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.20
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.06
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 21.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.63
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 151.00
#   __________________________12 Double Chance
#   ____________________________pre_double_chance_home_draw = '1.67',
#   ____________________________pre_double_chance_home_away = '1.29',
#   ____________________________pre_double_chance_draw_away = '1.25',
#   __________________________13 First Half Winner
#   ____________________________pre_first_half_winner_home = '4.00',
#   ____________________________pre_first_half_winner_draw = '2.05',
#   ____________________________pre_first_half_winner_away = '2.75',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 1.67
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 1.67
#   __________________________32 Win Both Halves
# ...
#   __________________________________  __________________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.67
#   __________________________________  __________________________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 29.00
#   __________________________________  __________________________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   __________________________________  __________________________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 4.50
#   __________________________________  __________________________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.18
#   ______________________________________17 Total - Away
#   __________________________________  __________________________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 21.00
#   __________________________________  __________________________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.02
#   __________________________________  __________________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.75
#   __________________________________  __________________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.40
#   __________________________________  __________________________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 51.00
#   __________________________________  __________________________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   __________________________________  __________________________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 7.00
#   __________________________________  __________________________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.10
#   ______________________________________18 Handicap Result - First Half
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 9.00
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.40
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.60
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.25
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 13.00
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 4.33
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 34.00
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 11.00
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.06
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 101.00
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 41.00
#   __________________________________  __________________________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.01
#   ______________________________________19 Asian Handicap First Half
#   ______________________________________20 Double Chance - First Half
#   ______________________________________34 Both Teams Score - First Half
#   ______________________________________35 Both Teams To Score - Second Half
#   ______________________________________36 Win To Nil
#   ________________________________________pre_win_to_nil_home = '3.75',
#   ________________________________________pre_win_to_nil_away = '6.00',
#   ______________________________________21 Odd/Even
#   ______________________________________22 Odd/Even - First Half
#   __________________________________  __________________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.10
#   __________________________________  __________________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   ______________________________________39 To Win Either Half
#   ________________________________________pre_to_win_either_half_home = '1.67',
#   ________________________________________pre_to_win_either_half_away = '2.00',
#   ______________________________________40 Home Team Exact Goals Number
#   ______________________________________41 Away Team Exact Goals Number
#   ______________________________________24 Results/Both Teams Score
#   ________________________________________pre_results_both_teams_score_home_yes = '4.33',
#   ________________________________________pre_results_both_teams_score_draw_yes = '4.33',
#   ________________________________________pre_results_both_teams_score_away_yes = '6.00',
#   ________________________________________pre_results_both_teams_score_home_no = '3.75',
#   ________________________________________pre_results_both_teams_score_draw_no = '10.00',
#   ________________________________________pre_results_both_teams_score_away_no = '6.00',
#   ______________________________________25 Result/Total Goals
#   ________________________________________pre_result_total_goals_home_over_25 = '3.50',
#   ________________________________________pre_result_total_goals_draw_over_25 = '11.00',
#   ________________________________________pre_result_total_goals_away_over_25 = '5.50',
#   ________________________________________pre_result_total_goals_home_under_25 = '5.00',
#   ________________________________________pre_result_total_goals_draw_under_25 = '4.33',
#   ________________________________________pre_result_total_goals_away_under_25 = '7.00',
#   ______________________________________43 Home Team Score a Goal
#   __________________________________  __________________________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.22
#   __________________________________  __________________________________bet_id: 43 --- bets_value: No --- bets_odd: 4.00
#   ______________________________________44 Away Team Score a Goal
#   __________________________________  __________________________________bet_id: 44 --- bets_value: Yes --- bets_odd: 1.36
#   __________________________________  __________________________________bet_id: 44 --- bets_value: No --- bets_odd: 3.00
#   ______________________________________54 First 10 min Winner
#   __________________________________  __________________________________bet_id: 54 --- bets_value: Home --- bets_odd: 7.50
#   __________________________________  __________________________________bet_id: 54 --- bets_value: Draw --- bets_odd: 1.17
#   __________________________________  __________________________________bet_id: 54 --- bets_value: Away --- bets_odd: 8.50
#   ______________________________________47 Winning Margin
#   __________________________________  __________________________________bet_id: 47 --- bets_value: Draw --- bets_odd: 10.00
#   __________________________________  __________________________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 4.00
#   __________________________________  __________________________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 5.00
#   __________________________________  __________________________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 6.50
#   __________________________________  __________________________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 10.00
#   __________________________________  __________________________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 13.00
#   __________________________________  __________________________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 21.00
#   __________________________________  __________________________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 23.00
#   __________________________________  __________________________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 41.00
#   __________________________________  __________________________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 4.33
#   ______________________________________48 To Score In Both Halves By Teams
#   ______________________________________49 Total Goals/Both Teams To Score
#   ________________________________________pre_total_goals_both_teams_to_score_over_yes_25 = '2.20',
#   ________________________________________pre_total_goals_both_teams_to_score_over_no_25 = '10.00',
#   ________________________________________pre_total_goals_both_teams_to_score_under_yes_25 = '6.50',
#   ________________________________________pre_total_goals_both_teams_to_score_under_no_25 = '2.40',
#   ______________________________________91 Total Goals (3 way)
#   __________________________________  __________________________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 3.50
#   __________________________________  __________________________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 1.95
#   __________________________________  __________________________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 3.25
#   ______________________________________50 Goal Line
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 3.30
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.32
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.27
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 3.55
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 4.5 --- bets_odd: 6.40
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 4.5 --- bets_odd: 1.11
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 1.93
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.88
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.45
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.67
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 2.60
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.48
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 5.75
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.14
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.68
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 2.15
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 2.85
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.40
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.15
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.68
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.18
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 4.80
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 4.25 --- bets_odd: 5.90
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 4.25 --- bets_odd: 1.13
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.35
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 3.10
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 3.90
#   __________________________________  __________________________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.24
#   ______________________________________72 Goal Line (1st Half)
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 2.85
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.40
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 6.00
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.13
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 6.80
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.10
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.38
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.55
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 3.70
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.26
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.90
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.90
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.55
#   __________________________________  __________________________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.38
#   ______________________________________52 Halftime Result/Both Teams Score
#   ______________________________________73 Both Teams to Score 1st Half - 2nd Half
#   ______________________________________74 10 Over/Under
#   ______________________________________78 RTG_H1
#   __________________________________  __________________________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 7.00
#   __________________________________  __________________________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 10.00
#   __________________________________  __________________________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 7.50
#   __________________________________  __________________________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 2.75
#   __________________________________  __________________________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 4.33
#   __________________________________  __________________________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 5.00
#   __________________________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#   ____________________________________ff_update_unfinished__
#   __________________________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-24 21:16:50

# %%
# Import
from a_settings.messages import *   
from a_models.football_fixtures import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(0, space).strftime("%Y-%m-%d")
    date_0_raw       = get_today(0, space)  
    # --------------------------------------------------  
    date_1         = get_today(1, space).strftime("%Y-%m-%d")
    date_1_raw       = get_today(1, space)  
    # --------------------------------------------------   
    # --------------------------------------------------  
    ff_get_fixture_today_xpattern_advices(date_0, date_1, "xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 21:16:50
#   __main()
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-24 21:16:50.869284
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-24 21:16:50.869284
#   ______get_today()
#   ________date_diff : 1
#   ________today_raw : 2023-03-25 21:16:50.869284
#   ______get_today()
#   ________date_diff : 1
#   ________today_raw : 2023-03-25 21:16:50.869284
#   ______ff_get_fixture_today_xpattern_advices()
#   ________Select  date,   fixtureapi_id,   league_country,   league_name,   season,   teams_home,   teams_away   from football_fixtures  where DATE(date) >= '2023-03-24'  and DATE(date) <= '2023-03-25'  order by date asc
#   ________Total Row(s) : 708
#   ________[1/708] 2023-03-24 00:00:00
#   ________Germany - Frauen Bundesliga 2022
# #885879  MSV Duisburg W vs Eintracht Frankfurt W
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 885879
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '82'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:74810
#   __________     total_fixtures:12
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '82'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:74810
#   __________     total_fixtures:12
#   __________       --UPDATED--
#   ________[2/708] 2023-03-24 00:00:00
#   ________Germany - Frauen Bundesliga 2022
# #885882  1899 Hoffenheim W vs SGS Essen W
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 885882
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '82'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:74813
#   __________     total_fixtures:12
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '82'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:74813
#   __________     total_fixtures:12
#   __________       --UPDATED--
#   ________[3/708] 2023-03-24 00:00:00
#   ________Germany - Frauen Bundesliga 2022
# #885883  Bayer Leverkusen W vs SC Freiburg W
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 885883
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '82'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:74814
#   __________     total_fixtures:12
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '82'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:74814
#   __________     total_fixtures:12
#   __________       --UPDATED--
#   ________[4/708] 2023-03-24 00:00:00
#   ________Germany - Frauen Bundesliga 2022
# #885884  Turbine Potsdam W vs Meppen
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 885884
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '82'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:74815
#   __________     total_fixtures:12
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '82'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:74815
#   __________     total_fixtures:12
#   __________       --UPDATED--
#   ________[5/708] 2023-03-24 00:00:00
#   ________Netherlands - Eredivisie Women 2022
# #913337  Ajax W vs VV Alkmaar W
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 913337
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '91'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '91'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[6/708] 2023-03-24 00:00:00
#   ________Netherlands - Eredivisie Women 2022
# #913339  Feyenoord W vs ADO Den Haag W
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 913339
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '91'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '91'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[7/708] 2023-03-24 00:00:00
#   ________Netherlands - Eredivisie Women 2022
# #913340  Fortuna Sittard W vs Excelsior W
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 913340
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '91'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '91'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[8/708] 2023-03-24 00:00:00
#   ________Argentina - Primera Nacional 2023
# #992666  CA Estudiantes vs Aldosivi
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992666
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130809
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130809
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ________[9/708] 2023-03-24 00:00:00
#   ________Argentina - Primera Nacional 2023
# #992667  Brown DE Adrogue vs Atletico DE Rafaela
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992667
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130810
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130810
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ________[10/708] 2023-03-24 00:00:00
#   ________Argentina - Primera Nacional 2023
# #992668  Quilmes vs Deportivo Madryn
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992668
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130811
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130811
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ________[11/708] 2023-03-24 00:00:00
#   ________Argentina - Primera Nacional 2023
# #992669  Gimnasia Jujuy vs Villa Dalmine
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992669
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130812
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130812
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ________[12/708] 2023-03-24 00:00:00
#   ________Argentina - Primera Nacional 2023
# #992670  Ferro Carril Oeste vs Deportivo Maipu
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992670
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130813
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130813
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ________[13/708] 2023-03-24 00:00:00
#   ________Argentina - Primera Nacional 2023
# #992671  Deportivo Riestra vs Independ. Rivadavia
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992671
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130814
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130814
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ________[14/708] 2023-03-24 00:00:00
#   ________Argentina - Primera Nacional 2023
# #992672  Racing Cordoba vs Chaco For Ever
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992672
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130815
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130815
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ________[15/708] 2023-03-24 00:00:00
#   ________Argentina - Primera Nacional 2023
# #992673  Atlanta vs Atletico Mitre
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992673
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130816
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130816
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ________[16/708] 2023-03-24 00:00:00
#   ________Argentina - Primera Nacional 2023
# #992674  Tristan Suarez vs Chacarita Juniors
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992674
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130817
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '129'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:130817
#   __________     total_fixtures:379
#   __________       --UPDATED--
#   ________[17/708] 2023-03-24 00:00:00
#   ________World - CONCACAF Nations League 2022
# #856816  Suriname vs Mexico
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 856816
#   __________> pre_ah_pattern = 175+2+225+25+H
#   __________> pre_ah_pattern_mirror = 25_225_2_175_H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '536'
#   __________     and pre_ah_pattern = '175+2+225+25+H'
#   __________     and pre_gou_pattern = '275g3g325g35g375gG'
#   __________     and end_ah_pattern = '175+2+225+25+H'
#   __________     and end_gou_pattern = '275g3g325g35g375gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '536'
#   __________     and pre_ah_pattern_mirror = '175+2+225+25+H'
#   __________     and pre_gou_pattern = '275g3g325g35g375gG'
#   __________     and end_ah_pattern_mirror = '175+2+225+25+H'
#   __________     and end_gou_pattern = '275g3g325g35g375gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[18/708] 2023-03-24 01:05:00
#   ________Mexico - Liga de Expansión MX 2022
# #975969  Leones Negros UDG vs Monarcas
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 975969
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '263'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:106714
#   __________     total_fixtures:15
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '263'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:106714
#   __________     total_fixtures:15
#   __________       --UPDATED--
#   ________[19/708] 2023-03-24 01:10:00
#   ________Colombia - Primera A 2023
# #989340  America de Cali vs Junior
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 989340
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '239'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:115642
#   __________     total_fixtures:151
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '239'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:115642
#   __________     total_fixtures:151
#   __________       --UPDATED--
#   ________[20/708] 2023-03-24 08:30:00
#   ________Australia - Victoria NPL 2023
# #978890  Melbourne Knights vs Altona Magic
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 978890
#   __________> pre_ah_pattern = 125_1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+125+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '195'
#   __________     and pre_ah_pattern = '125_1_075_05_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '125_1_075_05_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:131163
#   __________     total_fixtures:3
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '195'
#   __________     and pre_ah_pattern_mirror = '125_1_075_05_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '125_1_075_05_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[21/708] 2023-03-24 08:30:00
#   ________Australia - New South Wales NPL 2023
# #982294  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 982294
#   __________> pre_ah_pattern = 0#025+075+H
#   __________> pre_ah_pattern_mirror = 075_025_0#H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '192'
#   __________     and pre_ah_pattern = '0#025+075+H'
#   __________     and pre_gou_pattern = '275g3g325g35g375gG'
#   __________     and end_ah_pattern = '0#025+075+H'
#   __________     and end_gou_pattern = '275g3g325g35g375gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '192'
#   __________     and pre_ah_pattern_mirror = '0#025+075+H'
#   __________     and pre_gou_pattern = '275g3g325g35g375gG'
#   __________     and end_ah_pattern_mirror = '0#025+075+H'
#   __________     and end_gou_pattern = '275g3g325g35g375gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[22/708] 2023-03-24 08:45:00
#   ________Australia - New South Wales NPL 2023
# #982295  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 982295
#   __________> pre_ah_pattern = 025+075+1+125+H
#   __________> pre_ah_pattern_mirror = 125_1_075_025_H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '192'
#   __________     and pre_ah_pattern = '025+075+1+125+H'
#   __________     and pre_gou_pattern = '275g3g325g35g375gG'
#   __________     and end_ah_pattern = '025+075+1+125+H'
#   __________     and end_gou_pattern = '275g3g325g35g375gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:134915
#   __________     total_fixtures:1
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '192'
#   __________     and pre_ah_pattern_mirror = '025+075+1+125+H'
#   __________     and pre_gou_pattern = '275g3g325g35g375gG'
#   __________     and end_ah_pattern_mirror = '025+075+1+125+H'
#   __________     and end_gou_pattern = '275g3g325g35g375gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[23/708] 2023-03-24 09:00:00
#   ________Australia - Northern NSW NPL 2023
# #981885  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 981885
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '481'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:134913
#   __________     total_fixtures:57
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '481'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:134913
#   __________     total_fixtures:57
#   __________       --UPDATED--
#   ________[24/708] 2023-03-24 09:00:00
#   ________Australia - South Australia NPL 2023
# #990723  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 990723
#   __________> pre_ah_pattern = 125_1_075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+1+125+H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '194'
#   __________     and pre_ah_pattern = '125_1_075_025_H'
#   __________     and pre_gou_pattern = '25g275g3g325g35gG'
#   __________     and end_ah_pattern = '125_1_075_025_H'
#   __________     and end_gou_pattern = '25g275g3g325g35gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '194'
#   __________     and pre_ah_pattern_mirror = '125_1_075_025_H'
#   __________     and pre_gou_pattern = '25g275g3g325g35gG'
#   __________     and end_ah_pattern_mirror = '125_1_075_025_H'
#   __________     and end_gou_pattern = '25g275g3g325g35gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[25/708] 2023-03-24 09:00:00
#   ________World - Friendlies 2023
# #1012326  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1012326
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '10'
#   __________     and pre_ah_pattern = '025_0#025+H'
#   __________     and pre_gou_pattern = '2g225g25gG'
#   __________     and end_ah_pattern = '025_0#025+H'
#   __________     and end_gou_pattern = '2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '10'
#   __________     and pre_ah_pattern_mirror = '025_0#025+H'
#   __________     and pre_gou_pattern = '2g225g25gG'
#   __________     and end_ah_pattern_mirror = '025_0#025+H'
#   __________     and end_gou_pattern = '2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[26/708] 2023-03-24 09:30:00
#   ________Australia - Victoria NPL 2023
# #978892  Heidelberg United vs Bentleigh Greens
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 978892
#   __________> pre_ah_pattern = 125_1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+125+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '195'
#   __________     and pre_ah_pattern = '125_1_075_05_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '125_1_075_05_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:131169
#   __________     total_fixtures:3
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '195'
#   __________     and pre_ah_pattern_mirror = '125_1_075_05_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '125_1_075_05_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[27/708] 2023-03-24 09:45:00
#   ________Australia - South Australia NPL 2023
# #990724  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 990724
#   __________> pre_ah_pattern = 075+1+125+15+175+H
#   __________> pre_ah_pattern_mirror = 175_15_125_1_075_H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '194'
#   __________     and pre_ah_pattern = '075+1+125+15+175+H'
#   __________     and pre_gou_pattern = '275g3g325g35g375gG'
#   __________     and end_ah_pattern = '075+1+125+15+175+H'
#   __________     and end_gou_pattern = '275g3g325g35g375gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '194'
#   __________     and pre_ah_pattern_mirror = '075+1+125+15+175+H'
#   __________     and pre_gou_pattern = '275g3g325g35g375gG'
#   __________     and end_ah_pattern_mirror = '075+1+125+15+175+H'
#   __________     and end_gou_pattern = '275g3g325g35g375gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[28/708] 2023-03-24 10:00:00
#   ________South-Korea - K3 League 2023
# #1003894  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1003894
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '295'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '295'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[29/708] 2023-03-24 10:30:00
#   ________World - Friendlies 2023
# #1012327  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1012327
#   __________> pre_ah_pattern = 05_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+05+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '10'
#   __________     and pre_ah_pattern = '05_025_0#025+H'
#   __________     and pre_gou_pattern = '2g225g25gG'
#   __________     and end_ah_pattern = '05_025_0#025+H'
#   __________     and end_gou_pattern = '2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '10'
#   __________     and pre_ah_pattern_mirror = '05_025_0#025+H'
#   __________     and pre_gou_pattern = '2g225g25gG'
#   __________     and end_ah_pattern_mirror = '05_025_0#025+H'
#   __________     and end_gou_pattern = '2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[30/708] 2023-03-24 11:00:00
#   ________Thailand - Thai League 2 2022
# #974629  Kasetsart FC vs Udon Thani
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 974629
#   __________> pre_ah_pattern = 15_125_1_075_H
#   __________> pre_ah_pattern_mirror = 075+1+125+15+H
#   __________> pre_gou_pattern = 225g25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '297'
#   __________     and pre_ah_pattern = '15_125_1_075_H'
#   __________     and pre_gou_pattern = '225g25g275g3g325gG'
#   __________     and end_ah_pattern = '15_125_1_075_H'
#   __________     and end_gou_pattern = '225g25g275g3g325gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '297'
#   __________     and pre_ah_pattern_mirror = '15_125_1_075_H'
#   __________     and pre_gou_pattern = '225g25g275g3g325gG'
#   __________     and end_ah_pattern_mirror = '15_125_1_075_H'
#   __________     and end_gou_pattern = '225g25g275g3g325gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[31/708] 2023-03-24 11:00:00
#   ________World - Friendlies 2023
# #1012328  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1012328
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 175g2g225g25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '10'
#   __________     and pre_ah_pattern = '025_0#025+H'
#   __________     and pre_gou_pattern = '175g2g225g25gG'
#   __________     and end_ah_pattern = '025_0#025+H'
#   __________     and end_gou_pattern = '175g2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '10'
#   __________     and pre_ah_pattern_mirror = '025_0#025+H'
#   __________     and pre_gou_pattern = '175g2g225g25gG'
#   __________     and end_ah_pattern_mirror = '025_0#025+H'
#   __________     and end_gou_pattern = '175g2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[32/708] 2023-03-24 11:30:00
#   ________England - Professional Development League 2022
# #948589  Colchester United U21 vs Watford U21
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 948589
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '703'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:74197
#   __________     total_fixtures:66
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '703'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:74197
#   __________     total_fixtures:66
#   __________       --UPDATED--
#   ________[33/708] 2023-03-24 12:45:00
#   ________Greece - Super League 2 2022
# #966786  Proodeftiki vs PAO Rouf
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 966786
#   __________> pre_ah_pattern = 25_225_2_175_15_H
#   __________> pre_ah_pattern_mirror = 15+175+2+225+25+H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '494'
#   __________     and pre_ah_pattern = '25_225_2_175_15_H'
#   __________     and pre_gou_pattern = '25g275g3g325g35gG'
#   __________     and end_ah_pattern = '25_225_2_175_15_H'
#   __________     and end_gou_pattern = '25g275g3g325g35gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '494'
#   __________     and pre_ah_pattern_mirror = '25_225_2_175_15_H'
#   __________     and pre_gou_pattern = '25g275g3g325g35gG'
#   __________     and end_ah_pattern_mirror = '25_225_2_175_15_H'
#   __________     and end_gou_pattern = '25g275g3g325g35gG'
#   __________    Total Row(s) : 0
#   __________       --UPDATED--
#   ________[34/708] 2023-03-24 13:00:00
#   ________World - Africa Cup of Nations - Qualification 2023
# #859179  Congo DR vs Mauritania
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 859179
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '36'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:22442
#   __________     total_fixtures:54
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '36'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:22442
#   __________     total_fixtures:54
#   __________       --UPDATED--
#   ________[35/708] 2023-03-24 13:00:00
#   ________Brazil - CBF Brasileiro U20 2023
# #1010647  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1010647
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '740'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:134949
#   __________     total_fixtures:41
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '740'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:134949
#   __________     total_fixtures:41
#   __________       --UPDATED--
#   ________[36/708] 2023-03-24 13:00:00
#   ________World - Friendlies Clubs 2023
# #1014214  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1014214
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '667'
#   __________     and pre_ah_pattern = '0#H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '0#H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:134953
#   __________     total_fixtures:1
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '667'
#   __________     and pre_ah_pattern_mirror = '0#H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '0#H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:134953
#   __________     total_fixtures:1
#   __________       --UPDATED--
#   ________[37/708] 2023-03-24 13:00:00
#   ________World - Friendlies Clubs 2023
# #1017729  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1017729
#   __________> pre_ah_pattern = 075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '667'
#   __________     and pre_ah_pattern = '075_05_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '075_05_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '667'
#   __________     and pre_ah_pattern_mirror = '075_05_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '075_05_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[38/708] 2023-03-24 13:00:00
#   ________World - Friendlies Clubs 2023
# #1017730  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1017730
#   __________> pre_ah_pattern = 15_H
#   __________> pre_ah_pattern_mirror = 15+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '667'
#   __________     and pre_ah_pattern = '15_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '15_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:134956
#   __________     total_fixtures:1
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '667'
#   __________     and pre_ah_pattern_mirror = '15_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '15_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[39/708] 2023-03-24 13:15:00
#   ________Greece - Super League 2 2022
# #966589  Almopos vs Iraklis 1908
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 966589
#   __________> pre_ah_pattern = 025+075+H
#   __________> pre_ah_pattern_mirror = 075_025_H
#   __________> pre_gou_pattern = 15g175g2g225gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '494'
#   __________     and pre_ah_pattern = '025+075+H'
#   __________     and pre_gou_pattern = '15g175g2g225gG'
#   __________     and end_ah_pattern = '025+075+H'
#   __________     and end_gou_pattern = '15g175g2g225gG'
#   __________    Total Row(s) : 1
# ...
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 988073
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '132'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:121955
#   __________     total_fixtures:299
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '132'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:121955
#   __________     total_fixtures:299
#   __________       --UPDATED--
#   ________[697/708] 2023-03-25 23:00:00
#   ________Mexico - Liga de Expansión MX 2022
# #975972  Celaya vs Venados FC
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 975972
#   __________> pre_ah_pattern = 075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '263'
#   __________     and pre_ah_pattern = '075_05_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '075_05_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:106717
#   __________     total_fixtures:3
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '263'
#   __________     and pre_ah_pattern_mirror = '075_05_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '075_05_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[698/708] 2023-03-25 23:00:00
#   ________Mexico - Liga MX Femenil 2022
# #976348  Pachuca W vs Tijuana W
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 976348
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '673'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '673'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[699/708] 2023-03-25 23:00:00
#   ________World - CONCACAF Nations League 2022
# #856818  Martinique vs Costa Rica
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 856818
#   __________> pre_ah_pattern = 1+125+15+175+H
#   __________> pre_ah_pattern_mirror = 175_15_125_1_H
#   __________> pre_gou_pattern = 25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '536'
#   __________     and pre_ah_pattern = '1+125+15+175+H'
#   __________     and pre_gou_pattern = '25g275g3g325gG'
#   __________     and end_ah_pattern = '1+125+15+175+H'
#   __________     and end_gou_pattern = '25g275g3g325gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '536'
#   __________     and pre_ah_pattern_mirror = '1+125+15+175+H'
#   __________     and pre_gou_pattern = '25g275g3g325gG'
#   __________     and end_ah_pattern_mirror = '1+125+15+175+H'
#   __________     and end_gou_pattern = '25g275g3g325gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[700/708] 2023-03-25 23:15:00
#   ________Panama - Liga Panameña de Fútbol 2023
# #984865  Deportivo Universitario vs Alianza FC
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 984865
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '304'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '304'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[701/708] 2023-03-25 23:20:00
#   ________Colombia - Primera A 2023
# #989369  Atletico Nacional vs Independiente Medellin
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 989369
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '239'
#   __________     and pre_ah_pattern = '075_05_025_H'
#   __________     and pre_gou_pattern = '2g225g25gG'
#   __________     and end_ah_pattern = '075_05_025_H'
#   __________     and end_gou_pattern = '2g225g25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:115814
#   __________     total_fixtures:4
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '239'
#   __________     and pre_ah_pattern_mirror = '075_05_025_H'
#   __________     and pre_gou_pattern = '2g225g25gG'
#   __________     and end_ah_pattern_mirror = '075_05_025_H'
#   __________     and end_gou_pattern = '2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[702/708] 2023-03-25 23:30:00
#   ________Paraguay - Division Profesional - Apertura 2023
# #986907  Cerro Porteno vs Nacional Asuncion
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 986907
#   __________> pre_ah_pattern = 1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '250'
#   __________     and pre_ah_pattern = '1_075_05_H'
#   __________     and pre_gou_pattern = '2g225g25g275gG'
#   __________     and end_ah_pattern = '1_075_05_H'
#   __________     and end_gou_pattern = '2g225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '250'
#   __________     and pre_ah_pattern_mirror = '1_075_05_H'
#   __________     and pre_gou_pattern = '2g225g25g275gG'
#   __________     and end_ah_pattern_mirror = '1_075_05_H'
#   __________     and end_gou_pattern = '2g225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[703/708] 2023-03-25 23:30:00
#   ________USA - Major League Soccer 2023
# #980845  Charlotte vs New York Red Bulls
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 980845
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '253'
#   __________     and pre_ah_pattern = '025_0#025+H'
#   __________     and pre_gou_pattern = '2g225g25gG'
#   __________     and end_ah_pattern = '025_0#025+H'
#   __________     and end_gou_pattern = '2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '253'
#   __________     and pre_ah_pattern_mirror = '025_0#025+H'
#   __________     and pre_gou_pattern = '2g225g25gG'
#   __________     and end_ah_pattern_mirror = '025_0#025+H'
#   __________     and end_gou_pattern = '2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[704/708] 2023-03-25 23:30:00
#   ________USA - Major League Soccer 2023
# #980846  Columbus Crew vs Atlanta United FC
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 980846
#   __________> pre_ah_pattern = 05_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+05+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '253'
#   __________     and pre_ah_pattern = '05_025_0#025+H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern = '05_025_0#025+H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:132169
#   __________     total_fixtures:6
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '253'
#   __________     and pre_ah_pattern_mirror = '05_025_0#025+H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern_mirror = '05_025_0#025+H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:132169
#   __________     total_fixtures:3
#   __________       --UPDATED--
#   ________[705/708] 2023-03-25 23:30:00
#   ________USA - Major League Soccer 2023
# #980847  DC United vs New England Revolution
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 980847
#   __________> pre_ah_pattern = 025_H
#   __________> pre_ah_pattern_mirror = 025+H
#   __________> pre_gou_pattern = 25g275gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '253'
#   __________     and pre_ah_pattern = '025_H'
#   __________     and pre_gou_pattern = '25g275gG'
#   __________     and end_ah_pattern = '025_H'
#   __________     and end_gou_pattern = '25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '253'
#   __________     and pre_ah_pattern_mirror = '025_H'
#   __________     and pre_gou_pattern = '25g275gG'
#   __________     and end_ah_pattern_mirror = '025_H'
#   __________     and end_gou_pattern = '25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[706/708] 2023-03-25 23:30:00
#   ________USA - Major League Soccer 2023
# #980848  Inter Miami vs Chicago Fire
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 980848
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '253'
#   __________     and pre_ah_pattern = '075_05_025_H'
#   __________     and pre_gou_pattern = '225g25g275gG'
#   __________     and end_ah_pattern = '075_05_025_H'
#   __________     and end_gou_pattern = '225g25g275gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:132171
#   __________     total_fixtures:3
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '253'
#   __________     and pre_ah_pattern_mirror = '075_05_025_H'
#   __________     and pre_gou_pattern = '225g25g275gG'
#   __________     and end_ah_pattern_mirror = '075_05_025_H'
#   __________     and end_gou_pattern = '225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[707/708] 2023-03-25 23:30:00
#   ________USA - Major League Soccer 2023
# #980849  Philadelphia Union vs Orlando City SC
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 980849
#   __________> pre_ah_pattern = 075_H
#   __________> pre_ah_pattern_mirror = 075+H
#   __________> pre_gou_pattern = 25g275gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '253'
#   __________     and pre_ah_pattern = '075_H'
#   __________     and pre_gou_pattern = '25g275gG'
#   __________     and end_ah_pattern = '075_H'
#   __________     and end_gou_pattern = '25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '253'
#   __________     and pre_ah_pattern_mirror = '075_H'
#   __________     and pre_gou_pattern = '25g275gG'
#   __________     and end_ah_pattern_mirror = '075_H'
#   __________     and end_gou_pattern = '25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[708/708] 2023-03-25 23:30:00
#   ________USA - USL Championship 2023
# #1008367  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1008367
#   __________> pre_ah_pattern = 025+075+1+H
#   __________> pre_ah_pattern_mirror = 1_075_025_H
#   __________> pre_gou_pattern = 225g25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '255'
#   __________     and pre_ah_pattern = '025+075+1+H'
#   __________     and pre_gou_pattern = '225g25g275g3g325gG'
#   __________     and end_ah_pattern = '025+075+1+H'
#   __________     and end_gou_pattern = '225g25g275g3g325gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:135009
#   __________     total_fixtures:1
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '255'
#   __________     and pre_ah_pattern_mirror = '025+075+1+H'
#   __________     and pre_gou_pattern = '225g25g275g3g325gG'
#   __________     and end_ah_pattern_mirror = '025+075+1+H'
#   __________     and end_gou_pattern = '225g25g275g3g325gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:135009
#   __________     total_fixtures:1
#   __________       --UPDATED--
# # -------------------------------------------------- End at 2023-03-24 23:09:44

# %%
# X-ODDS READER
# Import
from a_settings.messages import *  
from a_models.predefine import *  

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------   
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=1)
    preday1 = today + DD
    day1 = preday1.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    print(space + "> day1 : " +  str(preday1) ) 
    # --------------------------------------------------   
    pd_get_fixtures_next_match(day0, preday1, 'fixture', space) 
#     pd_get_fixtures_next_match(day0, day1, ROUTES, space)
    # --------------------------------------------------  
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 23:09:44
#   __main()
#   ____get_date()
#   ______> day0 : 2023-03-24
#   ______> day1 : 2023-03-25 23:09:44.991712
#   ________pd_get_fixtures_next_match()
#   __________Select   teams_home_id,  teams_away_id,  leagueapi_id,  season,  fixtureapi_id,  teams_home,  teams_away,  date  , pre_both_teams_score_yes  , pre_both_teams_score_no  , pre_rcard_yes  , pre_rcard_no  , pre_first_half_winner_home  , pre_first_half_winner_draw  , pre_first_half_winner_away  , pre_second_half_winner_home  , pre_second_half_winner_draw  , pre_second_half_winner_away  , pre_htft_double_home_home  , pre_htft_double_home_draw  , pre_htft_double_home_away  , pre_htft_double_draw_home  , pre_htft_double_draw_draw  , pre_htft_double_draw_away  , pre_htft_double_away_home  , pre_htft_double_away_draw  , pre_htft_double_away_away  , pre_both_teams_score__first_half_yes  , pre_both_teams_score__first_half_no  , pre_both_teams_to_score__second_half_yes  , pre_both_teams_to_score__second_half_no  , pre_results_both_teams_score_home_yes  , pre_results_both_teams_score_draw_yes  , pre_results_both_teams_score_away_yes  , pre_results_both_teams_score_home_no  , pre_results_both_teams_score_draw_no  , pre_results_both_teams_score_away_no  , pre_to_score_in_both_halves_by_teams_home , pre_to_score_in_both_halves_by_teams_away , pre_total_goals_both_teams_to_score_over_yes_25 , pre_total_goals_both_teams_to_score_over_no_25 , pre_total_goals_both_teams_to_score_under_yes_25 , pre_total_goals_both_teams_to_score_under_no_25 , pre_both_teams_to_score_1st_half__2nd_half_yes_yes , pre_both_teams_to_score_1st_half__2nd_half_yes_no , pre_both_teams_to_score_1st_half__2nd_half_no_yes , pre_both_teams_to_score_1st_half__2nd_half_no_no , pre_highest_scoring_half_first , pre_highest_scoring_half_draw , pre_highest_scoring_half_second , pre_double_chance_home_draw , pre_double_chance_home_away , pre_double_chance_draw_away , pre_double_chance__first_half_home_draw , pre_double_chance__first_half_home_away , pre_double_chance__first_half_draw_away , pre_oddeven_odd , pre_oddeven_even , pre_result_total_goals_home_over_35 , pre_result_total_goals_draw_over_35 , pre_result_total_goals_away_over_35 , pre_result_total_goals_home_under_35 , pre_result_total_goals_draw_under_35 , pre_result_total_goals_away_under_35 , pre_result_total_goals_home_over_25 , pre_result_total_goals_draw_over_25 , pre_result_total_goals_away_over_25 , pre_result_total_goals_home_under_25 , pre_result_total_goals_draw_under_25 , pre_result_total_goals_away_under_25 , pre_clean_sheet__home_yes , pre_clean_sheet__home_no , pre_clean_sheet__away_yes , pre_clean_sheet__away_no , pre_win_both_halves_home , pre_win_both_halves_away , pre_win_to_nil_home , pre_win_to_nil_away , pre_to_win_either_half_home , pre_to_win_either_half_away , pre_halftime_result_both_teams_score_home_yes , pre_halftime_result_both_teams_score_draw_yes , pre_halftime_result_both_teams_score_away_yes , pre_halftime_result_both_teams_score_home_no , pre_halftime_result_both_teams_score_draw_no , pre_halftime_result_both_teams_score_away_no , pre_exact_goals_number__first_half_0 , pre_exact_goals_number__first_half_1 , pre_exact_goals_number__first_half_2 , pre_exact_goals_number__first_half_3 , pre_exact_goals_number__first_half_4 , pre_exact_goals_number__first_half_more_5 , pre_second_half_exact_goals_number_0 , pre_second_half_exact_goals_number_1 , pre_second_half_exact_goals_number_2 , pre_second_half_exact_goals_number_3 , pre_second_half_exact_goals_number_4 , pre_second_half_exact_goals_number_more_5 , pre_home_team_exact_goals_number_0 , pre_home_team_exact_goals_number_1 , pre_home_team_exact_goals_number_2 , pre_home_team_exact_goals_number_more_3 , pre_away_team_exact_goals_number_0 , pre_away_team_exact_goals_number_1 , pre_away_team_exact_goals_number_2 , pre_away_team_exact_goals_number_more_3 from football_fixtures  where date >= '2023-03-24'  and date <= '2023-03-25 23:09:44.991712'  and fixture_status like 'Not Started'  and deleted_at is null  order by date asc
#   __________Total Row(s) : 504
#   ____________[1/504] 536 - 2022 -----#Suriname 8171 - Mexico 16 - 2023-03-24 00:00:00
#   ______________pre_first_half_winner_away:1.53
#   ______________pre_second_half_winner_away:1.36
#   ______________pre_to_win_either_half_away:1.1
#   ______________pre_win_to_nil_away:1.8
#   ______________pre_result_total_goals_away_under_35:2.2
#   ______________pre_double_chance_home_draw:5.5
#   ______________pre_clean_sheet__home_yes:13.0
#   ______________pre_to_win_either_half_home:6.0
#
#   ____________[2/504] 263 - 2022 -----#Leones Negros UDG 2307 - Monarcas 2284 - 2023-03-24 01:05:00
#
#   ____________[3/504] 239 - 2023 -----#America de Cali 1138 - Junior 1135 - 2023-03-24 01:10:00
#
#   ____________[4/504] 195 - 2023 -----#Melbourne Knights 3807 - Altona Magic 3797 - 2023-03-24 08:30:00
#   ______________pre_second_half_winner_home:1.95
#
#   ____________[5/504] 195 - 2023 -----#Heidelberg United 3803 - Bentleigh Greens 3799 - 2023-03-24 09:30:00
#   ______________pre_second_half_winner_home:1.95
#
#   ____________[6/504] 297 - 2022 -----#Kasetsart FC 2800 - Udon Thani 2862 - 2023-03-24 11:00:00
#   ______________pre_second_half_winner_home:1.86
#
#   ____________[7/504] 703 - 2022 -----#Colchester United U21 20083 - Watford U21 20019 - 2023-03-24 11:30:00
#
#   ____________[8/504] 494 - 2022 -----#Proodeftiki 13924 - PAO Rouf 13931 - 2023-03-24 12:45:00
#   ______________pre_first_half_winner_home:1.53
#   ______________pre_second_half_winner_home:1.37
#   ______________pre_both_teams_score_yes:2.6
#   ______________pre_double_chance_draw_away:4.94
#
#   ____________[9/504] 36 - 2023 -----#Congo DR 1508 - Mauritania 1491 - 2023-03-24 13:00:00
#
#   ____________[10/504] 494 - 2022 -----#Almopos 12368 - Iraklis 1908 17991 - 2023-03-24 13:15:00
#   ______________pre_first_half_winner_draw:1.89
#
#   ____________[11/504] 274 - 2022 -----#Arema FC 2438 - Pusamania Borneo 2442 - 2023-03-24 13:30:00
#
#   ____________[12/504] 274 - 2022 -----#Persik Kediri 4241 - Persita 4244 - 2023-03-24 13:30:00
#   ______________pre_first_half_winner_draw:1.99
#
#   ____________[13/504] 274 - 2022 -----#Persib Bandung 2445 - Bhayangkara FC 2443 - 2023-03-24 13:30:00
#
#   ____________[14/504] 506 - 2022 -----#Žilina II 10546 - Pohronie 4134 - 2023-03-24 13:30:00
#   ______________pre_second_half_winner_home:1.88
#
#   ____________[15/504] 36 - 2023 -----#Uganda 1519 - Tanzania 1489 - 2023-03-24 14:00:00
#
#   ____________[16/504] 702 - 2022 -----#Derby County U21 19745 - Middlesbrough U21 11910 - 2023-03-24 14:00:00
#   ______________pre_first_half_winner_away:1.81
#   ______________pre_second_half_winner_away:1.65
#   ______________pre_both_teams_score_no:2.66
#
#   ____________[17/504] 361 - 2023 -----#Nevėžis 3865 - FA Šiauliai II 18840 - 2023-03-24 14:30:00
#   ______________pre_first_half_winner_home:1.75
#   ______________pre_second_half_winner_home:1.58
#   ______________pre_double_chance_draw_away:3.0
#
#   ____________[18/504] 211 - 2022 -----#HNK Cibalia 1021 - Croatia Zmijavci 6254 - 2023-03-24 14:30:00
#   ______________pre_second_half_winner_home:1.99
#
#   ____________[19/504] 667 - 2023 -----#FC Luzern 644 - Bellinzona 6616 - 2023-03-24 14:30:00
#   ______________pre_first_half_winner_home:1.91
#
#   ____________[20/504] 667 - 2023 -----#EIF 2078 - haka 2080 - 2023-03-24 15:00:00
#   ______________pre_first_half_winner_away:1.8
#
#   ____________[21/504] 667 - 2023 -----#ODD Ballklubb 330 - Sandefjord 332 - 2023-03-24 15:00:00
#
#   ____________[22/504] 667 - 2023 -----#EIF 2078 - haka 2080 - 2023-03-24 15:00:00
#   ______________pre_first_half_winner_away:1.73
#
#   ____________[23/504] 890 - 2022 -----#Poland U20 10298 - Czech Republic U20 18047 - 2023-03-24 15:00:00
#
#   ____________[24/504] 36 - 2023 -----#Nigeria 19 - Guinea-Bissau 1513 - 2023-03-24 16:00:00
#
#   ____________[25/504] 36 - 2023 -----#Cape Verde Islands 1533 - Eswatini 2995 - 2023-03-24 16:00:00
#
#   ____________[26/504] 36 - 2023 -----#Ivory Coast 1501 - Comoros 1524 - 2023-03-24 16:00:00
#
#   ____________[27/504] 36 - 2023 -----#South Africa 1531 - Liberia 1525 - 2023-03-24 16:00:00
#
#   ____________[28/504] 667 - 2023 -----#Kristiansund BK 320 - Viking 759 - 2023-03-24 16:00:00
#   ____________[29/504] 204 - 2022 -----#Denizlispor 3570 - Boluspor 3569 - 2023-03-24 17:00:00
#
#   ____________[30/504] 204 - 2022 -----#Samsunspor 3603 - Altınordu 3567 - 2023-03-24 17:00:00
#   ______________pre_first_half_winner_home:1.8
#   ______________pre_second_half_winner_home:1.57
#   ______________pre_to_win_either_half_home:1.18
#   ______________pre_win_to_nil_home:2.0
#   ______________pre_result_total_goals_home_over_25:2.0
#   ______________pre_double_chance_draw_away:3.4
#   ______________pre_clean_sheet__away_yes:8.0
#   ______________pre_to_win_either_half_away:4.33
#
#   ____________[31/504] 374 - 2022 -----#Triglav 4363 - Aluminij 4358 - 2023-03-24 17:00:00
#   ______________pre_second_half_winner_away:1.96
#
#   ____________[32/504] 374 - 2022 -----#Nafta 4376 - Brinje-Grosuplje 12744 - 2023-03-24 17:00:00
#
#   ____________[33/504] 361 - 2023 -----#Neptūną Klaipėda 14384 - Minija 3864 - 2023-03-24 17:00:00
#   ______________pre_first_half_winner_home:1.79
#   ______________pre_second_half_winner_home:1.63
#
#   ____________[34/504] 960 - 2023 -----#Bulgaria 1103 - Montenegro 1109 - 2023-03-24 17:00:00
#   ______________pre_first_half_winner_draw:1.91
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#
#   ____________[35/504] 549 - 2023 -----#Rosengård W 11075 - Piteå 10900 - 2023-03-24 17:00:00
#   ______________pre_first_half_winner_home:1.5
#   ______________pre_second_half_winner_home:1.33
#   ______________pre_to_win_either_half_home:1.1
#   ______________pre_win_to_nil_home:1.73
#   ______________pre_result_total_goals_home_under_35:2.2
#   ______________pre_double_chance_draw_away:4.33
#   ______________pre_clean_sheet__away_yes:9.0
#   ______________pre_to_win_either_half_away:6.0
#
#   ____________[36/504] 667 - 2023 -----#BAK '07 9351 - Hertha Berlin 159 - 2023-03-24 17:00:00
#   ______________pre_first_half_winner_away:1.36
#   ______________pre_double_chance_home_draw:6.5
#
#   ____________[37/504] 63 - 2022 -----#Chateauroux 107 - Bastia-Borgo 3019 - 2023-03-24 17:30:00
#   ______________pre_first_half_winner_home:1.86
#   ______________pre_second_half_winner_home:1.67
#
#   ____________[38/504] 63 - 2022 -----#Sedan 1310 - Dunkerque 1304 - 2023-03-24 17:30:00
#   ______________pre_first_half_winner_draw:1.99
#
#   ____________[39/504] 63 - 2022 -----#Gobelins 9238 - Bourg-en-bresse 01 430 - 2023-03-24 17:30:00
#   ______________pre_first_half_winner_draw:1.9
#
#   ____________[40/504] 63 - 2022 -----#RED Star FC 93 104 - Orleans 103 - 2023-03-24 17:30:00
#
#   ____________[41/504] 63 - 2022 -----#Cholet 1292 - Versailles 3131 - 2023-03-24 17:30:00
#   ______________pre_first_half_winner_draw:1.95
#
#   ____________[42/504] 63 - 2022 -----#Stade Briochin 3229 - Nancy 102 - 2023-03-24 17:30:00
#   ______________pre_first_half_winner_draw:1.9
#
#   ____________[43/504] 63 - 2022 -----#Avranches 1303 - Le Puy Foot 3069 - 2023-03-24 17:30:00
#
#   ____________[44/504] 63 - 2022 -----#Villefranche 1302 - Concarneau 1300 - 2023-03-24 17:30:00
#   ______________pre_first_half_winner_draw:1.99
#
#   ____________[45/504] 64 - 2022 -----#Le Havre W 14006 - FC Fleury 91 W 1677 - 2023-03-24 17:30:00
#   ______________pre_first_half_winner_away:1.73
#   ______________pre_second_half_winner_away:1.57
#   ______________pre_double_chance_home_draw:3.18
#
#   ____________[46/504] 222 - 2022 -----#Leoben 8326 - Bad Gleichenberg 4935 - 2023-03-24 17:45:00
#   ______________pre_first_half_winner_home:1.84
#   ______________pre_second_half_winner_home:1.67
#
#   ____________[47/504] 222 - 2022 -----#Kalsdorf 4946 - Deutschlandsberger SC 4972 - 2023-03-24 17:45:00
#   ______________pre_second_half_winner_away:1.84
#
#   ____________[48/504] 221 - 2022 -----#Mannsdorf-Großenzersdorf 4952 - Draßburg 4937 - 2023-03-24 17:45:00
#   ______________pre_first_half_winner_home:1.96
#   ______________pre_second_half_winner_home:1.78
#
#   ____________[49/504] 80 - 2022 -----#Hallescher FC 1316 - MSV Duisburg 187 - 2023-03-24 18:00:00
#
#   ____________[50/504] 83 - 2022 -----#Bayern München II 4674 - Augsburg II 9324 - 2023-03-24 18:00:00
#
#   ____________[51/504] 83 - 2022 -----#Wacker Burghausen 9337 - Heimstetten 9329 - 2023-03-24 18:00:00
#   ______________pre_first_half_winner_home:2.0
#   ______________pre_second_half_winner_home:1.8
#
#   ____________[52/504] 84 - 2022 -----#SSV Jeddeloh 1655 - Werder Bremen II 1330 - 2023-03-24 18:00:00
#   ______________pre_both_teams_score_no:2.5
#
#   ____________[53/504] 122 - 2022 -----#B 93 6009 - AB Copenhagen 2060 - 2023-03-24 18:00:00
#
#   ____________[54/504] 122 - 2022 -----#Skive 2068 - Aarhus Fremad 6004 - 2023-03-24 18:00:00
#   ______________pre_second_half_winner_away:1.91
#
#   ____________[55/504] 86 - 2022 -----#Kickers Offenbach 1628 - Balingen 9360 - 2023-03-24 18:00:00
#   ______________pre_first_half_winner_home:1.91
#   ______________pre_second_half_winner_home:1.73
#   ______________pre_to_win_either_half_home:1.25
#   ______________pre_result_total_goals_home_over_25:2.1
#
#   ____________[56/504] 86 - 2022 -----#FC Astoria Walldorf 1626 - VfR Aalen 1327 - 2023-03-24 18:00:00
#
#   ____________[57/504] 87 - 2022 -----#Rot Weiss Ahlen 12839 - Wiedenbrück 12897 - 2023-03-24 18:00:00
#
#   ____________[58/504] 753 - 2022 -----#SG Sonnenhof Grossaspach 1317 - Mutschelbach 19255 - 2023-03-24 18:00:00
#   ______________pre_second_half_winner_home:1.92
#
#   ____________[59/504] 753 - 2022 -----#FC Nottingen 1638 - Backnang 16113 - 2023-03-24 18:00:00
#   ______________pre_both_teams_score_no:3.38
#
#   ____________[60/504] 616 - 2023 -----#America-RN 2233 - Santa Cruz RN 2222 - 2023-03-24 18:00:00
#   ______________pre_first_half_winner_home:1.54
#   ______________pre_second_half_winner_home:1.38
#   ______________pre_double_chance_draw_away:4.32
#
#   ____________[61/504] 10 - 2023 -----#Uzbekistan 1568 - Bolivia 2381 - 2023-03-24 18:00:00
#   ______________pre_total_goals_both_teams_to_score_under_no_25:2.0
#
#   ____________[62/504] 740 - 2023 -----#Goiás U20 12961 - Cruzeiro U20 13000 - 2023-03-24 18:00:00
#
#   ____________[63/504] 63 - 2022 -----#Martigues 3200 - Le Mans 1298 - 2023-03-24 18:30:00
#
#   ____________[64/504] 745 - 2022 -----#Harksheide 19470 - Rugenbergen 16082 - 2023-03-24 18:30:00
#   ______________pre_both_teams_score_no:2.85
#
#   ____________[65/504] 745 - 2022 -----#Osdorf 12826 - Eimsbütteler TV 13947 - 2023-03-24 18:30:00
#   ______________pre_first_half_winner_away:1.47
#   ______________pre_second_half_winner_away:1.34
#   ______________pre_double_chance_home_draw:4.7
#
#   ____________[66/504] 745 - 2022 -----#Altona 93 9338 - Concordia 16085 - 2023-03-24 18:30:00
#   ______________pre_both_teams_score_no:2.7
#
#   ____________[67/504] 84 - 2022 -----#Hannover 96 II 9341 - SV Drochtersen/assel 1623 - 2023-03-24 18:30:00
#
#   ____________[68/504] 751 - 2022 -----#SSVg Velbert 12847 - KFC Uerdingen 05 1322 - 2023-03-24 18:30:00
#
#   ____________[69/504] 747 - 2022 -----#Sprockhovel 14527 - Bövinghausen 14650 - 2023-03-24 18:30:00
#   ______________pre_second_half_winner_away:1.92
#   ______________pre_both_teams_score_no:2.6
#
#   ____________[70/504] 748 - 2022 -----#Spelle-Venhaus 14787 - Bersenbrück 14635 - 2023-03-24 18:30:00
#   ______________pre_both_teams_score_no:2.66
#
#   ____________[71/504] 749 - 2022 -----#Komet Arsten 16093 - BTS Neustadt 16090 - 2023-03-24 18:30:00
#   ______________pre_both_teams_score_no:3.38
#
#   ____________[72/504] 746 - 2022 -----#Bonner SC 1637 - Viktoria Arnoldsweiler 14816 - 2023-03-24 18:45:00
#   ______________pre_first_half_winner_home:1.33
#   ______________pre_second_half_winner_home:1.22
#   ______________pre_double_chance_draw_away:7.3
#
#   ____________[73/504] 36 - 2023 -----#Egypt 32 - Malawi 1495 - 2023-03-24 19:00:00
#
#   ____________[74/504] 36 - 2023 -----#Mali 1500 - Gambia 1492 - 2023-03-24 19:00:00
#
#   ____________[75/504] 36 - 2023 -----#Equatorial Guinea 1521 - Botswana 1520 - 2023-03-24 19:00:00
#
#   ____________[76/504] 36 - 2023 -----#Senegal 13 - Mozambique 1512 - 2023-03-24 19:00:00
#
#   ____________[77/504] 84 - 2022 -----#VfB Lubeck 1625 - BW Lohne 14629 - 2023-03-24 19:00:00
#   ______________pre_first_half_winner_home:1.62
#   ______________pre_second_half_winner_home:1.44
#   ______________pre_to_win_either_half_home:1.14
#   ______________pre_win_to_nil_home:2.0
#   ______________pre_result_total_goals_home_over_25:1.95
#   ______________pre_double_chance_draw_away:3.6
#   ______________pre_clean_sheet__away_yes:8.0
#   ______________pre_to_win_either_half_away:4.33
#
#   ____________[78/504] 536 - 2022 -----#Anguilla 8150 - St. Lucia 5540 - 2023-03-24 19:00:00
#   ______________pre_first_half_winner_away:1.8
#   ______________pre_second_half_winner_away:1.62
#   ______________pre_to_win_either_half_away:1.2
#   ______________pre_result_total_goals_away_over_25:1.91
#   ______________pre_double_chance_home_draw:3.0
#   ______________pre_clean_sheet__home_yes:9.0
#
#   ____________[79/504] 10 - 2023 -----#Kuwait 1570 - Philippines 1555 - 2023-03-24 19:00:00
#   ______________pre_first_half_winner_home:1.91
#   ______________pre_second_half_winner_home:1.62
#   ______________pre_to_win_either_half_home:1.22
#   ______________pre_result_total_goals_home_over_25:2.05
#   ______________pre_clean_sheet__away_yes:8.0
#
#   ____________[80/504] 183 - 2022 -----#Clyde 6762 - Airdrie United 4668 - 2023-03-24 19:30:00
#   ______________pre_second_half_winner_away:1.83
#
#   ____________[81/504] 44 - 2022 -----#Everton W 1855 - Liverpool W 1847 - 2023-03-24 19:30:00
#
#   ____________[82/504] 111 - 2022 -----#Llandudno 362 - Conwy Borough 5612 - 2023-03-24 19:30:00
#   ______________pre_first_half_winner_home:1.49
#   ______________pre_second_half_winner_home:1.36
#   ______________pre_double_chance_draw_away:4.74
#
#   ____________[83/504] 111 - 2022 -----#Ruthin Town 5624 - Buckley Town 5609 - 2023-03-24 19:30:00
#   ______________pre_both_teams_score_no:2.63
#
#   ____________[84/504] 111 - 2022 -----#llanelli AFC 355 - Briton Ferry 2201 - 2023-03-24 19:30:00
#   ______________pre_both_teams_score_no:2.81
#
#   ____________[85/504] 111 - 2022 -----#Abergavenny Town 7579 - Ynyshir Albions 7601 - 2023-03-24 19:30:00
#   ______________pre_both_teams_score_no:2.85
#
#   ____________[86/504] 146 - 2022 -----#Genk W 1786 - Gent W 1789 - 2023-03-24 19:30:00
#   ______________pre_first_half_winner_home:1.92
#   ______________pre_second_half_winner_home:1.73
#
#   ____________[87/504] 146 - 2022 -----#White Star Woluwe W 14034 - Charleroi W 14036 - 2023-03-24 19:30:00
#   ______________pre_second_half_winner_home:1.93
#
#   ____________[88/504] 180 - 2022 -----#Ayr Utd 1387 - Cove Rangers 6763 - 2023-03-24 19:45:00
#   ______________pre_first_half_winner_home:2.0
#   ______________pre_second_half_winner_home:1.8
#
#   ____________[89/504] 180 - 2022 -----#Inverness CT 903 - Partick 901 - 2023-03-24 19:45:00
#
#   ____________[90/504] 180 - 2022 -----#Morton 1383 - Hamilton Academical 248 - 2023-03-24 19:45:00
#
#   ____________[91/504] 180 - 2022 -----#Queen's Park 6778 - Arbroath 4249 - 2023-03-24 19:45:00
#   ______________pre_second_half_winner_home:2.0
#
#   ____________[92/504] 183 - 2022 -----#Edinburgh City 6766 - Queen of the South 1384 - 2023-03-24 19:45:00
#
#   ____________[93/504] 183 - 2022 -----#Falkirk 1389 - Kelty Hearts 6773 - 2023-03-24 19:45:00
#   ______________pre_first_half_winner_home:1.91
#   ______________pre_second_half_winner_home:1.67
#   ______________pre_to_win_either_half_home:1.25
#   ______________pre_result_total_goals_home_over_25:2.2
#
#   ____________[94/504] 408 - 2022 -----#Dungannon Swifts 5351 - Linfield 583 - 2023-03-24 19:45:00
#   ______________pre_first_half_winner_away:1.64
#   ______________pre_second_half_winner_away:1.47
#   ______________pre_double_chance_home_draw:3.94
#
#   ____________[95/504] 60 - 2022 -----#Tiverton Town 7753 - Plymouth Parkway 8899 - 2023-03-24 19:45:00
#
#   ____________[96/504] 358 - 2023 -----#Galway United 3851 - Longford Town 3853 - 2023-03-24 19:45:00
#   ______________pre_first_half_winner_home:1.67
#   ______________pre_second_half_winner_home:1.5
#   ______________pre_to_win_either_half_home:1.14
#   ______________pre_win_to_nil_home:1.73
#   ______________pre_result_total_goals_home_over_25:1.91
#   ______________pre_both_teams_score_yes:2.63
#   ______________pre_double_chance_draw_away:3.75
#   ______________pre_clean_sheet__away_yes:7.5
#   ______________pre_to_win_either_half_away:5.5
#
#   ____________[97/504] 358 - 2023 -----#Bray Wanderers 3847 - Wexford 3855 - 2023-03-24 19:45:00
#
#   ____________[98/504] 358 - 2023 -----#Kerry 11328 - Athlone Town 3846 - 2023-03-24 19:45:00
#   ______________pre_second_half_winner_away:1.8
#
#   ____________[99/504] 358 - 2023 -----#Treaty United 16498 - Waterford 3845 - 2023-03-24 19:45:00
#   ______________pre_second_half_winner_away:1.83
#
#   ____________[100/504] 960 - 2023 -----#France 2 - Netherlands 1118 - 2023-03-24 19:45:00
#   ______________pre_second_half_winner_home:1.91
#
#   ____________[101/504] 960 - 2023 -----#Gibraltar 1093 - Greece 1117 - 2023-03-24 19:45:00
#   ______________pre_first_half_winner_away:1.33
#   ______________pre_second_half_winner_away:1.2
#   ______________pre_to_win_either_half_away:1.05
#   ______________pre_win_both_halves_away:1.73
#   ______________pre_win_to_nil_away:1.5
#   ______________pre_result_total_goals_away_over_35:2.05
#   ______________pre_result_total_goals_away_under_35:1.95
#   ______________pre_both_teams_score_yes:3.4
#   ______________pre_double_chance_home_draw:10.0
#   ______________pre_clean_sheet__home_yes:17.0
#   ______________pre_to_win_either_half_home:11.0
#   ______________pre_win_both_halves_home:101.0
#
#   ____________[102/504] 960 - 2023 -----#Czech Republic 770 - Poland 24 - 2023-03-24 19:45:00
#
#   ____________[103/504] 960 - 2023 -----#Moldova 1114 - Faroe Islands 1098 - 2023-03-24 19:45:00
#   ______________pre_first_half_winner_draw:1.91
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#
#   ____________[104/504] 960 - 2023 -----#Sweden 5 - Belgium 1 - 2023-03-24 19:45:00
#
#   ____________[105/504] 960 - 2023 -----#Austria 775 - Azerbaijan 1096 - 2023-03-24 19:45:00
#   ______________pre_first_half_winner_home:1.62
#   ______________pre_second_half_winner_home:1.44
#   ______________pre_to_win_either_half_home:1.13
#   ______________pre_win_to_nil_home:1.67
#   ______________pre_result_total_goals_home_over_25:1.91
#   ______________pre_both_teams_score_yes:2.63
#   ______________pre_double_chance_draw_away:4.33
#   ______________pre_clean_sheet__away_yes:9.0
#   ______________pre_to_win_either_half_away:6.0
#
#   ____________[106/504] 960 - 2023 -----#Serbia 14 - Lithuania 1097 - 2023-03-24 19:45:00
#   ______________pre_first_half_winner_home:1.33
#   ______________pre_second_half_winner_home:1.2
#   ______________pre_to_win_either_half_home:1.04
#   ______________pre_win_both_halves_home:1.67
#   ______________pre_win_to_nil_home:1.44
#   ______________pre_result_total_goals_home_over_35:1.8
#   ______________pre_both_teams_score_yes:2.63
#   ______________pre_double_chance_draw_away:11.0
#   ______________pre_clean_sheet__away_yes:15.0
#   ______________pre_to_win_either_half_away:10.0
#   ______________pre_win_both_halves_away:101.0
#
#   ____________[107/504] 110 - 2022 -----#GAP Connah S Quay FC 357 - Newtown AFC 358 - 2023-03-24 19:45:00
#   ______________pre_second_half_winner_home:1.83
#
#   ____________[108/504] 36 - 2023 -----#Burkina Faso 1502 - Togo 1534 - 2023-03-24 20:00:00
#
#   ____________[109/504] 184 - 2022 -----#East Fife 6764 - Elgin City 6767 - 2023-03-24 20:00:00
#
#   ____________[110/504] 141 - 2022 -----#FC Cartagena 5262 - Lugo 716 - 2023-03-24 20:00:00
#   ______________pre_total_goals_both_teams_to_score_under_no_25:2.0
#
#   ____________[111/504] 358 - 2023 -----#Finn Harps 3841 - Cobh Ramblers 3849 - 2023-03-24 20:00:00
#
#   ____________[112/504] 536 - 2022 -----#Bahamas 5157 - Trinidad and Tobago 5168 - 2023-03-24 20:00:00
#   ______________pre_first_half_winner_away:1.57
#   ______________pre_second_half_winner_away:1.4
#   ______________pre_to_win_either_half_away:1.11
#   ______________pre_win_to_nil_away:1.73
#   ______________pre_result_total_goals_away_under_35:2.1
#   ______________pre_result_total_goals_away_over_25:1.67
#   ______________pre_both_teams_score_yes:2.5
#   ______________pre_double_chance_home_draw:5.0
#   ______________pre_clean_sheet__home_yes:11.0
#   ______________pre_to_win_either_half_home:6.0
#
#   ____________[113/504] 36 - 2023 -----#Cameroon 1530 - Namibia 1493 - 2023-03-24 20:30:00
#
#   ____________[114/504] 36 - 2023 -----#Tunisia 28 - Libya 1526 - 2023-03-24 20:30:00
#
#   ____________[115/504] 450 - 2022 -----#Arucas 15472 - Las Palmas II 9574 - 2023-03-24 21:00:00
#   ______________pre_first_half_winner_draw:1.91
#
#   ____________[116/504] 450 - 2022 -----#Estrella 20275 - UD San Fernando 9804 - 2023-03-24 21:00:00
#   ______________pre_first_half_winner_away:1.88
#   ______________pre_second_half_winner_away:1.69
#
#   ____________[117/504] 36 - 2023 -----#Guinea 1509 - Ethiopia 1506 - 2023-03-24 21:30:00
#
#   ____________[118/504] 250 - 2023 -----#Club Guarani 1174 - Guairena FC 2138 - 2023-03-24 22:00:00
#   ______________pre_second_half_winner_home:1.91
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.95
#
#   ____________[119/504] 269 - 2023 -----#Rentistas 2371 - Cerrito 2367 - 2023-03-24 22:00:00
#   ______________pre_first_half_winner_draw:2.0
#
#   ____________[120/504] 255 - 2023 -----#Pittsburgh Riverhounds 4010 - Miami FC 9030 - 2023-03-24 23:00:00
#
#   ____________[121/504] 722 - 2022 -----#Inter Playa del Carmen 12793 - Tritons Vallarta 17790 - 2023-03-24 23:00:00
#
#   ____________[122/504] 711 - 2023 -----#Lautaro de Buin 5641 - Iberia 5640 - 2023-03-24 23:00:00
#
#   ____________[123/504] 740 - 2023 -----#Grêmio U20 13011 - Santos U20 13055 - 2023-03-24 23:00:00
#
#   ____________[124/504] 263 - 2022 -----#Alebrijes de Oaxaca 2300 - CA La Paz 19024 - 2023-03-24 23:05:00
#
#   ____________[125/504] 162 - 2022 -----#Guadalupe FC 821 - Sporting San Jose 2047 - 2023-03-24 23:30:00
#
#   ____________[126/504] 536 - 2022 -----#Grenada 5533 - USA 2384 - 2023-03-25 00:00:00
#   ______________pre_first_half_winner_away:1.25
#   ______________pre_second_half_winner_away:1.14
#   ______________pre_total_goals_both_teams_to_score_over_no_25:1.83
#   ______________pre_to_win_either_half_away:1.02
#   ______________pre_win_both_halves_away:1.5
#   ______________pre_win_to_nil_away:1.36
#   ______________pre_result_total_goals_away_over_35:1.67
#   ______________pre_both_teams_score_yes:3.25
#   ______________pre_double_chance_home_draw:13.0
#   ______________pre_clean_sheet__home_yes:23.0
#   ______________pre_to_win_either_half_home:15.0
#   ______________pre_win_both_halves_home:101.0
#
#   ____________[127/504] 536 - 2022 -----#Nicaragua 5164 - St. Vincent / Grenadines 5541 - 2023-03-25 00:00:00
#   ______________pre_first_half_winner_home:1.5
#   ______________pre_second_half_winner_home:1.33
#   ______________pre_to_win_either_half_home:1.08
#   ______________pre_win_to_nil_home:1.67
#   ______________pre_result_total_goals_home_under_35:2.05
#   ______________pre_double_chance_draw_away:5.5
#   ______________pre_clean_sheet__away_yes:13.0
#   ______________pre_to_win_either_half_away:6.5
#   ______________pre_win_both_halves_away:101.0
#
#   ____________[128/504] 268 - 2023 -----#Defensor Sporting 2350 - Plaza Colonia 2355 - 2023-03-25 00:15:00
#
#   ____________[129/504] 304 - 2023 -----#Independiente de La Chorrera 2890 - Plaza Amador 2883 - 2023-03-25 01:00:00
#
#   ____________[130/504] 263 - 2022 -----#Cancún 14276 - Cimarrones 2301 - 2023-03-25 01:05:00
#
#   ____________[131/504] 239 - 2023 -----#Rionegro Aguilas 1144 - Envigado 1129 - 2023-03-25 01:10:00
#
#   ____________[132/504] 281 - 2023 -----#Universitario 2540 - Cienciano 2562 - 2023-03-25 01:30:00
#
#   ____________[133/504] 536 - 2022 -----#Belize 5528 - Guatemala 5161 - 2023-03-25 02:00:00
#   ______________pre_first_half_winner_away:1.67
#   ______________pre_second_half_winner_away:1.5
#   ______________pre_to_win_either_half_away:1.14
#   ______________pre_win_to_nil_away:1.8
#   ______________pre_result_total_goals_away_over_25:1.83
#   ______________pre_double_chance_home_draw:4.0
#   ______________pre_clean_sheet__home_yes:9.0
#   ______________pre_to_win_either_half_home:5.0
#
#   ____________[134/504] 673 - 2022 -----#Querétaro W 14871 - Pumas UNAM W 14870 - 2023-03-25 03:00:00
#
#   ____________[135/504] 262 - 2022 -----#Mazatlán 14002 - Leon 2289 - 2023-03-25 03:05:00
#   ______________pre_total_goals_both_teams_to_score_over_yes_25:2.0
#
#   ____________[136/504] 190 - 2022 -----#Newcastle Jets FC W 1975 - Wellington Phoenix W 17905 - 2023-03-25 04:00:00
#
#   ____________[137/504] 190 - 2022 -----#Sydney FC W 1968 - Adelaide United W 1972 - 2023-03-25 04:00:00
#
#   ____________[138/504] 190 - 2022 -----#Western United W 20370 - Canberra United W 1970 - 2023-03-25 04:00:00
#
#   ____________[139/504] 195 - 2023 -----#Moreland City 16785 - North Geelong Warriors 16787 - 2023-03-25 04:00:00
#
#   ____________[140/504] 195 - 2023 -----#Avondale 3798 - Green Gully 3802 - 2023-03-25 04:15:00
#
#   ____________[141/504] 195 - 2023 -----#Dandenong Thunder 3801 - Port Melbourne 3810 - 2023-03-25 08:00:00
#
#   ____________[142/504] 195 - 2023 -----#Oakleigh Cannons 3808 - Hume City 3804 - 2023-03-25 08:45:00
#
#   ____________[143/504] 685 - 2022 -----#Jablonec II 12797 - Sokol Zápy 7356 - 2023-03-25 09:15:00
#
#   ____________[144/504] 685 - 2022 -----#Benešov 7273 - Ústí nad Labem 3735 - 2023-03-25 09:15:00
#
#   ____________[145/504] 685 - 2022 -----#Hradec Králové II 14495 - Pardubice II 14747 - 2023-03-25 09:15:00
#
#   ____________[146/504] 685 - 2022 -----#Přepeře 7336 - Sokol Živanice 7358 - 2023-03-25 09:30:00
#
#   ____________[147/504] 204 - 2022 -----#Keçiörengücü 3595 - Genclerbirligi 997 - 2023-03-25 10:30:00
#
#   ____________[148/504] 204 - 2022 -----#Tuzlaspor 3609 - Goztepe 994 - 2023-03-25 10:30:00
#
#   ____________[149/504] 205 - 2022 -----#İnegölspor 3612 - Somaspor 6538 - 2023-03-25 11:00:00
#
#   ____________[150/504] 205 - 2022 -----#Bayburt İÖİ 6338 - Nazilli Belediyespor 7415 - 2023-03-25 11:00:00
#
#   ____________[151/504] 205 - 2022 -----#Erokspor 7402 - Batman Petrolspor 7395 - 2023-03-25 11:00:00
#
#   ____________[152/504] 205 - 2022 -----#24 Erzincanspor 7392 - Şanlıurfaspor 3613 - 2023-03-25 11:00:00
#
#   ____________[153/504] 205 - 2022 -----#Düzcespor 7399 - Arnavutköy Belediyespor 15101 - 2023-03-25 11:00:00
#
#   ____________[154/504] 205 - 2022 -----#Tarsus İdman Yurdu 3607 - Bursaspor 1003 - 2023-03-25 11:00:00
#
#   ____________[155/504] 205 - 2022 -----#Amed 3579 - Yeni Çorumspor 6343 - 2023-03-25 11:00:00
#
#   ____________[156/504] 205 - 2022 -----#Ankaraspor 780 - Afjet Afyonspor 3565 - 2023-03-25 11:00:00
#
#   ____________[157/504] 205 - 2022 -----#Menemen Belediyespor 3599 - Isparta 32 Spor 6523 - 2023-03-25 11:00:00
#
#   ____________[158/504] 552 - 2022 -----#Belediye Derincespor 6511 - Yeni Orduspor 7426 - 2023-03-25 11:00:00
#
#   ____________[159/504] 205 - 2022 -----#Fethiyespor 3590 - Kocaelispor 7411 - 2023-03-25 11:00:00
#
#   ____________[160/504] 205 - 2022 -----#Kırklarelispor 3596 - Buca FK 7396 - 2023-03-25 11:00:00
#
#   ____________[161/504] 205 - 2022 -----#Hekimoğlu Trabzon 6340 - Ankara Demirspor 3581 - 2023-03-25 11:00:00
#
#   ____________[162/504] 205 - 2022 -----#Pazarspor 7420 - Kırşehir Belediyespor 6341 - 2023-03-25 11:00:00
#
#   ____________[163/504] 205 - 2022 -----#Zonguldak Kömürspor 3611 - Etimesgut Belediyespor 3587 - 2023-03-25 11:00:00
#
#   ____________[164/504] 205 - 2022 -----#Balıkesirspor 3568 - Serik Belediyespor 7421 - 2023-03-25 11:00:00
#
#   ____________[165/504] 205 - 2022 -----#Utaş Uşakspor 3610 - Sarıyer 3605 - 2023-03-25 11:00:00
#
#   ____________[166/504] 205 - 2022 -----#Van BB 6342 - Karacabey Belediyespor 7407 - 2023-03-25 11:00:00
#
#   ____________[167/504] 553 - 2022 -----#Bayrampaşaspor 3585 - Ayvalıkgücü Belediyespor 13407 - 2023-03-25 11:00:00
#
#   ____________[168/504] 554 - 2022 -----#Akhisar Belediye 995 - Siirt İl Özel İdaresi 6537 - 2023-03-25 11:00:00
#
#   ____________[169/504] 783 - 2022 -----#Wieczysta Kraków 17115 - Orlęta Radzyń Podlaski 14144 - 2023-03-25 11:00:00
#
#   ____________[170/504] 781 - 2022 -----#Vineta Wolin 19620 - Polonia Środa 6948 - 2023-03-25 11:30:00
#
#   ____________[171/504] 122 - 2022 -----#HIK 6021 - Brabrand 2071 - 2023-03-25 11:45:00
#
#   ____________[172/504] 494 - 2022 -----#AEK Athens II 18016 - Apollon Smirnis 951 - 2023-03-25 11:45:00
#
#   ____________[173/504] 85 - 2022 -----#Lichtenberg 9354 - SV Babelsberg 03 1622 - 2023-03-25 12:00:00
#
#   ____________[174/504] 84 - 2022 -----#Schwarz-Weiß Rehden 9345 - Teutonia Ottensen 12878 - 2023-03-25 12:00:00
#
#   ____________[175/504] 862 - 2022 -----#Dalum 6013 - Næsby 8635 - 2023-03-25 12:00:00
#
#   ____________[176/504] 749 - 2022 -----#Werder Bremen III 16097 - Geestemünde 12769 - 2023-03-25 12:00:00
#
#   ____________[177/504] 450 - 2022 -----#Panadería Pulido 9800 - Marino 9799 - 2023-03-25 12:00:00
#   ____________[178/504] 781 - 2022 -----#Unia Swarzędz 16257 - Zawisza Bydgoszcz 13843 - 2023-03-25 12:00:00
#
#   ____________[179/504] 84 - 2022 -----#Weiche Flensburg 1649 - Atlas Delmenhorst 4260 - 2023-03-25 12:30:00
#
#   ____________[180/504] 51 - 2022 -----#Slough Town 4685 - Ebbsfleet United 1840 - 2023-03-25 12:30:00
#
#   ____________[181/504] 450 - 2022 -----#Tamaraceite 9415 - Tenerife II 9802 - 2023-03-25 12:30:00
#
#   ____________[182/504] 862 - 2022 -----#FA 2000 8634 - Vanløse 6065 - 2023-03-25 12:45:00
#
#   ____________[183/504] 80 - 2022 -----#VfB Oldenburg 9347 - FC Viktoria Koln 1620 - 2023-03-25 13:00:00
#
#   ____________[184/504] 80 - 2022 -----#Waldhof Mannheim 4268 - VfL Osnabruck 1324 - 2023-03-25 13:00:00
#
#   ____________[185/504] 80 - 2022 -----#Rot-weiss Essen 1621 - SV Wehen 1319 - 2023-03-25 13:00:00
#
#   ____________[186/504] 80 - 2022 -----#SV Meppen 1318 - Erzgebirge AUE 190 - 2023-03-25 13:00:00
#
#   ____________[187/504] 80 - 2022 -----#Dynamo Dresden 183 - Bayreuth 9325 - 2023-03-25 13:00:00
#
#   ____________[188/504] 80 - 2022 -----#Verl 4265 - SV Elversberg 1660 - 2023-03-25 13:00:00
#
#   ____________[189/504] 83 - 2022 -----#Türkgücü-Ataspor 9335 - Eichstätt 4262 - 2023-03-25 13:00:00
#
#   ____________[190/504] 83 - 2022 -----#Hankofen-Hailing 12780 - SpVgg Unterhaching 1314 - 2023-03-25 13:00:00
#
#   ____________[191/504] 83 - 2022 -----#Rain / Lech 9333 - Ansbach 14621 - 2023-03-25 13:00:00
#
#   ____________[192/504] 83 - 2022 -----#Greuther Fürth II 9328 - Illertissen 9330 - 2023-03-25 13:00:00
#
#   ____________[193/504] 83 - 2022 -----#Aubstadt 9323 - Buchbach 9326 - 2023-03-25 13:00:00
#
#   ____________[194/504] 83 - 2022 -----#FC Wurzburger Kickers 784 - FC Schweinfurt 05 1635 - 2023-03-25 13:00:00
#
#   ____________[195/504] 204 - 2022 -----#Altay 3566 - Manisa BBSK 3597 - 2023-03-25 13:00:00
#
#   ____________[196/504] 84 - 2022 -----#Kickers Emden 12804 - Holstein Kiel II 9344 - 2023-03-25 13:00:00
#
#   ____________[197/504] 862 - 2022 -----#Holstebro 6028 - Ishøj 8645 - 2023-03-25 13:00:00
#
#   ____________[198/504] 862 - 2022 -----#Middelfart 6042 - SfB-Oure 6052 - 2023-03-25 13:00:00
#
#   ____________[199/504] 862 - 2022 -----#Silkeborg KFUM 8648 - VSK Århus 6064 - 2023-03-25 13:00:00
#
#   ____________[200/504] 862 - 2022 -----#AB Tårnby 8641 - Lyseng 6038 - 2023-03-25 13:00:00
#
#   ____________[201/504] 86 - 2022 -----#Eintracht Trier 1627 - Barockstadt Fulda-Lehn. 12735 - 2023-03-25 13:00:00
#
#   ____________[202/504] 86 - 2022 -----#SSV ULM 1846 1652 - FSV Frankfurt 1332 - 2023-03-25 13:00:00
#
#   ____________[203/504] 86 - 2022 -----#TSV Steinbach 1656 - TuS RW Koblenz 1657 - 2023-03-25 13:00:00
#
#   ____________[204/504] 86 - 2022 -----#FSV Mainz 05 II 1331 - Hoffenheim II 9364 - 2023-03-25 13:00:00
#
#   ____________[205/504] 86 - 2022 -----#Bahlinger SC 9359 - Wormatia Worms 1663 - 2023-03-25 13:00:00
#
#   ____________[206/504] 86 - 2022 -----#Hessen Kassel 12788 - FC 08 Homburg 1634 - 2023-03-25 13:00:00
#
#   ____________[207/504] 86 - 2022 -----#Stuttgart II 12867 - SGV Freiberg 12846 - 2023-03-25 13:00:00
#
#   ____________[208/504] 87 - 2022 -----#SV Rodinghausen 1650 - Fortuna Koln 1326 - 2023-03-25 13:00:00
#
#   ____________[209/504] 87 - 2022 -----#FC Bocholt 12764 - Preussen Munster 1313 - 2023-03-25 13:00:00
#
#   ____________[210/504] 87 - 2022 -----#Lippstadt 08 9372 - Fortuna Düsseldorf II 9369 - 2023-03-25 13:00:00
#
#   ____________[211/504] 87 - 2022 -----#Kaan-Marienborn 12799 - Düren Merzenich 12754 - 2023-03-25 13:00:00
#
#   ____________[212/504] 753 - 2022 -----#Stuttgarter Kickers 12868 - FV Ravensburg 1624 - 2023-03-25 13:00:00
#
#   ____________[213/504] 753 - 2022 -----#Göppinger SV 12777 - Neckarsulmer SU 12819 - 2023-03-25 13:00:00
#
#   ____________[214/504] 744 - 2022 -----#Union Neumünster 16076 - Heider SV 9343 - 2023-03-25 13:00:00
#
#   ____________[215/504] 744 - 2022 -----#Pansdorf 16074 - Husumer 14496 - 2023-03-25 13:00:00
#
#   ____________[216/504] 748 - 2022 -----#Schöningen 19475 - Germania Egestorf 1632 - 2023-03-25 13:00:00
#
#   ____________[217/504] 221 - 2022 -----#Fach-Donaufeld 8366 - Scheiblingkirchen 4982 - 2023-03-25 13:00:00
#
#   ____________[218/504] 754 - 2022 -----#Dynamo Schwerin 18384 - Optik Rathenow 9356 - 2023-03-25 13:00:00
#
#   ____________[219/504] 754 - 2022 -----#RSV Eintracht 14754 - Union Fürstenwalde 9357 - 2023-03-25 13:00:00
#
#   ____________[220/504] 702 - 2022 -----#Blackburn Rovers U21 19744 - Arsenal U21 7189 - 2023-03-25 13:00:00
#
#   ____________[221/504] 749 - 2022 -----#Vatan Sport 16096 - Aumund-Vegesack 13937 - 2023-03-25 13:00:00
#
#   ____________[222/504] 781 - 2022 -----#Solec K. 18408 - Gedania Gdansk 18385 - 2023-03-25 13:00:00
#
#   ____________[223/504] 268 - 2023 -----#Danubio 2352 - Deportivo Maldonado 2370 - 2023-03-25 13:00:00
#
#   ____________[224/504] 361 - 2023 -----#Jonava 3862 - Trakai II 3868 - 2023-03-25 13:00:00
#
#   ____________[225/504] 83 - 2022 -----#Nürnberg II 9332 - Viktoria Aschaffenburg 9336 - 2023-03-25 13:30:00
#
#   ____________[226/504] 274 - 2022 -----#Persebaya Surabaya 2446 - PS TIRA 2449 - 2023-03-25 13:30:00
#
#   ____________[227/504] 506 - 2022 -----#Dubnica 10532 - Považská Bystrica 14062 - 2023-03-25 13:30:00
#   ______________pre_both_teams_score_no:2.51
#
#   ____________[228/504] 506 - 2022 -----#Púchov 10540 - Rača 14046 - 2023-03-25 13:30:00
#   ______________pre_second_half_winner_home:1.92
#
#   ____________[229/504] 506 - 2022 -----#Humenné 14068 - Dolný Kubín 14956 - 2023-03-25 13:30:00
#   ______________pre_second_half_winner_home:1.88
#
#   ____________[230/504] 506 - 2022 -----#Slavoj Trebišov 10543 - Tatran Prešov 10550 - 2023-03-25 13:30:00
#
#   ____________[231/504] 492 - 2022 -----#Excelsior Maassluis 17129 - Noordwijk 1247 - 2023-03-25 13:30:00
#
#   ____________[232/504] 492 - 2022 -----#SVV Scheveningen 1250 - Volendam II 10321 - 2023-03-25 13:30:00
#
#   ____________[233/504] 492 - 2022 -----#OFC Oostzaan 1232 - FC Lisse 1257 - 2023-03-25 13:30:00
#
#   ____________[234/504] 750 - 2022 -----#Baunatal 4261 - Hadamar 14550 - 2023-03-25 13:30:00
#
#   ____________[235/504] 64 - 2022 -----#Montpellier W 1675 - Paris Saint Germain W 1667 - 2023-03-25 13:30:00
#
#   ____________[236/504] 64 - 2022 -----#Stade de Reims W 4911 - Soyaux W 1669 - 2023-03-25 13:30:00
#
#   ____________[237/504] 64 - 2022 -----#Bordeaux W 1671 - Paris FC W 1676 - 2023-03-25 13:30:00
#
#   ____________[238/504] 64 - 2022 -----#Dijon W 1679 - Rodez W 1668 - 2023-03-25 13:30:00
#
#   ____________[239/504] 64 - 2022 -----#Lyon W 1674 - Guingamp W 1672 - 2023-03-25 13:30:00
#
#   ____________[240/504] 348 - 2022 -----#Přeštice 7337 - Sokol Hostouň 7350 - 2023-03-25 13:30:00
#
#   ____________[241/504] 745 - 2022 -----#Curslack-Neuengamme 14653 - Victoria Hamburg 12890 - 2023-03-25 14:00:00
#
#   ____________[242/504] 374 - 2022 -----#Rudar 4361 - Bilje 4367 - 2023-03-25 14:00:00
#
#   ____________[243/504] 374 - 2022 -----#Beltinci 4366 - Krško 4365 - 2023-03-25 14:00:00
#   ______________pre_first_half_winner_home:1.82
#
#   ____________[244/504] 374 - 2022 -----#Bistrica 6718 - Ilirija 4381 - 2023-03-25 14:00:00
#   ______________pre_first_half_winner_away:1.97
#
#   ____________[245/504] 374 - 2022 -----#Fužinar 4373 - Rogaška 4379 - 2023-03-25 14:00:00
#
#   ____________[246/504] 492 - 2022 -----#Rijnsburgse Boys 1248 - HHC 1278 - 2023-03-25 14:00:00
#
#   ____________[247/504] 492 - 2022 -----#Ijsselmeervogels 1280 - Koninklijke HFC 1246 - 2023-03-25 14:00:00
#
#   ____________[248/504] 492 - 2022 -----#AFC Amsterdam 1252 - Kozakken Boys 1242 - 2023-03-25 14:00:00
#
#   ____________[249/504] 755 - 2022 -----#Einheit Rudolstadt 14548 - An der Fahner Höhe 16124 - 2023-03-25 14:00:00
#
#   ____________[250/504] 753 - 2022 -----#FC Holzhausen 19467 - CFR Pforzheim 1659 - 2023-03-25 14:00:00
#
#   ____________[251/504] 753 - 2022 -----#Bissingen 16114 - FC 08 Villingen 1619 - 2023-03-25 14:00:00
#
#   ____________[252/504] 750 - 2022 -----#Eintracht Frankfurt II 19217 - TSV Steinbach II 19468 - 2023-03-25 14:00:00
#
#   ____________[253/504] 750 - 2022 -----#Hanau 93 12779 - FC Gießen 9362 - 2023-03-25 14:00:00
#
#   ____________[254/504] 750 - 2022 -----#Fernwald 14677 - Waldgirmes 12894 - 2023-03-25 14:00:00
#
#   ____________[255/504] 750 - 2022 -----#Weidenhausen 19469 - Unter-Flockenbach 14808 - 2023-03-25 14:00:00
#   ____________[256/504] 750 - 2022 -----#Bayern Alzenau 9361 - Rot-Weiß Walldorf 16102 - 2023-03-25 14:00:00
#
#   ____________[257/504] 750 - 2022 -----#Viktoria Griesheim 12892 - SV Steinbach 16103 - 2023-03-25 14:00:00
#
#   ____________[258/504] 748 - 2022 -----#Ramlingen / Ehlershausen 16089 - Papenburg 14746 - 2023-03-25 14:00:00
#
#   ____________[259/504] 221 - 2022 -----#Siegendorf 4983 - Krems 5004 - 2023-03-25 14:00:00
#
#   ____________[260/504] 221 - 2022 -----#SC Wiener Neustadt 1396 - TWL Elektra 16999 - 2023-03-25 14:00:00
#
#   ____________[261/504] 749 - 2022 -----#Blumenthaler SV 16091 - Leher 1644 - 2023-03-25 14:00:00
#
#   ____________[262/504] 749 - 2022 -----#OSC Bremerhaven 16094 - Oberneuland 4263 - 2023-03-25 14:00:00
#
#   ____________[263/504] 510 - 2022 -----#Bavois 6615 - Biel-Bienne 12700 - 2023-03-25 14:00:00
#
#   ____________[264/504] 349 - 2022 -----#Vítkovice 3732 - Slovácko II 8623 - 2023-03-25 14:00:00
#   ______________pre_first_half_winner_away:1.82
#
#   ____________[265/504] 349 - 2022 -----#Blansko 7276 - Zlín II 8625 - 2023-03-25 14:00:00
#
#   ____________[266/504] 349 - 2022 -----#Frýdlant 7289 - Velké Meziříčí 7373 - 2023-03-25 14:00:00
#
#   ____________[267/504] 349 - 2022 -----#Znojmo 3734 - Slovan Rosice 7347 - 2023-03-25 14:00:00
#
#   ____________[268/504] 349 - 2022 -----#Frýdek-Místek 7288 - Hranice 7300 - 2023-03-25 14:00:00
#
#   ____________[269/504] 349 - 2022 -----#Hodonín 7297 - Hanácká 7291 - 2023-03-25 14:00:00
#
#   ____________[270/504] 349 - 2022 -----#Uherský Brod 8624 - Hlučín 7296 - 2023-03-25 14:00:00
#
#   ____________[271/504] 348 - 2022 -----#Loko Vltavín 7315 - Admira Praha 7268 - 2023-03-25 14:00:00
#
#   ____________[272/504] 348 - 2022 -----#Motorlet Praha 7319 - Viktoria Plzeň II 8620 - 2023-03-25 14:00:00
#
#   ____________[273/504] 348 - 2022 -----#Zbuzany 7380 - Jiskra Domažlice 7304 - 2023-03-25 14:00:00
#
#   ____________[274/504] 348 - 2022 -----#Povltava FA 14005 - Baník Sokolov 3721 - 2023-03-25 14:00:00
#
#   ____________[275/504] 348 - 2022 -----#Bohemians 1905 II 14473 - Králův Dvůr 7312 - 2023-03-25 14:00:00
#
#   ____________[276/504] 348 - 2022 -----#České Budějovice II 8629 - Dukla Praha II 15132 - 2023-03-25 14:00:00
#
#   ____________[277/504] 783 - 2022 -----#Avia Świdnik 16264 - KSZO 1929 6943 - 2023-03-25 14:00:00
#
#   ____________[278/504] 783 - 2022 -----#Korona Kielce II 16267 - Podlasie Biała Podlaska 16269 - 2023-03-25 14:00:00
#
#   ____________[279/504] 781 - 2022 -----#Starogard Gdański 16256 - Stargard Szczeciński 6959 - 2023-03-25 14:00:00
#
#   ____________[280/504] 781 - 2022 -----#Sokół Kleczew 16255 - Olimpia Grudziądz 4247 - 2023-03-25 14:00:00
#
#   ____________[281/504] 111 - 2022 -----#Chirk AAA 7685 - Llanidloes Town 6463 - 2023-03-25 14:00:00
#
#   ____________[282/504] 111 - 2022 -----#Carmarthen Town 359 - Goytre United 2187 - 2023-03-25 14:00:00
#
#   ____________[283/504] 685 - 2022 -----#Baník Souš 7271 - Slovan Velvary 7348 - 2023-03-25 14:00:00
#
#   ____________[284/504] 960 - 2023 -----#Scotland 1108 - Cyprus 1106 - 2023-03-25 14:00:00
#   ______________pre_first_half_winner_home:1.67
#   ______________pre_second_half_winner_home:1.5
#   ______________pre_to_win_either_half_home:1.14
#   ______________pre_win_to_nil_home:1.8
#   ______________pre_result_total_goals_home_over_25:1.91
#   ______________pre_both_teams_score_yes:2.5
#   ______________pre_double_chance_draw_away:3.75
#   ______________pre_clean_sheet__away_yes:8.0
#   ______________pre_to_win_either_half_away:5.5
#
#   ____________[285/504] 492 - 2022 -----#TEC 1255 - Katwijk 1237 - 2023-03-25 14:30:00
#
#   ____________[286/504] 753 - 2022 -----#Freiburger FC 16115 - Oberachern 12822 - 2023-03-25 14:30:00
#
#   ____________[287/504] 753 - 2022 -----#Reutlingen 13932 - Hollenbach 17048 - 2023-03-25 14:30:00
#
#   ____________[288/504] 221 - 2022 -----#Traiskirchen 4961 - Stripfing 4993 - 2023-03-25 14:30:00
#
#   ____________[289/504] 783 - 2022 -----#Wisłoka Dębica 16274 - Sokół Sieniawa 16270 - 2023-03-25 14:30:00
#
#   ____________[290/504] 783 - 2022 -----#Chełmianka Chełm 6936 - Stal Stalowa Wola 6958 - 2023-03-25 14:30:00
#
#   ____________[291/504] 781 - 2022 -----#Jarota Jarocin 16248 - Cartusia Kartuzy 20625 - 2023-03-25 14:30:00
#
#   ____________[292/504] 111 - 2022 -----#Colwyn Bay 5611 - Holywell 6459 - 2023-03-25 14:30:00
#
#   ____________[293/504] 111 - 2022 -----#Holyhead Hotspur 6457 - Cefn Druids AFC 360 - 2023-03-25 14:30:00
#
#   ____________[294/504] 111 - 2022 -----#Prestatyn Town 5622 - Guilsfield 5616 - 2023-03-25 14:30:00
#
#   ____________[295/504] 111 - 2022 -----#Mold Alexandra 6465 - Gresford Athletic 5615 - 2023-03-25 14:30:00
#
#   ____________[296/504] 111 - 2022 -----#Porthmadog 5621 - Penrhyncoch 5620 - 2023-03-25 14:30:00
#
#   ____________[297/504] 111 - 2022 -----#Llantwit Major 2196 - Afan Lido 2200 - 2023-03-25 14:30:00
#
#   ____________[298/504] 111 - 2022 -----#Trefelin 6479 - Swansea University 5626 - 2023-03-25 14:30:00
#
#   ____________[299/504] 111 - 2022 -----#Barry Town 361 - Pontardawe Town 7598 - 2023-03-25 14:30:00
#
#   ____________[300/504] 111 - 2022 -----#Taffs Well 2199 - Ammanford AFC 2188 - 2023-03-25 14:30:00
#
#   ____________[301/504] 111 - 2022 -----#Cambrian & Clydach 2202 - Cwmbran Celtic 2190 - 2023-03-25 14:30:00
#
#   ____________[302/504] 83 - 2022 -----#Pipinsried 12832 - Vilzing 12893 - 2023-03-25 15:00:00
#
#   ____________[303/504] 41 - 2022 -----#Barnsley 747 - Ipswich 57 - 2023-03-25 15:00:00
#
#   ____________[304/504] 41 - 2022 -----#Burton Albion 748 - Cambridge United 1370 - 2023-03-25 15:00:00
#
#   ____________[305/504] 41 - 2022 -----#Charlton 1335 - Wycombe 1358 - 2023-03-25 15:00:00
#
#   ____________[306/504] 41 - 2022 -----#Exeter City 1364 - Accrington ST 1360 - 2023-03-25 15:00:00
#   ______________pre_second_half_winner_home:2.0
#
#   ____________[307/504] 41 - 2022 -----#Fleetwood Town 1336 - Lincoln 1379 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:2.0
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.95
#
#   ____________[308/504] 41 - 2022 -----#Milton Keynes Dons 1348 - Morecambe 1375 - 2023-03-25 15:00:00
#
#   ____________[309/504] 41 - 2022 -----#Oxford United 1338 - Cheltenham 1372 - 2023-03-25 15:00:00
#
#   ____________[310/504] 41 - 2022 -----#Peterborough 1350 - Derby 69 - 2023-03-25 15:00:00
#
#   ____________[311/504] 41 - 2022 -----#Portsmouth 1355 - Port Vale 1351 - 2023-03-25 15:00:00
#
#   ____________[312/504] 41 - 2022 -----#Shrewsbury 1352 - Bristol Rovers 1334 - 2023-03-25 15:00:00
#
#   ____________[313/504] 42 - 2022 -----#Barrow 1819 - AFC Wimbledon 1333 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#
#   ____________[314/504] 42 - 2022 -----#Colchester 1361 - Tranmere 1381 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:1.91
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#
# ...
#
#   ____________[394/504] 50 - 2022 -----#Hereford 4692 - King's Lynn Town 8655 - 2023-03-25 15:00:00
#
#   ____________[395/504] 50 - 2022 -----#Kettering Town 8654 - Darlington 1883 10157 - 2023-03-25 15:00:00
#
#   ____________[396/504] 50 - 2022 -----#Kidderminster Harriers 4695 - Alfreton Town 4677 - 2023-03-25 15:00:00
#
#   ____________[397/504] 50 - 2022 -----#Leamington 8656 - Boston United 8146 - 2023-03-25 15:00:00
#
#   ____________[398/504] 50 - 2022 -----#Scarborough Athletic 7745 - Southport 1826 - 2023-03-25 15:00:00
#
#   ____________[399/504] 50 - 2022 -----#Spennymoor Town 4707 - Brackley Town 4701 - 2023-03-25 15:00:00
#
#   ____________[400/504] 51 - 2022 -----#Braintree 1831 - Taunton Town 4711 - 2023-03-25 15:00:00
#
#   ____________[401/504] 51 - 2022 -----#Cheshunt 7708 - Weymouth 8665 - 2023-03-25 15:00:00
#
#   ____________[402/504] 51 - 2022 -----#Chippenham Town 8147 - Eastbourne Borough 4704 - 2023-03-25 15:00:00
#
#   ____________[403/504] 51 - 2022 -----#Dartford 4690 - Chelmsford City 4689 - 2023-03-25 15:00:00
#   ______________pre_second_half_winner_home:2.0
#
#   ____________[404/504] 51 - 2022 -----#Dulwich Hamlet 8149 - Oxford City 4684 - 2023-03-25 15:00:00
#
#   ____________[405/504] 51 - 2022 -----#Hampton & Richmond 4680 - Farnborough 7715 - 2023-03-25 15:00:00
#
#   ____________[406/504] 51 - 2022 -----#Hemel Hempstead Town 8660 - Concord Rangers 8658 - 2023-03-25 15:00:00
#   ______________pre_second_half_winner_home:2.0
#
#   ____________[407/504] 51 - 2022 -----#St Albans City 4708 - Dover 1829 - 2023-03-25 15:00:00
#
#   ____________[408/504] 51 - 2022 -----#Tonbridge Angels 8662 - Hungerford Town 8661 - 2023-03-25 15:00:00
#
#   ____________[409/504] 51 - 2022 -----#Welling United 8664 - Bath City 8657 - 2023-03-25 15:00:00
#
#   ____________[410/504] 51 - 2022 -----#Worthing 7761 - Havant & Wville 1843 - 2023-03-25 15:00:00
#
#   ____________[411/504] 221 - 2022 -----#Wiener Viktoria 4966 - Mauerwerk 4953 - 2023-03-25 15:00:00
#
#   ____________[412/504] 221 - 2022 -----#Leobendorf 4951 - Neusiedl 4954 - 2023-03-25 15:00:00
#
#   ____________[413/504] 749 - 2022 -----#TuSpo Surheide 19755 - Woltmershausen 19756 - 2023-03-25 15:00:00
#
#   ____________[414/504] 879 - 2022 -----#Alcorcón II 9706 - CD Coria 9827 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:1.91
#
#   ____________[415/504] 875 - 2022 -----#Real Oviedo II 9576 - Real Valladolid II 9587 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:1.93
#
#   ____________[416/504] 510 - 2022 -----#YF Juventus 6652 - Breitenrain 10586 - 2023-03-25 15:00:00
#
#   ____________[417/504] 510 - 2022 -----#Stade Nyonnais 6646 - Basel II 10585 - 2023-03-25 15:00:00
#
#   ____________[418/504] 510 - 2022 -----#Luzern II 12706 - Young Boys II 12698 - 2023-03-25 15:00:00
#
#   ____________[419/504] 510 - 2022 -----#Zürich II 10591 - SC Kriens 2186 - 2023-03-25 15:00:00
#
#   ____________[420/504] 510 - 2022 -----#Rapperswil 2185 - St. Gallen II 12718 - 2023-03-25 15:00:00
#
#   ____________[421/504] 510 - 2022 -----#Brühl 10587 - Baden 12699 - 2023-03-25 15:00:00
#
#   ____________[422/504] 931 - 2022 -----#AFC Rushden & Diamonds 7691 - Leiston 7727 - 2023-03-25 15:00:00
#   ______________pre_second_half_winner_away:1.87
#
#   ____________[423/504] 931 - 2022 -----#Alvechurch 7692 - Bedford Town 7616 - 2023-03-25 15:00:00
#   ______________pre_second_half_winner_home:1.96
#
#   ____________[424/504] 931 - 2022 -----#Barwell 7697 - Hednesford Town 7721 - 2023-03-25 15:00:00
#   ______________pre_second_half_winner_home:1.97
#
#   ____________[425/504] 931 - 2022 -----#Basford United 7698 - Redditch United 7741 - 2023-03-25 15:00:00
#
#   ____________[426/504] 931 - 2022 -----#Bromsgrove Sporting 7705 - Mickleover Sports 7733 - 2023-03-25 15:00:00
#   ______________pre_both_teams_score_no:2.51
#
#   ____________[427/504] 931 - 2022 -----#Coalville Town 7709 - Kings Langley 7724 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_home:1.89
#   ______________pre_second_half_winner_home:1.71
#
#   ____________[428/504] 931 - 2022 -----#Hitchin Town 4682 - Stratford Town 7750 - 2023-03-25 15:00:00
#
#   ____________[429/504] 931 - 2022 -----#Needham Market 7735 - Nuneaton Town 10159 - 2023-03-25 15:00:00
#
#   ____________[430/504] 931 - 2022 -----#Royston Town 7742 - Tamworth 7752 - 2023-03-25 15:00:00
#
#   ____________[431/504] 931 - 2022 -----#Rushall Olympic 7743 - St Ives Town 7747 - 2023-03-25 15:00:00
#   ______________pre_second_half_winner_home:1.93
#
#   ____________[432/504] 931 - 2022 -----#Stourbridge 4710 - Ilkeston Town 7236 - 2023-03-25 15:00:00
#
#   ____________[433/504] 141 - 2022 -----#Ibiza 9390 - Burgos 9580 - 2023-03-25 15:15:00
#   ______________pre_first_half_winner_draw:1.83
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.67
#
#   ____________[434/504] 141 - 2022 -----#Racing Santander 4665 - Levante 539 - 2023-03-25 15:15:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#
#   ____________[435/504] 449 - 2022 -----#Constància 9776 - Portmany 9786 - 2023-03-25 15:30:00
#
#   ____________[436/504] 443 - 2022 -----#Tona 20264 - Peralada 9676 - 2023-03-25 15:30:00
#
#   ____________[437/504] 183 - 2022 -----#Montrose 4251 - Dunfermline 1388 - 2023-03-25 16:00:00
#   ______________pre_total_goals_both_teams_to_score_over_yes_25:2.0
#
#   ____________[438/504] 875 - 2022 -----#Cristo Atlético 9728 - Laredo 9394 - 2023-03-25 16:00:00
#   ______________pre_first_half_winner_draw:1.83
#
#   ____________[439/504] 875 - 2022 -----#Bergantiños 9383 - Burgos Promesas 9727 - 2023-03-25 16:00:00
#   ______________pre_first_half_winner_draw:1.93
#
#   ____________[440/504] 875 - 2022 -----#Guijuelo 9388 - Zamora 9418 - 2023-03-25 16:00:00
#   ______________pre_first_half_winner_draw:1.82
#
#   ____________[441/504] 510 - 2022 -----#Étoile Carouge 6654 - Bulle 6618 - 2023-03-25 16:00:00
#
#   ____________[442/504] 450 - 2022 -----#Ibarra 9795 - Mensajero 5269 - 2023-03-25 16:00:00
#
#   ____________[443/504] 450 - 2022 -----#Unión Sur Yaiza 17605 - La Cuadra 9796 - 2023-03-25 16:00:00
#
#   ____________[444/504] 455 - 2022 -----#Illueca 9391 - Cuarte 9886 - 2023-03-25 16:00:00
#
#   ____________[445/504] 460 - 2022 -----#Praiense 4786 - Rabo Peixe 4787 - 2023-03-25 16:00:00
#   ______________pre_first_half_winner_draw:1.97
#   ____________[446/504] 781 - 2022 -----#Bałtyk Gdynia 16244 - Pogoń Szczecin II 16252 - 2023-03-25 16:00:00
#
#   ____________[447/504] 877 - 2022 -----#Saguntino 9699 - Olot 9403 - 2023-03-25 16:30:00
#   ______________pre_first_half_winner_draw:1.92
#
#   ____________[448/504] 450 - 2022 -----#Santa Úrsula 9801 - Lanzarote 9797 - 2023-03-25 16:30:00
#
#   ____________[449/504] 942 - 2022 -----#Rimini 1709 - Reggiana 880 - 2023-03-25 16:30:00
#   ______________pre_first_half_winner_draw:1.91
#
#   ____________[450/504] 744 - 2022 -----#Oldenburger SV 16073 - Bordesholm 12741 - 2023-03-25 17:00:00
#
#   ____________[451/504] 875 - 2022 -----#Real Avilés 9632 - Racing Santander II 9643 - 2023-03-25 17:00:00
#
#   ____________[452/504] 348 - 2022 -----#Karlovy Vary 7306 - Písek 7334 - 2023-03-25 17:00:00
#
#   ____________[453/504] 783 - 2022 -----#Unia Tarnow 17322 - Lublinianka 19623 - 2023-03-25 17:00:00
#
#   ____________[454/504] 960 - 2023 -----#Armenia 1094 - Turkey 777 - 2023-03-25 17:00:00
#   ______________pre_first_half_winner_away:2.0
#   ______________pre_second_half_winner_away:1.73
#   ______________pre_to_win_either_half_away:1.25
#
#   ____________[455/504] 960 - 2023 -----#Belarus 1100 - Switzerland 15 - 2023-03-25 17:00:00
#   ______________pre_first_half_winner_away:1.67
#   ______________pre_second_half_winner_away:1.44
#   ______________pre_to_win_either_half_away:1.13
#   ______________pre_win_to_nil_away:1.8
#   ______________pre_result_total_goals_away_over_25:1.83
#   ______________pre_double_chance_home_draw:4.0
#   ______________pre_clean_sheet__home_yes:9.0
#   ______________pre_to_win_either_half_home:6.0
#
#   ____________[456/504] 960 - 2023 -----#Israel 1116 - Kosovo 1111 - 2023-03-25 17:00:00
#
#   ____________[457/504] 141 - 2022 -----#Alaves 542 - Tenerife 719 - 2023-03-25 17:30:00
#   ______________pre_first_half_winner_draw:1.83
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.62
#   ______________pre_both_teams_score_yes:2.63
#
#   ____________[458/504] 44 - 2022 -----#Manchester United W 4898 - West Ham W 1856 - 2023-03-25 17:30:00
#
#   ____________[459/504] 222 - 2022 -----#St. Anna 4959 - Union Vöcklamarkt 4964 - 2023-03-25 18:00:00
#
#   ____________[460/504] 303 - 2022 -----#Al Arabi 9135 - Al Ramms 13266 - 2023-03-25 18:00:00
#
#   ____________[461/504] 303 - 2022 -----#Al Thaid 9138 - Fursan Hispania 20026 - 2023-03-25 18:00:00
#
#   ____________[462/504] 303 - 2022 -----#Masafi 9141 - Al Urooba 9139 - 2023-03-25 18:00:00
#
#   ____________[463/504] 303 - 2022 -----#Masfut 9142 - City 17713 - 2023-03-25 18:00:00
#
#   ____________[464/504] 673 - 2022 -----#Cruz Azul W 14875 - Juárez W 14869 - 2023-03-25 18:00:00
#
#   ____________[465/504] 361 - 2023 -----#Kauno Žalgiris II 13971 - TransINVEST Vilnius 18878 - 2023-03-25 18:00:00
#
#   ____________[466/504] 536 - 2022 -----#Bermuda 5158 - Guyana 5162 - 2023-03-25 18:00:00
#
#   ____________[467/504] 487 - 2022 -----#Thes Sport 6227 - URSL Visé 6228 - 2023-03-25 18:30:00
#
#   ____________[468/504] 129 - 2023 -----#Agropecuario 462 - San Martin Tucuman 485 - 2023-03-25 18:30:00
#   ______________pre_first_half_winner_draw:1.83
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.67
#
#   ____________[469/504] 129 - 2023 -----#Flandria 471 - Defensores De Belgrano 1067 - 2023-03-25 18:30:00
#   ______________pre_first_half_winner_draw:1.83
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.73
#
#   ____________[470/504] 129 - 2023 -----#CA Estudiantes 1936 - Brown DE Adrogue 468 - 2023-03-25 18:30:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#
#   ____________[471/504] 133 - 2023 -----#Deportivo Paraguayo 8394 - Lugano 8396 - 2023-03-25 18:30:00
#
#   ____________[472/504] 133 - 2023 -----#El Porvenir 8384 - Defensores de Cambaceres 8392 - 2023-03-25 18:30:00
#
#   ____________[473/504] 133 - 2023 -----#Argentino Rosario 8389 - Centro Español 8390 - 2023-03-25 18:30:00
#
#   ____________[474/504] 133 - 2023 -----#Mercedes 18915 - Central Ballester 1967 - 2023-03-25 18:30:00
#
#   ____________[475/504] 487 - 2022 -----#Hoogstraten 5825 - Francs Borains 5805 - 2023-03-25 19:00:00
#
#   ____________[476/504] 487 - 2022 -----#Mandel United 5868 - Sint-Eloois-Winkel 6226 - 2023-03-25 19:00:00
#
#   ____________[477/504] 487 - 2022 -----#Rupel Boom 6225 - Olympic Charleroi 6221 - 2023-03-25 19:00:00
#
#   ____________[478/504] 487 - 2022 -----#Sporting Charleroi II 19959 - Ninove 5884 - 2023-03-25 19:00:00
#
#   ____________[479/504] 487 - 2022 -----#RAAL La Louvière 5902 - Heist 6217 - 2023-03-25 19:00:00
#
#   ____________[480/504] 239 - 2023 -----#Once Caldas 1136 - Deportivo Pereira 1462 - 2023-03-25 19:00:00
#   ______________pre_first_half_winner_draw:2.0
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.91
#
#   ____________[481/504] 129 - 2023 -----#Deportivo Madryn 1929 - Gimnasia Jujuy 479 - 2023-03-25 19:00:00
#   ______________pre_first_half_winner_draw:1.91
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#
#   ____________[482/504] 268 - 2023 -----#Liverpool Montevideo 2358 - Penarol 2348 - 2023-03-25 19:00:00
#
#   ____________[483/504] 536 - 2022 -----#Turks and Caicos Islands 5169 - US Virgin Islands 8172 - 2023-03-25 19:30:00
#   ______________pre_total_goals_both_teams_to_score_over_yes_25:1.83
#
#   ____________[484/504] 960 - 2023 -----#Spain 9 - Norway 1090 - 2023-03-25 19:45:00
#   ______________pre_first_half_winner_home:1.83
#   ______________pre_second_half_winner_home:1.62
#   ______________pre_to_win_either_half_home:1.2
#   ______________pre_win_to_nil_home:1.91
#   ______________pre_result_total_goals_home_over_25:2.2
#   ______________pre_double_chance_draw_away:3.25
#   ______________pre_to_win_either_half_away:4.33
#
#   ____________[485/504] 960 - 2023 -----#Croatia 3 - Wales 767 - 2023-03-25 19:45:00
#   ______________pre_second_half_winner_home:1.91
#
#   ____________[486/504] 960 - 2023 -----#Andorra 1110 - Romania 774 - 2023-03-25 19:45:00
#   ______________pre_first_half_winner_away:1.67
#   ______________pre_second_half_winner_away:1.44
#   ______________pre_to_win_either_half_away:1.14
#   ______________pre_win_to_nil_away:1.62
#   ______________pre_result_total_goals_away_over_25:1.95
#   ______________pre_both_teams_score_yes:3.0
#   ______________pre_double_chance_home_draw:4.33
#   ______________pre_clean_sheet__home_yes:8.0
#   ______________pre_to_win_either_half_home:6.5
#
#   ____________[487/504] 133 - 2023 -----#Sportivo Barracas 1931 - Juventud Unida 486 - 2023-03-25 20:00:00
#
#   ____________[488/504] 536 - 2022 -----#Sint Maarten 10985 - Bonaire 10982 - 2023-03-25 20:00:00
#   ______________pre_total_goals_both_teams_to_score_over_yes_25:1.91
#
#   ____________[489/504] 253 - 2023 -----#Portland Timbers 1617 - Los Angeles Galaxy 1605 - 2023-03-25 20:30:00
#
#   ____________[490/504] 162 - 2022 -----#Municipal Grecia 818 - Perez Zeledon 819 - 2023-03-25 21:00:00
#
#   ____________[491/504] 250 - 2023 -----#Sportivo Ameliano 10487 - Olimpia 1182 - 2023-03-25 21:00:00
#   ______________pre_second_half_winner_away:1.95
#
#   ____________[492/504] 281 - 2023 -----#Sporting Cristal 2546 - Academia Cantolao 2543 - 2023-03-25 21:00:00
#   ______________pre_first_half_winner_home:1.57
#   ______________pre_second_half_winner_home:1.4
#   ______________pre_to_win_either_half_home:1.11
#   ______________pre_win_to_nil_home:1.8
#   ______________pre_result_total_goals_home_under_35:2.1
#   ______________pre_result_total_goals_home_over_25:1.67
#   ______________pre_double_chance_draw_away:4.5
#   ______________pre_clean_sheet__away_yes:13.0
#   ______________pre_to_win_either_half_away:5.5
#
#   ____________[493/504] 304 - 2023 -----#Sporting San Miguelito 2889 - Herrera 15619 - 2023-03-25 21:00:00
#
#   ____________[494/504] 129 - 2023 -----#Patronato 444 - Club Atlético Güemes 3969 - 2023-03-25 21:00:00
#   ______________pre_total_goals_both_teams_to_score_under_no_25:2.0
#
#   ____________[495/504] 266 - 2023 -----#Recoleta 5644 - D. Puerto Montt 2342 - 2023-03-25 21:00:00
#   ______________pre_first_half_winner_draw:1.91
#
#   ____________[496/504] 536 - 2022 -----#Montserrat 8170 - Haiti 2386 - 2023-03-25 21:00:00
#   ______________pre_first_half_winner_away:1.91
#   ______________pre_second_half_winner_away:1.67
#   ______________pre_to_win_either_half_away:1.22
#   ______________pre_result_total_goals_away_over_25:2.2
#
#   ____________[497/504] 239 - 2023 -----#Alianza Petrolera 1141 - Bucaramanga 1131 - 2023-03-25 21:10:00
#
#   ____________[498/504] 268 - 2023 -----#Wanderers 2360 - Cerro 2362 - 2023-03-25 21:30:00
#
#   ____________[499/504] 130 - 2023 -----#Boca Juniors 451 - Olimpo Bahia Blanca 443 - 2023-03-25 22:00:00
#
#   ____________[500/504] 129 - 2023 -----#Alvarado 1962 - Almirante Brown 8375 - 2023-03-25 22:00:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.91
#
#   ____________[501/504] 129 - 2023 -----#Villa Dalmine 481 - Ferro Carril Oeste 470 - 2023-03-25 22:00:00
#   ______________pre_first_half_winner_draw:2.0
#   ______________pre_total_goals_both_teams_to_score_under_no_25:2.0
#
#   ____________[502/504] 263 - 2022 -----#Celaya 2308 - Venados FC 2311 - 2023-03-25 23:00:00
#
#   ____________[503/504] 673 - 2022 -----#Pachuca W 14881 - Tijuana W 14872 - 2023-03-25 23:00:00
#
#   ____________[504/504] 536 - 2022 -----#Martinique 8117 - Costa Rica 29 - 2023-03-25 23:00:00
#   ______________pre_first_half_winner_away:1.91
#   ______________pre_second_half_winner_away:1.67
#   ______________pre_to_win_either_half_away:1.25
#   ______________pre_result_total_goals_away_over_25:2.05
#   ______________pre_clean_sheet__home_yes:7.0
#
# # -------------------------------------------------- End at 2023-03-24 23:13:09
