# %%
# Import
from a_settings.messages import *   
from a_models.api_odds import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(0, space).strftime("%Y-%m-%d")
    date_raw       = get_today(0, space)  
    # -------------------------------------------------- 
    DICT = {
        'date_0' : date_0,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 0,
        'date_raw' : date_raw,
    }
    # --------------------------------------------------  
    PREP_ = "pre_"
    # -------------------------------------------------- 
    ao_controll_match_update(DICT, PREP_, space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 08:11:33
#   __main()
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-16 08:11:33.046767
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-16 08:11:33.051144
#   ______ao_controll_match_update()
#   ________aa_check_acccount()
#   __________API digitalmedia.arion@gmail.com counter is 99
#   __________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________ao_response_odds()
#   __________date_0 : 2023-03-16
#   __________page : 1
#   __________counter_loop : 0
#   __________date_diff : 0
#   __________date_raw : 2023-03-16 08:11:33.051144
#   ____________________________________________________________________________________
#   __________Total API Response(s) : 10
#
#   ____________1. Serbia,  Prva Liga  #287 - 2022 / 869147
#   ____________fixt date 2023-03-16 13:00:00+00:00
#   ____________fix local 2023-03-16 20:00:00
#   ____________local dat 2023-03-16 08:11:33
#   ____________Lebih
#   ______________league_rLeagues_id : 287
#   ______________league_rLeagues_name : Prva Liga
#   ______________bookmakersapi_rLeagues_id : 11
#   ______________bookmakers_rLeagues_name : 1xBet
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ______________11==11
#   __________________1 Match Winner
#   ____________________pre_match_winner_home = '4.64',
#   ____________________pre_match_winner_draw = '3.72',
#   ____________________pre_match_winner_away = '1.68',
#   __________________3 Second Half Winner
#   ____________________pre_second_half_winner_home = '4.70',
#   ____________________pre_second_half_winner_draw = '2.53',
#   ____________________pre_second_half_winner_away = '2.01',
#   __________________4 Asian Handicap
#   ____________________pre_asian_handicap_home_plus_0 = '3.42',
#   ____________________pre_asian_handicap_away_plus_0 = '1.25',
#   ____________________pre_asian_handicap_home_min_025 = '3.92',
#   ____________________pre_asian_handicap_away_min_025 = '1.20',
#   ____________________pre_asian_handicap_home_plus_025 = '2.54',
#   ____________________pre_asian_handicap_away_plus_025 = '1.44',
#   ____________________pre_asian_handicap_home_plus_075 = '1.91',
#   ____________________pre_asian_handicap_away_plus_075 = '1.87',
#   ____________________pre_asian_handicap_home_min_1 = '9.30',
#   ____________________pre_asian_handicap_away_min_1 = '1.02',
#   ____________________pre_asian_handicap_home_plus_1 = '1.64',
#   ____________________pre_asian_handicap_away_plus_1 = '2.22',
#   ____________________pre_asian_handicap_home_min_15 = '10.00',
#   ____________________pre_asian_handicap_away_min_15 = '1.01',
#   ____________________pre_asian_handicap_home_plus_15 = '1.36',
#   ____________________pre_asian_handicap_away_plus_15 = '2.81',
#   ____________________pre_asian_handicap_home_plus_125 = '1.46',
#   ____________________pre_asian_handicap_away_plus_125 = '2.50',
#   ____________________pre_asian_handicap_home_plus_175 = '1.26',
#   ____________________pre_asian_handicap_away_plus_175 = '3.42',
#   ____________________pre_asian_handicap_home_plus_2 = '1.13',
#   ____________________pre_asian_handicap_away_plus_2 = '4.74',
#   ____________________pre_asian_handicap_home_plus_25 = '1.10',
#   ____________________pre_asian_handicap_away_plus_25 = '5.50',
#   __________________5 Goals Over/Under
#   ____________________pre_goals_overunder_over_35 = '3.08',
#   ____________________pre_goals_overunder_under_35 = '1.30',
#   ____________________pre_goals_overunder_over_15 = '1.26',
#   ____________________pre_goals_overunder_under_15 = '3.34',
#   ____________________pre_goals_overunder_over_45 = '6.50',
#   ____________________pre_goals_overunder_under_45 = '1.08',
#   ____________________pre_goals_overunder_over_25 = '1.89',
#   ____________________pre_goals_overunder_under_25 = '1.89',
#   ____________________pre_goals_overunder_over_55 = '9.10',
#   ____________________pre_goals_overunder_under_55 = '1.03',
#   ____________________pre_goals_overunder_over_225 = '1.63',
#   ____________________pre_goals_overunder_under_225 = '2.11',
#   ____________________pre_goals_overunder_over_325 = '2.81',
#   ____________________pre_goals_overunder_under_325 = '1.37',
#   ____________________pre_goals_overunder_over_275 = '2.14',
#   ____________________pre_goals_overunder_under_275 = '1.70',
#   ____________________pre_goals_overunder_over_175 = '1.33',
#   ____________________pre_goals_overunder_under_175 = '3.00',
#   ____________________pre_goals_overunder_over_375 = '3.76',
#   ____________________pre_goals_overunder_under_375 = '1.22',
#   ____________________pre_goals_overunder_over_30 = '2.48',
#   ____________________pre_goals_overunder_under_30 = '1.46',
#   ____________________pre_goals_overunder_over_20 = '1.42',
#   ____________________pre_goals_overunder_under_20 = '2.61',
#   ____________________pre_goals_overunder_over_40 = '5.15',
#   ____________________pre_goals_overunder_under_40 = '1.11',
#   ____________________pre_goals_overunder_over_10 = '1.03',
#   ____________________pre_goals_overunder_under_10 = '8.10',
#   __________________6 Goals Over/Under First Half
#   ____________________pre_goals_overunder_first_half_over_15 = '2.73',
#   ____________________pre_goals_overunder_first_half_under_15 = '1.40',
#   ____________________pre_goals_overunder_first_half_over_25 = '6.90',
#   ____________________pre_goals_overunder_first_half_under_25 = '1.07',
#   ____________________pre_goals_overunder_first_half_over_05 = '1.36',
#   ____________________pre_goals_overunder_first_half_under_05 = '2.88',
#   ____________________pre_goals_overunder_first_half_over_125 = '2.28',
#   ____________________pre_goals_overunder_first_half_under_125 = '1.56',
#   ____________________pre_goals_overunder_first_half_over_075 = '1.51',
#   ____________________pre_goals_overunder_first_half_under_075 = '2.40',
#   ____________________pre_goals_overunder_first_half_over_10 = '1.81',
#   ____________________pre_goals_overunder_first_half_under_10 = '1.90',
#   __________________26 Goals Over/Under - Second Half
#   ____________________pre_goals_overunder__second_half_over_15 = '2.08',
#   ____________________pre_goals_overunder__second_half_under_15 = '1.67',
#   ____________________pre_goals_overunder__second_half_over_25 = '4.50',
#   ____________________pre_goals_overunder__second_half_under_25 = '1.16',
#   ____________________pre_goals_overunder__second_half_over_05 = '1.23',
#   ____________________pre_goals_overunder__second_half_under_05 = '3.70',
#   ____________________pre_goals_overunder__second_half_over_125 = '1.76',
#   ____________________pre_goals_overunder__second_half_under_125 = '1.95',
#   ____________________pre_goals_overunder__second_half_over_175 = '2.50',
#   ____________________pre_goals_overunder__second_half_under_175 = '1.47',
#   ____________________pre_goals_overunder__second_half_over_20 = '3.42',
#   ____________________pre_goals_overunder__second_half_under_20 = '1.27',
#   ____________________pre_goals_overunder__second_half_over_10 = '1.42',
#   ____________________pre_goals_overunder__second_half_under_10 = '2.66',
#   __________________7 HT/FT Double
#   __________________8 Both Teams Score
#   ____________________pre_both_teams_score_yes = '1.82',
#   ____________________pre_both_teams_score_no = '1.94',
#   __________________9 Handicap Result
#   ______________  ______________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 2.07
#   ______________  ______________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 2.81
#   ______________  ______________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.34
#   ______________  ______________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.36
#   ______________  ______________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 4.74
#   ______________  ______________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 5.50
#   __________________10 Exact Score
#   __________________11 Highest Scoring Half
#   __________________31 Correct Score - First Half
#   ______________  ______________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 6.50
#   ______________  ______________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 23.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 67.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.88
#   ______________  ______________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ______________  ______________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 8.50
#   ______________  ______________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 23.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 51.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 21.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 41.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________62 Correct Score - Second Half
#   ______________  ______________bet_id: 62 --- bets_value: 1:0 --- bets_odd: 6.40
#   ______________  ______________bet_id: 62 --- bets_value: 2:0 --- bets_odd: 24.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:1 --- bets_odd: 27.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:0 --- bets_odd: 3.70
#   ______________  ______________bet_id: 62 --- bets_value: 1:1 --- bets_odd: 6.80
#   ______________  ______________bet_id: 62 --- bets_value: 2:2 --- bets_odd: 60.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:1 --- bets_odd: 3.50
#   ______________  ______________bet_id: 62 --- bets_value: 0:2 --- bets_odd: 6.80
#   ______________  ______________bet_id: 62 --- bets_value: 0:3 --- bets_odd: 26.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:2 --- bets_odd: 14.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:3 --- bets_odd: 55.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________12 Double Chance
#   ____________________pre_double_chance_home_draw = '2.07',
#   ____________________pre_double_chance_home_away = '1.23',
#   ____________________pre_double_chance_draw_away = '1.15',
#   __________________13 First Half Winner
#   ____________________pre_first_half_winner_home = '5.25',
#   ____________________pre_first_half_winner_draw = '2.17',
#   ____________________pre_first_half_winner_away = '2.20',
#   __________________16 Total - Home
#   ______________  ______________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 3.64
#   ______________  ______________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.22
#   ______________  ______________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.53
#   ______________  ______________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 2.27
#   ______________  ______________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 8.60
#   ______________  ______________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.02
#   ______________  ______________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 2.40
#   ______________  ______________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 1.48
#   __________________17 Total - Away
#   ______________  ______________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 1.76
#   ______________  ______________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.91
#   ______________  ______________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.13
#   ______________  ______________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 4.80
#   ______________  ______________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 2.54
#   ______________  ______________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.43
#   ______________  ______________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.24
#   ______________  ______________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 3.48
#   __________________18 Handicap Result - First Half
#   ______________  ______________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.52
#   ______________  ______________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 5.95
#   ______________  ______________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.26
#   __________________19 Asian Handicap First Half
#   __________________20 Double Chance - First Half
#   __________________33 Double Chance - Second Half
#   ______________  ______________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.63
#   ______________  ______________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.39
#   ______________  ______________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.12
#   __________________34 Both Teams Score - First Half
#   __________________35 Both Teams To Score - Second Half
#   __________________21 Odd/Even
#   __________________22 Odd/Even - First Half
#   ______________  ______________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   ______________  ______________bet_id: 22 --- bets_value: Even --- bets_odd: 1.69
#   __________________23 Home Odd/Even
#   ______________  ______________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.12
#   ______________  ______________bet_id: 23 --- bets_value: Even --- bets_odd: 1.61
#   __________________60 Away Odd/Even
#   ______________  ______________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.86
#   ______________  ______________bet_id: 60 --- bets_value: Even --- bets_odd: 1.80
#   ______________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ______________2. Slovenia,  1. SNL  #373 - 2022 / 876868
#   ______________fixt date 2023-03-16 16:30:00+00:00
#   ______________fix local 2023-03-16 23:30:00
#   ______________local dat 2023-03-16 08:11:33
#   ______________Lebih
#   ________________league_rLeagues_id : 373
#   ________________league_rLeagues_name : 1. SNL
#   ________________bookmakersapi_rLeagues_id : 8
#   ________________bookmakers_rLeagues_name : Bet365
#   ______________Total fixtureapi_id Row(s) : 1
#   ______________good to Go 1
#   ________________8==8
#   ____________________1 Match Winner
#   ______________________pre_match_winner_home = '2.20',
#   ______________________pre_match_winner_draw = '3.00',
#   ______________________pre_match_winner_away = '3.25',
#   ____________________2 Home/Away
#   ______________________pre_homeaway_home = '1.62',
#   ______________________pre_homeaway_away = '2.20',
#   ____________________3 Second Half Winner
#   ______________________pre_second_half_winner_home = '2.63',
#   ______________________pre_second_half_winner_draw = '2.38',
#   ______________________pre_second_half_winner_away = '3.20',
#   ____________________4 Asian Handicap
#   ______________________pre_asian_handicap_home_plus_0 = '1.63',
#   ______________________pre_asian_handicap_away_plus_0 = '2.25',
#   ______________________pre_asian_handicap_home_min_025 = '1.98',
#   ______________________pre_asian_handicap_away_min_025 = '1.83',
#   ______________________pre_asian_handicap_home_plus_025 = '1.45',
#   ______________________pre_asian_handicap_away_plus_025 = '2.68',
#   ______________________pre_asian_handicap_home_min_05 = '2.30',
#   ______________________pre_asian_handicap_away_min_05 = '1.60',
#   ______________________pre_asian_handicap_home_plus_05 = '1.35',
#   ______________________pre_asian_handicap_away_plus_05 = '3.10',
#   ______________________pre_asian_handicap_home_min_075 = '2.68',
#   ______________________pre_asian_handicap_away_min_075 = '1.45',
#   ______________________pre_asian_handicap_home_plus_075 = '1.24',
#   ______________________pre_asian_handicap_away_plus_075 = '3.90',
#   ______________________pre_asian_handicap_home_min_1 = '3.55',
#   ______________________pre_asian_handicap_away_min_1 = '1.28',
#   ______________________pre_asian_handicap_home_plus_1 = '1.13',
#   ______________________pre_asian_handicap_away_plus_1 = '5.90',
#   ______________________pre_asian_handicap_home_min_15 = '4.50',
#   ______________________pre_asian_handicap_away_min_15 = '1.19',
#   ______________________pre_asian_handicap_home_plus_15 = '1.11',
#   ______________________pre_asian_handicap_away_plus_15 = '6.80',
#   ______________________pre_asian_handicap_home_min_125 = '4.10',
#   ______________________pre_asian_handicap_away_min_125 = '1.23',
#   ______________________pre_asian_handicap_home_min_175 = '6.00',
#   ______________________pre_asian_handicap_away_min_175 = '1.13',
#   ______________________pre_asian_handicap_home_plus_125 = '1.12',
#   ______________________pre_asian_handicap_away_plus_125 = '6.40',
#   ____________________5 Goals Over/Under
#   ______________________pre_goals_overunder_over_35 = '3.75',
#   ______________________pre_goals_overunder_under_35 = '1.25',
#   ______________________pre_goals_overunder_over_15 = '1.33',
#   ______________________pre_goals_overunder_under_15 = '3.25',
#   ______________________pre_goals_overunder_over_45 = '7.00',
#   ______________________pre_goals_overunder_under_45 = '1.08',
#   ______________________pre_goals_overunder_over_25 = '2.10',
#   ______________________pre_goals_overunder_under_25 = '1.70',
#   ______________________pre_goals_overunder_over_05 = '1.06',
#   ______________________pre_goals_overunder_under_05 = '8.00',
#   ______________________pre_goals_overunder_over_55 = '10.50',
#   ______________________pre_goals_overunder_under_55 = '1.03',
#   ______________________pre_goals_overunder_over_65 = '17.00',
#   ______________________pre_goals_overunder_under_65 = '1.01',
#   ______________________pre_goals_overunder_over_75 = '21.00',
#   ______________________pre_goals_overunder_under_75 = '1.00',
#   ____________________6 Goals Over/Under First Half
#   ______________________pre_goals_overunder_first_half_over_35 = '26.00',
#   ______________________pre_goals_overunder_first_half_under_35 = '1.01',
#   ______________________pre_goals_overunder_first_half_over_15 = '3.25',
#   ______________________pre_goals_overunder_first_half_under_15 = '1.33',
#   ______________________pre_goals_overunder_first_half_over_25 = '9.00',
#   ______________________pre_goals_overunder_first_half_under_25 = '1.07',
#   ______________________pre_goals_overunder_first_half_over_05 = '1.44',
#   ______________________pre_goals_overunder_first_half_under_05 = '2.63',
#   ____________________26 Goals Over/Under - Second Half
#   ______________________pre_goals_overunder__second_half_over_35 = '13.00',
#   ______________________pre_goals_overunder__second_half_under_35 = '1.04',
#   ______________________pre_goals_overunder__second_half_over_15 = '2.20',
#   ______________________pre_goals_overunder__second_half_under_15 = '1.62',
#   ______________________pre_goals_overunder__second_half_over_25 = '5.00',
#   ______________________pre_goals_overunder__second_half_under_25 = '1.17',
#   ______________________pre_goals_overunder__second_half_over_05 = '1.29',
#   ______________________pre_goals_overunder__second_half_under_05 = '3.50',
#   ____________________7 HT/FT Double
#   ____________________27 Clean Sheet - Home
#   ______________________pre_clean_sheet__home_yes = '2.63',
#   ______________________pre_clean_sheet__home_no = '1.44',
#   ____________________28 Clean Sheet - Away
#   ______________________pre_clean_sheet__away_yes = '3.50',
#   ______________________pre_clean_sheet__away_no = '1.29',
#   ____________________8 Both Teams Score
#   ______________________pre_both_teams_score_yes = '1.83',
#   ______________________pre_both_teams_score_no = '1.83',
#   ____________________9 Handicap Result
#   ________________  ________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 4.33
#   ________________  ________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.55
#   ________________  ________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.00
#   ________________  ________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.25
#   ________________  ________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 6.50
#   ________________  ________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.75
#   ________________  ________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.09
#   ________________  ________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 10.00
#   ________________  ________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 17.00
#   ________________  ________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 9.50
#   ________________  ________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 6.50
#   ________________  ________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.17
#   ________________  ________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 26.00
#   ________________  ________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 15.00
#   ________________  ________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.05
#   ____________________10 Exact Score
#   ____________________11 Highest Scoring Half
#   ____________________31 Correct Score - First Half
#   ________________  ________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.33
#   ________________  ________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 13.00
#   ________________  ________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 41.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 67.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 151.00
#   ________________  ________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 151.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.63
#   ________________  ________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ________________  ________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 5.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 17.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 151.00
#   ________________  ________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 29.00
#   ________________  ________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   ________________  ________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 151.00
#   ____________________12 Double Chance
#   ______________________pre_double_chance_home_draw = '1.25',
#   ______________________pre_double_chance_home_away = '1.30',
#   ______________________pre_double_chance_draw_away = '1.55',
#   ____________________13 First Half Winner
#   ______________________pre_first_half_winner_home = '3.00',
#   ______________________pre_first_half_winner_draw = '2.05',
#   ______________________pre_first_half_winner_away = '3.60',
#   ____________________14 Team To Score First
#   ________________  ________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.80
#   ________________  ________________bet_id: 14 --- bets_value: Draw --- bets_odd: 8.00
#   ________________  ________________bet_id: 14 --- bets_value: Away --- bets_odd: 2.38
#   ____________________15 Team To Score Last
#   ________________  ________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.80
#   ________________  ________________bet_id: 15 --- bets_value: Draw --- bets_odd: 8.00
#   ________________  ________________bet_id: 15 --- bets_value: Away --- bets_odd: 2.38
#   ____________________32 Win Both Halves
#   ______________________pre_win_both_halves_home = '8.00',
#   ______________________pre_win_both_halves_away = '11.00',
#   ____________________16 Total - Home
#   ________________  ________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 10.00
#   ________________  ________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.03
#   ________________  ________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.38
#   ________________  ________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.53
#   ________________  ________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 17.00
#   ________________  ________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   ________________  ________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 5.00
#   ________________  ________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.14
#   ____________________17 Total - Away
#   ________________  ________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 12.00
#   ________________  ________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.02
#   ________________  ________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 3.00
#   ________________  ________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.36
#   ________________  ________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 21.00
#   ________________  ________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   ________________  ________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 7.00
#   ________________  ________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.08
#   ____________________18 Handicap Result - First Half
#   ________________  ________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 10.00
#   ________________  ________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.36
#   ________________  ________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.75
#   ________________  ________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.29
#   ________________  ________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 13.00
#   ________________  ________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 4.33
#   ________________  ________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 34.00
#   ________________  ________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 12.00
#   ________________  ________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.05
#   ________________  ________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 151.00
#   ________________  ________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 41.00
#   ________________  ________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.01
#   ____________________19 Asian Handicap First Half
#   ____________________20 Double Chance - First Half
#   ____________________34 Both Teams Score - First Half
#   ____________________35 Both Teams To Score - Second Half
#   ____________________36 Win To Nil
#   ______________________pre_win_to_nil_home = '3.75',
#   ______________________pre_win_to_nil_away = '5.50',
#   ____________________21 Odd/Even
#   ____________________22 Odd/Even - First Half
#   ________________  ________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.20
#   ________________  ________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.67
#   ____________________23 Home Odd/Even
#   ________________  ________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.00
#   ________________  ________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.73
#   ____________________60 Away Odd/Even
#   ________________  ________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.10
#   ________________  ________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.67
#   ____________________39 To Win Either Half
#   ______________________pre_to_win_either_half_home = '1.73',
#   ______________________pre_to_win_either_half_away = '2.00',
#   ____________________40 Home Team Exact Goals Number
#   ____________________41 Away Team Exact Goals Number
#   ____________________24 Results/Both Teams Score
#   ______________________pre_results_both_teams_score_home_yes = '5.00',
#   ______________________pre_results_both_teams_score_draw_yes = '4.33',
#   ______________________pre_results_both_teams_score_away_yes = '7.00',
#   ______________________pre_results_both_teams_score_home_no = '3.75',
#   ______________________pre_results_both_teams_score_draw_no = '8.00',
#   ______________________pre_results_both_teams_score_away_no = '5.50',
#   ____________________25 Result/Total Goals
#   ______________________pre_result_total_goals_home_over_25 = '4.00',
#   ______________________pre_result_total_goals_draw_over_25 = '13.00',
#   ______________________pre_result_total_goals_away_over_25 = '5.50',
#   ______________________pre_result_total_goals_home_under_25 = '4.75',
#   ______________________pre_result_total_goals_draw_under_25 = '3.75',
#   ______________________pre_result_total_goals_away_under_25 = '6.50',
#   ____________________45 Corners Over Under
#   ________________  ________________bet_id: 45 --- bets_value: Over 10.5 --- bets_odd: 1.98
#   ________________  ________________bet_id: 45 --- bets_value: Under 10.5 --- bets_odd: 1.83
#   ____________________63 Odd/Even - Second Half
#   ________________  ________________bet_id: 63 --- bets_value: Odd --- bets_odd: 2.00
#   ________________  ________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.73
#   ____________________48 To Score In Both Halves By Teams
#   ____________________50 Goal Line
#   ________________  ________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 3.70
#   ________________  ________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.26
#   ________________  ________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.35
#   ________________  ________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 3.10
#   ________________  ________________bet_id: 50 --- bets_value: Over 4.5 --- bets_odd: 7.00
#   ________________  ________________bet_id: 50 --- bets_value: Under 4.5 --- bets_odd: 1.10
#   ________________  ________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 2.15
#   ________________  ________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.68
#   ________________  ________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.60
#   ________________  ________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.30
#   ________________  ________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 3.10
#   ________________  ________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.35
#   ________________  ________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 6.80
#   ________________  ________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.11
#   ________________  ________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.88
#   ________________  ________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 1.93
#   ________________  ________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 3.45
#   ________________  ________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.30
#   ________________  ________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.43
#   ________________  ________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.53
#   ________________  ________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.23
#   ________________  ________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 4.00
#   ________________  ________________bet_id: 50 --- bets_value: Over 4.25 --- bets_odd: 6.60
#   ________________  ________________bet_id: 50 --- bets_value: Under 4.25 --- bets_odd: 1.11
#   ________________  ________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.45
#   ________________  ________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 2.68
#   ________________  ________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 4.65
#   ________________  ________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.18
#   ________________  ________________bet_id: 50 --- bets_value: Over 1 --- bets_odd: 1.11
#   ________________  ________________bet_id: 50 --- bets_value: Under 1 --- bets_odd: 6.80
#   ____________________72 Goal Line (1st Half)
#   ________________  ________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 3.10
#   ________________  ________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.35
#   ________________  ________________bet_id: 72 --- bets_value: Over 0.5 --- bets_odd: 1.48
#   ________________  ________________bet_id: 72 --- bets_value: Under 0.5 --- bets_odd: 2.60
#   ________________  ________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 6.80
#   ________________  ________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.11
#   ________________  ________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 6.60
#   ________________  ________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.11
#   ________________  ________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.60
#   ________________  ________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.48
#   ________________  ________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 4.15
#   ________________  ________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.22
#   ________________  ________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 2.08
#   ________________  ________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.73
#   ________________  ________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.65
#   ________________  ________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.20
#   ____________________85 Total Corners (3 way)
#   ________________  ________________bet_id: 85 --- bets_value: Over 5 --- bets_odd: 1.04
#   ________________  ________________bet_id: 85 --- bets_value: Under 5 --- bets_odd: 21.00
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 5 --- bets_odd: 19.00
#   ________________  ________________bet_id: 85 --- bets_value: Over 6 --- bets_odd: 1.08
#   ________________  ________________bet_id: 85 --- bets_value: Under 6 --- bets_odd: 13.00
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 6 --- bets_odd: 15.00
#   ________________  ________________bet_id: 85 --- bets_value: Over 7 --- bets_odd: 1.18
#   ________________  ________________bet_id: 85 --- bets_value: Under 7 --- bets_odd: 8.00
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 7 --- bets_odd: 11.00
#   ________________  ________________bet_id: 85 --- bets_value: Over 8 --- bets_odd: 1.33
#   ________________  ________________bet_id: 85 --- bets_value: Under 8 --- bets_odd: 4.50
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 8 --- bets_odd: 9.00
#   ________________  ________________bet_id: 85 --- bets_value: Over 9 --- bets_odd: 1.57
#   ________________  ________________bet_id: 85 --- bets_value: Under 9 --- bets_odd: 3.25
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 9 --- bets_odd: 8.50
#   ________________  ________________bet_id: 85 --- bets_value: Over 10 --- bets_odd: 1.91
#   ________________  ________________bet_id: 85 --- bets_value: Under 10 --- bets_odd: 2.25
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 10 --- bets_odd: 8.00
#   ________________  ________________bet_id: 85 --- bets_value: Over 11 --- bets_odd: 2.50
#   ________________  ________________bet_id: 85 --- bets_value: Under 11 --- bets_odd: 1.80
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 11 --- bets_odd: 8.50
#   ____________________73 Both Teams to Score 1st Half - 2nd Half
#   ____________________77 Total Corners (1st Half)
#   ________________  ________________bet_id: 77 --- bets_value: Over 5 --- bets_odd: 1.98
#   ________________  ________________bet_id: 77 --- bets_value: Under 5 --- bets_odd: 1.83
#   ____________________84 Total Corners (3 way) (1st Half)
#   ________________  ________________bet_id: 84 --- bets_value: Over 5 --- bets_odd: 2.30
#   ________________  ________________bet_id: 84 --- bets_value: Under 5 --- bets_odd: 2.10
#   ________________  ________________bet_id: 84 --- bets_value: Exactly 5 --- bets_odd: 5.50
#   ________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ________________3. Slovenia,  1. SNL  #373 - 2022 / 876869
#   ________________fixt date 2023-03-16 14:00:00+00:00
#   ________________fix local 2023-03-16 21:00:00
#   ________________local dat 2023-03-16 08:11:33
#   ________________Lebih
#   __________________league_rLeagues_id : 373
#   __________________league_rLeagues_name : 1. SNL
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   __________________8==8
#   ______________________1 Match Winner
#   ________________________pre_match_winner_home = '2.55',
#   ________________________pre_match_winner_draw = '3.10',
#   ________________________pre_match_winner_away = '2.55',
#   ______________________2 Home/Away
#   ________________________pre_homeaway_home = '1.83',
#   ________________________pre_homeaway_away = '1.83',
#   ______________________3 Second Half Winner
#   ________________________pre_second_half_winner_home = '2.88',
#   ________________________pre_second_half_winner_draw = '2.38',
#   ________________________pre_second_half_winner_away = '2.88',
#   ______________________4 Asian Handicap
#   ________________________pre_asian_handicap_home_plus_0 = '1.88',
#   ________________________pre_asian_handicap_away_plus_0 = '1.93',
#   ________________________pre_asian_handicap_home_min_025 = '2.25',
#   ________________________pre_asian_handicap_away_min_025 = '1.63',
#   ________________________pre_asian_handicap_home_plus_025 = '1.63',
#   ________________________pre_asian_handicap_away_plus_025 = '2.25',
#   ________________________pre_asian_handicap_home_min_05 = '2.50',
#   ________________________pre_asian_handicap_away_min_05 = '1.50',
#   ________________________pre_asian_handicap_home_plus_05 = '1.48',
#   ________________________pre_asian_handicap_away_plus_05 = '2.60',
#   ________________________pre_asian_handicap_home_min_075 = '3.10',
#   ________________________pre_asian_handicap_away_min_075 = '1.35',
#   ________________________pre_asian_handicap_home_plus_075 = '1.33',
#   ________________________pre_asian_handicap_away_plus_075 = '3.30',
#   ________________________pre_asian_handicap_home_min_1 = '4.40',
#   ________________________pre_asian_handicap_away_min_1 = '1.20',
#   ________________________pre_asian_handicap_home_plus_1 = '1.20',
#   ________________________pre_asian_handicap_away_plus_1 = '4.40',
#   ________________________pre_asian_handicap_home_min_15 = '5.50',
#   ________________________pre_asian_handicap_away_min_15 = '1.15',
#   ________________________pre_asian_handicap_home_plus_15 = '1.15',
#   ________________________pre_asian_handicap_away_plus_15 = '5.50',
#   ________________________pre_asian_handicap_home_min_125 = '4.80',
#   ________________________pre_asian_handicap_away_min_125 = '1.18',
#   ________________________pre_asian_handicap_home_min_175 = '7.00',
#   ________________________pre_asian_handicap_away_min_175 = '1.10',
#   ________________________pre_asian_handicap_home_plus_125 = '1.17',
#   ________________________pre_asian_handicap_away_plus_125 = '5.00',
#   ______________________5 Goals Over/Under
#   ________________________pre_goals_overunder_over_35 = '3.75',
#   ________________________pre_goals_overunder_under_35 = '1.25',
#   ________________________pre_goals_overunder_over_15 = '1.33',
#   ________________________pre_goals_overunder_under_15 = '3.25',
#   ________________________pre_goals_overunder_over_45 = '7.00',
#   ________________________pre_goals_overunder_under_45 = '1.08',
#   ________________________pre_goals_overunder_over_25 = '2.10',
#   ________________________pre_goals_overunder_under_25 = '1.70',
#   ________________________pre_goals_overunder_over_05 = '1.07',
#   ________________________pre_goals_overunder_under_05 = '7.50',
#   ________________________pre_goals_overunder_over_55 = '10.50',
#   ________________________pre_goals_overunder_under_55 = '1.03',
#   ________________________pre_goals_overunder_over_65 = '17.00',
#   ________________________pre_goals_overunder_under_65 = '1.01',
#   ______________________6 Goals Over/Under First Half
#   ________________________pre_goals_overunder_first_half_over_35 = '26.00',
#   ________________________pre_goals_overunder_first_half_under_35 = '1.01',
#   ________________________pre_goals_overunder_first_half_over_15 = '3.25',
#   ________________________pre_goals_overunder_first_half_under_15 = '1.33',
#   ________________________pre_goals_overunder_first_half_over_25 = '9.00',
#   ________________________pre_goals_overunder_first_half_under_25 = '1.07',
#   ________________________pre_goals_overunder_first_half_over_05 = '1.44',
#   ________________________pre_goals_overunder_first_half_under_05 = '2.63',
#   ______________________26 Goals Over/Under - Second Half
#   ________________________pre_goals_overunder__second_half_over_35 = '13.00',
#   ________________________pre_goals_overunder__second_half_under_35 = '1.04',
#   ________________________pre_goals_overunder__second_half_over_15 = '2.20',
#   ________________________pre_goals_overunder__second_half_under_15 = '1.62',
#   ________________________pre_goals_overunder__second_half_over_25 = '5.00',
#   ________________________pre_goals_overunder__second_half_under_25 = '1.17',
#   ________________________pre_goals_overunder__second_half_over_05 = '1.25',
#   ________________________pre_goals_overunder__second_half_under_05 = '3.75',
#   ______________________7 HT/FT Double
#   ______________________27 Clean Sheet - Home
#   ________________________pre_clean_sheet__home_yes = '3.00',
#   ________________________pre_clean_sheet__home_no = '1.36',
#   ______________________28 Clean Sheet - Away
#   ________________________pre_clean_sheet__away_yes = '3.00',
#   ________________________pre_clean_sheet__away_no = '1.36',
#   ______________________8 Both Teams Score
#   ________________________pre_both_teams_score_yes = '1.83',
#   ________________________pre_both_teams_score_no = '1.83',
#   ______________________9 Handicap Result
#   __________________  __________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.00
#   __________________  __________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.44
#   __________________  __________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.33
#   __________________  __________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.44
#   __________________  __________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 5.00
#   __________________  __________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.33
#   __________________  __________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.11
#   __________________  __________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 7.50
#   __________________  __________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 12.00
#   __________________  __________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 12.00
#   __________________  __________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 7.50
#   __________________  __________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.11
#   __________________  __________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 29.00
#   __________________  __________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 17.00
#   __________________  __________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.04
#   __________________  __________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.04
#   __________________  __________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 17.00
#   __________________  __________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 29.00
#   ______________________10 Exact Score
#   ______________________11 Highest Scoring Half
#   ______________________31 Correct Score - First Half
# ...
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.09
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 101.00
#   __________________________12 Double Chance
#   ____________________________pre_double_chance_home_draw = '1.17',
#   ____________________________pre_double_chance_home_away = '1.29',
#   ____________________________pre_double_chance_draw_away = '1.73',
#   __________________________13 First Half Winner
#   ____________________________pre_first_half_winner_home = '2.50',
#   ____________________________pre_first_half_winner_draw = '2.10',
#   ____________________________pre_first_half_winner_away = '4.33',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.57
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 2.63
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.57
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 2.75
#   __________________________32 Win Both Halves
#   ____________________________pre_win_both_halves_home = '5.50',
#   ____________________________pre_win_both_halves_away = '17.00',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.06
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 5.5 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 5.5 --- bets_odd: 1.00
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.06
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.40
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 4.75
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.02
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________pre_win_to_nil_home = '3.25',
#   ____________________________pre_win_to_nil_away = '7.00',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   __________________________23 Home Odd/Even
#   ______________________  ______________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.80
#   __________________________60 Away Odd/Even
#   ______________________  ______________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.62
#   __________________________39 To Win Either Half
#   ____________________________pre_to_win_either_half_home = '1.50',
#   ____________________________pre_to_win_either_half_away = '2.50',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________24 Results/Both Teams Score
#   ____________________________pre_results_both_teams_score_home_yes = '4.00',
#   ____________________________pre_results_both_teams_score_draw_yes = '4.33',
#   ____________________________pre_results_both_teams_score_away_yes = '8.50',
#   ____________________________pre_results_both_teams_score_home_no = '3.25',
#   ____________________________pre_results_both_teams_score_draw_no = '9.00',
#   ____________________________pre_results_both_teams_score_away_no = '7.00',
#   __________________________25 Result/Total Goals
#   ____________________________pre_result_total_goals_home_over_25 = '3.10',
#   ____________________________pre_result_total_goals_draw_over_25 = '12.00',
#   ____________________________pre_result_total_goals_away_over_25 = '7.00',
#   ____________________________pre_result_total_goals_home_under_25 = '4.33',
#   ____________________________pre_result_total_goals_draw_under_25 = '4.00',
#   ____________________________pre_result_total_goals_away_under_25 = '8.50',
#   __________________________63 Odd/Even - Second Half
#   ______________________  ______________________bet_id: 63 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.73
#   __________________________48 To Score In Both Halves By Teams
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 3.30
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.33
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 3.45
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.5 --- bets_odd: 6.60
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.5 --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 1.98
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.83
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.48
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.60
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 2.68
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.45
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 5.75
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 2.08
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.38
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.65
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.19
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.25 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.25 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.38
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.23
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 2.85
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 6.25
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.12
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.55
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 3.80
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.95
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.85
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.58
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.35
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   ______________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ______________________6. Mongolia,  Premier League  #764 - 2023 / 1014338
#   ______________________fixt date 2023-03-16 05:00:00+00:00
#   ______________________fix local 2023-03-16 12:00:00
#   ______________________local dat 2023-03-16 08:11:33
#   ______________________Lebih
#   ______________________gak ready BM
#   ______________________8 Bet365 = 17
#   ______________________11 1xBet = 12
#   ______________________good to Go 0
#
#   ______________________7. Mongolia,  Premier League  #764 - 2023 / 1014339
#   ______________________fixt date 2023-03-16 08:00:00+00:00
#   ______________________fix local 2023-03-16 15:00:00
#   ______________________local dat 2023-03-16 08:11:33
#   ______________________Lebih
#   ______________________gak ready BM
#   ______________________8 Bet365 = 17
#   ______________________11 1xBet = 12
#   ______________________good to Go 0
#
#   ______________________8. Algeria,  U21 League 1  #515 - 2022 / 1014765
#   ______________________fixt date 2023-03-16 09:00:00+00:00
#   ______________________fix local 2023-03-16 16:00:00
#   ______________________local dat 2023-03-16 08:11:33
#   ______________________Lebih
#   ______________________gak ready BM
#   ______________________8 Bet365 = 13
#   ______________________11 1xBet = 11
#   ______________________good to Go 0
#
#   ______________________9. Algeria,  U21 League 1  #515 - 2022 / 1014766
#   ______________________fixt date 2023-03-16 14:00:00+00:00
#   ______________________fix local 2023-03-16 21:00:00
#   ______________________local dat 2023-03-16 08:11:33
#   ______________________Lebih
#   ______________________gak ready BM
#   ______________________8 Bet365 = 13
#   ______________________11 1xBet = 11
#   ______________________good to Go 0
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-16 08:13:29

# %%
# Import
from a_settings.messages import *   
from a_models.api_odds import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(1, space).strftime("%Y-%m-%d")
    date_raw       = get_today(1, space)  
    # -------------------------------------------------- 
    DICT = {
        'date_0' : date_0,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 1,
        'date_raw' : date_raw,
    }
    # --------------------------------------------------  
    PREP_ = "pre_"
    # -------------------------------------------------- 
    ao_controll_match_update(DICT, PREP_, space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 08:13:29
#   __main()
#   ______get_today()
#   ________date_diff : 1
#   ________today_raw : 2023-03-17 08:13:29.055433
#   ______get_today()
#   ________date_diff : 1
#   ________today_raw : 2023-03-17 08:13:29.055433
#   ______ao_controll_match_update()
#   ________aa_check_acccount()
#   __________API digitalmedia.arion@gmail.com counter is 92
#   __________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________ao_response_odds()
#   __________date_0 : 2023-03-17
#   __________page : 1
#   __________counter_loop : 0
#   __________date_diff : 1
#   __________date_raw : 2023-03-17 08:13:29.055433
#   ____________________________________________________________________________________
#   __________Total API Response(s) : 10
#
#   ____________1. Serbia,  Super Liga  #286 - 2022 / 877125
#   ____________fixt date 2023-03-17 17:00:00+00:00
#   ____________fix local 2023-03-18 00:00:00
#   ____________local dat 2023-03-17 08:13:29
#   ____________Lebih
#   ______________league_rLeagues_id : 286
#   ______________league_rLeagues_name : Super Liga
#   ______________bookmakersapi_rLeagues_id : 11
#   ______________bookmakers_rLeagues_name : 1xBet
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ______________11==11
#   __________________1 Match Winner
#   ____________________pre_match_winner_home = '2.89',
#   ____________________pre_match_winner_draw = '3.20',
#   ____________________pre_match_winner_away = '2.43',
#   __________________3 Second Half Winner
#   ____________________pre_second_half_winner_home = '3.34',
#   ____________________pre_second_half_winner_draw = '2.28',
#   ____________________pre_second_half_winner_away = '2.73',
#   __________________4 Asian Handicap
#   ____________________pre_asian_handicap_home_plus_0 = '2.08',
#   ____________________pre_asian_handicap_away_plus_0 = '1.74',
#   ____________________pre_asian_handicap_home_min_025 = '2.46',
#   ____________________pre_asian_handicap_away_min_025 = '1.54',
#   ____________________pre_asian_handicap_home_plus_025 = '1.72',
#   ____________________pre_asian_handicap_away_plus_025 = '2.00',
#   ____________________pre_asian_handicap_home_min_075 = '3.44',
#   ____________________pre_asian_handicap_away_min_075 = '1.26',
#   ____________________pre_asian_handicap_home_plus_075 = '1.37',
#   ____________________pre_asian_handicap_away_plus_075 = '2.83',
#   ____________________pre_asian_handicap_home_min_1 = '5.15',
#   ____________________pre_asian_handicap_away_min_1 = '1.12',
#   ____________________pre_asian_handicap_home_plus_1 = '1.20',
#   ____________________pre_asian_handicap_away_plus_1 = '3.92',
#   ____________________pre_asian_handicap_home_min_15 = '6.10',
#   ____________________pre_asian_handicap_away_min_15 = '1.08',
#   ____________________pre_asian_handicap_home_plus_15 = '1.13',
#   ____________________pre_asian_handicap_away_plus_15 = '4.84',
#   ____________________pre_asian_handicap_home_min_125 = '5.70',
#   ____________________pre_asian_handicap_away_min_125 = '1.10',
#   ____________________pre_asian_handicap_home_min_175 = '8.50',
#   ____________________pre_asian_handicap_away_min_175 = '1.04',
#   ____________________pre_asian_handicap_home_plus_125 = '1.17',
#   ____________________pre_asian_handicap_away_plus_125 = '4.44',
#   ____________________pre_asian_handicap_home_plus_175 = '1.08',
#   ____________________pre_asian_handicap_away_plus_175 = '6.50',
#   ____________________pre_asian_handicap_home_plus_2 = '1.01',
#   ____________________pre_asian_handicap_away_plus_2 = '9.80',
#   ____________________pre_asian_handicap_home_plus_25 = '1.00',
#   ____________________pre_asian_handicap_away_plus_25 = '10.50',
#   __________________5 Goals Over/Under
#   ____________________pre_goals_overunder_over_35 = '3.88',
#   ____________________pre_goals_overunder_under_35 = '1.20',
#   ____________________pre_goals_overunder_over_15 = '1.36',
#   ____________________pre_goals_overunder_under_15 = '2.79',
#   ____________________pre_goals_overunder_over_45 = '7.60',
#   ____________________pre_goals_overunder_under_45 = '1.04',
#   ____________________pre_goals_overunder_over_25 = '2.21',
#   ____________________pre_goals_overunder_under_25 = '1.66',
#   ____________________pre_goals_overunder_over_05 = '1.04',
#   ____________________pre_goals_overunder_under_05 = '7.60',
#   ____________________pre_goals_overunder_over_55 = '16.00',
#   ____________________pre_goals_overunder_under_55 = '1.03',
#   ____________________pre_goals_overunder_over_225 = '1.94',
#   ____________________pre_goals_overunder_under_225 = '1.86',
#   ____________________pre_goals_overunder_over_325 = '3.56',
#   ____________________pre_goals_overunder_under_325 = '1.25',
#   ____________________pre_goals_overunder_over_275 = '2.51',
#   ____________________pre_goals_overunder_under_275 = '1.46',
#   ____________________pre_goals_overunder_over_125 = '1.23',
#   ____________________pre_goals_overunder_under_125 = '3.68',
#   ____________________pre_goals_overunder_over_425 = '7.60',
#   ____________________pre_goals_overunder_under_425 = '1.05',
#   ____________________pre_goals_overunder_over_175 = '1.47',
#   ____________________pre_goals_overunder_under_175 = '2.49',
#   ____________________pre_goals_overunder_over_375 = '4.94',
#   ____________________pre_goals_overunder_under_375 = '1.14',
#   ____________________pre_goals_overunder_over_65 = '17.00',
#   ____________________pre_goals_overunder_under_65 = '1.01',
#   ____________________pre_goals_overunder_over_075 = '1.06',
#   ____________________pre_goals_overunder_under_075 = '7.20',
#   ____________________pre_goals_overunder_over_30 = '3.18',
#   ____________________pre_goals_overunder_under_30 = '1.30',
#   ____________________pre_goals_overunder_over_20 = '1.62',
#   ____________________pre_goals_overunder_under_20 = '2.15',
#   ____________________pre_goals_overunder_over_40 = '6.85',
#   ____________________pre_goals_overunder_under_40 = '1.06',
#   ____________________pre_goals_overunder_over_10 = '1.07',
#   ____________________pre_goals_overunder_under_10 = '6.30',
#   __________________6 Goals Over/Under First Half
#   ____________________pre_goals_overunder_first_half_over_35 = '23.00',
#   ____________________pre_goals_overunder_first_half_under_35 = '1.01',
#   ____________________pre_goals_overunder_first_half_over_15 = '3.14',
#   ____________________pre_goals_overunder_first_half_under_15 = '1.33',
#   ____________________pre_goals_overunder_first_half_over_25 = '8.40',
#   ____________________pre_goals_overunder_first_half_under_25 = '1.05',
#   ____________________pre_goals_overunder_first_half_over_05 = '1.47',
#   ____________________pre_goals_overunder_first_half_under_05 = '2.57',
#   ____________________pre_goals_overunder_first_half_over_225 = '7.70',
#   ____________________pre_goals_overunder_first_half_under_225 = '1.06',
#   ____________________pre_goals_overunder_first_half_over_125 = '2.65',
#   ____________________pre_goals_overunder_first_half_under_125 = '1.44',
#   ____________________pre_goals_overunder_first_half_over_175 = '4.24',
#   ____________________pre_goals_overunder_first_half_under_175 = '1.20',
#   ____________________pre_goals_overunder_first_half_over_075 = '1.66',
#   ____________________pre_goals_overunder_first_half_under_075 = '2.14',
#   ____________________pre_goals_overunder_first_half_over_20 = '7.20',
#   ____________________pre_goals_overunder_first_half_under_20 = '1.08',
#   ____________________pre_goals_overunder_first_half_over_10 = '2.09',
#   ____________________pre_goals_overunder_first_half_under_10 = '1.69',
#   __________________26 Goals Over/Under - Second Half
#   ____________________pre_goals_overunder__second_half_over_35 = '13.00',
#   ____________________pre_goals_overunder__second_half_under_35 = '1.04',
#   ____________________pre_goals_overunder__second_half_over_15 = '2.38',
#   ____________________pre_goals_overunder__second_half_under_15 = '1.54',
#   ____________________pre_goals_overunder__second_half_over_25 = '5.50',
#   ____________________pre_goals_overunder__second_half_under_25 = '1.13',
#   ____________________pre_goals_overunder__second_half_over_05 = '1.30',
#   ____________________pre_goals_overunder__second_half_under_05 = '3.32',
#   ____________________pre_goals_overunder__second_half_over_225 = '4.94',
#   ____________________pre_goals_overunder__second_half_under_225 = '1.15',
#   ____________________pre_goals_overunder__second_half_over_125 = '1.98',
#   ____________________pre_goals_overunder__second_half_under_125 = '1.77',
#   ____________________pre_goals_overunder__second_half_over_175 = '2.97',
#   ____________________pre_goals_overunder__second_half_under_175 = '1.37',
#   ____________________pre_goals_overunder__second_half_over_075 = '1.40',
#   ____________________pre_goals_overunder__second_half_under_075 = '2.81',
#   ____________________pre_goals_overunder__second_half_over_20 = '4.40',
#   ____________________pre_goals_overunder__second_half_under_20 = '1.19',
#   ____________________pre_goals_overunder__second_half_over_10 = '1.59',
#   ____________________pre_goals_overunder__second_half_under_10 = '2.27',
#   __________________7 HT/FT Double
#   __________________8 Both Teams Score
#   ____________________pre_both_teams_score_yes = '1.85',
#   ____________________pre_both_teams_score_no = '1.91',
#   __________________9 Handicap Result
#   ______________  ______________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 6.10
#   ______________  ______________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.38
#   ______________  ______________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.20
#   ______________  ______________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.52
#   ______________  ______________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 4.84
#   ______________  ______________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.74
#   ______________  ______________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.13
#   ______________  ______________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 6.70
#   ______________  ______________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 10.50
#   ______________  ______________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 13.00
#   ______________  ______________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 8.50
#   ______________  ______________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.08
#   ______________  ______________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 29.00
#   ______________  ______________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 21.00
#   ______________  ______________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.01
#   ______________  ______________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.04
#   ______________  ______________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 15.00
#   ______________  ______________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 26.00
#   ______________  ______________bet_id: 9 --- bets_value: Home +4 --- bets_odd: 1.01
#   ______________  ______________bet_id: 9 --- bets_value: Draw +4 --- bets_odd: 23.00
#   ______________  ______________bet_id: 9 --- bets_value: Away +4 --- bets_odd: 29.00
#   __________________10 Exact Score
#   __________________11 Highest Scoring Half
#   __________________31 Correct Score - First Half
#   ______________  ______________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 17.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 26.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 81.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.57
#   ______________  ______________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.32
#   ______________  ______________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 13.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 23.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 67.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________62 Correct Score - Second Half
#   ______________  ______________bet_id: 62 --- bets_value: 1:0 --- bets_odd: 5.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:0 --- bets_odd: 15.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:1 --- bets_odd: 19.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:0 --- bets_odd: 50.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:1 --- bets_odd: 60.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:2 --- bets_odd: 60.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:0 --- bets_odd: 3.32
#   ______________  ______________bet_id: 62 --- bets_value: 1:1 --- bets_odd: 7.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:2 --- bets_odd: 40.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:1 --- bets_odd: 4.80
#   ______________  ______________bet_id: 62 --- bets_value: 0:2 --- bets_odd: 12.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:3 --- bets_odd: 35.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:2 --- bets_odd: 18.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:3 --- bets_odd: 55.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:3 --- bets_odd: 60.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________12 Double Chance
#   ____________________pre_double_chance_home_draw = '1.52',
#   ____________________pre_double_chance_home_away = '1.32',
#   ____________________pre_double_chance_draw_away = '1.38',
#   __________________13 First Half Winner
#   ____________________pre_first_half_winner_home = '3.70',
#   ____________________pre_first_half_winner_draw = '1.98',
#   ____________________pre_first_half_winner_away = '3.04',
#   __________________16 Total - Home
#   ______________  ______________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.75
#   ______________  ______________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.40
#   ______________  ______________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 7.20
#   ______________  ______________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.06
#   ______________  ______________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.38
#   ______________  ______________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 2.80
#   ______________  ______________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 5.70
#   ______________  ______________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.10
#   ______________  ______________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.82
#   ______________  ______________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 1.88
#   __________________17 Total - Away
#   ______________  ______________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 11.00
#   ______________  ______________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.03
#   ______________  ______________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.44
#   ______________  ______________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.49
#   ______________  ______________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 5.90
#   ______________  ______________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.10
#   ______________  ______________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.31
#   ______________  ______________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 3.10
#   ______________  ______________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 5.50
#   ______________  ______________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.11
#   ______________  ______________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.63
#   ______________  ______________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 2.15
#   __________________18 Handicap Result - First Half
#   ______________  ______________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 12.00
#   ______________  ______________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.29
#   ______________  ______________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 4.32
#   ______________  ______________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.28
#   ______________  ______________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 9.40
#   ______________  ______________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.94
#   ______________  ______________bet_id: 18 --- bets_value: Home +2 --- bets_odd: 1.05
#   ______________  ______________bet_id: 18 --- bets_value: Draw +2 --- bets_odd: 12.00
#   ______________  ______________bet_id: 18 --- bets_value: Away +2 --- bets_odd: 34.00
#   ______________  ______________bet_id: 18 --- bets_value: Home +3 --- bets_odd: 1.01
#   ______________  ______________bet_id: 18 --- bets_value: Draw +3 --- bets_odd: 41.00
#   ______________  ______________bet_id: 18 --- bets_value: Away +3 --- bets_odd: 151.00
#   __________________19 Asian Handicap First Half
#   __________________20 Double Chance - First Half
#   __________________33 Double Chance - Second Half
#   ______________  ______________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.34
#   ______________  ______________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.48
#   ______________  ______________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.24
#   __________________34 Both Teams Score - First Half
#   __________________35 Both Teams To Score - Second Half
#   __________________21 Odd/Even
#   __________________22 Odd/Even - First Half
#   ______________  ______________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.07
#   ______________  ______________bet_id: 22 --- bets_value: Even --- bets_odd: 1.64
#   __________________23 Home Odd/Even
#   ______________  ______________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.01
#   ______________  ______________bet_id: 23 --- bets_value: Even --- bets_odd: 1.68
#   __________________60 Away Odd/Even
#   ______________  ______________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.95
#   ______________  ______________bet_id: 60 --- bets_value: Even --- bets_odd: 1.72
#   ______________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ______________2. Serbia,  Super Liga  #286 - 2022 / 877129
#   ______________fixt date 2023-03-17 15:00:00+00:00
#   ______________fix local 2023-03-17 22:00:00
#   ______________local dat 2023-03-17 08:13:29
#   ______________Lebih
#   ________________league_rLeagues_id : 286
#   ________________league_rLeagues_name : Super Liga
#   ________________bookmakersapi_rLeagues_id : 11
#   ________________bookmakers_rLeagues_name : 1xBet
#   ______________Total fixtureapi_id Row(s) : 1
#   ______________good to Go 1
#   ________________11==11
#   ____________________1 Match Winner
#   ______________________pre_match_winner_home = '1.20',
#   ______________________pre_match_winner_draw = '6.20',
#   ______________________pre_match_winner_away = '13.50',
#   ____________________3 Second Half Winner
#   ______________________pre_second_half_winner_home = '1.43',
#   ______________________pre_second_half_winner_draw = '3.22',
#   ______________________pre_second_half_winner_away = '10.00',
#   ____________________4 Asian Handicap
#   ______________________pre_asian_handicap_home_plus_0 = '1.01',
#   ______________________pre_asian_handicap_away_plus_0 = '9.80',
#   ______________________pre_asian_handicap_home_min_025 = '1.10',
#   ______________________pre_asian_handicap_away_min_025 = '5.75',
#   ______________________pre_asian_handicap_home_min_075 = '1.22',
#   ______________________pre_asian_handicap_away_min_075 = '3.80',
#   ______________________pre_asian_handicap_home_min_1 = '1.27',
#   ______________________pre_asian_handicap_away_min_1 = '3.36',
#   ______________________pre_asian_handicap_home_min_15 = '1.68',
#   ______________________pre_asian_handicap_away_min_15 = '2.17',
#   ______________________pre_asian_handicap_home_min_125 = '1.45',
#   ______________________pre_asian_handicap_away_min_125 = '2.53',
#   ______________________pre_asian_handicap_home_min_175 = '1.86',
#   ______________________pre_asian_handicap_away_min_175 = '1.93',
#   ______________________pre_asian_handicap_home_min_2 = '2.07',
#   ______________________pre_asian_handicap_away_min_2 = '1.66',
#   ______________________pre_asian_handicap_home_min_3 = '4.04',
#   ______________________pre_asian_handicap_away_min_3 = '1.18',
#   ______________________pre_asian_handicap_home_min_25 = '2.60',
#   ______________________pre_asian_handicap_away_min_25 = '1.41',
#   ______________________pre_asian_handicap_home_min_225 = '2.35',
#   ______________________pre_asian_handicap_away_min_225 = '1.52',
#   ______________________pre_asian_handicap_home_min_275 = '3.11',
#   ______________________pre_asian_handicap_away_min_275 = '1.31',
#   ______________________pre_asian_handicap_home_min_325 = '4.42',
#   ______________________pre_asian_handicap_away_min_325 = '1.17',
#   ______________________pre_asian_handicap_home_min_375 = '6.00',
#   ______________________pre_asian_handicap_away_min_375 = '1.09',
#   ______________________pre_asian_handicap_home_min_4 = '8.40',
#   ______________________pre_asian_handicap_away_min_4 = '1.03',
#   ______________________pre_asian_handicap_home_min_45 = '8.90',
#   ______________________pre_asian_handicap_away_min_45 = '1.02',
#   ______________________pre_asian_handicap_home_min_35 = '4.74',
#   ______________________pre_asian_handicap_away_min_35 = '1.13',
#   ____________________5 Goals Over/Under
#   ______________________pre_goals_overunder_over_35 = '2.60',
#   ______________________pre_goals_overunder_under_35 = '1.41',
#   ______________________pre_goals_overunder_over_15 = '1.18',
#   ______________________pre_goals_overunder_under_15 = '4.00',
#   ______________________pre_goals_overunder_over_45 = '4.64',
#   ______________________pre_goals_overunder_under_45 = '1.14',
#   ______________________pre_goals_overunder_over_25 = '1.69',
#   ______________________pre_goals_overunder_under_25 = '2.16',
#   ______________________pre_goals_overunder_over_05 = '1.04',
#   ______________________pre_goals_overunder_under_05 = '12.00',
#   ______________________pre_goals_overunder_over_55 = '8.60',
#   ______________________pre_goals_overunder_under_55 = '1.03',
#   ______________________pre_goals_overunder_over_225 = '1.47',
#   ______________________pre_goals_overunder_under_225 = '2.48',
#   ______________________pre_goals_overunder_over_325 = '2.35',
#   ______________________pre_goals_overunder_under_325 = '1.52',
#   ______________________pre_goals_overunder_over_275 = '1.87',
#   ______________________pre_goals_overunder_under_275 = '1.93',
#   ______________________pre_goals_overunder_over_125 = '1.10',
#   ______________________pre_goals_overunder_under_125 = '5.55',
#   ______________________pre_goals_overunder_over_425 = '4.34',
#   ______________________pre_goals_overunder_under_425 = '1.17',
#   ______________________pre_goals_overunder_over_175 = '1.24',
#   ______________________pre_goals_overunder_under_175 = '3.62',
#   ______________________pre_goals_overunder_over_375 = '3.11',
#   ______________________pre_goals_overunder_under_375 = '1.31',
#   ______________________pre_goals_overunder_over_475 = '5.80',
#   ______________________pre_goals_overunder_under_475 = '1.10',
#   ______________________pre_goals_overunder_over_65 = '11.00',
#   ______________________pre_goals_overunder_under_65 = '1.02',
#   ______________________pre_goals_overunder_over_75 = '17.00',
#   ______________________pre_goals_overunder_under_75 = '1.01',
#   ______________________pre_goals_overunder_over_30 = '2.08',
#   ______________________pre_goals_overunder_under_30 = '1.66',
#   ______________________pre_goals_overunder_over_20 = '1.30',
#   ______________________pre_goals_overunder_under_20 = '3.18',
#   ______________________pre_goals_overunder_over_40 = '3.98',
#   ______________________pre_goals_overunder_under_40 = '1.19',
#   ______________________pre_goals_overunder_over_10 = '1.01',
#   ______________________pre_goals_overunder_under_10 = '10.00',
#   ______________________pre_goals_overunder_over_50 = '7.90',
#   ______________________pre_goals_overunder_under_50 = '1.04',
#   ____________________6 Goals Over/Under First Half
#   ______________________pre_goals_overunder_first_half_over_35 = '10.00',
#   ______________________pre_goals_overunder_first_half_under_35 = '1.04',
#   ______________________pre_goals_overunder_first_half_over_15 = '2.48',
#   ______________________pre_goals_overunder_first_half_under_15 = '1.50',
#   ______________________pre_goals_overunder_first_half_over_25 = '5.85',
#   ______________________pre_goals_overunder_first_half_under_25 = '1.11',
#   ______________________pre_goals_overunder_first_half_over_05 = '1.31',
#   ______________________pre_goals_overunder_first_half_under_05 = '3.26',
#   ______________________pre_goals_overunder_first_half_over_225 = '5.25',
#   ______________________pre_goals_overunder_first_half_under_225 = '1.14',
#   ______________________pre_goals_overunder_first_half_over_125 = '2.06',
#   ______________________pre_goals_overunder_first_half_under_125 = '1.71',
#   ______________________pre_goals_overunder_first_half_over_175 = '3.10',
#   ______________________pre_goals_overunder_first_half_under_175 = '1.34',
#   ______________________pre_goals_overunder_first_half_over_075 = '1.42',
#   ______________________pre_goals_overunder_first_half_under_075 = '2.74',
#   ______________________pre_goals_overunder_first_half_over_30 = '8.00',
#   ______________________pre_goals_overunder_first_half_under_30 = '1.05',
#   ______________________pre_goals_overunder_first_half_over_20 = '4.70',
#   ______________________pre_goals_overunder_first_half_under_20 = '1.17',
#   ______________________pre_goals_overunder_first_half_over_10 = '1.64',
#   ______________________pre_goals_overunder_first_half_under_10 = '2.18',
#   ____________________26 Goals Over/Under - Second Half
#   ______________________pre_goals_overunder__second_half_over_35 = '8.00',
#   ______________________pre_goals_overunder__second_half_under_35 = '1.06',
#   ______________________pre_goals_overunder__second_half_over_15 = '1.90',
#   ______________________pre_goals_overunder__second_half_under_15 = '1.84',
#   ______________________pre_goals_overunder__second_half_over_25 = '3.80',
#   ______________________pre_goals_overunder__second_half_under_25 = '1.24',
#   ______________________pre_goals_overunder__second_half_over_05 = '1.18',
#   ______________________pre_goals_overunder__second_half_under_05 = '4.50',
#   ______________________pre_goals_overunder__second_half_over_225 = '3.32',
#   ______________________pre_goals_overunder__second_half_under_225 = '1.30',
#   ______________________pre_goals_overunder__second_half_over_125 = '1.62',
#   ______________________pre_goals_overunder__second_half_under_125 = '2.22',
#   ______________________pre_goals_overunder__second_half_over_175 = '2.23',
#   ______________________pre_goals_overunder__second_half_under_175 = '1.61',
#   ______________________pre_goals_overunder__second_half_over_075 = '1.24',
#   ______________________pre_goals_overunder__second_half_under_075 = '3.78',
#   ______________________pre_goals_overunder__second_half_over_30 = '6.70',
#   ______________________pre_goals_overunder__second_half_under_30 = '1.07',
#   ______________________pre_goals_overunder__second_half_over_20 = '2.90',
#   ______________________pre_goals_overunder__second_half_under_20 = '1.38',
#   ______________________pre_goals_overunder__second_half_over_10 = '1.33',
#   ______________________pre_goals_overunder__second_half_under_10 = '3.14',
#   ____________________7 HT/FT Double
#   ____________________8 Both Teams Score
#   ______________________pre_both_teams_score_yes = '2.42',
#   ______________________pre_both_teams_score_no = '1.54',
#   ____________________9 Handicap Result
#   ________________  ________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 1.68
#   ________________  ________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 4.30
#   ________________  ________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.56
#   ________________  ________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.02
#   ________________  ________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 26.00
#   ________________  ________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 13.00
#   ________________  ________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 2.60
#   ________________  ________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 3.64
#   ________________  ________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 2.17
#   ________________  ________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 4.74
#   ________________  ________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 4.80
#   ________________  ________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.41
#   ________________  ________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 8.90
#   ________________  ________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.13
#   ________________  ________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 7.30
#   ________________  ________________bet_id: 9 --- bets_value: Home -5 --- bets_odd: 17.00
#   ________________  ________________bet_id: 9 --- bets_value: Away -5 --- bets_odd: 1.03
#   ________________  ________________bet_id: 9 --- bets_value: Draw -5 --- bets_odd: 13.00
#   ____________________10 Exact Score
#   ____________________11 Highest Scoring Half
#   ____________________31 Correct Score - First Half
#   ________________  ________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.10
#   ________________  ________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 5.50
#   ________________  ________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 19.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 13.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 41.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 34.00
#   ________________  ________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 81.00
#   ________________  ________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 81.00
#   ________________  ________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.26
#   ________________  ________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 11.00
#   ________________  ________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 12.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 51.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 51.00
#   ________________  ________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ________________  ________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   ____________________62 Correct Score - Second Half
#   ________________  ________________bet_id: 62 --- bets_value: 1:0 --- bets_odd: 3.50
#   ________________  ________________bet_id: 62 --- bets_value: 2:0 --- bets_odd: 5.00
#   ________________  ________________bet_id: 62 --- bets_value: 2:1 --- bets_odd: 15.00
#   ________________  ________________bet_id: 62 --- bets_value: 3:0 --- bets_odd: 10.00
#   ________________  ________________bet_id: 62 --- bets_value: 3:1 --- bets_odd: 30.00
#   ________________  ________________bet_id: 62 --- bets_value: 3:2 --- bets_odd: 60.00
#   ________________  ________________bet_id: 62 --- bets_value: 4:0 --- bets_odd: 37.00
#   ________________  ________________bet_id: 62 --- bets_value: 4:1 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 4:2 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 4:3 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 5:0 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 5:1 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 5:2 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 5:3 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 5:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 0:0 --- bets_odd: 4.50
#   ________________  ________________bet_id: 62 --- bets_value: 1:1 --- bets_odd: 10.00
#   ________________  ________________bet_id: 62 --- bets_value: 2:2 --- bets_odd: 60.00
#   ________________  ________________bet_id: 62 --- bets_value: 3:3 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 4:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 0:1 --- bets_odd: 13.00
#   ________________  ________________bet_id: 62 --- bets_value: 0:2 --- bets_odd: 60.00
#   ________________  ________________bet_id: 62 --- bets_value: 0:3 --- bets_odd: 60.00
#   ________________  ________________bet_id: 62 --- bets_value: 0:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 0:5 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 1:2 --- bets_odd: 45.00
#   ________________  ________________bet_id: 62 --- bets_value: 1:3 --- bets_odd: 60.00
#   ________________  ________________bet_id: 62 --- bets_value: 1:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 1:5 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 2:3 --- bets_odd: 60.00
#   ________________  ________________bet_id: 62 --- bets_value: 2:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 2:5 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 3:4 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 3:5 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 4:5 --- bets_odd: 100.00
#   ________________  ________________bet_id: 62 --- bets_value: 5:5 --- bets_odd: 100.00
#   ____________________12 Double Chance
#   ______________________pre_double_chance_home_draw = '1.02',
#   ______________________pre_double_chance_home_away = '1.10',
#   ______________________pre_double_chance_draw_away = '4.30',
#   ____________________13 First Half Winner
#   ______________________pre_first_half_winner_home = '1.60',
#   ______________________pre_first_half_winner_draw = '2.60',
#   ______________________pre_first_half_winner_away = '10.00',
#   ____________________16 Total - Home
#   ________________  ________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 3.74
#   ________________  ________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.23
#   ________________  ________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.35
#   ________________  ________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 2.90
#   ________________  ________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 7.10
#   ________________  ________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.06
#   ________________  ________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 2.15
#   ________________  ________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.63
#   ________________  ________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.05
#   ________________  ________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 7.90
#   ________________  ________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 1.60
#   ________________  ________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 2.20
#   ________________  ________________bet_id: 16 --- bets_value: Over 3 --- bets_odd: 3.10
#   ________________  ________________bet_id: 16 --- bets_value: Under 3 --- bets_odd: 1.32
#   ________________  ________________bet_id: 16 --- bets_value: Over 4 --- bets_odd: 5.80
#   ________________  ________________bet_id: 16 --- bets_value: Under 4 --- bets_odd: 1.10
#   ________________  ________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.08
#   ________________  ________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 6.40
#   ____________________17 Total - Away
#   ________________  ________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 7.20
#   ________________  ________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.06
#   ________________  ________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 2.13
#   ________________  ________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 1.64
#   ________________  ________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 5.30
#   ________________  ________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 1.12
#   ____________________18 Handicap Result - First Half
#   ________________  ________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 3.48
#   ________________  ________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 2.07
#   ________________  ________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 2.72
#   ________________  ________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.03
#   ________________  ________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 41.00
#   ________________  ________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 11.00
#   ________________  ________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 8.60
#   ________________  ________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 5.25
#   ________________  ________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.24
#   ________________  ________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 23.00
#   ________________  ________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 12.00
#   ________________  ________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.06
#   ____________________19 Asian Handicap First Half
#   ____________________20 Double Chance - First Half
#   ____________________33 Double Chance - Second Half
#   ________________  ________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.03
#   ________________  ________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.24
#   ________________  ________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 2.43
#   ____________________34 Both Teams Score - First Half
#   ____________________35 Both Teams To Score - Second Half
#   ____________________21 Odd/Even
#   ____________________22 Odd/Even - First Half
#   ________________  ________________bet_id: 22 --- bets_value: Odd --- bets_odd: 1.95
#   ________________  ________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   ____________________23 Home Odd/Even
#   ________________  ________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.83
#   ________________  ________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.83
#   ____________________60 Away Odd/Even
#   ________________  ________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.75
#   ________________  ________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.37
#   ________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ________________3. Bulgaria,  First League  #172 - 2022 / 883502
#   ________________fixt date 2023-03-17 13:00:00+00:00
#   ________________fix local 2023-03-17 20:00:00
#   ________________local dat 2023-03-17 08:13:29
#   ________________Lebih
#   __________________league_rLeagues_id : 172
#   __________________league_rLeagues_name : A PFG
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   __________________8==8
#   ______________________1 Match Winner
#   ________________________pre_match_winner_home = '1.50',
#   ________________________pre_match_winner_draw = '3.80',
#   ________________________pre_match_winner_away = '7.00',
#   ______________________2 Home/Away
#   ________________________pre_homeaway_home = '1.17',
#   ________________________pre_homeaway_away = '5.00',
#   ______________________3 Second Half Winner
#   ________________________pre_second_half_winner_home = '1.83',
#   ________________________pre_second_half_winner_draw = '2.50',
#   ________________________pre_second_half_winner_away = '6.00',
#   ______________________4 Asian Handicap
#   ________________________pre_asian_handicap_home_plus_0 = '1.16',
#   ________________________pre_asian_handicap_away_plus_0 = '5.25',
#   ________________________pre_asian_handicap_home_min_025 = '1.32',
#   ________________________pre_asian_handicap_away_min_025 = '3.30',
#   ________________________pre_asian_handicap_home_plus_025 = '1.13',
#   ________________________pre_asian_handicap_away_plus_025 = '5.90',
#   ________________________pre_asian_handicap_home_min_05 = '1.50',
#   ________________________pre_asian_handicap_away_min_05 = '2.50',
#   ________________________pre_asian_handicap_home_plus_05 = '1.11',
#   ________________________pre_asian_handicap_away_plus_05 = '6.40',
#   ________________________pre_asian_handicap_home_min_075 = '1.63',
#   ________________________pre_asian_handicap_away_min_075 = '2.25',
#   ________________________pre_asian_handicap_home_plus_075 = '1.10',
#   ________________________pre_asian_handicap_away_plus_075 = '7.00',
#   ________________________pre_asian_handicap_home_min_1 = '1.90',
#   ________________________pre_asian_handicap_away_min_1 = '1.95',
#   ________________________pre_asian_handicap_home_min_15 = '2.42',
#   ________________________pre_asian_handicap_away_min_15 = '1.52',
#   ________________________pre_asian_handicap_home_min_125 = '2.20',
#   ________________________pre_asian_handicap_away_min_125 = '1.65',
#   ________________________pre_asian_handicap_home_min_175 = '3.00',
#   ________________________pre_asian_handicap_away_min_175 = '1.38',
#   ________________________pre_asian_handicap_home_min_2 = '4.10',
#   ________________________pre_asian_handicap_away_min_2 = '1.23',
# ...
#   ____________________________pre_goals_overunder__second_half_under_30 = '1.15',
#   ____________________________pre_goals_overunder__second_half_over_20 = '2.05',
#   ____________________________pre_goals_overunder__second_half_under_20 = '1.69',
#   ____________________________pre_goals_overunder__second_half_over_10 = '1.16',
#   ____________________________pre_goals_overunder__second_half_under_10 = '4.54',
#   __________________________7 HT/FT Double
#   __________________________8 Both Teams Score
#   ____________________________pre_both_teams_score_yes = '1.34',
#   ____________________________pre_both_teams_score_no = '3.14',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 3.42
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.66
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.10
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.36
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 5.25
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.80
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 7.70
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 6.55
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 5.80
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.05
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 15.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 4.10
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________________62 Correct Score - Second Half
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:0 --- bets_odd: 5.60
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:0 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:1 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:0 --- bets_odd: 27.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:1 --- bets_odd: 28.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:2 --- bets_odd: 53.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:0 --- bets_odd: 73.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:1 --- bets_odd: 78.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:0 --- bets_odd: 6.10
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:1 --- bets_odd: 6.05
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:2 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:1 --- bets_odd: 6.70
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:2 --- bets_odd: 14.50
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:3 --- bets_odd: 43.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:2 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:3 --- bets_odd: 38.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:3 --- bets_odd: 61.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________________12 Double Chance
#   ____________________________pre_double_chance_home_draw = '1.36',
#   ____________________________pre_double_chance_home_away = '1.21',
#   ____________________________pre_double_chance_draw_away = '1.66',
#   __________________________13 First Half Winner
#   ____________________________pre_first_half_winner_home = '2.49',
#   ____________________________pre_first_half_winner_draw = '2.48',
#   ____________________________pre_first_half_winner_away = '3.32',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 5.60
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.63
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 2.13
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 2.80
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 4.90
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 2.15
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.63
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3 --- bets_odd: 4.80
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3 --- bets_odd: 1.15
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 3.84
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.72
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 4.10
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.19
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.23
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 3.74
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 3.20
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 3 --- bets_odd: 6.80
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 3 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 2.70
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 6.35
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.41
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.76
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.24
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 8.60
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 4.44
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________33 Double Chance - Second Half
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.47
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.76
#   __________________________23 Home Odd/Even
#   ______________________  ______________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.85
#   ______________________  ______________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.81
#   __________________________60 Away Odd/Even
#   ______________________  ______________________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.88
#   ______________________  ______________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.78
#   ______________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-16 08:14:17

# %%
# Import
from a_settings.messages import *   
from a_models.football_fixtures import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(0, space).strftime("%Y-%m-%d")  
    date_raw         = get_today(0, space)
    # --------------------------------------------------   
    ff_gak_sempet_predates(date_0, date_raw, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 08:14:17
#   __main()
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-16 08:14:17.456992
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-16 08:14:17.456992
#   ______ff_gak_sempet_predates()
#   ________Select leagueapi_id, league_name, league_country, season, DATE(date),   (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id)  from football_fixtures  where date = '2023-03-16'  and deleted_at is null  and pre_odd_updated_at is null  group by leagueapi_id, league_name, league_country, season, DATE(date)  order by league_country, leagueapi_id asc
#   ________Total Row(s) : 0
#   __________Are you sure want to continue? :  yes
# # -------------------------------------------------- End at 2023-03-16 08:14:22

# %%
# Import
from a_settings.messages import *   
from a_models.football_fixtures import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(1, space).strftime("%Y-%m-%d")  
    date_raw         = get_today(0, space)
    # --------------------------------------------------   
    ff_gak_sempet_predates(date_0, date_raw, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 08:14:22
#   __main()
#   ______get_today()
#   ________date_diff : 1
#   ________today_raw : 2023-03-17 08:14:22.141527
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-16 08:14:22.141527
#   ______ff_gak_sempet_predates()
#   ________Select leagueapi_id, league_name, league_country, season, DATE(date),   (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id)  from football_fixtures  where date = '2023-03-17'  and deleted_at is null  and pre_odd_updated_at is null  group by leagueapi_id, league_name, league_country, season, DATE(date)  order by league_country, leagueapi_id asc
#   ________Total Row(s) : 6
#   __________[1/6] Argentina - Primera Nacional -----#129 - 2023 - 2023-03-17 - 8
#   __________[2/6] Austria - 2. Liga -----#219 - 2022 - 2023-03-17 - 8
#   __________[3/6] Azerbaidjan - Premyer Liqa -----#419 - 2022 - 2023-03-17 - 11
#   __________[4/6] Germany - Frauen Bundesliga -----#82 - 2022 - 2023-03-17 - 11
#   __________[5/6] Switzerland - Challenge League -----#208 - 2022 - 2023-03-17 - 11
#   __________[6/6] World - CONCACAF Champions League -----#16 - 2023 - 2023-03-17 - 8
#   __________Are you sure want to continue? :  yes
#   __________[1/6] Argentina - Primera Nacional -----#129 - 2023 - 2023-03-17 - 8
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 89
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-17
#   ________________date_raw : 2023-03-16 08:14:22.141527
#   ________________bookmaker : 8
#   ________________season : 2023
#   ________________league : 129
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[2/6] Austria - 2. Liga -----#219 - 2022 - 2023-03-17 - 8
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 88
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-17
#   ________________date_raw : 2023-03-16 08:14:22.141527
#   ________________bookmaker : 8
#   ________________season : 2022
#   ________________league : 219
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[3/6] Azerbaidjan - Premyer Liqa -----#419 - 2022 - 2023-03-17 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 87
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-17
#   ________________date_raw : 2023-03-16 08:14:22.141527
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 419
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[4/6] Germany - Frauen Bundesliga -----#82 - 2022 - 2023-03-17 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 86
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-17
#   ________________date_raw : 2023-03-16 08:14:22.141527
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 82
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[5/6] Switzerland - Challenge League -----#208 - 2022 - 2023-03-17 - 11
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 85
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-17
#   ________________date_raw : 2023-03-16 08:14:22.141527
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 208
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________[6/6] World - CONCACAF Champions League -----#16 - 2023 - 2023-03-17 - 8
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 84
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-17
#   ________________date_raw : 2023-03-16 08:14:22.141527
#   ________________bookmaker : 8
#   ________________season : 2023
#   ________________league : 16
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 2
#
#   __________________1. World,  CONCACAF Champions League  #16 - 2023 / 972938
#   __________________fixt date 2023-03-17 00:00:00+00:00
#   __________________fix local 2023-03-17 07:00:00
#   __________________local dat 2023-03-16 08:14:22
#   __________________Lebih
#   ____________________league_rLeagues_id : 16
#   ____________________league_rLeagues_name : CONCACAF Champions League
#   ____________________bookmakersapi_rLeagues_id : 8
#   ____________________bookmakers_rLeagues_name : Bet365
#   __________________Total fixtureapi_id Row(s) : 1
#   __________________good to Go 1
#   ____________________8==8
#   ________________________1 Match Winner
#   __________________________pre_match_winner_home = '1.20',
#   __________________________pre_match_winner_draw = '5.00',
#   __________________________pre_match_winner_away = '12.00',
#   ________________________2 Home/Away
#   __________________________pre_homeaway_home = '1.05',
#   __________________________pre_homeaway_away = '11.00',
#   ________________________3 Second Half Winner
#   __________________________pre_second_half_winner_home = '1.44',
#   __________________________pre_second_half_winner_draw = '3.10',
#   __________________________pre_second_half_winner_away = '11.00',
#   ________________________5 Goals Over/Under
#   __________________________pre_goals_overunder_over_35 = '2.63',
#   __________________________pre_goals_overunder_under_35 = '1.44',
#   __________________________pre_goals_overunder_over_15 = '1.22',
#   __________________________pre_goals_overunder_under_15 = '4.00',
#   __________________________pre_goals_overunder_over_45 = '5.00',
#   __________________________pre_goals_overunder_under_45 = '1.17',
#   __________________________pre_goals_overunder_over_25 = '1.67',
#   __________________________pre_goals_overunder_under_25 = '2.15',
#   __________________________pre_goals_overunder_over_05 = '1.05',
#   __________________________pre_goals_overunder_under_05 = '11.00',
#   __________________________pre_goals_overunder_over_55 = '11.00',
#   __________________________pre_goals_overunder_under_55 = '1.05',
#   __________________________pre_goals_overunder_over_65 = '21.00',
#   __________________________pre_goals_overunder_under_65 = '1.02',
#   __________________________pre_goals_overunder_over_75 = '41.00',
#   __________________________pre_goals_overunder_under_75 = '1.00',
#   ________________________6 Goals Over/Under First Half
#   __________________________pre_goals_overunder_first_half_over_35 = '17.00',
#   __________________________pre_goals_overunder_first_half_under_35 = '1.02',
#   __________________________pre_goals_overunder_first_half_over_15 = '2.50',
#   __________________________pre_goals_overunder_first_half_under_15 = '1.50',
#   __________________________pre_goals_overunder_first_half_over_25 = '6.00',
#   __________________________pre_goals_overunder_first_half_under_25 = '1.13',
#   __________________________pre_goals_overunder_first_half_over_05 = '1.33',
#   __________________________pre_goals_overunder_first_half_under_05 = '3.25',
#   ________________________26 Goals Over/Under - Second Half
#   __________________________pre_goals_overunder__second_half_over_35 = '10.00',
#   __________________________pre_goals_overunder__second_half_under_35 = '1.06',
#   __________________________pre_goals_overunder__second_half_over_15 = '1.83',
#   __________________________pre_goals_overunder__second_half_under_15 = '1.83',
#   __________________________pre_goals_overunder__second_half_over_25 = '3.75',
#   __________________________pre_goals_overunder__second_half_under_25 = '1.25',
#   __________________________pre_goals_overunder__second_half_over_05 = '1.18',
#   __________________________pre_goals_overunder__second_half_under_05 = '4.50',
#   ________________________7 HT/FT Double
#   ________________________27 Clean Sheet - Home
#   __________________________pre_clean_sheet__home_yes = '1.57',
#   __________________________pre_clean_sheet__home_no = '2.25',
#   ________________________28 Clean Sheet - Away
#   __________________________pre_clean_sheet__away_yes = '9.00',
#   __________________________pre_clean_sheet__away_no = '1.07',
#   ________________________8 Both Teams Score
#   __________________________pre_both_teams_score_yes = '2.50',
#   __________________________pre_both_teams_score_no = '1.50',
#   ________________________9 Handicap Result
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 1.67
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.04
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 2.75
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 2.10
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.44
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 10.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.14
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 8.00
#   ________________________10 Exact Score
#   ________________________11 Highest Scoring Half
#   ________________________31 Correct Score - First Half
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 21.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 151.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 301.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 6:0 --- bets_odd: 351.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.25
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 351.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 351.00
#   ________________________12 Double Chance
#   __________________________pre_double_chance_home_draw = '1.04',
#   __________________________pre_double_chance_home_away = '1.14',
#   __________________________pre_double_chance_draw_away = '4.00',
#   ________________________13 First Half Winner
#   __________________________pre_first_half_winner_home = '1.62',
#   __________________________pre_first_half_winner_draw = '2.60',
#   __________________________pre_first_half_winner_away = '12.00',
#   ________________________14 Team To Score First
#   ____________________  ____________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.17
#   ____________________  ____________________bet_id: 14 --- bets_value: Draw --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 14 --- bets_value: Away --- bets_odd: 6.00
#   ________________________15 Team To Score Last
#   ____________________  ____________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.17
#   ____________________  ____________________bet_id: 15 --- bets_value: Draw --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 15 --- bets_value: Away --- bets_odd: 6.00
#   ________________________32 Win Both Halves
#   __________________________pre_win_both_halves_home = '2.50',
#   __________________________pre_win_both_halves_away = '67.00',
#   ________________________16 Total - Home
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.22
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.36
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.07
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 2.10
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.67
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 5.5 --- bets_odd: 19.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 5.5 --- bets_odd: 1.02
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 6.5 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 6.5 --- bets_odd: 1.00
#   ________________________17 Total - Away
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.07
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.00
#   ________________________18 Handicap Result - First Half
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 3.50
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 2.20
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 2.75
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.02
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 4.75
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.25
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 26.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.05
#   ________________________20 Double Chance - First Half
#   ________________________34 Both Teams Score - First Half
#   ________________________35 Both Teams To Score - Second Half
#   ________________________36 Win To Nil
#   __________________________pre_win_to_nil_home = '1.73',
#   __________________________pre_win_to_nil_away = '19.00',
#   ________________________21 Odd/Even
#   ________________________22 Odd/Even - First Half
#   ____________________  ____________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.10
#   ____________________  ____________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   ________________________39 To Win Either Half
#   __________________________pre_to_win_either_half_home = '1.13',
#   __________________________pre_to_win_either_half_away = '6.00',
#   ________________________40 Home Team Exact Goals Number
#   ________________________41 Away Team Exact Goals Number
#   ________________________61 To Qualify
#   ____________________  ____________________bet_id: 61 --- bets_value: Home --- bets_odd: 1.02
#   ____________________  ____________________bet_id: 61 --- bets_value: Away --- bets_odd: 17.00
#   ________________________24 Results/Both Teams Score
#   __________________________pre_results_both_teams_score_home_yes = '3.50',
#   __________________________pre_results_both_teams_score_draw_yes = '8.00',
#   __________________________pre_results_both_teams_score_away_yes = '26.00',
#   __________________________pre_results_both_teams_score_home_no = '1.73',
#   __________________________pre_results_both_teams_score_draw_no = '11.00',
#   __________________________pre_results_both_teams_score_away_no = '19.00',
#   ________________________25 Result/Total Goals
#   __________________________pre_result_total_goals_home_over_25 = '1.83',
#   __________________________pre_result_total_goals_draw_over_25 = '26.00',
#   __________________________pre_result_total_goals_away_over_25 = '26.00',
#   __________________________pre_result_total_goals_home_under_25 = '3.20',
#   __________________________pre_result_total_goals_draw_under_25 = '6.00',
#   __________________________pre_result_total_goals_away_under_25 = '21.00',
#   ________________________43 Home Team Score a Goal
#   ____________________  ____________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.07
#   ____________________  ____________________bet_id: 43 --- bets_value: No --- bets_odd: 9.00
#   ________________________44 Away Team Score a Goal
#   ____________________  ____________________bet_id: 44 --- bets_value: Yes --- bets_odd: 2.25
#   ____________________  ____________________bet_id: 44 --- bets_value: No --- bets_odd: 1.57
#   ________________________54 First 10 min Winner
#   ____________________  ____________________bet_id: 54 --- bets_value: Home --- bets_odd: 4.50
#   ____________________  ____________________bet_id: 54 --- bets_value: Draw --- bets_odd: 1.18
#   ____________________  ____________________bet_id: 54 --- bets_value: Away --- bets_odd: 19.00
#   ________________________45 Corners Over Under
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 2.00
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 1.73
#   ________________________47 Winning Margin
#   ____________________  ____________________bet_id: 47 --- bets_value: Draw --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 151.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 351.00
#   ____________________  ____________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 8.50
#   ________________________48 To Score In Both Halves By Teams
#   ________________________49 Total Goals/Both Teams To Score
#   __________________________pre_total_goals_both_teams_to_score_over_yes_25 = '3.00',
#   __________________________pre_total_goals_both_teams_to_score_over_no_25 = '3.40',
#   __________________________pre_total_goals_both_teams_to_score_under_yes_25 = '12.00',
#   __________________________pre_total_goals_both_teams_to_score_under_no_25 = '2.50',
#   ________________________91 Total Goals (3 way)
#   ____________________  ____________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 2.05
#   ____________________  ____________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 2.63
#   ________________________52 Halftime Result/Both Teams Score
#   ________________________85 Total Corners (3 way)
#   ____________________  ____________________bet_id: 85 --- bets_value: Over 9 --- bets_odd: 2.00
#   ____________________  ____________________bet_id: 85 --- bets_value: Under 9 --- bets_odd: 2.20
#   ____________________  ____________________bet_id: 85 --- bets_value: Exactly 9 --- bets_odd: 7.50
#   ________________________73 Both Teams to Score 1st Half - 2nd Half
#   ________________________74 10 Over/Under
#   ________________________78 RTG_H1
#   ____________________  ____________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 3.10
#   ____________________  ____________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 3.25
#   ____________________  ____________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 13.00
#   ____________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ____________________2. World,  CONCACAF Champions League  #16 - 2023 / 972942
#   ____________________fixt date 2023-03-17 02:15:00+00:00
#   ____________________fix local 2023-03-17 09:15:00
#   ____________________local dat 2023-03-16 08:14:22
#   ____________________Lebih
#   ______________________league_rLeagues_id : 16
#   ______________________league_rLeagues_name : CONCACAF Champions League
#   ______________________bookmakersapi_rLeagues_id : 8
#   ______________________bookmakers_rLeagues_name : Bet365
#   ____________________Total fixtureapi_id Row(s) : 1
#   ____________________good to Go 1
#   ______________________8==8
#   __________________________1 Match Winner
#   ____________________________pre_match_winner_home = '1.22',
#   ____________________________pre_match_winner_draw = '4.75',
#   ____________________________pre_match_winner_away = '12.00',
#   __________________________2 Home/Away
#   ____________________________pre_homeaway_home = '1.05',
#   ____________________________pre_homeaway_away = '11.00',
#   __________________________3 Second Half Winner
#   ____________________________pre_second_half_winner_home = '1.50',
#   ____________________________pre_second_half_winner_draw = '3.00',
#   ____________________________pre_second_half_winner_away = '9.00',
#   __________________________5 Goals Over/Under
#   ____________________________pre_goals_overunder_over_35 = '2.63',
#   ____________________________pre_goals_overunder_under_35 = '1.44',
#   ____________________________pre_goals_overunder_over_15 = '1.20',
#   ____________________________pre_goals_overunder_under_15 = '4.33',
#   ____________________________pre_goals_overunder_over_45 = '5.00',
#   ____________________________pre_goals_overunder_under_45 = '1.17',
#   ____________________________pre_goals_overunder_over_25 = '1.70',
#   ____________________________pre_goals_overunder_under_25 = '2.10',
#   ____________________________pre_goals_overunder_over_05 = '1.05',
#   ____________________________pre_goals_overunder_under_05 = '11.00',
#   ____________________________pre_goals_overunder_over_55 = '11.00',
#   ____________________________pre_goals_overunder_under_55 = '1.05',
#   ____________________________pre_goals_overunder_over_65 = '21.00',
#   ____________________________pre_goals_overunder_under_65 = '1.02',
#   ____________________________pre_goals_overunder_over_75 = '41.00',
#   ____________________________pre_goals_overunder_under_75 = '1.00',
#   __________________________6 Goals Over/Under First Half
#   ____________________________pre_goals_overunder_first_half_over_35 = '17.00',
#   ____________________________pre_goals_overunder_first_half_under_35 = '1.02',
#   ____________________________pre_goals_overunder_first_half_over_15 = '2.50',
#   ____________________________pre_goals_overunder_first_half_under_15 = '1.50',
#   ____________________________pre_goals_overunder_first_half_over_25 = '6.00',
#   ____________________________pre_goals_overunder_first_half_under_25 = '1.13',
#   ____________________________pre_goals_overunder_first_half_over_05 = '1.30',
#   ____________________________pre_goals_overunder_first_half_under_05 = '3.40',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________pre_goals_overunder__second_half_over_35 = '10.00',
#   ____________________________pre_goals_overunder__second_half_under_35 = '1.06',
#   ____________________________pre_goals_overunder__second_half_over_15 = '1.83',
#   ____________________________pre_goals_overunder__second_half_under_15 = '1.83',
#   ____________________________pre_goals_overunder__second_half_over_25 = '3.75',
#   ____________________________pre_goals_overunder__second_half_under_25 = '1.25',
#   ____________________________pre_goals_overunder__second_half_over_05 = '1.18',
#   ____________________________pre_goals_overunder__second_half_under_05 = '4.50',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________pre_clean_sheet__home_yes = '1.67',
#   ____________________________pre_clean_sheet__home_no = '2.10',
#   __________________________28 Clean Sheet - Away
#   ____________________________pre_clean_sheet__away_yes = '9.00',
#   ____________________________pre_clean_sheet__away_no = '1.07',
#   __________________________8 Both Teams Score
#   ____________________________pre_both_teams_score_yes = '2.25',
#   ____________________________pre_both_teams_score_no = '1.57',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 2.88
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.36
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 9.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 301.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.40
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 251.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 251.00
#   __________________________12 Double Chance
#   ____________________________pre_double_chance_home_draw = '1.04',
#   ____________________________pre_double_chance_home_away = '1.17',
#   ____________________________pre_double_chance_draw_away = '3.75',
#   __________________________13 First Half Winner
#   ____________________________pre_first_half_winner_home = '1.73',
#   ____________________________pre_first_half_winner_draw = '2.60',
#   ____________________________pre_first_half_winner_away = '9.50',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.18
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 5.50
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.18
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 5.50
#   __________________________32 Win Both Halves
#   ____________________________pre_win_both_halves_home = '2.63',
#   ____________________________pre_win_both_halves_away = '51.00',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.62
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 5.5 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 5.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 6.5 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 6.5 --- bets_odd: 1.00
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.01
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.05
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________pre_win_to_nil_home = '1.83',
#   ____________________________pre_win_to_nil_away = '19.00',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.80
#   __________________________39 To Win Either Half
#   ____________________________pre_to_win_either_half_home = '1.14',
#   ____________________________pre_to_win_either_half_away = '5.00',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________61 To Qualify
#   ______________________  ______________________bet_id: 61 --- bets_value: Home --- bets_odd: 1.20
#   ______________________  ______________________bet_id: 61 --- bets_value: Away --- bets_odd: 4.33
#   __________________________24 Results/Both Teams Score
#   ____________________________pre_results_both_teams_score_home_yes = '3.25',
#   ____________________________pre_results_both_teams_score_draw_yes = '7.00',
#   ____________________________pre_results_both_teams_score_away_yes = '23.00',
#   ____________________________pre_results_both_teams_score_home_no = '1.83',
#   ____________________________pre_results_both_teams_score_draw_no = '11.00',
#   ____________________________pre_results_both_teams_score_away_no = '19.00',
#   __________________________25 Result/Total Goals
#   ____________________________pre_result_total_goals_home_over_25 = '1.91',
#   ____________________________pre_result_total_goals_draw_over_25 = '21.00',
#   ____________________________pre_result_total_goals_away_over_25 = '23.00',
#   ____________________________pre_result_total_goals_home_under_25 = '3.25',
#   ____________________________pre_result_total_goals_draw_under_25 = '6.00',
#   ____________________________pre_result_total_goals_away_under_25 = '21.00',
#   __________________________43 Home Team Score a Goal
#   ______________________  ______________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 43 --- bets_value: No --- bets_odd: 9.00
#   __________________________44 Away Team Score a Goal
#   ______________________  ______________________bet_id: 44 --- bets_value: Yes --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 44 --- bets_value: No --- bets_odd: 1.67
#   __________________________54 First 10 min Winner
#   ______________________  ______________________bet_id: 54 --- bets_value: Home --- bets_odd: 4.75
#   ______________________  ______________________bet_id: 54 --- bets_value: Draw --- bets_odd: 1.18
#   ______________________  ______________________bet_id: 54 --- bets_value: Away --- bets_odd: 17.00
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 1.83
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 1.83
#   __________________________47 Winning Margin
#   ______________________  ______________________bet_id: 47 --- bets_value: Draw --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 7.50
#   __________________________48 To Score In Both Halves By Teams
#   __________________________49 Total Goals/Both Teams To Score
#   ____________________________pre_total_goals_both_teams_to_score_over_yes_25 = '2.75',
#   ____________________________pre_total_goals_both_teams_to_score_over_no_25 = '3.75',
#   ____________________________pre_total_goals_both_teams_to_score_under_yes_25 = '10.00',
#   ____________________________pre_total_goals_both_teams_to_score_under_no_25 = '2.50',
#   __________________________91 Total Goals (3 way)
#   ______________________  ______________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 2.05
#   ______________________  ______________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 2.63
#   __________________________52 Halftime Result/Both Teams Score
#   __________________________85 Total Corners (3 way)
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 10 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 10 --- bets_odd: 1.83
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 10 --- bets_odd: 8.00
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   __________________________74 10 Over/Under
#   __________________________78 RTG_H1
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 3.25
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 3.40
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 11.00
#   ______________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-16 08:14:39

# %%
# Import
from a_settings.messages import *   
from a_models.football_fixtures import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(0, space).strftime("%Y-%m-%d")
    date_0_raw       = get_today(0, space)  
    # --------------------------------------------------  
    date_1         = get_today(1, space).strftime("%Y-%m-%d")
    date_1_raw       = get_today(1, space)  
    # --------------------------------------------------   
    # --------------------------------------------------  
    ff_get_fixture_today_xpattern_advices(date_0, date_1, "xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 08:14:39
#   __main()
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-16 08:14:39.891141
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-16 08:14:39.894647
#   ______get_today()
#   ________date_diff : 1
#   ________today_raw : 2023-03-17 08:14:39.894647
#   ______get_today()
#   ________date_diff : 1
#   ________today_raw : 2023-03-17 08:14:39.894647
#   ______ff_get_fixture_today_xpattern_advices()
#   ________Select  date,   fixtureapi_id,   league_country,   league_name,   season,   teams_home,   teams_away   from football_fixtures  where DATE(date) >= '2023-03-16'  and DATE(date) <= '2023-03-17'  order by date asc
#   ________Total Row(s) : 213
#   ________[1/213] 2023-03-16 00:15:00
#   ________World - CONCACAF Champions League 2023
# #972940  Orlando City SC vs Tigres UANL
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 972940
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '16'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '16'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[2/213] 2023-03-16 00:30:00
#   ________World - CONMEBOL Libertadores 2023
# #1011467  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1011467
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '13'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:133794
#   __________     total_fixtures:143
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '13'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:133794
#   __________     total_fixtures:143
#   __________       --UPDATED--
#   ________[3/213] 2023-03-16 01:00:00
#   ________USA - USL Championship 2023
# #1008357  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1008357
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '255'
#   __________     and pre_ah_pattern = '0#H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '0#H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '255'
#   __________     and pre_ah_pattern_mirror = '0#H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '0#H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[4/213] 2023-03-16 01:05:00
#   ________Mexico - Liga de Expansión MX 2022
# #975956  Monarcas vs Raya2
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 975956
#   __________> pre_ah_pattern = 075_H
#   __________> pre_ah_pattern_mirror = 075+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '263'
#   __________     and pre_ah_pattern = '075_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '075_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:106701
#   __________     total_fixtures:5
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '263'
#   __________     and pre_ah_pattern_mirror = '075_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '075_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[5/213] 2023-03-16 02:30:00
#   ________World - CONCACAF Champions League 2023
# #972946  Los Angeles FC vs LD Alajuelense
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 972946
#   __________> pre_ah_pattern = 175_15_125_1_H
#   __________> pre_ah_pattern_mirror = 1+125+15+175+H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '16'
#   __________     and pre_ah_pattern = '175_15_125_1_H'
#   __________     and pre_gou_pattern = '25g275g3g325g35gG'
#   __________     and end_ah_pattern = '175_15_125_1_H'
#   __________     and end_gou_pattern = '25g275g3g325g35gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '16'
#   __________     and pre_ah_pattern_mirror = '175_15_125_1_H'
#   __________     and pre_gou_pattern = '25g275g3g325g35gG'
#   __________     and end_ah_pattern_mirror = '175_15_125_1_H'
#   __________     and end_gou_pattern = '25g275g3g325g35gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[6/213] 2023-03-16 03:05:00
#   ________Mexico - Liga de Expansión MX 2022
# #975957  Dorados vs Atlante FC
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 975957
#   __________> pre_ah_pattern = 025+05+075+1+H
#   __________> pre_ah_pattern_mirror = 1_075_05_025_H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '263'
#   __________     and pre_ah_pattern = '025+05+075+1+H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '025+05+075+1+H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '263'
#   __________     and pre_ah_pattern_mirror = '025+05+075+1+H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '025+05+075+1+H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[7/213] 2023-03-16 08:00:00
#   ________Indonesia - Liga 1 2022
# #899803  Persija vs PSIS Semarang
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 899803
#   __________> pre_ah_pattern = 1_075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+1+H
#   __________> pre_gou_pattern = 175g2g225g25g275gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '274'
#   __________     and pre_ah_pattern = '1_075_025_H'
#   __________     and pre_gou_pattern = '175g2g225g25g275gG'
#   __________     and end_ah_pattern = '1_075_025_H'
#   __________     and end_gou_pattern = '175g2g225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '274'
#   __________     and pre_ah_pattern_mirror = '1_075_025_H'
#   __________     and pre_gou_pattern = '175g2g225g25g275gG'
#   __________     and end_ah_pattern_mirror = '1_075_025_H'
#   __________     and end_gou_pattern = '175g2g225g25g275gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:46422
#   __________     total_fixtures:1
#   __________       --UPDATED--
#   ________[8/213] 2023-03-16 10:00:00
#   ________Indonesia - Liga 1 2022
# #899805  Bali United vs Persepam Madura Utd
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 899805
#   __________> pre_ah_pattern = 1_075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+1+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '274'
#   __________     and pre_ah_pattern = '1_075_025_H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern = '1_075_025_H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:46424
#   __________     total_fixtures:1
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '274'
#   __________     and pre_ah_pattern_mirror = '1_075_025_H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern_mirror = '1_075_025_H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[9/213] 2023-03-16 11:00:00
#   ________Portugal - Liga Revelação U23 2022
# #992352  Farense U23 vs Marítimo U23
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992352
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '701'
#   __________     and pre_ah_pattern = '025_0#025+H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern = '025_0#025+H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:130977
#   __________     total_fixtures:2
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '701'
#   __________     and pre_ah_pattern_mirror = '025_0#025+H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern_mirror = '025_0#025+H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:130977
#   __________     total_fixtures:2
#   __________       --UPDATED--
#   ________[10/213] 2023-03-16 11:15:00
#   ________Iran - Azadegan League 2022
# #998368  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 998368
#   __________> pre_ah_pattern = 125_1_075_H
#   __________> pre_ah_pattern_mirror = 075+1+125+H
#   __________> pre_gou_pattern = 15g175g2g225gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '291'
#   __________     and pre_ah_pattern = '125_1_075_H'
#   __________     and pre_gou_pattern = '15g175g2g225gG'
#   __________     and end_ah_pattern = '125_1_075_H'
#   __________     and end_gou_pattern = '15g175g2g225gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '291'
#   __________     and pre_ah_pattern_mirror = '125_1_075_H'
#   __________     and pre_gou_pattern = '15g175g2g225gG'
#   __________     and end_ah_pattern_mirror = '125_1_075_H'
#   __________     and end_gou_pattern = '15g175g2g225gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[11/213] 2023-03-16 11:30:00
#   ________Iran - Azadegan League 2022
# #998363  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 998363
#   __________> pre_ah_pattern = 075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+H
#   __________> pre_gou_pattern = 15g175g2g225gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '291'
#   __________     and pre_ah_pattern = '075_025_H'
#   __________     and pre_gou_pattern = '15g175g2g225gG'
#   __________     and end_ah_pattern = '075_025_H'
#   __________     and end_gou_pattern = '15g175g2g225gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '291'
#   __________     and pre_ah_pattern_mirror = '075_025_H'
#   __________     and pre_gou_pattern = '15g175g2g225gG'
#   __________     and end_ah_pattern_mirror = '075_025_H'
#   __________     and end_gou_pattern = '15g175g2g225gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[12/213] 2023-03-16 11:30:00
#   ________Iran - Azadegan League 2022
# #998365  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 998365
#   __________> pre_ah_pattern = 025+075+H
#   __________> pre_ah_pattern_mirror = 075_025_H
#   __________> pre_gou_pattern = 15g175g2g225g25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '291'
#   __________     and pre_ah_pattern = '025+075+H'
#   __________     and pre_gou_pattern = '15g175g2g225g25gG'
#   __________     and end_ah_pattern = '025+075+H'
#   __________     and end_gou_pattern = '15g175g2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '291'
#   __________     and pre_ah_pattern_mirror = '025+075+H'
#   __________     and pre_gou_pattern = '15g175g2g225g25gG'
#   __________     and end_ah_pattern_mirror = '025+075+H'
#   __________     and end_gou_pattern = '15g175g2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[13/213] 2023-03-16 11:30:00
#   ________Iran - Azadegan League 2022
# #998366  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 998366
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '291'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '291'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[14/213] 2023-03-16 11:30:00
#   ________Iran - Azadegan League 2022
# #998367  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 998367
#   __________> pre_ah_pattern = 025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+H
#   __________> pre_gou_pattern = 15g175g2g225gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '291'
#   __________     and pre_ah_pattern = '025_0#H'
#   __________     and pre_gou_pattern = '15g175g2g225gG'
#   __________     and end_ah_pattern = '025_0#H'
#   __________     and end_gou_pattern = '15g175g2g225gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '291'
#   __________     and pre_ah_pattern_mirror = '025_0#H'
#   __________     and pre_gou_pattern = '15g175g2g225gG'
#   __________     and end_ah_pattern_mirror = '025_0#H'
#   __________     and end_gou_pattern = '15g175g2g225gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[15/213] 2023-03-16 12:00:00
#   ________Israel - Liga Alef 2022
# #934827  Shimshon Kafr Qasim vs Shimshon Tel Aviv
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 934827
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = 25g3gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '496'
#   __________     and pre_ah_pattern = '0#H'
#   __________     and pre_gou_pattern = '25g3gG'
#   __________     and end_ah_pattern = '0#H'
#   __________     and end_gou_pattern = '25g3gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:77461
#   __________     total_fixtures:10
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '496'
#   __________     and pre_ah_pattern_mirror = '0#H'
#   __________     and pre_gou_pattern = '25g3gG'
#   __________     and end_ah_pattern_mirror = '0#H'
#   __________     and end_gou_pattern = '25g3gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:77461
#   __________     total_fixtures:10
#   __________       --UPDATED--
#   ________[16/213] 2023-03-16 12:15:00
#   ________Malaysia - Super League 2023
# #997445  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 997445
#   __________> pre_ah_pattern = 0#025+075+H
#   __________> pre_ah_pattern_mirror = 075_025_0#H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '278'
#   __________     and pre_ah_pattern = '0#025+075+H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern = '0#025+075+H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '278'
#   __________     and pre_ah_pattern_mirror = '0#025+075+H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern_mirror = '0#025+075+H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[17/213] 2023-03-16 13:00:00
#   ________Serbia - Prva Liga 2022
# #869147  FK Zlatibor vs Grafičar
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 869147
#   __________> pre_ah_pattern = 025+075+1+125+H
#   __________> pre_ah_pattern_mirror = 125_1_075_025_H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '287'
#   __________     and pre_ah_pattern = '025+075+1+125+H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern = '025+075+1+125+H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '287'
#   __________     and pre_ah_pattern_mirror = '025+075+1+125+H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern_mirror = '025+075+1+125+H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[18/213] 2023-03-16 13:00:00
#   ________Egypt - Second League - Group A 2022
# #964788  Telephonaat Beni Suef vs Asmant Asyut
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 964788
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88144
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88144
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ________[19/213] 2023-03-16 13:00:00
#   ________Egypt - Second League - Group A 2022
# #964789  Al Nasr Taaden vs El Minya
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 964789
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88145
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88145
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ________[20/213] 2023-03-16 13:00:00
#   ________Egypt - Second League - Group A 2022
# #964790  Shoban Moslemen Qena vs Misr EL Makasa
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 964790
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88146
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88146
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ________[21/213] 2023-03-16 13:00:00
#   ________Egypt - Second League - Group A 2022
# #964791  Tamya vs Aluminium Nag Hammadi
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 964791
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88147
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88147
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ________[22/213] 2023-03-16 13:00:00
#   ________Egypt - Second League - Group A 2022
# #964792  Mallawi vs Dayrout
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 964792
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88148
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88148
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ________[23/213] 2023-03-16 13:00:00
#   ________Egypt - Second League - Group A 2022
# #964793  Asyut Petrol vs Kima Aswan
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 964793
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88149
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88149
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ________[24/213] 2023-03-16 13:00:00
#   ________Egypt - Second League - Group A 2022
# #964794  El Gouna FC vs La Viena FC
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 964794
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88150
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '887'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:88150
#   __________     total_fixtures:45
#   __________       --UPDATED--
#   ________[25/213] 2023-03-16 13:00:00
#   ________Saudi-Arabia - Pro League 2022
# #976691  Al Khaleej Saihat vs Al Taee
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 976691
#   __________> pre_ah_pattern = 025_0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#025+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '307'
#   __________     and pre_ah_pattern = '025_0#025+05+H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '025_0#025+05+H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:107416
#   __________     total_fixtures:2
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '307'
#   __________     and pre_ah_pattern_mirror = '025_0#025+05+H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '025_0#025+05+H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[26/213] 2023-03-16 13:00:00
#   ________Egypt - Second League - Group C 2022
# #965269  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 965269
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '889'
#   __________     and pre_ah_pattern = '0#H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = '0#H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '889'
#   __________     and pre_ah_pattern_mirror = '0#H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = '0#H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[27/213] 2023-03-16 13:00:00
#   ________Malaysia - Super League 2023
# #997446  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 997446
#   __________> pre_ah_pattern = 0#025+075+H
#   __________> pre_ah_pattern_mirror = 075_025_0#H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '278'
#   __________     and pre_ah_pattern = '0#025+075+H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern = '0#025+075+H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '278'
#   __________     and pre_ah_pattern_mirror = '0#025+075+H'
#   __________     and pre_gou_pattern = '225g25g275g3gG'
#   __________     and end_ah_pattern_mirror = '0#025+075+H'
#   __________     and end_gou_pattern = '225g25g275g3gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[28/213] 2023-03-16 13:30:00
#   ________Italy - Serie C - Girone C 2022
# #953103  Fidelis Andria vs Crotone
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 953103
#   __________> pre_ah_pattern = 05+075+1+H
#   __________> pre_ah_pattern_mirror = 1_075_05_H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '943'
#   __________     and pre_ah_pattern = '05+075+1+H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = '05+075+1+H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '943'
#   __________     and pre_ah_pattern_mirror = '05+075+1+H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = '05+075+1+H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[29/213] 2023-03-16 14:00:00
#   ________Slovenia - 1. SNL 2022
# #876869  Tabor Sežana vs Gorica
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 876869
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '373'
#   __________     and pre_ah_pattern = '025_0#025+H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '025_0#025+H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:38096
#   __________     total_fixtures:1
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '373'
#   __________     and pre_ah_pattern_mirror = '025_0#025+H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '025_0#025+H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:38096
#   __________     total_fixtures:1
#   __________       --UPDATED--
#   ________[30/213] 2023-03-16 15:00:00
#   ________Egypt - Premier League 2022
# #967402  Ghazl El Mehalla vs Al Ittihad
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 967402
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '233'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:80375
#   __________     total_fixtures:202
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '233'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:80375
#   __________     total_fixtures:202
#   __________       --UPDATED--
#   ________[31/213] 2023-03-16 15:00:00
#   ________Azerbaidjan - Premyer Liqa 2022
# #923319  Neftchi Baku vs Kapaz
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 923319
#   __________> pre_ah_pattern = 15_125_1_075_H
#   __________> pre_ah_pattern_mirror = 075+1+125+15+H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '419'
#   __________     and pre_ah_pattern = '15_125_1_075_H'
#   __________     and pre_gou_pattern = '2g225g25g275gG'
#   __________     and end_ah_pattern = '15_125_1_075_H'
#   __________     and end_gou_pattern = '2g225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '419'
#   __________     and pre_ah_pattern_mirror = '15_125_1_075_H'
#   __________     and pre_gou_pattern = '2g225g25g275gG'
#   __________     and end_ah_pattern_mirror = '15_125_1_075_H'
#   __________     and end_gou_pattern = '2g225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[32/213] 2023-03-16 15:00:00
#   ________Russia - Cup 2022
# #1011977  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1011977
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 175g2g225g25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '237'
#   __________     and pre_ah_pattern = '025_0#025+H'
#   __________     and pre_gou_pattern = '175g2g225g25gG'
#   __________     and end_ah_pattern = '025_0#025+H'
#   __________     and end_gou_pattern = '175g2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '237'
#   __________     and pre_ah_pattern_mirror = '025_0#025+H'
#   __________     and pre_gou_pattern = '175g2g225g25gG'
#   __________     and end_ah_pattern_mirror = '025_0#025+H'
#   __________     and end_gou_pattern = '175g2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[33/213] 2023-03-16 15:30:00
#   ________Israel - Liga Alef 2022
# #934829  Maccabi Yavne vs Hapoel Kfar Shalem
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 934829
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '496'
#   __________     and pre_ah_pattern = '025_0#025+H'
#   __________     and pre_gou_pattern = '2g225g25g275gG'
#   __________     and end_ah_pattern = '025_0#025+H'
#   __________     and end_gou_pattern = '2g225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '496'
#   __________     and pre_ah_pattern_mirror = '025_0#025+H'
#   __________     and pre_gou_pattern = '2g225g25g275gG'
#   __________     and end_ah_pattern_mirror = '025_0#025+H'
#   __________     and end_gou_pattern = '2g225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[34/213] 2023-03-16 16:00:00
#   ________Estonia - Meistriliiga 2023
# #1001212  Vaprus vs Kalju Nomme
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1001212
#   __________> pre_ah_pattern = 125+15+175+2+225+25+H
#   __________> pre_ah_pattern_mirror = 25_225_2_175_15_125_H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '329'
#   __________     and pre_ah_pattern = '125+15+175+2+225+25+H'
#   __________     and pre_gou_pattern = '25g275g3g325g35gG'
#   __________     and end_ah_pattern = '125+15+175+2+225+25+H'
#   __________     and end_gou_pattern = '25g275g3g325g35gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '329'
#   __________     and pre_ah_pattern_mirror = '125+15+175+2+225+25+H'
#   __________     and pre_gou_pattern = '25g275g3g325g35gG'
#   __________     and end_ah_pattern_mirror = '125+15+175+2+225+25+H'
#   __________     and end_gou_pattern = '25g275g3g325g35gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[35/213] 2023-03-16 16:30:00
#   ________Slovenia - 1. SNL 2022
# #876868  Mura vs Koper
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 876868
#   __________> pre_ah_pattern = 05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '373'
#   __________     and pre_ah_pattern = '05_025_0#H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '05_025_0#H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:38095
#   __________     total_fixtures:5
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '373'
#   __________     and pre_ah_pattern_mirror = '05_025_0#H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '05_025_0#H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:38095
#   __________     total_fixtures:4
#   __________       --UPDATED--
#   ________[36/213] 2023-03-16 16:30:00
#   ________Saudi-Arabia - Pro League 2022
# #976694  Al-Raed vs Al Shabab
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 976694
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '307'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:107419
#   __________     total_fixtures:37
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '307'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:107419
#   __________     total_fixtures:37
#   __________       --UPDATED--
#   ________[37/213] 2023-03-16 16:30:00
#   ________Italy - Serie C - Girone C 2022
# #953107  Catanzaro vs Monterosi
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 953107
#   __________> pre_ah_pattern = 225_2_175_15_H
#   __________> pre_ah_pattern_mirror = 15+175+2+225+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '943'
#   __________     and pre_ah_pattern = '225_2_175_15_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '225_2_175_15_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '943'
#   __________     and pre_ah_pattern_mirror = '225_2_175_15_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern_mirror = '225_2_175_15_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[38/213] 2023-03-16 17:00:00
#   ________Egypt - Premier League 2022
# #967403  Smouha SC vs Ismaily SC
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 967403
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '233'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:80376
#   __________     total_fixtures:202
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '233'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:80376
#   __________     total_fixtures:202
#   __________       --UPDATED--
#   ________[39/213] 2023-03-16 17:00:00
#   ________Cyprus - 1. Division 2022
# #1014329  None vs None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1014329
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '318'
#   __________     and pre_ah_pattern = '075_05_025_H'
#   __________     and pre_gou_pattern = '25gG'
#   __________     and end_ah_pattern = '075_05_025_H'
#   __________     and end_gou_pattern = '25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:133796
#   __________     total_fixtures:1
# ...
#   __________     total_fixtures:225
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '135'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:47108
#   __________     total_fixtures:225
#   __________       --UPDATED--
#   ________[201/213] 2023-03-17 19:45:00
#   ________Northern-Ireland - Premiership 2022
# #877543  Larne vs Ballymena United
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 877543
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '408'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:51842
#   __________     total_fixtures:155
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '408'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:51842
#   __________     total_fixtures:155
#   __________       --UPDATED--
#   ________[202/213] 2023-03-17 19:45:00
#   ________Ireland - First Division 2023
# #998570  Athlone Town vs Treaty United
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 998570
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '358'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:131227
#   __________     total_fixtures:155
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '358'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:131227
#   __________     total_fixtures:155
#   __________       --UPDATED--
#   ________[203/213] 2023-03-17 19:45:00
#   ________Ireland - First Division 2023
# #998571  Cobh Ramblers vs Galway United
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 998571
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '358'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:131230
#   __________     total_fixtures:155
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '358'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:131230
#   __________     total_fixtures:155
#   __________       --UPDATED--
#   ________[204/213] 2023-03-17 19:45:00
#   ________Ireland - First Division 2023
# #998572  Wexford vs Kerry
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 998572
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '358'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:131231
#   __________     total_fixtures:155
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '358'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:131231
#   __________     total_fixtures:155
#   __________       --UPDATED--
#   ________[205/213] 2023-03-17 20:00:00
#   ________England - Premier League 2022
# #868223  Nottingham Forest vs Newcastle
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868223
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '39'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:43271
#   __________     total_fixtures:214
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '39'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:43271
#   __________     total_fixtures:214
#   __________       --UPDATED--
#   ________[206/213] 2023-03-17 20:00:00
#   ________France - Ligue 1 2022
# #871743  Lyon vs Nantes
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 871743
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '61'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:45685
#   __________     total_fixtures:219
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '61'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:45685
#   __________     total_fixtures:219
#   __________       --UPDATED--
#   ________[207/213] 2023-03-17 20:00:00
#   ________Spain - La Liga 2022
# #878198  Valladolid vs Athletic Club
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 878198
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '140'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:51529
#   __________     total_fixtures:218
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '140'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:51529
#   __________     total_fixtures:218
#   __________       --UPDATED--
#   ________[208/213] 2023-03-17 20:15:00
#   ________Portugal - Primeira Liga 2022
# #898823  Santa Clara vs Rio Ave
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 898823
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '94'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:50724
#   __________     total_fixtures:178
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '94'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:50724
#   __________     total_fixtures:178
#   __________       --UPDATED--
#   ________[209/213] 2023-03-17 21:00:00
#   ________Spain - Tercera División RFEF - Group 12 2022
# #956769  Villa Santa Brígida vs Arucas
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 956769
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '450'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '450'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[210/213] 2023-03-17 21:00:00
#   ________Spain - Tercera División RFEF - Group 12 2022
# #956770  UD San Fernando vs Tamaraceite
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 956770
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '450'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '450'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[211/213] 2023-03-17 21:00:00
#   ________Mexico - Liga Premier Serie A 2022
# #938855  Inter Playa del Carmen vs Escorpiones
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 938855
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '722'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '722'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[212/213] 2023-03-17 23:00:00
#   ________Mexico - Liga MX Femenil 2022
# #976337  Atlas W vs Pumas UNAM W
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 976337
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '673'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '673'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ________[213/213] 2023-03-17 23:00:00
#   ________Mexico - Liga Premier Serie A 2022
# #938861  Los Cabos United vs Mineros de Fresnillo
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 938861
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '722'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '722'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 0
#
#   __________       --UPDATED--
# # -------------------------------------------------- End at 2023-03-16 09:16:56

# %%
# X-ODDS READER
# Import
from a_settings.messages import *  
from a_models.predefine import *  

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------   
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=1)
    preday1 = today + DD
    day1 = preday1.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    print(space + "> day1 : " +  str(preday1) ) 
    # --------------------------------------------------   
    pd_get_fixtures_next_match(day0, preday1, 'fixture', space) 
#     pd_get_fixtures_next_match(day0, day1, ROUTES, space)
    # --------------------------------------------------  
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 14:55:28
#   __main()
#   ____get_date()
#   ______> day0 : 2023-03-16
#   ______> day1 : 2023-03-17 14:55:28.972658
#   ________pd_get_fixtures_next_match()
#   __________Select   teams_home_id,  teams_away_id,  leagueapi_id,  season,  fixtureapi_id,  teams_home,  teams_away,  date  , pre_both_teams_score_yes  , pre_both_teams_score_no  , pre_rcard_yes  , pre_rcard_no  , pre_first_half_winner_home  , pre_first_half_winner_draw  , pre_first_half_winner_away  , pre_second_half_winner_home  , pre_second_half_winner_draw  , pre_second_half_winner_away  , pre_htft_double_home_home  , pre_htft_double_home_draw  , pre_htft_double_home_away  , pre_htft_double_draw_home  , pre_htft_double_draw_draw  , pre_htft_double_draw_away  , pre_htft_double_away_home  , pre_htft_double_away_draw  , pre_htft_double_away_away  , pre_both_teams_score__first_half_yes  , pre_both_teams_score__first_half_no  , pre_both_teams_to_score__second_half_yes  , pre_both_teams_to_score__second_half_no  , pre_results_both_teams_score_home_yes  , pre_results_both_teams_score_draw_yes  , pre_results_both_teams_score_away_yes  , pre_results_both_teams_score_home_no  , pre_results_both_teams_score_draw_no  , pre_results_both_teams_score_away_no  , pre_to_score_in_both_halves_by_teams_home , pre_to_score_in_both_halves_by_teams_away , pre_total_goals_both_teams_to_score_over_yes_25 , pre_total_goals_both_teams_to_score_over_no_25 , pre_total_goals_both_teams_to_score_under_yes_25 , pre_total_goals_both_teams_to_score_under_no_25 , pre_both_teams_to_score_1st_half__2nd_half_yes_yes , pre_both_teams_to_score_1st_half__2nd_half_yes_no , pre_both_teams_to_score_1st_half__2nd_half_no_yes , pre_both_teams_to_score_1st_half__2nd_half_no_no , pre_highest_scoring_half_first , pre_highest_scoring_half_draw , pre_highest_scoring_half_second , pre_double_chance_home_draw , pre_double_chance_home_away , pre_double_chance_draw_away , pre_double_chance__first_half_home_draw , pre_double_chance__first_half_home_away , pre_double_chance__first_half_draw_away , pre_oddeven_odd , pre_oddeven_even , pre_result_total_goals_home_over_35 , pre_result_total_goals_draw_over_35 , pre_result_total_goals_away_over_35 , pre_result_total_goals_home_under_35 , pre_result_total_goals_draw_under_35 , pre_result_total_goals_away_under_35 , pre_result_total_goals_home_over_25 , pre_result_total_goals_draw_over_25 , pre_result_total_goals_away_over_25 , pre_result_total_goals_home_under_25 , pre_result_total_goals_draw_under_25 , pre_result_total_goals_away_under_25 , pre_clean_sheet__home_yes , pre_clean_sheet__home_no , pre_clean_sheet__away_yes , pre_clean_sheet__away_no , pre_win_both_halves_home , pre_win_both_halves_away , pre_win_to_nil_home , pre_win_to_nil_away , pre_to_win_either_half_home , pre_to_win_either_half_away , pre_halftime_result_both_teams_score_home_yes , pre_halftime_result_both_teams_score_draw_yes , pre_halftime_result_both_teams_score_away_yes , pre_halftime_result_both_teams_score_home_no , pre_halftime_result_both_teams_score_draw_no , pre_halftime_result_both_teams_score_away_no , pre_exact_goals_number__first_half_0 , pre_exact_goals_number__first_half_1 , pre_exact_goals_number__first_half_2 , pre_exact_goals_number__first_half_3 , pre_exact_goals_number__first_half_4 , pre_exact_goals_number__first_half_more_5 , pre_second_half_exact_goals_number_0 , pre_second_half_exact_goals_number_1 , pre_second_half_exact_goals_number_2 , pre_second_half_exact_goals_number_3 , pre_second_half_exact_goals_number_4 , pre_second_half_exact_goals_number_more_5 , pre_home_team_exact_goals_number_0 , pre_home_team_exact_goals_number_1 , pre_home_team_exact_goals_number_2 , pre_home_team_exact_goals_number_more_3 , pre_away_team_exact_goals_number_0 , pre_away_team_exact_goals_number_1 , pre_away_team_exact_goals_number_2 , pre_away_team_exact_goals_number_more_3 from football_fixtures  where date >= '2023-03-16'  and date <= '2023-03-17 14:55:28.972658'  and fixture_status like 'Not Started'  and deleted_at is null  order by date asc
#   __________Total Row(s) : 81
#   ____________[1/81] 16 - 2023 -----#Orlando City SC 1598 - Tigres UANL 2279 - 2023-03-16 00:15:00
#
#   ____________[2/81] 263 - 2022 -----#Monarcas 2284 - Raya2 16850 - 2023-03-16 01:05:00
#
#   ____________[3/81] 16 - 2023 -----#Los Angeles FC 1616 - LD Alajuelense 822 - 2023-03-16 02:30:00
#   ______________pre_first_half_winner_home:1.91
#   ______________pre_second_half_winner_home:1.67
#   ______________pre_to_win_either_half_home:1.22
#   ______________pre_result_total_goals_home_over_25:2.1
#   ______________pre_clean_sheet__away_yes:8.0
#
#   ____________[4/81] 263 - 2022 -----#Dorados 2297 - Atlante FC 2312 - 2023-03-16 03:05:00
#
#   ____________[5/81] 274 - 2022 -----#Persija 10134 - PSIS Semarang 2451 - 2023-03-16 08:00:00
#
#   ____________[6/81] 274 - 2022 -----#Bali United 2448 - Persepam Madura Utd 2444 - 2023-03-16 10:00:00
#
#   ____________[7/81] 701 - 2022 -----#Farense U23 17474 - Marítimo U23 15466 - 2023-03-16 11:00:00
#
#   ____________[8/81] 291 - 2022 -----#Kheybar Khorramabad 2716 - Khalij Fars 18300 - 2023-03-16 11:15:00
#   ______________pre_first_half_winner_draw:1.97
#   ______________pre_second_half_winner_home:1.98
#   ______________pre_both_teams_score_yes:3.0
#
#   ____________[9/81] 291 - 2022 -----#Darya Babol 19965 - Esteghlal Mollasani 15540 - 2023-03-16 11:30:00
#   ______________pre_first_half_winner_draw:1.77
#
#   ____________[10/81] 291 - 2022 -----#Saipa 2736 - Shams Azar Qazvin 18159 - 2023-03-16 11:30:00
#   ______________pre_first_half_winner_draw:1.83
#
#   ____________[11/81] 291 - 2022 -----#Fajr Sepasi 2713 - Chooka Talesh 10387 - 2023-03-16 11:30:00
#   ______________pre_first_half_winner_home:1.93
#   ______________pre_double_chance_draw_away:3.0
#
#   ____________[12/81] 291 - 2022 -----#Shahrdari Hamedan 18014 - Khooshe Talaee Saveh 7501 - 2023-03-16 11:30:00
#   ______________pre_first_half_winner_draw:1.86
#   ______________pre_both_teams_score_yes:2.5
#
#   ____________[13/81] 278 - 2023 -----#Negeri Sembilan 2502 - Terengganu 2518 - 2023-03-16 12:15:00
#
#   ____________[14/81] 887 - 2022 -----#Telephonaat Beni Suef 13823 - Asmant Asyut 20455 - 2023-03-16 13:00:00
#
#   ____________[15/81] 887 - 2022 -----#Al Nasr Taaden 1047 - El Minya 13821 - 2023-03-16 13:00:00
#
#   ____________[16/81] 887 - 2022 -----#Shoban Moslemen Qena 20456 - Misr EL Makasa 1038 - 2023-03-16 13:00:00
#
#   ____________[17/81] 887 - 2022 -----#Tamya 18027 - Aluminium Nag Hammadi 18020 - 2023-03-16 13:00:00
#
#   ____________[18/81] 887 - 2022 -----#Mallawi 18026 - Dayrout 18022 - 2023-03-16 13:00:00
#
#   ____________[19/81] 887 - 2022 -----#Asyut Petrol 18021 - Kima Aswan 16435 - 2023-03-16 13:00:00
#
#   ____________[20/81] 887 - 2022 -----#El Gouna FC 1574 - La Viena FC 16436 - 2023-03-16 13:00:00
#
#   ____________[21/81] 307 - 2022 -----#Al Khaleej Saihat 2928 - Al Taee 2942 - 2023-03-16 13:00:00
#
#   ____________[22/81] 889 - 2022 -----#Helal Aldabaa 20460 - Kafr El Sheikh 18041 - 2023-03-16 13:00:00
#   ______________pre_first_half_winner_draw:1.83
#
#   ____________[23/81] 278 - 2023 -----#Perak 2524 - Pahang 2525 - 2023-03-16 13:00:00
#
#   ____________[24/81] 943 - 2022 -----#Fidelis Andria 1695 - Crotone 501 - 2023-03-16 13:30:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_both_teams_score_yes:2.5
#
#   ____________[25/81] 233 - 2022 -----#Ghazl El Mehalla 13819 - Al Ittihad 1572 - 2023-03-16 15:00:00
#
#   ____________[26/81] 237 - 2022 -----#Nizhny Novgorod 2011 - FC Rostov 779 - 2023-03-16 15:00:00
#   ______________pre_first_half_winner_draw:1.99
#
#   ____________[27/81] 307 - 2022 -----#Al-Raed 2935 - Al Shabab 2940 - 2023-03-16 16:30:00
#
#   ____________[28/81] 943 - 2022 -----#Catanzaro 1687 - Monterosi 882 - 2023-03-16 16:30:00
#   ______________pre_first_half_winner_home:1.57
#   ______________pre_second_half_winner_home:1.4
#   ______________pre_to_win_either_half_home:1.13
#   ______________pre_win_to_nil_home:1.62
#   ______________pre_result_total_goals_home_over_25:1.83
#   ______________pre_both_teams_score_yes:2.75
#   ______________pre_double_chance_draw_away:4.0
#   ______________pre_clean_sheet__away_yes:7.5
#   ______________pre_to_win_either_half_away:6.5
#   ____________[29/81] 233 - 2022 -----#Smouha SC 1044 - Ismaily SC 1030 - 2023-03-16 17:00:00
#
#   ____________[30/81] 318 - 2022 -----#Doxa 3398 - Karmiotissa 3413 - 2023-03-16 17:00:00
#
#   ____________[31/81] 3 - 2022 -----#SC Freiburg 160 - Juventus 496 - 2023-03-16 17:45:00
#   ______________pre_first_half_winner_draw:2.0
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.95
#
#   ____________[32/81] 3 - 2022 -----#Fenerbahce 611 - Sevilla 536 - 2023-03-16 17:45:00
#
#   ____________[33/81] 3 - 2022 -----#Real Betis 543 - Manchester United 33 - 2023-03-16 17:45:00
#
#   ____________[34/81] 3 - 2022 -----#Feyenoord 209 - Shakhtar Donetsk 550 - 2023-03-16 17:45:00
#   ______________pre_first_half_winner_home:2.0
#   ______________pre_second_half_winner_home:1.73
#   ______________pre_to_win_either_half_home:1.29
#
#   ____________[35/81] 848 - 2022 -----#Sivasspor 1002 - Fiorentina 502 - 2023-03-16 17:45:00
#   ______________pre_second_half_winner_away:1.83
#
#   ____________[36/81] 848 - 2022 -----#Djurgardens IF 364 - Lech Poznan 347 - 2023-03-16 17:45:00
#
#   ____________[37/81] 848 - 2022 -----#Slovan Bratislava 656 - FC Basel 1893 551 - 2023-03-16 17:45:00
#
#   ____________[38/81] 740 - 2023 -----#Corinthians U20 12998 - RB Bragantino U20 18345 - 2023-03-16 18:00:00
#   ______________pre_second_half_winner_home:1.83
#
#   ____________[39/81] 740 - 2023 -----#Fortaleza U20 13009 - Athletico PR U20 12984 - 2023-03-16 18:00:00
#
#   ____________[40/81] 703 - 2022 -----#Queens Park Rangers U21 20085 - Charlton Athletic U21 20082 - 2023-03-16 19:00:00
#   ______________pre_both_teams_score_no:3.3
#
#   ____________[41/81] 357 - 2023 -----#Drogheda United 3850 - Dundalk 584 - 2023-03-16 19:45:00
#
#   ____________[42/81] 3 - 2022 -----#Union St. Gilloise 1393 - Union Berlin 182 - 2023-03-16 20:00:00
#
#   ____________[43/81] 3 - 2022 -----#Ferencvarosi TC 651 - Bayer Leverkusen 168 - 2023-03-16 20:00:00
#
#   ____________[44/81] 3 - 2022 -----#Arsenal 42 - Sporting CP 228 - 2023-03-16 20:00:00
#   ______________pre_first_half_winner_home:1.83
#   ______________pre_second_half_winner_home:1.62
#   ______________pre_to_win_either_half_home:1.22
#   ______________pre_result_total_goals_home_over_25:2.05
#   ______________pre_clean_sheet__away_yes:7.0
#
#   ____________[45/81] 3 - 2022 -----#Real Sociedad 548 - AS Roma 497 - 2023-03-16 20:00:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#
#   ____________[46/81] 848 - 2022 -----#AZ Alkmaar 201 - Lazio 487 - 2023-03-16 20:00:00
#
#   ____________[47/81] 848 - 2022 -----#West Ham 48 - AEK Larnaca 614 - 2023-03-16 20:00:00
#   ______________pre_first_half_winner_home:1.73
#   ______________pre_second_half_winner_home:1.5
#   ______________pre_to_win_either_half_home:1.14
#   ______________pre_win_to_nil_home:1.8
#   ______________pre_result_total_goals_home_over_25:1.95
#   ______________pre_both_teams_score_yes:2.5
#   ______________pre_double_chance_draw_away:3.75
#   ______________pre_clean_sheet__away_yes:8.0
#   ______________pre_to_win_either_half_away:5.5
#
#   ____________[48/81] 848 - 2022 -----#Nice 84 - Sheriff Tiraspol 568 - 2023-03-16 20:00:00
#   ______________pre_first_half_winner_home:1.91
#   ______________pre_second_half_winner_home:1.67
#   ______________pre_to_win_either_half_home:1.25
#   ______________pre_to_win_either_half_away:4.0
#
#   ____________[49/81] 848 - 2022 -----#Villarreal 533 - Anderlecht 554 - 2023-03-16 20:00:00
#   ______________pre_first_half_winner_home:1.91
#   ______________pre_second_half_winner_home:1.67
#   ______________pre_to_win_either_half_home:1.25
#   ______________pre_result_total_goals_home_over_25:2.2
#   ______________pre_clean_sheet__away_yes:7.0
#
#   ____________[50/81] 740 - 2023 -----#Palmeiras U20 12968 - Goiás U20 12961 - 2023-03-16 21:30:00
#   ______________pre_first_half_winner_home:1.7
#   ______________pre_second_half_winner_home:1.53
#   ______________pre_double_chance_draw_away:3.52
#
#   ____________[51/81] 13 - 2023 -----#Cerro Porteno 1176 - Fortaleza EC 154 - 2023-03-16 22:00:00
#   ______________pre_first_half_winner_draw:2.0
#   ______________pre_total_goals_both_teams_to_score_under_no_25:2.0
#
#   ____________[52/81] 73 - 2023 -----#CSA 150 - Brusque 1211 - 2023-03-16 22:00:00
#   ______________pre_first_half_winner_draw:2.0
#
#   ____________[53/81] 73 - 2023 -----#Gremio 130 - Ferroviario 1195 - 2023-03-16 23:00:00
#   ______________pre_first_half_winner_home:1.67
#   ______________pre_double_chance_draw_away:4.0
#
#   ____________[54/81] 16 - 2023 -----#Leon 2289 - Tauro FC 2885 - 2023-03-17 00:00:00
#   ______________pre_first_half_winner_home:1.62
#   ______________pre_second_half_winner_home:1.44
#   ______________pre_to_win_either_half_home:1.13
#   ______________pre_win_to_nil_home:1.73
#   ______________pre_result_total_goals_home_over_25:1.83
#   ______________pre_both_teams_score_yes:2.5
#   ______________pre_double_chance_draw_away:4.0
#   ______________pre_clean_sheet__away_yes:9.0
#   ______________pre_to_win_either_half_away:6.0
#
#   ____________[55/81] 263 - 2022 -----#Cancún 14276 - Mineros de Zacatecas 2299 - 2023-03-17 01:05:00
#
#   ____________[56/81] 16 - 2023 -----#Pachuca 2292 - CD Motagua 1055 - 2023-03-17 02:15:00
#   ______________pre_first_half_winner_home:1.73
#   ______________pre_second_half_winner_home:1.5
#   ______________pre_to_win_either_half_home:1.14
#   ______________pre_win_to_nil_home:1.83
#   ______________pre_result_total_goals_home_over_25:1.91
#   ______________pre_double_chance_draw_away:3.75
#   ______________pre_clean_sheet__away_yes:9.0
#   ______________pre_to_win_either_half_away:5.0
#
#   ____________[57/81] 263 - 2022 -----#Tapatío 14278 - Cimarrones 2301 - 2023-03-17 03:05:00
#
#   ____________[58/81] 190 - 2022 -----#Adelaide United W 1972 - Newcastle Jets FC W 1975 - 2023-03-17 06:05:00
#
#   ____________[59/81] 274 - 2022 -----#PSM Makassar 2441 - Bhayangkara FC 2443 - 2023-03-17 08:00:00
#
#   ____________[60/81] 195 - 2023 -----#Bentleigh Greens 3799 - Dandenong Thunder 3801 - 2023-03-17 08:30:00
#
#   ____________[61/81] 195 - 2023 -----#South Melbourne 3811 - Heidelberg United 3803 - 2023-03-17 08:30:00
#   ______________pre_second_half_winner_home:1.95
#
#   ____________[62/81] 188 - 2022 -----#Adelaide United 948 - Wellington Phoenix 942 - 2023-03-17 08:45:00
#   ______________pre_total_goals_both_teams_to_score_over_yes_25:1.73
#   ______________pre_both_teams_score_no:2.5
#
#   ____________[63/81] 195 - 2023 -----#Oakleigh Cannons 3808 - St. Albans Saints 9978 - 2023-03-17 09:30:00
#
#   ____________[64/81] 703 - 2022 -----#Cardiff City U21 20016 - Ipswich Town U21 20094 - 2023-03-17 11:00:00
#
#   ____________[65/81] 888 - 2022 -----#Wadi Degla 1046 - El Seka El Hadid 18031 - 2023-03-17 12:30:00
#
#   ____________[66/81] 888 - 2022 -----#Suez 18034 - AL Nasr SC 2617 - 2023-03-17 12:30:00
#
#   ____________[67/81] 888 - 2022 -----#Itesalat 18032 - Media 15735 - 2023-03-17 12:30:00
#
#   ____________[68/81] 888 - 2022 -----#Kahraba Ismailia 20458 - Tersana 15739 - 2023-03-17 12:30:00
#
#   ____________[69/81] 888 - 2022 -----#El Sharqia Dokhan 18053 - Olympic El Qanah 13822 - 2023-03-17 12:30:00
#
#   ____________[70/81] 888 - 2022 -----#El Obour Sporting 16433 - El Entag EL Harby 1034 - 2023-03-17 12:30:00
#
#   ____________[71/81] 888 - 2022 -----#Al Mostaqbal 20457 - Porto Suez 18033 - 2023-03-17 12:30:00
#
#   ____________[72/81] 888 - 2022 -----#Petrojet 1041 - Masr 7520 - 2023-03-17 12:30:00
#
#   ____________[73/81] 887 - 2022 -----#Fayoum 18025 - El Madina El Monowara 18024 - 2023-03-17 13:00:00
#
#   ____________[74/81] 307 - 2022 -----#Al-Fayha 2944 - Al-Adalah 2950 - 2023-03-17 13:00:00
#
#   ____________[75/81] 307 - 2022 -----#Dhamk 2956 - Al Baten 2926 - 2023-03-17 13:00:00
#   ______________pre_first_half_winner_home:2.0
#
#   ____________[76/81] 506 - 2022 -----#Pohronie 4134 - Petržalka 10538 - 2023-03-17 13:30:00
#
#   ____________[77/81] 301 - 2022 -----#Baniyas SC 2877 - Dibba Al-Fujairah 2867 - 2023-03-17 13:45:00
#   ______________pre_second_half_winner_home:1.95
#
#   ____________[78/81] 301 - 2022 -----#Shabab Al Ahli Dubai 2870 - Al Khaleej 4912 - 2023-03-17 13:45:00
#   ______________pre_first_half_winner_home:1.83
#   ______________pre_second_half_winner_home:1.67
#   ______________pre_to_win_either_half_home:1.22
#   ______________pre_result_total_goals_home_over_25:2.05
#
#   ____________[79/81] 305 - 2022 -----#UMM Salal 2899 - Al-Gharafa 2903 - 2023-03-17 14:00:00
#
#   ____________[80/81] 305 - 2022 -----#Al Shamal 2916 - Al Sadd 2895 - 2023-03-17 14:00:00
#   ______________pre_first_half_winner_away:1.67
#   ______________pre_second_half_winner_away:1.51
#   ______________pre_double_chance_home_draw:3.42
#
#   ____________[81/81] 303 - 2022 -----#City 17713 - Masafi 9141 - 2023-03-17 14:45:00
#
# # -------------------------------------------------- End at 2023-03-16 14:56:53
