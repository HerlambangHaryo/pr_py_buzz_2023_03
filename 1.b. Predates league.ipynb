# %%
""" 
    Update league fixture 0-2 days
"""

# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.predates import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_adds(2, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------     
    today       = get_today_adds(0, space) 
    # --------------------------------------------------    
    pd_gak_sempet_predates(day1, day2, today, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-27 12:12:09
#   __main()
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-08-27 12:12:09.806612
#   ____get_today_adds()
#   ______adds date_diff : 2
#   ______today_raw : 2023-08-29 12:12:09.807616
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-08-27 12:12:09.808608
#   ____pd_gak_sempet_predates()
#   ______Select  leagueapi_id  , season from football_fixtures  where date >= '2023-08-27'  and date <= '2023-08-29'  and deleted_at is null  and fixture_status IN ('Not Started', 'Not Started Goto', 'Not Started One')  group by leagueapi_id, season  order by leagueapi_id asc
#   ______Total Row(s) : 221
#   ________[1/221]  #39 - 2023
#   __________pd_detail_fixtures()
# ...

# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.xpattern_new_auto import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------      
    xpNa_set_pattern('pre_', 4, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-26 15:49:02
#   __main()
#   ____xpNa_set_pattern()
#   ____Total Row(s) : 133
#   ____
#   ____ [1/133]
#   ____  > fixtureapi_id = 1086194
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [2/133]
#   ____  > fixtureapi_id = 1086195
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [3/133]
#   ____  > fixtureapi_id = 1085276
#   ____  __> pre_ah_pattern = H
# ...
