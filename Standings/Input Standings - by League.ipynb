# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *  
from a_models.standings import *   
from a_models.leagues import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    space += "__"
    # --------------------------------------------------  
    leagueapi_id = input(space + "Enter your leagueapi id : ")
    season = input(space + "Enter your season : ")
    # --------------------------------------------------
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")   
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    # --------------------------------------------------  
    st_check_standings(leagueapi_id, season, space)
    st_get_team_direct_updated(leagueapi_id, season, space)
    st_get_team_rank(leagueapi_id, season, day0, space)
    lg_update_tanggal(leagueapi_id, 'tanggal_update_standing', day0, space)
     
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-26 21:07:17
#   __main()
#   ____Enter your leagueapi id : 960
#   ____Enter your season : 2023
#   ______> day0 : 2023-03-26
#   ________st_check_standings()
#   __________ Select *  from standings  where leagueapi_id = '960'  and season = '2023'
#   __________Total Row(s) : 53
#   ________st_get_team_direct_updated()
#   __________Total Row(s) : 53
#   ____________[1/53] 1 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980468
#   ________________> standings UPDATED
#   ____________[2/53] 10 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980457
#   ________________> standings UPDATED
#   ____________[3/53] 1090 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[4/53] 1091 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980456
#   ________________> standings UPDATED
#   ____________[5/53] 1092 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[6/53] 1093 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980465
#   ________________> standings UPDATED
#   ____________[7/53] 1094 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[8/53] 1095 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980456
#   ________________> standings UPDATED
#   ____________[9/53] 1096 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980469
#   ________________> standings UPDATED
#   ____________[10/53] 1097 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980471
#   ________________> standings UPDATED
#   ____________[11/53] 1098 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980467
#   ________________> standings UPDATED
#   ____________[12/53] 1099 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980459
#   ________________> standings UPDATED
#   ____________[13/53] 1100 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[14/53] 1101 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[15/53] 1102 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980462
#   ________________> standings UPDATED
#   ____________[16/53] 1103 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980470
#   ________________> standings UPDATED
#   ____________[17/53] 1104 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[18/53] 1105 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980458
#   ________________> standings UPDATED
#   ____________[19/53] 1106 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980472
#   ________________> standings UPDATED
#   ____________[20/53] 1107 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980461
#   ________________> standings UPDATED
#   ____________[21/53] 1108 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980472
#   ________________> standings UPDATED
#   ____________[22/53] 1109 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980470
#   ________________> standings UPDATED
#   ____________[23/53] 1110 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[24/53] 1111 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[25/53] 1112 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980458
#   ________________> standings UPDATED
#   ____________[26/53] 1113 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980463
#   ________________> standings UPDATED
#   ____________[27/53] 1114 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980467
#   ________________> standings UPDATED
#   ____________[28/53] 1115 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980460
#   ________________> standings UPDATED
#   ____________[29/53] 1116 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[30/53] 1117 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980465
#   ________________> standings UPDATED
#   ____________[31/53] 1118 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980464
#   ________________> standings UPDATED
#   ____________[32/53] 14 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980471
#   ________________> standings UPDATED
#   ____________[33/53] 15 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[34/53] 18 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980463
#   ________________> standings UPDATED
#   ____________[35/53] 2 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980464
#   ________________> standings UPDATED
#   ____________[36/53] 21 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980459
#   ________________> standings UPDATED
#   ____________[37/53] 24 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980466
#   ________________> standings UPDATED
#   ____________[38/53] 27 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980461
#   ________________> standings UPDATED
#   ____________[39/53] 3 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[40/53] 5 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980468
#   ________________> standings UPDATED
#   ____________[41/53] 767 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[42/53] 768 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980457
#   ________________> standings UPDATED
#   ____________[43/53] 769 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[44/53] 770 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980466
#   ________________> standings UPDATED
#   ____________[45/53] 771 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980460
#   ________________> standings UPDATED
#   ____________[46/53] 772 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[47/53] 773 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980462
#   ________________> standings UPDATED
#   ____________[48/53] 774 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[49/53] 775 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 1
#   ________________#980469
#   ________________> standings UPDATED
#   ____________[50/53] 776 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[51/53] 777 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[52/53] 778 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ____________[53/53] 9 - 2023-03-26
#   ______________st_update_standing()
#   ________________> Total Row(s) : 0
#   ________________No Match
#   ________st_get_team_rank()
#   __________Total Row(s) : 53
#   ____________[1/53] 2 - France - 3pts - 4gs
#   ____________> standing rank UPDATED
#   ____________[2/53] 27 - Portugal - 3pts - 4gs
#   ____________> standing rank UPDATED
#   ____________[3/53] 1113 - Bosnia & Herzegovina - 3pts - 3gs
#   ____________> standing rank UPDATED
#   ____________[4/53] 1117 - Greece - 3pts - 3gs
#   ____________> standing rank UPDATED
#   ____________[5/53] 775 - Austria - 3pts - 3gs
#   ____________> standing rank UPDATED
#   ____________[6/53] 1 - Belgium - 3pts - 3gs
#   ____________> standing rank UPDATED
#   ____________[7/53] 1108 - Scotland - 3pts - 3gs
#   ____________> standing rank UPDATED
#   ____________[8/53] 14 - Serbia - 3pts - 2gs
#   ____________> standing rank UPDATED
#   ____________[9/53] 21 - Denmark - 3pts - 2gs
#   ____________> standing rank UPDATED
#   ____________[10/53] 770 - Czech Republic - 3pts - 2gs
#   ____________> standing rank UPDATED
#   ____________[11/53] 771 - Northern Ireland - 3pts - 2gs
#   ____________> standing rank UPDATED
#   ____________[12/53] 10 - England - 3pts - 1gs
#   ____________> standing rank UPDATED
#   ____________[13/53] 1091 - Slovenia - 3pts - 1gs
#   ____________> standing rank UPDATED
#   ____________[14/53] 1105 - FYR Macedonia - 3pts - 1gs
#   ____________> standing rank UPDATED
#   ____________[15/53] 1109 - Montenegro - 3pts - 1gs
#   ____________> standing rank UPDATED
#   ____________[16/53] 1114 - Moldova - 1pts - 0gs
#   ____________> standing rank UPDATED
#   ____________[17/53] 773 - Slovakia - 1pts - 0gs
#   ____________> standing rank UPDATED
#   ____________[18/53] 1098 - Faroe Islands - 1pts - 0gs
#   ____________> standing rank UPDATED
#   ____________[19/53] 1102 - Luxembourg - 1pts - 0gs
#   ____________> standing rank UPDATED
#   ____________[20/53] 768 - Italy - 0pts - -1gs
#   ____________> standing rank UPDATED
#   ____________[21/53] 1095 - Kazakhstan - 0pts - -1gs
#   ____________> standing rank UPDATED
#   ____________[22/53] 1103 - Bulgaria - 0pts - -1gs
#   ____________> standing rank UPDATED
#   ____________[23/53] 1112 - Malta - 0pts - -1gs
#   ____________> standing rank UPDATED
#   ____________[24/53] 1115 - San Marino - 0pts - -2gs
#   ____________> standing rank UPDATED
#   ____________[25/53] 24 - Poland - 0pts - -2gs
#   ____________> standing rank UPDATED
#   ____________[26/53] 1097 - Lithuania - 0pts - -2gs
#   ____________> standing rank UPDATED
#   ____________[27/53] 1099 - Finland - 0pts - -2gs
#   ____________> standing rank UPDATED
#   ____________[28/53] 18 - Iceland - 0pts - -3gs
#   ____________> standing rank UPDATED
#   ____________[29/53] 5 - Sweden - 0pts - -3gs
#   ____________> standing rank UPDATED
#   ____________[30/53] 1093 - Gibraltar - 0pts - -3gs
#   ____________> standing rank UPDATED
#   ____________[31/53] 1096 - Azerbaijan - 0pts - -3gs
#   ____________> standing rank UPDATED
#   ____________[32/53] 1106 - Cyprus - 0pts - -3gs
#   ____________> standing rank UPDATED
#   ____________[33/53] 1118 - Netherlands - 0pts - -4gs
#   ____________> standing rank UPDATED
#   ____________[34/53] 1107 - Liechtenstein - 0pts - -4gs
#   ____________> standing rank UPDATED
#   ____________[35/53] 1116 - Israel - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[36/53] 15 - Switzerland - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[37/53] 3 - Croatia - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[38/53] 767 - Wales - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[39/53] 769 - Hungary - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[40/53] 772 - Ukraine - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[41/53] 774 - Romania - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[42/53] 776 - Rep. Of Ireland - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[43/53] 777 - Turkey - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[44/53] 778 - Albania - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[45/53] 9 - Spain - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[46/53] 1090 - Norway - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[47/53] 1092 - Latvia - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[48/53] 1094 - Armenia - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[49/53] 1100 - Belarus - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[50/53] 1101 - Estonia - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[51/53] 1104 - Georgia - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[52/53] 1110 - Andorra - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ____________[53/53] 1111 - Kosovo - Nonepts - Nonegs
#   ____________> standing rank UPDATED
#   ________lg_update_tanggal()
#   __________update leagues set  tanggal_update_standing = '2023-03-26'  where leagueapi_id = '960'
#   __________> leagues : tanggal_update_standing UPDATED at 2023-03-26
# # -------------------------------------------------- End at 2023-03-26 21:10:41
