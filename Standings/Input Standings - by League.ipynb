# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *  
from a_models.standings import *   
from a_models.leagues import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    space += "__"
    # --------------------------------------------------  
    leagueapi_id = input(space + "Enter your leagueapi id : ")
    season = input(space + "Enter your season : ")
    # --------------------------------------------------
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")   
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    # --------------------------------------------------  
    st_check_standings(leagueapi_id, season, space)
    st_get_team_direct_updated(leagueapi_id, season, space)
    st_get_team_rank(leagueapi_id, season, day0, space)
    lg_update_tanggal(leagueapi_id, 'tanggal_update_standing', day0, space)
     
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 01:38:09
#   __main()
#   ____Enter your leagueapi id : 5
#   ____Enter your season : 2022
#   ______> day0 : 2023-03-25
#   ________st_check_standings()
#   __________ Select *  from standings  where leagueapi_id = '5'  and season = '2022'
#   __________Total Row(s) : 55
#   ________st_get_team_direct_updated()
#   __________Total Row(s) : 55
#   ____________[1/55] 1 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 6
#   ________________#854581
#   ________________#854589
#   ________________#854598
#   ________________#854606
#   ________________#854611
#   ________________#854619
#   ________________> standings UPDATED
#   ____________[2/55] 10 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 6
#   ________________#854583
#   ________________#854591
#   ________________#854599
#   ________________#854607
# ...
