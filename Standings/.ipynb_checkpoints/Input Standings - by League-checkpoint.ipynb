# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *  
from a_models.standings import *   
from a_models.leagues import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    space += "__"
    # --------------------------------------------------  
    leagueapi_id = input(space + "Enter your leagueapi id : ")
    season = input(space + "Enter your season : ")
    # --------------------------------------------------
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")   
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    # --------------------------------------------------  
    st_check_standings(leagueapi_id, season, space)
    st_get_team_direct_updated(leagueapi_id, season, space)
    st_get_team_rank(leagueapi_id, season, day0, space)
    lg_update_tanggal(leagueapi_id, 'tanggal_update_standing', day0, space)
     
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 01:34:41
#   __main()
#   ____Enter your leagueapi id : 1
#   ____Enter your season : 2022
#   ______> day0 : 2023-03-25
#   ________st_check_standings()
#   __________ Select *  from standings  where leagueapi_id = '1'  and season = '2022'
#   __________Total Row(s) : 32
#   ________st_get_team_direct_updated()
#   __________Total Row(s) : 32
#   ____________[1/32] 1 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855742
#   ________________#855753
#   ________________#855766
#   ________________> standings UPDATED
#   ____________[2/32] 10 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 5
#   ________________#855735
#   ________________#855749
#   ________________#866683
#   ________________#976534
#   ________________#978036
#   ________________> standings UPDATED
#   ____________[3/32] 1118 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 5
#   ________________#855734
#   ________________#855748
#   ________________#855760
#   ________________#976533
#   ________________#977794
#   ________________> standings UPDATED
#   ____________[4/32] 12 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 4
#   ________________#855741
#   ________________#871853
#   ________________#855768
#   ________________#977344
#   ________________> standings UPDATED
#   ____________[5/32] 13 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 4
#   ________________#855734
#   ________________#855747
#   ________________#855761
#   ________________#976534
#   ________________> standings UPDATED
#   ____________[6/32] 14 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855746
#   ________________#855756
#   ________________#855772
#   ________________> standings UPDATED
#   ____________[7/32] 15 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 4
#   ________________#855743
#   ________________#855758
#   ________________#855772
#   ________________#977706
#   ________________> standings UPDATED
#   ____________[8/32] 1504 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855745
#   ________________#855757
#   ________________#855770
#   ________________> standings UPDATED
#   ____________[9/32] 1530 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855743
#   ________________#855756
#   ________________#855771
#   ________________> standings UPDATED
#   ____________[10/32] 1569 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855736
#   ________________#855747
#   ________________#855760
#   ________________> standings UPDATED
#   ____________[11/32] 16 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855739
#   ________________#855752
#   ________________#855765
#   ________________> standings UPDATED
#   ____________[12/32] 17 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 4
#   ________________#855744
#   ________________#855757
#   ________________#855769
#   ________________#977705
#   ________________> standings UPDATED
#   ____________[13/32] 2 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 7
#   ________________#871850
#   ________________#855751
#   ________________#855763
#   ________________#976643
#   ________________#978036
#   ________________#978488
#   ________________#979139
#   ________________> standings UPDATED
#   ____________[14/32] 20 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 4
#   ________________#871850
#   ________________#871852
#   ________________#871854
#   ________________#976642
#   ________________> standings UPDATED
#   ____________[15/32] 21 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855738
#   ________________#855751
#   ________________#871854
#   ________________> standings UPDATED
#   ____________[16/32] 22 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855735
#   ________________#866682
#   ________________#855762
#   ________________> standings UPDATED
#   ____________[17/32] 23 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855737
#   ________________#855750
#   ________________#855765
#   ________________> standings UPDATED
#   ____________[18/32] 2382 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855736
#   ________________#855748
#   ________________#855761
#   ________________> standings UPDATED
#   ____________[19/32] 2384 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 4
#   ________________#866681
#   ________________#855749
#   ________________#855762
#   ________________#976533
#   ________________> standings UPDATED
#   ____________[20/32] 24 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 4
#   ________________#855739
#   ________________#855750
#   ________________#855764
#   ________________#976643
#   ________________> standings UPDATED
#   ____________[21/32] 25 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855741
#   ________________#855755
#   ________________#871855
#   ________________> standings UPDATED
#   ____________[22/32] 26 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 7
#   ________________#855737
#   ________________#855752
#   ________________#855764
#   ________________#976642
#   ________________#977794
#   ________________#978279
#   ________________#979139
#   ________________> standings UPDATED
#   ____________[23/32] 27 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 5
#   ________________#855745
#   ________________#855759
#   ________________#855769
#   ________________#977706
#   ________________#978088
#   ________________> standings UPDATED
#   ____________[24/32] 28 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855738
#   ________________#871852
#   ________________#855763
#   ________________> standings UPDATED
#   ____________[25/32] 29 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#871851
#   ________________#871853
#   ________________#871855
#   ________________> standings UPDATED
#   ____________[26/32] 3 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 7
#   ________________#855740
#   ________________#855754
#   ________________#855766
#   ________________#977344
#   ________________#978072
#   ________________#978279
#   ________________#979138
#   ________________> standings UPDATED
#   ____________[27/32] 31 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 7
#   ________________#855740
#   ________________#855753
#   ________________#855767
#   ________________#977345
#   ________________#978088
#   ________________#978488
#   ________________#979138
#   ________________> standings UPDATED
#   ____________[28/32] 5529 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855742
#   ________________#855754
#   ________________#855767
#   ________________> standings UPDATED
#   ____________[29/32] 6 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 5
#   ________________#855746
#   ________________#855758
#   ________________#855771
#   ________________#977705
#   ________________#978072
#   ________________> standings UPDATED
#   ____________[30/32] 7 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#855744
#   ________________#855759
#   ________________#855770
#   ________________> standings UPDATED
#   ____________[31/32] 767 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 3
#   ________________#866681
#   ________________#866682
#   ________________#866683
#   ________________> standings UPDATED
#   ____________[32/32] 9 - 2023-03-25
#   ______________st_update_standing()
#   ________________> Total Row(s) : 4
#   ________________#871851
#   ________________#855755
#   ________________#855768
#   ________________#977345
#   ________________> standings UPDATED
#   ________st_get_team_rank()
#   __________Total Row(s) : 32
#   ____________[1/32] 2 - France - 16pts - 8gs
#   ____________> standing rank UPDATED
#   ____________[2/32] 26 - Argentina - 14pts - 7gs
#   ____________> standing rank UPDATED
#   ____________[3/32] 1118 - Netherlands - 11pts - 6gs
#   ____________> standing rank UPDATED
#   ____________[4/32] 31 - Morocco - 11pts - 1gs
#   ____________> standing rank UPDATED
#   ____________[5/32] 10 - England - 10pts - 9gs
#   ____________> standing rank UPDATED
#   ____________[6/32] 6 - Brazil - 10pts - 5gs
#   ____________> standing rank UPDATED
#   ____________[7/32] 3 - Croatia - 10pts - 1gs
#   ____________> standing rank UPDATED
#   ____________[8/32] 27 - Portugal - 9pts - 6gs
#   ____________> standing rank UPDATED
#   ____________[9/32] 12 - Japan - 7pts - 1gs
#   ____________> standing rank UPDATED
#   ____________[10/32] 13 - Senegal - 6pts - -2gs
#   ____________> standing rank UPDATED
#   ____________[11/32] 20 - Australia - 6pts - -2gs
#   ____________> standing rank UPDATED
#   ____________[12/32] 15 - Switzerland - 6pts - -4gs
#   ____________> standing rank UPDATED
#   ____________[13/32] 9 - Spain - 5pts - 6gs
#   ____________> standing rank UPDATED
#   ____________[14/32] 2384 - USA - 5pts - -1gs
#   ____________> standing rank UPDATED
#   ____________[15/32] 2382 - Ecuador - 4pts - 1gs
#   ____________> standing rank UPDATED
#   ____________[16/32] 25 - Germany - 4pts - 1gs
#   ____________> standing rank UPDATED
#   ____________[17/32] 1530 - Cameroon - 4pts - 0gs
#   ____________> standing rank UPDATED
#   ____________[18/32] 28 - Tunisia - 4pts - 0gs
#   ____________> standing rank UPDATED
#   ____________[19/32] 7 - Uruguay - 4pts - 0gs
#   ____________> standing rank UPDATED
#   ____________[20/32] 1 - Belgium - 4pts - -1gs
#   ____________> standing rank UPDATED
#   ____________[21/32] 16 - Mexico - 4pts - -1gs
#   ____________> standing rank UPDATED
#   ____________[22/32] 24 - Poland - 4pts - -2gs
#   ____________> standing rank UPDATED
#   ____________[23/32] 17 - South Korea - 4pts - -3gs
#   ____________> standing rank UPDATED
#   ____________[24/32] 1504 - Ghana - 3pts - -2gs
#   ____________> standing rank UPDATED
#   ____________[25/32] 23 - Saudi Arabia - 3pts - -2gs
#   ____________> standing rank UPDATED
#   ____________[26/32] 22 - Iran - 3pts - -3gs
#   ____________> standing rank UPDATED
#   ____________[27/32] 29 - Costa Rica - 3pts - -8gs
#   ____________> standing rank UPDATED
#   ____________[28/32] 21 - Denmark - 1pts - -2gs
#   ____________> standing rank UPDATED
#   ____________[29/32] 14 - Serbia - 1pts - -3gs
#   ____________> standing rank UPDATED
#   ____________[30/32] 767 - Wales - 1pts - -5gs
#   ____________> standing rank UPDATED
#   ____________[31/32] 5529 - Canada - 0pts - -5gs
#   ____________> standing rank UPDATED
#   ____________[32/32] 1569 - Qatar - 0pts - -6gs
#   ____________> standing rank UPDATED
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#      30 st_get_team_direct_updated(leagueapi_id, season, space)
#      31 st_get_team_rank(leagueapi_id, season, day0, space)
# ---> 32 lg_update_tanggal(leagueapi_id, 'tanggal_update_standing', day0, space)
#      34 # --------------------------------------------------
#      35 its_end()
#
# NameError: name 'lg_update_tanggal' is not defined
