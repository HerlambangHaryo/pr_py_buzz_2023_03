# %%
# Import 
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *   
from a_models.api_odds_new import *   
from a_models.football_leagues import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    leagueapi_id    = input(space + "Enter your leagueapi id :  ") 
    season          = input(space + "Enter your season :  ") 
    # --------------------------------------------------    
    date_0          = get_today_adds(0, space).strftime("%Y-%m-%d") 
    date_raw        = get_today_adds(0, space) 
    # -------------------------------------------------- 
    bookmaker       = fl_check_league(leagueapi_id, "bookmakersapi_id", space)
    # --------------------------------------------------  
    DICT = {
        'date' : date_0,
        'date_raw' : date_raw,
        'league' : leagueapi_id,
        'season' : season,
        'bookmaker' : bookmaker,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 0, 
        'max_page' : 0, 
    } 
    # --------------------------------------------------  
    PREP_ = "preleague_"
    # -------------------------------------------------- 
    aoN_controll_match_update(DICT, PREP_, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 09:56:55
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 09:56:57.826876
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 09:56:57.827877
#   ______fl_check_league()
#   ______bookmakersapi_id: 2
#   ______aoN_controll_match_update()
#   ________aa_check_acccount()
#   __________API api4@ariondigitalmedia.com counter is 36
#   __________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________aoN_response_odds()
#   __________date : 2023-09-03
#   __________date_raw : 2023-09-03 09:56:57.827877
#   __________bookmaker : 2
#   __________season : 2023
#   __________league : 699
#   __________page : 1
#   ____________Total API Response(s) : 5
#   ____________total_MAX_PAGE : 1
#   ______________
#   ______________1/5
#   ______________England,  Women's Championship  #699 - 2023
#   ______________2023-08-26 16:30:00+00:00 // UTC // 1075563
#   ____________________aoN_football_odds_insert_rows()
#   ____________________football_odds INSERTED
#   ________________aoN_football_statistics_check()
#   ____________________England,  Women's Championship - 2023 __ 1075563 __ 2023-08-26 23:30:00 __ 2
#   ______________________________Blackburn Rovers W vs Birmingham City W
#   __________________________Kurang 2023-08-26 23:30:00 < 2023-09-03 09:56:57
#   ________________PREP_check_date is not valid
#   ________________
#   ________________2/5
#   ________________England,  Women's Championship  #699 - 2023
#   ________________2023-08-27 12:00:00+00:00 // UTC // 1075565
#   ______________________aoN_football_odds_insert_rows()
#   ______________________football_odds INSERTED
#   __________________aoN_football_statistics_check()
#   ______________________England,  Women's Championship - 2023 __ 1075565 __ 2023-08-27 19:00:00 __ 2
#   ________________________________Sunderland W vs London City Lionesses
#   ____________________________Kurang 2023-08-27 19:00:00 < 2023-09-03 09:56:57
#   __________________PREP_check_date is not valid
#   __________________
#   __________________3/5
#   __________________England,  Women's Championship  #699 - 2023
#   __________________2023-08-27 13:00:00+00:00 // UTC // 1075566
#   ________________________aoN_football_odds_insert_rows()
#   ________________________football_odds INSERTED
#   ____________________aoN_football_statistics_check()
#   ________________________England,  Women's Championship - 2023 __ 1075566 __ 2023-08-27 20:00:00 __ 2
#   __________________________________Crystal Palace W vs Reading W
#   ______________________________Kurang 2023-08-27 20:00:00 < 2023-09-03 09:56:57
#   ____________________PREP_check_date is not valid
#   ____________________
#   ____________________4/5
#   ____________________England,  Women's Championship  #699 - 2023
#   ____________________2023-09-02 16:15:00+00:00 // UTC // 1075569
#   __________________________aoN_football_odds_insert_rows()
#   __________________________football_odds INSERTED
#   ______________________aoN_football_statistics_check()
#   __________________________England,  Women's Championship - 2023 __ 1075569 __ 2023-09-02 23:15:00 __ 2
#   ____________________________________Reading W vs Charlton Athletic W
#   ________________________________Kurang 2023-09-02 23:15:00 < 2023-09-03 09:56:57
#   ______________________PREP_check_date is not valid
#   ______________________
#   ______________________5/5
#   ______________________England,  Women's Championship  #699 - 2023
#   ______________________2023-09-03 14:00:00+00:00 // UTC // 1075573
#   ____________________________aoN_football_odds_insert_rows()
#   ____________________________football_odds INSERTED
#   ________________________aoN_football_statistics_check()
#   ____________________________England,  Women's Championship - 2023 __ 1075573 __ 2023-09-03 21:00:00 __ 2
#   ______________________________________Birmingham City W vs Crystal Palace W
#   __________________________________Lebih 2023-09-03 21:00:00 >= 2023-09-03 09:56:57
#   __________________________fua_update_or_insert()
#   ____________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '699'  and season = '2023'  and fixtureapi_id = '1075573'
#   ______________________________Total Row(s) : 0
#   ________________________________football_ultimate_assessments INSERTED
#   ________________________football_odds UPDATED
#   ________________________football_fixtures UPDATED
#   __________________________football_fixtures 1075573 UPDATED Not Started Goto
#   ________________________STOP RESPONSE
# # -------------------------------------------------- End at 2023-09-03 09:57:08

# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.xpattern_new_auto import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------      
    xpNa_set_pattern('pre_', 4, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 09:57:08
#   __main()
#   ____xpNa_set_pattern()
#   ____Total Row(s) : 1
#   ____
#   ____ [1/1]
#   ____  > fixtureapi_id = 1075573
#   ____  __> pre_ah_pattern = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-09-03 09:57:11
