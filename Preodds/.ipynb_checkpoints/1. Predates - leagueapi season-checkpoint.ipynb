# %%
# Import 
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *   
from a_models.api_odds_new import *   
from a_models.football_leagues import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    leagueapi_id    = input(space + "Enter your leagueapi id :  ") 
    season          = input(space + "Enter your season :  ") 
    # --------------------------------------------------    
    date_0          = get_today_adds(0, space).strftime("%Y-%m-%d") 
    date_raw        = get_today_adds(0, space) 
    # -------------------------------------------------- 
    bookmaker       = fl_check_league(leagueapi_id, "bookmakersapi_id", space)
    # --------------------------------------------------  
    DICT = {
        'date' : date_0,
        'date_raw' : date_raw,
        'league' : leagueapi_id,
        'season' : season,
        'bookmaker' : bookmaker,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 0, 
    } 
    # --------------------------------------------------  
    PREP_ = "preleague_"
    # -------------------------------------------------- 
    aoN_controll_match_update(DICT, PREP_, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-11 18:44:33
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-08-11 18:44:37.191583
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-08-11 18:44:37.193585
#   ______fl_check_league()
#   ______bookmakersapi_id: 8
#   ______aoN_controll_match_update()
#   ________aa_check_acccount()
#   __________API digitalmedia.arion@gmail.com counter is 49
#   __________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________aoN_response_odds()
#   __________date : 2023-08-11
#   __________date_raw : 2023-08-11 18:44:37.193585
#   __________bookmaker : 8
#   __________season : 2023
#   __________league : 39
#   __________page : 1
#   ____________Total API Response(s) : 10
#   ______________
#   ______________1/10
#   ______________England,  Premier League  #39 - 2023 // 2023-08-12 14:00:00+00:00 // 1035041
#   ________________aoN_football_statistics_check()
#   ____________________England,  Premier League - 2023 __ 1035041 __ 2023-08-12 21:00:00 __ 8
#   ______________________________Everton vs Fulham
#   __________________________Lebih
#   __________________fua_update_or_insert()
#   ____________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035041'
#   ______________________Total Row(s) : 1
#   ________________________football_ultimate_assessments UPDATED
#   ________________football_odds UPDATED
#   __________________football_fixtures 1035041 UPDATED Not Started Goto
#   ________________
#   ________________2/10
#   ________________England,  Premier League  #39 - 2023 // 2023-08-12 14:00:00+00:00 // 1035040
#   __________________aoN_football_statistics_check()
#   ______________________England,  Premier League - 2023 __ 1035040 __ 2023-08-12 21:00:00 __ 8
#   ________________________________Brighton vs Luton
#   ____________________________Lebih
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035040'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   ____________________football_fixtures 1035040 UPDATED Not Started Goto
#   __________________
#   __________________3/10
#   __________________England,  Premier League  #39 - 2023 // 2023-08-12 14:00:00+00:00 // 1035039
#   ____________________aoN_football_statistics_check()
#   ________________________England,  Premier League - 2023 __ 1035039 __ 2023-08-12 21:00:00 __ 8
#   __________________________________Bournemouth vs West Ham
#   ______________________________Lebih
#   ______________________fua_update_or_insert()
#   ________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035039'
#   __________________________Total Row(s) : 1
#   ____________________________football_ultimate_assessments UPDATED
#   ____________________football_odds UPDATED
#   ______________________football_fixtures 1035039 UPDATED Not Started Goto
#   ____________________
#   ____________________4/10
#   ____________________England,  Premier League  #39 - 2023 // 2023-08-12 11:30:00+00:00 // 1035038
#   ______________________aoN_football_statistics_check()
#   __________________________England,  Premier League - 2023 __ 1035038 __ 2023-08-12 18:30:00 __ 8
#   ____________________________________Arsenal vs Nottingham Forest
#   ________________________________Lebih
#   ________________________fua_update_or_insert()
#   __________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035038'
#   ____________________________Total Row(s) : 1
#   ______________________________football_ultimate_assessments UPDATED
#   ______________________football_odds UPDATED
#   ________________________football_fixtures 1035038 UPDATED Not Started Goto
#   ______________________
#   ______________________5/10
#   ______________________England,  Premier League  #39 - 2023 // 2023-08-11 19:00:00+00:00 // 1035037
#   ________________________aoN_football_statistics_check()
#   ____________________________England,  Premier League - 2023 __ 1035037 __ 2023-08-12 02:00:00 __ 8
#   ______________________________________Burnley vs Manchester City
#   __________________________________Lebih
#   __________________________fua_update_or_insert()
#   ____________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035037'
#   ______________________________Total Row(s) : 1
#   ________________________________football_ultimate_assessments UPDATED
#   ________________________football_odds UPDATED
#   __________________________football_fixtures 1035037 UPDATED Not Started Goto
#   ________________________
#   ________________________6/10
#   ________________________England,  Premier League  #39 - 2023 // 2023-08-13 13:00:00+00:00 // 1035044
#   __________________________aoN_football_statistics_check()
#   ______________________________England,  Premier League - 2023 __ 1035044 __ 2023-08-13 20:00:00 __ 8
#   ________________________________________Brentford vs Tottenham
#   ____________________________________Lebih
#   ____________________________fua_update_or_insert()
#   ______________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035044'
#   ________________________________Total Row(s) : 1
#   __________________________________football_ultimate_assessments UPDATED
#   __________________________football_odds UPDATED
#   ____________________________football_fixtures 1035044 UPDATED Not Started Goto
#   __________________________
#   __________________________7/10
#   __________________________England,  Premier League  #39 - 2023 // 2023-08-14 19:00:00+00:00 // 1035046
#   ____________________________aoN_football_statistics_check()
#   ________________________________England,  Premier League - 2023 __ 1035046 __ 2023-08-15 02:00:00 __ 8
#   __________________________________________Manchester United vs Wolves
#   ______________________________________Lebih
#   ______________________________fua_update_or_insert()
#   ________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035046'
#   __________________________________Total Row(s) : 1
#   ____________________________________football_ultimate_assessments UPDATED
#   ____________________________football_odds UPDATED
#   ______________________________football_fixtures 1035046 UPDATED Not Started Goto
#   ____________________________
#   ____________________________8/10
#   ____________________________England,  Premier League  #39 - 2023 // 2023-08-13 15:30:00+00:00 // 1035045
#   ______________________________aoN_football_statistics_check()
#   __________________________________England,  Premier League - 2023 __ 1035045 __ 2023-08-13 22:30:00 __ 8
#   ____________________________________________Chelsea vs Liverpool
#   ________________________________________Lebih
#   ________________________________fua_update_or_insert()
#   __________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035045'
#   ____________________________________Total Row(s) : 1
#   ______________________________________football_ultimate_assessments UPDATED
#   ______________________________football_odds UPDATED
#   ________________________________football_fixtures 1035045 UPDATED Not Started Goto
#   ______________________________
#   ______________________________9/10
#   ______________________________England,  Premier League  #39 - 2023 // 2023-08-12 16:30:00+00:00 // 1035043
#   ________________________________aoN_football_statistics_check()
#   ____________________________________England,  Premier League - 2023 __ 1035043 __ 2023-08-12 23:30:00 __ 8
#   ______________________________________________Newcastle vs Aston Villa
#   __________________________________________Lebih
#   __________________________________fua_update_or_insert()
#   ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035043'
#   ______________________________________Total Row(s) : 1
#   ________________________________________football_ultimate_assessments UPDATED
#   ________________________________football_odds UPDATED
#   __________________________________football_fixtures 1035043 UPDATED Not Started Goto
#   ________________________________
#   ________________________________10/10
#   ________________________________England,  Premier League  #39 - 2023 // 2023-08-12 14:00:00+00:00 // 1035042
#   __________________________________aoN_football_statistics_check()
#   ______________________________________England,  Premier League - 2023 __ 1035042 __ 2023-08-12 21:00:00 __ 8
#   ________________________________________________Sheffield Utd vs Crystal Palace
#   ____________________________________________Lebih
#   ____________________________________fua_update_or_insert()
#   ______________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035042'
#   ________________________________________Total Row(s) : 1
#   __________________________________________football_ultimate_assessments UPDATED
#   __________________________________football_odds UPDATED
#   ____________________________________football_fixtures 1035042 UPDATED Not Started Goto
#   __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API digitalmedia.arion@gmail.com counter is 48
# __________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date : 2023-08-11
# __________date_raw : 2023-08-11 18:44:37.193585
# __________bookmaker : 8
# __________season : 2023
# __________league : 39
# __________page : 2
# ____________Total API Response(s) : 9
# ______________
# ______________1/9
# ______________England,  Premier League  #39 - 2023 // 2023-08-19 16:30:00+00:00 // 1035054
# ____________________aoN_football_odds_insert_rows()
# ____________________football_odds INSERTED
# ________________aoN_football_statistics_check()
# ____________________England,  Premier League - 2023 __ 1035054 __ 2023-08-19 23:30:00 __ 8
# ______________________________Tottenham vs Manchester United
# __________________________Lebih
# __________________fua_update_or_insert()
# ____________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035054'
# ______________________Total Row(s) : 0
# ________________________football_ultimate_assessments INSERTED
# ________________football_odds UPDATED
# __________________football_fixtures 1035054 UPDATED Not Started Goto
# ________________
# ________________2/9
# ________________England,  Premier League  #39 - 2023 // 2023-08-18 18:45:00+00:00 // 1035053
# ______________________aoN_football_odds_insert_rows()
# ______________________football_odds INSERTED
# __________________aoN_football_statistics_check()
# ______________________England,  Premier League - 2023 __ 1035053 __ 2023-08-19 01:45:00 __ 8
# ________________________________Nottingham Forest vs Sheffield Utd
# ____________________________Lebih
# __________________football_odds UPDATED
# ____________________football_fixtures 1035053 UPDATED Not Started Goto
# __________________
# __________________3/9
# __________________England,  Premier League  #39 - 2023 // 2023-08-19 19:00:00+00:00 // 1035052
# ________________________aoN_football_odds_insert_rows()
# ________________________football_odds INSERTED
# ____________________aoN_football_statistics_check()
# ________________________England,  Premier League - 2023 __ 1035052 __ 2023-08-20 02:00:00 __ 8
# __________________________________Manchester City vs Newcastle
# ______________________________Lebih
# ______________________fua_update_or_insert()
# ________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035052'
# __________________________Total Row(s) : 0
# ____________________________football_ultimate_assessments INSERTED
# ____________________football_odds UPDATED
# ______________________football_fixtures 1035052 UPDATED Not Started Goto
# ____________________
# ____________________4/9
# ____________________England,  Premier League  #39 - 2023 // 2023-08-19 14:00:00+00:00 // 1035056
# __________________________aoN_football_odds_insert_rows()
# __________________________football_odds INSERTED
# ______________________aoN_football_statistics_check()
# __________________________England,  Premier League - 2023 __ 1035056 __ 2023-08-19 21:00:00 __ 8
# ____________________________________Wolves vs Brighton
# ________________________________Lebih
# ________________________fua_update_or_insert()
# __________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035056'
# ____________________________Total Row(s) : 0
# ______________________________football_ultimate_assessments INSERTED
# ______________________football_odds UPDATED
# ________________________football_fixtures 1035056 UPDATED Not Started Goto
# ______________________
# ______________________5/9
# ______________________England,  Premier League  #39 - 2023 // 2023-08-20 13:00:00+00:00 // 1035047
# ____________________________aoN_football_odds_insert_rows()
# ____________________________football_odds INSERTED
# ________________________aoN_football_statistics_check()
# ____________________________England,  Premier League - 2023 __ 1035047 __ 2023-08-20 20:00:00 __ 8
# ______________________________________Aston Villa vs Everton
# __________________________________Lebih
# __________________________fua_update_or_insert()
# ____________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035047'
# ______________________________Total Row(s) : 0
# ________________________________football_ultimate_assessments INSERTED
# ________________________football_odds UPDATED
# __________________________football_fixtures 1035047 UPDATED Not Started Goto
# ________________________
# ________________________6/9
# ________________________England,  Premier League  #39 - 2023 // 2023-08-20 15:30:00+00:00 // 1035055
# ______________________________aoN_football_odds_insert_rows()
# ______________________________football_odds INSERTED
# __________________________aoN_football_statistics_check()
# ______________________________England,  Premier League - 2023 __ 1035055 __ 2023-08-20 22:30:00 __ 8
# ________________________________________West Ham vs Chelsea
# ____________________________________Lebih
# ____________________________fua_update_or_insert()
# ______________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035055'
# ________________________________Total Row(s) : 0
# __________________________________football_ultimate_assessments INSERTED
# __________________________football_odds UPDATED
# ____________________________football_fixtures 1035055 UPDATED Not Started Goto
# __________________________
# __________________________7/9
# __________________________England,  Premier League  #39 - 2023 // 2023-08-21 19:00:00+00:00 // 1035048
# ________________________________aoN_football_odds_insert_rows()
# ________________________________football_odds INSERTED
# ____________________________aoN_football_statistics_check()
# ________________________________England,  Premier League - 2023 __ 1035048 __ 2023-08-22 02:00:00 __ 8
# __________________________________________Crystal Palace vs Arsenal
# ______________________________________Lebih
# ______________________________fua_update_or_insert()
# ________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035048'
# __________________________________Total Row(s) : 0
# ____________________________________football_ultimate_assessments INSERTED
# ____________________________football_odds UPDATED
# ______________________________football_fixtures 1035048 UPDATED Not Started Goto
# ____________________________
# ____________________________8/9
# ____________________________England,  Premier League  #39 - 2023 // 2023-08-19 14:00:00+00:00 // 1035050
# __________________________________aoN_football_odds_insert_rows()
# __________________________________football_odds INSERTED
# ______________________________aoN_football_statistics_check()
# __________________________________England,  Premier League - 2023 __ 1035050 __ 2023-08-19 21:00:00 __ 8
# ____________________________________________Liverpool vs Bournemouth
# ________________________________________Lebih
# ________________________________fua_update_or_insert()
# __________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035050'
# ____________________________________Total Row(s) : 0
# ______________________________________football_ultimate_assessments INSERTED
# ______________________________football_odds UPDATED
# ________________________________football_fixtures 1035050 UPDATED Not Started Goto
# ______________________________
# ______________________________9/9
# ______________________________England,  Premier League  #39 - 2023 // 2023-08-19 14:00:00+00:00 // 1035049
# ____________________________________aoN_football_odds_insert_rows()
# ____________________________________football_odds INSERTED
# ________________________________aoN_football_statistics_check()
# ____________________________________England,  Premier League - 2023 __ 1035049 __ 2023-08-19 21:00:00 __ 8
# ______________________________________________Fulham vs Brentford
# __________________________________________Lebih
# __________________________________fua_update_or_insert()
# ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035049'
# ______________________________________Total Row(s) : 0
# ________________________________________football_ultimate_assessments INSERTED
# ________________________________football_odds UPDATED
# __________________________________football_fixtures 1035049 UPDATED Not Started Goto
# ________________________________STOP RESPONSE
# # -------------------------------------------------- End at 2023-08-11 18:45:52

# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.xpattern_new_auto import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------      
    xpNa_set_pattern('pre_', 4, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-11 18:45:55
#   __main()
#   ____xpNa_set_pattern()
#   ____Total Row(s) : 19
#   ____
#   ____ [1/19]
#   ____  > fixtureapi_id = 1035037
#   ____  __> pre_ah_pattern = +125+15+175H
#   ____  __> pre_ah_pattern_mirror = -175-15-125H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = +1+125+15+175H
#   ____  __> pre_ah_pattern_mirror_4 = -175-15-125-1H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [2/19]
#   ____  > fixtureapi_id = 1035041
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [3/19]
#   ____  > fixtureapi_id = 1035040
#   ____  __> pre_ah_pattern = -175-15-125H
#   ____  __> pre_ah_pattern_mirror = +125+15+175H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -2-175-15-125H
#   ____  __> pre_ah_pattern_mirror_4 = +125+15+175+2H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [4/19]
#   ____  > fixtureapi_id = 1035039
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [5/19]
#   ____  > fixtureapi_id = 1035038
#   ____  __> pre_ah_pattern = -25-225-2-175-15H
#   ____  __> pre_ah_pattern_mirror = +15+175+2+225+25H
#   ____  __> pre_gou_pattern = 30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -25-225-2-175-15H
#   ____  __> pre_ah_pattern_mirror_4 = +15+175+2+225+25H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [6/19]
#   ____  > fixtureapi_id = 1035043
#   ____  __> pre_ah_pattern = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [7/19]
#   ____  > fixtureapi_id = 1035042
#   ____  __> pre_ah_pattern = +0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [8/19]
#   ____  > fixtureapi_id = 1035044
#   ____  __> pre_ah_pattern = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [9/19]
#   ____  > fixtureapi_id = 1035045
#   ____  __> pre_ah_pattern = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [10/19]
#   ____  > fixtureapi_id = 1035046
#   ____  __> pre_ah_pattern = -175-15-125H
#   ____  __> pre_ah_pattern_mirror = +125+15+175H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125H
#   ____  __> pre_ah_pattern_mirror_4 = +125+15+175H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [11/19]
#   ____  > fixtureapi_id = 1035055
#   ____  __> pre_ah_pattern = +025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [12/19]
#   ____  > fixtureapi_id = 1035048
#   ____  __> pre_ah_pattern = +075+1+125+15H
#   ____  __> pre_ah_pattern_mirror = -15-125-1-075H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +05+075+1+125+15H
#   ____  __> pre_ah_pattern_mirror_4 = -15-125-1-075-05H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [13/19]
#   ____  > fixtureapi_id = 1035050
#   ____  __> pre_ah_pattern = -25-225-2-175-15H
#   ____  __> pre_ah_pattern_mirror = +15+175+2+225+25H
#   ____  __> pre_gou_pattern = 30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -25-225-2-175-15H
#   ____  __> pre_ah_pattern_mirror_4 = +15+175+2+225+25H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [14/19]
#   ____  > fixtureapi_id = 1035049
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [15/19]
#   ____  > fixtureapi_id = 1035054
#   ____  __> pre_ah_pattern = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [16/19]
#   ____  > fixtureapi_id = 1035053
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [17/19]
#   ____  > fixtureapi_id = 1035052
#   ____  __> pre_ah_pattern = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [18/19]
#   ____  > fixtureapi_id = 1035056
#   ____  __> pre_ah_pattern = +05+075+1H
#   ____  __> pre_ah_pattern_mirror = -1-075-05H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075+1H
#   ____  __> pre_ah_pattern_mirror_4 = -1-075-05-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [19/19]
#   ____  > fixtureapi_id = 1035047
#   ____  __> pre_ah_pattern = -125-1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1+125H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1+125H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-08-11 18:46:31
