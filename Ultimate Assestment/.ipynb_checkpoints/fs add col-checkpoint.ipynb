# %%
stats = [
    'goals',
    'score_halftime',
    'score_secondtime',
    'shots_on_goal',
    'shots_off_goal',
    'total_shots',
    'blocked_shots',
    'shots_inside_box',
    'shots_outside_box',
    'fouls',
    'corner_kicks',
    'offsides',
    'ball_possession',
    'yellow_cards',
    'red_cards',
    'goalkeeper_saves',
    'total_passess',
    'passess_accurate',
    'passess', 
    'cards'
]

# %%
end_col = 'passess_away'

# %%
import mysql.connector

# ALTER TABLE `football_fixtures` ADD `aaa` DECIMAL(5,3) NULL DEFAULT NULL AFTER `end_exact_score`; 

# -----------------------------------------------------------------
query = ""
# ----------------------------------------------------------------- 
host="localhost"
user="root"
database="pr_mmbuzz_2022_06" 
mydb = mysql.connector.connect( host=host, user=user, password="", database=database )
mycursor = mydb.cursor()
# ----------------------------------------------------------------- 
for x in stats:
    # -------------------------------------------------------------
    # -------------------------------------------------------------
    # -------------------------------------------------------------
    new_col = x + '_total_home'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    # -------------------------------------------------------------
    new_col = x + '_total_home_ratio'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    # -------------------------------------------------------------
    new_col = x + '_total_away'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    # -------------------------------------------------------------
    new_col = x + '_total_away_ratio'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col 
    # -------------------------------------------------------------
    new_col = x + '_as_home'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    # -------------------------------------------------------------
    new_col = x + '_as_home_ratio'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    # -------------------------------------------------------------
    new_col = x + '_opponents_home'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    # -------------------------------------------------------------
    new_col = x + '_opponents_home_ratio'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    # -------------------------------------------------------------
    new_col = x + '_as_away'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    # -------------------------------------------------------------
    new_col = x + '_as_away_ratio'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    # -------------------------------------------------------------
    new_col = x + '_opponents_away'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    # -------------------------------------------------------------
    new_col = x + '_opponents_away_ratio'
    query += "ALTER TABLE `football_statistics` ADD `"+new_col+"` DOUBLE NULL DEFAULT NULL AFTER `"+end_col+"`;"
    end_col = new_col  
    
# -----------------------------------------------------------------
print(query)
# mycursor.execute(query)
# mydb.commit()  
# # ------------------------ close the cursor and database connection
# mycursor.close()
# mydb.close()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# Input In [3], in <cell line: 68>()
#      66 # -----------------------------------------------------------------
#      67 mycursor.execute(query)
# ---> 68 mydb.commit()
#      69 # ------------------------ close the cursor and database connection
#      70 mycursor.close()
#
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:425, in CMySQLConnection.commit(self)
#     423 if self._cmysql:
#     424     self.handle_unread_result()
# --> 425     self._cmysql.commit()
#
# MySQLInterfaceError: Commands out of sync; you can't run this command now
