# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_statistics import *  
     
if __name__ == '__main__': 
    # ----------------------------------------------------------  
    its_start()
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------  
    print(space + "main()", flush=True)  
    # ----------------------------------------------------------  
    space += "__" 
    # ----------------------------------------------------------  
    leagueapi_id = input(space + "Enter your leagueapi id : ") 
    season = input(space + "Enter your season : ")
    # ----------------------------------------------------------  
    fS_check_date_is_null(leagueapi_id, season, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-23 23:10:19
#   __main()
#   ____Enter your leagueapi id : 39
#   ____Enter your season : 2022
#   ______fS_check_date_is_null()
#   ______ SELECT   fixtureapi_id  , leagueapi_id  , season  , teams_homeapi_id  , teams_awayapi_id  , date FROM football_statistics WHERE leagueapi_id = '39'  and season = '2022'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and date is null  order by fixtureapi_id asc
#   ______Total Row(s) : 0
#   ________fS_get_match_finished_for_ultimate_assessment()
#   ________ SELECT   fixtureapi_id  , leagueapi_id  , season  , teams_homeapi_id  , teams_awayapi_id  , date FROM football_statistics WHERE leagueapi_id = '39'  and season = '2022'  and fixture_status in ('Match Finished', 'Match Finished Ended')  order by date asc
#   ________Total Row(s) : 367
#   ________[1/367]  2022-08-05 19:00:00 #867946  39 - 2022 [52 vs 42]
#
#   ________[2/367]  2022-08-06 11:30:00 #867947  39 - 2022 [36 vs 40]
#
#   ________[3/367]  2022-08-06 14:00:00 #867948  39 - 2022 [35 vs 66]
#
#   ________[4/367]  2022-08-06 14:00:00 #867949  39 - 2022 [63 vs 39]
#
#   ________[5/367]  2022-08-06 14:00:00 #867951  39 - 2022 [34 vs 65]
#
#   ________[6/367]  2022-08-06 14:00:00 #867952  39 - 2022 [47 vs 41]
#
#   ________[7/367]  2022-08-06 16:30:00 #867953  39 - 2022 [45 vs 49]
#
#   ________[8/367]  2022-08-07 13:00:00 #867950  39 - 2022 [46 vs 55]
#
#   ________[9/367]  2022-08-07 13:00:00 #867954  39 - 2022 [33 vs 51]
#
#   ________[10/367]  2022-08-07 15:30:00 #867955  39 - 2022 [48 vs 50]
#
#   ________[11/367]  2022-08-13 11:30:00 #867957  39 - 2022 [66 vs 45]
#   __________goals ratio: 0.0
#   __________goals ratio: 0.0
#
#   ________[12/367]  2022-08-13 14:00:00 #867965  39 - 2022 [39 vs 36]
#   __________goals ratio: 1.0
#   __________goals ratio: 2.0
#
#   ________[13/367]  2022-08-13 14:00:00 #867964  39 - 2022 [41 vs 63]
#   __________goals ratio: 1.0
#   __________goals ratio: 2.0
#
#   ________[14/367]  2022-08-13 14:00:00 #867962  39 - 2022 [50 vs 35]
#   __________goals ratio: 2.0
#   __________goals ratio: 2.0
#
#   ________[15/367]  2022-08-13 14:00:00 #867959  39 - 2022 [51 vs 34]
#   __________goals ratio: 2.0
#   __________goals ratio: 2.0
#
#   ________[16/367]  2022-08-13 14:00:00 #867956  39 - 2022 [42 vs 46]
#   __________goals ratio: 2.0
#   __________goals ratio: 2.0
#
#   ________[17/367]  2022-08-13 16:30:00 #867958  39 - 2022 [55 vs 33]
#   __________goals ratio: 2.0
#   __________goals ratio: 1.0
#
#   ________[18/367]  2022-08-14 13:00:00 #867963  39 - 2022 [65 vs 48]
#   __________goals ratio: 0.0
#   __________goals ratio: 0.0
#
#   ________[19/367]  2022-08-14 15:30:00 #867960  39 - 2022 [49 vs 47]
#   __________goals ratio: 1.0
#   __________goals ratio: 4.0
#
#   ________[20/367]  2022-08-15 19:00:00 #867961  39 - 2022 [40 vs 52]
#   __________goals ratio: 2.0
#   __________goals ratio: 0.0
#
#   ________[21/367]  2022-08-20 11:30:00 #867974  39 - 2022 [47 vs 39]
#   __________goals ratio: 3.0
#   __________goals ratio: 0.5
#
#   ________[22/367]  2022-08-20 14:00:00 #867971  39 - 2022 [46 vs 41]
#   __________goals ratio: 2.0
#   __________goals ratio: 1.5
