# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_statistics import *  
     
if __name__ == '__main__': 
    # ----------------------------------------------------------  
    its_start()
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------  
    print(space + "main()", flush=True)  
    # ----------------------------------------------------------  
    space += "__" 
    # ----------------------------------------------------------  
    leagueapi_id = input(space + "Enter your leagueapi id : ") 
    season = input(space + "Enter your season : ")
    # ----------------------------------------------------------  
    fS_check_date_is_null(leagueapi_id, season, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-24 12:47:01
#   __main()
#   ____Enter your leagueapi id : 39
#   ____Enter your season : 2022
#   ______fS_check_date_is_null()
#   ______ SELECT   fixtureapi_id  , leagueapi_id  , season  , teams_homeapi_id  , teams_awayapi_id  , date FROM football_statistics WHERE leagueapi_id = '39'  and season = '2022'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and date is null  order by fixtureapi_id asc
#   ______Total Row(s) : 1
#   ______[1/1] #868311 #39 - 2022
#   ________fO_import_date()
#   ________Total Row(s) : 1
#   ________[1/1]  2023-05-22 19:00:00 #868311  39 - 2022
#   __________fS_update_date()
#   ________fS_get_match_finished_for_ultimate_assessment()
#   ________ SELECT   fixtureapi_id  , leagueapi_id  , season  , teams_homeapi_id  , teams_awayapi_id  , date FROM football_statistics WHERE leagueapi_id = '39'  and season = '2022'  and fixture_status in ('Match Finished', 'Match Finished Ended')  order by date asc
#   ________Total Row(s) : 368
#   ________[1/368]  2022-08-05 19:00:00 #867946  39 - 2022 [52 vs 42]
#
#   ________[2/368]  2022-08-06 11:30:00 #867947  39 - 2022 [36 vs 40]
#
#   ________[3/368]  2022-08-06 14:00:00 #867948  39 - 2022 [35 vs 66]
#
#   ________[4/368]  2022-08-06 14:00:00 #867949  39 - 2022 [63 vs 39]
#
#   ________[5/368]  2022-08-06 14:00:00 #867951  39 - 2022 [34 vs 65]
#
#   ________[6/368]  2022-08-06 14:00:00 #867952  39 - 2022 [47 vs 41]
#
#   ________[7/368]  2022-08-06 16:30:00 #867953  39 - 2022 [45 vs 49]
#
#   ________[8/368]  2022-08-07 13:00:00 #867950  39 - 2022 [46 vs 55]
#
#   ________[9/368]  2022-08-07 13:00:00 #867954  39 - 2022 [33 vs 51]
#
#   ________[10/368]  2022-08-07 15:30:00 #867955  39 - 2022 [48 vs 50]
#
#   ________[11/368]  2022-08-13 11:30:00 #867957  39 - 2022 [66 vs 45]
#   __________goals ratio: 0.0
#   __________half ratio: 0.0
#   __________second ratio: 0.0
#   __________corners ratio: 5.0
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#   __________goals ratio: 0.0
#   __________half ratio: 0.0
#   __________second ratio: 0.0
#   __________corners ratio: 4.0
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#
#   ________[12/368]  2022-08-13 14:00:00 #867965  39 - 2022 [39 vs 36]
#   __________goals ratio: 1.0
#   __________half ratio: 1.0
#   __________second ratio: 0.0
#   __________corners ratio: 4.0
#   __________yellows ratio: 0.0
#   __________cards ratio: 0.0
#   __________goals ratio: 2.0
#   __________half ratio: 1.0
#   __________second ratio: 1.0
#   __________corners ratio: 4.0
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#
#   ________[13/368]  2022-08-13 14:00:00 #867964  39 - 2022 [41 vs 63]
#   __________goals ratio: 1.0
#   __________half ratio: 1.0
#   __________second ratio: 0.0
#   __________corners ratio: 2.0
#   __________yellows ratio: 0.0
#   __________cards ratio: 0.0
#   __________goals ratio: 2.0
#   __________half ratio: 1.0
#   __________second ratio: 1.0
#   __________corners ratio: 6.0
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#
#   ________[14/368]  2022-08-13 14:00:00 #867962  39 - 2022 [50 vs 35]
#   __________goals ratio: 2.0
#   __________half ratio: 1.0
#   __________second ratio: 1.0
#   __________corners ratio: 4.0
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#   __________goals ratio: 2.0
#   __________half ratio: 1.0
#   __________second ratio: 1.0
#   __________corners ratio: 5.0
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#
#   ________[15/368]  2022-08-13 14:00:00 #867959  39 - 2022 [51 vs 34]
#   __________goals ratio: 2.0
#   __________half ratio: 2.0
#   __________second ratio: 0.0
#   __________corners ratio: 2.0
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#   __________goals ratio: 2.0
#   __________half ratio: 0.0
#   __________second ratio: 2.0
#   __________corners ratio: 11.0
#   __________yellows ratio: 0.0
#   __________cards ratio: 0.0
#
#   ________[16/368]  2022-08-13 14:00:00 #867956  39 - 2022 [42 vs 46]
#   __________goals ratio: 2.0
#   __________half ratio: 1.0
#   __________second ratio: 1.0
#   __________corners ratio: 5.0
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#   __________goals ratio: 2.0
#   __________half ratio: 1.0
#   __________second ratio: 1.0
#   __________corners ratio: 5.0
#   __________yellows ratio: 0.0
#   __________cards ratio: 0.0
#
#   ________[17/368]  2022-08-13 16:30:00 #867958  39 - 2022 [55 vs 33]
#   __________goals ratio: 2.0
#   __________half ratio: 0.0
#   __________second ratio: 2.0
#   __________corners ratio: 6.0
#   __________yellows ratio: 0.0
#   __________cards ratio: 0.0
#   __________goals ratio: 1.0
#   __________half ratio: 0.0
#   __________second ratio: 1.0
#   __________corners ratio: 6.0
#   __________yellows ratio: 4.0
#   __________cards ratio: 4.0
#
#   ________[18/368]  2022-08-14 13:00:00 #867963  39 - 2022 [65 vs 48]
#   __________goals ratio: 0.0
#   __________half ratio: 0.0
#   __________second ratio: 0.0
#   __________corners ratio: 1.0
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#   __________goals ratio: 0.0
#   __________half ratio: 0.0
#   __________second ratio: 0.0
#   __________corners ratio: 1.0
#   __________yellows ratio: 0.0
#   __________cards ratio: 0.0
#
#   ________[19/368]  2022-08-14 15:30:00 #867960  39 - 2022 [49 vs 47]
#   __________goals ratio: 1.0
#   __________half ratio: 1.0
#   __________second ratio: 0.0
#   __________corners ratio: 16.0
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#   __________goals ratio: 4.0
#   __________half ratio: 2.0
#   __________second ratio: 2.0
#   __________corners ratio: 10.0
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#
#   ________[20/368]  2022-08-15 19:00:00 #867961  39 - 2022 [40 vs 52]
#   __________goals ratio: 2.0
#   __________half ratio: 0.0
#   __________second ratio: 2.0
#   __________corners ratio: 4.0
#   __________yellows ratio: 0.0
#   __________cards ratio: 0.0
#   __________goals ratio: 0.0
#   __________half ratio: 0.0
#   __________second ratio: 0.0
#   __________corners ratio: 3.0
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#
#   ________[21/368]  2022-08-20 11:30:00 #867974  39 - 2022 [47 vs 39]
#   __________goals ratio: 3.0
#   __________half ratio: 1.0
#   __________second ratio: 2.0
#   __________corners ratio: 7.5
#   __________yellows ratio: 1.5
#   __________cards ratio: 1.5
#   __________goals ratio: 0.5
#   __________half ratio: 0.5
#   __________second ratio: 0.0
#   __________corners ratio: 4.5
#   __________yellows ratio: 1.5
#   __________cards ratio: 1.5
#
#   ________[22/368]  2022-08-20 14:00:00 #867971  39 - 2022 [46 vs 41]
#   __________goals ratio: 2.0
#   __________half ratio: 0.5
#   __________second ratio: 1.5
#   __________corners ratio: 3.5
#   __________yellows ratio: 0.5
#   __________cards ratio: 0.5
#   __________goals ratio: 1.5
#   __________half ratio: 0.5
#   __________second ratio: 1.0
#   __________corners ratio: 2.0
#   __________yellows ratio: 0.5
#   __________cards ratio: 0.5
#
#   ________[23/368]  2022-08-20 14:00:00 #867969  39 - 2022 [36 vs 55]
#   __________goals ratio: 1.0
#   __________half ratio: 0.5
#   __________second ratio: 0.5
#   __________corners ratio: 3.5
#   __________yellows ratio: 2.5
#   __________cards ratio: 2.5
#   __________goals ratio: 3.0
#   __________half ratio: 2.0
#   __________second ratio: 1.0
#   __________corners ratio: 7.0
#   __________yellows ratio: 0.0
#   __________cards ratio: 0.0
#
#   ________[24/368]  2022-08-20 14:00:00 #867968  39 - 2022 [45 vs 65]
#   __________goals ratio: 0.5
#   __________half ratio: 0.0
#   __________second ratio: 0.5
#   __________corners ratio: 6.0
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#   __________goals ratio: 0.5
#   __________half ratio: 0.5
#   __________second ratio: 0.0
#   __________corners ratio: 3.5
#   __________yellows ratio: 3.5
#   __________cards ratio: 3.5
#
#   ________[25/368]  2022-08-20 14:00:00 #867967  39 - 2022 [52 vs 66]
#   __________goals ratio: 0.5
#   __________half ratio: 0.5
#   __________second ratio: 0.0
#   __________corners ratio: 2.5
#   __________yellows ratio: 2.5
#   __________cards ratio: 2.5
#   __________goals ratio: 1.0
#   __________half ratio: 0.5
#   __________second ratio: 0.5
#   __________corners ratio: 5.0
#   __________yellows ratio: 3.5
#   __________cards ratio: 3.5
#
#   ________[26/368]  2022-08-20 16:30:00 #867966  39 - 2022 [35 vs 42]
#   __________goals ratio: 1.0
#   __________half ratio: 0.5
#   __________second ratio: 0.5
#   __________corners ratio: 3.0
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#   __________goals ratio: 3.0
#   __________half ratio: 1.5
#   __________second ratio: 1.5
#   __________corners ratio: 5.5
#   __________yellows ratio: 1.5
#   __________cards ratio: 1.5
#
#   ________[27/368]  2022-08-21 13:00:00 #867970  39 - 2022 [63 vs 49]
#   __________goals ratio: 2.0
#   __________half ratio: 0.5
#   __________second ratio: 1.5
#   __________corners ratio: 5.5
#   __________yellows ratio: 2.5
#   __________cards ratio: 2.5
#   __________goals ratio: 1.5
#   __________half ratio: 1.0
#   __________second ratio: 0.5
#   __________corners ratio: 12.0
#   __________yellows ratio: 2.5
#   __________cards ratio: 2.5
#
#   ________[28/368]  2022-08-21 13:00:00 #867975  39 - 2022 [48 vs 51]
#   __________goals ratio: 0.0
#   __________half ratio: 0.0
#   __________second ratio: 0.0
#   __________corners ratio: 4.0
#   __________yellows ratio: 0.5
#   __________cards ratio: 0.5
#   __________goals ratio: 1.0
#   __________half ratio: 1.0
#   __________second ratio: 0.0
#   __________corners ratio: 4.5
#   __________yellows ratio: 1.5
#   __________cards ratio: 1.5
#
#   ________[29/368]  2022-08-21 15:30:00 #867973  39 - 2022 [34 vs 50]
#   __________goals ratio: 1.0
#   __________half ratio: 0.0
#   __________second ratio: 1.0
#   __________corners ratio: 7.0
#   __________yellows ratio: 1.5
#   __________cards ratio: 1.5
#   __________goals ratio: 3.0
#   __________half ratio: 2.0
#   __________second ratio: 1.0
#   __________corners ratio: 7.5
#   __________yellows ratio: 0.5
#   __________cards ratio: 0.5
#
#   ________[30/368]  2022-08-22 19:00:00 #867972  39 - 2022 [33 vs 40]
#   __________goals ratio: 0.5
#   __________half ratio: 0.0
#   __________second ratio: 0.5
#   __________corners ratio: 4.0
#   __________yellows ratio: 4.0
#   __________cards ratio: 4.0
#   __________goals ratio: 1.5
#   __________half ratio: 0.0
#   __________second ratio: 1.5
#   __________corners ratio: 4.0
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.5
#
#   ________[31/368]  2022-08-27 11:30:00 #867984  39 - 2022 [41 vs 33]
#   __________goals ratio: 1.6666666666666667
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 1.3333333333333333
#   __________corners ratio: 3.0
#   __________yellows ratio: 1.3333333333333333
#   __________cards ratio: 1.3333333333333333
#   __________goals ratio: 1.0
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 0.6666666666666666
#   __________corners ratio: 4.666666666666667
#   __________yellows ratio: 3.6666666666666665
#   __________cards ratio: 3.6666666666666665
#
#   ________[32/368]  2022-08-27 14:00:00 #867982  39 - 2022 [50 vs 52]
#   __________goals ratio: 3.0
#   __________half ratio: 1.6666666666666667
#   __________second ratio: 1.3333333333333333
#   __________corners ratio: 6.666666666666667
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#   __________goals ratio: 1.3333333333333333
#   __________half ratio: 0.6666666666666666
#   __________second ratio: 0.6666666666666666
#   __________corners ratio: 3.0
#   __________yellows ratio: 2.3333333333333335
#   __________cards ratio: 2.3333333333333335
#
#   ________[33/368]  2022-08-27 14:00:00 #867981  39 - 2022 [40 vs 35]
#   __________goals ratio: 1.3333333333333333
#   __________half ratio: 0.0
#   __________second ratio: 1.3333333333333333
#   __________corners ratio: 5.333333333333333
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.3333333333333333
#   __________goals ratio: 0.6666666666666666
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 0.3333333333333333
#   __________corners ratio: 3.0
#   __________yellows ratio: 2.6666666666666665
#   __________cards ratio: 2.6666666666666665
#
#   ________[34/368]  2022-08-27 14:00:00 #867980  39 - 2022 [49 vs 46]
#   __________goals ratio: 1.0
#   __________half ratio: 0.6666666666666666
#   __________second ratio: 0.3333333333333333
#   __________corners ratio: 10.0
#   __________yellows ratio: 2.6666666666666665
#   __________cards ratio: 3.0
#   __________goals ratio: 1.6666666666666667
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 1.3333333333333333
#   __________corners ratio: 3.0
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#
#   ________[35/368]  2022-08-27 14:00:00 #867979  39 - 2022 [51 vs 63]
#   __________goals ratio: 1.3333333333333333
#   __________half ratio: 1.0
#   __________second ratio: 0.3333333333333333
#   __________corners ratio: 4.333333333333333
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#   __________goals ratio: 2.3333333333333335
#   __________half ratio: 1.0
#   __________second ratio: 1.3333333333333333
#   __________corners ratio: 5.0
#   __________yellows ratio: 1.6666666666666667
#   __________cards ratio: 1.6666666666666667
#
#   ________[36/368]  2022-08-27 14:00:00 #867978  39 - 2022 [55 vs 45]
#   __________goals ratio: 2.6666666666666665
#   __________half ratio: 1.6666666666666667
#   __________second ratio: 1.0
#   __________corners ratio: 5.666666666666667
#   __________yellows ratio: 0.6666666666666666
#   __________cards ratio: 0.6666666666666666
#   __________goals ratio: 0.6666666666666666
#   __________half ratio: 0.0
#   __________second ratio: 0.6666666666666666
#   __________corners ratio: 6.0
#   __________yellows ratio: 2.3333333333333335
#   __________cards ratio: 2.3333333333333335
#
#   ________[37/368]  2022-08-27 16:30:00 #867976  39 - 2022 [42 vs 36]
#   __________goals ratio: 3.0
#   __________half ratio: 1.6666666666666667
#   __________second ratio: 1.3333333333333333
#   __________corners ratio: 5.0
#   __________yellows ratio: 1.3333333333333333
#   __________cards ratio: 1.3333333333333333
#   __________goals ratio: 1.6666666666666667
#   __________half ratio: 1.0
#   __________second ratio: 0.6666666666666666
#   __________corners ratio: 4.333333333333333
#   __________yellows ratio: 2.6666666666666665
#   __________cards ratio: 2.6666666666666665
#
#   ________[38/368]  2022-08-28 13:00:00 #867977  39 - 2022 [66 vs 48]
#   __________goals ratio: 1.0
#   __________half ratio: 0.6666666666666666
#   __________second ratio: 0.3333333333333333
#   __________corners ratio: 4.0
#   __________yellows ratio: 2.6666666666666665
#   __________cards ratio: 2.6666666666666665
#   __________goals ratio: 0.0
#   __________half ratio: 0.0
#   __________second ratio: 0.0
#   __________corners ratio: 4.333333333333333
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#
#   ________[39/368]  2022-08-28 13:00:00 #867985  39 - 2022 [39 vs 34]
#   __________goals ratio: 0.3333333333333333
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 0.0
#   __________corners ratio: 5.0
#   __________yellows ratio: 1.6666666666666667
#   __________cards ratio: 1.6666666666666667
#   __________goals ratio: 1.6666666666666667
#   __________half ratio: 0.6666666666666666
#   __________second ratio: 1.0
#   __________corners ratio: 6.333333333333333
#   __________yellows ratio: 2.3333333333333335
#   __________cards ratio: 2.3333333333333335
#
#   ________[40/368]  2022-08-28 15:30:00 #867983  39 - 2022 [65 vs 47]
#   __________goals ratio: 0.6666666666666666
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 0.3333333333333333
#   __________corners ratio: 3.0
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#   __________goals ratio: 2.3333333333333335
#   __________half ratio: 0.6666666666666666
#   __________second ratio: 1.6666666666666667
#   __________corners ratio: 7.666666666666667
#   __________yellows ratio: 1.6666666666666667
#   __________cards ratio: 1.6666666666666667
#
#   ________[41/368]  2022-08-30 18:30:00 #867992  39 - 2022 [52 vs 55]
#   __________goals ratio: 1.5
#   __________half ratio: 1.0
#   __________second ratio: 0.5
#   __________corners ratio: 2.5
#   __________yellows ratio: 2.25
#   __________cards ratio: 2.25
#   __________goals ratio: 2.25
#   __________half ratio: 1.25
#   __________second ratio: 1.0
#   __________corners ratio: 6.25
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#
#   ________[42/368]  2022-08-30 18:30:00 #867988  39 - 2022 [36 vs 51]
#   __________goals ratio: 1.5
#   __________half ratio: 0.75
#   __________second ratio: 0.75
#   __________corners ratio: 3.75
#   __________yellows ratio: 2.75
#   __________cards ratio: 2.75
#   __________goals ratio: 1.25
#   __________half ratio: 0.75
#   __________second ratio: 0.5
#   __________corners ratio: 4.5
#   __________yellows ratio: 1.25
#   __________cards ratio: 1.25
#
#   ________[43/368]  2022-08-30 18:45:00 #867993  39 - 2022 [41 vs 49]
#   __________goals ratio: 1.25
#   __________half ratio: 0.25
#   __________second ratio: 1.0
#   __________corners ratio: 3.5
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#   __________goals ratio: 1.25
#   __________half ratio: 0.5
#   __________second ratio: 0.75
#   __________corners ratio: 8.25
#   __________yellows ratio: 2.75
#   __________cards ratio: 3.25
#
#   ________[44/368]  2022-08-30 19:00:00 #867989  39 - 2022 [63 vs 45]
#   __________goals ratio: 1.75
#   __________half ratio: 0.75
#   __________second ratio: 1.0
#   __________corners ratio: 4.5
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#   __________goals ratio: 0.75
#   __________half ratio: 0.25
#   __________second ratio: 0.5
#   __________corners ratio: 5.75
#   __________yellows ratio: 2.25
#   __________cards ratio: 2.25
#
#   ________[45/368]  2022-08-31 18:30:00 #867986  39 - 2022 [35 vs 39]
#   __________goals ratio: 0.5
#   __________half ratio: 0.25
#   __________second ratio: 0.25
#   __________corners ratio: 2.5
#   __________yellows ratio: 2.25
#   __________cards ratio: 2.25
#   __________goals ratio: 0.5
#   __________half ratio: 0.5
#   __________second ratio: 0.0
#   __________corners ratio: 4.75
#   __________yellows ratio: 1.75
#   __________cards ratio: 1.75
#
#   ________[46/368]  2022-08-31 18:30:00 #867987  39 - 2022 [42 vs 66]
#   __________goals ratio: 2.75
#   __________half ratio: 1.25
#   __________second ratio: 1.5
#   __________corners ratio: 6.0
#   __________yellows ratio: 1.5
#   __________cards ratio: 1.5
#   __________goals ratio: 0.75
#   __________half ratio: 0.5
#   __________second ratio: 0.25
#   __________corners ratio: 3.75
#   __________yellows ratio: 2.5
#   __________cards ratio: 2.5
#
#   ________[47/368]  2022-08-31 18:30:00 #867995  39 - 2022 [50 vs 65]
#   __________goals ratio: 3.25
#   __________half ratio: 1.25
#   __________second ratio: 2.0
#   __________corners ratio: 6.5
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#   __________goals ratio: 0.5
#   __________half ratio: 0.25
#   __________second ratio: 0.25
#   __________corners ratio: 3.75
#   __________yellows ratio: 3.75
#   __________cards ratio: 3.75
#
#   ________[48/368]  2022-08-31 18:45:00 #867991  39 - 2022 [48 vs 47]
#   __________goals ratio: 0.25
#   __________half ratio: 0.0
#   __________second ratio: 0.25
#   __________corners ratio: 3.75
#   __________yellows ratio: 0.75
#   __________cards ratio: 0.75
#   __________goals ratio: 2.25
#   __________half ratio: 0.75
#   __________second ratio: 1.5
#   __________corners ratio: 6.0
#   __________yellows ratio: 1.5
#   __________cards ratio: 1.5
#
#   ________[49/368]  2022-08-31 19:00:00 #867994  39 - 2022 [40 vs 34]
#   __________goals ratio: 3.25
#   __________half ratio: 1.25
#   __________second ratio: 2.0
#   __________corners ratio: 6.0
#   __________yellows ratio: 0.75
#   __________cards ratio: 1.0
#   __________goals ratio: 1.5
#   __________half ratio: 0.5
#   __________second ratio: 1.0
#   __________corners ratio: 8.0
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#
#   ________[50/368]  2022-09-01 19:00:00 #867990  39 - 2022 [46 vs 33]
#   __________goals ratio: 1.5
#   __________half ratio: 0.25
#   __________second ratio: 1.25
#   __________corners ratio: 5.0
#   __________yellows ratio: 1.25
#   __________cards ratio: 1.25
#   __________goals ratio: 1.0
#   __________half ratio: 0.25
#   __________second ratio: 0.75
#   __________corners ratio: 4.25
#   __________yellows ratio: 3.5
#   __________cards ratio: 3.5
#
#   ________[51/368]  2022-09-03 11:30:00 #868000  39 - 2022 [45 vs 40]
#   __________goals ratio: 0.8
#   __________half ratio: 0.4
#   __________second ratio: 0.4
#   __________corners ratio: 5.0
#   __________yellows ratio: 2.4
#   __________cards ratio: 2.4
#   __________goals ratio: 3.0
#   __________half ratio: 1.0
#   __________second ratio: 2.0
#   __________corners ratio: 7.4
#   __________yellows ratio: 0.6
#   __________cards ratio: 0.8
#
#   ________[52/368]  2022-09-03 14:00:00 #868005  39 - 2022 [39 vs 41]
#   __________goals ratio: 0.4
#   __________half ratio: 0.4
#   __________second ratio: 0.0
#   __________corners ratio: 4.8
#   __________yellows ratio: 1.6
#   __________cards ratio: 1.6
#   __________goals ratio: 1.4
#   __________half ratio: 0.6
#   __________second ratio: 0.8
#   __________corners ratio: 3.8
#   __________yellows ratio: 1.2
#   __________cards ratio: 1.2
#
#   ________[53/368]  2022-09-03 14:00:00 #868004  39 - 2022 [47 vs 36]
#   __________goals ratio: 2.0
#   __________half ratio: 0.8
#   __________second ratio: 1.2
#   __________corners ratio: 5.6
#   __________yellows ratio: 2.2
#   __________cards ratio: 2.2
#   __________goals ratio: 1.6
#   __________half ratio: 0.6
#   __________second ratio: 1.0
#   __________corners ratio: 3.6
#   __________yellows ratio: 2.6
#   __________cards ratio: 2.6
#
#   ________[54/368]  2022-09-03 14:00:00 #868003  39 - 2022 [65 vs 35]
#   __________goals ratio: 0.4
#   __________half ratio: 0.2
#   __________second ratio: 0.2
#   __________corners ratio: 3.2
#   __________yellows ratio: 3.2
#   __________cards ratio: 3.2
#   __________goals ratio: 0.4
#   __________half ratio: 0.2
#   __________second ratio: 0.2
#   __________corners ratio: 2.4
#   __________yellows ratio: 2.2
#   __________cards ratio: 2.2
#
#   ________[55/368]  2022-09-03 14:00:00 #868002  39 - 2022 [34 vs 52]
#   __________goals ratio: 1.4
#   __________half ratio: 0.6
#   __________second ratio: 0.8
#   __________corners ratio: 6.4
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#   __________goals ratio: 1.4
#   __________half ratio: 0.8
#   __________second ratio: 0.6
#   __________corners ratio: 2.8
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#
#   ________[56/368]  2022-09-03 14:00:00 #867999  39 - 2022 [49 vs 48]
#   __________goals ratio: 1.2
#   __________half ratio: 0.6
#   __________second ratio: 0.6
#   __________corners ratio: 7.2
#   __________yellows ratio: 2.4
#   __________cards ratio: 2.8
#   __________goals ratio: 0.4
#   __________half ratio: 0.0
#   __________second ratio: 0.4
#   __________corners ratio: 3.6
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.0
#
#   ________[57/368]  2022-09-03 14:00:00 #867997  39 - 2022 [55 vs 63]
#   __________goals ratio: 2.0
#   __________half ratio: 1.0
#   __________second ratio: 1.0
#   __________corners ratio: 6.2
#   __________yellows ratio: 1.2
#   __________cards ratio: 1.2
#   __________goals ratio: 1.6
#   __________half ratio: 0.6
#   __________second ratio: 1.0
#   __________corners ratio: 5.6
#   __________yellows ratio: 2.2
#   __________cards ratio: 2.2
#
#   ________[58/368]  2022-09-03 16:30:00 #867996  39 - 2022 [66 vs 50]
#   __________goals ratio: 0.8
#   __________half ratio: 0.4
#   __________second ratio: 0.4
#   __________corners ratio: 3.6
#   __________yellows ratio: 2.6
#   __________cards ratio: 2.6
#   __________goals ratio: 3.8
#   __________half ratio: 1.6
#   __________second ratio: 2.2
#   __________corners ratio: 7.2
#   __________yellows ratio: 0.8
#   __________cards ratio: 0.8
#
#   ________[59/368]  2022-09-04 13:00:00 #867998  39 - 2022 [51 vs 46]
#   __________goals ratio: 1.2
#   __________half ratio: 0.6
#   __________second ratio: 0.6
#   __________corners ratio: 4.2
#   __________yellows ratio: 1.2
#   __________cards ratio: 1.2
#   __________goals ratio: 1.2
#   __________half ratio: 0.2
#   __________second ratio: 1.0
#   __________corners ratio: 4.2
#   __________yellows ratio: 1.2
#   __________cards ratio: 1.2
#
#   ________[60/368]  2022-09-04 15:30:00 #868001  39 - 2022 [33 vs 42]
#   __________goals ratio: 1.0
#   __________half ratio: 0.4
#   __________second ratio: 0.6
#   __________corners ratio: 4.0
#   __________yellows ratio: 3.4
#   __________cards ratio: 3.4
#   __________goals ratio: 2.6
#   __________half ratio: 1.2
#   __________second ratio: 1.4
#   __________corners ratio: 6.8
#   __________yellows ratio: 1.6
#   __________cards ratio: 1.6
#
#   ________[61/368]  2022-09-16 19:00:00 #868016  39 - 2022 [66 vs 41]
#   __________goals ratio: 0.8333333333333334
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 0.5
#   __________corners ratio: 3.1666666666666665
#   __________yellows ratio: 2.5
#   __________cards ratio: 2.5
#   __________goals ratio: 1.1666666666666667
#   __________half ratio: 0.5
#   __________second ratio: 0.6666666666666666
#   __________corners ratio: 4.166666666666667
#   __________yellows ratio: 1.3333333333333333
#   __________cards ratio: 1.3333333333333333
#
#   ________[62/368]  2022-09-16 19:00:00 #868023  39 - 2022 [65 vs 36]
#   __________goals ratio: 0.6666666666666666
#   __________half ratio: 0.5
#   __________second ratio: 0.16666666666666666
#   __________corners ratio: 3.3333333333333335
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#   __________goals ratio: 1.5
#   __________half ratio: 0.5
#   __________second ratio: 1.0
#   __________corners ratio: 3.5
#   __________yellows ratio: 2.8333333333333335
#   __________cards ratio: 2.8333333333333335
#
#   ________[63/368]  2022-09-17 11:30:00 #868025  39 - 2022 [39 vs 50]
#   __________goals ratio: 0.5
#   __________half ratio: 0.5
#   __________second ratio: 0.0
#   __________corners ratio: 4.833333333333333
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#   __________goals ratio: 3.3333333333333335
#   __________half ratio: 1.3333333333333333
#   __________second ratio: 2.0
#   __________corners ratio: 6.666666666666667
#   __________yellows ratio: 0.6666666666666666
#   __________cards ratio: 0.6666666666666666
#
#   ________[64/368]  2022-09-17 14:00:00 #868022  39 - 2022 [34 vs 35]
#   __________goals ratio: 1.1666666666666667
#   __________half ratio: 0.5
#   __________second ratio: 0.6666666666666666
#   __________corners ratio: 7.5
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#   __________goals ratio: 0.8333333333333334
#   __________half ratio: 0.16666666666666666
#   __________second ratio: 0.6666666666666666
#   __________corners ratio: 3.0
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#
#   ________[65/368]  2022-09-17 16:30:00 #868024  39 - 2022 [47 vs 46]
#   __________goals ratio: 2.0
#   __________half ratio: 0.8333333333333334
#   __________second ratio: 1.1666666666666667
#   __________corners ratio: 6.333333333333333
#   __________yellows ratio: 2.3333333333333335
#   __________cards ratio: 2.3333333333333335
#   __________goals ratio: 1.3333333333333333
#   __________half ratio: 0.5
#   __________second ratio: 0.8333333333333334
#   __________corners ratio: 3.6666666666666665
#   __________yellows ratio: 1.1666666666666667
#   __________cards ratio: 1.1666666666666667
#
#   ________[66/368]  2022-09-18 11:00:00 #868017  39 - 2022 [55 vs 42]
#   __________goals ratio: 2.5
#   __________half ratio: 1.1666666666666667
#   __________second ratio: 1.3333333333333333
#   __________corners ratio: 5.5
#   __________yellows ratio: 1.3333333333333333
#   __________cards ratio: 1.3333333333333333
#   __________goals ratio: 2.3333333333333335
#   __________half ratio: 1.0
#   __________second ratio: 1.3333333333333333
#   __________corners ratio: 6.5
#   __________yellows ratio: 1.8333333333333333
#   __________cards ratio: 1.8333333333333333
#
#   ________[67/368]  2022-09-18 13:15:00 #868020  39 - 2022 [45 vs 48]
#   __________goals ratio: 0.6666666666666666
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 0.3333333333333333
#   __________corners ratio: 5.333333333333333
#   __________yellows ratio: 2.3333333333333335
#   __________cards ratio: 2.3333333333333335
#   __________goals ratio: 0.5
#   __________half ratio: 0.0
#   __________second ratio: 0.5
#   __________corners ratio: 3.5
#   __________yellows ratio: 1.1666666666666667
#   __________cards ratio: 1.1666666666666667
#
#   ________[68/368]  2022-10-01 11:30:00 #868027  39 - 2022 [42 vs 47]
#   __________goals ratio: 2.4285714285714284
#   __________half ratio: 1.1428571428571428
#   __________second ratio: 1.2857142857142858
#   __________corners ratio: 6.0
#   __________yellows ratio: 1.8571428571428572
#   __________cards ratio: 1.8571428571428572
#   __________goals ratio: 2.5714285714285716
#   __________half ratio: 1.0
#   __________second ratio: 1.5714285714285714
#   __________corners ratio: 6.285714285714286
#   __________yellows ratio: 2.142857142857143
#   __________cards ratio: 2.142857142857143
#
#   ________[69/368]  2022-10-01 14:00:00 #868034  39 - 2022 [41 vs 45]
#   __________goals ratio: 1.0
#   __________half ratio: 0.42857142857142855
#   __________second ratio: 0.5714285714285714
#   __________corners ratio: 4.0
#   __________yellows ratio: 1.2857142857142858
#   __________cards ratio: 1.2857142857142858
#   __________goals ratio: 0.7142857142857143
#   __________half ratio: 0.2857142857142857
#   __________second ratio: 0.42857142857142855
#   __________corners ratio: 5.285714285714286
#   __________yellows ratio: 2.4285714285714284
#   __________cards ratio: 2.4285714285714284
#
#   ________[70/368]  2022-10-01 14:00:00 #868032  39 - 2022 [40 vs 51]
#   __________goals ratio: 2.5
#   __________half ratio: 0.8333333333333334
#   __________second ratio: 1.6666666666666667
#   __________corners ratio: 7.666666666666667
#   __________yellows ratio: 0.8333333333333334
#   __________cards ratio: 1.0
#   __________goals ratio: 1.8333333333333333
#   __________half ratio: 0.8333333333333334
#   __________second ratio: 1.0
#   __________corners ratio: 5.166666666666667
#   __________yellows ratio: 1.1666666666666667
#   __________cards ratio: 1.1666666666666667
#
#   ________[71/368]  2022-10-01 14:00:00 #868029  39 - 2022 [36 vs 34]
#   __________goals ratio: 1.7142857142857142
#   __________half ratio: 0.42857142857142855
#   __________second ratio: 1.2857142857142858
#   __________corners ratio: 4.428571428571429
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#   __________goals ratio: 1.1428571428571428
#   __________half ratio: 0.42857142857142855
#   __________second ratio: 0.7142857142857143
#   __________corners ratio: 7.571428571428571
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#
#   ________[72/368]  2022-10-01 14:00:00 #868028  39 - 2022 [52 vs 49]
#   __________goals ratio: 1.1666666666666667
#   __________half ratio: 0.6666666666666666
#   __________second ratio: 0.5
#   __________corners ratio: 3.1666666666666665
#   __________yellows ratio: 1.8333333333333333
#   __________cards ratio: 1.8333333333333333
#   __________goals ratio: 1.3333333333333333
#   __________half ratio: 0.5
#   __________second ratio: 0.8333333333333334
#   __________corners ratio: 7.666666666666667
#   __________yellows ratio: 2.6666666666666665
#   __________cards ratio: 3.0
#
#   ________[73/368]  2022-10-01 14:00:00 #868026  39 - 2022 [35 vs 55]
#   __________goals ratio: 0.8571428571428571
#   __________half ratio: 0.14285714285714285
#   __________second ratio: 0.7142857142857143
#   __________corners ratio: 2.7142857142857144
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.0
#   __________goals ratio: 2.142857142857143
#   __________half ratio: 1.0
#   __________second ratio: 1.1428571428571428
#   __________corners ratio: 5.142857142857143
#   __________yellows ratio: 1.1428571428571428
#   __________cards ratio: 1.1428571428571428
#
#   ________[74/368]  2022-10-01 16:30:00 #868035  39 - 2022 [48 vs 39]
#   __________goals ratio: 0.42857142857142855
#   __________half ratio: 0.0
#   __________second ratio: 0.42857142857142855
#   __________corners ratio: 5.0
#   __________yellows ratio: 1.1428571428571428
#   __________cards ratio: 1.1428571428571428
#   __________goals ratio: 0.42857142857142855
#   __________half ratio: 0.42857142857142855
#   __________second ratio: 0.0
#   __________corners ratio: 4.857142857142857
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.142857142857143
#
#   ________[75/368]  2022-10-02 13:00:00 #868033  39 - 2022 [50 vs 33]
#   __________goals ratio: 3.2857142857142856
#   __________half ratio: 1.4285714285714286
#   __________second ratio: 1.8571428571428572
#   __________corners ratio: 6.714285714285714
#   __________yellows ratio: 0.7142857142857143
#   __________cards ratio: 0.7142857142857143
#   __________goals ratio: 1.3333333333333333
#   __________half ratio: 0.5
#   __________second ratio: 0.8333333333333334
#   __________corners ratio: 3.6666666666666665
#   __________yellows ratio: 3.3333333333333335
#   __________cards ratio: 3.3333333333333335
#
#   ________[76/368]  2022-10-02 15:30:00 #868030  39 - 2022 [63 vs 66]
#   __________goals ratio: 1.6666666666666667
#   __________half ratio: 0.6666666666666666
#   __________second ratio: 1.0
#   __________corners ratio: 5.666666666666667
#   __________yellows ratio: 2.1666666666666665
#   __________cards ratio: 2.1666666666666665
#   __________goals ratio: 0.8571428571428571
#   __________half ratio: 0.42857142857142855
#   __________second ratio: 0.42857142857142855
#   __________corners ratio: 3.5714285714285716
#   __________yellows ratio: 2.5714285714285716
#   __________cards ratio: 2.5714285714285716
#
#   ________[77/368]  2022-10-03 19:00:00 #868031  39 - 2022 [46 vs 65]
#   __________goals ratio: 1.4285714285714286
#   __________half ratio: 0.7142857142857143
#   __________second ratio: 0.7142857142857143
#   __________corners ratio: 3.2857142857142856
#   __________yellows ratio: 1.2857142857142858
#   __________cards ratio: 1.2857142857142858
#   __________goals ratio: 0.8571428571428571
#   __________half ratio: 0.5714285714285714
#   __________second ratio: 0.2857142857142857
#   __________corners ratio: 3.142857142857143
#   __________yellows ratio: 2.857142857142857
#   __________cards ratio: 2.857142857142857
#
#   ________[78/368]  2022-10-08 14:00:00 #868043  39 - 2022 [34 vs 55]
#   __________goals ratio: 1.5
#   __________half ratio: 0.75
#   __________second ratio: 0.75
#   __________corners ratio: 7.625
#   __________yellows ratio: 1.75
#   __________cards ratio: 1.75
#   __________goals ratio: 1.875
#   __________half ratio: 0.875
#   __________second ratio: 1.0
#   __________corners ratio: 5.5
#   __________yellows ratio: 1.25
#   __________cards ratio: 1.25
#
#   ________[79/368]  2022-10-08 14:00:00 #868042  39 - 2022 [50 vs 41]
#   __________goals ratio: 3.625
#   __________half ratio: 1.75
#   __________second ratio: 1.875
#   __________corners ratio: 6.5
#   __________yellows ratio: 0.625
#   __________cards ratio: 0.625
#   __________goals ratio: 1.0
#   __________half ratio: 0.375
#   __________second ratio: 0.625
#   __________corners ratio: 4.375
#   __________yellows ratio: 1.375
#   __________cards ratio: 1.375
#
#   ________[80/368]  2022-10-08 14:00:00 #868039  39 - 2022 [49 vs 39]
#   __________goals ratio: 1.4285714285714286
#   __________half ratio: 0.5714285714285714
#   __________second ratio: 0.8571428571428571
#   __________corners ratio: 6.857142857142857
#   __________yellows ratio: 2.7142857142857144
#   __________cards ratio: 3.0
#   __________goals ratio: 0.375
#   __________half ratio: 0.375
#   __________second ratio: 0.0
#   __________corners ratio: 5.0
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.125
#
#   ________[81/368]  2022-10-08 14:00:00 #868036  39 - 2022 [35 vs 46]
#   __________goals ratio: 0.75
#   __________half ratio: 0.125
#   __________second ratio: 0.625
#   __________corners ratio: 3.25
#   __________yellows ratio: 1.875
#   __________cards ratio: 1.875
#   __________goals ratio: 1.75
#   __________half ratio: 1.0
#   __________second ratio: 0.75
#   __________corners ratio: 3.625
#   __________yellows ratio: 1.375
#   __________cards ratio: 1.375
#
#   ________[82/368]  2022-10-08 16:30:00 #868038  39 - 2022 [51 vs 47]
#   __________goals ratio: 2.0
#   __________half ratio: 1.0
#   __________second ratio: 1.0
#   __________corners ratio: 4.714285714285714
#   __________yellows ratio: 1.1428571428571428
#   __________cards ratio: 1.1428571428571428
#   __________goals ratio: 2.375
#   __________half ratio: 1.0
#   __________second ratio: 1.375
#   __________corners ratio: 5.75
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.125
#
#   ________[83/368]  2022-10-09 13:00:00 #868045  39 - 2022 [48 vs 36]
#   __________goals ratio: 0.625
#   __________half ratio: 0.125
#   __________second ratio: 0.5
#   __________corners ratio: 4.5
#   __________yellows ratio: 1.25
#   __________cards ratio: 1.25
#   __________goals ratio: 1.625
#   __________half ratio: 0.375
#   __________second ratio: 1.25
#   __________corners ratio: 4.0
#   __________yellows ratio: 2.875
#   __________cards ratio: 3.0
#
#   ________[84/368]  2022-10-09 13:00:00 #868040  39 - 2022 [52 vs 63]
#   __________goals ratio: 1.1428571428571428
#   __________half ratio: 0.7142857142857143
#   __________second ratio: 0.42857142857142855
#   __________corners ratio: 3.4285714285714284
#   __________yellows ratio: 1.7142857142857142
#   __________cards ratio: 1.7142857142857142
#   __________goals ratio: 1.4285714285714286
#   __________half ratio: 0.5714285714285714
#   __________second ratio: 0.8571428571428571
#   __________corners ratio: 5.142857142857143
#   __________yellows ratio: 2.5714285714285716
#   __________cards ratio: 2.7142857142857144
#
#   ________[85/368]  2022-10-09 15:30:00 #868037  39 - 2022 [42 vs 40]
#   __________goals ratio: 2.5
#   __________half ratio: 1.125
#   __________second ratio: 1.375
#   __________corners ratio: 5.875
#   __________yellows ratio: 1.875
#   __________cards ratio: 1.875
#   __________goals ratio: 2.5714285714285716
#   __________half ratio: 0.8571428571428571
#   __________second ratio: 1.7142857142857142
#   __________corners ratio: 7.857142857142857
#   __________yellows ratio: 0.8571428571428571
#   __________cards ratio: 1.0
#
#   ________[86/368]  2022-10-09 18:00:00 #868041  39 - 2022 [45 vs 33]
#   __________goals ratio: 0.875
#   __________half ratio: 0.25
#   __________second ratio: 0.625
#   __________corners ratio: 5.375
#   __________yellows ratio: 2.375
#   __________cards ratio: 2.375
#   __________goals ratio: 1.5714285714285714
#   __________half ratio: 0.42857142857142855
#   __________second ratio: 1.1428571428571428
#   __________corners ratio: 3.2857142857142856
#   __________yellows ratio: 3.2857142857142856
#   __________cards ratio: 3.2857142857142856
#
#   ________[87/368]  2022-10-10 19:00:00 #868044  39 - 2022 [65 vs 66]
#   __________goals ratio: 0.75
#   __________half ratio: 0.5
#   __________second ratio: 0.25
#   __________corners ratio: 3.5
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#   __________goals ratio: 0.75
#   __________half ratio: 0.375
#   __________second ratio: 0.375
#   __________corners ratio: 4.25
#   __________yellows ratio: 2.5
#   __________cards ratio: 2.5
#
#   ________[88/368]  2022-10-14 19:00:00 #868047  39 - 2022 [55 vs 51]
#   __________goals ratio: 1.7777777777777777
#   __________half ratio: 0.7777777777777778
#   __________second ratio: 1.0
#   __________corners ratio: 5.444444444444445
#   __________yellows ratio: 1.2222222222222223
#   __________cards ratio: 1.2222222222222223
#   __________goals ratio: 1.75
#   __________half ratio: 0.875
#   __________second ratio: 0.875
#   __________corners ratio: 4.875
#   __________yellows ratio: 1.125
#   __________cards ratio: 1.125
#
#   ________[89/368]  2022-10-15 11:30:00 #868050  39 - 2022 [46 vs 52]
#   __________goals ratio: 1.6666666666666667
#   __________half ratio: 1.0
#   __________second ratio: 0.6666666666666666
#   __________corners ratio: 3.4444444444444446
#   __________yellows ratio: 1.4444444444444444
#   __________cards ratio: 1.4444444444444444
#   __________goals ratio: 1.25
#   __________half ratio: 0.75
#   __________second ratio: 0.5
#   __________corners ratio: 3.625
#   __________yellows ratio: 1.875
#   __________cards ratio: 1.875
#
#   ________[90/368]  2022-10-15 14:00:00 #868048  39 - 2022 [36 vs 35]
#   __________goals ratio: 1.5555555555555556
#   __________half ratio: 0.4444444444444444
#   __________second ratio: 1.1111111111111112
#   __________corners ratio: 3.7777777777777777
#   __________yellows ratio: 2.888888888888889
#   __________cards ratio: 3.0
#   __________goals ratio: 0.8888888888888888
#   __________half ratio: 0.1111111111111111
#   __________second ratio: 0.7777777777777778
#   __________corners ratio: 3.6666666666666665
#   __________yellows ratio: 1.7777777777777777
#   __________cards ratio: 1.7777777777777777
#
#   ________[91/368]  2022-10-15 14:00:00 #868055  39 - 2022 [39 vs 65]
#   __________goals ratio: 0.3333333333333333
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 0.0
#   __________corners ratio: 4.666666666666667
#   __________yellows ratio: 1.7777777777777777
#   __________cards ratio: 1.8888888888888888
#   __________goals ratio: 0.7777777777777778
#   __________half ratio: 0.5555555555555556
#   __________second ratio: 0.2222222222222222
#   __________corners ratio: 3.2222222222222223
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#
#   ________[92/368]  2022-10-15 16:30:00 #868054  39 - 2022 [47 vs 45]
#   __________goals ratio: 2.2222222222222223
#   __________half ratio: 1.0
#   __________second ratio: 1.2222222222222223
#   __________corners ratio: 5.333333333333333
#   __________yellows ratio: 2.0
#   __________cards ratio: 2.111111111111111
#   __________goals ratio: 0.8888888888888888
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 0.5555555555555556
#   __________corners ratio: 5.333333333333333
#   __________yellows ratio: 2.3333333333333335
#   __________cards ratio: 2.3333333333333335
#
#   ________[93/368]  2022-10-16 13:00:00 #868053  39 - 2022 [41 vs 48]
#   __________goals ratio: 0.8888888888888888
#   __________half ratio: 0.3333333333333333
#   __________second ratio: 0.5555555555555556
#   __________corners ratio: 4.0
#   __________yellows ratio: 1.3333333333333333
#   __________cards ratio: 1.3333333333333333
#   __________goals ratio: 0.8888888888888888
#   __________half ratio: 0.2222222222222222
#   __________second ratio: 0.6666666666666666
#   __________corners ratio: 4.444444444444445
#   __________yellows ratio: 1.2222222222222223
#   __________cards ratio: 1.2222222222222223
#
#   ________[94/368]  2022-10-16 13:00:00 #868052  39 - 2022 [33 vs 34]
#   __________goals ratio: 1.625
#   __________half ratio: 0.625
#   __________second ratio: 1.0
#   __________corners ratio: 3.375
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#   __________goals ratio: 1.8888888888888888
#   __________half ratio: 0.8888888888888888
#   __________second ratio: 1.0
#   __________corners ratio: 7.777777777777778
#   __________yellows ratio: 1.5555555555555556
#   __________cards ratio: 1.5555555555555556
#
#   ________[95/368]  2022-10-16 13:00:00 #868049  39 - 2022 [63 vs 42]
#   __________goals ratio: 1.375
#   __________half ratio: 0.625
#   __________second ratio: 0.75
#   __________corners ratio: 4.875
#   __________yellows ratio: 2.625
#   __________cards ratio: 2.75
#   __________goals ratio: 2.5555555555555554
#   __________half ratio: 1.2222222222222223
#   __________second ratio: 1.3333333333333333
#   __________corners ratio: 5.666666666666667
#   __________yellows ratio: 1.7777777777777777
#   __________cards ratio: 1.7777777777777777
#
#   ________[96/368]  2022-10-16 13:00:00 #868046  39 - 2022 [66 vs 49]
#   __________goals ratio: 0.7777777777777778
#   __________half ratio: 0.4444444444444444
#   __________second ratio: 0.3333333333333333
#   __________corners ratio: 4.222222222222222
#   __________yellows ratio: 2.5555555555555554
#   __________cards ratio: 2.5555555555555554
#   __________goals ratio: 1.625
#   __________half ratio: 0.625
#   __________second ratio: 1.0
#   __________corners ratio: 6.5
#   __________yellows ratio: 2.625
#   __________cards ratio: 2.875
#
#   ________[97/368]  2022-10-16 15:30:00 #868051  39 - 2022 [40 vs 50]
#   __________goals ratio: 2.5
#   __________half ratio: 0.875
#   __________second ratio: 1.625
#   __________corners ratio: 7.25
#   __________yellows ratio: 1.0
#   __________cards ratio: 1.125
#   __________goals ratio: 3.6666666666666665
#   __________half ratio: 1.7777777777777777
#   __________second ratio: 1.8888888888888888
#   __________corners ratio: 6.777777777777778
#   __________yellows ratio: 0.5555555555555556
#   __________cards ratio: 0.5555555555555556
#
#   ________[98/368]  2022-10-18 18:30:00 #868059  39 - 2022 [51 vs 65]
#   __________goals ratio: 1.5555555555555556
#   __________half ratio: 0.7777777777777778
#   __________second ratio: 0.7777777777777778
#   __________corners ratio: 5.555555555555555
#   __________yellows ratio: 1.1111111111111112
#   __________cards ratio: 1.1111111111111112
#   __________goals ratio: 0.7
#   __________half ratio: 0.5
#   __________second ratio: 0.2
#   __________corners ratio: 3.4
#   __________yellows ratio: 2.9
#   __________cards ratio: 2.9
#
#   ________[99/368]  2022-10-18 19:15:00 #868062  39 - 2022 [52 vs 39]
#   __________goals ratio: 1.1111111111111112
#   __________half ratio: 0.6666666666666666
#   __________second ratio: 0.4444444444444444
#   __________corners ratio: 3.4444444444444446
#   __________yellows ratio: 1.8888888888888888
#   __________cards ratio: 1.8888888888888888
#   __________goals ratio: 0.4
#   __________half ratio: 0.3
#   __________second ratio: 0.1
#   __________corners ratio: 4.6
#   __________yellows ratio: 1.8
#   __________cards ratio: 1.9
#
#   ________[100/368]  2022-10-19 18:30:00 #868064  39 - 2022 [40 vs 48]
#   __________goals ratio: 2.3333333333333335
#   __________half ratio: 0.7777777777777778
#   __________second ratio: 1.5555555555555556
#   __________corners ratio: 7.0
#   __________yellows ratio: 1.2222222222222223
#   __________cards ratio: 1.3333333333333333
#   __________goals ratio: 0.9
#   __________half ratio: 0.2
#   __________second ratio: 0.7
#   __________corners ratio: 5.4
#   __________yellows ratio: 1.2
#   __________cards ratio: 1.2
#
#   ________[101/368]  2022-10-19 18:30:00 #868063  39 - 2022 [34 vs 45]
#   __________goals ratio: 1.7
#   __________half ratio: 0.8
#   __________second ratio: 0.9
#   __________corners ratio: 7.4
#   __________yellows ratio: 1.5
#   __________cards ratio: 1.5
#   __________goals ratio: 0.8
#   __________half ratio: 0.3
#   __________second ratio: 0.5
#   __________corners ratio: 4.9
#   __________yellows ratio: 2.5
#   __________cards ratio: 2.5
#
#   ________[102/368]  2022-10-19 18:30:00 #868058  39 - 2022 [55 vs 49]
#   __________goals ratio: 1.8
#   __________half ratio: 0.8
#   __________second ratio: 1.0
#   __________corners ratio: 5.1
#   __________yellows ratio: 1.4
#   __________cards ratio: 1.4
#   __________goals ratio: 1.6666666666666667
#   __________half ratio: 0.6666666666666666
#   __________second ratio: 1.0
#   __________corners ratio: 5.888888888888889
#   __________yellows ratio: 2.6666666666666665
#   __________cards ratio: 2.888888888888889
#
#   ________[103/368]  2022-10-19 18:30:00 #868056  39 - 2022 [35 vs 41]
#   __________goals ratio: 1.0
#   __________half ratio: 0.3
#   __________second ratio: 0.7
#   __________corners ratio: 3.9
#   __________yellows ratio: 1.6
#   __________cards ratio: 1.6
#   __________goals ratio: 0.9
#   __________half ratio: 0.4
#   __________second ratio: 0.5
#   __________corners ratio: 4.0
#   __________yellows ratio: 1.3
#   __________cards ratio: 1.3
#
#   ________[104/368]  2022-10-19 19:15:00 #868065  39 - 2022 [33 vs 47]
#   __________goals ratio: 1.4444444444444444
#   __________half ratio: 0.5555555555555556
#   __________second ratio: 0.8888888888888888
#   __________corners ratio: 3.4444444444444446
#   __________yellows ratio: 3.0
#   __________cards ratio: 3.0
#   __________goals ratio: 2.2
#   __________half ratio: 0.9
#   __________second ratio: 1.3
#   __________corners ratio: 5.5
#   __________yellows ratio: 1.9
#   __________cards ratio: 2.0
#
#   ________[105/368]  2022-10-20 18:30:00 #868060  39 - 2022 [36 vs 66]
#   __________goals ratio: 1.6
#   __________half ratio: 0.5
#   __________second ratio: 1.1
#   __________corners ratio: 3.9
#   __________yellows ratio: 2.8
#   __________cards ratio: 2.9
#   __________goals ratio: 0.7
#   __________half ratio: 0.4
#   __________second ratio: 0.3
#   __________corners ratio: 4.5
#   __________yellows ratio: 2.3
#   __________cards ratio: 2.3
#
# ...
#   __________corners ratio: 5.575757575757576
#   __________yellows ratio: 2.1818181818181817
#   __________cards ratio: 2.272727272727273
#
#   ________[342/368]  2023-05-06 16:30:00 #868289  39 - 2022 [40 vs 55]
#   __________goals ratio: 1.9411764705882353
#   __________half ratio: 0.9117647058823529
#   __________second ratio: 1.0294117647058822
#   __________corners ratio: 6.0588235294117645
#   __________yellows ratio: 1.3823529411764706
#   __________cards ratio: 1.411764705882353
#   __________goals ratio: 1.5294117647058822
#   __________half ratio: 0.7352941176470589
#   __________second ratio: 0.7941176470588235
#   __________corners ratio: 4.352941176470588
#   __________yellows ratio: 1.4411764705882353
#   __________cards ratio: 1.4705882352941178
#
#   ________[343/368]  2023-05-07 15:30:00 #868291  39 - 2022 [34 vs 42]
#   __________goals ratio: 1.8484848484848484
#   __________half ratio: 0.8484848484848485
#   __________second ratio: 1.0
#   __________corners ratio: 7.090909090909091
#   __________yellows ratio: 1.606060606060606
#   __________cards ratio: 1.6363636363636365
#   __________goals ratio: 2.3823529411764706
#   __________half ratio: 1.088235294117647
#   __________second ratio: 1.2941176470588236
#   __________corners ratio: 5.882352941176471
#   __________yellows ratio: 1.3823529411764706
#   __________cards ratio: 1.3823529411764706
#
#   ________[344/368]  2023-05-07 18:00:00 #868294  39 - 2022 [48 vs 33]
#   __________goals ratio: 1.088235294117647
#   __________half ratio: 0.6176470588235294
#   __________second ratio: 0.47058823529411764
#   __________corners ratio: 5.352941176470588
#   __________yellows ratio: 1.2352941176470589
#   __________cards ratio: 1.2352941176470589
#   __________goals ratio: 1.4848484848484849
#   __________half ratio: 0.6363636363636364
#   __________second ratio: 0.8484848484848485
#   __________corners ratio: 4.96969696969697
#   __________yellows ratio: 2.1515151515151514
#   __________cards ratio: 2.212121212121212
#
#   ________[345/368]  2023-05-08 14:00:00 #868288  39 - 2022 [36 vs 46]
#   __________goals ratio: 1.3235294117647058
#   __________half ratio: 0.5
#   __________second ratio: 0.8235294117647058
#   __________corners ratio: 4.735294117647059
#   __________yellows ratio: 2.2058823529411766
#   __________cards ratio: 2.235294117647059
#   __________goals ratio: 1.3529411764705883
#   __________half ratio: 0.8235294117647058
#   __________second ratio: 0.5294117647058824
#   __________corners ratio: 3.5294117647058822
#   __________yellows ratio: 1.6764705882352942
#   __________cards ratio: 1.7352941176470589
#
#   ________[346/368]  2023-05-08 16:30:00 #868287  39 - 2022 [51 vs 45]
#   __________goals ratio: 1.9375
#   __________half ratio: 0.9375
#   __________second ratio: 1.0
#   __________corners ratio: 6.34375
#   __________yellows ratio: 1.375
#   __________cards ratio: 1.375
#   __________goals ratio: 0.7941176470588235
#   __________half ratio: 0.3235294117647059
#   __________second ratio: 0.47058823529411764
#   __________corners ratio: 4.411764705882353
#   __________yellows ratio: 2.1470588235294117
#   __________cards ratio: 2.2058823529411766
#
#   ________[347/368]  2023-05-08 19:00:00 #868292  39 - 2022 [65 vs 41]
#   __________goals ratio: 0.8823529411764706
#   __________half ratio: 0.4117647058823529
#   __________second ratio: 0.47058823529411764
#   __________corners ratio: 3.3529411764705883
#   __________yellows ratio: 2.264705882352941
#   __________cards ratio: 2.264705882352941
#   __________goals ratio: 0.8235294117647058
#   __________half ratio: 0.35294117647058826
#   __________second ratio: 0.47058823529411764
#   __________corners ratio: 4.117647058823529
#   __________yellows ratio: 1.9411764705882353
#   __________cards ratio: 1.9411764705882353
#
#   ________[348/368]  2023-05-13 11:30:00 #868302  39 - 2022 [63 vs 34]
#   __________goals ratio: 1.2571428571428571
#   __________half ratio: 0.5428571428571428
#   __________second ratio: 0.7142857142857143
#   __________corners ratio: 5.142857142857143
#   __________yellows ratio: 2.257142857142857
#   __________cards ratio: 2.3142857142857145
#   __________goals ratio: 1.7941176470588236
#   __________half ratio: 0.8235294117647058
#   __________second ratio: 0.9705882352941176
#   __________corners ratio: 7.147058823529412
#   __________yellows ratio: 1.6176470588235294
#   __________cards ratio: 1.6470588235294117
#
#   ________[349/368]  2023-05-13 14:00:00 #868305  39 - 2022 [41 vs 36]
#   __________goals ratio: 0.8857142857142857
#   __________half ratio: 0.37142857142857144
#   __________second ratio: 0.5142857142857142
#   __________corners ratio: 4.314285714285714
#   __________yellows ratio: 1.8857142857142857
#   __________cards ratio: 1.8857142857142857
#   __________goals ratio: 1.4285714285714286
#   __________half ratio: 0.5714285714285714
#   __________second ratio: 0.8571428571428571
#   __________corners ratio: 4.6571428571428575
#   __________yellows ratio: 2.142857142857143
#   __________cards ratio: 2.1714285714285713
#
#   ________[350/368]  2023-05-13 14:00:00 #868304  39 - 2022 [33 vs 39]
#   __________goals ratio: 1.4411764705882353
#   __________half ratio: 0.6176470588235294
#   __________second ratio: 0.8235294117647058
#   __________corners ratio: 5.0
#   __________yellows ratio: 2.1470588235294117
#   __________cards ratio: 2.2058823529411766
#   __________goals ratio: 0.8571428571428571
#   __________half ratio: 0.45714285714285713
#   __________second ratio: 0.4
#   __________corners ratio: 4.942857142857143
#   __________yellows ratio: 2.2285714285714286
#   __________cards ratio: 2.4
#
#   ________[351/368]  2023-05-13 14:00:00 #868300  39 - 2022 [52 vs 35]
#   __________goals ratio: 1.0
#   __________half ratio: 0.4
#   __________second ratio: 0.6
#   __________corners ratio: 4.742857142857143
#   __________yellows ratio: 2.342857142857143
#   __________cards ratio: 2.4285714285714284
#   __________goals ratio: 1.0571428571428572
#   __________half ratio: 0.4857142857142857
#   __________second ratio: 0.5714285714285714
#   __________corners ratio: 3.8857142857142857
#   __________yellows ratio: 1.7714285714285714
#   __________cards ratio: 1.7714285714285714
#
#   ________[352/368]  2023-05-13 14:00:00 #868299  39 - 2022 [49 vs 65]
#   __________goals ratio: 1.0
#   __________half ratio: 0.4117647058823529
#   __________second ratio: 0.5882352941176471
#   __________corners ratio: 5.617647058823529
#   __________yellows ratio: 2.2058823529411766
#   __________cards ratio: 2.2941176470588234
#   __________goals ratio: 0.9714285714285714
#   __________half ratio: 0.4857142857142857
#   __________second ratio: 0.4857142857142857
#   __________corners ratio: 3.3142857142857145
#   __________yellows ratio: 2.2285714285714286
#   __________cards ratio: 2.2285714285714286
#
#   ________[353/368]  2023-05-13 14:00:00 #868297  39 - 2022 [66 vs 47]
#   __________goals ratio: 1.3142857142857143
#   __________half ratio: 0.6285714285714286
#   __________second ratio: 0.6857142857142857
#   __________corners ratio: 4.257142857142857
#   __________yellows ratio: 1.9428571428571428
#   __________cards ratio: 1.9714285714285715
#   __________goals ratio: 1.8285714285714285
#   __________half ratio: 0.6285714285714286
#   __________second ratio: 1.2
#   __________corners ratio: 5.4
#   __________yellows ratio: 2.085714285714286
#   __________cards ratio: 2.1714285714285713
#
#   ________[354/368]  2023-05-14 13:00:00 #868298  39 - 2022 [55 vs 48]
#   __________goals ratio: 1.4857142857142858
#   __________half ratio: 0.7142857142857143
#   __________second ratio: 0.7714285714285715
#   __________corners ratio: 4.314285714285714
#   __________yellows ratio: 1.457142857142857
#   __________cards ratio: 1.4857142857142858
#   __________goals ratio: 1.0857142857142856
#   __________half ratio: 0.6285714285714286
#   __________second ratio: 0.45714285714285713
#   __________corners ratio: 5.371428571428571
#   __________yellows ratio: 1.2
#   __________cards ratio: 1.2
#
#   ________[355/368]  2023-05-14 13:00:00 #868301  39 - 2022 [45 vs 50]
#   __________goals ratio: 0.9142857142857143
#   __________half ratio: 0.4
#   __________second ratio: 0.5142857142857142
#   __________corners ratio: 4.314285714285714
#   __________yellows ratio: 2.2285714285714286
#   __________cards ratio: 2.2857142857142856
#   __________goals ratio: 2.6176470588235294
#   __________half ratio: 1.2647058823529411
#   __________second ratio: 1.3529411764705883
#   __________corners ratio: 6.529411764705882
#   __________yellows ratio: 1.2647058823529411
#   __________cards ratio: 1.2941176470588236
#
#   ________[356/368]  2023-05-14 15:30:00 #868296  39 - 2022 [42 vs 51]
#   __________goals ratio: 2.3714285714285714
#   __________half ratio: 1.0857142857142856
#   __________second ratio: 1.2857142857142858
#   __________corners ratio: 5.828571428571428
#   __________yellows ratio: 1.3714285714285714
#   __________cards ratio: 1.3714285714285714
#   __________goals ratio: 1.9090909090909092
#   __________half ratio: 0.9090909090909091
#   __________second ratio: 1.0
#   __________corners ratio: 6.606060606060606
#   __________yellows ratio: 1.3636363636363635
#   __________cards ratio: 1.3636363636363635
#
#   ________[357/368]  2023-05-15 19:00:00 #868303  39 - 2022 [46 vs 40]
#   __________goals ratio: 1.4
#   __________half ratio: 0.8
#   __________second ratio: 0.6
#   __________corners ratio: 3.6285714285714286
#   __________yellows ratio: 1.7142857142857142
#   __________cards ratio: 1.7714285714285714
#   __________goals ratio: 1.9142857142857144
#   __________half ratio: 0.9142857142857143
#   __________second ratio: 1.0
#   __________corners ratio: 6.085714285714285
#   __________yellows ratio: 1.457142857142857
#   __________cards ratio: 1.4857142857142858
#
#   ________[358/368]  2023-05-18 18:30:00 #868193  39 - 2022 [34 vs 51]
#   __________goals ratio: 1.8
#   __________half ratio: 0.8285714285714286
#   __________second ratio: 0.9714285714285714
#   __________corners ratio: 7.114285714285714
#   __________yellows ratio: 1.6285714285714286
#   __________cards ratio: 1.6571428571428573
#   __________goals ratio: 1.9411764705882353
#   __________half ratio: 0.8823529411764706
#   __________second ratio: 1.0588235294117647
#   __________corners ratio: 6.470588235294118
#   __________yellows ratio: 1.3823529411764706
#   __________cards ratio: 1.3823529411764706
#
#   ________[359/368]  2023-05-20 11:30:00 #868313  39 - 2022 [47 vs 55]
#   __________goals ratio: 1.8055555555555556
#   __________half ratio: 0.6111111111111112
#   __________second ratio: 1.1944444444444444
#   __________corners ratio: 5.333333333333333
#   __________yellows ratio: 2.111111111111111
#   __________cards ratio: 2.1944444444444446
#   __________goals ratio: 1.5
#   __________half ratio: 0.75
#   __________second ratio: 0.75
#   __________corners ratio: 4.388888888888889
#   __________yellows ratio: 1.4444444444444444
#   __________cards ratio: 1.4722222222222223
#
#   ________[360/368]  2023-05-20 14:00:00 #868306  39 - 2022 [35 vs 33]
#   __________goals ratio: 1.0277777777777777
#   __________half ratio: 0.4722222222222222
#   __________second ratio: 0.5555555555555556
#   __________corners ratio: 3.8333333333333335
#   __________yellows ratio: 1.7777777777777777
#   __________cards ratio: 1.7777777777777777
#   __________goals ratio: 1.457142857142857
#   __________half ratio: 0.6285714285714286
#   __________second ratio: 0.8285714285714286
#   __________corners ratio: 5.171428571428572
#   __________yellows ratio: 2.1714285714285713
#   __________cards ratio: 2.2285714285714286
#
#   ________[361/368]  2023-05-20 14:00:00 #868308  39 - 2022 [36 vs 52]
#   __________goals ratio: 1.4444444444444444
#   __________half ratio: 0.5555555555555556
#   __________second ratio: 0.8888888888888888
#   __________corners ratio: 4.75
#   __________yellows ratio: 2.0833333333333335
#   __________cards ratio: 2.111111111111111
#   __________goals ratio: 1.0277777777777777
#   __________half ratio: 0.4166666666666667
#   __________second ratio: 0.6111111111111112
#   __________corners ratio: 4.916666666666667
#   __________yellows ratio: 2.2777777777777777
#   __________cards ratio: 2.361111111111111
#
#   ________[362/368]  2023-05-20 14:00:00 #868309  39 - 2022 [40 vs 66]
#   __________goals ratio: 1.9444444444444444
#   __________half ratio: 0.9444444444444444
#   __________second ratio: 1.0
#   __________corners ratio: 6.027777777777778
#   __________yellows ratio: 1.4444444444444444
#   __________cards ratio: 1.4722222222222223
#   __________goals ratio: 1.3333333333333333
#   __________half ratio: 0.6388888888888888
#   __________second ratio: 0.6944444444444444
#   __________corners ratio: 4.361111111111111
#   __________yellows ratio: 1.9722222222222223
#   __________cards ratio: 2.0
#
#   ________[363/368]  2023-05-20 14:00:00 #868315  39 - 2022 [39 vs 45]
#   __________goals ratio: 0.8333333333333334
#   __________half ratio: 0.4444444444444444
#   __________second ratio: 0.3888888888888889
#   __________corners ratio: 5.0
#   __________yellows ratio: 2.2222222222222223
#   __________cards ratio: 2.388888888888889
#   __________goals ratio: 0.8888888888888888
#   __________half ratio: 0.3888888888888889
#   __________second ratio: 0.5
#   __________corners ratio: 4.416666666666667
#   __________yellows ratio: 2.1944444444444446
#   __________cards ratio: 2.25
#
#   ________[364/368]  2023-05-20 16:30:00 #868312  39 - 2022 [65 vs 42]
#   __________goals ratio: 1.0
#   __________half ratio: 0.5
#   __________second ratio: 0.5
#   __________corners ratio: 3.361111111111111
#   __________yellows ratio: 2.1944444444444446
#   __________cards ratio: 2.1944444444444446
#   __________goals ratio: 2.3055555555555554
#   __________half ratio: 1.0555555555555556
#   __________second ratio: 1.25
#   __________corners ratio: 5.805555555555555
#   __________yellows ratio: 1.3611111111111112
#   __________cards ratio: 1.3611111111111112
#
#   ________[365/368]  2023-05-21 12:30:00 #868314  39 - 2022 [48 vs 63]
#   __________goals ratio: 1.0555555555555556
#   __________half ratio: 0.6111111111111112
#   __________second ratio: 0.4444444444444444
#   __________corners ratio: 5.361111111111111
#   __________yellows ratio: 1.1666666666666667
#   __________cards ratio: 1.1666666666666667
#   __________goals ratio: 1.2777777777777777
#   __________half ratio: 0.5555555555555556
#   __________second ratio: 0.7222222222222222
#   __________corners ratio: 5.055555555555555
#   __________yellows ratio: 2.3055555555555554
#   __________cards ratio: 2.388888888888889
#
#   ________[366/368]  2023-05-21 13:00:00 #868307  39 - 2022 [51 vs 41]
#   __________goals ratio: 1.9142857142857144
#   __________half ratio: 0.8571428571428571
#   __________second ratio: 1.0571428571428572
#   __________corners ratio: 6.314285714285714
#   __________yellows ratio: 1.457142857142857
#   __________cards ratio: 1.457142857142857
#   __________goals ratio: 0.8611111111111112
#   __________half ratio: 0.3611111111111111
#   __________second ratio: 0.5
#   __________corners ratio: 4.222222222222222
#   __________yellows ratio: 1.8888888888888888
#   __________cards ratio: 1.8888888888888888
#
#   ________[367/368]  2023-05-21 15:00:00 #868310  39 - 2022 [50 vs 49]
#   __________goals ratio: 2.6285714285714286
#   __________half ratio: 1.2857142857142858
#   __________second ratio: 1.3428571428571427
#   __________corners ratio: 6.514285714285714
#   __________yellows ratio: 1.2285714285714286
#   __________cards ratio: 1.2571428571428571
#   __________goals ratio: 1.0285714285714285
#   __________half ratio: 0.4
#   __________second ratio: 0.6285714285714286
#   __________corners ratio: 5.514285714285714
#   __________yellows ratio: 2.2285714285714286
#   __________cards ratio: 2.3142857142857145
#
#   ________[368/368]  2023-05-22 19:00:00 #868311  39 - 2022 [34 vs 46]
#   __________goals ratio: 1.8611111111111112
#   __________half ratio: 0.8611111111111112
#   __________second ratio: 1.0
#   __________corners ratio: 7.083333333333333
#   __________yellows ratio: 1.6388888888888888
#   __________cards ratio: 1.6666666666666667
#   __________goals ratio: 1.3611111111111112
#   __________half ratio: 0.7777777777777778
#   __________second ratio: 0.5833333333333334
#   __________corners ratio: 3.638888888888889
#   __________yellows ratio: 1.7222222222222223
#   __________cards ratio: 1.7777777777777777
#
# # -------------------------------------------------- End at 2023-05-24 13:31:00
