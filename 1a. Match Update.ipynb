# %%
# 1. query Not started but 1-7 Days
    # check detailed data on leagues by id

# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    day0         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_check_updates(day0, day1, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 22:21:47
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 7
#   ________today_raw : 2023-05-22 22:21:47.781351
#   ______get_today_subs()
#   ________subs date_diff : 1
#   ________today_raw : 2023-05-28 22:21:47.781351
#   ______fO_check_updates()
#   ________Select  date as date  , leagueapi_id as lg  , season as ss  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_homeapi_id) as home  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_awayapi_id) as away  , SUBSTR(fixture_status, 1, 15)  as fs  , end_response as pr  , end_ah_pattern as ah  , end_gou_pattern as gou  from football_odds  where date >= '2023-05-22'  and date <= '2023-05-28'  and fixture_status not in ('Match Finished', 'Match Finished Ended' )  and deleted_at is null  order by  date, leagueapi_id asc
#   ________Total Row(s) : 67
#
# ...

# %%
# Import
from a_settings.messages import *  
from a_models.football_odds import *  

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------  
    # -------------------------------------------------- 
    today = datetime.datetime.now() 
    todayx = today.strftime("%Y-%m-%d") 
    
    DD = datetime.timedelta(days=7)
    week = today - DD
    day1 = week.strftime("%Y-%m-%d") 

    DD = datetime.timedelta(days=1)
    yesterday = today - DD
    day2 = yesterday.strftime("%Y-%m-%d") 
    
    pre_tw = datetime.timedelta(days=7)
    one_week_later =  today + pre_tw 
    
    aft_tw = datetime.timedelta(days=14)
    two_weeks_before = today - aft_tw
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day1 : " +  str(day1) )
    print(space + "> day2 : " + str(day2) ) 
    print(space + "> today : " + str(todayx) ) 
    # --------------------------------------------------   
    fO_get_league_group_fixture_status_not_in_match_finished(day1, day2, todayx, space)
    # --------------------------------------------------
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 08:45:09
#   __main()
#   ____get_date()
#   ______> day1 : 2023-05-22
#   ______> day2 : 2023-05-28
#   ______> today : 2023-05-29
#   ________fO_get_league_group_fixture_status_not_in_match_finished()
#   ________ Select  leagueapi_id  , season   from football_odds  where date <= '2023-05-28'  and date >= '2023-05-22'  and deleted_at is null  and fixture_status not in ('Match Finished', 'Match Finished Ended' )  group by leagueapi_id, season  order by date, leagueapi_id asc
#   ________Total Row(s) : 92
#   ________[1/92]  #247 - 2023
#   __________af_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API herlambangharyo@live.com counter is 99
#   ______________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________af_response_fixtures()
#   ______________ROUTES : leagueapi_id
# ...

# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    day0         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_check_updates(day0, day1, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 09:55:29
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 7
#   ________today_raw : 2023-05-22 09:55:29.083903
#   ______get_today_subs()
#   ________subs date_diff : 1
#   ________today_raw : 2023-05-28 09:55:29.085995
#   ______fO_check_updates()
#   ________Select  leagueapi_id as lg  , season as ss  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_homeapi_id) as home  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_awayapi_id) as away  , SUBSTR(fixture_status, 1, 15)  as fs  , end_response as pr  , end_ah_pattern as ah  , end_gou_pattern as gou  from football_odds  where date >= '2023-05-22'  and date <= '2023-05-28'  and fixture_status not in ('Match Finished', 'Match Finished Ended' )  and deleted_at is null  order by leagueapi_id, date asc
#   ________Total Row(s) : 69
#
# ...

# %%
# Import
from a_settings.messages import *  
from a_models.football_statistics import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------    
    fS_get_fixture_that_not_update_stats_all_league(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-06-06 23:57:04
#   __main()
#   ____fS_get_fixture_that_not_update_stats_all_league()
#   ____ SELECT   fixtureapi_id  , leagueapi_id  , season FROM football_statistics WHERE leagueapi_id IN (select leagueapi_id from football_leagues where detail_stats = 1)  and fixture_status in ('Match Finished', 'Match Finished Ended')  and shots_on_goal_home is null  and shots_on_goal_away is null  and season >= 2022
#   ____Total Row(s) : 5117
#   ____[1/5117] #816812 #253 - 2022
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API lincahlogistik@gmail.com counter is 58
#   __________APIkey: 405acb0deemsha32f06ee6179f6bp1cce74jsnf61631260341
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 816812
#   ____________Total API Response(s) : 1
# ...

# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    day0         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_check_updates(day0, day1, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
