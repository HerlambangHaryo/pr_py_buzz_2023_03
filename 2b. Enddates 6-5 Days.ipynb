# %%
# Import
from a_settings.messages import *  

today = datetime.datetime.now()  
days0 = 6
days1 = 5
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 6 - 5 --> 2023-03-22 02:47:31.426354

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-22 02:47:31
#   __main()
#   ____get_date()
#   ______days : 6
#   ______days : 5
#   ______tgl_awal : 2023-03-16
#   ______tgl_akhir : 2023-03-17
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-17'  and date >= '2023-03-16'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 8
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 27
#   ______________1. 2023-03-16 // 130 // 8 // 2023 // 979214 // None // None
#   ______________2. 2023-03-16 // 241 // 8 // 2023 // 1010862 // None // None
#   ______________3. 2023-03-16 // 255 // 11 // 2023 // 1008357 // 0#H // 25gG
#   ______________4. 2023-03-16 // 263 // 8 // 2022 // 975956 // 075_H // 25gG
#   ______________5. 2023-03-16 // 263 // 8 // 2022 // 975957 // 025+05+075+1+H // 25gG
#   ______________6. 2023-03-16 // 274 // 11 // 2022 // 899803 // 1_075_025_H // 175g2g225g25g275gG
#   ______________7. 2023-03-16 // 274 // 11 // 2022 // 899805 // 1_075_025_H // 225g25g275g3gG
#   ______________8. 2023-03-16 // 278 // 11 // 2023 // 997445 // 0#025+075+H // 225g25g275g3gG
#   ______________9. 2023-03-16 // 278 // 11 // 2023 // 997446 // 0#025+075+H // 225g25g275g3gG
#   ______________10. 2023-03-16 // 287 // 11 // 2022 // 869147 // 025+075+1+125+H // 225g25g275g3gG
#   ______________11. 2023-03-16 // 291 // 11 // 2022 // 998364 // None // None
#   ______________12. 2023-03-16 // 307 // 8 // 2022 // 976691 // 025_0#025+05+H // 25gG
#   ______________13. 2023-03-16 // 318 // 8 // 2022 // 1014329 // 075_05_025_H // 25gG
#   ______________14. 2023-03-16 // 329 // 11 // 2023 // 1001212 // 125+15+175+2+225+25+H // 25g275g3g325g35gG
#   ______________15. 2023-03-16 // 373 // 8 // 2022 // 876868 // 05_025_0#H // 25gG
#   ______________16. 2023-03-16 // 373 // 8 // 2022 // 876869 // 025_0#025+H // 25gG
#   ______________17. 2023-03-16 // 419 // 11 // 2022 // 923317 // H // G
#   ______________18. 2023-03-16 // 475 // 8 // 2023 // 1014793 // None // None
#   ______________19. 2023-03-16 // 496 // 11 // 2022 // 934831 // H // G
#   ______________20. 2023-03-16 // 496 // 11 // 2022 // 934832 // H // G
#   ______________21. 2023-03-16 // 703 // 11 // 2022 // 948532 // 075_025_0#H // 3g325g35g375g4g425gG
#   ______________22. 2023-03-16 // 740 // 11 // 2023 // 1010643 // None // None
#   ______________23. 2023-03-16 // 887 // 11 // 2022 // 964788 // H // G
#   ______________24. 2023-03-16 // 888 // 11 // 2022 // 965030 // H // G
#   ______________25. 2023-03-16 // 889 // 11 // 2022 // 965269 // 0#H // G
#   ______________26. 2023-03-16 // 943 // 8 // 2022 // 953103 // 05+075+1+H // G
#   ______________27. 2023-03-16 // 943 // 8 // 2022 // 953107 // 225_2_175_15_H // 25gG
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-03-16 // 241 // 8 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 16
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-16
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 241
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. Colombia,  Copa Colombia  #241 - 2023 / 1010864
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '2.25',
#   ____________________________end_match_winner_draw = '3.40',
#   ____________________________end_match_winner_away = '2.70',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '1.73',
#   ____________________________end_homeaway_away = '2.00',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '2.63',
#   ____________________________end_second_half_winner_draw = '2.38',
#   ____________________________end_second_half_winner_away = '3.25',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.73',
#   ____________________________end_asian_handicap_away_plus_0 = '2.08',
#   ____________________________end_asian_handicap_home_min_025 = '2.02',
#   ____________________________end_asian_handicap_away_min_025 = '1.77',
#   ____________________________end_asian_handicap_home_plus_025 = '1.55',
#   ____________________________end_asian_handicap_away_plus_025 = '2.38',
#   ____________________________end_asian_handicap_home_min_05 = '2.30',
#   ____________________________end_asian_handicap_away_min_05 = '1.60',
#   ____________________________end_asian_handicap_home_plus_05 = '1.43',
#   ____________________________end_asian_handicap_away_plus_05 = '2.75',
#   ____________________________end_asian_handicap_home_min_075 = '2.75',
#   ____________________________end_asian_handicap_away_min_075 = '1.43',
#   ____________________________end_asian_handicap_home_plus_075 = '1.30',
#   ____________________________end_asian_handicap_away_plus_075 = '3.45',
#   ____________________________end_asian_handicap_home_min_1 = '3.70',
#   ____________________________end_asian_handicap_away_min_1 = '1.26',
#   ____________________________end_asian_handicap_home_plus_1 = '1.16',
#   ____________________________end_asian_handicap_away_plus_1 = '5.25',
#   ____________________________end_asian_handicap_home_min_15 = '4.65',
#   ____________________________end_asian_handicap_away_min_15 = '1.18',
#   ____________________________end_asian_handicap_home_plus_15 = '1.11',
#   ____________________________end_asian_handicap_away_plus_15 = '6.40',
#   ____________________________end_asian_handicap_home_min_125 = '4.25',
#   ____________________________end_asian_handicap_away_min_125 = '1.21',
#   ____________________________end_asian_handicap_home_min_175 = '6.40',
#   ____________________________end_asian_handicap_away_min_175 = '1.11',
#   ____________________________end_asian_handicap_home_plus_125 = '1.13',
#   ____________________________end_asian_handicap_away_plus_125 = '5.90',
#   ____________________________end_asian_handicap_home_plus_175 = '1.10',
#   ____________________________end_asian_handicap_away_plus_175 = '7.00',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '4.00',
#   ____________________________end_goals_overunder_under_35 = '1.22',
#   ____________________________end_goals_overunder_over_15 = '1.40',
#   ____________________________end_goals_overunder_under_15 = '2.75',
#   ____________________________end_goals_overunder_over_45 = '9.00',
#   ____________________________end_goals_overunder_under_45 = '1.07',
#   ____________________________end_goals_overunder_over_25 = '2.20',
#   ____________________________end_goals_overunder_under_25 = '1.65',
#   ____________________________end_goals_overunder_over_05 = '1.06',
#   ____________________________end_goals_overunder_under_05 = '10.00',
#   ____________________________end_goals_overunder_over_55 = '19.00',
#   ____________________________end_goals_overunder_under_55 = '1.02',
#   ____________________________end_goals_overunder_over_225 = '1.95',
#   ____________________________end_goals_overunder_under_225 = '1.85',
#   ____________________________end_goals_overunder_over_325 = '3.70',
#   ____________________________end_goals_overunder_under_325 = '1.26',
#   ____________________________end_goals_overunder_over_275 = '2.60',
#   ____________________________end_goals_overunder_under_275 = '1.48',
#   ____________________________end_goals_overunder_over_125 = '1.25',
#   ____________________________end_goals_overunder_under_125 = '3.80',
#   ____________________________end_goals_overunder_over_175 = '1.50',
#   ____________________________end_goals_overunder_under_175 = '2.50',
#   ____________________________end_goals_overunder_over_375 = '5.25',
#   ____________________________end_goals_overunder_under_375 = '1.16',
#   ____________________________end_goals_overunder_over_65 = '41.00',
#   ____________________________end_goals_overunder_under_65 = '1.00',
#   ____________________________end_goals_overunder_over_30 = '3.30',
#   ____________________________end_goals_overunder_under_30 = '1.32',
#   ____________________________end_goals_overunder_over_20 = '1.65',
#   ____________________________end_goals_overunder_under_20 = '2.20',
#   ____________________________end_goals_overunder_over_40 = '7.00',
#   ____________________________end_goals_overunder_under_40 = '1.10',
#   ____________________________end_goals_overunder_over_10 = '1.10',
#   ____________________________end_goals_overunder_under_10 = '7.00',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '26.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.01',
#   ____________________________end_goals_overunder_first_half_over_15 = '3.25',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.33',
#   ____________________________end_goals_overunder_first_half_over_25 = '10.00',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.06',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.44',
#   ____________________________end_goals_overunder_first_half_under_05 = '2.63',
#   ____________________________end_goals_overunder_first_half_over_125 = '2.67',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.45',
#   ____________________________end_goals_overunder_first_half_over_175 = '4.40',
#   ____________________________end_goals_overunder_first_half_under_175 = '1.20',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.68',
#   ____________________________end_goals_overunder_first_half_under_075 = '2.15',
#   ____________________________end_goals_overunder_first_half_over_10 = '2.15',
#   ____________________________end_goals_overunder_first_half_under_10 = '1.68',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '15.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.03',
#   ____________________________end_goals_overunder__second_half_over_15 = '2.38',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.53',
#   ____________________________end_goals_overunder__second_half_over_25 = '5.50',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.14',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.29',
#   ____________________________end_goals_overunder__second_half_under_05 = '3.50',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________end_clean_sheet__home_yes = '2.75',
#   ____________________________end_clean_sheet__home_no = '1.40',
#   __________________________28 Clean Sheet - Away
#   ____________________________end_clean_sheet__away_yes = '3.25',
#   ____________________________end_clean_sheet__away_no = '1.33',
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '1.91',
#   ____________________________end_both_teams_score_no = '1.80',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 4.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.53
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.17
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.03
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 34.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 201.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 301.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.63
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 251.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 201.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.40',
#   ____________________________end_double_chance_home_away = '1.29',
#   ____________________________end_double_chance_draw_away = '1.53',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '3.10',
#   ____________________________end_first_half_winner_draw = '2.05',
#   ____________________________end_first_half_winner_away = '3.75',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 2.25
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 2.25
#   __________________________32 Win Both Halves
#   ____________________________end_win_both_halves_home = '8.00',
#   ____________________________end_win_both_halves_away = '13.00',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.13
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.36
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.08
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.36
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +2 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +2 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.05
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 201.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +3 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +3 --- bets_odd: 301.00
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________end_win_to_nil_home = '3.75',
#   ____________________________end_win_to_nil_away = '4.50',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.67
#   __________________________39 To Win Either Half
#   ____________________________end_to_win_either_half_home = '1.73',
#   ____________________________end_to_win_either_half_away = '2.00',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________24 Results/Both Teams Score
#   ____________________________end_results_both_teams_score_home_yes = '5.50',
#   ____________________________end_results_both_teams_score_draw_yes = '5.00',
#   ____________________________end_results_both_teams_score_away_yes = '6.50',
#   ____________________________end_results_both_teams_score_home_no = '3.75',
#   ____________________________end_results_both_teams_score_draw_no = '9.00',
#   ____________________________end_results_both_teams_score_away_no = '4.50',
#   __________________________25 Result/Total Goals
#   ____________________________end_result_total_goals_home_over_25 = '4.33',
#   ____________________________end_result_total_goals_draw_over_25 = '15.00',
#   ____________________________end_result_total_goals_away_over_25 = '5.00',
#   ____________________________end_result_total_goals_home_under_25 = '4.50',
#   ____________________________end_result_total_goals_draw_under_25 = '4.33',
#   ____________________________end_result_total_goals_away_under_25 = '5.50',
#   __________________________43 Home Team Score a Goal
#   ______________________  ______________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.33
#   ______________________  ______________________bet_id: 43 --- bets_value: No --- bets_odd: 3.25
#   __________________________44 Away Team Score a Goal
#   ______________________  ______________________bet_id: 44 --- bets_value: Yes --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 44 --- bets_value: No --- bets_odd: 2.75
#   __________________________54 First 10 min Winner
#   ______________________  ______________________bet_id: 54 --- bets_value: Home --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 54 --- bets_value: Draw --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 54 --- bets_value: Away --- bets_odd: 9.00
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 8.5 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 8.5 --- bets_odd: 2.00
#   __________________________47 Winning Margin
#   ______________________  ______________________bet_id: 47 --- bets_value: Draw --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 5.00
#   __________________________48 To Score In Both Halves By Teams
#   __________________________49 Total Goals/Both Teams To Score
#   ____________________________end_total_goals_both_teams_to_score_over_yes_25 = '2.50',
#   ____________________________end_total_goals_both_teams_to_score_over_no_25 = '11.00',
#   ____________________________end_total_goals_both_teams_to_score_under_yes_25 = '7.00',
#   ____________________________end_total_goals_both_teams_to_score_under_no_25 = '2.05',
#   __________________________91 Total Goals (3 way)
#   ______________________  ______________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 1.95
#   ______________________  ______________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 4.00
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 4.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.23
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 2.85
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.65
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.65
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 3.30
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.32
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.95
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 1.85
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 3.70
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.26
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.60
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.48
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 3.80
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 5.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.16
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1 --- bets_odd: 7.00
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 3.30
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.32
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.5 --- bets_odd: 1.48
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.5 --- bets_odd: 2.60
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.67
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.45
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 4.40
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.20
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 2.15
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.68
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.68
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.15
#   __________________________52 Halftime Result/Both Teams Score
#   __________________________85 Total Corners (3 way)
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 9 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 9 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 9 --- bets_odd: 7.50
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   __________________________74 10 Over/Under
#   __________________________78 RTG_H1
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 2.63
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 5.00
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ______________________2. Colombia,  Copa Colombia  #241 - 2023 / 1010859
#   ______________________good to Go 1
#   ____________________________1 Match Winner
#   ______________________________end_match_winner_home = '1.33',
#   ______________________________end_match_winner_draw = '4.20',
#   ______________________________end_match_winner_away = '8.00',
#   ____________________________2 Home/Away
#   ______________________________end_homeaway_home = '1.10',
#   ______________________________end_homeaway_away = '7.00',
#   ____________________________3 Second Half Winner
#   ______________________________end_second_half_winner_home = '1.67',
#   ______________________________end_second_half_winner_draw = '2.63',
#   ______________________________end_second_half_winner_away = '8.00',
#   ____________________________4 Asian Handicap
#   ______________________________end_asian_handicap_home_plus_0 = '1.11',
#   ______________________________end_asian_handicap_away_plus_0 = '6.60',
#   ______________________________end_asian_handicap_home_min_025 = '1.24',
#   ______________________________end_asian_handicap_away_min_025 = '3.90',
#   ______________________________end_asian_handicap_home_plus_025 = '1.10',
#   ______________________________end_asian_handicap_away_plus_025 = '7.00',
#   ______________________________end_asian_handicap_home_min_05 = '1.38',
#   ______________________________end_asian_handicap_away_min_05 = '3.00',
#   ______________________________end_asian_handicap_home_plus_05 = '1.10',
#   ______________________________end_asian_handicap_away_plus_05 = '6.80',
#   ______________________________end_asian_handicap_home_min_075 = '1.45',
#   ______________________________end_asian_handicap_away_min_075 = '2.67',
#   ______________________________end_asian_handicap_home_min_1 = '1.60',
#   ______________________________end_asian_handicap_away_min_1 = '2.30',
#   ______________________________end_asian_handicap_home_min_15 = '2.10',
#   ______________________________end_asian_handicap_away_min_15 = '1.70',
#   ______________________________end_asian_handicap_home_min_125 = '1.88',
#   ______________________________end_asian_handicap_away_min_125 = '1.93',
#   ______________________________end_asian_handicap_home_min_175 = '2.42',
#   ______________________________end_asian_handicap_away_min_175 = '1.52',
#   ______________________________end_asian_handicap_home_min_2 = '3.30',
#   ______________________________end_asian_handicap_away_min_2 = '1.32',
#   ______________________________end_asian_handicap_home_min_25 = '3.90',
#   ______________________________end_asian_handicap_away_min_25 = '1.24',
#   ______________________________end_asian_handicap_home_min_225 = '3.55',
#   ______________________________end_asian_handicap_away_min_225 = '1.27',
#   ______________________________end_asian_handicap_home_min_275 = '5.25',
#   ______________________________end_asian_handicap_away_min_275 = '1.16',
#   ____________________________5 Goals Over/Under
#   ______________________________end_goals_overunder_over_35 = '3.75',
#   ______________________________end_goals_overunder_under_35 = '1.25',
#   ______________________________end_goals_overunder_over_15 = '1.36',
#   ______________________________end_goals_overunder_under_15 = '3.00',
#   ______________________________end_goals_overunder_over_45 = '8.00',
#   ______________________________end_goals_overunder_under_45 = '1.08',
#   ______________________________end_goals_overunder_over_25 = '2.10',
#   ______________________________end_goals_overunder_under_25 = '1.70',
#   ______________________________end_goals_overunder_over_05 = '1.06',
#   ______________________________end_goals_overunder_under_05 = '10.00',
#   ______________________________end_goals_overunder_over_55 = '19.00',
#   ______________________________end_goals_overunder_under_55 = '1.02',
#   ______________________________end_goals_overunder_over_225 = '1.88',
#   ______________________________end_goals_overunder_under_225 = '1.93',
#   ______________________________end_goals_overunder_over_325 = '3.45',
#   ______________________________end_goals_overunder_under_325 = '1.30',
#   ______________________________end_goals_overunder_over_275 = '2.42',
#   ______________________________end_goals_overunder_under_275 = '1.52',
#   ______________________________end_goals_overunder_over_125 = '1.23',
#   ______________________________end_goals_overunder_under_125 = '4.00',
#   ______________________________end_goals_overunder_over_425 = '7.00',
#   ______________________________end_goals_overunder_under_425 = '1.10',
#   ______________________________end_goals_overunder_over_175 = '1.45',
#   ______________________________end_goals_overunder_under_175 = '2.67',
#   ______________________________end_goals_overunder_over_375 = '5.00',
#   ______________________________end_goals_overunder_under_375 = '1.17',
#   ______________________________end_goals_overunder_over_65 = '41.00',
#   ______________________________end_goals_overunder_under_65 = '1.00',
#   ______________________________end_goals_overunder_over_30 = '3.10',
#   ______________________________end_goals_overunder_under_30 = '1.35',
#   ______________________________end_goals_overunder_over_20 = '1.60',
#   ______________________________end_goals_overunder_under_20 = '2.30',
#   ______________________________end_goals_overunder_over_40 = '7.00',
#   ______________________________end_goals_overunder_under_40 = '1.10',
#   ______________________________end_goals_overunder_over_10 = '1.10',
#   ______________________________end_goals_overunder_under_10 = '7.00',
#   ____________________________6 Goals Over/Under First Half
#   ______________________________end_goals_overunder_first_half_over_35 = '23.00',
#   ______________________________end_goals_overunder_first_half_under_35 = '1.01',
#   ______________________________end_goals_overunder_first_half_over_15 = '3.00',
#   ______________________________end_goals_overunder_first_half_under_15 = '1.36',
#   ______________________________end_goals_overunder_first_half_over_25 = '9.00',
#   ______________________________end_goals_overunder_first_half_under_25 = '1.07',
#   ______________________________end_goals_overunder_first_half_over_05 = '1.44',
#   ______________________________end_goals_overunder_first_half_under_05 = '2.63',
#   ______________________________end_goals_overunder_first_half_over_125 = '2.60',
#   ______________________________end_goals_overunder_first_half_under_125 = '1.48',
#   ______________________________end_goals_overunder_first_half_over_175 = '4.15',
#   ______________________________end_goals_overunder_first_half_under_175 = '1.22',
#   ______________________________end_goals_overunder_first_half_over_075 = '1.65',
#   ______________________________end_goals_overunder_first_half_under_075 = '2.20',
#   ______________________________end_goals_overunder_first_half_over_20 = '7.00',
#   ______________________________end_goals_overunder_first_half_under_20 = '1.10',
#   ______________________________end_goals_overunder_first_half_over_10 = '2.05',
#   ______________________________end_goals_overunder_first_half_under_10 = '1.75',
#   ____________________________26 Goals Over/Under - Second Half
#   ______________________________end_goals_overunder__second_half_over_35 = '15.00',
#   ______________________________end_goals_overunder__second_half_under_35 = '1.03',
#   ______________________________end_goals_overunder__second_half_over_15 = '2.25',
#   ______________________________end_goals_overunder__second_half_under_15 = '1.57',
#   ______________________________end_goals_overunder__second_half_over_25 = '5.50',
#   ______________________________end_goals_overunder__second_half_under_25 = '1.14',
#   ______________________________end_goals_overunder__second_half_over_05 = '1.25',
#   ______________________________end_goals_overunder__second_half_under_05 = '3.75',
#   ____________________________7 HT/FT Double
#   ____________________________27 Clean Sheet - Home
#   ______________________________end_clean_sheet__home_yes = '1.62',
#   ______________________________end_clean_sheet__home_no = '2.20',
#   ____________________________28 Clean Sheet - Away
#   ______________________________end_clean_sheet__away_yes = '6.00',
#   ______________________________end_clean_sheet__away_no = '1.13',
#   ____________________________8 Both Teams Score
#   ______________________________end_both_teams_score_yes = '2.63',
#   ______________________________end_both_teams_score_no = '1.44',
#   ____________________________9 Handicap Result
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 2.10
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 3.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.07
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 29.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 11.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.01
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 34.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 4.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 4.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.67
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 8.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 6.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.22
#   ____________________________10 Exact Score
#   ____________________________11 Highest Scoring Half
#   ____________________________31 Correct Score - First Half
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.10
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 6.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 19.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 201.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 151.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 151.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.63
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 11.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 9.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 301.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 301.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 351.00
#   ____________________________12 Double Chance
#   ______________________________end_double_chance_home_draw = '1.07',
#   ______________________________end_double_chance_home_away = '1.20',
#   ______________________________end_double_chance_draw_away = '3.00',
#   ____________________________13 First Half Winner
#   ______________________________end_first_half_winner_home = '1.91',
#   ______________________________end_first_half_winner_draw = '2.25',
#   ______________________________end_first_half_winner_away = '9.00',
#   ____________________________14 Team To Score First
#   ________________________  ________________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.25
#   ________________________  ________________________bet_id: 14 --- bets_value: Draw --- bets_odd: 8.50
#   ________________________  ________________________bet_id: 14 --- bets_value: Away --- bets_odd: 5.00
#   ____________________________15 Team To Score Last
#   ________________________  ________________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.25
#   ________________________  ________________________bet_id: 15 --- bets_value: Draw --- bets_odd: 8.50
#   ________________________  ________________________bet_id: 15 --- bets_value: Away --- bets_odd: 5.00
#   ____________________________32 Win Both Halves
#   ______________________________end_win_both_halves_home = '3.40',
#   ______________________________end_win_both_halves_away = '51.00',
#   ____________________________16 Total - Home
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 6.50
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.11
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.62
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 2.20
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.03
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 3.00
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.36
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 5.5 --- bets_odd: 34.00
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 5.5 --- bets_odd: 1.00
#   ____________________________17 Total - Away
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.00
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.08
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 29.00
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.01
#   ____________________________18 Handicap Result - First Half
#   ________________________  ________________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 4.75
#   ________________________  ________________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.80
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 2.75
#   ________________________  ________________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.04
#   ________________________  ________________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 9.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 13.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 6.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.14
#   ________________________  ________________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 17.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.03
#   ____________________________19 Asian Handicap First Half
# ...
#   ________________________________end_goals_overunder_over_15 = '1.18',
#   ________________________________end_goals_overunder_under_15 = '4.10',
#   ________________________________end_goals_overunder_over_45 = '4.70',
#   ________________________________end_goals_overunder_under_45 = '1.15',
#   ________________________________end_goals_overunder_over_25 = '1.66',
#   ________________________________end_goals_overunder_under_25 = '2.19',
#   ________________________________end_goals_overunder_over_55 = '7.80',
#   ________________________________end_goals_overunder_under_55 = '1.05',
#   ________________________________end_goals_overunder_over_225 = '1.45',
#   ________________________________end_goals_overunder_under_225 = '2.50',
#   ________________________________end_goals_overunder_over_325 = '2.29',
#   ________________________________end_goals_overunder_under_325 = '1.54',
#   ________________________________end_goals_overunder_over_275 = '1.83',
#   ________________________________end_goals_overunder_under_275 = '1.95',
#   ________________________________end_goals_overunder_over_425 = '4.18',
#   ________________________________end_goals_overunder_under_425 = '1.18',
#   ________________________________end_goals_overunder_over_175 = '1.23',
#   ________________________________end_goals_overunder_under_175 = '3.66',
#   ________________________________end_goals_overunder_over_375 = '3.00',
#   ________________________________end_goals_overunder_under_375 = '1.33',
#   ________________________________end_goals_overunder_over_30 = '2.03',
#   ________________________________end_goals_overunder_under_30 = '1.68',
#   ________________________________end_goals_overunder_over_20 = '1.28',
#   ________________________________end_goals_overunder_under_20 = '3.26',
#   ________________________________end_goals_overunder_over_40 = '3.84',
#   ________________________________end_goals_overunder_under_40 = '1.20',
#   ________________________________end_goals_overunder_over_10 = '1.00',
#   ________________________________end_goals_overunder_under_10 = '10.00',
#   ______________________________6 Goals Over/Under First Half
#   ________________________________end_goals_overunder_first_half_over_15 = '2.42',
#   ________________________________end_goals_overunder_first_half_under_15 = '1.50',
#   ________________________________end_goals_overunder_first_half_over_25 = '5.50',
#   ________________________________end_goals_overunder_first_half_under_25 = '1.11',
#   ________________________________end_goals_overunder_first_half_over_05 = '1.29',
#   ________________________________end_goals_overunder_first_half_under_05 = '3.28',
#   ________________________________end_goals_overunder_first_half_over_125 = '2.01',
#   ________________________________end_goals_overunder_first_half_under_125 = '1.72',
#   ________________________________end_goals_overunder_first_half_over_075 = '1.40',
#   ________________________________end_goals_overunder_first_half_under_075 = '2.73',
#   ________________________________end_goals_overunder_first_half_over_10 = '1.61',
#   ________________________________end_goals_overunder_first_half_under_10 = '2.18',
#   ______________________________26 Goals Over/Under - Second Half
#   ________________________________end_goals_overunder__second_half_over_15 = '1.86',
#   ________________________________end_goals_overunder__second_half_under_15 = '1.85',
#   ________________________________end_goals_overunder__second_half_over_25 = '3.60',
#   ________________________________end_goals_overunder__second_half_under_25 = '1.24',
#   ________________________________end_goals_overunder__second_half_over_05 = '1.16',
#   ________________________________end_goals_overunder__second_half_under_05 = '4.60',
#   ________________________________end_goals_overunder__second_half_over_125 = '1.59',
#   ________________________________end_goals_overunder__second_half_under_125 = '2.22',
#   ________________________________end_goals_overunder__second_half_over_175 = '2.17',
#   ________________________________end_goals_overunder__second_half_under_175 = '1.62',
#   ________________________________end_goals_overunder__second_half_over_20 = '2.77',
#   ________________________________end_goals_overunder__second_half_under_20 = '1.39',
#   ________________________________end_goals_overunder__second_half_over_10 = '1.30',
#   ________________________________end_goals_overunder__second_half_under_10 = '3.22',
#   ______________________________7 HT/FT Double
#   ______________________________8 Both Teams Score
#   ________________________________end_both_teams_score_yes = '2.09',
#   ________________________________end_both_teams_score_no = '1.70',
#   ______________________________9 Handicap Result
#   __________________________  __________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 1.84
#   __________________________  __________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 3.52
#   __________________________  __________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.48
#   __________________________  __________________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 2.93
#   __________________________  __________________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 3.84
#   __________________________  __________________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.94
#   ______________________________10 Exact Score
#   ______________________________11 Highest Scoring Half
#   ______________________________31 Correct Score - First Half
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 2.90
#   __________________________  __________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 5.50
#   __________________________  __________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 16.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 47.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 94.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.28
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 45.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 9.20
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 42.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 41.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   ______________________________12 Double Chance
#   ________________________________end_double_chance_home_draw = '1.02',
#   ________________________________end_double_chance_home_away = '1.11',
#   ________________________________end_double_chance_draw_away = '3.52',
#   ______________________________13 First Half Winner
#   ________________________________end_first_half_winner_home = '1.70',
#   ________________________________end_first_half_winner_draw = '2.52',
#   ________________________________end_first_half_winner_away = '8.30',
#   ______________________________16 Total - Home
#   __________________________  __________________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 4.00
#   __________________________  __________________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.19
#   __________________________  __________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.38
#   __________________________  __________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 2.71
#   __________________________  __________________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 2.19
#   __________________________  __________________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.57
#   __________________________  __________________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.04
#   __________________________  __________________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 7.60
#   __________________________  __________________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 1.65
#   __________________________  __________________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 2.05
#   ______________________________17 Total - Away
#   __________________________  __________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 5.70
#   __________________________  __________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.09
#   __________________________  __________________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 11.00
#   __________________________  __________________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.01
#   __________________________  __________________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.91
#   __________________________  __________________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 1.76
#   __________________________  __________________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 4.04
#   __________________________  __________________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 1.18
#   ______________________________18 Handicap Result - First Half
#   __________________________  __________________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 3.74
#   __________________________  __________________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.92
#   __________________________  __________________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 2.83
#   ______________________________19 Asian Handicap First Half
#   ______________________________20 Double Chance - First Half
#   ______________________________33 Double Chance - Second Half
#   __________________________  __________________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.01
#   __________________________  __________________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.27
#   __________________________  __________________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 2.20
#   ______________________________34 Both Teams Score - First Half
#   ______________________________35 Both Teams To Score - Second Half
#   ______________________________21 Odd/Even
#   ______________________________22 Odd/Even - First Half
#   __________________________  __________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 1.95
#   __________________________  __________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   ______________________________23 Home Odd/Even
#   __________________________  __________________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.83
#   __________________________  __________________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.83
#   ______________________________60 Away Odd/Even
#   __________________________  __________________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.45
#   __________________________  __________________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.46
#   ______________________________45 Corners Over Under
#   __________________________  __________________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 1.85
#   __________________________  __________________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 1.95
#   __________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ____________________________ff_update_unfinished__
#   __________________________  > No longer get supported
#   ____________7. 2023-03-16 // 887 // 11 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 5
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-16
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 887
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________8. 2023-03-16 // 888 // 11 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 4
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-16
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 888
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
# # -------------------------------------------------- End at 2023-03-22 02:48:43

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-22 02:48:43
#   __main()
#   ____get_date()
#   ______days : 6
#   ______days : 5
#   ______tgl_awal : 2023-03-16
#   ______tgl_akhir : 2023-03-17
#   ________ff_get_fixture_status_match_finished()
#   __________Total Row(s) : 43
#   __________1. 2023-03-16 // 3 // 8 // 2022 // 1010823 // 0#025+05+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010823
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-03-16 // 3 // 8 // 2022 // 1010825 // 025+05+075+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010825
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-03-16 // 3 // 8 // 2022 // 1010827 // 175_15_125_1_H // 25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010827
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________4. 2023-03-16 // 3 // 8 // 2022 // 1010829 // 075_05_025_H // 175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010829
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________5. 2023-03-16 // 3 // 8 // 2022 // 1010831 // 0#025+05+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010831
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________6. 2023-03-16 // 3 // 8 // 2022 // 1010833 // 05_025_0#H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010833
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________7. 2023-03-16 // 3 // 8 // 2022 // 1010835 // 025+05+075+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010835
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________8. 2023-03-16 // 3 // 8 // 2022 // 1010837 // 15_125_1_075_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010837
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________9. 2023-03-16 // 13 // 8 // 2023 // 1011465 // 05_025_0#025+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011465
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________10. 2023-03-16 // 13 // 8 // 2023 // 1011467 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011467
#   ____________> end_ah_pattern = 15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________11. 2023-03-17 // 13 // 8 // 2023 // 1011461 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011461
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________12. 2023-03-16 // 13 // 8 // 2023 // 1011463 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011463
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________13. 2023-03-17 // 16 // 8 // 2023 // 972938 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 972938
#   ____________> end_ah_pattern = 275_25_225_2_175_H
#   ____________> end_ah_pattern_mirror = 175+2+225+25+275+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________14. 2023-03-16 // 16 // 8 // 2023 // 972940 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 972940
#   ____________> end_ah_pattern = 0#025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_0#H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________15. 2023-03-16 // 16 // 8 // 2023 // 972946 // 175_15_125_1_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 972946
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________16. 2023-03-16 // 73 // 8 // 2023 // 1011445 // 175_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011445
#   ____________> end_ah_pattern = 225_2_175_15_H
#   ____________> end_ah_pattern_mirror = 15+175+2+225+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________17. 2023-03-16 // 73 // 8 // 2023 // 1011450 // 025_H // 2g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011450
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________18. 2023-03-16 // 73 // 8 // 2023 // 1011455 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011455
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________19. 2023-03-16 // 237 // 11 // 2022 // 1011977 // 025_0#025+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011977
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________20. 2023-03-16 // 241 // 8 // 2023 // 1010859 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010859
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________21. 2023-03-16 // 241 // 8 // 2023 // 1010864 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010864
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________22. 2023-03-16 // 284 // 8 // 2022 // 1014836 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1014836
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________23. 2023-03-16 // 291 // 11 // 2022 // 998363 // 075_025_H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998363
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________24. 2023-03-16 // 291 // 11 // 2022 // 998365 // 025+075+H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998365
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________25. 2023-03-16 // 291 // 11 // 2022 // 998366 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998366
#   ____________> end_ah_pattern = 15_H
#   ____________> end_ah_pattern_mirror = 15+H
#   ____________> end_gou_pattern = 2gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________26. 2023-03-16 // 291 // 11 // 2022 // 998367 // 025_0#H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998367
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________27. 2023-03-16 // 291 // 11 // 2022 // 998368 // 125_1_075_H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998368
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________28. 2023-03-16 // 357 // 8 // 2023 // 1002552 // 0#025+05+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1002552
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________29. 2023-03-16 // 419 // 11 // 2022 // 923319 // 15_125_1_075_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 923319
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________30. 2023-03-16 // 496 // 11 // 2022 // 934827 // 0#H // 25g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934827
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 25g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________31. 2023-03-16 // 496 // 11 // 2022 // 934829 // 025_0#025+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934829
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________32. 2023-03-16 // 496 // 11 // 2022 // 934833 // 0#025+075+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934833
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________33. 2023-03-16 // 701 // 11 // 2022 // 992352 // 025_0#025+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992352
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________34. 2023-03-16 // 740 // 11 // 2023 // 1010641 // 15_125_1_075_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010641
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________35. 2023-03-16 // 740 // 11 // 2023 // 1010642 // 025_0#025+H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010642
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________36. 2023-03-16 // 740 // 11 // 2023 // 1010644 // 2_175_15_125_H // 225g25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010644
#   ____________> end_ah_pattern = 2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________37. 2023-03-16 // 848 // 8 // 2022 // 1010843 // 025_0#025+05+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010843
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________38. 2023-03-16 // 848 // 8 // 2022 // 1010845 // 2_175_15_125_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010845
#   ____________> end_ah_pattern = 2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________39. 2023-03-16 // 848 // 8 // 2022 // 1010847 // 15_125_1_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010847
#   ____________> end_ah_pattern = 15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________40. 2023-03-16 // 848 // 8 // 2022 // 1010849 // 15_125_1_075_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010849
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________41. 2023-03-16 // 848 // 8 // 2022 // 1010853 // 05+075+1+125+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010853
#   ____________> end_ah_pattern = 05+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_05_H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________42. 2023-03-16 // 848 // 8 // 2022 // 1010855 // 05_025_0#025+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010855
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________43. 2023-03-16 // 848 // 8 // 2022 // 1010857 // 025_0#025+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010857
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
# # -------------------------------------------------- End at 2023-03-22 02:50:22

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-22 02:50:22
#   __main()
#   ____get_date()
#   ______days : 6
#   ______days : 5
#   ______tgl_awal : 2023-03-16
#   ______tgl_akhir : 2023-03-17
#   ________ff_get_fixture_status_match_finished_for_daily_update_patternlist()
#   ________Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date <= '2023-03-17'  and date >= '2023-03-16'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 61
#   ____________[1/61] #876868 #Slovenia 373-2022 / Mura vs Koper
#   ____________pre-ah:05_025_0#H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:27:16
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '373'  and league_country = 'Slovenia'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 8
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 8
#   ____________________patternlists updated
#
#   ____________[2/61] #876869 #Slovenia 373-2022 / Tabor Sežana vs Gorica
#   ____________pre-ah:025_0#025+H -- pre-gou:25gG -/- end-ah:025_0#025+05+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:27:17
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '373'  and league_country = 'Slovenia'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[3/61] #899803 #Indonesia 274-2022 / Persija vs PSIS Semarang
#   ____________pre-ah:1_075_025_H -- pre-gou:175g2g225g25g275gG -/- end-ah:15_125_1_075_H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:26:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '274'  and league_country = 'Indonesia'  and pre_ah_pattern = '1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+H'  and pre_gou_pattern = '175g2g225g25g275gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[4/61] #899805 #Indonesia 274-2022 / Bali United vs Persepam Madura Utd
#   ____________pre-ah:1_075_025_H -- pre-gou:225g25g275g3gG -/- end-ah:125_1_075_025_H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:26:48
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '274'  and league_country = 'Indonesia'  and pre_ah_pattern = '1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '125_1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+125+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[5/61] #869147 #Serbia 287-2022 / FK Zlatibor vs Grafičar
#   ____________pre-ah:025+075+1+125+H -- pre-gou:225g25g275g3gG -/- end-ah:075+1+125+H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:26:55
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '287'  and league_country = 'Serbia'  and pre_ah_pattern = '025+075+1+125+H'  and pre_ah_pattern_mirror = '125_1_075_025_H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[6/61] #948532 #England 703-2022 / Queens Park Rangers U21 vs Charlton Athletic U21
#   ____________pre-ah:075_025_0#H -- pre-gou:3g325g35g375g4g425gG -/- end-ah:075_025_0#H -- end-gou:3g325g35g375g4g425gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:27:29
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '703'  and league_country = 'England'  and pre_ah_pattern = '075_025_0#H'  and pre_ah_pattern_mirror = '0#025+075+H'  and pre_gou_pattern = '3g325g35g375g4g425gG'  and end_ah_pattern = '075_025_0#H'  and end_ah_pattern_mirror = '0#025+075+H'  and end_gou_pattern = '3g325g35g375g4g425gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[7/61] #934827 #Israel 496-2022 / Shimshon Kafr Qasim vs Shimshon Tel Aviv
#   ____________pre-ah:0#H -- pre-gou:25g3gG -/- end-ah:0#H -- end-gou:25g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:29
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '496'  and league_country = 'Israel'  and pre_ah_pattern = '0#H'  and pre_ah_pattern_mirror = '0#H'  and pre_gou_pattern = '25g3gG'  and end_ah_pattern = '0#H'  and end_ah_pattern_mirror = '0#H'  and end_gou_pattern = '25g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 12
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 12
#   ____________________patternlists updated
#
#   ____________[8/61] #934829 #Israel 496-2022 / Maccabi Yavne vs Hapoel Kfar Shalem
#   ____________pre-ah:025_0#025+H -- pre-gou:2g225g25g275gG -/- end-ah:025+075+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:31
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '496'  and league_country = 'Israel'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[9/61] #934833 #Israel 496-2022 / Beitar Tel Aviv Ramla vs Hapoel Marmorek
#   ____________pre-ah:0#025+075+H -- pre-gou:2g225g25g275gG -/- end-ah:0#025+075+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:33
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '496'  and league_country = 'Israel'  and pre_ah_pattern = '0#025+075+H'  and pre_ah_pattern_mirror = '075_025_0#H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[10/61] #975956 #Mexico 263-2022 / Monarcas vs Raya2
#   ____________pre-ah:075_H -- pre-gou:25gG -/- end-ah:1_075_05_025_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:26:43
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = '075_H'  and pre_ah_pattern_mirror = '075+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[11/61] #975957 #Mexico 263-2022 / Dorados vs Atlante FC
#   ____________pre-ah:025+05+075+1+H -- pre-gou:25gG -/- end-ah:025+05+075+1+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:26:45
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = '025+05+075+1+H'  and pre_ah_pattern_mirror = '1_075_05_025_H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025+05+075+1+H'  and end_ah_pattern_mirror = '1_075_05_025_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[12/61] #976691 #Saudi-Arabia 307-2022 / Al Khaleej Saihat vs Al Taee
#   ____________pre-ah:025_0#025+05+H -- pre-gou:25gG -/- end-ah:05_025_0#025+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:27:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '307'  and league_country = 'Saudi-Arabia'  and pre_ah_pattern = '025_0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[13/61] #953103 #Italy 943-2022 / Fidelis Andria vs Crotone
#   ____________pre-ah:05+075+1+H -- pre-gou:G -/- end-ah:025+05+075+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:27:52
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '943'  and league_country = 'Italy'  and pre_ah_pattern = '05+075+1+H'  and pre_ah_pattern_mirror = '1_075_05_H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[14/61] #953107 #Italy 943-2022 / Catanzaro vs Monterosi
#   ____________pre-ah:225_2_175_15_H -- pre-gou:25gG -/- end-ah:25_225_2_175_15_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:27:54
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '943'  and league_country = 'Italy'  and pre_ah_pattern = '225_2_175_15_H'  and pre_ah_pattern_mirror = '15+175+2+225+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '25_225_2_175_15_H'  and end_ah_pattern_mirror = '15+175+2+225+25+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[15/61] #979214 #Argentina 130-2023 / San Lorenzo vs Sarmiento Resistencia
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:175_15_125_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-17 08:24:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '130'  and league_country = 'Argentina'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[16/61] #923319 #Azerbaidjan 419-2022 / Neftchi Baku vs Kapaz
#   ____________pre-ah:15_125_1_075_H -- pre-gou:2g225g25g275gG -/- end-ah:15_125_1_075_H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:25
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '419'  and league_country = 'Azerbaidjan'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[17/61] #992352 #Portugal 701-2022 / Farense U23 vs Marítimo U23
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275g3gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 12:27:27
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '701'  and league_country = 'Portugal'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 5
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 5
#   ____________________patternlists updated
#
#   ____________[18/61] #972938 #World 16-2023 / Leon vs Tauro FC
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:275_25_225_2_175_H -- end-gou:275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '16'  and league_country = 'World'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '275_25_225_2_175_H'  and end_ah_pattern_mirror = '175+2+225+25+275+H'  and end_gou_pattern = '275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[19/61] #972940 #World 16-2023 / Orlando City SC vs Tigres UANL
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:0#025+05+075+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:05:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '16'  and league_country = 'World'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '0#025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_0#H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[20/61] #972946 #World 16-2023 / Los Angeles FC vs LD Alajuelense
#   ____________pre-ah:175_15_125_1_H -- pre-gou:25g275g3g325g35gG -/- end-ah:175_15_125_1_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:05:02
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '16'  and league_country = 'World'  and pre_ah_pattern = '175_15_125_1_H'  and pre_ah_pattern_mirror = '1+125+15+175+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[21/61] #1010823 #World 3-2022 / Union St. Gilloise vs Union Berlin
#   ____________pre-ah:0#025+05+H -- pre-gou:2g225g25g275gG -/- end-ah:0#025+05+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:45
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '3'  and league_country = 'World'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[22/61] #1010825 #World 3-2022 / Ferencvarosi TC vs Bayer Leverkusen
#   ____________pre-ah:025+05+075+H -- pre-gou:225g25g275g3gG -/- end-ah:025+05+075+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:41
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '3'  and league_country = 'World'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[23/61] #1010827 #World 3-2022 / Arsenal vs Sporting CP
#   ____________pre-ah:175_15_125_1_H -- pre-gou:25g275g3g325gG -/- end-ah:175_15_125_1_H -- end-gou:25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:46
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '3'  and league_country = 'World'  and pre_ah_pattern = '175_15_125_1_H'  and pre_ah_pattern_mirror = '1+125+15+175+H'  and pre_gou_pattern = '25g275g3g325gG'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[24/61] #1010829 #World 3-2022 / Real Sociedad vs AS Roma
#   ____________pre-ah:075_05_025_H -- pre-gou:175g2g225gG -/- end-ah:075_05_025_H -- end-gou:175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '3'  and league_country = 'World'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '175g2g225gG'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[25/61] #1010831 #World 3-2022 / SC Freiburg vs Juventus
#   ____________pre-ah:0#025+05+H -- pre-gou:175g2g225g25gG -/- end-ah:0#025+05+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '3'  and league_country = 'World'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[26/61] #1010833 #World 3-2022 / Fenerbahce vs Sevilla
#   ____________pre-ah:05_025_0#H -- pre-gou:225g25g275gG -/- end-ah:05_025_0#H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:52
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '3'  and league_country = 'World'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[27/61] #1010835 #World 3-2022 / Real Betis vs Manchester United
#   ____________pre-ah:025+05+075+H -- pre-gou:225g25g275g3gG -/- end-ah:025+05+075+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:49
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '3'  and league_country = 'World'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[28/61] #1010837 #World 3-2022 / Feyenoord vs Shakhtar Donetsk
#   ____________pre-ah:15_125_1_075_H -- pre-gou:225g25g275g3gG -/- end-ah:15_125_1_075_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:48
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '3'  and league_country = 'World'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[29/61] #1010843 #World 848-2022 / AZ Alkmaar vs Lazio
#   ____________pre-ah:025_0#025+05+H -- pre-gou:225g25g275gG -/- end-ah:025_0#025+05+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 12:27:38
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '848'  and league_country = 'World'  and pre_ah_pattern = '025_0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#025+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[30/61] #1010845 #World 848-2022 / West Ham vs AEK Larnaca
#   ____________pre-ah:2_175_15_125_H -- pre-gou:225g25g275g3gG -/- end-ah:2_175_15_125_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 12:27:40
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '848'  and league_country = 'World'  and pre_ah_pattern = '2_175_15_125_H'  and pre_ah_pattern_mirror = '125+15+175+2+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[31/61] #1010847 #World 848-2022 / Nice vs Sheriff Tiraspol
#   ____________pre-ah:15_125_1_H -- pre-gou:225g25g275gG -/- end-ah:15_125_1_H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 12:27:46
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '848'  and league_country = 'World'  and pre_ah_pattern = '15_125_1_H'  and pre_ah_pattern_mirror = '1+125+15+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[32/61] #1010849 #World 848-2022 / Villarreal vs Anderlecht
#   ____________pre-ah:15_125_1_075_H -- pre-gou:225g25g275g3gG -/- end-ah:15_125_1_075_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 12:27:43
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '848'  and league_country = 'World'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[33/61] #1010853 #World 848-2022 / Sivasspor vs Fiorentina
#   ____________pre-ah:05+075+1+125+H -- pre-gou:225g25g275gG -/- end-ah:05+075+1+125+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 12:27:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '848'  and league_country = 'World'  and pre_ah_pattern = '05+075+1+125+H'  and pre_ah_pattern_mirror = '125_1_075_05_H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '05+075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_05_H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[34/61] #1010855 #World 848-2022 / Djurgardens IF vs Lech Poznan
#   ____________pre-ah:05_025_0#025+H -- pre-gou:225g25g275gG -/- end-ah:05_025_0#025+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 12:27:45
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '848'  and league_country = 'World'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[35/61] #1010857 #World 848-2022 / Slovan Bratislava vs FC Basel 1893
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275gG -/- end-ah:025_0#025+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 12:27:42
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '848'  and league_country = 'World'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[36/61] #1001212 #Estonia 329-2023 / Vaprus vs Kalju Nomme
#   ____________pre-ah:125+15+175+2+225+25+H -- pre-gou:25g275g3g325g35gG -/- end-ah:125+15+175+2+225+25+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:27:11
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '329'  and league_country = 'Estonia'  and pre_ah_pattern = '125+15+175+2+225+25+H'  and pre_ah_pattern_mirror = '25_225_2_175_15_125_H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '125+15+175+2+225+25+H'  and end_ah_pattern_mirror = '25_225_2_175_15_125_H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[37/61] #1008357 #USA 255-2023 / El Paso Locomotive vs Colorado Springs
#   ____________pre-ah:0#H -- pre-gou:25gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:26:41
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '255'  and league_country = 'USA'  and pre_ah_pattern = '0#H'  and pre_ah_pattern_mirror = '0#H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[38/61] #1011465 #World 13-2023 / Cerro Porteno vs Fortaleza EC
#   ____________pre-ah:05_025_0#025+H -- pre-gou:175g2g225g25gG -/- end-ah:05_025_0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 01:31:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '13'  and league_country = 'World'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[39/61] #1011467 #World 13-2023 / Atletico-MG vs Millonarios
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:15_125_1_H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 01:31:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '13'  and league_country = 'World'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[40/61] #1011977 #Russia 237-2022 / Nizhny Novgorod vs FC Rostov
#   ____________pre-ah:025_0#025+H -- pre-gou:175g2g225g25gG -/- end-ah:025_0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:05:10
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '237'  and league_country = 'Russia'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[41/61] #1014329 #Cyprus 318-2022 / Doxa vs Karmiotissa
#   ____________pre-ah:075_05_025_H -- pre-gou:25gG -/- end-ah:075_05_025_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:27:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '318'  and league_country = 'Cyprus'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 7
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 7
#   ____________________patternlists updated
#
#   ____________[42/61] #965269 #Egypt 889-2022 / Helal Aldabaa vs Kafr El Sheikh
#   ____________pre-ah:0#H -- pre-gou:G -/- end-ah:025_0#025+H -- end-gou:15g175g2g225gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:27:50
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '889'  and league_country = 'Egypt'  and pre_ah_pattern = '0#H'  and pre_ah_pattern_mirror = '0#H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[43/61] #997445 #Malaysia 278-2023 / Negeri Sembilan vs Terengganu
#   ____________pre-ah:0#025+075+H -- pre-gou:225g25g275g3gG -/- end-ah:025+075+1+H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 12:26:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
# ...
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[47/61] #998366 #Iran 291-2022 / Fajr Sepasi vs Chooka Talesh
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:15_H -- end-gou:2gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:16
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '291'  and league_country = 'Iran'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '15_H'  and end_ah_pattern_mirror = '15+H'  and end_gou_pattern = '2gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[48/61] #998367 #Iran 291-2022 / Shahrdari Hamedan vs Khooshe Talaee Saveh
#   ____________pre-ah:025_0#H -- pre-gou:15g175g2g225gG -/- end-ah:025_0#H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '291'  and league_country = 'Iran'  and pre_ah_pattern = '025_0#H'  and pre_ah_pattern_mirror = '0#025+H'  and pre_gou_pattern = '15g175g2g225gG'  and end_ah_pattern = '025_0#H'  and end_ah_pattern_mirror = '0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[49/61] #998368 #Iran 291-2022 / Kheybar Khorramabad vs Khalij Fars
#   ____________pre-ah:125_1_075_H -- pre-gou:15g175g2g225gG -/- end-ah:15_125_1_075_H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:13
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '291'  and league_country = 'Iran'  and pre_ah_pattern = '125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+H'  and pre_gou_pattern = '15g175g2g225gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[50/61] #1002552 #Ireland 357-2023 / Drogheda United vs Dundalk
#   ____________pre-ah:0#025+05+H -- pre-gou:2g225g25g275gG -/- end-ah:0#025+05+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 12:27:13
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '357'  and league_country = 'Ireland'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[51/61] #1010641 #Brazil 740-2023 / Corinthians U20 vs RB Bragantino U20
#   ____________pre-ah:15_125_1_075_H -- pre-gou:225g25g275g3gG -/- end-ah:15_125_1_075_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[52/61] #1010642 #Brazil 740-2023 / Fortaleza U20 vs Athletico PR U20
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275g3g325gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:38
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[53/61] #1010644 #Brazil 740-2023 / Palmeiras U20 vs Goiás U20
#   ____________pre-ah:2_175_15_125_H -- pre-gou:225g25g275g3g325g35gG -/- end-ah:2_175_15_125_H -- end-gou:225g25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = '2_175_15_125_H'  and pre_ah_pattern_mirror = '125+15+175+2+H'  and pre_gou_pattern = '225g25g275g3g325g35gG'  and end_ah_pattern = '2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+H'  and end_gou_pattern = '225g25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[54/61] #1011445 #Brazil 73-2023 / Gremio vs Ferroviario
#   ____________pre-ah:175_H -- pre-gou:25gG -/- end-ah:225_2_175_15_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:05:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = '175_H'  and pre_ah_pattern_mirror = '175+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '225_2_175_15_H'  and end_ah_pattern_mirror = '15+175+2+225+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[55/61] #1011450 #Brazil 73-2023 / CSA vs Brusque
#   ____________pre-ah:025_H -- pre-gou:2g25gG -/- end-ah:05_025_0#H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:05:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = '025_H'  and pre_ah_pattern_mirror = '025+H'  and pre_gou_pattern = '2g25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[56/61] #1010859 #Colombia 241-2023 / Patriotas vs Orsomarso
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:175_15_125_1_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:48:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '241'  and league_country = 'Colombia'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[57/61] #1010864 #Colombia 241-2023 / Bogota FC vs Alianza Petrolera
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:05_025_0#025+H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 02:47:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '241'  and league_country = 'Colombia'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[58/61] #1011455 #Brazil 73-2023 / Ypiranga-RS vs RB Bragantino
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025+05+075+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:05:05
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[59/61] #1011461 #World 13-2023 / Sporting Cristal vs Huracan
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#025+05+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:55
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '13'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[60/61] #1011463 #World 13-2023 / Independiente Medellin vs Magallanes
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:125_1_075_05_H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 01:31:34
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '13'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[61/61] #1014836 #Romania 284-2022 / CSA Steaua Bucureşti vs Unirea Dej
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:125_1_075_05_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-21 02:09:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '284'  and league_country = 'Romania'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
# # -------------------------------------------------- End at 2023-03-22 02:58:55
