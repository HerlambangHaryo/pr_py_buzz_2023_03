# %%
# Import
from a_settings.messages import *  

today = datetime.datetime.now()  
days0 = 6
days1 = 5
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 6 - 5 --> 2023-03-16 14:50:43.015399

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 14:50:43
#   __main()
#   ____get_date()
#   ______days : 6
#   ______days : 5
#   ______tgl_awal : 2023-03-10
#   ______tgl_akhir : 2023-03-11
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-11'  and date >= '2023-03-10'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 17
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 143
#   ______________1. 2023-03-10 // 16 // 8 // 2023 // 972941 // H // G
#   ______________2. 2023-03-10 // 16 // 8 // 2023 // 972945 // H // G
#   ______________3. 2023-03-10 // 40 // 8 // 2022 // 881148 // 075_05_025_H // 2g225g25g275gG
#   ______________4. 2023-03-10 // 42 // 8 // 2022 // 876475 // 025+05+075+H // 225g25g275gG
#   ______________5. 2023-03-10 // 61 // 8 // 2022 // 871737 // 075_05_025_H // 225g25g275g3g325gG
#   ______________6. 2023-03-10 // 63 // 11 // 2022 // 914091 // H // G
#   ______________7. 2023-03-10 // 63 // 11 // 2022 // 914092 // H // G
#   ______________8. 2023-03-10 // 63 // 11 // 2022 // 914093 // 0#H // 25gG
#   ______________9. 2023-03-10 // 63 // 11 // 2022 // 914094 // 15_H // 25gG
#   ______________10. 2023-03-10 // 63 // 11 // 2022 // 914095 // 025_0#025+H // 175g2g225g25g275gG
#   ______________11. 2023-03-10 // 63 // 11 // 2022 // 914096 // 0#H // 25gG
#   ______________12. 2023-03-10 // 63 // 11 // 2022 // 914097 // H // G
#   ______________13. 2023-03-10 // 63 // 11 // 2022 // 924498 // H // G
#   ______________14. 2023-03-10 // 73 // 8 // 2023 // 1012105 // None // None
#   ______________15. 2023-03-10 // 78 // 8 // 2022 // 871374 // 125_1_075_05_H // 225g25g275g3gG
#   ______________16. 2023-03-10 // 79 // 8 // 2022 // 873071 // 075_05_025_H // 225g25g275gG
#   ______________17. 2023-03-10 // 79 // 8 // 2022 // 873077 // 1_075_05_H // 225g25g275gG
#   ______________18. 2023-03-10 // 80 // 8 // 2022 // 879370 // H // G
#   ______________19. 2023-03-10 // 82 // 11 // 2022 // 885870 // H // G
#   ______________20. 2023-03-10 // 83 // 8 // 2022 // 904273 // H // G
#   ______________21. 2023-03-10 // 86 // 8 // 2022 // 904889 // H // G
#   ______________22. 2023-03-10 // 86 // 8 // 2022 // 904896 // H // G
#   ______________23. 2023-03-10 // 89 // 11 // 2022 // 867835 // 0#025+H // 225g25g275g3g325gG
#   ______________24. 2023-03-10 // 89 // 11 // 2022 // 867836 // 075_025_0#H // 25g275g3g325g35gG
#   ______________25. 2023-03-10 // 89 // 11 // 2022 // 867837 // H // G
#   ______________26. 2023-03-10 // 89 // 11 // 2022 // 867838 // H // G
#   ______________27. 2023-03-10 // 89 // 11 // 2022 // 867839 // H // G
#   ______________28. 2023-03-10 // 89 // 11 // 2022 // 867840 // 0#025+H // 25g275g3g325g35gG
#   ______________29. 2023-03-10 // 89 // 11 // 2022 // 867841 // 075_025_H // 2g225g25g275gG
#   ______________30. 2023-03-10 // 89 // 11 // 2022 // 867842 // 15_125_1_075_H // 25g275g3g325g35gG
#   ______________31. 2023-03-10 // 89 // 11 // 2022 // 867843 // 0#H // 25g275gG
#   ______________32. 2023-03-10 // 91 // 11 // 2022 // 913332 // H // G
#   ______________33. 2023-03-10 // 94 // 8 // 2022 // 898811 // 225_2_175_15_H // 25g275g3g325gG
#   ______________34. 2023-03-10 // 95 // 8 // 2022 // 899117 // H // G
#   ______________35. 2023-03-10 // 106 // 8 // 2022 // 865292 // 05_025_0#H // 225g25g275gG
#   ______________36. 2023-03-10 // 106 // 8 // 2022 // 865294 // 175_15_125_H // 225g25g275g3gG
#   ______________37. 2023-03-10 // 107 // 8 // 2022 // 867070 // H // G
#   ______________38. 2023-03-10 // 107 // 8 // 2022 // 867073 // H // G
#   ______________39. 2023-03-10 // 110 // 8 // 2022 // 990901 // None // None
#   ______________40. 2023-03-10 // 119 // 8 // 2022 // 881749 // H // 25gG
#   ______________41. 2023-03-11 // 128 // 8 // 2023 // 971424 // H // G
#   ______________42. 2023-03-10 // 128 // 8 // 2023 // 971431 // 025_0#025+H // 175g2g225gG
#   ______________43. 2023-03-11 // 128 // 8 // 2023 // 988709 // H // G
#   ______________44. 2023-03-11 // 129 // 8 // 2023 // 992645 // H // G
#   ______________45. 2023-03-10 // 132 // 11 // 2023 // 988049 // H // G
#   ______________46. 2023-03-10 // 132 // 11 // 2023 // 988053 // H // G
#   ______________47. 2023-03-10 // 134 // 11 // 2023 // 1010328 // None // None
#   ______________48. 2023-03-10 // 135 // 8 // 2022 // 882039 // 075+1+125+15+H // 225g25g275g3gG
#   ______________49. 2023-03-10 // 140 // 8 // 2022 // 878186 // 05_025_0#H // 15g175g2gG
#   ______________50. 2023-03-10 // 141 // 8 // 2022 // 878656 // 025_0#025+H // 125g15g175gG
#   ______________51. 2023-03-10 // 144 // 8 // 2022 // 874987 // 075_05_025_H // 225g25g275g3gG
#   ______________52. 2023-03-10 // 145 // 8 // 2022 // 1005162 // 05_025_0#H // 225g25g275g3gG
#   ______________53. 2023-03-10 // 145 // 8 // 2022 // 1005192 // 025_0#025+05+H // 225g25g275g3gG
#   ______________54. 2023-03-10 // 168 // 8 // 2023 // 976073 // H // G
#   ______________55. 2023-03-10 // 168 // 8 // 2023 // 976079 // H // G
#   ______________56. 2023-03-10 // 168 // 8 // 2023 // 976081 // H // G
#   ______________57. 2023-03-10 // 172 // 8 // 2022 // 883501 // H // G
#   ______________58. 2023-03-10 // 173 // 11 // 2022 // 882786 // H // G
#   ______________59. 2023-03-10 // 180 // 8 // 2022 // 873424 // 15_125_1_075_H // 25g275g3g325gG
#   ______________60. 2023-03-10 // 181 // 8 // 2022 // 1005154 // 0#025+05+075+H // 225g25g275gG
#   ______________61. 2023-03-10 // 188 // 8 // 2022 // 924629 // 0#025+05+H // 225g25g275gG
#   ______________62. 2023-03-10 // 192 // 11 // 2023 // 982279 // None // None
#   ______________63. 2023-03-10 // 194 // 11 // 2023 // 990717 // 025+075+1+H // 275g3g325g35g375g4gG
#   ______________64. 2023-03-10 // 194 // 11 // 2023 // 990718 // 125_1_075_025_H // 275g3g325g35g375gG
#   ______________65. 2023-03-10 // 194 // 11 // 2023 // 990719 // 075_025_0#H // 275g3g325g35g375gG
#   ______________66. 2023-03-10 // 195 // 8 // 2023 // 978876 // 05_025_0#025+H // 25gG
#   ______________67. 2023-03-10 // 195 // 8 // 2023 // 978877 // 025+05+075+1+H // 25gG
#   ______________68. 2023-03-10 // 200 // 8 // 2022 // 1011155 // None // None
#   ______________69. 2023-03-10 // 203 // 8 // 2022 // 884557 // H // G
#   ______________70. 2023-03-10 // 210 // 8 // 2022 // 866498 // H // G
#   ______________71. 2023-03-10 // 222 // 11 // 2022 // 896412 // H // G
#   ______________72. 2023-03-10 // 235 // 11 // 2022 // 880017 // 075_025_H // 275g3g325g35gG
#   ______________73. 2023-03-10 // 239 // 8 // 2023 // 989290 // 025_0#025+H // 175g2g225g25gG
#   ______________74. 2023-03-10 // 250 // 8 // 2023 // 986899 // 175_15_125_1_H // 225g25g275g3gG
#   ______________75. 2023-03-10 // 263 // 8 // 2022 // 975949 // 025_0#H // 25gG
#   ______________76. 2023-03-10 // 263 // 8 // 2022 // 975950 // 05_H // 25gG
#   ______________77. 2023-03-10 // 265 // 8 // 2023 // 983719 // 025_0#025+05+H // 225g25g275gG
#   ______________78. 2023-03-10 // 266 // 11 // 2023 // 987772 // None // None
#   ______________79. 2023-03-10 // 268 // 8 // 2023 // 1003355 // H // G
#   ______________80. 2023-03-10 // 269 // 8 // 2023 // 1009259 // None // None
#   ______________81. 2023-03-10 // 274 // 11 // 2022 // 899779 // 025_0#025+H // 225g25g275g3g325gG
#   ______________82. 2023-03-10 // 274 // 11 // 2022 // 899781 // 025_0#025+H // 225g25g275g3gG
#   ______________83. 2023-03-10 // 281 // 8 // 2023 // 985143 // H // 25gG
#   ______________84. 2023-03-10 // 283 // 8 // 2022 // 883189 // H // G
#   ______________85. 2023-03-10 // 283 // 8 // 2022 // 883194 // H // G
#   ______________86. 2023-03-10 // 291 // 11 // 2022 // 998356 // None // None
#   ______________87. 2023-03-10 // 299 // 11 // 2023 // 998081 // None // None
#   ______________88. 2023-03-10 // 318 // 8 // 2022 // 1012382 // H // G
#   ______________89. 2023-03-10 // 330 // 8 // 2022 // 991144 // None // None
#   ______________90. 2023-03-10 // 330 // 8 // 2022 // 991143 // None // None
#   ______________91. 2023-03-10 // 332 // 8 // 2022 // 1012052 // None // None
#   ______________92. 2023-03-10 // 344 // 8 // 2023 // 1000968 // None // None
#   ______________93. 2023-03-10 // 346 // 8 // 2022 // 879649 // H // G
#   ______________94. 2023-03-10 // 349 // 11 // 2022 // 969564 // None // None
#   ______________95. 2023-03-10 // 362 // 8 // 2023 // 998385 // H // G
#   ______________96. 2023-03-10 // 368 // 11 // 2023 // 997872 // None // None
#   ______________97. 2023-03-10 // 368 // 11 // 2023 // 997873 // None // None
#   ______________98. 2023-03-10 // 373 // 8 // 2022 // 876863 // H // 25gG
#   ______________99. 2023-03-10 // 382 // 8 // 2022 // 877777 // H // G
#   ______________100. 2023-03-10 // 382 // 8 // 2022 // 877778 // H // G
#   ______________101. 2023-03-10 // 382 // 8 // 2022 // 877779 // H // G
#   ______________102. 2023-03-10 // 382 // 8 // 2022 // 877780 // H // G
#   ______________103. 2023-03-10 // 382 // 8 // 2022 // 877781 // H // G
#   ______________104. 2023-03-10 // 386 // 11 // 2022 // 1011473 // None // None
#   ______________105. 2023-03-10 // 386 // 11 // 2022 // 1013015 // None // None
#   ______________106. 2023-03-10 // 406 // 11 // 2022 // 986505 // H // G
#   ______________107. 2023-03-10 // 406 // 11 // 2022 // 986506 // H // G
#   ______________108. 2023-03-10 // 406 // 11 // 2022 // 986507 // H // G
#   ______________109. 2023-03-10 // 419 // 11 // 2022 // 923311 // 175_15_125_H // 2g225g25g275gG
#   ______________110. 2023-03-10 // 419 // 11 // 2022 // 923312 // 025+075+H // 2g225g25g275gG
#   ______________111. 2023-03-10 // 450 // 11 // 2022 // 956762 // H // G
#   ______________112. 2023-03-10 // 450 // 11 // 2022 // 956763 // H // G
#   ______________113. 2023-03-10 // 475 // 8 // 2023 // 1013057 // None // None
#   ______________114. 2023-03-10 // 487 // 11 // 2022 // 941885 // H // G
#   ______________115. 2023-03-10 // 494 // 11 // 2022 // 966571 // 025_0#025+H // 175g2g225g25g275gG
#   ______________116. 2023-03-10 // 494 // 11 // 2022 // 966775 // 0#025+H // 15g175g2g225g25gG
#   ______________117. 2023-03-10 // 496 // 11 // 2022 // 934584 // H // G
#   ______________118. 2023-03-10 // 496 // 11 // 2022 // 934820 // H // G
#   ______________119. 2023-03-10 // 496 // 11 // 2022 // 934823 // H // G
#   ______________120. 2023-03-10 // 667 // 8 // 2023 // 994339 // None // None
#   ______________121. 2023-03-10 // 667 // 8 // 2023 // 994340 // None // None
#   ______________122. 2023-03-10 // 667 // 8 // 2023 // 1007912 // None // None
#   ______________123. 2023-03-10 // 667 // 8 // 2023 // 1014174 // None // None
#   ______________124. 2023-03-10 // 667 // 8 // 2023 // 1014175 // None // None
#   ______________125. 2023-03-10 // 667 // 8 // 2023 // 1014176 // None // None
#   ______________126. 2023-03-10 // 667 // 8 // 2023 // 1014260 // None // None
#   ______________127. 2023-03-10 // 667 // 8 // 2023 // 1014294 // None // None
#   ______________128. 2023-03-10 // 667 // 8 // 2023 // 1014295 // None // None
#   ______________129. 2023-03-10 // 667 // 8 // 2023 // 1014296 // None // None
#   ______________130. 2023-03-10 // 667 // 8 // 2023 // 1014297 // None // None
#   ______________131. 2023-03-10 // 667 // 8 // 2023 // 1014298 // None // None
#   ______________132. 2023-03-10 // 667 // 8 // 2023 // 1014299 // None // None
#   ______________133. 2023-03-10 // 673 // 8 // 2022 // 976328 // H // G
#   ______________134. 2023-03-10 // 701 // 11 // 2022 // 992383 // H // G
#   ______________135. 2023-03-10 // 701 // 11 // 2022 // 992386 // H // G
#   ______________136. 2023-03-10 // 705 // 8 // 2022 // 915516 // H // G
#   ______________137. 2023-03-10 // 711 // 11 // 2023 // 1006059 // None // None
#   ______________138. 2023-03-10 // 722 // 11 // 2022 // 938840 // H // G
#   ______________139. 2023-03-10 // 722 // 11 // 2022 // 938841 // H // G
#   ______________140. 2023-03-10 // 722 // 11 // 2022 // 938843 // H // G
#   ______________141. 2023-03-10 // 722 // 11 // 2022 // 938852 // H // G
#   ______________142. 2023-03-10 // 750 // 11 // 2022 // 907464 // H // G
#   ______________143. 2023-03-10 // 888 // 11 // 2022 // 965025 // H // G
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-03-10 // 73 // 8 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 89
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-10
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 73
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Brazil,  Copa Do Brasil  #73 - 2023 / 1012105
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.22',
#   ____________________________end_match_winner_draw = '6.00',
#   ____________________________end_match_winner_away = '15.00',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '1.05',
#   ____________________________end_homeaway_away = '11.00',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '1.44',
#   ____________________________end_second_half_winner_draw = '3.00',
#   ____________________________end_second_half_winner_away = '10.00',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_min_175 = '1.93',
#   ____________________________end_asian_handicap_away_min_175 = '1.93',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '2.75',
#   ____________________________end_goals_overunder_under_35 = '1.40',
#   ____________________________end_goals_overunder_over_15 = '1.22',
#   ____________________________end_goals_overunder_under_15 = '4.00',
#   ____________________________end_goals_overunder_over_45 = '5.50',
#   ____________________________end_goals_overunder_under_45 = '1.14',
#   ____________________________end_goals_overunder_over_25 = '1.73',
#   ____________________________end_goals_overunder_under_25 = '2.08',
#   ____________________________end_goals_overunder_over_05 = '1.04',
#   ____________________________end_goals_overunder_under_05 = '13.00',
#   ____________________________end_goals_overunder_over_55 = '11.00',
#   ____________________________end_goals_overunder_under_55 = '1.05',
#   ____________________________end_goals_overunder_over_275 = '1.98',
#   ____________________________end_goals_overunder_under_275 = '1.88',
#   ____________________________end_goals_overunder_over_65 = '23.00',
#   ____________________________end_goals_overunder_under_65 = '1.01',
#   ____________________________end_goals_overunder_over_75 = '51.00',
#   ____________________________end_goals_overunder_under_75 = '1.00',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '19.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.02',
#   ____________________________end_goals_overunder_first_half_over_15 = '2.63',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.44',
#   ____________________________end_goals_overunder_first_half_over_25 = '6.50',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.11',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.33',
#   ____________________________end_goals_overunder_first_half_under_05 = '3.25',
#   ____________________________end_goals_overunder_first_half_over_125 = '2.10',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.70',
#   ____________________________end_goals_overunder_first_half_over_10 = '1.70',
#   ____________________________end_goals_overunder_first_half_under_10 = '2.10',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '11.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.05',
#   ____________________________end_goals_overunder__second_half_over_15 = '1.91',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.80',
#   ____________________________end_goals_overunder__second_half_over_25 = '4.00',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.22',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.20',
#   ____________________________end_goals_overunder__second_half_under_05 = '4.33',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________end_clean_sheet__home_yes = '1.53',
#   ____________________________end_clean_sheet__home_no = '2.38',
#   __________________________28 Clean Sheet - Away
#   ____________________________end_clean_sheet__away_yes = '9.00',
#   ____________________________end_clean_sheet__away_no = '1.07',
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '2.63',
#   ____________________________end_both_teams_score_no = '1.44',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 1.67
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.03
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 8.50
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 201.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 501.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 6:0 --- bets_odd: 401.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.25
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 401.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 401.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.03',
#   ____________________________end_double_chance_home_away = '1.13',
#   ____________________________end_double_chance_draw_away = '4.00',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '1.67',
#   ____________________________end_first_half_winner_draw = '2.60',
#   ____________________________end_first_half_winner_away = '12.00',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.17
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 6.00
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.17
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 6.00
#   __________________________32 Win Both Halves
#   ____________________________end_win_both_halves_home = '2.50',
#   ____________________________end_win_both_halves_away = '67.00',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.62
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 5.5 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 5.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 6.5 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 6.5 --- bets_odd: 1.00
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.06
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.00
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 3.60
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.05
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.05
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________end_win_to_nil_home = '1.73',
#   ____________________________end_win_to_nil_away = '19.00',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.80
#   __________________________39 To Win Either Half
#   ____________________________end_to_win_either_half_home = '1.14',
#   ____________________________end_to_win_either_half_away = '6.00',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________61 To Qualify
#   ______________________  ______________________bet_id: 61 --- bets_value: Home --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 61 --- bets_value: Away --- bets_odd: 6.50
#   __________________________24 Results/Both Teams Score
#   ____________________________end_results_both_teams_score_home_yes = '3.75',
#   ____________________________end_results_both_teams_score_draw_yes = '8.50',
#   ____________________________end_results_both_teams_score_away_yes = '26.00',
#   ____________________________end_results_both_teams_score_home_no = '1.73',
#   ____________________________end_results_both_teams_score_draw_no = '11.00',
#   ____________________________end_results_both_teams_score_away_no = '19.00',
#   __________________________25 Result/Total Goals
#   ____________________________end_result_total_goals_home_over_25 = '1.91',
#   ____________________________end_result_total_goals_draw_over_25 = '29.00',
#   ____________________________end_result_total_goals_away_over_25 = '26.00',
#   ____________________________end_result_total_goals_home_under_25 = '3.00',
#   ____________________________end_result_total_goals_draw_under_25 = '6.50',
#   ____________________________end_result_total_goals_away_under_25 = '19.00',
#   __________________________43 Home Team Score a Goal
#   ______________________  ______________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 43 --- bets_value: No --- bets_odd: 9.00
#   __________________________44 Away Team Score a Goal
#   ______________________  ______________________bet_id: 44 --- bets_value: Yes --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 44 --- bets_value: No --- bets_odd: 1.53
#   __________________________55 Corners 1x2
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 10.5 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 10.5 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 11.5 --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 11.5 --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 12.5 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 12.5 --- bets_odd: 1.67
#   __________________________47 Winning Margin
#   ______________________  ______________________bet_id: 47 --- bets_value: Draw --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 501.00
#   ______________________  ______________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 9.00
#   __________________________48 To Score In Both Halves By Teams
#   __________________________49 Total Goals/Both Teams To Score
#   ____________________________end_total_goals_both_teams_to_score_over_yes_25 = '3.10',
#   ____________________________end_total_goals_both_teams_to_score_over_no_25 = '3.40',
#   ____________________________end_total_goals_both_teams_to_score_under_yes_25 = '12.00',
#   ____________________________end_total_goals_both_teams_to_score_under_no_25 = '2.30',
#   __________________________91 Total Goals (3 way)
#   ______________________  ______________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 2.75
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 1.98
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.88
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.70
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.70
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 2.10
#   __________________________52 Halftime Result/Both Teams Score
#   __________________________56 Corners Asian Handicap
#   ______________________  ______________________bet_id: 56 --- bets_value: Home -5 --- bets_odd: 1.77
#   ______________________  ______________________bet_id: 56 --- bets_value: Away -5 --- bets_odd: 2.02
#   __________________________57 Home Corners Over/Under
#   ______________________  ______________________bet_id: 57 --- bets_value: Over 7.5 --- bets_odd: 1.67
#   ______________________  ______________________bet_id: 57 --- bets_value: Under 7.5 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 57 --- bets_value: Over 8.5 --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 57 --- bets_value: Under 8.5 --- bets_odd: 1.80
#   __________________________58 Away Corners Over/Under
#   ______________________  ______________________bet_id: 58 --- bets_value: Over 3.5 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 58 --- bets_value: Under 3.5 --- bets_odd: 1.62
#   ______________________  ______________________bet_id: 58 --- bets_value: Over 2.5 --- bets_odd: 1.57
#   ______________________  ______________________bet_id: 58 --- bets_value: Under 2.5 --- bets_odd: 2.25
#   __________________________85 Total Corners (3 way)
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 10 --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 10 --- bets_odd: 2.25
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 10 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 11 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 11 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 11 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 12 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 12 --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 12 --- bets_odd: 9.00
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   __________________________75 Last Corner
#   ______________________  ______________________bet_id: 75 --- bets_value: Home --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 75 --- bets_value: Away --- bets_odd: 4.00
#   __________________________76 First Corner
#   ______________________  ______________________bet_id: 76 --- bets_value: Home --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 76 --- bets_value: Away --- bets_odd: 4.00
#   __________________________78 RTG_H1
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 3.25
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 3.25
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 12.00
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
#   ____________2. 2023-03-10 // 91 // 11 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 88
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-10
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 91
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 3
#
#   ____________________1. Netherlands,  Eredivisie Women  #91 - 2022 / 913334
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '38.00',
#   ____________________________end_match_winner_draw = '17.00',
#   ____________________________end_match_winner_away = '1.03',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '32.00',
#   ____________________________end_second_half_winner_draw = '7.20',
#   ____________________________end_second_half_winner_away = '1.07',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '21.00',
#   ____________________________end_asian_handicap_away_plus_0 = '1.00',
#   ____________________________end_asian_handicap_home_plus_15 = '5.95',
#   ____________________________end_asian_handicap_away_plus_15 = '1.08',
#   ____________________________end_asian_handicap_home_plus_2 = '5.55',
#   ____________________________end_asian_handicap_away_plus_2 = '1.10',
#   ____________________________end_asian_handicap_home_plus_3 = '2.75',
#   ____________________________end_asian_handicap_away_plus_3 = '1.37',
#   ____________________________end_asian_handicap_home_plus_25 = '3.28',
#   ____________________________end_asian_handicap_away_plus_25 = '1.27',
#   ____________________________end_asian_handicap_home_plus_225 = '4.06',
#   ____________________________end_asian_handicap_away_plus_225 = '1.19',
#   ____________________________end_asian_handicap_home_plus_325 = '2.31',
#   ____________________________end_asian_handicap_away_plus_325 = '1.53',
#   ____________________________end_asian_handicap_home_plus_275 = '2.99',
#   ____________________________end_asian_handicap_away_plus_275 = '1.33',
#   ____________________________end_asian_handicap_home_plus_35 = '2.06',
#   ____________________________end_asian_handicap_away_plus_35 = '1.66',
#   ____________________________end_asian_handicap_home_plus_4 = '1.76',
#   ____________________________end_asian_handicap_away_plus_4 = '2.03',
#   ____________________________end_asian_handicap_home_plus_375 = '1.94',
#   ____________________________end_asian_handicap_away_plus_375 = '1.84',
#   ____________________________end_asian_handicap_home_plus_45 = '1.50',
#   ____________________________end_asian_handicap_away_plus_45 = '2.38',
#   ____________________________end_asian_handicap_home_plus_425 = '1.59',
#   ____________________________end_asian_handicap_away_plus_425 = '2.17',
#   ____________________________end_asian_handicap_home_plus_55 = '1.22',
#   ____________________________end_asian_handicap_away_plus_55 = '3.64',
#   ____________________________end_asian_handicap_home_plus_5 = '1.28',
#   ____________________________end_asian_handicap_away_plus_5 = '3.20',
#   ____________________________end_asian_handicap_home_plus_475 = '1.40',
#   ____________________________end_asian_handicap_away_plus_475 = '2.68',
#   ____________________________end_asian_handicap_home_plus_575 = '1.16',
#   ____________________________end_asian_handicap_away_plus_575 = '4.46',
#   ____________________________end_asian_handicap_home_plus_525 = '1.26',
#   ____________________________end_asian_handicap_away_plus_525 = '3.42',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '1.37',
#   ____________________________end_goals_overunder_under_35 = '2.75',
#   ____________________________end_goals_overunder_over_15 = '1.01',
#   ____________________________end_goals_overunder_under_15 = '13.00',
#   ____________________________end_goals_overunder_over_45 = '1.90',
#   ____________________________end_goals_overunder_under_45 = '1.88',
#   ____________________________end_goals_overunder_over_25 = '1.12',
#   ____________________________end_goals_overunder_under_25 = '5.05',
#   ____________________________end_goals_overunder_over_55 = '2.71',
#   ____________________________end_goals_overunder_under_55 = '1.38',
#   ____________________________end_goals_overunder_over_325 = '1.28',
#   ____________________________end_goals_overunder_under_325 = '3.28',
#   ____________________________end_goals_overunder_over_275 = '1.14',
#   ____________________________end_goals_overunder_under_275 = '4.72',
#   ____________________________end_goals_overunder_over_425 = '1.74',
#   ____________________________end_goals_overunder_under_425 = '2.07',
#   ____________________________end_goals_overunder_over_375 = '1.45',
#   ____________________________end_goals_overunder_under_375 = '2.52',
#   ____________________________end_goals_overunder_over_475 = '2.03',
#   ____________________________end_goals_overunder_under_475 = '1.68',
#   ____________________________end_goals_overunder_over_65 = '4.32',
#   ____________________________end_goals_overunder_under_65 = '1.16',
#   ____________________________end_goals_overunder_over_75 = '5.05',
#   ____________________________end_goals_overunder_under_75 = '1.12',
#   ____________________________end_goals_overunder_over_525 = '2.52',
#   ____________________________end_goals_overunder_under_525 = '1.45',
#   ____________________________end_goals_overunder_over_575 = '3.16',
#   ____________________________end_goals_overunder_under_575 = '1.30',
#   ____________________________end_goals_overunder_over_625 = '4.10',
#   ____________________________end_goals_overunder_under_625 = '1.18',
#   ____________________________end_goals_overunder_over_675 = '3.66',
#   ____________________________end_goals_overunder_under_675 = '1.23',
#   ____________________________end_goals_overunder_over_30 = '1.16',
#   ____________________________end_goals_overunder_under_30 = '4.34',
#   ____________________________end_goals_overunder_over_40 = '1.53',
#   ____________________________end_goals_overunder_under_40 = '2.30',
#   ____________________________end_goals_overunder_over_50 = '2.30',
#   ____________________________end_goals_overunder_under_50 = '1.53',
#   ____________________________end_goals_overunder_under_60 = '1.21',
#   ____________________________end_goals_overunder_over_60 = '3.74',
#   ____________________________end_goals_overunder_under_70 = '1.06',
#   ____________________________end_goals_overunder_over_70 = '6.65',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_15 = '1.56',
#   ____________________________end_goals_overunder_first_half_under_15 = '2.28',
#   ____________________________end_goals_overunder_first_half_over_25 = '2.69',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.41',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.09',
#   ____________________________end_goals_overunder_first_half_under_05 = '6.10',
#   ____________________________end_goals_overunder_first_half_over_225 = '2.34',
#   ____________________________end_goals_overunder_first_half_under_225 = '1.53',
#   ____________________________end_goals_overunder_first_half_over_275 = '2.70',
#   ____________________________end_goals_overunder_first_half_under_275 = '1.41',
#   ____________________________end_goals_overunder_first_half_over_125 = '1.36',
#   ____________________________end_goals_overunder_first_half_under_125 = '2.90',
#   ____________________________end_goals_overunder_first_half_over_175 = '1.73',
#   ____________________________end_goals_overunder_first_half_under_175 = '2.00',
#   ____________________________end_goals_overunder_first_half_over_20 = '2.02',
#   ____________________________end_goals_overunder_first_half_under_20 = '1.71',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '2.59',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.44',
#   ____________________________end_goals_overunder__second_half_over_25 = '1.90',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.81',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.01',
#   ____________________________end_goals_overunder__second_half_under_05 = '11.00',
#   ____________________________end_goals_overunder__second_half_over_225 = '1.68',
#   ____________________________end_goals_overunder__second_half_under_225 = '2.06',
#   ____________________________end_goals_overunder__second_half_over_325 = '2.77',
#   ____________________________end_goals_overunder__second_half_under_325 = '1.39',
#   ____________________________end_goals_overunder__second_half_over_275 = '2.16',
#   ____________________________end_goals_overunder__second_half_under_275 = '1.62',
#   ____________________________end_goals_overunder__second_half_over_175 = '1.36',
#   ____________________________end_goals_overunder__second_half_under_175 = '2.90',
#   ____________________________end_goals_overunder__second_half_over_30 = '2.62',
#   ____________________________end_goals_overunder__second_half_under_30 = '1.43',
#   ____________________________end_goals_overunder__second_half_over_20 = '1.46',
#   ____________________________end_goals_overunder__second_half_under_20 = '2.53',
#   __________________________7 HT/FT Double
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 6.25
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 5.55
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 1.27
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 3.28
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 4.54
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 1.66
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +4 --- bets_odd: 2.06
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +4 --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +4 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +5 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +5 --- bets_odd: 3.64
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +5 --- bets_odd: 5.30
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +6 --- bets_odd: 1.26
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +6 --- bets_odd: 5.55
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +6 --- bets_odd: 6.60
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
# ...
#   __________________________________end_asian_handicap_home_plus_075 = '1.53',
#   __________________________________end_asian_handicap_away_plus_075 = '2.30',
#   __________________________________end_asian_handicap_home_min_1 = '8.40',
#   __________________________________end_asian_handicap_away_min_1 = '1.03',
#   __________________________________end_asian_handicap_home_plus_1 = '1.31',
#   __________________________________end_asian_handicap_away_plus_1 = '3.04',
#   __________________________________end_asian_handicap_home_min_15 = '9.30',
#   __________________________________end_asian_handicap_away_min_15 = '1.02',
#   __________________________________end_asian_handicap_home_plus_15 = '1.18',
#   __________________________________end_asian_handicap_away_plus_15 = '4.00',
#   __________________________________end_asian_handicap_home_plus_125 = '1.25',
#   __________________________________end_asian_handicap_away_plus_125 = '3.48',
#   __________________________________end_asian_handicap_home_plus_2 = '1.03',
#   __________________________________end_asian_handicap_away_plus_2 = '8.00',
#   __________________________________end_asian_handicap_home_plus_25 = '1.02',
#   __________________________________end_asian_handicap_away_plus_25 = '8.90',
#   ________________________________5 Goals Over/Under
#   __________________________________end_goals_overunder_over_35 = '5.15',
#   __________________________________end_goals_overunder_under_35 = '1.11',
#   __________________________________end_goals_overunder_over_15 = '1.56',
#   __________________________________end_goals_overunder_under_15 = '2.39',
#   __________________________________end_goals_overunder_over_45 = '9.80',
#   __________________________________end_goals_overunder_under_45 = '1.02',
#   __________________________________end_goals_overunder_over_25 = '2.57',
#   __________________________________end_goals_overunder_under_25 = '1.42',
#   __________________________________end_goals_overunder_over_05 = '1.08',
#   __________________________________end_goals_overunder_under_05 = '6.00',
#   __________________________________end_goals_overunder_over_225 = '2.29',
#   __________________________________end_goals_overunder_under_225 = '1.54',
#   __________________________________end_goals_overunder_over_275 = '3.19',
#   __________________________________end_goals_overunder_under_275 = '1.29',
#   __________________________________end_goals_overunder_over_125 = '1.33',
#   __________________________________end_goals_overunder_under_125 = '2.96',
#   __________________________________end_goals_overunder_over_175 = '1.73',
#   __________________________________end_goals_overunder_under_175 = '2.08',
#   __________________________________end_goals_overunder_over_075 = '1.11',
#   __________________________________end_goals_overunder_under_075 = '5.40',
#   __________________________________end_goals_overunder_over_30 = '4.32',
#   __________________________________end_goals_overunder_under_30 = '1.16',
#   __________________________________end_goals_overunder_over_20 = '1.95',
#   __________________________________end_goals_overunder_under_20 = '1.74',
#   __________________________________end_goals_overunder_over_40 = '7.90',
#   __________________________________end_goals_overunder_under_40 = '1.05',
#   __________________________________end_goals_overunder_over_10 = '1.14',
#   __________________________________end_goals_overunder_under_10 = '4.74',
#   ________________________________6 Goals Over/Under First Half
#   __________________________________end_goals_overunder_first_half_over_35 = '41.00',
#   __________________________________end_goals_overunder_first_half_over_15 = '3.74',
#   __________________________________end_goals_overunder_first_half_under_15 = '1.23',
#   __________________________________end_goals_overunder_first_half_over_25 = '9.00',
#   __________________________________end_goals_overunder_first_half_under_25 = '1.03',
#   __________________________________end_goals_overunder_first_half_over_05 = '1.57',
#   __________________________________end_goals_overunder_first_half_under_05 = '2.26',
#   __________________________________end_goals_overunder_first_half_over_125 = '3.10',
#   __________________________________end_goals_overunder_first_half_under_125 = '1.32',
#   __________________________________end_goals_overunder_first_half_over_075 = '1.84',
#   __________________________________end_goals_overunder_first_half_under_075 = '1.87',
#   __________________________________end_goals_overunder_first_half_over_10 = '2.47',
#   __________________________________end_goals_overunder_first_half_under_10 = '1.48',
#   ________________________________26 Goals Over/Under - Second Half
#   __________________________________end_goals_overunder__second_half_over_15 = '2.77',
#   __________________________________end_goals_overunder__second_half_under_15 = '1.39',
#   __________________________________end_goals_overunder__second_half_over_25 = '6.20',
#   __________________________________end_goals_overunder__second_half_under_25 = '1.09',
#   __________________________________end_goals_overunder__second_half_over_05 = '1.38',
#   __________________________________end_goals_overunder__second_half_under_05 = '2.81',
#   __________________________________end_goals_overunder__second_half_over_125 = '2.30',
#   __________________________________end_goals_overunder__second_half_under_125 = '1.55',
#   __________________________________end_goals_overunder__second_half_over_075 = '1.52',
#   __________________________________end_goals_overunder__second_half_under_075 = '2.38',
#   __________________________________end_goals_overunder__second_half_over_10 = '1.83',
#   __________________________________end_goals_overunder__second_half_under_10 = '1.88',
#   ________________________________7 HT/FT Double
#   ________________________________8 Both Teams Score
#   __________________________________end_both_teams_score_yes = '2.21',
#   __________________________________end_both_teams_score_no = '1.63',
#   ________________________________9 Handicap Result
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.72
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 4.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.28
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.18
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 5.70
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 8.90
#   ________________________________10 Exact Score
#   ________________________________11 Highest Scoring Half
#   ________________________________31 Correct Score - First Half
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 6.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 23.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 41.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 81.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.26
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 10.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 3.74
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 11.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 29.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 67.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   ________________________________12 Double Chance
#   __________________________________end_double_chance_home_draw = '1.72',
#   __________________________________end_double_chance_home_away = '1.32',
#   __________________________________end_double_chance_draw_away = '1.21',
#   ________________________________13 First Half Winner
#   __________________________________end_first_half_winner_home = '5.00',
#   __________________________________end_first_half_winner_draw = '1.86',
#   __________________________________end_first_half_winner_away = '2.71',
#   ________________________________16 Total - Home
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 4.10
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.19
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.68
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 2.06
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 11.00
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.01
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 2.75
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 1.39
#   ________________________________17 Total - Away
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.48
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.48
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 6.10
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.09
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.32
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 3.10
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 4.74
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.13
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.65
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 2.10
#   ________________________________18 Handicap Result - First Half
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.35
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 8.60
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.64
#   ________________________________19 Asian Handicap First Half
#   ________________________________20 Double Chance - First Half
#   ________________________________33 Double Chance - Second Half
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.44
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.54
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.13
#   ________________________________34 Both Teams Score - First Half
#   ________________________________35 Both Teams To Score - Second Half
#   ________________________________21 Odd/Even
#   ________________________________22 Odd/Even - First Half
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.16
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.59
#   ________________________________23 Home Odd/Even
#   ____________________________  ____________________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.23
#   ____________________________  ____________________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.55
#   ________________________________60 Away Odd/Even
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.95
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.72
#   ____________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ______________________________ff_update_unfinished__
#   ____________________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-16 14:52:40

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 14:52:40
#   __main()
#   ____get_date()
#   ______days : 6
#   ______days : 5
#   ______tgl_awal : 2023-03-10
#   ______tgl_akhir : 2023-03-11
#   ________ff_get_fixture_status_match_finished()
#   __________Total Row(s) : 97
#   __________1. 2023-03-10 // 11 // 8 // 2023 // 981709 // 05_025_0#H // 175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981709
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-03-10 // 11 // 8 // 2023 // 981710 // 15_125_1_075_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981710
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-03-10 // 11 // 8 // 2023 // 981711 // 1_075_05_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981711
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________4. 2023-03-10 // 13 // 8 // 2023 // 1011460 // 15_125_1_075_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011460
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________5. 2023-03-10 // 64 // 11 // 2022 // 931866 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 931866
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________6. 2023-03-10 // 64 // 11 // 2022 // 931869 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 931869
#   ____________> end_ah_pattern = 075+1+125+15+175+H
#   ____________> end_ah_pattern_mirror = 175_15_125_1_075_H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________7. 2023-03-10 // 73 // 8 // 2023 // 1012105 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1012105
#   ____________> end_ah_pattern = 175_H
#   ____________> end_ah_pattern_mirror = 175+H
#   ____________> end_gou_pattern = 25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________8. 2023-03-10 // 87 // 8 // 2022 // 905230 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 905230
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________9. 2023-03-10 // 87 // 8 // 2022 // 905232 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 905232
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________10. 2023-03-10 // 87 // 8 // 2022 // 905237 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 905237
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________11. 2023-03-10 // 91 // 11 // 2022 // 913333 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 913333
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________12. 2023-03-10 // 91 // 11 // 2022 // 913334 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 913334
#   ____________> end_ah_pattern = 325+35+375+4+425+45+H
#   ____________> end_ah_pattern_mirror = 45_425_4_375_35_325_H
#   ____________> end_gou_pattern = 375g4g425g45g475g5g525gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________13. 2023-03-10 // 91 // 11 // 2022 // 913335 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 913335
#   ____________> end_ah_pattern = 575_55_525_H
#   ____________> end_ah_pattern_mirror = 525+55+575+H
#   ____________> end_gou_pattern = 6g625g65g675g7g75gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________14. 2023-03-10 // 111 // 11 // 2022 // 892817 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 892817
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________15. 2023-03-10 // 111 // 11 // 2022 // 892818 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 892818
#   ____________> end_ah_pattern = 15+2+H
#   ____________> end_ah_pattern_mirror = 2_15_H
#   ____________> end_gou_pattern = 25g3g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________16. 2023-03-10 // 111 // 11 // 2022 // 892824 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 892824
#   ____________> end_ah_pattern = 025+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_025_H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________17. 2023-03-10 // 111 // 11 // 2022 // 892866 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 892866
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________18. 2023-03-10 // 111 // 11 // 2022 // 893057 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 893057
#   ____________> end_ah_pattern = 1+15+H
#   ____________> end_ah_pattern_mirror = 15_1_H
#   ____________> end_gou_pattern = 25g3g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________19. 2023-03-10 // 111 // 11 // 2022 // 893058 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 893058
#   ____________> end_ah_pattern = 1_H
#   ____________> end_ah_pattern_mirror = 1+H
#   ____________> end_gou_pattern = 3g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________20. 2023-03-10 // 111 // 11 // 2022 // 893059 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 893059
#   ____________> end_ah_pattern = 1+H
#   ____________> end_ah_pattern_mirror = 1_H
#   ____________> end_gou_pattern = 25g3g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________21. 2023-03-10 // 111 // 11 // 2022 // 893060 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 893060
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 25g3g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________22. 2023-03-10 // 131 // 11 // 2023 // 987027 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 987027
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________23. 2023-03-10 // 132 // 11 // 2023 // 988047 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988047
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________24. 2023-03-10 // 132 // 11 // 2023 // 988048 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988048
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________25. 2023-03-10 // 132 // 11 // 2023 // 988050 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988050
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________26. 2023-03-10 // 132 // 11 // 2023 // 988051 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988051
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________27. 2023-03-10 // 132 // 11 // 2023 // 988052 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988052
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________28. 2023-03-10 // 136 // 8 // 2022 // 903824 // 075_05_025_H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 903824
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________29. 2023-03-10 // 192 // 11 // 2023 // 982278 // 0#025+075+H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 982278
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________30. 2023-03-10 // 208 // 11 // 2022 // 869393 // 025+075+1+H // 225g25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 869393
#   ____________> end_ah_pattern = 025+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_025_H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________31. 2023-03-10 // 219 // 8 // 2022 // 878982 // 05_025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 878982
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________32. 2023-03-10 // 219 // 8 // 2022 // 878983 // 05+075+1+125+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 878983
#   ____________> end_ah_pattern = 05+075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_05_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________33. 2023-03-10 // 219 // 8 // 2022 // 878984 // 025_0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 878984
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________34. 2023-03-10 // 219 // 8 // 2022 // 878985 // 075_05_025_0#H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 878985
#   ____________> end_ah_pattern = 075_05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________35. 2023-03-10 // 219 // 8 // 2022 // 878986 // 05+075+1+125+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 878986
#   ____________> end_ah_pattern = 05+075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_05_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________36. 2023-03-10 // 219 // 8 // 2022 // 878988 // 025_0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 878988
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________37. 2023-03-10 // 221 // 11 // 2022 // 896664 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896664
#   ____________> end_ah_pattern = 025+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_025_H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________38. 2023-03-10 // 221 // 11 // 2022 // 896665 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896665
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________39. 2023-03-10 // 221 // 11 // 2022 // 896666 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896666
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________40. 2023-03-10 // 222 // 11 // 2022 // 896407 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896407
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________41. 2023-03-10 // 222 // 11 // 2022 // 896408 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896408
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________42. 2023-03-10 // 222 // 11 // 2022 // 896409 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896409
#   ____________> end_ah_pattern = 2_175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+2+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________43. 2023-03-10 // 222 // 11 // 2022 // 896411 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896411
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________44. 2023-03-10 // 222 // 11 // 2022 // 896414 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896414
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________45. 2023-03-10 // 291 // 11 // 2022 // 998355 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998355
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________46. 2023-03-10 // 291 // 11 // 2022 // 998357 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998357
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 125g15g175g2gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________47. 2023-03-10 // 291 // 11 // 2022 // 998358 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998358
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 125g15g175g2gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________48. 2023-03-10 // 291 // 11 // 2022 // 998359 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998359
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________49. 2023-03-10 // 291 // 11 // 2022 // 998360 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998360
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 125g15g175g2gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________50. 2023-03-10 // 291 // 11 // 2022 // 998361 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998361
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________51. 2023-03-10 // 296 // 11 // 2022 // 974514 // 025_0#H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974514
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________52. 2023-03-10 // 297 // 11 // 2022 // 974659 // 15_1_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974659
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________53. 2023-03-10 // 301 // 8 // 2022 // 986022 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 986022
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________54. 2023-03-10 // 301 // 8 // 2022 // 986023 // 025+05+075+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 986023
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________55. 2023-03-10 // 301 // 8 // 2022 // 986024 // 025_0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 986024
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________56. 2023-03-10 // 301 // 8 // 2022 // 986027 // 075_05_025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 986027
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________57. 2023-03-10 // 307 // 8 // 2022 // 976684 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 976684
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________58. 2023-03-10 // 307 // 8 // 2022 // 976687 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 976687
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________59. 2023-03-10 // 357 // 8 // 2023 // 1002547 // 1_075_05_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1002547
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________60. 2023-03-10 // 357 // 8 // 2023 // 1002548 // 025+05+075+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1002548
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________61. 2023-03-10 // 357 // 8 // 2023 // 1002549 // 05_025_0#H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1002549
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________62. 2023-03-10 // 357 // 8 // 2023 // 1002550 // 025+05+075+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1002550
#   ____________> end_ah_pattern = 025+05+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_05_025_H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________63. 2023-03-10 // 358 // 8 // 2023 // 998565 // 075+1+125+15+175+H // 35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998565
#   ____________> end_ah_pattern = 05+075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_05_H
#   ____________> end_gou_pattern = 25g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________64. 2023-03-10 // 358 // 8 // 2023 // 998566 // 075_05_025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998566
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________65. 2023-03-10 // 358 // 8 // 2023 // 998567 // 25_225_2_175_15_H // 35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998567
#   ____________> end_ah_pattern = 275_25_225_2_175_H
#   ____________> end_ah_pattern_mirror = 175+2+225+25+275+H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________66. 2023-03-10 // 358 // 8 // 2023 // 998568 // 05_025_0#H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998568
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________67. 2023-03-10 // 358 // 8 // 2023 // 998569 // 025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998569
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________68. 2023-03-10 // 361 // 11 // 2023 // 1011567 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011567
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 25g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________69. 2023-03-10 // 368 // 11 // 2023 // 997872 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 997872
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 325g35g375g4g425g45gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________70. 2023-03-10 // 368 // 11 // 2023 // 997873 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 997873
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 325g35g375g4g425g45gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________71. 2023-03-10 // 369 // 11 // 2023 // 1005553 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1005553
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________72. 2023-03-10 // 369 // 11 // 2023 // 1005554 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1005554
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________73. 2023-03-10 // 374 // 11 // 2022 // 885706 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 885706
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________74. 2023-03-10 // 406 // 11 // 2022 // 986507 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 986507
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________75. 2023-03-10 // 453 // 11 // 2022 // 957514 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 957514
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________76. 2023-03-10 // 488 // 11 // 2022 // 900404 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 900404
#   ____________> end_ah_pattern = 275_25_225_2_175_H
#   ____________> end_ah_pattern_mirror = 175+2+225+25+275+H
#   ____________> end_gou_pattern = 35g375g4g425g45g475gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________77. 2023-03-10 // 496 // 11 // 2022 // 934580 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934580
#   ____________> end_ah_pattern = 15_1_H
#   ____________> end_ah_pattern_mirror = 1+15+H
#   ____________> end_gou_pattern = 3g35g4gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________78. 2023-03-10 // 496 // 11 // 2022 // 934582 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934582
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________79. 2023-03-10 // 496 // 11 // 2022 // 934583 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934583
#   ____________> end_ah_pattern = 1+H
#   ____________> end_ah_pattern_mirror = 1_H
#   ____________> end_gou_pattern = 2g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________80. 2023-03-10 // 496 // 11 // 2022 // 934585 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934585
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________81. 2023-03-10 // 496 // 11 // 2022 // 934586 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934586
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________82. 2023-03-10 // 496 // 11 // 2022 // 934587 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934587
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 25g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________83. 2023-03-10 // 496 // 11 // 2022 // 934818 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934818
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________84. 2023-03-10 // 496 // 11 // 2022 // 934821 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934821
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________85. 2023-03-10 // 667 // 8 // 2023 // 992139 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992139
#   ____________> end_ah_pattern = 125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________86. 2023-03-10 // 667 // 8 // 2023 // 994338 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 994338
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________87. 2023-03-10 // 667 // 8 // 2023 // 999291 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 999291
#   ____________> end_ah_pattern = 025_H
#   ____________> end_ah_pattern_mirror = 025+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________88. 2023-03-10 // 701 // 11 // 2022 // 992383 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992383
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________89. 2023-03-10 // 701 // 11 // 2022 // 992386 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992386
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________90. 2023-03-10 // 705 // 8 // 2022 // 915523 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 915523
#   ____________> end_ah_pattern = 075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________91. 2023-03-10 // 753 // 11 // 2022 // 907094 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 907094
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________92. 2023-03-10 // 887 // 11 // 2022 // 964786 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964786
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________93. 2023-03-10 // 887 // 11 // 2022 // 964787 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964787
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________94. 2023-03-10 // 888 // 11 // 2022 // 965020 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965020
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________95. 2023-03-10 // 888 // 11 // 2022 // 965022 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965022
#   ____________> end_ah_pattern = 1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________96. 2023-03-10 // 888 // 11 // 2022 // 965023 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965023
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________97. 2023-03-10 // 888 // 11 // 2022 // 965026 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965026
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
# # -------------------------------------------------- End at 2023-03-16 15:01:29

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 15:01:29
#   __main()
#   ____get_date()
#   ______days : 6
#   ______days : 5
#   ______tgl_awal : 2023-03-10
#   ______tgl_akhir : 2023-03-11
#   ________ff_get_fixture_status_match_finished_for_daily_update_patternlist()
#   ________Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date <= '2023-03-11'  and date >= '2023-03-10'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 200
#   ____________[1/200] #883189 #Romania 283-2022 / Universitatea Craiova vs Uta Arad
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:1_075_05_H -- end-gou:2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:26:21
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '283'  and league_country = 'Romania'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[2/200] #883194 #Romania 283-2022 / FC Botosani vs CS Mioveni
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:26:22
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '283'  and league_country = 'Romania'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[3/200] #865292 #Poland 106-2022 / Lechia Gdansk vs Miedz Legnica
#   ____________pre-ah:05_025_0#H -- pre-gou:225g25g275gG -/- end-ah:05_025_0#025+H -- end-gou:225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '106'  and league_country = 'Poland'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[4/200] #865294 #Poland 106-2022 / Raków Częstochowa vs Slask Wroclaw
#   ____________pre-ah:175_15_125_H -- pre-gou:225g25g275g3gG -/- end-ah:175_15_125_H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '106'  and league_country = 'Poland'  and pre_ah_pattern = '175_15_125_H'  and pre_ah_pattern_mirror = '125+15+175+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[5/200] #881749 #Denmark 119-2022 / Odense vs Aalborg
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:24:15
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '119'  and league_country = 'Denmark'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[6/200] #880017 #Russia 235-2022 / PFC Sochi vs Orenburg
#   ____________pre-ah:075_025_H -- pre-gou:275g3g325g35gG -/- end-ah:125_1_075_025_H -- end-gou:25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:25:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '235'  and league_country = 'Russia'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '275g3g325g35gG'  and end_ah_pattern = '125_1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+125+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[7/200] #866498 #Croatia 210-2022 / HNK Gorica vs Istra 1961
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:25:36
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '210'  and league_country = 'Croatia'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[8/200] #876863 #Slovenia 373-2022 / Gorica vs Mura
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:0#025+05+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:27:23
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '373'  and league_country = 'Slovenia'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[9/200] #873071 #Germany 79-2022 / FC Nurnberg vs Eintracht Braunschweig
#   ____________pre-ah:075_05_025_H -- pre-gou:225g25g275gG -/- end-ah:05_025_0#H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:13
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '79'  and league_country = 'Germany'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[10/200] #873077 #Germany 79-2022 / FC Kaiserslautern vs SV Sandhausen
#   ____________pre-ah:1_075_05_H -- pre-gou:225g25g275gG -/- end-ah:125_1_075_05_H -- end-gou:225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:14
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '79'  and league_country = 'Germany'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[11/200] #867070 #Poland 107-2022 / Podbeskidzie vs Chrobry Głogów
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:1_075_05_H -- end-gou:225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:24:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '107'  and league_country = 'Poland'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[12/200] #867073 #Poland 107-2022 / Chojniczanka Chojnice vs Ruch Chorzów
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:0#025+05+075+H -- end-gou:2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:24:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '107'  and league_country = 'Poland'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '0#025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_0#H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[13/200] #883501 #Bulgaria 172-2022 / Septemvri Sofia vs Botev Plovdiv
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_0#025+05+H -- end-gou:25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:25:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '172'  and league_country = 'Bulgaria'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[14/200] #882786 #Bulgaria 173-2022 / Etar Veliko Tarnovo vs Sportist Svoge
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:125_1_075_H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:25:10
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '173'  and league_country = 'Bulgaria'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[15/200] #874987 #Belgium 144-2022 / Charleroi vs OH Leuven
#   ____________pre-ah:075_05_025_H -- pre-gou:225g25g275g3gG -/- end-ah:075_05_025_H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:24:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '144'  and league_country = 'Belgium'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 5
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 5
#   ____________________patternlists updated
#
#   ____________[16/200] #879370 #Germany 80-2022 / Verl vs Hallescher FC
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_0#H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:16
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '80'  and league_country = 'Germany'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+075+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[17/200] #869393 #Switzerland 208-2022 / FC Schaffhausen vs Lausanne
#   ____________pre-ah:025+075+1+H -- pre-gou:225g25g275g3g325g35gG -/- end-ah:025+075+1+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 13:25:34
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '208'  and league_country = 'Switzerland'  and pre_ah_pattern = '025+075+1+H'  and pre_ah_pattern_mirror = '1_075_025_H'  and pre_gou_pattern = '225g25g275g3g325g35gG'  and end_ah_pattern = '025+075+1+H'  and end_ah_pattern_mirror = '1_075_025_H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[18/200] #878982 #Austria 219-2022 / FC Liefering vs SV Horn
#   ____________pre-ah:05_025_0#025+H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:25g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 13:25:41
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '219'  and league_country = 'Austria'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '25g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[19/200] #878983 #Austria 219-2022 / Austria Vienna (Am) vs SKN ST. Polten
#   ____________pre-ah:05+075+1+125+H -- pre-gou:25gG -/- end-ah:05+075+1+125+15+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 13:25:45
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '219'  and league_country = 'Austria'  and pre_ah_pattern = '05+075+1+125+H'  and pre_ah_pattern_mirror = '125_1_075_05_H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05+075+1+125+15+H'  and end_ah_pattern_mirror = '15_125_1_075_05_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[20/200] #878984 #Austria 219-2022 / SKU Amstetten vs Floridsdorfer AC
#   ____________pre-ah:025_0#025+05+H -- pre-gou:25gG -/- end-ah:0#025+05+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 13:25:42
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '219'  and league_country = 'Austria'  and pre_ah_pattern = '025_0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 5
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 5
#   ____________________patternlists updated
#
#   ____________[21/200] #878985 #Austria 219-2022 / SK Vorwarts Steyr vs SV Kapfenberg
#   ____________pre-ah:075_05_025_0#H -- pre-gou:25gG -/- end-ah:075_05_025_0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 13:25:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '219'  and league_country = 'Austria'  and pre_ah_pattern = '075_05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+075+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '075_05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[22/200] #878986 #Austria 219-2022 / SV Lafnitz vs FC BW Linz
#   ____________pre-ah:05+075+1+125+H -- pre-gou:25gG -/- end-ah:05+075+1+125+15+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 13:25:43
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '219'  and league_country = 'Austria'  and pre_ah_pattern = '05+075+1+125+H'  and pre_ah_pattern_mirror = '125_1_075_05_H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05+075+1+125+15+H'  and end_ah_pattern_mirror = '15_125_1_075_05_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[23/200] #878988 #Austria 219-2022 / First Vienna vs Grazer AK
#   ____________pre-ah:025_0#025+05+H -- pre-gou:25gG -/- end-ah:025_0#025+05+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 13:25:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '219'  and league_country = 'Austria'  and pre_ah_pattern = '025_0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 5
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 5
#   ____________________patternlists updated
#
#   ____________[24/200] #904273 #Germany 83-2022 / Bayern München II vs Buchbach
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:175_15_125_1_H -- end-gou:25g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:21
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '83'  and league_country = 'Germany'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '25g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[25/200] #881148 #England 40-2022 / Stoke City vs Blackburn
#   ____________pre-ah:075_05_025_H -- pre-gou:2g225g25g275gG -/- end-ah:075_05_025_H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:22:46
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '40'  and league_country = 'England'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[26/200] #876475 #England 42-2022 / Crewe vs Salford City
#   ____________pre-ah:025+05+075+H -- pre-gou:225g25g275gG -/- end-ah:025+05+075+H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:22:49
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '42'  and league_country = 'England'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[27/200] #871737 #France 61-2022 / Lille vs Lyon
#   ____________pre-ah:075_05_025_H -- pre-gou:225g25g275g3g325gG -/- end-ah:075_05_025_H -- end-gou:25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:22:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '61'  and league_country = 'France'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[28/200] #914091 #France 63-2022 / Chateauroux vs Concarneau
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_0#025+H -- end-gou:15g175g2g225gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[29/200] #914092 #France 63-2022 / Sedan vs Bourg-en-bresse 01
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_0#025+H -- end-gou:15g175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:04
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '15g175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[30/200] #914093 #France 63-2022 / Gobelins vs Martigues
#   ____________pre-ah:0#H -- pre-gou:25gG -/- end-ah:025_0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:22:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '0#H'  and pre_ah_pattern_mirror = '0#H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[31/200] #914094 #France 63-2022 / RED Star FC 93 vs Le Puy Foot
#   ____________pre-ah:15_H -- pre-gou:25gG -/- end-ah:15_125_1_075_H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:22:59
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '15_H'  and pre_ah_pattern_mirror = '15+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[32/200] #914095 #France 63-2022 / Cholet vs Nancy
#   ____________pre-ah:025_0#025+H -- pre-gou:175g2g225g25g275gG -/- end-ah:025_0#025+H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:22:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '175g2g225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[33/200] #914096 #France 63-2022 / Stade Briochin vs Dunkerque
#   ____________pre-ah:0#H -- pre-gou:25gG -/- end-ah:025_0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:22:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '0#H'  and pre_ah_pattern_mirror = '0#H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[34/200] #914097 #France 63-2022 / Avranches vs Le Mans
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:0#025+075+H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[35/200] #924498 #France 63-2022 / Villefranche vs Orleans
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_0#H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:03
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#H'  and end_ah_pattern_mirror = '0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[36/200] #899779 #Indonesia 274-2022 / Cilegon United vs Persis Solo
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275g3g325gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:26:14
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '274'  and league_country = 'Indonesia'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[37/200] #899781 #Indonesia 274-2022 / Arema FC vs Dewa United
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275g3gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:26:15
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '274'  and league_country = 'Indonesia'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[38/200] #903824 #Italy 136-2022 / Cagliari vs Ascoli
#   ____________pre-ah:075_05_025_H -- pre-gou:175g2g225g25gG -/- end-ah:075_05_025_H -- end-gou:175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 13:24:49
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '136'  and league_country = 'Italy'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[39/200] #882039 #Italy 135-2022 / Spezia vs Inter
#   ____________pre-ah:075+1+125+15+H -- pre-gou:225g25g275g3gG -/- end-ah:1+125+15+175+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:24:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '135'  and league_country = 'Italy'  and pre_ah_pattern = '075+1+125+15+H'  and pre_ah_pattern_mirror = '15_125_1_075_H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '1+125+15+175+H'  and end_ah_pattern_mirror = '175_15_125_1_H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[40/200] #873424 #Scotland 180-2022 / Queen's Park vs Cove Rangers
#   ____________pre-ah:15_125_1_075_H -- pre-gou:25g275g3g325gG -/- end-ah:15_125_1_075_H -- end-gou:275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:25:12
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '180'  and league_country = 'Scotland'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '25g275g3g325gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[41/200] #867835 #Netherlands 89-2022 / Dordrecht vs De Graafschap
#   ____________pre-ah:0#025+H -- pre-gou:225g25g275g3g325gG -/- end-ah:075+1+125+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:38
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '89'  and league_country = 'Netherlands'  and pre_ah_pattern = '0#025+H'  and pre_ah_pattern_mirror = '025_0#H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[42/200] #867836 #Netherlands 89-2022 / FC Eindhoven vs Jong Ajax
#   ____________pre-ah:075_025_0#H -- pre-gou:25g275g3g325g35gG -/- end-ah:075_025_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '89'  and league_country = 'Netherlands'  and pre_ah_pattern = '075_025_0#H'  and pre_ah_pattern_mirror = '0#025+075+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[43/200] #867837 #Netherlands 89-2022 / Helmond Sport vs Jong PSV
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_0#025+H -- end-gou:225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:23:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '89'  and league_country = 'Netherlands'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
# ...
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '125_1_H'  and end_ah_pattern_mirror = '1+125+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[185/200] #994338 #World 667-2023 / Honka vs Kristiansund BK
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 14:52:19
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#H'  and end_ah_pattern_mirror = '0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[186/200] #999291 #World 667-2023 / Bærum vs Strommen
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 14:52:22
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_H'  and end_ah_pattern_mirror = '025+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[187/200] #1012052 #Slovakia 332-2022 / AS Trencin vs Ružomberok
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:05_025_0#025+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:26:53
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '332'  and league_country = 'Slovakia'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[188/200] #990901 #Wales 110-2022 / Cardiff MET vs Newtown AFC
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_05_025_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:24:03
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '110'  and league_country = 'Wales'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[189/200] #1011473 #Ivory-Coast 386-2022 / Stade d'Abidjan vs ES Bafing
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:27:36
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '386'  and league_country = 'Ivory-Coast'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[190/200] #1013015 #Ivory-Coast 386-2022 / Denguélé vs San-Pédro
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_0#H -- end-gou:15g175g2g225gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:27:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '386'  and league_country = 'Ivory-Coast'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_0#H'  and end_ah_pattern_mirror = '0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[191/200] #1012382 #Cyprus 318-2022 / Karmiotissa vs Enosis
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_0#025+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:26:48
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '318'  and league_country = 'Cyprus'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[192/200] #1000968 #Bolivia 344-2023 / Independiente Petrolero vs Libertad
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:26:55
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '344'  and league_country = 'Bolivia'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[193/200] #987027 #Argentina 131-2023 / Dock Sud vs Villa San Carlos
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_0#H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 13:24:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '131'  and league_country = 'Argentina'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_0#H'  and end_ah_pattern_mirror = '0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[194/200] #1009259 #Uruguay 269-2023 / Progreso vs Atenas
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_0#H -- end-gou:G
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:26:12
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '269'  and league_country = 'Uruguay'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_0#H'  and end_ah_pattern_mirror = '0#025+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[195/200] #987772 #Chile 266-2023 / Recoleta vs San Marcos de Arica
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_025_0#H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:26:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '266'  and league_country = 'Chile'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_025_0#H'  and end_ah_pattern_mirror = '0#025+075+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[196/200] #1006059 #Chile 711-2023 / Deportes Limache vs Provincial Osorno
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_025_H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:28:16
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '711'  and league_country = 'Chile'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[197/200] #998081 #Venezuela 299-2023 / Portuguesa FC vs Real Esppor Club
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_0#025+H -- end-gou:15g175g2g225gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 13:26:36
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '299'  and league_country = 'Venezuela'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[198/200] #997872 #Singapore 368-2023 / Tanjong Pagar vs Geylang International
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#025+075+H -- end-gou:325g35g375g4g425g45gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 14:51:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '368'  and league_country = 'Singapore'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '325g35g375g4g425g45gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[199/200] #997873 #Singapore 368-2023 / DPMM FC vs Balestier Khalsa
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:15_125_1_075_H -- end-gou:325g35g375g4g425g45gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 14:52:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '368'  and league_country = 'Singapore'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '325g35g375g4g425g45gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[200/200] #1012105 #Brazil 73-2023 / Santos vs Iguatu
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:175_H -- end-gou:25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 14:51:19
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '175_H'  and end_ah_pattern_mirror = '175+H'  and end_gou_pattern = '25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
# # -------------------------------------------------- End at 2023-03-16 16:02:20
