# %%
from a_settings.messages import *  
from a_models.date import *   
from a_models.football_odds import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------    
    day0         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    today_day    = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_get_group_league_status_match_finished(day0, day1, today_day, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-30 21:40:49
#   __main()
#   ____get_today_subs()
#   ______subs date_diff : 7
#   ______today_raw : 2023-07-23 21:40:49.609478
#   ____get_today_subs()
#   ______subs date_diff : 1
#   ______today_raw : 2023-07-29 21:40:49.611530
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-07-30 21:40:49.613610
#   ____fO_get_group_league_status_match_finished()
#   ____Select  DATE(date)  , leagueapi_id , (select bookmakersapi_id from football_leagues where leagueapi_id = football_odds.leagueapi_id)  , season , DATE(end_odd_updated_at)  , fixture_status   , count(*) as count_rows   from football_odds  where  date <= '2023-07-29'  and date >= '2023-07-23'  and fixture_status like 'Match Finished'  and deleted_at is null  group by DATE(date), leagueapi_id, season  order by date
#   ______Total Row(s) : 23
#   ______Are you sure want to continue? :  yes
# ...

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.date import * 
from a_models.football_odds import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    day0         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(1, space).strftime("%Y-%m-%d")   
    # --------------------------------------------------    
    fO_get_group_league_status_match_finished_DETAILED(day0, day1, "all_end_xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-30 22:02:17
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 7
#   ________today_raw : 2023-07-23 22:02:17.086038
#   ______get_today_subs()
#   ________subs date_diff : 1
#   ________today_raw : 2023-07-29 22:02:17.098817
#   ______fO_get_group_league_status_match_finished_DETAILED()
#   ______Select  DATE(date),  leagueapi_id,  (select bookmakersapi_id from football_leagues where football_leagues.leagueapi_id = football_odds.leagueapi_id),  season,   fixtureapi_id,   pre_ah_pattern,   pre_gou_pattern,   fixture_status   from football_odds  where date <= '2023-07-29'  and date >= '2023-07-23'  and  deleted_at is null  and end_response != 3  and fixture_status like 'Match Finished'  order by date, leagueapi_id, fixtureapi_id  desc
#   ________Total Row(s) : 72
#   ________1. 2023-07-23 // 673 // 8 // 2023 // 1041173 // H // G // Match Finished
#   __________xpN_set_pattern()
# ...

# %%
from a_settings.messages import *  
from a_models.date import *   
from a_models.football_odds import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()")  
    # --------------------------------------------------    
    today_day    = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_pattern_match_finished(today_day, 'pattern_from', space)
    fO_pattern_match_finished(today_day, 'pattern_only', space) 
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-30 22:07:34
#   __main()
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-07-30 22:07:34.484770
#   ____fO_pattern_match_finished()
#   ____ Select  leagueapi_id  from football_odds  where date <= Date('2023-07-30')  and pattern_from is null  and fixture_status IN ('Match Finished', 'Match Finished Ended')  and deleted_at is null  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  group by leagueapi_id
#   ____Total Row(s) : 106
#   ____[1/106]  #2
#   ______ff_get_fixtures_group_by_pre_end_patternlists()
# ...
