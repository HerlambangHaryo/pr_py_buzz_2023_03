# %%
# Import
from a_settings.messages import *  
from a_models.predefine import *  

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------   
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=1)
    preday1 = today + DD
    day1 = preday1.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    print(space + "> day1 : " +  str(preday1) ) 
    # --------------------------------------------------   
    pd_get_fixtures_next_match(day0, preday1, 'fixture', space) 
#     pd_get_fixtures_next_match(day0, day1, ROUTES, space)
    # --------------------------------------------------  
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-22 21:34:58
#   __main()
#   ____get_date()
#   ______> day0 : 2023-03-22
#   ______> day1 : 2023-03-23 21:34:58.675637
#   ________pd_get_fixtures_next_match()
#   __________Select   teams_home_id,  teams_away_id,  leagueapi_id,  season,  fixtureapi_id,  teams_home,  teams_away,  date  , pre_both_teams_score_yes  , pre_both_teams_score_no  , pre_rcard_yes  , pre_rcard_no  , pre_first_half_winner_home  , pre_first_half_winner_draw  , pre_first_half_winner_away  , pre_second_half_winner_home  , pre_second_half_winner_draw  , pre_second_half_winner_away  , pre_htft_double_home_home  , pre_htft_double_home_draw  , pre_htft_double_home_away  , pre_htft_double_draw_home  , pre_htft_double_draw_draw  , pre_htft_double_draw_away  , pre_htft_double_away_home  , pre_htft_double_away_draw  , pre_htft_double_away_away  , pre_both_teams_score__first_half_yes  , pre_both_teams_score__first_half_no  , pre_both_teams_to_score__second_half_yes  , pre_both_teams_to_score__second_half_no  , pre_results_both_teams_score_home_yes  , pre_results_both_teams_score_draw_yes  , pre_results_both_teams_score_away_yes  , pre_results_both_teams_score_home_no  , pre_results_both_teams_score_draw_no  , pre_results_both_teams_score_away_no  , pre_to_score_in_both_halves_by_teams_home , pre_to_score_in_both_halves_by_teams_away , pre_total_goals_both_teams_to_score_over_yes_25 , pre_total_goals_both_teams_to_score_over_no_25 , pre_total_goals_both_teams_to_score_under_yes_25 , pre_total_goals_both_teams_to_score_under_no_25 , pre_both_teams_to_score_1st_half__2nd_half_yes_yes , pre_both_teams_to_score_1st_half__2nd_half_yes_no , pre_both_teams_to_score_1st_half__2nd_half_no_yes , pre_both_teams_to_score_1st_half__2nd_half_no_no , pre_highest_scoring_half_first , pre_highest_scoring_half_draw , pre_highest_scoring_half_second , pre_double_chance_home_draw , pre_double_chance_home_away , pre_double_chance_draw_away , pre_double_chance__first_half_home_draw , pre_double_chance__first_half_home_away , pre_double_chance__first_half_draw_away , pre_oddeven_odd , pre_oddeven_even , pre_result_total_goals_home_over_35 , pre_result_total_goals_draw_over_35 , pre_result_total_goals_away_over_35 , pre_result_total_goals_home_under_35 , pre_result_total_goals_draw_under_35 , pre_result_total_goals_away_under_35 , pre_result_total_goals_home_over_25 , pre_result_total_goals_draw_over_25 , pre_result_total_goals_away_over_25 , pre_result_total_goals_home_under_25 , pre_result_total_goals_draw_under_25 , pre_result_total_goals_away_under_25 , pre_clean_sheet__home_yes , pre_clean_sheet__home_no , pre_clean_sheet__away_yes , pre_clean_sheet__away_no , pre_win_both_halves_home , pre_win_both_halves_away , pre_win_to_nil_home , pre_win_to_nil_away , pre_to_win_either_half_home , pre_to_win_either_half_away , pre_halftime_result_both_teams_score_home_yes , pre_halftime_result_both_teams_score_draw_yes , pre_halftime_result_both_teams_score_away_yes , pre_halftime_result_both_teams_score_home_no , pre_halftime_result_both_teams_score_draw_no , pre_halftime_result_both_teams_score_away_no , pre_exact_goals_number__first_half_0 , pre_exact_goals_number__first_half_1 , pre_exact_goals_number__first_half_2 , pre_exact_goals_number__first_half_3 , pre_exact_goals_number__first_half_4 , pre_exact_goals_number__first_half_more_5 , pre_second_half_exact_goals_number_0 , pre_second_half_exact_goals_number_1 , pre_second_half_exact_goals_number_2 , pre_second_half_exact_goals_number_3 , pre_second_half_exact_goals_number_4 , pre_second_half_exact_goals_number_more_5 , pre_home_team_exact_goals_number_0 , pre_home_team_exact_goals_number_1 , pre_home_team_exact_goals_number_2 , pre_home_team_exact_goals_number_more_3 , pre_away_team_exact_goals_number_0 , pre_away_team_exact_goals_number_1 , pre_away_team_exact_goals_number_2 , pre_away_team_exact_goals_number_more_3 from football_fixtures  where date >= '2023-03-22'  and date <= '2023-03-23 21:34:58.675637'  and fixture_status like 'Not Started'  and deleted_at is null  order by date asc
#   __________Total Row(s) : 49
#   ____________[1/49] 128 - 2023 -----#Velez Sarsfield 438 - Central Cordoba de Santiago 1065 - 2023-03-22 00:00:00
#
#   ____________[2/49] 263 - 2022 -----#Mineros de Zacatecas 2299 - Alebrijes de Oaxaca 2300 - 2023-03-22 01:05:00
#
#   ____________[3/49] 263 - 2022 -----#Cimarrones 2301 - Celaya 2308 - 2023-03-22 03:05:00
#
#   ____________[4/49] 263 - 2022 -----#CA La Paz 19024 - Dorados 2297 - 2023-03-22 03:05:00
#
#   ____________[5/49] 701 - 2022 -----#Marítimo U23 15466 - Portimonense U23 15467 - 2023-03-22 11:00:00
#
#   ____________[6/49] 36 - 2023 -----#Benin 1516 - Rwanda 1514 - 2023-03-22 15:00:00
#
#   ____________[7/49] 701 - 2022 -----#Leixões U23 15465 - Mafra U23 19826 - 2023-03-22 15:00:00
#
#   ____________[8/49] 239 - 2023 -----#Santa Fe 1139 - Deportivo Cali 1127 - 2023-03-22 15:15:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#
#   ____________[9/49] 36 - 2023 -----#Sierra Leone 1499 - Sao Tome and Principe 1494 - 2023-03-22 17:00:00
#
#   ____________[10/49] 745 - 2022 -----#Hamm United 16080 - Sasel 16083 - 2023-03-22 18:30:00
#   ______________pre_first_half_winner_away:1.79
#   ______________pre_second_half_winner_away:1.65
#   ______________pre_both_teams_score_no:2.7
#
#   ____________[11/49] 751 - 2022 -----#FSV Duisburg 12765 - Hilden 12790 - 2023-03-22 18:30:00
#   ______________pre_first_half_winner_away:1.44
#   ______________pre_second_half_winner_away:1.31
#   ______________pre_double_chance_home_draw:5.4
#
#   ____________[12/49] 751 - 2022 -----#TVD Velbert 12873 - SW Essen 14523 - 2023-03-22 18:30:00
#   ______________pre_both_teams_score_no:2.85
#
#   ____________[13/49] 751 - 2022 -----#SF Baumberg 12844 - Homberg 9370 - 2023-03-22 18:30:00
#   ______________pre_both_teams_score_no:2.77
#
#   ____________[14/49] 751 - 2022 -----#Union Nettetal 14556 - Meerbusch 14553 - 2023-03-22 18:30:00
#   ______________pre_second_half_winner_away:1.93
#
#   ____________[15/49] 751 - 2022 -----#SC St. Tönis 19466 - SSVg Velbert 12847 - 2023-03-22 18:30:00
#   ______________pre_second_half_winner_away:1.78
#
#   ____________[16/49] 751 - 2022 -----#Germania Ratingen 14689 - SF Hamborn 12845 - 2023-03-22 18:30:00
#   ______________pre_first_half_winner_home:2.0
#   ______________pre_second_half_winner_home:1.8
#
#   ____________[17/49] 751 - 2022 -----#MSV Düsseldorf 14721 - Kray 12808 - 2023-03-22 18:30:00
#   ______________pre_first_half_winner_home:2.0
#   ______________pre_second_half_winner_home:1.82
#   ______________pre_both_teams_score_no:2.51
#
#   ____________[18/49] 751 - 2022 -----#Cronenberger SC 12749 - Monheim 12818 - 2023-03-22 18:30:00
#   ______________pre_second_half_winner_away:1.89
#   ______________pre_both_teams_score_no:2.63
#
#   ____________[19/49] 751 - 2022 -----#Sonsbeck 14555 - Kleve 16105 - 2023-03-22 18:30:00
#   ______________pre_both_teams_score_no:2.7
#
#   ____________[20/49] 751 - 2022 -----#Schonnebeck 12848 - TuRU 1880 Düsseldorf 12881 - 2023-03-22 18:30:00
#
#   ____________[21/49] 487 - 2022 -----#Rupel Boom 6225 - Francs Borains 5805 - 2023-03-22 18:30:00
#   ______________pre_first_half_winner_away:1.81
#   ______________pre_second_half_winner_away:1.64
#
#   ____________[22/49] 750 - 2022 -----#Neuhof 16101 - Hadamar 14550 - 2023-03-22 19:00:00
#   ______________pre_both_teams_score_no:2.77
#
#   ____________[23/49] 510 - 2022 -----#Luzern II 12706 - SC Kriens 2186 - 2023-03-22 19:00:00
#
#   ____________[24/49] 510 - 2022 -----#Rapperswil 2185 - Baden 12699 - 2023-03-22 19:00:00
#   ______________pre_both_teams_score_no:2.51
#
#   ____________[25/49] 42 - 2022 -----#Mansfield Town 1374 - Grimsby 1365 - 2023-03-22 19:45:00
#
