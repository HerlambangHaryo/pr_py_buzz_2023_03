# %%
import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.api__team_statistics import *   
from a_models.date import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    # fixtureapi_id   = input(space + "Enter your fixtureapi_id :  ")  
    fixtureapi_id   = 1035045
    fixture_updated_at  =  get_today_adds(0, space) 
    # ----------------------------------------------------------    
    DICT = {
        'fixtureapi_id' :fixtureapi_id,
        'fixture_updated_at' :fixture_updated_at, 
    }
    # ---------------------------------------------------------- 
    a_ts_controll_match_update(DICT, 'fixtureapi_id', space) 
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 12:16:46
#   ____main__
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 12:16:46.967851
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 94
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035045
#   ____________fixture_updated_at : 2023-09-03 12:16:46.967851
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-13 15:30:00+00:00
# team_id: 49
#
# ID :49
# lineups_coach_homeapi_id :13
# lineups_coach_home_name :M. Pochettino
# lineups_coach_home_photo :https://media-2.api-sports.io/football/coachs/13.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 13
#   __________________name : M. Pochettino
# lineups_formation_home :3-4-2-1
# team_id: 40
#
# ID :40
# lineups_coach_awayapi_id :1
# lineups_coach_away_name :J. Klopp
# lineups_coach_away_photo :https://media-2.api-sports.io/football/coachs/1.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1
#   __________________name : J. Klopp
# lineups_formation_away :4-3-3
#
# shots_on_goal_home :4
# shots_off_goal_home :4
# total_shots_home :10
# blocked_shots_home :2
# shots_inside_box_home :9
# shots_outside_box_home :1
# fouls_home :5
# corner_kicks_home :4
# offsides_home :3
# ball_possession_home :65
# yellow_cards_home :3
# red_cards_home :Null
# goalkeeper_saves_home :Null
# total_passess_home :698
# passess_accurate_home :610
# passess_home :87
# expected_goals_home :1.35
#
# shots_on_goal_away :1
# shots_off_goal_away :7
# total_shots_away :13
# blocked_shots_away :5
# shots_inside_box_away :8
# shots_outside_box_away :5
# fouls_away :13
# corner_kicks_away :4
# offsides_away :5
# ball_possession_away :35
# yellow_cards_away :3
# red_cards_away :Null
# goalkeeper_saves_away :4
# total_passess_away :377
# passess_accurate_away :301
# passess_away :80
# expected_goals_away :1.28
# update football_statistics set  fixture_status = 'Match Finished',  teams_homeapi_id = 49,  teams_awayapi_id = 40,  goals_home = '1',  goals_away = '1',  score_halftime_home = '1',  score_halftime_away = '1',  score_secondtime_home = '0',  score_secondtime_away = '0',  score_fulltime_home = '1',  score_fulltime_away = '1',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '13',  lineups_coach_awayapi_id = '1',  lineups_formation_home = '3-4-2-1',  lineups_formation_away = '4-3-3',  shots_on_goal_home = 4,  shots_on_goal_away = 1,  shots_off_goal_home = 4,  shots_off_goal_away = 7,  total_shots_home = 10,  total_shots_away = 13,  blocked_shots_home = 2,  blocked_shots_away = 5,  shots_inside_box_home = 9,  shots_inside_box_away = 8,  shots_outside_box_home = 1,  shots_outside_box_away = 5,  fouls_home = 5,  fouls_away = 13,  offsides_home = 3,  offsides_away = 5,  ball_possession_home = 65,  ball_possession_away = 35,  corner_kicks_home = 4,  corner_kicks_away = 4,  yellow_cards_home = 3,  yellow_cards_away = 3,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = Null,  goalkeeper_saves_away = 4,  total_passess_home = 698,  total_passess_away = 377,  passess_accurate_home = 610,  passess_accurate_away = 301,  passess_home = 87,  passess_away = 80,  expected_goals_home = 1.35,  expected_goals_away = 1.28,  updated_at = current_timestamp  where fixtureapi_id = '1035045'
# # -------------------------------------------------- End at 2023-09-03 12:16:49
