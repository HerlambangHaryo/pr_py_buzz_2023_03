# %%
import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *    
from a_models.team_statistics import *    

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "main__") 
    # ----------------------------------------------------------  
    space += "__"  
    # ----------------------------------------------------------  
    leagueapi_id    = input(space + "Enter your leagueapi id :  ") 
    season          = input(space + "Enter your season :  ") 
    # ----------------------------------------------------------  
    ts_league_season(leagueapi_id, season, space)   
    # ----------------------------------------------------------    
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 14:23:49
#   __main__
#   ______ts_league_season()
#   ______Select  fixtureapi_id  from football_fixtures  where leagueapi_id = '39'  and season = '2023'  and fixture_status like '%Match Finished%'
#   ______Total Row(s) : 30
#   ______[1/30]  #39 __ 2023 __ 1035037
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:23:52.438984
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 63
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035037
#   ____________fixture_updated_at : 2023-09-03 14:23:52.438984
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-11 19:00:00+00:00
# team_id: 44
#
# ID :44
# lineups_coach_homeapi_id :12590
# lineups_coach_home_name :V. Kompany
# lineups_coach_home_photo :https://media-2.api-sports.io/football/coachs/12590.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 12590
#   __________________name : V. Kompany
# lineups_formation_home :5-4-1
# team_id: 50
#
# ID :50
# lineups_coach_awayapi_id :4
# lineups_coach_away_name :Pep Guardiola
# lineups_coach_away_photo :https://media-1.api-sports.io/football/coachs/4.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4
#   __________________name : Pep Guardiola
# lineups_formation_away :4-2-3-1
#
# shots_on_goal_home :1
# shots_off_goal_home :3
# total_shots_home :6
# blocked_shots_home :2
# shots_inside_box_home :5
# shots_outside_box_home :1
# fouls_home :11
# corner_kicks_home :6
# offsides_home :Null
# ball_possession_home :34
# yellow_cards_home :Null
# red_cards_home :1
# goalkeeper_saves_home :5
# total_passess_home :365
# passess_accurate_home :290
# passess_home :79
# expected_goals_home :0.33
#
# shots_on_goal_away :8
# shots_off_goal_away :4
# total_shots_away :17
# blocked_shots_away :5
# shots_inside_box_away :14
# shots_outside_box_away :3
# fouls_away :8
# corner_kicks_away :5
# offsides_away :1
# ball_possession_away :66
# yellow_cards_away :Null
# red_cards_away :Null
# goalkeeper_saves_away :1
# total_passess_away :706
# passess_accurate_away :634
# passess_away :90
# expected_goals_away :2.08
# update football_statistics set  date = '2023-08-11 19:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 44,  teams_awayapi_id = 50,  goals_home = '0',  goals_away = '3',  score_halftime_home = '0',  score_halftime_away = '2',  score_secondtime_home = '0',  score_secondtime_away = '1',  score_fulltime_home = '0',  score_fulltime_away = '3',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '12590',  lineups_coach_awayapi_id = '4',  lineups_formation_home = '5-4-1',  lineups_formation_away = '4-2-3-1',  shots_on_goal_home = 1,  shots_on_goal_away = 8,  shots_off_goal_home = 3,  shots_off_goal_away = 4,  total_shots_home = 6,  total_shots_away = 17,  blocked_shots_home = 2,  blocked_shots_away = 5,  shots_inside_box_home = 5,  shots_inside_box_away = 14,  shots_outside_box_home = 1,  shots_outside_box_away = 3,  fouls_home = 11,  fouls_away = 8,  offsides_home = Null,  offsides_away = 1,  ball_possession_home = 34,  ball_possession_away = 66,  corner_kicks_home = 6,  corner_kicks_away = 5,  yellow_cards_home = Null,  yellow_cards_away = Null,  red_cards_home = 1,  red_cards_away = Null,  goalkeeper_saves_home = 5,  goalkeeper_saves_away = 1,  total_passess_home = 365,  total_passess_away = 706,  passess_accurate_home = 290,  passess_accurate_away = 634,  passess_home = 79,  passess_away = 90,  expected_goals_home = 0.33,  expected_goals_away = 2.08,  updated_at = current_timestamp  where fixtureapi_id = '1035037'
#   ______[2/30]  #39 __ 2023 __ 1035038
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:23:55.392246
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 62
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035038
#   ____________fixture_updated_at : 2023-09-03 14:23:55.392246
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-12 11:30:00+00:00
# team_id: 42
#
# ID :42
# lineups_coach_homeapi_id :7248
# lineups_coach_home_name :Mikel Arteta
# lineups_coach_home_photo :https://media-1.api-sports.io/football/coachs/7248.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7248
#   __________________name : Mikel Arteta
# lineups_formation_home :4-3-3
# team_id: 65
#
# ID :65
# lineups_coach_awayapi_id :98
# lineups_coach_away_name :S. Cooper
# lineups_coach_away_photo :https://media-2.api-sports.io/football/coachs/98.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 98
#   __________________name : S. Cooper
# lineups_formation_away :3-4-3
#
# shots_on_goal_home :7
# shots_off_goal_home :3
# total_shots_home :15
# blocked_shots_home :5
# shots_inside_box_home :8
# shots_outside_box_home :7
# fouls_home :12
# corner_kicks_home :8
# offsides_home :2
# ball_possession_home :78
# yellow_cards_home :2
# red_cards_home :Null
# goalkeeper_saves_home :1
# total_passess_home :769
# passess_accurate_home :693
# passess_home :90
# expected_goals_home :0.83
#
# shots_on_goal_away :2
# shots_off_goal_away :3
# total_shots_away :6
# blocked_shots_away :1
# shots_inside_box_away :4
# shots_outside_box_away :2
# fouls_away :12
# corner_kicks_away :3
# offsides_away :1
# ball_possession_away :22
# yellow_cards_away :2
# red_cards_away :Null
# goalkeeper_saves_away :5
# total_passess_away :200
# passess_accurate_away :137
# passess_away :69
# expected_goals_away :1.18
# update football_statistics set  date = '2023-08-12 11:30:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 42,  teams_awayapi_id = 65,  goals_home = '2',  goals_away = '1',  score_halftime_home = '2',  score_halftime_away = '0',  score_secondtime_home = '0',  score_secondtime_away = '1',  score_fulltime_home = '2',  score_fulltime_away = '1',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '7248',  lineups_coach_awayapi_id = '98',  lineups_formation_home = '4-3-3',  lineups_formation_away = '3-4-3',  shots_on_goal_home = 7,  shots_on_goal_away = 2,  shots_off_goal_home = 3,  shots_off_goal_away = 3,  total_shots_home = 15,  total_shots_away = 6,  blocked_shots_home = 5,  blocked_shots_away = 1,  shots_inside_box_home = 8,  shots_inside_box_away = 4,  shots_outside_box_home = 7,  shots_outside_box_away = 2,  fouls_home = 12,  fouls_away = 12,  offsides_home = 2,  offsides_away = 1,  ball_possession_home = 78,  ball_possession_away = 22,  corner_kicks_home = 8,  corner_kicks_away = 3,  yellow_cards_home = 2,  yellow_cards_away = 2,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 1,  goalkeeper_saves_away = 5,  total_passess_home = 769,  total_passess_away = 200,  passess_accurate_home = 693,  passess_accurate_away = 137,  passess_home = 90,  passess_away = 69,  expected_goals_home = 0.83,  expected_goals_away = 1.18,  updated_at = current_timestamp  where fixtureapi_id = '1035038'
#   ______[3/30]  #39 __ 2023 __ 1035039
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:23:57.682066
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 61
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035039
#   ____________fixture_updated_at : 2023-09-03 14:23:57.682066
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-12 14:00:00+00:00
# team_id: 35
#
# ID :35
# lineups_coach_homeapi_id :2108
# lineups_coach_home_name :Andoni Iraola
# lineups_coach_home_photo :https://media-3.api-sports.io/football/coachs/2108.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2108
#   __________________name : Andoni Iraola
# lineups_formation_home :4-2-3-1
# team_id: 48
#
# ID :48
# lineups_coach_awayapi_id :5662
# lineups_coach_away_name :D. Moyes
# lineups_coach_away_photo :https://media-3.api-sports.io/football/coachs/5662.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5662
#   __________________name : D. Moyes
# lineups_formation_away :4-2-3-1
#
# shots_on_goal_home :5
# shots_off_goal_home :6
# total_shots_home :14
# blocked_shots_home :3
# shots_inside_box_home :5
# shots_outside_box_home :9
# fouls_home :9
# corner_kicks_home :10
# offsides_home :Null
# ball_possession_home :63
# yellow_cards_home :1
# red_cards_home :Null
# goalkeeper_saves_home :1
# total_passess_home :517
# passess_accurate_home :423
# passess_home :82
# expected_goals_home :1.37
#
# shots_on_goal_away :3
# shots_off_goal_away :9
# total_shots_away :16
# blocked_shots_away :4
# shots_inside_box_away :12
# shots_outside_box_away :4
# fouls_away :14
# corner_kicks_away :4
# offsides_away :2
# ball_possession_away :37
# yellow_cards_away :4
# red_cards_away :Null
# goalkeeper_saves_away :4
# total_passess_away :304
# passess_accurate_away :206
# passess_away :68
# expected_goals_away :1.07
# update football_statistics set  date = '2023-08-12 14:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 35,  teams_awayapi_id = 48,  goals_home = '1',  goals_away = '1',  score_halftime_home = '0',  score_halftime_away = '0',  score_secondtime_home = '1',  score_secondtime_away = '1',  score_fulltime_home = '1',  score_fulltime_away = '1',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '2108',  lineups_coach_awayapi_id = '5662',  lineups_formation_home = '4-2-3-1',  lineups_formation_away = '4-2-3-1',  shots_on_goal_home = 5,  shots_on_goal_away = 3,  shots_off_goal_home = 6,  shots_off_goal_away = 9,  total_shots_home = 14,  total_shots_away = 16,  blocked_shots_home = 3,  blocked_shots_away = 4,  shots_inside_box_home = 5,  shots_inside_box_away = 12,  shots_outside_box_home = 9,  shots_outside_box_away = 4,  fouls_home = 9,  fouls_away = 14,  offsides_home = Null,  offsides_away = 2,  ball_possession_home = 63,  ball_possession_away = 37,  corner_kicks_home = 10,  corner_kicks_away = 4,  yellow_cards_home = 1,  yellow_cards_away = 4,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 1,  goalkeeper_saves_away = 4,  total_passess_home = 517,  total_passess_away = 304,  passess_accurate_home = 423,  passess_accurate_away = 206,  passess_home = 82,  passess_away = 68,  expected_goals_home = 1.37,  expected_goals_away = 1.07,  updated_at = current_timestamp  where fixtureapi_id = '1035039'
#   ______[4/30]  #39 __ 2023 __ 1035040
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:00.009597
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 60
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035040
#   ____________fixture_updated_at : 2023-09-03 14:24:00.009597
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-12 14:00:00+00:00
# team_id: 51
#
# ID :51
# lineups_coach_homeapi_id :2424
# lineups_coach_home_name :R. De Zerbi
# lineups_coach_home_photo :https://media-3.api-sports.io/football/coachs/2424.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2424
#   __________________name : R. De Zerbi
# lineups_formation_home :4-2-3-1
# team_id: 1359
#
# ID :1359
# lineups_coach_awayapi_id :636
# lineups_coach_away_name :R. Edwards
# lineups_coach_away_photo :https://media-3.api-sports.io/football/coachs/636.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 636
#   __________________name : R. Edwards
# lineups_formation_away :3-5-2
#
# shots_on_goal_home :12
# shots_off_goal_home :10
# total_shots_home :27
# blocked_shots_home :5
# shots_inside_box_home :20
# shots_outside_box_home :7
# fouls_home :11
# corner_kicks_home :6
# offsides_home :2
# ball_possession_home :71
# yellow_cards_home :2
# red_cards_home :Null
# goalkeeper_saves_home :2
# total_passess_home :605
# passess_accurate_home :551
# passess_home :91
# expected_goals_home :4.01
#
# shots_on_goal_away :3
# shots_off_goal_away :4
# total_shots_away :9
# blocked_shots_away :2
# shots_inside_box_away :7
# shots_outside_box_away :2
# fouls_away :12
# corner_kicks_away :7
# offsides_away :3
# ball_possession_away :29
# yellow_cards_away :2
# red_cards_away :Null
# goalkeeper_saves_away :8
# total_passess_away :234
# passess_accurate_away :168
# passess_away :72
# expected_goals_away :1.48
# update football_statistics set  date = '2023-08-12 14:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 51,  teams_awayapi_id = 1359,  goals_home = '4',  goals_away = '1',  score_halftime_home = '1',  score_halftime_away = '0',  score_secondtime_home = '3',  score_secondtime_away = '1',  score_fulltime_home = '4',  score_fulltime_away = '1',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '2424',  lineups_coach_awayapi_id = '636',  lineups_formation_home = '4-2-3-1',  lineups_formation_away = '3-5-2',  shots_on_goal_home = 12,  shots_on_goal_away = 3,  shots_off_goal_home = 10,  shots_off_goal_away = 4,  total_shots_home = 27,  total_shots_away = 9,  blocked_shots_home = 5,  blocked_shots_away = 2,  shots_inside_box_home = 20,  shots_inside_box_away = 7,  shots_outside_box_home = 7,  shots_outside_box_away = 2,  fouls_home = 11,  fouls_away = 12,  offsides_home = 2,  offsides_away = 3,  ball_possession_home = 71,  ball_possession_away = 29,  corner_kicks_home = 6,  corner_kicks_away = 7,  yellow_cards_home = 2,  yellow_cards_away = 2,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 2,  goalkeeper_saves_away = 8,  total_passess_home = 605,  total_passess_away = 234,  passess_accurate_home = 551,  passess_accurate_away = 168,  passess_home = 91,  passess_away = 72,  expected_goals_home = 4.01,  expected_goals_away = 1.48,  updated_at = current_timestamp  where fixtureapi_id = '1035040'
#   ______[5/30]  #39 __ 2023 __ 1035041
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:02.319998
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 59
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035041
#   ____________fixture_updated_at : 2023-09-03 14:24:02.319998
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-12 14:00:00+00:00
# team_id: 45
#
# ID :45
# lineups_coach_homeapi_id :7
# lineups_coach_home_name :S. Dyche
# lineups_coach_home_photo :https://media-1.api-sports.io/football/coachs/7.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7
#   __________________name : S. Dyche
# lineups_formation_home :4-4-1-1
# team_id: 36
#
# ID :36
# lineups_coach_awayapi_id :10
# lineups_coach_away_name :Marco Silva
# lineups_coach_away_photo :https://media-3.api-sports.io/football/coachs/10.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 10
#   __________________name : Marco Silva
# lineups_formation_away :4-3-3
#
# shots_on_goal_home :9
# shots_off_goal_home :6
# total_shots_home :19
# blocked_shots_home :4
# shots_inside_box_home :14
# shots_outside_box_home :5
# fouls_home :12
# corner_kicks_home :10
# offsides_home :6
# ball_possession_home :41
# yellow_cards_home :Null
# red_cards_home :Null
# goalkeeper_saves_home :1
# total_passess_home :366
# passess_accurate_home :288
# passess_home :79
# expected_goals_home :2.73
#
# shots_on_goal_away :2
# shots_off_goal_away :6
# total_shots_away :9
# blocked_shots_away :1
# shots_inside_box_away :6
# shots_outside_box_away :3
# fouls_away :6
# corner_kicks_away :4
# offsides_away :3
# ball_possession_away :59
# yellow_cards_away :2
# red_cards_away :Null
# goalkeeper_saves_away :9
# total_passess_away :556
# passess_accurate_away :470
# passess_away :85
# expected_goals_away :1.50
# update football_statistics set  date = '2023-08-12 14:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 45,  teams_awayapi_id = 36,  goals_home = '0',  goals_away = '1',  score_halftime_home = '0',  score_halftime_away = '0',  score_secondtime_home = '0',  score_secondtime_away = '1',  score_fulltime_home = '0',  score_fulltime_away = '1',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '7',  lineups_coach_awayapi_id = '10',  lineups_formation_home = '4-4-1-1',  lineups_formation_away = '4-3-3',  shots_on_goal_home = 9,  shots_on_goal_away = 2,  shots_off_goal_home = 6,  shots_off_goal_away = 6,  total_shots_home = 19,  total_shots_away = 9,  blocked_shots_home = 4,  blocked_shots_away = 1,  shots_inside_box_home = 14,  shots_inside_box_away = 6,  shots_outside_box_home = 5,  shots_outside_box_away = 3,  fouls_home = 12,  fouls_away = 6,  offsides_home = 6,  offsides_away = 3,  ball_possession_home = 41,  ball_possession_away = 59,  corner_kicks_home = 10,  corner_kicks_away = 4,  yellow_cards_home = Null,  yellow_cards_away = 2,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 1,  goalkeeper_saves_away = 9,  total_passess_home = 366,  total_passess_away = 556,  passess_accurate_home = 288,  passess_accurate_away = 470,  passess_home = 79,  passess_away = 85,  expected_goals_home = 2.73,  expected_goals_away = 1.50,  updated_at = current_timestamp  where fixtureapi_id = '1035041'
#   ______[6/30]  #39 __ 2023 __ 1035042
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:04.656649
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 58
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035042
#   ____________fixture_updated_at : 2023-09-03 14:24:04.656649
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-12 14:00:00+00:00
# team_id: 62
#
# ID :62
# lineups_coach_homeapi_id :2397
# lineups_coach_home_name :P. Heckingbottom
# lineups_coach_home_photo :https://media-3.api-sports.io/football/coachs/2397.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2397
#   __________________name : P. Heckingbottom
# lineups_formation_home :3-5-2
# team_id: 52
#
# ID :52
# lineups_coach_awayapi_id :9
# lineups_coach_away_name :R. Hodgson
# lineups_coach_away_photo :https://media-3.api-sports.io/football/coachs/9.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 9
#   __________________name : R. Hodgson
# lineups_formation_away :4-2-3-1
#
# shots_on_goal_home :1
# shots_off_goal_home :4
# total_shots_home :8
# blocked_shots_home :3
# shots_inside_box_home :4
# shots_outside_box_home :4
# fouls_home :18
# corner_kicks_home :5
# offsides_home :2
# ball_possession_home :32
# yellow_cards_home :3
# red_cards_home :Null
# goalkeeper_saves_home :7
# total_passess_home :262
# passess_accurate_home :162
# passess_home :62
# expected_goals_home :0.51
#
# shots_on_goal_away :8
# shots_off_goal_away :8
# total_shots_away :24
# blocked_shots_away :8
# shots_inside_box_away :17
# shots_outside_box_away :7
# fouls_away :11
# corner_kicks_away :5
# offsides_away :2
# ball_possession_away :68
# yellow_cards_away :Null
# red_cards_away :Null
# goalkeeper_saves_away :1
# total_passess_away :562
# passess_accurate_away :466
# passess_away :83
# expected_goals_away :1.89
# update football_statistics set  date = '2023-08-12 14:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 62,  teams_awayapi_id = 52,  goals_home = '0',  goals_away = '1',  score_halftime_home = '0',  score_halftime_away = '0',  score_secondtime_home = '0',  score_secondtime_away = '1',  score_fulltime_home = '0',  score_fulltime_away = '1',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '2397',  lineups_coach_awayapi_id = '9',  lineups_formation_home = '3-5-2',  lineups_formation_away = '4-2-3-1',  shots_on_goal_home = 1,  shots_on_goal_away = 8,  shots_off_goal_home = 4,  shots_off_goal_away = 8,  total_shots_home = 8,  total_shots_away = 24,  blocked_shots_home = 3,  blocked_shots_away = 8,  shots_inside_box_home = 4,  shots_inside_box_away = 17,  shots_outside_box_home = 4,  shots_outside_box_away = 7,  fouls_home = 18,  fouls_away = 11,  offsides_home = 2,  offsides_away = 2,  ball_possession_home = 32,  ball_possession_away = 68,  corner_kicks_home = 5,  corner_kicks_away = 5,  yellow_cards_home = 3,  yellow_cards_away = Null,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 7,  goalkeeper_saves_away = 1,  total_passess_home = 262,  total_passess_away = 562,  passess_accurate_home = 162,  passess_accurate_away = 466,  passess_home = 62,  passess_away = 83,  expected_goals_home = 0.51,  expected_goals_away = 1.89,  updated_at = current_timestamp  where fixtureapi_id = '1035042'
#   ______[7/30]  #39 __ 2023 __ 1035043
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:07.001443
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 57
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035043
#   ____________fixture_updated_at : 2023-09-03 14:24:07.001443
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-12 16:30:00+00:00
# team_id: 34
#
# ID :34
# lineups_coach_homeapi_id :5
# lineups_coach_home_name :E. Howe
# lineups_coach_home_photo :https://media-1.api-sports.io/football/coachs/5.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5
#   __________________name : E. Howe
# lineups_formation_home :4-3-3
# team_id: 66
#
# ID :66
# lineups_coach_awayapi_id :18
# lineups_coach_away_name :Unai Emery
# lineups_coach_away_photo :https://media-1.api-sports.io/football/coachs/18.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 18
#   __________________name : Unai Emery
# lineups_formation_away :4-2-3-1
#
# shots_on_goal_home :13
# shots_off_goal_home :2
# total_shots_home :17
# blocked_shots_home :2
# shots_inside_box_home :14
# shots_outside_box_home :3
# fouls_home :12
# corner_kicks_home :6
# offsides_home :2
# ball_possession_home :53
# yellow_cards_home :4
# red_cards_home :Null
# goalkeeper_saves_home :5
# total_passess_home :502
# passess_accurate_home :428
# passess_home :85
# expected_goals_home :3.41
#
# shots_on_goal_away :6
# shots_off_goal_away :7
# total_shots_away :16
# blocked_shots_away :3
# shots_inside_box_away :12
# shots_outside_box_away :4
# fouls_away :17
# corner_kicks_away :5
# offsides_away :Null
# ball_possession_away :47
# yellow_cards_away :4
# red_cards_away :Null
# goalkeeper_saves_away :7
# total_passess_away :447
# passess_accurate_away :382
# passess_away :85
# expected_goals_away :1.77
# update football_statistics set  date = '2023-08-12 16:30:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 34,  teams_awayapi_id = 66,  goals_home = '5',  goals_away = '1',  score_halftime_home = '2',  score_halftime_away = '1',  score_secondtime_home = '3',  score_secondtime_away = '0',  score_fulltime_home = '5',  score_fulltime_away = '1',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '5',  lineups_coach_awayapi_id = '18',  lineups_formation_home = '4-3-3',  lineups_formation_away = '4-2-3-1',  shots_on_goal_home = 13,  shots_on_goal_away = 6,  shots_off_goal_home = 2,  shots_off_goal_away = 7,  total_shots_home = 17,  total_shots_away = 16,  blocked_shots_home = 2,  blocked_shots_away = 3,  shots_inside_box_home = 14,  shots_inside_box_away = 12,  shots_outside_box_home = 3,  shots_outside_box_away = 4,  fouls_home = 12,  fouls_away = 17,  offsides_home = 2,  offsides_away = Null,  ball_possession_home = 53,  ball_possession_away = 47,  corner_kicks_home = 6,  corner_kicks_away = 5,  yellow_cards_home = 4,  yellow_cards_away = 4,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 5,  goalkeeper_saves_away = 7,  total_passess_home = 502,  total_passess_away = 447,  passess_accurate_home = 428,  passess_accurate_away = 382,  passess_home = 85,  passess_away = 85,  expected_goals_home = 3.41,  expected_goals_away = 1.77,  updated_at = current_timestamp  where fixtureapi_id = '1035043'
#   ______[8/30]  #39 __ 2023 __ 1035044
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:09.264073
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 56
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035044
#   ____________fixture_updated_at : 2023-09-03 14:24:09.264073
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-13 13:00:00+00:00
# team_id: 55
#
# ID :55
# lineups_coach_homeapi_id :90
# lineups_coach_home_name :T. Frank
# lineups_coach_home_photo :https://media-3.api-sports.io/football/coachs/90.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 90
#   __________________name : T. Frank
# lineups_formation_home :5-3-2
# team_id: 47
#
# ID :47
# lineups_coach_awayapi_id :548
# lineups_coach_away_name :A. Postecoglou
# lineups_coach_away_photo :https://media-3.api-sports.io/football/coachs/548.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 548
#   __________________name : A. Postecoglou
# lineups_formation_away :4-2-3-1
#
# shots_on_goal_home :6
# shots_off_goal_home :2
# total_shots_home :11
# blocked_shots_home :3
# shots_inside_box_home :9
# shots_outside_box_home :2
# fouls_home :12
# corner_kicks_home :3
# offsides_home :1
# ball_possession_home :30
# yellow_cards_home :1
# red_cards_home :Null
# goalkeeper_saves_home :4
# total_passess_home :306
# passess_accurate_home :235
# passess_home :77
# expected_goals_home :2.22
#
# shots_on_goal_away :6
# shots_off_goal_away :6
# total_shots_away :18
# blocked_shots_away :6
# shots_inside_box_away :12
# shots_outside_box_away :6
# fouls_away :13
# corner_kicks_away :6
# offsides_away :Null
# ball_possession_away :70
# yellow_cards_away :4
# red_cards_away :Null
# goalkeeper_saves_away :4
# total_passess_away :711
# passess_accurate_away :638
# passess_away :90
# expected_goals_away :1.27
# update football_statistics set  date = '2023-08-13 13:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 55,  teams_awayapi_id = 47,  goals_home = '2',  goals_away = '2',  score_halftime_home = '2',  score_halftime_away = '2',  score_secondtime_home = '0',  score_secondtime_away = '0',  score_fulltime_home = '2',  score_fulltime_away = '2',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '90',  lineups_coach_awayapi_id = '548',  lineups_formation_home = '5-3-2',  lineups_formation_away = '4-2-3-1',  shots_on_goal_home = 6,  shots_on_goal_away = 6,  shots_off_goal_home = 2,  shots_off_goal_away = 6,  total_shots_home = 11,  total_shots_away = 18,  blocked_shots_home = 3,  blocked_shots_away = 6,  shots_inside_box_home = 9,  shots_inside_box_away = 12,  shots_outside_box_home = 2,  shots_outside_box_away = 6,  fouls_home = 12,  fouls_away = 13,  offsides_home = 1,  offsides_away = Null,  ball_possession_home = 30,  ball_possession_away = 70,  corner_kicks_home = 3,  corner_kicks_away = 6,  yellow_cards_home = 1,  yellow_cards_away = 4,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 4,  goalkeeper_saves_away = 4,  total_passess_home = 306,  total_passess_away = 711,  passess_accurate_home = 235,  passess_accurate_away = 638,  passess_home = 77,  passess_away = 90,  expected_goals_home = 2.22,  expected_goals_away = 1.27,  updated_at = current_timestamp  where fixtureapi_id = '1035044'
#   ______[9/30]  #39 __ 2023 __ 1035045
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:11.588897
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 55
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035045
#   ____________fixture_updated_at : 2023-09-03 14:24:11.588897
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-13 15:30:00+00:00
# team_id: 49
#
# ID :49
# lineups_coach_homeapi_id :13
# lineups_coach_home_name :M. Pochettino
# lineups_coach_home_photo :https://media-2.api-sports.io/football/coachs/13.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 13
#   __________________name : M. Pochettino
# lineups_formation_home :3-4-2-1
# team_id: 40
#
# ID :40
# lineups_coach_awayapi_id :1
# lineups_coach_away_name :J. Klopp
# lineups_coach_away_photo :https://media-1.api-sports.io/football/coachs/1.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1
#   __________________name : J. Klopp
# lineups_formation_away :4-3-3
#
# shots_on_goal_home :4
# shots_off_goal_home :4
# total_shots_home :10
# blocked_shots_home :2
# shots_inside_box_home :9
# shots_outside_box_home :1
# fouls_home :5
# corner_kicks_home :4
# offsides_home :3
# ball_possession_home :65
# yellow_cards_home :3
# red_cards_home :Null
# goalkeeper_saves_home :Null
# total_passess_home :698
# passess_accurate_home :610
# passess_home :87
# expected_goals_home :1.35
#
# shots_on_goal_away :1
# shots_off_goal_away :7
# total_shots_away :13
# blocked_shots_away :5
# shots_inside_box_away :8
# shots_outside_box_away :5
# fouls_away :13
# corner_kicks_away :4
# offsides_away :5
# ball_possession_away :35
# yellow_cards_away :3
# red_cards_away :Null
# goalkeeper_saves_away :4
# total_passess_away :377
# passess_accurate_away :301
# passess_away :80
# expected_goals_away :1.28
# update football_statistics set  date = '2023-08-13 15:30:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 49,  teams_awayapi_id = 40,  goals_home = '1',  goals_away = '1',  score_halftime_home = '1',  score_halftime_away = '1',  score_secondtime_home = '0',  score_secondtime_away = '0',  score_fulltime_home = '1',  score_fulltime_away = '1',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '13',  lineups_coach_awayapi_id = '1',  lineups_formation_home = '3-4-2-1',  lineups_formation_away = '4-3-3',  shots_on_goal_home = 4,  shots_on_goal_away = 1,  shots_off_goal_home = 4,  shots_off_goal_away = 7,  total_shots_home = 10,  total_shots_away = 13,  blocked_shots_home = 2,  blocked_shots_away = 5,  shots_inside_box_home = 9,  shots_inside_box_away = 8,  shots_outside_box_home = 1,  shots_outside_box_away = 5,  fouls_home = 5,  fouls_away = 13,  offsides_home = 3,  offsides_away = 5,  ball_possession_home = 65,  ball_possession_away = 35,  corner_kicks_home = 4,  corner_kicks_away = 4,  yellow_cards_home = 3,  yellow_cards_away = 3,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = Null,  goalkeeper_saves_away = 4,  total_passess_home = 698,  total_passess_away = 377,  passess_accurate_home = 610,  passess_accurate_away = 301,  passess_home = 87,  passess_away = 80,  expected_goals_home = 1.35,  expected_goals_away = 1.28,  updated_at = current_timestamp  where fixtureapi_id = '1035045'
#   ______[10/30]  #39 __ 2023 __ 1035046
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:13.921281
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 54
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035046
#   ____________fixture_updated_at : 2023-09-03 14:24:13.921281
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-14 19:00:00+00:00
# team_id: 33
#
# ID :33
# lineups_coach_homeapi_id :1993
# lineups_coach_home_name :E. ten Hag
# lineups_coach_home_photo :https://media-1.api-sports.io/football/coachs/1993.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1993
#   __________________name : E. ten Hag
# lineups_formation_home :4-1-4-1
# team_id: 39
#
# ID :39
# lineups_coach_awayapi_id :18151
# lineups_coach_away_name :G. O'Neil
# lineups_coach_away_photo :https://media-3.api-sports.io/football/coachs/18151.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 18151
#   __________________name : G. O'Neil
# lineups_formation_away :4-4-2
#
# shots_on_goal_home :3
# shots_off_goal_home :4
# total_shots_home :15
# blocked_shots_home :8
# shots_inside_box_home :12
# shots_outside_box_home :3
# fouls_home :15
# corner_kicks_home :8
# offsides_home :1
# ball_possession_home :51
# yellow_cards_home :2
# red_cards_home :Null
# goalkeeper_saves_home :6
# total_passess_home :465
# passess_accurate_home :383
# passess_home :82
# expected_goals_home :2.21
#
# shots_on_goal_away :6
# shots_off_goal_away :7
# total_shots_away :23
# blocked_shots_away :10
# shots_inside_box_away :17
# shots_outside_box_away :6
# fouls_away :10
# corner_kicks_away :7
# offsides_away :3
# ball_possession_away :49
# yellow_cards_away :3
# red_cards_away :Null
# goalkeeper_saves_away :2
# total_passess_away :439
# passess_accurate_away :355
# passess_away :81
# expected_goals_away :2.35
# update football_statistics set  date = '2023-08-14 19:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 33,  teams_awayapi_id = 39,  goals_home = '1',  goals_away = '0',  score_halftime_home = '0',  score_halftime_away = '0',  score_secondtime_home = '1',  score_secondtime_away = '0',  score_fulltime_home = '1',  score_fulltime_away = '0',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '1993',  lineups_coach_awayapi_id = '18151',  lineups_formation_home = '4-1-4-1',  lineups_formation_away = '4-4-2',  shots_on_goal_home = 3,  shots_on_goal_away = 6,  shots_off_goal_home = 4,  shots_off_goal_away = 7,  total_shots_home = 15,  total_shots_away = 23,  blocked_shots_home = 8,  blocked_shots_away = 10,  shots_inside_box_home = 12,  shots_inside_box_away = 17,  shots_outside_box_home = 3,  shots_outside_box_away = 6,  fouls_home = 15,  fouls_away = 10,  offsides_home = 1,  offsides_away = 3,  ball_possession_home = 51,  ball_possession_away = 49,  corner_kicks_home = 8,  corner_kicks_away = 7,  yellow_cards_home = 2,  yellow_cards_away = 3,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 6,  goalkeeper_saves_away = 2,  total_passess_home = 465,  total_passess_away = 439,  passess_accurate_home = 383,  passess_accurate_away = 355,  passess_home = 82,  passess_away = 81,  expected_goals_home = 2.21,  expected_goals_away = 2.35,  updated_at = current_timestamp  where fixtureapi_id = '1035046'
#   ______[11/30]  #39 __ 2023 __ 1035047
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:16.209359
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 53
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035047
#   ____________fixture_updated_at : 2023-09-03 14:24:16.209359
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-20 13:00:00+00:00
# team_id: 66
#
# ID :66
# lineups_coach_homeapi_id :18
# lineups_coach_home_name :Unai Emery
# lineups_coach_home_photo :https://media-2.api-sports.io/football/coachs/18.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 18
#   __________________name : Unai Emery
# lineups_formation_home :4-2-3-1
# team_id: 45
#
# ID :45
# lineups_coach_awayapi_id :7
# lineups_coach_away_name :S. Dyche
# lineups_coach_away_photo :https://media-1.api-sports.io/football/coachs/7.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7
#   __________________name : S. Dyche
# lineups_formation_away :4-1-4-1
#
# shots_on_goal_home :7
# shots_off_goal_home :4
# total_shots_home :13
# blocked_shots_home :2
# shots_inside_box_home :9
# shots_outside_box_home :4
# fouls_home :8
# corner_kicks_home :7
# offsides_home :1
# ball_possession_home :60
# yellow_cards_home :3
# red_cards_home :Null
# goalkeeper_saves_home :2
# total_passess_home :566
# passess_accurate_home :507
# passess_home :90
# expected_goals_home :3.00
#
# shots_on_goal_away :2
# shots_off_goal_away :3
# total_shots_away :9
# blocked_shots_away :4
# shots_inside_box_away :6
# shots_outside_box_away :3
# fouls_away :12
# corner_kicks_away :6
# offsides_away :1
# ball_possession_away :40
# yellow_cards_away :4
# red_cards_away :Null
# goalkeeper_saves_away :3
# total_passess_away :361
# passess_accurate_away :294
# passess_away :81
# expected_goals_away :0.63
# update football_statistics set  date = '2023-08-20 13:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 66,  teams_awayapi_id = 45,  goals_home = '4',  goals_away = '0',  score_halftime_home = '2',  score_halftime_away = '0',  score_secondtime_home = '2',  score_secondtime_away = '0',  score_fulltime_home = '4',  score_fulltime_away = '0',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '18',  lineups_coach_awayapi_id = '7',  lineups_formation_home = '4-2-3-1',  lineups_formation_away = '4-1-4-1',  shots_on_goal_home = 7,  shots_on_goal_away = 2,  shots_off_goal_home = 4,  shots_off_goal_away = 3,  total_shots_home = 13,  total_shots_away = 9,  blocked_shots_home = 2,  blocked_shots_away = 4,  shots_inside_box_home = 9,  shots_inside_box_away = 6,  shots_outside_box_home = 4,  shots_outside_box_away = 3,  fouls_home = 8,  fouls_away = 12,  offsides_home = 1,  offsides_away = 1,  ball_possession_home = 60,  ball_possession_away = 40,  corner_kicks_home = 7,  corner_kicks_away = 6,  yellow_cards_home = 3,  yellow_cards_away = 4,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 2,  goalkeeper_saves_away = 3,  total_passess_home = 566,  total_passess_away = 361,  passess_accurate_home = 507,  passess_accurate_away = 294,  passess_home = 90,  passess_away = 81,  expected_goals_home = 3.00,  expected_goals_away = 0.63,  updated_at = current_timestamp  where fixtureapi_id = '1035047'
#   ______[12/30]  #39 __ 2023 __ 1035048
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:18.483212
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 52
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035048
#   ____________fixture_updated_at : 2023-09-03 14:24:18.483212
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-21 19:00:00+00:00
# team_id: 52
#
# ID :52
# lineups_coach_homeapi_id :9
# lineups_coach_home_name :R. Hodgson
# lineups_coach_home_photo :https://media-2.api-sports.io/football/coachs/9.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 9
#   __________________name : R. Hodgson
# lineups_formation_home :4-2-3-1
# team_id: 42
#
# ID :42
# lineups_coach_awayapi_id :7248
# lineups_coach_away_name :Mikel Arteta
# lineups_coach_away_photo :https://media-1.api-sports.io/football/coachs/7248.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7248
#   __________________name : Mikel Arteta
# lineups_formation_away :4-3-3
#
# shots_on_goal_home :2
# shots_off_goal_home :5
# total_shots_home :14
# blocked_shots_home :7
# shots_inside_box_home :10
# shots_outside_box_home :4
# fouls_home :14
# corner_kicks_home :1
# offsides_home :Null
# ball_possession_home :47
# yellow_cards_home :2
# red_cards_home :Null
# goalkeeper_saves_home :2
# total_passess_home :428
# passess_accurate_home :370
# passess_home :86
# expected_goals_home :1.01
#
# shots_on_goal_away :3
# shots_off_goal_away :7
# total_shots_away :14
# blocked_shots_away :4
# shots_inside_box_away :11
# shots_outside_box_away :3
# fouls_away :10
# corner_kicks_away :8
# offsides_away :2
# ball_possession_away :53
# yellow_cards_away :3
# red_cards_away :1
# goalkeeper_saves_away :2
# total_passess_away :489
# passess_accurate_away :422
# passess_away :86
# expected_goals_away :2.02
# update football_statistics set  date = '2023-08-21 19:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 52,  teams_awayapi_id = 42,  goals_home = '0',  goals_away = '1',  score_halftime_home = '0',  score_halftime_away = '0',  score_secondtime_home = '0',  score_secondtime_away = '1',  score_fulltime_home = '0',  score_fulltime_away = '1',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '9',  lineups_coach_awayapi_id = '7248',  lineups_formation_home = '4-2-3-1',  lineups_formation_away = '4-3-3',  shots_on_goal_home = 2,  shots_on_goal_away = 3,  shots_off_goal_home = 5,  shots_off_goal_away = 7,  total_shots_home = 14,  total_shots_away = 14,  blocked_shots_home = 7,  blocked_shots_away = 4,  shots_inside_box_home = 10,  shots_inside_box_away = 11,  shots_outside_box_home = 4,  shots_outside_box_away = 3,  fouls_home = 14,  fouls_away = 10,  offsides_home = Null,  offsides_away = 2,  ball_possession_home = 47,  ball_possession_away = 53,  corner_kicks_home = 1,  corner_kicks_away = 8,  yellow_cards_home = 2,  yellow_cards_away = 3,  red_cards_home = Null,  red_cards_away = 1,  goalkeeper_saves_home = 2,  goalkeeper_saves_away = 2,  total_passess_home = 428,  total_passess_away = 489,  passess_accurate_home = 370,  passess_accurate_away = 422,  passess_home = 86,  passess_away = 86,  expected_goals_home = 1.01,  expected_goals_away = 2.02,  updated_at = current_timestamp  where fixtureapi_id = '1035048'
#   ______[13/30]  #39 __ 2023 __ 1035049
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:20.821925
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 51
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035049
#   ____________fixture_updated_at : 2023-09-03 14:24:20.821925
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-19 14:00:00+00:00
# team_id: 36
#
# ID :36
# lineups_coach_homeapi_id :10
# lineups_coach_home_name :Marco Silva
# lineups_coach_home_photo :https://media-2.api-sports.io/football/coachs/10.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 10
#   __________________name : Marco Silva
# lineups_formation_home :4-3-3
# team_id: 55
#
# ID :55
# lineups_coach_awayapi_id :90
# lineups_coach_away_name :T. Frank
# lineups_coach_away_photo :https://media-2.api-sports.io/football/coachs/90.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 90
#   __________________name : T. Frank
# lineups_formation_away :4-3-3
#
# shots_on_goal_home :2
# shots_off_goal_home :4
# total_shots_home :10
# blocked_shots_home :4
# shots_inside_box_home :4
# shots_outside_box_home :6
# fouls_home :13
# corner_kicks_home :5
# offsides_home :1
# ball_possession_home :55
# yellow_cards_home :4
# red_cards_home :1
# goalkeeper_saves_home :5
# total_passess_home :474
# passess_accurate_home :396
# passess_home :84
# expected_goals_home :0.46
#
# shots_on_goal_away :8
# shots_off_goal_away :7
# total_shots_away :17
# blocked_shots_away :2
# shots_inside_box_away :15
# shots_outside_box_away :2
# fouls_away :12
# corner_kicks_away :5
# offsides_away :4
# ball_possession_away :45
# yellow_cards_away :2
# red_cards_away :Null
# goalkeeper_saves_away :2
# total_passess_away :391
# passess_accurate_away :325
# passess_away :83
# expected_goals_away :3.93
# update football_statistics set  date = '2023-08-19 14:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 36,  teams_awayapi_id = 55,  goals_home = '0',  goals_away = '3',  score_halftime_home = '0',  score_halftime_away = '1',  score_secondtime_home = '0',  score_secondtime_away = '2',  score_fulltime_home = '0',  score_fulltime_away = '3',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '10',  lineups_coach_awayapi_id = '90',  lineups_formation_home = '4-3-3',  lineups_formation_away = '4-3-3',  shots_on_goal_home = 2,  shots_on_goal_away = 8,  shots_off_goal_home = 4,  shots_off_goal_away = 7,  total_shots_home = 10,  total_shots_away = 17,  blocked_shots_home = 4,  blocked_shots_away = 2,  shots_inside_box_home = 4,  shots_inside_box_away = 15,  shots_outside_box_home = 6,  shots_outside_box_away = 2,  fouls_home = 13,  fouls_away = 12,  offsides_home = 1,  offsides_away = 4,  ball_possession_home = 55,  ball_possession_away = 45,  corner_kicks_home = 5,  corner_kicks_away = 5,  yellow_cards_home = 4,  yellow_cards_away = 2,  red_cards_home = 1,  red_cards_away = Null,  goalkeeper_saves_home = 5,  goalkeeper_saves_away = 2,  total_passess_home = 474,  total_passess_away = 391,  passess_accurate_home = 396,  passess_accurate_away = 325,  passess_home = 84,  passess_away = 83,  expected_goals_home = 0.46,  expected_goals_away = 3.93,  updated_at = current_timestamp  where fixtureapi_id = '1035049'
#   ______[14/30]  #39 __ 2023 __ 1035050
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:23.103807
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 50
# ...
# total_passess_away :472
# passess_accurate_away :396
# passess_away :84
# expected_goals_away :1.08
# update football_statistics set  date = '2023-08-26 14:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 45,  teams_awayapi_id = 39,  goals_home = '0',  goals_away = '1',  score_halftime_home = '0',  score_halftime_away = '0',  score_secondtime_home = '0',  score_secondtime_away = '1',  score_fulltime_home = '0',  score_fulltime_away = '1',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '7',  lineups_coach_awayapi_id = '18151',  lineups_formation_home = '4-1-4-1',  lineups_formation_away = '4-4-1-1',  shots_on_goal_home = 7,  shots_on_goal_away = 2,  shots_off_goal_home = 6,  shots_off_goal_away = 5,  total_shots_home = 15,  total_shots_away = 11,  blocked_shots_home = 2,  blocked_shots_away = 4,  shots_inside_box_home = 11,  shots_inside_box_away = 7,  shots_outside_box_home = 4,  shots_outside_box_away = 4,  fouls_home = 10,  fouls_away = 14,  offsides_home = 1,  offsides_away = 1,  ball_possession_home = 47,  ball_possession_away = 53,  corner_kicks_home = 7,  corner_kicks_away = Null,  yellow_cards_home = 3,  yellow_cards_away = 4,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 2,  goalkeeper_saves_away = 7,  total_passess_home = 406,  total_passess_away = 472,  passess_accurate_home = 333,  passess_accurate_away = 396,  passess_home = 82,  passess_away = 84,  expected_goals_home = 1.34,  expected_goals_away = 1.08,  updated_at = current_timestamp  where fixtureapi_id = '1035063'
#   ______[27/30]  #39 __ 2023 __ 1035064
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:53.712018
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 37
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035064
#   ____________fixture_updated_at : 2023-09-03 14:24:53.712018
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-26 14:00:00+00:00
# team_id: 33
#
# ID :33
# lineups_coach_homeapi_id :1993
# lineups_coach_home_name :E. ten Hag
# lineups_coach_home_photo :https://media-3.api-sports.io/football/coachs/1993.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1993
#   __________________name : E. ten Hag
# lineups_formation_home :4-2-3-1
# team_id: 65
#
# ID :65
# lineups_coach_awayapi_id :98
# lineups_coach_away_name :S. Cooper
# lineups_coach_away_photo :https://media-2.api-sports.io/football/coachs/98.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 98
#   __________________name : S. Cooper
# lineups_formation_away :3-4-2-1
#
# shots_on_goal_home :9
# shots_off_goal_home :5
# total_shots_home :18
# blocked_shots_home :4
# shots_inside_box_home :7
# shots_outside_box_home :11
# fouls_home :13
# corner_kicks_home :11
# offsides_home :3
# ball_possession_home :66
# yellow_cards_home :4
# red_cards_home :Null
# goalkeeper_saves_home :2
# total_passess_home :637
# passess_accurate_home :548
# passess_home :86
# expected_goals_home :2.83
#
# shots_on_goal_away :4
# shots_off_goal_away :3
# total_shots_away :9
# blocked_shots_away :2
# shots_inside_box_away :7
# shots_outside_box_away :2
# fouls_away :11
# corner_kicks_away :3
# offsides_away :2
# ball_possession_away :34
# yellow_cards_away :4
# red_cards_away :1
# goalkeeper_saves_away :7
# total_passess_away :316
# passess_accurate_away :228
# passess_away :72
# expected_goals_away :1.21
# update football_statistics set  date = '2023-08-26 14:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 33,  teams_awayapi_id = 65,  goals_home = '3',  goals_away = '2',  score_halftime_home = '1',  score_halftime_away = '2',  score_secondtime_home = '2',  score_secondtime_away = '0',  score_fulltime_home = '3',  score_fulltime_away = '2',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '1993',  lineups_coach_awayapi_id = '98',  lineups_formation_home = '4-2-3-1',  lineups_formation_away = '3-4-2-1',  shots_on_goal_home = 9,  shots_on_goal_away = 4,  shots_off_goal_home = 5,  shots_off_goal_away = 3,  total_shots_home = 18,  total_shots_away = 9,  blocked_shots_home = 4,  blocked_shots_away = 2,  shots_inside_box_home = 7,  shots_inside_box_away = 7,  shots_outside_box_home = 11,  shots_outside_box_away = 2,  fouls_home = 13,  fouls_away = 11,  offsides_home = 3,  offsides_away = 2,  ball_possession_home = 66,  ball_possession_away = 34,  corner_kicks_home = 11,  corner_kicks_away = 3,  yellow_cards_home = 4,  yellow_cards_away = 4,  red_cards_home = Null,  red_cards_away = 1,  goalkeeper_saves_home = 2,  goalkeeper_saves_away = 7,  total_passess_home = 637,  total_passess_away = 316,  passess_accurate_home = 548,  passess_accurate_away = 228,  passess_home = 86,  passess_away = 72,  expected_goals_home = 2.83,  expected_goals_away = 1.21,  updated_at = current_timestamp  where fixtureapi_id = '1035064'
#   ______[28/30]  #39 __ 2023 __ 1035065
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:57.107745
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 36
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035065
#   ____________fixture_updated_at : 2023-09-03 14:24:57.107745
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-27 15:30:00+00:00
# team_id: 34
#
# ID :34
# lineups_coach_homeapi_id :5
# lineups_coach_home_name :E. Howe
# lineups_coach_home_photo :https://media-2.api-sports.io/football/coachs/5.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5
#   __________________name : E. Howe
# lineups_formation_home :4-3-3
# team_id: 40
#
# ID :40
# lineups_coach_awayapi_id :1
# lineups_coach_away_name :J. Klopp
# lineups_coach_away_photo :https://media-3.api-sports.io/football/coachs/1.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1
#   __________________name : J. Klopp
# lineups_formation_away :4-3-3
#
# shots_on_goal_home :8
# shots_off_goal_home :11
# total_shots_home :23
# blocked_shots_home :4
# shots_inside_box_home :14
# shots_outside_box_home :9
# fouls_home :16
# corner_kicks_home :5
# offsides_home :Null
# ball_possession_home :60
# yellow_cards_home :1
# red_cards_home :Null
# goalkeeper_saves_home :2
# total_passess_home :590
# passess_accurate_home :508
# passess_home :86
# expected_goals_home :1.99
#
# shots_on_goal_away :4
# shots_off_goal_away :3
# total_shots_away :9
# blocked_shots_away :2
# shots_inside_box_away :6
# shots_outside_box_away :3
# fouls_away :10
# corner_kicks_away :9
# offsides_away :1
# ball_possession_away :40
# yellow_cards_away :2
# red_cards_away :1
# goalkeeper_saves_away :7
# total_passess_away :384
# passess_accurate_away :307
# passess_away :80
# expected_goals_away :0.88
# update football_statistics set  date = '2023-08-27 15:30:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 34,  teams_awayapi_id = 40,  goals_home = '1',  goals_away = '2',  score_halftime_home = '1',  score_halftime_away = '0',  score_secondtime_home = '0',  score_secondtime_away = '2',  score_fulltime_home = '1',  score_fulltime_away = '2',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '5',  lineups_coach_awayapi_id = '1',  lineups_formation_home = '4-3-3',  lineups_formation_away = '4-3-3',  shots_on_goal_home = 8,  shots_on_goal_away = 4,  shots_off_goal_home = 11,  shots_off_goal_away = 3,  total_shots_home = 23,  total_shots_away = 9,  blocked_shots_home = 4,  blocked_shots_away = 2,  shots_inside_box_home = 14,  shots_inside_box_away = 6,  shots_outside_box_home = 9,  shots_outside_box_away = 3,  fouls_home = 16,  fouls_away = 10,  offsides_home = Null,  offsides_away = 1,  ball_possession_home = 60,  ball_possession_away = 40,  corner_kicks_home = 5,  corner_kicks_away = 9,  yellow_cards_home = 1,  yellow_cards_away = 2,  red_cards_home = Null,  red_cards_away = 1,  goalkeeper_saves_home = 2,  goalkeeper_saves_away = 7,  total_passess_home = 590,  total_passess_away = 384,  passess_accurate_home = 508,  passess_accurate_away = 307,  passess_home = 86,  passess_away = 80,  expected_goals_home = 1.99,  expected_goals_away = 0.88,  updated_at = current_timestamp  where fixtureapi_id = '1035065'
#   ______[29/30]  #39 __ 2023 __ 1035066
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:24:59.357970
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 35
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035066
#   ____________fixture_updated_at : 2023-09-03 14:24:59.357970
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-08-27 13:00:00+00:00
# team_id: 62
#
# ID :62
# lineups_coach_homeapi_id :2397
# lineups_coach_home_name :P. Heckingbottom
# lineups_coach_home_photo :https://media-1.api-sports.io/football/coachs/2397.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2397
#   __________________name : P. Heckingbottom
# lineups_formation_home :3-5-2
# team_id: 50
#
# ID :50
# lineups_coach_awayapi_id :4
# lineups_coach_away_name :Pep Guardiola
# lineups_coach_away_photo :https://media-3.api-sports.io/football/coachs/4.png
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4
#   __________________name : Pep Guardiola
# lineups_formation_away :4-2-3-1
#
# shots_on_goal_home :2
# shots_off_goal_home :4
# total_shots_home :6
# blocked_shots_home :Null
# shots_inside_box_home :4
# shots_outside_box_home :2
# fouls_home :11
# corner_kicks_home :1
# offsides_home :1
# ball_possession_home :21
# yellow_cards_home :4
# red_cards_home :Null
# goalkeeper_saves_home :7
# total_passess_home :194
# passess_accurate_home :132
# passess_home :68
# expected_goals_home :0.67
#
# shots_on_goal_away :9
# shots_off_goal_away :13
# total_shots_away :30
# blocked_shots_away :8
# shots_inside_box_away :20
# shots_outside_box_away :10
# fouls_away :2
# corner_kicks_away :12
# offsides_away :2
# ball_possession_away :79
# yellow_cards_away :Null
# red_cards_away :Null
# goalkeeper_saves_away :Null
# total_passess_away :742
# passess_accurate_away :685
# passess_away :92
# expected_goals_away :3.60
# update football_statistics set  date = '2023-08-27 13:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 62,  teams_awayapi_id = 50,  goals_home = '1',  goals_away = '2',  score_halftime_home = '0',  score_halftime_away = '0',  score_secondtime_home = '1',  score_secondtime_away = '2',  score_fulltime_home = '1',  score_fulltime_away = '2',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = '2397',  lineups_coach_awayapi_id = '4',  lineups_formation_home = '3-5-2',  lineups_formation_away = '4-2-3-1',  shots_on_goal_home = 2,  shots_on_goal_away = 9,  shots_off_goal_home = 4,  shots_off_goal_away = 13,  total_shots_home = 6,  total_shots_away = 30,  blocked_shots_home = Null,  blocked_shots_away = 8,  shots_inside_box_home = 4,  shots_inside_box_away = 20,  shots_outside_box_home = 2,  shots_outside_box_away = 10,  fouls_home = 11,  fouls_away = 2,  offsides_home = 1,  offsides_away = 2,  ball_possession_home = 21,  ball_possession_away = 79,  corner_kicks_home = 1,  corner_kicks_away = 12,  yellow_cards_home = 4,  yellow_cards_away = Null,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 7,  goalkeeper_saves_away = Null,  total_passess_home = 194,  total_passess_away = 742,  passess_accurate_home = 132,  passess_accurate_away = 685,  passess_home = 68,  passess_away = 92,  expected_goals_home = 0.67,  expected_goals_away = 3.60,  updated_at = current_timestamp  where fixtureapi_id = '1035066'
#   ______[30/30]  #39 __ 2023 __ 1035074
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-03 14:25:01.637474
#   ________a_ts_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 34
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________a_ts_response_fixtures()
#   ____________fixtureapi_id : 1035074
#   ____________fixture_updated_at : 2023-09-03 14:25:01.637474
#   ____________ROUTES : fixtureapi_id
#   ______________Total API Response(s) : 1
#   ________________ [1/1] fixture_status: Match Finished __ 39 __ 2023-09-01 19:00:00+00:00
# team_id: 1359
#
# ID :1359
# lineups_coach_homeapi_id :None
# lineups_coach_home_name :None
# lineups_coach_home_photo :Null
# lineups_formation_home :5-3-2
# team_id: 48
#
# ID :48
# lineups_coach_awayapi_id :None
# lineups_coach_away_name :None
# lineups_coach_away_photo :Null
# lineups_formation_away :4-2-3-1
#
# shots_on_goal_home :1
# shots_off_goal_home :10
# total_shots_home :16
# blocked_shots_home :5
# shots_inside_box_home :13
# shots_outside_box_home :3
# fouls_home :8
# corner_kicks_home :9
# offsides_home :Null
# ball_possession_home :39
# yellow_cards_home :1
# red_cards_home :Null
# goalkeeper_saves_home :1
# total_passess_home :366
# passess_accurate_home :266
# passess_home :73
# expected_goals_home :1.47
#
# shots_on_goal_away :3
# shots_off_goal_away :4
# total_shots_away :9
# blocked_shots_away :2
# shots_inside_box_away :6
# shots_outside_box_away :3
# fouls_away :13
# corner_kicks_away :6
# offsides_away :6
# ball_possession_away :61
# yellow_cards_away :1
# red_cards_away :Null
# goalkeeper_saves_away :Null
# total_passess_away :609
# passess_accurate_away :507
# passess_away :83
# expected_goals_away :1.03
# update football_statistics set  date = '2023-09-01 19:00:00+00:00',  fixture_status = 'Match Finished',  teams_homeapi_id = 1359,  teams_awayapi_id = 48,  goals_home = '1',  goals_away = '2',  score_halftime_home = '0',  score_halftime_away = '1',  score_secondtime_home = '1',  score_secondtime_away = '1',  score_fulltime_home = '1',  score_fulltime_away = '2',  score_extratime_home = Null,  score_extratime_away = Null,  score_penalty_home = Null,  score_penalty_away = Null,  lineups_coach_homeapi_id = 'None',  lineups_coach_awayapi_id = 'None',  lineups_formation_home = '5-3-2',  lineups_formation_away = '4-2-3-1',  shots_on_goal_home = 1,  shots_on_goal_away = 3,  shots_off_goal_home = 10,  shots_off_goal_away = 4,  total_shots_home = 16,  total_shots_away = 9,  blocked_shots_home = 5,  blocked_shots_away = 2,  shots_inside_box_home = 13,  shots_inside_box_away = 6,  shots_outside_box_home = 3,  shots_outside_box_away = 3,  fouls_home = 8,  fouls_away = 13,  offsides_home = Null,  offsides_away = 6,  ball_possession_home = 39,  ball_possession_away = 61,  corner_kicks_home = 9,  corner_kicks_away = 6,  yellow_cards_home = 1,  yellow_cards_away = 1,  red_cards_home = Null,  red_cards_away = Null,  goalkeeper_saves_home = 1,  goalkeeper_saves_away = Null,  total_passess_home = 366,  total_passess_away = 609,  passess_accurate_home = 266,  passess_accurate_away = 507,  passess_home = 73,  passess_away = 83,  expected_goals_home = 1.47,  expected_goals_away = 1.03,  updated_at = current_timestamp  where fixtureapi_id = '1035074'
# # -------------------------------------------------- End at 2023-09-03 14:25:03
