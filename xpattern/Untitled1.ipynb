# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " SELECT * "
# ---------------------------------------------------------- 
query += ' FROM `bets_old` '   
query += ' WHERE `bet_id` = 4 '    
query += ' order by total asc '   
# ---------------------------------------------------------- 
print(space + query, flush=True) 
# ---------------------------------------------------------- 
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ---------------------------------------------------------- 
space += "__"
# ---------------------------------------------------------- 
total_rows = len(result)
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------    
print("", flush=True)
counter = 0
# ----------------------------------------------------------  
space += "__"
# ---------------------------------------------------------- 
for x in result:   
    # ------------------------------------------------------
    counter        += 1
    # ------------------------------------------------------ 
    columnx = str(x[5]) 
    # ------------------------------------------------------
    #  query_1 += ", " + prep_col + "asian_handicap_home_min_675"
    word = 'query_1 += ", " + prep_col + "'+columnx+'"'
    print(word, flush=True)
# Out:
# __ SELECT *  FROM `bets_old`  WHERE `bet_id` = 4  order by total asc
# ____Total Row(s) : 110
#
# query_1 += ", " + prep_col + "asian_handicap_home_min_675"
# query_1 += ", " + prep_col + "asian_handicap_away_min_675"
# query_1 += ", " + prep_col + "asian_handicap_home_min_65"
# query_1 += ", " + prep_col + "asian_handicap_away_min_65"
# query_1 += ", " + prep_col + "asian_handicap_home_min_625"
# query_1 += ", " + prep_col + "asian_handicap_away_min_625"
# query_1 += ", " + prep_col + "asian_handicap_home_min_6"
# query_1 += ", " + prep_col + "asian_handicap_away_min_6"
# query_1 += ", " + prep_col + "asian_handicap_home_min_575"
# query_1 += ", " + prep_col + "asian_handicap_away_min_575"
# query_1 += ", " + prep_col + "asian_handicap_home_min_55"
# query_1 += ", " + prep_col + "asian_handicap_away_min_55"
# query_1 += ", " + prep_col + "asian_handicap_home_min_525"
# query_1 += ", " + prep_col + "asian_handicap_away_min_525"
# ...

# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " SELECT * "
# ---------------------------------------------------------- 
query += ' FROM `bets_old` '   
query += ' WHERE `bet_id` = 5 '    
query += ' order by total asc '   
# ---------------------------------------------------------- 
print(space + query, flush=True) 
# ---------------------------------------------------------- 
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ---------------------------------------------------------- 
space += "__"
# ---------------------------------------------------------- 
total_rows = len(result)
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------    
print("", flush=True)
counter = 0
# ----------------------------------------------------------  
space += "__"
# ---------------------------------------------------------- 
for x in result:   
    # ------------------------------------------------------
    counter        += 1
    # ------------------------------------------------------ 
    columnx = str(x[5]) 
    # ------------------------------------------------------
    #  query_1 += ", " + prep_col + "asian_handicap_home_min_675"
    word = 'query_1 += ", " + prep_col + "'+columnx+'"'
    print(word, flush=True)
# Out:
# __ SELECT *  FROM `bets_old`  WHERE `bet_id` = 5  order by total asc
# ____Total Row(s) : 60
#
# query_1 += ", " + prep_col + "goals_overunder_over_05"
# query_1 += ", " + prep_col + "goals_overunder_under_05"
# query_1 += ", " + prep_col + "goals_overunder_over_075"
# query_1 += ", " + prep_col + "goals_overunder_under_075"
# query_1 += ", " + prep_col + "goals_overunder_over_10"
# query_1 += ", " + prep_col + "goals_overunder_under_10"
# query_1 += ", " + prep_col + "goals_overunder_over_125"
# query_1 += ", " + prep_col + "goals_overunder_under_125"
# query_1 += ", " + prep_col + "goals_overunder_over_15"
# query_1 += ", " + prep_col + "goals_overunder_under_15"
# query_1 += ", " + prep_col + "goals_overunder_over_175"
# query_1 += ", " + prep_col + "goals_overunder_under_175"
# query_1 += ", " + prep_col + "goals_overunder_over_20"
# query_1 += ", " + prep_col + "goals_overunder_under_20"
# query_1 += ", " + prep_col + "goals_overunder_over_225"
# ...

# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " SELECT * "
# ---------------------------------------------------------- 
query += ' FROM `bets_old` '   
query += ' WHERE `bet_id` = 4 '   
query += ' and value like "%Home%" '   
query += ' order by total asc '   
# ---------------------------------------------------------- 
print(space + query, flush=True) 
# ---------------------------------------------------------- 
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ---------------------------------------------------------- 
space += "__"
# ---------------------------------------------------------- 
total_rows = len(result)
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------    
print("", flush=True)
counter = 0
# ----------------------------------------------------------  
space += "__"
# ---------------------------------------------------------- 
for x in result:   
    # ------------------------------------------------------
    counter        += 1
    # ------------------------------------------------------ 
    value = str(x[3].replace("+", "plus_").replace("-", "min_").replace("Home ", "").replace(".", ""))
     
    # ------------------------------------------------------
    word = ""
    print(word, flush=True)
    # ------------------------------------------------------
    word = "counter_col += 1"
    print(word, flush=True)
    # ------------------------------------------------------
    word = "ah_" + value + " = rs1[counter_col] "
    print(word, flush=True)
# Out:
# __ SELECT *  FROM `bets_old`  WHERE `bet_id` = 4  and value like "%Home%"  order by total asc
# ____Total Row(s) : 55
#
#
# counter_col += 1
# ah_min_675 = rs1[counter_col]
#
# counter_col += 1
# ah_min_65 = rs1[counter_col]
#
# counter_col += 1
# ah_min_625 = rs1[counter_col]
#
# counter_col += 1
# ah_min_6 = rs1[counter_col]
#
# counter_col += 1
# ah_min_575 = rs1[counter_col]
#
# counter_col += 1
# ah_min_55 = rs1[counter_col]
#
# counter_col += 1
# ah_min_525 = rs1[counter_col]
#
# counter_col += 1
# ah_min_5 = rs1[counter_col]
#
# counter_col += 1
# ah_min_475 = rs1[counter_col]
#
# counter_col += 1
# ah_min_45 = rs1[counter_col]
#
# counter_col += 1
# ah_min_425 = rs1[counter_col]
#
# counter_col += 1
# ah_min_4 = rs1[counter_col]
#
# counter_col += 1
# ah_min_375 = rs1[counter_col]
#
# counter_col += 1
# ah_min_35 = rs1[counter_col]
#
# counter_col += 1
# ah_min_325 = rs1[counter_col]
#
# counter_col += 1
# ah_min_3 = rs1[counter_col]
#
# counter_col += 1
# ...

# %%
# Out:
# __ SELECT *  FROM `bets_old`  WHERE `bet_id` = 5  and value like "%Over%"  order by total asc
# ____Total Row(s) : 30
#
#
# counter_col += 1
# gou_05 = rs1[counter_col]
#
# counter_col += 1
# gou_075 = rs1[counter_col]
#
# counter_col += 1
# gou_10 = rs1[counter_col]
#
# counter_col += 1
# gou_125 = rs1[counter_col]
#
# counter_col += 1
# gou_15 = rs1[counter_col]
#
# counter_col += 1
# gou_175 = rs1[counter_col]
#
# counter_col += 1
# gou_20 = rs1[counter_col]
#
# counter_col += 1
# gou_225 = rs1[counter_col]
#
# counter_col += 1
# gou_25 = rs1[counter_col]
#
# counter_col += 1
# gou_275 = rs1[counter_col]
#
# counter_col += 1
# gou_30 = rs1[counter_col]
#
# counter_col += 1
# gou_325 = rs1[counter_col]
#
# counter_col += 1
# gou_35 = rs1[counter_col]
#
# counter_col += 1
# gou_375 = rs1[counter_col]
#
# counter_col += 1
# gou_40 = rs1[counter_col]
#
# counter_col += 1
# gou_425 = rs1[counter_col]
#
# counter_col += 1
# gou_45 = rs1[counter_col]
#
# counter_col += 1
# ...

# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " SELECT * "
# ---------------------------------------------------------- 
query += ' FROM `bets_old` '   
query += ' WHERE `bet_id` = 4 '   
query += ' and value like "%Home%" '   
query += ' order by total asc '   
# ---------------------------------------------------------- 
print(space + query, flush=True) 
# ---------------------------------------------------------- 
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ---------------------------------------------------------- 
space += "__"
# ---------------------------------------------------------- 
total_rows = len(result)
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------    
print("", flush=True)
counter = 0
# ----------------------------------------------------------  
space += "__"
# ---------------------------------------------------------- 
for x in result:   
    # ------------------------------------------------------
    counter        += 1
    # ------------------------------------------------------ 
    value = str(x[3].replace("+", "plus_").replace("-", "min_").replace("Home ", "").replace(".", ""))
     
    # ------------------------------------------------------
    word = ""
    print(word, flush=True)
    # ------------------------------------------------------
    word = "counter_col += 1"
    print(word, flush=True)
    # ------------------------------------------------------
    word = "ah_" + value + " = rs1[counter_col] "
    print(word, flush=True)
# Out:
# __ SELECT *  FROM `bets_old`  WHERE `bet_id` = 4  and value like "%Home%"  order by total asc
# ____Total Row(s) : 55
#
#
# counter_col += 1
# ah_min_675 = rs1[counter_col]
#
# counter_col += 1
# ah_min_65 = rs1[counter_col]
#
# counter_col += 1
# ah_min_625 = rs1[counter_col]
#
# counter_col += 1
# ah_min_6 = rs1[counter_col]
#
# counter_col += 1
# ah_min_575 = rs1[counter_col]
#
# counter_col += 1
# ah_min_55 = rs1[counter_col]
#
# counter_col += 1
# ah_min_525 = rs1[counter_col]
#
# counter_col += 1
# ah_min_5 = rs1[counter_col]
#
# counter_col += 1
# ah_min_475 = rs1[counter_col]
#
# counter_col += 1
# ah_min_45 = rs1[counter_col]
#
# counter_col += 1
# ah_min_425 = rs1[counter_col]
#
# counter_col += 1
# ah_min_4 = rs1[counter_col]
#
# counter_col += 1
# ah_min_375 = rs1[counter_col]
#
# counter_col += 1
# ah_min_35 = rs1[counter_col]
#
# counter_col += 1
# ah_min_325 = rs1[counter_col]
#
# counter_col += 1
# ah_min_3 = rs1[counter_col]
#
# counter_col += 1
# ...
