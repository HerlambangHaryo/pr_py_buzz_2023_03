# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-06-08 12:57:46
#   __main()
#   ____Enter your leagueapi id :  39
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '39'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '39'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 422
#   __________[1/422] #710897 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710897
#   ____________> pre_ah_pattern = +05+075+1H
#   ____________> pre_ah_pattern_mirror = +1+075+05H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[2/422] #710902 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710902
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = -1-125-15-175H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[3/422] #710904 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710904
#   ____________> pre_ah_pattern = +05+075H
#   ____________> pre_ah_pattern_mirror = +075+05H
#   ____________> pre_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[4/422] #710899 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710899
#   ____________> pre_ah_pattern = -1-075-05H
#   ____________> pre_ah_pattern_mirror = -05-075-1H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[5/422] #710907 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710907
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[6/422] #710909 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710909
#   ____________> pre_ah_pattern = -025+0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0-025H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[7/422] #710910 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710910
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = -1-125-15-175H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[8/422] #710911 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710911
#   ____________> pre_ah_pattern = -125-1-075-05H
#   ____________> pre_ah_pattern_mirror = -05-075-1-125H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[9/422] #710908 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710908
#   ____________> pre_ah_pattern = -025+0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0-025H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[10/422] #710913 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710913
#   ____________> pre_ah_pattern = -175-15-125-1-075H
#   ____________> pre_ah_pattern_mirror = -075-1-125-15-175H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[11/422] #710906 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710906
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[12/422] #710912 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710912
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[13/422] #710915 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710915
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[14/422] #710914 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710914
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[15/422] #710876 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710876
#   ____________> pre_ah_pattern = +075+1+125+15H
#   ____________> pre_ah_pattern_mirror = +15+125+1+075H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[16/422] #710878 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710878
#   ____________> pre_ah_pattern = +05+075+1+125H
#   ____________> pre_ah_pattern_mirror = +125+1+075+05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[17/422] #710762 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710762
#   ____________> pre_ah_pattern = -175-15-125-1-075H
#   ____________> pre_ah_pattern_mirror = -075-1-125-15-175H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[18/422] #710854 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710854
#   ____________> pre_ah_pattern = +025+05+075+1H
#   ____________> pre_ah_pattern_mirror = +1+075+05+025H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[19/422] #710885 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710885
#   ____________> pre_ah_pattern = +125+15+175+2H
#   ____________> pre_ah_pattern_mirror = +2+175+15+125H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[20/422] #710773 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710773
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05-075H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[21/422] #710922 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710922
#   ____________> pre_ah_pattern = -175-15-125H
#   ____________> pre_ah_pattern_mirror = -125-15-175H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[22/422] #710916 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710916
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[23/422] #710918 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710918
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025-05H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[24/422] #710923 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710923
#   ____________> pre_ah_pattern = +0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[25/422] #710924 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710924
#   ____________> pre_ah_pattern = +1+125+15+175H
#   ____________> pre_ah_pattern_mirror = +175+15+125+1H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[26/422] #710925 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710925
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = -075-1-125-15H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[27/422] #710917 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710917
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[28/422] #710920 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710920
#   ____________> pre_ah_pattern = +025+05+075+1H
#   ____________> pre_ah_pattern_mirror = +1+075+05+025H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[29/422] #710921 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710921
#   ____________> pre_ah_pattern = +1+125+15+175H
#   ____________> pre_ah_pattern_mirror = +175+15+125+1H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[30/422] #710877 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710877
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[31/422] #710726 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710726
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[32/422] #710819 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710819
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = -1-125-15-175H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[33/422] #710926 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710926
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = -075-1-125-15H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[34/422] #710927 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710927
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[35/422] #710928 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710928
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025-05H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[36/422] #710929 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710929
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025-05H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[37/422] #710930 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710930
#   ____________> pre_ah_pattern = -25-225-2-175H
#   ____________> pre_ah_pattern_mirror = -175-2-225-25H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[38/422] #710931 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710931
#   ____________> pre_ah_pattern = +0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[39/422] #710932 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710932
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[40/422] #710933 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710933
#   ____________> pre_ah_pattern = -25-225-2-175-15H
#   ____________> pre_ah_pattern_mirror = -15-175-2-225-25H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[41/422] #710934 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710934
#   ____________> pre_ah_pattern = -25-225-2-175H
#   ____________> pre_ah_pattern_mirror = -175-2-225-25H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[42/422] #710935 #39 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 710935
#   ____________> pre_ah_pattern = +15+175+2+225H
#   ____________> pre_ah_pattern_mirror = +225+2+175+15H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[43/422] #867946 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867946
#   ____________> pre_ah_pattern = +025+05+075+1H
#   ____________> pre_ah_pattern_mirror = +1+075+05+025H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[44/422] #867947 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867947
#   ____________> pre_ah_pattern = +125+15+175+2+225H
#   ____________> pre_ah_pattern_mirror = +225+2+175+15+125H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[45/422] #867948 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867948
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[46/422] #867949 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867949
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[47/422] #867951 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867951
#   ____________> pre_ah_pattern = -125-1-075-05H
#   ____________> pre_ah_pattern_mirror = -05-075-1-125H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[48/422] #867952 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867952
#   ____________> pre_ah_pattern = -15-125H
#   ____________> pre_ah_pattern_mirror = -125-15H
#   ____________> pre_gou_pattern = 25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[49/422] #867953 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867953
#   ____________> pre_ah_pattern = +05+075+1+125H
#   ____________> pre_ah_pattern_mirror = +125+1+075+05H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[50/422] #867950 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867950
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[51/422] #867954 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867954
#   ____________> pre_ah_pattern = -125-1-075-05H
#   ____________> pre_ah_pattern_mirror = -05-075-1-125H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[52/422] #867955 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867955
#   ____________> pre_ah_pattern = +1+125+15+175H
#   ____________> pre_ah_pattern_mirror = +175+15+125+1H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[53/422] #867957 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867957
#   ____________> pre_ah_pattern = -1-075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075-1H
#   ____________> pre_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[54/422] #867956 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867956
#   ____________> pre_ah_pattern = -15-125-1-075-05H
#   ____________> pre_ah_pattern_mirror = -05-075-1-125-15H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[55/422] #867959 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867959
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[56/422] #867962 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867962
#   ____________> pre_ah_pattern = -35-325-3-275-25H
#   ____________> pre_ah_pattern_mirror = -25-275-3-325-35H
#   ____________> pre_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[57/422] #867964 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867964
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[58/422] #867965 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867965
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[59/422] #867958 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867958
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[60/422] #867963 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867963
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[61/422] #867960 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867960
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[62/422] #867961 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867961
#   ____________> pre_ah_pattern = -225-2-175-15H
#   ____________> pre_ah_pattern_mirror = -15-175-2-225H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[63/422] #867974 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867974
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = -1-125-15-175H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[64/422] #867967 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867967
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025-05H
#   ____________> pre_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[65/422] #867968 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867968
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[66/422] #867969 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867969
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025-05H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[67/422] #867971 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867971
#   ____________> pre_ah_pattern = -1-075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075-1H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[68/422] #867966 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867966
#   ____________> pre_ah_pattern = +075+1+125+15H
#   ____________> pre_ah_pattern_mirror = +15+125+1+075H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[69/422] #867970 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867970
#   ____________> pre_ah_pattern = +05+075+1+125+15H
#   ____________> pre_ah_pattern_mirror = +15+125+1+075+05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[70/422] #867975 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867975
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[71/422] #867973 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867973
#   ____________> pre_ah_pattern = +1+125+15+175H
#   ____________> pre_ah_pattern_mirror = +175+15+125+1H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[72/422] #867972 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867972
#   ____________> pre_ah_pattern = +05+075+1+125H
#   ____________> pre_ah_pattern_mirror = +125+1+075+05H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[73/422] #867984 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867984
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[74/422] #867978 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867978
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[75/422] #867979 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867979
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[76/422] #867980 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867980
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[77/422] #867981 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867981
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[78/422] #867982 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867982
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[79/422] #867976 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867976
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[80/422] #867977 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867977
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[81/422] #867985 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867985
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[82/422] #867983 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867983
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[83/422] #867988 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867988
#   ____________> pre_ah_pattern = +0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[84/422] #867992 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867992
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05-075H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[85/422] #867993 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867993
#   ____________> pre_ah_pattern = +05+075+1+125+15H
#   ____________> pre_ah_pattern_mirror = +15+125+1+075+05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[86/422] #867989 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867989
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05-075H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[87/422] #867986 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867986
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025H
#   ____________> pre_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[88/422] #867987 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867987
#   ____________> pre_ah_pattern = -15-125-1-075+025H
#   ____________> pre_ah_pattern_mirror = +025-075-1-125-15H
#   ____________> pre_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[89/422] #867995 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867995
#   ____________> pre_ah_pattern = -35-325-3-275-25+025H
#   ____________> pre_ah_pattern_mirror = +025-25-275-3-325-35H
#   ____________> pre_gou_pattern = 25g35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[90/422] #867991 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867991
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[91/422] #867994 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867994
#   ____________> pre_ah_pattern = -2-175-15-125+025H
#   ____________> pre_ah_pattern_mirror = +025-125-15-175-2H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[92/422] #867990 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867990
#   ____________> pre_ah_pattern = +0+025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025+0H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[93/422] #868000 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868000
#   ____________> pre_ah_pattern = +1+125+15+175H
#   ____________> pre_ah_pattern_mirror = +175+15+125+1H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[94/422] #867997 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867997
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[95/422] #867999 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867999
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[96/422] #868002 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868002
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[97/422] #868003 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868003
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[98/422] #868004 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868004
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = -1-125-15-175H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[99/422] #868005 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868005
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[100/422] #867996 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867996
#   ____________> pre_ah_pattern = +1+125+15+175H
#   ____________> pre_ah_pattern_mirror = +175+15+125+1H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[101/422] #867998 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 867998
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[102/422] #868001 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868001
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025-05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[103/422] #868016 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868016
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[104/422] #868023 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868023
#   ____________> pre_ah_pattern = -025+0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0-025H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[105/422] #868025 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868025
#   ____________> pre_ah_pattern = +125+15+175H
#   ____________> pre_ah_pattern_mirror = +175+15+125H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[106/422] #868022 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868022
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = -075-1-125-15H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[107/422] #868024 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868024
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = -075-1-125-15H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[108/422] #868017 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868017
#   ____________> pre_ah_pattern = +05+075+1H
#   ____________> pre_ah_pattern_mirror = +1+075+05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[109/422] #868020 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868020
#   ____________> pre_ah_pattern = -025+0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0-025H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[110/422] #868027 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868027
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05-075H
#   ____________> pre_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[111/422] #868026 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868026
#   ____________> pre_ah_pattern = +0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[112/422] #868028 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868028
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[113/422] #868029 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868029
#   ____________> pre_ah_pattern = +0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[114/422] #868032 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868032
#   ____________> pre_ah_pattern = -175-15-125H
#   ____________> pre_ah_pattern_mirror = -125-15-175H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[115/422] #868034 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868034
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05-075H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[116/422] #868035 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868035
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[117/422] #868033 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868033
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = -1-125-15-175H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[118/422] #868030 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868030
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[119/422] #868031 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868031
#   ____________> pre_ah_pattern = -075H
#   ____________> pre_ah_pattern_mirror = -075H
#   ____________> pre_gou_pattern = 25g275gG
#   ____________> football_odds update pattern commited
#   __________[120/422] #868036 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868036
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[121/422] #868039 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868039
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = -1-125-15-175H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[122/422] #868042 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868042
#   ____________> pre_ah_pattern = -3-275-25-225H
#   ____________> pre_ah_pattern_mirror = -225-25-275-3H
#   ____________> pre_gou_pattern = 35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[123/422] #868043 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868043
#   ____________> pre_ah_pattern = -1-075-05H
#   ____________> pre_ah_pattern_mirror = -05-075-1H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[124/422] #868038 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868038
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[125/422] #868040 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868040
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[126/422] #868045 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868045
#   ____________> pre_ah_pattern = -1-075-05H
#   ____________> pre_ah_pattern_mirror = -05-075-1H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[127/422] #868037 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868037
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025-05H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[128/422] #868041 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868041
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[129/422] #868044 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868044
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[130/422] #868047 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868047
#   ____________> pre_ah_pattern = +0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[131/422] #868050 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868050
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0-025-05H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[132/422] #868048 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868048
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[133/422] #868055 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868055
#   ____________> pre_ah_pattern = -1-075-05H
#   ____________> pre_ah_pattern_mirror = -05-075-1H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[134/422] #868054 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868054
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = -075-1-125-15H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[135/422] #868046 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868046
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = +075+05+025H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[136/422] #868049 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868049
#   ____________> pre_ah_pattern = +05+075+1+125+15H
#   ____________> pre_ah_pattern_mirror = +15+125+1+075+05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[137/422] #868052 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868052
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[138/422] #868053 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868053
#   ____________> pre_ah_pattern = +0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[139/422] #868051 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868051
#   ____________> pre_ah_pattern = +025+05+075+1H
#   ____________> pre_ah_pattern_mirror = +1+075+05+025H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[140/422] #868059 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868059
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[141/422] #868062 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868062
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[142/422] #868056 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868056
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025H
#   ____________> pre_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[143/422] #868058 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868058
#   ____________> pre_ah_pattern = +025+05+075+1H
#   ____________> pre_ah_pattern_mirror = +1+075+05+025H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[144/422] #868063 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868063
#   ____________> pre_ah_pattern = -125-1-075-05H
#   ____________> pre_ah_pattern_mirror = -05-075-1-125H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[145/422] #868064 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868064
#   ____________> pre_ah_pattern = -175-15-125-1-075H
#   ____________> pre_ah_pattern_mirror = -075-1-125-15-175H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[146/422] #868065 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868065
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025-05H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[147/422] #868060 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868060
#   ____________> pre_ah_pattern = -025+0+025+05H
#   ____________> pre_ah_pattern_mirror = +05+025+0-025H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[148/422] #868061 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868061
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025-05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[149/422] #868071 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868071
#   ____________> pre_ah_pattern = +125+15+175+2H
#   ____________> pre_ah_pattern_mirror = +2+175+15+125H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[150/422] #868068 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868068
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = +025+0-025H
#   ____________> pre_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[151/422] #868070 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868070
#   ____________> pre_ah_pattern = -25-225-2-175-15H
#   ____________> pre_ah_pattern_mirror = -15-175-2-225-25H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[152/422] #868067 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868067
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = -025-05-075H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[153/422] #868066 #39 - 2022
#   ____________xpN_set_pattern()
# ...
#   ____________> fixtureapi_id = 868285
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = -125-15-175-2H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[223/271] #868283 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868283
#   ____________> end_ah_pattern = -15-125-1-075-05H
#   ____________> end_ah_pattern_mirror = -05-075-1-125-15H
#   ____________> end_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[224/271] #868282 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868282
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = -025-05-075H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[225/271] #868277 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868277
#   ____________> end_ah_pattern = -15-125-1-075-05H
#   ____________> end_ah_pattern_mirror = -05-075-1-125-15H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[226/271] #868221 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868221
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = -125-15-175-2H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[227/271] #868222 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868222
#   ____________> end_ah_pattern = -225-2-175-15H
#   ____________> end_ah_pattern_mirror = -15-175-2-225H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[228/271] #868219 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868219
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = -025-05-075H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[229/271] #868286 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868286
#   ____________> end_ah_pattern = +0+025+05+075H
#   ____________> end_ah_pattern_mirror = +075+05+025+0H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[230/271] #868290 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868290
#   ____________> end_ah_pattern = -275-25-225-2-175H
#   ____________> end_ah_pattern_mirror = -175-2-225-25-275H
#   ____________> end_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[231/271] #868293 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868293
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = -025-05-075-1H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[232/271] #868295 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868295
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = +05+025+0H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[233/271] #868289 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868289
#   ____________> end_ah_pattern = -175-15-125-1H
#   ____________> end_ah_pattern_mirror = -1-125-15-175H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[234/271] #868291 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868291
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = +025+0-025-05H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[235/271] #868294 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868294
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = +075+05+025H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[236/271] #868288 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868288
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = +05+025+0-025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[237/271] #868287 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868287
#   ____________> end_ah_pattern = -175-15-125H
#   ____________> end_ah_pattern_mirror = -125-15-175H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[238/271] #868292 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868292
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = -025-05-075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[239/271] #868302 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868302
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = +125+1+075+05H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[240/271] #868297 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868297
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = +025+0-025-05H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[241/271] #868299 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868299
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = -075-1-125-15H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[242/271] #868300 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868300
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = -05-075-1H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[243/271] #868304 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868304
#   ____________> end_ah_pattern = -175-15-125-1H
#   ____________> end_ah_pattern_mirror = -1-125-15-175H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[244/271] #868305 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868305
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = +05+025+0-025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[245/271] #868298 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868298
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = -025-05-075-1H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[246/271] #868301 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868301
#   ____________> end_ah_pattern = +1+125+15+175H
#   ____________> end_ah_pattern_mirror = +175+15+125+1H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[247/271] #868296 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868296
#   ____________> end_ah_pattern = -125-1-075-05-025H
#   ____________> end_ah_pattern_mirror = -025-05-075-1-125H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[248/271] #868303 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868303
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = +125+1+075+05H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[249/271] #868193 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868193
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = -025-05-075-1H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[250/271] #868313 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868313
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = -025-05-075H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[251/271] #868306 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868306
#   ____________> end_ah_pattern = +075+1+125+15+175H
#   ____________> end_ah_pattern_mirror = +175+15+125+1+075H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[252/271] #868308 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868308
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0-025-05H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[253/271] #868309 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868309
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = -075-1-125-15H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[254/271] #868315 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868315
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = +05+025+0-025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[255/271] #868312 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868312
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = +125+1+075+05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[256/271] #868314 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868314
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = +025+0-025-05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[257/271] #868307 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868307
#   ____________> end_ah_pattern = -25-225-2-175-15H
#   ____________> end_ah_pattern_mirror = -15-175-2-225-25H
#   ____________> end_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[258/271] #868310 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868310
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = -125-15-175-2H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[259/271] #868311 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868311
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = -125-15-175-2H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[260/271] #868259 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868259
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = +075+05+025H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[261/271] #868264 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868264
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = -05-075-1-125H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[262/271] #868316 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868316
#   ____________> end_ah_pattern = -225-2-175-15-125H
#   ____________> end_ah_pattern_mirror = -125-15-175-2-225H
#   ____________> end_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[263/271] #868317 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868317
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = -025-05-075-1H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[264/271] #868318 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868318
#   ____________> end_ah_pattern = +0+025+05+075H
#   ____________> end_ah_pattern_mirror = +075+05+025+0H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[265/271] #868319 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868319
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = +05+025+0-025H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[266/271] #868320 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868320
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = -05-075-1-125H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[267/271] #868321 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868321
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = -05-075-1-125H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[268/271] #868322 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868322
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = +05+025+0-025H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[269/271] #868323 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868323
#   ____________> end_ah_pattern = -075-05-025+0H
#   ____________> end_ah_pattern_mirror = +0-025-05-075H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[270/271] #868324 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868324
#   ____________> end_ah_pattern = -175-15-125-1-075H
#   ____________> end_ah_pattern_mirror = -075-1-125-15-175H
#   ____________> end_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[271/271] #868325 #39 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 868325
#   ____________> end_ah_pattern = +075+1+125+15+175H
#   ____________> end_ah_pattern_mirror = +175+15+125+1+075H
#   ____________> end_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-06-08 13:32:16
