# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.football_odds import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------   
    # --------------------------------------------------  
    fO_get_group_league_status_match_finished_DETAILED('', '', "all_pre_xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-27 11:25:51
#   __main()
#   ______fO_get_group_league_status_match_finished_DETAILED()
#   ______Select  DATE(date),  leagueapi_id,  (select bookmakersapi_id from football_leagues where football_leagues.leagueapi_id = football_odds.leagueapi_id),  season,   fixtureapi_id,   pre_ah_pattern,   pre_gou_pattern,   fixture_status   from football_odds  where  deleted_at is null  and pre_response = 1  order by date, leagueapi_id, fixtureapi_id  desc
#   ________Total Row(s) : 653
#   ________1. 2023-05-27 // 129 // 8 // 2023 // 992602 // 075_05_025_H // 175g2g225gG // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992602
#   __________> pre_ah_pattern = 1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+H
#   __________> pre_gou_pattern = 175g2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________2. 2023-05-27 // 254 // 11 // 2023 // 1004134 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1004134
#   __________> pre_ah_pattern = 0#025+075+H
#   __________> pre_ah_pattern_mirror = 075_025_0#H
#   __________> pre_gou_pattern = 225g25g275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________3. 2023-05-27 // 255 // 11 // 2023 // 1008463 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1008463
#   __________> pre_ah_pattern = 15_125_1_075_H
#   __________> pre_ah_pattern_mirror = 075+1+125+15+H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________4. 2023-05-27 // 189 // 11 // 2023 // 979252 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 979252
#   __________> pre_ah_pattern = 35_325_3_275_25_225_H
#   __________> pre_ah_pattern_mirror = 225+25+275+3+325+35+H
#   __________> pre_gou_pattern = 35g375g4g425g45gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________5. 2023-05-27 // 189 // 11 // 2023 // 979251 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 979251
#   __________> pre_ah_pattern = 075_05_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+05+075+H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________6. 2023-05-27 // 195 // 8 // 2023 // 978958 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 978958
#   __________> pre_ah_pattern = 0#025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_0#H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________7. 2023-05-27 // 195 // 8 // 2023 // 978955 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 978955
#   __________> pre_ah_pattern = 125_1_075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+1+125+H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________8. 2023-05-27 // 100 // 11 // 2023 // 995461 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 995461
#   __________> pre_ah_pattern = 075_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+075+H
#   __________> pre_gou_pattern = 175g2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________9. 2023-05-27 // 295 // 8 // 2023 // 1003850 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1003850
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________10. 2023-05-27 // 295 // 8 // 2023 // 1003849 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1003849
#   __________> pre_ah_pattern = 125_H
#   __________> pre_ah_pattern_mirror = 125+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________11. 2023-05-27 // 295 // 8 // 2023 // 1003848 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1003848
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________12. 2023-05-27 // 196 // 11 // 2023 // 1013225 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1013225
#   __________> pre_ah_pattern = 175_15_125_1_075_H
#   __________> pre_ah_pattern_mirror = 075+1+125+15+175+H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________13. 2023-05-27 // 196 // 11 // 2023 // 1013223 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1013223
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 25g275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________14. 2023-05-27 // 196 // 11 // 2023 // 1013222 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1013222
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________15. 2023-05-27 // 196 // 11 // 2023 // 1013220 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1013220
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________16. 2023-05-27 // 293 // 8 // 2023 // 997268 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 997268
#   __________> pre_ah_pattern = 025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________17. 2023-05-27 // 293 // 8 // 2023 // 997267 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 997267
#   __________> pre_ah_pattern = 125_1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+125+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________18. 2023-05-27 // 481 // 8 // 2023 // 981939 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 981939
#   __________> pre_ah_pattern = 075+H
#   __________> pre_ah_pattern_mirror = 075_H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________19. 2023-05-27 // 195 // 8 // 2023 // 978956 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 978956
#   __________> pre_ah_pattern = 25_225_2_175_15_H
#   __________> pre_ah_pattern_mirror = 15+175+2+225+25+H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________20. 2023-05-27 // 292 // 8 // 2023 // 1002791 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1002791
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________21. 2023-05-27 // 194 // 11 // 2023 // 990782 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 990782
#   __________> pre_ah_pattern = 125_1_075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+1+125+H
#   __________> pre_gou_pattern = 225g25g275g3g325gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________22. 2023-05-27 // 98 // 8 // 2023 // 994740 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 994740
#   __________> pre_ah_pattern = 025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________23. 2023-05-27 // 196 // 11 // 2023 // 1013260 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1013260
#   __________> pre_ah_pattern = 025_0#025+075+H
#   __________> pre_ah_pattern_mirror = 075_025_0#025+H
#   __________> pre_gou_pattern = 25g275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________24. 2023-05-27 // 195 // 8 // 2023 // 978957 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 978957
#   __________> pre_ah_pattern = 125+15+175+2+H
#   __________> pre_ah_pattern_mirror = 2_175_15_125_H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________25. 2023-05-27 // 348 // 11 // 2022 // 975185 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 975185
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 25g275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________26. 2023-05-27 // 348 // 11 // 2022 // 975184 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 975184
#   __________> pre_ah_pattern = 175_15_125_1_075_H
#   __________> pre_ah_pattern_mirror = 075+1+125+15+175+H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________27. 2023-05-27 // 348 // 11 // 2022 // 975182 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 975182
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = 25g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________28. 2023-05-27 // 685 // 11 // 2022 // 1007127 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1007127
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________29. 2023-05-27 // 685 // 11 // 2022 // 1007124 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1007124
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________30. 2023-05-27 // 192 // 11 // 2023 // 982368 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 982368
#   __________> pre_ah_pattern = 075_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+075+H
#   __________> pre_gou_pattern = 25g275g3g325gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________31. 2023-05-27 // 348 // 11 // 2022 // 975179 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 975179
#   __________> pre_ah_pattern = 025+075+H
#   __________> pre_ah_pattern_mirror = 075_025_H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________32. 2023-05-27 // 685 // 11 // 2022 // 1007131 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1007131
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________33. 2023-05-27 // 685 // 11 // 2022 // 1007130 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1007130
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25g3g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________34. 2023-05-27 // 192 // 11 // 2023 // 982246 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 982246
#   __________> pre_ah_pattern = 0#025+075+H
#   __________> pre_ah_pattern_mirror = 075_025_0#H
#   __________> pre_gou_pattern = 25g275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________35. 2023-05-27 // 293 // 8 // 2023 // 997269 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 997269
#   __________> pre_ah_pattern = 0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________36. 2023-05-27 // 95 // 8 // 2022 // 899211 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 899211
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________37. 2023-05-27 // 98 // 8 // 2023 // 994741 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 994741
#   __________> pre_ah_pattern = 025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________38. 2023-05-27 // 196 // 11 // 2023 // 1013221 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1013221
#   __________> pre_ah_pattern = 075_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+075+H
#   __________> pre_gou_pattern = 25g275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________39. 2023-05-27 // 292 // 8 // 2023 // 1002792 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1002792
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________40. 2023-05-27 // 340 // 11 // 2023 // 1004708 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1004708
#   __________> pre_ah_pattern = 075+1+125+H
#   __________> pre_ah_pattern_mirror = 125_1_075_H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________41. 2023-05-27 // 361 // 11 // 2023 // 1011637 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1011637
#   __________> pre_ah_pattern = 15_H
#   __________> pre_ah_pattern_mirror = 15+H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________42. 2023-05-27 // 368 // 11 // 2023 // 997906 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 997906
#   __________> pre_ah_pattern = 075+1+125+15+175+H
#   __________> pre_ah_pattern_mirror = 175_15_125_1_075_H
#   __________> pre_gou_pattern = 325g35g375g4g425g45gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________43. 2023-05-27 // 398 // 11 // 2023 // 1015166 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1015166
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________44. 2023-05-27 // 398 // 11 // 2023 // 1015165 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1015165
#   __________> pre_ah_pattern = 075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________45. 2023-05-27 // 594 // 8 // 2023 // 993571 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 993571
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________46. 2023-05-27 // 594 // 8 // 2023 // 993569 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 993569
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________47. 2023-05-27 // 780 // 11 // 2022 // 969360 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 969360
#   __________> pre_ah_pattern = 075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________48. 2023-05-27 // 139 // 8 // 2022 // 1011413 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1011413
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________49. 2023-05-27 // 139 // 8 // 2022 // 1011412 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1011412
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________50. 2023-05-27 // 114 // 8 // 2023 // 1002353 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1002353
#   __________> pre_ah_pattern = 05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________51. 2023-05-27 // 120 // 8 // 2022 // 1017373 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1017373
#   __________> pre_ah_pattern = 025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_H
#   __________> pre_gou_pattern = 25g275g3g325gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________52. 2023-05-27 // 235 // 11 // 2022 // 880098 // 0#025+H // 225g25g275g3gG // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 880098
#   __________> pre_ah_pattern = 025+075+H
#   __________> pre_ah_pattern_mirror = 075_025_H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________53. 2023-05-27 // 334 // 11 // 2022 // 977413 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 977413
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 15g175g2g225gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________54. 2023-05-27 // 334 // 11 // 2022 // 977411 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 977411
#   __________> pre_ah_pattern = 025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+H
#   __________> pre_gou_pattern = 175g2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________55. 2023-05-27 // 334 // 11 // 2022 // 977410 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 977410
#   __________> pre_ah_pattern = 1_075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+1+H
#   __________> pre_gou_pattern = 175g2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________56. 2023-05-27 // 340 // 11 // 2023 // 1004710 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1004710
#   __________> pre_ah_pattern = 1_075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+1+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________57. 2023-05-27 // 340 // 11 // 2023 // 1004709 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1004709
#   __________> pre_ah_pattern = 0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________58. 2023-05-27 // 361 // 11 // 2023 // 1011638 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1011638
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________59. 2023-05-27 // 365 // 8 // 2023 // 1009365 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1009365
#   __________> pre_ah_pattern = 1_075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+1+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________60. 2023-05-27 // 563 // 8 // 2023 // 982930 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 982930
#   __________> pre_ah_pattern = 2_175_15_125_H
#   __________> pre_ah_pattern_mirror = 125+15+175+2+H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________61. 2023-05-27 // 563 // 8 // 2023 // 982928 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 982928
#   __________> pre_ah_pattern = 125_1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+125+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________62. 2023-05-27 // 594 // 8 // 2023 // 993572 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 993572
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________63. 2023-05-27 // 596 // 8 // 2023 // 993384 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 993384
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________64. 2023-05-27 // 597 // 8 // 2023 // 993750 // None // None // Time to be defined
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 993750
#   __________> pre_ah_pattern = 025+05+075+1+H
#   __________> pre_ah_pattern_mirror = 1_075_05_025_H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________65. 2023-05-27 // 597 // 8 // 2023 // 993749 // None // None // Time to be defined
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 993749
#   __________> pre_ah_pattern = 275_25_225_2_H
#   __________> pre_ah_pattern_mirror = 2+225+25+275+H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________66. 2023-05-27 // 705 // 8 // 2022 // 915623 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 915623
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________67. 2023-05-27 // 705 // 8 // 2022 // 915622 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 915622
#   __________> pre_ah_pattern = 0#H
#   __________> pre_ah_pattern_mirror = 0#H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________68. 2023-05-27 // 705 // 8 // 2022 // 915621 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 915621
#   __________> pre_ah_pattern = 075_H
#   __________> pre_ah_pattern_mirror = 075+H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________69. 2023-05-27 // 705 // 8 // 2022 // 915620 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 915620
#   __________> pre_ah_pattern = 05+H
#   __________> pre_ah_pattern_mirror = 05_H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________70. 2023-05-27 // 705 // 8 // 2022 // 915619 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 915619
#   __________> pre_ah_pattern = 025_H
#   __________> pre_ah_pattern_mirror = 025+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________71. 2023-05-27 // 705 // 8 // 2022 // 915618 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 915618
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________72. 2023-05-27 // 705 // 8 // 2022 // 915617 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 915617
#   __________> pre_ah_pattern = 075_H
#   __________> pre_ah_pattern_mirror = 075+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________73. 2023-05-27 // 705 // 8 // 2022 // 915616 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 915616
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________74. 2023-05-27 // 80 // 8 // 2022 // 879491 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 879491
#   __________> pre_ah_pattern = 05_025_0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#025+05+H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________75. 2023-05-27 // 80 // 8 // 2022 // 879490 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 879490
#   __________> pre_ah_pattern = 175_15_125_1_H
#   __________> pre_ah_pattern_mirror = 1+125+15+175+H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________76. 2023-05-27 // 80 // 8 // 2022 // 879489 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 879489
#   __________> pre_ah_pattern = 175_15_125_1_075_H
#   __________> pre_ah_pattern_mirror = 075+1+125+15+175+H
#   __________> pre_gou_pattern = 275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________77. 2023-05-27 // 80 // 8 // 2022 // 879488 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 879488
#   __________> pre_ah_pattern = 025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________78. 2023-05-27 // 80 // 8 // 2022 // 879487 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 879487
#   __________> pre_ah_pattern = 225_2_175_15_125_H
#   __________> pre_ah_pattern_mirror = 125+15+175+2+225+H
#   __________> pre_gou_pattern = 3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________79. 2023-05-27 // 80 // 8 // 2022 // 879486 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 879486
#   __________> pre_ah_pattern = 05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+H
#   __________> pre_gou_pattern = 25g275g3g325gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________80. 2023-05-27 // 80 // 8 // 2022 // 879485 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 879485
#   __________> pre_ah_pattern = 125_1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+125+H
#   __________> pre_gou_pattern = 275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________81. 2023-05-27 // 80 // 8 // 2022 // 879484 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 879484
#   __________> pre_ah_pattern = 025+05+075+1+H
#   __________> pre_ah_pattern_mirror = 1_075_05_025_H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________82. 2023-05-27 // 80 // 8 // 2022 // 879483 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 879483
#   __________> pre_ah_pattern = 175_15_125_1_H
#   __________> pre_ah_pattern_mirror = 1+125+15+175+H
#   __________> pre_gou_pattern = 325g35g375g4g425gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________83. 2023-05-27 // 80 // 8 // 2022 // 879482 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 879482
#   __________> pre_ah_pattern = 25_225_2_175_15_H
#   __________> pre_ah_pattern_mirror = 15+175+2+225+25+H
#   __________> pre_gou_pattern = 35g375g4g425gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________84. 2023-05-27 // 179 // 8 // 2022 // 1023346 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1023346
#   __________> pre_ah_pattern = 075+1+125+15+H
#   __________> pre_ah_pattern_mirror = 15_125_1_075_H
#   __________> pre_gou_pattern = 25g275g3g325gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________85. 2023-05-27 // 179 // 8 // 2022 // 1023345 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1023345
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 225g25g275g3g325gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________86. 2023-05-27 // 179 // 8 // 2022 // 1023344 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1023344
#   __________> pre_ah_pattern = 25_225_2_175_15_H
#   __________> pre_ah_pattern_mirror = 15+175+2+225+25+H
#   __________> pre_gou_pattern = 325g35g375g4gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________87. 2023-05-27 // 169 // 8 // 2023 // 1021343 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1021343
#   __________> pre_ah_pattern = 075+1+125+15+H
#   __________> pre_ah_pattern_mirror = 15_125_1_075_H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________88. 2023-05-27 // 94 // 8 // 2022 // 898907 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 898907
#   __________> pre_ah_pattern = 05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________89. 2023-05-27 // 95 // 8 // 2022 // 899212 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 899212
#   __________> pre_ah_pattern = 1_075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+1+H
#   __________> pre_gou_pattern = 25g275g3g325gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________90. 2023-05-27 // 83 // 8 // 2022 // 904392 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 904392
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________91. 2023-05-27 // 83 // 8 // 2022 // 904391 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 904391
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________92. 2023-05-27 // 83 // 8 // 2022 // 904388 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 904388
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________93. 2023-05-27 // 83 // 8 // 2022 // 904387 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 904387
#   __________> pre_ah_pattern = 075+1+125+15+H
#   __________> pre_ah_pattern_mirror = 15_125_1_075_H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________94. 2023-05-27 // 83 // 8 // 2022 // 904385 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 904385
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________95. 2023-05-27 // 83 // 8 // 2022 // 904200 // H // G // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 904200
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________96. 2023-05-27 // 84 // 8 // 2022 // 909436 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 909436
#   __________> pre_ah_pattern = 1_075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+1+H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________97. 2023-05-27 // 84 // 8 // 2022 // 909434 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 909434
#   __________> pre_ah_pattern = 05_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+05+H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________98. 2023-05-27 // 84 // 8 // 2022 // 909433 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 909433
#   __________> pre_ah_pattern = 225_2_175_15_125_H
#   __________> pre_ah_pattern_mirror = 125+15+175+2+225+H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________99. 2023-05-27 // 84 // 8 // 2022 // 909432 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 909432
#   __________> pre_ah_pattern = 025_0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#025+H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________100. 2023-05-27 // 84 // 8 // 2022 // 909431 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 909431
#   __________> pre_ah_pattern = 05+075+1+125+H
#   __________> pre_ah_pattern_mirror = 125_1_075_05_H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________101. 2023-05-27 // 84 // 8 // 2022 // 909430 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 909430
#   __________> pre_ah_pattern = 15_125_1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+125+15+H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________102. 2023-05-27 // 84 // 8 // 2022 // 909429 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 909429
#   __________> pre_ah_pattern = 025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________103. 2023-05-27 // 84 // 8 // 2022 // 909428 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 909428
#   __________> pre_ah_pattern = 05_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+05+H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________104. 2023-05-27 // 86 // 8 // 2022 // 905004 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 905004
#   __________> pre_ah_pattern = 075_05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+075+H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________105. 2023-05-27 // 86 // 8 // 2022 // 905003 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 905003
#   __________> pre_ah_pattern = 075_05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+075+H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________106. 2023-05-27 // 86 // 8 // 2022 // 905002 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 905002
#   __________> pre_ah_pattern = 025_0#025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_0#025+H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________107. 2023-05-27 // 86 // 8 // 2022 // 905001 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 905001
#   __________> pre_ah_pattern = 125_1_075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+1+125+H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________108. 2023-05-27 // 86 // 8 // 2022 // 905000 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 905000
#   __________> pre_ah_pattern = 05_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+05+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________109. 2023-05-27 // 86 // 8 // 2022 // 904999 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 904999
#   __________> pre_ah_pattern = 025+05+075+1+125+H
#   __________> pre_ah_pattern_mirror = 125_1_075_05_025_H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________110. 2023-05-27 // 86 // 8 // 2022 // 904998 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 904998
#   __________> pre_ah_pattern = 075_05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+075+H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________111. 2023-05-27 // 86 // 8 // 2022 // 904996 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 904996
#   __________> pre_ah_pattern = 05_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+05+H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________112. 2023-05-27 // 122 // 8 // 2022 // 1022444 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1022444
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________113. 2023-05-27 // 122 // 8 // 2022 // 1022443 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1022443
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________114. 2023-05-27 // 122 // 8 // 2022 // 1022416 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1022416
#   __________> pre_ah_pattern = 05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________115. 2023-05-27 // 484 // 8 // 2022 // 885542 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 885542
#   __________> pre_ah_pattern = 15+2+H
#   __________> pre_ah_pattern_mirror = 2_15_H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________116. 2023-05-27 // 593 // 8 // 2023 // 993205 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 993205
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________117. 2023-05-27 // 594 // 8 // 2023 // 993566 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 993566
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________118. 2023-05-27 // 750 // 11 // 2022 // 907571 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 907571
#   __________> pre_ah_pattern = 025+075+1+H
#   __________> pre_ah_pattern_mirror = 1_075_025_H
#   __________> pre_gou_pattern = 325g35g375g4g425gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________119. 2023-05-27 // 754 // 11 // 2022 // 905620 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 905620
#   __________> pre_ah_pattern = 175_15_125_1_075_H
#   __________> pre_ah_pattern_mirror = 075+1+125+15+175+H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________120. 2023-05-27 // 211 // 11 // 2022 // 1017529 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1017529
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________121. 2023-05-27 // 494 // 11 // 2022 // 966863 // None // None // Match Postponed
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 966863
#   __________> pre_ah_pattern = 075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+H
#   __________> pre_gou_pattern = 15g175g2g225gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________122. 2023-05-27 // 107 // 8 // 2022 // 867161 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 867161
#   __________> pre_ah_pattern = 025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________123. 2023-05-27 // 113 // 8 // 2023 // 1001879 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1001879
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________124. 2023-05-27 // 114 // 8 // 2023 // 1002356 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1002356
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________125. 2023-05-27 // 114 // 8 // 2023 // 1002355 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1002355
#   __________> pre_ah_pattern = 025_0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#025+H
# ...
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________613. 2023-05-28 // 71 // 8 // 2023 // 1005723 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005723
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________614. 2023-05-28 // 266 // 11 // 2023 // 987844 // None // None // Time to be defined
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 987844
#   __________> pre_ah_pattern = 1_075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+1+H
#   __________> pre_gou_pattern = 225g25g275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________615. 2023-05-28 // 344 // 8 // 2023 // 1001044 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1001044
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________616. 2023-05-28 // 71 // 8 // 2023 // 1005720 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005720
#   __________> pre_ah_pattern = 1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________617. 2023-05-28 // 75 // 11 // 2023 // 1012435 // None // None // None
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1012435
#   __________> pre_ah_pattern = 075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+H
#   __________> pre_gou_pattern = 175g2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________618. 2023-05-28 // 128 // 8 // 2023 // 971562 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 971562
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 175g2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________619. 2023-05-28 // 255 // 11 // 2023 // 1008471 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1008471
#   __________> pre_ah_pattern = 0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________620. 2023-05-28 // 129 // 8 // 2023 // 992741 // 075_05_025_H // 175g2g225gG // Match Postponed
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992741
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 175g2g225gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________621. 2023-05-28 // 250 // 8 // 2023 // 986973 // None // None // Time to be defined
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 986973
#   __________> pre_ah_pattern = 025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________622. 2023-05-28 // 242 // 8 // 2023 // 996307 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 996307
#   __________> pre_ah_pattern = 075_05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+075+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________623. 2023-05-28 // 281 // 8 // 2023 // 985223 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 985223
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________624. 2023-05-28 // 281 // 8 // 2023 // 985218 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 985218
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________625. 2023-05-28 // 344 // 8 // 2023 // 1001045 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1001045
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________626. 2023-05-29 // 266 // 11 // 2023 // 987850 // None // None // Time to be defined
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 987850
#   __________> pre_ah_pattern = 1_075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+1+H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________627. 2023-05-29 // 281 // 8 // 2023 // 985225 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 985225
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________628. 2023-05-29 // 344 // 8 // 2023 // 1001041 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1001041
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________629. 2023-05-29 // 266 // 11 // 2023 // 987846 // None // None // Time to be defined
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 987846
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________630. 2023-05-29 // 250 // 8 // 2023 // 986976 // None // None // Time to be defined
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 986976
#   __________> pre_ah_pattern = 0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________631. 2023-05-29 // 129 // 8 // 2023 // 992746 // 05_025_0#H // 2g225g25gG // Match Postponed
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992746
#   __________> pre_ah_pattern = 05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________632. 2023-05-30 // 242 // 8 // 2023 // 996308 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 996308
#   __________> pre_ah_pattern = 15_125_1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+125+15+H
#   __________> pre_gou_pattern = 25g275g3g325gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________633. 2023-05-30 // 250 // 8 // 2023 // 986977 // None // None // Time to be defined
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 986977
#   __________> pre_ah_pattern = 1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________634. 2023-05-30 // 203 // 8 // 2022 // 884663 // None // None // Match Postponed
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 884663
#   __________> pre_ah_pattern = 075_05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+075+H
#   __________> pre_gou_pattern = 3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________635. 2023-05-30 // 203 // 8 // 2022 // 884662 // None // None // Match Postponed
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 884662
#   __________> pre_ah_pattern = 075_05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+075+H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________636. 2023-05-30 // 203 // 8 // 2022 // 884661 // None // None // Match Postponed
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 884661
#   __________> pre_ah_pattern = 05_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+05+H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________637. 2023-05-30 // 203 // 8 // 2022 // 884660 // None // None // Match Postponed
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 884660
#   __________> pre_ah_pattern = 0#025+05+075+H
#   __________> pre_ah_pattern_mirror = 075_05_025_0#H
#   __________> pre_gou_pattern = 3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________638. 2023-05-30 // 203 // 8 // 2022 // 884658 // None // None // Match Postponed
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 884658
#   __________> pre_ah_pattern = 025_0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#025+H
#   __________> pre_gou_pattern = 25g275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________639. 2023-05-30 // 203 // 8 // 2022 // 884657 // None // None // Match Postponed
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 884657
#   __________> pre_ah_pattern = 05+075+1+125+15+H
#   __________> pre_ah_pattern_mirror = 15_125_1_075_05_H
#   __________> pre_gou_pattern = 275g3g325g35g375gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________640. 2023-05-30 // 203 // 8 // 2022 // 884655 // None // None // Match Postponed
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 884655
#   __________> pre_ah_pattern = 175_15_125_1_H
#   __________> pre_ah_pattern_mirror = 1+125+15+175+H
#   __________> pre_gou_pattern = 275g3g325g35gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________641. 2023-05-30 // 250 // 8 // 2023 // 986974 // None // None // Time to be defined
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 986974
#   __________> pre_ah_pattern = 0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________642. 2023-05-31 // 129 // 8 // 2023 // 992601 // 05_025_H // 175g2g225gG // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 992601
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 15g175g2g225gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________643. 2023-06-01 // 255 // 11 // 2023 // 1008472 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1008472
#   __________> pre_ah_pattern = 075_025_H
#   __________> pre_ah_pattern_mirror = 025+075+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________644. 2023-06-03 // 71 // 8 // 2023 // 1005737 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005737
#   __________> pre_ah_pattern = 1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________645. 2023-06-03 // 71 // 8 // 2023 // 1005738 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005738
#   __________> pre_ah_pattern = 05_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+05+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________646. 2023-06-03 // 71 // 8 // 2023 // 1005736 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005736
#   __________> pre_ah_pattern = 05_025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+05+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________647. 2023-06-03 // 71 // 8 // 2023 // 1005734 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005734
#   __________> pre_ah_pattern = 0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________648. 2023-06-04 // 71 // 8 // 2023 // 1005732 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005732
#   __________> pre_ah_pattern = 05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________649. 2023-06-04 // 71 // 8 // 2023 // 1005735 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005735
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________650. 2023-06-04 // 71 // 8 // 2023 // 1005729 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005729
#   __________> pre_ah_pattern = 1_075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+1+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________651. 2023-06-04 // 71 // 8 // 2023 // 1005733 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005733
#   __________> pre_ah_pattern = 05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________652. 2023-06-04 // 71 // 8 // 2023 // 1005731 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005731
#   __________> pre_ah_pattern = 2_175_15_125_H
#   __________> pre_ah_pattern_mirror = 125+15+175+2+H
#   __________> pre_gou_pattern = 225g25g275g3gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
#   ________653. 2023-06-05 // 71 // 8 // 2023 // 1005730 // None // None // Not Started
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1005730
#   __________> pre_ah_pattern = 0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
# # -------------------------------------------------- End at 2023-05-27 11:53:20

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.football_odds import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------   
    # --------------------------------------------------  
    fO_get_group_league_status_match_finished_DETAILED('', '', "all_end_xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-27 11:23:33
#   __main()
#   ______fO_get_group_league_status_match_finished_DETAILED()
#   ______Select  DATE(date),  leagueapi_id,  (select bookmakersapi_id from football_leagues where football_leagues.leagueapi_id = football_odds.leagueapi_id),  season,   fixtureapi_id,   pre_ah_pattern,   pre_gou_pattern,   fixture_status   from football_odds  where  deleted_at is null  and end_response = 1  and fixture_status like 'Match Finished'  order by date, leagueapi_id, fixtureapi_id  desc
#   ________Total Row(s) : 1
#   ________1. 2023-05-21 // 221 // 11 // 2022 // 896743 // 075_025_0#H // 225g25g275g3gG // Match Finished
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 896743
#   __________> end_ah_pattern = 025_0#H
#   __________> end_ah_pattern_mirror = 0#025+H
#   __________> end_gou_pattern = 2g225g25g275gG
#   __________> football_odds update pattern commited
#   __________> no PL predates get advices
# # -------------------------------------------------- End at 2023-05-27 11:23:36
