# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

today = datetime.datetime.now()  
days0 = 7
days1 = 6
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 7 - 6 --> 2023-03-16 14:36:14.125274

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 09:40:56
#   __main()
#   ____get_date()
#   ______days : 7
#   ______days : 6
#   ______tgl_awal : 2023-03-09
#   ______tgl_akhir : 2023-03-10
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-10'  and date >= '2023-03-09'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 10
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 36
#   ______________1. 2023-03-09 // 16 // 8 // 2023 // 972944 // H // G
#   ______________2. 2023-03-09 // 16 // 8 // 2023 // 972947 // 0#025+05+H // 225g25g275g3gG
#   ______________3. 2023-03-09 // 20 // 8 // 2022 // 978761 // None // None
#   ______________4. 2023-03-09 // 73 // 8 // 2023 // 1011454 // None // None
#   ______________5. 2023-03-09 // 73 // 8 // 2023 // 1011457 // None // None
#   ______________6. 2023-03-09 // 73 // 8 // 2023 // 1011458 // None // None
#   ______________7. 2023-03-09 // 168 // 8 // 2023 // 976082 // H // G
#   ______________8. 2023-03-09 // 204 // 8 // 2022 // 884988 // 0#025+05+H // 225g25g275gG
#   ______________9. 2023-03-09 // 204 // 8 // 2022 // 884993 // 025+05+075+H // 225g25g275g3gG
#   ______________10. 2023-03-09 // 240 // 8 // 2023 // 989575 // 05_025_H // 25gG
#   ______________11. 2023-03-09 // 240 // 8 // 2023 // 989574 // H // G
#   ______________12. 2023-03-09 // 240 // 8 // 2023 // 989569 // 05_H // G
#   ______________13. 2023-03-09 // 240 // 8 // 2023 // 989568 // 0#H // 25gG
#   ______________14. 2023-03-09 // 263 // 8 // 2022 // 975947 // 0#025+H // 25gG
#   ______________15. 2023-03-09 // 263 // 8 // 2022 // 975948 // 025_H // 25gG
#   ______________16. 2023-03-09 // 274 // 11 // 2022 // 899780 // 025_0#025+H // 2g225g25g275gG
#   ______________17. 2023-03-09 // 274 // 11 // 2022 // 899782 // 025_0#025+H // 225g25g275g3gG
#   ______________18. 2023-03-09 // 328 // 11 // 2023 // 1001392 // None // None
#   ______________19. 2023-03-09 // 328 // 11 // 2023 // 1001393 // None // None
#   ______________20. 2023-03-09 // 328 // 11 // 2023 // 1001394 // None // None
#   ______________21. 2023-03-09 // 330 // 8 // 2022 // 991145 // None // None
#   ______________22. 2023-03-09 // 330 // 8 // 2022 // 991142 // None // None
#   ______________23. 2023-03-09 // 368 // 11 // 2023 // 997870 // None // None
#   ______________24. 2023-03-09 // 368 // 11 // 2023 // 997871 // None // None
#   ______________25. 2023-03-09 // 382 // 8 // 2022 // 877731 // H // 25gG
#   ______________26. 2023-03-09 // 417 // 8 // 2022 // 997657 // H // G
#   ______________27. 2023-03-09 // 667 // 8 // 2023 // 1014171 // None // None
#   ______________28. 2023-03-09 // 667 // 8 // 2023 // 1014172 // None // None
#   ______________29. 2023-03-09 // 667 // 8 // 2023 // 1014173 // None // None
#   ______________30. 2023-03-10 // 667 // 8 // 2023 // 1014174 // None // None
#   ______________31. 2023-03-09 // 701 // 11 // 2022 // 992384 // 075_025_0#025+H // 225g25g275g3g325gG
#   ______________32. 2023-03-09 // 701 // 11 // 2022 // 992385 // 025_0#025+H // 25g275g3g325g35gG
#   ______________33. 2023-03-09 // 740 // 11 // 2023 // 1010631 // None // None
#   ______________34. 2023-03-09 // 740 // 11 // 2023 // 1010632 // None // None
#   ______________35. 2023-03-09 // 887 // 11 // 2022 // 964781 // H // G
#   ______________36. 2023-03-09 // 887 // 11 // 2022 // 964783 // H // G
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-03-09 // 16 // 8 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 99
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-09
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 16
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. World,  CONCACAF Champions League  #16 - 2023 / 972944
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.40',
#   ____________________________end_match_winner_draw = '4.75',
#   ____________________________end_match_winner_away = '8.00',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '1.13',
#   ____________________________end_homeaway_away = '6.00',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '1.67',
#   ____________________________end_second_half_winner_draw = '2.88',
#   ____________________________end_second_half_winner_away = '6.00',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.14',
#   ____________________________end_asian_handicap_away_plus_0 = '5.75',
#   ____________________________end_asian_handicap_home_min_025 = '1.27',
#   ____________________________end_asian_handicap_away_min_025 = '3.55',
#   ____________________________end_asian_handicap_home_plus_025 = '1.12',
#   ____________________________end_asian_handicap_away_plus_025 = '6.25',
#   ____________________________end_asian_handicap_home_min_05 = '1.40',
#   ____________________________end_asian_handicap_away_min_05 = '2.85',
#   ____________________________end_asian_handicap_home_plus_05 = '1.10',
#   ____________________________end_asian_handicap_away_plus_05 = '6.80',
#   ____________________________end_asian_handicap_home_min_075 = '1.48',
#   ____________________________end_asian_handicap_away_min_075 = '2.60',
#   ____________________________end_asian_handicap_home_min_1 = '1.63',
#   ____________________________end_asian_handicap_away_min_1 = '2.25',
#   ____________________________end_asian_handicap_home_min_15 = '2.08',
#   ____________________________end_asian_handicap_away_min_15 = '1.73',
#   ____________________________end_asian_handicap_home_min_125 = '1.88',
#   ____________________________end_asian_handicap_away_min_125 = '1.98',
#   ____________________________end_asian_handicap_home_min_175 = '2.38',
#   ____________________________end_asian_handicap_away_min_175 = '1.55',
#   ____________________________end_asian_handicap_home_min_2 = '3.00',
#   ____________________________end_asian_handicap_away_min_2 = '1.38',
#   ____________________________end_asian_handicap_home_min_3 = '6.40',
#   ____________________________end_asian_handicap_away_min_3 = '1.11',
#   ____________________________end_asian_handicap_home_min_25 = '3.55',
#   ____________________________end_asian_handicap_away_min_25 = '1.27',
#   ____________________________end_asian_handicap_home_min_225 = '3.30',
#   ____________________________end_asian_handicap_away_min_225 = '1.32',
#   ____________________________end_asian_handicap_home_min_275 = '4.50',
#   ____________________________end_asian_handicap_away_min_275 = '1.19',
#   ____________________________end_asian_handicap_home_min_325 = '6.80',
#   ____________________________end_asian_handicap_away_min_325 = '1.10',
#   ____________________________end_asian_handicap_home_min_35 = '6.60',
#   ____________________________end_asian_handicap_away_min_35 = '1.11',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '2.50',
#   ____________________________end_goals_overunder_under_35 = '1.50',
#   ____________________________end_goals_overunder_over_15 = '1.18',
#   ____________________________end_goals_overunder_under_15 = '4.50',
#   ____________________________end_goals_overunder_over_45 = '4.50',
#   ____________________________end_goals_overunder_under_45 = '1.18',
#   ____________________________end_goals_overunder_over_25 = '1.62',
#   ____________________________end_goals_overunder_under_25 = '2.25',
#   ____________________________end_goals_overunder_over_05 = '1.03',
#   ____________________________end_goals_overunder_under_05 = '15.00',
#   ____________________________end_goals_overunder_over_55 = '10.00',
#   ____________________________end_goals_overunder_under_55 = '1.06',
#   ____________________________end_goals_overunder_over_225 = '1.45',
#   ____________________________end_goals_overunder_under_225 = '2.67',
#   ____________________________end_goals_overunder_over_325 = '2.30',
#   ____________________________end_goals_overunder_under_325 = '1.60',
#   ____________________________end_goals_overunder_over_275 = '1.77',
#   ____________________________end_goals_overunder_under_275 = '2.02',
#   ____________________________end_goals_overunder_over_125 = '1.11',
#   ____________________________end_goals_overunder_under_125 = '6.40',
#   ____________________________end_goals_overunder_over_425 = '4.15',
#   ____________________________end_goals_overunder_under_425 = '1.22',
#   ____________________________end_goals_overunder_over_175 = '1.23',
#   ____________________________end_goals_overunder_under_175 = '4.10',
#   ____________________________end_goals_overunder_over_375 = '3.00',
#   ____________________________end_goals_overunder_under_375 = '1.38',
#   ____________________________end_goals_overunder_over_475 = '5.75',
#   ____________________________end_goals_overunder_under_475 = '1.14',
#   ____________________________end_goals_overunder_over_65 = '19.00',
#   ____________________________end_goals_overunder_under_65 = '1.02',
#   ____________________________end_goals_overunder_over_75 = '41.00',
#   ____________________________end_goals_overunder_under_75 = '1.00',
#   ____________________________end_goals_overunder_over_525 = '7.00',
#   ____________________________end_goals_overunder_under_525 = '1.10',
#   ____________________________end_goals_overunder_over_30 = '2.05',
#   ____________________________end_goals_overunder_under_30 = '1.80',
#   ____________________________end_goals_overunder_over_20 = '1.27',
#   ____________________________end_goals_overunder_under_20 = '3.55',
#   ____________________________end_goals_overunder_over_40 = '3.80',
#   ____________________________end_goals_overunder_under_40 = '1.25',
#   ____________________________end_goals_overunder_over_50 = '6.60',
#   ____________________________end_goals_overunder_under_50 = '1.11',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '17.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.02',
#   ____________________________end_goals_overunder_first_half_over_15 = '2.38',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.53',
#   ____________________________end_goals_overunder_first_half_over_25 = '6.00',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.13',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.30',
#   ____________________________end_goals_overunder_first_half_under_05 = '3.40',
#   ____________________________end_goals_overunder_first_half_over_225 = '5.25',
#   ____________________________end_goals_overunder_first_half_under_225 = '1.16',
#   ____________________________end_goals_overunder_first_half_over_275 = '6.80',
#   ____________________________end_goals_overunder_first_half_under_275 = '1.10',
#   ____________________________end_goals_overunder_first_half_over_125 = '2.02',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.77',
#   ____________________________end_goals_overunder_first_half_over_175 = '3.00',
#   ____________________________end_goals_overunder_first_half_under_175 = '1.38',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.40',
#   ____________________________end_goals_overunder_first_half_under_075 = '2.85',
#   ____________________________end_goals_overunder_first_half_over_20 = '4.40',
#   ____________________________end_goals_overunder_first_half_under_20 = '1.20',
#   ____________________________end_goals_overunder_first_half_over_10 = '1.60',
#   ____________________________end_goals_overunder_first_half_under_10 = '2.30',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '9.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.07',
#   ____________________________end_goals_overunder__second_half_over_15 = '1.83',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.83',
#   ____________________________end_goals_overunder__second_half_over_25 = '3.75',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.25',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.18',
#   ____________________________end_goals_overunder__second_half_under_05 = '4.50',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________end_clean_sheet__home_yes = '2.10',
#   ____________________________end_clean_sheet__home_no = '1.67',
#   __________________________28 Clean Sheet - Away
#   ____________________________end_clean_sheet__away_yes = '8.00',
#   ____________________________end_clean_sheet__away_no = '1.08',
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '1.83',
#   ____________________________end_both_teams_score_no = '1.83',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 2.05
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.08
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 3.60
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 9.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.40
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 301.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 6:0 --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.40
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 251.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.08',
#   ____________________________end_double_chance_home_away = '1.18',
#   ____________________________end_double_chance_draw_away = '2.75',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '1.91',
#   ____________________________end_first_half_winner_draw = '2.50',
#   ____________________________end_first_half_winner_away = '6.50',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 3.75
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 3.75
#   __________________________32 Win Both Halves
#   ____________________________end_win_both_halves_home = '3.40',
#   ____________________________end_win_both_halves_away = '29.00',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.17
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.44
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 2.63
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.05
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 5.5 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 5.5 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 6.5 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 6.5 --- bets_odd: 1.00
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.20
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.03
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 2.88
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.17
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.04
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________end_win_to_nil_home = '2.38',
#   ____________________________end_win_to_nil_away = '13.00',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.80
#   __________________________39 To Win Either Half
#   ____________________________end_to_win_either_half_home = '1.22',
#   ____________________________end_to_win_either_half_away = '3.50',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________24 Results/Both Teams Score
#   ____________________________end_results_both_teams_score_home_yes = '3.10',
#   ____________________________end_results_both_teams_score_draw_yes = '6.00',
#   ____________________________end_results_both_teams_score_away_yes = '13.00',
#   ____________________________end_results_both_teams_score_home_no = '2.38',
#   ____________________________end_results_both_teams_score_draw_no = '13.00',
#   ____________________________end_results_both_teams_score_away_no = '13.00',
#   __________________________25 Result/Total Goals
#   ____________________________end_result_total_goals_home_over_35 = '2.75',
#   ____________________________end_result_total_goals_draw_over_35 = '15.00',
#   ____________________________end_result_total_goals_away_over_35 = '29.00',
#   ____________________________end_result_total_goals_home_under_35 = '2.30',
#   ____________________________end_result_total_goals_draw_under_35 = '6.50',
#   ____________________________end_result_total_goals_away_under_35 = '11.00',
#   ____________________________end_result_total_goals_home_over_25 = '2.05',
#   ____________________________end_result_total_goals_draw_over_25 = '15.00',
#   ____________________________end_result_total_goals_away_over_25 = '12.00',
#   ____________________________end_result_total_goals_home_under_25 = '4.00',
#   ____________________________end_result_total_goals_draw_under_25 = '6.00',
#   ____________________________end_result_total_goals_away_under_25 = '15.00',
#   __________________________43 Home Team Score a Goal
#   ______________________  ______________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.08
#   ______________________  ______________________bet_id: 43 --- bets_value: No --- bets_odd: 8.00
#   __________________________44 Away Team Score a Goal
#   ______________________  ______________________bet_id: 44 --- bets_value: Yes --- bets_odd: 1.67
#   ______________________  ______________________bet_id: 44 --- bets_value: No --- bets_odd: 2.10
#   __________________________54 First 10 min Winner
#   ______________________  ______________________bet_id: 54 --- bets_value: Home --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 54 --- bets_value: Draw --- bets_odd: 1.20
#   ______________________  ______________________bet_id: 54 --- bets_value: Away --- bets_odd: 12.00
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 10.5 --- bets_odd: 1.83
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 10.5 --- bets_odd: 1.83
#   __________________________47 Winning Margin
#   ______________________  ______________________bet_id: 47 --- bets_value: Draw --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 251.00
#   ______________________  ______________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 6.00
#   __________________________48 To Score In Both Halves By Teams
#   __________________________49 Total Goals/Both Teams To Score
#   ____________________________end_total_goals_both_teams_to_score_over_yes_25 = '2.25',
#   ____________________________end_total_goals_both_teams_to_score_over_no_25 = '5.00',
#   ____________________________end_total_goals_both_teams_to_score_under_yes_25 = '9.00',
#   ____________________________end_total_goals_both_teams_to_score_under_no_25 = '2.75',
#   __________________________91 Total Goals (3 way)
#   ______________________  ______________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 2.05
#   ______________________  ______________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 2.50
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.19
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.5 --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.5 --- bets_odd: 1.19
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 1.63
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 2.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.27
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 3.55
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 2.05
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 3.80
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.45
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 2.67
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 2.30
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.60
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 1.77
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 2.02
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 6.40
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.25 --- bets_odd: 4.15
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.25 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.23
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 4.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.38
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.75 --- bets_odd: 5.75
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.75 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 5 --- bets_odd: 6.60
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 5 --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 5.25 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 5.25 --- bets_odd: 1.10
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.55
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2.5 --- bets_odd: 5.75
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2.5 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.5 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.5 --- bets_odd: 3.45
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 4.40
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.20
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 5.25
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.16
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2.75 --- bets_odd: 6.80
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2.75 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.02
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.77
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.38
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.60
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 2.30
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.85
#   __________________________52 Halftime Result/Both Teams Score
#   __________________________85 Total Corners (3 way)
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 10 --- bets_odd: 1.83
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 10 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 10 --- bets_odd: 8.00
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   __________________________74 10 Over/Under
#   __________________________78 RTG_H1
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 3.40
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 3.40
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 8.50
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ______________________2. World,  CONCACAF Champions League  #16 - 2023 / 972947
#   ______________________good to Go 1
#   ____________________________1 Match Winner
#   ______________________________end_match_winner_home = '2.75',
#   ______________________________end_match_winner_draw = '3.10',
#   ______________________________end_match_winner_away = '2.75',
#   ____________________________2 Home/Away
#   ______________________________end_homeaway_home = '1.83',
#   ______________________________end_homeaway_away = '1.83',
#   ____________________________3 Second Half Winner
#   ______________________________end_second_half_winner_home = '2.88',
#   ______________________________end_second_half_winner_draw = '2.38',
#   ______________________________end_second_half_winner_away = '2.88',
#   ____________________________4 Asian Handicap
#   ______________________________end_asian_handicap_home_plus_0 = '1.93',
#   ______________________________end_asian_handicap_away_plus_0 = '1.93',
#   ______________________________end_asian_handicap_home_min_025 = '2.30',
#   ______________________________end_asian_handicap_away_min_025 = '1.60',
#   ______________________________end_asian_handicap_home_plus_025 = '1.60',
#   ______________________________end_asian_handicap_away_plus_025 = '2.30',
#   ______________________________end_asian_handicap_home_min_05 = '2.67',
#   ______________________________end_asian_handicap_away_min_05 = '1.45',
#   ______________________________end_asian_handicap_home_plus_05 = '1.45',
#   ______________________________end_asian_handicap_away_plus_05 = '2.67',
#   ______________________________end_asian_handicap_home_min_075 = '3.30',
#   ______________________________end_asian_handicap_away_min_075 = '1.32',
#   ______________________________end_asian_handicap_home_plus_075 = '1.32',
#   ______________________________end_asian_handicap_away_plus_075 = '3.30',
#   ______________________________end_asian_handicap_home_min_1 = '4.50',
#   ______________________________end_asian_handicap_away_min_1 = '1.19',
#   ______________________________end_asian_handicap_home_plus_1 = '1.19',
#   ______________________________end_asian_handicap_away_plus_1 = '4.50',
#   ______________________________end_asian_handicap_home_min_15 = '5.75',
#   ______________________________end_asian_handicap_away_min_15 = '1.14',
#   ______________________________end_asian_handicap_home_plus_15 = '1.14',
#   ______________________________end_asian_handicap_away_plus_15 = '5.75',
#   ______________________________end_asian_handicap_home_min_125 = '5.25',
#   ______________________________end_asian_handicap_away_min_125 = '1.16',
#   ______________________________end_asian_handicap_home_plus_125 = '1.16',
#   ______________________________end_asian_handicap_away_plus_125 = '5.25',
#   ______________________________end_asian_handicap_home_plus_175 = '1.11',
#   ______________________________end_asian_handicap_away_plus_175 = '6.40',
#   ____________________________5 Goals Over/Under
#   ______________________________end_goals_overunder_over_35 = '3.75',
#   ______________________________end_goals_overunder_under_35 = '1.25',
#   ______________________________end_goals_overunder_over_15 = '1.36',
#   ______________________________end_goals_overunder_under_15 = '3.00',
#   ______________________________end_goals_overunder_over_45 = '9.00',
#   ______________________________end_goals_overunder_under_45 = '1.07',
#   ______________________________end_goals_overunder_over_25 = '2.15',
#   ______________________________end_goals_overunder_under_25 = '1.67',
#   ______________________________end_goals_overunder_over_05 = '1.08',
#   ______________________________end_goals_overunder_under_05 = '8.00',
#   ______________________________end_goals_overunder_over_55 = '19.00',
#   ______________________________end_goals_overunder_under_55 = '1.02',
#   ______________________________end_goals_overunder_over_225 = '1.93',
#   ______________________________end_goals_overunder_under_225 = '1.93',
#   ______________________________end_goals_overunder_over_325 = '3.45',
#   ______________________________end_goals_overunder_under_325 = '1.30',
#   ______________________________end_goals_overunder_over_275 = '2.50',
#   ______________________________end_goals_overunder_under_275 = '1.50',
#   ______________________________end_goals_overunder_over_125 = '1.23',
#   ______________________________end_goals_overunder_under_125 = '4.00',
#   ______________________________end_goals_overunder_over_425 = '6.40',
#   ______________________________end_goals_overunder_under_425 = '1.11',
#   ______________________________end_goals_overunder_over_175 = '1.45',
#   ______________________________end_goals_overunder_under_175 = '2.67',
#   ______________________________end_goals_overunder_over_375 = '4.80',
#   ______________________________end_goals_overunder_under_375 = '1.18',
#   ______________________________end_goals_overunder_over_65 = '41.00',
#   ______________________________end_goals_overunder_under_65 = '1.00',
#   ______________________________end_goals_overunder_over_75 = '51.00',
#   ______________________________end_goals_overunder_under_75 = '1.00',
#   ______________________________end_goals_overunder_over_30 = '3.10',
#   ______________________________end_goals_overunder_under_30 = '1.35',
#   ______________________________end_goals_overunder_over_20 = '1.60',
#   ______________________________end_goals_overunder_under_20 = '2.30',
#   ______________________________end_goals_overunder_over_40 = '6.80',
#   ______________________________end_goals_overunder_under_40 = '1.10',
#   ______________________________end_goals_overunder_over_10 = '1.10',
#   ______________________________end_goals_overunder_under_10 = '6.80',
#   ____________________________6 Goals Over/Under First Half
#   ______________________________end_goals_overunder_first_half_over_35 = '26.00',
#   ______________________________end_goals_overunder_first_half_under_35 = '1.01',
#   ______________________________end_goals_overunder_first_half_over_15 = '3.25',
#   ______________________________end_goals_overunder_first_half_under_15 = '1.33',
#   ______________________________end_goals_overunder_first_half_over_25 = '10.00',
#   ______________________________end_goals_overunder_first_half_under_25 = '1.06',
#   ______________________________end_goals_overunder_first_half_over_05 = '1.44',
#   ______________________________end_goals_overunder_first_half_under_05 = '2.63',
#   ______________________________end_goals_overunder_first_half_over_225 = '6.60',
#   ______________________________end_goals_overunder_first_half_under_225 = '1.11',
#   ______________________________end_goals_overunder_first_half_over_125 = '2.67',
#   ______________________________end_goals_overunder_first_half_under_125 = '1.45',
#   ______________________________end_goals_overunder_first_half_over_175 = '4.25',
#   ______________________________end_goals_overunder_first_half_under_175 = '1.21',
#   ______________________________end_goals_overunder_first_half_over_075 = '1.68',
#   ______________________________end_goals_overunder_first_half_under_075 = '2.15',
#   ______________________________end_goals_overunder_first_half_over_20 = '6.40',
#   ______________________________end_goals_overunder_first_half_under_20 = '1.11',
#   ______________________________end_goals_overunder_first_half_over_10 = '2.10',
#   ______________________________end_goals_overunder_first_half_under_10 = '1.70',
#   ____________________________26 Goals Over/Under - Second Half
#   ______________________________end_goals_overunder__second_half_over_35 = '15.00',
#   ______________________________end_goals_overunder__second_half_under_35 = '1.03',
#   ______________________________end_goals_overunder__second_half_over_15 = '2.25',
#   ______________________________end_goals_overunder__second_half_under_15 = '1.57',
#   ______________________________end_goals_overunder__second_half_over_25 = '5.50',
#   ______________________________end_goals_overunder__second_half_under_25 = '1.14',
#   ______________________________end_goals_overunder__second_half_over_05 = '1.29',
#   ______________________________end_goals_overunder__second_half_under_05 = '3.50',
#   ____________________________7 HT/FT Double
#   ____________________________27 Clean Sheet - Home
#   ______________________________end_clean_sheet__home_yes = '3.00',
#   ______________________________end_clean_sheet__home_no = '1.36',
#   ____________________________28 Clean Sheet - Away
#   ______________________________end_clean_sheet__away_yes = '3.00',
#   ______________________________end_clean_sheet__away_no = '1.36',
#   ____________________________8 Both Teams Score
#   ______________________________end_both_teams_score_yes = '1.83',
#   ______________________________end_both_teams_score_no = '1.83',
#   ____________________________9 Handicap Result
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.40
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.33
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.40
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 5.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.33
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.13
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 13.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 13.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.13
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.03
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 19.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 34.00
#   ____________________________10 Exact Score
#   ____________________________11 Highest Scoring Half
#   ____________________________31 Correct Score - First Half
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 26.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 201.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 201.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 351.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.63
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 201.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 26.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 351.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 201.00
#   ____________________________12 Double Chance
#   ______________________________end_double_chance_home_draw = '1.40',
#   ______________________________end_double_chance_home_away = '1.36',
#   ______________________________end_double_chance_draw_away = '1.40',
#   ____________________________13 First Half Winner
# ...
#   __________________________________end_asian_handicap_away_plus_15 = '4.54',
#   __________________________________end_asian_handicap_home_plus_125 = '1.18',
#   __________________________________end_asian_handicap_away_plus_125 = '4.16',
#   __________________________________end_asian_handicap_home_plus_2 = '1.02',
#   __________________________________end_asian_handicap_away_plus_2 = '9.00',
#   __________________________________end_asian_handicap_home_plus_25 = '1.01',
#   __________________________________end_asian_handicap_away_plus_25 = '9.70',
#   ________________________________5 Goals Over/Under
#   __________________________________end_goals_overunder_over_35 = '3.34',
#   __________________________________end_goals_overunder_under_35 = '1.26',
#   __________________________________end_goals_overunder_over_15 = '1.30',
#   __________________________________end_goals_overunder_under_15 = '3.08',
#   __________________________________end_goals_overunder_over_45 = '6.70',
#   __________________________________end_goals_overunder_under_45 = '1.07',
#   __________________________________end_goals_overunder_over_25 = '2.00',
#   __________________________________end_goals_overunder_under_25 = '1.79',
#   __________________________________end_goals_overunder_over_05 = '1.04',
#   __________________________________end_goals_overunder_under_05 = '8.50',
#   __________________________________end_goals_overunder_over_55 = '13.00',
#   __________________________________end_goals_overunder_under_55 = '1.02',
#   __________________________________end_goals_overunder_over_225 = '1.77',
#   __________________________________end_goals_overunder_under_225 = '2.03',
#   __________________________________end_goals_overunder_over_325 = '3.05',
#   __________________________________end_goals_overunder_under_325 = '1.32',
#   __________________________________end_goals_overunder_over_275 = '2.24',
#   __________________________________end_goals_overunder_under_275 = '1.56',
#   __________________________________end_goals_overunder_over_125 = '1.21',
#   __________________________________end_goals_overunder_under_125 = '3.86',
#   __________________________________end_goals_overunder_over_175 = '1.38',
#   __________________________________end_goals_overunder_under_175 = '2.77',
#   __________________________________end_goals_overunder_over_375 = '4.20',
#   __________________________________end_goals_overunder_under_375 = '1.18',
#   __________________________________end_goals_overunder_over_30 = '2.75',
#   __________________________________end_goals_overunder_under_30 = '1.38',
#   __________________________________end_goals_overunder_over_20 = '1.49',
#   __________________________________end_goals_overunder_under_20 = '2.40',
#   __________________________________end_goals_overunder_over_40 = '5.75',
#   __________________________________end_goals_overunder_under_40 = '1.09',
#   __________________________________end_goals_overunder_over_10 = '1.05',
#   __________________________________end_goals_overunder_under_10 = '7.30',
#   ________________________________6 Goals Over/Under First Half
#   __________________________________end_goals_overunder_first_half_over_35 = '21.00',
#   __________________________________end_goals_overunder_first_half_over_15 = '2.90',
#   __________________________________end_goals_overunder_first_half_under_15 = '1.36',
#   __________________________________end_goals_overunder_first_half_over_25 = '6.80',
#   __________________________________end_goals_overunder_first_half_under_25 = '1.07',
#   __________________________________end_goals_overunder_first_half_over_05 = '1.40',
#   __________________________________end_goals_overunder_first_half_under_05 = '2.73',
#   __________________________________end_goals_overunder_first_half_over_125 = '2.40',
#   __________________________________end_goals_overunder_first_half_under_125 = '1.51',
#   __________________________________end_goals_overunder_first_half_over_075 = '1.56',
#   __________________________________end_goals_overunder_first_half_under_075 = '2.28',
#   __________________________________end_goals_overunder_first_half_over_10 = '1.90',
#   __________________________________end_goals_overunder_first_half_under_10 = '1.81',
#   ________________________________26 Goals Over/Under - Second Half
#   __________________________________end_goals_overunder__second_half_over_15 = '2.18',
#   __________________________________end_goals_overunder__second_half_under_15 = '1.61',
#   __________________________________end_goals_overunder__second_half_over_25 = '4.70',
#   __________________________________end_goals_overunder__second_half_under_25 = '1.15',
#   __________________________________end_goals_overunder__second_half_over_05 = '1.26',
#   __________________________________end_goals_overunder__second_half_under_05 = '3.50',
#   __________________________________end_goals_overunder__second_half_over_125 = '1.84',
#   __________________________________end_goals_overunder__second_half_under_125 = '1.87',
#   __________________________________end_goals_overunder__second_half_over_175 = '2.66',
#   __________________________________end_goals_overunder__second_half_under_175 = '1.42',
#   __________________________________end_goals_overunder__second_half_over_075 = '1.39',
#   __________________________________end_goals_overunder__second_half_under_075 = '2.77',
#   __________________________________end_goals_overunder__second_half_over_20 = '3.74',
#   __________________________________end_goals_overunder__second_half_under_20 = '1.23',
#   __________________________________end_goals_overunder__second_half_over_10 = '1.48',
#   __________________________________end_goals_overunder__second_half_under_10 = '2.47',
#   ________________________________7 HT/FT Double
#   ________________________________8 Both Teams Score
#   __________________________________end_both_teams_score_yes = '1.75',
#   __________________________________end_both_teams_score_no = '2.03',
#   ________________________________9 Handicap Result
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.90
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.37
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.30
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.53
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 4.54
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.74
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.12
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 7.50
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 13.00
#   ________________________________10 Exact Score
#   ________________________________11 Highest Scoring Half
#   ________________________________31 Correct Score - First Half
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 17.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 81.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.73
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 67.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.50
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 13.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 26.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 67.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   ________________________________12 Double Chance
#   __________________________________end_double_chance_home_draw = '1.53',
#   __________________________________end_double_chance_home_away = '1.29',
#   __________________________________end_double_chance_draw_away = '1.37',
#   ________________________________13 First Half Winner
#   __________________________________end_first_half_winner_home = '3.60',
#   __________________________________end_first_half_winner_draw = '2.06',
#   __________________________________end_first_half_winner_away = '2.92',
#   ________________________________16 Total - Home
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.64
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.40
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.33
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 2.93
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 5.25
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.11
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.74
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 1.93
#   ________________________________17 Total - Away
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.28
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.53
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.26
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 3.34
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 4.14
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.18
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.53
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 2.28
#   ________________________________18 Handicap Result - First Half
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.30
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 8.80
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.94
#   ________________________________19 Asian Handicap First Half
#   ________________________________20 Double Chance - First Half
#   ________________________________33 Double Chance - Second Half
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.36
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.44
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.25
#   ________________________________34 Both Teams Score - First Half
#   ________________________________35 Both Teams To Score - Second Half
#   ________________________________21 Odd/Even
#   ________________________________22 Odd/Even - First Half
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.03
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.67
#   ________________________________23 Home Odd/Even
#   ____________________________  ____________________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.98
#   ____________________________  ____________________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.70
#   ________________________________60 Away Odd/Even
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.93
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.74
#   ____________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ______________________________ff_update_unfinished__
#   ____________________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-16 09:41:45

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 12:10:28
#   __main()
#   ____get_date()
#   ______days : 7
#   ______days : 6
#   ______tgl_awal : 2023-03-09
#   ______tgl_akhir : 2023-03-10
#   ________ff_get_fixture_status_match_finished()
#   __________Total Row(s) : 58
#   __________1. 2023-03-09 // 3 // 8 // 2022 // 1010834 // 175_15_125_1_075_H // 25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010834
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-03-09 // 3 // 8 // 2022 // 1010822 // 125_1_075_05_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010822
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-03-09 // 3 // 8 // 2022 // 1010824 // 175_15_125_H // 25g275g3g325gG
#   ____________xp_set_pattern()

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 14:36:19
#   __main()
#   ____get_date()
#   ______days : 7
#   ______days : 6
#   ______tgl_awal : 2023-03-09
#   ______tgl_akhir : 2023-03-10
#   ________ff_get_fixture_status_match_finished_for_daily_update_patternlist()
#   ________Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date <= '2023-03-10'  and date >= '2023-03-09'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 43
#   ____________[1/43] #899780 #Indonesia 274-2022 / PS TIRA vs PSM Makassar
#   ____________pre-ah:025_0#025+H -- pre-gou:2g225g25g275gG -/- end-ah:025_0#025+H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:32
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '274'  and league_country = 'Indonesia'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 11
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 11
#   ____________________patternlists updated
#
#   ____________[2/43] #899782 #Indonesia 274-2022 / Barito Putera vs Persebaya Surabaya
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275g3gG -/- end-ah:075_025_0#025+H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:34
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '274'  and league_country = 'Indonesia'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '075_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+075+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[3/43] #884988 #Turkey 204-2022 / Bandırmaspor vs Eyüpspor
#   ____________pre-ah:0#025+05+H -- pre-gou:225g25g275gG -/- end-ah:0#025+05+075+H -- end-gou:225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:12
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '204'  and league_country = 'Turkey'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '0#025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_0#H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[4/43] #884993 #Turkey 204-2022 / Sakaryaspor vs Samsunspor
#   ____________pre-ah:025+05+075+H -- pre-gou:225g25g275g3gG -/- end-ah:025+05+075+H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:15
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '204'  and league_country = 'Turkey'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[5/43] #877731 #Israel 382-2022 / Hapoel Umm al-Fahm vs Maccabi Petah Tikva
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:59
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '382'  and league_country = 'Israel'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = 'H'  and end_ah_pattern_mirror = 'H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[6/43] #934819 #Israel 496-2022 / Hapoel Bik'at HaYarden vs Beitar Tel Aviv Ramla
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_025_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 11:25:05
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '496'  and league_country = 'Israel'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[7/43] #934822 #Israel 496-2022 / Hapoel Kfar Shalem vs Holon Yermiyahu
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:15_125_1_075_H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 11:25:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '496'  and league_country = 'Israel'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[8/43] #934824 #Israel 496-2022 / Shimshon Tel Aviv vs Hapoel Herzliya
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025+075+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 11:25:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '496'  and league_country = 'Israel'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[9/43] #934825 #Israel 496-2022 / Maccabi Shaarayim vs Shimshon Kafr Qasim
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_0#H -- end-gou:2g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 11:25:10
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '496'  and league_country = 'Israel'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#H'  and end_ah_pattern_mirror = '0#025+H'  and end_gou_pattern = '2g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[10/43] #964780 #Egypt 887-2022 / El Madina El Monowara vs Shoban Moslemen Qena
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:0#025+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '887'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '0#025+H'  and end_ah_pattern_mirror = '025_0#H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[11/43] #964782 #Egypt 887-2022 / Kima Aswan vs La Viena FC
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:025+075+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:42
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '887'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[12/43] #964784 #Egypt 887-2022 / Misr EL Makasa vs Tamya
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:125_1_075_H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '887'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[13/43] #964785 #Egypt 887-2022 / Telephonaat Beni Suef vs El Gouna FC
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075+1+125+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:41
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '887'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[14/43] #991145 #Kuwait 330-2022 / Al Salmiyah vs Al Kuwait
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025+05+075+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:52
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '330'  and league_country = 'Kuwait'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[15/43] #991142 #Kuwait 330-2022 / Al Jahra vs Al Fahaheel
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_0#025+05+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:55
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '330'  and league_country = 'Kuwait'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[16/43] #989575 #Colombia 240-2023 / Depor FC vs Real Cartagena
#   ____________pre-ah:05_025_H -- pre-gou:25gG -/- end-ah:05_025_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:20
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '240'  and league_country = 'Colombia'  and pre_ah_pattern = '05_025_H'  and pre_ah_pattern_mirror = '025+05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_H'  and end_ah_pattern_mirror = '025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[17/43] #989574 #Colombia 240-2023 / Patriotas vs Popayan
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:25
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '240'  and league_country = 'Colombia'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_H'  and end_ah_pattern_mirror = '075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[18/43] #989569 #Colombia 240-2023 / Tigres FC vs Valledupar
#   ____________pre-ah:05_H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:G
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:28
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '240'  and league_country = 'Colombia'  and pre_ah_pattern = '05_H'  and pre_ah_pattern_mirror = '05+H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[19/43] #989568 #Colombia 240-2023 / Orsomarso vs Leones FC
#   ____________pre-ah:0#H -- pre-gou:25gG -/- end-ah:0#H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:22
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '240'  and league_country = 'Colombia'  and pre_ah_pattern = '0#H'  and pre_ah_pattern_mirror = '0#H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '0#H'  and end_ah_pattern_mirror = '0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 5
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 5
#   ____________________patternlists updated
#
#   ____________[20/43] #975947 #Mexico 263-2022 / Venados FC vs Atlante FC
#   ____________pre-ah:0#025+H -- pre-gou:25gG -/- end-ah:0#025+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-14 12:22:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = '0#025+H'  and pre_ah_pattern_mirror = '025_0#H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '0#025+H'  and end_ah_pattern_mirror = '025_0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[21/43] #975948 #Mexico 263-2022 / Raya2 vs Alebrijes de Oaxaca
#   ____________pre-ah:025_H -- pre-gou:25gG -/- end-ah:05_025_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-14 12:23:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = '025_H'  and pre_ah_pattern_mirror = '025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_H'  and end_ah_pattern_mirror = '025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 8
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 8
#   ____________________patternlists updated
#
#   ____________[22/43] #976686 #Saudi-Arabia 307-2022 / Al Baten vs Al Khaleej Saihat
#   ____________pre-ah:025+05+075+H -- pre-gou:25gG -/- end-ah:0#025+05+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 11:24:41
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '307'  and league_country = 'Saudi-Arabia'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[23/43] #976688 #Saudi-Arabia 307-2022 / Al-Ittihad FC vs Al-Nassr
#   ____________pre-ah:0#025+05+H -- pre-gou:25gG -/- end-ah:025_0#025+05+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 11:24:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '307'  and league_country = 'Saudi-Arabia'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[24/43] #976689 #Saudi-Arabia 307-2022 / Al-Ettifaq vs Al Wehda Club
#   ____________pre-ah:075_05_025_0#H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 11:24:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '307'  and league_country = 'Saudi-Arabia'  and pre_ah_pattern = '075_05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+075+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[25/43] #976690 #Saudi-Arabia 307-2022 / Al Shabab vs Al-Fayha
#   ____________pre-ah:125_1_075_05_H -- pre-gou:25gG -/- end-ah:175_15_125_1_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 11:24:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '307'  and league_country = 'Saudi-Arabia'  and pre_ah_pattern = '125_1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+125+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[26/43] #992384 #Portugal 701-2022 / Rio Ave U23 vs Leixões U23
#   ____________pre-ah:075_025_0#025+H -- pre-gou:225g25g275g3g325gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:30
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '701'  and league_country = 'Portugal'  and pre_ah_pattern = '075_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+075+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[27/43] #992385 #Portugal 701-2022 / Sporting CP U23 vs Portimonense U23
#   ____________pre-ah:025_0#025+H -- pre-gou:25g275g3g325g35gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:31
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '701'  and league_country = 'Portugal'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[28/43] #976082 #Iceland 168-2023 / HK Kopavogur vs Vestri
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:225_2_175_15_125_H -- end-gou:35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-13 11:24:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '168'  and league_country = 'Iceland'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '225_2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+225+H'  and end_gou_pattern = '35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[29/43] #965027 #Egypt 888-2022 / Wadi Degla vs Petrojet
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_0#025+H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-13 11:25:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '888'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[30/43] #972944 #World 16-2023 / Vancouver Whitecaps vs Real Espana
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:175_15_125_1_H -- end-gou:25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:07
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '16'  and league_country = 'World'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[31/43] #972947 #World 16-2023 / CD Olimpia vs Atlas
#   ____________pre-ah:0#025+05+H -- pre-gou:225g25g275g3gG -/- end-ah:025_0#025+H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '16'  and league_country = 'World'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[32/43] #1010627 #Brazil 740-2023 / Botafogo SP U20 vs Ceará U20
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_025_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:34
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[33/43] #997660 #Bahrain 417-2022 / Budaiya vs Muharraq
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:20
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '417'  and league_country = 'Bahrain'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = 'H'  and end_ah_pattern_mirror = 'H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[34/43] #1010630 #Brazil 740-2023 / RB Bragantino U20 vs Cuiabá U20
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:125_1_075_025_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:35
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '125_1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+125+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[35/43] #1010633 #Brazil 740-2023 / Atlético GO U20 vs Palmeiras U20
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025+075+1+125+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025+075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_025_H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[36/43] #1011454 #Brazil 73-2023 / Nautico Recife vs Vila Nova
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:05_025_0#H -- end-gou:175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:11
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[37/43] #1011458 #Brazil 73-2023 / Botafogo SP vs Sao Raimundo
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:15_125_1_075_H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:13
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[38/43] #1001392 #Estonia 328-2023 / Paide II vs Elva
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#075+H -- end-gou:3g35g4gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-14 12:23:16
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '328'  and league_country = 'Estonia'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#075+H'  and end_ah_pattern_mirror = '075_0#H'  and end_gou_pattern = '3g35g4gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[39/43] #1001393 #Estonia 328-2023 / FCI Levadia II vs K-Järve JK Järve
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:35_3_275_25_H -- end-gou:35g4g45gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-14 12:23:07
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '328'  and league_country = 'Estonia'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '35_3_275_25_H'  and end_ah_pattern_mirror = '25+275+3+35+H'  and end_gou_pattern = '35g4g45gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[40/43] #1001394 #Estonia 328-2023 / Nõmme United vs Legion
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:15_1_H -- end-gou:3g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-14 12:23:09
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '328'  and league_country = 'Estonia'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '15_1_H'  and end_ah_pattern_mirror = '1+15+H'  and end_gou_pattern = '3g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[41/43] #1012132 #India 323-2022 / Hyderabad vs ATK Mohun Bagan
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:05_025_0#025+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-14 12:23:03
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '323'  and league_country = 'India'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[42/43] #997870 #Singapore 368-2023 / Albirex Niigata S vs Home United
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_0#025+H -- end-gou:275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:16
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '368'  and league_country = 'Singapore'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[43/43] #997871 #Singapore 368-2023 / Young Lions vs Tampines Rovers
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:2+225+25+275+3+325+H -- end-gou:35g375g4g425g45g475gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-16 09:41:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '368'  and league_country = 'Singapore'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '2+225+25+275+3+325+H'  and end_ah_pattern_mirror = '325_3_275_25_225_2_H'  and end_gou_pattern = '35g375g4g425g45g475gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
# # -------------------------------------------------- End at 2023-03-16 14:44:58
