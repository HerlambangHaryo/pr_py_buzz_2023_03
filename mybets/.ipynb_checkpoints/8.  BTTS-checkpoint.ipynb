# %%
INIT_bet_id = "8"

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " , id  "
query += " from bets_old " 
query += " where bet_id = " + INIT_bet_id   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close()
# Out:
# select  bet_id  , bet   , value   , columny   , columnx   from bets_old  where bet_id = 8 order by bet_id, total asc

# %%
# -----------------------------------------------------  
# ----------------------------------------------------- 
word = '<div class="btn-group mt-2">'
print(word, flush=True)
# ----------------------------------------------------- 
space = "    "
# ----------------------------------------------------- 
for x in result2:  
    # ------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # ------------------------------------------------- 
    word = space + '<a'
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + '@if(!is_null($row->pre_'+columnx+'))'
    print(word, flush=True)
    # ------------------------------------------------- 
    route = "{{route('Mybets.datacreateanalysis',["
    # ------------------------------------------------- 
    word = space + space + 'href="'+route
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'leagueapi_id' => $row->leagueapi_id,"
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'season' => $row->season,"
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'fixtureapi_id' => $row->fixtureapi_id,"
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'betsapi_id' => "+INIT_bet_id+","
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'value' => " + "'" + value + "'"+ ","
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'odd' => $row->pre_"+columnx+","
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + '])}}"'
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + '@endif'
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + 'target="_blank"'
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + 'class="btn bg-gray-700 btn-sm text-white">'
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space2 + value
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space2 + "<br/>"
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space2 + "{{ $row->pre_"+columnx+" }}"
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + '</a>'
    print(word, flush=True)
    # ------------------------------------------------- 
# ----------------------------------------------------- 
# ----------------------------------------------------- 
# ----------------------------------------------------- 
# ----------------------------------------------------- 
word = '</div>'
print(word, flush=True)
# -----------------------------------------------------
# Out:
# <div class="btn-group mt-2">
#     <a
#     @if(!is_null($row->pre_both_teams_score_yes))
#         href="{{route('Mybets.datacreateanalysis',[
#             'leagueapi_id' => $row->leagueapi_id,
#             'season' => $row->season,
#             'fixtureapi_id' => $row->fixtureapi_id,
#             'betsapi_id' => 8,
#             'value' => 'Yes',
#             'odd' => $row->pre_both_teams_score_yes,
#         ])}}"
#     @endif
#     target="_blank"
#     class="btn bg-gray-700 btn-sm text-white">
#         Yes
#         <br/>
#         {{ $row->pre_both_teams_score_yes }}
#     </a>
#     <a
#     @if(!is_null($row->pre_both_teams_score_no))
#         href="{{route('Mybets.datacreateanalysis',[
#             'leagueapi_id' => $row->leagueapi_id,
#             'season' => $row->season,
#             'fixtureapi_id' => $row->fixtureapi_id,
#             'betsapi_id' => 8,
#             'value' => 'No',
#             'odd' => $row->pre_both_teams_score_no,
#         ])}}"
# ...

# %%
# ----------------------------------------------------- 
word = ''
print(word, flush=True)
# ----------------------------------------------------- 
word = '<br/>'
print(word, flush=True)
# ----------------------------------------------------- 
word = ''
print(word, flush=True)
# ----------------------------------------------------- 
word = ''
print(word, flush=True)
# ----------------------------------------------------- 
word = '<div class="btn-group mt-2">'
print(word, flush=True)
# ----------------------------------------------------- 
# ----------------------------------------------------- 
# ----------------------------------------------------- 
space = "    "
# ----------------------------------------------------- 
for x in result2:  
    # ------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # ------------------------------------------------- 
    word = space + '<a'
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + '@if(!is_null($row->end_'+columnx+'))'
    print(word, flush=True)
    # ------------------------------------------------- 
    route = "{{route('Mybets.datacreate',["
    # ------------------------------------------------- 
    word = space + space + 'href="'+route
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'leagueapi_id' => $row->leagueapi_id,"
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'season' => $row->season,"
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'fixtureapi_id' => $row->fixtureapi_id,"
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'betsapi_id' => "+INIT_bet_id+","
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'value' => " + "'" + value + "'"+ ","
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + space + "'odd' => $row->end_"+columnx+","
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space + '])}}"'
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + '@endif'
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + 'target="_blank"'
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + 'class="btn bg-gray-800 btn-sm text-white">'
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + space2 + "{{ $row->end_"+columnx+" }}"
    print(word, flush=True)
    # ------------------------------------------------- 
    word = space + '</a>'
    print(word, flush=True)
    # ------------------------------------------------- 
# ----------------------------------------------------- 
# ----------------------------------------------------- 
# ----------------------------------------------------- 
# ----------------------------------------------------- 
word = '</div>'
print(word, flush=True)
# -----------------------------------------------------
# Out:
# <br/>
#
#
# <div class="btn-group mt-2">
#     <a
#     @if(!is_null($row->end_both_teams_score_yes))
#         href="{{route('Mybets.datacreate',[
#             'leagueapi_id' => $row->leagueapi_id,
#             'season' => $row->season,
#             'fixtureapi_id' => $row->fixtureapi_id,
#             'betsapi_id' => 8,
#             'value' => 'Yes',
#             'odd' => $row->end_both_teams_score_yes,
#         ])}}"
#     @endif
#     target="_blank"
#     class="btn bg-gray-800 btn-sm text-white">
#         {{ $row->end_both_teams_score_yes }}
#     </a>
#     <a
#     @if(!is_null($row->end_both_teams_score_no))
#         href="{{route('Mybets.datacreate',[
#             'leagueapi_id' => $row->leagueapi_id,
#             'season' => $row->season,
#             'fixtureapi_id' => $row->fixtureapi_id,
#             'betsapi_id' => 8,
#             'value' => 'No',
#             'odd' => $row->end_both_teams_score_no,
#         ])}}"
#     @endif
#     target="_blank"
# ...
