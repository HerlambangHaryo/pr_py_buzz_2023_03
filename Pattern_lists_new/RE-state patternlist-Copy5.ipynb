# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:41:58
#   ____main__
#   ______Enter your leagueapi id :  242
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 7
#   ______________[1/7]  #242 - 2023 => 2 / 1 == Match Finished Ended
#   ______________[2/7]  #242 - 2023 => 3 / None == Match Finished
#   ______________[3/7]  #242 - 2023 => 3 / 1 == Match Finished
#   ______________[4/7]  #242 - 2023 => 3 / 1 == Match Finished Ended
#   ______________[5/7]  #242 - 2023 => 3 / 2 == Match Finished
#   ______________[6/7]  #242 - 2023 => 3 / 2 == Match Finished Ended
#   ______________[7/7]  #242 - 2023 => 3 / 3 == Match Finished
# # -------------------------------------------------- End at 2023-07-29 07:42:08

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:42:08
#   __main()
#   ____Enter your leagueapi id :  242
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '242'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '242'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 1
#   __________[1/1] #996315 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996315
#   ____________> pre_ah_pattern = -1-075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075+1H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '242'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '242'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 119
#   __________[1/119] #996227 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996227
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[2/119] #996230 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996230
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[3/119] #996242 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996242
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[4/119] #996240 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996240
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[5/119] #996235 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996235
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[6/119] #996238 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996238
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[7/119] #996250 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996250
#   ____________> end_ah_pattern = -175-15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15+175H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[8/119] #996245 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996245
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[9/119] #996248 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996248
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[10/119] #996249 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996249
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[11/119] #996247 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996247
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[12/119] #996254 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996254
#   ____________> end_ah_pattern = -175-15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15+175H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[13/119] #996262 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996262
#   ____________> end_ah_pattern = +05+075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075-05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[14/119] #996261 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996261
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[15/119] #996260 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996260
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[16/119] #996259 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996259
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[17/119] #996266 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996266
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[18/119] #996264 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996264
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[19/119] #996274 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996274
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[20/119] #996273 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996273
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[21/119] #996267 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996267
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[22/119] #996270 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996270
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[23/119] #996276 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996276
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[24/119] #996278 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996278
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[25/119] #996282 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996282
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[26/119] #996277 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996277
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[27/119] #996275 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996275
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[28/119] #996280 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996280
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[29/119] #996281 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996281
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[30/119] #996279 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996279
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[31/119] #996285 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996285
#   ____________> end_ah_pattern = +075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[32/119] #996289 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996289
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[33/119] #996290 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996290
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[34/119] #996283 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996283
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[35/119] #996284 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996284
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[36/119] #996286 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996286
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[37/119] #996287 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996287
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[38/119] #996288 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996288
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175+2H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[39/119] #996291 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996291
#   ____________> end_ah_pattern = +05H
#   ____________> end_ah_pattern_mirror = -05H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[40/119] #996292 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996292
#   ____________> end_ah_pattern = -275-25-225-2-175H
#   ____________> end_ah_pattern_mirror = +175+2+225+25+275H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[41/119] #996293 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996293
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[42/119] #996294 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996294
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[43/119] #996295 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996295
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[44/119] #996296 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996296
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[45/119] #996297 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996297
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[46/119] #996298 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996298
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[47/119] #996299 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996299
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[48/119] #996300 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996300
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[49/119] #996301 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996301
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[50/119] #996302 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996302
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[51/119] #996303 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996303
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[52/119] #996304 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996304
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[53/119] #996305 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996305
#   ____________> end_ah_pattern = -15-125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[54/119] #996306 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996306
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[55/119] #996307 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996307
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[56/119] #996308 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996308
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175+2H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[57/119] #996309 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996309
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[58/119] #996310 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996310
#   ____________> end_ah_pattern = +0+025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025+0H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[59/119] #996311 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996311
#   ____________> end_ah_pattern = -175-15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15+175H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[60/119] #996312 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996312
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[61/119] #996313 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996313
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[62/119] #996314 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996314
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[63/119] #996315 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996315
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[64/119] #996316 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996316
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[65/119] #996317 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996317
#   ____________> end_ah_pattern = +05+075+1H
#   ____________> end_ah_pattern_mirror = -1-075-05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[66/119] #996318 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996318
#   ____________> end_ah_pattern = -175-15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[67/119] #996319 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996319
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[68/119] #996320 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996320
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[69/119] #996321 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996321
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[70/119] #996322 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996322
#   ____________> end_ah_pattern = -175-15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15+175H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[71/119] #996323 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996323
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[72/119] #996324 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996324
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[73/119] #996325 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996325
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[74/119] #996326 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996326
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175+2H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[75/119] #996327 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996327
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[76/119] #996328 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996328
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[77/119] #996329 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996329
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[78/119] #996331 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996331
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[79/119] #996332 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996332
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[80/119] #996333 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996333
#   ____________> end_ah_pattern = +025+05+075+1H
#   ____________> end_ah_pattern_mirror = -1-075-05-025H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[81/119] #996334 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996334
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[82/119] #996335 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996335
#   ____________> end_ah_pattern = -15-125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[83/119] #996336 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996336
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[84/119] #996337 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996337
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[85/119] #996338 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996338
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[86/119] #996241 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996241
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[87/119] #996244 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996244
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[88/119] #996237 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996237
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[89/119] #996236 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996236
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[90/119] #996239 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996239
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[91/119] #996246 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996246
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[92/119] #996243 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996243
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[93/119] #996263 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996263
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[94/119] #996219 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996219
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[95/119] #996220 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996220
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[96/119] #996221 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996221
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[97/119] #996222 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996222
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[98/119] #996223 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996223
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[99/119] #996224 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996224
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[100/119] #996225 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996225
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[101/119] #996226 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996226
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[102/119] #996228 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996228
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[103/119] #996229 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996229
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[104/119] #996231 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996231
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[105/119] #996232 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996232
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[106/119] #996233 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996233
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[107/119] #996234 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996234
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[108/119] #996251 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996251
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[109/119] #996252 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996252
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[110/119] #996253 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996253
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[111/119] #996255 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996255
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[112/119] #996256 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996256
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[113/119] #996257 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996257
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[114/119] #996258 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996258
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[115/119] #996265 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996265
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[116/119] #996268 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996268
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[117/119] #996269 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996269
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[118/119] #996271 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996271
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[119/119] #996272 #242 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 996272
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-29 08:36:39

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 08:36:39
#   ____main__
#   ______Enter your leagueapi id :  242
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 2
#   ______________[1/2]  #242 - 2023 => 3 / 3 == Match Finished
#   ______________[2/2]  #242 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-30 17:09:48

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-30 17:09:48
#   ____main__
#   ______Enter your leagueapi id :  242
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '242'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 65
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '65'  where leagueapi_id = '242'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/65] 2. -05-025+0H // 225g25g275gG >> -075-05-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[2/65] 2. -025+0+025+05H // 225g25g275g30gG >> -025+0+025+05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-025+0+025+05H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[3/65] 2. -075-05-025H // 225g25g275gG >> -1-075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[4/65] 1. -175-15-125-1H // 225g25g275g30gG >> -175-15-125-1H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-175-15-125-1H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_from update done
#   ______________[5/65] 1. -15-125-1-075-05H // 225g25g275g30gG >> -15-125-1-075H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-15-125-1-075-05H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_from update done
#   ______________[6/65] 1. -15-125-1-075-05H // 25g275g30g325gG >> -2-175-15-125H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-15-125-1-075-05H'  and `pre_gou_pattern` like '25g275g30g325gG'  and `end_ah_pattern` like '-2-175-15-125H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_from update done
#   ______________[7/65] 1. +025+05+075H // 225g25g275gG >> +0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+025+05+075H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[8/65] 1. +025+05+075H // 20g225g25g275gG >> -025+0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+025+05+075H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[9/65] 1. -075-05-025H // 25g275g30g325gG >> -075-05-025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '25g275g30g325gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_from update done
#   ______________[10/65] 1. -075-05-025H // 225g25g275g30gG >> -075-05-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[11/65] 1. -2-175-15-125H // 25g275g30g325gG >> -2-175-15-125H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-2-175-15-125H'  and `pre_gou_pattern` like '25g275g30g325gG'  and `end_ah_pattern` like '-2-175-15-125H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_from update done
#   ______________[12/65] 1. -15-125-1-075H // 225g25g275gG >> -15-125-1-075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-15-125-1-075H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[13/65] 1. +0+025+05+075H // 225g25g275gG >> +025+05+075H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+0+025+05+075H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_from update done
#   ______________[14/65] 1. +025+05+075H // 225g25g275g30gG >> +0+025+05+075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+025+05+075H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[15/65] 1. -05-025+0+025H // 225g25g275gG >> -05-025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-05-025+0+025H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[16/65] 1. -025+0+025+05H // 20g225g25g275gG >> -025+0+025+05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-025+0+025+05H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[17/65] 1. -125-1-075-05H // 225g25g275gG >> -125-1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-125-1-075-05H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[18/65] 1. -1-075-05H // 225g25g275gG >> -175-15-125-1H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[19/65] 1. -1-075-05H // 225g25g275g30gG >> -1-075-05-025H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_from update done
#   ______________[20/65] 1. -125-1-075-05H // 225g25g275g30gG >> -1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-125-1-075-05H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[21/65] 1. -025+0+025H // 225g25g275gG >> +0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[22/65] 1. -075-05-025H // 20g225g25gG >> -05-025+0H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '20g225g25gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_from update done
#   ______________[23/65] 1. -025+0+025H // 225g25g275gG >> -025+0+025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[24/65] 1. -1-075-05-025H // 225g25g275gG >> -125-1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[25/65] 1. +05H // 25gG >> +05H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+05H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '+05H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[26/65] 1. -1-075-05-025H // 20g225g25g275gG >> -1-075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[27/65] 1. +025+05+075+1H // 225g25g275g30gG >> +025+05+075+1H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+025+05+075+1H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_from update done
#   ______________[28/65] 1. -05-025+0H // 20g225g25gG >> -025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '20g225g25gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[29/65] 1. -225-2-175-15-125H // 25g275g30g325g35gG >> -275-25-225-2-175H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-225-2-175-15-125H'  and `pre_gou_pattern` like '25g275g30g325g35gG'  and `end_ah_pattern` like '-275-25-225-2-175H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_from update done
#   ______________[30/65] 1. -1-075-05-025H // 20g225g25g275gG >> -1-075-05-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[31/65] 1. -075-05-025H // 225g25g275g30gG >> -125-1-075-05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[32/65] 1. -025+0+025+05H // 20g225g25g275gG >> -025+0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-025+0+025+05H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[33/65] 1. -1-075-05-025H // 225g25g275gG >> -075-05-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[34/65] 1. -075-05-025H // 175g20g225g25gG >> -075-05-025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[35/65] 1. -15-125-1-075H // 25g275g30g325gG >> -15-125-1-075H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-15-125-1-075H'  and `pre_gou_pattern` like '25g275g30g325gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_from update done
#   ______________[36/65] 1. -1-075-05-025H // 20g225g25g275gG >> -1-075-05H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_from update done
#   ______________[37/65] 1. -125-1-075-05H // 225g25g275gG >> -15-125-1-075H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-125-1-075-05H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[38/65] 1. -075-05-025H // 20g225g25gG >> -075-05-025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '20g225g25gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_from update done
#   ______________[39/65] 1. -075-05-025H // 225g25g275gG >> -075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[40/65] 1. -075-05-025+0H // 225g25g275gG >> -075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025+0H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[41/65] 1. +025+05+075+1H // 20g225g25g275gG >> +05+075+1H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+025+05+075+1H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '+05+075+1H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[42/65] 1. -05-025+0H // 175g20g225g25gG >> -05-025+0H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_from update done
#   ______________[43/65] 1. -1-075-05H // 225g25g275gG >> -1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[44/65] 1. -175-15-125-1H // 25g275g30g325gG >> -175-15-125-1-075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-175-15-125-1H'  and `pre_gou_pattern` like '25g275g30g325gG'  and `end_ah_pattern` like '-175-15-125-1-075H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_from update done
#   ______________[45/65] 1. -075-05-025H // 225g25g275gG >> -1-075-05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[46/65] 1. -025+0+025H // 20g225g25g275gG >> -025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[47/65] 1. -125-1-075-05H // 225g25g275g30g325gG >> -125-1-075-05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-125-1-075-05H'  and `pre_gou_pattern` like '225g25g275g30g325gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[48/65] 1. +0+025+05+075H // 225g25g275g30gG >> +0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+0+025+05+075H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[49/65] 1. -05-025+0H // 20g225g25g275gG >> -025+0+025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[50/65] 1. -05-025+0H // 20g225g25gG >> -05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '20g225g25gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[51/65] 1. -075-05-025H // 225g25g275gG >> -1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[52/65] 1. -05-025+0H // 20g225g25gG >> -1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '20g225g25gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[53/65] 1. +0+025+05H // 225g25g275gG >> +0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+0+025+05H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[54/65] 1. +0+025+05H // 225g25g275gG >> -05-025+0+025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+0+025+05H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[55/65] 1. +05+075+1H // 225g25g275gG >> +05+075+1+125H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+05+075+1H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '+05+075+1+125H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[56/65] 1. -05-025+0H // 20g225g25g275gG >> -075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[57/65] 1. -05-025+0H // 175g20g225g25gG >> -05-025+0H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_from update done
#   ______________[58/65] 1. -175-15-125-1H // 20g225g25g275gG >> -15-125-1-075H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-175-15-125-1H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[59/65] 1. -05-025+0+025H // 225g25g275g30gG >> -05-025+0+025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-05-025+0+025H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_from update done
#   ______________[60/65] 1. -15-125-1H // 225g25g275g30gG >> -15-125-1-075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-15-125-1H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[61/65] 1. -175-15-125-1H // 25g275g30g325gG >> -175-15-125-1H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-175-15-125-1H'  and `pre_gou_pattern` like '25g275g30g325gG'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_from update done
#   ______________[62/65] 1. -1-075-05H // 20g225g25gG >> -125-1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '20g225g25gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[63/65] 1. +05+075+1H // 225g25g275gG >> +075+1+125+15H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '+05+075+1H'  and `pre_gou_pattern` like '225g25g275gG'  and `end_ah_pattern` like '+075+1+125+15H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[64/65] 1. -075-05-025+0H // 225g25g275g30gG >> -05-025+0H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like '-075-05-025+0H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[65/65] 1. +05+075+1+125H // 225g25g275g30gG >> +05+075+1+125H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
# ...
#   __________________pattern_only update done
#   ______________[33/55] 1.  >> -175-15-125H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[34/55] 1.  >> -075-05-025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[35/55] 1.  >> -125-1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[36/55] 1.  >> -05-025+0H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[37/55] 1.  >> -025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[38/55] 1.  >> -025+0+025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[39/55] 1.  >> +025+05+075H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[40/55] 1.  >> +025+05+075+1H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[41/55] 1.  >> +0+025+05+075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[42/55] 1.  >> -15-125-1-075-05H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[43/55] 1.  >> -1-075-05-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[44/55] 1.  >> -075-05-025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[45/55] 1.  >> +05+075+1+125H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1+125H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[46/55] 1.  >> +05H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_only update done
#   ______________[47/55] 1.  >> +05+075+1H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[48/55] 1.  >> -075-05-025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[49/55] 1.  >> -275-25-225-2-175H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-275-25-225-2-175H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[50/55] 1.  >> +025+05+075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[51/55] 1.  >> -175-15-125-1-075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1-075H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[52/55] 1.  >> -1-075-05H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[53/55] 1.  >> -075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[54/55] 1.  >> -025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[55/55] 1.  >> -1-075-05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 242  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
# # -------------------------------------------------- End at 2023-07-30 18:18:25
