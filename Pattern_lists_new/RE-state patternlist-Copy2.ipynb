gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[83/95] #922124 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 922124
#   ____________> pre_ah_pattern = -125-1-075-05H
#   ____________> pre_ah_pattern_mirror = +05+075+1+125H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[84/95] #922125 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 922125
#   ____________> pre_ah_pattern = +15+175+2+225+25H
#   ____________> pre_ah_pattern_mirror = -25-225-2-175-15H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[85/95] #922122 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 922122
#   ____________> pre_ah_pattern = -125-1-075-05+025H
#   ____________> pre_ah_pattern_mirror = -025+05+075+1+125H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[86/95] #922123 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 922123
#   ____________> pre_ah_pattern = -075-05-025+025H
#   ____________> pre_ah_pattern_mirror = -025+025+05+075H
#   ____________> pre_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[87/95] #922126 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 922126
#   ____________> pre_ah_pattern = -125-1-075-05+025H
#   ____________> pre_ah_pattern_mirror = -025+05+075+1+125H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[88/95] #922127 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 922127
#   ____________> pre_ah_pattern = +025+15+175+2+225+25H
#   ____________> pre_ah_pattern_mirror = -25-225-2-175-15-025H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[89/95] #948825 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 948825
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[90/95] #948828 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 948828
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[91/95] #948827 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 948827
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[92/95] #948826 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 948826
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[93/95] #967596 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 967596
#   ____________> pre_ah_pattern = -3-275-25-225-2H
#   ____________> pre_ah_pattern_mirror = +2+225+25+275+3H
#   ____________> pre_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[94/95] #967595 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 967595
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[95/95] #1031811 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031811
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '185'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '185'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 150
#   __________[1/150] #967596 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 967596
#   ____________> end_ah_pattern = -3-275-25-225-2H
#   ____________> end_ah_pattern_mirror = +2+225+25+275+3H
#   ____________> end_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[2/150] #967595 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 967595
#   ____________> end_ah_pattern = -175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[3/150] #1031817 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031817
#   ____________> end_ah_pattern = +125+15+175+2H
#   ____________> end_ah_pattern_mirror = -2-175-15-125H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[4/150] #1031813 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031813
#   ____________> end_ah_pattern = +025+05+075+1H
#   ____________> end_ah_pattern_mirror = -1-075-05-025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[5/150] #1031814 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031814
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[6/150] #1031815 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031815
#   ____________> end_ah_pattern = +075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[7/150] #1031816 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031816
#   ____________> end_ah_pattern = +025+05+075+1H
#   ____________> end_ah_pattern_mirror = -1-075-05-025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[8/150] #1031812 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031812
#   ____________> end_ah_pattern = +175+2+225+25+275H
#   ____________> end_ah_pattern_mirror = -275-25-225-2-175H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[9/150] #1031802 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031802
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175+2H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[10/150] #1031803 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031803
#   ____________> end_ah_pattern = -225-2-175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175+2+225H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[11/150] #1031804 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031804
#   ____________> end_ah_pattern = -175-15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[12/150] #1031805 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031805
#   ____________> end_ah_pattern = +15+175+2+225+25H
#   ____________> end_ah_pattern_mirror = -25-225-2-175-15H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[13/150] #1031806 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031806
#   ____________> end_ah_pattern = +075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[14/150] #1031807 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031807
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[15/150] #1031808 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031808
#   ____________> end_ah_pattern = +1+125+15+175H
#   ____________> end_ah_pattern_mirror = -175-15-125-1H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[16/150] #1031809 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031809
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[17/150] #1031810 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031810
#   ____________> end_ah_pattern = +125+15+175+2H
#   ____________> end_ah_pattern_mirror = -2-175-15-125H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[18/150] #1031811 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031811
#   ____________> end_ah_pattern = +125+15+175H
#   ____________> end_ah_pattern_mirror = -175-15-125H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[19/150] #1031818 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031818
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[20/150] #1031819 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031819
#   ____________> end_ah_pattern = -175-15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15+175H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[21/150] #1031820 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031820
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[22/150] #1031821 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031821
#   ____________> end_ah_pattern = +05+075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075-05H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[23/150] #1031822 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031822
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[24/150] #1031823 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031823
#   ____________> end_ah_pattern = -25-225-2-175-15H
#   ____________> end_ah_pattern_mirror = +15+175+2+225+25H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[25/150] #1031824 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031824
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[26/150] #1031825 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031825
#   ____________> end_ah_pattern = -225-2-175-15H
#   ____________> end_ah_pattern_mirror = +15+175+2+225H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[27/150] #1031826 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031826
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[28/150] #1031827 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031827
#   ____________> end_ah_pattern = +075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[29/150] #1031828 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031828
#   ____________> end_ah_pattern = +125+15+175+2+225H
#   ____________> end_ah_pattern_mirror = -225-2-175-15-125H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[30/150] #1031829 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031829
#   ____________> end_ah_pattern = +05+075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075-05H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[31/150] #1031830 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031830
#   ____________> end_ah_pattern = -175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[32/150] #1031831 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031831
#   ____________> end_ah_pattern = -225-2-175-15H
#   ____________> end_ah_pattern_mirror = +15+175+2+225H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[33/150] #1031832 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031832
#   ____________> end_ah_pattern = -225-2-175-15H
#   ____________> end_ah_pattern_mirror = +15+175+2+225H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[34/150] #1031833 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031833
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[35/150] #1031834 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031834
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[36/150] #1031835 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031835
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[37/150] #1031836 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031836
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175+2H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[38/150] #1031837 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031837
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[39/150] #1031838 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031838
#   ____________> end_ah_pattern = +075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[40/150] #1031839 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031839
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[41/150] #1031840 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031840
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[42/150] #1031841 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031841
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[43/150] #1031842 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031842
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[44/150] #1031843 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031843
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[45/150] #1031844 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031844
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[46/150] #1031845 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031845
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[47/150] #1031846 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031846
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[48/150] #1031847 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031847
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[49/150] #1031848 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031848
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[50/150] #1031849 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031849
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[51/150] #1031850 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031850
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[52/150] #1031851 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031851
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[53/150] #1031852 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031852
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[54/150] #1031853 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031853
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[55/150] #1031854 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031854
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[56/150] #1031855 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031855
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[57/150] #1031856 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031856
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[58/150] #1031857 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031857
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[59/150] #1031858 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031858
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[60/150] #1031859 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031859
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[61/150] #1031860 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031860
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[62/150] #1031861 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031861
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[63/150] #1031862 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031862
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[64/150] #1031863 #185 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1031863
# ...
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863923
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[95/150] #863924 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863924
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[96/150] #863925 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863925
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[97/150] #863926 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863926
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[98/150] #863927 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863927
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[99/150] #863928 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863928
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[100/150] #863929 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863929
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[101/150] #863930 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863930
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[102/150] #863931 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863931
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[103/150] #863932 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863932
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[104/150] #863933 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863933
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[105/150] #863934 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863934
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[106/150] #863935 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863935
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[107/150] #863936 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863936
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[108/150] #863937 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863937
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[109/150] #863938 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863938
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[110/150] #863939 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863939
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[111/150] #863940 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863940
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[112/150] #863941 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863941
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[113/150] #863942 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863942
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[114/150] #863943 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863943
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[115/150] #863944 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863944
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[116/150] #863945 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863945
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[117/150] #863946 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863946
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[118/150] #863947 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863947
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[119/150] #863948 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863948
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[120/150] #863949 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863949
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[121/150] #863950 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863950
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[122/150] #863951 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863951
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[123/150] #863952 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863952
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[124/150] #863953 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863953
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[125/150] #863954 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863954
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[126/150] #863955 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863955
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[127/150] #863956 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863956
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[128/150] #863957 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863957
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[129/150] #863958 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863958
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[130/150] #863959 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863959
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[131/150] #863960 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863960
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[132/150] #863961 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863961
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[133/150] #863962 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863962
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[134/150] #863963 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863963
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[135/150] #863964 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863964
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[136/150] #863965 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863965
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[137/150] #863966 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863966
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[138/150] #863967 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863967
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[139/150] #863968 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863968
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[140/150] #863969 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863969
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[141/150] #863970 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863970
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[142/150] #863971 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863971
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[143/150] #863972 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863972
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[144/150] #863973 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863973
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[145/150] #863974 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863974
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[146/150] #863975 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 863975
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[147/150] #948825 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 948825
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[148/150] #948828 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 948828
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[149/150] #948827 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 948827
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[150/150] #948826 #185 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 948826
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-28 23:27:04

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-28 23:27:04
#   ____main__
#   ______Enter your leagueapi id :  185
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 5
#   ______________[1/5]  #185 - 2022 => 3 / 3 == Match Finished
#   ______________[2/5]  #185 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/5]  #185 - 2023 => 3 / 1 == Match Finished Ended
#   ______________[4/5]  #185 - 2023 => 3 / 3 == Match Finished
#   ______________[5/5]  #185 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-29 07:23:24

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:23:24
#   ____main__
#   ______Enter your leagueapi id :  185
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '185'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 28
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '28'  where leagueapi_id = '185'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/28] 2. +025+05+075+1H // 225g25g275g30gG >> +025+05+075+1H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[2/28] 1. +1+125+15+175H // 25g275g30g325gG >> +1+125+15+175H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[3/28] 1. -05-025+0H // 25g275g30g325gG >> -05-025+0+025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[4/28] 1. +05+075+1+125H // 225g25g275g30g325gG >> +05+075+1+125H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[5/28] 1. +075+1+125+15H // 25g275g30g325g35gG >> +125+15+175+2H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[6/28] 1. -125-1-075-05H // 25g275g30g325gG >> -075-05-025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[7/28] 1. -175-15-125H // 25g275g30g325g35gG >> -175-15-125-1H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[8/28] 1. +125+15+175+2H // 275g30g325g35gG >> +125+15+175+2H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[9/28] 1. -05-025+0+025H // 25g275g30g325gG >> -025+0+025+05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[10/28] 1. -175-15-125-1-075H // 25g275g30g325g35gG >> -15-125-1-075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[11/28] 1. -15-125-1-075-05H // 225g25g275g30gG >> -15-125-1-075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[12/28] 1. -25-225-2-175-15H // 25g275g30g325g35gG >> -25-225-2-175-15H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[13/28] 1. +075+1+125+15H // 225g25g275g30g325gG >> +075+1+125+15H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[14/28] 1. -125-1-075-05H // 25g275g30g325gG >> -1-075-05-025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[15/28] 1. +15+175+2+225H // 25g275g30g325g35gG >> +175+2+225+25+275H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[16/28] 1. -2-175-15-125H // 275g30g325g35gG >> -225-2-175-15H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[17/28] 1. -2-175-15-125H // 25g275g30g325g35gG >> -2-175-15-125H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[18/28] 1. -075-05-025+0H // 25g275g30g325gG >> -1-075-05-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[19/28] 1. -225-2-175-15-125H // 25g275g30g325g35gG >> -225-2-175-15-125H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[20/28] 1. +05+075+1+125H // 25g275g30g325g35gG >> +075+1+125+15H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[21/28] 1. -175-15-125-1-075H // 25g275g30g325g35gG >> -175-15-125-1-075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[22/28] 1. +125+15+175+2H // 275g30g325g35gG >> +125+15+175+2+225H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[23/28] 1. +15+175+2+225+25H // 275g30g325g35g375gG >> +15+175+2+225+25H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[24/28] 1. +05+075+1+125H // 25g275g30g325gG >> +05+075+1+125+15H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[25/28] 1. +05+075+1+125H // 25g275g30g325gG >> +075+1+125+15H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[26/28] 1. -175-15-125H // 25g275g30g325g35gG >> -175-15-125H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[27/28] 1. -075-05-025+0H // 225g25g275g30gG >> -05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[28/28] 1. -225-2-175-15H // 275g30g325g35gG >> -225-2-175-15H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ________ff_get_fixtures_group_by_only_end_patternlists()
#   ____________Total Row(s) : 38
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_only_ends = '38'  where leagueapi_id = '185'
#   ________________> football_leagues : total_pattern_only_ends UPDATED
#   ______________[1/38] 2.  >> +15+175+2+225+25H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 185  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+15+175+2+225+25H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[2/38] 2.  >> +075+1+125+15H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[3/38] 2.  >> +025+05+075+1H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[4/38] 2.  >> -1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 185  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[5/38] 1.  >> -075-05-025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 185  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[6/38] 1.  >> -05-025+0+025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[7/38] 1.  >> -175-15-125-1-075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[8/38] 1.  >> -15-125-1-075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[9/38] 1.  >> -25-225-2-175-15H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[10/38] 1.  >> -3-275-25-225-2H // 325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 185  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-3-275-25-225-2H'  and `end_gou_pattern` like '325g35g375g40gG'
#   __________________pattern_only update done
#   ______________[11/38] 1.  >> -05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[12/38] 1.  >> -1-075-05-025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[13/38] 1.  >> -175-15-125H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 185  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[14/38] 1.  >> +1+125+15+175H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[15/38] 1.  >> -225-2-175-15H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[16/38] 1.  >> +125+15+175+2H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[17/38] 1.  >> +05+075+1+125H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[18/38] 1.  >> -1-075-05-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[19/38] 1.  >> +125+15+175+2H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[20/38] 1.  >> -4-375-35-325H // 35g375g40g425g45g475gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 185  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-4-375-35-325H'  and `end_gou_pattern` like '35g375g40g425g45g475gG'
#   __________________pattern_only update done
#   ______________[21/38] 1.  >> +125+15+175+2+225H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[22/38] 1.  >> -15-125-1-075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[23/38] 1.  >> +125+15+175H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[24/38] 1.  >> -05-025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 185  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[25/38] 1.  >> +05+075+1+125+15H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[26/38] 1.  >> +075+1+125+15H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[27/38] 1.  >> -075-05-025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[28/38] 1.  >> -125-1-075-05H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 185  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[29/38] 1.  >> -175-15-125H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[30/38] 1.  >> +175+2+225+25+275H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[31/38] 1.  >> -175-15-125-1H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[32/38] 1.  >> +175+2+225+25H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 185  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+175+2+225+25H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[33/38] 1.  >> -225-2-175-15H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[34/38] 1.  >> -2-175-15-125H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[35/38] 1.  >> -025+0+025+05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[36/38] 1.  >> -225-2-175-15H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[37/38] 1.  >> -225-2-175-15-125H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[38/38] 1.  >> +05+075+1+125+15H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
# # -------------------------------------------------- End at 2023-07-29 08:40:36
