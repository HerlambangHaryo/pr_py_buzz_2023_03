# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:58:12
#   ____main__
#   ______Enter your leagueapi id :  714
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 2
#   ______________[1/2]  #714 - 2022 => 0 / 1 == Match Finished Ended
#   ______________[2/2]  #714 - 2022 => 3 / 1 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-29 07:58:24

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:58:24
#   __main()
#   ____Enter your leagueapi id :  714
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '714'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '714'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 1
#   __________[1/1] #1042574 #714 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1042574
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '714'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '714'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 4
#   __________[1/4] #1041116 #714 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1041116
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[2/4] #1042575 #714 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1042575
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[3/4] #1030833 #714 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1030833
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[4/4] #1042574 #714 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1042574
#   ____________> end_ah_pattern = +05+075+1H
#   ____________> end_ah_pattern_mirror = -1-075-05H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-29 08:02:42

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 08:02:42
#   ____main__
#   ______Enter your leagueapi id :  714
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 1
#   ______________[1/1]  #714 - 2022 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-29 08:07:55

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 08:07:55
#   ____main__
#   ______Enter your leagueapi id :  714
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '714'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 0
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '0'  where leagueapi_id = '714'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ________ff_get_fixtures_group_by_only_end_patternlists()
#   ____________Total Row(s) : 3
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_only_ends = '3'  where leagueapi_id = '714'
#   ________________> football_leagues : total_pattern_only_ends UPDATED
#   ______________[1/3] 1.  >> +05+075+1H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[2/3] 1.  >> -075-05-025H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[3/3] 1.  >> -15-125-1-075H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
# # -------------------------------------------------- End at 2023-07-29 08:12:07
