# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-28 23:11:28
#   ____main__
#   ______Enter your leagueapi id :  104
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 6
#   ______________[1/6]  #104 - 2022 => 3 / 3 == Match Finished
#   ______________[2/6]  #104 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/6]  #104 - 2023 => 1 / 1 == Match Finished Ended
#   ______________[4/6]  #104 - 2023 => 3 / 1 == Match Finished Ended
#   ______________[5/6]  #104 - 2023 => 3 / 3 == Match Finished
#   ______________[6/6]  #104 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-28 23:12:11

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-28 23:12:11
#   __main()
#   ____Enter your leagueapi id :  104
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '104'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '104'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 1
#   __________[1/1] #1002143 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002143
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '104'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '104'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 24
#   __________[1/24] #1002143 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002143
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[2/24] #1002144 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002144
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[3/24] #1002145 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002145
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[4/24] #1002146 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002146
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[5/24] #1002147 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002147
#   ____________> end_ah_pattern = -15-125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[6/24] #1002148 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002148
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[7/24] #1002149 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002149
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[8/24] #1002150 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002150
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[9/24] #1002151 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002151
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[10/24] #1002152 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002152
#   ____________> end_ah_pattern = -175-15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[11/24] #1002153 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002153
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[12/24] #1002154 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002154
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[13/24] #1002155 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002155
#   ____________> end_ah_pattern = +0+025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025+0H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[14/24] #1002156 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002156
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[15/24] #1002157 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002157
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[16/24] #1002158 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002158
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[17/24] #1002159 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002159
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[18/24] #1002160 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002160
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[19/24] #1002161 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002161
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[20/24] #1002162 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002162
#   ____________> end_ah_pattern = -125-1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1+125H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[21/24] #1002163 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002163
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[22/24] #1002164 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002164
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[23/24] #1002165 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002165
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[24/24] #1002166 #104 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1002166
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-28 23:26:36

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-28 23:26:36
#   ____main__
#   ______Enter your leagueapi id :  104
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 4
#   ______________[1/4]  #104 - 2022 => 3 / 3 == Match Finished
#   ______________[2/4]  #104 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/4]  #104 - 2023 => 3 / 3 == Match Finished
#   ______________[4/4]  #104 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-29 07:22:50

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:22:50
#   ____main__
#   ______Enter your leagueapi id :  104
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '104'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 8
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '8'  where leagueapi_id = '104'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/8] 1. -125-1-075-05H // 25g275g30g325g35gG >> -15-125-1-075H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[2/8] 1. +025+05+075H // 225g25g275g30gG >> +025+05+075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[3/8] 1. -075-05-025+0H // 30g325g35g375gG >> -075-05-025H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[4/8] 1. -125-1-075-05-025H // 275g30g325g35g375gG >> -125-1-075-05-025H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[5/8] 1. -05-025+0H // 20g225g25g275gG >> -05-025+0H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[6/8] 1. -05-025+0H // 225g25g275g30gG >> -075-05-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[7/8] 1. +0+025+05+075H // 25g275g30g325gG >> +025+05+075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[8/8] 1. -075-05-025+0H // 275g30g325g35g375gG >> -1-075-05-025H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ________ff_get_fixtures_group_by_only_end_patternlists()
#   ____________Total Row(s) : 133
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_only_ends = '133'  where leagueapi_id = '104'
#   ________________> football_leagues : total_pattern_only_ends UPDATED
#   ______________[1/133] 14.  >> -075-05-025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 14
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[2/133] 11.  >> -1-075-05-025H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 11
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[3/133] 9.  >> -05-025+0H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 9
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[4/133] 8.  >> -075-05-025+0H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 8
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[5/133] 8.  >> -05-025+0H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 8
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[6/133] 7.  >> -025+0+025+05H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[7/133] 7.  >> -05-025+0+025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[8/133] 6.  >> +0+025+05+075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 6
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[9/133] 6.  >> +0+025+05H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 6
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[10/133] 5.  >> -075-05-025H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[11/133] 5.  >> -025+0+025+05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[12/133] 5.  >> -075-05-025H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[13/133] 5.  >> -025+0+025+05H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[14/133] 5.  >> +025+05+075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[15/133] 5.  >> -025+0+025+05H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[16/133] 4.  >> -075-05-025+0H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[17/133] 4.  >> -05-025+0+025H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[18/133] 4.  >> -1-075-05-025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[19/133] 4.  >> -075-05-025+0H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[20/133] 4.  >> -125-1-075-05H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[21/133] 4.  >> +0+025+05+075H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[22/133] 4.  >> -1-075-05-025H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[23/133] 3.  >> -125-1-075-05H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[24/133] 3.  >> -075-05-025H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[25/133] 3.  >> +025+05+075H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[26/133] 3.  >> -1-075-05-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[27/133] 3.  >> -075-05-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[28/133] 3.  >> +025+05+075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[29/133] 3.  >> -125-1-075-05H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[30/133] 3.  >> -05-025+0H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[31/133] 3.  >> -125-1-075-05H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[32/133] 3.  >> +0+025+05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[33/133] 3.  >> -175-15-125-1H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[34/133] 3.  >> -15-125-1-075-05H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[35/133] 3.  >> -15-125-1-075-05H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[36/133] 3.  >> -05-025+0+025H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[37/133] 3.  >> -075-05-025+0H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[38/133] 2.  >> +025+05+075+1H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[39/133] 2.  >> -075-05-025H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[40/133] 2.  >> -15-125-1-075-05H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[41/133] 2.  >> -025+0+025+05H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[42/133] 2.  >> -1-075-05-025H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[43/133] 2.  >> -025+0+025H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[44/133] 2.  >> -175-15-125-1-075H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1-075H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[45/133] 2.  >> -125-1-075-05-025H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05-025H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[46/133] 2.  >> +05+075+1+125+15H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1+125+15H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[47/133] 2.  >> -25-225-2-175-15H // 325g35g375g40g425gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-25-225-2-175-15H'  and `end_gou_pattern` like '325g35g375g40g425gG'
#   __________________pattern_only update done
#   ______________[48/133] 2.  >> -175-15-125-1H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[49/133] 2.  >> +0+025+05H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[50/133] 2.  >> +025+05+075H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[51/133] 2.  >> -075-05-025+0H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[52/133] 2.  >> -025+0+025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[53/133] 2.  >> -15-125-1-075H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[54/133] 2.  >> -05-025+0+025+05H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025+05H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[55/133] 2.  >> +0+025+05+075H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[56/133] 2.  >> -05-025+0H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[57/133] 2.  >> -05-025+0H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[58/133] 2.  >> -175-15-125-1-075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1-075H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[59/133] 2.  >> -05-025+0+025H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[60/133] 2.  >> -075-05-025H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[61/133] 2.  >> +025+05+075+1H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[62/133] 1.  >> -075-05-025+0H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[63/133] 1.  >> -225-2-175-15-125H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-225-2-175-15-125H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[64/133] 1.  >> -05-025+0H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
# ...
#   __________________pattern_only update done
#   ______________[111/133] 1.  >> +125+15+175+2H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+125+15+175+2H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[112/133] 1.  >> -025+0+025+05H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[113/133] 1.  >> +05+075+1+125+15H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1+125+15H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[114/133] 1.  >> -35-325-3-275-25-225H // 35g375g40g425g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-35-325-3-275-25-225H'  and `end_gou_pattern` like '35g375g40g425g45gG'
#   __________________pattern_only update done
#   ______________[115/133] 1.  >> +15+175+2+225H // 325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+15+175+2+225H'  and `end_gou_pattern` like '325g35g375g40gG'
#   __________________pattern_only update done
#   ______________[116/133] 1.  >> -3-275-25-225-2H // 35g375g40g425g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-3-275-25-225-2H'  and `end_gou_pattern` like '35g375g40g425g45gG'
#   __________________pattern_only update done
#   ______________[117/133] 1.  >> -125-1-075-05H // 325g35g375g40g425gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '325g35g375g40g425gG'
#   __________________pattern_only update done
#   ______________[118/133] 1.  >> +0+025+05H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[119/133] 1.  >> -075H // 275g30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075H'  and `end_gou_pattern` like '275g30g35gG'
#   __________________pattern_only update done
#   ______________[120/133] 1.  >> -175-15-125H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[121/133] 1.  >> -225-2-175-15H // 325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-225-2-175-15H'  and `end_gou_pattern` like '325g35g375g40gG'
#   __________________pattern_only update done
#   ______________[122/133] 1.  >> -075-05-025H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '30g325g35g375g40gG'
#   __________________pattern_only update done
#   ______________[123/133] 1.  >> +0+025+05+075H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[124/133] 1.  >> +025+05+075H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[125/133] 1.  >> -125-1-075-05-025+0H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05-025+0H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[126/133] 1.  >> -15-125-1-075-05H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[127/133] 1.  >> -425-4-375-35-325H // 425g45g475g50g525gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-425-4-375-35-325H'  and `end_gou_pattern` like '425g45g475g50g525gG'
#   __________________pattern_only update done
#   ______________[128/133] 1.  >> -125-1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[129/133] 1.  >> -05-025+0H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[130/133] 1.  >> +15+175+2+225+25H // 325g35g375g40g425gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+15+175+2+225+25H'  and `end_gou_pattern` like '325g35g375g40g425gG'
#   __________________pattern_only update done
#   ______________[131/133] 1.  >> -275-25-225-2-175H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-275-25-225-2-175H'  and `end_gou_pattern` like '30g325g35g375g40gG'
#   __________________pattern_only update done
#   ______________[132/133] 1.  >> -2-175-15-125H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-2-175-15-125H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[133/133] 1.  >> -025H // 25g30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 104  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025H'  and `end_gou_pattern` like '25g30g35gG'
#   __________________pattern_only update done
# # -------------------------------------------------- End at 2023-07-29 09:21:33
