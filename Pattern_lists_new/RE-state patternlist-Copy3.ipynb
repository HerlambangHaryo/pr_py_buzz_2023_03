# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:25:14
#   ____main__
#   ______Enter your leagueapi id :  129
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 6
#   ______________[1/6]  #129 - 2022 => 3 / 3 == Match Finished
#   ______________[2/6]  #129 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/6]  #129 - 2023 => 1 / 1 == Match Finished Ended
#   ______________[4/6]  #129 - 2023 => 3 / 1 == Match Finished Ended
#   ______________[5/6]  #129 - 2023 => 3 / 3 == Match Finished
#   ______________[6/6]  #129 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-29 07:25:39

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:25:39
#   __main()
#   ____Enter your leagueapi id :  129
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '129'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '129'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 2
#   __________[1/2] #1027754 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027754
#   ____________> pre_ah_pattern = +0+025+05H
#   ____________> pre_ah_pattern_mirror = -05-025+0H
#   ____________> pre_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[2/2] #1027756 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027756
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05H
#   ____________> pre_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '129'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '129'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 112
#   __________[1/112] #992529 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 992529
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[2/112] #1027583 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027583
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[3/112] #1027584 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027584
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[4/112] #1027585 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027585
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[5/112] #1027586 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027586
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[6/112] #1027587 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027587
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[7/112] #1027588 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027588
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[8/112] #1027589 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027589
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[9/112] #1027590 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027590
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[10/112] #1027591 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027591
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[11/112] #1027592 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027592
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[12/112] #1027593 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027593
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[13/112] #1027594 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027594
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[14/112] #1027595 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027595
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[15/112] #1027596 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027596
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[16/112] #1027597 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027597
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[17/112] #1027598 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027598
#   ____________> end_ah_pattern = +05+075+1H
#   ____________> end_ah_pattern_mirror = -1-075-05H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[18/112] #1027599 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027599
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[19/112] #1027600 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027600
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[20/112] #1027601 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027601
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[21/112] #1027602 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027602
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[22/112] #1027603 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027603
#   ____________> end_ah_pattern = -05-025H
#   ____________> end_ah_pattern_mirror = +025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[23/112] #1027604 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027604
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[24/112] #1027605 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027605
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[25/112] #1027606 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027606
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[26/112] #1027607 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027607
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[27/112] #1027736 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027736
#   ____________> end_ah_pattern = -125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[28/112] #1027737 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027737
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[29/112] #1027738 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027738
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[30/112] #1027739 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027739
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[31/112] #1027740 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027740
#   ____________> end_ah_pattern = -025+0H
#   ____________> end_ah_pattern_mirror = +0+025H
#   ____________> end_gou_pattern = 15g175gG
#   ____________> football_odds update pattern commited
#   __________[32/112] #1027741 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027741
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[33/112] #1027742 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027742
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[34/112] #1027743 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027743
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[35/112] #1027744 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027744
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[36/112] #1027754 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027754
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[37/112] #1027746 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027746
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[38/112] #1027749 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027749
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[39/112] #1027753 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027753
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[40/112] #1027750 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027750
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[41/112] #1027747 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027747
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[42/112] #1027745 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027745
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[43/112] #1027748 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027748
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[44/112] #1027752 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027752
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[45/112] #1027751 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027751
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[46/112] #1027755 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027755
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[47/112] #1027756 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027756
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[48/112] #1027757 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027757
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[49/112] #1027758 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027758
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[50/112] #1027759 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027759
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[51/112] #1027760 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027760
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[52/112] #1027761 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027761
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[53/112] #1027762 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027762
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[54/112] #1027765 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027765
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[55/112] #1027767 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027767
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[56/112] #1027770 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027770
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[57/112] #1027768 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027768
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[58/112] #1027771 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027771
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[59/112] #1027766 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027766
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[60/112] #1027763 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027763
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[61/112] #1027610 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027610
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[62/112] #1027611 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027611
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[63/112] #1027612 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027612
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[64/112] #1027613 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027613
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[65/112] #1027614 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027614
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[66/112] #1027615 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027615
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[67/112] #1027616 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027616
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[68/112] #1027617 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027617
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[69/112] #1027618 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027618
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[70/112] #1027772 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027772
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[71/112] #1027773 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027773
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[72/112] #1027774 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027774
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[73/112] #1027775 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027775
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[74/112] #1027776 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027776
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[75/112] #1027778 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027778
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[76/112] #1027779 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027779
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[77/112] #1027780 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027780
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[78/112] #1027619 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027619
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[79/112] #1027620 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027620
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[80/112] #1027621 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027621
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[81/112] #1027623 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027623
#   ____________> end_ah_pattern = -125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[82/112] #1027624 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027624
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[83/112] #1027625 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027625
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[84/112] #1027626 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027626
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[85/112] #1027627 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027627
#   ____________> end_ah_pattern = -05-025H
#   ____________> end_ah_pattern_mirror = +025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[86/112] #1027628 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027628
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[87/112] #1027629 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027629
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[88/112] #1027630 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027630
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[89/112] #1027631 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027631
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[90/112] #1027632 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027632
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[91/112] #1027633 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027633
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[92/112] #1027634 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027634
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[93/112] #1027635 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027635
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[94/112] #1027636 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027636
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[95/112] #1027781 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027781
#   ____________> end_ah_pattern = -15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[96/112] #1027782 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027782
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175gG
#   ____________> football_odds update pattern commited
#   __________[97/112] #1027783 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027783
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[98/112] #1027784 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027784
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[99/112] #1027785 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027785
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[100/112] #1027786 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027786
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[101/112] #1027787 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027787
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[102/112] #1027788 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027788
#   ____________> end_ah_pattern = -05-025H
#   ____________> end_ah_pattern_mirror = +025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[103/112] #1027789 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027789
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[104/112] #1027793 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027793
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[105/112] #1027791 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027791
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[106/112] #1027794 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027794
#   ____________> end_ah_pattern = +0+025H
#   ____________> end_ah_pattern_mirror = -025+0H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[107/112] #1027795 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027795
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[108/112] #1027796 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027796
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[109/112] #1027798 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027798
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[110/112] #1027792 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027792
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[111/112] #1027797 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027797
#   ____________> end_ah_pattern = +0+025H
#   ____________> end_ah_pattern_mirror = -025+0H
#   ____________> end_gou_pattern = 125g15g175gG
#   ____________> football_odds update pattern commited
#   __________[112/112] #1027790 #129 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1027790
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-29 07:44:44

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:44:44
#   ____main__
#   ______Enter your leagueapi id :  129
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 4
#   ______________[1/4]  #129 - 2022 => 3 / 3 == Match Finished
#   ______________[2/4]  #129 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/4]  #129 - 2023 => 3 / 3 == Match Finished
#   ______________[4/4]  #129 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-29 07:44:56

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:44:56
#   ____main__
#   ______Enter your leagueapi id :  129
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '129'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 73
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '73'  where leagueapi_id = '129'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/73] 4. -075-05-025H // 175g20g225gG >> -075-05-025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 20
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_from update done
#   ______________[2/73] 4. -025+0+025H // 15g175g20g225gG >> -025+0+025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 9
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[3/73] 4. -05-025+0H // 175g20g225gG >> -075-05-025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 9
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_from update done
#   ______________[4/73] 3. -075-05-025H // 175g20g225g25gG >> -075-05-025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 8
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_from update done
#   ______________[5/73] 3. -05-025+0H // 175g20g225gG >> -05-025+0H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 16
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_from update done
#   ______________[6/73] 3. -05-025+0H // 15g175g20g225gG >> -05-025+0H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 16
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[7/73] 3. -05-025+0H // 15g175g20g225gG >> -05-025+0H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_from update done
#   ______________[8/73] 2. -05-025+0H // 175g20g225g25gG >> -05-025+0H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_from update done
#   ______________[9/73] 2. -1-075-05H // 175g20g225gG >> -1-075-05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_from update done
#   ______________[10/73] 2. -075-05-025H // 15g175g20gG >> -075-05-025H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '15g175g20gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_from update done
#   ______________[11/73] 2. -075-05-025H // 15g175g20g225gG >> -05-025+0H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[12/73] 2. -075-05-025H // 15g175g20g225gG >> -05-025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[13/73] 2. -075-05-025H // 15g175g20g225gG >> -075-05-025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 8
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[14/73] 2. -025+0+025H // 15g175g20g225gG >> -025+0+025H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_from update done
#   ______________[15/73] 2. -05-025+0H // 175g20g225g25gG >> -05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[16/73] 2. -075-05-025H // 175g20g225g25gG >> -075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 13
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[17/73] 2. -025+0+025H // 175g20g225gG >> -025+0+025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[18/73] 2. -05-025+0H // 175g20g225gG >> -05-025+0H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 8
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[19/73] 2. -05-025+0H // 15g175g20gG >> -05-025+0H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 12
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '15g175g20gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_from update done
#   ______________[20/73] 1. -075-05-025H // 15g175g20gG >> -075-05-025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '15g175g20gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[21/73] 1. -075-05-025H // 15g175g20gG >> -05-025+0H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[22/73] 1. -05-025H // 175g20g225g25gG >> -05-025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[23/73] 1. -1-075-05-025H // 20g225g25gG >> -1-075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '20g225g25gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[24/73] 1. -05-025+0H // 175g20g225gG >> -05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[25/73] 1. -05-025+0H // 15g175gG >> -05-025+0H // 15g175gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[26/73] 1. -1-075-05H // 20g225g25g275gG >> -1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[27/73] 1. -1-075-05H // 20g225g25g275gG >> -125-1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[28/73] 1. -1-075-05H // 15g175g20gG >> -1-075-05H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '15g175g20gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_from update done
#   ______________[29/73] 1. -025+0+025H // 15g175g20g225gG >> +0+025+05H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[30/73] 1. -025+0H // 15g175gG >> -05-025+0H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-025+0H'  and `pre_gou_pattern` like '15g175gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_from update done
#   ______________[31/73] 1. -025+0H // 175g20g225gG >> -05-025+0H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[32/73] 1. -1-075-05H // 175g20g225gG >> -1-075-05H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[33/73] 1. -125-1-075H // 175g20g225g25gG >> -15-125-1-075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-125-1-075H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[34/73] 1. -075-05-025H // 175g20g225gG >> -075-05-025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 6
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[35/73] 1. -025+0+025H // 175g20g225g25gG >> -025+0+025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[36/73] 1. +0+025+05H // 20g225g25gG >> -025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[37/73] 1. -1-075-05H // 15g175g20g225gG >> -1-075-05H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[38/73] 1. -1-075-05H // 20g225g25gG >> -125-1-075-05H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '20g225g25gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_from update done
#   ______________[39/73] 1. -1-075-05H // 175g20g225gG >> -125-1-075H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-125-1-075H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[40/73] 1. -125-1-075-05H // 175g20g225g25gG >> -125-1-075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[41/73] 1. -025+0+025H // 15g175g20g225gG >> -05-025+0H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[42/73] 1. -025+0+025H // 20g225g25gG >> -05-025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '20g225g25gG'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[43/73] 1. -025+0+025H // 175g20g225g25gG >> -05-025+0H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_from update done
#   ______________[44/73] 1. -075-05-025+0H // 175g20g225g25gG >> -075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[45/73] 1. -125-1-075-05H // 175g20g225g25gG >> -125-1-075-05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-125-1-075-05H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[46/73] 1. -05-025+0H // 15g175g20gG >> -05-025+0H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '15g175g20gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[47/73] 1. -1-075-05-025H // 15g175g20g225gG >> -1-075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[48/73] 1. -075-05-025H // 175g20g225gG >> -075-05-025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_from update done
#   ______________[49/73] 1. -05-025+0H // 15g175g20g225gG >> -075-05-025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[50/73] 1. -025+0+025H // 15g175g20g225gG >> +0+025H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '+0+025H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_from update done
#   ______________[51/73] 1. -05-025+0H // 15g175g20gG >> -025+0H // 15g175gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '15g175g20gG'  and `end_ah_pattern` like '-025+0H'  and `end_gou_pattern` like '15g175gG'
#   __________________pattern_from update done
#   ______________[52/73] 1. -1-075-05-025H // 175g20g225g25gG >> -1-075-05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[53/73] 1. -075-05-025H // 175g20g225gG >> -075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[54/73] 1. -025+0+025+05H // 175g20g225g25gG >> -025+0+025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-025+0+025+05H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_from update done
#   ______________[55/73] 1. -075-05-025H // 15g175g20gG >> -125-1-075-05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '15g175g20gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[56/73] 1. -05-025+0H // 175g20g225gG >> -025+0+025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[57/73] 1. +0+025+05H // 15g175g20gG >> +0+025+05H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '+0+025+05H'  and `pre_gou_pattern` like '15g175g20gG'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_from update done
#   ______________[58/73] 1. -075-05-025H // 15g175g20g225gG >> -1-075-05H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[59/73] 1. -05-025H // 175g20g225gG >> -05-025+0H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[60/73] 1. +0+025H // 175g20g225gG >> +0+025+05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[61/73] 1. -05-025+0H // 175g20g225gG >> -025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[62/73] 1. -05-025+0H // 15g175g20g225gG >> -05-025+0H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_from update done
#   ______________[63/73] 1. +025+05H // 15g175g20g225gG >> +025+05+075H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[64/73] 1. -025+0+025H // 15g175g20gG >> +0+025H // 125g15g175gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[65/73] 1. -05-025+0H // 175g20g225g25gG >> -05-025+0H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[66/73] 1. -125-1-075-05H // 20g225g25gG >> -125-1-075-05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[67/73] 1. +05+075+1H // 175g20g225g25gG >> +05+075+1H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '+05+075+1H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '+05+075+1H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[68/73] 1. +0+025+05H // 175g20g225gG >> +0+025+05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '+0+025+05H'  and `pre_gou_pattern` like '175g20g225gG'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_from update done
#   ______________[69/73] 1. -1-075-05H // 20g225g25gG >> -1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[70/73] 1. -125-1-075-05H // 20g225g25gG >> -1-075-05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '-125-1-075-05H'  and `pre_gou_pattern` like '20g225g25gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[71/73] 1. -125-1-075-05H // 20g225g25g275gG >> -125-1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[72/73] 1. +0+025+05H // 15g175g20g225gG >> +025+05+075H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like '+0+025+05H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[73/73] 1. -15-125-1-075H // 175g20g225g25gG >> -15-125-1H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ________ff_get_fixtures_group_by_only_end_patternlists()
#   ____________Total Row(s) : 93
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_only_ends = '93'  where leagueapi_id = '129'
#   ________________> football_leagues : total_pattern_only_ends UPDATED
#   ______________[1/93] 71.  >> -075-05-025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 71
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
# ...
#   __________________pattern_only update done
#   ______________[70/93] 1.  >> +05+075+1H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[71/93] 1.  >> -1-075-05-025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_only update done
#   ______________[72/93] 1.  >> -05H // 15g175gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05H'  and `end_gou_pattern` like '15g175gG'
#   __________________pattern_only update done
#   ______________[73/93] 1.  >> +025+05+075H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[74/93] 1.  >> +05+075+1+125H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1+125H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[75/93] 1.  >> -025H // 15g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025H'  and `end_gou_pattern` like '15g20gG'
#   __________________pattern_only update done
#   ______________[76/93] 1.  >> -025+0+025+05H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[77/93] 1.  >> -025H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_only update done
#   ______________[78/93] 1.  >> -025+0+025+05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_only update done
#   ______________[79/93] 1.  >> -125-1-075-05H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[80/93] 1.  >> +05+075+1H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[81/93] 1.  >> +1+125+15H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+1+125+15H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_only update done
#   ______________[82/93] 1.  >> -075-05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[83/93] 1.  >> -05-025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[84/93] 1.  >> -125-1-075H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[85/93] 1.  >> -15-125-1-075H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[86/93] 1.  >> -125-1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[87/93] 1.  >> +0H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_only update done
#   ______________[88/93] 1.  >> -15-125-1-075H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[89/93] 1.  >> -025+0H // 15g175gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0H'  and `end_gou_pattern` like '15g175gG'
#   __________________pattern_only update done
#   ______________[90/93] 1.  >> +025+05+075H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[91/93] 1.  >> -125-1-075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[92/93] 1.  >> -075-05H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_only update done
#   ______________[93/93] 1.  >> -075-05-025H // 15g175gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 129  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '15g175gG'
#   __________________pattern_only update done
# # -------------------------------------------------- End at 2023-07-30 11:47:56
