#323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953934
#   ____________> pre_ah_pattern = +025+05+075H
#   ____________> pre_ah_pattern_mirror = -075-05-025H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[101/117] #953935 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953935
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[102/117] #953936 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953936
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[103/117] #953937 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953937
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[104/117] #953938 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953938
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[105/117] #953939 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953939
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[106/117] #953942 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953942
#   ____________> pre_ah_pattern = -125-1-075-05H
#   ____________> pre_ah_pattern_mirror = +05+075+1+125H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[107/117] #953940 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953940
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[108/117] #953941 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953941
#   ____________> pre_ah_pattern = -2-175-15-125H
#   ____________> pre_ah_pattern_mirror = +125+15+175+2H
#   ____________> pre_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[109/117] #953943 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953943
#   ____________> pre_ah_pattern = +05+075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075-05H
#   ____________> pre_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[110/117] #953944 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953944
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[111/117] #1011100 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1011100
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[112/117] #1011101 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1011101
#   ____________> pre_ah_pattern = -1-075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075+1H
#   ____________> pre_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[113/117] #1012085 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1012085
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[114/117] #1012132 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1012132
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[115/117] #1012086 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1012086
#   ____________> pre_ah_pattern = +0+025+05+075H
#   ____________> pre_ah_pattern_mirror = -075-05-025+0H
#   ____________> pre_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[116/117] #1012133 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1012133
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+05H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[117/117] #1014792 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1014792
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '323'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '323'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 117
#   __________[1/117] #953907 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953907
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[2/117] #953908 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953908
#   ____________> end_ah_pattern = +0+025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025+0H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[3/117] #953909 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953909
#   ____________> end_ah_pattern = +075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[4/117] #953912 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953912
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[5/117] #953910 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953910
#   ____________> end_ah_pattern = -325-3-275-25-225H
#   ____________> end_ah_pattern_mirror = +225+25+275+3+325H
#   ____________> end_gou_pattern = 35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[6/117] #953911 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953911
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[7/117] #953913 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953913
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[8/117] #953914 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953914
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[9/117] #953915 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953915
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175+2H
#   ____________> end_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[10/117] #953916 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953916
#   ____________> end_ah_pattern = +075+1+125+15+175H
#   ____________> end_ah_pattern_mirror = -175-15-125-1-075H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[11/117] #953917 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953917
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[12/117] #953918 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953918
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[13/117] #953919 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953919
#   ____________> end_ah_pattern = -275-25-225-2-175H
#   ____________> end_ah_pattern_mirror = +175+2+225+25+275H
#   ____________> end_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[14/117] #953920 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953920
#   ____________> end_ah_pattern = -075-05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05+075H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[15/117] #953921 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953921
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[16/117] #953922 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953922
#   ____________> end_ah_pattern = -125-1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1+125H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[17/117] #953923 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953923
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[18/117] #953924 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953924
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[19/117] #953925 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953925
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[20/117] #953926 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953926
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[21/117] #953927 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953927
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[22/117] #953928 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953928
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[23/117] #953929 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953929
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[24/117] #953930 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953930
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[25/117] #953931 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953931
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[26/117] #953932 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953932
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[27/117] #953933 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953933
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[28/117] #953934 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953934
#   ____________> end_ah_pattern = +0+025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025+0H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[29/117] #953935 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953935
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[30/117] #953936 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953936
#   ____________> end_ah_pattern = +075+1+125+15+175H
#   ____________> end_ah_pattern_mirror = -175-15-125-1-075H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[31/117] #953939 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953939
#   ____________> end_ah_pattern = -25-225-2-175H
#   ____________> end_ah_pattern_mirror = +175+2+225+25H
#   ____________> end_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[32/117] #953942 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953942
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[33/117] #953940 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953940
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[34/117] #953941 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953941
#   ____________> end_ah_pattern = -2-175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175+2H
#   ____________> end_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[35/117] #953943 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953943
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[36/117] #953944 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953944
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[37/117] #1011100 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1011100
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[38/117] #1011101 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1011101
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[39/117] #1012085 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1012085
#   ____________> end_ah_pattern = -15-125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[40/117] #1012132 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1012132
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[41/117] #1012086 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1012086
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
# ...
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[62/117] #953854 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953854
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[63/117] #953855 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953855
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[64/117] #953856 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953856
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[65/117] #953857 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953857
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[66/117] #953858 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953858
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[67/117] #953859 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953859
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[68/117] #953862 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953862
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[69/117] #953860 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953860
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[70/117] #953861 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953861
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[71/117] #953863 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953863
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[72/117] #953864 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953864
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[73/117] #953865 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953865
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[74/117] #953866 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953866
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[75/117] #953867 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953867
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[76/117] #953868 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953868
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[77/117] #953869 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953869
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[78/117] #953870 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953870
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[79/117] #953871 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953871
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[80/117] #953872 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953872
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[81/117] #953873 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953873
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[82/117] #953874 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953874
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[83/117] #953875 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953875
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[84/117] #953876 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953876
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[85/117] #953877 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953877
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[86/117] #953878 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953878
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[87/117] #953879 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953879
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[88/117] #953880 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953880
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[89/117] #953881 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953881
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[90/117] #953882 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953882
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[91/117] #953883 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953883
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[92/117] #953884 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953884
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[93/117] #953885 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953885
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[94/117] #953886 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953886
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[95/117] #953887 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953887
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[96/117] #953888 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953888
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[97/117] #953889 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953889
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[98/117] #953890 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953890
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[99/117] #953891 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953891
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[100/117] #953892 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953892
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[101/117] #953893 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953893
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[102/117] #953894 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953894
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[103/117] #953895 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953895
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[104/117] #953896 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953896
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[105/117] #953897 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953897
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[106/117] #953898 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953898
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[107/117] #953899 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953899
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[108/117] #953900 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953900
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[109/117] #953901 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953901
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[110/117] #953902 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953902
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[111/117] #953903 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953903
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[112/117] #953904 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953904
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[113/117] #953905 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953905
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[114/117] #953906 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953906
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[115/117] #953937 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953937
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[116/117] #953938 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 953938
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[117/117] #1014792 #323 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1014792
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-23 01:43:54

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-23 01:43:54
#   ____main__
#   ______Enter your leagueapi id :  323
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 1
#   ______________[1/1]  #323 - 2022 => 3 / 3 == Match Finished
# # -------------------------------------------------- End at 2023-07-23 04:35:29

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-23 04:35:29
#   ____main__
#   ______Enter your leagueapi id :  323
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '323'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 28
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '28'  where leagueapi_id = '323'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/28] 1. -1-075-05-025H // 25g275g30g325gG >> -075-05-025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:535, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     534         query = query.encode('utf-8')
# --> 535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Lock wait timeout exceeded; try restarting transaction
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [5], in <cell line: 12>()
#      22 leagueapi_id   = input(space + "Enter your leagueapi id :  ")
#      23 # ----------------------------------------------------------
# ---> 24 ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
#      25 ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
#      26 # ----------------------------------------------------------
#
# File ~\AryaDataAnalyst\pr_py_buzz_2023_03\Pattern_lists_new\..\a_models\football_fixtures.py:104, in ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
#     102 print(word, flush=True)
#     103 # ------------------------------------------------------
# --> 104 aP_controll_pattern_ROUTE('from', leagueapi_id, pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern, space)
#
# File ~\AryaDataAnalyst\pr_py_buzz_2023_03\Pattern_lists_new\..\a_models\assessment_pattern.py:153, in aP_controll_pattern_ROUTE(TABLE, leagueapi_id, pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern, space)
#     151 # ----------------------------------------------------------
#     152 aP_check_patternlist(TABLE, leagueapi_id, pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern, space)
# --> 153 aP_final_assestment(query, TABLE, total_rows,
#     154     leagueapi_id, pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern, space)
#
# File ~\AryaDataAnalyst\pr_py_buzz_2023_03\Pattern_lists_new\..\a_models\assessment_pattern.py:4948, in aP_final_assestment(PRE_result, TABLE, PRE_total_rows, leagueapi_id, pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern, space)
#    4940 # ----------------------------------------------------------
#    4941 if(SUM_match_winner_home is not None and
#    4942     SUM_match_winner_draw is not None and
#    4943     SUM_match_winner_away is not None
#    (...)
#    4946     # print(space + query_update, flush=True)
#    4947     # ------------------------------------------------------
# -> 4948     mycursor.execute(query_update)
#    4949     mydb.commit()
#    4950     # close the cursor and database connection
#
# File ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py:269, in CMySQLCursor.execute(self, operation, params, multi)
#     265             raise errors.ProgrammingError(
#     266                 "Not all parameters were used in the SQL statement")
#     268 try:
# --> 269     result = self._cnx.cmd_query(stmt, raw=self._raw,
#     270                                  buffered=self._buffered,
#     271                                  raw_as_string=self._raw_as_string)
#     272 except MySQLInterfaceError as exc:
#     273     raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#     274                                      sqlstate=exc.sqlstate)
#
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:540, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
# --> 540     raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     541                                      sqlstate=exc.sqlstate)
#     542 except AttributeError:
#     543     if self._unix_socket:
#
# DatabaseError: 1205 (HY000): Lock wait timeout exceeded; try restarting transaction
