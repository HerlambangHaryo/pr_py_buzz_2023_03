# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-22 23:52:15
#   ____main__
#   ______Enter your leagueapi id :  165
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 13
#   ______________[1/13]  #165 - 2022 => 0 / None == Match Finished
#   ______________[2/13]  #165 - 2022 => 0 / None == Match Finished Ended
#   ______________[3/13]  #165 - 2022 => 0 / 3 == Match Finished
#   ______________[4/13]  #165 - 2022 => 2 / None == Match Finished
#   ______________[5/13]  #165 - 2023 => 0 / 2 == Match Finished
#   ______________[6/13]  #165 - 2023 => 0 / 2 == Match Finished Ended
#   ______________[7/13]  #165 - 2023 => 1 / 1 == Match Finished Ended
#   ______________[8/13]  #165 - 2023 => 2 / 1 == Match Finished Ended
#   ______________[9/13]  #165 - 2023 => 2 / 2 == Match Finished
#   ______________[10/13]  #165 - 2023 => 2 / 2 == Match Finished Ended
#   ______________[11/13]  #165 - 2023 => 3 / None == Match Finished
#   ______________[12/13]  #165 - 2023 => 3 / 1 == Match Finished
#   ______________[13/13]  #165 - 2023 => 3 / 1 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-22 23:55:07

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-22 23:55:07
#   __main()
#   ____Enter your leagueapi id :  165
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '165'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '165'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 168
#   __________[1/168] #822302 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822302
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[2/168] #822303 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822303
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[3/168] #822304 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822304
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[4/168] #822305 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822305
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[5/168] #822306 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822306
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[6/168] #822307 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822307
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[7/168] #822309 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822309
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[8/168] #822310 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822310
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[9/168] #822308 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822308
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[10/168] #822311 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822311
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[11/168] #822312 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822312
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[12/168] #822373 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822373
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[13/168] #822314 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822314
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[14/168] #822315 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822315
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[15/168] #822316 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822316
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[16/168] #822317 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822317
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[17/168] #822318 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822318
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[18/168] #822319 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822319
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[19/168] #822320 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822320
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[20/168] #822322 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822322
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[21/168] #822324 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822324
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[22/168] #822321 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822321
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[23/168] #822325 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822325
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[24/168] #822387 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822387
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[25/168] #822326 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822326
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[26/168] #822327 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822327
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[27/168] #822328 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822328
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[28/168] #822330 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822330
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 30g325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[29/168] #822331 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822331
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[30/168] #822332 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822332
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[31/168] #822334 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822334
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[32/168] #822335 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822335
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[33/168] #822336 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822336
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[34/168] #822337 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822337
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[35/168] #822338 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822338
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[36/168] #822339 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822339
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[37/168] #822340 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822340
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[38/168] #822341 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822341
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[39/168] #822342 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822342
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[40/168] #822343 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822343
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[41/168] #822347 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822347
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[42/168] #822344 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822344
#   ____________> pre_ah_pattern = +0+025+075H
#   ____________> pre_ah_pattern_mirror = -075-025+0H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[43/168] #822345 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822345
#   ____________> pre_ah_pattern = -075-025H
#   ____________> pre_ah_pattern_mirror = +025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[44/168] #822346 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822346
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[45/168] #822348 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822348
#   ____________> pre_ah_pattern = +0+025H
#   ____________> pre_ah_pattern_mirror = -025+0H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[46/168] #822349 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822349
#   ____________> pre_ah_pattern = -075-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+075H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[47/168] #822333 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822333
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = +1+125+15+175H
#   ____________> pre_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[48/168] #822350 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822350
#   ____________> pre_ah_pattern = -125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[49/168] #822354 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822354
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[50/168] #822351 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822351
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[51/168] #822352 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822352
#   ____________> pre_ah_pattern = -075-025H
#   ____________> pre_ah_pattern_mirror = +025+075H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[52/168] #822355 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822355
#   ____________> pre_ah_pattern = -075-025H
#   ____________> pre_ah_pattern_mirror = +025+075H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[53/168] #822353 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822353
#   ____________> pre_ah_pattern = -125-1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1+125H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[54/168] #822356 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822356
#   ____________> pre_ah_pattern = -125-1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1+125H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[55/168] #822360 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822360
#   ____________> pre_ah_pattern = -075-025H
#   ____________> pre_ah_pattern_mirror = +025+075H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[56/168] #822357 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822357
#   ____________> pre_ah_pattern = -125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[57/168] #822358 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822358
#   ____________> pre_ah_pattern = +025+075H
#   ____________> pre_ah_pattern_mirror = -075-025H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[58/168] #822359 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822359
#   ____________> pre_ah_pattern = +125+15+175H
#   ____________> pre_ah_pattern_mirror = -175-15-125H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[59/168] #822361 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822361
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[60/168] #822362 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822362
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[61/168] #822363 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822363
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = +1+125+15+175H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[62/168] #822364 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822364
#   ____________> pre_ah_pattern = -125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[63/168] #822365 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822365
#   ____________> pre_ah_pattern = +025+075H
#   ____________> pre_ah_pattern_mirror = -075-025H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[64/168] #822366 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822366
#   ____________> pre_ah_pattern = +025+075H
#   ____________> pre_ah_pattern_mirror = -075-025H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[65/168] #822367 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822367
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[66/168] #822368 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822368
#   ____________> pre_ah_pattern = +075+1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1-075H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[67/168] #822369 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822369
#   ____________> pre_ah_pattern = -1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[68/168] #822370 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822370
#   ____________> pre_ah_pattern = -125-1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1+125H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[69/168] #822372 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822372
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = +1+125+15+175H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[70/168] #822371 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822371
#   ____________> pre_ah_pattern = +0+025H
#   ____________> pre_ah_pattern_mirror = -025+0H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[71/168] #822313 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822313
#   ____________> pre_ah_pattern = -075-025H
#   ____________> pre_ah_pattern_mirror = +025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[72/168] #822329 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822329
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[73/168] #822374 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822374
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = +1+125+15+175H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[74/168] #822375 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822375
#   ____________> pre_ah_pattern = +075+1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1-075H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[75/168] #822376 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822376
#   ____________> pre_ah_pattern = -075-025H
#   ____________> pre_ah_pattern_mirror = +025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[76/168] #822377 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822377
#   ____________> pre_ah_pattern = +0+025+075H
#   ____________> pre_ah_pattern_mirror = -075-025+0H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[77/168] #822378 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822378
#   ____________> pre_ah_pattern = -125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[78/168] #822379 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822379
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[79/168] #822380 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822380
#   ____________> pre_ah_pattern = +0+025H
#   ____________> pre_ah_pattern_mirror = -025+0H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[80/168] #822381 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822381
#   ____________> pre_ah_pattern = +025+075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075-025H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[81/168] #822382 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822382
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[82/168] #822383 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822383
#   ____________> pre_ah_pattern = -075-025H
#   ____________> pre_ah_pattern_mirror = +025+075H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[83/168] #822384 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822384
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[84/168] #822385 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822385
#   ____________> pre_ah_pattern = -225-2-175-15-125H
#   ____________> pre_ah_pattern_mirror = +125+15+175+2+225H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[85/168] #822386 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822386
#   ____________> pre_ah_pattern = +075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[86/168] #822323 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822323
#   ____________> pre_ah_pattern = +025+075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075-025H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[87/168] #822388 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822388
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[88/168] #822389 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822389
#   ____________> pre_ah_pattern = +025+075H
#   ____________> pre_ah_pattern_mirror = -075-025H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[89/168] #822390 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822390
#   ____________> pre_ah_pattern = -175-15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[90/168] #822391 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822391
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[91/168] #822392 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822392
#   ____________> pre_ah_pattern = -075-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+075H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[92/168] #822396 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822396
#   ____________> pre_ah_pattern = -275-25-225-2-175-15H
#   ____________> pre_ah_pattern_mirror = +15+175+2+225+25+275H
#   ____________> pre_gou_pattern = 325g35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[93/168] #822393 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822393
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[94/168] #822394 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822394
#   ____________> pre_ah_pattern = +075+1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1-075H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[95/168] #822397 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822397
#   ____________> pre_ah_pattern = +025+075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075-025H
#   ____________> pre_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[96/168] #822395 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822395
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[97/168] #822399 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822399
#   ____________> pre_ah_pattern = +025+075+1H
#   ____________> pre_ah_pattern_mirror = -1-075-025H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[98/168] #822398 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822398
#   ____________> pre_ah_pattern = +075+1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1-075H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[99/168] #822400 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822400
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[100/168] #822402 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822402
#   ____________> pre_ah_pattern = -075-025H
#   ____________> pre_ah_pattern_mirror = +025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[101/168] #822401 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822401
#   ____________> pre_ah_pattern = -175-15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[102/168] #822403 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822403
#   ____________> pre_ah_pattern = -2-175-15-125H
#   ____________> pre_ah_pattern_mirror = +125+15+175+2H
#   ____________> pre_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[103/168] #822404 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822404
#   ____________> pre_ah_pattern = +0+025+075H
#   ____________> pre_ah_pattern_mirror = -075-025+0H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[104/168] #822405 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822405
#   ____________> pre_ah_pattern = +025+075+1H
#   ____________> pre_ah_pattern_mirror = -1-075-025H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[105/168] #822407 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822407
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[106/168] #822406 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822406
#   ____________> pre_ah_pattern = -125-1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1+125H
#   ____________> pre_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[107/168] #822408 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822408
#   ____________> pre_ah_pattern = -25-225-2-175-15H
#   ____________> pre_ah_pattern_mirror = +15+175+2+225+25H
#   ____________> pre_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[108/168] #822409 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822409
#   ____________> pre_ah_pattern = -075-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[109/168] #822410 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822410
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[110/168] #822411 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822411
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[111/168] #822412 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822412
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[112/168] #822413 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822413
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[113/168] #822414 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822414
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[114/168] #822415 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822415
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[115/168] #822416 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822416
#   ____________> pre_ah_pattern = -075-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[116/168] #822417 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822417
#   ____________> pre_ah_pattern = +025+075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075-025H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[117/168] #822418 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822418
#   ____________> pre_ah_pattern = -125-1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1+125H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[118/168] #822420 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822420
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[119/168] #822421 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822421
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[120/168] #822419 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822419
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[121/168] #822422 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822422
#   ____________> pre_ah_pattern = -125-1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1+125H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[122/168] #822423 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822423
#   ____________> pre_ah_pattern = -075-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[123/168] #822424 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822424
#   ____________> pre_ah_pattern = -075-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+075H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[124/168] #822425 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822425
#   ____________> pre_ah_pattern = -375-35-325-3-275-25H
#   ____________> pre_ah_pattern_mirror = +25+275+3+325+35+375H
#   ____________> pre_gou_pattern = 375g40g425g45g475gG
#   ____________> football_odds update pattern commited
#   __________[125/168] #822426 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822426
#   ____________> pre_ah_pattern = +025+075+1H
#   ____________> pre_ah_pattern_mirror = -1-075-025H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[126/168] #822427 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822427
#   ____________> pre_ah_pattern = +0+025+075H
#   ____________> pre_ah_pattern_mirror = -075-025+0H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[127/168] #822428 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822428
#   ____________> pre_ah_pattern = +125+15+175+2+225H
#   ____________> pre_ah_pattern_mirror = -225-2-175-15-125H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[128/168] #822429 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822429
#   ____________> pre_ah_pattern = -025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025H
#   ____________> pre_gou_pattern = 325g35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[129/168] #822430 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822430
#   ____________> pre_ah_pattern = -1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[130/168] #822431 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822431
#   ____________> pre_ah_pattern = -075-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+075H
#   ____________> pre_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[131/168] #822432 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822432
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[132/168] #822433 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822433
#   ____________> pre_ah_pattern = +075+1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1-075H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[133/168] #985381 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985381
#   ____________> pre_ah_pattern = -075-025H
#   ____________> pre_ah_pattern_mirror = +025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[134/168] #985377 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985377
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[135/168] #985378 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985378
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[136/168] #985379 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985379
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[137/168] #985380 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985380
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[138/168] #985382 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985382
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[139/168] #985383 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985383
#   ____________> pre_ah_pattern = -2-175-15-125H
#   ____________> pre_ah_pattern_mirror = +125+15+175+2H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[140/168] #985384 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985384
#   ____________> pre_ah_pattern = -125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[141/168] #985385 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985385
#   ____________> pre_ah_pattern = -075-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+075H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[142/168] #985386 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985386
#   ____________> pre_ah_pattern = -125-1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1+125H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[143/168] #985387 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985387
#   ____________> pre_ah_pattern = -1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[144/168] #985388 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985388
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[145/168] #985389 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985389
#   ____________> pre_ah_pattern = -075-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[146/168] #985390 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985390
#   ____________> pre_ah_pattern = -125-1-075-025H
#   ____________> pre_ah_pattern_mirror = +025+075+1+125H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[147/168] #985391 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985391
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[148/168] #985392 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985392
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[149/168] #985393 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985393
#   ____________> pre_ah_pattern = -075-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[150/168] #985394 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985394
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[151/168] #985395 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985395
#   ____________> pre_ah_pattern = -075-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+075H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[152/168] #985396 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985396
#   ____________> pre_ah_pattern = +0+025+075H
#   ____________> pre_ah_pattern_mirror = -075-025+0H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[153/168] #985397 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985397
#   ____________> pre_ah_pattern = -075-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[154/168] #985399 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985399
#   ____________> pre_ah_pattern = -075-025H
#   ____________> pre_ah_pattern_mirror = +025+075H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[155/168] #985400 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985400
#   ____________> pre_ah_pattern = +0+025H
#   ____________> pre_ah_pattern_mirror = -025+0H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
# ...
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[149/199] #822381 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822381
#   ____________> end_ah_pattern = +025+075H
#   ____________> end_ah_pattern_mirror = -075-025H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[150/199] #822382 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822382
#   ____________> end_ah_pattern = +0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0H
#   ____________> end_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[151/199] #822383 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822383
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[152/199] #822384 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822384
#   ____________> end_ah_pattern = -175-15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> end_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[153/199] #822385 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822385
#   ____________> end_ah_pattern = -225-2-175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175+2+225H
#   ____________> end_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[154/199] #822386 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822386
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[155/199] #822323 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822323
#   ____________> end_ah_pattern = +0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[156/199] #822388 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822388
#   ____________> end_ah_pattern = -075-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+075H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[157/199] #822389 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822389
#   ____________> end_ah_pattern = +0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[158/199] #822390 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822390
#   ____________> end_ah_pattern = -175-15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15+175H
#   ____________> end_gou_pattern = 325g35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[159/199] #822391 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822391
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[160/199] #822392 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822392
#   ____________> end_ah_pattern = -075-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+075H
#   ____________> end_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[161/199] #822396 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822396
#   ____________> end_ah_pattern = -3-275-25-225-2-175H
#   ____________> end_ah_pattern_mirror = +175+2+225+25+275+3H
#   ____________> end_gou_pattern = 325g35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[162/199] #822393 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822393
#   ____________> end_ah_pattern = -025+0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0+025H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[163/199] #822394 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822394
#   ____________> end_ah_pattern = +075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[164/199] #822397 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822397
#   ____________> end_ah_pattern = +025+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-025H
#   ____________> end_gou_pattern = 325g35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[165/199] #822395 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822395
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[166/199] #822399 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822399
#   ____________> end_ah_pattern = +025+075H
#   ____________> end_ah_pattern_mirror = -075-025H
#   ____________> end_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[167/199] #822398 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822398
#   ____________> end_ah_pattern = +075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[168/199] #822400 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822400
#   ____________> end_ah_pattern = -175-15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> end_gou_pattern = 325g35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[169/199] #822402 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822402
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[170/199] #822401 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822401
#   ____________> end_ah_pattern = -175-15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> end_gou_pattern = 325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[171/199] #822403 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822403
#   ____________> end_ah_pattern = -25-225-2-175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175+2+225+25H
#   ____________> end_gou_pattern = 35g375g40g425g45g475gG
#   ____________> football_odds update pattern commited
#   __________[172/199] #822404 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822404
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[173/199] #822405 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822405
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[174/199] #822407 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822407
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[175/199] #822406 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822406
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[176/199] #822408 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822408
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[177/199] #822409 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822409
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[178/199] #822410 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822410
#   ____________> end_ah_pattern = -2-175-15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15+175+2H
#   ____________> end_gou_pattern = 325g35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[179/199] #822411 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822411
#   ____________> end_ah_pattern = -075-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+075H
#   ____________> end_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[180/199] #822412 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822412
#   ____________> end_ah_pattern = -175-15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> end_gou_pattern = 325g35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[181/199] #822413 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822413
#   ____________> end_ah_pattern = +0+025H
#   ____________> end_ah_pattern_mirror = -025+0H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[182/199] #822414 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822414
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[183/199] #822415 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822415
#   ____________> end_ah_pattern = +0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0H
#   ____________> end_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[184/199] #822416 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822416
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[185/199] #822417 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822417
#   ____________> end_ah_pattern = +0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0H
#   ____________> end_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[186/199] #822418 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822418
#   ____________> end_ah_pattern = -075-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+075H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[187/199] #822420 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822420
#   ____________> end_ah_pattern = +0+075H
#   ____________> end_ah_pattern_mirror = -075+0H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[188/199] #822421 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822421
#   ____________> end_ah_pattern = -075-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+075H
#   ____________> end_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[189/199] #822419 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822419
#   ____________> end_ah_pattern = +025+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-025H
#   ____________> end_gou_pattern = 25g275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[190/199] #822428 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822428
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[191/199] #822429 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822429
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[192/199] #822430 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822430
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[193/199] #822431 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822431
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[194/199] #822432 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822432
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[195/199] #822433 #165 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 822433
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[196/199] #985450 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985450
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[197/199] #985451 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985451
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[198/199] #985452 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985452
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[199/199] #985453 #165 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 985453
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-23 02:43:50

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-23 02:43:50
#   ____main__
#   ______Enter your leagueapi id :  165
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 4
#   ______________[1/4]  #165 - 2022 => 3 / 3 == Match Finished
#   ______________[2/4]  #165 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/4]  #165 - 2023 => 3 / 3 == Match Finished
#   ______________[4/4]  #165 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-23 04:32:48

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-23 04:32:48
#   ____main__
#   ______Enter your leagueapi id :  165
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '165'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 115
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '115'  where leagueapi_id = '165'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/115] 3. -025+0+025H // 275g30g325g35g375gG >> -025+0+025H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 165  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '275g30g325g35g375gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_from update done
#   ______________[2/115] 2. -025+0+025H // 275g30g325g35g375gG >> -025+0+025H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 165  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '275g30g325g35g375gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_from update done
#   ______________[3/115] 2. -15-125-1-075H // 275g30g325g35g375gG >> -15-125-1-075H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 165  and `pre_ah_pattern` like '-15-125-1-075H'  and `pre_gou_pattern` like '275g30g325g35g375gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_from update done
#   ______________[4/115] 2. -075-025H // 275g30g325g35g375gG >> -075-025+0H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:535, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     534         query = query.encode('utf-8')
# --> 535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Lock wait timeout exceeded; try restarting transaction
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [5], in <cell line: 12>()
#      22 leagueapi_id   = input(space + "Enter your leagueapi id :  ")
#      23 # ----------------------------------------------------------
# ---> 24 ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
#      25 ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
#      26 # ----------------------------------------------------------
#
# File ~\AryaDataAnalyst\pr_py_buzz_2023_03\Pattern_lists_new\..\a_models\football_fixtures.py:104, in ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
#     102 print(word, flush=True)
#     103 # ------------------------------------------------------
# --> 104 aP_controll_pattern_ROUTE('from', leagueapi_id, pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern, space)
#
# File ~\AryaDataAnalyst\pr_py_buzz_2023_03\Pattern_lists_new\..\a_models\assessment_pattern.py:153, in aP_controll_pattern_ROUTE(TABLE, leagueapi_id, pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern, space)
#     151 # ----------------------------------------------------------
#     152 aP_check_patternlist(TABLE, leagueapi_id, pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern, space)
# --> 153 aP_final_assestment(query, TABLE, total_rows,
#     154     leagueapi_id, pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern, space)
#
# File ~\AryaDataAnalyst\pr_py_buzz_2023_03\Pattern_lists_new\..\a_models\assessment_pattern.py:4948, in aP_final_assestment(PRE_result, TABLE, PRE_total_rows, leagueapi_id, pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern, space)
#    4940 # ----------------------------------------------------------
#    4941 if(SUM_match_winner_home is not None and
#    4942     SUM_match_winner_draw is not None and
#    4943     SUM_match_winner_away is not None
#    (...)
#    4946     # print(space + query_update, flush=True)
#    4947     # ------------------------------------------------------
# -> 4948     mycursor.execute(query_update)
#    4949     mydb.commit()
#    4950     # close the cursor and database connection
#
# File ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py:269, in CMySQLCursor.execute(self, operation, params, multi)
#     265             raise errors.ProgrammingError(
#     266                 "Not all parameters were used in the SQL statement")
#     268 try:
# --> 269     result = self._cnx.cmd_query(stmt, raw=self._raw,
#     270                                  buffered=self._buffered,
#     271                                  raw_as_string=self._raw_as_string)
#     272 except MySQLInterfaceError as exc:
#     273     raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#     274                                      sqlstate=exc.sqlstate)
#
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:540, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
# --> 540     raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     541                                      sqlstate=exc.sqlstate)
#     542 except AttributeError:
#     543     if self._unix_socket:
#
# DatabaseError: 1205 (HY000): Lock wait timeout exceeded; try restarting transaction
