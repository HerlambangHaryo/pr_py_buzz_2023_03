# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 06:37:16
#   ____main__
#   ______Enter your leagueapi id :  814
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 5
#   ______________[1/5]  #814 - 2023 => 0 / None == Match Finished
#   ______________[2/5]  #814 - 2023 => 0 / None == Match Finished Ended
#   ______________[3/5]  #814 - 2023 => 0 / 2 == Match Finished
#   ______________[4/5]  #814 - 2023 => 2 / 2 == Match Finished
#   ______________[5/5]  #814 - 2023 => 2 / 2 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-27 06:50:20

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 06:50:20
#   __main()
#   ____Enter your leagueapi id :  814
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '814'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '814'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 12
#   __________[1/12] #975331 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975331
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[2/12] #975332 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975332
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[3/12] #975330 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975330
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[4/12] #975329 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975329
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[5/12] #975333 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975333
#   ____________> pre_ah_pattern = +175H
#   ____________> pre_ah_pattern_mirror = -175H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[6/12] #975335 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975335
#   ____________> pre_ah_pattern = -15-125-1H
#   ____________> pre_ah_pattern_mirror = +1+125+15H
#   ____________> pre_gou_pattern = 35g375gG
#   ____________> football_odds update pattern commited
#   __________[7/12] #975336 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975336
#   ____________> pre_ah_pattern = -275-25-225H
#   ____________> pre_ah_pattern_mirror = +225+25+275H
#   ____________> pre_gou_pattern = 40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[8/12] #975334 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975334
#   ____________> pre_ah_pattern = -175-15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[9/12] #975340 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975340
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[10/12] #975339 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975339
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[11/12] #975337 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975337
#   ____________> pre_ah_pattern = +025+075+1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1-075-025H
#   ____________> pre_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[12/12] #975338 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975338
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '814'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '814'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 12
#   __________[1/12] #975331 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975331
#   ____________> end_ah_pattern = -275-25-225-2-175H
#   ____________> end_ah_pattern_mirror = +175+2+225+25+275H
#   ____________> end_gou_pattern = 35g375g40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[2/12] #975332 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975332
#   ____________> end_ah_pattern = +125+15+175+2+225+25H
#   ____________> end_ah_pattern_mirror = -25-225-2-175-15-125H
#   ____________> end_gou_pattern = 40g425g45g475g50g525gG
#   ____________> football_odds update pattern commited
#   __________[3/12] #975330 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975330
#   ____________> end_ah_pattern = +125H
#   ____________> end_ah_pattern_mirror = -125H
#   ____________> end_gou_pattern = 35g45gG
#   ____________> football_odds update pattern commited
#   __________[4/12] #975329 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975329
#   ____________> end_ah_pattern = -3H
#   ____________> end_ah_pattern_mirror = +3H
#   ____________> end_gou_pattern = 45gG
#   ____________> football_odds update pattern commited
#   __________[5/12] #975333 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975333
#   ____________> end_ah_pattern = +175H
#   ____________> end_ah_pattern_mirror = -175H
#   ____________> end_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[6/12] #975335 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975335
#   ____________> end_ah_pattern = -15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15H
#   ____________> end_gou_pattern = 35g375gG
#   ____________> football_odds update pattern commited
#   __________[7/12] #975336 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975336
#   ____________> end_ah_pattern = -275-25-225H
#   ____________> end_ah_pattern_mirror = +225+25+275H
#   ____________> end_gou_pattern = 40g425g45gG
#   ____________> football_odds update pattern commited
#   __________[8/12] #975334 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975334
#   ____________> end_ah_pattern = -175-15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> end_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[9/12] #975339 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975339
#   ____________> end_ah_pattern = +0+025H
#   ____________> end_ah_pattern_mirror = -025+0H
#   ____________> end_gou_pattern = 35g375g40g45gG
#   ____________> football_odds update pattern commited
#   __________[10/12] #975337 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975337
#   ____________> end_ah_pattern = +025+075+1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1-075-025H
#   ____________> end_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[11/12] #975340 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975340
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[12/12] #975338 #814 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 975338
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-27 07:03:39

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 07:03:39
#   ____main__
#   ______Enter your leagueapi id :  814
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 2
#   ______________[1/2]  #814 - 2023 => 3 / 3 == Match Finished
#   ______________[2/2]  #814 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-27 07:14:35

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 07:14:35
#   ____main__
#   ______Enter your leagueapi id :  814
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '814'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 5
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '5'  where leagueapi_id = '814'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/5] 1. +175H // 35g40g45gG >> +175H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like '+175H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '+175H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[2/5] 1. -15-125-1H // 35g375gG >> -15-125-1H // 35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like '-15-125-1H'  and `pre_gou_pattern` like '35g375gG'  and `end_ah_pattern` like '-15-125-1H'  and `end_gou_pattern` like '35g375gG'
#   __________________pattern_from update done
#   ______________[3/5] 1. -275-25-225H // 40g425g45gG >> -275-25-225H // 40g425g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like '-275-25-225H'  and `pre_gou_pattern` like '40g425g45gG'  and `end_ah_pattern` like '-275-25-225H'  and `end_gou_pattern` like '40g425g45gG'
#   __________________pattern_from update done
#   ______________[4/5] 1. -175-15-125-1-075H // 30g325g35g375g40gG >> -175-15-125-1-075H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like '-175-15-125-1-075H'  and `pre_gou_pattern` like '30g325g35g375g40gG'  and `end_ah_pattern` like '-175-15-125-1-075H'  and `end_gou_pattern` like '30g325g35g375g40gG'
#   __________________pattern_from update done
#   ______________[5/5] 1. +025+075+1+125+15H // 325g35g375g40g425gG >> +025+075+1+125+15H // 325g35g375g40g425gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like '+025+075+1+125+15H'  and `pre_gou_pattern` like '325g35g375g40g425gG'  and `end_ah_pattern` like '+025+075+1+125+15H'  and `end_gou_pattern` like '325g35g375g40g425gG'
#   __________________pattern_from update done
#   ________ff_get_fixtures_group_by_only_end_patternlists()
#   ____________Total Row(s) : 10
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_only_ends = '10'  where leagueapi_id = '814'
#   ________________> football_leagues : total_pattern_only_ends UPDATED
#   ______________[1/10] 1.  >> -175-15-125-1-075H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1-075H'  and `end_gou_pattern` like '30g325g35g375g40gG'
#   __________________pattern_only update done
#   ______________[2/10] 1.  >> +0+025H // 35g375g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025H'  and `end_gou_pattern` like '35g375g40g45gG'
#   __________________pattern_only update done
#   ______________[3/10] 1.  >> +025+075+1+125+15H // 325g35g375g40g425gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+075+1+125+15H'  and `end_gou_pattern` like '325g35g375g40g425gG'
#   __________________pattern_only update done
#   ______________[4/10] 1.  >> -275-25-225-2-175H // 35g375g40g425g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-275-25-225-2-175H'  and `end_gou_pattern` like '35g375g40g425g45gG'
#   __________________pattern_only update done
#   ______________[5/10] 1.  >> +125+15+175+2+225+25H // 40g425g45g475g50g525gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+125+15+175+2+225+25H'  and `end_gou_pattern` like '40g425g45g475g50g525gG'
#   __________________pattern_only update done
#   ______________[6/10] 1.  >> +125H // 35g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+125H'  and `end_gou_pattern` like '35g45gG'
#   __________________pattern_only update done
#   ______________[7/10] 1.  >> -3H // 45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-3H'  and `end_gou_pattern` like '45gG'
#   __________________pattern_only update done
#   ______________[8/10] 1.  >> +175H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+175H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_only update done
#   ______________[9/10] 1.  >> -15-125-1H // 35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1H'  and `end_gou_pattern` like '35g375gG'
#   __________________pattern_only update done
#   ______________[10/10] 1.  >> -275-25-225H // 40g425g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 814  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-275-25-225H'  and `end_gou_pattern` like '40g425g45gG'
#   __________________pattern_only update done
# # -------------------------------------------------- End at 2023-07-27 07:35:10
