# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 06:37:20
#   ____main__
#   ______Enter your leagueapi id :  775
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 13
#   ______________[1/13]  #775 - 2022 => 0 / None == Match Finished
#   ______________[2/13]  #775 - 2022 => 0 / 3 == Match Finished
#   ______________[3/13]  #775 - 2022 => 0 / 3 == Match Finished Ended
#   ______________[4/13]  #775 - 2022 => 2 / None == Match Finished
#   ______________[5/13]  #775 - 2022 => 2 / 2 == Match Finished Ended
#   ______________[6/13]  #775 - 2022 => 2 / 3 == Match Finished
#   ______________[7/13]  #775 - 2022 => 2 / 3 == Match Finished Ended
#   ______________[8/13]  #775 - 2022 => 3 / None == Match Finished
#   ______________[9/13]  #775 - 2023 => 0 / 1 == Match Finished Ended
#   ______________[10/13]  #775 - 2023 => 1 / 1 == Match Finished Ended
#   ______________[11/13]  #775 - 2023 => 3 / 1 == Match Finished
#   ______________[12/13]  #775 - 2023 => 3 / 1 == Match Finished Ended
#   ______________[13/13]  #775 - 2023 => 3 / 3 == Match Finished
# # -------------------------------------------------- End at 2023-07-27 06:50:25

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 06:50:25
#   __main()
#   ____Enter your leagueapi id :  775
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '775'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '775'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 159
#   __________[1/159] #835102 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835102
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[2/159] #835096 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835096
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[3/159] #835108 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835108
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[4/159] #835106 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835106
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[5/159] #835103 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835103
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[6/159] #835104 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835104
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[7/159] #835105 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835105
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[8/159] #835109 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835109
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[9/159] #835107 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835107
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[10/159] #835112 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835112
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[11/159] #835115 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835115
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[12/159] #835111 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835111
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[13/159] #835113 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835113
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[14/159] #835116 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835116
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[15/159] #835110 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835110
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[16/159] #835114 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835114
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[17/159] #835118 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835118
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[18/159] #835119 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835119
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[19/159] #835121 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835121
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[20/159] #835117 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835117
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[21/159] #835123 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835123
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[22/159] #835120 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835120
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[23/159] #835122 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835122
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[24/159] #835130 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835130
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[25/159] #835124 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835124
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[26/159] #835127 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835127
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[27/159] #835129 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835129
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[28/159] #835126 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835126
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[29/159] #835128 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835128
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[30/159] #835125 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835125
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[31/159] #835131 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835131
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[32/159] #835137 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835137
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[33/159] #835136 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835136
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[34/159] #835132 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835132
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[35/159] #835133 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835133
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[36/159] #835135 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835135
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[37/159] #835134 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835134
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[38/159] #835139 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835139
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[39/159] #835142 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835142
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[40/159] #835143 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835143
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[41/159] #835141 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835141
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[42/159] #835144 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835144
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[43/159] #835138 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835138
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[44/159] #835140 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835140
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[45/159] #835149 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835149
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[46/159] #835147 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835147
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[47/159] #835148 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835148
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[48/159] #835150 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835150
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[49/159] #835146 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835146
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[50/159] #835145 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835145
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[51/159] #835155 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835155
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[52/159] #835152 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835152
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[53/159] #835153 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835153
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[54/159] #835156 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835156
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[55/159] #835158 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835158
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[56/159] #835154 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835154
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[57/159] #835157 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835157
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[58/159] #835161 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835161
#   ____________> pre_ah_pattern = -2-15H
#   ____________> pre_ah_pattern_mirror = +15+2H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[59/159] #835163 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835163
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[60/159] #835159 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835159
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[61/159] #835162 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835162
#   ____________> pre_ah_pattern = -1-075H
#   ____________> pre_ah_pattern_mirror = +075+1H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[62/159] #835164 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835164
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[63/159] #835160 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835160
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[64/159] #835165 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835165
#   ____________> pre_ah_pattern = +1+125+15+2H
#   ____________> pre_ah_pattern_mirror = -2-15-125-1H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[65/159] #835166 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835166
#   ____________> pre_ah_pattern = -1H
#   ____________> pre_ah_pattern_mirror = +1H
#   ____________> pre_gou_pattern = 25g30g35gG
#   ____________> football_odds update pattern commited
#   __________[66/159] #835172 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835172
#   ____________> pre_ah_pattern = -35-3-25H
#   ____________> pre_ah_pattern_mirror = +25+3+35H
#   ____________> pre_gou_pattern = 40g45g50gG
#   ____________> football_odds update pattern commited
#   __________[67/159] #835168 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835168
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[68/159] #835167 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835167
#   ____________> pre_ah_pattern = -3-25-2H
#   ____________> pre_ah_pattern_mirror = +2+25+3H
#   ____________> pre_gou_pattern = 40g45gG
#   ____________> football_odds update pattern commited
#   __________[69/159] #835169 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835169
#   ____________> pre_ah_pattern = -15-1H
#   ____________> pre_ah_pattern_mirror = +1+15H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[70/159] #835170 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835170
#   ____________> pre_ah_pattern = +15+2+25H
#   ____________> pre_ah_pattern_mirror = -25-2-15H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[71/159] #835171 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835171
#   ____________> pre_ah_pattern = -15-1-025H
#   ____________> pre_ah_pattern_mirror = +025+1+15H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[72/159] #835175 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835175
#   ____________> pre_ah_pattern = +1+15+2H
#   ____________> pre_ah_pattern_mirror = -2-15-1H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[73/159] #835174 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835174
#   ____________> pre_ah_pattern = -15-1H
#   ____________> pre_ah_pattern_mirror = +1+15H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[74/159] #835177 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835177
#   ____________> pre_ah_pattern = +0+1H
#   ____________> pre_ah_pattern_mirror = -1+0H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[75/159] #835173 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835173
#   ____________> pre_ah_pattern = -15-1H
#   ____________> pre_ah_pattern_mirror = +1+15H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[76/159] #835179 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835179
#   ____________> pre_ah_pattern = +1+15H
#   ____________> pre_ah_pattern_mirror = -15-1H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[77/159] #835176 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835176
#   ____________> pre_ah_pattern = +25+3+35H
#   ____________> pre_ah_pattern_mirror = -35-3-25H
#   ____________> pre_gou_pattern = 40g45g50gG
#   ____________> football_odds update pattern commited
#   __________[78/159] #835178 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835178
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[79/159] #835180 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835180
#   ____________> pre_ah_pattern = -35-3-25H
#   ____________> pre_ah_pattern_mirror = +25+3+35H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[80/159] #835184 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835184
#   ____________> pre_ah_pattern = -25-2-15H
#   ____________> pre_ah_pattern_mirror = +15+2+25H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[81/159] #835182 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835182
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[82/159] #835183 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835183
#   ____________> pre_ah_pattern = -1H
#   ____________> pre_ah_pattern_mirror = +1H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[83/159] #835186 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835186
#   ____________> pre_ah_pattern = -25-2-15H
#   ____________> pre_ah_pattern_mirror = +15+2+25H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[84/159] #835181 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835181
#   ____________> pre_ah_pattern = -15-1H
#   ____________> pre_ah_pattern_mirror = +1+15H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[85/159] #835185 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835185
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[86/159] #835187 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835187
#   ____________> pre_ah_pattern = -2-15-1H
#   ____________> pre_ah_pattern_mirror = +1+15+2H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[87/159] #835188 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835188
#   ____________> pre_ah_pattern = +1+15+2H
#   ____________> pre_ah_pattern_mirror = -2-15-1H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[88/159] #835189 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835189
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[89/159] #835191 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835191
#   ____________> pre_ah_pattern = +1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[90/159] #835193 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835193
#   ____________> pre_ah_pattern = +0+1H
#   ____________> pre_ah_pattern_mirror = -1+0H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[91/159] #835190 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835190
#   ____________> pre_ah_pattern = +3+35+4H
#   ____________> pre_ah_pattern_mirror = -4-35-3H
#   ____________> pre_gou_pattern = 45g50g55gG
#   ____________> football_odds update pattern commited
#   __________[92/159] #835192 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835192
#   ____________> pre_ah_pattern = +1+15+2H
#   ____________> pre_ah_pattern_mirror = -2-15-1H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[93/159] #835194 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835194
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[94/159] #835197 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835197
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[95/159] #835200 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835200
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[96/159] #835198 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835198
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[97/159] #835199 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835199
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[98/159] #835196 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835196
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[99/159] #835195 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835195
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[100/159] #835207 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835207
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[101/159] #835202 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835202
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[102/159] #835203 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835203
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[103/159] #835201 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835201
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[104/159] #835206 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835206
#   ____________> pre_ah_pattern = -1H
#   ____________> pre_ah_pattern_mirror = +1H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[105/159] #835204 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835204
#   ____________> pre_ah_pattern = +1+15+2H
#   ____________> pre_ah_pattern_mirror = -2-15-1H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[106/159] #835205 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835205
#   ____________> pre_ah_pattern = +1+15H
#   ____________> pre_ah_pattern_mirror = -15-1H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[107/159] #835212 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835212
#   ____________> pre_ah_pattern = -25-2-15H
#   ____________> pre_ah_pattern_mirror = +15+2+25H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[108/159] #835208 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835208
#   ____________> pre_ah_pattern = -025+0H
#   ____________> pre_ah_pattern_mirror = +0+025H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[109/159] #835209 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835209
#   ____________> pre_ah_pattern = -25-2-15H
#   ____________> pre_ah_pattern_mirror = +15+2+25H
#   ____________> pre_gou_pattern = 40g45gG
#   ____________> football_odds update pattern commited
#   __________[110/159] #835213 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835213
#   ____________> pre_ah_pattern = -2-15H
#   ____________> pre_ah_pattern_mirror = +15+2H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[111/159] #835210 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835210
#   ____________> pre_ah_pattern = -1-075H
#   ____________> pre_ah_pattern_mirror = +075+1H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[112/159] #835211 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835211
#   ____________> pre_ah_pattern = -25-2-15H
#   ____________> pre_ah_pattern_mirror = +15+2+25H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[113/159] #835214 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835214
#   ____________> pre_ah_pattern = +1+15+2H
#   ____________> pre_ah_pattern_mirror = -2-15-1H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[114/159] #835216 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835216
#   ____________> pre_ah_pattern = -15-125-1H
#   ____________> pre_ah_pattern_mirror = +1+125+15H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[115/159] #835221 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835221
#   ____________> pre_ah_pattern = -25-2-175-15H
#   ____________> pre_ah_pattern_mirror = +15+175+2+25H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[116/159] #835219 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835219
#   ____________> pre_ah_pattern = +0+025H
#   ____________> pre_ah_pattern_mirror = -025+0H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[117/159] #835220 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835220
#   ____________> pre_ah_pattern = +2+225+25H
#   ____________> pre_ah_pattern_mirror = -25-225-2H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[118/159] #835217 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835217
#   ____________> pre_ah_pattern = +1+15H
#   ____________> pre_ah_pattern_mirror = -15-1H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[119/159] #835218 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835218
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[120/159] #835215 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835215
#   ____________> pre_ah_pattern = -1H
#   ____________> pre_ah_pattern_mirror = +1H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[121/159] #835151 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835151
#   ____________> pre_ah_pattern = -025+0H
#   ____________> pre_ah_pattern_mirror = +0+025H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[122/159] #835224 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835224
#   ____________> pre_ah_pattern = -15-1H
#   ____________> pre_ah_pattern_mirror = +1+15H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[123/159] #835225 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835225
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[124/159] #835227 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835227
#   ____________> pre_ah_pattern = -3-25-2H
#   ____________> pre_ah_pattern_mirror = +2+25+3H
#   ____________> pre_gou_pattern = 40g45g50gG
#   ____________> football_odds update pattern commited
#   __________[125/159] #835226 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835226
#   ____________> pre_ah_pattern = -25-2H
#   ____________> pre_ah_pattern_mirror = +2+25H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[126/159] #835223 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835223
#   ____________> pre_ah_pattern = -2-15-125-1H
#   ____________> pre_ah_pattern_mirror = +1+125+15+2H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[127/159] #835228 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835228
#   ____________> pre_ah_pattern = +15+2+25H
#   ____________> pre_ah_pattern_mirror = -25-2-15H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[128/159] #835234 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835234
#   ____________> pre_ah_pattern = +0+025+1H
#   ____________> pre_ah_pattern_mirror = -1-025+0H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[129/159] #835235 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835235
#   ____________> pre_ah_pattern = -1-075H
#   ____________> pre_ah_pattern_mirror = +075+1H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[130/159] #835229 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835229
#   ____________> pre_ah_pattern = -15-1H
#   ____________> pre_ah_pattern_mirror = +1+15H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[131/159] #835231 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835231
#   ____________> pre_ah_pattern = -5-45-4-35H
#   ____________> pre_ah_pattern_mirror = +35+4+45+5H
#   ____________> pre_gou_pattern = 50g55g60g65gG
#   ____________> football_odds update pattern commited
#   __________[132/159] #835232 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835232
#   ____________> pre_ah_pattern = -025+0H
#   ____________> pre_ah_pattern_mirror = +0+025H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[133/159] #835230 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835230
#   ____________> pre_ah_pattern = +0+025H
#   ____________> pre_ah_pattern_mirror = -025+0H
#   ____________> pre_gou_pattern = 35g40gG
#   ____________> football_odds update pattern commited
#   __________[134/159] #835233 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835233
#   ____________> pre_ah_pattern = +1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[135/159] #835236 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835236
#   ____________> pre_ah_pattern = -2-15-125-1H
#   ____________> pre_ah_pattern_mirror = +1+125+15+2H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[136/159] #835240 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835240
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[137/159] #835239 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835239
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 25g30g35gG
#   ____________> football_odds update pattern commited
#   __________[138/159] #835237 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835237
#   ____________> pre_ah_pattern = +0+025H
#   ____________> pre_ah_pattern_mirror = -025+0H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[139/159] #835241 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835241
#   ____________> pre_ah_pattern = +0+025+1H
#   ____________> pre_ah_pattern_mirror = -1-025+0H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[140/159] #835242 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835242
#   ____________> pre_ah_pattern = -025+0H
#   ____________> pre_ah_pattern_mirror = +0+025H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[141/159] #835238 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835238
#   ____________> pre_ah_pattern = -1-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+1H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[142/159] #835222 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835222
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 25g30g35gG
#   ____________> football_odds update pattern commited
#   __________[143/159] #835243 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835243
#   ____________> pre_ah_pattern = -1-075H
#   ____________> pre_ah_pattern_mirror = +075+1H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[144/159] #835244 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835244
#   ____________> pre_ah_pattern = -15-1H
#   ____________> pre_ah_pattern_mirror = +1+15H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[145/159] #835245 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835245
#   ____________> pre_ah_pattern = -2-175-15H
#   ____________> pre_ah_pattern_mirror = +15+175+2H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[146/159] #835246 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835246
#   ____________> pre_ah_pattern = -25-2-175-15H
#   ____________> pre_ah_pattern_mirror = +15+175+2+25H
#   ____________> pre_gou_pattern = 40g45g50gG
#   ____________> football_odds update pattern commited
#   __________[147/159] #835247 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835247
#   ____________> pre_ah_pattern = +2+25H
#   ____________> pre_ah_pattern_mirror = -25-2H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[148/159] #835248 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835248
#   ____________> pre_ah_pattern = +0+1H
#   ____________> pre_ah_pattern_mirror = -1+0H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[149/159] #835249 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835249
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[150/159] #835250 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835250
#   ____________> pre_ah_pattern = +1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[151/159] #835251 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835251
#   ____________> pre_ah_pattern = +075+1+15H
#   ____________> pre_ah_pattern_mirror = -15-1-075H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[152/159] #835252 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835252
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[153/159] #835253 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835253
#   ____________> pre_ah_pattern = -3-25-225-2H
#   ____________> pre_ah_pattern_mirror = +2+225+25+3H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[154/159] #835254 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835254
#   ____________> pre_ah_pattern = -1-075H
#   ____________> pre_ah_pattern_mirror = +075+1H
#   ____________> pre_gou_pattern = 30g35g40gG
#   ____________> football_odds update pattern commited
#   __________[155/159] #835255 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835255
#   ____________> pre_ah_pattern = +1+15H
#   ____________> pre_ah_pattern_mirror = -15-1H
#   ____________> pre_gou_pattern = 40g45g50gG
#   ____________> football_odds update pattern commited
#   __________[156/159] #835256 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835256
#   ____________> pre_ah_pattern = +1+125+15+2H
#   ____________> pre_ah_pattern_mirror = -2-15-125-1H
#   ____________> pre_gou_pattern = 35g40g45gG
#   ____________> football_odds update pattern commited
#   __________[157/159] #1032140 #775 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1032140
#   ____________> pre_ah_pattern = -4-375-35-325-3-275-25-175-15-125H
#   ____________> pre_ah_pattern_mirror = +125+15+175+25+275+3+325+35+375+4H
#   ____________> pre_gou_pattern = 375g40g425g45g475g50g525gG
#   ____________> football_odds update pattern commited
#   __________[158/159] #1032141 #775 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1032141
#   ____________> pre_ah_pattern = -25-225-2-175-15H
#   ____________> pre_ah_pattern_mirror = +15+175+2+225+25H
#   ____________> pre_gou_pattern = 35g375g40g425g45g475gG
#   ____________> football_odds update pattern commited
#   __________[159/159] #1032126 #775 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1032126
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '775'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '775'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 126
#   __________[1/126] #835250 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835250
#   ____________> end_ah_pattern = +1+125+15H
#   ____________> end_ah_pattern_mirror = -15-125-1H
#   ____________> end_gou_pattern = 30g35gG
#   ____________> football_odds update pattern commited
#   __________[2/126] #835251 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835251
#   ____________> end_ah_pattern = +075+1+15H
#   ____________> end_ah_pattern_mirror = -15-1-075H
# ...
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835107
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[71/126] #835112 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835112
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[72/126] #835115 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835115
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[73/126] #835111 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835111
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[74/126] #835113 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835113
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[75/126] #835116 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835116
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[76/126] #835110 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835110
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[77/126] #835114 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835114
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[78/126] #835118 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835118
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[79/126] #835119 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835119
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[80/126] #835121 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835121
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[81/126] #835117 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835117
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[82/126] #835123 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835123
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[83/126] #835120 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835120
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[84/126] #835122 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835122
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[85/126] #835130 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835130
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[86/126] #835124 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835124
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[87/126] #835127 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835127
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[88/126] #835129 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835129
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[89/126] #835126 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835126
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[90/126] #835128 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835128
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[91/126] #835125 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835125
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[92/126] #835131 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835131
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[93/126] #835137 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835137
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[94/126] #835136 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835136
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[95/126] #835132 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835132
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[96/126] #835133 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835133
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[97/126] #835135 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835135
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[98/126] #835134 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835134
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[99/126] #835139 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835139
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[100/126] #835142 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835142
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[101/126] #835143 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835143
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[102/126] #835141 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835141
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[103/126] #835144 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835144
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[104/126] #835138 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835138
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[105/126] #835140 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835140
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[106/126] #835149 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835149
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[107/126] #835147 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835147
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[108/126] #835148 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835148
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[109/126] #835150 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835150
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[110/126] #835146 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835146
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[111/126] #835145 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835145
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[112/126] #835187 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835187
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[113/126] #835188 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835188
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[114/126] #835189 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835189
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[115/126] #835191 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835191
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[116/126] #835193 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835193
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[117/126] #835190 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835190
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[118/126] #835192 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835192
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[119/126] #835221 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835221
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[120/126] #835219 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835219
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[121/126] #835220 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835220
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[122/126] #835217 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835217
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[123/126] #835218 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835218
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[124/126] #835224 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835224
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[125/126] #835225 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835225
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[126/126] #835227 #775 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 835227
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-27 08:47:47

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 08:47:47
#   ____main__
#   ______Enter your leagueapi id :  775
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 4
#   ______________[1/4]  #775 - 2022 => 3 / 3 == Match Finished
#   ______________[2/4]  #775 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/4]  #775 - 2023 => 3 / 3 == Match Finished
#   ______________[4/4]  #775 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-27 09:48:33

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 09:48:33
#   ____main__
#   ______Enter your leagueapi id :  775
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '775'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 81
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '81'  where leagueapi_id = '775'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/81] 3. +0H // 30g35g40gG >> +0H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+0H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '+0H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_from update done
#   ______________[2/81] 2. -25-2-15H // 35g40g45gG >> -25-2-15H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-25-2-15H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '-25-2-15H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[3/81] 2. -15-1H // 30g35g40gG >> -15-1H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-15-1H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '-15-1H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_from update done
#   ______________[4/81] 2. +0H // 30g35gG >> +0H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+0H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '+0H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_from update done
#   ______________[5/81] 2. -1-075H // 30g35g40gG >> -1-075H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-1-075H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '-1-075H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_from update done
#   ______________[6/81] 2. +1+15+2H // 35g40g45gG >> +1+15+2H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+1+15+2H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '+1+15+2H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[7/81] 2. +0H // 25g30g35gG >> +0H // 25g30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+0H'  and `pre_gou_pattern` like '25g30g35gG'  and `end_ah_pattern` like '+0H'  and `end_gou_pattern` like '25g30g35gG'
#   __________________pattern_from update done
#   ______________[8/81] 1. +125+15+175+2H // 275g30g325g35g375g40gG >> +125+15+175+2+225+25H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[9/81] 1. +0H // 30g35gG >> -025+0H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+0H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '-025+0H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_from update done
#   ______________[10/81] 1. +0H // 30g35gG >> -1H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+0H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '-1H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_from update done
#   ______________[11/81] 1. -025+0H // 30g35g40gG >> -025+0H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-025+0H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '-025+0H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_from update done
#   ______________[12/81] 1. -1-025+0H // 35g40g45gG >> -1-075-025H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-1-025+0H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '-1-075-025H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[13/81] 1. +1+125+15+175+2+225H // 35g375g40g425g45g475gG >> +075+1+125+15+175H // 35g375g40g425g45g475gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[14/81] 1. +1+125+15+2H // 35g40g45gG >> +1+125+15+2+25H // 40g45g50gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+1+125+15+2H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '+1+125+15+2+25H'  and `end_gou_pattern` like '40g45g50gG'
#   __________________pattern_from update done
#   ______________[15/81] 1. -1H // 30g35gG >> -1H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-1H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '-1H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_from update done
#   ______________[16/81] 1. -25-2H // 35g40g45gG >> -25-225-2H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-25-2H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '-25-225-2H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[17/81] 1. -2-175-15H // 35g40g45gG >> -2-175-15H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-2-175-15H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '-2-175-15H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[18/81] 1. -35-325-3-275-25-225H // 35g375g40g425g45g475gG >> -35-325-3-275-25-225H // 35g375g40g425g45g475gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-35-325-3-275-25-225H'  and `pre_gou_pattern` like '35g375g40g425g45g475gG'  and `end_ah_pattern` like '-35-325-3-275-25-225H'  and `end_gou_pattern` like '35g375g40g425g45g475gG'
#   __________________pattern_from update done
#   ______________[19/81] 1. -1-075-025+0H // 325g35g375g40g425gG >> -1-075-025+0H // 325g35g375g40g425gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[20/81] 1. -1H // 25g30g35gG >> -1-075H // 25g30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-1H'  and `pre_gou_pattern` like '25g30g35gG'  and `end_ah_pattern` like '-1-075H'  and `end_gou_pattern` like '25g30g35gG'
#   __________________pattern_from update done
#   ______________[21/81] 1. -2-15-125-1H // 35g40gG >> -2-15-125-1H // 35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-2-15-125-1H'  and `pre_gou_pattern` like '35g40gG'  and `end_ah_pattern` like '-2-15-125-1H'  and `end_gou_pattern` like '35g40gG'
#   __________________pattern_from update done
#   ______________[22/81] 1. -25-2-175-15H // 40g45g50gG >> -3-25-2-175H // 40g45g50gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-25-2-175-15H'  and `pre_gou_pattern` like '40g45g50gG'  and `end_ah_pattern` like '-3-25-2-175H'  and `end_gou_pattern` like '40g45g50gG'
#   __________________pattern_from update done
#   ______________[23/81] 1. -175-15-125-1-075H // 35g375g40g425g45g475gG >> -175-15-125-1-075H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-175-15-125-1-075H'  and `pre_gou_pattern` like '35g375g40g425g45g475gG'  and `end_ah_pattern` like '-175-15-125-1-075H'  and `end_gou_pattern` like '30g325g35g375g40gG'
#   __________________pattern_from update done
#   ______________[24/81] 1. +15+175+2+225+25+275H // 35g375g40g425g45g475g50gG >> +15+175+2+225+25+275H // 35g375g40g425g45g475g50gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[25/81] 1. -35-3-25H // 40g45g50gG >> -35-3-25H // 40g45g50gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-35-3-25H'  and `pre_gou_pattern` like '40g45g50gG'  and `end_ah_pattern` like '-35-3-25H'  and `end_gou_pattern` like '40g45g50gG'
#   __________________pattern_from update done
#   ______________[26/81] 1. +15+2+25H // 30g35g40gG >> +15+2+25H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+15+2+25H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '+15+2+25H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[27/81] 1. +2+25H // 35g40g45gG >> +15+2+25H // 40g45g50gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+2+25H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '+15+2+25H'  and `end_gou_pattern` like '40g45g50gG'
#   __________________pattern_from update done
#   ______________[28/81] 1. -3-25-2H // 40g45gG >> -35-3-275-25H // 45g50g55gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-3-25-2H'  and `pre_gou_pattern` like '40g45gG'  and `end_ah_pattern` like '-35-3-275-25H'  and `end_gou_pattern` like '45g50g55gG'
#   __________________pattern_from update done
#   ______________[29/81] 1. +0H // 35g40gG >> -025+0H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+0H'  and `pre_gou_pattern` like '35g40gG'  and `end_ah_pattern` like '-025+0H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[30/81] 1. +0+025+1H // 30g35gG >> +0+025+1H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+0+025+1H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '+0+025+1H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_from update done
#   ______________[31/81] 1. +0+1H // 30g35gG >> +0+1H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+0+1H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '+0+1H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_from update done
#   ______________[32/81] 1. +025+075+1+125H // 325g35g375g40g425g45gG >> +075+1+125+15H // 325g35g375g40g425g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+025+075+1+125H'  and `pre_gou_pattern` like '325g35g375g40g425g45gG'  and `end_ah_pattern` like '+075+1+125+15H'  and `end_gou_pattern` like '325g35g375g40g425g45gG'
#   __________________pattern_from update done
#   ______________[33/81] 1. -15-1H // 30g35gG >> -25-2-175-125H // 35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-15-1H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '-25-2-175-125H'  and `end_gou_pattern` like '35g40gG'
#   __________________pattern_from update done
#   ______________[34/81] 1. +1+125+15H // 30g35gG >> +1+125+15H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+1+125+15H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '+1+125+15H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_from update done
#   ______________[35/81] 1. -4-375-35-325-3-275-25-175-15-125H // 375g40g425g45g475g50g525gG >> -375-35-325-3-275-25-225-175-15-125H // 40g425g45g475g50g525g55gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-4-375-35-325-3-275-25-175-15-125H'  and `pre_gou_pattern` like '375g40g425g45g475g50g525gG'  and `end_ah_pattern` like '-375-35-325-3-275-25-225-175-15-125H'  and `end_gou_pattern` like '40g425g45g475g50g525g55gG'
#   __________________pattern_from update done
#   ______________[36/81] 1. +15+2+25H // 35g40gG >> +075+1+175H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+15+2+25H'  and `pre_gou_pattern` like '35g40gG'  and `end_ah_pattern` like '+075+1+175H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_from update done
#   ______________[37/81] 1. -1H // 35g40gG >> -1H // 35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-1H'  and `pre_gou_pattern` like '35g40gG'  and `end_ah_pattern` like '-1H'  and `end_gou_pattern` like '35g40gG'
#   __________________pattern_from update done
#   ______________[38/81] 1. -15-1H // 30g35g40gG >> -2-15-1H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-15-1H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '-2-15-1H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_from update done
#   ______________[39/81] 1. +075+1+15H // 35g40g45gG >> +075+1+15H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+075+1+15H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '+075+1+15H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[40/81] 1. -25-225-2-175-15H // 35g375g40g425g45g475gG >> -35-325-3-275-25-225-2H // 40g425g45g475g50g525g55gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-25-225-2-175-15H'  and `pre_gou_pattern` like '35g375g40g425g45g475gG'  and `end_ah_pattern` like '-35-325-3-275-25-225-2H'  and `end_gou_pattern` like '40g425g45g475g50g525g55gG'
#   __________________pattern_from update done
#   ______________[41/81] 1. -15-1-025H // 30g35g40gG >> -2-15-125-1-025H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-15-1-025H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '-2-15-125-1-025H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_from update done
#   ______________[42/81] 1. -5-45-4-35H // 50g55g60g65gG >> -5-45-4-35H // 45g50g55g60gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-5-45-4-35H'  and `pre_gou_pattern` like '50g55g60g65gG'  and `end_ah_pattern` like '-5-45-4-35H'  and `end_gou_pattern` like '45g50g55g60gG'
#   __________________pattern_from update done
#   ______________[43/81] 1. -3-25-225-2H // 35g40g45gG >> -3-25-225-2H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-3-25-225-2H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '-3-25-225-2H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[44/81] 1. -2-175-15-125-1-075H // 325g35g375g40g425g45g475gG >> -275-25-225-2-175-15H // 35g375g40g425g45g475g50gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-2-175-15-125-1-075H'  and `pre_gou_pattern` like '325g35g375g40g425g45g475gG'  and `end_ah_pattern` like '-275-25-225-2-175-15H'  and `end_gou_pattern` like '35g375g40g425g45g475g50gG'
#   __________________pattern_from update done
#   ______________[45/81] 1. +1+15+2H // 35g40gG >> +1+15+175+225H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+1+15+2H'  and `pre_gou_pattern` like '35g40gG'  and `end_ah_pattern` like '+1+15+175+225H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[46/81] 1. +1+15H // 35g40gG >> +0+025H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+1+15H'  and `pre_gou_pattern` like '35g40gG'  and `end_ah_pattern` like '+0+025H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[47/81] 1. -025+0H // 35g40g45gG >> -025+0H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-025+0H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '-025+0H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[48/81] 1. -1-075H // 30g35g40gG >> -075H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-1-075H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '-075H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_from update done
#   ______________[49/81] 1. -125-1-075-025H // 35g375g40g425g45g475gG >> -15-125-1-075-025H // 35g375g40g425g45g475gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-125-1-075-025H'  and `pre_gou_pattern` like '35g375g40g425g45g475gG'  and `end_ah_pattern` like '-15-125-1-075-025H'  and `end_gou_pattern` like '35g375g40g425g45g475gG'
#   __________________pattern_from update done
#   ______________[50/81] 1. -15-1H // 30g35gG >> -15-1H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-15-1H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '-15-1H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_from update done
#   ______________[51/81] 1. -025+0H // 30g35gG >> -1-025H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-025+0H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '-1-025H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_from update done
#   ______________[52/81] 1. +0+025H // 35g40gG >> +0+025H // 35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+0+025H'  and `pre_gou_pattern` like '35g40gG'  and `end_ah_pattern` like '+0+025H'  and `end_gou_pattern` like '35g40gG'
#   __________________pattern_from update done
#   ______________[53/81] 1. +1+15H // 40g45g50gG >> +1+15H // 40g45g50gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+1+15H'  and `pre_gou_pattern` like '40g45g50gG'  and `end_ah_pattern` like '+1+15H'  and `end_gou_pattern` like '40g45g50gG'
#   __________________pattern_from update done
#   ______________[54/81] 1. -175-15-125-1-075H // 325g35g375g40g425gG >> -2-175-15-125-1H // 325g35g375g40g425g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-175-15-125-1-075H'  and `pre_gou_pattern` like '325g35g375g40g425gG'  and `end_ah_pattern` like '-2-175-15-125-1H'  and `end_gou_pattern` like '325g35g375g40g425g45gG'
#   __________________pattern_from update done
#   ______________[55/81] 1. +225+25+275+3+325+35+375H // 40g425g45g475g50g525gG >> +25+275+3+325+35+375+4H // 425g45g475g50g525g55g575gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[56/81] 1. +0+1H // 30g35g40gG >> +0+1H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+0+1H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '+0+1H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_from update done
#   ______________[57/81] 1. -25-2-15H // 40g45gG >> -35-3-25H // 45g50g55gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-25-2-15H'  and `pre_gou_pattern` like '40g45gG'  and `end_ah_pattern` like '-35-3-25H'  and `end_gou_pattern` like '45g50g55gG'
#   __________________pattern_from update done
#   ______________[58/81] 1. +1+125+15H // 30g35g40gG >> +0+025+125H // 35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+1+125+15H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '+0+025+125H'  and `end_gou_pattern` like '35g40gG'
#   __________________pattern_from update done
#   ______________[59/81] 1. +1+125+15+2H // 35g40g45gG >> +1+125+15+2H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+1+125+15+2H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '+1+125+15+2H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[60/81] 1. -275-25-225-2-175-15H // 35g375g40g425g45g475gG >> -275-25-225-2-175-15H // 35g375g40g425g45g475gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[61/81] 1. -15-1H // 30g35gG >> -1H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-15-1H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '-1H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_from update done
#   ______________[62/81] 1. -2-15H // 35g40gG >> -25-2-15H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-2-15H'  and `pre_gou_pattern` like '35g40gG'  and `end_ah_pattern` like '-25-2-15H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[63/81] 1. -2-15-125-1H // 35g40g45gG >> -2-15-125-1H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-2-15-125-1H'  and `pre_gou_pattern` like '35g40g45gG'  and `end_ah_pattern` like '-2-15-125-1H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_from update done
#   ______________[64/81] 1. -025+0+025H // 275g30g325g35g375gG >> -025+0+025H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '275g30g325g35g375gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_from update done
#   ______________[65/81] 1. +025+075+1H // 30g325g35g375g40gG >> +025+075+1H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[66/81] 1. +1+15H // 30g35g40gG >> +1+125+15+2H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '+1+15H'  and `pre_gou_pattern` like '30g35g40gG'  and `end_ah_pattern` like '+1+125+15+2H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_from update done
#   ______________[67/81] 1. -1-075H // 30g35gG >> -1-075H // 25g30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-1-075H'  and `pre_gou_pattern` like '30g35gG'  and `end_ah_pattern` like '-1-075H'  and `end_gou_pattern` like '25g30g35gG'
#   __________________pattern_from update done
#   ______________[68/81] 1. -3-275-25-225-2-175H // 35g375g40g425g45g475gG >> -325-3-275-25-225-2H // 35g375g40g425g45g475gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[69/81] 1. -2-15H // 35g40gG >> -25-2-175-15H // 35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like '-2-15H'  and `pre_gou_pattern` like '35g40gG'  and `end_ah_pattern` like '-25-2-175-15H'  and `end_gou_pattern` like '35g40gG'
#   __________________pattern_from update done
#   ______________[70/81] 1. +25+3+35H // 40g45g50gG >> +3+35+4H // 45g50g55gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
# ...
#   __________________pattern_only update done
#   ______________[70/94] 1.  >> +25+275+3+325+35+375+4H // 425g45g475g50g525g55g575gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[71/94] 1.  >> +1+125+15H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+1+125+15H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_only update done
#   ______________[72/94] 1.  >> -075-025+0H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-025+0H'  and `end_gou_pattern` like '30g325g35g375g40gG'
#   __________________pattern_only update done
#   ______________[73/94] 1.  >> +1+15+175+225H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+1+15+175+225H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_only update done
#   ______________[74/94] 1.  >> +0+025H // 35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025H'  and `end_gou_pattern` like '35g40gG'
#   __________________pattern_only update done
#   ______________[75/94] 1.  >> -275-25-225-2-175-15H // 35g375g40g425g45g475gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[76/94] 1.  >> +075+1+15H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+075+1+15H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_only update done
#   ______________[77/94] 1.  >> -15-1-075H // 35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-1-075H'  and `end_gou_pattern` like '35g40gG'
#   __________________pattern_only update done
#   ______________[78/94] 1.  >> +0+025H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_only update done
#   ______________[79/94] 1.  >> +15+175+2+225+25H // 325g35g375g40g425g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+15+175+2+225+25H'  and `end_gou_pattern` like '325g35g375g40g425g45gG'
#   __________________pattern_only update done
#   ______________[80/94] 1.  >> +0+025+125H // 35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+125H'  and `end_gou_pattern` like '35g40gG'
#   __________________pattern_only update done
#   ______________[81/94] 1.  >> +025+075+1H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[82/94] 1.  >> +1+125+15H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+1+125+15H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_only update done
#   ______________[83/94] 1.  >> -3-25-225-2H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-3-25-225-2H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_only update done
#   ______________[84/94] 1.  >> -1-025H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-025H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_only update done
#   ______________[85/94] 1.  >> -375-35-325-3-275-25-225-175-15-125H // 40g425g45g475g50g525g55gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-375-35-325-3-275-25-225-175-15-125H'  and `end_gou_pattern` like '40g425g45g475g50g525g55gG'
#   __________________pattern_only update done
#   ______________[86/94] 1.  >> +0+1H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+1H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_only update done
#   ______________[87/94] 1.  >> -2-15-125-1H // 35g40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-2-15-125-1H'  and `end_gou_pattern` like '35g40g45gG'
#   __________________pattern_only update done
#   ______________[88/94] 1.  >> -325-3-275-25-225-2H // 35g375g40g425g45g475gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[89/94] 1.  >> -15-125-1H // 30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1H'  and `end_gou_pattern` like '30g35gG'
#   __________________pattern_only update done
#   ______________[90/94] 1.  >> +0H // 35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0H'  and `end_gou_pattern` like '35g40gG'
#   __________________pattern_only update done
#   ______________[91/94] 1.  >> -075H // 30g35g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075H'  and `end_gou_pattern` like '30g35g40gG'
#   __________________pattern_only update done
#   ______________[92/94] 1.  >> +1+125+15+2+25H // 40g45g50gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+1+125+15+2+25H'  and `end_gou_pattern` like '40g45g50gG'
#   __________________pattern_only update done
#   ______________[93/94] 1.  >> -35-3-25H // 45g50g55gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-35-3-25H'  and `end_gou_pattern` like '45g50g55gG'
#   __________________pattern_only update done
#   ______________[94/94] 1.  >> -35-325-3-275-25-225-2H // 40g425g45g475g50g525g55gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 775  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-35-325-3-275-25-225-2H'  and `end_gou_pattern` like '40g425g45g475g50g525g55gG'
#   __________________pattern_only update done
# # -------------------------------------------------- End at 2023-07-27 10:38:04
