# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    host="localhost"
    user="root" 
    database="pr_mmbuzz_2022_06"
    mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
    mycursor = mydb.cursor()
    # ----------------------------------------------------------
    query = " Select  leagueapi_id " 
    query += " from football_leagues "    
    query += " where star is not null "   
    # ----------------------------------------------------------
    mycursor = mydb.cursor()
    mycursor.execute(query)
    result =  mycursor.fetchall()
    # ----------------------------------------------------------
    for x in result:    
    # ----------------------------------------------------------
        print(x[0])
        ff_get_fixtures_group_by_pre_end_patternlists(x[0], space)
    # ----------------------------------------------------------
    space += "____"  
    # ----------------------------------------------------------  
#     leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
#     ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-27 09:46:53
#   ____main__
# 39
# 40
# 46
# 45
# 47
# 48
# 43
# 41
# 42
# 528
# 88
# 90
# 89
# 78
# 79
# 81
# 135
# 547
# 136
# 137
# 140
# 141
# 143
# 61
# 62
# 63
# 66
# 144
# 145
# 147
# 218
# 71
# 72
# 73
# 244
# 245
# 346
# 345
# 119
# 210
# 211
# 197
# 199
# 271
# 164
# 167
# 168
# 274
# 357
# 358
# 98
# 101
# 262
# 263
# 103
# 104
# 105
# 107
# 106
# 108
# 94
# 95
# 96
# 97
# 235
# 180
# 179
# 181
# 182
# 203
# 206
# 297
# 296
# 207
# 208
# 209
# 114
# 113
# 373
# 1
# 2
# 3
# 5
# 253
# 12
# 536
# 848
# 292
# 293
# 283
# 188
# 128
# 287
# 286
# 265
# 239
# 116
# 250
# 281
# 368
# 365
# 364
# 362
# 361
# 169
# 328
# 242
# 307
# 318
# 288
# 960
# 490
# 340
# # -------------------------------------------------- End at 2023-05-27 09:46:53
