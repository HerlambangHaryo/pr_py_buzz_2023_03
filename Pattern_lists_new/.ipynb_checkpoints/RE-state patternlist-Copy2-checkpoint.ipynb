# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 06:37:39
#   ____main__
#   ______Enter your leagueapi id :  906
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 5
#   ______________[1/5]  #906 - 2023 => 0 / 1 == Match Finished Ended
#   ______________[2/5]  #906 - 2023 => 0 / 3 == Match Finished
#   ______________[3/5]  #906 - 2023 => 3 / 0 == Match Finished
#   ______________[4/5]  #906 - 2023 => 3 / 1 == Match Finished Ended
#   ______________[5/5]  #906 - 2023 => 3 / 3 == Match Finished
# # -------------------------------------------------- End at 2023-07-27 06:50:54

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 06:50:54
#   __main()
#   ____Enter your leagueapi id :  906
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '906'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '906'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 10
#   __________[1/10] #997027 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997027
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[2/10] #997028 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997028
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[3/10] #997030 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997030
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[4/10] #997031 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997031
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[5/10] #997032 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997032
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[6/10] #997033 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997033
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[7/10] #997035 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997035
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[8/10] #997036 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997036
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[9/10] #997039 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997039
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[10/10] #997085 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997085
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '906'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '906'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 77
#   __________[1/77] #997028 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997028
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[2/77] #997029 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997029
#   ____________> end_ah_pattern = -125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[3/77] #997030 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997030
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[4/77] #997031 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997031
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 15g175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[5/77] #997032 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997032
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[6/77] #997033 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997033
#   ____________> end_ah_pattern = -125-1-075-025H
#   ____________> end_ah_pattern_mirror = +025+075+1+125H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[7/77] #997034 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997034
#   ____________> end_ah_pattern = +075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[8/77] #997035 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997035
#   ____________> end_ah_pattern = -125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[9/77] #997036 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997036
#   ____________> end_ah_pattern = +025+075H
#   ____________> end_ah_pattern_mirror = -075-025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[10/77] #997037 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997037
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[11/77] #997038 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997038
#   ____________> end_ah_pattern = -125-1-075-025H
#   ____________> end_ah_pattern_mirror = +025+075+1+125H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[12/77] #997039 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997039
#   ____________> end_ah_pattern = +0+025H
#   ____________> end_ah_pattern_mirror = -025+0H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[13/77] #997040 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997040
#   ____________> end_ah_pattern = +0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[14/77] #997044 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997044
#   ____________> end_ah_pattern = -125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[15/77] #997045 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997045
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[16/77] #997052 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997052
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[17/77] #997053 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997053
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[18/77] #997054 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997054
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[19/77] #997048 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997048
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[20/77] #997047 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997047
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[21/77] #997049 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997049
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[22/77] #997050 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997050
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[23/77] #997051 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997051
#   ____________> end_ah_pattern = +0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0H
#   ____________> end_gou_pattern = 15g175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[24/77] #997041 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997041
#   ____________> end_ah_pattern = -075-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+075H
#   ____________> end_gou_pattern = 15g175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[25/77] #997042 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997042
#   ____________> end_ah_pattern = -125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[26/77] #997043 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997043
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[27/77] #997046 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997046
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 15g175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[28/77] #997055 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997055
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[29/77] #997057 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997057
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[30/77] #997058 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997058
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[31/77] #997059 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997059
#   ____________> end_ah_pattern = -1-075-025H
#   ____________> end_ah_pattern_mirror = +025+075+1H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[32/77] #997060 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997060
#   ____________> end_ah_pattern = -1-075-025H
#   ____________> end_ah_pattern_mirror = +025+075+1H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[33/77] #997061 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997061
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[34/77] #997062 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997062
#   ____________> end_ah_pattern = -1-075-025H
#   ____________> end_ah_pattern_mirror = +025+075+1H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[35/77] #997063 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997063
#   ____________> end_ah_pattern = +075+1+125+15+175H
#   ____________> end_ah_pattern_mirror = -175-15-125-1-075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[36/77] #997064 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997064
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[37/77] #997065 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997065
#   ____________> end_ah_pattern = +0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[38/77] #997066 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997066
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[39/77] #997067 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997067
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[40/77] #997068 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997068
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[41/77] #997069 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997069
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[42/77] #997070 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997070
#   ____________> end_ah_pattern = +0+025H
#   ____________> end_ah_pattern_mirror = -025+0H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[43/77] #997071 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997071
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[44/77] #997072 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997072
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[45/77] #997073 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997073
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[46/77] #997074 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997074
#   ____________> end_ah_pattern = -175-15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15+175H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[47/77] #997075 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997075
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[48/77] #997076 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997076
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[49/77] #997077 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997077
#   ____________> end_ah_pattern = -025+0H
#   ____________> end_ah_pattern_mirror = +0+025H
#   ____________> end_gou_pattern = 15g175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[50/77] #997078 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997078
#   ____________> end_ah_pattern = +0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[51/77] #997079 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997079
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[52/77] #997080 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997080
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[53/77] #997081 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997081
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[54/77] #997082 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997082
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[55/77] #997088 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997088
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 15g175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[56/77] #997086 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997086
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[57/77] #997093 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997093
#   ____________> end_ah_pattern = -075-025H
#   ____________> end_ah_pattern_mirror = +025+075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[58/77] #997083 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997083
#   ____________> end_ah_pattern = +025+075H
#   ____________> end_ah_pattern_mirror = -075-025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[59/77] #997084 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997084
#   ____________> end_ah_pattern = -1-075-025H
#   ____________> end_ah_pattern_mirror = +025+075+1H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[60/77] #997085 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997085
#   ____________> end_ah_pattern = -1-075-025H
#   ____________> end_ah_pattern_mirror = +025+075+1H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[61/77] #997087 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997087
#   ____________> end_ah_pattern = -1-075-025H
#   ____________> end_ah_pattern_mirror = +025+075+1H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[62/77] #997089 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997089
#   ____________> end_ah_pattern = -125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[63/77] #997090 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997090
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[64/77] #997091 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997091
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[65/77] #997092 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997092
#   ____________> end_ah_pattern = +075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075H
#   ____________> end_gou_pattern = 225g25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[66/77] #997094 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997094
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[67/77] #997095 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997095
#   ____________> end_ah_pattern = -075-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+075H
#   ____________> end_gou_pattern = 15g175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[68/77] #997096 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997096
#   ____________> end_ah_pattern = -125-1-075-025H
#   ____________> end_ah_pattern_mirror = +025+075+1+125H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[69/77] #997098 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997098
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[70/77] #997101 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997101
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[71/77] #997104 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997104
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[72/77] #997105 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997105
#   ____________> end_ah_pattern = +0+025+075H
#   ____________> end_ah_pattern_mirror = -075-025+0H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[73/77] #997106 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997106
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[74/77] #997107 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997107
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[75/77] #997108 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997108
#   ____________> end_ah_pattern = +0+025H
#   ____________> end_ah_pattern_mirror = -025+0H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[76/77] #997109 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997109
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[77/77] #997110 #906 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 997110
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-27 07:37:12

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 07:37:12
#   ____main__
#   ______Enter your leagueapi id :  906
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 2
#   ______________[1/2]  #906 - 2023 => 3 / 3 == Match Finished
#   ______________[2/2]  #906 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-27 07:43:57

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 07:43:57
#   ____main__
#   ______Enter your leagueapi id :  906
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '906'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 45
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '45'  where leagueapi_id = '906'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/45] 4. -025+0+025H // 20g225g25g275gG >> -025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[2/45] 3. -025+0+025H // 175g20g225g25gG >> -025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[3/45] 2. -075-025H // 15g175g20g225g25gG >> -075-025H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[4/45] 2. -025+0+025H // 15g175g20g225gG >> -025+0+025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like '-025+0+025H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_from update done
#   ______________[5/45] 2. -025+0+025H // 20g225g25g275gG >> -025+0+025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[6/45] 1. +0+025+075H // 225g25g275g30g325g35gG >> +0+025+075H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[7/45] 1. +075+1+125+15H // 225g25g275g30gG >> +075+1+125H // 225g25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[8/45] 1. -075-025H // 20g225g25g275gG >> -075-025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[9/45] 1. -025+0+025H // 175g20g225g25gG >> -025+0+025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[10/45] 1. -125-1-075H // 175g20g225g25g275gG >> -15-125-1-075H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[11/45] 1. -125-1-075-025H // 225g25g275g30g325gG >> -075-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[12/45] 1. -025+0H // 15g175g20g225gG >> -075-025+0H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[13/45] 1. -025+0+025H // 175g20g225g25g275gG >> -025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[14/45] 1. -025+0+025H // 175g20g225g25gG >> +0+025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[15/45] 1. -1-075-025H // 20g225g25g275gG >> -125-1-075-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[16/45] 1. -025+0+025H // 175g20g225g25g275gG >> -075-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[17/45] 1. -075-025H // 175g20g225g25gG >> -075-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[18/45] 1. +0+025+075H // 20g225g25g275gG >> +0+025+075H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[19/45] 1. +0+025+075H // 175g20g225g25gG >> +0+025+075H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[20/45] 1. -175-15-125-1H // 20g225g25g275gG >> -175-15-125-1H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[21/45] 1. -075-025+0H // 15g175g20g225g25gG >> -075-025+0H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[22/45] 1. -15-125-1-075H // 225g25g275g30g325gG >> -15-125-1-075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[23/45] 1. -125-1-075H // 175g20g225g25gG >> -125-1-075H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[24/45] 1. -025+0H // 15g175g20g225g25gG >> -025+0H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[25/45] 1. -075-025H // 15g175g20g225gG >> -125-1-075H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like '-075-025H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '-125-1-075H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[26/45] 1. -025+0+025H // 175g20g225g25gG >> -025+0+025H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[27/45] 1. +0H // 25gG >> +0+025+075H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[28/45] 1. +075+1+125H // 20g225g25g275gG >> +075+1+125H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like '+075+1+125H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '+075+1+125H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[29/45] 1. +0H // 25gG >> -025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[30/45] 1. -025+0+025H // 225g25g275g30gG >> -025+0+025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[31/45] 1. -025+0+025H // 15g175g20g225g25gG >> -025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[32/45] 1. -075-025H // 225g25g275g30gG >> -125-1-075-025H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like '-075-025H'  and `pre_gou_pattern` like '225g25g275g30gG'  and `end_ah_pattern` like '-125-1-075-025H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_from update done
#   ______________[33/45] 1. -075-025H // 225g25g275g30gG >> -075-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[34/45] 1. -075-025H // 175g20g225g25g275gG >> -075-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[35/45] 1. +0+025H // 15g175g20g225gG >> +0+025+075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like '+0+025H'  and `pre_gou_pattern` like '15g175g20g225gG'  and `end_ah_pattern` like '+0+025+075H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[36/45] 1. -1-075-025H // 175g20g225g25gG >> -15-125-1-075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[37/45] 1. +025+075H // 225g25g275g30gG >> +025+075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[38/45] 1. -1-075H // 15g175g20g225g25gG >> -125-1-075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[39/45] 1. -075-025H // 175g20g225g25g275gG >> -1-075-025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[40/45] 1. -1-075-025H // 225g25g275g30g325gG >> -1-075-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[41/45] 1. -075-025H // 175g20g225g25gG >> -075-025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[42/45] 1. -075-025H // 20g225g25g275gG >> -1-075-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[43/45] 1. -125-1-075H // 175g20g225g25gG >> -125-1-075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[44/45] 1. +075+1+125+15+175H // 225g25g275g30gG >> +075+1+125+15+175H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[45/45] 1. +025+075H // 175g20g225g25gG >> -025+0+025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ________ff_get_fixtures_group_by_only_end_patternlists()
#   ____________Total Row(s) : 37
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_only_ends = '37'  where leagueapi_id = '906'
#   ________________> football_leagues : total_pattern_only_ends UPDATED
#   ______________[1/37] 8.  >> -025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 8
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[2/37] 5.  >> -025+0+025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[3/37] 5.  >> -075-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[4/37] 5.  >> -025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[5/37] 3.  >> -075-025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[6/37] 3.  >> -075-025H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-025H'  and `end_gou_pattern` like '15g175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[7/37] 3.  >> -125-1-075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[8/37] 2.  >> +025+075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+075H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[9/37] 2.  >> -025+0+025H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[10/37] 2.  >> -025+0+025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[11/37] 2.  >> -1-075-025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[12/37] 2.  >> -1-075-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[13/37] 2.  >> -125-1-075H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[14/37] 2.  >> -075-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[15/37] 2.  >> -125-1-075-025H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-025H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[16/37] 2.  >> -075-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[17/37] 2.  >> -075-025+0H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[18/37] 1.  >> -025+0H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[19/37] 1.  >> -025+0+025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[20/37] 1.  >> +0+025+075H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[21/37] 1.  >> +0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[22/37] 1.  >> -15-125-1-075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[23/37] 1.  >> -1-075-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[24/37] 1.  >> +0+025+075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+075H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[25/37] 1.  >> -1-075-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[26/37] 1.  >> +075+1+125H // 225g25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[27/37] 1.  >> +075+1+125+15+175H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[28/37] 1.  >> -125-1-075-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[29/37] 1.  >> +0+025+075H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[30/37] 1.  >> +0+025+075H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[31/37] 1.  >> -15-125-1-075H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[32/37] 1.  >> +0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[33/37] 1.  >> +0+025H // 175g20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[34/37] 1.  >> +075+1+125H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 906  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+075+1+125H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[35/37] 1.  >> +0+025+075H // 15g175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[36/37] 1.  >> -175-15-125-1H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[37/37] 1.  >> -15-125-1-075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
# # -------------------------------------------------- End at 2023-07-27 08:44:27
