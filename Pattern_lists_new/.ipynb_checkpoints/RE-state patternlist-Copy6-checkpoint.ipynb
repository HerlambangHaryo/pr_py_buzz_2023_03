# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 06:37:22
#   ____main__
#   ______Enter your leagueapi id :  347
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 9
#   ______________[1/9]  #347 - 2021 => 0 / None == Match Finished
#   ______________[2/9]  #347 - 2021 => 3 / None == Match Finished
#   ______________[3/9]  #347 - 2022 => 0 / None == Match Finished
#   ______________[4/9]  #347 - 2022 => 0 / 2 == Match Finished
#   ______________[5/9]  #347 - 2022 => 0 / 3 == Match Finished
#   ______________[6/9]  #347 - 2022 => 2 / None == Match Finished
#   ______________[7/9]  #347 - 2022 => 2 / 2 == Match Finished
#   ______________[8/9]  #347 - 2022 => 2 / 2 == Match Finished Ended
#   ______________[9/9]  #347 - 2022 => 2 / 3 == Match Finished
# # -------------------------------------------------- End at 2023-07-27 06:50:31

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 06:50:31
#   __main()
#   ____Enter your leagueapi id :  347
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '347'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '347'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 155
#   __________[1/155] #853784 #347 - 2021
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 853784
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[2/155] #898297 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898297
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[3/155] #898295 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898295
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[4/155] #898296 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898296
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[5/155] #898249 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898249
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[6/155] #898263 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898263
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[7/155] #898264 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898264
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[8/155] #898250 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898250
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[9/155] #898258 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898258
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[10/155] #898265 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898265
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[11/155] #898291 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898291
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[12/155] #898276 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898276
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[13/155] #898251 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898251
#   ____________> pre_ah_pattern = -025+0+025+05+075H
#   ____________> pre_ah_pattern_mirror = -075-05-025+0+025H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[14/155] #898252 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898252
#   ____________> pre_ah_pattern = -15-125-1-075-05H
#   ____________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[15/155] #898254 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898254
#   ____________> pre_ah_pattern = +0+025+05+075H
#   ____________> pre_ah_pattern_mirror = -075-05-025+0H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[16/155] #898256 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898256
#   ____________> pre_ah_pattern = +025+05+075+1H
#   ____________> pre_ah_pattern_mirror = -1-075-05-025H
#   ____________> pre_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[17/155] #898260 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898260
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[18/155] #898288 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898288
#   ____________> pre_ah_pattern = -05-025+0+025+05H
#   ____________> pre_ah_pattern_mirror = -05-025+0+025+05H
#   ____________> pre_gou_pattern = 275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[19/155] #898257 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898257
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[20/155] #898259 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898259
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[21/155] #898261 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898261
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[22/155] #898262 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898262
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[23/155] #898266 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898266
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[24/155] #898267 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898267
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[25/155] #898268 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898268
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[26/155] #898270 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898270
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[27/155] #898272 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898272
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[28/155] #898273 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898273
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[29/155] #898274 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898274
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[30/155] #898275 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898275
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[31/155] #898277 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898277
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[32/155] #898279 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898279
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[33/155] #898280 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898280
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[34/155] #898281 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898281
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[35/155] #898282 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898282
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[36/155] #898283 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898283
#   ____________> pre_ah_pattern = +05+075+1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1-075-05H
#   ____________> pre_gou_pattern = 30g325g35g375g40gG
#   ____________> football_odds update pattern commited
#   __________[37/155] #898284 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898284
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[38/155] #898286 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898286
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[39/155] #898287 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898287
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[40/155] #898289 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898289
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[41/155] #898290 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898290
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[42/155] #898292 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898292
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[43/155] #898269 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898269
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[44/155] #898278 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898278
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[45/155] #898293 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898293
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[46/155] #898294 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898294
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[47/155] #898255 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898255
#   ____________> pre_ah_pattern = +025+05+075+1H
#   ____________> pre_ah_pattern_mirror = -1-075-05-025H
#   ____________> pre_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[48/155] #898285 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898285
#   ____________> pre_ah_pattern = +075+1+125+15+175H
#   ____________> pre_ah_pattern_mirror = -175-15-125-1-075H
#   ____________> pre_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[49/155] #898253 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898253
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[50/155] #898271 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 898271
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[51/155] #946954 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946954
#   ____________> pre_ah_pattern = +175H
#   ____________> pre_ah_pattern_mirror = -175H
#   ____________> pre_gou_pattern = 325g35gG
#   ____________> football_odds update pattern commited
#   __________[52/155] #946960 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946960
#   ____________> pre_ah_pattern = +25+275H
#   ____________> pre_ah_pattern_mirror = -275-25H
#   ____________> pre_gou_pattern = 35g375g45gG
#   ____________> football_odds update pattern commited
#   __________[53/155] #946964 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946964
#   ____________> pre_ah_pattern = +15H
#   ____________> pre_ah_pattern_mirror = -15H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[54/155] #946957 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946957
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[55/155] #946965 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946965
#   ____________> pre_ah_pattern = +225H
#   ____________> pre_ah_pattern_mirror = -225H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[56/155] #946970 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946970
#   ____________> pre_ah_pattern = +15H
#   ____________> pre_ah_pattern_mirror = -15H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[57/155] #946955 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946955
#   ____________> pre_ah_pattern = +2H
#   ____________> pre_ah_pattern_mirror = -2H
#   ____________> pre_gou_pattern = 40g45gG
#   ____________> football_odds update pattern commited
#   __________[58/155] #946956 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946956
#   ____________> pre_ah_pattern = +25+275H
#   ____________> pre_ah_pattern_mirror = -275-25H
#   ____________> pre_gou_pattern = 35g45gG
#   ____________> football_odds update pattern commited
#   __________[59/155] #962758 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962758
#   ____________> pre_ah_pattern = -125H
#   ____________> pre_ah_pattern_mirror = +125H
#   ____________> pre_gou_pattern = 325gG
#   ____________> football_odds update pattern commited
#   __________[60/155] #962761 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962761
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[61/155] #962762 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962762
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[62/155] #962752 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962752
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[63/155] #962754 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962754
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[64/155] #962755 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962755
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[65/155] #962759 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962759
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[66/155] #962764 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962764
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[67/155] #962765 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962765
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[68/155] #962766 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962766
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[69/155] #962763 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962763
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[70/155] #962753 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962753
#   ____________> pre_ah_pattern = -175H
#   ____________> pre_ah_pattern_mirror = +175H
#   ____________> pre_gou_pattern = 35g375gG
#   ____________> football_odds update pattern commited
#   __________[71/155] #962756 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962756
#   ____________> pre_ah_pattern = -2H
#   ____________> pre_ah_pattern_mirror = +2H
#   ____________> pre_gou_pattern = 35g375gG
#   ____________> football_odds update pattern commited
#   __________[72/155] #962767 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962767
#   ____________> pre_ah_pattern = +2+225H
#   ____________> pre_ah_pattern_mirror = -225-2H
#   ____________> pre_gou_pattern = 375gG
#   ____________> football_odds update pattern commited
#   __________[73/155] #962760 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962760
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[74/155] #962757 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962757
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[75/155] #970208 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970208
#   ____________> pre_ah_pattern = +0+025H
#   ____________> pre_ah_pattern_mirror = -025+0H
#   ____________> pre_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[76/155] #995828 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995828
#   ____________> pre_ah_pattern = +0H
#   ____________> pre_ah_pattern_mirror = +0H
#   ____________> pre_gou_pattern = 25g275gG
#   ____________> football_odds update pattern commited
#   __________[77/155] #1005234 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1005234
#   ____________> pre_ah_pattern = -025H
#   ____________> pre_ah_pattern_mirror = +025H
#   ____________> pre_gou_pattern = 25g30gG
#   ____________> football_odds update pattern commited
#   __________[78/155] #995827 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995827
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[79/155] #995826 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995826
#   ____________> pre_ah_pattern = -25H
#   ____________> pre_ah_pattern_mirror = +25H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[80/155] #1013674 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1013674
#   ____________> pre_ah_pattern = -2H
#   ____________> pre_ah_pattern_mirror = +2H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[81/155] #1013675 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1013675
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[82/155] #1020769 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1020769
#   ____________> pre_ah_pattern = -05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05H
#   ____________> pre_gou_pattern = 25g275gG
#   ____________> football_odds update pattern commited
#   __________[83/155] #922090 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 922090
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[84/155] #922091 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 922091
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[85/155] #922092 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 922092
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[86/155] #929881 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929881
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[87/155] #929882 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929882
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[88/155] #929883 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929883
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[89/155] #929884 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929884
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[90/155] #929885 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929885
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[91/155] #929886 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929886
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[92/155] #929887 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929887
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[93/155] #929888 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929888
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[94/155] #929889 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929889
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[95/155] #929890 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929890
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[96/155] #929891 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929891
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[97/155] #929892 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929892
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[98/155] #929893 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929893
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[99/155] #929894 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929894
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[100/155] #929895 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929895
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[101/155] #929896 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929896
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[102/155] #929897 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929897
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[103/155] #929898 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929898
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[104/155] #929899 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929899
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[105/155] #929900 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929900
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[106/155] #929901 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929901
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[107/155] #929902 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929902
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[108/155] #929903 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929903
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[109/155] #929904 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929904
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[110/155] #929905 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929905
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[111/155] #929906 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929906
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[112/155] #929907 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929907
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[113/155] #929908 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929908
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[114/155] #929909 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929909
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[115/155] #929910 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929910
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[116/155] #929911 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929911
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[117/155] #929912 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929912
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[118/155] #929913 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929913
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[119/155] #929914 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929914
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[120/155] #929915 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929915
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[121/155] #929916 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929916
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[122/155] #929917 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929917
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[123/155] #929918 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929918
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[124/155] #929919 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929919
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[125/155] #929920 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929920
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[126/155] #929921 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929921
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[127/155] #930611 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 930611
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[128/155] #933537 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 933537
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[129/155] #933538 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 933538
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[130/155] #946945 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946945
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[131/155] #946946 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946946
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[132/155] #946947 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946947
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[133/155] #946948 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946948
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[134/155] #946949 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946949
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[135/155] #946950 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946950
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[136/155] #946951 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946951
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[137/155] #946952 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946952
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[138/155] #946953 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946953
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[139/155] #946958 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946958
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[140/155] #946959 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946959
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[141/155] #946961 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946961
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[142/155] #946962 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946962
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[143/155] #946963 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946963
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[144/155] #946966 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946966
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[145/155] #946967 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946967
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[146/155] #946968 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946968
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[147/155] #946969 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946969
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[148/155] #946971 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946971
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[149/155] #970201 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970201
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[150/155] #970202 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970202
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[151/155] #970203 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970203
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[152/155] #970204 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970204
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[153/155] #970205 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970205
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[154/155] #970206 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970206
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[155/155] #970207 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970207
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '347'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '347'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 244
#   __________[1/244] #962760 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962760
#   ____________> end_ah_pattern = +15+175+2+225+25H
#   ____________> end_ah_pattern_mirror = -25-225-2-175-15H
#   ____________> end_gou_pattern = 325g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[2/244] #962757 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 962757
#   ____________> end_ah_pattern = -175-15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> end_gou_pattern = 275g30g325g375gG
#   ____________> football_odds update pattern commited
#   __________[3/244] #970208 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970208
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[4/244] #995828 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995828
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 25g275gG
#   ____________> football_odds update pattern commited
#   __________[5/244] #1005234 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1005234
#   ____________> end_ah_pattern = -025H
#   ____________> end_ah_pattern_mirror = +025H
#   ____________> end_gou_pattern = 25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[6/244] #995827 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995827
#   ____________> end_ah_pattern = -025H
#   ____________> end_ah_pattern_mirror = +025H
#   ____________> end_gou_pattern = 25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[7/244] #995826 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995826
#   ____________> end_ah_pattern = -275-25H
#   ____________> end_ah_pattern_mirror = +25+275H
#   ____________> end_gou_pattern = 35g375gG
#   ____________> football_odds update pattern commited
#   __________[8/244] #1013674 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1013674
#   ____________> end_ah_pattern = -225-2H
#   ____________> end_ah_pattern_mirror = +2+225H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[9/244] #1013675 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1013675
#   ____________> end_ah_pattern = -15H
#   ____________> end_ah_pattern_mirror = +15H
#   ____________> end_gou_pattern = 25g30g35gG
#   ____________> football_odds update pattern commited
#   __________[10/244] #1020769 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1020769
# ...
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929894
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[189/244] #929895 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929895
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[190/244] #929896 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929896
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[191/244] #929897 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929897
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[192/244] #929898 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929898
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[193/244] #929899 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929899
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[194/244] #929900 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929900
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[195/244] #929901 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929901
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[196/244] #929902 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929902
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[197/244] #929903 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929903
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[198/244] #929904 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929904
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[199/244] #929905 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929905
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[200/244] #929906 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929906
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[201/244] #929907 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929907
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[202/244] #929908 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929908
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[203/244] #929909 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929909
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[204/244] #929910 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929910
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[205/244] #929911 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929911
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[206/244] #929912 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929912
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[207/244] #929913 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929913
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[208/244] #929914 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929914
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[209/244] #929915 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929915
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[210/244] #929916 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929916
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[211/244] #929917 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929917
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[212/244] #929918 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929918
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[213/244] #929919 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929919
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[214/244] #929920 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929920
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[215/244] #929921 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 929921
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[216/244] #930611 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 930611
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[217/244] #933537 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 933537
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[218/244] #933538 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 933538
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[219/244] #946945 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946945
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[220/244] #946946 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946946
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[221/244] #946947 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946947
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[222/244] #946948 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946948
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[223/244] #946949 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946949
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[224/244] #946950 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946950
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[225/244] #946951 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946951
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[226/244] #946952 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946952
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[227/244] #946953 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946953
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[228/244] #946958 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946958
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[229/244] #946959 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946959
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[230/244] #946961 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946961
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[231/244] #946962 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946962
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[232/244] #946963 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946963
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[233/244] #946966 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946966
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[234/244] #946967 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946967
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[235/244] #946968 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946968
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[236/244] #946969 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946969
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[237/244] #946971 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 946971
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[238/244] #970201 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970201
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[239/244] #970202 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970202
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[240/244] #970203 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970203
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[241/244] #970204 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970204
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[242/244] #970205 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970205
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[243/244] #970206 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970206
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[244/244] #970207 #347 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 970207
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-27 09:03:34

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 09:03:34
#   ____main__
#   ______Enter your leagueapi id :  347
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 3
#   ______________[1/3]  #347 - 2021 => 3 / 3 == Match Finished
#   ______________[2/3]  #347 - 2022 => 3 / 3 == Match Finished
#   ______________[3/3]  #347 - 2022 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-27 09:48:25

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 09:48:25
#   ____main__
#   ______Enter your leagueapi id :  347
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '347'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 22
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '22'  where leagueapi_id = '347'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/22] 2. +15H // 35gG >> +15H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+15H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '+15H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[2/22] 1. +025+05+075+1H // 30g325g35g375gG >> +025+05+075+1H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+025+05+075+1H'  and `pre_gou_pattern` like '30g325g35g375gG'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_from update done
#   ______________[3/22] 1. +075+1+125+15+175H // 275g30g325g35g375gG >> +075+1+125+15+175H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+075+1+125+15+175H'  and `pre_gou_pattern` like '275g30g325g35g375gG'  and `end_ah_pattern` like '+075+1+125+15+175H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_from update done
#   ______________[4/22] 1. +175H // 325g35gG >> +175H // 325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+175H'  and `pre_gou_pattern` like '325g35gG'  and `end_ah_pattern` like '+175H'  and `end_gou_pattern` like '325g35gG'
#   __________________pattern_from update done
#   ______________[5/22] 1. +25+275H // 35g375g45gG >> +25+275H // 35g375g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+25+275H'  and `pre_gou_pattern` like '35g375g45gG'  and `end_ah_pattern` like '+25+275H'  and `end_gou_pattern` like '35g375g45gG'
#   __________________pattern_from update done
#   ______________[6/22] 1. +2H // 40g45gG >> +2H // 40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+2H'  and `pre_gou_pattern` like '40g45gG'  and `end_ah_pattern` like '+2H'  and `end_gou_pattern` like '40g45gG'
#   __________________pattern_from update done
#   ______________[7/22] 1. +25+275H // 35g45gG >> +25+275H // 35g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+25+275H'  and `pre_gou_pattern` like '35g45gG'  and `end_ah_pattern` like '+25+275H'  and `end_gou_pattern` like '35g45gG'
#   __________________pattern_from update done
#   ______________[8/22] 1. -125H // 325gG >> -175-15-125-1-075H // 275g30g325g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '-125H'  and `pre_gou_pattern` like '325gG'  and `end_ah_pattern` like '-175-15-125-1-075H'  and `end_gou_pattern` like '275g30g325g375gG'
#   __________________pattern_from update done
#   ______________[9/22] 1. -175H // 35g375gG >> -175H // 35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '-175H'  and `pre_gou_pattern` like '35g375gG'  and `end_ah_pattern` like '-175H'  and `end_gou_pattern` like '35g375gG'
#   __________________pattern_from update done
#   ______________[10/22] 1. -2H // 35g375gG >> -2H // 35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '-2H'  and `pre_gou_pattern` like '35g375gG'  and `end_ah_pattern` like '-2H'  and `end_gou_pattern` like '35g375gG'
#   __________________pattern_from update done
#   ______________[11/22] 1. -025+0+025+05+075H // 25g275g30g325g35gG >> -025+0+025+05+075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '-025+0+025+05+075H'  and `pre_gou_pattern` like '25g275g30g325g35gG'  and `end_ah_pattern` like '-025+0+025+05+075H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_from update done
#   ______________[12/22] 1. +0+025H // 25gG >> -025+0+025+05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+0+025H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_from update done
#   ______________[13/22] 1. -15-125-1-075-05H // 30g325g35g375gG >> -15-125-1-075-05H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '-15-125-1-075-05H'  and `pre_gou_pattern` like '30g325g35g375gG'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_from update done
#   ______________[14/22] 1. +0H // 25g275gG >> +0+025+05H // 25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+0H'  and `pre_gou_pattern` like '25g275gG'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '25g275gG'
#   __________________pattern_from update done
#   ______________[15/22] 1. +0+025+05+075H // 275g30g325g35gG >> +0+025+05+075H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+0+025+05+075H'  and `pre_gou_pattern` like '275g30g325g35gG'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_from update done
#   ______________[16/22] 1. -025H // 25g30gG >> -025H // 25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '-025H'  and `pre_gou_pattern` like '25g30gG'  and `end_ah_pattern` like '-025H'  and `end_gou_pattern` like '25g275g30gG'
#   __________________pattern_from update done
#   ______________[17/22] 1. +025+05+075+1H // 25g275g30g325g35gG >> +025+05+075+1H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+025+05+075+1H'  and `pre_gou_pattern` like '25g275g30g325g35gG'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_from update done
#   ______________[18/22] 1. -25H // 35gG >> -275-25H // 35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '-25H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-275-25H'  and `end_gou_pattern` like '35g375gG'
#   __________________pattern_from update done
#   ______________[19/22] 1. -05-025+0+025+05H // 275g30g325g35gG >> -05-025+0+025+05H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '-05-025+0+025+05H'  and `pre_gou_pattern` like '275g30g325g35gG'  and `end_ah_pattern` like '-05-025+0+025+05H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_from update done
#   ______________[20/22] 1. -2H // 35gG >> -225-2H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '-2H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-225-2H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[21/22] 1. +05+075+1+125+15H // 30g325g35g375g40gG >> +05+075+1+125+15H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like '+05+075+1+125+15H'  and `pre_gou_pattern` like '30g325g35g375g40gG'  and `end_ah_pattern` like '+05+075+1+125+15H'  and `end_gou_pattern` like '30g325g35g375g40gG'
#   __________________pattern_from update done
#   ______________[22/22] 1. -05-025+0H // 25g275gG >> -025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ________ff_get_fixtures_group_by_only_end_patternlists()
#   ____________Total Row(s) : 37
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_only_ends = '37'  where leagueapi_id = '347'
#   ________________> football_leagues : total_pattern_only_ends UPDATED
#   ______________[1/37] 2.  >> +15H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+15H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_only update done
#   ______________[2/37] 2.  >> -2H // 35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-2H'  and `end_gou_pattern` like '35g375gG'
#   __________________pattern_only update done
#   ______________[3/37] 2.  >> -175-15-125-1-075H // 275g30g325g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1-075H'  and `end_gou_pattern` like '275g30g325g375gG'
#   __________________pattern_only update done
#   ______________[4/37] 2.  >> +025+05+075+1H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[5/37] 2.  >> -025H // 25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025H'  and `end_gou_pattern` like '25g275g30gG'
#   __________________pattern_only update done
#   ______________[6/37] 1.  >> +075H // 25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+075H'  and `end_gou_pattern` like '25g275gG'
#   __________________pattern_only update done
#   ______________[7/37] 1.  >> +05+075+1+125H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1+125H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[8/37] 1.  >> -225-2H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-225-2H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_only update done
#   ______________[9/37] 1.  >> +25+275H // 35g375g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+25+275H'  and `end_gou_pattern` like '35g375g45gG'
#   __________________pattern_only update done
#   ______________[10/37] 1.  >> +225+25H // 45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+225+25H'  and `end_gou_pattern` like '45gG'
#   __________________pattern_only update done
#   ______________[11/37] 1.  >> -025+0+025+05+075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05+075H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[12/37] 1.  >> -15H // 25g30g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15H'  and `end_gou_pattern` like '25g30g35gG'
#   __________________pattern_only update done
#   ______________[13/37] 1.  >> +25H // 35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+25H'  and `end_gou_pattern` like '35g375g40gG'
#   __________________pattern_only update done
#   ______________[14/37] 1.  >> -15-125-1-075-05H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[15/37] 1.  >> -025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[16/37] 1.  >> +2H // 40g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+2H'  and `end_gou_pattern` like '40g45gG'
#   __________________pattern_only update done
#   ______________[17/37] 1.  >> +0+025+05+075H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[18/37] 1.  >> +25+275H // 35g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+25+275H'  and `end_gou_pattern` like '35g45gG'
#   __________________pattern_only update done
#   ______________[19/37] 1.  >> -175H // 325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175H'  and `end_gou_pattern` like '325g35gG'
#   __________________pattern_only update done
#   ______________[20/37] 1.  >> +025+05+075+1H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[21/37] 1.  >> -175H // 35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175H'  and `end_gou_pattern` like '35g375gG'
#   __________________pattern_only update done
#   ______________[22/37] 1.  >> -05-025+0+025+05H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025+05H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[23/37] 1.  >> +175+2H // 325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+175+2H'  and `end_gou_pattern` like '325gG'
#   __________________pattern_only update done
#   ______________[24/37] 1.  >> +15+175+2+225+25H // 325g375g40g425gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+15+175+2+225+25H'  and `end_gou_pattern` like '325g375g40g425gG'
#   __________________pattern_only update done
#   ______________[25/37] 1.  >> +05+075+1+125+15H // 30g325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1+125+15H'  and `end_gou_pattern` like '30g325g35g375g40gG'
#   __________________pattern_only update done
#   ______________[26/37] 1.  >> -025+0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[27/37] 1.  >> -025+0+025+05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[28/37] 1.  >> +15+175H // 325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+15+175H'  and `end_gou_pattern` like '325g35gG'
#   __________________pattern_only update done
#   ______________[29/37] 1.  >> +0+025+05H // 25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '25g275gG'
#   __________________pattern_only update done
#   ______________[30/37] 1.  >> -05H // 325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05H'  and `end_gou_pattern` like '325gG'
#   __________________pattern_only update done
#   ______________[31/37] 1.  >> +125H // 35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+125H'  and `end_gou_pattern` like '35g375gG'
#   __________________pattern_only update done
#   ______________[32/37] 1.  >> -05-025+0+025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[33/37] 1.  >> +075+1+125+15+175H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+075+1+125+15+175H'  and `end_gou_pattern` like '275g30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[34/37] 1.  >> +2H // 35g375g425gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+2H'  and `end_gou_pattern` like '35g375g425gG'
#   __________________pattern_only update done
#   ______________[35/37] 1.  >> -1-075-05-025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[36/37] 1.  >> -275-25H // 35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-275-25H'  and `end_gou_pattern` like '35g375gG'
#   __________________pattern_only update done
#   ______________[37/37] 1.  >> +175H // 325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 347  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+175H'  and `end_gou_pattern` like '325g35gG'
#   __________________pattern_only update done
# # -------------------------------------------------- End at 2023-07-27 10:06:43
