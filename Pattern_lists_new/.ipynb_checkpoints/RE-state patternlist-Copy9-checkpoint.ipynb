# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-22 23:52:12
#   ____main__
#   ______Enter your leagueapi id :  473
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 16
#   ______________[1/16]  #473 - 2022 => 0 / None == Match Finished
#   ______________[2/16]  #473 - 2022 => 0 / 3 == Match Finished
#   ______________[3/16]  #473 - 2022 => 2 / None == Match Finished
#   ______________[4/16]  #473 - 2022 => 2 / 3 == Match Finished
#   ______________[5/16]  #473 - 2022 => 3 / None == Match Finished
#   ______________[6/16]  #473 - 2023 => 0 / None == Match Finished
#   ______________[7/16]  #473 - 2023 => 0 / 1 == Match Finished Ended
#   ______________[8/16]  #473 - 2023 => 0 / 2 == Match Finished
#   ______________[9/16]  #473 - 2023 => 0 / 2 == Match Finished Ended
#   ______________[10/16]  #473 - 2023 => 1 / 1 == Match Finished Ended
#   ______________[11/16]  #473 - 2023 => 2 / None == Match Finished
#   ______________[12/16]  #473 - 2023 => 2 / 1 == Match Finished Ended
#   ______________[13/16]  #473 - 2023 => 2 / 2 == Match Finished
#   ______________[14/16]  #473 - 2023 => 2 / 2 == Match Finished Ended
#   ______________[15/16]  #473 - 2023 => 3 / None == Match Finished
#   ______________[16/16]  #473 - 2023 => 3 / 1 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-22 23:55:07

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-22 23:55:07
#   __main()
#   ____Enter your leagueapi id :  473
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '473'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '473'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 191
#   __________[1/191] #832505 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832505
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[2/191] #832507 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832507
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[3/191] #832506 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832506
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[4/191] #832514 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832514
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[5/191] #832517 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832517
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[6/191] #832515 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832515
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[7/191] #832518 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832518
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[8/191] #832516 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832516
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[9/191] #832512 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832512
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[10/191] #832513 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832513
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[11/191] #832519 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832519
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[12/191] #832525 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832525
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[13/191] #832523 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832523
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[14/191] #832524 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832524
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[15/191] #832521 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832521
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[16/191] #832522 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832522
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[17/191] #832520 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832520
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[18/191] #832532 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832532
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[19/191] #832527 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832527
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[20/191] #832526 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832526
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[21/191] #832528 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832528
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[22/191] #832531 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832531
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[23/191] #832530 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832530
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[24/191] #832529 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832529
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[25/191] #832536 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832536
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[26/191] #832539 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832539
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[27/191] #832533 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832533
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[28/191] #832537 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832537
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[29/191] #832534 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832534
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[30/191] #832535 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832535
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[31/191] #832538 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832538
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[32/191] #832540 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832540
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[33/191] #832545 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832545
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[34/191] #832541 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832541
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[35/191] #832543 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832543
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[36/191] #832544 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832544
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[37/191] #832546 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832546
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[38/191] #832549 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832549
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[39/191] #832551 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832551
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[40/191] #832550 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832550
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[41/191] #832552 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832552
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[42/191] #832548 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832548
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[43/191] #832547 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832547
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[44/191] #832557 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832557
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[45/191] #832556 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832556
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[46/191] #832554 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832554
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[47/191] #832558 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832558
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[48/191] #832559 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832559
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[49/191] #832555 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832555
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[50/191] #832563 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832563
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[51/191] #832566 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832566
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[52/191] #832561 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832561
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[53/191] #832564 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832564
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[54/191] #832565 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832565
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[55/191] #832562 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832562
#   ____________> pre_ah_pattern = -025+0+025+05+075H
#   ____________> pre_ah_pattern_mirror = -075-05-025+0+025H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[56/191] #832569 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832569
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[57/191] #832572 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832572
#   ____________> pre_ah_pattern = -1-075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075+1H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[58/191] #832574 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832574
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[59/191] #832573 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832573
#   ____________> pre_ah_pattern = +05+075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075-05H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[60/191] #832568 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832568
#   ____________> pre_ah_pattern = -15-125-1-075-05H
#   ____________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[61/191] #832570 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832570
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[62/191] #832578 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832578
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[63/191] #832580 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832580
#   ____________> pre_ah_pattern = +025+05+075+1H
#   ____________> pre_ah_pattern_mirror = -1-075-05-025H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[64/191] #832575 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832575
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[65/191] #832577 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832577
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[66/191] #832576 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832576
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[67/191] #832579 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832579
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[68/191] #832588 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832588
#   ____________> pre_ah_pattern = -025H
#   ____________> pre_ah_pattern_mirror = +025H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[69/191] #832583 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832583
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[70/191] #832587 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832587
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[71/191] #832585 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832585
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[72/191] #832584 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832584
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[73/191] #832586 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832586
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[74/191] #832592 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832592
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[75/191] #832594 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832594
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[76/191] #832589 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832589
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[77/191] #832590 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832590
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[78/191] #832591 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832591
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[79/191] #832593 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832593
#   ____________> pre_ah_pattern = -025+0+025+05H
#   ____________> pre_ah_pattern_mirror = -05-025+0+025H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[80/191] #832597 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832597
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[81/191] #832600 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832600
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[82/191] #832596 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832596
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[83/191] #832598 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832598
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[84/191] #832602 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832602
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[85/191] #832601 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832601
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[86/191] #832605 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832605
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[87/191] #832603 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832603
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[88/191] #832606 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832606
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[89/191] #832608 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832608
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[90/191] #832607 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832607
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[91/191] #832604 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832604
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[92/191] #832615 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832615
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[93/191] #832610 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832610
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[94/191] #832611 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832611
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[95/191] #832613 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832613
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[96/191] #832612 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832612
#   ____________> pre_ah_pattern = -15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[97/191] #832614 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832614
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+05H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[98/191] #832622 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832622
#   ____________> pre_ah_pattern = -05-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+05H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[99/191] #832617 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832617
#   ____________> pre_ah_pattern = -25-225-2-175-15H
#   ____________> pre_ah_pattern_mirror = +15+175+2+225+25H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[100/191] #832620 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832620
#   ____________> pre_ah_pattern = -1-075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075+1H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[101/191] #832619 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832619
#   ____________> pre_ah_pattern = -15-125-1-075-05H
#   ____________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[102/191] #832618 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832618
#   ____________> pre_ah_pattern = -175-15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[103/191] #832621 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832621
#   ____________> pre_ah_pattern = +025+05+075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075-05-025H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[104/191] #832625 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832625
#   ____________> pre_ah_pattern = -025+0+025+05H
#   ____________> pre_ah_pattern_mirror = -05-025+0+025H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[105/191] #832630 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832630
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[106/191] #832628 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832628
#   ____________> pre_ah_pattern = -05-025+0+025+05H
#   ____________> pre_ah_pattern_mirror = -05-025+0+025+05H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[107/191] #832624 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832624
#   ____________> pre_ah_pattern = -15-125-1-075-05H
#   ____________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[108/191] #832626 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832626
#   ____________> pre_ah_pattern = -175-15-125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[109/191] #832627 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832627
#   ____________> pre_ah_pattern = -025+0+025+05H
#   ____________> pre_ah_pattern_mirror = -05-025+0+025H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[110/191] #832631 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832631
#   ____________> pre_ah_pattern = -2-175-15-125H
#   ____________> pre_ah_pattern_mirror = +125+15+175+2H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[111/191] #832636 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832636
#   ____________> pre_ah_pattern = -025+0+025+05H
#   ____________> pre_ah_pattern_mirror = -05-025+0+025H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[112/191] #832633 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832633
#   ____________> pre_ah_pattern = +025+05+075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075-05-025H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[113/191] #832635 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832635
#   ____________> pre_ah_pattern = +025+05+075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075-05-025H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[114/191] #832634 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832634
#   ____________> pre_ah_pattern = -025+0+025+05H
#   ____________> pre_ah_pattern_mirror = -05-025+0+025H
#   ____________> pre_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[115/191] #832643 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832643
#   ____________> pre_ah_pattern = -075-05-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[116/191] #832641 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832641
#   ____________> pre_ah_pattern = +025+05+075+1+125H
#   ____________> pre_ah_pattern_mirror = -125-1-075-05-025H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[117/191] #832644 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832644
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[118/191] #832640 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832640
#   ____________> pre_ah_pattern = -325-3-275-25-225H
#   ____________> pre_ah_pattern_mirror = +225+25+275+3+325H
#   ____________> pre_gou_pattern = 45gG
#   ____________> football_odds update pattern commited
#   __________[119/191] #832638 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832638
#   ____________> pre_ah_pattern = -15-125-1-075-05H
#   ____________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[120/191] #832639 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832639
#   ____________> pre_ah_pattern = -1-075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075+1H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[121/191] #832649 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832649
#   ____________> pre_ah_pattern = +0+025+05+075H
#   ____________> pre_ah_pattern_mirror = -075-05-025+0H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[122/191] #832645 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832645
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[123/191] #832648 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832648
#   ____________> pre_ah_pattern = -1-075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075+1H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[124/191] #832651 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832651
#   ____________> pre_ah_pattern = +05+075+1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1-075-05H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[125/191] #832650 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832650
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[126/191] #832646 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832646
#   ____________> pre_ah_pattern = -075-05-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+05+075H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[127/191] #832632 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832632
#   ____________> pre_ah_pattern = -175-15-125-1H
#   ____________> pre_ah_pattern_mirror = +1+125+15+175H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[128/191] #832652 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832652
#   ____________> pre_ah_pattern = -1-075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075+1H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[129/191] #832653 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832653
#   ____________> pre_ah_pattern = -225-2-175-15-125H
#   ____________> pre_ah_pattern_mirror = +125+15+175+2+225H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[130/191] #832654 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832654
#   ____________> pre_ah_pattern = -15-125-1-075-05H
#   ____________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[131/191] #832655 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832655
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[132/191] #832656 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832656
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[133/191] #832657 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832657
#   ____________> pre_ah_pattern = -075-05-025+0+025H
#   ____________> pre_ah_pattern_mirror = -025+0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[134/191] #832659 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832659
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[135/191] #832660 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832660
#   ____________> pre_ah_pattern = -1-075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075+1H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[136/191] #832661 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832661
#   ____________> pre_ah_pattern = +05+075+1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1-075-05H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[137/191] #832662 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832662
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[138/191] #832663 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832663
#   ____________> pre_ah_pattern = +075+1+125+15H
#   ____________> pre_ah_pattern_mirror = -15-125-1-075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[139/191] #832664 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832664
#   ____________> pre_ah_pattern = +075+1+125+15+175H
#   ____________> pre_ah_pattern_mirror = -175-15-125-1-075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[140/191] #980095 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980095
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[141/191] #980096 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980096
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[142/191] #980097 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980097
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[143/191] #980098 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980098
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[144/191] #980094 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980094
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[145/191] #980099 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980099
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[146/191] #980100 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980100
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[147/191] #980101 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980101
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[148/191] #980103 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980103
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[149/191] #980102 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980102
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[150/191] #980104 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980104
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[151/191] #980105 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980105
#   ____________> pre_ah_pattern = -075-05-025+0H
#   ____________> pre_ah_pattern_mirror = +0+025+05+075H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[152/191] #980106 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980106
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[153/191] #980107 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980107
#   ____________> pre_ah_pattern = -275-25-225-2H
#   ____________> pre_ah_pattern_mirror = +2+225+25+275H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[154/191] #980115 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980115
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[155/191] #980117 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980117
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[156/191] #980116 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980116
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[157/191] #980119 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980119
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[158/191] #980118 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980118
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[159/191] #980120 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980120
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[160/191] #980121 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980121
#   ____________> pre_ah_pattern = -375-35-325-3-275-25H
#   ____________> pre_ah_pattern_mirror = +25+275+3+325+35+375H
#   ____________> pre_gou_pattern = 45gG
#   ____________> football_odds update pattern commited
#   __________[161/191] #980123 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980123
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   __________[162/191] #980124 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980124
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[163/191] #980125 #473 - 2023
#   ____________xpN_set_pattern()
# ...
#   ____________> fixtureapi_id = 832539
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[129/184] #832533 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832533
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[130/184] #832537 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832537
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[131/184] #832534 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832534
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[132/184] #832535 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832535
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[133/184] #832538 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832538
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[134/184] #832540 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832540
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[135/184] #832545 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832545
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[136/184] #832541 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832541
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[137/184] #832543 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832543
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[138/184] #832544 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832544
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[139/184] #832546 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832546
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[140/184] #832549 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832549
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[141/184] #832551 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832551
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[142/184] #832550 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832550
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[143/184] #832552 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832552
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[144/184] #832548 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832548
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[145/184] #832547 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832547
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[146/184] #832557 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832557
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[147/184] #832556 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832556
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[148/184] #832554 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832554
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[149/184] #832558 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832558
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[150/184] #832559 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832559
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[151/184] #832555 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832555
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[152/184] #832601 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832601
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[153/184] #832604 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832604
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[154/184] #832615 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832615
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[155/184] #832611 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832611
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[156/184] #832613 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832613
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[157/184] #832625 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832625
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[158/184] #832630 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832630
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[159/184] #832628 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832628
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[160/184] #832626 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832626
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[161/184] #832627 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832627
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[162/184] #832631 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832631
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[163/184] #832636 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832636
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[164/184] #832633 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832633
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[165/184] #832656 #473 - 2022
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 832656
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[166/184] #980095 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980095
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[167/184] #980096 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980096
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[168/184] #980097 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980097
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[169/184] #980098 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980098
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[170/184] #980094 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980094
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[171/184] #980104 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980104
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   __________[172/184] #980106 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980106
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[173/184] #980107 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980107
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[174/184] #980118 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980118
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   __________[175/184] #980108 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980108
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[176/184] #980109 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980109
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[177/184] #980110 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980110
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[178/184] #980111 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980111
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[179/184] #980112 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980112
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[180/184] #980113 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980113
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[181/184] #980114 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980114
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[182/184] #980162 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980162
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[183/184] #980163 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980163
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[184/184] #980174 #473 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 980174
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-23 02:46:11

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-23 02:46:11
#   ____main__
#   ______Enter your leagueapi id :  473
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 3
#   ______________[1/3]  #473 - 2022 => 3 / 3 == Match Finished
#   ______________[2/3]  #473 - 2023 => 3 / 3 == Match Finished
#   ______________[3/3]  #473 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-23 04:33:00

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-23 04:33:01
#   ____main__
#   ______Enter your leagueapi id :  473
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '473'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 73
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '73'  where leagueapi_id = '473'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/73] 4. -075-05-025+0H // 35gG >> -075-05-025+0H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025+0H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[2/73] 3. +025+05+075+1+125H // 35gG >> +025+05+075+1+125H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+025+05+075+1+125H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '+025+05+075+1+125H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[3/73] 3. -15-125-1-075-05H // 35gG >> -15-125-1-075-05H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-15-125-1-075-05H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[4/73] 3. -075-05-025+0+025H // 35gG >> -075-05-025+0+025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025+0+025H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-075-05-025+0+025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[5/73] 3. -2-175-15-125H // 35gG >> -2-175-15-125H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-2-175-15-125H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-2-175-15-125H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[6/73] 2. -1-075-05-025H // 35gG >> -1-075-05-025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[7/73] 2. -025+0+025+05H // 25gG >> -025+0+025+05H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-025+0+025+05H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[8/73] 2. -05-025+0+025+05H // 25gG >> -05-025+0+025+05H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-05-025+0+025+05H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '-05-025+0+025+05H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[9/73] 2. +075+1+125+15H // 35gG >> +075+1+125+15+175H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+075+1+125+15H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '+075+1+125+15+175H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[10/73] 2. -15-125-1-075H // 35gG >> -15-125-1-075-05H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-15-125-1-075H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[11/73] 2. -05-025+0+025+05H // 25g35gG >> -05-025+0+025+05H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-05-025+0+025+05H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '-05-025+0+025+05H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[12/73] 1. -175-15-125-1H // 35gG >> -2-175-15-125H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-175-15-125-1H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-2-175-15-125H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[13/73] 1. -15-125-1-075-05H // 35gG >> -2-175-15-125-1H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-15-125-1-075-05H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-2-175-15-125-1H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[14/73] 1. +025+05+075+1+125H // 25gG >> +05+075+1+125H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[15/73] 1. -15-125-1-075-05H // 35gG >> -125-1-075-05H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-15-125-1-075-05H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[16/73] 1. -1-075-05-025H // 35gG >> -125-1-075-05H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[17/73] 1. -1-075-05-025H // 25gG >> -125-1-075-05-025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '-125-1-075-05-025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[18/73] 1. -075-05-025H // 25gG >> -075-05-025H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[19/73] 1. -025+0+025+05+075H // 25g35gG >> -025+0+025+05+075H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-025+0+025+05+075H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '-025+0+025+05+075H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[20/73] 1. -175-15-125-1-075H // 35gG >> -15-125-1-075-05H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-175-15-125-1-075H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[21/73] 1. -225-2-175-15-125H // 35gG >> -25-225-2-175-15H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-225-2-175-15-125H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-25-225-2-175-15H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[22/73] 1. +025+05+075+1H // 25gG >> +025+05+075H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+025+05+075+1H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[23/73] 1. -05-025+0H // 25gG >> -05-025+0+025H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[24/73] 1. -1-075-05-025H // 25g35gG >> -1-075-05-025H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[25/73] 1. -075-05-025H // 35gG >> -1-075-05-025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[26/73] 1. +025+05+075H // 25gG >> +025+05+075H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+025+05+075H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[27/73] 1. -25-225-2-175-15H // 35gG >> -275-25-225-2-175H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[28/73] 1. -075-05-025H // 25g35gG >> -075-05-025H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[29/73] 1. -075-05-025+0H // 35gG >> -1-075-05-025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025+0H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[30/73] 1. -075-05-025+0+025H // 35gG >> +225+25+275+3+325+35H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[31/73] 1. -125-1-075-05H // 25g35gG >> -125-1-075-05H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[32/73] 1. +05+075+1+125H // 35gG >> +025+05+075+1+125H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+05+075+1+125H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '+025+05+075+1+125H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[33/73] 1. -025+0+025+05H // 25gG >> +0+025+05+075H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-025+0+025+05H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[34/73] 1. +05+075+1+125+15H // 25g35gG >> +125+15+175H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+05+075+1+125+15H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '+125+15+175H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[35/73] 1. -15-125-1-075H // 25g35gG >> -15-125-1-075H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[36/73] 1. -15-125-1-075-05H // 35gG >> -125-1-075-05-025H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-15-125-1-075-05H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-125-1-075-05-025H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[37/73] 1. -15-125-1-075H // 35gG >> -15-125-1-075H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-15-125-1-075H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[38/73] 1. -275-25-225-2-175H // 35gG >> -25-225-2-175-15H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[39/73] 1. +075+1+125+15+175H // 35gG >> +125+15+175+2H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+075+1+125+15+175H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '+125+15+175+2H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[40/73] 1. -2-175-15-125H // 35gG >> -25-225-2-175-15H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-2-175-15-125H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-25-225-2-175-15H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[41/73] 1. -075-05-025+0H // 25g35gG >> -15-125-1-075-05H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[42/73] 1. +025+05+075+1H // 25g35gG >> +05+075+1+125H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+025+05+075+1H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '+05+075+1+125H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[43/73] 1. -325-3-275-25-225H // 45gG >> -35-325-3-275-25H // 45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-325-3-275-25-225H'  and `pre_gou_pattern` like '45gG'  and `end_ah_pattern` like '-35-325-3-275-25H'  and `end_gou_pattern` like '45gG'
#   __________________pattern_from update done
#   ______________[44/73] 1. -075-05-025+0H // 25g35gG >> -075-05-025+0H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025+0H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[45/73] 1. -175-15-125-1H // 35gG >> -2-175-15-125H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-175-15-125-1H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-2-175-15-125H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[46/73] 1. +075+1+125+15H // 25g35gG >> +075+1+125+15H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[47/73] 1. -025H // 25g35gG >> -05-025+0+025+05H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-025H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '-05-025+0+025+05H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[48/73] 1. -15-125-1-075-05H // 35gG >> -175-15-125-1H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-15-125-1-075-05H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[49/73] 1. -075-05-025+0H // 35gG >> -05-025+0+025+05H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025+0H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-05-025+0+025+05H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[50/73] 1. -15-125-1-075-05H // 25g35gG >> -175-15-125-1-075H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[51/73] 1. -075-05-025+0+025H // 25g35gG >> -075-05-025+0+025H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[52/73] 1. -075-05-025+0H // 35gG >> -05-025+0+025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025+0H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[53/73] 1. -1-075-05-025H // 35gG >> -075-05-025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[54/73] 1. -375-35-325-3-275-25H // 45gG >> -4-375-35-325-3H // 45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-375-35-325-3-275-25H'  and `pre_gou_pattern` like '45gG'  and `end_ah_pattern` like '-4-375-35-325-3H'  and `end_gou_pattern` like '45gG'
#   __________________pattern_from update done
#   ______________[55/73] 1. +05+075+1+125+15H // 35gG >> +05+075+1+125H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+05+075+1+125+15H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '+05+075+1+125H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[56/73] 1. -025+0+025+05H // 25g35gG >> -025+0+025+05H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-025+0+025+05H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[57/73] 1. +0+025+05+075H // 35gG >> -025+0+025+05+075H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+0+025+05+075H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-025+0+025+05+075H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[58/73] 1. -125-1-075-05H // 25gG >> -15-125-1-075H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-125-1-075-05H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[59/73] 1. -15-125-1-075H // 35gG >> -1-075-05-025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-15-125-1-075H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[60/73] 1. -1-075-05-025H // 35gG >> -075-05-025+0H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-1-075-05-025H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[61/73] 1. -075-05-025H // 25gG >> -075-05-025+0H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[62/73] 1. -05-025+0+025H // 25gG >> -05-025+0+025H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-05-025+0+025H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[63/73] 1. -05-025+0+025H // 35gG >> -05-025+0+025+05H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-05-025+0+025H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-05-025+0+025+05H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
#   ______________[64/73] 1. +05+075+1+125+15H // 35gG >> +05+075+1+125+15H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+05+075+1+125+15H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '+05+075+1+125+15H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[65/73] 1. -125-1-075-05H // 25g35gG >> -175-15-125-1-075H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-125-1-075-05H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '-175-15-125-1-075H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[66/73] 1. -05-025+0+025H // 35gG >> -05-025+0+025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-05-025+0+025H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[67/73] 1. -075-05-025+0H // 35gG >> -075-05-025+0+025H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025+0H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-075-05-025+0+025H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_from update done
#   ______________[68/73] 1. +075+1+125+15H // 35gG >> +125+15+175H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '+075+1+125+15H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '+125+15+175H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[69/73] 1. -3-275-25-225-2H // 45gG >> -35-325-3-275-25-225H // 45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-3-275-25-225-2H'  and `pre_gou_pattern` like '45gG'  and `end_ah_pattern` like '-35-325-3-275-25-225H'  and `end_gou_pattern` like '45gG'
#   __________________pattern_from update done
#   ______________[70/73] 1. -25-225-2-175-15H // 35gG >> -25-225-2-175-15H // 35g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-25-225-2-175-15H'  and `pre_gou_pattern` like '35gG'  and `end_ah_pattern` like '-25-225-2-175-15H'  and `end_gou_pattern` like '35g45gG'
#   __________________pattern_from update done
#   ______________[71/73] 1. -075-05-025+0+025H // 25g35gG >> -05-025+0+025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-075-05-025+0+025H'  and `pre_gou_pattern` like '25g35gG'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_from update done
#   ______________[72/73] 1. -15-125-1-075H // 25gG >> -15-125-1-075H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like '-15-125-1-075H'  and `pre_gou_pattern` like '25gG'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_from update done
# ...
#   ______________[45/70] 1.  >> -275-25-225-2-175-15H // 35g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-275-25-225-2-175-15H'  and `end_gou_pattern` like '35g45gG'
#   __________________pattern_only update done
#   ______________[46/70] 1.  >> -275-25-225-2-175H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[47/70] 1.  >> -225-2-175-15H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[48/70] 1.  >> -225-2-175-15-125H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-225-2-175-15-125H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_only update done
#   ______________[49/70] 1.  >> -125-1-075-05H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_only update done
#   ______________[50/70] 1.  >> +0+025+05+075H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_only update done
#   ______________[51/70] 1.  >> -35-325-3-275-25H // 45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-35-325-3-275-25H'  and `end_gou_pattern` like '45gG'
#   __________________pattern_only update done
#   ______________[52/70] 1.  >> +075+1+125+15H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[53/70] 1.  >> -025+0+025+05H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_only update done
#   ______________[54/70] 1.  >> -075-05-025H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_only update done
#   ______________[55/70] 1.  >> +125+15+175+2+225H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[56/70] 1.  >> -4-375-35-325-3H // 45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-4-375-35-325-3H'  and `end_gou_pattern` like '45gG'
#   __________________pattern_only update done
#   ______________[57/70] 1.  >> -175-15-125-1H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_only update done
#   ______________[58/70] 1.  >> +025+05+075H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_only update done
#   ______________[59/70] 1.  >> -025+0+025+05H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_only update done
#   ______________[60/70] 1.  >> -15-125-1-075-05H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_only update done
#   ______________[61/70] 1.  >> -175-15-125-1H // 35g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '35g45gG'
#   __________________pattern_only update done
#   ______________[62/70] 1.  >> +225+25+275+3+325+35H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[63/70] 1.  >> -1-075-05-025H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_only update done
#   ______________[64/70] 1.  >> -15-125-1-075-05H // 35g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '35g45gG'
#   __________________pattern_only update done
#   ______________[65/70] 1.  >> -2-175-15-125H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-2-175-15-125H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_only update done
#   ______________[66/70] 1.  >> -15-125-1-075H // 35g45gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '35g45gG'
#   __________________pattern_only update done
#   ______________[67/70] 1.  >> +05+075+1+125H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1+125H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_only update done
#   ______________[68/70] 1.  >> +025+05+075+1+125H // 25g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075+1+125H'  and `end_gou_pattern` like '25g35gG'
#   __________________pattern_only update done
#   ______________[69/70] 1.  >> +1H // 35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+1H'  and `end_gou_pattern` like '35gG'
#   __________________pattern_only update done
#   ______________[70/70] 1.  >> +025+05+075+1H // 25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 473  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '25gG'
#   __________________pattern_only update done
# # -------------------------------------------------- End at 2023-07-23 06:27:59
