# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 06:37:34
#   ____main__
#   ______Enter your leagueapi id :  11
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 8
#   ______________[1/8]  #11 - 2022 => 3 / 3 == Match Finished
#   ______________[2/8]  #11 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/8]  #11 - 2023 => 0 / None == Match Finished
#   ______________[4/8]  #11 - 2023 => 0 / 1 == Match Finished Ended
#   ______________[5/8]  #11 - 2023 => 1 / 1 == Match Finished Ended
#   ______________[6/8]  #11 - 2023 => 3 / 1 == Match Finished Ended
#   ______________[7/8]  #11 - 2023 => 3 / 3 == Match Finished
#   ______________[8/8]  #11 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-27 06:50:50

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 06:50:50
#   __main()
#   ____Enter your leagueapi id :  11
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '11'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '11'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 10
#   __________[1/10] #1019466 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019466
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[2/10] #1019467 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019467
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[3/10] #1019468 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019468
#   ____________> pre_ah_pattern = -35-3-275-25-225H
#   ____________> pre_ah_pattern_mirror = +225+25+275+3+35H
#   ____________> pre_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[4/10] #1019469 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019469
#   ____________> pre_ah_pattern = -275-25-225-2H
#   ____________> pre_ah_pattern_mirror = +2+225+25+275H
#   ____________> pre_gou_pattern = 275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[5/10] #1019470 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019470
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[6/10] #1019471 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019471
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[7/10] #1019472 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019472
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[8/10] #1019473 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019473
#   ____________> pre_ah_pattern = H
#   ____________> pre_ah_pattern_mirror = H
#   ____________> pre_gou_pattern = G
#   ____________> football_odds update pattern commited
#   __________[9/10] #1019474 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019474
#   ____________> pre_ah_pattern = -2-175-15-125H
#   ____________> pre_ah_pattern_mirror = +125+15+175+2H
#   ____________> pre_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[10/10] #1019475 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019475
#   ____________> pre_ah_pattern = -125-1-075-05H
#   ____________> pre_ah_pattern_mirror = +05+075+1+125H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '11'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '11'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 29
#   __________[1/29] #1019464 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019464
#   ____________> end_ah_pattern = -275-25-225-2H
#   ____________> end_ah_pattern_mirror = +2+225+25+275H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[2/29] #1019465 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019465
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[3/29] #1019466 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019466
#   ____________> end_ah_pattern = -15-125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[4/29] #1019467 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019467
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[5/29] #1019468 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019468
#   ____________> end_ah_pattern = -425-4-375-35-325H
#   ____________> end_ah_pattern_mirror = +325+35+375+4+425H
#   ____________> end_gou_pattern = 375g40g425g45g475gG
#   ____________> football_odds update pattern commited
#   __________[6/29] #1019469 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019469
#   ____________> end_ah_pattern = -35-325-3-275-25H
#   ____________> end_ah_pattern_mirror = +25+275+3+325+35H
#   ____________> end_gou_pattern = 325g35g375g40g425gG
#   ____________> football_odds update pattern commited
#   __________[7/29] #1019470 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019470
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[8/29] #1019472 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019472
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[9/29] #1019473 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019473
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[10/29] #1019474 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019474
#   ____________> end_ah_pattern = -225-2-175-15H
#   ____________> end_ah_pattern_mirror = +15+175+2+225H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[11/29] #1019475 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019475
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[12/29] #1019476 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019476
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[13/29] #1019477 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019477
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[14/29] #1019478 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019478
#   ____________> end_ah_pattern = -275-25-225-2H
#   ____________> end_ah_pattern_mirror = +2+225+25+275H
#   ____________> end_gou_pattern = 30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[15/29] #1019479 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019479
#   ____________> end_ah_pattern = -25-225-2-175H
#   ____________> end_ah_pattern_mirror = +175+2+225+25H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[16/29] #1046415 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046415
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[17/29] #1046421 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046421
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[18/29] #1046416 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046416
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[19/29] #1046417 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046417
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[20/29] #1046418 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046418
#   ____________> end_ah_pattern = -15-125-1H
#   ____________> end_ah_pattern_mirror = +1+125+15H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[21/29] #1046419 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046419
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[22/29] #1046420 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046420
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[23/29] #1046422 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046422
#   ____________> end_ah_pattern = -175-15-125H
#   ____________> end_ah_pattern_mirror = +125+15+175H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[24/29] #1046424 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046424
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[25/29] #1046426 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046426
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[26/29] #1046427 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046427
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[27/29] #1046428 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046428
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[28/29] #1046430 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1046430
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[29/29] #1019471 #11 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 1019471
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-27 07:08:18

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 07:08:18
#   ____main__
#   ______Enter your leagueapi id :  11
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 4
#   ______________[1/4]  #11 - 2022 => 3 / 3 == Match Finished
#   ______________[2/4]  #11 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/4]  #11 - 2023 => 3 / 3 == Match Finished
#   ______________[4/4]  #11 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-27 07:15:34

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 07:15:34
#   ____main__
#   ______Enter your leagueapi id :  11
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '11'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 22
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '22'  where leagueapi_id = '11'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/22] 1. -25-225-2-175H // 25g275g30g325g35gG >> -25-225-2-175H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like '-25-225-2-175H'  and `pre_gou_pattern` like '25g275g30g325g35gG'  and `end_ah_pattern` like '-25-225-2-175H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_from update done
#   ______________[2/22] 1. -1-075-05H // 20g225g25gG >> -1-075-05-025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[3/22] 1. +025+05+075+1H // 20g225g25g275gG >> +0+025+05H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[4/22] 1. -075-05-025H // 20g225g25g275gG >> -075-05-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like '-075-05-025H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[5/22] 1. -125-1-075H // 225g25g275gG >> -15-125-1H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[6/22] 1. -05-025+0H // 175g20g225gG >> -025+0+025H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[7/22] 1. -175-15-125H // 225g25g275g30gG >> -175-15-125H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[8/22] 1. -05-025+0H // 225g25g275g30gG >> -05-025+0H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[9/22] 1. -1-075-05H // 225g25g275gG >> -1-075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[10/22] 1. -35-3-275-25-225H // 325g35g375g40g425gG >> -425-4-375-35-325H // 375g40g425g45g475gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like '-35-3-275-25-225H'  and `pre_gou_pattern` like '325g35g375g40g425gG'  and `end_ah_pattern` like '-425-4-375-35-325H'  and `end_gou_pattern` like '375g40g425g45g475gG'
#   __________________pattern_from update done
#   ______________[11/22] 1. -05-025+0H // 15g175g20g225gG >> -05-025+0H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[12/22] 1. -275-25-225-2H // 275g30g325gG >> -35-325-3-275-25H // 325g35g375g40g425gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like '-275-25-225-2H'  and `pre_gou_pattern` like '275g30g325gG'  and `end_ah_pattern` like '-35-325-3-275-25H'  and `end_gou_pattern` like '325g35g375g40g425gG'
#   __________________pattern_from update done
#   ______________[13/22] 1. -125-1-075-05H // 175g20g225g25gG >> -125-1-075-05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[14/22] 1. -2-175-15-125H // 25g275g30g325gG >> -225-2-175-15H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like '-2-175-15-125H'  and `pre_gou_pattern` like '25g275g30g325gG'  and `end_ah_pattern` like '-225-2-175-15H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_from update done
#   ______________[15/22] 1. -05-025+0H // 20g225g25g275gG >> -025+0+025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[16/22] 1. -125-1-075-05H // 20g225g25g275gG >> -125-1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like '-125-1-075-05H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[17/22] 1. -05-025+0H // 175g20g225g25gG >> -025+0+025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[18/22] 1. -05-025+0+025H // 20g225g25g275gG >> -05-025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like '-05-025+0+025H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[19/22] 1. -075-05-025H // 225g25g275gG >> -1-075-05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[20/22] 1. -1-075-05H // 20g225g25g275gG >> -1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like '-1-075-05H'  and `pre_gou_pattern` like '20g225g25g275gG'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_from update done
#   ______________[21/22] 1. -05-025+0H // 175g20g225g25gG >> -05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like '-05-025+0H'  and `pre_gou_pattern` like '175g20g225g25gG'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_from update done
#   ______________[22/22] 1. -275-25-225-2H // 30g325g35g375gG >> -275-25-225-2H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_from = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like '-275-25-225-2H'  and `pre_gou_pattern` like '30g325g35g375gG'  and `end_ah_pattern` like '-275-25-225-2H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_from update done
#   ________ff_get_fixtures_group_by_only_end_patternlists()
#   ____________Total Row(s) : 72
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_only_ends = '72'  where leagueapi_id = '11'
#   ________________> football_leagues : total_pattern_only_ends UPDATED
#   ______________[1/72] 6.  >> -05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 6
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[2/72] 5.  >> -075-05-025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[3/72] 4.  >> -075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[4/72] 4.  >> -1-075-05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[5/72] 4.  >> -175-15-125H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[6/72] 4.  >> -075-05-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[7/72] 3.  >> +025+05+075H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[8/72] 3.  >> -125-1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[9/72] 3.  >> -025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[10/72] 3.  >> -175-15-125-1H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[11/72] 3.  >> -05-025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[12/72] 3.  >> -1-075-05H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[13/72] 3.  >> -15-125-1-075H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[14/72] 3.  >> -05-025+0H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 3
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[15/72] 2.  >> -025+0+025+05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[16/72] 2.  >> -05-025H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_only update done
#   ______________[17/72] 2.  >> -1-075-05-025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[18/72] 2.  >> +0+025+05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_only update done
#   ______________[19/72] 2.  >> +0+025+05H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[20/72] 2.  >> -1-075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[21/72] 2.  >> +0+025+05H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[22/72] 2.  >> -075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[23/72] 2.  >> +025+05+075H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[24/72] 2.  >> -1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[25/72] 2.  >> +075+1+125+15H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 2
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+075+1+125+15H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[26/72] 1.  >> -125-1-075-05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[27/72] 1.  >> +0+025+05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[28/72] 1.  >> -025+0+025+05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[29/72] 1.  >> -35-325-3-275-25H // 325g35g375g40g425gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-35-325-3-275-25H'  and `end_gou_pattern` like '325g35g375g40g425gG'
#   __________________pattern_only update done
#   ______________[30/72] 1.  >> +025+05+075H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[31/72] 1.  >> -025+0+025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[32/72] 1.  >> +05+075+1+125H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1+125H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[33/72] 1.  >> +125+15+175H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+125+15+175H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[34/72] 1.  >> -2-175-15-125H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-2-175-15-125H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[35/72] 1.  >> -125-1-075-05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[36/72] 1.  >> -025+0+025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[37/72] 1.  >> +0+025+05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[38/72] 1.  >> +05+075+1+125H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1+125H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[39/72] 1.  >> -05-025+0H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[40/72] 1.  >> -1-075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[41/72] 1.  >> -05-025+0H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[42/72] 1.  >> -35-325-3-275-25H // 325g35g375g40gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-35-325-3-275-25H'  and `end_gou_pattern` like '325g35g375g40gG'
#   __________________pattern_only update done
#   ______________[43/72] 1.  >> +075+1+125+15H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+075+1+125+15H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[44/72] 1.  >> +125+15+175+2+225H // 275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+125+15+175+2+225H'  and `end_gou_pattern` like '275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[45/72] 1.  >> -225-2-175-15H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-225-2-175-15H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[46/72] 1.  >> +0+025+05+075H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05+075H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[47/72] 1.  >> -125-1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[48/72] 1.  >> +05+075+1H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[49/72] 1.  >> -225-2-175-15H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-225-2-175-15H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[50/72] 1.  >> -275-25-225-2H // 30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-275-25-225-2H'  and `end_gou_pattern` like '30g325g35g375gG'
#   __________________pattern_only update done
#   ______________[51/72] 1.  >> -175-15-125-1H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[52/72] 1.  >> +05+075+1H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[53/72] 1.  >> -25-225-2-175H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-25-225-2-175H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[54/72] 1.  >> -05-025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[55/72] 1.  >> -15-125-1-075H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[56/72] 1.  >> -025+0+025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[57/72] 1.  >> -075-05-025+0H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[58/72] 1.  >> -15-125-1H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[59/72] 1.  >> -1-075-05-025H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[60/72] 1.  >> -05-025+0H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[61/72] 1.  >> -125-1-075-05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[62/72] 1.  >> -1-075-05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[63/72] 1.  >> +025+05+075+1H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[64/72] 1.  >> -275-25-225-2H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-275-25-225-2H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[65/72] 1.  >> -075-05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[66/72] 1.  >> -025+0+025H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[67/72] 1.  >> +0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[68/72] 1.  >> +125+15+175H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+125+15+175H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[69/72] 1.  >> -15-125-1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[70/72] 1.  >> -05-025+0H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[71/72] 1.  >> -1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[72/72] 1.  >> -425-4-375-35-325H // 375g40g425g45g475gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 11  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-425-4-375-35-325H'  and `end_gou_pattern` like '375g40g425g45g475gG'
#   __________________pattern_only update done
# # -------------------------------------------------- End at 2023-07-27 08:37:44
