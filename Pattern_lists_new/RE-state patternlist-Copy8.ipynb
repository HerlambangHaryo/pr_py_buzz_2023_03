# %%
# 1. kalibrasi pre end pattern
# 2. delete patternlist pre end
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-28 22:42:42
#   ____main__
#   ______Enter your leagueapi id :  99
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 6
#   ______________[1/6]  #99 - 2022 => 3 / 3 == Match Finished
#   ______________[2/6]  #99 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/6]  #99 - 2023 => 1 / 1 == Match Finished Ended
#   ______________[4/6]  #99 - 2023 => 3 / 1 == Match Finished Ended
#   ______________[5/6]  #99 - 2023 => 3 / 3 == Match Finished
#   ______________[6/6]  #99 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-28 22:43:11

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.xpattern_new import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------   
    xpN_get_league_fixture_to_reset(leagueapi_id, 'pre_', 4, space)
    xpN_get_league_fixture_to_reset(leagueapi_id, 'end_', 4, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-28 22:43:11
#   __main()
#   ____Enter your leagueapi id :  99
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '99'  and pre_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '99'  and pre_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 2
#   __________[1/2] #995135 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995135
#   ____________> pre_ah_pattern = -125-1-075H
#   ____________> pre_ah_pattern_mirror = +075+1+125H
#   ____________> pre_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[2/2] #995136 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995136
#   ____________> pre_ah_pattern = -075-05-025H
#   ____________> pre_ah_pattern_mirror = +025+05+075H
#   ____________> pre_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   ______xpN_get_league_fixture_to_reset()
#   ________( Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '99'  and end_response != 3  and fixture_status  in ('Match Finished', 'Match Finished Ended') ) union (Select   teams_homeapi_id ,  teams_awayapi_id,  leagueapi_id,  season,  fixtureapi_id  from football_odds  where leagueapi_id = '99'  and end_response is null  and fixture_status  in ('Match Finished', 'Match Finished Ended') )
#   ________Total Row(s) : 77
#   __________[1/77] #995126 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995126
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[2/77] #995127 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995127
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[3/77] #995128 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995128
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[4/77] #995129 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995129
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[5/77] #995130 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995130
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[6/77] #995131 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995131
#   ____________> end_ah_pattern = +025+05+075+1H
#   ____________> end_ah_pattern_mirror = -1-075-05-025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[7/77] #995132 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995132
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[8/77] #995133 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995133
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[9/77] #995134 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995134
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[10/77] #995137 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995137
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[11/77] #995138 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995138
#   ____________> end_ah_pattern = +025+05+075+1H
#   ____________> end_ah_pattern_mirror = -1-075-05-025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[12/77] #995139 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995139
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[13/77] #995140 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995140
#   ____________> end_ah_pattern = -075-05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05+075H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[14/77] #995141 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995141
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[15/77] #995142 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995142
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[16/77] #995143 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995143
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[17/77] #995144 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995144
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[18/77] #995145 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995145
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[19/77] #995146 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995146
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[20/77] #995147 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995147
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[21/77] #995135 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995135
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[22/77] #995136 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995136
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[23/77] #995148 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995148
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[24/77] #995149 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995149
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[25/77] #995150 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995150
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[26/77] #995151 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995151
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[27/77] #995152 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995152
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[28/77] #995153 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995153
#   ____________> end_ah_pattern = -1-075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075+1H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[29/77] #995154 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995154
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[30/77] #995155 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995155
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[31/77] #995156 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995156
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[32/77] #995157 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995157
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[33/77] #995158 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995158
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[34/77] #995159 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995159
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[35/77] #995160 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995160
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 15g175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[36/77] #995161 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995161
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[37/77] #995162 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995162
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[38/77] #995163 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995163
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[39/77] #995164 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995164
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[40/77] #995165 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995165
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[41/77] #995166 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995166
#   ____________> end_ah_pattern = -125-1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1+125H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[42/77] #995167 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995167
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[43/77] #995168 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995168
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[44/77] #995169 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995169
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[45/77] #995170 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995170
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[46/77] #995171 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995171
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[47/77] #995172 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995172
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[48/77] #995173 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995173
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225gG
#   ____________> football_odds update pattern commited
#   __________[49/77] #995174 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995174
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[50/77] #995175 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995175
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[51/77] #995176 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995176
#   ____________> end_ah_pattern = +025+05+075H
#   ____________> end_ah_pattern_mirror = -075-05-025H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[52/77] #995177 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995177
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[53/77] #995178 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995178
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[54/77] #995179 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995179
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[55/77] #995180 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995180
#   ____________> end_ah_pattern = +025+05+075+1H
#   ____________> end_ah_pattern_mirror = -1-075-05-025H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[56/77] #995181 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995181
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[57/77] #995182 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995182
#   ____________> end_ah_pattern = +0H
#   ____________> end_ah_pattern_mirror = +0H
#   ____________> end_gou_pattern = 225g25gG
#   ____________> football_odds update pattern commited
#   __________[58/77] #995184 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995184
#   ____________> end_ah_pattern = +025+05H
#   ____________> end_ah_pattern_mirror = -05-025H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[59/77] #995185 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995185
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[60/77] #995186 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995186
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[61/77] #995187 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995187
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[62/77] #995188 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995188
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[63/77] #995183 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995183
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[64/77] #995189 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995189
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[65/77] #995190 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995190
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[66/77] #995191 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995191
#   ____________> end_ah_pattern = -15-125-1-075H
#   ____________> end_ah_pattern_mirror = +075+1+125+15H
#   ____________> end_gou_pattern = 275g30g325g35g375gG
#   ____________> football_odds update pattern commited
#   __________[67/77] #995192 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995192
#   ____________> end_ah_pattern = +05+075+1H
#   ____________> end_ah_pattern_mirror = -1-075-05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[68/77] #995193 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995193
#   ____________> end_ah_pattern = -075-05-025H
#   ____________> end_ah_pattern_mirror = +025+05+075H
#   ____________> end_gou_pattern = 175g20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[69/77] #995194 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995194
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[70/77] #995195 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995195
#   ____________> end_ah_pattern = -05-025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025+05H
#   ____________> end_gou_pattern = 25g275g30g325g35gG
#   ____________> football_odds update pattern commited
#   __________[71/77] #995196 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995196
#   ____________> end_ah_pattern = -025+0+025H
#   ____________> end_ah_pattern_mirror = -025+0+025H
#   ____________> end_gou_pattern = 15g175g20gG
#   ____________> football_odds update pattern commited
#   __________[72/77] #995197 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995197
#   ____________> end_ah_pattern = -025+0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0+025H
#   ____________> end_gou_pattern = 20g225g25gG
#   ____________> football_odds update pattern commited
#   __________[73/77] #995198 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995198
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 20g225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[74/77] #995199 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995199
#   ____________> end_ah_pattern = -1-075-05H
#   ____________> end_ah_pattern_mirror = +05+075+1H
#   ____________> end_gou_pattern = 25g275g30g325gG
#   ____________> football_odds update pattern commited
#   __________[75/77] #995200 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995200
#   ____________> end_ah_pattern = +0+025+05H
#   ____________> end_ah_pattern_mirror = -05-025+0H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   __________[76/77] #995201 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995201
#   ____________> end_ah_pattern = +05+075+1+125H
#   ____________> end_ah_pattern_mirror = -125-1-075-05H
#   ____________> end_gou_pattern = 225g25g275g30gG
#   ____________> football_odds update pattern commited
#   __________[77/77] #995202 #99 - 2023
#   ____________xpN_set_pattern()
#   ____________> fixtureapi_id = 995202
#   ____________> end_ah_pattern = -05-025+0H
#   ____________> end_ah_pattern_mirror = +0+025+05H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-28 23:27:50

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_odds import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    fO_check_pre_end_response(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-28 23:27:50
#   ____main__
#   ______Enter your leagueapi id :  99
#   ________fO_check_pre_end_response()
#   ____________Total Row(s) : 4
#   ______________[1/4]  #99 - 2022 => 3 / 3 == Match Finished
#   ______________[2/4]  #99 - 2022 => 3 / 3 == Match Finished Ended
#   ______________[3/4]  #99 - 2023 => 3 / 3 == Match Finished
#   ______________[4/4]  #99 - 2023 => 3 / 3 == Match Finished Ended
# # -------------------------------------------------- End at 2023-07-29 07:23:08

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    ff_get_fixtures_group_by_only_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-29 07:23:08
#   ____main__
#   ______Enter your leagueapi id :  99
#   ________ff_get_fixtures_group_by_pre_end_patternlists()
#   __________Select  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '99'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  and pre_response = 3  and end_response = 3  and pattern_from is null  group by  pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 35
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_pre_ends = '35'  where leagueapi_id = '99'
#   ________________> football_leagues : total_pattern_pre_ends UPDATED
#   ______________[1/35] 1. +0+025+05H // 20g225g25g275gG >> +025+05+075H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[2/35] 1. -1-075-05H // 20g225g25gG >> -1-075-05H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[3/35] 1. -075-05-025H // 20g225g25g275gG >> -1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[4/35] 1. +025+05+075H // 15g175g20gG >> +025+05H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[5/35] 1. -075-05-025H // 15g175g20g225gG >> -075-05-025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[6/35] 1. -025+0+025H // 225g25g275g30gG >> -05-025+0H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[7/35] 1. -15-125-1-075-05H // 25g275g30g325gG >> -125-1-075-05H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[8/35] 1. -1-075-05H // 225g25g275g30gG >> -075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[9/35] 1. -075-05-025H // 225g25g275g30gG >> -05-025+0H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[10/35] 1. -025+0+025H // 25g275g30g325gG >> -025+0+025+05H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[11/35] 1. +0+025+05H // 20g225g25gG >> +0+025+05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[12/35] 1. -125-1-075-05H // 275g30g325g35gG >> -15-125-1-075H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[13/35] 1. +0+025+05H // 175g20g225g25gG >> +0+025+05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[14/35] 1. +05+075+1+125H // 225g25g275gG >> +05+075+1H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[15/35] 1. -05-025+0+025H // 175g20g225gG >> +0+025+05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[16/35] 1. -075-05-025H // 175g20g225gG >> -075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[17/35] 1. -05-025+0H // 175g20g225gG >> -025+0+025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[18/35] 1. -05-025+0+025H // 225g25g275g30gG >> -05-025+0H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[19/35] 1. -025+0+025+05H // 225g25g275g30g325gG >> -025+0+025+05H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[20/35] 1. -075-05-025+0H // 25g275g30g325g35gG >> -05-025+0+025H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[21/35] 1. -075-05-025H // 20g225g25g275gG >> -05-025+0H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[22/35] 1. +0+025+05H // 20g225g25gG >> -025+0+025+05H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[23/35] 1. +0+025+05+075H // 225g25g275g30g325gG >> +025+05+075H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[24/35] 1. -075-05-025H // 20g225g25g275gG >> -05-025+0H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[25/35] 1. -025+0+025H // 225g25g275gG >> -025+0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[26/35] 1. -075-05-025H // 25g275g30g325gG >> -1-075-05H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[27/35] 1. +025+05+075+1H // 25g275g30g325gG >> +05+075+1+125H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[28/35] 1. -1-075-05H // 20g225g25g275gG >> -075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[29/35] 1. +0+025+05+075H // 225g25g275gG >> +0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[30/35] 1. -05-025+0+025H // 20g225g25g275gG >> -075-05-025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[31/35] 1. -025+0+025+05H // 175g20g225g25gG >> -025+0+025+05H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[32/35] 1. +05+075+1+125H // 225g25g275g30gG >> +05+075+1+125H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[33/35] 1. +025+05+075H // 225g25g275gG >> +025+05+075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[34/35] 1. +025+05+075H // 225g25g275g30gG >> +025+05+075+1H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[35/35] 1. -05-025+0H // 20g225g25g275gG >> -05-025+0H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ________ff_get_fixtures_group_by_only_end_patternlists()
#   ____________Total Row(s) : 118
#   ______________lg_update_total_pattern()
#   ________________update football_leagues set  total_pattern_only_ends = '118'  where leagueapi_id = '99'
#   ________________> football_leagues : total_pattern_only_ends UPDATED
#   ______________[1/118] 24.  >> -05-025+0H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 24
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[2/118] 17.  >> -075-05-025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 17
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[3/118] 15.  >> -05-025+0H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 15
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[4/118] 14.  >> -075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 14
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[5/118] 13.  >> -025+0+025H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 13
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[6/118] 11.  >> -025+0+025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 11
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[7/118] 11.  >> -05-025+0H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 11
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[8/118] 11.  >> -05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 11
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[9/118] 11.  >> -075-05-025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 11
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[10/118] 11.  >> +025+05+075H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 11
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[11/118] 10.  >> -05-025+0H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 10
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[12/118] 10.  >> -025+0+025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 10
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[13/118] 10.  >> +025+05+075H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 10
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[14/118] 9.  >> -025+0+025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 9
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_only update done
#   ______________[15/118] 9.  >> -075-05-025H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 9
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_only update done
#   ______________[16/118] 9.  >> -075-05-025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 9
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[17/118] 8.  >> +025+05+075H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 8
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[18/118] 7.  >> +0+025+05H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_only update done
#   ______________[19/118] 7.  >> +0+025+05H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[20/118] 7.  >> -025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[21/118] 7.  >> -05-025+0H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[22/118] 7.  >> -05-025+0H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_only update done
#   ______________[23/118] 7.  >> -025+0+025+05H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[24/118] 7.  >> -1-075-05-025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 7
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[25/118] 6.  >> -025+0+025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 6
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[26/118] 6.  >> -05-025+0+025H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 6
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[27/118] 6.  >> +0+025+05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 6
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[28/118] 6.  >> +0+025+05H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 6
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[29/118] 6.  >> +0+025+05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 6
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[30/118] 6.  >> -025+0+025H // 15g175g20gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 6
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '15g175g20gG'
#   __________________pattern_only update done
#   ______________[31/118] 5.  >> -05-025+0+025H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[32/118] 5.  >> +0+025+05H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[33/118] 5.  >> -05-025+0H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_only update done
#   ______________[34/118] 5.  >> +0+025+05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[35/118] 5.  >> +025+05+075H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[36/118] 5.  >> -05-025+0+025H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[37/118] 5.  >> -1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 5
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[38/118] 4.  >> -125-1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[39/118] 4.  >> -1-075-05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[40/118] 4.  >> +0+025+05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025+05H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_only update done
#   ______________[41/118] 4.  >> +025+05+075+1H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[42/118] 4.  >> -125-1-075-05H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[43/118] 4.  >> -075-05-025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[44/118] 4.  >> -15-125-1-075H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[45/118] 4.  >> -025+0+025+05H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[46/118] 4.  >> -1-075-05-025H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-1-075-05-025H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[47/118] 4.  >> -025+0+025+05H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[48/118] 4.  >> -025+0+025+05H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 4
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025+05H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[49/118] 3.  >> -05-025+0H // 225g25g275g30g325gG
# ...
#   __________________pattern_only update done
#   ______________[94/118] 1.  >> -15-125-1-075H // 275g30g325g35g375gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[95/118] 1.  >> +0+025H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[96/118] 1.  >> +025+05+075+1H // 20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075+1H'  and `end_gou_pattern` like '20g225g25gG'
#   __________________pattern_only update done
#   ______________[97/118] 1.  >> -175-15-125-1H // 25g275g30g325g35gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-175-15-125-1H'  and `end_gou_pattern` like '25g275g30g325g35gG'
#   __________________pattern_only update done
#   ______________[98/118] 1.  >> -05-025H // 125g15g175gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025H'  and `end_gou_pattern` like '125g15g175gG'
#   __________________pattern_only update done
#   ______________[99/118] 1.  >> +025+05H // 25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05H'  and `end_gou_pattern` like '25g275gG'
#   __________________pattern_only update done
#   ______________[100/118] 1.  >> +05+075+1H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[101/118] 1.  >> +025+05+075H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[102/118] 1.  >> -125-1-075H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[103/118] 1.  >> +0+025H // 15g175gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+0+025H'  and `end_gou_pattern` like '15g175gG'
#   __________________pattern_only update done
#   ______________[104/118] 1.  >> -075-05H // 20g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05H'  and `end_gou_pattern` like '20g25gG'
#   __________________pattern_only update done
#   ______________[105/118] 1.  >> -075-05-025+0H // 20g225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '20g225g25g275gG'
#   __________________pattern_only update done
#   ______________[106/118] 1.  >> -1-075-05H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[107/118] 1.  >> -15-125-1-075-05H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-15-125-1-075-05H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[108/118] 1.  >> +05+075+1+125H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query CANT update
#   ______________[109/118] 1.  >> -075-05-025+0H // 175g20g225g25gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-075-05-025+0H'  and `end_gou_pattern` like '175g20g225g25gG'
#   __________________pattern_only update done
#   ______________[110/118] 1.  >> +025+05H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_only update done
#   ______________[111/118] 1.  >> +025+05H // 15g175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05H'  and `end_gou_pattern` like '15g175g20g225gG'
#   __________________pattern_only update done
#   ______________[112/118] 1.  >> +05+075+1H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[113/118] 1.  >> +025+05+075H // 175g20g225gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+025+05+075H'  and `end_gou_pattern` like '175g20g225gG'
#   __________________pattern_only update done
#   ______________[114/118] 1.  >> +05+075+1+125H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1+125H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
#   ______________[115/118] 1.  >> -025+0+025H // 25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 0
#   ________________________insert commited
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-025+0+025H'  and `end_gou_pattern` like '25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[116/118] 1.  >> -125-1-075-05H // 225g25g275g30g325gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-125-1-075-05H'  and `end_gou_pattern` like '225g25g275g30g325gG'
#   __________________pattern_only update done
#   ______________[117/118] 1.  >> -05-025+0+025H // 225g25g275g30gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '-05-025+0+025H'  and `end_gou_pattern` like '225g25g275g30gG'
#   __________________pattern_only update done
#   ______________[118/118] 1.  >> +05+075+1H // 225g25g275gG
#   ________________aP_controll_pattern_ROUTE()
#   ________________Total Row(s) : 1
#   __________________aP_check_patternlist()
#   ____________________Total Row(s) : 1
#   ______________________Already Data
#   __________________aP_final_assestment()
#   __________________Total Row(s) : 1
#   __________________query update done
#   __________________ UPDATE `football_odds` SET  pattern_only = 1  WHERE leagueapi_id = 99  and `pre_ah_pattern` like 'Null'  and `pre_gou_pattern` like 'Null'  and `end_ah_pattern` like '+05+075+1H'  and `end_gou_pattern` like '225g25g275gG'
#   __________________pattern_only update done
# # -------------------------------------------------- End at 2023-07-29 09:26:36
