# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/fixtures/players"

querystring = {"fixture":"868324"}

headers = {
	"X-RapidAPI-Key": "fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
print(response.json())
# Out:
# {'get': 'fixtures/players', 'parameters': {'fixture': '868324'}, 'errors': [], 'results': 2, 'paging': {'current': 1, 'total': 1}, 'response': [{'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-2.api-sports.io/football/teams/33.png', 'update': '2023-05-30T04:16:42+00:00'}, 'players': [{'player': {'id': 882, 'name': 'David De Gea', 'photo': 'https://media-2.api-sports.io/football/players/882.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 1, 'position': 'G', 'rating': '7.3', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': None, 'on': None}, 'goals': {'total': None, 'conceded': 1, 'assists': None, 'saves': 2}, 'passes': {'total': 28, 'key': None, 'accuracy': '21'}, 'tackles': {'total': None, 'blocks': None, 'interceptions': None}, 'duels': {'total': None, 'won': None}, 'dribbles': {'attempts': None, 'success': None, 'past': None}, 'fouls': {'drawn': None, 'committed': None}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': 1}}]}, {'player': {'id': 886, 'name': 'Diogo Dalot', 'photo': 'https://media-2.api-sports.io/football/players/886.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 20, 'position': 'D', 'rating': '7', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 1, 'on': 1}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 38, 'key': None, 'accuracy': '33'}, 'tackles': {'total': 1, 'blocks': None, 'interceptions': 2}, 'duels': {'total': 4, 'won': 3}, 'dribbles': {'attempts': None, 'success': None, 'past': None}, 'fouls': {'drawn': None, 'committed': None}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 2935, 'name': 'Harry Maguire', 'photo': 'https://media-2.api-sports.io/football/players/2935.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 5, 'position': 'D', 'rating': '6.9', 'captain': True, 'substitute': False}, 'offsides': None, 'shots': {'total': 1, 'on': None}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 61, 'key': None, 'accuracy': '50'}, 'tackles': {'total': 1, 'blocks': None, 'interceptions': 3}, 'duels': {'total': 12, 'won': 7}, 'dribbles': {'attempts': None, 'success': None, 'past': None}, 'fouls': {'drawn': 1, 'committed': 1}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 889, 'name': 'Victor Lindelöf', 'photo': 'https://media-3.api-sports.io/football/players/889.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 2, 'position': 'D', 'rating': '7', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': None, 'on': None}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 62, 'key': None, 'accuracy': '59'}, 'tackles': {'total': 2, 'blocks': None, 'interceptions': 2}, 'duels': {'total': 6, 'won': 4}, 'dribbles': {'attempts': None, 'success': None, 'past': None}, 'fouls': {'drawn': None, 'committed': 2}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 37145, 'name': 'Tyrell Malacia', 'photo': 'https://media-2.api-sports.io/football/players/37145.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 12, 'position': 'D', 'rating': '7.2', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': None, 'on': None}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 45, 'key': 2, 'accuracy': '43'}, 'tackles': {'total': 4, 'blocks': None, 'interceptions': 3}, 'duels': {'total': 11, 'won': 6}, 'dribbles': {'attempts': None, 'success': None, 'past': 2}, 'fouls': {'drawn': 2, 'committed': 2}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited ...

# %%
import json 
d = json.loads(response.text) 
print(d['response'])
# Out:
# [{'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-2.api-sports.io/football/teams/33.png', 'update': '2023-05-30T04:16:42+00:00'}, 'players': [{'player': {'id': 882, 'name': 'David De Gea', 'photo': 'https://media-2.api-sports.io/football/players/882.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 1, 'position': 'G', 'rating': '7.3', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': None, 'on': None}, 'goals': {'total': None, 'conceded': 1, 'assists': None, 'saves': 2}, 'passes': {'total': 28, 'key': None, 'accuracy': '21'}, 'tackles': {'total': None, 'blocks': None, 'interceptions': None}, 'duels': {'total': None, 'won': None}, 'dribbles': {'attempts': None, 'success': None, 'past': None}, 'fouls': {'drawn': None, 'committed': None}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': 1}}]}, {'player': {'id': 886, 'name': 'Diogo Dalot', 'photo': 'https://media-2.api-sports.io/football/players/886.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 20, 'position': 'D', 'rating': '7', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 1, 'on': 1}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 38, 'key': None, 'accuracy': '33'}, 'tackles': {'total': 1, 'blocks': None, 'interceptions': 2}, 'duels': {'total': 4, 'won': 3}, 'dribbles': {'attempts': None, 'success': None, 'past': None}, 'fouls': {'drawn': None, 'committed': None}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 2935, 'name': 'Harry Maguire', 'photo': 'https://media-2.api-sports.io/football/players/2935.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 5, 'position': 'D', 'rating': '6.9', 'captain': True, 'substitute': False}, 'offsides': None, 'shots': {'total': 1, 'on': None}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 61, 'key': None, 'accuracy': '50'}, 'tackles': {'total': 1, 'blocks': None, 'interceptions': 3}, 'duels': {'total': 12, 'won': 7}, 'dribbles': {'attempts': None, 'success': None, 'past': None}, 'fouls': {'drawn': 1, 'committed': 1}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 889, 'name': 'Victor Lindelöf', 'photo': 'https://media-3.api-sports.io/football/players/889.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 2, 'position': 'D', 'rating': '7', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': None, 'on': None}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 62, 'key': None, 'accuracy': '59'}, 'tackles': {'total': 2, 'blocks': None, 'interceptions': 2}, 'duels': {'total': 6, 'won': 4}, 'dribbles': {'attempts': None, 'success': None, 'past': None}, 'fouls': {'drawn': None, 'committed': 2}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 37145, 'name': 'Tyrell Malacia', 'photo': 'https://media-2.api-sports.io/football/players/37145.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 12, 'position': 'D', 'rating': '7.2', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': None, 'on': None}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 45, 'key': 2, 'accuracy': '43'}, 'tackles': {'total': 4, 'blocks': None, 'interceptions': 3}, 'duels': {'total': 11, 'won': 6}, 'dribbles': {'attempts': None, 'success': None, 'past': 2}, 'fouls': {'drawn': 2, 'committed': 2}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 747, 'name': 'Casemiro', 'photo': 'https://media-3.api-sports.io/footba ...

# %%
data = d['response']

counter = 0
# Iterate through each team in the data
for team_data in data:
    # Get the team name
    team_name = team_data['team']['name']
    print("Team Name: " + team_name)
    
    counter2 = 0
    players_list = team_data['players']
    
    for pl in players_list: 
        
        response_player = team_data['players'][counter2]['player'] 
        #  
        player_id = response_player['id']
        print("  player_id: " + str(player_id))    
        #  
        player_name = response_player['name']
        print("  player_name: " + str(player_name))    
        #  
        player_photo = response_player['photo']
        print("  player_photo: " + str(player_photo))
        
        print("") 
        response_games = team_data['players'][counter2]['statistics'][counter]['games']
        #  
        player_games_minutes = response_games['minutes']
        print("    player_games_minutes: " + str(player_games_minutes))
        #  
        player_games_number = response_games['number']
        print("    player_games_number: " + str(player_games_number))
        #  
        player_games_position = response_games['position']
        print("    player_games_position: " + str(player_games_position))
        #  
        player_games_rating = response_games['rating']
        print("    player_games_rating: " + str(player_games_rating))
        #  
        player_games_captain = response_games['captain']
        print("    player_games_captain: " + str(player_games_captain))
        #  
        player_games_substitute = response_games['substitute']
        print("    player_games_substitute: " + str(player_games_substitute))
         
        #  
        player_offsides = team_data['players'][counter2]['statistics'][counter]['offsides']
        print("    player_offsides: " + str(player_offsides))
        
        
        print("")
        response_shots = team_data['players'][counter2]['statistics'][counter]['shots']
        #  
        player_shots_total = response_shots['total']
        print("    player_shots_total: " + str(player_shots_total))
        #  
        player_shots_on = response_shots['on']
        print("    player_shots_on: " + str(player_shots_on))
        
        
        print("")
        response_goals = team_data['players'][counter2]['statistics'][counter]['goals']
        #  
        player_goals_total = response_goals['total']
        print("    player_goals_total: " + str(player_goals_total))
        #  
        player_goals_conceded = response_goals['conceded']
        print("    player_goals_conceded: " + str(player_goals_conceded))
        #  
        player_goals_assists = response_goals['assists']
        print("    player_goals_assists: " + str(player_goals_assists))
        #  
        player_goals_saves = response_goals['saves']
        print("    player_goals_saves: " + str(player_goals_saves))
        
        
        
        print("")
        response_passes = team_data['players'][counter2]['statistics'][counter]['passes']
        #  
        player_passes_total = response_passes['total']
        print("    player_passes_total: " + str(player_passes_total))
        #  
        player_passes_key = response_passes['key']
        print("    player_passes_key: " + str(player_passes_key))
        #  
        player_passes_accuracy = response_passes['accuracy']
        print("    player_passes_accuracy: " + str(player_passes_accuracy))
        
        
        print("")
        response_tackles = team_data['players'][counter2]['statistics'][counter]['tackles']
        #  
        player_tackles_total = response_tackles['total']
        print("    player_tackles_total: " + str(player_tackles_total))
        #  
        player_tackles_blocks = response_tackles['blocks']
        print("    player_tackles_blocks: " + str(player_tackles_blocks))
        #  
        player_tackles_interceptions = response_tackles['interceptions']
        print("    player_tackles_interceptions: " + str(player_tackles_interceptions))
        
        
        
        print("")
        response_duels = team_data['players'][counter2]['statistics'][counter]['duels']
        #  
        player_duels_total = response_duels['total']
        print("    player_duels_total: " + str(player_duels_total))
        #  
        player_duels_won = response_duels['won']
        print("    player_duels_won: " + str(player_duels_won))
        
        
        
        print("")
        response_dribbles = team_data['players'][counter2]['statistics'][counter]['dribbles']
        #  
        player_dribbles_attempts = response_dribbles['attempts']
        print("    player_dribbles_attempts: " + str(player_dribbles_attempts))
        #  
        player_dribbles_success = response_dribbles['success']
        print("    player_dribbles_success: " + str(player_dribbles_success))
        #  
        player_dribbles_past = response_dribbles['past']
        print("    player_dribbles_past: " + str(player_dribbles_past))
        
        
        print("")
        response_fouls = team_data['players'][counter2]['statistics'][counter]['fouls']
        #  
        player_fouls_drawn = response_fouls['drawn']
        print("    player_fouls_drawn: " + str(player_fouls_drawn))
        #  
        player_fouls_committed = response_fouls['committed']
        print("    player_fouls_committed: " + str(player_fouls_committed))
        
        
        
        
        
        
        counter2 += 1    
        print("")
    print("")
# Out:
# Team Name: Manchester United
#   player_id: 882
#   player_name: David De Gea
#   player_photo: https://media-2.api-sports.io/football/players/882.png
#
#     player_games_minutes: 90
#     player_games_number: 1
#     player_games_position: G
#     player_games_rating: 7.3
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 1
#     player_goals_assists: None
#     player_goals_saves: 2
#
#     player_passes_total: 28
#     player_passes_key: None
#     player_passes_accuracy: 21
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 886
#   player_name: Diogo Dalot
#   player_photo: https://media-2.api-sports.io/football/players/886.png
#
#     player_games_minutes: 90
#     player_games_number: 20
#     player_games_position: D
#     player_games_rating: 7
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 1
#     player_shots_on: 1
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 38
#     player_passes_key: None
#     player_passes_accuracy: 33
#
#     player_tackles_total: 1
#     player_tackles_blocks: None
#     player_tackles_interceptions: 2
#
#     player_duels_total: 4
#     player_duels_won: 3
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 2935
#   player_name: Harry Maguire
#   player_photo: https://media-2.api-sports.io/football/players/2935.png
#
#     player_games_minutes: 90
#     player_games_number: 5
#     player_games_position: D
#     player_games_rating: 6.9
#     player_games_captain: True
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 1
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 61
#     player_passes_key: None
#     player_passes_accuracy: 50
#
#     player_tackles_total: 1
#     player_tackles_blocks: None
#     player_tackles_interceptions: 3
#
#     player_duels_total: 12
#     player_duels_won: 7
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 889
#   player_name: Victor Lindelöf
#   player_photo: https://media-3.api-sports.io/football/players/889.png
#
#     player_games_minutes: 90
#     player_games_number: 2
#     player_games_position: D
#     player_games_rating: 7
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 62
#     player_passes_key: None
#     player_passes_accuracy: 59
#
#     player_tackles_total: 2
#     player_tackles_blocks: None
#     player_tackles_interceptions: 2
#
#     player_duels_total: 6
#     player_duels_won: 4
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 37145
#   player_name: Tyrell Malacia
#   player_photo: https://media-2.api-sports.io/football/players/37145.png
#
#     player_games_minutes: 90
#     player_games_number: 12
#     player_games_position: D
#     player_games_rating: 7.2
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 45
#     player_passes_key: 2
#     player_passes_accuracy: 43
#
#     player_tackles_total: 4
#     player_tackles_blocks: None
#     player_tackles_interceptions: 3
#
#     player_duels_total: 11
#     player_duels_won: 6
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: 2
#
#   player_id: 747
#   player_name: Casemiro
#   player_photo: https://media-3.api-sports.io/football/players/747.png
#
#     player_games_minutes: 67
#     player_games_number: 18
#     player_games_position: M
#     player_games_rating: 7.2
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 2
#     player_shots_on: 1
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 50
#     player_passes_key: 2
#     player_passes_accuracy: 40
#
#     player_tackles_total: 1
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 8
#     player_duels_won: 3
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: 1
#     player_dribbles_past: 1
#
#   player_id: 905
#   player_name: Fred
#   player_photo: https://media-3.api-sports.io/football/players/905.png
#
#     player_games_minutes: 66
#     player_games_number: 17
#     player_games_position: M
#     player_games_rating: 7.5
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: 1
#     player_goals_saves: None
#
#     player_passes_total: 51
#     player_passes_key: 5
#     player_passes_accuracy: 42
#
#     player_tackles_total: 4
#     player_tackles_blocks: None
#     player_tackles_interceptions: 1
#
#     player_duels_total: 15
#     player_duels_won: 6
#
#     player_dribbles_attempts: 5
#     player_dribbles_success: 1
#     player_dribbles_past: None
#
#   player_id: 18
#   player_name: Jadon Sancho
#   player_photo: https://media-1.api-sports.io/football/players/18.png
#
#     player_games_minutes: 90
#     player_games_number: 25
#     player_games_position: M
#     player_games_rating: 7.7
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 1
#     player_shots_on: 1
#
#     player_goals_total: 1
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 33
#     player_passes_key: 2
#     player_passes_accuracy: 29
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 6
#     player_duels_won: 3
#
#     player_dribbles_attempts: 6
#     player_dribbles_success: 3
#     player_dribbles_past: None
#
#   player_id: 1485
#   player_name: Bruno Fernandes
#   player_photo: https://media-2.api-sports.io/football/players/1485.png
#
#     player_games_minutes: 84
#     player_games_number: 8
#     player_games_position: M
#     player_games_rating: 7.9
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 2
#     player_shots_on: 2
#
#     player_goals_total: 1
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 41
#     player_passes_key: 6
#     player_passes_accuracy: 26
#
#     player_tackles_total: 1
#     player_tackles_blocks: None
#     player_tackles_interceptions: 1
#
#     player_duels_total: 6
#     player_duels_won: 1
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: None
#     player_dribbles_past: 1
#
#   player_id: 284324
#   player_name: Alejandro Garnacho
#   player_photo: https://media-3.api-sports.io/football/players/284324.png
#
#     player_games_minutes: 67
#     player_games_number: 49
#     player_games_position: M
#     player_games_rating: 6.3
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 3
#     player_shots_on: 1
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 23
#     player_passes_key: None
#     player_passes_accuracy: 19
#
#     player_tackles_total: 2
#     player_tackles_blocks: None
#     player_tackles_interceptions: 1
#
#     player_duels_total: 10
#     player_duels_won: 5
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: None
#     player_dribbles_past: 2
#
#   player_id: 909
#   player_name: Marcus Rashford
#   player_photo: https://media-2.api-sports.io/football/players/909.png
#
#     player_games_minutes: 77
#     player_games_number: 10
#     player_games_position: F
#     player_games_rating: 6.2
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 4
#     player_shots_on: 2
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 21
#     player_passes_key: None
#     player_passes_accuracy: 19
#
#     player_tackles_total: 1
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 3
#     player_duels_won: 2
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: 1
#     player_dribbles_past: None
#
#   player_id: 174
#   player_name: Christian Eriksen
#   player_photo: https://media-1.api-sports.io/football/players/174.png
#
#     player_games_minutes: 24
#     player_games_number: 14
#     player_games_position: M
#     player_games_rating: 6.6
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 15
#     player_passes_key: 1
#     player_passes_accuracy: 14
#
#     player_tackles_total: 1
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 3
#     player_duels_won: 1
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 903
#   player_name: Scott McTominay
#   player_photo: https://media-1.api-sports.io/football/players/903.png
#
#     player_games_minutes: 23
#     player_games_number: 39
#     player_games_position: M
#     player_games_rating: 6.5
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 14
#     player_passes_key: None
#     player_passes_accuracy: 11
#
#     player_tackles_total: None
#     player_tackles_blocks: 1
#     player_tackles_interceptions: 1
#
#     player_duels_total: 2
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: 1
#
#   player_id: 908
#   player_name: Anthony Martial
#   player_photo: https://media-1.api-sports.io/football/players/908.png
#
#     player_games_minutes: 23
#     player_games_number: 9
#     player_games_position: F
#     player_games_rating: 6.6
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: 1
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 3
#     player_passes_key: None
#     player_passes_accuracy: 2
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 5
#     player_duels_won: 4
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 25416
#   player_name: Wout Weghorst
#   player_photo: https://media-3.api-sports.io/football/players/25416.png
#
#     player_games_minutes: 13
#     player_games_number: 27
#     player_games_position: F
#     player_games_rating: 6
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: 1
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 5
#     player_passes_key: None
#     player_passes_accuracy: 4
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 6
#     player_duels_won: 2
#
#     player_dribbles_attempts: 3
#     player_dribbles_success: 1
#     player_dribbles_past: None
#
#   player_id: 70078
#   player_name: Facundo Pellistri
#   player_photo: https://media-3.api-sports.io/football/players/70078.png
#
#     player_games_minutes: 11
#     player_games_number: 28
#     player_games_position: M
#     player_games_rating: 6.9
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 3
#     player_passes_key: None
#     player_passes_accuracy: 3
#
#     player_tackles_total: 1
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 5
#     player_duels_won: 4
#
#     player_dribbles_attempts: 2
#     player_dribbles_success: 2
#     player_dribbles_past: None
#
#   player_id: 2930
#   player_name: Jack Butland
#   player_photo: https://media-3.api-sports.io/football/players/2930.png
#
#     player_games_minutes: None
#     player_games_number: 31
#     player_games_position: G
#     player_games_rating: None
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: None
#     player_passes_key: None
#     player_passes_accuracy: None
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 18846
#   player_name: Aaron Wan-Bissaka
#   player_photo: https://media-2.api-sports.io/football/players/18846.png
#
#     player_games_minutes: None
#     player_games_number: 29
#     player_games_position: D
#     player_games_rating: None
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: None
#     player_passes_key: None
#     player_passes_accuracy: None
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 742
#   player_name: Raphaël Varane
#   player_photo: https://media-3.api-sports.io/football/players/742.png
#
#     player_games_minutes: None
#     player_games_number: 19
#     player_games_position: D
#     player_games_rating: None
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: None
#     player_passes_key: None
#     player_passes_accuracy: None
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 891
#   player_name: Luke Shaw
#   player_photo: https://media-3.api-sports.io/football/players/891.png
#
#     player_games_minutes: None
#     player_games_number: 23
#     player_games_position: D
#     player_games_rating: None
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: None
#     player_passes_key: None
#     player_passes_accuracy: None
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#
# Team Name: Fulham
#   player_id: 1438
#   player_name: Bernd Leno
#   player_photo: https://media-2.api-sports.io/football/players/1438.png
#
#     player_games_minutes: 90
#     player_games_number: 17
#     player_games_position: G
#     player_games_rating: 7.2
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 2
#     player_goals_assists: None
#     player_goals_saves: 6
#
#     player_passes_total: 43
#     player_passes_key: None
#     player_passes_accuracy: 35
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 657
#   player_name: Kenny Tete
#   player_photo: https://media-2.api-sports.io/football/players/657.png
#
#     player_games_minutes: 90
#     player_games_number: 2
#     player_games_position: D
#     player_games_rating: 7.9
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 1
#     player_shots_on: 1
#
#     player_goals_total: 1
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 36
#     player_passes_key: None
#     player_passes_accuracy: 31
#
#     player_tackles_total: 2
#     player_tackles_blocks: 1
#     player_tackles_interceptions: 3
#
#     player_duels_total: 11
#     player_duels_won: 8
#
#     player_dribbles_attempts: 2
#     player_dribbles_success: 1
#     player_dribbles_past: None
#
#   player_id: 19145
#   player_name: Tosin Adarabioyo
#   player_photo: https://media-2.api-sports.io/football/players/19145.png
#
#     player_games_minutes: 90
#     player_games_number: 4
#     player_games_position: D
#     player_games_rating: 7.2
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 57
#     player_passes_key: None
#     player_passes_accuracy: 49
#
#     player_tackles_total: 3
#     player_tackles_blocks: 1
#     player_tackles_interceptions: 2
#
#     player_duels_total: 5
#     player_duels_won: 4
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 18814
#   player_name: Issa Diop
#   player_photo: https://media-1.api-sports.io/football/players/18814.png
#
#     player_games_minutes: 90
#     player_games_number: 31
#     player_games_position: D
#     player_games_rating: 7.2
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 64
#     player_passes_key: 1
#     player_passes_accuracy: 60
#
#     player_tackles_total: 2
#     player_tackles_blocks: 1
#     player_tackles_interceptions: None
#
#     player_duels_total: 5
#     player_duels_won: 3
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: 1
#     player_dribbles_past: 1
#
#   player_id: 19549
#   player_name: Antonee Robinson
#   player_photo: https://media-1.api-sports.io/football/players/19549.png
#
#     player_games_minutes: 90
#     player_games_number: 33
#     player_games_position: D
#     player_games_rating: 6.9
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 42
#     player_passes_key: None
#     player_passes_accuracy: 31
#
#     player_tackles_total: 3
#     player_tackles_blocks: 1
#     player_tackles_interceptions: 1
#
#     player_duels_total: 8
#     player_duels_won: 5
#
#     player_dribbles_attempts: 2
#     player_dribbles_success: 1
#     player_dribbles_past: 1
#
#   player_id: 2823
#   player_name: Saša Lukić
#   player_photo: https://media-3.api-sports.io/football/players/2823.png
#
#     player_games_minutes: 66
#     player_games_number: 28
#     player_games_position: M
#     player_games_rating: 6.9
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 1
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 18
#     player_passes_key: None
#     player_passes_accuracy: 17
#
#     player_tackles_total: None
#     player_tackles_blocks: 1
#     player_tackles_interceptions: 1
#
#     player_duels_total: 10
#     player_duels_won: 5
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: 1
#     player_dribbles_past: 1
#
#   player_id: 41104
#   player_name: João Palhinha
#   player_photo: https://media-1.api-sports.io/football/players/41104.png
#
#     player_games_minutes: 90
#     player_games_number: 26
#     player_games_position: M
#     player_games_rating: 6.5
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 33
#     player_passes_key: None
#     player_passes_accuracy: 26
#
#     player_tackles_total: 3
#     player_tackles_blocks: None
#     player_tackles_interceptions: 3
#
#     player_duels_total: 16
#     player_duels_won: 8
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: None
#     player_dribbles_past: 3
#
#   player_id: 19221
#   player_name: Harry Wilson
#   player_photo: https://media-1.api-sports.io/football/players/19221.png
#
#     player_games_minutes: 66
#     player_games_number: 8
#     player_games_position: M
#     player_games_rating: 6.6
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 1
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 17
#     player_passes_key: None
#     player_passes_accuracy: 14
#
#     player_tackles_total: 2
#     player_tackles_blocks: 1
#     player_tackles_interceptions: None
#
#     player_duels_total: 6
#     player_duels_won: 3
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 19025
#   player_name: Tom Cairney
#   player_photo: https://media-2.api-sports.io/football/players/19025.png
#
#     player_games_minutes: 80
#     player_games_number: 10
#     player_games_position: M
#     player_games_rating: 6.9
#     player_games_captain: True
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 1
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 30
#     player_passes_key: None
#     player_passes_accuracy: 27
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 8
#     player_duels_won: 4
#
#     player_dribbles_attempts: 2
#     player_dribbles_success: 1
#     player_dribbles_past: None
#
#   player_id: 2294
#   player_name: Willian
#   player_photo: https://media-1.api-sports.io/football/players/2294.png
#
#     player_games_minutes: 90
#     player_games_number: 20
#     player_games_position: M
#     player_games_rating: 7.2
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: 1
#     player_goals_saves: None
#
#     player_passes_total: 33
#     player_passes_key: 3
#     player_passes_accuracy: 28
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 5
#     player_duels_won: 2
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: 1
#     player_dribbles_past: 1
#
#   player_id: 2825
#   player_name: Aleksandar Mitrović
#   player_photo: https://media-1.api-sports.io/football/players/2825.png
#
#     player_games_minutes: 80
#     player_games_number: 9
#     player_games_position: F
#     player_games_rating: 5.3
#     player_games_captain: False
#     player_games_substitute: False
#     player_offsides: None
#
#     player_shots_total: 3
#     player_shots_on: 1
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 16
#     player_passes_key: 1
#     player_passes_accuracy: 8
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 21
#     player_duels_won: 7
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 19480
#   player_name: Harrison Reed
#   player_photo: https://media-3.api-sports.io/football/players/19480.png
#
#     player_games_minutes: 24
#     player_games_number: 6
#     player_games_position: M
#     player_games_rating: 6.7
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 22
#     player_passes_key: 1
#     player_passes_accuracy: 20
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 1
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: 1
#
#   player_id: 697
#   player_name: Manor Solomon
#   player_photo: https://media-2.api-sports.io/football/players/697.png
#
#     player_games_minutes: 24
#     player_games_number: 11
#     player_games_position: F
#     player_games_rating: 6.6
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: 2
#     player_shots_on: 1
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 11
#     player_passes_key: 1
#     player_passes_accuracy: 10
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: 1
#
#     player_duels_total: 2
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: 1
#
#   player_id: 19329
#   player_name: Daniel James
#   player_photo: https://media-2.api-sports.io/football/players/19329.png
#
#     player_games_minutes: 10
#     player_games_number: 21
#     player_games_position: M
#     player_games_rating: 6.6
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 1
#     player_passes_key: None
#     player_passes_accuracy: 1
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 2
#     player_duels_won: 1
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: 1
#     player_dribbles_past: None
#
#   player_id: 104
#   player_name: Carlos Vinícius
#   player_photo: https://media-3.api-sports.io/football/players/104.png
#
#     player_games_minutes: 10
#     player_games_number: 30
#     player_games_position: F
#     player_games_rating: 6.5
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: 1
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: 3
#     player_passes_key: None
#     player_passes_accuracy: 1
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: 2
#     player_duels_won: 1
#
#     player_dribbles_attempts: 1
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 19657
#   player_name: Marek Rodák
#   player_photo: https://media-3.api-sports.io/football/players/19657.png
#
#     player_games_minutes: None
#     player_games_number: 1
#     player_games_position: G
#     player_games_rating: None
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: None
#     player_passes_key: None
#     player_passes_accuracy: None
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 190
#   player_name: Cédric Soares
#   player_photo: https://media-3.api-sports.io/football/players/190.png
#
#     player_games_minutes: None
#     player_games_number: 12
#     player_games_position: D
#     player_games_rating: None
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: None
#     player_passes_key: None
#     player_passes_accuracy: None
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 284470
#   player_name: Matthew Max Dibley-Dias
#   player_photo: https://media-3.api-sports.io/football/players/284470.png
#
#     player_games_minutes: None
#     player_games_number: 49
#     player_games_position: M
#     player_games_rating: None
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: None
#     player_passes_key: None
#     player_passes_accuracy: None
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 19027
#   player_name: Neeskens Kebano
#   player_photo: https://media-1.api-sports.io/football/players/19027.png
#
#     player_games_minutes: None
#     player_games_number: 7
#     player_games_position: M
#     player_games_rating: None
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: None
#     player_passes_key: None
#     player_passes_accuracy: None
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
#
#   player_id: 19004
#   player_name: Bobby Decordova-Reid
#   player_photo: https://media-2.api-sports.io/football/players/19004.png
#
#     player_games_minutes: None
#     player_games_number: 14
#     player_games_position: F
#     player_games_rating: None
#     player_games_captain: False
#     player_games_substitute: True
#     player_offsides: None
#
#     player_shots_total: None
#     player_shots_on: None
#
#     player_goals_total: None
#     player_goals_conceded: 0
#     player_goals_assists: None
#     player_goals_saves: None
#
#     player_passes_total: None
#     player_passes_key: None
#     player_passes_accuracy: None
#
#     player_tackles_total: None
#     player_tackles_blocks: None
#     player_tackles_interceptions: None
#
#     player_duels_total: None
#     player_duels_won: None
#
#     player_dribbles_attempts: None
#     player_dribbles_success: None
#     player_dribbles_past: None
