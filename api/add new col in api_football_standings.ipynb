# %%
arr_col = [
# "home_goals_for_average:double",
# "away_goals_for_average:double",
# "goals_for_average:double",

# "home_goals_for_minute_0_15_total:SMALLINT",
# "home_goals_for_minute_0_15_percentage:double",

# "home_goals_for_minute_16_30_total:SMALLINT",
# "home_goals_for_minute_16_30_percentage:double",

# "home_goals_for_minute_31_45_total:SMALLINT",
# "home_goals_for_minute_31_45_percentage:double",

# "home_goals_for_minute_46_60_total:SMALLINT",
# "home_goals_for_minute_46_60_percentage:double",

# "home_goals_for_minute_61_75_total:SMALLINT",
# "home_goals_for_minute_61_75_percentage:double",

# "home_goals_for_minute_76_90_total:SMALLINT",
# "home_goals_for_minute_76_90_percentage:double",

# "home_goals_for_minute_91_105_total:SMALLINT",
# "home_goals_for_minute_91_105_percentage:double",

# "home_goals_for_minute_106_120_total:SMALLINT",
# "home_goals_for_minute_106_120_percentage:double",

# "away_goals_for_minute_0_15_total:SMALLINT",
# "away_goals_for_minute_0_15_percentage:double",

# "away_goals_for_minute_16_30_total:SMALLINT",
# "away_goals_for_minute_16_30_percentage:double",

# "away_goals_for_minute_31_45_total:SMALLINT",
# "away_goals_for_minute_31_45_percentage:double",

# "away_goals_for_minute_46_60_total:SMALLINT",
# "away_goals_for_minute_46_60_percentage:double",

# "away_goals_for_minute_61_75_total:SMALLINT",
# "away_goals_for_minute_61_75_percentage:double",

# "away_goals_for_minute_76_90_total:SMALLINT",
# "away_goals_for_minute_76_90_percentage:double",

# "away_goals_for_minute_91_105_total:SMALLINT",
# "away_goals_for_minute_91_105_percentage:double",

# "away_goals_for_minute_106_120_total:SMALLINT",
# "away_goals_for_minute_106_120_percentage:double",

# "home_goals_against_average:double",
# "away_goals_against_average:double",
# "goals_against_average:double",


# "home_goals_against_minute_0_15_total:SMALLINT",
# "home_goals_against_minute_0_15_percentage:double",

# "home_goals_against_minute_16_30_total:SMALLINT",
# "home_goals_against_minute_16_30_percentage:double",

# "home_goals_against_minute_31_45_total:SMALLINT",
# "home_goals_against_minute_31_45_percentage:double",

# "home_goals_against_minute_46_60_total:SMALLINT",
# "home_goals_against_minute_46_60_percentage:double",

# "home_goals_against_minute_61_75_total:SMALLINT",
# "home_goals_against_minute_61_75_percentage:double",

# "home_goals_against_minute_76_90_total:SMALLINT",
# "home_goals_against_minute_76_90_percentage:double",

# "home_goals_against_minute_91_105_total:SMALLINT",
# "home_goals_against_minute_91_105_percentage:double",

# "home_goals_against_minute_106_120_total:SMALLINT",
# "home_goals_against_minute_106_120_percentage:double",

# "away_goals_against_minute_0_15_total:SMALLINT",
# "away_goals_against_minute_0_15_percentage:double",

# "away_goals_against_minute_16_30_total:SMALLINT",
# "away_goals_against_minute_16_30_percentage:double",

# "away_goals_against_minute_31_45_total:SMALLINT",
# "away_goals_against_minute_31_45_percentage:double",

# "away_goals_against_minute_46_60_total:SMALLINT",
# "away_goals_against_minute_46_60_percentage:double",

# "away_goals_against_minute_61_75_total:SMALLINT",
# "away_goals_against_minute_61_75_percentage:double",

# "away_goals_against_minute_76_90_total:SMALLINT",
# "away_goals_against_minute_76_90_percentage:double",

# "away_goals_against_minute_91_105_total:SMALLINT",
# "away_goals_against_minute_91_105_percentage:double",

# "away_goals_against_minute_106_120_total:SMALLINT",
# "away_goals_against_minute_106_120_percentage:double",

# "biggest_streak_wins:SMALLINT",
# "biggest_streak_draws:SMALLINT",
# "biggest_streak_loses:SMALLINT",

"biggest_wins_home:varchar(5)",
"biggest_wins_away:varchar(5)",

"biggest_loses_home:varchar(5)",
"biggest_loses_away:varchar(5)",

"biggest_goals_for_home:SMALLINT",
"biggest_goals_for_away:SMALLINT",

"biggest_goals_against_home:SMALLINT",
"biggest_goals_against_away:SMALLINT",

"clean_sheet_home:SMALLINT",
"clean_sheet_away:SMALLINT",
"clean_sheet_total:SMALLINT",

"failed_to_score_home:SMALLINT",
"failed_to_score_away:SMALLINT",
"failed_to_score_total:SMALLINT",

"penalty_scored_total:SMALLINT",
"penalty_scored_percentage:double",

"penalty_missed_total:SMALLINT",
"penalty_missed_percentage:double",

"penalty_total:SMALLINT",

"cards_yellow_0_15_total:SMALLINT",
"cards_yellow_0_15_percentage:double",

"cards_yellow_16_30_total:SMALLINT",
"cards_yellow_16_30_percentage:double",

"cards_yellow_31_45_total:SMALLINT",
"cards_yellow_31_45_percentage:double",

"cards_yellow_46_60_total:SMALLINT",
"cards_yellow_46_60_percentage:double",

"cards_yellow_61_75_total:SMALLINT",
"cards_yellow_61_75_percentage:double",

"cards_yellow_76_90_total:SMALLINT",
"cards_yellow_76_90_percentage:double",

"cards_yellow_91_105_total:SMALLINT",
"cards_yellow_91_105_percentage:double",

"cards_yellow_106_120_total:SMALLINT",
"cards_yellow_106_120_percentage:double",

"cards_red_0_15_total:SMALLINT",
"cards_red_0_15_percentage:double",

"cards_red_16_30_total:SMALLINT",
"cards_red_16_30_percentage:double",

"cards_red_31_45_total:SMALLINT",
"cards_red_31_45_percentage:double",

"cards_red_46_60_total:SMALLINT",
"cards_red_46_60_percentage:double",

"cards_red_61_75_total:SMALLINT",
"cards_red_61_75_percentage:double",

"cards_red_76_90_total:SMALLINT",
"cards_red_76_90_percentage:double",

"cards_red_91_105_total:SMALLINT",
"cards_red_91_105_percentage:double", 

"cards_red_106_120_total:SMALLINT",
"cards_red_106_120_percentage:double",
]

# %%
import mysql.connector


old_col =  "biggest_streak_loses"
for x in arr_col:  
      
    # -----------------------------------------------------------------
    host="localhost"
    user="root"
    database="pr_mmbuzz_2022_06" 
    mydb = mysql.connector.connect( host=host, user=user, password="", database=database )
    mycursor = mydb.cursor() 
    # -----------------------------------------------------------------
    column_name, data_type = x.split(":")
    
    query = "ALTER TABLE `api_football_standings` ADD `"+column_name+"` "+data_type+" NULL DEFAULT NULL AFTER `"+old_col+"`;"
    old_col = column_name
    print(query) 
    mycursor.execute(query)
    mydb.commit()
# Out:
# ALTER TABLE `api_football_standings` ADD `biggest_wins_home` varchar(5) NULL DEFAULT NULL AFTER `biggest_streak_loses`;
# ALTER TABLE `api_football_standings` ADD `biggest_wins_away` varchar(5) NULL DEFAULT NULL AFTER `biggest_wins_home`;
# ALTER TABLE `api_football_standings` ADD `biggest_loses_home` varchar(5) NULL DEFAULT NULL AFTER `biggest_wins_away`;
# ALTER TABLE `api_football_standings` ADD `biggest_loses_away` varchar(5) NULL DEFAULT NULL AFTER `biggest_loses_home`;
# ALTER TABLE `api_football_standings` ADD `biggest_goals_for_home` SMALLINT NULL DEFAULT NULL AFTER `biggest_loses_away`;
# ALTER TABLE `api_football_standings` ADD `biggest_goals_for_away` SMALLINT NULL DEFAULT NULL AFTER `biggest_goals_for_home`;
# ALTER TABLE `api_football_standings` ADD `biggest_goals_against_home` SMALLINT NULL DEFAULT NULL AFTER `biggest_goals_for_away`;
# ALTER TABLE `api_football_standings` ADD `biggest_goals_against_away` SMALLINT NULL DEFAULT NULL AFTER `biggest_goals_against_home`;
# ...
