# %%
# Import 

# Import
import sys
sys.path.append('../')


from a_settings.messages import *   
from a_models.date import *   
from a_models.football_statistics import *   
from a_models.api_standings import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    leagueapi_id   = input(space + "Enter your leagueapi id :  ")
    season         = input(space + "Enter your season :  ")   
    # --------------------------------------------------  
    DICT = {
        'leagueapi_id' :leagueapi_id,
        'season' :season, 
    }
    # # ------------------------------------------------------  
    as_controll_match_update(DICT, "Null", space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-23 23:31:21
#   __main()
#   ____Enter your leagueapi id :  61
#   ____Enter your season :  2022
#   ______as_controll_match_update()
#   ________aa_check_acccount()
#   __________API api3@ariondigitalmedia.com counter is 41
#   __________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________as_response_odds()
#   __________DICTleagueapi_id : 61
#   __________DICTseason : 2022
#   __________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________
#   __________Total API Response(s) : 1
#
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 85
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 85
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 40
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 85
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 11
#   ____________________api_football_standings STATISTICS UPDATED
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 116
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 116
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 39
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 116
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 11
#   ____________________api_football_standings STATISTICS UPDATED
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 81
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 81
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 38
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 81
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 11
#   ____________________api_football_standings STATISTICS UPDATED
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 94
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 94
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 37
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 94
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 11
#   ____________________api_football_standings STATISTICS UPDATED
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 79
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 79
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 36
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 79
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 11
#   ____________________api_football_standings STATISTICS UPDATED
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 91
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 91
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 35
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 91
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 11
#   ____________________api_football_standings STATISTICS UPDATED
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 80
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 80
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 34
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 80
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 11
#   ____________________api_football_standings STATISTICS UPDATED
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 99
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 99
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 33
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 99
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 11
#   ____________________api_football_standings STATISTICS UPDATED
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 84
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 84
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 32
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 84
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 11
#   ____________________api_football_standings STATISTICS UPDATED
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 97
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 97
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 31
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 97
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 11
#   ____________________api_football_standings STATISTICS UPDATED
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 93
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 93
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 30
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 93
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
# KeyErrorKeyErrorKeyError
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 82
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 82
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 29
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 82
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
# KeyErrorKeyErrorKeyError
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 96
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 96
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 28
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 96
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
# KeyErrorKeyErrorKeyError
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 106
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 106
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 27
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 106
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
# KeyErrorKeyErrorKeyError
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 95
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 95
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 26
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 95
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
# KeyErrorKeyErrorKeyError
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 83
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 83
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 25
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 83
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
# KeyErrorKeyErrorKeyError
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 108
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 108
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 24
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 108
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
# KeyErrorKeyErrorKeyError
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 98
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 98
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 23
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 98
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
# KeyErrorKeyErrorKeyError
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 110
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 110
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 22
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 110
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
# KeyErrorKeyErrorKeyError
#   ______________aFS_check()
#   ______________leagueapi_id : 61
#   ______________season : 2022
#   ______________teamapi_id : 77
#   ________________ Select  *  from api_football_standings  where leagueapi_id = 61  and season = 2022  and teamapi_id = 77
#   ________________total_rows: 0
#   ____________api_football_standings INSERTED
#   ______________ats_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api3@ariondigitalmedia.com counter is 21
#   __________________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ats_response_odds()
#   __________________DICTleagueapi_id : 61
#   __________________DICTseason : 2022
#   __________________DICTteam : 77
#   __________________APIkey : dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________________________________________________________________________________________
# KeyErrorKeyErrorKeyError
# # -------------------------------------------------- End at 2023-07-23 23:31:35
