# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *  
from a_models.date import *    
from a_models.team_analysis import *    
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_adds(2, space).strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    ta_analyze_today(day1, day2, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 16:20:46
#   __main()
#   ____get_today_subs()
#   ______subs date_diff : 1
#   ______today_raw : 2023-09-02 16:20:46.969609
#   ____get_today_adds()
#   ______adds date_diff : 2
#   ______today_raw : 2023-09-05 16:20:46.970610
#   ____ta_analyze_today()
#   ______Select  fixtureapi_id  ,  leagueapi_id  ,  season  ,  date  ,  teams_homeapi_id  ,  teams_awayapi_id  ,  round  from football_fixtures  where DATE(date) >= DATE('2023-09-02')  and DATE(date) <= DATE('2023-09-05')  and leagueapi_id IN (Select leagueapi_id from football_leagues where team_statistics = 1 )
#   ________Total Row(s) : 9
#   __________[1/9]  #39 __ 2023 __ 1035067 __ 2023-09-03 15:30:00 __ Regular Season - 4
#   ____________ta_analyze_details()
#   ______________corners: 24 __ avg: 8.0000
#   ______________total_shots: 48 __ avg: 16.0000
#   ______________shots_on_goal: 21 __ avg: 7.0000
#   ______________fouls: 28 __ avg: 9.3333
#   ______________offsides: 8 __ avg: 2.6667
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 24,  `corner_kicks_avg` = 8.0000,  `corner_kicks_max` = 8,  `corner_kicks_min` = 8,  `total_shots_total` = 48,  `total_shots_avg` = 16.0000,  `total_shots_max` = 19,  `total_shots_min` = 14,  `shots_on_goal_total` = 21,  `shots_on_goal_avg` = 7.0000,  `shots_on_goal_max` = 11,  `shots_on_goal_min` = 3,  `fouls_total` = 28,  `fouls_avg` = 9.3333,  `fouls_max` = 12,  `fouls_min` = 6,  `offsides_total` = 8,  `offsides_avg` = 2.6667,  `offsides_max` = 4,  `offsides_min` = 2,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 42
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_home` = 24,  `corner_kicks_avg_home` = 8.0000,  `corner_kicks_max_home` = 8,  `corner_kicks_min_home` = 8,  `total_shots_total_home` = 48,  `total_shots_avg_home` = 16.0000,  `total_shots_max_home` = 19,  `total_shots_min_home` = 14,  `shots_on_goal_total_home` = 21,  `shots_on_goal_avg_home` = 7.0000,  `shots_on_goal_max_home` = 11,  `shots_on_goal_min_home` = 3,  `fouls_total_home` = 28,  `fouls_avg_home` = 9.3333,  `fouls_max_home` = 12,  `fouls_min_home` = 6,  `offsides_total_home` = 8,  `offsides_avg_home` = 2.6667,  `offsides_max_home` = 4,  `offsides_min_home` = 2,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035067
#   ____________ta_analyze_details()
#   ______________corners: 25 __ avg: 8.3333
#   ______________total_shots: 55 __ avg: 18.3333
#   ______________shots_on_goal: 18 __ avg: 6.0000
#   ______________fouls: 36 __ avg: 12.0000
#   ______________offsides: 8 __ avg: 2.6667
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 25,  `corner_kicks_avg` = 8.3333,  `corner_kicks_max` = 11,  `corner_kicks_min` = 6,  `total_shots_total` = 55,  `total_shots_avg` = 18.3333,  `total_shots_max` = 22,  `total_shots_min` = 15,  `shots_on_goal_total` = 18,  `shots_on_goal_avg` = 6.0000,  `shots_on_goal_max` = 9,  `shots_on_goal_min` = 3,  `fouls_total` = 36,  `fouls_avg` = 12.0000,  `fouls_max` = 15,  `fouls_min` = 8,  `offsides_total` = 8,  `offsides_avg` = 2.6667,  `offsides_max` = 4,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 33
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_away` = 25,  `corner_kicks_avg_away` = 8.3333,  `corner_kicks_max_away` = 11,  `corner_kicks_min_away` = 6,  `total_shots_total_away` = 55,  `total_shots_avg_away` = 18.3333,  `total_shots_max_away` = 22,  `total_shots_min_away` = 15,  `shots_on_goal_total_away` = 18,  `shots_on_goal_avg_away` = 6.0000,  `shots_on_goal_max_away` = 9,  `shots_on_goal_min_away` = 3,  `fouls_total_away` = 36,  `fouls_avg_away` = 12.0000,  `fouls_max_away` = 15,  `fouls_min_away` = 8,  `offsides_total_away` = 8,  `offsides_avg_away` = 2.6667,  `offsides_max_away` = 4,  `offsides_min_away` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035067
#   __________[2/9]  #39 __ 2023 __ 1035068 __ 2023-09-02 14:00:00 __ Regular Season - 4
#   ____________ta_analyze_details()
#   ______________corners: 16 __ avg: 5.3333
#   ______________total_shots: 40 __ avg: 13.3333
#   ______________shots_on_goal: 15 __ avg: 5.0000
#   ______________fouls: 33 __ avg: 11.0000
#   ______________offsides: 7 __ avg: 2.3333
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 16,  `corner_kicks_avg` = 5.3333,  `corner_kicks_max` = 8,  `corner_kicks_min` = 3,  `total_shots_total` = 40,  `total_shots_avg` = 13.3333,  `total_shots_max` = 17,  `total_shots_min` = 11,  `shots_on_goal_total` = 15,  `shots_on_goal_avg` = 5.0000,  `shots_on_goal_max` = 8,  `shots_on_goal_min` = 1,  `fouls_total` = 33,  `fouls_avg` = 11.0000,  `fouls_max` = 12,  `fouls_min` = 9,  `offsides_total` = 7,  `offsides_avg` = 2.3333,  `offsides_max` = 4,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 55
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_home` = 16,  `corner_kicks_avg_home` = 5.3333,  `corner_kicks_max_home` = 8,  `corner_kicks_min_home` = 3,  `total_shots_total_home` = 40,  `total_shots_avg_home` = 13.3333,  `total_shots_max_home` = 17,  `total_shots_min_home` = 11,  `shots_on_goal_total_home` = 15,  `shots_on_goal_avg_home` = 5.0000,  `shots_on_goal_max_home` = 8,  `shots_on_goal_min_home` = 1,  `fouls_total_home` = 33,  `fouls_avg_home` = 11.0000,  `fouls_max_home` = 12,  `fouls_min_home` = 9,  `offsides_total_home` = 7,  `offsides_avg_home` = 2.3333,  `offsides_max_home` = 4,  `offsides_min_home` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035068
#   ____________ta_analyze_details()
#   ______________corners: 18 __ avg: 6.0000
#   ______________total_shots: 38 __ avg: 12.6667
#   ______________shots_on_goal: 13 __ avg: 4.3333
#   ______________fouls: 40 __ avg: 13.3333
#   ______________offsides: 6 __ avg: 3.0000
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 18,  `corner_kicks_avg` = 6.0000,  `corner_kicks_max` = 10,  `corner_kicks_min` = 2,  `total_shots_total` = 38,  `total_shots_avg` = 12.6667,  `total_shots_max` = 14,  `total_shots_min` = 11,  `shots_on_goal_total` = 13,  `shots_on_goal_avg` = 4.3333,  `shots_on_goal_max` = 5,  `shots_on_goal_min` = 3,  `fouls_total` = 40,  `fouls_avg` = 13.3333,  `fouls_max` = 18,  `fouls_min` = 9,  `offsides_total` = 6,  `offsides_avg` = 3.0000,  `offsides_max` = 3,  `offsides_min` = 3,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 35
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_away` = 18,  `corner_kicks_avg_away` = 6.0000,  `corner_kicks_max_away` = 10,  `corner_kicks_min_away` = 2,  `total_shots_total_away` = 38,  `total_shots_avg_away` = 12.6667,  `total_shots_max_away` = 14,  `total_shots_min_away` = 11,  `shots_on_goal_total_away` = 13,  `shots_on_goal_avg_away` = 4.3333,  `shots_on_goal_max_away` = 5,  `shots_on_goal_min_away` = 3,  `fouls_total_away` = 40,  `fouls_avg_away` = 13.3333,  `fouls_max_away` = 18,  `fouls_min_away` = 9,  `offsides_total_away` = 6,  `offsides_avg_away` = 3.0000,  `offsides_max_away` = 3,  `offsides_min_away` = 3,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035068
#   __________[3/9]  #39 __ 2023 __ 1035069 __ 2023-09-02 16:30:00 __ Regular Season - 4
#   ____________ta_analyze_details()
#   ______________corners: 26 __ avg: 8.6667
#   ______________total_shots: 68 __ avg: 22.6667
#   ______________shots_on_goal: 30 __ avg: 10.0000
#   ______________fouls: 32 __ avg: 10.6667
#   ______________offsides: 10 __ avg: 3.3333
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 26,  `corner_kicks_avg` = 8.6667,  `corner_kicks_max` = 17,  `corner_kicks_min` = 3,  `total_shots_total` = 68,  `total_shots_avg` = 22.6667,  `total_shots_max` = 27,  `total_shots_min` = 16,  `shots_on_goal_total` = 30,  `shots_on_goal_avg` = 10.0000,  `shots_on_goal_max` = 12,  `shots_on_goal_min` = 8,  `fouls_total` = 32,  `fouls_avg` = 10.6667,  `fouls_max` = 11,  `fouls_min` = 10,  `offsides_total` = 10,  `offsides_avg` = 3.3333,  `offsides_max` = 7,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 51
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_home` = 26,  `corner_kicks_avg_home` = 8.6667,  `corner_kicks_max_home` = 17,  `corner_kicks_min_home` = 3,  `total_shots_total_home` = 68,  `total_shots_avg_home` = 22.6667,  `total_shots_max_home` = 27,  `total_shots_min_home` = 16,  `shots_on_goal_total_home` = 30,  `shots_on_goal_avg_home` = 10.0000,  `shots_on_goal_max_home` = 12,  `shots_on_goal_min_home` = 8,  `fouls_total_home` = 32,  `fouls_avg_home` = 10.6667,  `fouls_max_home` = 11,  `fouls_min_home` = 10,  `offsides_total_home` = 10,  `offsides_avg_home` = 3.3333,  `offsides_max_home` = 7,  `offsides_min_home` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035069
#   ____________ta_analyze_details()
#   ______________corners: 11 __ avg: 5.5000
#   ______________total_shots: 47 __ avg: 15.6667
#   ______________shots_on_goal: 22 __ avg: 7.3333
#   ______________fouls: 39 __ avg: 13.0000
#   ______________offsides: 6 __ avg: 3.0000
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 11,  `corner_kicks_avg` = 5.5000,  `corner_kicks_max` = 6,  `corner_kicks_min` = 5,  `total_shots_total` = 47,  `total_shots_avg` = 15.6667,  `total_shots_max` = 23,  `total_shots_min` = 7,  `shots_on_goal_total` = 22,  `shots_on_goal_avg` = 7.3333,  `shots_on_goal_max` = 13,  `shots_on_goal_min` = 1,  `fouls_total` = 39,  `fouls_avg` = 13.0000,  `fouls_max` = 16,  `fouls_min` = 11,  `offsides_total` = 6,  `offsides_avg` = 3.0000,  `offsides_max` = 4,  `offsides_min` = 2,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 34
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_away` = 11,  `corner_kicks_avg_away` = 5.5000,  `corner_kicks_max_away` = 6,  `corner_kicks_min_away` = 5,  `total_shots_total_away` = 47,  `total_shots_avg_away` = 15.6667,  `total_shots_max_away` = 23,  `total_shots_min_away` = 7,  `shots_on_goal_total_away` = 22,  `shots_on_goal_avg_away` = 7.3333,  `shots_on_goal_max_away` = 13,  `shots_on_goal_min_away` = 1,  `fouls_total_away` = 39,  `fouls_avg_away` = 13.0000,  `fouls_max_away` = 16,  `fouls_min_away` = 11,  `offsides_total_away` = 6,  `offsides_avg_away` = 3.0000,  `offsides_max_away` = 4,  `offsides_min_away` = 2,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035069
#   __________[4/9]  #39 __ 2023 __ 1035070 __ 2023-09-02 14:00:00 __ Regular Season - 4
#   ____________ta_analyze_details()
#   ______________corners: 10 __ avg: 5.0000
#   ______________total_shots: 15 __ avg: 7.5000
#   ______________shots_on_goal: 3 __ avg: 1.5000
#   ______________fouls: 23 __ avg: 11.5000
#   ______________offsides: 5 __ avg: 5.0000
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 10,  `corner_kicks_avg` = 5.0000,  `corner_kicks_max` = 6,  `corner_kicks_min` = 4,  `total_shots_total` = 15,  `total_shots_avg` = 7.5000,  `total_shots_max` = 9,  `total_shots_min` = 6,  `shots_on_goal_total` = 3,  `shots_on_goal_avg` = 1.5000,  `shots_on_goal_max` = 2,  `shots_on_goal_min` = 1,  `fouls_total` = 23,  `fouls_avg` = 11.5000,  `fouls_max` = 12,  `fouls_min` = 11,  `offsides_total` = 5,  `offsides_avg` = 5.0000,  `offsides_max` = 5,  `offsides_min` = 5,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 44
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_home` = 10,  `corner_kicks_avg_home` = 5.0000,  `corner_kicks_max_home` = 6,  `corner_kicks_min_home` = 4,  `total_shots_total_home` = 15,  `total_shots_avg_home` = 7.5000,  `total_shots_max_home` = 9,  `total_shots_min_home` = 6,  `shots_on_goal_total_home` = 3,  `shots_on_goal_avg_home` = 1.5000,  `shots_on_goal_max_home` = 2,  `shots_on_goal_min_home` = 1,  `fouls_total_home` = 23,  `fouls_avg_home` = 11.5000,  `fouls_max_home` = 12,  `fouls_min_home` = 11,  `offsides_total_home` = 5,  `offsides_avg_home` = 5.0000,  `offsides_max_home` = 5,  `offsides_min_home` = 5,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035070
#   ____________ta_analyze_details()
#   ______________corners: 13 __ avg: 4.3333
#   ______________total_shots: 52 __ avg: 17.3333
#   ______________shots_on_goal: 18 __ avg: 6.0000
#   ______________fouls: 33 __ avg: 11.0000
#   ______________offsides: 1 __ avg: 1.0000
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 13,  `corner_kicks_avg` = 4.3333,  `corner_kicks_max` = 6,  `corner_kicks_min` = 2,  `total_shots_total` = 52,  `total_shots_avg` = 17.3333,  `total_shots_max` = 18,  `total_shots_min` = 17,  `shots_on_goal_total` = 18,  `shots_on_goal_avg` = 6.0000,  `shots_on_goal_max` = 6,  `shots_on_goal_min` = 6,  `fouls_total` = 33,  `fouls_avg` = 11.0000,  `fouls_max` = 13,  `fouls_min` = 9,  `offsides_total` = 1,  `offsides_avg` = 1.0000,  `offsides_max` = 1,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 47
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_away` = 13,  `corner_kicks_avg_away` = 4.3333,  `corner_kicks_max_away` = 6,  `corner_kicks_min_away` = 2,  `total_shots_total_away` = 52,  `total_shots_avg_away` = 17.3333,  `total_shots_max_away` = 18,  `total_shots_min_away` = 17,  `shots_on_goal_total_away` = 18,  `shots_on_goal_avg_away` = 6.0000,  `shots_on_goal_max_away` = 6,  `shots_on_goal_min_away` = 6,  `fouls_total_away` = 33,  `fouls_avg_away` = 11.0000,  `fouls_max_away` = 13,  `fouls_min_away` = 9,  `offsides_total_away` = 1,  `offsides_avg_away` = 1.0000,  `offsides_max_away` = 1,  `offsides_min_away` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035070
#   __________[5/9]  #39 __ 2023 __ 1035071 __ 2023-09-02 14:00:00 __ Regular Season - 4
#   ____________ta_analyze_details()
#   ______________corners: 19 __ avg: 6.3333
#   ______________total_shots: 46 __ avg: 15.3333
#   ______________shots_on_goal: 16 __ avg: 5.3333
#   ______________fouls: 29 __ avg: 9.6667
#   ______________offsides: 5 __ avg: 2.5000
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 19,  `corner_kicks_avg` = 6.3333,  `corner_kicks_max` = 9,  `corner_kicks_min` = 4,  `total_shots_total` = 46,  `total_shots_avg` = 15.3333,  `total_shots_max` = 19,  `total_shots_min` = 10,  `shots_on_goal_total` = 16,  `shots_on_goal_avg` = 5.3333,  `shots_on_goal_max` = 8,  `shots_on_goal_min` = 4,  `fouls_total` = 29,  `fouls_avg` = 9.6667,  `fouls_max` = 15,  `fouls_min` = 5,  `offsides_total` = 5,  `offsides_avg` = 2.5000,  `offsides_max` = 3,  `offsides_min` = 2,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 49
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_home` = 19,  `corner_kicks_avg_home` = 6.3333,  `corner_kicks_max_home` = 9,  `corner_kicks_min_home` = 4,  `total_shots_total_home` = 46,  `total_shots_avg_home` = 15.3333,  `total_shots_max_home` = 19,  `total_shots_min_home` = 10,  `shots_on_goal_total_home` = 16,  `shots_on_goal_avg_home` = 5.3333,  `shots_on_goal_max_home` = 8,  `shots_on_goal_min_home` = 4,  `fouls_total_home` = 29,  `fouls_avg_home` = 9.6667,  `fouls_max_home` = 15,  `fouls_min_home` = 5,  `offsides_total_home` = 5,  `offsides_avg_home` = 2.5000,  `offsides_max_home` = 3,  `offsides_min_home` = 2,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035071
#   ____________ta_analyze_details()
#   ______________corners: 12 __ avg: 4.0000
#   ______________total_shots: 31 __ avg: 10.3333
#   ______________shots_on_goal: 10 __ avg: 3.3333
#   ______________fouls: 28 __ avg: 9.3333
#   ______________offsides: 6 __ avg: 2.0000
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 12,  `corner_kicks_avg` = 4.0000,  `corner_kicks_max` = 6,  `corner_kicks_min` = 3,  `total_shots_total` = 31,  `total_shots_avg` = 10.3333,  `total_shots_max` = 16,  `total_shots_min` = 6,  `shots_on_goal_total` = 10,  `shots_on_goal_avg` = 3.3333,  `shots_on_goal_max` = 4,  `shots_on_goal_min` = 2,  `fouls_total` = 28,  `fouls_avg` = 9.3333,  `fouls_max` = 12,  `fouls_min` = 5,  `offsides_total` = 6,  `offsides_avg` = 2.0000,  `offsides_max` = 3,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 65
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_away` = 12,  `corner_kicks_avg_away` = 4.0000,  `corner_kicks_max_away` = 6,  `corner_kicks_min_away` = 3,  `total_shots_total_away` = 31,  `total_shots_avg_away` = 10.3333,  `total_shots_max_away` = 16,  `total_shots_min_away` = 6,  `shots_on_goal_total_away` = 10,  `shots_on_goal_avg_away` = 3.3333,  `shots_on_goal_max_away` = 4,  `shots_on_goal_min_away` = 2,  `fouls_total_away` = 28,  `fouls_avg_away` = 9.3333,  `fouls_max_away` = 12,  `fouls_min_away` = 5,  `offsides_total_away` = 6,  `offsides_avg_away` = 2.0000,  `offsides_max_away` = 3,  `offsides_min_away` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035071
#   __________[6/9]  #39 __ 2023 __ 1035072 __ 2023-09-03 13:00:00 __ Regular Season - 4
#   ____________ta_analyze_details()
#   ______________corners: 12 __ avg: 4.0000
#   ______________total_shots: 53 __ avg: 17.6667
#   ______________shots_on_goal: 15 __ avg: 5.0000
#   ______________fouls: 40 __ avg: 13.3333
#   ______________offsides: 4 __ avg: 2.0000
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 12,  `corner_kicks_avg` = 4.0000,  `corner_kicks_max` = 6,  `corner_kicks_min` = 1,  `total_shots_total` = 53,  `total_shots_avg` = 17.6667,  `total_shots_max` = 24,  `total_shots_min` = 14,  `shots_on_goal_total` = 15,  `shots_on_goal_avg` = 5.0000,  `shots_on_goal_max` = 8,  `shots_on_goal_min` = 2,  `fouls_total` = 40,  `fouls_avg` = 13.3333,  `fouls_max` = 15,  `fouls_min` = 11,  `offsides_total` = 4,  `offsides_avg` = 2.0000,  `offsides_max` = 2,  `offsides_min` = 2,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 52
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_home` = 12,  `corner_kicks_avg_home` = 4.0000,  `corner_kicks_max_home` = 6,  `corner_kicks_min_home` = 1,  `total_shots_total_home` = 53,  `total_shots_avg_home` = 17.6667,  `total_shots_max_home` = 24,  `total_shots_min_home` = 14,  `shots_on_goal_total_home` = 15,  `shots_on_goal_avg_home` = 5.0000,  `shots_on_goal_max_home` = 8,  `shots_on_goal_min_home` = 2,  `fouls_total_home` = 40,  `fouls_avg_home` = 13.3333,  `fouls_max_home` = 15,  `fouls_min_home` = 11,  `offsides_total_home` = 4,  `offsides_avg_home` = 2.0000,  `offsides_max_home` = 2,  `offsides_min_home` = 2,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035072
#   ____________ta_analyze_details()
#   ______________corners: 12 __ avg: 6.0000
#   ______________total_shots: 50 __ avg: 16.6667
#   ______________shots_on_goal: 13 __ avg: 4.3333
#   ______________fouls: 38 __ avg: 12.6667
#   ______________offsides: 8 __ avg: 2.6667
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 12,  `corner_kicks_avg` = 6.0000,  `corner_kicks_max` = 7,  `corner_kicks_min` = 5,  `total_shots_total` = 50,  `total_shots_avg` = 16.6667,  `total_shots_max` = 23,  `total_shots_min` = 11,  `shots_on_goal_total` = 13,  `shots_on_goal_avg` = 4.3333,  `shots_on_goal_max` = 6,  `shots_on_goal_min` = 2,  `fouls_total` = 38,  `fouls_avg` = 12.6667,  `fouls_max` = 14,  `fouls_min` = 10,  `offsides_total` = 8,  `offsides_avg` = 2.6667,  `offsides_max` = 4,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 39
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_away` = 12,  `corner_kicks_avg_away` = 6.0000,  `corner_kicks_max_away` = 7,  `corner_kicks_min_away` = 5,  `total_shots_total_away` = 50,  `total_shots_avg_away` = 16.6667,  `total_shots_max_away` = 23,  `total_shots_min_away` = 11,  `shots_on_goal_total_away` = 13,  `shots_on_goal_avg_away` = 4.3333,  `shots_on_goal_max_away` = 6,  `shots_on_goal_min_away` = 2,  `fouls_total_away` = 38,  `fouls_avg_away` = 12.6667,  `fouls_max_away` = 14,  `fouls_min_away` = 10,  `offsides_total_away` = 8,  `offsides_avg_away` = 2.6667,  `offsides_max_away` = 4,  `offsides_min_away` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035072
#   __________[7/9]  #39 __ 2023 __ 1035073 __ 2023-09-03 13:00:00 __ Regular Season - 4
#   ____________ta_analyze_details()
#   ______________corners: 23 __ avg: 7.6667
#   ______________total_shots: 48 __ avg: 16.0000
#   ______________shots_on_goal: 15 __ avg: 5.0000
#   ______________fouls: 34 __ avg: 11.3333
#   ______________offsides: 6 __ avg: 3.0000
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 23,  `corner_kicks_avg` = 7.6667,  `corner_kicks_max` = 10,  `corner_kicks_min` = 4,  `total_shots_total` = 48,  `total_shots_avg` = 16.0000,  `total_shots_max` = 26,  `total_shots_min` = 9,  `shots_on_goal_total` = 15,  `shots_on_goal_avg` = 5.0000,  `shots_on_goal_max` = 10,  `shots_on_goal_min` = 1,  `fouls_total` = 34,  `fouls_avg` = 11.3333,  `fouls_max` = 13,  `fouls_min` = 10,  `offsides_total` = 6,  `offsides_avg` = 3.0000,  `offsides_max` = 5,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 40
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_home` = 23,  `corner_kicks_avg_home` = 7.6667,  `corner_kicks_max_home` = 10,  `corner_kicks_min_home` = 4,  `total_shots_total_home` = 48,  `total_shots_avg_home` = 16.0000,  `total_shots_max_home` = 26,  `total_shots_min_home` = 9,  `shots_on_goal_total_home` = 15,  `shots_on_goal_avg_home` = 5.0000,  `shots_on_goal_max_home` = 10,  `shots_on_goal_min_home` = 1,  `fouls_total_home` = 34,  `fouls_avg_home` = 11.3333,  `fouls_max_home` = 13,  `fouls_min_home` = 10,  `offsides_total_home` = 6,  `offsides_avg_home` = 3.0000,  `offsides_max_home` = 5,  `offsides_min_home` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035073
#   ____________ta_analyze_details()
#   ______________corners: 18 __ avg: 6.0000
#   ______________total_shots: 45 __ avg: 15.0000
#   ______________shots_on_goal: 19 __ avg: 6.3333
#   ______________fouls: 36 __ avg: 12.0000
#   ______________offsides: 2 __ avg: 1.0000
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 18,  `corner_kicks_avg` = 6.0000,  `corner_kicks_max` = 7,  `corner_kicks_min` = 5,  `total_shots_total` = 45,  `total_shots_avg` = 15.0000,  `total_shots_max` = 16,  `total_shots_min` = 13,  `shots_on_goal_total` = 19,  `shots_on_goal_avg` = 6.3333,  `shots_on_goal_max` = 7,  `shots_on_goal_min` = 6,  `fouls_total` = 36,  `fouls_avg` = 12.0000,  `fouls_max` = 17,  `fouls_min` = 8,  `offsides_total` = 2,  `offsides_avg` = 1.0000,  `offsides_max` = 1,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 66
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_away` = 18,  `corner_kicks_avg_away` = 6.0000,  `corner_kicks_max_away` = 7,  `corner_kicks_min_away` = 5,  `total_shots_total_away` = 45,  `total_shots_avg_away` = 15.0000,  `total_shots_max_away` = 16,  `total_shots_min_away` = 13,  `shots_on_goal_total_away` = 19,  `shots_on_goal_avg_away` = 6.3333,  `shots_on_goal_max_away` = 7,  `shots_on_goal_min_away` = 6,  `fouls_total_away` = 36,  `fouls_avg_away` = 12.0000,  `fouls_max_away` = 17,  `fouls_min_away` = 8,  `offsides_total_away` = 2,  `offsides_avg_away` = 1.0000,  `offsides_max_away` = 1,  `offsides_min_away` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035073
#   __________[8/9]  #39 __ 2023 __ 1035075 __ 2023-09-02 14:00:00 __ Regular Season - 4
#   ____________ta_analyze_details()
#   ______________corners: 20 __ avg: 6.6667
#   ______________total_shots: 61 __ avg: 20.3333
#   ______________shots_on_goal: 21 __ avg: 7.0000
#   ______________fouls: 22 __ avg: 7.3333
#   ______________offsides: 4 __ avg: 1.3333
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 20,  `corner_kicks_avg` = 6.6667,  `corner_kicks_max` = 12,  `corner_kicks_min` = 3,  `total_shots_total` = 61,  `total_shots_avg` = 20.3333,  `total_shots_max` = 30,  `total_shots_min` = 14,  `shots_on_goal_total` = 21,  `shots_on_goal_avg` = 7.0000,  `shots_on_goal_max` = 9,  `shots_on_goal_min` = 4,  `fouls_total` = 22,  `fouls_avg` = 7.3333,  `fouls_max` = 12,  `fouls_min` = 2,  `offsides_total` = 4,  `offsides_avg` = 1.3333,  `offsides_max` = 2,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 50
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_home` = 20,  `corner_kicks_avg_home` = 6.6667,  `corner_kicks_max_home` = 12,  `corner_kicks_min_home` = 3,  `total_shots_total_home` = 61,  `total_shots_avg_home` = 20.3333,  `total_shots_max_home` = 30,  `total_shots_min_home` = 14,  `shots_on_goal_total_home` = 21,  `shots_on_goal_avg_home` = 7.0000,  `shots_on_goal_max_home` = 9,  `shots_on_goal_min_home` = 4,  `fouls_total_home` = 22,  `fouls_avg_home` = 7.3333,  `fouls_max_home` = 12,  `fouls_min_home` = 2,  `offsides_total_home` = 4,  `offsides_avg_home` = 1.3333,  `offsides_max_home` = 2,  `offsides_min_home` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035075
#   ____________ta_analyze_details()
#   ______________corners: 12 __ avg: 4.0000
#   ______________total_shots: 27 __ avg: 9.0000
#   ______________shots_on_goal: 7 __ avg: 2.3333
#   ______________fouls: 24 __ avg: 8.0000
#   ______________offsides: 5 __ avg: 1.6667
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 12,  `corner_kicks_avg` = 4.0000,  `corner_kicks_max` = 5,  `corner_kicks_min` = 3,  `total_shots_total` = 27,  `total_shots_avg` = 9.0000,  `total_shots_max` = 10,  `total_shots_min` = 8,  `shots_on_goal_total` = 7,  `shots_on_goal_avg` = 2.3333,  `shots_on_goal_max` = 3,  `shots_on_goal_min` = 2,  `fouls_total` = 24,  `fouls_avg` = 8.0000,  `fouls_max` = 13,  `fouls_min` = 5,  `offsides_total` = 5,  `offsides_avg` = 1.6667,  `offsides_max` = 3,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 36
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_away` = 12,  `corner_kicks_avg_away` = 4.0000,  `corner_kicks_max_away` = 5,  `corner_kicks_min_away` = 3,  `total_shots_total_away` = 27,  `total_shots_avg_away` = 9.0000,  `total_shots_max_away` = 10,  `total_shots_min_away` = 8,  `shots_on_goal_total_away` = 7,  `shots_on_goal_avg_away` = 2.3333,  `shots_on_goal_max_away` = 3,  `shots_on_goal_min_away` = 2,  `fouls_total_away` = 24,  `fouls_avg_away` = 8.0000,  `fouls_max_away` = 13,  `fouls_min_away` = 5,  `offsides_total_away` = 5,  `offsides_avg_away` = 1.6667,  `offsides_max_away` = 3,  `offsides_min_away` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035075
#   __________[9/9]  #39 __ 2023 __ 1035076 __ 2023-09-02 11:30:00 __ Regular Season - 4
#   ____________ta_analyze_details()
#   ______________corners: 13 __ avg: 4.3333
#   ______________total_shots: 21 __ avg: 7.0000
#   ______________shots_on_goal: 6 __ avg: 2.0000
#   ______________fouls: 38 __ avg: 12.6667
#   ______________offsides: 5 __ avg: 1.6667
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 13,  `corner_kicks_avg` = 4.3333,  `corner_kicks_max` = 7,  `corner_kicks_min` = 1,  `total_shots_total` = 21,  `total_shots_avg` = 7.0000,  `total_shots_max` = 8,  `total_shots_min` = 6,  `shots_on_goal_total` = 6,  `shots_on_goal_avg` = 2.0000,  `shots_on_goal_max` = 3,  `shots_on_goal_min` = 1,  `fouls_total` = 38,  `fouls_avg` = 12.6667,  `fouls_max` = 18,  `fouls_min` = 9,  `offsides_total` = 5,  `offsides_avg` = 1.6667,  `offsides_max` = 2,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 62
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_home` = 13,  `corner_kicks_avg_home` = 4.3333,  `corner_kicks_max_home` = 7,  `corner_kicks_min_home` = 1,  `total_shots_total_home` = 21,  `total_shots_avg_home` = 7.0000,  `total_shots_max_home` = 8,  `total_shots_min_home` = 6,  `shots_on_goal_total_home` = 6,  `shots_on_goal_avg_home` = 2.0000,  `shots_on_goal_max_home` = 3,  `shots_on_goal_min_home` = 1,  `fouls_total_home` = 38,  `fouls_avg_home` = 12.6667,  `fouls_max_home` = 18,  `fouls_min_home` = 9,  `offsides_total_home` = 5,  `offsides_avg_home` = 1.6667,  `offsides_max_home` = 2,  `offsides_min_home` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035076
#   ____________ta_analyze_details()
#   ______________corners: 23 __ avg: 7.6667
#   ______________total_shots: 43 __ avg: 14.3333
#   ______________shots_on_goal: 18 __ avg: 6.0000
#   ______________fouls: 34 __ avg: 11.3333
#   ______________offsides: 8 __ avg: 2.6667
#
#   ______________UPDATE `api_football_league_standings` SET  `corner_kicks_total` = 23,  `corner_kicks_avg` = 7.6667,  `corner_kicks_max` = 10,  `corner_kicks_min` = 6,  `total_shots_total` = 43,  `total_shots_avg` = 14.3333,  `total_shots_max` = 19,  `total_shots_min` = 9,  `shots_on_goal_total` = 18,  `shots_on_goal_avg` = 6.0000,  `shots_on_goal_max` = 9,  `shots_on_goal_min` = 2,  `fouls_total` = 34,  `fouls_avg` = 11.3333,  `fouls_max` = 12,  `fouls_min` = 10,  `offsides_total` = 8,  `offsides_avg` = 2.6667,  `offsides_max` = 6,  `offsides_min` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and teamapi_id = 45
#   ______________UPDATE `football_statistics` SET  `corner_kicks_total_away` = 23,  `corner_kicks_avg_away` = 7.6667,  `corner_kicks_max_away` = 10,  `corner_kicks_min_away` = 6,  `total_shots_total_away` = 43,  `total_shots_avg_away` = 14.3333,  `total_shots_max_away` = 19,  `total_shots_min_away` = 9,  `shots_on_goal_total_away` = 18,  `shots_on_goal_avg_away` = 6.0000,  `shots_on_goal_max_away` = 9,  `shots_on_goal_min_away` = 2,  `fouls_total_away` = 34,  `fouls_avg_away` = 11.3333,  `fouls_max_away` = 12,  `fouls_min_away` = 10,  `offsides_total_away` = 8,  `offsides_avg_away` = 2.6667,  `offsides_max_away` = 6,  `offsides_min_away` = 1,  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035076
# # -------------------------------------------------- End at 2023-09-03 16:21:02
