# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_statistics import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------     
    fS_get_fixture_that_not_update_stats_all_league(space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-03 09:42:10
#   __main()
#   ______fS_get_fixture_that_not_update_stats_all_league()
#   ______ SELECT   fixtureapi_id  , leagueapi_id  , season FROM football_statistics WHERE leagueapi_id IN (select leagueapi_id from football_leagues where detail_stats = 1)  and fixture_status in ('Match Finished', 'Match Finished Ended')  and lineups_coach_homeapi_id  is null  and lineups_coach_awayapi_id  is null  order by date desc
#   ______Total Row(s) : 399
#   ______[1/399] #721327 #141 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 59
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 721327
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 130
#   __________________name : Pepe Mel
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2113
#   __________________name : Bolo
#   ________________football_odds UPDATED
#
#   ______[2/399] #721335 #141 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 44
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 721335
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6709
#   __________________name : Íñigo Vélez
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1581
#   __________________name : Gaizka Garitano
#   ________________football_odds UPDATED
#
#   ______[3/399] #710607 #39 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 41
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 710607
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 90
#   __________________name : T. Frank
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1
#   __________________name : J. Klopp
#   ________________football_odds UPDATED
#
#   ______[4/399] #719398 #78 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 40
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 719398
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1542
#   __________________name : A. Hütter
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1540
#   __________________name : M. Rose
#   ________________football_odds UPDATED
#
#   ______[5/399] #720806 #140 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 39
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 720806
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1594
#   __________________name : Lopetegui
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1597
#   __________________name : Vicente Moreno
#   ________________football_odds UPDATED
#
#   ______[6/399] #710115 #144 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 38
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 710115
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1515
#   __________________name : F. Dury
#   __________________fC_insert_new()
#   __________________coacheapi_id : 29
#   __________________name : L. Elsner
#   ________________football_odds UPDATED
#
#   ______[7/399] #768959 #136 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 37
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 768959
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 399
#   __________________name : M. Zaffaroni
#   __________________fC_insert_new()
#   __________________coacheapi_id : 416
#   __________________name : F. Modesto
#   ________________football_odds UPDATED
#
#   ______[8/399] #707233 #88 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 36
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707233
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1993
#   __________________name : E. ten Hag
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1995
#   __________________name : D. Buijs
#   ________________football_odds UPDATED
#
#   ______[9/399] #707235 #88 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 35
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707235
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2935
#   __________________name : T. Letsch
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2007
#   __________________name : S. Ultee
#   ________________football_odds UPDATED
#
#   ______[10/399] #718429 #61 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 34
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718429
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 31
#   __________________name : J. Stéphan
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2507
#   __________________name : J. Gourvennec
#   ________________football_odds UPDATED
#
#   ______[11/399] #731335 #94 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 33
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 731335
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2221
#   __________________name : Pêpa
#   __________________fC_insert_new()
#   __________________coacheapi_id : 123
#   __________________name : Jorge Jesus
#   ________________football_odds UPDATED
#
#   ______[12/399] #708985 #345 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 32
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 708985
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 15702
#   __________________name : M. Kalivoda
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1804
#   __________________name : P. Vrba
#   ________________football_odds UPDATED
#
#   ______[13/399] #710985 #210 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 31
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 710985
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 14911
#   __________________name : Mario Rosas
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2510
#   __________________name : N. Bjelica
#   ________________football_odds UPDATED
#
#   ______[14/399] #712864 #106 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 30
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 712864
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5834
#   __________________name : C. Michniewicz
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1222
#   __________________name : M. Papszun
#   ________________football_odds UPDATED
#
#   ______[15/399] #722963 #283 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 29
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 722963
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1201
#   __________________name : E. Iordănescu
#   __________________fC_insert_new()
#   __________________coacheapi_id : 11049
#   __________________name : I. Chirilă
#   ________________football_odds UPDATED
#
#   ______[16/399] #731635 #135 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 28
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 731635
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3722
#   __________________name : D. Ballardini
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2432
#   __________________name : I. Tudor
#   ________________football_odds UPDATED
#
#   ______[17/399] #710111 #144 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 27
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 710111
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 13568
#   __________________name : M. Leye
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1514
#   __________________name : B. Hollerbach
#   ________________football_odds UPDATED
#
#   ______[18/399] #718424 #61 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 26
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718424
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1532
#   __________________name : P. Bosz
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1470
#   __________________name : C. Pélissier
#   ________________football_odds UPDATED
#
#   ______[19/399] #718426 #61 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 25
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718426
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 13
#   __________________name : M. Pochettino
#   __________________fC_insert_new()
#   __________________coacheapi_id : 34
#   __________________name : O. Dall’Oglio
#   ________________football_odds UPDATED
#
#   ______[20/399] #707237 #88 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 24
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707237
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2006
#   __________________name : A. Slot
#   __________________fC_insert_new()
#   __________________coacheapi_id : 12353
#   __________________name : R. Meijer
#   ________________football_odds UPDATED
#
#   ______[21/399] #707241 #88 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 23
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707241
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1492
#   __________________name : R. Hake
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5863
#   __________________name : A. Langeler
#   ________________football_odds UPDATED
#
#   ______[22/399] #720804 #140 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 22
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 720804
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2407
#   __________________name : C. Ancelotti
#   __________________fC_insert_new()
#   __________________coacheapi_id : 18
#   __________________name : Unai Emery
#   ________________football_odds UPDATED
#
#   ______[23/399] #731338 #94 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 21
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 731338
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3947
#   __________________name : Pako Ayestarán
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2220
#   __________________name : Ivo Vieira
#   ________________football_odds UPDATED
#
#   ______[24/399] #707238 #88 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 20
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707238
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2005
#   __________________name : H. Fraser
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1480
#   __________________name : H. de Jong
#   ________________football_odds UPDATED
#
#   ______[25/399] #712862 #106 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 19
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 712862
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3147
#   __________________name : M. Lewandowski
#   __________________fC_insert_new()
#   __________________coacheapi_id : 15260
#   __________________name : J. Urban
#   ________________football_odds UPDATED
#
#   ______[26/399] #731637 #135 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 18
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 731637
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3386
#   __________________name : M. Allegri
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2438
#   __________________name : R. D'Aversa
#   ________________football_odds UPDATED
#
#   ______[27/399] #758587 #203 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 17
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 758587
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3284
#   __________________name : H. Keleş
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1447
#   __________________name : H. Karaman
#   ________________football_odds UPDATED
#
#   ______[28/399] #718421 #61 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 16
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718421
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 186
#   __________________name : V. Petković
#   __________________fC_insert_new()
#   __________________coacheapi_id : 68
#   __________________name : B. Génésio
#   ________________football_odds UPDATED
#
#   ______[29/399] #709701 #179 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 15
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 709701
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2402
#   __________________name : J. Goodwin
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1044
#   __________________name : S. Glass
#   ________________football_odds UPDATED
#
#   ______[30/399] #710114 #144 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 14
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 710114
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1509
#   __________________name : F. Mazzù
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1682
#   __________________name : B. Priske
#   ________________football_odds UPDATED
#
#   ______[31/399] #747109 #136 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 13
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 747109
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 413
#   __________________name : M. Alvini
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3718
#   __________________name : M. Longo
#   ________________football_odds UPDATED
#
#   ______[32/399] #720803 #140 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 12
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 720803
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 45
#   __________________name : Luis García
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1588
#   __________________name : Arrasate
#   ________________football_odds UPDATED
#
#   ______[33/399] #721329 #141 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 11
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 721329
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6710
#   __________________name : Lolo Escobar
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1591
#   __________________name : Asier Garitano
#   ________________football_odds UPDATED
#
#   ______[34/399] #707239 #88 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 10
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707239
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 10421
#   __________________name : P. Jansen
#   __________________fC_insert_new()
#   __________________coacheapi_id : 12507
#   __________________name : K. van Wonderen
#   ________________football_odds UPDATED
#
#   ______[35/399] #707240 #88 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 9
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707240
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2001
#   __________________name : J. Jansen
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1986
#   __________________name : R. Jans
#   ________________football_odds UPDATED
#
#   ______[36/399] #722967 #283 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 7
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 722967
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1199
#   __________________name : G. Hagi
#   __________________fC_insert_new()
#   __________________coacheapi_id : 758
#   __________________name : A. Pelici
#   ________________football_odds UPDATED
#
#   ______[37/399] #718959 #218 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 6
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718959
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1423
#   __________________name : K. Russ
#   __________________fC_insert_new()
#   __________________coacheapi_id : 14951
#   __________________name : M. Schmid
#   ________________football_odds UPDATED
#
#   ______[38/399] #718961 #218 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 5
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718961
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3599
#   __________________name : A. Wieland
#   __________________fC_insert_new()
#   __________________coacheapi_id : 169
#   __________________name : A. Herzog
#   ________________football_odds UPDATED
#
#   ______[39/399] #710614 #39 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 4
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 710614
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 8
#   __________________name : R. Hasenhüttl
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2213
#   __________________name : Bruno Lage
#   ________________football_odds UPDATED
#
#   ______[40/399] #718422 #61 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 3
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718422
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 30
#   __________________name : M. Der Zakarian
#   __________________fC_insert_new()
#   __________________coacheapi_id : 39
#   __________________name : F. Antonetti
#   ________________football_odds UPDATED
#
#   ______[41/399] #718427 #61 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 2
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718427
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6455
#   __________________name : Óscar García
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3044
#   __________________name : A. Kombouare
#   ________________football_odds UPDATED
#
#   ______[42/399] #718430 #61 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API arya6792@gmail.com counter is 1
#   ____________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718430
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1475
#   __________________name : L. Batlles
#   __________________fC_insert_new()
#   __________________coacheapi_id : 15087
#   __________________name : G. Baticle
#   ________________football_odds UPDATED
#
#   ______[43/399] #712869 #106 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 99
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 712869
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 8187
#   __________________name : J. Magiera
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4457
#   __________________name : M. Bartoszek
#   ________________football_odds UPDATED
#
#   ______[44/399] #731634 #135 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 98
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 731634
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2439
#   __________________name : A. Andreazzoli
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2413
#   __________________name : S. Mihajlović
#   ________________football_odds UPDATED
#
#   ______[45/399] #731640 #135 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 97
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 731640
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1612
#   __________________name : A. Dionisi
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2897
#   __________________name : F. Castori
#   ________________football_odds UPDATED
#
#   ______[46/399] #731642 #135 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 96
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 731642
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6114
#   __________________name : L. Gotti
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1611
#   __________________name : V. Italiano
#   ________________football_odds UPDATED
#
#   ______[47/399] #758594 #203 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 95
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 758594
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1449
#   __________________name : A. Kocaman
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3286
#   __________________name : H. Hamzaoğlu
#   ________________football_odds UPDATED
#
#   ______[48/399] #758596 #203 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 94
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 758596
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 10117
#   __________________name : Ö. Erdoğan
#   __________________fC_insert_new()
#   __________________coacheapi_id : 55
#   __________________name : Vítor Pereira
#   ________________football_odds UPDATED
#
#   ______[49/399] #719401 #78 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 92
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 719401
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1347
#   __________________name : T. Reis
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7611
#   __________________name : P. Matarazzo
#   ________________football_odds UPDATED
#
#   ______[50/399] #721332 #141 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 91
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 721332
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1593
#   __________________name : David Gallego
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2115
#   __________________name : José Alberto López
#   ________________football_odds UPDATED
#
#   ______[51/399] #710113 #144 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 90
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 710113
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2880
#   __________________name : H. Vanhaezebrouck
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1510
#   __________________name : Y. Vanderhaeghe
#   ________________football_odds UPDATED
#
#   ______[52/399] #709696 #179 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 89
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 709696
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 548
#   __________________name : A. Postecoglou
#   __________________fC_insert_new()
#   __________________coacheapi_id : 14870
#   __________________name : T. Courts
#   ________________football_odds UPDATED
#
#   ______[53/399] #709699 #179 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 88
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 709699
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 644
#   __________________name : J. Ross
#   __________________fC_insert_new()
#   __________________coacheapi_id : 12748
#   __________________name : C. Davidson
#   ________________football_odds UPDATED
#
#   ______[54/399] #708986 #345 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 87
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 708986
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1798
#   __________________name : P. Rada
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7753
#   __________________name : L. Kozel
#   ________________football_odds UPDATED
#
#   ______[55/399] #708988 #345 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 86
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 708988
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3408
#   __________________name : K. Jarolím
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1811
#   __________________name : M. Svědík
#   ________________football_odds UPDATED
#
#   ______[56/399] #708989 #345 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 85
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 708989
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1185
#   __________________name : R. Kučera
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1810
#   __________________name : V. Jílek
#   ________________football_odds UPDATED
#
#   ______[57/399] #747108 #136 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 84
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 747108
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 12629
#   __________________name : E. Maresca
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1602
#   __________________name : L. D'Angelo
#   ________________football_odds UPDATED
#
#   ______[58/399] #720800 #140 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 83
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 720800
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 73
#   __________________name : R. Koeman
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1592
#   __________________name : Paco López
#   ________________football_odds UPDATED
#
#   ______[59/399] #707236 #88 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 82
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707236
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2000
#   __________________name : F. Wormuth
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6671
#   __________________name : J. Oosting
#   ________________football_odds UPDATED
#
#   ______[60/399] #718423 #61 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 81
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718423
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1468
#   __________________name : P. Gastien
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1528
#   __________________name : N. Kovač
#   ________________football_odds UPDATED
#
#   ______[61/399] #722962 #283 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 80
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 722962
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1208
#   __________________name : M. Croitoru
#   __________________fC_insert_new()
#   __________________coacheapi_id : 11046
#   __________________name : A. Mutu
#   ________________football_odds UPDATED
#
#   ______[62/399] #718960 #218 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 79
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 718960
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1913
#   __________________name : D. Kühbauer
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1918
#   __________________name : C. Ilzer
#   ________________football_odds UPDATED
#
#   ______[63/399] #710981 #210 - 2021
#   ________af_controll_match_update()
# ...
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707575
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3175
#   __________________name : M. Santoni
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1487
#   __________________name : W. Boessen
#   ________________football_odds UPDATED
#
#   ______[380/399] #721349 #141 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 57
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 721349
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3241
#   __________________name : José Luis Oltra
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1591
#   __________________name : Asier Garitano
#   ________________football_odds UPDATED
#
#   ______[381/399] #721354 #141 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 56
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 721354
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 80
#   __________________name : Luis Miguel Ramis
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6709
#   __________________name : Íñigo Vélez
#   ________________football_odds UPDATED
#
#   ______[382/399] #721357 #141 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 55
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 721357
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 131
#   __________________name : Anquela
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6714
#   __________________name : Julián Calero
#   ________________football_odds UPDATED
#
#   ______[383/399] #707580 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 54
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707580
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1138
#   __________________name : G. Verbeek
#   __________________fC_insert_new()
#   __________________coacheapi_id : 10345
#   __________________name : R. Robbemond
#   ________________football_odds UPDATED
#
#   ______[384/399] #721356 #141 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 53
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 721356
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3684
#   __________________name : Juan Ignacio Martínez
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1683
#   __________________name : I. Ambriz
#   ________________football_odds UPDATED
#
#   ______[385/399] #710993 #210 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 52
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 710993
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1650
#   __________________name : D. Mladina
#   __________________fC_insert_new()
#   __________________coacheapi_id : 14970
#   __________________name : S. Čabraja
#   ________________football_odds UPDATED
#
#   ______[386/399] #758614 #203 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 51
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 758614
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 15846
#   __________________name : E. Sözer
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1441
#   __________________name : S. Yalçın
#   ________________football_odds UPDATED
#
#   ______[387/399] #722977 #283 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 50
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 722977
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1198
#   __________________name : I. Poenaru
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2985
#   __________________name : M. Rednic
#   ________________football_odds UPDATED
#
#   ______[388/399] #707585 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 49
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707585
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1477
#   __________________name : J. de Gier
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1138
#   __________________name : G. Verbeek
#   ________________football_odds UPDATED
#
#   ______[389/399] #707586 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 48
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707586
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7633
#   __________________name : M. Dijkhuizen
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1345
#   __________________name : J. Luhukay
#   ________________football_odds UPDATED
#
#   ______[390/399] #707587 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 47
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707587
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 10345
#   __________________name : R. Robbemond
#   __________________fC_insert_new()
#   __________________coacheapi_id : 15080
#   __________________name : R. Penders
#   ________________football_odds UPDATED
#
#   ______[391/399] #707588 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 46
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707588
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1487
#   __________________name : W. Boessen
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1490
#   __________________name : R. Brood
#   ________________football_odds UPDATED
#
#   ______[392/399] #707589 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 45
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707589
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1485
#   __________________name : K. Wels
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3175
#   __________________name : M. Santoni
#   ________________football_odds UPDATED
#
#   ______[393/399] #707590 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 44
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707590
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1551
#   __________________name : B. Peeters
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1994
#   __________________name : D. Lukkien
#   ________________football_odds UPDATED
#
#   ______[394/399] #707591 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 43
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707591
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5322
#   __________________name : J. Heitinga
#   __________________fC_insert_new()
#   __________________coacheapi_id : 721
#   __________________name : D. Kalezić
#   ________________football_odds UPDATED
#
#   ______[395/399] #707592 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 42
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707592
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 15099
#   __________________name : E. de Graaf
#   __________________fC_insert_new()
#   __________________coacheapi_id : 15114
#   __________________name : M. Martens
#   ________________football_odds UPDATED
#
#   ______[396/399] #707593 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 41
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707593
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1147
#   __________________name : J. Streppel
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5380
#   __________________name : R. van Nistelrooy
#   ________________football_odds UPDATED
#
#   ______[397/399] #707594 #89 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 40
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 707594
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1495
#   __________________name : A. Jonker
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1488
#   __________________name : W. Jonk
#   ________________football_odds UPDATED
#
#   ______[398/399] #719418 #78 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 39
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 719418
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1399
#   __________________name : S. Hoeneb
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1533
#   __________________name : S. Baumgart
#   ________________football_odds UPDATED
#
#   ______[399/399] #710128 #144 - 2021
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 38
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 710128
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1518
#   __________________name : P. Clement
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1521
#   __________________name : K. Belhocine
#   ________________football_odds UPDATED
#
# # -------------------------------------------------- End at 2023-07-03 13:04:09

# %%
print(13794 - 29 - 99 - 99 - 99 - 99 - 99 - 99)
# Out:
# 13171

# %%
43988
# Out:
# 43988

# %%
8695
# Out:
# 8695
