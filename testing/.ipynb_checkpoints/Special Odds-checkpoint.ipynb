# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *  
from a_models.odd_col import *  

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "__"  
    # ----------------------------------------------------------  
    odd_array = odd_col_list()
    # ---------------------------------------------------------- 
    print("") 
    # ----------------------------------------------------------  
    # ----------------------------------------------------------
    for x in odd_array:
        word = "// " + x
        print(word, flush=True)
        
        ## if (in_array($first->pre_total_home_over_15, $special_odds))
        word = "    if (in_array($first->"+x+", $special_odds) || $first->"+x+" <= 2)"
        print(word, flush=True)
        ## 
        word = "    {"
        print(word, flush=True)
        
        # $isi .= '<a href="" class="me-1 badge  bg-gray-800">';
        if("_over_" in x):
            class_detail = "success"
        elif("_under_" in x):
            class_detail = "danger"
        elif("_home" in x):
            class_detail = "primary"
        elif("_away" in x):
            class_detail = "warning"
        elif("_draw" in x):
            class_detail = "gray-700"
        else:
            class_detail = "gray-800"
            
            
        class_html = '"me-1 badge bg-'+class_detail+'"'
        href = '""'
        word = "        $isi .= '<a href="+href+" class="+class_html+">';"
        print(word, flush=True)
        
        # $isi .= "pre_total_home_over_15 : " . $first->pre_total_home_over_15; 
        temp_x = x.replace("_match_winner_", " Winner ")
        temp_x = temp_x.replace("_first_half_winner_", " 1st Winner ")
        temp_x = temp_x.replace("_second_half_winner_", " 2nd Winner ")
        
        temp_x = temp_x.replace("_asian_handicap_home_min_", " Home -")
        temp_x = temp_x.replace("_asian_handicap_home_plus_", " Home +")
        temp_x = temp_x.replace("_asian_handicap_away_min_", " Away +")
        temp_x = temp_x.replace("_asian_handicap_away_plus_", " Away -")
        
        temp_x = temp_x.replace("_goals_overunder_over_", " Over ")
        temp_x = temp_x.replace("_goals_overunder_under_", " Under ")
        
        temp_x = temp_x.replace("_corners_over_under_over_", " Corner - Over ")
        temp_x = temp_x.replace("_corners_over_under_under_", " Corner - Under ")
        
        
        temp_x = temp_x.replace("_asian_handicap_first_half_home_min_", " 1st Home -")
        temp_x = temp_x.replace("_asian_handicap_first_half_home_plus_", " 1st Home +")
        temp_x = temp_x.replace("_asian_handicap_first_half_away_min_", " 1st Away +")
        temp_x = temp_x.replace("_asian_handicap_first_half_away_plus_", " 1st Away -")
        
        temp_x = temp_x.replace("_goals_overunder_first_half_over_", " 1st Over ")
        temp_x = temp_x.replace("_goals_overunder_first_half_under_", " 1st Under ")
        
        temp_x = temp_x.replace("_goals_overunder__second_half_over_", " 2nd Over ")
        temp_x = temp_x.replace("_goals_overunder__second_half_under_", " 2nd Under ")
        
        temp_x = temp_x.replace("_homeaway_", " DNB ")
        
        temp_x = temp_x.replace("_total_goals_both_teams_to_score_over_no_", " BTTS No - Over ")
        temp_x = temp_x.replace("_total_goals_both_teams_to_score_under_no_", " BTTS No - Under ")
        
        temp_x = temp_x.replace("_total_goals_both_teams_to_score_over_yes_", " BTTS Yes - Over ")
        temp_x = temp_x.replace("_total_goals_both_teams_to_score_under_yes_", " BTTS Yes - Under ")
          
        temp_x = temp_x.replace("_both_teams_score_", " BTTS ")
        
        word = "            $isi .= '"+temp_x+" : ' . $first->"+x+";"
        print(word, flush=True)
        
        
        # $isi .= '</a>'; 
        word = "        $isi .= '</a>';"
        print(word, flush=True)
        
        ## 
        word = "    }"
        print(word, flush=True)
        
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-04 11:38:27
#   ____main__
#
# // pre_match_winner_home
#     if (in_array($first->pre_match_winner_home, $special_odds) || $first->pre_match_winner_home <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Winner home : ' . $first->pre_match_winner_home;
#         $isi .= '</a>';
#     }
# // pre_match_winner_draw
#     if (in_array($first->pre_match_winner_draw, $special_odds) || $first->pre_match_winner_draw <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-gray-700">';
#             $isi .= 'pre Winner draw : ' . $first->pre_match_winner_draw;
#         $isi .= '</a>';
#     }
# // pre_match_winner_away
#     if (in_array($first->pre_match_winner_away, $special_odds) || $first->pre_match_winner_away <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Winner away : ' . $first->pre_match_winner_away;
#         $isi .= '</a>';
#     }
# // end_match_winner_home
#     if (in_array($first->end_match_winner_home, $special_odds) || $first->end_match_winner_home <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end Winner home : ' . $first->end_match_winner_home;
#         $isi .= '</a>';
#     }
# // end_match_winner_draw
#     if (in_array($first->end_match_winner_draw, $special_odds) || $first->end_match_winner_draw <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-gray-700">';
#             $isi .= 'end Winner draw : ' . $first->end_match_winner_draw;
#         $isi .= '</a>';
#     }
# // end_match_winner_away
#     if (in_array($first->end_match_winner_away, $special_odds) || $first->end_match_winner_away <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'end Winner away : ' . $first->end_match_winner_away;
#         $isi .= '</a>';
#     }
# // pre_homeaway_home
#     if (in_array($first->pre_homeaway_home, $special_odds) || $first->pre_homeaway_home <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre DNB home : ' . $first->pre_homeaway_home;
#         $isi .= '</a>';
#     }
# // pre_homeaway_away
#     if (in_array($first->pre_homeaway_away, $special_odds) || $first->pre_homeaway_away <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre DNB away : ' . $first->pre_homeaway_away;
#         $isi .= '</a>';
#     }
# // end_homeaway_home
#     if (in_array($first->end_homeaway_home, $special_odds) || $first->end_homeaway_home <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end DNB home : ' . $first->end_homeaway_home;
#         $isi .= '</a>';
#     }
# // end_homeaway_away
#     if (in_array($first->end_homeaway_away, $special_odds) || $first->end_homeaway_away <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end DNB away : ' . $first->end_homeaway_away;
#         $isi .= '</a>';
#     }
# // pre_first_half_winner_home
#     if (in_array($first->pre_first_half_winner_home, $special_odds) || $first->pre_first_half_winner_home <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre 1st Winner home : ' . $first->pre_first_half_winner_home;
#         $isi .= '</a>';
#     }
# // pre_first_half_winner_draw
#     if (in_array($first->pre_first_half_winner_draw, $special_odds) || $first->pre_first_half_winner_draw <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-gray-700">';
#             $isi .= 'pre 1st Winner draw : ' . $first->pre_first_half_winner_draw;
#         $isi .= '</a>';
#     }
# // pre_first_half_winner_away
#     if (in_array($first->pre_first_half_winner_away, $special_odds) || $first->pre_first_half_winner_away <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre 1st Winner away : ' . $first->pre_first_half_winner_away;
#         $isi .= '</a>';
#     }
# // end_first_half_winner_home
#     if (in_array($first->end_first_half_winner_home, $special_odds) || $first->end_first_half_winner_home <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end 1st Winner home : ' . $first->end_first_half_winner_home;
#         $isi .= '</a>';
#     }
# // end_first_half_winner_draw
#     if (in_array($first->end_first_half_winner_draw, $special_odds) || $first->end_first_half_winner_draw <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-gray-700">';
#             $isi .= 'end 1st Winner draw : ' . $first->end_first_half_winner_draw;
#         $isi .= '</a>';
#     }
# // end_first_half_winner_away
#     if (in_array($first->end_first_half_winner_away, $special_odds) || $first->end_first_half_winner_away <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'end 1st Winner away : ' . $first->end_first_half_winner_away;
#         $isi .= '</a>';
#     }
# // pre_second_half_winner_home
#     if (in_array($first->pre_second_half_winner_home, $special_odds) || $first->pre_second_half_winner_home <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre 2nd Winner home : ' . $first->pre_second_half_winner_home;
#         $isi .= '</a>';
#     }
# // pre_second_half_winner_draw
#     if (in_array($first->pre_second_half_winner_draw, $special_odds) || $first->pre_second_half_winner_draw <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-gray-700">';
#             $isi .= 'pre 2nd Winner draw : ' . $first->pre_second_half_winner_draw;
#         $isi .= '</a>';
#     }
# // pre_second_half_winner_away
#     if (in_array($first->pre_second_half_winner_away, $special_odds) || $first->pre_second_half_winner_away <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre 2nd Winner away : ' . $first->pre_second_half_winner_away;
#         $isi .= '</a>';
#     }
# // end_second_half_winner_home
#     if (in_array($first->end_second_half_winner_home, $special_odds) || $first->end_second_half_winner_home <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end 2nd Winner home : ' . $first->end_second_half_winner_home;
#         $isi .= '</a>';
#     }
# // end_second_half_winner_draw
#     if (in_array($first->end_second_half_winner_draw, $special_odds) || $first->end_second_half_winner_draw <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-gray-700">';
#             $isi .= 'end 2nd Winner draw : ' . $first->end_second_half_winner_draw;
#         $isi .= '</a>';
#     }
# // end_second_half_winner_away
#     if (in_array($first->end_second_half_winner_away, $special_odds) || $first->end_second_half_winner_away <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'end 2nd Winner away : ' . $first->end_second_half_winner_away;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_675
#     if (in_array($first->pre_asian_handicap_home_min_675, $special_odds) || $first->pre_asian_handicap_home_min_675 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -675 : ' . $first->pre_asian_handicap_home_min_675;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_675
#     if (in_array($first->pre_asian_handicap_away_min_675, $special_odds) || $first->pre_asian_handicap_away_min_675 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +675 : ' . $first->pre_asian_handicap_away_min_675;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_65
#     if (in_array($first->pre_asian_handicap_home_min_65, $special_odds) || $first->pre_asian_handicap_home_min_65 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -65 : ' . $first->pre_asian_handicap_home_min_65;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_65
#     if (in_array($first->pre_asian_handicap_away_min_65, $special_odds) || $first->pre_asian_handicap_away_min_65 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +65 : ' . $first->pre_asian_handicap_away_min_65;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_625
#     if (in_array($first->pre_asian_handicap_home_min_625, $special_odds) || $first->pre_asian_handicap_home_min_625 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -625 : ' . $first->pre_asian_handicap_home_min_625;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_625
#     if (in_array($first->pre_asian_handicap_away_min_625, $special_odds) || $first->pre_asian_handicap_away_min_625 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +625 : ' . $first->pre_asian_handicap_away_min_625;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_6
#     if (in_array($first->pre_asian_handicap_home_min_6, $special_odds) || $first->pre_asian_handicap_home_min_6 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -6 : ' . $first->pre_asian_handicap_home_min_6;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_6
#     if (in_array($first->pre_asian_handicap_away_min_6, $special_odds) || $first->pre_asian_handicap_away_min_6 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +6 : ' . $first->pre_asian_handicap_away_min_6;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_575
#     if (in_array($first->pre_asian_handicap_home_min_575, $special_odds) || $first->pre_asian_handicap_home_min_575 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -575 : ' . $first->pre_asian_handicap_home_min_575;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_575
#     if (in_array($first->pre_asian_handicap_away_min_575, $special_odds) || $first->pre_asian_handicap_away_min_575 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +575 : ' . $first->pre_asian_handicap_away_min_575;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_55
#     if (in_array($first->pre_asian_handicap_home_min_55, $special_odds) || $first->pre_asian_handicap_home_min_55 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -55 : ' . $first->pre_asian_handicap_home_min_55;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_55
#     if (in_array($first->pre_asian_handicap_away_min_55, $special_odds) || $first->pre_asian_handicap_away_min_55 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +55 : ' . $first->pre_asian_handicap_away_min_55;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_525
#     if (in_array($first->pre_asian_handicap_home_min_525, $special_odds) || $first->pre_asian_handicap_home_min_525 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -525 : ' . $first->pre_asian_handicap_home_min_525;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_525
#     if (in_array($first->pre_asian_handicap_away_min_525, $special_odds) || $first->pre_asian_handicap_away_min_525 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +525 : ' . $first->pre_asian_handicap_away_min_525;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_5
#     if (in_array($first->pre_asian_handicap_home_min_5, $special_odds) || $first->pre_asian_handicap_home_min_5 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -5 : ' . $first->pre_asian_handicap_home_min_5;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_5
#     if (in_array($first->pre_asian_handicap_away_min_5, $special_odds) || $first->pre_asian_handicap_away_min_5 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +5 : ' . $first->pre_asian_handicap_away_min_5;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_475
#     if (in_array($first->pre_asian_handicap_home_min_475, $special_odds) || $first->pre_asian_handicap_home_min_475 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -475 : ' . $first->pre_asian_handicap_home_min_475;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_475
#     if (in_array($first->pre_asian_handicap_away_min_475, $special_odds) || $first->pre_asian_handicap_away_min_475 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +475 : ' . $first->pre_asian_handicap_away_min_475;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_45
#     if (in_array($first->pre_asian_handicap_home_min_45, $special_odds) || $first->pre_asian_handicap_home_min_45 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -45 : ' . $first->pre_asian_handicap_home_min_45;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_45
#     if (in_array($first->pre_asian_handicap_away_min_45, $special_odds) || $first->pre_asian_handicap_away_min_45 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +45 : ' . $first->pre_asian_handicap_away_min_45;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_425
#     if (in_array($first->pre_asian_handicap_home_min_425, $special_odds) || $first->pre_asian_handicap_home_min_425 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -425 : ' . $first->pre_asian_handicap_home_min_425;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_425
#     if (in_array($first->pre_asian_handicap_away_min_425, $special_odds) || $first->pre_asian_handicap_away_min_425 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +425 : ' . $first->pre_asian_handicap_away_min_425;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_4
#     if (in_array($first->pre_asian_handicap_home_min_4, $special_odds) || $first->pre_asian_handicap_home_min_4 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -4 : ' . $first->pre_asian_handicap_home_min_4;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_4
#     if (in_array($first->pre_asian_handicap_away_min_4, $special_odds) || $first->pre_asian_handicap_away_min_4 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +4 : ' . $first->pre_asian_handicap_away_min_4;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_375
#     if (in_array($first->pre_asian_handicap_home_min_375, $special_odds) || $first->pre_asian_handicap_home_min_375 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -375 : ' . $first->pre_asian_handicap_home_min_375;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_375
#     if (in_array($first->pre_asian_handicap_away_min_375, $special_odds) || $first->pre_asian_handicap_away_min_375 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +375 : ' . $first->pre_asian_handicap_away_min_375;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_35
#     if (in_array($first->pre_asian_handicap_home_min_35, $special_odds) || $first->pre_asian_handicap_home_min_35 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -35 : ' . $first->pre_asian_handicap_home_min_35;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_35
#     if (in_array($first->pre_asian_handicap_away_min_35, $special_odds) || $first->pre_asian_handicap_away_min_35 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +35 : ' . $first->pre_asian_handicap_away_min_35;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_325
#     if (in_array($first->pre_asian_handicap_home_min_325, $special_odds) || $first->pre_asian_handicap_home_min_325 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -325 : ' . $first->pre_asian_handicap_home_min_325;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_325
#     if (in_array($first->pre_asian_handicap_away_min_325, $special_odds) || $first->pre_asian_handicap_away_min_325 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +325 : ' . $first->pre_asian_handicap_away_min_325;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_3
#     if (in_array($first->pre_asian_handicap_home_min_3, $special_odds) || $first->pre_asian_handicap_home_min_3 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -3 : ' . $first->pre_asian_handicap_home_min_3;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_3
#     if (in_array($first->pre_asian_handicap_away_min_3, $special_odds) || $first->pre_asian_handicap_away_min_3 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +3 : ' . $first->pre_asian_handicap_away_min_3;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_275
#     if (in_array($first->pre_asian_handicap_home_min_275, $special_odds) || $first->pre_asian_handicap_home_min_275 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -275 : ' . $first->pre_asian_handicap_home_min_275;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_275
#     if (in_array($first->pre_asian_handicap_away_min_275, $special_odds) || $first->pre_asian_handicap_away_min_275 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +275 : ' . $first->pre_asian_handicap_away_min_275;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_25
#     if (in_array($first->pre_asian_handicap_home_min_25, $special_odds) || $first->pre_asian_handicap_home_min_25 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -25 : ' . $first->pre_asian_handicap_home_min_25;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_25
#     if (in_array($first->pre_asian_handicap_away_min_25, $special_odds) || $first->pre_asian_handicap_away_min_25 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +25 : ' . $first->pre_asian_handicap_away_min_25;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_225
#     if (in_array($first->pre_asian_handicap_home_min_225, $special_odds) || $first->pre_asian_handicap_home_min_225 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -225 : ' . $first->pre_asian_handicap_home_min_225;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_225
#     if (in_array($first->pre_asian_handicap_away_min_225, $special_odds) || $first->pre_asian_handicap_away_min_225 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +225 : ' . $first->pre_asian_handicap_away_min_225;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_2
#     if (in_array($first->pre_asian_handicap_home_min_2, $special_odds) || $first->pre_asian_handicap_home_min_2 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -2 : ' . $first->pre_asian_handicap_home_min_2;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_2
#     if (in_array($first->pre_asian_handicap_away_min_2, $special_odds) || $first->pre_asian_handicap_away_min_2 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +2 : ' . $first->pre_asian_handicap_away_min_2;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_175
#     if (in_array($first->pre_asian_handicap_home_min_175, $special_odds) || $first->pre_asian_handicap_home_min_175 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -175 : ' . $first->pre_asian_handicap_home_min_175;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_175
#     if (in_array($first->pre_asian_handicap_away_min_175, $special_odds) || $first->pre_asian_handicap_away_min_175 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +175 : ' . $first->pre_asian_handicap_away_min_175;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_15
#     if (in_array($first->pre_asian_handicap_home_min_15, $special_odds) || $first->pre_asian_handicap_home_min_15 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -15 : ' . $first->pre_asian_handicap_home_min_15;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_15
#     if (in_array($first->pre_asian_handicap_away_min_15, $special_odds) || $first->pre_asian_handicap_away_min_15 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +15 : ' . $first->pre_asian_handicap_away_min_15;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_125
#     if (in_array($first->pre_asian_handicap_home_min_125, $special_odds) || $first->pre_asian_handicap_home_min_125 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -125 : ' . $first->pre_asian_handicap_home_min_125;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_125
#     if (in_array($first->pre_asian_handicap_away_min_125, $special_odds) || $first->pre_asian_handicap_away_min_125 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +125 : ' . $first->pre_asian_handicap_away_min_125;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_1
#     if (in_array($first->pre_asian_handicap_home_min_1, $special_odds) || $first->pre_asian_handicap_home_min_1 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -1 : ' . $first->pre_asian_handicap_home_min_1;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_1
#     if (in_array($first->pre_asian_handicap_away_min_1, $special_odds) || $first->pre_asian_handicap_away_min_1 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +1 : ' . $first->pre_asian_handicap_away_min_1;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_075
#     if (in_array($first->pre_asian_handicap_home_min_075, $special_odds) || $first->pre_asian_handicap_home_min_075 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -075 : ' . $first->pre_asian_handicap_home_min_075;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_075
#     if (in_array($first->pre_asian_handicap_away_min_075, $special_odds) || $first->pre_asian_handicap_away_min_075 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +075 : ' . $first->pre_asian_handicap_away_min_075;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_05
#     if (in_array($first->pre_asian_handicap_home_min_05, $special_odds) || $first->pre_asian_handicap_home_min_05 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -05 : ' . $first->pre_asian_handicap_home_min_05;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_05
#     if (in_array($first->pre_asian_handicap_away_min_05, $special_odds) || $first->pre_asian_handicap_away_min_05 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +05 : ' . $first->pre_asian_handicap_away_min_05;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_min_025
#     if (in_array($first->pre_asian_handicap_home_min_025, $special_odds) || $first->pre_asian_handicap_home_min_025 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home -025 : ' . $first->pre_asian_handicap_home_min_025;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_min_025
#     if (in_array($first->pre_asian_handicap_away_min_025, $special_odds) || $first->pre_asian_handicap_away_min_025 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away +025 : ' . $first->pre_asian_handicap_away_min_025;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_0
#     if (in_array($first->pre_asian_handicap_home_plus_0, $special_odds) || $first->pre_asian_handicap_home_plus_0 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +0 : ' . $first->pre_asian_handicap_home_plus_0;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_0
#     if (in_array($first->pre_asian_handicap_away_plus_0, $special_odds) || $first->pre_asian_handicap_away_plus_0 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -0 : ' . $first->pre_asian_handicap_away_plus_0;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_025
#     if (in_array($first->pre_asian_handicap_home_plus_025, $special_odds) || $first->pre_asian_handicap_home_plus_025 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +025 : ' . $first->pre_asian_handicap_home_plus_025;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_025
#     if (in_array($first->pre_asian_handicap_away_plus_025, $special_odds) || $first->pre_asian_handicap_away_plus_025 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -025 : ' . $first->pre_asian_handicap_away_plus_025;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_05
#     if (in_array($first->pre_asian_handicap_home_plus_05, $special_odds) || $first->pre_asian_handicap_home_plus_05 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +05 : ' . $first->pre_asian_handicap_home_plus_05;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_05
#     if (in_array($first->pre_asian_handicap_away_plus_05, $special_odds) || $first->pre_asian_handicap_away_plus_05 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -05 : ' . $first->pre_asian_handicap_away_plus_05;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_075
#     if (in_array($first->pre_asian_handicap_home_plus_075, $special_odds) || $first->pre_asian_handicap_home_plus_075 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +075 : ' . $first->pre_asian_handicap_home_plus_075;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_075
#     if (in_array($first->pre_asian_handicap_away_plus_075, $special_odds) || $first->pre_asian_handicap_away_plus_075 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -075 : ' . $first->pre_asian_handicap_away_plus_075;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_1
#     if (in_array($first->pre_asian_handicap_home_plus_1, $special_odds) || $first->pre_asian_handicap_home_plus_1 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +1 : ' . $first->pre_asian_handicap_home_plus_1;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_1
#     if (in_array($first->pre_asian_handicap_away_plus_1, $special_odds) || $first->pre_asian_handicap_away_plus_1 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -1 : ' . $first->pre_asian_handicap_away_plus_1;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_125
#     if (in_array($first->pre_asian_handicap_home_plus_125, $special_odds) || $first->pre_asian_handicap_home_plus_125 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +125 : ' . $first->pre_asian_handicap_home_plus_125;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_125
#     if (in_array($first->pre_asian_handicap_away_plus_125, $special_odds) || $first->pre_asian_handicap_away_plus_125 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -125 : ' . $first->pre_asian_handicap_away_plus_125;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_15
#     if (in_array($first->pre_asian_handicap_home_plus_15, $special_odds) || $first->pre_asian_handicap_home_plus_15 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +15 : ' . $first->pre_asian_handicap_home_plus_15;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_15
#     if (in_array($first->pre_asian_handicap_away_plus_15, $special_odds) || $first->pre_asian_handicap_away_plus_15 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -15 : ' . $first->pre_asian_handicap_away_plus_15;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_175
#     if (in_array($first->pre_asian_handicap_home_plus_175, $special_odds) || $first->pre_asian_handicap_home_plus_175 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +175 : ' . $first->pre_asian_handicap_home_plus_175;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_175
#     if (in_array($first->pre_asian_handicap_away_plus_175, $special_odds) || $first->pre_asian_handicap_away_plus_175 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -175 : ' . $first->pre_asian_handicap_away_plus_175;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_2
#     if (in_array($first->pre_asian_handicap_home_plus_2, $special_odds) || $first->pre_asian_handicap_home_plus_2 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +2 : ' . $first->pre_asian_handicap_home_plus_2;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_2
#     if (in_array($first->pre_asian_handicap_away_plus_2, $special_odds) || $first->pre_asian_handicap_away_plus_2 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -2 : ' . $first->pre_asian_handicap_away_plus_2;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_225
#     if (in_array($first->pre_asian_handicap_home_plus_225, $special_odds) || $first->pre_asian_handicap_home_plus_225 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +225 : ' . $first->pre_asian_handicap_home_plus_225;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_225
#     if (in_array($first->pre_asian_handicap_away_plus_225, $special_odds) || $first->pre_asian_handicap_away_plus_225 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -225 : ' . $first->pre_asian_handicap_away_plus_225;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_25
#     if (in_array($first->pre_asian_handicap_home_plus_25, $special_odds) || $first->pre_asian_handicap_home_plus_25 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +25 : ' . $first->pre_asian_handicap_home_plus_25;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_25
#     if (in_array($first->pre_asian_handicap_away_plus_25, $special_odds) || $first->pre_asian_handicap_away_plus_25 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -25 : ' . $first->pre_asian_handicap_away_plus_25;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_275
#     if (in_array($first->pre_asian_handicap_home_plus_275, $special_odds) || $first->pre_asian_handicap_home_plus_275 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +275 : ' . $first->pre_asian_handicap_home_plus_275;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_275
#     if (in_array($first->pre_asian_handicap_away_plus_275, $special_odds) || $first->pre_asian_handicap_away_plus_275 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -275 : ' . $first->pre_asian_handicap_away_plus_275;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_3
#     if (in_array($first->pre_asian_handicap_home_plus_3, $special_odds) || $first->pre_asian_handicap_home_plus_3 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +3 : ' . $first->pre_asian_handicap_home_plus_3;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_3
#     if (in_array($first->pre_asian_handicap_away_plus_3, $special_odds) || $first->pre_asian_handicap_away_plus_3 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -3 : ' . $first->pre_asian_handicap_away_plus_3;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_325
#     if (in_array($first->pre_asian_handicap_home_plus_325, $special_odds) || $first->pre_asian_handicap_home_plus_325 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +325 : ' . $first->pre_asian_handicap_home_plus_325;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_325
#     if (in_array($first->pre_asian_handicap_away_plus_325, $special_odds) || $first->pre_asian_handicap_away_plus_325 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -325 : ' . $first->pre_asian_handicap_away_plus_325;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_35
#     if (in_array($first->pre_asian_handicap_home_plus_35, $special_odds) || $first->pre_asian_handicap_home_plus_35 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +35 : ' . $first->pre_asian_handicap_home_plus_35;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_35
#     if (in_array($first->pre_asian_handicap_away_plus_35, $special_odds) || $first->pre_asian_handicap_away_plus_35 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -35 : ' . $first->pre_asian_handicap_away_plus_35;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_375
#     if (in_array($first->pre_asian_handicap_home_plus_375, $special_odds) || $first->pre_asian_handicap_home_plus_375 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +375 : ' . $first->pre_asian_handicap_home_plus_375;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_375
#     if (in_array($first->pre_asian_handicap_away_plus_375, $special_odds) || $first->pre_asian_handicap_away_plus_375 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -375 : ' . $first->pre_asian_handicap_away_plus_375;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_4
#     if (in_array($first->pre_asian_handicap_home_plus_4, $special_odds) || $first->pre_asian_handicap_home_plus_4 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +4 : ' . $first->pre_asian_handicap_home_plus_4;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_4
#     if (in_array($first->pre_asian_handicap_away_plus_4, $special_odds) || $first->pre_asian_handicap_away_plus_4 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -4 : ' . $first->pre_asian_handicap_away_plus_4;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_425
#     if (in_array($first->pre_asian_handicap_home_plus_425, $special_odds) || $first->pre_asian_handicap_home_plus_425 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +425 : ' . $first->pre_asian_handicap_home_plus_425;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_425
#     if (in_array($first->pre_asian_handicap_away_plus_425, $special_odds) || $first->pre_asian_handicap_away_plus_425 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -425 : ' . $first->pre_asian_handicap_away_plus_425;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_45
#     if (in_array($first->pre_asian_handicap_home_plus_45, $special_odds) || $first->pre_asian_handicap_home_plus_45 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +45 : ' . $first->pre_asian_handicap_home_plus_45;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_45
#     if (in_array($first->pre_asian_handicap_away_plus_45, $special_odds) || $first->pre_asian_handicap_away_plus_45 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -45 : ' . $first->pre_asian_handicap_away_plus_45;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_475
#     if (in_array($first->pre_asian_handicap_home_plus_475, $special_odds) || $first->pre_asian_handicap_home_plus_475 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +475 : ' . $first->pre_asian_handicap_home_plus_475;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_475
#     if (in_array($first->pre_asian_handicap_away_plus_475, $special_odds) || $first->pre_asian_handicap_away_plus_475 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -475 : ' . $first->pre_asian_handicap_away_plus_475;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_5
#     if (in_array($first->pre_asian_handicap_home_plus_5, $special_odds) || $first->pre_asian_handicap_home_plus_5 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +5 : ' . $first->pre_asian_handicap_home_plus_5;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_5
#     if (in_array($first->pre_asian_handicap_away_plus_5, $special_odds) || $first->pre_asian_handicap_away_plus_5 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -5 : ' . $first->pre_asian_handicap_away_plus_5;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_525
#     if (in_array($first->pre_asian_handicap_home_plus_525, $special_odds) || $first->pre_asian_handicap_home_plus_525 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +525 : ' . $first->pre_asian_handicap_home_plus_525;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_525
#     if (in_array($first->pre_asian_handicap_away_plus_525, $special_odds) || $first->pre_asian_handicap_away_plus_525 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -525 : ' . $first->pre_asian_handicap_away_plus_525;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_55
#     if (in_array($first->pre_asian_handicap_home_plus_55, $special_odds) || $first->pre_asian_handicap_home_plus_55 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +55 : ' . $first->pre_asian_handicap_home_plus_55;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_55
#     if (in_array($first->pre_asian_handicap_away_plus_55, $special_odds) || $first->pre_asian_handicap_away_plus_55 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -55 : ' . $first->pre_asian_handicap_away_plus_55;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_575
#     if (in_array($first->pre_asian_handicap_home_plus_575, $special_odds) || $first->pre_asian_handicap_home_plus_575 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +575 : ' . $first->pre_asian_handicap_home_plus_575;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_575
#     if (in_array($first->pre_asian_handicap_away_plus_575, $special_odds) || $first->pre_asian_handicap_away_plus_575 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -575 : ' . $first->pre_asian_handicap_away_plus_575;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_6
#     if (in_array($first->pre_asian_handicap_home_plus_6, $special_odds) || $first->pre_asian_handicap_home_plus_6 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +6 : ' . $first->pre_asian_handicap_home_plus_6;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_6
#     if (in_array($first->pre_asian_handicap_away_plus_6, $special_odds) || $first->pre_asian_handicap_away_plus_6 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -6 : ' . $first->pre_asian_handicap_away_plus_6;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_625
#     if (in_array($first->pre_asian_handicap_home_plus_625, $special_odds) || $first->pre_asian_handicap_home_plus_625 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +625 : ' . $first->pre_asian_handicap_home_plus_625;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_625
#     if (in_array($first->pre_asian_handicap_away_plus_625, $special_odds) || $first->pre_asian_handicap_away_plus_625 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -625 : ' . $first->pre_asian_handicap_away_plus_625;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_65
#     if (in_array($first->pre_asian_handicap_home_plus_65, $special_odds) || $first->pre_asian_handicap_home_plus_65 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +65 : ' . $first->pre_asian_handicap_home_plus_65;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_65
#     if (in_array($first->pre_asian_handicap_away_plus_65, $special_odds) || $first->pre_asian_handicap_away_plus_65 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -65 : ' . $first->pre_asian_handicap_away_plus_65;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_home_plus_675
#     if (in_array($first->pre_asian_handicap_home_plus_675, $special_odds) || $first->pre_asian_handicap_home_plus_675 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'pre Home +675 : ' . $first->pre_asian_handicap_home_plus_675;
#         $isi .= '</a>';
#     }
# // pre_asian_handicap_away_plus_675
#     if (in_array($first->pre_asian_handicap_away_plus_675, $special_odds) || $first->pre_asian_handicap_away_plus_675 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'pre Away -675 : ' . $first->pre_asian_handicap_away_plus_675;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_home_min_675
#     if (in_array($first->end_asian_handicap_home_min_675, $special_odds) || $first->end_asian_handicap_home_min_675 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end Home -675 : ' . $first->end_asian_handicap_home_min_675;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_away_min_675
#     if (in_array($first->end_asian_handicap_away_min_675, $special_odds) || $first->end_asian_handicap_away_min_675 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'end Away +675 : ' . $first->end_asian_handicap_away_min_675;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_home_min_65
#     if (in_array($first->end_asian_handicap_home_min_65, $special_odds) || $first->end_asian_handicap_home_min_65 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end Home -65 : ' . $first->end_asian_handicap_home_min_65;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_away_min_65
#     if (in_array($first->end_asian_handicap_away_min_65, $special_odds) || $first->end_asian_handicap_away_min_65 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'end Away +65 : ' . $first->end_asian_handicap_away_min_65;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_home_min_625
#     if (in_array($first->end_asian_handicap_home_min_625, $special_odds) || $first->end_asian_handicap_home_min_625 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end Home -625 : ' . $first->end_asian_handicap_home_min_625;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_away_min_625
#     if (in_array($first->end_asian_handicap_away_min_625, $special_odds) || $first->end_asian_handicap_away_min_625 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'end Away +625 : ' . $first->end_asian_handicap_away_min_625;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_home_min_6
#     if (in_array($first->end_asian_handicap_home_min_6, $special_odds) || $first->end_asian_handicap_home_min_6 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end Home -6 : ' . $first->end_asian_handicap_home_min_6;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_away_min_6
#     if (in_array($first->end_asian_handicap_away_min_6, $special_odds) || $first->end_asian_handicap_away_min_6 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'end Away +6 : ' . $first->end_asian_handicap_away_min_6;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_home_min_575
#     if (in_array($first->end_asian_handicap_home_min_575, $special_odds) || $first->end_asian_handicap_home_min_575 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end Home -575 : ' . $first->end_asian_handicap_home_min_575;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_away_min_575
#     if (in_array($first->end_asian_handicap_away_min_575, $special_odds) || $first->end_asian_handicap_away_min_575 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'end Away +575 : ' . $first->end_asian_handicap_away_min_575;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_home_min_55
#     if (in_array($first->end_asian_handicap_home_min_55, $special_odds) || $first->end_asian_handicap_home_min_55 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end Home -55 : ' . $first->end_asian_handicap_home_min_55;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_away_min_55
#     if (in_array($first->end_asian_handicap_away_min_55, $special_odds) || $first->end_asian_handicap_away_min_55 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-warning">';
#             $isi .= 'end Away +55 : ' . $first->end_asian_handicap_away_min_55;
#         $isi .= '</a>';
#     }
# // end_asian_handicap_home_min_525
#     if (in_array($first->end_asian_handicap_home_min_525, $special_odds) || $first->end_asian_handicap_home_min_525 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-primary">';
#             $isi .= 'end Home -525 : ' . $first->end_asian_handicap_home_min_525;
#         $isi .= '</a>';
# ...
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_750
#     if (in_array($first->pre_corners_over_under_over_750, $special_odds) || $first->pre_corners_over_under_over_750 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 750 : ' . $first->pre_corners_over_under_over_750;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_750
#     if (in_array($first->pre_corners_over_under_under_750, $special_odds) || $first->pre_corners_over_under_under_750 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 750 : ' . $first->pre_corners_over_under_under_750;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_775
#     if (in_array($first->pre_corners_over_under_over_775, $special_odds) || $first->pre_corners_over_under_over_775 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 775 : ' . $first->pre_corners_over_under_over_775;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_775
#     if (in_array($first->pre_corners_over_under_under_775, $special_odds) || $first->pre_corners_over_under_under_775 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 775 : ' . $first->pre_corners_over_under_under_775;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_800
#     if (in_array($first->pre_corners_over_under_over_800, $special_odds) || $first->pre_corners_over_under_over_800 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 800 : ' . $first->pre_corners_over_under_over_800;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_800
#     if (in_array($first->pre_corners_over_under_under_800, $special_odds) || $first->pre_corners_over_under_under_800 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 800 : ' . $first->pre_corners_over_under_under_800;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_825
#     if (in_array($first->pre_corners_over_under_over_825, $special_odds) || $first->pre_corners_over_under_over_825 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 825 : ' . $first->pre_corners_over_under_over_825;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_825
#     if (in_array($first->pre_corners_over_under_under_825, $special_odds) || $first->pre_corners_over_under_under_825 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 825 : ' . $first->pre_corners_over_under_under_825;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_850
#     if (in_array($first->pre_corners_over_under_over_850, $special_odds) || $first->pre_corners_over_under_over_850 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 850 : ' . $first->pre_corners_over_under_over_850;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_850
#     if (in_array($first->pre_corners_over_under_under_850, $special_odds) || $first->pre_corners_over_under_under_850 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 850 : ' . $first->pre_corners_over_under_under_850;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_875
#     if (in_array($first->pre_corners_over_under_over_875, $special_odds) || $first->pre_corners_over_under_over_875 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 875 : ' . $first->pre_corners_over_under_over_875;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_875
#     if (in_array($first->pre_corners_over_under_under_875, $special_odds) || $first->pre_corners_over_under_under_875 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 875 : ' . $first->pre_corners_over_under_under_875;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_900
#     if (in_array($first->pre_corners_over_under_over_900, $special_odds) || $first->pre_corners_over_under_over_900 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 900 : ' . $first->pre_corners_over_under_over_900;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_900
#     if (in_array($first->pre_corners_over_under_under_900, $special_odds) || $first->pre_corners_over_under_under_900 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 900 : ' . $first->pre_corners_over_under_under_900;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_925
#     if (in_array($first->pre_corners_over_under_over_925, $special_odds) || $first->pre_corners_over_under_over_925 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 925 : ' . $first->pre_corners_over_under_over_925;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_925
#     if (in_array($first->pre_corners_over_under_under_925, $special_odds) || $first->pre_corners_over_under_under_925 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 925 : ' . $first->pre_corners_over_under_under_925;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_950
#     if (in_array($first->pre_corners_over_under_over_950, $special_odds) || $first->pre_corners_over_under_over_950 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 950 : ' . $first->pre_corners_over_under_over_950;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_950
#     if (in_array($first->pre_corners_over_under_under_950, $special_odds) || $first->pre_corners_over_under_under_950 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 950 : ' . $first->pre_corners_over_under_under_950;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_975
#     if (in_array($first->pre_corners_over_under_over_975, $special_odds) || $first->pre_corners_over_under_over_975 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 975 : ' . $first->pre_corners_over_under_over_975;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_975
#     if (in_array($first->pre_corners_over_under_under_975, $special_odds) || $first->pre_corners_over_under_under_975 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 975 : ' . $first->pre_corners_over_under_under_975;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1000
#     if (in_array($first->pre_corners_over_under_over_1000, $special_odds) || $first->pre_corners_over_under_over_1000 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1000 : ' . $first->pre_corners_over_under_over_1000;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1000
#     if (in_array($first->pre_corners_over_under_under_1000, $special_odds) || $first->pre_corners_over_under_under_1000 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1000 : ' . $first->pre_corners_over_under_under_1000;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1025
#     if (in_array($first->pre_corners_over_under_over_1025, $special_odds) || $first->pre_corners_over_under_over_1025 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1025 : ' . $first->pre_corners_over_under_over_1025;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1025
#     if (in_array($first->pre_corners_over_under_under_1025, $special_odds) || $first->pre_corners_over_under_under_1025 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1025 : ' . $first->pre_corners_over_under_under_1025;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1050
#     if (in_array($first->pre_corners_over_under_over_1050, $special_odds) || $first->pre_corners_over_under_over_1050 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1050 : ' . $first->pre_corners_over_under_over_1050;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1050
#     if (in_array($first->pre_corners_over_under_under_1050, $special_odds) || $first->pre_corners_over_under_under_1050 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1050 : ' . $first->pre_corners_over_under_under_1050;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1075
#     if (in_array($first->pre_corners_over_under_over_1075, $special_odds) || $first->pre_corners_over_under_over_1075 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1075 : ' . $first->pre_corners_over_under_over_1075;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1075
#     if (in_array($first->pre_corners_over_under_under_1075, $special_odds) || $first->pre_corners_over_under_under_1075 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1075 : ' . $first->pre_corners_over_under_under_1075;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1100
#     if (in_array($first->pre_corners_over_under_over_1100, $special_odds) || $first->pre_corners_over_under_over_1100 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1100 : ' . $first->pre_corners_over_under_over_1100;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1100
#     if (in_array($first->pre_corners_over_under_under_1100, $special_odds) || $first->pre_corners_over_under_under_1100 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1100 : ' . $first->pre_corners_over_under_under_1100;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1125
#     if (in_array($first->pre_corners_over_under_over_1125, $special_odds) || $first->pre_corners_over_under_over_1125 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1125 : ' . $first->pre_corners_over_under_over_1125;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1125
#     if (in_array($first->pre_corners_over_under_under_1125, $special_odds) || $first->pre_corners_over_under_under_1125 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1125 : ' . $first->pre_corners_over_under_under_1125;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1150
#     if (in_array($first->pre_corners_over_under_over_1150, $special_odds) || $first->pre_corners_over_under_over_1150 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1150 : ' . $first->pre_corners_over_under_over_1150;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1150
#     if (in_array($first->pre_corners_over_under_under_1150, $special_odds) || $first->pre_corners_over_under_under_1150 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1150 : ' . $first->pre_corners_over_under_under_1150;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1175
#     if (in_array($first->pre_corners_over_under_over_1175, $special_odds) || $first->pre_corners_over_under_over_1175 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1175 : ' . $first->pre_corners_over_under_over_1175;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1175
#     if (in_array($first->pre_corners_over_under_under_1175, $special_odds) || $first->pre_corners_over_under_under_1175 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1175 : ' . $first->pre_corners_over_under_under_1175;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1200
#     if (in_array($first->pre_corners_over_under_over_1200, $special_odds) || $first->pre_corners_over_under_over_1200 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1200 : ' . $first->pre_corners_over_under_over_1200;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1200
#     if (in_array($first->pre_corners_over_under_under_1200, $special_odds) || $first->pre_corners_over_under_under_1200 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1200 : ' . $first->pre_corners_over_under_under_1200;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1225
#     if (in_array($first->pre_corners_over_under_over_1225, $special_odds) || $first->pre_corners_over_under_over_1225 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1225 : ' . $first->pre_corners_over_under_over_1225;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1225
#     if (in_array($first->pre_corners_over_under_under_1225, $special_odds) || $first->pre_corners_over_under_under_1225 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1225 : ' . $first->pre_corners_over_under_under_1225;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1250
#     if (in_array($first->pre_corners_over_under_over_1250, $special_odds) || $first->pre_corners_over_under_over_1250 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1250 : ' . $first->pre_corners_over_under_over_1250;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1250
#     if (in_array($first->pre_corners_over_under_under_1250, $special_odds) || $first->pre_corners_over_under_under_1250 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1250 : ' . $first->pre_corners_over_under_under_1250;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_over_1275
#     if (in_array($first->pre_corners_over_under_over_1275, $special_odds) || $first->pre_corners_over_under_over_1275 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Over 1275 : ' . $first->pre_corners_over_under_over_1275;
#         $isi .= '</a>';
#     }
# // pre_corners_over_under_under_1275
#     if (in_array($first->pre_corners_over_under_under_1275, $special_odds) || $first->pre_corners_over_under_under_1275 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'pre Corner - Under 1275 : ' . $first->pre_corners_over_under_under_1275;
#         $isi .= '</a>';
#     }
# // end_corners_over_under_over_700
#     if (in_array($first->end_corners_over_under_over_700, $special_odds) || $first->end_corners_over_under_over_700 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
#             $isi .= 'end Corner - Over 700 : ' . $first->end_corners_over_under_over_700;
#         $isi .= '</a>';
#     }
# // end_corners_over_under_under_700
#     if (in_array($first->end_corners_over_under_under_700, $special_odds) || $first->end_corners_over_under_under_700 <= 2)
#     {
#         $isi .= '<a href="" class="me-1 badge bg-success">';
