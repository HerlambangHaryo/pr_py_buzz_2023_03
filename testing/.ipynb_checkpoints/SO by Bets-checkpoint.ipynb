# %%
import mysql.connector 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " , id  "
query += " from bets_old " 
query += " where level1_order = 0 " 
query += " order by bet_id, total asc " 
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------ 
mycursor.close()
mydb.close()
# ------------------------------------------------------ 
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    idx = str(x[5])
    # -------------------------------------------------- 
    route = "pre"
    col = route + "_" + columnx
    # --------------------------------------------------  
    word = "// " + col
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "    if (in_array($first->"+col+", $special_odds) )"
    print(word, flush=True)
    # --------------------------------------------------  
    word = "    {"
    print(word, flush=True)
    # --------------------------------------------------   
    bet_rep = bet.replace("-", "").replace(" ", "_").replace("/", "")
    word = "        $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => "+idx+" ] );"
    print(word, flush=True)
    # --------------------------------------------------   
    class_html = '"me-1 badge '+columny+'"' 
    word = "        $isi .= '<a ';"
    print(word, flush=True)
    # -------------------------------------------------- 
    href = "'.$route.'"  
    prehref = '"'  
    word = "            $isi .= 'href="+prehref+href+prehref+" ';"
    print(word, flush=True)
    # --------------------------------------------------   
    word = "            $isi .= 'class="+class_html+">';"
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "            $isi .= '"+route+" "+bet+" "+value+" : ' . $first->"+col+";"
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "        $isi .= '</a>';"
    print(word, flush=True) 
    # --------------------------------------------------  
    word = "    }"
    print(word, flush=True)
    # -------------------------------------------------- 

# ------------------------------------------------------ 
word = "    $isi .= '<br/><br/>';"
print(word, flush=True)
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    idx = str(x[5])
    # -------------------------------------------------- 
    route = "end"
    col = route + "_" + columnx
    # --------------------------------------------------  
    word = "// " + col
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "    if (in_array($first->"+col+", $special_odds) )"
    print(word, flush=True)
    # --------------------------------------------------  
    word = "    {"
    print(word, flush=True)
    # --------------------------------------------------   
    bet_rep = bet.replace("-", "").replace(" ", "_").replace("/", "")
    # word = "        $route = route('Special_odds.bet', '"+idx+"');" 
    word = "        $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => "+idx+" ] );"
    print(word, flush=True)
    # --------------------------------------------------   
    class_html = '"me-1 badge '+columny+'"' 
    word = "        $isi .= '<a ';"
    print(word, flush=True)
    # -------------------------------------------------- 
    href = "'.$route.'"  
    prehref = '"'  
    word = "            $isi .= 'href="+prehref+href+prehref+" ';"
    print(word, flush=True)
    # --------------------------------------------------   
    word = "            $isi .= 'class="+class_html+">';"
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "            $isi .= '"+route+" "+bet+" "+value+" : ' . $first->"+col+";"
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "        $isi .= '</a>';"
    print(word, flush=True) 
    # --------------------------------------------------  
    word = "    }"
    print(word, flush=True)
    # --------------------------------------------------  
    # --------------------------------------------------  
    # --------------------------------------------------  
    # --------------------------------------------------  
    # --------------------------------------------------
# Out:
# // pre_results_both_teams_score_home_yes
#     if (in_array($first->pre_results_both_teams_score_home_yes, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 321 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'pre Results/Both Teams Score Home/Yes : ' . $first->pre_results_both_teams_score_home_yes;
#         $isi .= '</a>';
#     }
# // pre_results_both_teams_score_draw_yes
#     if (in_array($first->pre_results_both_teams_score_draw_yes, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 322 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-gray-700">';
#             $isi .= 'pre Results/Both Teams Score Draw/Yes : ' . $first->pre_results_both_teams_score_draw_yes;
#         $isi .= '</a>';
#     }
# // pre_results_both_teams_score_away_yes
#     if (in_array($first->pre_results_both_teams_score_away_yes, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 323 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'pre Results/Both Teams Score Away/Yes : ' . $first->pre_results_both_teams_score_away_yes;
#         $isi .= '</a>';
#     }
# // pre_results_both_teams_score_home_no
#     if (in_array($first->pre_results_both_teams_score_home_no, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 324 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'pre Results/Both Teams Score Home/No : ' . $first->pre_results_both_teams_score_home_no;
#         $isi .= '</a>';
#     }
# // pre_results_both_teams_score_draw_no
#     if (in_array($first->pre_results_both_teams_score_draw_no, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 325 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-gray-700">';
#             $isi .= 'pre Results/Both Teams Score Draw/No : ' . $first->pre_results_both_teams_score_draw_no;
#         $isi .= '</a>';
#     }
# // pre_results_both_teams_score_away_no
#     if (in_array($first->pre_results_both_teams_score_away_no, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 326 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'pre Results/Both Teams Score Away/No : ' . $first->pre_results_both_teams_score_away_no;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_home_over_35
#     if (in_array($first->pre_result_total_goals_home_over_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 327 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Result/Total Goals Home/Over 3.5 : ' . $first->pre_result_total_goals_home_over_35;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_draw_over_35
#     if (in_array($first->pre_result_total_goals_draw_over_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 328 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Result/Total Goals Draw/Over 3.5 : ' . $first->pre_result_total_goals_draw_over_35;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_away_over_35
#     if (in_array($first->pre_result_total_goals_away_over_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 329 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Result/Total Goals Away/Over 3.5 : ' . $first->pre_result_total_goals_away_over_35;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_home_under_35
#     if (in_array($first->pre_result_total_goals_home_under_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 330 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Result/Total Goals Home/Under 3.5 : ' . $first->pre_result_total_goals_home_under_35;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_draw_under_35
#     if (in_array($first->pre_result_total_goals_draw_under_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 331 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Result/Total Goals Draw/Under 3.5 : ' . $first->pre_result_total_goals_draw_under_35;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_away_under_35
#     if (in_array($first->pre_result_total_goals_away_under_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 332 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Result/Total Goals Away/Under 3.5 : ' . $first->pre_result_total_goals_away_under_35;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_home_over_25
#     if (in_array($first->pre_result_total_goals_home_over_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 333 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Result/Total Goals Home/Over 2.5 : ' . $first->pre_result_total_goals_home_over_25;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_draw_over_25
#     if (in_array($first->pre_result_total_goals_draw_over_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 334 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Result/Total Goals Draw/Over 2.5 : ' . $first->pre_result_total_goals_draw_over_25;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_away_over_25
#     if (in_array($first->pre_result_total_goals_away_over_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 335 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Result/Total Goals Away/Over 2.5 : ' . $first->pre_result_total_goals_away_over_25;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_home_under_25
#     if (in_array($first->pre_result_total_goals_home_under_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 336 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Result/Total Goals Home/Under 2.5 : ' . $first->pre_result_total_goals_home_under_25;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_draw_under_25
#     if (in_array($first->pre_result_total_goals_draw_under_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 337 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Result/Total Goals Draw/Under 2.5 : ' . $first->pre_result_total_goals_draw_under_25;
#         $isi .= '</a>';
#     }
# // pre_result_total_goals_away_under_25
#     if (in_array($first->pre_result_total_goals_away_under_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 338 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Result/Total Goals Away/Under 2.5 : ' . $first->pre_result_total_goals_away_under_25;
#         $isi .= '</a>';
#     }
# // pre_win_both_halves_home
#     if (in_array($first->pre_win_both_halves_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 228 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'pre Win Both Halves Home : ' . $first->pre_win_both_halves_home;
#         $isi .= '</a>';
#     }
# // pre_win_both_halves_away
#     if (in_array($first->pre_win_both_halves_away, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 229 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'pre Win Both Halves Away : ' . $first->pre_win_both_halves_away;
#         $isi .= '</a>';
#     }
# // pre_win_to_nil_home
#     if (in_array($first->pre_win_to_nil_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 287 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'pre Win To Nil Home : ' . $first->pre_win_to_nil_home;
#         $isi .= '</a>';
#     }
# // pre_win_to_nil_away
#     if (in_array($first->pre_win_to_nil_away, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 288 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'pre Win To Nil Away : ' . $first->pre_win_to_nil_away;
#         $isi .= '</a>';
#     }
# // pre_to_win_either_half_home
#     if (in_array($first->pre_to_win_either_half_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 305 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'pre To Win Either Half Home : ' . $first->pre_to_win_either_half_home;
#         $isi .= '</a>';
#     }
# // pre_to_win_either_half_away
#     if (in_array($first->pre_to_win_either_half_away, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 306 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'pre To Win Either Half Away : ' . $first->pre_to_win_either_half_away;
#         $isi .= '</a>';
#     }
# // pre_to_score_in_both_halves_by_teams_home
#     if (in_array($first->pre_to_score_in_both_halves_by_teams_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 369 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'pre To Score In Both Halves By Teams Home : ' . $first->pre_to_score_in_both_halves_by_teams_home;
#         $isi .= '</a>';
#     }
# // pre_to_score_in_both_halves_by_teams_away
#     if (in_array($first->pre_to_score_in_both_halves_by_teams_away, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 370 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'pre To Score In Both Halves By Teams Away : ' . $first->pre_to_score_in_both_halves_by_teams_away;
#         $isi .= '</a>';
#     }
# // pre_total_goals_both_teams_to_score_over_yes_25
#     if (in_array($first->pre_total_goals_both_teams_to_score_over_yes_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 371 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge over_25_btts_yes">';
#             $isi .= 'pre Total Goals/Both Teams To Score o/yes 2.5 : ' . $first->pre_total_goals_both_teams_to_score_over_yes_25;
#         $isi .= '</a>';
#     }
# // pre_total_goals_both_teams_to_score_over_no_25
#     if (in_array($first->pre_total_goals_both_teams_to_score_over_no_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 372 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge over_25_btts_no">';
#             $isi .= 'pre Total Goals/Both Teams To Score o/no 2.5 : ' . $first->pre_total_goals_both_teams_to_score_over_no_25;
#         $isi .= '</a>';
#     }
# // pre_total_goals_both_teams_to_score_under_yes_25
#     if (in_array($first->pre_total_goals_both_teams_to_score_under_yes_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 373 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge under_25_btts_yes">';
#             $isi .= 'pre Total Goals/Both Teams To Score u/yes 2.5 : ' . $first->pre_total_goals_both_teams_to_score_under_yes_25;
#         $isi .= '</a>';
#     }
# // pre_total_goals_both_teams_to_score_under_no_25
#     if (in_array($first->pre_total_goals_both_teams_to_score_under_no_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 374 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge under_25_btts_no">';
#             $isi .= 'pre Total Goals/Both Teams To Score u/no 2.5 : ' . $first->pre_total_goals_both_teams_to_score_under_no_25;
#         $isi .= '</a>';
#     }
#     $isi .= '<br/><br/>';
# // end_results_both_teams_score_home_yes
#     if (in_array($first->end_results_both_teams_score_home_yes, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 321 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'end Results/Both Teams Score Home/Yes : ' . $first->end_results_both_teams_score_home_yes;
#         $isi .= '</a>';
#     }
# // end_results_both_teams_score_draw_yes
#     if (in_array($first->end_results_both_teams_score_draw_yes, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 322 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-gray-700">';
#             $isi .= 'end Results/Both Teams Score Draw/Yes : ' . $first->end_results_both_teams_score_draw_yes;
#         $isi .= '</a>';
#     }
# // end_results_both_teams_score_away_yes
#     if (in_array($first->end_results_both_teams_score_away_yes, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 323 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'end Results/Both Teams Score Away/Yes : ' . $first->end_results_both_teams_score_away_yes;
#         $isi .= '</a>';
#     }
# // end_results_both_teams_score_home_no
#     if (in_array($first->end_results_both_teams_score_home_no, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 324 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'end Results/Both Teams Score Home/No : ' . $first->end_results_both_teams_score_home_no;
#         $isi .= '</a>';
#     }
# // end_results_both_teams_score_draw_no
#     if (in_array($first->end_results_both_teams_score_draw_no, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 325 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-gray-700">';
#             $isi .= 'end Results/Both Teams Score Draw/No : ' . $first->end_results_both_teams_score_draw_no;
#         $isi .= '</a>';
#     }
# // end_results_both_teams_score_away_no
#     if (in_array($first->end_results_both_teams_score_away_no, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 326 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'end Results/Both Teams Score Away/No : ' . $first->end_results_both_teams_score_away_no;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_home_over_35
#     if (in_array($first->end_result_total_goals_home_over_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 327 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Result/Total Goals Home/Over 3.5 : ' . $first->end_result_total_goals_home_over_35;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_draw_over_35
#     if (in_array($first->end_result_total_goals_draw_over_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 328 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Result/Total Goals Draw/Over 3.5 : ' . $first->end_result_total_goals_draw_over_35;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_away_over_35
#     if (in_array($first->end_result_total_goals_away_over_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 329 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Result/Total Goals Away/Over 3.5 : ' . $first->end_result_total_goals_away_over_35;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_home_under_35
#     if (in_array($first->end_result_total_goals_home_under_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 330 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Result/Total Goals Home/Under 3.5 : ' . $first->end_result_total_goals_home_under_35;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_draw_under_35
#     if (in_array($first->end_result_total_goals_draw_under_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 331 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Result/Total Goals Draw/Under 3.5 : ' . $first->end_result_total_goals_draw_under_35;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_away_under_35
#     if (in_array($first->end_result_total_goals_away_under_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 332 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Result/Total Goals Away/Under 3.5 : ' . $first->end_result_total_goals_away_under_35;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_home_over_25
#     if (in_array($first->end_result_total_goals_home_over_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 333 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Result/Total Goals Home/Over 2.5 : ' . $first->end_result_total_goals_home_over_25;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_draw_over_25
#     if (in_array($first->end_result_total_goals_draw_over_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 334 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Result/Total Goals Draw/Over 2.5 : ' . $first->end_result_total_goals_draw_over_25;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_away_over_25
#     if (in_array($first->end_result_total_goals_away_over_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 335 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Result/Total Goals Away/Over 2.5 : ' . $first->end_result_total_goals_away_over_25;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_home_under_25
#     if (in_array($first->end_result_total_goals_home_under_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 336 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Result/Total Goals Home/Under 2.5 : ' . $first->end_result_total_goals_home_under_25;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_draw_under_25
#     if (in_array($first->end_result_total_goals_draw_under_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 337 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Result/Total Goals Draw/Under 2.5 : ' . $first->end_result_total_goals_draw_under_25;
#         $isi .= '</a>';
#     }
# // end_result_total_goals_away_under_25
#     if (in_array($first->end_result_total_goals_away_under_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 338 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Result/Total Goals Away/Under 2.5 : ' . $first->end_result_total_goals_away_under_25;
#         $isi .= '</a>';
#     }
# // end_win_both_halves_home
#     if (in_array($first->end_win_both_halves_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 228 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'end Win Both Halves Home : ' . $first->end_win_both_halves_home;
#         $isi .= '</a>';
#     }
# // end_win_both_halves_away
#     if (in_array($first->end_win_both_halves_away, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 229 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'end Win Both Halves Away : ' . $first->end_win_both_halves_away;
#         $isi .= '</a>';
#     }
# // end_win_to_nil_home
#     if (in_array($first->end_win_to_nil_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 287 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'end Win To Nil Home : ' . $first->end_win_to_nil_home;
#         $isi .= '</a>';
#     }
# // end_win_to_nil_away
#     if (in_array($first->end_win_to_nil_away, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 288 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'end Win To Nil Away : ' . $first->end_win_to_nil_away;
#         $isi .= '</a>';
#     }
# // end_to_win_either_half_home
#     if (in_array($first->end_to_win_either_half_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 305 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'end To Win Either Half Home : ' . $first->end_to_win_either_half_home;
#         $isi .= '</a>';
#     }
# // end_to_win_either_half_away
#     if (in_array($first->end_to_win_either_half_away, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 306 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'end To Win Either Half Away : ' . $first->end_to_win_either_half_away;
#         $isi .= '</a>';
#     }
# // end_to_score_in_both_halves_by_teams_home
#     if (in_array($first->end_to_score_in_both_halves_by_teams_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 369 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'end To Score In Both Halves By Teams Home : ' . $first->end_to_score_in_both_halves_by_teams_home;
#         $isi .= '</a>';
#     }
# // end_to_score_in_both_halves_by_teams_away
#     if (in_array($first->end_to_score_in_both_halves_by_teams_away, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 370 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'end To Score In Both Halves By Teams Away : ' . $first->end_to_score_in_both_halves_by_teams_away;
#         $isi .= '</a>';
#     }
# // end_total_goals_both_teams_to_score_over_yes_25
#     if (in_array($first->end_total_goals_both_teams_to_score_over_yes_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 371 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge over_25_btts_yes">';
#             $isi .= 'end Total Goals/Both Teams To Score o/yes 2.5 : ' . $first->end_total_goals_both_teams_to_score_over_yes_25;
#         $isi .= '</a>';
#     }
# // end_total_goals_both_teams_to_score_over_no_25
#     if (in_array($first->end_total_goals_both_teams_to_score_over_no_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 372 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge over_25_btts_no">';
#             $isi .= 'end Total Goals/Both Teams To Score o/no 2.5 : ' . $first->end_total_goals_both_teams_to_score_over_no_25;
#         $isi .= '</a>';
#     }
# // end_total_goals_both_teams_to_score_under_yes_25
#     if (in_array($first->end_total_goals_both_teams_to_score_under_yes_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 373 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge under_25_btts_yes">';
#             $isi .= 'end Total Goals/Both Teams To Score u/yes 2.5 : ' . $first->end_total_goals_both_teams_to_score_under_yes_25;
#         $isi .= '</a>';
#     }
# // end_total_goals_both_teams_to_score_under_no_25
#     if (in_array($first->end_total_goals_both_teams_to_score_under_no_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' = > 374 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge under_25_btts_no">';
#             $isi .= 'end Total Goals/Both Teams To Score u/no 2.5 : ' . $first->end_total_goals_both_teams_to_score_under_no_25;
#         $isi .= '</a>';
#     }
