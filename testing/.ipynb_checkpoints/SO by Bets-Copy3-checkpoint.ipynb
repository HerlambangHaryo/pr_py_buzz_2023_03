# %%
import mysql.connector 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  " 
query += " from bets_old " 
query += " group by bet_id, bet " 
query += " order by bet_id, total asc " 
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------ 
mycursor.close()
mydb.close()
# ------------------------------------------------------  
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1].replace(")", "").replace("(", "").replace("-", "_").replace("/", "").replace(" ", "").lower()) 
    # --------------------------------------------------   
    word = "@include('contents.includes.pattern."+bet_id+"_"+bet+"')  "
    print(word, flush=True)   
    # --------------------------------------------------
# Out:
# @include('contents.includes.pattern.matchwinner')
# @include('contents.includes.pattern.homeaway')
# @include('contents.includes.pattern.secondhalfwinner')
# @include('contents.includes.pattern.asianhandicap')
# @include('contents.includes.pattern.goalsoverunder')
# @include('contents.includes.pattern.goalsoverunderfirsthalf')
# @include('contents.includes.pattern.htftdouble')
# @include('contents.includes.pattern.bothteamsscore')
# @include('contents.includes.pattern.highestscoringhalf')
# @include('contents.includes.pattern.doublechance')
# @include('contents.includes.pattern.firsthalfwinner')
# @include('contents.includes.pattern.teamtoscorefirst')
# @include('contents.includes.pattern.teamtoscorelast')
# @include('contents.includes.pattern.total_home')
# @include('contents.includes.pattern.total_away')
# @include('contents.includes.pattern.asianhandicapfirsthalf')
# @include('contents.includes.pattern.doublechance_firsthalf')
# @include('contents.includes.pattern.oddeven')
# @include('contents.includes.pattern.resultsbothteamsscore')
# @include('contents.includes.pattern.resulttotalgoals')
# @include('contents.includes.pattern.goalsoverunder_secondhalf')
# @include('contents.includes.pattern.cleansheet_home')
# @include('contents.includes.pattern.cleansheet_away')
# @include('contents.includes.pattern.winbothhalves')
# @include('contents.includes.pattern.bothteamsscore_firsthalf')
# @include('contents.includes.pattern.bothteamstoscore_secondhalf')
# @include('contents.includes.pattern.wintonil')
# @include('contents.includes.pattern.exactgoalsnumber')
# @include('contents.includes.pattern.towineitherhalf')
# @include('contents.includes.pattern.hometeamexactgoalsnumber')
# @include('contents.includes.pattern.awayteamexactgoalsnumber')
# @include('contents.includes.pattern.secondhalfexactgoalsnumber')
# @include('contents.includes.pattern.cornersoverunder')
# @include('contents.includes.pattern.exactgoalsnumber_firsthalf')
# @include('contents.includes.pattern.toscoreinbothhalvesbyteams')
# @include('contents.includes.pattern.totalgoalsbothteamstoscore')
# @include('contents.includes.pattern.halftimeresultbothteamsscore')
# @include('contents.includes.pattern.corners1x2')
# @include('contents.includes.pattern.cornersasianhandicap')
# @include('contents.includes.pattern.homecornersoverunder')
# @include('contents.includes.pattern.awaycornersoverunder')
# @include('contents.includes.pattern.bothteamstoscore1sthalf_2ndhalf')
# @include('contents.includes.pattern.10overunder')
# @include('contents.includes.pattern.lastcorner')
# @include('contents.includes.pattern.firstcorner')
# @include('contents.includes.pattern.cardseuropeanhandicap')
# @include('contents.includes.pattern.cardsoverunder')
# @include('contents.includes.pattern.cardsasianhandicap')
# @include('contents.includes.pattern.hometeamtotalcards')
# @include('contents.includes.pattern.awayteamtotalcards')
# @include('contents.includes.pattern.rcard')
# @include('contents.includes.pattern.totalgoals3way')
# @include('contents.includes.pattern.firstgoalmethod')
# @include('contents.includes.pattern.toscoreapenalty')
# @include('contents.includes.pattern.tomissapenalty')
