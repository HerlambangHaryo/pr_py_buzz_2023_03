# %%
import mysql.connector 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " order by bet_id, total asc "  
query += " limit 600, 100 "  
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------ 
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # --------------------------------------------------   
    word = "def sA_" + columnx + "(space):"
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    space += "__"'
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    print(space + "sA_'+columnx+'()", flush=True)'
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    space += "__"'
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    host="localhost"'
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    user="root"'
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    database="pr_mmbuzz_2022_06"'
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    mydb = mysql.connector.connect(host=host,user=user,password="",database=database)'
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    mycursor = mydb.cursor()'
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    query = " UPDATE `football_statistics` SET  "'
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    space += "__"'
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    query += " `'+columnx+'` = 1 "'
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    fix_status = "'Match Finished', 'Match Finished Ended'"
    word = '    query += " where fixture_status in ('+fix_status+') "'
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    query += " and goals_home < goals_away "'
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    mycursor.execute(query)'
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    mydb.commit()'
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    mycursor.close()'
    print(word, flush=True)
    # --------------------------------------------------   
    word = '    mydb.close()'
    print(word, flush=True)
    # --------------------------------------------------   
    word = "    # ----------------------------------------------------------"
    print(word, flush=True)
    # --------------------------------------------------   
    word = ""
    print(word, flush=True)
    # --------------------------------------------------
# Out:
# def sA_home_corners_overunder_over_45(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_home_corners_overunder_over_45()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `home_corners_overunder_over_45` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_home_corners_overunder_under_45(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_home_corners_overunder_under_45()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `home_corners_overunder_under_45` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_home_corners_overunder_over_55(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_home_corners_overunder_over_55()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `home_corners_overunder_over_55` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_home_corners_overunder_under_55(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_home_corners_overunder_under_55()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `home_corners_overunder_under_55` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_home_corners_overunder_over_65(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_home_corners_overunder_over_65()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `home_corners_overunder_over_65` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_home_corners_overunder_under_65(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_home_corners_overunder_under_65()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `home_corners_overunder_under_65` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_home_corners_overunder_over_75(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_home_corners_overunder_over_75()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `home_corners_overunder_over_75` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_home_corners_overunder_under_75(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_home_corners_overunder_under_75()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `home_corners_overunder_under_75` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_home_corners_overunder_over_85(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_home_corners_overunder_over_85()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `home_corners_overunder_over_85` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_home_corners_overunder_under_85(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_home_corners_overunder_under_85()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `home_corners_overunder_under_85` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_over_25(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_over_25()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_over_25` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_under_25(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_under_25()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_under_25` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_over_35(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_over_35()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_over_35` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_under_35(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_under_35()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_under_35` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_over_45(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_over_45()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_over_45` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_under_45(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_under_45()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_under_45` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_over_55(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_over_55()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_over_55` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_under_55(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_under_55()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_under_55` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_over_65(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_over_65()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_over_65` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_under_65(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_under_65()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_under_65` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_over_75(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_over_75()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_over_75` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_under_75(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_under_75()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_under_75` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_over_85(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_over_85()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_over_85` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_away_corners_overunder_under_85(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_away_corners_overunder_under_85()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `away_corners_overunder_under_85` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_both_teams_to_score_1st_half__2nd_half_yes_yes(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_both_teams_to_score_1st_half__2nd_half_yes_yes()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `both_teams_to_score_1st_half__2nd_half_yes_yes` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_both_teams_to_score_1st_half__2nd_half_yes_no(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_both_teams_to_score_1st_half__2nd_half_yes_no()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `both_teams_to_score_1st_half__2nd_half_yes_no` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_both_teams_to_score_1st_half__2nd_half_no_yes(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_both_teams_to_score_1st_half__2nd_half_no_yes()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `both_teams_to_score_1st_half__2nd_half_no_yes` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_both_teams_to_score_1st_half__2nd_half_no_no(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_both_teams_to_score_1st_half__2nd_half_no_no()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `both_teams_to_score_1st_half__2nd_half_no_no` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_10_overunder_over_05(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_10_overunder_over_05()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `10_overunder_over_05` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_10_overunder_under_05(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_10_overunder_under_05()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `10_overunder_under_05` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_last_corner_home(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_last_corner_home()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `last_corner_home` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_last_corner_away(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_last_corner_away()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `last_corner_away` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_first_corner_home(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_first_corner_home()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `first_corner_home` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_first_corner_away(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_first_corner_away()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `first_corner_away` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_cards_european_handicap_home_min_2(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_cards_european_handicap_home_min_2()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
# ...
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `total_goals_2_or_3` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_total_goals_over_3(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_total_goals_over_3()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `total_goals_over_3` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_first_goal_method_shot(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_first_goal_method_shot()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `first_goal_method_shot` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_first_goal_method_header(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_first_goal_method_header()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `first_goal_method_header` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_first_goal_method_penalty(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_first_goal_method_penalty()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `first_goal_method_penalty` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_first_goal_method_freekick(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_first_goal_method_freekick()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `first_goal_method_freekick` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_first_goal_method_owngoal(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_first_goal_method_owngoal()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `first_goal_method_owngoal` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_first_goal_method_draw(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_first_goal_method_draw()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `first_goal_method_draw` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_to_score_a_penalty_home(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_to_score_a_penalty_home()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `to_score_a_penalty_home` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_to_score_a_penalty_away(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_to_score_a_penalty_away()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `to_score_a_penalty_away` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_to_miss_a_penalty_home(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_to_miss_a_penalty_home()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `to_miss_a_penalty_home` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
#
# def sA_to_miss_a_penalty_away(space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sA_to_miss_a_penalty_away()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `to_miss_a_penalty_away` = 1 "
#     # ----------------------------------------------------------
#     query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "
#     # ----------------------------------------------------------
#     query += " and goals_home < goals_away "
#     # ----------------------------------------------------------
#     mycursor.execute(query)
#     mydb.commit()
#     # ----------------------------------------------------------
#     mycursor.close()
#     mydb.close()
#     # ----------------------------------------------------------
