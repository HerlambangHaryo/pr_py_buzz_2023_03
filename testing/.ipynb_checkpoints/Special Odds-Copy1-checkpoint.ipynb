# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *  
from a_models.odd_col import *  

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "__"  
    # ----------------------------------------------------------  
    odd_array = odd_col_list()
    # ---------------------------------------------------------- 
    total_rows = str(len(odd_array))
    print(space + total_rows, flush=True) 
    print("") 
    # ----------------------------------------------------------  
    # ----------------------------------------------------------
    for x in odd_array: 
        temp_x = x.replace("pre_", "").replace("end_", "")
        # ------------------------------------------------------ 
        host="localhost"
        user="root" 
        database="pr_mmbuzz_2022_06"
        mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
        mycursor = mydb.cursor()
        # ------------------------------------------------------
        query = "select * "
        query += " from bets_old "
        query += " where columnx = '"+temp_x+"' "
        # ------------------------------------------------------ 
        # ------------------------------------------------------   
        mycursor = mydb.cursor()
        mycursor.execute(query)
        result2 =  mycursor.fetchall()
        # ------------------------------------------------------ 
        total_rows2 = len(result2)
        # print(space + "Total Row(s) : " + str(total_rows2), flush=True) 
        # ------------------------------------------------------ 
        if(total_rows2 != 0):
            print(temp_x, flush=True)
        # ------------------------------------------------------
        
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-06 22:23:12
#   ____main__
#   ____1188
#
# match_winner_home
# match_winner_draw
# match_winner_away
# match_winner_home
# match_winner_draw
# match_winner_away
# homeaway_home
# homeaway_away
# homeaway_home
# homeaway_away
# first_half_winner_home
# first_half_winner_draw
# first_half_winner_away
# first_half_winner_home
# first_half_winner_draw
# first_half_winner_away
# second_half_winner_home
# second_half_winner_draw
# second_half_winner_away
# second_half_winner_home
# second_half_winner_draw
# second_half_winner_away
# asian_handicap_home_min_675
# asian_handicap_away_min_675
# asian_handicap_home_min_65
# asian_handicap_away_min_65
# asian_handicap_home_min_625
# asian_handicap_away_min_625
# asian_handicap_home_min_6
# asian_handicap_away_min_6
# asian_handicap_home_min_575
# asian_handicap_away_min_575
# asian_handicap_home_min_55
# asian_handicap_away_min_55
# asian_handicap_home_min_525
# asian_handicap_away_min_525
# asian_handicap_home_min_5
# asian_handicap_away_min_5
# asian_handicap_home_min_475
# asian_handicap_away_min_475
# asian_handicap_home_min_45
# asian_handicap_away_min_45
# asian_handicap_home_min_425
# asian_handicap_away_min_425
# asian_handicap_home_min_4
# asian_handicap_away_min_4
# asian_handicap_home_min_375
# asian_handicap_away_min_375
# asian_handicap_home_min_35
# asian_handicap_away_min_35
# asian_handicap_home_min_325
# asian_handicap_away_min_325
# asian_handicap_home_min_3
# asian_handicap_away_min_3
# asian_handicap_home_min_275
# asian_handicap_away_min_275
# asian_handicap_home_min_25
# asian_handicap_away_min_25
# asian_handicap_home_min_225
# asian_handicap_away_min_225
# asian_handicap_home_min_2
# asian_handicap_away_min_2
# asian_handicap_home_min_175
# asian_handicap_away_min_175
# asian_handicap_home_min_15
# asian_handicap_away_min_15
# asian_handicap_home_min_125
# asian_handicap_away_min_125
# asian_handicap_home_min_1
# asian_handicap_away_min_1
# asian_handicap_home_min_075
# asian_handicap_away_min_075
# asian_handicap_home_min_05
# asian_handicap_away_min_05
# asian_handicap_home_min_025
# asian_handicap_away_min_025
# asian_handicap_home_plus_0
# asian_handicap_away_plus_0
# asian_handicap_home_plus_025
# asian_handicap_away_plus_025
# asian_handicap_home_plus_05
# asian_handicap_away_plus_05
# asian_handicap_home_plus_075
# asian_handicap_away_plus_075
# asian_handicap_home_plus_1
# asian_handicap_away_plus_1
# asian_handicap_home_plus_125
# asian_handicap_away_plus_125
# asian_handicap_home_plus_15
# asian_handicap_away_plus_15
# asian_handicap_home_plus_175
# asian_handicap_away_plus_175
# asian_handicap_home_plus_2
# asian_handicap_away_plus_2
# asian_handicap_home_plus_225
# asian_handicap_away_plus_225
# asian_handicap_home_plus_25
# asian_handicap_away_plus_25
# asian_handicap_home_plus_275
# asian_handicap_away_plus_275
# asian_handicap_home_plus_3
# asian_handicap_away_plus_3
# asian_handicap_home_plus_325
# asian_handicap_away_plus_325
# asian_handicap_home_plus_35
# asian_handicap_away_plus_35
# asian_handicap_home_plus_375
# asian_handicap_away_plus_375
# asian_handicap_home_plus_4
# asian_handicap_away_plus_4
# asian_handicap_home_plus_425
# asian_handicap_away_plus_425
# asian_handicap_home_plus_45
# asian_handicap_away_plus_45
# asian_handicap_home_plus_475
# asian_handicap_away_plus_475
# asian_handicap_home_plus_5
# asian_handicap_away_plus_5
# asian_handicap_home_plus_525
# asian_handicap_away_plus_525
# asian_handicap_home_plus_55
# asian_handicap_away_plus_55
# asian_handicap_home_plus_575
# asian_handicap_away_plus_575
# asian_handicap_home_plus_6
# asian_handicap_away_plus_6
# asian_handicap_home_plus_625
# asian_handicap_away_plus_625
# asian_handicap_home_plus_65
# asian_handicap_away_plus_65
# asian_handicap_home_plus_675
# asian_handicap_away_plus_675
# asian_handicap_home_min_675
# asian_handicap_away_min_675
# asian_handicap_home_min_65
# asian_handicap_away_min_65
# asian_handicap_home_min_625
# asian_handicap_away_min_625
# asian_handicap_home_min_6
# asian_handicap_away_min_6
# asian_handicap_home_min_575
# asian_handicap_away_min_575
# asian_handicap_home_min_55
# asian_handicap_away_min_55
# asian_handicap_home_min_525
# asian_handicap_away_min_525
# asian_handicap_home_min_5
# asian_handicap_away_min_5
# asian_handicap_home_min_475
# asian_handicap_away_min_475
# asian_handicap_home_min_45
# asian_handicap_away_min_45
# asian_handicap_home_min_425
# asian_handicap_away_min_425
# asian_handicap_home_min_4
# asian_handicap_away_min_4
# asian_handicap_home_min_375
# asian_handicap_away_min_375
# asian_handicap_home_min_35
# asian_handicap_away_min_35
# asian_handicap_home_min_325
# asian_handicap_away_min_325
# asian_handicap_home_min_3
# asian_handicap_away_min_3
# asian_handicap_home_min_275
# asian_handicap_away_min_275
# asian_handicap_home_min_25
# asian_handicap_away_min_25
# asian_handicap_home_min_225
# asian_handicap_away_min_225
# asian_handicap_home_min_2
# asian_handicap_away_min_2
# asian_handicap_home_min_175
# asian_handicap_away_min_175
# asian_handicap_home_min_15
# asian_handicap_away_min_15
# asian_handicap_home_min_125
# asian_handicap_away_min_125
# asian_handicap_home_min_1
# asian_handicap_away_min_1
# asian_handicap_home_min_075
# asian_handicap_away_min_075
# asian_handicap_home_min_05
# asian_handicap_away_min_05
# asian_handicap_home_min_025
# asian_handicap_away_min_025
# asian_handicap_home_plus_0
# asian_handicap_away_plus_0
# asian_handicap_home_plus_025
# asian_handicap_away_plus_025
# asian_handicap_home_plus_05
# asian_handicap_away_plus_05
# asian_handicap_home_plus_075
# asian_handicap_away_plus_075
# asian_handicap_home_plus_1
# asian_handicap_away_plus_1
# asian_handicap_home_plus_125
# asian_handicap_away_plus_125
# asian_handicap_home_plus_15
# asian_handicap_away_plus_15
# asian_handicap_home_plus_175
# asian_handicap_away_plus_175
# asian_handicap_home_plus_2
# asian_handicap_away_plus_2
# asian_handicap_home_plus_225
# asian_handicap_away_plus_225
# asian_handicap_home_plus_25
# asian_handicap_away_plus_25
# asian_handicap_home_plus_275
# asian_handicap_away_plus_275
# asian_handicap_home_plus_3
# asian_handicap_away_plus_3
# asian_handicap_home_plus_325
# asian_handicap_away_plus_325
# asian_handicap_home_plus_35
# asian_handicap_away_plus_35
# asian_handicap_home_plus_375
# asian_handicap_away_plus_375
# asian_handicap_home_plus_4
# asian_handicap_away_plus_4
# asian_handicap_home_plus_425
# asian_handicap_away_plus_425
# asian_handicap_home_plus_45
# asian_handicap_away_plus_45
# asian_handicap_home_plus_475
# asian_handicap_away_plus_475
# asian_handicap_home_plus_5
# asian_handicap_away_plus_5
# asian_handicap_home_plus_525
# asian_handicap_away_plus_525
# asian_handicap_home_plus_55
# asian_handicap_away_plus_55
# asian_handicap_home_plus_575
# asian_handicap_away_plus_575
# asian_handicap_home_plus_6
# asian_handicap_away_plus_6
# asian_handicap_home_plus_625
# asian_handicap_away_plus_625
# asian_handicap_home_plus_65
# asian_handicap_away_plus_65
# asian_handicap_home_plus_675
# asian_handicap_away_plus_675
# goals_overunder_over_05
# goals_overunder_under_05
# goals_overunder_over_075
# goals_overunder_under_075
# goals_overunder_over_10
# goals_overunder_under_10
# goals_overunder_over_125
# goals_overunder_under_125
# goals_overunder_over_15
# goals_overunder_under_15
# goals_overunder_over_175
# goals_overunder_under_175
# goals_overunder_over_20
# goals_overunder_under_20
# goals_overunder_over_225
# goals_overunder_under_225
# goals_overunder_over_25
# goals_overunder_under_25
# goals_overunder_over_275
# goals_overunder_under_275
# goals_overunder_over_30
# goals_overunder_under_30
# goals_overunder_over_325
# goals_overunder_under_325
# goals_overunder_over_35
# goals_overunder_under_35
# goals_overunder_over_375
# goals_overunder_under_375
# goals_overunder_over_40
# goals_overunder_under_40
# goals_overunder_over_425
# goals_overunder_under_425
# goals_overunder_over_45
# goals_overunder_under_45
# goals_overunder_over_475
# goals_overunder_under_475
# goals_overunder_over_50
# goals_overunder_under_50
# goals_overunder_over_525
# goals_overunder_under_525
# goals_overunder_over_55
# goals_overunder_under_55
# goals_overunder_over_575
# goals_overunder_under_575
# goals_overunder_over_60
# goals_overunder_under_60
# goals_overunder_over_625
# goals_overunder_under_625
# goals_overunder_over_65
# goals_overunder_under_65
# goals_overunder_over_675
# goals_overunder_under_675
# goals_overunder_over_70
# goals_overunder_under_70
# goals_overunder_over_75
# goals_overunder_under_75
# goals_overunder_over_85
# goals_overunder_under_85
# goals_overunder_over_95
# goals_overunder_under_95
# goals_overunder_over_05
# goals_overunder_under_05
# goals_overunder_over_075
# goals_overunder_under_075
# goals_overunder_over_10
# goals_overunder_under_10
# goals_overunder_over_125
# goals_overunder_under_125
# goals_overunder_over_15
# goals_overunder_under_15
# goals_overunder_over_175
# goals_overunder_under_175
# goals_overunder_over_20
# goals_overunder_under_20
# goals_overunder_over_225
# goals_overunder_under_225
# goals_overunder_over_25
# goals_overunder_under_25
# goals_overunder_over_275
# goals_overunder_under_275
# goals_overunder_over_30
# goals_overunder_under_30
# goals_overunder_over_325
# goals_overunder_under_325
# goals_overunder_over_35
# goals_overunder_under_35
# goals_overunder_over_375
# goals_overunder_under_375
# goals_overunder_over_40
# goals_overunder_under_40
# goals_overunder_over_425
# goals_overunder_under_425
# goals_overunder_over_45
# goals_overunder_under_45
# goals_overunder_over_475
# goals_overunder_under_475
# goals_overunder_over_50
# goals_overunder_under_50
# goals_overunder_over_525
# goals_overunder_under_525
# goals_overunder_over_55
# goals_overunder_under_55
# goals_overunder_over_575
# goals_overunder_under_575
# goals_overunder_over_60
# goals_overunder_under_60
# goals_overunder_over_625
# goals_overunder_under_625
# goals_overunder_over_65
# goals_overunder_under_65
# goals_overunder_over_675
# goals_overunder_under_675
# goals_overunder_over_70
# goals_overunder_under_70
# goals_overunder_over_75
# goals_overunder_under_75
# goals_overunder_over_85
# goals_overunder_under_85
# goals_overunder_over_95
# goals_overunder_under_95
# asian_handicap_first_half_home_min_175
# asian_handicap_first_half_away_min_175
# asian_handicap_first_half_home_min_15
# asian_handicap_first_half_away_min_15
# asian_handicap_first_half_home_min_125
# asian_handicap_first_half_away_min_125
# asian_handicap_first_half_home_min_1
# asian_handicap_first_half_away_min_1
# asian_handicap_first_half_home_min_075
# asian_handicap_first_half_away_min_075
# asian_handicap_first_half_home_min_05
# asian_handicap_first_half_away_min_05
# asian_handicap_first_half_home_min_025
# asian_handicap_first_half_away_min_025
# asian_handicap_first_half_home_plus_0
# asian_handicap_first_half_away_plus_0
# asian_handicap_first_half_home_plus_025
# asian_handicap_first_half_away_plus_025
# asian_handicap_first_half_home_plus_05
# asian_handicap_first_half_away_plus_05
# asian_handicap_first_half_home_plus_075
# asian_handicap_first_half_away_plus_075
# asian_handicap_first_half_home_plus_1
# asian_handicap_first_half_away_plus_1
# asian_handicap_first_half_home_plus_125
# asian_handicap_first_half_away_plus_125
# asian_handicap_first_half_home_plus_15
# asian_handicap_first_half_away_plus_15
# asian_handicap_first_half_home_plus_175
# asian_handicap_first_half_away_plus_175
# asian_handicap_first_half_home_min_175
# asian_handicap_first_half_away_min_175
# asian_handicap_first_half_home_min_15
# asian_handicap_first_half_away_min_15
# asian_handicap_first_half_home_min_125
# asian_handicap_first_half_away_min_125
# asian_handicap_first_half_home_min_1
# asian_handicap_first_half_away_min_1
# asian_handicap_first_half_home_min_075
# asian_handicap_first_half_away_min_075
# asian_handicap_first_half_home_min_05
# asian_handicap_first_half_away_min_05
# asian_handicap_first_half_home_min_025
# asian_handicap_first_half_away_min_025
# asian_handicap_first_half_home_plus_0
# asian_handicap_first_half_away_plus_0
# asian_handicap_first_half_home_plus_025
# asian_handicap_first_half_away_plus_025
# asian_handicap_first_half_home_plus_05
# asian_handicap_first_half_away_plus_05
# asian_handicap_first_half_home_plus_075
# asian_handicap_first_half_away_plus_075
# asian_handicap_first_half_home_plus_1
# asian_handicap_first_half_away_plus_1
# asian_handicap_first_half_home_plus_125
# asian_handicap_first_half_away_plus_125
# asian_handicap_first_half_home_plus_15
# asian_handicap_first_half_away_plus_15
# asian_handicap_first_half_home_plus_175
# asian_handicap_first_half_away_plus_175
# goals_overunder_first_half_over_05
# goals_overunder_first_half_under_05
# goals_overunder_first_half_over_075
# goals_overunder_first_half_under_075
# goals_overunder_first_half_over_10
# goals_overunder_first_half_under_10
# goals_overunder_first_half_over_125
# goals_overunder_first_half_under_125
# goals_overunder_first_half_over_15
# goals_overunder_first_half_under_15
# goals_overunder_first_half_over_175
# goals_overunder_first_half_under_175
# goals_overunder_first_half_over_20
# goals_overunder_first_half_under_20
# goals_overunder_first_half_over_225
# goals_overunder_first_half_under_225
# goals_overunder_first_half_over_25
# goals_overunder_first_half_under_25
# goals_overunder_first_half_over_275
# goals_overunder_first_half_under_275
# goals_overunder_first_half_over_30
# goals_overunder_first_half_under_30
# goals_overunder_first_half_over_325
# goals_overunder_first_half_under_325
# goals_overunder_first_half_over_35
# goals_overunder_first_half_under_35
# goals_overunder_first_half_over_375
# goals_overunder_first_half_under_375
# goals_overunder_first_half_over_05
# goals_overunder_first_half_under_05
# goals_overunder_first_half_over_075
# goals_overunder_first_half_under_075
# goals_overunder_first_half_over_10
# goals_overunder_first_half_under_10
# goals_overunder_first_half_over_125
# goals_overunder_first_half_under_125
# goals_overunder_first_half_over_15
# goals_overunder_first_half_under_15
# goals_overunder_first_half_over_175
# goals_overunder_first_half_under_175
# goals_overunder_first_half_over_20
# goals_overunder_first_half_under_20
# goals_overunder_first_half_over_225
# goals_overunder_first_half_under_225
# goals_overunder_first_half_over_25
# goals_overunder_first_half_under_25
# goals_overunder_first_half_over_275
# goals_overunder_first_half_under_275
# goals_overunder_first_half_over_30
# goals_overunder_first_half_under_30
# goals_overunder_first_half_over_325
# goals_overunder_first_half_under_325
# goals_overunder_first_half_over_35
# goals_overunder_first_half_under_35
# goals_overunder_first_half_over_375
# goals_overunder_first_half_under_375
# goals_overunder__second_half_over_05
# goals_overunder__second_half_under_05
# goals_overunder__second_half_over_075
# goals_overunder__second_half_under_075
# goals_overunder__second_half_over_10
# goals_overunder__second_half_under_10
# goals_overunder__second_half_over_125
# goals_overunder__second_half_under_125
# goals_overunder__second_half_over_15
# goals_overunder__second_half_under_15
# goals_overunder__second_half_over_175
# goals_overunder__second_half_under_175
# goals_overunder__second_half_over_20
# goals_overunder__second_half_under_20
# goals_overunder__second_half_over_225
# goals_overunder__second_half_under_225
# goals_overunder__second_half_over_25
# goals_overunder__second_half_under_25
# goals_overunder__second_half_over_275
# goals_overunder__second_half_under_275
# goals_overunder__second_half_over_30
# goals_overunder__second_half_under_30
# goals_overunder__second_half_over_325
# goals_overunder__second_half_under_325
# goals_overunder__second_half_over_35
# goals_overunder__second_half_under_35
# goals_overunder__second_half_over_375
# goals_overunder__second_half_under_375
# goals_overunder__second_half_over_05
# goals_overunder__second_half_under_05
# goals_overunder__second_half_over_075
# goals_overunder__second_half_under_075
# goals_overunder__second_half_over_10
# goals_overunder__second_half_under_10
# goals_overunder__second_half_over_125
# goals_overunder__second_half_under_125
# goals_overunder__second_half_over_15
# goals_overunder__second_half_under_15
# goals_overunder__second_half_over_175
# goals_overunder__second_half_under_175
# goals_overunder__second_half_over_20
# goals_overunder__second_half_under_20
# goals_overunder__second_half_over_225
# goals_overunder__second_half_under_225
# goals_overunder__second_half_over_25
# goals_overunder__second_half_under_25
# goals_overunder__second_half_over_275
# goals_overunder__second_half_under_275
# goals_overunder__second_half_over_30
# goals_overunder__second_half_under_30
# goals_overunder__second_half_over_325
# goals_overunder__second_half_under_325
# goals_overunder__second_half_over_35
# goals_overunder__second_half_under_35
# goals_overunder__second_half_over_375
# goals_overunder__second_half_under_375
# htft_double_home_home
# htft_double_home_draw
# htft_double_home_away
# htft_double_draw_home
# htft_double_draw_draw
# htft_double_draw_away
# htft_double_away_home
# htft_double_away_draw
# htft_double_away_away
# htft_double_home_home
# htft_double_home_draw
# htft_double_home_away
# htft_double_draw_home
# htft_double_draw_draw
# htft_double_draw_away
# htft_double_away_home
# htft_double_away_draw
# htft_double_away_away
# both_teams_score_yes
# both_teams_score_no
# both_teams_score_yes
# both_teams_score_no
# both_teams_score__first_half_yes
# both_teams_score__first_half_no
# both_teams_score__first_half_yes
# both_teams_score__first_half_no
# both_teams_to_score__second_half_yes
# both_teams_to_score__second_half_no
# both_teams_to_score__second_half_yes
# both_teams_to_score__second_half_no
# results_both_teams_score_home_yes
# results_both_teams_score_draw_yes
# results_both_teams_score_away_yes
# results_both_teams_score_home_no
# results_both_teams_score_draw_no
# results_both_teams_score_away_no
# results_both_teams_score_home_yes
# results_both_teams_score_draw_yes
# results_both_teams_score_away_yes
# results_both_teams_score_home_no
# results_both_teams_score_draw_no
# results_both_teams_score_away_no
# to_score_in_both_halves_by_teams_home
# to_score_in_both_halves_by_teams_away
# to_score_in_both_halves_by_teams_home
# to_score_in_both_halves_by_teams_away
# total_goals_both_teams_to_score_over_yes_25
# total_goals_both_teams_to_score_over_no_25
# total_goals_both_teams_to_score_under_yes_25
# total_goals_both_teams_to_score_under_no_25
# total_goals_both_teams_to_score_over_yes_25
# total_goals_both_teams_to_score_over_no_25
# total_goals_both_teams_to_score_under_yes_25
# total_goals_both_teams_to_score_under_no_25
# both_teams_to_score_1st_half__2nd_half_yes_yes
# both_teams_to_score_1st_half__2nd_half_yes_no
# both_teams_to_score_1st_half__2nd_half_no_yes
# both_teams_to_score_1st_half__2nd_half_no_no
# both_teams_to_score_1st_half__2nd_half_yes_yes
# both_teams_to_score_1st_half__2nd_half_yes_no
# both_teams_to_score_1st_half__2nd_half_no_yes
# both_teams_to_score_1st_half__2nd_half_no_no
# highest_scoring_half_first
# highest_scoring_half_draw
# highest_scoring_half_second
# highest_scoring_half_first
# highest_scoring_half_draw
# highest_scoring_half_second
# double_chance_home_draw
# double_chance_home_away
# double_chance_draw_away
# double_chance_home_draw
# double_chance_home_away
# double_chance_draw_away
# double_chance__first_half_home_draw
# double_chance__first_half_home_away
# double_chance__first_half_draw_away
# double_chance__first_half_home_draw
# double_chance__first_half_home_away
# double_chance__first_half_draw_away
# oddeven_odd
# oddeven_even
# oddeven_odd
# oddeven_even
# result_total_goals_home_over_35
# result_total_goals_draw_over_35
# result_total_goals_away_over_35
# result_total_goals_home_under_35
# result_total_goals_draw_under_35
# result_total_goals_away_under_35
# result_total_goals_home_over_25
# result_total_goals_draw_over_25
# result_total_goals_away_over_25
# result_total_goals_home_under_25
# result_total_goals_draw_under_25
# result_total_goals_away_under_25
# result_total_goals_home_over_35
# result_total_goals_draw_over_35
# result_total_goals_away_over_35
# result_total_goals_home_under_35
# result_total_goals_draw_under_35
# result_total_goals_away_under_35
# result_total_goals_home_over_25
# result_total_goals_draw_over_25
# result_total_goals_away_over_25
# result_total_goals_home_under_25
# result_total_goals_draw_under_25
# result_total_goals_away_under_25
# clean_sheet__home_yes
# clean_sheet__home_no
# clean_sheet__home_yes
# clean_sheet__home_no
# clean_sheet__away_yes
# clean_sheet__away_no
# clean_sheet__away_yes
# clean_sheet__away_no
# win_both_halves_home
# win_both_halves_away
# win_both_halves_home
# win_both_halves_away
# win_to_nil_home
# win_to_nil_away
# win_to_nil_home
# win_to_nil_away
# to_win_either_half_home
# to_win_either_half_away
# to_win_either_half_home
# to_win_either_half_away
# halftime_result_both_teams_score_home_yes
# halftime_result_both_teams_score_draw_yes
# halftime_result_both_teams_score_away_yes
# halftime_result_both_teams_score_home_no
# halftime_result_both_teams_score_draw_no
# halftime_result_both_teams_score_away_no
# halftime_result_both_teams_score_home_yes
# halftime_result_both_teams_score_draw_yes
# halftime_result_both_teams_score_away_yes
# halftime_result_both_teams_score_home_no
# halftime_result_both_teams_score_draw_no
# halftime_result_both_teams_score_away_no
# exact_goals_number_0
# exact_goals_number_1
# exact_goals_number_2
# exact_goals_number_3
# exact_goals_number_4
# exact_goals_number_5
# exact_goals_number_6
# exact_goals_number_more_7
# exact_goals_number_0
# exact_goals_number_1
# exact_goals_number_2
# exact_goals_number_3
# exact_goals_number_4
# exact_goals_number_5
# exact_goals_number_6
# exact_goals_number_more_7
# exact_goals_number__first_half_0
# exact_goals_number__first_half_1
# exact_goals_number__first_half_2
# exact_goals_number__first_half_3
# exact_goals_number__first_half_4
# exact_goals_number__first_half_more_5
# exact_goals_number__first_half_0
# exact_goals_number__first_half_1
# exact_goals_number__first_half_2
# exact_goals_number__first_half_3
# exact_goals_number__first_half_4
# exact_goals_number__first_half_more_5
# second_half_exact_goals_number_0
# second_half_exact_goals_number_1
# second_half_exact_goals_number_2
# second_half_exact_goals_number_3
# second_half_exact_goals_number_4
# second_half_exact_goals_number_more_5
# second_half_exact_goals_number_0
# second_half_exact_goals_number_1
# second_half_exact_goals_number_2
# second_half_exact_goals_number_3
# second_half_exact_goals_number_4
# second_half_exact_goals_number_more_5
# home_team_exact_goals_number_0
# home_team_exact_goals_number_1
# home_team_exact_goals_number_2
# home_team_exact_goals_number_more_3
# home_team_exact_goals_number_0
# home_team_exact_goals_number_1
# home_team_exact_goals_number_2
# home_team_exact_goals_number_more_3
# away_team_exact_goals_number_0
# away_team_exact_goals_number_1
# away_team_exact_goals_number_2
# away_team_exact_goals_number_more_3
# away_team_exact_goals_number_0
# away_team_exact_goals_number_1
# away_team_exact_goals_number_2
# away_team_exact_goals_number_more_3
# corners_winner_home
# corners_winner_draw
# corners_winner_away
# corners_winner_home
# corners_winner_draw
# corners_winner_away
# 10_overunder_over_05
# 10_overunder_under_05
# 10_overunder_over_05
# 10_overunder_under_05
# cards_european_handicap_home_min_2
# cards_european_handicap_draw_min_2
# cards_european_handicap_away_min_2
# cards_european_handicap_home_min_1
# cards_european_handicap_draw_min_1
# cards_european_handicap_away_min_1
# cards_european_handicap_home_plus_0
# cards_european_handicap_draw_plus_0
# cards_european_handicap_away_plus_0
# cards_european_handicap_home_plus_1
# cards_european_handicap_draw_plus_1
# cards_european_handicap_away_plus_1
# cards_european_handicap_home_plus_2
# cards_european_handicap_draw_plus_2
# cards_european_handicap_away_plus_2
# cards_european_handicap_home_min_2
# cards_european_handicap_draw_min_2
# cards_european_handicap_away_min_2
# cards_european_handicap_home_min_1
# cards_european_handicap_draw_min_1
# cards_european_handicap_away_min_1
# cards_european_handicap_home_plus_0
# cards_european_handicap_draw_plus_0
# cards_european_handicap_away_plus_0
# cards_european_handicap_home_plus_1
# cards_european_handicap_draw_plus_1
# cards_european_handicap_away_plus_1
# cards_european_handicap_home_plus_2
# cards_european_handicap_draw_plus_2
# cards_european_handicap_away_plus_2
# rcard_yes
# rcard_no
# rcard_yes
# rcard_no
# team_to_score_first_home
# team_to_score_first_draw
# team_to_score_first_away
# team_to_score_first_home
# team_to_score_first_draw
# team_to_score_first_away
# team_to_score_last_home
# team_to_score_last_draw
# team_to_score_last_away
# team_to_score_last_home
# team_to_score_last_draw
# team_to_score_last_away
# total_home_over_15
# total_home_under_15
# total_home_over_25
# total_home_under_25
# total_home_over_35
# total_home_under_35
# total_home_over_45
# total_home_under_45
# total_home_over_55
# total_home_under_55
# total_home_over_65
# total_home_under_65
# total_home_over_15
# total_home_under_15
# total_home_over_25
# total_home_under_25
# total_home_over_35
# total_home_under_35
# total_home_over_45
# total_home_under_45
# total_home_over_55
# total_home_under_55
# total_home_over_65
# total_home_under_65
# total_away_over_15
# total_away_under_15
# total_away_over_25
# total_away_under_25
# total_away_over_35
# total_away_under_35
# total_away_over_45
# total_away_under_45
# total_away_over_55
# total_away_under_55
# total_away_over_65
# total_away_under_65
# total_away_over_15
# total_away_under_15
# total_away_over_25
# total_away_under_25
# total_away_over_35
# total_away_under_35
# total_away_over_45
# total_away_under_45
# total_away_over_55
# total_away_under_55
# total_away_over_65
# total_away_under_65
# corners_asian_handicap_home_min_65
# corners_asian_handicap_away_min_65
# corners_asian_handicap_home_min_6
# corners_asian_handicap_away_min_6
# corners_asian_handicap_home_min_55
# corners_asian_handicap_away_min_55
# corners_asian_handicap_home_min_5
# corners_asian_handicap_away_min_5
# corners_asian_handicap_home_min_45
# corners_asian_handicap_away_min_45
# corners_asian_handicap_home_min_4
# corners_asian_handicap_away_min_4
# corners_asian_handicap_home_min_35
# corners_asian_handicap_away_min_35
# corners_asian_handicap_home_min_3
# corners_asian_handicap_away_min_3
# corners_asian_handicap_home_min_25
# corners_asian_handicap_away_min_25
# corners_asian_handicap_home_min_2
# corners_asian_handicap_away_min_2
# corners_asian_handicap_home_min_15
# corners_asian_handicap_away_min_15
# corners_asian_handicap_home_min_1
# corners_asian_handicap_home_min_05
# corners_asian_handicap_away_min_1
# corners_asian_handicap_away_min_05
# corners_asian_handicap_home_plus_0
# corners_asian_handicap_away_plus_0
# corners_asian_handicap_home_plus_05
# corners_asian_handicap_away_plus_05
# corners_asian_handicap_home_plus_1
# corners_asian_handicap_away_plus_1
# corners_asian_handicap_home_plus_15
# corners_asian_handicap_away_plus_15
# corners_asian_handicap_home_plus_2
# corners_asian_handicap_away_plus_2
# corners_asian_handicap_home_plus_25
# corners_asian_handicap_away_plus_25
# corners_asian_handicap_home_plus_3
# corners_asian_handicap_away_plus_3
# corners_asian_handicap_home_plus_35
# corners_asian_handicap_away_plus_35
# corners_asian_handicap_home_plus_4
# corners_asian_handicap_away_plus_4
# corners_asian_handicap_home_plus_45
# corners_asian_handicap_away_plus_45
# corners_asian_handicap_home_plus_5
# corners_asian_handicap_away_plus_5
# corners_asian_handicap_home_plus_55
# corners_asian_handicap_away_plus_55
# corners_asian_handicap_home_plus_6
# corners_asian_handicap_away_plus_6
# corners_asian_handicap_home_plus_65
# corners_asian_handicap_away_plus_65
# corners_asian_handicap_home_min_65
# corners_asian_handicap_away_min_65
# corners_asian_handicap_home_min_6
# corners_asian_handicap_away_min_6
# corners_asian_handicap_home_min_55
# corners_asian_handicap_away_min_55
# corners_asian_handicap_home_min_5
# corners_asian_handicap_away_min_5
# corners_asian_handicap_home_min_45
# corners_asian_handicap_away_min_45
# corners_asian_handicap_home_min_4
# corners_asian_handicap_away_min_4
# corners_asian_handicap_home_min_35
# corners_asian_handicap_away_min_35
# corners_asian_handicap_home_min_3
# corners_asian_handicap_away_min_3
# corners_asian_handicap_home_min_25
# corners_asian_handicap_away_min_25
# corners_asian_handicap_home_min_2
# corners_asian_handicap_away_min_2
# corners_asian_handicap_home_min_15
# corners_asian_handicap_away_min_15
# corners_asian_handicap_home_min_1
# corners_asian_handicap_home_min_05
# corners_asian_handicap_away_min_1
# corners_asian_handicap_away_min_05
# corners_asian_handicap_home_plus_0
# corners_asian_handicap_away_plus_0
# corners_asian_handicap_home_plus_05
# corners_asian_handicap_away_plus_05
# corners_asian_handicap_home_plus_1
# corners_asian_handicap_away_plus_1
# corners_asian_handicap_home_plus_15
# corners_asian_handicap_away_plus_15
# corners_asian_handicap_home_plus_2
# corners_asian_handicap_away_plus_2
# corners_asian_handicap_home_plus_25
# corners_asian_handicap_away_plus_25
# corners_asian_handicap_home_plus_3
# corners_asian_handicap_away_plus_3
# corners_asian_handicap_home_plus_35
# corners_asian_handicap_away_plus_35
# corners_asian_handicap_home_plus_4
# corners_asian_handicap_away_plus_4
# corners_asian_handicap_home_plus_45
# corners_asian_handicap_away_plus_45
# corners_asian_handicap_home_plus_5
# corners_asian_handicap_away_plus_5
# corners_asian_handicap_home_plus_55
# corners_asian_handicap_away_plus_55
# corners_asian_handicap_home_plus_6
# corners_asian_handicap_away_plus_6
# corners_asian_handicap_home_plus_65
# corners_asian_handicap_away_plus_65
# corners_over_under_over_700
# corners_over_under_under_700
# corners_over_under_over_725
# corners_over_under_under_725
# corners_over_under_over_750
# corners_over_under_under_750
# corners_over_under_over_775
# corners_over_under_under_775
# corners_over_under_over_800
# corners_over_under_under_800
# corners_over_under_over_825
# corners_over_under_under_825
# corners_over_under_over_850
# corners_over_under_under_850
# corners_over_under_over_875
# corners_over_under_under_875
# corners_over_under_over_900
# corners_over_under_under_900
# corners_over_under_over_925
# corners_over_under_under_925
# corners_over_under_over_950
# corners_over_under_under_950
# corners_over_under_over_975
# corners_over_under_under_975
# corners_over_under_over_1000
# corners_over_under_under_1000
# corners_over_under_over_1025
# corners_over_under_under_1025
# corners_over_under_over_1050
# corners_over_under_under_1050
# corners_over_under_over_1075
# corners_over_under_under_1075
# corners_over_under_over_1100
# corners_over_under_under_1100
# corners_over_under_over_1125
# corners_over_under_under_1125
# corners_over_under_over_1150
# corners_over_under_under_1150
# corners_over_under_over_1175
# corners_over_under_under_1175
# corners_over_under_over_1200
# corners_over_under_under_1200
# corners_over_under_over_1225
# corners_over_under_under_1225
# corners_over_under_over_1250
# corners_over_under_under_1250
# corners_over_under_over_1275
# corners_over_under_under_1275
# corners_over_under_over_700
# corners_over_under_under_700
# corners_over_under_over_725
# corners_over_under_under_725
# corners_over_under_over_750
# corners_over_under_under_750
# corners_over_under_over_775
# corners_over_under_under_775
# corners_over_under_over_800
# corners_over_under_under_800
# corners_over_under_over_825
# corners_over_under_under_825
# corners_over_under_over_850
# corners_over_under_under_850
# corners_over_under_over_875
# corners_over_under_under_875
# corners_over_under_over_900
# corners_over_under_under_900
# corners_over_under_over_925
# corners_over_under_under_925
# corners_over_under_over_950
# corners_over_under_under_950
# corners_over_under_over_975
# corners_over_under_under_975
# corners_over_under_over_1000
# corners_over_under_under_1000
# corners_over_under_over_1025
# corners_over_under_under_1025
# corners_over_under_over_1050
# corners_over_under_under_1050
# corners_over_under_over_1075
# corners_over_under_under_1075
# corners_over_under_over_1100
# corners_over_under_under_1100
# corners_over_under_over_1125
# corners_over_under_under_1125
# corners_over_under_over_1150
# corners_over_under_under_1150
# corners_over_under_over_1175
# corners_over_under_under_1175
# corners_over_under_over_1200
# corners_over_under_under_1200
# corners_over_under_over_1225
# corners_over_under_under_1225
# corners_over_under_over_1250
# corners_over_under_under_1250
# corners_over_under_over_1275
# corners_over_under_under_1275
# home_corners_overunder_over_25
# home_corners_overunder_under_25
# home_corners_overunder_over_35
# home_corners_overunder_under_35
# home_corners_overunder_over_45
# home_corners_overunder_under_45
# home_corners_overunder_over_55
# home_corners_overunder_under_55
# home_corners_overunder_over_65
# home_corners_overunder_under_65
# home_corners_overunder_over_75
# home_corners_overunder_under_75
# home_corners_overunder_over_85
# home_corners_overunder_under_85
# home_corners_overunder_over_25
# home_corners_overunder_under_25
# home_corners_overunder_over_35
# home_corners_overunder_under_35
# home_corners_overunder_over_45
# home_corners_overunder_under_45
# home_corners_overunder_over_55
# home_corners_overunder_under_55
# home_corners_overunder_over_65
# home_corners_overunder_under_65
# home_corners_overunder_over_75
# home_corners_overunder_under_75
# home_corners_overunder_over_85
# home_corners_overunder_under_85
# away_corners_overunder_over_25
# away_corners_overunder_under_25
# away_corners_overunder_over_35
# away_corners_overunder_under_35
# away_corners_overunder_over_45
# away_corners_overunder_under_45
# away_corners_overunder_over_55
# away_corners_overunder_under_55
# away_corners_overunder_over_65
# away_corners_overunder_under_65
# away_corners_overunder_over_75
# away_corners_overunder_under_75
# away_corners_overunder_over_85
# away_corners_overunder_under_85
# away_corners_overunder_over_25
# away_corners_overunder_under_25
# away_corners_overunder_over_35
# away_corners_overunder_under_35
# away_corners_overunder_over_45
# away_corners_overunder_under_45
# away_corners_overunder_over_55
# away_corners_overunder_under_55
# away_corners_overunder_over_65
# away_corners_overunder_under_65
# away_corners_overunder_over_75
# away_corners_overunder_under_75
# away_corners_overunder_over_85
# away_corners_overunder_under_85
# first_corner_home
# first_corner_away
# first_corner_home
# first_corner_away
# last_corner_home
# last_corner_away
# last_corner_home
# last_corner_away
# cards_asian_handicap_home_min_05
# cards_asian_handicap_away_min_05
# cards_asian_handicap_home_plus_0
# cards_asian_handicap_away_plus_0
# cards_asian_handicap_home_plus_05
# cards_asian_handicap_away_plus_05
# cards_asian_handicap_home_min_05
# cards_asian_handicap_away_min_05
# cards_asian_handicap_home_plus_0
# cards_asian_handicap_away_plus_0
# cards_asian_handicap_home_plus_05
# cards_asian_handicap_away_plus_05
# cards_overunder_over_25
# cards_overunder_under_25
# cards_overunder_over_35
# cards_overunder_under_35
# cards_overunder_over_45
# cards_overunder_under_45
# cards_overunder_over_55
# cards_overunder_under_55
# cards_overunder_over_65
# cards_overunder_under_65
# cards_overunder_over_75
# cards_overunder_under_75
# cards_overunder_over_25
# cards_overunder_under_25
# cards_overunder_over_35
# cards_overunder_under_35
# cards_overunder_over_45
# cards_overunder_under_45
# cards_overunder_over_55
# cards_overunder_under_55
# cards_overunder_over_65
# cards_overunder_under_65
# cards_overunder_over_75
# cards_overunder_under_75
# home_team_total_cards_over_15
# home_team_total_cards_under_15
# home_team_total_cards_over_25
# home_team_total_cards_under_25
# home_team_total_cards_over_35
# home_team_total_cards_under_35
# home_team_total_cards_over_15
# home_team_total_cards_under_15
# home_team_total_cards_over_25
# home_team_total_cards_under_25
# home_team_total_cards_over_35
# home_team_total_cards_under_35
# away_team_total_cards_over_15
# away_team_total_cards_under_15
# away_team_total_cards_over_25
# away_team_total_cards_under_25
# away_team_total_cards_over_35
# away_team_total_cards_under_35
# away_team_total_cards_over_15
# away_team_total_cards_under_15
# away_team_total_cards_over_25
# away_team_total_cards_under_25
# away_team_total_cards_over_35
# away_team_total_cards_under_35
# total_goals_under_2
# total_goals_2_or_3
# total_goals_over_3
# total_goals_under_2
# total_goals_2_or_3
# total_goals_over_3
# first_goal_method_shot
# first_goal_method_header
# first_goal_method_penalty
# first_goal_method_freekick
# first_goal_method_owngoal
# first_goal_method_draw
# first_goal_method_shot
# first_goal_method_header
# first_goal_method_penalty
# first_goal_method_freekick
# first_goal_method_owngoal
# first_goal_method_draw
# to_score_a_penalty_home
# to_score_a_penalty_away
# to_score_a_penalty_home
# to_score_a_penalty_away
# to_miss_a_penalty_home
# to_miss_a_penalty_away
# to_miss_a_penalty_home
# to_miss_a_penalty_away
# # -------------------------------------------------- End at 2023-05-06 22:23:13
