# %%
# ------------------------------------------------------
import mysql.connector 
# ------------------------------------------------------
old_col = "passess_away"
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " order by bet_id, total asc " 
# ------------------------------------------------------   
print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ------------------------------------------------------ 
for x in result: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4]) 
    # --------------------------------------------------   
    # ALTER TABLE `bets_new` ADD `"+old_col+"` BOOLEAN NULL DEFAULT NULL AFTER `test`; 
    alter =  "ALTER TABLE `football_statistics` ADD `"+columnx+"` BOOLEAN NULL DEFAULT NULL AFTER `"+old_col+"`;"
    old_col = columnx
    print(alter, flush=True) 
    mycursor.execute(alter)
    mydb.commit()  
    # --------------------------------------------------  
# ------------------------------------------------------
# Out:
# select  bet_id  , bet   , value   , columny   , columnx   from bets_old  order by bet_id, total asc
# ALTER TABLE `football_statistics` ADD `match_winner_home` BOOLEAN NULL DEFAULT NULL AFTER `passess_away`;
# ALTER TABLE `football_statistics` ADD `match_winner_draw` BOOLEAN NULL DEFAULT NULL AFTER `match_winner_home`;
# ALTER TABLE `football_statistics` ADD `match_winner_away` BOOLEAN NULL DEFAULT NULL AFTER `match_winner_draw`;
# ALTER TABLE `football_statistics` ADD `homeaway_home` BOOLEAN NULL DEFAULT NULL AFTER `match_winner_away`;
# ALTER TABLE `football_statistics` ADD `homeaway_away` BOOLEAN NULL DEFAULT NULL AFTER `homeaway_home`;
# ALTER TABLE `football_statistics` ADD `second_half_winner_home` BOOLEAN NULL DEFAULT NULL AFTER `homeaway_away`;
# ALTER TABLE `football_statistics` ADD `second_half_winner_draw` BOOLEAN NULL DEFAULT NULL AFTER `second_half_winner_home`;
# ...
