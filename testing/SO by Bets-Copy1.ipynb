# %%
import mysql.connector 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " , id  "
query += " from bets_old " 
query += " order by bet_id, total asc " 
# ------------------------------------------------------   
print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------ 
mycursor.close()
mydb.close()
# ------------------------------------------------------ 
# for x in result2: 
#     # -------------------------------------------------- 
#     bet_id = str(x[0])
#     bet = str(x[1])
#     value = str(x[2])
#     columny = str(x[3])
#     columnx = str(x[4])
#     idx = str(x[5])
#     # -------------------------------------------------- 
#     route = "pre"
#     col = route + "_" + columnx
#     # --------------------------------------------------  
#     word = "// " + col
#     print(word, flush=True)
#     # -------------------------------------------------- 
#     word = "    if (in_array($first->"+col+", $special_odds) )"
#     print(word, flush=True)
#     # --------------------------------------------------  
#     word = "    {"
#     print(word, flush=True)
#     # --------------------------------------------------   
#     bet_rep = bet.replace("-", "").replace(" ", "_").replace("/", "")
#     word = "        $route = route('Special_odds.league', ['leagueapi_id' = > $first->leagueapi_id,'bet' = > "+idx+" ] );"
#     print(word, flush=True)
#     # --------------------------------------------------   
#     class_html = '"me-1 badge '+columny+'"' 
#     word = "        $isi .= '<a ';"
#     print(word, flush=True)
#     # -------------------------------------------------- 
#     href = "'.$route.'"  
#     prehref = '"'  
#     word = "            $isi .= 'href="+prehref+href+prehref+" ';"
#     print(word, flush=True)
#     # --------------------------------------------------   
#     word = "            $isi .= 'class="+class_html+">';"
#     print(word, flush=True)
#     # -------------------------------------------------- 
#     word = "            $isi .= '"+route+" "+bet+" "+value+" : ' . $first->"+col+";"
#     print(word, flush=True)
#     # -------------------------------------------------- 
#     word = "        $isi .= '</a>';"
#     print(word, flush=True) 
#     # --------------------------------------------------  
#     word = "    }"
#     print(word, flush=True)
    # -------------------------------------------------- 

# ------------------------------------------------------ 
# word = "    $isi .= '<br/>';"
# print(word, flush=True)
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    idx = str(x[5])
    # -------------------------------------------------- 
    route = "end"
    col = route + "_" + columnx
    # --------------------------------------------------  
    word = "// " + col
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "    if (in_array($first->"+col+", $special_odds) )"
    print(word, flush=True)
    # --------------------------------------------------  
    word = "    {"
    print(word, flush=True)
    # --------------------------------------------------   
    bet_rep = bet.replace("-", "").replace(" ", "_").replace("/", "")
    # word = "        $route = route('Special_odds.bet', '"+idx+"');" 
    word = "        $route = route('Special_odds.league', ['leagueapi_id' = > $first->leagueapi_id,'bet' = > "+idx+" ] );"
    print(word, flush=True)
    # --------------------------------------------------   
    class_html = '"me-1 badge '+columny+'"' 
    word = "        $isi .= '<a ';"
    print(word, flush=True)
    # -------------------------------------------------- 
    href = "'.$route.'"  
    prehref = '"'  
    word = "            $isi .= 'href="+prehref+href+prehref+" ';"
    print(word, flush=True)
    # --------------------------------------------------   
    word = "            $isi .= 'class="+class_html+">';"
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "            $isi .= '"+route+" "+bet+" "+value+" : ' . $first->"+col+";"
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "        $isi .= '</a>';"
    print(word, flush=True) 
    # --------------------------------------------------  
    word = "    }"
    print(word, flush=True)
    # --------------------------------------------------  
    # --------------------------------------------------  
    # --------------------------------------------------  
    # --------------------------------------------------  
    # --------------------------------------------------
# Out:
# select  bet_id  , bet   , value   , columny   , columnx   , id   from bets_old  order by bet_id, total asc
# // end_match_winner_home
#     if (in_array($first->end_match_winner_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' = > $first->leagueapi_id,'bet' = > 1 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'end Match Winner Home : ' . $first->end_match_winner_home;
#         $isi .= '</a>';
#     }
# // end_match_winner_draw
#     if (in_array($first->end_match_winner_draw, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' = > $first->leagueapi_id,'bet' = > 2 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-gray-700">';
#             $isi .= 'end Match Winner Draw : ' . $first->end_match_winner_draw;
#         $isi .= '</a>';
# ...
