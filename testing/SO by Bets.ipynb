# %%
import mysql.connector 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " , id  "
query += " from bets_old " 
query += " where level1_order = 9 " 
query += " order by bet_id, total asc " 
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------ 
mycursor.close()
mydb.close()
# ------------------------------------------------------ 
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    idx = str(x[5])
    # -------------------------------------------------- 
    route = "pre"
    col = route + "_" + columnx
    # --------------------------------------------------  
    word = "// " + col
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "    if (in_array($first->"+col+", $special_odds) )"
    print(word, flush=True)
    # --------------------------------------------------  
    word = "    {"
    print(word, flush=True)
    # --------------------------------------------------   
    bet_rep = bet.replace("-", "").replace(" ", "_").replace("/", "")
    word = "        $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => "+idx+" ] );"
    print(word, flush=True)
    # --------------------------------------------------   
    class_html = '"me-1 badge '+columny+'"' 
    word = "        $isi .= '<a ';"
    print(word, flush=True)
    # -------------------------------------------------- 
    href = "'.$route.'"  
    prehref = '"'  
    word = "            $isi .= 'href="+prehref+href+prehref+" ';"
    print(word, flush=True)
    # --------------------------------------------------   
    word = "            $isi .= 'class="+class_html+">';"
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "            $isi .= '"+route+" "+bet+" "+value+" : ' . $first->"+col+";"
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "        $isi .= '</a>';"
    print(word, flush=True) 
    # --------------------------------------------------  
    word = "    }"
    print(word, flush=True)
    # -------------------------------------------------- 

# ------------------------------------------------------ 
word = "    $isi .= '<br/><br/>';"
print(word, flush=True)
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    idx = str(x[5])
    # -------------------------------------------------- 
    route = "end"
    col = route + "_" + columnx
    # --------------------------------------------------  
    word = "// " + col
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "    if (in_array($first->"+col+", $special_odds) )"
    print(word, flush=True)
    # --------------------------------------------------  
    word = "    {"
    print(word, flush=True)
    # --------------------------------------------------   
    bet_rep = bet.replace("-", "").replace(" ", "_").replace("/", "")
    # word = "        $route = route('Special_odds.bet', '"+idx+"');" 
    word = "        $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => "+idx+" ] );"
    print(word, flush=True)
    # --------------------------------------------------   
    class_html = '"me-1 badge '+columny+'"' 
    word = "        $isi .= '<a ';"
    print(word, flush=True)
    # -------------------------------------------------- 
    href = "'.$route.'"  
    prehref = '"'  
    word = "            $isi .= 'href="+prehref+href+prehref+" ';"
    print(word, flush=True)
    # --------------------------------------------------   
    word = "            $isi .= 'class="+class_html+">';"
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "            $isi .= '"+route+" "+bet+" "+value+" : ' . $first->"+col+";"
    print(word, flush=True)
    # -------------------------------------------------- 
    word = "        $isi .= '</a>';"
    print(word, flush=True) 
    # --------------------------------------------------  
    word = "    }"
    print(word, flush=True)
    # --------------------------------------------------  
    # --------------------------------------------------  
    # --------------------------------------------------  
    # --------------------------------------------------  
    # --------------------------------------------------
# Out:
# // pre_team_to_score_last_home
#     if (in_array($first->pre_team_to_score_last_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 919 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'pre Team To Score Last Home : ' . $first->pre_team_to_score_last_home;
#         $isi .= '</a>';
#     }
# // pre_team_to_score_last_draw
#     if (in_array($first->pre_team_to_score_last_draw, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 920 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-gray-700">';
#             $isi .= 'pre Team To Score Last Draw : ' . $first->pre_team_to_score_last_draw;
#         $isi .= '</a>';
#     }
# // pre_team_to_score_last_away
#     if (in_array($first->pre_team_to_score_last_away, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 921 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'pre Team To Score Last Away : ' . $first->pre_team_to_score_last_away;
#         $isi .= '</a>';
#     }
# // pre_total_home_over_15
#     if (in_array($first->pre_total_home_over_15, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 924 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Home Over 1.5 : ' . $first->pre_total_home_over_15;
#         $isi .= '</a>';
#     }
# // pre_total_home_under_15
#     if (in_array($first->pre_total_home_under_15, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 925 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Home Under 1.5 : ' . $first->pre_total_home_under_15;
#         $isi .= '</a>';
#     }
# // pre_total_home_over_25
#     if (in_array($first->pre_total_home_over_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 926 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Home Over 2.5 : ' . $first->pre_total_home_over_25;
#         $isi .= '</a>';
#     }
# // pre_total_home_under_25
#     if (in_array($first->pre_total_home_under_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 927 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Home Under 2.5 : ' . $first->pre_total_home_under_25;
#         $isi .= '</a>';
#     }
# // pre_total_home_over_35
#     if (in_array($first->pre_total_home_over_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 922 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Home Over 3.5 : ' . $first->pre_total_home_over_35;
#         $isi .= '</a>';
#     }
# // pre_total_home_under_35
#     if (in_array($first->pre_total_home_under_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 923 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Home Under 3.5 : ' . $first->pre_total_home_under_35;
#         $isi .= '</a>';
#     }
# // pre_total_home_over_45
#     if (in_array($first->pre_total_home_over_45, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 971 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Home Over 4.5 : ' . $first->pre_total_home_over_45;
#         $isi .= '</a>';
#     }
# // pre_total_home_under_45
#     if (in_array($first->pre_total_home_under_45, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 972 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Home Under 4.5 : ' . $first->pre_total_home_under_45;
#         $isi .= '</a>';
#     }
# // pre_total_home_over_55
#     if (in_array($first->pre_total_home_over_55, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 973 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Home Over 5.5 : ' . $first->pre_total_home_over_55;
#         $isi .= '</a>';
#     }
# // pre_total_home_under_55
#     if (in_array($first->pre_total_home_under_55, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 974 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Home Under 5.5 : ' . $first->pre_total_home_under_55;
#         $isi .= '</a>';
#     }
# // pre_total_home_over_65
#     if (in_array($first->pre_total_home_over_65, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 975 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Home Over 6.5 : ' . $first->pre_total_home_over_65;
#         $isi .= '</a>';
#     }
# // pre_total_home_under_65
#     if (in_array($first->pre_total_home_under_65, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 976 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Home Under 6.5 : ' . $first->pre_total_home_under_65;
#         $isi .= '</a>';
#     }
# // pre_total_away_over_15
#     if (in_array($first->pre_total_away_over_15, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 930 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Away Over 1.5 : ' . $first->pre_total_away_over_15;
#         $isi .= '</a>';
#     }
# // pre_total_away_under_15
#     if (in_array($first->pre_total_away_under_15, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 931 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Away Under 1.5 : ' . $first->pre_total_away_under_15;
#         $isi .= '</a>';
#     }
# // pre_total_away_over_25
#     if (in_array($first->pre_total_away_over_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 934 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Away Over 2.5 : ' . $first->pre_total_away_over_25;
#         $isi .= '</a>';
#     }
# // pre_total_away_under_25
#     if (in_array($first->pre_total_away_under_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 935 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Away Under 2.5 : ' . $first->pre_total_away_under_25;
#         $isi .= '</a>';
#     }
# // pre_total_away_over_35
#     if (in_array($first->pre_total_away_over_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 928 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Away Over 3.5 : ' . $first->pre_total_away_over_35;
#         $isi .= '</a>';
#     }
# // pre_total_away_under_35
#     if (in_array($first->pre_total_away_under_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 929 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Away Under 3.5 : ' . $first->pre_total_away_under_35;
#         $isi .= '</a>';
#     }
# // pre_total_away_over_45
#     if (in_array($first->pre_total_away_over_45, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 932 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Away Over 4.5 : ' . $first->pre_total_away_over_45;
#         $isi .= '</a>';
#     }
# // pre_total_away_under_45
#     if (in_array($first->pre_total_away_under_45, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 933 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Away Under 4.5 : ' . $first->pre_total_away_under_45;
#         $isi .= '</a>';
#     }
# // pre_total_away_over_55
#     if (in_array($first->pre_total_away_over_55, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 936 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Away Over 5.5 : ' . $first->pre_total_away_over_55;
#         $isi .= '</a>';
#     }
# // pre_total_away_under_55
#     if (in_array($first->pre_total_away_under_55, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 937 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Away Under 5.5 : ' . $first->pre_total_away_under_55;
#         $isi .= '</a>';
#     }
# // pre_total_away_over_65
#     if (in_array($first->pre_total_away_over_65, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 938 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'pre Total - Away Over 6.5 : ' . $first->pre_total_away_over_65;
#         $isi .= '</a>';
#     }
# // pre_total_away_under_65
#     if (in_array($first->pre_total_away_under_65, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 939 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'pre Total - Away Under 6.5 : ' . $first->pre_total_away_under_65;
#         $isi .= '</a>';
#     }
# // pre_exact_goals_number_0
#     if (in_array($first->pre_exact_goals_number_0, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 301 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Exact Goals Number 0 : ' . $first->pre_exact_goals_number_0;
#         $isi .= '</a>';
#     }
# // pre_exact_goals_number_1
#     if (in_array($first->pre_exact_goals_number_1, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 300 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Exact Goals Number 1 : ' . $first->pre_exact_goals_number_1;
#         $isi .= '</a>';
#     }
# // pre_exact_goals_number_2
#     if (in_array($first->pre_exact_goals_number_2, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 297 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Exact Goals Number 2 : ' . $first->pre_exact_goals_number_2;
#         $isi .= '</a>';
#     }
# // pre_exact_goals_number_3
#     if (in_array($first->pre_exact_goals_number_3, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 298 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Exact Goals Number 3 : ' . $first->pre_exact_goals_number_3;
#         $isi .= '</a>';
#     }
# // pre_exact_goals_number_4
#     if (in_array($first->pre_exact_goals_number_4, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 299 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Exact Goals Number 4 : ' . $first->pre_exact_goals_number_4;
#         $isi .= '</a>';
#     }
# // pre_exact_goals_number_5
#     if (in_array($first->pre_exact_goals_number_5, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 302 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Exact Goals Number 5 : ' . $first->pre_exact_goals_number_5;
#         $isi .= '</a>';
#     }
# // pre_exact_goals_number_6
#     if (in_array($first->pre_exact_goals_number_6, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 303 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Exact Goals Number 6 : ' . $first->pre_exact_goals_number_6;
#         $isi .= '</a>';
#     }
# // pre_exact_goals_number_more_7
#     if (in_array($first->pre_exact_goals_number_more_7, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 304 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Exact Goals Number more 7 : ' . $first->pre_exact_goals_number_more_7;
#         $isi .= '</a>';
#     }
# // pre_home_team_exact_goals_number_0
#     if (in_array($first->pre_home_team_exact_goals_number_0, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 309 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Home Team Exact Goals Number 0 : ' . $first->pre_home_team_exact_goals_number_0;
#         $isi .= '</a>';
#     }
# // pre_home_team_exact_goals_number_1
#     if (in_array($first->pre_home_team_exact_goals_number_1, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 308 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Home Team Exact Goals Number 1 : ' . $first->pre_home_team_exact_goals_number_1;
#         $isi .= '</a>';
#     }
# // pre_home_team_exact_goals_number_2
#     if (in_array($first->pre_home_team_exact_goals_number_2, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 307 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Home Team Exact Goals Number 2 : ' . $first->pre_home_team_exact_goals_number_2;
#         $isi .= '</a>';
#     }
# // pre_home_team_exact_goals_number_more_3
#     if (in_array($first->pre_home_team_exact_goals_number_more_3, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 310 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Home Team Exact Goals Number more 3 : ' . $first->pre_home_team_exact_goals_number_more_3;
#         $isi .= '</a>';
#     }
# // pre_away_team_exact_goals_number_0
#     if (in_array($first->pre_away_team_exact_goals_number_0, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 313 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Away Team Exact Goals Number 0 : ' . $first->pre_away_team_exact_goals_number_0;
#         $isi .= '</a>';
#     }
# // pre_away_team_exact_goals_number_1
#     if (in_array($first->pre_away_team_exact_goals_number_1, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 312 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Away Team Exact Goals Number 1 : ' . $first->pre_away_team_exact_goals_number_1;
#         $isi .= '</a>';
#     }
# // pre_away_team_exact_goals_number_2
#     if (in_array($first->pre_away_team_exact_goals_number_2, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 311 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Away Team Exact Goals Number 2 : ' . $first->pre_away_team_exact_goals_number_2;
#         $isi .= '</a>';
#     }
# // pre_away_team_exact_goals_number_more_3
#     if (in_array($first->pre_away_team_exact_goals_number_more_3, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 314 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'pre Away Team Exact Goals Number more 3 : ' . $first->pre_away_team_exact_goals_number_more_3;
#         $isi .= '</a>';
#     }
#     $isi .= '<br/><br/>';
# // end_team_to_score_last_home
#     if (in_array($first->end_team_to_score_last_home, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 919 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-primary">';
#             $isi .= 'end Team To Score Last Home : ' . $first->end_team_to_score_last_home;
#         $isi .= '</a>';
#     }
# // end_team_to_score_last_draw
#     if (in_array($first->end_team_to_score_last_draw, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 920 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-gray-700">';
#             $isi .= 'end Team To Score Last Draw : ' . $first->end_team_to_score_last_draw;
#         $isi .= '</a>';
#     }
# // end_team_to_score_last_away
#     if (in_array($first->end_team_to_score_last_away, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 921 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-warning">';
#             $isi .= 'end Team To Score Last Away : ' . $first->end_team_to_score_last_away;
#         $isi .= '</a>';
#     }
# // end_total_home_over_15
#     if (in_array($first->end_total_home_over_15, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 924 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Home Over 1.5 : ' . $first->end_total_home_over_15;
#         $isi .= '</a>';
#     }
# // end_total_home_under_15
#     if (in_array($first->end_total_home_under_15, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 925 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Home Under 1.5 : ' . $first->end_total_home_under_15;
#         $isi .= '</a>';
#     }
# // end_total_home_over_25
#     if (in_array($first->end_total_home_over_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 926 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Home Over 2.5 : ' . $first->end_total_home_over_25;
#         $isi .= '</a>';
#     }
# // end_total_home_under_25
#     if (in_array($first->end_total_home_under_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 927 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Home Under 2.5 : ' . $first->end_total_home_under_25;
#         $isi .= '</a>';
#     }
# // end_total_home_over_35
#     if (in_array($first->end_total_home_over_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 922 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Home Over 3.5 : ' . $first->end_total_home_over_35;
#         $isi .= '</a>';
#     }
# // end_total_home_under_35
#     if (in_array($first->end_total_home_under_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 923 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Home Under 3.5 : ' . $first->end_total_home_under_35;
#         $isi .= '</a>';
#     }
# // end_total_home_over_45
#     if (in_array($first->end_total_home_over_45, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 971 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Home Over 4.5 : ' . $first->end_total_home_over_45;
#         $isi .= '</a>';
#     }
# // end_total_home_under_45
#     if (in_array($first->end_total_home_under_45, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 972 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Home Under 4.5 : ' . $first->end_total_home_under_45;
#         $isi .= '</a>';
#     }
# // end_total_home_over_55
#     if (in_array($first->end_total_home_over_55, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 973 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Home Over 5.5 : ' . $first->end_total_home_over_55;
#         $isi .= '</a>';
#     }
# // end_total_home_under_55
#     if (in_array($first->end_total_home_under_55, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 974 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Home Under 5.5 : ' . $first->end_total_home_under_55;
#         $isi .= '</a>';
#     }
# // end_total_home_over_65
#     if (in_array($first->end_total_home_over_65, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 975 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Home Over 6.5 : ' . $first->end_total_home_over_65;
#         $isi .= '</a>';
#     }
# // end_total_home_under_65
#     if (in_array($first->end_total_home_under_65, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 976 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Home Under 6.5 : ' . $first->end_total_home_under_65;
#         $isi .= '</a>';
#     }
# // end_total_away_over_15
#     if (in_array($first->end_total_away_over_15, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 930 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Away Over 1.5 : ' . $first->end_total_away_over_15;
#         $isi .= '</a>';
#     }
# // end_total_away_under_15
#     if (in_array($first->end_total_away_under_15, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 931 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Away Under 1.5 : ' . $first->end_total_away_under_15;
#         $isi .= '</a>';
#     }
# // end_total_away_over_25
#     if (in_array($first->end_total_away_over_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 934 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Away Over 2.5 : ' . $first->end_total_away_over_25;
#         $isi .= '</a>';
#     }
# // end_total_away_under_25
#     if (in_array($first->end_total_away_under_25, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 935 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Away Under 2.5 : ' . $first->end_total_away_under_25;
#         $isi .= '</a>';
#     }
# // end_total_away_over_35
#     if (in_array($first->end_total_away_over_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 928 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Away Over 3.5 : ' . $first->end_total_away_over_35;
#         $isi .= '</a>';
#     }
# // end_total_away_under_35
#     if (in_array($first->end_total_away_under_35, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 929 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Away Under 3.5 : ' . $first->end_total_away_under_35;
#         $isi .= '</a>';
#     }
# // end_total_away_over_45
#     if (in_array($first->end_total_away_over_45, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 932 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Away Over 4.5 : ' . $first->end_total_away_over_45;
#         $isi .= '</a>';
#     }
# // end_total_away_under_45
#     if (in_array($first->end_total_away_under_45, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 933 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Away Under 4.5 : ' . $first->end_total_away_under_45;
#         $isi .= '</a>';
#     }
# // end_total_away_over_55
#     if (in_array($first->end_total_away_over_55, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 936 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Away Over 5.5 : ' . $first->end_total_away_over_55;
#         $isi .= '</a>';
#     }
# // end_total_away_under_55
#     if (in_array($first->end_total_away_under_55, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 937 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Away Under 5.5 : ' . $first->end_total_away_under_55;
#         $isi .= '</a>';
#     }
# // end_total_away_over_65
#     if (in_array($first->end_total_away_over_65, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 938 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-success">';
#             $isi .= 'end Total - Away Over 6.5 : ' . $first->end_total_away_over_65;
#         $isi .= '</a>';
#     }
# // end_total_away_under_65
#     if (in_array($first->end_total_away_under_65, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 939 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge bg-danger">';
#             $isi .= 'end Total - Away Under 6.5 : ' . $first->end_total_away_under_65;
#         $isi .= '</a>';
#     }
# // end_exact_goals_number_0
#     if (in_array($first->end_exact_goals_number_0, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 301 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Exact Goals Number 0 : ' . $first->end_exact_goals_number_0;
#         $isi .= '</a>';
#     }
# // end_exact_goals_number_1
#     if (in_array($first->end_exact_goals_number_1, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 300 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Exact Goals Number 1 : ' . $first->end_exact_goals_number_1;
#         $isi .= '</a>';
#     }
# // end_exact_goals_number_2
#     if (in_array($first->end_exact_goals_number_2, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 297 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Exact Goals Number 2 : ' . $first->end_exact_goals_number_2;
#         $isi .= '</a>';
#     }
# // end_exact_goals_number_3
#     if (in_array($first->end_exact_goals_number_3, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 298 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Exact Goals Number 3 : ' . $first->end_exact_goals_number_3;
#         $isi .= '</a>';
#     }
# // end_exact_goals_number_4
#     if (in_array($first->end_exact_goals_number_4, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 299 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Exact Goals Number 4 : ' . $first->end_exact_goals_number_4;
#         $isi .= '</a>';
#     }
# // end_exact_goals_number_5
#     if (in_array($first->end_exact_goals_number_5, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 302 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Exact Goals Number 5 : ' . $first->end_exact_goals_number_5;
#         $isi .= '</a>';
#     }
# // end_exact_goals_number_6
#     if (in_array($first->end_exact_goals_number_6, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 303 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Exact Goals Number 6 : ' . $first->end_exact_goals_number_6;
#         $isi .= '</a>';
#     }
# // end_exact_goals_number_more_7
#     if (in_array($first->end_exact_goals_number_more_7, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 304 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Exact Goals Number more 7 : ' . $first->end_exact_goals_number_more_7;
#         $isi .= '</a>';
#     }
# // end_home_team_exact_goals_number_0
#     if (in_array($first->end_home_team_exact_goals_number_0, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 309 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Home Team Exact Goals Number 0 : ' . $first->end_home_team_exact_goals_number_0;
#         $isi .= '</a>';
#     }
# // end_home_team_exact_goals_number_1
#     if (in_array($first->end_home_team_exact_goals_number_1, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 308 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Home Team Exact Goals Number 1 : ' . $first->end_home_team_exact_goals_number_1;
#         $isi .= '</a>';
#     }
# // end_home_team_exact_goals_number_2
#     if (in_array($first->end_home_team_exact_goals_number_2, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 307 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Home Team Exact Goals Number 2 : ' . $first->end_home_team_exact_goals_number_2;
#         $isi .= '</a>';
#     }
# // end_home_team_exact_goals_number_more_3
#     if (in_array($first->end_home_team_exact_goals_number_more_3, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 310 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Home Team Exact Goals Number more 3 : ' . $first->end_home_team_exact_goals_number_more_3;
#         $isi .= '</a>';
#     }
# // end_away_team_exact_goals_number_0
#     if (in_array($first->end_away_team_exact_goals_number_0, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 313 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Away Team Exact Goals Number 0 : ' . $first->end_away_team_exact_goals_number_0;
#         $isi .= '</a>';
#     }
# // end_away_team_exact_goals_number_1
#     if (in_array($first->end_away_team_exact_goals_number_1, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 312 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Away Team Exact Goals Number 1 : ' . $first->end_away_team_exact_goals_number_1;
#         $isi .= '</a>';
#     }
# // end_away_team_exact_goals_number_2
#     if (in_array($first->end_away_team_exact_goals_number_2, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 311 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Away Team Exact Goals Number 2 : ' . $first->end_away_team_exact_goals_number_2;
#         $isi .= '</a>';
#     }
# // end_away_team_exact_goals_number_more_3
#     if (in_array($first->end_away_team_exact_goals_number_more_3, $special_odds) )
#     {
#         $route = route('Special_odds.league', ['leagueapi_id' => $first->leagueapi_id,'bet' => 314 ] );
#         $isi .= '<a ';
#             $isi .= 'href="'.$route.'" ';
#             $isi .= 'class="me-1 badge None">';
#             $isi .= 'end Away Team Exact Goals Number more 3 : ' . $first->end_away_team_exact_goals_number_more_3;
#         $isi .= '</a>';
#     }
