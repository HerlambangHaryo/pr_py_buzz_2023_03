# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 19 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($odd->pre_"+columnx_1+") && !is_null($odd->pre_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->pre_"+columnx_1+" + $odd->pre_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($odd->pre_asian_handicap_first_half_home_min_175) && !is_null($odd->pre_asian_handicap_first_half_away_min_175) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_min_175 + $odd->pre_asian_handicap_first_half_away_min_175) < 4 )
#         {
#             $asian_handicap_first_half_home_min_175 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_min_15) && !is_null($odd->pre_asian_handicap_first_half_away_min_15) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_min_15 + $odd->pre_asian_handicap_first_half_away_min_15) < 4 )
#         {
#             $asian_handicap_first_half_home_min_15 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_min_125) && !is_null($odd->pre_asian_handicap_first_half_away_min_125) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_min_125 + $odd->pre_asian_handicap_first_half_away_min_125) < 4 )
#         {
#             $asian_handicap_first_half_home_min_125 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_min_1) && !is_null($odd->pre_asian_handicap_first_half_away_min_1) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_min_1 + $odd->pre_asian_handicap_first_half_away_min_1) < 4 )
#         {
#             $asian_handicap_first_half_home_min_1 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_min_075) && !is_null($odd->pre_asian_handicap_first_half_away_min_075) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_min_075 + $odd->pre_asian_handicap_first_half_away_min_075) < 4 )
#         {
#             $asian_handicap_first_half_home_min_075 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_min_05) && !is_null($odd->pre_asian_handicap_first_half_away_min_05) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_min_05 + $odd->pre_asian_handicap_first_half_away_min_05) < 4 )
#         {
#             $asian_handicap_first_half_home_min_05 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_min_025) && !is_null($odd->pre_asian_handicap_first_half_away_min_025) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_min_025 + $odd->pre_asian_handicap_first_half_away_min_025) < 4 )
#         {
#             $asian_handicap_first_half_home_min_025 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_plus_0) && !is_null($odd->pre_asian_handicap_first_half_away_plus_0) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_plus_0 + $odd->pre_asian_handicap_first_half_away_plus_0) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_0 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_plus_025) && !is_null($odd->pre_asian_handicap_first_half_away_plus_025) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_plus_025 + $odd->pre_asian_handicap_first_half_away_plus_025) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_025 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_plus_05) && !is_null($odd->pre_asian_handicap_first_half_away_plus_05) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_plus_05 + $odd->pre_asian_handicap_first_half_away_plus_05) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_05 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_plus_075) && !is_null($odd->pre_asian_handicap_first_half_away_plus_075) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_plus_075 + $odd->pre_asian_handicap_first_half_away_plus_075) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_075 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_plus_1) && !is_null($odd->pre_asian_handicap_first_half_away_plus_1) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_plus_1 + $odd->pre_asian_handicap_first_half_away_plus_1) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_1 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_plus_125) && !is_null($odd->pre_asian_handicap_first_half_away_plus_125) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_plus_125 + $odd->pre_asian_handicap_first_half_away_plus_125) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_125 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_plus_15) && !is_null($odd->pre_asian_handicap_first_half_away_plus_15) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_plus_15 + $odd->pre_asian_handicap_first_half_away_plus_15) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_15 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_asian_handicap_first_half_home_plus_175) && !is_null($odd->pre_asian_handicap_first_half_away_plus_175) )
#     {
#         if( ($odd->pre_asian_handicap_first_half_home_plus_175 + $odd->pre_asian_handicap_first_half_away_plus_175) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_175 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 19 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($odd->end_"+columnx_1+") && !is_null($odd->end_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->end_"+columnx_1+" + $odd->end_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($odd->end_asian_handicap_first_half_home_min_175) && !is_null($odd->end_asian_handicap_first_half_away_min_175) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_min_175 + $odd->end_asian_handicap_first_half_away_min_175) < 4 )
#         {
#             $asian_handicap_first_half_home_min_175 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_min_15) && !is_null($odd->end_asian_handicap_first_half_away_min_15) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_min_15 + $odd->end_asian_handicap_first_half_away_min_15) < 4 )
#         {
#             $asian_handicap_first_half_home_min_15 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_min_125) && !is_null($odd->end_asian_handicap_first_half_away_min_125) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_min_125 + $odd->end_asian_handicap_first_half_away_min_125) < 4 )
#         {
#             $asian_handicap_first_half_home_min_125 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_min_1) && !is_null($odd->end_asian_handicap_first_half_away_min_1) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_min_1 + $odd->end_asian_handicap_first_half_away_min_1) < 4 )
#         {
#             $asian_handicap_first_half_home_min_1 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_min_075) && !is_null($odd->end_asian_handicap_first_half_away_min_075) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_min_075 + $odd->end_asian_handicap_first_half_away_min_075) < 4 )
#         {
#             $asian_handicap_first_half_home_min_075 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_min_05) && !is_null($odd->end_asian_handicap_first_half_away_min_05) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_min_05 + $odd->end_asian_handicap_first_half_away_min_05) < 4 )
#         {
#             $asian_handicap_first_half_home_min_05 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_min_025) && !is_null($odd->end_asian_handicap_first_half_away_min_025) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_min_025 + $odd->end_asian_handicap_first_half_away_min_025) < 4 )
#         {
#             $asian_handicap_first_half_home_min_025 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_plus_0) && !is_null($odd->end_asian_handicap_first_half_away_plus_0) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_plus_0 + $odd->end_asian_handicap_first_half_away_plus_0) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_0 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_plus_025) && !is_null($odd->end_asian_handicap_first_half_away_plus_025) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_plus_025 + $odd->end_asian_handicap_first_half_away_plus_025) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_025 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_plus_05) && !is_null($odd->end_asian_handicap_first_half_away_plus_05) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_plus_05 + $odd->end_asian_handicap_first_half_away_plus_05) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_05 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_plus_075) && !is_null($odd->end_asian_handicap_first_half_away_plus_075) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_plus_075 + $odd->end_asian_handicap_first_half_away_plus_075) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_075 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_plus_1) && !is_null($odd->end_asian_handicap_first_half_away_plus_1) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_plus_1 + $odd->end_asian_handicap_first_half_away_plus_1) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_1 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_plus_125) && !is_null($odd->end_asian_handicap_first_half_away_plus_125) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_plus_125 + $odd->end_asian_handicap_first_half_away_plus_125) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_125 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_plus_15) && !is_null($odd->end_asian_handicap_first_half_away_plus_15) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_plus_15 + $odd->end_asian_handicap_first_half_away_plus_15) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_15 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_asian_handicap_first_half_home_plus_175) && !is_null($odd->end_asian_handicap_first_half_away_plus_175) )
#     {
#         if( ($odd->end_asian_handicap_first_half_home_plus_175 + $odd->end_asian_handicap_first_half_away_plus_175) < 4 )
#         {
#             $asian_handicap_first_half_home_plus_175 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 19 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "$"+columnx_1+" = 0;"
        print(word, flush=True) 
        # ----------------------------------------------  
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
# $asian_handicap_first_half_home_min_175 = 0;
# $asian_handicap_first_half_home_min_15 = 0;
# $asian_handicap_first_half_home_min_125 = 0;
# $asian_handicap_first_half_home_min_1 = 0;
# $asian_handicap_first_half_home_min_075 = 0;
# $asian_handicap_first_half_home_min_05 = 0;
# $asian_handicap_first_half_home_min_025 = 0;
# $asian_handicap_first_half_home_plus_0 = 0;
# $asian_handicap_first_half_home_plus_025 = 0;
# $asian_handicap_first_half_home_plus_05 = 0;
# $asian_handicap_first_half_home_plus_075 = 0;
# $asian_handicap_first_half_home_plus_1 = 0;
# $asian_handicap_first_half_home_plus_125 = 0;
# $asian_handicap_first_half_home_plus_15 = 0;
# $asian_handicap_first_half_home_plus_175 = 0;
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 19 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0  
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "@if($"+columnx_1+" == 1)"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        <div class="card">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-header">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                ' + bet_1 + ' #' + str(bet_id_1)
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-body text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        Home ' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        ' + value_2.replace('Under ', '') 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' + $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' + $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-footer text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' - $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_1+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' - $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_2+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "@endif"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ----------------------------------------------
# Out:
# @if($asian_handicap_first_half_home_min_175 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_175 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_175 }}
#                     </div>
#                     <div class="col-4">
#                         Away -1.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_min_175 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_min_175 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_175 + $odd->pre_asian_handicap_first_half_away_min_175 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_175 + $odd->end_asian_handicap_first_half_away_min_175 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_min_175 - $odd->pre_asian_handicap_first_half_home_min_175 }}
#                         @if($stats->asian_handicap_first_half_home_min_175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_min_175 - $odd->pre_asian_handicap_first_half_away_min_175 }}
#                         @if($stats->asian_handicap_first_half_away_min_175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_min_15 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_15 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_15 }}
#                     </div>
#                     <div class="col-4">
#                         Away -1.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_min_15 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_min_15 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_15 + $odd->pre_asian_handicap_first_half_away_min_15 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_15 + $odd->end_asian_handicap_first_half_away_min_15 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_min_15 - $odd->pre_asian_handicap_first_half_home_min_15 }}
#                         @if($stats->asian_handicap_first_half_home_min_15 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_min_15 - $odd->pre_asian_handicap_first_half_away_min_15 }}
#                         @if($stats->asian_handicap_first_half_away_min_15 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_min_125 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_125 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_125 }}
#                     </div>
#                     <div class="col-4">
#                         Away -1.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_min_125 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_min_125 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_125 + $odd->pre_asian_handicap_first_half_away_min_125 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_125 + $odd->end_asian_handicap_first_half_away_min_125 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_min_125 - $odd->pre_asian_handicap_first_half_home_min_125 }}
#                         @if($stats->asian_handicap_first_half_home_min_125 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_min_125 - $odd->pre_asian_handicap_first_half_away_min_125 }}
#                         @if($stats->asian_handicap_first_half_away_min_125 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_min_1 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_1 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_1 }}
#                     </div>
#                     <div class="col-4">
#                         Away -1
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_min_1 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_min_1 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_1 + $odd->pre_asian_handicap_first_half_away_min_1 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_1 + $odd->end_asian_handicap_first_half_away_min_1 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_min_1 - $odd->pre_asian_handicap_first_half_home_min_1 }}
#                         @if($stats->asian_handicap_first_half_home_min_1 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_min_1 - $odd->pre_asian_handicap_first_half_away_min_1 }}
#                         @if($stats->asian_handicap_first_half_away_min_1 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_min_075 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_075 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_075 }}
#                     </div>
#                     <div class="col-4">
#                         Away -0.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_min_075 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_min_075 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_075 + $odd->pre_asian_handicap_first_half_away_min_075 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_075 + $odd->end_asian_handicap_first_half_away_min_075 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_min_075 - $odd->pre_asian_handicap_first_half_home_min_075 }}
#                         @if($stats->asian_handicap_first_half_home_min_075 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_min_075 - $odd->pre_asian_handicap_first_half_away_min_075 }}
#                         @if($stats->asian_handicap_first_half_away_min_075 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_min_05 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_05 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_05 }}
#                     </div>
#                     <div class="col-4">
#                         Away -0.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_min_05 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_min_05 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_05 + $odd->pre_asian_handicap_first_half_away_min_05 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_05 + $odd->end_asian_handicap_first_half_away_min_05 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_min_05 - $odd->pre_asian_handicap_first_half_home_min_05 }}
#                         @if($stats->asian_handicap_first_half_home_min_05 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_min_05 - $odd->pre_asian_handicap_first_half_away_min_05 }}
#                         @if($stats->asian_handicap_first_half_away_min_05 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_min_025 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_025 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_025 }}
#                     </div>
#                     <div class="col-4">
#                         Away -0.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_min_025 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_min_025 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_min_025 + $odd->pre_asian_handicap_first_half_away_min_025 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_min_025 + $odd->end_asian_handicap_first_half_away_min_025 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_min_025 - $odd->pre_asian_handicap_first_half_home_min_025 }}
#                         @if($stats->asian_handicap_first_half_home_min_025 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_min_025 - $odd->pre_asian_handicap_first_half_away_min_025 }}
#                         @if($stats->asian_handicap_first_half_away_min_025 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_plus_0 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_0 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_0 }}
#                     </div>
#                     <div class="col-4">
#                         Away +0
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_plus_0 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_plus_0 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_0 + $odd->pre_asian_handicap_first_half_away_plus_0 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_0 + $odd->end_asian_handicap_first_half_away_plus_0 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_plus_0 - $odd->pre_asian_handicap_first_half_home_plus_0 }}
#                         @if($stats->asian_handicap_first_half_home_plus_0 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_plus_0 - $odd->pre_asian_handicap_first_half_away_plus_0 }}
#                         @if($stats->asian_handicap_first_half_away_plus_0 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_plus_025 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_025 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_025 }}
#                     </div>
#                     <div class="col-4">
#                         Away +0.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_plus_025 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_plus_025 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_025 + $odd->pre_asian_handicap_first_half_away_plus_025 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_025 + $odd->end_asian_handicap_first_half_away_plus_025 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_plus_025 - $odd->pre_asian_handicap_first_half_home_plus_025 }}
#                         @if($stats->asian_handicap_first_half_home_plus_025 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_plus_025 - $odd->pre_asian_handicap_first_half_away_plus_025 }}
#                         @if($stats->asian_handicap_first_half_away_plus_025 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_plus_05 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_05 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_05 }}
#                     </div>
#                     <div class="col-4">
#                         Away +0.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_plus_05 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_plus_05 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_05 + $odd->pre_asian_handicap_first_half_away_plus_05 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_05 + $odd->end_asian_handicap_first_half_away_plus_05 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_plus_05 - $odd->pre_asian_handicap_first_half_home_plus_05 }}
#                         @if($stats->asian_handicap_first_half_home_plus_05 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_plus_05 - $odd->pre_asian_handicap_first_half_away_plus_05 }}
#                         @if($stats->asian_handicap_first_half_away_plus_05 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_plus_075 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_075 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_075 }}
#                     </div>
#                     <div class="col-4">
#                         Away +0.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_plus_075 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_plus_075 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_075 + $odd->pre_asian_handicap_first_half_away_plus_075 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_075 + $odd->end_asian_handicap_first_half_away_plus_075 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_plus_075 - $odd->pre_asian_handicap_first_half_home_plus_075 }}
#                         @if($stats->asian_handicap_first_half_home_plus_075 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_plus_075 - $odd->pre_asian_handicap_first_half_away_plus_075 }}
#                         @if($stats->asian_handicap_first_half_away_plus_075 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_plus_1 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_1 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_1 }}
#                     </div>
#                     <div class="col-4">
#                         Away +1
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_plus_1 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_plus_1 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_1 + $odd->pre_asian_handicap_first_half_away_plus_1 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_1 + $odd->end_asian_handicap_first_half_away_plus_1 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_plus_1 - $odd->pre_asian_handicap_first_half_home_plus_1 }}
#                         @if($stats->asian_handicap_first_half_home_plus_1 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_plus_1 - $odd->pre_asian_handicap_first_half_away_plus_1 }}
#                         @if($stats->asian_handicap_first_half_away_plus_1 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_plus_125 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_125 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_125 }}
#                     </div>
#                     <div class="col-4">
#                         Away +1.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_plus_125 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_plus_125 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_125 + $odd->pre_asian_handicap_first_half_away_plus_125 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_125 + $odd->end_asian_handicap_first_half_away_plus_125 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_plus_125 - $odd->pre_asian_handicap_first_half_home_plus_125 }}
#                         @if($stats->asian_handicap_first_half_home_plus_125 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_plus_125 - $odd->pre_asian_handicap_first_half_away_plus_125 }}
#                         @if($stats->asian_handicap_first_half_away_plus_125 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_plus_15 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_15 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_15 }}
#                     </div>
#                     <div class="col-4">
#                         Away +1.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_plus_15 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_plus_15 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_15 + $odd->pre_asian_handicap_first_half_away_plus_15 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_15 + $odd->end_asian_handicap_first_half_away_plus_15 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_plus_15 - $odd->pre_asian_handicap_first_half_home_plus_15 }}
#                         @if($stats->asian_handicap_first_half_home_plus_15 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_plus_15 - $odd->pre_asian_handicap_first_half_away_plus_15 }}
#                         @if($stats->asian_handicap_first_half_away_plus_15 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_first_half_home_plus_175 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap First Half #19
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_175 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_175 }}
#                     </div>
#                     <div class="col-4">
#                         Away +1.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_away_plus_175 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_away_plus_175 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_first_half_home_plus_175 + $odd->pre_asian_handicap_first_half_away_plus_175 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_first_half_home_plus_175 + $odd->end_asian_handicap_first_half_away_plus_175 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_home_plus_175 - $odd->pre_asian_handicap_first_half_home_plus_175 }}
#                         @if($stats->asian_handicap_first_half_home_plus_175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_first_half_away_plus_175 - $odd->pre_asian_handicap_first_half_away_plus_175 }}
#                         @if($stats->asian_handicap_first_half_away_plus_175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
