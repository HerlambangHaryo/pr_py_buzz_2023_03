# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 42 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------
word = '<div class="col-6">'
print(word, flush=True)  
# ------------------------------------------------------
word = '    <div class="card">'
print(word, flush=True)  
# ------------------------------------------------------
word = '        <div class="card-header">'
print(word, flush=True)  
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # --------------------------------------------------    
# ------------------------------------------------------
word = '            ' + bet + ' #' + str(bet_id)
print(word, flush=True)  
# ------------------------------------------------------
word = '        </div>'
print(word, flush=True)  
# ------------------------------------------------------
word = '        <div class="card-body text-center">'
print(word, flush=True)     
# ------------------------------------------------------
word = '            <div class="row">'
print(word, flush=True)   
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # --------------------------------------------------  
    # --------------------------------------------------
    word = '                <div class="col-1">' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    ' + value
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    <br/>' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    {{ $odd->pre_'+columnx+' }}' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    <br/>' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    {{ $odd->end_'+columnx+' }}' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                </div>' 
    print(word, flush=True)     
# ------------------------------------------------------
# ------------------------------------------------------
word = '                <div class="col-1">' 
print(word, flush=True)     
# ------------------------------------------------------
word = '                    <br/>' 
print(word, flush=True)     
# ------------------------------------------------------
word = '                    {{ '  
# ------------------------------------------------------
counter = 0 
for x in result2: 
    # -------------------------------------------------- 
    counter += 1 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # -------------------------------------------------- 
    word += '$odd->pre_'+columnx  
    if(total_rows != counter):
        word += ' + '  
    # -------------------------------------------------- 
# ------------------------------------------------------
word += ' }}' 
print(word, flush=True)    
# ------------------------------------------------------
word = '                    <br/>' 
print(word, flush=True)     
# ------------------------------------------------------
word = '                    {{ '  
# ------------------------------------------------------
counter = 0 
for x in result2: 
    # -------------------------------------------------- 
    counter += 1 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # -------------------------------------------------- 
    word += '$odd->end_'+columnx  
    if(total_rows != counter):
        word += ' + '  
    # -------------------------------------------------- 
# ------------------------------------------------------
word += ' }}' 
print(word, flush=True)    
# ------------------------------------------------------
word = '                </div>'
print(word, flush=True)  
# ------------------------------------------------------
word = '            </div>'
print(word, flush=True)  
# ------------------------------------------------------
word = '        </div>'
print(word, flush=True)  
# ------------------------------------------------------
word = '        <div class="card-footer text-center">'
print(word, flush=True)  
# ------------------------------------------------------
word = '            <div class="row">'
print(word, flush=True)     
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # --------------------------------------------------  
    # --------------------------------------------------
    word = '                <div class="col-1">' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    {{ $odd->end_'+columnx+' - $odd->pre_'+columnx+' }}' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    @if($stats->'+columnx+' == 1)' 
    print(word, flush=True)      
    # --------------------------------------------------
    word = '                        <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
    print(word, flush=True)      
    # --------------------------------------------------
    word = '                    @endif' 
    print(word, flush=True)      
    # --------------------------------------------------
    word = '                </div>' 
    print(word, flush=True)     
# ------------------------------------------------------
# ------------------------------------------------------
word = '            </div>'
print(word, flush=True)  
# ------------------------------------------------------
word = '        </div>'
print(word, flush=True)  
# ------------------------------------------------------   
word = '    </div>'
print(word, flush=True)  
# ------------------------------------------------------   
word = '</div>'
print(word, flush=True)  
# ------------------------------------------------------
# Out:
# <div class="col-6">
#     <div class="card">
#         <div class="card-header">
#             Second Half Exact Goals Number #42
#         </div>
#         <div class="card-body text-center">
#             <div class="row">
#                 <div class="col-1">
#                     0
#                     <br/>
#                     {{ $odd->pre_second_half_exact_goals_number_0 }}
#                     <br/>
#                     {{ $odd->end_second_half_exact_goals_number_0 }}
#                 </div>
#                 <div class="col-1">
#                     1
#                     <br/>
#                     {{ $odd->pre_second_half_exact_goals_number_1 }}
#                     <br/>
#                     {{ $odd->end_second_half_exact_goals_number_1 }}
#                 </div>
#                 <div class="col-1">
#                     2
#                     <br/>
#                     {{ $odd->pre_second_half_exact_goals_number_2 }}
#                     <br/>
# ...
