# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 56 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($odd->pre_"+columnx_1+") && !is_null($odd->pre_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->pre_"+columnx_1+" + $odd->pre_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($odd->pre_corners_asian_handicap_home_min_65) && !is_null($odd->pre_corners_asian_handicap_away_min_65) )
#     {
#         if( ($odd->pre_corners_asian_handicap_home_min_65 + $odd->pre_corners_asian_handicap_away_min_65) < 4 )
#         {
#             $corners_asian_handicap_home_min_65 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_asian_handicap_home_min_6) && !is_null($odd->pre_corners_asian_handicap_away_min_6) )
#     {
#         if( ($odd->pre_corners_asian_handicap_home_min_6 + $odd->pre_corners_asian_handicap_away_min_6) < 4 )
#         {
#             $corners_asian_handicap_home_min_6 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_asian_handicap_home_min_55) && !is_null($odd->pre_corners_asian_handicap_away_min_55) )
#     {
#         if( ($odd->pre_corners_asian_handicap_home_min_55 + $odd->pre_corners_asian_handicap_away_min_55) < 4 )
#         {
#             $corners_asian_handicap_home_min_55 = 1;
#         }
# ...

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 56 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($odd->end_"+columnx_1+") && !is_null($odd->end_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->end_"+columnx_1+" + $odd->end_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($odd->end_corners_asian_handicap_home_min_65) && !is_null($odd->end_corners_asian_handicap_away_min_65) )
#     {
#         if( ($odd->end_corners_asian_handicap_home_min_65 + $odd->end_corners_asian_handicap_away_min_65) < 4 )
#         {
#             $corners_asian_handicap_home_min_65 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_asian_handicap_home_min_6) && !is_null($odd->end_corners_asian_handicap_away_min_6) )
#     {
#         if( ($odd->end_corners_asian_handicap_home_min_6 + $odd->end_corners_asian_handicap_away_min_6) < 4 )
#         {
#             $corners_asian_handicap_home_min_6 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_asian_handicap_home_min_55) && !is_null($odd->end_corners_asian_handicap_away_min_55) )
#     {
#         if( ($odd->end_corners_asian_handicap_home_min_55 + $odd->end_corners_asian_handicap_away_min_55) < 4 )
#         {
#             $corners_asian_handicap_home_min_55 = 1;
#         }
# ...

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 56 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "$"+columnx_1+" = 0;"
        print(word, flush=True) 
        # ----------------------------------------------  
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
# $corners_asian_handicap_home_min_65 = 0;
# $corners_asian_handicap_home_min_6 = 0;
# $corners_asian_handicap_home_min_55 = 0;
# $corners_asian_handicap_home_min_5 = 0;
# $corners_asian_handicap_home_min_45 = 0;
# $corners_asian_handicap_home_min_4 = 0;
# $corners_asian_handicap_home_min_35 = 0;
# $corners_asian_handicap_home_min_3 = 0;
# $corners_asian_handicap_home_min_25 = 0;
# $corners_asian_handicap_home_min_2 = 0;
# $corners_asian_handicap_home_min_15 = 0;
# $corners_asian_handicap_home_min_1 = 0;
# $corners_asian_handicap_away_min_1 = 0;
# $corners_asian_handicap_home_plus_0 = 0;
# $corners_asian_handicap_home_plus_05 = 0;
# $corners_asian_handicap_home_plus_1 = 0;
# $corners_asian_handicap_home_plus_15 = 0;
# $corners_asian_handicap_home_plus_2 = 0;
# $corners_asian_handicap_home_plus_25 = 0;
# $corners_asian_handicap_home_plus_3 = 0;
# $corners_asian_handicap_home_plus_35 = 0;
# $corners_asian_handicap_home_plus_4 = 0;
# $corners_asian_handicap_home_plus_45 = 0;
# ...

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 56 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0  
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "@if($"+columnx_1+" == 1)"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        <div class="card">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-header">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                ' + bet_1 + ' #' + str(bet_id_1)
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-body text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        Home ' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        ' + value_2.replace('Under ', '') 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' + $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' + $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-footer text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' - $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_1+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' - $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_2+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "@endif"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ----------------------------------------------
# Out:
# @if($corners_asian_handicap_home_min_65 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Asian Handicap  #56
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_asian_handicap_home_min_65 }}
#                         <br/>
#                         {{ $odd->end_corners_asian_handicap_home_min_65 }}
#                     </div>
#                     <div class="col-4">
#                         Away -6.5
#                         <br/>
#                         {{ $odd->pre_corners_asian_handicap_away_min_65 }}
#                         <br/>
#                         {{ $odd->end_corners_asian_handicap_away_min_65 }}
#                     </div>
#                     <div class="col-3">
# ...
