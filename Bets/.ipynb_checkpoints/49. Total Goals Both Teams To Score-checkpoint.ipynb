# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 49 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------
word = '<div class="col-6">'
print(word, flush=True)  
# ------------------------------------------------------
word = '    <div class="card">'
print(word, flush=True)  
# ------------------------------------------------------
word = '        <div class="card-header">'
print(word, flush=True)  
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # --------------------------------------------------    
# ------------------------------------------------------
word = '            ' + bet + ' #' + str(bet_id)
print(word, flush=True)  
# ------------------------------------------------------
word = '        </div>'
print(word, flush=True)  
# ------------------------------------------------------
word = '        <div class="card-body text-center">'
print(word, flush=True)     
# ------------------------------------------------------
word = '            <div class="row">'
print(word, flush=True)   
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # --------------------------------------------------  
    # --------------------------------------------------
    word = '                <div class="col-2">' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    ' + value
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    <br/>' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    {{ $odd->pre_'+columnx+' }}' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    <br/>' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    {{ $odd->end_'+columnx+' }}' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                </div>' 
    print(word, flush=True)     
# ------------------------------------------------------
# ------------------------------------------------------
word = '                <div class="col-2">' 
print(word, flush=True)     
# ------------------------------------------------------
word = '                    <br/>' 
print(word, flush=True)     
# ------------------------------------------------------
word = '                    {{ '  
# ------------------------------------------------------
counter = 0 
for x in result2: 
    # -------------------------------------------------- 
    counter += 1 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # -------------------------------------------------- 
    word += '$odd->pre_'+columnx  
    if(total_rows != counter):
        word += ' + '  
    # -------------------------------------------------- 
# ------------------------------------------------------
word += ' }}' 
print(word, flush=True)    
# ------------------------------------------------------
word = '                    <br/>' 
print(word, flush=True)     
# ------------------------------------------------------
word = '                    {{ '  
# ------------------------------------------------------
counter = 0 
for x in result2: 
    # -------------------------------------------------- 
    counter += 1 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # -------------------------------------------------- 
    word += '$odd->end_'+columnx  
    if(total_rows != counter):
        word += ' + '  
    # -------------------------------------------------- 
# ------------------------------------------------------
word += ' }}' 
print(word, flush=True)    
# ------------------------------------------------------
word = '                </div>'
print(word, flush=True)  
# ------------------------------------------------------
word = '            </div>'
print(word, flush=True)  
# ------------------------------------------------------
word = '        </div>'
print(word, flush=True)  
# ------------------------------------------------------
word = '        <div class="card-footer text-center">'
print(word, flush=True)  
# ------------------------------------------------------
word = '            <div class="row">'
print(word, flush=True)     
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    bet = str(x[1])
    value = str(x[2])
    columny = str(x[3])
    columnx = str(x[4])
    # --------------------------------------------------  
    # --------------------------------------------------
    word = '                <div class="col-2">' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    {{ $odd->end_'+columnx+' - $odd->pre_'+columnx+' }}' 
    print(word, flush=True)     
    # --------------------------------------------------
    word = '                    @if($stats->'+columnx+' == 1)' 
    print(word, flush=True)      
    # --------------------------------------------------
    word = '                        <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
    print(word, flush=True)      
    # --------------------------------------------------
    word = '                    @endif' 
    print(word, flush=True)      
    # --------------------------------------------------
    word = '                </div>' 
    print(word, flush=True)     
# ------------------------------------------------------
# ------------------------------------------------------
word = '            </div>'
print(word, flush=True)  
# ------------------------------------------------------
word = '        </div>'
print(word, flush=True)  
# ------------------------------------------------------   
word = '    </div>'
print(word, flush=True)  
# ------------------------------------------------------   
word = '</div>'
print(word, flush=True)  
# ------------------------------------------------------
# Out:
# <div class="col-6">
#     <div class="card">
#         <div class="card-header">
#             Total Goals/Both Teams To Score #49
#         </div>
#         <div class="card-body text-center">
#             <div class="row">
#                 <div class="col-2">
#                     o/yes 2.5
#                     <br/>
#                     {{ $odd->pre_total_goals_both_teams_to_score_over_yes_25 }}
#                     <br/>
#                     {{ $odd->end_total_goals_both_teams_to_score_over_yes_25 }}
#                 </div>
#                 <div class="col-2">
#                     o/no 2.5
#                     <br/>
#                     {{ $odd->pre_total_goals_both_teams_to_score_over_no_25 }}
#                     <br/>
#                     {{ $odd->end_total_goals_both_teams_to_score_over_no_25 }}
#                 </div>
#                 <div class="col-2">
#                     u/yes 2.5
#                     <br/>
#                     {{ $odd->pre_total_goals_both_teams_to_score_under_yes_25 }}
#                     <br/>
#                     {{ $odd->end_total_goals_both_teams_to_score_under_yes_25 }}
#                 </div>
#                 <div class="col-2">
#                     u/no 2.5
#                     <br/>
#                     {{ $odd->pre_total_goals_both_teams_to_score_under_no_25 }}
#                     <br/>
#                     {{ $odd->end_total_goals_both_teams_to_score_under_no_25 }}
#                 </div>
#                 <div class="col-2">
#                     <br/>
#                     {{ $odd->pre_total_goals_both_teams_to_score_over_yes_25 + $odd->pre_total_goals_both_teams_to_score_over_no_25 + $odd->pre_total_goals_both_teams_to_score_under_yes_25 + $odd->pre_total_goals_both_teams_to_score_under_no_25 }}
#                     <br/>
#                     {{ $odd->end_total_goals_both_teams_to_score_over_yes_25 + $odd->end_total_goals_both_teams_to_score_over_no_25 + $odd->end_total_goals_both_teams_to_score_under_yes_25 + $odd->end_total_goals_both_teams_to_score_under_no_25 }}
#                 </div>
#             </div>
#         </div>
#         <div class="card-footer text-center">
#             <div class="row">
#                 <div class="col-2">
#                     {{ $odd->end_total_goals_both_teams_to_score_over_yes_25 - $odd->pre_total_goals_both_teams_to_score_over_yes_25 }}
#                     @if($stats->total_goals_both_teams_to_score_over_yes_25 == 1)
#                         <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                     @endif
#                 </div>
#                 <div class="col-2">
#                     {{ $odd->end_total_goals_both_teams_to_score_over_no_25 - $odd->pre_total_goals_both_teams_to_score_over_no_25 }}
#                     @if($stats->total_goals_both_teams_to_score_over_no_25 == 1)
#                         <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                     @endif
#                 </div>
#                 <div class="col-2">
#                     {{ $odd->end_total_goals_both_teams_to_score_under_yes_25 - $odd->pre_total_goals_both_teams_to_score_under_yes_25 }}
#                     @if($stats->total_goals_both_teams_to_score_under_yes_25 == 1)
#                         <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                     @endif
#                 </div>
#                 <div class="col-2">
#                     {{ $odd->end_total_goals_both_teams_to_score_under_no_25 - $odd->pre_total_goals_both_teams_to_score_under_no_25 }}
#                     @if($stats->total_goals_both_teams_to_score_under_no_25 == 1)
#                         <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                     @endif
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
