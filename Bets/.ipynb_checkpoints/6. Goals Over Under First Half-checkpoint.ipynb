# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 5 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($odd->pre_"+columnx_1+") && !is_null($odd->pre_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->pre_"+columnx_1+" + $odd->pre_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($row->pre_goals_overunder_over_05) && !is_null($odd->pre_goals_overunder_under_05) )
#     {
#         if( ($odd->pre_goals_overunder_over_05 + $odd->pre_goals_overunder_under_05) < 4 )
#         {
#             $goals_overunder_over_05 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_075) && !is_null($odd->pre_goals_overunder_under_075) )
#     {
#         if( ($odd->pre_goals_overunder_over_075 + $odd->pre_goals_overunder_under_075) < 4 )
#         {
#             $goals_overunder_over_075 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_10) && !is_null($odd->pre_goals_overunder_under_10) )
#     {
#         if( ($odd->pre_goals_overunder_over_10 + $odd->pre_goals_overunder_under_10) < 4 )
#         {
#             $goals_overunder_over_10 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_125) && !is_null($odd->pre_goals_overunder_under_125) )
#     {
#         if( ($odd->pre_goals_overunder_over_125 + $odd->pre_goals_overunder_under_125) < 4 )
#         {
#             $goals_overunder_over_125 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_15) && !is_null($odd->pre_goals_overunder_under_15) )
#     {
#         if( ($odd->pre_goals_overunder_over_15 + $odd->pre_goals_overunder_under_15) < 4 )
#         {
#             $goals_overunder_over_15 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_175) && !is_null($odd->pre_goals_overunder_under_175) )
#     {
#         if( ($odd->pre_goals_overunder_over_175 + $odd->pre_goals_overunder_under_175) < 4 )
#         {
#             $goals_overunder_over_175 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_20) && !is_null($odd->pre_goals_overunder_under_20) )
#     {
#         if( ($odd->pre_goals_overunder_over_20 + $odd->pre_goals_overunder_under_20) < 4 )
#         {
#             $goals_overunder_over_20 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_225) && !is_null($odd->pre_goals_overunder_under_225) )
#     {
#         if( ($odd->pre_goals_overunder_over_225 + $odd->pre_goals_overunder_under_225) < 4 )
#         {
#             $goals_overunder_over_225 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_25) && !is_null($odd->pre_goals_overunder_under_25) )
#     {
#         if( ($odd->pre_goals_overunder_over_25 + $odd->pre_goals_overunder_under_25) < 4 )
#         {
#             $goals_overunder_over_25 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_275) && !is_null($odd->pre_goals_overunder_under_275) )
#     {
#         if( ($odd->pre_goals_overunder_over_275 + $odd->pre_goals_overunder_under_275) < 4 )
#         {
#             $goals_overunder_over_275 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_30) && !is_null($odd->pre_goals_overunder_under_30) )
#     {
#         if( ($odd->pre_goals_overunder_over_30 + $odd->pre_goals_overunder_under_30) < 4 )
#         {
#             $goals_overunder_over_30 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_325) && !is_null($odd->pre_goals_overunder_under_325) )
#     {
#         if( ($odd->pre_goals_overunder_over_325 + $odd->pre_goals_overunder_under_325) < 4 )
#         {
#             $goals_overunder_over_325 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_35) && !is_null($odd->pre_goals_overunder_under_35) )
#     {
#         if( ($odd->pre_goals_overunder_over_35 + $odd->pre_goals_overunder_under_35) < 4 )
#         {
#             $goals_overunder_over_35 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_375) && !is_null($odd->pre_goals_overunder_under_375) )
#     {
#         if( ($odd->pre_goals_overunder_over_375 + $odd->pre_goals_overunder_under_375) < 4 )
#         {
#             $goals_overunder_over_375 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_40) && !is_null($odd->pre_goals_overunder_under_40) )
#     {
#         if( ($odd->pre_goals_overunder_over_40 + $odd->pre_goals_overunder_under_40) < 4 )
#         {
#             $goals_overunder_over_40 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_425) && !is_null($odd->pre_goals_overunder_under_425) )
#     {
#         if( ($odd->pre_goals_overunder_over_425 + $odd->pre_goals_overunder_under_425) < 4 )
#         {
#             $goals_overunder_over_425 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_45) && !is_null($odd->pre_goals_overunder_under_45) )
#     {
#         if( ($odd->pre_goals_overunder_over_45 + $odd->pre_goals_overunder_under_45) < 4 )
#         {
#             $goals_overunder_over_45 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_475) && !is_null($odd->pre_goals_overunder_under_475) )
#     {
#         if( ($odd->pre_goals_overunder_over_475 + $odd->pre_goals_overunder_under_475) < 4 )
#         {
#             $goals_overunder_over_475 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_50) && !is_null($odd->pre_goals_overunder_under_50) )
#     {
#         if( ($odd->pre_goals_overunder_over_50 + $odd->pre_goals_overunder_under_50) < 4 )
#         {
#             $goals_overunder_over_50 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_525) && !is_null($odd->pre_goals_overunder_under_525) )
#     {
#         if( ($odd->pre_goals_overunder_over_525 + $odd->pre_goals_overunder_under_525) < 4 )
#         {
#             $goals_overunder_over_525 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_55) && !is_null($odd->pre_goals_overunder_under_55) )
#     {
#         if( ($odd->pre_goals_overunder_over_55 + $odd->pre_goals_overunder_under_55) < 4 )
#         {
#             $goals_overunder_over_55 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_575) && !is_null($odd->pre_goals_overunder_under_575) )
#     {
#         if( ($odd->pre_goals_overunder_over_575 + $odd->pre_goals_overunder_under_575) < 4 )
#         {
#             $goals_overunder_over_575 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_60) && !is_null($odd->pre_goals_overunder_under_60) )
#     {
#         if( ($odd->pre_goals_overunder_over_60 + $odd->pre_goals_overunder_under_60) < 4 )
#         {
#             $goals_overunder_over_60 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_625) && !is_null($odd->pre_goals_overunder_under_625) )
#     {
#         if( ($odd->pre_goals_overunder_over_625 + $odd->pre_goals_overunder_under_625) < 4 )
#         {
#             $goals_overunder_over_625 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_65) && !is_null($odd->pre_goals_overunder_under_65) )
#     {
#         if( ($odd->pre_goals_overunder_over_65 + $odd->pre_goals_overunder_under_65) < 4 )
#         {
#             $goals_overunder_over_65 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_675) && !is_null($odd->pre_goals_overunder_under_675) )
#     {
#         if( ($odd->pre_goals_overunder_over_675 + $odd->pre_goals_overunder_under_675) < 4 )
#         {
#             $goals_overunder_over_675 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_70) && !is_null($odd->pre_goals_overunder_under_70) )
#     {
#         if( ($odd->pre_goals_overunder_over_70 + $odd->pre_goals_overunder_under_70) < 4 )
#         {
#             $goals_overunder_over_70 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_75) && !is_null($odd->pre_goals_overunder_under_75) )
#     {
#         if( ($odd->pre_goals_overunder_over_75 + $odd->pre_goals_overunder_under_75) < 4 )
#         {
#             $goals_overunder_over_75 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_85) && !is_null($odd->pre_goals_overunder_under_85) )
#     {
#         if( ($odd->pre_goals_overunder_over_85 + $odd->pre_goals_overunder_under_85) < 4 )
#         {
#             $goals_overunder_over_85 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_goals_overunder_over_95) && !is_null($odd->pre_goals_overunder_under_95) )
#     {
#         if( ($odd->pre_goals_overunder_over_95 + $odd->pre_goals_overunder_under_95) < 4 )
#         {
#             $goals_overunder_over_95 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 5 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($row->end_"+columnx_1+") && !is_null($odd->end_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->end_"+columnx_1+" + $odd->end_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($row->end_goals_overunder_over_05) && !is_null($odd->end_goals_overunder_under_05) )
#     {
#         if( ($odd->end_goals_overunder_over_05 + $odd->end_goals_overunder_under_05) < 4 )
#         {
#             $goals_overunder_over_05 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_075) && !is_null($odd->end_goals_overunder_under_075) )
#     {
#         if( ($odd->end_goals_overunder_over_075 + $odd->end_goals_overunder_under_075) < 4 )
#         {
#             $goals_overunder_over_075 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_10) && !is_null($odd->end_goals_overunder_under_10) )
#     {
#         if( ($odd->end_goals_overunder_over_10 + $odd->end_goals_overunder_under_10) < 4 )
#         {
#             $goals_overunder_over_10 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_125) && !is_null($odd->end_goals_overunder_under_125) )
#     {
#         if( ($odd->end_goals_overunder_over_125 + $odd->end_goals_overunder_under_125) < 4 )
#         {
#             $goals_overunder_over_125 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_15) && !is_null($odd->end_goals_overunder_under_15) )
#     {
#         if( ($odd->end_goals_overunder_over_15 + $odd->end_goals_overunder_under_15) < 4 )
#         {
#             $goals_overunder_over_15 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_175) && !is_null($odd->end_goals_overunder_under_175) )
#     {
#         if( ($odd->end_goals_overunder_over_175 + $odd->end_goals_overunder_under_175) < 4 )
#         {
#             $goals_overunder_over_175 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_20) && !is_null($odd->end_goals_overunder_under_20) )
#     {
#         if( ($odd->end_goals_overunder_over_20 + $odd->end_goals_overunder_under_20) < 4 )
#         {
#             $goals_overunder_over_20 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_225) && !is_null($odd->end_goals_overunder_under_225) )
#     {
#         if( ($odd->end_goals_overunder_over_225 + $odd->end_goals_overunder_under_225) < 4 )
#         {
#             $goals_overunder_over_225 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_25) && !is_null($odd->end_goals_overunder_under_25) )
#     {
#         if( ($odd->end_goals_overunder_over_25 + $odd->end_goals_overunder_under_25) < 4 )
#         {
#             $goals_overunder_over_25 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_275) && !is_null($odd->end_goals_overunder_under_275) )
#     {
#         if( ($odd->end_goals_overunder_over_275 + $odd->end_goals_overunder_under_275) < 4 )
#         {
#             $goals_overunder_over_275 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_30) && !is_null($odd->end_goals_overunder_under_30) )
#     {
#         if( ($odd->end_goals_overunder_over_30 + $odd->end_goals_overunder_under_30) < 4 )
#         {
#             $goals_overunder_over_30 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_325) && !is_null($odd->end_goals_overunder_under_325) )
#     {
#         if( ($odd->end_goals_overunder_over_325 + $odd->end_goals_overunder_under_325) < 4 )
#         {
#             $goals_overunder_over_325 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_35) && !is_null($odd->end_goals_overunder_under_35) )
#     {
#         if( ($odd->end_goals_overunder_over_35 + $odd->end_goals_overunder_under_35) < 4 )
#         {
#             $goals_overunder_over_35 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_375) && !is_null($odd->end_goals_overunder_under_375) )
#     {
#         if( ($odd->end_goals_overunder_over_375 + $odd->end_goals_overunder_under_375) < 4 )
#         {
#             $goals_overunder_over_375 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_40) && !is_null($odd->end_goals_overunder_under_40) )
#     {
#         if( ($odd->end_goals_overunder_over_40 + $odd->end_goals_overunder_under_40) < 4 )
#         {
#             $goals_overunder_over_40 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_425) && !is_null($odd->end_goals_overunder_under_425) )
#     {
#         if( ($odd->end_goals_overunder_over_425 + $odd->end_goals_overunder_under_425) < 4 )
#         {
#             $goals_overunder_over_425 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_45) && !is_null($odd->end_goals_overunder_under_45) )
#     {
#         if( ($odd->end_goals_overunder_over_45 + $odd->end_goals_overunder_under_45) < 4 )
#         {
#             $goals_overunder_over_45 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_475) && !is_null($odd->end_goals_overunder_under_475) )
#     {
#         if( ($odd->end_goals_overunder_over_475 + $odd->end_goals_overunder_under_475) < 4 )
#         {
#             $goals_overunder_over_475 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_50) && !is_null($odd->end_goals_overunder_under_50) )
#     {
#         if( ($odd->end_goals_overunder_over_50 + $odd->end_goals_overunder_under_50) < 4 )
#         {
#             $goals_overunder_over_50 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_525) && !is_null($odd->end_goals_overunder_under_525) )
#     {
#         if( ($odd->end_goals_overunder_over_525 + $odd->end_goals_overunder_under_525) < 4 )
#         {
#             $goals_overunder_over_525 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_55) && !is_null($odd->end_goals_overunder_under_55) )
#     {
#         if( ($odd->end_goals_overunder_over_55 + $odd->end_goals_overunder_under_55) < 4 )
#         {
#             $goals_overunder_over_55 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_575) && !is_null($odd->end_goals_overunder_under_575) )
#     {
#         if( ($odd->end_goals_overunder_over_575 + $odd->end_goals_overunder_under_575) < 4 )
#         {
#             $goals_overunder_over_575 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_60) && !is_null($odd->end_goals_overunder_under_60) )
#     {
#         if( ($odd->end_goals_overunder_over_60 + $odd->end_goals_overunder_under_60) < 4 )
#         {
#             $goals_overunder_over_60 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_625) && !is_null($odd->end_goals_overunder_under_625) )
#     {
#         if( ($odd->end_goals_overunder_over_625 + $odd->end_goals_overunder_under_625) < 4 )
#         {
#             $goals_overunder_over_625 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_65) && !is_null($odd->end_goals_overunder_under_65) )
#     {
#         if( ($odd->end_goals_overunder_over_65 + $odd->end_goals_overunder_under_65) < 4 )
#         {
#             $goals_overunder_over_65 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_675) && !is_null($odd->end_goals_overunder_under_675) )
#     {
#         if( ($odd->end_goals_overunder_over_675 + $odd->end_goals_overunder_under_675) < 4 )
#         {
#             $goals_overunder_over_675 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_70) && !is_null($odd->end_goals_overunder_under_70) )
#     {
#         if( ($odd->end_goals_overunder_over_70 + $odd->end_goals_overunder_under_70) < 4 )
#         {
#             $goals_overunder_over_70 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_75) && !is_null($odd->end_goals_overunder_under_75) )
#     {
#         if( ($odd->end_goals_overunder_over_75 + $odd->end_goals_overunder_under_75) < 4 )
#         {
#             $goals_overunder_over_75 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_85) && !is_null($odd->end_goals_overunder_under_85) )
#     {
#         if( ($odd->end_goals_overunder_over_85 + $odd->end_goals_overunder_under_85) < 4 )
#         {
#             $goals_overunder_over_85 = 1;
#         }
#     }
#
#     if(!is_null($row->end_goals_overunder_over_95) && !is_null($odd->end_goals_overunder_under_95) )
#     {
#         if( ($odd->end_goals_overunder_over_95 + $odd->end_goals_overunder_under_95) < 4 )
#         {
#             $goals_overunder_over_95 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 5 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "$"+columnx_1+" = 0;"
        print(word, flush=True) 
        # ----------------------------------------------  
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
# $goals_overunder_over_05 = 0;
# $goals_overunder_over_075 = 0;
# $goals_overunder_over_10 = 0;
# $goals_overunder_over_125 = 0;
# $goals_overunder_over_15 = 0;
# $goals_overunder_over_175 = 0;
# $goals_overunder_over_20 = 0;
# $goals_overunder_over_225 = 0;
# $goals_overunder_over_25 = 0;
# $goals_overunder_over_275 = 0;
# $goals_overunder_over_30 = 0;
# $goals_overunder_over_325 = 0;
# $goals_overunder_over_35 = 0;
# $goals_overunder_over_375 = 0;
# $goals_overunder_over_40 = 0;
# $goals_overunder_over_425 = 0;
# $goals_overunder_over_45 = 0;
# $goals_overunder_over_475 = 0;
# $goals_overunder_over_50 = 0;
# $goals_overunder_over_525 = 0;
# $goals_overunder_over_55 = 0;
# $goals_overunder_over_575 = 0;
# $goals_overunder_over_60 = 0;
# $goals_overunder_over_625 = 0;
# $goals_overunder_over_65 = 0;
# $goals_overunder_over_675 = 0;
# $goals_overunder_over_70 = 0;
# $goals_overunder_over_75 = 0;
# $goals_overunder_over_85 = 0;
# $goals_overunder_over_95 = 0;
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 5 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0  
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "@if($"+columnx_1+" == 1)"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        <div class="card">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-header">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                ' + bet_1 + ' #' + str(bet_id_1)
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-body text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        Home ' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        ' + value_2.replace('Under ', '') 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' + $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' + $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-footer text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' - $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_1+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' - $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_2+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "@endif"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ----------------------------------------------
# Out:
# @if($goals_overunder_over_05 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_05 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_05 }}
#                     </div>
#                     <div class="col-4">
#                         0.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_05 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_05 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_05 + $odd->pre_goals_overunder_under_05 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_05 + $odd->end_goals_overunder_under_05 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_05 - $odd->pre_goals_overunder_over_05 }}
#                         @if($stats->goals_overunder_over_05 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_05 - $odd->pre_goals_overunder_under_05 }}
#                         @if($stats->goals_overunder_under_05 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_075 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_075 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_075 }}
#                     </div>
#                     <div class="col-4">
#                         0.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_075 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_075 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_075 + $odd->pre_goals_overunder_under_075 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_075 + $odd->end_goals_overunder_under_075 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_075 - $odd->pre_goals_overunder_over_075 }}
#                         @if($stats->goals_overunder_over_075 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_075 - $odd->pre_goals_overunder_under_075 }}
#                         @if($stats->goals_overunder_under_075 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_10 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_10 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_10 }}
#                     </div>
#                     <div class="col-4">
#                         1.0
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_10 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_10 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_10 + $odd->pre_goals_overunder_under_10 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_10 + $odd->end_goals_overunder_under_10 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_10 - $odd->pre_goals_overunder_over_10 }}
#                         @if($stats->goals_overunder_over_10 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_10 - $odd->pre_goals_overunder_under_10 }}
#                         @if($stats->goals_overunder_under_10 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_125 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_125 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_125 }}
#                     </div>
#                     <div class="col-4">
#                         1.25
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_125 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_125 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_125 + $odd->pre_goals_overunder_under_125 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_125 + $odd->end_goals_overunder_under_125 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_125 - $odd->pre_goals_overunder_over_125 }}
#                         @if($stats->goals_overunder_over_125 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_125 - $odd->pre_goals_overunder_under_125 }}
#                         @if($stats->goals_overunder_under_125 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_15 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_15 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_15 }}
#                     </div>
#                     <div class="col-4">
#                         1.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_15 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_15 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_15 + $odd->pre_goals_overunder_under_15 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_15 + $odd->end_goals_overunder_under_15 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_15 - $odd->pre_goals_overunder_over_15 }}
#                         @if($stats->goals_overunder_over_15 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_15 - $odd->pre_goals_overunder_under_15 }}
#                         @if($stats->goals_overunder_under_15 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_175 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_175 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_175 }}
#                     </div>
#                     <div class="col-4">
#                         1.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_175 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_175 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_175 + $odd->pre_goals_overunder_under_175 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_175 + $odd->end_goals_overunder_under_175 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_175 - $odd->pre_goals_overunder_over_175 }}
#                         @if($stats->goals_overunder_over_175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_175 - $odd->pre_goals_overunder_under_175 }}
#                         @if($stats->goals_overunder_under_175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_20 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_20 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_20 }}
#                     </div>
#                     <div class="col-4">
#                         2.0
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_20 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_20 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_20 + $odd->pre_goals_overunder_under_20 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_20 + $odd->end_goals_overunder_under_20 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_20 - $odd->pre_goals_overunder_over_20 }}
#                         @if($stats->goals_overunder_over_20 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_20 - $odd->pre_goals_overunder_under_20 }}
#                         @if($stats->goals_overunder_under_20 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_225 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_225 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_225 }}
#                     </div>
#                     <div class="col-4">
#                         2.25
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_225 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_225 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_225 + $odd->pre_goals_overunder_under_225 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_225 + $odd->end_goals_overunder_under_225 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_225 - $odd->pre_goals_overunder_over_225 }}
#                         @if($stats->goals_overunder_over_225 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_225 - $odd->pre_goals_overunder_under_225 }}
#                         @if($stats->goals_overunder_under_225 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_25 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_25 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_25 }}
#                     </div>
#                     <div class="col-4">
#                         2.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_25 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_25 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_25 + $odd->pre_goals_overunder_under_25 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_25 + $odd->end_goals_overunder_under_25 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_25 - $odd->pre_goals_overunder_over_25 }}
#                         @if($stats->goals_overunder_over_25 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_25 - $odd->pre_goals_overunder_under_25 }}
#                         @if($stats->goals_overunder_under_25 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_275 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_275 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_275 }}
#                     </div>
#                     <div class="col-4">
#                         2.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_275 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_275 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_275 + $odd->pre_goals_overunder_under_275 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_275 + $odd->end_goals_overunder_under_275 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_275 - $odd->pre_goals_overunder_over_275 }}
#                         @if($stats->goals_overunder_over_275 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_275 - $odd->pre_goals_overunder_under_275 }}
#                         @if($stats->goals_overunder_under_275 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_30 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_30 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_30 }}
#                     </div>
#                     <div class="col-4">
#                         3.0
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_30 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_30 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_30 + $odd->pre_goals_overunder_under_30 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_30 + $odd->end_goals_overunder_under_30 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_30 - $odd->pre_goals_overunder_over_30 }}
#                         @if($stats->goals_overunder_over_30 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_30 - $odd->pre_goals_overunder_under_30 }}
#                         @if($stats->goals_overunder_under_30 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_325 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_325 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_325 }}
#                     </div>
#                     <div class="col-4">
#                         3.25
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_325 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_325 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_325 + $odd->pre_goals_overunder_under_325 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_325 + $odd->end_goals_overunder_under_325 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_325 - $odd->pre_goals_overunder_over_325 }}
#                         @if($stats->goals_overunder_over_325 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_325 - $odd->pre_goals_overunder_under_325 }}
#                         @if($stats->goals_overunder_under_325 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_35 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_35 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_35 }}
#                     </div>
#                     <div class="col-4">
#                         3.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_35 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_35 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_35 + $odd->pre_goals_overunder_under_35 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_35 + $odd->end_goals_overunder_under_35 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_35 - $odd->pre_goals_overunder_over_35 }}
#                         @if($stats->goals_overunder_over_35 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_35 - $odd->pre_goals_overunder_under_35 }}
#                         @if($stats->goals_overunder_under_35 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_375 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_375 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_375 }}
#                     </div>
#                     <div class="col-4">
#                         3.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_375 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_375 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_375 + $odd->pre_goals_overunder_under_375 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_375 + $odd->end_goals_overunder_under_375 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_375 - $odd->pre_goals_overunder_over_375 }}
#                         @if($stats->goals_overunder_over_375 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_375 - $odd->pre_goals_overunder_under_375 }}
#                         @if($stats->goals_overunder_under_375 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_40 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_40 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_40 }}
#                     </div>
#                     <div class="col-4">
#                         4.0
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_40 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_40 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_40 + $odd->pre_goals_overunder_under_40 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_40 + $odd->end_goals_overunder_under_40 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_40 - $odd->pre_goals_overunder_over_40 }}
#                         @if($stats->goals_overunder_over_40 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_40 - $odd->pre_goals_overunder_under_40 }}
#                         @if($stats->goals_overunder_under_40 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_425 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_425 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_425 }}
#                     </div>
#                     <div class="col-4">
#                         4.25
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_425 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_425 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_425 + $odd->pre_goals_overunder_under_425 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_425 + $odd->end_goals_overunder_under_425 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_425 - $odd->pre_goals_overunder_over_425 }}
#                         @if($stats->goals_overunder_over_425 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_425 - $odd->pre_goals_overunder_under_425 }}
#                         @if($stats->goals_overunder_under_425 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_45 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_45 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_45 }}
#                     </div>
#                     <div class="col-4">
#                         4.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_45 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_45 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_45 + $odd->pre_goals_overunder_under_45 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_45 + $odd->end_goals_overunder_under_45 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_45 - $odd->pre_goals_overunder_over_45 }}
#                         @if($stats->goals_overunder_over_45 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_45 - $odd->pre_goals_overunder_under_45 }}
#                         @if($stats->goals_overunder_under_45 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_475 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_475 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_475 }}
#                     </div>
#                     <div class="col-4">
#                         4.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_475 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_475 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_475 + $odd->pre_goals_overunder_under_475 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_475 + $odd->end_goals_overunder_under_475 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_475 - $odd->pre_goals_overunder_over_475 }}
#                         @if($stats->goals_overunder_over_475 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_475 - $odd->pre_goals_overunder_under_475 }}
#                         @if($stats->goals_overunder_under_475 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_50 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_50 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_50 }}
#                     </div>
#                     <div class="col-4">
#                         5.0
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_50 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_50 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_50 + $odd->pre_goals_overunder_under_50 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_50 + $odd->end_goals_overunder_under_50 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_50 - $odd->pre_goals_overunder_over_50 }}
#                         @if($stats->goals_overunder_over_50 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_50 - $odd->pre_goals_overunder_under_50 }}
#                         @if($stats->goals_overunder_under_50 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_525 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_525 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_525 }}
#                     </div>
#                     <div class="col-4">
#                         5.25
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_525 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_525 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_525 + $odd->pre_goals_overunder_under_525 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_525 + $odd->end_goals_overunder_under_525 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_525 - $odd->pre_goals_overunder_over_525 }}
#                         @if($stats->goals_overunder_over_525 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_525 - $odd->pre_goals_overunder_under_525 }}
#                         @if($stats->goals_overunder_under_525 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_55 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_55 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_55 }}
#                     </div>
#                     <div class="col-4">
#                         5.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_55 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_55 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_55 + $odd->pre_goals_overunder_under_55 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_55 + $odd->end_goals_overunder_under_55 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_55 - $odd->pre_goals_overunder_over_55 }}
#                         @if($stats->goals_overunder_over_55 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_55 - $odd->pre_goals_overunder_under_55 }}
#                         @if($stats->goals_overunder_under_55 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_575 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_575 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_575 }}
#                     </div>
#                     <div class="col-4">
#                         5.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_575 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_575 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_575 + $odd->pre_goals_overunder_under_575 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_575 + $odd->end_goals_overunder_under_575 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_575 - $odd->pre_goals_overunder_over_575 }}
#                         @if($stats->goals_overunder_over_575 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_575 - $odd->pre_goals_overunder_under_575 }}
#                         @if($stats->goals_overunder_under_575 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_60 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_60 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_60 }}
#                     </div>
#                     <div class="col-4">
#                         6.0
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_60 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_60 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_60 + $odd->pre_goals_overunder_under_60 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_60 + $odd->end_goals_overunder_under_60 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_60 - $odd->pre_goals_overunder_over_60 }}
#                         @if($stats->goals_overunder_over_60 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_60 - $odd->pre_goals_overunder_under_60 }}
#                         @if($stats->goals_overunder_under_60 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_625 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_625 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_625 }}
#                     </div>
#                     <div class="col-4">
#                         6.25
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_625 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_625 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_625 + $odd->pre_goals_overunder_under_625 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_625 + $odd->end_goals_overunder_under_625 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_625 - $odd->pre_goals_overunder_over_625 }}
#                         @if($stats->goals_overunder_over_625 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_625 - $odd->pre_goals_overunder_under_625 }}
#                         @if($stats->goals_overunder_under_625 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_65 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_65 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_65 }}
#                     </div>
#                     <div class="col-4">
#                         6.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_65 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_65 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_65 + $odd->pre_goals_overunder_under_65 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_65 + $odd->end_goals_overunder_under_65 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_65 - $odd->pre_goals_overunder_over_65 }}
#                         @if($stats->goals_overunder_over_65 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_65 - $odd->pre_goals_overunder_under_65 }}
#                         @if($stats->goals_overunder_under_65 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_675 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_675 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_675 }}
#                     </div>
#                     <div class="col-4">
#                         6.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_675 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_675 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_675 + $odd->pre_goals_overunder_under_675 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_675 + $odd->end_goals_overunder_under_675 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_675 - $odd->pre_goals_overunder_over_675 }}
#                         @if($stats->goals_overunder_over_675 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_675 - $odd->pre_goals_overunder_under_675 }}
#                         @if($stats->goals_overunder_under_675 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_70 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_70 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_70 }}
#                     </div>
#                     <div class="col-4">
#                         7.0
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_70 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_70 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_70 + $odd->pre_goals_overunder_under_70 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_70 + $odd->end_goals_overunder_under_70 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_70 - $odd->pre_goals_overunder_over_70 }}
#                         @if($stats->goals_overunder_over_70 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_70 - $odd->pre_goals_overunder_under_70 }}
#                         @if($stats->goals_overunder_under_70 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_75 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_75 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_75 }}
#                     </div>
#                     <div class="col-4">
#                         7.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_75 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_75 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_75 + $odd->pre_goals_overunder_under_75 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_75 + $odd->end_goals_overunder_under_75 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_75 - $odd->pre_goals_overunder_over_75 }}
#                         @if($stats->goals_overunder_over_75 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_75 - $odd->pre_goals_overunder_under_75 }}
#                         @if($stats->goals_overunder_under_75 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_85 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_85 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_85 }}
#                     </div>
#                     <div class="col-4">
#                         8.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_85 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_85 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_85 + $odd->pre_goals_overunder_under_85 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_85 + $odd->end_goals_overunder_under_85 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_85 - $odd->pre_goals_overunder_over_85 }}
#                         @if($stats->goals_overunder_over_85 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_85 - $odd->pre_goals_overunder_under_85 }}
#                         @if($stats->goals_overunder_under_85 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder_over_95 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under #5
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_95 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_95 }}
#                     </div>
#                     <div class="col-4">
#                         9.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder_under_95 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_under_95 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder_over_95 + $odd->pre_goals_overunder_under_95 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder_over_95 + $odd->end_goals_overunder_under_95 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_over_95 - $odd->pre_goals_overunder_over_95 }}
#                         @if($stats->goals_overunder_over_95 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder_under_95 - $odd->pre_goals_overunder_under_95 }}
#                         @if($stats->goals_overunder_under_95 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
