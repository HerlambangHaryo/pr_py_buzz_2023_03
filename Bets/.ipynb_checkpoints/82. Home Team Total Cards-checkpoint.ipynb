# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 80 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($odd->pre_"+columnx_1+") && !is_null($odd->pre_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->pre_"+columnx_1+" + $odd->pre_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($odd->pre_cards_overunder_over_25) && !is_null($odd->pre_cards_overunder_under_25) )
#     {
#         if( ($odd->pre_cards_overunder_over_25 + $odd->pre_cards_overunder_under_25) < 4 )
#         {
#             $cards_overunder_over_25 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_cards_overunder_over_35) && !is_null($odd->pre_cards_overunder_under_35) )
#     {
#         if( ($odd->pre_cards_overunder_over_35 + $odd->pre_cards_overunder_under_35) < 4 )
#         {
#             $cards_overunder_over_35 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_cards_overunder_over_45) && !is_null($odd->pre_cards_overunder_under_45) )
#     {
#         if( ($odd->pre_cards_overunder_over_45 + $odd->pre_cards_overunder_under_45) < 4 )
#         {
#             $cards_overunder_over_45 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_cards_overunder_over_55) && !is_null($odd->pre_cards_overunder_under_55) )
#     {
#         if( ($odd->pre_cards_overunder_over_55 + $odd->pre_cards_overunder_under_55) < 4 )
#         {
#             $cards_overunder_over_55 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_cards_overunder_over_65) && !is_null($odd->pre_cards_overunder_under_65) )
#     {
#         if( ($odd->pre_cards_overunder_over_65 + $odd->pre_cards_overunder_under_65) < 4 )
#         {
#             $cards_overunder_over_65 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_cards_overunder_over_75) && !is_null($odd->pre_cards_overunder_under_75) )
#     {
#         if( ($odd->pre_cards_overunder_over_75 + $odd->pre_cards_overunder_under_75) < 4 )
#         {
#             $cards_overunder_over_75 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 80 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($row->end_"+columnx_1+") && !is_null($odd->end_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->end_"+columnx_1+" + $odd->end_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($row->end_cards_overunder_over_25) && !is_null($odd->end_cards_overunder_under_25) )
#     {
#         if( ($odd->end_cards_overunder_over_25 + $odd->end_cards_overunder_under_25) < 4 )
#         {
#             $cards_overunder_over_25 = 1;
#         }
#     }
#
#     if(!is_null($row->end_cards_overunder_over_35) && !is_null($odd->end_cards_overunder_under_35) )
#     {
#         if( ($odd->end_cards_overunder_over_35 + $odd->end_cards_overunder_under_35) < 4 )
#         {
#             $cards_overunder_over_35 = 1;
#         }
#     }
#
#     if(!is_null($row->end_cards_overunder_over_45) && !is_null($odd->end_cards_overunder_under_45) )
#     {
#         if( ($odd->end_cards_overunder_over_45 + $odd->end_cards_overunder_under_45) < 4 )
#         {
#             $cards_overunder_over_45 = 1;
#         }
#     }
#
#     if(!is_null($row->end_cards_overunder_over_55) && !is_null($odd->end_cards_overunder_under_55) )
#     {
#         if( ($odd->end_cards_overunder_over_55 + $odd->end_cards_overunder_under_55) < 4 )
#         {
#             $cards_overunder_over_55 = 1;
#         }
#     }
#
#     if(!is_null($row->end_cards_overunder_over_65) && !is_null($odd->end_cards_overunder_under_65) )
#     {
#         if( ($odd->end_cards_overunder_over_65 + $odd->end_cards_overunder_under_65) < 4 )
#         {
#             $cards_overunder_over_65 = 1;
#         }
#     }
#
#     if(!is_null($row->end_cards_overunder_over_75) && !is_null($odd->end_cards_overunder_under_75) )
#     {
#         if( ($odd->end_cards_overunder_over_75 + $odd->end_cards_overunder_under_75) < 4 )
#         {
#             $cards_overunder_over_75 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 80 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "$"+columnx_1+" = 0;"
        print(word, flush=True) 
        # ----------------------------------------------  
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
# $cards_overunder_over_25 = 0;
# $cards_overunder_over_35 = 0;
# $cards_overunder_over_45 = 0;
# $cards_overunder_over_55 = 0;
# $cards_overunder_over_65 = 0;
# $cards_overunder_over_75 = 0;
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 80 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0  
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "@if($"+columnx_1+" == 1)"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        <div class="card">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-header">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                ' + bet_1 + ' #' + str(bet_id_1)
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-body text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        Home ' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        ' + value_2.replace('Under ', '') 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' + $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' + $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-footer text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' - $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_1+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' - $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_2+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "@endif"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ----------------------------------------------
# Out:
# @if($cards_overunder_over_25 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Cards Over/Under #80
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_25 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_25 }}
#                     </div>
#                     <div class="col-4">
#                         2.5
#                         <br/>
#                         {{ $odd->pre_cards_overunder_under_25 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_under_25 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_25 + $odd->pre_cards_overunder_under_25 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_25 + $odd->end_cards_overunder_under_25 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_over_25 - $odd->pre_cards_overunder_over_25 }}
#                         @if($stats->cards_overunder_over_25 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_under_25 - $odd->pre_cards_overunder_under_25 }}
#                         @if($stats->cards_overunder_under_25 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($cards_overunder_over_35 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Cards Over/Under  #80
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_35 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_35 }}
#                     </div>
#                     <div class="col-4">
#                         3.5
#                         <br/>
#                         {{ $odd->pre_cards_overunder_under_35 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_under_35 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_35 + $odd->pre_cards_overunder_under_35 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_35 + $odd->end_cards_overunder_under_35 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_over_35 - $odd->pre_cards_overunder_over_35 }}
#                         @if($stats->cards_overunder_over_35 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_under_35 - $odd->pre_cards_overunder_under_35 }}
#                         @if($stats->cards_overunder_under_35 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($cards_overunder_over_45 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Cards Over/Under  #80
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_45 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_45 }}
#                     </div>
#                     <div class="col-4">
#                         4.5
#                         <br/>
#                         {{ $odd->pre_cards_overunder_under_45 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_under_45 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_45 + $odd->pre_cards_overunder_under_45 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_45 + $odd->end_cards_overunder_under_45 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_over_45 - $odd->pre_cards_overunder_over_45 }}
#                         @if($stats->cards_overunder_over_45 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_under_45 - $odd->pre_cards_overunder_under_45 }}
#                         @if($stats->cards_overunder_under_45 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($cards_overunder_over_55 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Cards Over/Under  #80
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_55 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_55 }}
#                     </div>
#                     <div class="col-4">
#                         5.5
#                         <br/>
#                         {{ $odd->pre_cards_overunder_under_55 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_under_55 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_55 + $odd->pre_cards_overunder_under_55 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_55 + $odd->end_cards_overunder_under_55 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_over_55 - $odd->pre_cards_overunder_over_55 }}
#                         @if($stats->cards_overunder_over_55 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_under_55 - $odd->pre_cards_overunder_under_55 }}
#                         @if($stats->cards_overunder_under_55 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($cards_overunder_over_65 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Cards Over/Under  #80
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_65 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_65 }}
#                     </div>
#                     <div class="col-4">
#                         6.5
#                         <br/>
#                         {{ $odd->pre_cards_overunder_under_65 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_under_65 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_65 + $odd->pre_cards_overunder_under_65 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_65 + $odd->end_cards_overunder_under_65 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_over_65 - $odd->pre_cards_overunder_over_65 }}
#                         @if($stats->cards_overunder_over_65 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_under_65 - $odd->pre_cards_overunder_under_65 }}
#                         @if($stats->cards_overunder_under_65 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($cards_overunder_over_75 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Cards Over/Under  #80
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_75 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_75 }}
#                     </div>
#                     <div class="col-4">
#                         7.5
#                         <br/>
#                         {{ $odd->pre_cards_overunder_under_75 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_under_75 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_cards_overunder_over_75 + $odd->pre_cards_overunder_under_75 }}
#                         <br/>
#                         {{ $odd->end_cards_overunder_over_75 + $odd->end_cards_overunder_under_75 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_over_75 - $odd->pre_cards_overunder_over_75 }}
#                         @if($stats->cards_overunder_over_75 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_cards_overunder_under_75 - $odd->pre_cards_overunder_under_75 }}
#                         @if($stats->cards_overunder_under_75 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
