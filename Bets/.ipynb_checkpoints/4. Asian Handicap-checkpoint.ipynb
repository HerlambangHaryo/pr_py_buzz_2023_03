# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 4 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($row->pre_"+columnx_1+") && !is_null($odd->pre_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->pre_"+columnx_1+" + $odd->pre_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($row->pre_asian_handicap_home_min_675) && !is_null($odd->pre_asian_handicap_away_min_675) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_675 + $odd->pre_asian_handicap_away_min_675) < 4 )
#         {
#             $asian_handicap_home_min_675 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_65) && !is_null($odd->pre_asian_handicap_away_min_65) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_65 + $odd->pre_asian_handicap_away_min_65) < 4 )
#         {
#             $asian_handicap_home_min_65 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_625) && !is_null($odd->pre_asian_handicap_away_min_625) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_625 + $odd->pre_asian_handicap_away_min_625) < 4 )
#         {
#             $asian_handicap_home_min_625 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_6) && !is_null($odd->pre_asian_handicap_away_min_6) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_6 + $odd->pre_asian_handicap_away_min_6) < 4 )
#         {
#             $asian_handicap_home_min_6 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_575) && !is_null($odd->pre_asian_handicap_away_min_575) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_575 + $odd->pre_asian_handicap_away_min_575) < 4 )
#         {
#             $asian_handicap_home_min_575 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_55) && !is_null($odd->pre_asian_handicap_away_min_55) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_55 + $odd->pre_asian_handicap_away_min_55) < 4 )
#         {
#             $asian_handicap_home_min_55 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_525) && !is_null($odd->pre_asian_handicap_away_min_525) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_525 + $odd->pre_asian_handicap_away_min_525) < 4 )
#         {
#             $asian_handicap_home_min_525 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_5) && !is_null($odd->pre_asian_handicap_away_min_5) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_5 + $odd->pre_asian_handicap_away_min_5) < 4 )
#         {
#             $asian_handicap_home_min_5 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_475) && !is_null($odd->pre_asian_handicap_away_min_475) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_475 + $odd->pre_asian_handicap_away_min_475) < 4 )
#         {
#             $asian_handicap_home_min_475 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_45) && !is_null($odd->pre_asian_handicap_away_min_45) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_45 + $odd->pre_asian_handicap_away_min_45) < 4 )
#         {
#             $asian_handicap_home_min_45 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_425) && !is_null($odd->pre_asian_handicap_away_min_425) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_425 + $odd->pre_asian_handicap_away_min_425) < 4 )
#         {
#             $asian_handicap_home_min_425 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_4) && !is_null($odd->pre_asian_handicap_away_min_4) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_4 + $odd->pre_asian_handicap_away_min_4) < 4 )
#         {
#             $asian_handicap_home_min_4 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_375) && !is_null($odd->pre_asian_handicap_away_min_375) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_375 + $odd->pre_asian_handicap_away_min_375) < 4 )
#         {
#             $asian_handicap_home_min_375 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_35) && !is_null($odd->pre_asian_handicap_away_min_35) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_35 + $odd->pre_asian_handicap_away_min_35) < 4 )
#         {
#             $asian_handicap_home_min_35 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_325) && !is_null($odd->pre_asian_handicap_away_min_325) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_325 + $odd->pre_asian_handicap_away_min_325) < 4 )
#         {
#             $asian_handicap_home_min_325 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_3) && !is_null($odd->pre_asian_handicap_away_min_3) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_3 + $odd->pre_asian_handicap_away_min_3) < 4 )
#         {
#             $asian_handicap_home_min_3 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_275) && !is_null($odd->pre_asian_handicap_away_min_275) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_275 + $odd->pre_asian_handicap_away_min_275) < 4 )
#         {
#             $asian_handicap_home_min_275 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_25) && !is_null($odd->pre_asian_handicap_away_min_25) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_25 + $odd->pre_asian_handicap_away_min_25) < 4 )
#         {
#             $asian_handicap_home_min_25 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_225) && !is_null($odd->pre_asian_handicap_away_min_225) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_225 + $odd->pre_asian_handicap_away_min_225) < 4 )
#         {
#             $asian_handicap_home_min_225 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_2) && !is_null($odd->pre_asian_handicap_away_min_2) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_2 + $odd->pre_asian_handicap_away_min_2) < 4 )
#         {
#             $asian_handicap_home_min_2 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_175) && !is_null($odd->pre_asian_handicap_away_min_175) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_175 + $odd->pre_asian_handicap_away_min_175) < 4 )
#         {
#             $asian_handicap_home_min_175 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_15) && !is_null($odd->pre_asian_handicap_away_min_15) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_15 + $odd->pre_asian_handicap_away_min_15) < 4 )
#         {
#             $asian_handicap_home_min_15 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_125) && !is_null($odd->pre_asian_handicap_away_min_125) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_125 + $odd->pre_asian_handicap_away_min_125) < 4 )
#         {
#             $asian_handicap_home_min_125 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_1) && !is_null($odd->pre_asian_handicap_away_min_1) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_1 + $odd->pre_asian_handicap_away_min_1) < 4 )
#         {
#             $asian_handicap_home_min_1 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_075) && !is_null($odd->pre_asian_handicap_away_min_075) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_075 + $odd->pre_asian_handicap_away_min_075) < 4 )
#         {
#             $asian_handicap_home_min_075 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_05) && !is_null($odd->pre_asian_handicap_away_min_05) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_05 + $odd->pre_asian_handicap_away_min_05) < 4 )
#         {
#             $asian_handicap_home_min_05 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_min_025) && !is_null($odd->pre_asian_handicap_away_min_025) )
#     {
#         if( ($odd->pre_asian_handicap_home_min_025 + $odd->pre_asian_handicap_away_min_025) < 4 )
#         {
#             $asian_handicap_home_min_025 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_0) && !is_null($odd->pre_asian_handicap_away_plus_0) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_0 + $odd->pre_asian_handicap_away_plus_0) < 4 )
#         {
#             $asian_handicap_home_plus_0 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_025) && !is_null($odd->pre_asian_handicap_away_plus_025) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_025 + $odd->pre_asian_handicap_away_plus_025) < 4 )
#         {
#             $asian_handicap_home_plus_025 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_05) && !is_null($odd->pre_asian_handicap_away_plus_05) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_05 + $odd->pre_asian_handicap_away_plus_05) < 4 )
#         {
#             $asian_handicap_home_plus_05 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_075) && !is_null($odd->pre_asian_handicap_away_plus_075) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_075 + $odd->pre_asian_handicap_away_plus_075) < 4 )
#         {
#             $asian_handicap_home_plus_075 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_1) && !is_null($odd->pre_asian_handicap_away_plus_1) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_1 + $odd->pre_asian_handicap_away_plus_1) < 4 )
#         {
#             $asian_handicap_home_plus_1 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_125) && !is_null($odd->pre_asian_handicap_away_plus_125) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_125 + $odd->pre_asian_handicap_away_plus_125) < 4 )
#         {
#             $asian_handicap_home_plus_125 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_15) && !is_null($odd->pre_asian_handicap_away_plus_15) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_15 + $odd->pre_asian_handicap_away_plus_15) < 4 )
#         {
#             $asian_handicap_home_plus_15 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_175) && !is_null($odd->pre_asian_handicap_away_plus_175) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_175 + $odd->pre_asian_handicap_away_plus_175) < 4 )
#         {
#             $asian_handicap_home_plus_175 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_2) && !is_null($odd->pre_asian_handicap_away_plus_2) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_2 + $odd->pre_asian_handicap_away_plus_2) < 4 )
#         {
#             $asian_handicap_home_plus_2 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_225) && !is_null($odd->pre_asian_handicap_away_plus_225) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_225 + $odd->pre_asian_handicap_away_plus_225) < 4 )
#         {
#             $asian_handicap_home_plus_225 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_25) && !is_null($odd->pre_asian_handicap_away_plus_25) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_25 + $odd->pre_asian_handicap_away_plus_25) < 4 )
#         {
#             $asian_handicap_home_plus_25 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_275) && !is_null($odd->pre_asian_handicap_away_plus_275) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_275 + $odd->pre_asian_handicap_away_plus_275) < 4 )
#         {
#             $asian_handicap_home_plus_275 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_3) && !is_null($odd->pre_asian_handicap_away_plus_3) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_3 + $odd->pre_asian_handicap_away_plus_3) < 4 )
#         {
#             $asian_handicap_home_plus_3 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_325) && !is_null($odd->pre_asian_handicap_away_plus_325) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_325 + $odd->pre_asian_handicap_away_plus_325) < 4 )
#         {
#             $asian_handicap_home_plus_325 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_35) && !is_null($odd->pre_asian_handicap_away_plus_35) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_35 + $odd->pre_asian_handicap_away_plus_35) < 4 )
#         {
#             $asian_handicap_home_plus_35 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_375) && !is_null($odd->pre_asian_handicap_away_plus_375) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_375 + $odd->pre_asian_handicap_away_plus_375) < 4 )
#         {
#             $asian_handicap_home_plus_375 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_4) && !is_null($odd->pre_asian_handicap_away_plus_4) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_4 + $odd->pre_asian_handicap_away_plus_4) < 4 )
#         {
#             $asian_handicap_home_plus_4 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_425) && !is_null($odd->pre_asian_handicap_away_plus_425) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_425 + $odd->pre_asian_handicap_away_plus_425) < 4 )
#         {
#             $asian_handicap_home_plus_425 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_45) && !is_null($odd->pre_asian_handicap_away_plus_45) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_45 + $odd->pre_asian_handicap_away_plus_45) < 4 )
#         {
#             $asian_handicap_home_plus_45 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_475) && !is_null($odd->pre_asian_handicap_away_plus_475) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_475 + $odd->pre_asian_handicap_away_plus_475) < 4 )
#         {
#             $asian_handicap_home_plus_475 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_5) && !is_null($odd->pre_asian_handicap_away_plus_5) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_5 + $odd->pre_asian_handicap_away_plus_5) < 4 )
#         {
#             $asian_handicap_home_plus_5 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_525) && !is_null($odd->pre_asian_handicap_away_plus_525) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_525 + $odd->pre_asian_handicap_away_plus_525) < 4 )
#         {
#             $asian_handicap_home_plus_525 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_55) && !is_null($odd->pre_asian_handicap_away_plus_55) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_55 + $odd->pre_asian_handicap_away_plus_55) < 4 )
#         {
#             $asian_handicap_home_plus_55 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_575) && !is_null($odd->pre_asian_handicap_away_plus_575) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_575 + $odd->pre_asian_handicap_away_plus_575) < 4 )
#         {
#             $asian_handicap_home_plus_575 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_6) && !is_null($odd->pre_asian_handicap_away_plus_6) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_6 + $odd->pre_asian_handicap_away_plus_6) < 4 )
#         {
#             $asian_handicap_home_plus_6 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_625) && !is_null($odd->pre_asian_handicap_away_plus_625) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_625 + $odd->pre_asian_handicap_away_plus_625) < 4 )
#         {
#             $asian_handicap_home_plus_625 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_65) && !is_null($odd->pre_asian_handicap_away_plus_65) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_65 + $odd->pre_asian_handicap_away_plus_65) < 4 )
#         {
#             $asian_handicap_home_plus_65 = 1;
#         }
#     }
#
#     if(!is_null($row->pre_asian_handicap_home_plus_675) && !is_null($odd->pre_asian_handicap_away_plus_675) )
#     {
#         if( ($odd->pre_asian_handicap_home_plus_675 + $odd->pre_asian_handicap_away_plus_675) < 4 )
#         {
#             $asian_handicap_home_plus_675 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 4 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($row->end_"+columnx_1+") && !is_null($odd->end_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->end_"+columnx_1+" + $odd->end_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($row->end_asian_handicap_home_min_675) && !is_null($odd->end_asian_handicap_away_min_675) )
#     {
#         if( ($odd->end_asian_handicap_home_min_675 + $odd->end_asian_handicap_away_min_675) < 4 )
#         {
#             $asian_handicap_home_min_675 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_65) && !is_null($odd->end_asian_handicap_away_min_65) )
#     {
#         if( ($odd->end_asian_handicap_home_min_65 + $odd->end_asian_handicap_away_min_65) < 4 )
#         {
#             $asian_handicap_home_min_65 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_625) && !is_null($odd->end_asian_handicap_away_min_625) )
#     {
#         if( ($odd->end_asian_handicap_home_min_625 + $odd->end_asian_handicap_away_min_625) < 4 )
#         {
#             $asian_handicap_home_min_625 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_6) && !is_null($odd->end_asian_handicap_away_min_6) )
#     {
#         if( ($odd->end_asian_handicap_home_min_6 + $odd->end_asian_handicap_away_min_6) < 4 )
#         {
#             $asian_handicap_home_min_6 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_575) && !is_null($odd->end_asian_handicap_away_min_575) )
#     {
#         if( ($odd->end_asian_handicap_home_min_575 + $odd->end_asian_handicap_away_min_575) < 4 )
#         {
#             $asian_handicap_home_min_575 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_55) && !is_null($odd->end_asian_handicap_away_min_55) )
#     {
#         if( ($odd->end_asian_handicap_home_min_55 + $odd->end_asian_handicap_away_min_55) < 4 )
#         {
#             $asian_handicap_home_min_55 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_525) && !is_null($odd->end_asian_handicap_away_min_525) )
#     {
#         if( ($odd->end_asian_handicap_home_min_525 + $odd->end_asian_handicap_away_min_525) < 4 )
#         {
#             $asian_handicap_home_min_525 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_5) && !is_null($odd->end_asian_handicap_away_min_5) )
#     {
#         if( ($odd->end_asian_handicap_home_min_5 + $odd->end_asian_handicap_away_min_5) < 4 )
#         {
#             $asian_handicap_home_min_5 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_475) && !is_null($odd->end_asian_handicap_away_min_475) )
#     {
#         if( ($odd->end_asian_handicap_home_min_475 + $odd->end_asian_handicap_away_min_475) < 4 )
#         {
#             $asian_handicap_home_min_475 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_45) && !is_null($odd->end_asian_handicap_away_min_45) )
#     {
#         if( ($odd->end_asian_handicap_home_min_45 + $odd->end_asian_handicap_away_min_45) < 4 )
#         {
#             $asian_handicap_home_min_45 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_425) && !is_null($odd->end_asian_handicap_away_min_425) )
#     {
#         if( ($odd->end_asian_handicap_home_min_425 + $odd->end_asian_handicap_away_min_425) < 4 )
#         {
#             $asian_handicap_home_min_425 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_4) && !is_null($odd->end_asian_handicap_away_min_4) )
#     {
#         if( ($odd->end_asian_handicap_home_min_4 + $odd->end_asian_handicap_away_min_4) < 4 )
#         {
#             $asian_handicap_home_min_4 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_375) && !is_null($odd->end_asian_handicap_away_min_375) )
#     {
#         if( ($odd->end_asian_handicap_home_min_375 + $odd->end_asian_handicap_away_min_375) < 4 )
#         {
#             $asian_handicap_home_min_375 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_35) && !is_null($odd->end_asian_handicap_away_min_35) )
#     {
#         if( ($odd->end_asian_handicap_home_min_35 + $odd->end_asian_handicap_away_min_35) < 4 )
#         {
#             $asian_handicap_home_min_35 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_325) && !is_null($odd->end_asian_handicap_away_min_325) )
#     {
#         if( ($odd->end_asian_handicap_home_min_325 + $odd->end_asian_handicap_away_min_325) < 4 )
#         {
#             $asian_handicap_home_min_325 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_3) && !is_null($odd->end_asian_handicap_away_min_3) )
#     {
#         if( ($odd->end_asian_handicap_home_min_3 + $odd->end_asian_handicap_away_min_3) < 4 )
#         {
#             $asian_handicap_home_min_3 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_275) && !is_null($odd->end_asian_handicap_away_min_275) )
#     {
#         if( ($odd->end_asian_handicap_home_min_275 + $odd->end_asian_handicap_away_min_275) < 4 )
#         {
#             $asian_handicap_home_min_275 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_25) && !is_null($odd->end_asian_handicap_away_min_25) )
#     {
#         if( ($odd->end_asian_handicap_home_min_25 + $odd->end_asian_handicap_away_min_25) < 4 )
#         {
#             $asian_handicap_home_min_25 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_225) && !is_null($odd->end_asian_handicap_away_min_225) )
#     {
#         if( ($odd->end_asian_handicap_home_min_225 + $odd->end_asian_handicap_away_min_225) < 4 )
#         {
#             $asian_handicap_home_min_225 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_2) && !is_null($odd->end_asian_handicap_away_min_2) )
#     {
#         if( ($odd->end_asian_handicap_home_min_2 + $odd->end_asian_handicap_away_min_2) < 4 )
#         {
#             $asian_handicap_home_min_2 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_175) && !is_null($odd->end_asian_handicap_away_min_175) )
#     {
#         if( ($odd->end_asian_handicap_home_min_175 + $odd->end_asian_handicap_away_min_175) < 4 )
#         {
#             $asian_handicap_home_min_175 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_15) && !is_null($odd->end_asian_handicap_away_min_15) )
#     {
#         if( ($odd->end_asian_handicap_home_min_15 + $odd->end_asian_handicap_away_min_15) < 4 )
#         {
#             $asian_handicap_home_min_15 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_125) && !is_null($odd->end_asian_handicap_away_min_125) )
#     {
#         if( ($odd->end_asian_handicap_home_min_125 + $odd->end_asian_handicap_away_min_125) < 4 )
#         {
#             $asian_handicap_home_min_125 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_1) && !is_null($odd->end_asian_handicap_away_min_1) )
#     {
#         if( ($odd->end_asian_handicap_home_min_1 + $odd->end_asian_handicap_away_min_1) < 4 )
#         {
#             $asian_handicap_home_min_1 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_075) && !is_null($odd->end_asian_handicap_away_min_075) )
#     {
#         if( ($odd->end_asian_handicap_home_min_075 + $odd->end_asian_handicap_away_min_075) < 4 )
#         {
#             $asian_handicap_home_min_075 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_05) && !is_null($odd->end_asian_handicap_away_min_05) )
#     {
#         if( ($odd->end_asian_handicap_home_min_05 + $odd->end_asian_handicap_away_min_05) < 4 )
#         {
#             $asian_handicap_home_min_05 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_min_025) && !is_null($odd->end_asian_handicap_away_min_025) )
#     {
#         if( ($odd->end_asian_handicap_home_min_025 + $odd->end_asian_handicap_away_min_025) < 4 )
#         {
#             $asian_handicap_home_min_025 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_0) && !is_null($odd->end_asian_handicap_away_plus_0) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_0 + $odd->end_asian_handicap_away_plus_0) < 4 )
#         {
#             $asian_handicap_home_plus_0 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_025) && !is_null($odd->end_asian_handicap_away_plus_025) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_025 + $odd->end_asian_handicap_away_plus_025) < 4 )
#         {
#             $asian_handicap_home_plus_025 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_05) && !is_null($odd->end_asian_handicap_away_plus_05) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_05 + $odd->end_asian_handicap_away_plus_05) < 4 )
#         {
#             $asian_handicap_home_plus_05 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_075) && !is_null($odd->end_asian_handicap_away_plus_075) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_075 + $odd->end_asian_handicap_away_plus_075) < 4 )
#         {
#             $asian_handicap_home_plus_075 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_1) && !is_null($odd->end_asian_handicap_away_plus_1) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_1 + $odd->end_asian_handicap_away_plus_1) < 4 )
#         {
#             $asian_handicap_home_plus_1 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_125) && !is_null($odd->end_asian_handicap_away_plus_125) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_125 + $odd->end_asian_handicap_away_plus_125) < 4 )
#         {
#             $asian_handicap_home_plus_125 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_15) && !is_null($odd->end_asian_handicap_away_plus_15) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_15 + $odd->end_asian_handicap_away_plus_15) < 4 )
#         {
#             $asian_handicap_home_plus_15 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_175) && !is_null($odd->end_asian_handicap_away_plus_175) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_175 + $odd->end_asian_handicap_away_plus_175) < 4 )
#         {
#             $asian_handicap_home_plus_175 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_2) && !is_null($odd->end_asian_handicap_away_plus_2) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_2 + $odd->end_asian_handicap_away_plus_2) < 4 )
#         {
#             $asian_handicap_home_plus_2 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_225) && !is_null($odd->end_asian_handicap_away_plus_225) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_225 + $odd->end_asian_handicap_away_plus_225) < 4 )
#         {
#             $asian_handicap_home_plus_225 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_25) && !is_null($odd->end_asian_handicap_away_plus_25) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_25 + $odd->end_asian_handicap_away_plus_25) < 4 )
#         {
#             $asian_handicap_home_plus_25 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_275) && !is_null($odd->end_asian_handicap_away_plus_275) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_275 + $odd->end_asian_handicap_away_plus_275) < 4 )
#         {
#             $asian_handicap_home_plus_275 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_3) && !is_null($odd->end_asian_handicap_away_plus_3) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_3 + $odd->end_asian_handicap_away_plus_3) < 4 )
#         {
#             $asian_handicap_home_plus_3 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_325) && !is_null($odd->end_asian_handicap_away_plus_325) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_325 + $odd->end_asian_handicap_away_plus_325) < 4 )
#         {
#             $asian_handicap_home_plus_325 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_35) && !is_null($odd->end_asian_handicap_away_plus_35) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_35 + $odd->end_asian_handicap_away_plus_35) < 4 )
#         {
#             $asian_handicap_home_plus_35 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_375) && !is_null($odd->end_asian_handicap_away_plus_375) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_375 + $odd->end_asian_handicap_away_plus_375) < 4 )
#         {
#             $asian_handicap_home_plus_375 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_4) && !is_null($odd->end_asian_handicap_away_plus_4) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_4 + $odd->end_asian_handicap_away_plus_4) < 4 )
#         {
#             $asian_handicap_home_plus_4 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_425) && !is_null($odd->end_asian_handicap_away_plus_425) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_425 + $odd->end_asian_handicap_away_plus_425) < 4 )
#         {
#             $asian_handicap_home_plus_425 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_45) && !is_null($odd->end_asian_handicap_away_plus_45) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_45 + $odd->end_asian_handicap_away_plus_45) < 4 )
#         {
#             $asian_handicap_home_plus_45 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_475) && !is_null($odd->end_asian_handicap_away_plus_475) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_475 + $odd->end_asian_handicap_away_plus_475) < 4 )
#         {
#             $asian_handicap_home_plus_475 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_5) && !is_null($odd->end_asian_handicap_away_plus_5) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_5 + $odd->end_asian_handicap_away_plus_5) < 4 )
#         {
#             $asian_handicap_home_plus_5 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_525) && !is_null($odd->end_asian_handicap_away_plus_525) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_525 + $odd->end_asian_handicap_away_plus_525) < 4 )
#         {
#             $asian_handicap_home_plus_525 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_55) && !is_null($odd->end_asian_handicap_away_plus_55) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_55 + $odd->end_asian_handicap_away_plus_55) < 4 )
#         {
#             $asian_handicap_home_plus_55 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_575) && !is_null($odd->end_asian_handicap_away_plus_575) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_575 + $odd->end_asian_handicap_away_plus_575) < 4 )
#         {
#             $asian_handicap_home_plus_575 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_6) && !is_null($odd->end_asian_handicap_away_plus_6) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_6 + $odd->end_asian_handicap_away_plus_6) < 4 )
#         {
#             $asian_handicap_home_plus_6 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_625) && !is_null($odd->end_asian_handicap_away_plus_625) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_625 + $odd->end_asian_handicap_away_plus_625) < 4 )
#         {
#             $asian_handicap_home_plus_625 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_65) && !is_null($odd->end_asian_handicap_away_plus_65) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_65 + $odd->end_asian_handicap_away_plus_65) < 4 )
#         {
#             $asian_handicap_home_plus_65 = 1;
#         }
#     }
#
#     if(!is_null($row->end_asian_handicap_home_plus_675) && !is_null($odd->end_asian_handicap_away_plus_675) )
#     {
#         if( ($odd->end_asian_handicap_home_plus_675 + $odd->end_asian_handicap_away_plus_675) < 4 )
#         {
#             $asian_handicap_home_plus_675 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 4 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "$"+columnx_1+" = 0;"
        print(word, flush=True) 
        # ----------------------------------------------  
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
# $asian_handicap_home_min_675 = 0;
# $asian_handicap_home_min_65 = 0;
# $asian_handicap_home_min_625 = 0;
# $asian_handicap_home_min_6 = 0;
# $asian_handicap_home_min_575 = 0;
# $asian_handicap_home_min_55 = 0;
# $asian_handicap_home_min_525 = 0;
# $asian_handicap_home_min_5 = 0;
# $asian_handicap_home_min_475 = 0;
# $asian_handicap_home_min_45 = 0;
# $asian_handicap_home_min_425 = 0;
# $asian_handicap_home_min_4 = 0;
# $asian_handicap_home_min_375 = 0;
# $asian_handicap_home_min_35 = 0;
# $asian_handicap_home_min_325 = 0;
# $asian_handicap_home_min_3 = 0;
# $asian_handicap_home_min_275 = 0;
# $asian_handicap_home_min_25 = 0;
# $asian_handicap_home_min_225 = 0;
# $asian_handicap_home_min_2 = 0;
# $asian_handicap_home_min_175 = 0;
# $asian_handicap_home_min_15 = 0;
# $asian_handicap_home_min_125 = 0;
# $asian_handicap_home_min_1 = 0;
# $asian_handicap_home_min_075 = 0;
# $asian_handicap_home_min_05 = 0;
# $asian_handicap_home_min_025 = 0;
# $asian_handicap_home_plus_0 = 0;
# $asian_handicap_home_plus_025 = 0;
# $asian_handicap_home_plus_05 = 0;
# $asian_handicap_home_plus_075 = 0;
# $asian_handicap_home_plus_1 = 0;
# $asian_handicap_home_plus_125 = 0;
# $asian_handicap_home_plus_15 = 0;
# $asian_handicap_home_plus_175 = 0;
# $asian_handicap_home_plus_2 = 0;
# $asian_handicap_home_plus_225 = 0;
# $asian_handicap_home_plus_25 = 0;
# $asian_handicap_home_plus_275 = 0;
# $asian_handicap_home_plus_3 = 0;
# $asian_handicap_home_plus_325 = 0;
# $asian_handicap_home_plus_35 = 0;
# $asian_handicap_home_plus_375 = 0;
# $asian_handicap_home_plus_4 = 0;
# $asian_handicap_home_plus_425 = 0;
# $asian_handicap_home_plus_45 = 0;
# $asian_handicap_home_plus_475 = 0;
# $asian_handicap_home_plus_5 = 0;
# $asian_handicap_home_plus_525 = 0;
# $asian_handicap_home_plus_55 = 0;
# $asian_handicap_home_plus_575 = 0;
# $asian_handicap_home_plus_6 = 0;
# $asian_handicap_home_plus_625 = 0;
# $asian_handicap_home_plus_65 = 0;
# $asian_handicap_home_plus_675 = 0;
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 4 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0  
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "@if($"+columnx_1+" == 1)"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        <div class="card">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-header">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                ' + bet_1 + ' #' + str(bet_id_1)
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-body text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        Home ' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        ' + value_2.replace('Away ', '') 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' + $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' + $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-footer text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' - $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_1+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' - $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_2+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "@endif"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ----------------------------------------------
# Out:
# @if($asian_handicap_home_min_675 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_675 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_675 }}
#                     </div>
#                     <div class="col-4">
#                         -6.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_675 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_675 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_675 + $odd->pre_asian_handicap_away_min_675 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_675 + $odd->end_asian_handicap_away_min_675 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_675 - $odd->pre_asian_handicap_home_min_675 }}
#                         @if($stats->asian_handicap_home_min_675 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_675 - $odd->pre_asian_handicap_away_min_675 }}
#                         @if($stats->asian_handicap_away_min_675 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_65 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_65 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_65 }}
#                     </div>
#                     <div class="col-4">
#                         -6.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_65 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_65 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_65 + $odd->pre_asian_handicap_away_min_65 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_65 + $odd->end_asian_handicap_away_min_65 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_65 - $odd->pre_asian_handicap_home_min_65 }}
#                         @if($stats->asian_handicap_home_min_65 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_65 - $odd->pre_asian_handicap_away_min_65 }}
#                         @if($stats->asian_handicap_away_min_65 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_625 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_625 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_625 }}
#                     </div>
#                     <div class="col-4">
#                         -6.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_625 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_625 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_625 + $odd->pre_asian_handicap_away_min_625 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_625 + $odd->end_asian_handicap_away_min_625 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_625 - $odd->pre_asian_handicap_home_min_625 }}
#                         @if($stats->asian_handicap_home_min_625 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_625 - $odd->pre_asian_handicap_away_min_625 }}
#                         @if($stats->asian_handicap_away_min_625 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_6 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_6 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_6 }}
#                     </div>
#                     <div class="col-4">
#                         -6
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_6 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_6 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_6 + $odd->pre_asian_handicap_away_min_6 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_6 + $odd->end_asian_handicap_away_min_6 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_6 - $odd->pre_asian_handicap_home_min_6 }}
#                         @if($stats->asian_handicap_home_min_6 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_6 - $odd->pre_asian_handicap_away_min_6 }}
#                         @if($stats->asian_handicap_away_min_6 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_575 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_575 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_575 }}
#                     </div>
#                     <div class="col-4">
#                         -5.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_575 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_575 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_575 + $odd->pre_asian_handicap_away_min_575 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_575 + $odd->end_asian_handicap_away_min_575 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_575 - $odd->pre_asian_handicap_home_min_575 }}
#                         @if($stats->asian_handicap_home_min_575 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_575 - $odd->pre_asian_handicap_away_min_575 }}
#                         @if($stats->asian_handicap_away_min_575 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_55 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_55 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_55 }}
#                     </div>
#                     <div class="col-4">
#                         -5.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_55 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_55 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_55 + $odd->pre_asian_handicap_away_min_55 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_55 + $odd->end_asian_handicap_away_min_55 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_55 - $odd->pre_asian_handicap_home_min_55 }}
#                         @if($stats->asian_handicap_home_min_55 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_55 - $odd->pre_asian_handicap_away_min_55 }}
#                         @if($stats->asian_handicap_away_min_55 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_525 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_525 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_525 }}
#                     </div>
#                     <div class="col-4">
#                         -5.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_525 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_525 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_525 + $odd->pre_asian_handicap_away_min_525 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_525 + $odd->end_asian_handicap_away_min_525 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_525 - $odd->pre_asian_handicap_home_min_525 }}
#                         @if($stats->asian_handicap_home_min_525 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_525 - $odd->pre_asian_handicap_away_min_525 }}
#                         @if($stats->asian_handicap_away_min_525 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_5 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_5 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_5 }}
#                     </div>
#                     <div class="col-4">
#                         -5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_5 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_5 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_5 + $odd->pre_asian_handicap_away_min_5 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_5 + $odd->end_asian_handicap_away_min_5 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_5 - $odd->pre_asian_handicap_home_min_5 }}
#                         @if($stats->asian_handicap_home_min_5 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_5 - $odd->pre_asian_handicap_away_min_5 }}
#                         @if($stats->asian_handicap_away_min_5 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_475 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_475 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_475 }}
#                     </div>
#                     <div class="col-4">
#                         -4.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_475 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_475 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_475 + $odd->pre_asian_handicap_away_min_475 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_475 + $odd->end_asian_handicap_away_min_475 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_475 - $odd->pre_asian_handicap_home_min_475 }}
#                         @if($stats->asian_handicap_home_min_475 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_475 - $odd->pre_asian_handicap_away_min_475 }}
#                         @if($stats->asian_handicap_away_min_475 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_45 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_45 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_45 }}
#                     </div>
#                     <div class="col-4">
#                         -4.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_45 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_45 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_45 + $odd->pre_asian_handicap_away_min_45 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_45 + $odd->end_asian_handicap_away_min_45 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_45 - $odd->pre_asian_handicap_home_min_45 }}
#                         @if($stats->asian_handicap_home_min_45 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_45 - $odd->pre_asian_handicap_away_min_45 }}
#                         @if($stats->asian_handicap_away_min_45 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_425 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_425 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_425 }}
#                     </div>
#                     <div class="col-4">
#                         -4.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_425 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_425 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_425 + $odd->pre_asian_handicap_away_min_425 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_425 + $odd->end_asian_handicap_away_min_425 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_425 - $odd->pre_asian_handicap_home_min_425 }}
#                         @if($stats->asian_handicap_home_min_425 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_425 - $odd->pre_asian_handicap_away_min_425 }}
#                         @if($stats->asian_handicap_away_min_425 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_4 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_4 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_4 }}
#                     </div>
#                     <div class="col-4">
#                         -4
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_4 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_4 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_4 + $odd->pre_asian_handicap_away_min_4 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_4 + $odd->end_asian_handicap_away_min_4 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_4 - $odd->pre_asian_handicap_home_min_4 }}
#                         @if($stats->asian_handicap_home_min_4 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_4 - $odd->pre_asian_handicap_away_min_4 }}
#                         @if($stats->asian_handicap_away_min_4 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_375 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_375 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_375 }}
#                     </div>
#                     <div class="col-4">
#                         -3.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_375 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_375 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_375 + $odd->pre_asian_handicap_away_min_375 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_375 + $odd->end_asian_handicap_away_min_375 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_375 - $odd->pre_asian_handicap_home_min_375 }}
#                         @if($stats->asian_handicap_home_min_375 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_375 - $odd->pre_asian_handicap_away_min_375 }}
#                         @if($stats->asian_handicap_away_min_375 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_35 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_35 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_35 }}
#                     </div>
#                     <div class="col-4">
#                         -3.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_35 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_35 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_35 + $odd->pre_asian_handicap_away_min_35 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_35 + $odd->end_asian_handicap_away_min_35 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_35 - $odd->pre_asian_handicap_home_min_35 }}
#                         @if($stats->asian_handicap_home_min_35 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_35 - $odd->pre_asian_handicap_away_min_35 }}
#                         @if($stats->asian_handicap_away_min_35 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_325 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_325 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_325 }}
#                     </div>
#                     <div class="col-4">
#                         -3.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_325 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_325 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_325 + $odd->pre_asian_handicap_away_min_325 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_325 + $odd->end_asian_handicap_away_min_325 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_325 - $odd->pre_asian_handicap_home_min_325 }}
#                         @if($stats->asian_handicap_home_min_325 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_325 - $odd->pre_asian_handicap_away_min_325 }}
#                         @if($stats->asian_handicap_away_min_325 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_3 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_3 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_3 }}
#                     </div>
#                     <div class="col-4">
#                         -3
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_3 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_3 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_3 + $odd->pre_asian_handicap_away_min_3 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_3 + $odd->end_asian_handicap_away_min_3 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_3 - $odd->pre_asian_handicap_home_min_3 }}
#                         @if($stats->asian_handicap_home_min_3 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_3 - $odd->pre_asian_handicap_away_min_3 }}
#                         @if($stats->asian_handicap_away_min_3 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_275 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_275 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_275 }}
#                     </div>
#                     <div class="col-4">
#                         -2.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_275 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_275 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_275 + $odd->pre_asian_handicap_away_min_275 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_275 + $odd->end_asian_handicap_away_min_275 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_275 - $odd->pre_asian_handicap_home_min_275 }}
#                         @if($stats->asian_handicap_home_min_275 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_275 - $odd->pre_asian_handicap_away_min_275 }}
#                         @if($stats->asian_handicap_away_min_275 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_25 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_25 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_25 }}
#                     </div>
#                     <div class="col-4">
#                         -2.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_25 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_25 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_25 + $odd->pre_asian_handicap_away_min_25 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_25 + $odd->end_asian_handicap_away_min_25 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_25 - $odd->pre_asian_handicap_home_min_25 }}
#                         @if($stats->asian_handicap_home_min_25 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_25 - $odd->pre_asian_handicap_away_min_25 }}
#                         @if($stats->asian_handicap_away_min_25 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_225 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_225 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_225 }}
#                     </div>
#                     <div class="col-4">
#                         -2.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_225 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_225 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_225 + $odd->pre_asian_handicap_away_min_225 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_225 + $odd->end_asian_handicap_away_min_225 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_225 - $odd->pre_asian_handicap_home_min_225 }}
#                         @if($stats->asian_handicap_home_min_225 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_225 - $odd->pre_asian_handicap_away_min_225 }}
#                         @if($stats->asian_handicap_away_min_225 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_2 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_2 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_2 }}
#                     </div>
#                     <div class="col-4">
#                         -2
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_2 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_2 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_2 + $odd->pre_asian_handicap_away_min_2 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_2 + $odd->end_asian_handicap_away_min_2 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_2 - $odd->pre_asian_handicap_home_min_2 }}
#                         @if($stats->asian_handicap_home_min_2 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_2 - $odd->pre_asian_handicap_away_min_2 }}
#                         @if($stats->asian_handicap_away_min_2 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_175 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_175 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_175 }}
#                     </div>
#                     <div class="col-4">
#                         -1.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_175 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_175 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_175 + $odd->pre_asian_handicap_away_min_175 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_175 + $odd->end_asian_handicap_away_min_175 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_175 - $odd->pre_asian_handicap_home_min_175 }}
#                         @if($stats->asian_handicap_home_min_175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_175 - $odd->pre_asian_handicap_away_min_175 }}
#                         @if($stats->asian_handicap_away_min_175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_15 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_15 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_15 }}
#                     </div>
#                     <div class="col-4">
#                         -1.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_15 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_15 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_15 + $odd->pre_asian_handicap_away_min_15 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_15 + $odd->end_asian_handicap_away_min_15 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_min_15 - $odd->pre_asian_handicap_home_min_15 }}
#                         @if($stats->asian_handicap_home_min_15 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_min_15 - $odd->pre_asian_handicap_away_min_15 }}
#                         @if($stats->asian_handicap_away_min_15 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_min_125 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_125 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_125 }}
#                     </div>
#                     <div class="col-4">
#                         -1.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_min_125 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_min_125 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_min_125 + $odd->pre_asian_handicap_away_min_125 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_min_125 + $odd->end_asian_handicap_away_min_125 }}
#                     </div>
#                 </div>
#             </div>
# ...
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_plus_2 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_2 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_2 }}
#                     </div>
#                     <div class="col-4">
#                         +2
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_plus_2 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_plus_2 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_2 + $odd->pre_asian_handicap_away_plus_2 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_2 + $odd->end_asian_handicap_away_plus_2 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_plus_2 - $odd->pre_asian_handicap_home_plus_2 }}
#                         @if($stats->asian_handicap_home_plus_2 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_plus_2 - $odd->pre_asian_handicap_away_plus_2 }}
#                         @if($stats->asian_handicap_away_plus_2 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_plus_225 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_225 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_225 }}
#                     </div>
#                     <div class="col-4">
#                         +2.25
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_plus_225 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_plus_225 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_225 + $odd->pre_asian_handicap_away_plus_225 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_225 + $odd->end_asian_handicap_away_plus_225 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_plus_225 - $odd->pre_asian_handicap_home_plus_225 }}
#                         @if($stats->asian_handicap_home_plus_225 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_plus_225 - $odd->pre_asian_handicap_away_plus_225 }}
#                         @if($stats->asian_handicap_away_plus_225 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_plus_25 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_25 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_25 }}
#                     </div>
#                     <div class="col-4">
#                         +2.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_plus_25 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_plus_25 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_25 + $odd->pre_asian_handicap_away_plus_25 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_25 + $odd->end_asian_handicap_away_plus_25 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_plus_25 - $odd->pre_asian_handicap_home_plus_25 }}
#                         @if($stats->asian_handicap_home_plus_25 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_plus_25 - $odd->pre_asian_handicap_away_plus_25 }}
#                         @if($stats->asian_handicap_away_plus_25 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_plus_275 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_275 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_275 }}
#                     </div>
#                     <div class="col-4">
#                         +2.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_plus_275 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_plus_275 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_275 + $odd->pre_asian_handicap_away_plus_275 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_275 + $odd->end_asian_handicap_away_plus_275 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_plus_275 - $odd->pre_asian_handicap_home_plus_275 }}
#                         @if($stats->asian_handicap_home_plus_275 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_plus_275 - $odd->pre_asian_handicap_away_plus_275 }}
#                         @if($stats->asian_handicap_away_plus_275 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_plus_3 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_3 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_3 }}
#                     </div>
#                     <div class="col-4">
#                         +3
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_plus_3 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_plus_3 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_3 + $odd->pre_asian_handicap_away_plus_3 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_3 + $odd->end_asian_handicap_away_plus_3 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_plus_3 - $odd->pre_asian_handicap_home_plus_3 }}
#                         @if($stats->asian_handicap_home_plus_3 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_plus_3 - $odd->pre_asian_handicap_away_plus_3 }}
#                         @if($stats->asian_handicap_away_plus_3 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_plus_325 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_325 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_325 }}
#                     </div>
#                     <div class="col-4">
#                         +3.25
#                         @if($stats->asian_handicap_away_plus_625 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_plus_65 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_65 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_65 }}
#                     </div>
#                     <div class="col-4">
#                         +6.5
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_plus_65 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_plus_65 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_65 + $odd->pre_asian_handicap_away_plus_65 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_65 + $odd->end_asian_handicap_away_plus_65 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_plus_65 - $odd->pre_asian_handicap_home_plus_65 }}
#                         @if($stats->asian_handicap_home_plus_65 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_plus_65 - $odd->pre_asian_handicap_away_plus_65 }}
#                         @if($stats->asian_handicap_away_plus_65 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($asian_handicap_home_plus_675 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Asian Handicap #4
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_675 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_675 }}
#                     </div>
#                     <div class="col-4">
#                         +6.75
#                         <br/>
#                         {{ $odd->pre_asian_handicap_away_plus_675 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_away_plus_675 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_asian_handicap_home_plus_675 + $odd->pre_asian_handicap_away_plus_675 }}
#                         <br/>
#                         {{ $odd->end_asian_handicap_home_plus_675 + $odd->end_asian_handicap_away_plus_675 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_home_plus_675 - $odd->pre_asian_handicap_home_plus_675 }}
#                         @if($stats->asian_handicap_home_plus_675 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_asian_handicap_away_plus_675 - $odd->pre_asian_handicap_away_plus_675 }}
#                         @if($stats->asian_handicap_away_plus_675 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
