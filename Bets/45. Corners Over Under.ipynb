# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 45 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($odd->pre_"+columnx_1+") && !is_null($odd->pre_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->pre_"+columnx_1+" + $odd->pre_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($odd->pre_corners_over_under_over_700) && !is_null($odd->pre_corners_over_under_under_700) )
#     {
#         if( ($odd->pre_corners_over_under_over_700 + $odd->pre_corners_over_under_under_700) < 4 )
#         {
#             $corners_over_under_over_700 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_725) && !is_null($odd->pre_corners_over_under_under_725) )
#     {
#         if( ($odd->pre_corners_over_under_over_725 + $odd->pre_corners_over_under_under_725) < 4 )
#         {
#             $corners_over_under_over_725 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_750) && !is_null($odd->pre_corners_over_under_under_750) )
#     {
#         if( ($odd->pre_corners_over_under_over_750 + $odd->pre_corners_over_under_under_750) < 4 )
#         {
#             $corners_over_under_over_750 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_775) && !is_null($odd->pre_corners_over_under_under_775) )
#     {
#         if( ($odd->pre_corners_over_under_over_775 + $odd->pre_corners_over_under_under_775) < 4 )
#         {
#             $corners_over_under_over_775 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_800) && !is_null($odd->pre_corners_over_under_under_800) )
#     {
#         if( ($odd->pre_corners_over_under_over_800 + $odd->pre_corners_over_under_under_800) < 4 )
#         {
#             $corners_over_under_over_800 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_825) && !is_null($odd->pre_corners_over_under_under_825) )
#     {
#         if( ($odd->pre_corners_over_under_over_825 + $odd->pre_corners_over_under_under_825) < 4 )
#         {
#             $corners_over_under_over_825 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_850) && !is_null($odd->pre_corners_over_under_under_850) )
#     {
#         if( ($odd->pre_corners_over_under_over_850 + $odd->pre_corners_over_under_under_850) < 4 )
#         {
#             $corners_over_under_over_850 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_875) && !is_null($odd->pre_corners_over_under_under_875) )
#     {
#         if( ($odd->pre_corners_over_under_over_875 + $odd->pre_corners_over_under_under_875) < 4 )
#         {
#             $corners_over_under_over_875 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_900) && !is_null($odd->pre_corners_over_under_under_900) )
#     {
#         if( ($odd->pre_corners_over_under_over_900 + $odd->pre_corners_over_under_under_900) < 4 )
#         {
#             $corners_over_under_over_900 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_925) && !is_null($odd->pre_corners_over_under_under_925) )
#     {
#         if( ($odd->pre_corners_over_under_over_925 + $odd->pre_corners_over_under_under_925) < 4 )
#         {
#             $corners_over_under_over_925 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_950) && !is_null($odd->pre_corners_over_under_under_950) )
#     {
#         if( ($odd->pre_corners_over_under_over_950 + $odd->pre_corners_over_under_under_950) < 4 )
#         {
#             $corners_over_under_over_950 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_975) && !is_null($odd->pre_corners_over_under_under_975) )
#     {
#         if( ($odd->pre_corners_over_under_over_975 + $odd->pre_corners_over_under_under_975) < 4 )
#         {
#             $corners_over_under_over_975 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1000) && !is_null($odd->pre_corners_over_under_under_1000) )
#     {
#         if( ($odd->pre_corners_over_under_over_1000 + $odd->pre_corners_over_under_under_1000) < 4 )
#         {
#             $corners_over_under_over_1000 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1025) && !is_null($odd->pre_corners_over_under_under_1025) )
#     {
#         if( ($odd->pre_corners_over_under_over_1025 + $odd->pre_corners_over_under_under_1025) < 4 )
#         {
#             $corners_over_under_over_1025 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1050) && !is_null($odd->pre_corners_over_under_under_1050) )
#     {
#         if( ($odd->pre_corners_over_under_over_1050 + $odd->pre_corners_over_under_under_1050) < 4 )
#         {
#             $corners_over_under_over_1050 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1075) && !is_null($odd->pre_corners_over_under_under_1075) )
#     {
#         if( ($odd->pre_corners_over_under_over_1075 + $odd->pre_corners_over_under_under_1075) < 4 )
#         {
#             $corners_over_under_over_1075 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1100) && !is_null($odd->pre_corners_over_under_under_1100) )
#     {
#         if( ($odd->pre_corners_over_under_over_1100 + $odd->pre_corners_over_under_under_1100) < 4 )
#         {
#             $corners_over_under_over_1100 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1125) && !is_null($odd->pre_corners_over_under_under_1125) )
#     {
#         if( ($odd->pre_corners_over_under_over_1125 + $odd->pre_corners_over_under_under_1125) < 4 )
#         {
#             $corners_over_under_over_1125 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1150) && !is_null($odd->pre_corners_over_under_under_1150) )
#     {
#         if( ($odd->pre_corners_over_under_over_1150 + $odd->pre_corners_over_under_under_1150) < 4 )
#         {
#             $corners_over_under_over_1150 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1175) && !is_null($odd->pre_corners_over_under_under_1175) )
#     {
#         if( ($odd->pre_corners_over_under_over_1175 + $odd->pre_corners_over_under_under_1175) < 4 )
#         {
#             $corners_over_under_over_1175 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1200) && !is_null($odd->pre_corners_over_under_under_1200) )
#     {
#         if( ($odd->pre_corners_over_under_over_1200 + $odd->pre_corners_over_under_under_1200) < 4 )
#         {
#             $corners_over_under_over_1200 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1225) && !is_null($odd->pre_corners_over_under_under_1225) )
#     {
#         if( ($odd->pre_corners_over_under_over_1225 + $odd->pre_corners_over_under_under_1225) < 4 )
#         {
#             $corners_over_under_over_1225 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1250) && !is_null($odd->pre_corners_over_under_under_1250) )
#     {
#         if( ($odd->pre_corners_over_under_over_1250 + $odd->pre_corners_over_under_under_1250) < 4 )
#         {
#             $corners_over_under_over_1250 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_corners_over_under_over_1275) && !is_null($odd->pre_corners_over_under_under_1275) )
#     {
#         if( ($odd->pre_corners_over_under_over_1275 + $odd->pre_corners_over_under_under_1275) < 4 )
#         {
#             $corners_over_under_over_1275 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 45 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($odd->end_"+columnx_1+") && !is_null($odd->end_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->end_"+columnx_1+" + $odd->end_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($odd->end_corners_over_under_over_700) && !is_null($odd->end_corners_over_under_under_700) )
#     {
#         if( ($odd->end_corners_over_under_over_700 + $odd->end_corners_over_under_under_700) < 4 )
#         {
#             $corners_over_under_over_700 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_725) && !is_null($odd->end_corners_over_under_under_725) )
#     {
#         if( ($odd->end_corners_over_under_over_725 + $odd->end_corners_over_under_under_725) < 4 )
#         {
#             $corners_over_under_over_725 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_750) && !is_null($odd->end_corners_over_under_under_750) )
#     {
#         if( ($odd->end_corners_over_under_over_750 + $odd->end_corners_over_under_under_750) < 4 )
#         {
#             $corners_over_under_over_750 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_775) && !is_null($odd->end_corners_over_under_under_775) )
#     {
#         if( ($odd->end_corners_over_under_over_775 + $odd->end_corners_over_under_under_775) < 4 )
#         {
#             $corners_over_under_over_775 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_800) && !is_null($odd->end_corners_over_under_under_800) )
#     {
#         if( ($odd->end_corners_over_under_over_800 + $odd->end_corners_over_under_under_800) < 4 )
#         {
#             $corners_over_under_over_800 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_825) && !is_null($odd->end_corners_over_under_under_825) )
#     {
#         if( ($odd->end_corners_over_under_over_825 + $odd->end_corners_over_under_under_825) < 4 )
#         {
#             $corners_over_under_over_825 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_850) && !is_null($odd->end_corners_over_under_under_850) )
#     {
#         if( ($odd->end_corners_over_under_over_850 + $odd->end_corners_over_under_under_850) < 4 )
#         {
#             $corners_over_under_over_850 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_875) && !is_null($odd->end_corners_over_under_under_875) )
#     {
#         if( ($odd->end_corners_over_under_over_875 + $odd->end_corners_over_under_under_875) < 4 )
#         {
#             $corners_over_under_over_875 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_900) && !is_null($odd->end_corners_over_under_under_900) )
#     {
#         if( ($odd->end_corners_over_under_over_900 + $odd->end_corners_over_under_under_900) < 4 )
#         {
#             $corners_over_under_over_900 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_925) && !is_null($odd->end_corners_over_under_under_925) )
#     {
#         if( ($odd->end_corners_over_under_over_925 + $odd->end_corners_over_under_under_925) < 4 )
#         {
#             $corners_over_under_over_925 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_950) && !is_null($odd->end_corners_over_under_under_950) )
#     {
#         if( ($odd->end_corners_over_under_over_950 + $odd->end_corners_over_under_under_950) < 4 )
#         {
#             $corners_over_under_over_950 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_975) && !is_null($odd->end_corners_over_under_under_975) )
#     {
#         if( ($odd->end_corners_over_under_over_975 + $odd->end_corners_over_under_under_975) < 4 )
#         {
#             $corners_over_under_over_975 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1000) && !is_null($odd->end_corners_over_under_under_1000) )
#     {
#         if( ($odd->end_corners_over_under_over_1000 + $odd->end_corners_over_under_under_1000) < 4 )
#         {
#             $corners_over_under_over_1000 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1025) && !is_null($odd->end_corners_over_under_under_1025) )
#     {
#         if( ($odd->end_corners_over_under_over_1025 + $odd->end_corners_over_under_under_1025) < 4 )
#         {
#             $corners_over_under_over_1025 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1050) && !is_null($odd->end_corners_over_under_under_1050) )
#     {
#         if( ($odd->end_corners_over_under_over_1050 + $odd->end_corners_over_under_under_1050) < 4 )
#         {
#             $corners_over_under_over_1050 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1075) && !is_null($odd->end_corners_over_under_under_1075) )
#     {
#         if( ($odd->end_corners_over_under_over_1075 + $odd->end_corners_over_under_under_1075) < 4 )
#         {
#             $corners_over_under_over_1075 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1100) && !is_null($odd->end_corners_over_under_under_1100) )
#     {
#         if( ($odd->end_corners_over_under_over_1100 + $odd->end_corners_over_under_under_1100) < 4 )
#         {
#             $corners_over_under_over_1100 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1125) && !is_null($odd->end_corners_over_under_under_1125) )
#     {
#         if( ($odd->end_corners_over_under_over_1125 + $odd->end_corners_over_under_under_1125) < 4 )
#         {
#             $corners_over_under_over_1125 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1150) && !is_null($odd->end_corners_over_under_under_1150) )
#     {
#         if( ($odd->end_corners_over_under_over_1150 + $odd->end_corners_over_under_under_1150) < 4 )
#         {
#             $corners_over_under_over_1150 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1175) && !is_null($odd->end_corners_over_under_under_1175) )
#     {
#         if( ($odd->end_corners_over_under_over_1175 + $odd->end_corners_over_under_under_1175) < 4 )
#         {
#             $corners_over_under_over_1175 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1200) && !is_null($odd->end_corners_over_under_under_1200) )
#     {
#         if( ($odd->end_corners_over_under_over_1200 + $odd->end_corners_over_under_under_1200) < 4 )
#         {
#             $corners_over_under_over_1200 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1225) && !is_null($odd->end_corners_over_under_under_1225) )
#     {
#         if( ($odd->end_corners_over_under_over_1225 + $odd->end_corners_over_under_under_1225) < 4 )
#         {
#             $corners_over_under_over_1225 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1250) && !is_null($odd->end_corners_over_under_under_1250) )
#     {
#         if( ($odd->end_corners_over_under_over_1250 + $odd->end_corners_over_under_under_1250) < 4 )
#         {
#             $corners_over_under_over_1250 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_corners_over_under_over_1275) && !is_null($odd->end_corners_over_under_under_1275) )
#     {
#         if( ($odd->end_corners_over_under_over_1275 + $odd->end_corners_over_under_under_1275) < 4 )
#         {
#             $corners_over_under_over_1275 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 45 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "$"+columnx_1+" = 0;"
        print(word, flush=True) 
        # ----------------------------------------------  
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
# $corners_over_under_over_700 = 0;
# $corners_over_under_over_725 = 0;
# $corners_over_under_over_750 = 0;
# $corners_over_under_over_775 = 0;
# $corners_over_under_over_800 = 0;
# $corners_over_under_over_825 = 0;
# $corners_over_under_over_850 = 0;
# $corners_over_under_over_875 = 0;
# $corners_over_under_over_900 = 0;
# $corners_over_under_over_925 = 0;
# $corners_over_under_over_950 = 0;
# $corners_over_under_over_975 = 0;
# $corners_over_under_over_1000 = 0;
# $corners_over_under_over_1025 = 0;
# $corners_over_under_over_1050 = 0;
# $corners_over_under_over_1075 = 0;
# $corners_over_under_over_1100 = 0;
# $corners_over_under_over_1125 = 0;
# $corners_over_under_over_1150 = 0;
# $corners_over_under_over_1175 = 0;
# $corners_over_under_over_1200 = 0;
# $corners_over_under_over_1225 = 0;
# $corners_over_under_over_1250 = 0;
# $corners_over_under_over_1275 = 0;
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 45 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0  
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "@if($"+columnx_1+" == 1)"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        <div class="card">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-header">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                ' + bet_1 + ' #' + str(bet_id_1)
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-body text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        Home ' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        ' + value_2.replace('Under ', '') 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' + $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' + $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-footer text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' - $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_1+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' - $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_2+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "@endif"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ----------------------------------------------
# Out:
# @if($corners_over_under_over_700 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_700 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_700 }}
#                     </div>
#                     <div class="col-4">
#                         7
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_700 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_700 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_700 + $odd->pre_corners_over_under_under_700 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_700 + $odd->end_corners_over_under_under_700 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_700 - $odd->pre_corners_over_under_over_700 }}
#                         @if($stats->corners_over_under_over_700 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_700 - $odd->pre_corners_over_under_under_700 }}
#                         @if($stats->corners_over_under_under_700 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_725 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_725 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_725 }}
#                     </div>
#                     <div class="col-4">
#                         7.25
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_725 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_725 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_725 + $odd->pre_corners_over_under_under_725 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_725 + $odd->end_corners_over_under_under_725 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_725 - $odd->pre_corners_over_under_over_725 }}
#                         @if($stats->corners_over_under_over_725 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_725 - $odd->pre_corners_over_under_under_725 }}
#                         @if($stats->corners_over_under_under_725 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_750 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_750 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_750 }}
#                     </div>
#                     <div class="col-4">
#                         7.5
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_750 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_750 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_750 + $odd->pre_corners_over_under_under_750 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_750 + $odd->end_corners_over_under_under_750 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_750 - $odd->pre_corners_over_under_over_750 }}
#                         @if($stats->corners_over_under_over_750 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_750 - $odd->pre_corners_over_under_under_750 }}
#                         @if($stats->corners_over_under_under_750 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_775 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_775 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_775 }}
#                     </div>
#                     <div class="col-4">
#                         7.75
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_775 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_775 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_775 + $odd->pre_corners_over_under_under_775 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_775 + $odd->end_corners_over_under_under_775 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_775 - $odd->pre_corners_over_under_over_775 }}
#                         @if($stats->corners_over_under_over_775 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_775 - $odd->pre_corners_over_under_under_775 }}
#                         @if($stats->corners_over_under_under_775 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_800 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_800 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_800 }}
#                     </div>
#                     <div class="col-4">
#                         8
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_800 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_800 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_800 + $odd->pre_corners_over_under_under_800 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_800 + $odd->end_corners_over_under_under_800 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_800 - $odd->pre_corners_over_under_over_800 }}
#                         @if($stats->corners_over_under_over_800 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_800 - $odd->pre_corners_over_under_under_800 }}
#                         @if($stats->corners_over_under_under_800 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_825 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_825 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_825 }}
#                     </div>
#                     <div class="col-4">
#                         8.25
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_825 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_825 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_825 + $odd->pre_corners_over_under_under_825 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_825 + $odd->end_corners_over_under_under_825 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_825 - $odd->pre_corners_over_under_over_825 }}
#                         @if($stats->corners_over_under_over_825 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_825 - $odd->pre_corners_over_under_under_825 }}
#                         @if($stats->corners_over_under_under_825 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_850 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_850 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_850 }}
#                     </div>
#                     <div class="col-4">
#                         8.5
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_850 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_850 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_850 + $odd->pre_corners_over_under_under_850 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_850 + $odd->end_corners_over_under_under_850 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_850 - $odd->pre_corners_over_under_over_850 }}
#                         @if($stats->corners_over_under_over_850 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_850 - $odd->pre_corners_over_under_under_850 }}
#                         @if($stats->corners_over_under_under_850 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_875 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_875 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_875 }}
#                     </div>
#                     <div class="col-4">
#                         8.75
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_875 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_875 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_875 + $odd->pre_corners_over_under_under_875 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_875 + $odd->end_corners_over_under_under_875 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_875 - $odd->pre_corners_over_under_over_875 }}
#                         @if($stats->corners_over_under_over_875 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_875 - $odd->pre_corners_over_under_under_875 }}
#                         @if($stats->corners_over_under_under_875 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_900 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_900 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_900 }}
#                     </div>
#                     <div class="col-4">
#                         9
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_900 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_900 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_900 + $odd->pre_corners_over_under_under_900 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_900 + $odd->end_corners_over_under_under_900 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_900 - $odd->pre_corners_over_under_over_900 }}
#                         @if($stats->corners_over_under_over_900 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_900 - $odd->pre_corners_over_under_under_900 }}
#                         @if($stats->corners_over_under_under_900 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_925 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_925 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_925 }}
#                     </div>
#                     <div class="col-4">
#                         9.25
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_925 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_925 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_925 + $odd->pre_corners_over_under_under_925 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_925 + $odd->end_corners_over_under_under_925 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_925 - $odd->pre_corners_over_under_over_925 }}
#                         @if($stats->corners_over_under_over_925 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_925 - $odd->pre_corners_over_under_under_925 }}
#                         @if($stats->corners_over_under_under_925 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_950 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_950 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_950 }}
#                     </div>
#                     <div class="col-4">
#                         9.5
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_950 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_950 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_950 + $odd->pre_corners_over_under_under_950 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_950 + $odd->end_corners_over_under_under_950 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_950 - $odd->pre_corners_over_under_over_950 }}
#                         @if($stats->corners_over_under_over_950 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_950 - $odd->pre_corners_over_under_under_950 }}
#                         @if($stats->corners_over_under_under_950 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_975 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_975 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_975 }}
#                     </div>
#                     <div class="col-4">
#                         9.75
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_975 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_975 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_975 + $odd->pre_corners_over_under_under_975 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_975 + $odd->end_corners_over_under_under_975 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_975 - $odd->pre_corners_over_under_over_975 }}
#                         @if($stats->corners_over_under_over_975 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_975 - $odd->pre_corners_over_under_under_975 }}
#                         @if($stats->corners_over_under_under_975 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1000 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1000 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1000 }}
#                     </div>
#                     <div class="col-4">
#                         10
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1000 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1000 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1000 + $odd->pre_corners_over_under_under_1000 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1000 + $odd->end_corners_over_under_under_1000 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1000 - $odd->pre_corners_over_under_over_1000 }}
#                         @if($stats->corners_over_under_over_1000 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1000 - $odd->pre_corners_over_under_under_1000 }}
#                         @if($stats->corners_over_under_under_1000 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1025 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1025 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1025 }}
#                     </div>
#                     <div class="col-4">
#                         10.25
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1025 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1025 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1025 + $odd->pre_corners_over_under_under_1025 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1025 + $odd->end_corners_over_under_under_1025 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1025 - $odd->pre_corners_over_under_over_1025 }}
#                         @if($stats->corners_over_under_over_1025 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1025 - $odd->pre_corners_over_under_under_1025 }}
#                         @if($stats->corners_over_under_under_1025 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1050 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1050 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1050 }}
#                     </div>
#                     <div class="col-4">
#                         10.5
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1050 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1050 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1050 + $odd->pre_corners_over_under_under_1050 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1050 + $odd->end_corners_over_under_under_1050 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1050 - $odd->pre_corners_over_under_over_1050 }}
#                         @if($stats->corners_over_under_over_1050 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1050 - $odd->pre_corners_over_under_under_1050 }}
#                         @if($stats->corners_over_under_under_1050 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1075 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1075 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1075 }}
#                     </div>
#                     <div class="col-4">
#                         10.75
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1075 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1075 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1075 + $odd->pre_corners_over_under_under_1075 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1075 + $odd->end_corners_over_under_under_1075 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1075 - $odd->pre_corners_over_under_over_1075 }}
#                         @if($stats->corners_over_under_over_1075 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1075 - $odd->pre_corners_over_under_under_1075 }}
#                         @if($stats->corners_over_under_under_1075 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1100 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1100 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1100 }}
#                     </div>
#                     <div class="col-4">
#                         11
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1100 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1100 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1100 + $odd->pre_corners_over_under_under_1100 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1100 + $odd->end_corners_over_under_under_1100 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1100 - $odd->pre_corners_over_under_over_1100 }}
#                         @if($stats->corners_over_under_over_1100 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1100 - $odd->pre_corners_over_under_under_1100 }}
#                         @if($stats->corners_over_under_under_1100 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1125 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1125 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1125 }}
#                     </div>
#                     <div class="col-4">
#                         11.25
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1125 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1125 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1125 + $odd->pre_corners_over_under_under_1125 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1125 + $odd->end_corners_over_under_under_1125 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1125 - $odd->pre_corners_over_under_over_1125 }}
#                         @if($stats->corners_over_under_over_1125 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1125 - $odd->pre_corners_over_under_under_1125 }}
#                         @if($stats->corners_over_under_under_1125 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1150 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1150 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1150 }}
#                     </div>
#                     <div class="col-4">
#                         11.5
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1150 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1150 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1150 + $odd->pre_corners_over_under_under_1150 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1150 + $odd->end_corners_over_under_under_1150 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1150 - $odd->pre_corners_over_under_over_1150 }}
#                         @if($stats->corners_over_under_over_1150 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1150 - $odd->pre_corners_over_under_under_1150 }}
#                         @if($stats->corners_over_under_under_1150 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1175 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1175 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1175 }}
#                     </div>
#                     <div class="col-4">
#                         11.75
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1175 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1175 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1175 + $odd->pre_corners_over_under_under_1175 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1175 + $odd->end_corners_over_under_under_1175 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1175 - $odd->pre_corners_over_under_over_1175 }}
#                         @if($stats->corners_over_under_over_1175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1175 - $odd->pre_corners_over_under_under_1175 }}
#                         @if($stats->corners_over_under_under_1175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1200 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1200 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1200 }}
#                     </div>
#                     <div class="col-4">
#                         12
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1200 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1200 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1200 + $odd->pre_corners_over_under_under_1200 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1200 + $odd->end_corners_over_under_under_1200 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1200 - $odd->pre_corners_over_under_over_1200 }}
#                         @if($stats->corners_over_under_over_1200 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1200 - $odd->pre_corners_over_under_under_1200 }}
#                         @if($stats->corners_over_under_under_1200 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1225 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1225 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1225 }}
#                     </div>
#                     <div class="col-4">
#                         12.25
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1225 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1225 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1225 + $odd->pre_corners_over_under_under_1225 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1225 + $odd->end_corners_over_under_under_1225 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1225 - $odd->pre_corners_over_under_over_1225 }}
#                         @if($stats->corners_over_under_over_1225 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1225 - $odd->pre_corners_over_under_under_1225 }}
#                         @if($stats->corners_over_under_under_1225 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1250 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1250 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1250 }}
#                     </div>
#                     <div class="col-4">
#                         12.5
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1250 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1250 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1250 + $odd->pre_corners_over_under_under_1250 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1250 + $odd->end_corners_over_under_under_1250 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1250 - $odd->pre_corners_over_under_over_1250 }}
#                         @if($stats->corners_over_under_over_1250 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1250 - $odd->pre_corners_over_under_under_1250 }}
#                         @if($stats->corners_over_under_under_1250 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($corners_over_under_over_1275 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Corners Over Under #45
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1275 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1275 }}
#                     </div>
#                     <div class="col-4">
#                         12.75
#                         <br/>
#                         {{ $odd->pre_corners_over_under_under_1275 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_under_1275 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_corners_over_under_over_1275 + $odd->pre_corners_over_under_under_1275 }}
#                         <br/>
#                         {{ $odd->end_corners_over_under_over_1275 + $odd->end_corners_over_under_under_1275 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_over_1275 - $odd->pre_corners_over_under_over_1275 }}
#                         @if($stats->corners_over_under_over_1275 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_corners_over_under_under_1275 - $odd->pre_corners_over_under_under_1275 }}
#                         @if($stats->corners_over_under_under_1275 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
