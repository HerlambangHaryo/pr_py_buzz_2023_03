# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 26 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($odd->pre_"+columnx_1+") && !is_null($odd->pre_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->pre_"+columnx_1+" + $odd->pre_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($odd->pre_goals_overunder__second_half_over_05) && !is_null($odd->pre_goals_overunder__second_half_under_05) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_05 + $odd->pre_goals_overunder__second_half_under_05) < 4 )
#         {
#             $goals_overunder__second_half_over_05 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_075) && !is_null($odd->pre_goals_overunder__second_half_under_075) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_075 + $odd->pre_goals_overunder__second_half_under_075) < 4 )
#         {
#             $goals_overunder__second_half_over_075 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_10) && !is_null($odd->pre_goals_overunder__second_half_under_10) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_10 + $odd->pre_goals_overunder__second_half_under_10) < 4 )
#         {
#             $goals_overunder__second_half_over_10 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_125) && !is_null($odd->pre_goals_overunder__second_half_under_125) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_125 + $odd->pre_goals_overunder__second_half_under_125) < 4 )
#         {
#             $goals_overunder__second_half_over_125 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_15) && !is_null($odd->pre_goals_overunder__second_half_under_15) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_15 + $odd->pre_goals_overunder__second_half_under_15) < 4 )
#         {
#             $goals_overunder__second_half_over_15 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_175) && !is_null($odd->pre_goals_overunder__second_half_under_175) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_175 + $odd->pre_goals_overunder__second_half_under_175) < 4 )
#         {
#             $goals_overunder__second_half_over_175 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_20) && !is_null($odd->pre_goals_overunder__second_half_under_20) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_20 + $odd->pre_goals_overunder__second_half_under_20) < 4 )
#         {
#             $goals_overunder__second_half_over_20 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_225) && !is_null($odd->pre_goals_overunder__second_half_under_225) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_225 + $odd->pre_goals_overunder__second_half_under_225) < 4 )
#         {
#             $goals_overunder__second_half_over_225 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_25) && !is_null($odd->pre_goals_overunder__second_half_under_25) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_25 + $odd->pre_goals_overunder__second_half_under_25) < 4 )
#         {
#             $goals_overunder__second_half_over_25 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_275) && !is_null($odd->pre_goals_overunder__second_half_under_275) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_275 + $odd->pre_goals_overunder__second_half_under_275) < 4 )
#         {
#             $goals_overunder__second_half_over_275 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_30) && !is_null($odd->pre_goals_overunder__second_half_under_30) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_30 + $odd->pre_goals_overunder__second_half_under_30) < 4 )
#         {
#             $goals_overunder__second_half_over_30 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_325) && !is_null($odd->pre_goals_overunder__second_half_under_325) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_325 + $odd->pre_goals_overunder__second_half_under_325) < 4 )
#         {
#             $goals_overunder__second_half_over_325 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_35) && !is_null($odd->pre_goals_overunder__second_half_under_35) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_35 + $odd->pre_goals_overunder__second_half_under_35) < 4 )
#         {
#             $goals_overunder__second_half_over_35 = 1;
#         }
#     }
#
#     if(!is_null($odd->pre_goals_overunder__second_half_over_375) && !is_null($odd->pre_goals_overunder__second_half_under_375) )
#     {
#         if( ($odd->pre_goals_overunder__second_half_over_375 + $odd->pre_goals_overunder__second_half_under_375) < 4 )
#         {
#             $goals_overunder__second_half_over_375 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 26 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0 
        # ---------------------------------------------- 
        word = "    if(!is_null($odd->end_"+columnx_1+") && !is_null($odd->end_"+columnx_2+") )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        if( ($odd->end_"+columnx_1+" + $odd->end_"+columnx_2+") < 4 )"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        {"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "            $"+columnx_1+" = 1;"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "        }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "    }"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ---------------------------------------------- 
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
#     if(!is_null($odd->end_goals_overunder__second_half_over_05) && !is_null($odd->end_goals_overunder__second_half_under_05) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_05 + $odd->end_goals_overunder__second_half_under_05) < 4 )
#         {
#             $goals_overunder__second_half_over_05 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_075) && !is_null($odd->end_goals_overunder__second_half_under_075) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_075 + $odd->end_goals_overunder__second_half_under_075) < 4 )
#         {
#             $goals_overunder__second_half_over_075 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_10) && !is_null($odd->end_goals_overunder__second_half_under_10) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_10 + $odd->end_goals_overunder__second_half_under_10) < 4 )
#         {
#             $goals_overunder__second_half_over_10 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_125) && !is_null($odd->end_goals_overunder__second_half_under_125) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_125 + $odd->end_goals_overunder__second_half_under_125) < 4 )
#         {
#             $goals_overunder__second_half_over_125 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_15) && !is_null($odd->end_goals_overunder__second_half_under_15) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_15 + $odd->end_goals_overunder__second_half_under_15) < 4 )
#         {
#             $goals_overunder__second_half_over_15 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_175) && !is_null($odd->end_goals_overunder__second_half_under_175) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_175 + $odd->end_goals_overunder__second_half_under_175) < 4 )
#         {
#             $goals_overunder__second_half_over_175 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_20) && !is_null($odd->end_goals_overunder__second_half_under_20) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_20 + $odd->end_goals_overunder__second_half_under_20) < 4 )
#         {
#             $goals_overunder__second_half_over_20 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_225) && !is_null($odd->end_goals_overunder__second_half_under_225) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_225 + $odd->end_goals_overunder__second_half_under_225) < 4 )
#         {
#             $goals_overunder__second_half_over_225 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_25) && !is_null($odd->end_goals_overunder__second_half_under_25) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_25 + $odd->end_goals_overunder__second_half_under_25) < 4 )
#         {
#             $goals_overunder__second_half_over_25 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_275) && !is_null($odd->end_goals_overunder__second_half_under_275) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_275 + $odd->end_goals_overunder__second_half_under_275) < 4 )
#         {
#             $goals_overunder__second_half_over_275 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_30) && !is_null($odd->end_goals_overunder__second_half_under_30) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_30 + $odd->end_goals_overunder__second_half_under_30) < 4 )
#         {
#             $goals_overunder__second_half_over_30 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_325) && !is_null($odd->end_goals_overunder__second_half_under_325) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_325 + $odd->end_goals_overunder__second_half_under_325) < 4 )
#         {
#             $goals_overunder__second_half_over_325 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_35) && !is_null($odd->end_goals_overunder__second_half_under_35) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_35 + $odd->end_goals_overunder__second_half_under_35) < 4 )
#         {
#             $goals_overunder__second_half_over_35 = 1;
#         }
#     }
#
#     if(!is_null($odd->end_goals_overunder__second_half_over_375) && !is_null($odd->end_goals_overunder__second_half_under_375) )
#     {
#         if( ($odd->end_goals_overunder__second_half_over_375 + $odd->end_goals_overunder__second_half_under_375) < 4 )
#         {
#             $goals_overunder__second_half_over_375 = 1;
#         }
#     }
#
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 26 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0 
# ---------------------------------------------- 
word = "<?php"
print(word, flush=True) 
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "$"+columnx_1+" = 0;"
        print(word, flush=True) 
        # ----------------------------------------------  
        
word = "?>"
print(word, flush=True)
# ----------------------------------------------
# Out:
# <?php
# $goals_overunder__second_half_over_05 = 0;
# $goals_overunder__second_half_over_075 = 0;
# $goals_overunder__second_half_over_10 = 0;
# $goals_overunder__second_half_over_125 = 0;
# $goals_overunder__second_half_over_15 = 0;
# $goals_overunder__second_half_over_175 = 0;
# $goals_overunder__second_half_over_20 = 0;
# $goals_overunder__second_half_over_225 = 0;
# $goals_overunder__second_half_over_25 = 0;
# $goals_overunder__second_half_over_275 = 0;
# $goals_overunder__second_half_over_30 = 0;
# $goals_overunder__second_half_over_325 = 0;
# $goals_overunder__second_half_over_35 = 0;
# $goals_overunder__second_half_over_375 = 0;
# ?>

# %%
import mysql.connector 
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , bet  "
query += " , value  "
query += " , columny  "
query += " , columnx  "
query += " from bets_old " 
query += " where bet_id = 26 "   
query += " order by bet_id, total asc "   
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result2 =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result2)
# ------------------------------------------------------    
mycursor.close()
mydb.close() 
# ------------------------------------------------------  
counter = 0  
# ------------------------------------------------------
for x in result2: 
    # -------------------------------------------------- 
    counter += 1
        # ---------------------------------------------- 
    
    # -------------------------------------------------- 
    if(counter == 1):
        # ----------------------------------------------  
        bet_id_1 = str(x[0])
        bet_1 = str(x[1])
        value_1 = str(x[2])
        columny_1 = str(x[3])
        columnx_1 = str(x[4])
    
    # -------------------------------------------------- 
    if(counter == 2):
        # ----------------------------------------------  
        bet_id_2 = str(x[0])
        bet_2 = str(x[1])
        value_2 = str(x[2])
        columny_2 = str(x[3])
        columnx_2 = str(x[4])
        # ---------------------------------------------- 
        col2 = x
        counter = 0  
        # ---------------------------------------------- 
        word = "@if($"+columnx_1+" == 1)"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        <div class="card">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-header">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                ' + bet_1 + ' #' + str(bet_id_1)
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-body text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        Home ' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        ' + value_2.replace('Under ', '') 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-3">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->pre_'+columnx_1+' + $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        <br/>' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' + $odd->end_'+columnx_2+' }}' 
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            <div class="card-footer text-center">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                <div class="row">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_1+' - $odd->pre_'+columnx_1+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_1+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                    <div class="col-4">'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                        {{ $odd->end_'+columnx_2+' - $odd->pre_'+columnx_2+' }}' 
        print(word, flush=True)     
        # ---------------------------------------------- 
        word = '                        @if($stats->'+columnx_2+' == 1)' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                            <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                        @endif' 
        print(word, flush=True)      
        # ---------------------------------------------- 
        word = '                    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '                </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '            </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '        </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = '    </div>'
        print(word, flush=True)
        # ---------------------------------------------- 
        word = "@endif"
        print(word, flush=True)
        # ---------------------------------------------- 
        word = ""
        print(word, flush=True)
        # ----------------------------------------------
# Out:
# @if($goals_overunder__second_half_over_05 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_05 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_05 }}
#                     </div>
#                     <div class="col-4">
#                         0.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_05 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_05 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_05 + $odd->pre_goals_overunder__second_half_under_05 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_05 + $odd->end_goals_overunder__second_half_under_05 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_05 - $odd->pre_goals_overunder__second_half_over_05 }}
#                         @if($stats->goals_overunder__second_half_over_05 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_05 - $odd->pre_goals_overunder__second_half_under_05 }}
#                         @if($stats->goals_overunder__second_half_under_05 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_075 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_075 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_075 }}
#                     </div>
#                     <div class="col-4">
#                         0.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_075 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_075 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_075 + $odd->pre_goals_overunder__second_half_under_075 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_075 + $odd->end_goals_overunder__second_half_under_075 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_075 - $odd->pre_goals_overunder__second_half_over_075 }}
#                         @if($stats->goals_overunder__second_half_over_075 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_075 - $odd->pre_goals_overunder__second_half_under_075 }}
#                         @if($stats->goals_overunder__second_half_under_075 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_10 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_10 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_10 }}
#                     </div>
#                     <div class="col-4">
#                         1.0
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_10 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_10 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_10 + $odd->pre_goals_overunder__second_half_under_10 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_10 + $odd->end_goals_overunder__second_half_under_10 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_10 - $odd->pre_goals_overunder__second_half_over_10 }}
#                         @if($stats->goals_overunder__second_half_over_10 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_10 - $odd->pre_goals_overunder__second_half_under_10 }}
#                         @if($stats->goals_overunder__second_half_under_10 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_125 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_125 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_125 }}
#                     </div>
#                     <div class="col-4">
#                         1.25
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_125 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_125 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_125 + $odd->pre_goals_overunder__second_half_under_125 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_125 + $odd->end_goals_overunder__second_half_under_125 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_125 - $odd->pre_goals_overunder__second_half_over_125 }}
#                         @if($stats->goals_overunder__second_half_over_125 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_125 - $odd->pre_goals_overunder__second_half_under_125 }}
#                         @if($stats->goals_overunder__second_half_under_125 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_15 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_15 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_15 }}
#                     </div>
#                     <div class="col-4">
#                         1.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_15 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_15 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_15 + $odd->pre_goals_overunder__second_half_under_15 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_15 + $odd->end_goals_overunder__second_half_under_15 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_15 - $odd->pre_goals_overunder__second_half_over_15 }}
#                         @if($stats->goals_overunder__second_half_over_15 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_15 - $odd->pre_goals_overunder__second_half_under_15 }}
#                         @if($stats->goals_overunder__second_half_under_15 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_175 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_175 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_175 }}
#                     </div>
#                     <div class="col-4">
#                         1.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_175 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_175 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_175 + $odd->pre_goals_overunder__second_half_under_175 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_175 + $odd->end_goals_overunder__second_half_under_175 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_175 - $odd->pre_goals_overunder__second_half_over_175 }}
#                         @if($stats->goals_overunder__second_half_over_175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_175 - $odd->pre_goals_overunder__second_half_under_175 }}
#                         @if($stats->goals_overunder__second_half_under_175 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_20 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_20 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_20 }}
#                     </div>
#                     <div class="col-4">
#                         2.0
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_20 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_20 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_20 + $odd->pre_goals_overunder__second_half_under_20 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_20 + $odd->end_goals_overunder__second_half_under_20 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_20 - $odd->pre_goals_overunder__second_half_over_20 }}
#                         @if($stats->goals_overunder__second_half_over_20 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_20 - $odd->pre_goals_overunder__second_half_under_20 }}
#                         @if($stats->goals_overunder__second_half_under_20 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_225 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_225 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_225 }}
#                     </div>
#                     <div class="col-4">
#                         2.25
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_225 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_225 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_225 + $odd->pre_goals_overunder__second_half_under_225 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_225 + $odd->end_goals_overunder__second_half_under_225 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_225 - $odd->pre_goals_overunder__second_half_over_225 }}
#                         @if($stats->goals_overunder__second_half_over_225 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_225 - $odd->pre_goals_overunder__second_half_under_225 }}
#                         @if($stats->goals_overunder__second_half_under_225 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_25 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_25 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_25 }}
#                     </div>
#                     <div class="col-4">
#                         2.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_25 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_25 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_25 + $odd->pre_goals_overunder__second_half_under_25 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_25 + $odd->end_goals_overunder__second_half_under_25 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_25 - $odd->pre_goals_overunder__second_half_over_25 }}
#                         @if($stats->goals_overunder__second_half_over_25 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_25 - $odd->pre_goals_overunder__second_half_under_25 }}
#                         @if($stats->goals_overunder__second_half_under_25 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_275 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_275 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_275 }}
#                     </div>
#                     <div class="col-4">
#                         2.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_275 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_275 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_275 + $odd->pre_goals_overunder__second_half_under_275 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_275 + $odd->end_goals_overunder__second_half_under_275 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_275 - $odd->pre_goals_overunder__second_half_over_275 }}
#                         @if($stats->goals_overunder__second_half_over_275 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_275 - $odd->pre_goals_overunder__second_half_under_275 }}
#                         @if($stats->goals_overunder__second_half_under_275 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_30 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_30 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_30 }}
#                     </div>
#                     <div class="col-4">
#                         3.0
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_30 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_30 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_30 + $odd->pre_goals_overunder__second_half_under_30 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_30 + $odd->end_goals_overunder__second_half_under_30 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_30 - $odd->pre_goals_overunder__second_half_over_30 }}
#                         @if($stats->goals_overunder__second_half_over_30 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_30 - $odd->pre_goals_overunder__second_half_under_30 }}
#                         @if($stats->goals_overunder__second_half_under_30 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_325 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_325 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_325 }}
#                     </div>
#                     <div class="col-4">
#                         3.25
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_325 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_325 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_325 + $odd->pre_goals_overunder__second_half_under_325 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_325 + $odd->end_goals_overunder__second_half_under_325 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_325 - $odd->pre_goals_overunder__second_half_over_325 }}
#                         @if($stats->goals_overunder__second_half_over_325 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_325 - $odd->pre_goals_overunder__second_half_under_325 }}
#                         @if($stats->goals_overunder__second_half_under_325 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_35 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_35 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_35 }}
#                     </div>
#                     <div class="col-4">
#                         3.5
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_35 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_35 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_35 + $odd->pre_goals_overunder__second_half_under_35 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_35 + $odd->end_goals_overunder__second_half_under_35 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_35 - $odd->pre_goals_overunder__second_half_over_35 }}
#                         @if($stats->goals_overunder__second_half_over_35 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_35 - $odd->pre_goals_overunder__second_half_under_35 }}
#                         @if($stats->goals_overunder__second_half_under_35 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
#
# @if($goals_overunder__second_half_over_375 == 1)
#     <div class="col-3">
#         <div class="card">
#             <div class="card-header">
#                 Goals Over/Under - Second Half #26
#             </div>
#             <div class="card-body text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         Home
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_375 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_375 }}
#                     </div>
#                     <div class="col-4">
#                         3.75
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_under_375 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_under_375 }}
#                     </div>
#                     <div class="col-3">
#                         <br/>
#                         {{ $odd->pre_goals_overunder__second_half_over_375 + $odd->pre_goals_overunder__second_half_under_375 }}
#                         <br/>
#                         {{ $odd->end_goals_overunder__second_half_over_375 + $odd->end_goals_overunder__second_half_under_375 }}
#                     </div>
#                 </div>
#             </div>
#             <div class="card-footer text-center">
#                 <div class="row">
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_over_375 - $odd->pre_goals_overunder__second_half_over_375 }}
#                         @if($stats->goals_overunder__second_half_over_375 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                     <div class="col-4">
#                         {{ $odd->end_goals_overunder__second_half_under_375 - $odd->pre_goals_overunder__second_half_under_375 }}
#                         @if($stats->goals_overunder__second_half_under_375 == 1)
#                             <br/><i class="fas fa-lg fa-fw  fa-check-square text-success"></i>
#                         @endif
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# @endif
