# %%
import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.api_fixtures_new import *   

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    season   = input(space + "Enter your season :  ") 
    # ----------------------------------------------------------   
    DICT = {
        'leagueapi_id' :leagueapi_id,
        'season' :season, 
    }
    # ------------------------------------------------------ 
    afN_controll_match_update(DICT, 'league_season', space)
    # ------------------------------------------------------ 
    print("  ___________________________________________________", flush=True)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-05 23:24:20
#   ____main__
#   ______Enter your leagueapi id :  47
#   ______Enter your season :  2023
#   ________afN_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api1@ariondigitalmedia.com counter is 16
#   ____________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________afN_response_fixtures()
#   ____________leagueapi_id : 47
#   ____________season : 2023
#   ____________ROUTES : league_season
#   ______________Total API Response(s) : 79
#   ________________
#   ________________ [1/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [2/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [3/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [4/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [5/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [6/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [7/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [8/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [9/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [10/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [11/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [12/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [13/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [14/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [15/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [16/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [17/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [18/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [19/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [20/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [21/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [22/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [23/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [24/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [25/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [26/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [27/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [28/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [29/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [30/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [31/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ____________________football_venues INSERTED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [32/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [33/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [34/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [35/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [36/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [37/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [38/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [39/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [40/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [41/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [42/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [43/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [44/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [45/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [46/79] fixture_status: Not Started __ 47 __ 2023-09-09 14:00:00+00:00
