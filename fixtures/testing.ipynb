# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/fixtures"

querystring = {"id":"868290"}

headers = {
	"X-RapidAPI-Key": "0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
print(response.json())
# Out:
# {'get': 'fixtures', 'parameters': {'id': '868290'}, 'errors': [], 'results': 1, 'paging': {'current': 1, 'total': 1}, 'response': [{'fixture': {'id': 868290, 'referee': 'A. Madley', 'timezone': 'UTC', 'date': '2023-05-06T14:00:00+00:00', 'timestamp': 1683381600, 'periods': {'first': 1683381600, 'second': 1683385200}, 'venue': {'id': 555, 'name': 'Etihad Stadium', 'city': 'Manchester'}, 'status': {'long': 'Match Finished', 'short': 'FT', 'elapsed': 90}}, 'league': {'id': 39, 'name': 'Premier League', 'country': 'England', 'logo': 'https://media-2.api-sports.io/football/leagues/39.png', 'flag': 'https://media-2.api-sports.io/flags/gb.svg', 'season': 2022, 'round': 'Regular Season - 35'}, 'teams': {'home': {'id': 50, 'name': 'Manchester City', 'logo': 'https://media-1.api-sports.io/football/teams/50.png', 'winner': True}, 'away': {'id': 63, 'name': 'Leeds', 'logo': 'https://media-1.api-sports.io/football/teams/63.png', 'winner': False}}, 'goals': {'home': 2, 'away': 1}, 'score': {'halft
# ...

# %%
data = response.json() 

array_response = data['response'] 

for row in array_response:
    # --------------------------------------------------
    array_events = row['events'] 
    # --------------------------------------------------
    for eve in array_events:
        print(eve['type'])
    # --------------------------------------------------
    # team_name = row['team']['name']  
    # print(team_name, flush=True)
    # --------------------------------------------------
