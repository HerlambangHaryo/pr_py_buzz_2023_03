# %%
import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.api_fixtures_new import *   
from a_models.date import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    fixtureapi_id   = input(space + "Enter your fixtureapi_id :  ")  
    fixture_updated_at  =  get_today_adds(0, space) 
    # ----------------------------------------------------------    
    DICT = {
        'fixtureapi_id' :fixtureapi_id,
        'fixture_updated_at' :fixture_updated_at, 
    }
    # ---------------------------------------------------------- 
    afN_controll_match_update(DICT, 'fixtureapi_id_EVENT', space) 
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-02 00:30:24
#   ____main__
#   ________get_today_adds()
#   __________adds date_diff : 0
#   __________today_raw : 2023-09-02 00:30:26.377143
#   ________afN_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 67
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________afN_response_fixtures()
#   ____________fixtureapi_id : 881819
#   ____________fixture_updated_at : 2023-09-02 00:30:26.377143
#   ____________ROUTES : fixtureapi_id_EVENT
#   ______________Total API Response(s) : 1
#   ________________
#   ________________ [1/1] fixture_status: Match Finished __ 135 __ 2022-09-01 18:45:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________MASOK fixtureapi_id_EVENT
#   ________________MASOK len(array_events 14
#   ________________time_elapsed: 46
#   ________________playerapi_id: 127011
#   ________________player_name: 'A. Cambiaso'
#   ________________type: 'subst'
#
#   ________________time_elapsed: 46
#   ________________playerapi_id: 179839
#   ________________player_name: 'D. Kasius'
#   ________________type: 'subst'
#
#   ________________time_elapsed: 46
#   ________________playerapi_id: 30755
#   ________________player_name: 'E. Vignato'
#   ________________type: 'subst'
#
#   ________________time_elapsed: 50
#   ________________playerapi_id: 31389
#   ________________player_name: 'Norbert Gyömbér'
#   ________________type: 'Card'
#
#   ________________football_events INSERT
#   ________________time_elapsed: 52
#   ________________playerapi_id: 18830
#   ________________player_name: 'M. Arnautović'
#   ________________type: 'Goal'
#
#   ________________football_events INSERT
#   ________________time_elapsed: 54
#   ________________playerapi_id: 14327
#   ________________player_name: 'D. Bradarić'
#   ________________type: 'subst'
#
#   ________________time_elapsed: 63
#   ________________playerapi_id: 31436
#   ________________player_name: 'F. Bonazzoli'
#   ________________type: 'subst'
#
#   ________________time_elapsed: 64
#   ________________playerapi_id: 1982
#   ________________player_name: 'Gary Medel'
#   ________________type: 'Card'
#
#   ________________football_events INSERT
#   ________________time_elapsed: 65
#   ________________playerapi_id: 30498
#   ________________player_name: 'Lorenzo De Silvestri'
#   ________________type: 'Card'
#
#   ________________football_events INSERT
#   ________________time_elapsed: 74
#   ________________playerapi_id: 30490
#   ________________player_name: 'N. Sansone'
#   ________________type: 'subst'
#
#   ________________time_elapsed: 76
#   ________________playerapi_id: 2945
#   ________________player_name: 'D. Bronn'
#   ________________type: 'subst'
#
#   ________________time_elapsed: 81
#   ________________playerapi_id: 6056
#   ________________player_name: 'N. Domínguez'
#   ________________type: 'subst'
#
#   ________________time_elapsed: 82
#   ________________playerapi_id: 37157
#   ________________player_name: 'Tonny Vilhena'
#   ________________type: 'Card'
#
#   ________________football_events INSERT
#   ________________time_elapsed: 88
#   ________________playerapi_id: 22015
#   ________________player_name: 'B. Dia'
#   ________________type: 'Goal'
#
#   ________________football_events INSERT
# # -------------------------------------------------- End at 2023-09-02 00:30:28
