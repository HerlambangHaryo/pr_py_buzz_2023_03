# %%
import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.api_fixtures_new import *   

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    season   = input(space + "Enter your season :  ") 
    # ----------------------------------------------------------   
    DICT = {
        'leagueapi_id' :leagueapi_id,
        'season' :season, 
    }
    # ------------------------------------------------------ 
    afN_controll_match_update(DICT, 'league_season', space)
    # ------------------------------------------------------ 
    print("  ___________________________________________________", flush=True)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-22 12:09:48
#   ____main__
#   ________afN_controll_match_update()
#   __________aa_check_acccount()
#   ____________API hariyant2410@gmail.com counter is 40
#   ____________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________afN_response_fixtures()
#   ____________leagueapi_id : 3
#   ____________season : 2023
#   ____________ROUTES : league_season
#   ______________Total API Response(s) : 34
#   ________________
#   ________________ [1/34] fixture_status: Match Finished __ 3 __ 2023-08-10 17:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [2/34] fixture_status: Match Finished __ 3 __ 2023-08-17 18:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [3/34] fixture_status: Match Finished __ 3 __ 2023-08-08 14:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [4/34] fixture_status: Match Finished __ 3 __ 2023-08-17 18:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [5/34] fixture_status: Match Finished __ 3 __ 2023-08-10 16:00:00+00:00
#   ____________________football_venues INSERTED
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [6/34] fixture_status: Match Finished __ 3 __ 2023-08-17 16:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [7/34] fixture_status: Match Finished __ 3 __ 2023-08-10 16:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [8/34] fixture_status: Match Finished __ 3 __ 2023-08-17 17:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [9/34] fixture_status: Match Finished __ 3 __ 2023-08-10 17:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [10/34] fixture_status: Match Finished __ 3 __ 2023-08-17 18:00:00+00:00
#   ____________________football_venues INSERTED
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [11/34] fixture_status: Match Finished __ 3 __ 2023-08-10 19:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [12/34] fixture_status: Match Finished __ 3 __ 2023-08-17 17:30:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [13/34] fixture_status: Match Finished __ 3 __ 2023-08-10 19:00:00+00:00
#   ____________________football_venues INSERTED
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [14/34] fixture_status: Match Finished __ 3 __ 2023-08-17 18:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures UPDATED
#   ________________
#   ________________ [15/34] fixture_status: Not Started __ 3 __ 2023-08-24 18:30:00+00:00
#   ____________________football_venues INSERTED
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [16/34] fixture_status: Not Started __ 3 __ 2023-08-31 18:30:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [17/34] fixture_status: Not Started __ 3 __ 2023-08-24 18:30:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [18/34] fixture_status: Not Started __ 3 __ 2023-08-31 17:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [19/34] fixture_status: Not Started __ 3 __ 2023-08-24 17:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [20/34] fixture_status: Not Started __ 3 __ 2023-08-31 17:00:00+00:00
#   ____________________football_venues INSERTED
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [21/34] fixture_status: Not Started __ 3 __ 2023-08-24 19:00:00+00:00
#   ____________________football_venues INSERTED
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [22/34] fixture_status: Not Started __ 3 __ 2023-08-31 18:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [23/34] fixture_status: Not Started __ 3 __ 2023-08-24 18:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [24/34] fixture_status: Not Started __ 3 __ 2023-08-31 18:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [25/34] fixture_status: Not Started __ 3 __ 2023-08-24 19:00:00+00:00
#   ____________________football_venues INSERTED
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [26/34] fixture_status: Not Started __ 3 __ 2023-08-31 18:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [27/34] fixture_status: Not Started __ 3 __ 2023-08-24 17:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [28/34] fixture_status: Not Started __ 3 __ 2023-08-31 18:45:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [29/34] fixture_status: Not Started __ 3 __ 2023-08-24 18:45:00+00:00
#   ____________________football_venues INSERTED
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [30/34] fixture_status: Not Started __ 3 __ 2023-08-31 17:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [31/34] fixture_status: Not Started __ 3 __ 2023-08-24 18:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [32/34] fixture_status: Not Started __ 3 __ 2023-08-31 16:00:00+00:00
#   ____________________football_venues INSERTED
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [33/34] fixture_status: Not Started __ 3 __ 2023-08-24 18:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ________________
#   ________________ [34/34] fixture_status: Not Started __ 3 __ 2023-08-31 17:00:00+00:00
#   ____________________football_teams UPDATED
#   ____________________football_teams UPDATED
#   ________________football_fixtures INSERTED
#   ___________________________________________________
# # -------------------------------------------------- End at 2023-08-22 12:10:48
