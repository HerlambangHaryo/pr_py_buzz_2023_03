# %%
from a_settings.messages import *  
from a_models.football_set_ones import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # -------------------------------------------------- 
    fso_get_fixture_one(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 18:03:51
#   __main()
#   ____fso_get_fixture_one()
#   ____Select  leagueapi_id  , season  , fixtureapi_id  , (select bookmakersapi_id from football_leagues where football_leagues.leagueapi_id = football_set_ones.leagueapi_id)   from football_set_ones  where status = 1  order by id asc
#   ______Total Row(s) : 28
#   ________  ________1. 84 // 2023 // 1086201 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 99
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1086201
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Regionalliga - Nord  #84 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1086201
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '84'  and season = '2023'  and fixtureapi_id = '1086201'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________2. 84 // 2023 // 1086202 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 98
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1086202
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Regionalliga - Nord  #84 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1086202
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '84'  and season = '2023'  and fixtureapi_id = '1086202'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________3. 84 // 2023 // 1086203 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 97
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1086203
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Regionalliga - Nord  #84 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1086203
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '84'  and season = '2023'  and fixtureapi_id = '1086203'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________4. 86 // 2023 // 1085892 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 96
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1085892
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Regionalliga - SudWest  #86 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1085892
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________5. 86 // 2023 // 1085893 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 95
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1085893
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Regionalliga - SudWest  #86 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1085893
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '86'  and season = '2023'  and fixtureapi_id = '1085893'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________6. 86 // 2023 // 1085896 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 94
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1085896
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Regionalliga - SudWest  #86 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1085896
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________7. 87 // 2023 // 1086509 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 93
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1086509
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Regionalliga - West  #87 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1086509
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '87'  and season = '2023'  and fixtureapi_id = '1086509'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________8. 92 // 2023 // 1094836 // 2
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 92
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1094836
#   ______________bookmaker : 2
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Netherlands,  Derde Divisie - Saturday  #92 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1094836
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '92'  and season = '2023'  and fixtureapi_id = '1094836'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________9. 93 // 2023 // 1095139 // 2
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 91
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1095139
#   ______________bookmaker : 2
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Netherlands,  Derde Divisie - Sunday  #93 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1095139
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '93'  and season = '2023'  and fixtureapi_id = '1095139'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________10. 93 // 2023 // 1095141 // 2
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 90
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1095141
#   ______________bookmaker : 2
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Netherlands,  Derde Divisie - Sunday  #93 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1095141
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '93'  and season = '2023'  and fixtureapi_id = '1095141'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________11. 116 // 2023 // 1009640 // 11
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 89
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1009640
#   ______________bookmaker : 11
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Belarus,  Premier League  #116 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1009640
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '116'  and season = '2023'  and fixtureapi_id = '1009640'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________12. 119 // 2023 // 1034916 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 88
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1034916
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Denmark,  Superliga  #119 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1034916
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '119'  and season = '2023'  and fixtureapi_id = '1034916'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________13. 119 // 2023 // 1034917 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 87
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1034917
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Denmark,  Superliga  #119 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1034917
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '119'  and season = '2023'  and fixtureapi_id = '1034917'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________14. 120 // 2023 // 1037472 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 86
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1037472
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Denmark,  1. Division  #120 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1037472
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '120'  and season = '2023'  and fixtureapi_id = '1037472'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________15. 140 // 2023 // 1037986 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 85
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1037986
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Spain,  La Liga  #140 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1037986
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '140'  and season = '2023'  and fixtureapi_id = '1037986'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________16. 141 // 2023 // 1045222 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 84
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1045222
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Spain,  Segunda División  #141 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1045222
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '141'  and season = '2023'  and fixtureapi_id = '1045222'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________17. 236 // 2023 // 1092790 // 11
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 83
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1092790
#   ______________bookmaker : 11
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Russia,  First League  #236 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1092790
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '236'  and season = '2023'  and fixtureapi_id = '1092790'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________18. 274 // 2023 // 1030046 // 11
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 82
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1030046
#   ______________bookmaker : 11
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Indonesia,  Liga 1  #274 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1030046
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '274'  and season = '2023'  and fixtureapi_id = '1030046'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________19. 274 // 2023 // 1030047 // 11
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 81
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1030047
#   ______________bookmaker : 11
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Indonesia,  Liga 1  #274 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1030047
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '274'  and season = '2023'  and fixtureapi_id = '1030047'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________20. 364 // 2023 // 1018935 // 2
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 80
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1018935
#   ______________bookmaker : 2
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Latvia,  1. Liga  #364 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1018935
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '364'  and season = '2023'  and fixtureapi_id = '1018935'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________21. 474 // 2023 // 980031 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 79
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 980031
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Norway,  2. Division - Group 2  #474 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 980031
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '474'  and season = '2023'  and fixtureapi_id = '980031'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________22. 592 // 2023 // 993095 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 78
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 993095
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Sweden,  Division 2 - Norra Götaland  #592 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 993095
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________23. 592 // 2023 // 993096 // 8
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 77
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 993096
#   ______________bookmaker : 8
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Sweden,  Division 2 - Norra Götaland  #592 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 993096
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '592'  and season = '2023'  and fixtureapi_id = '993096'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________24. 744 // 2023 // 1090147 // 11
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 76
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1090147
#   ______________bookmaker : 11
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Oberliga - Schleswig-Holstein  #744 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1090147
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '744'  and season = '2023'  and fixtureapi_id = '1090147'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________25. 752 // 2023 // 1090724 // 11
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 75
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1090724
#   ______________bookmaker : 11
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Oberliga - Rheinland-Pfalz / Saar  #752 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1090724
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________26. 754 // 2023 // 1089352 // 11
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 74
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1089352
#   ______________bookmaker : 11
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Oberliga - Nordost-Nord  #754 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1089352
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '754'  and season = '2023'  and fixtureapi_id = '1089352'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________27. 755 // 2023 // 1089591 // 11
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 73
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1089591
#   ______________bookmaker : 11
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Germany,  Oberliga - Nordost-Süd  #755 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1089591
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '755'  and season = '2023'  and fixtureapi_id = '1089591'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
#   ________  ________28. 783 // 2023 // 1057410 // 11
#   __________aoN_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 72
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________aoN_response_odds()
#   ______________fixture : 1057410
#   ______________bookmaker : 11
#   ________________Total API Response(s) : 1
#   ________________total_MAX_PAGE : 1
#   __________________
#   __________________1/1
#   __________________Poland,  III Liga - Group 4  #783 - 2023
#   __________________2023-09-03 12:00:00+00:00 // UTC // 1057410
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '783'  and season = '2023'  and fixtureapi_id = '1057410'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   __________________STOP RESPONSE
# # -------------------------------------------------- End at 2023-09-03 18:05:53

# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.xpattern_new_auto import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------      
    xpNa_set_pattern('one_', 4, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 18:05:53
#   __main()
#   ____xpNa_set_pattern()
#   ____Total Row(s) : 28
#   ____
#   ____ [1/28]
#   ____  > fixtureapi_id = 980031
#   ____  __> end_ah_pattern = -1-075-05-025H
#   ____  __> end_ah_pattern_mirror = +025+05+075+1H
#   ____  __> end_gou_pattern = 35gG
#   ____
#   ____  __> end_ah_pattern_4 = -1-075-05-025H
#   ____  __> end_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> end_gou_pattern_4 = 35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [2/28]
#   ____  > fixtureapi_id = 993095
#   ____  __> end_ah_pattern = -025+0+025+05H
#   ____  __> end_ah_pattern_mirror = -05-025+0+025H
#   ____  __> end_gou_pattern = 35gG
#   ____
#   ____  __> end_ah_pattern_4 = -025+0+025+05H
#   ____  __> end_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> end_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [3/28]
#   ____  > fixtureapi_id = 993096
#   ____  __> end_ah_pattern = +0+025+05+075H
#   ____  __> end_ah_pattern_mirror = -075-05-025+0H
#   ____  __> end_gou_pattern = 25g35gG
#   ____
#   ____  __> end_ah_pattern_4 = -025+0+025+05+075H
#   ____  __> end_ah_pattern_mirror_4 = -075-05-025+0+025H
#   ____  __> end_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [4/28]
#   ____  > fixtureapi_id = 1009640
#   ____  __> end_ah_pattern = -125-1-075H
#   ____  __> end_ah_pattern_mirror = +075+1+125H
#   ____  __> end_gou_pattern = 225g25g275gG
#   ____
#   ____  __> end_ah_pattern_4 = -125-1-075H
#   ____  __> end_ah_pattern_mirror_4 = +075+1+125H
#   ____  __> end_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [5/28]
#   ____  > fixtureapi_id = 1034916
#   ____  __> end_ah_pattern = -175-15-125-1H
#   ____  __> end_ah_pattern_mirror = +1+125+15+175H
#   ____  __> end_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> end_ah_pattern_4 = -175-15-125-1H
#   ____  __> end_ah_pattern_mirror_4 = +1+125+15+175H
#   ____  __> end_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [6/28]
#   ____  > fixtureapi_id = 1034917
#   ____  __> end_ah_pattern = +025+05+075+1H
#   ____  __> end_ah_pattern_mirror = -1-075-05-025H
#   ____  __> end_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> end_ah_pattern_4 = +025+05+075+1H
#   ____  __> end_ah_pattern_mirror_4 = -1-075-05-025H
#   ____  __> end_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [7/28]
#   ____  > fixtureapi_id = 1037472
#   ____  __> end_ah_pattern = -075-05-025+0H
#   ____  __> end_ah_pattern_mirror = +0+025+05+075H
#   ____  __> end_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> end_ah_pattern_4 = -075-05-025+0H
#   ____  __> end_ah_pattern_mirror_4 = +0+025+05+075H
#   ____  __> end_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [8/28]
#   ____  > fixtureapi_id = 1037986
#   ____  __> end_ah_pattern = -1-075-05H
#   ____  __> end_ah_pattern_mirror = +05+075+1H
#   ____  __> end_gou_pattern = 225g25g275gG
#   ____
#   ____  __> end_ah_pattern_4 = -1-075-05-025H
#   ____  __> end_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> end_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [9/28]
#   ____  > fixtureapi_id = 1045222
#   ____  __> end_ah_pattern = -05-025+0H
#   ____  __> end_ah_pattern_mirror = +0+025+05H
#   ____  __> end_gou_pattern = 15g175g20g225gG
#   ____
#   ____  __> end_ah_pattern_4 = -05-025+0H
#   ____  __> end_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> end_gou_pattern_4 = 15g175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [10/28]
#   ____  > fixtureapi_id = 1057410
#   ____  __> end_ah_pattern = +0+025+075H
#   ____  __> end_ah_pattern_mirror = -075-025+0H
#   ____  __> end_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> end_ah_pattern_4 = +0+025+075H
#   ____  __> end_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> end_gou_pattern_4 = 225g25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [11/28]
#   ____  > fixtureapi_id = 1090147
#   ____  __> end_ah_pattern = +125+15+175+2+225+25H
#   ____  __> end_ah_pattern_mirror = -25-225-2-175-15-125H
#   ____  __> end_gou_pattern = 35g375g40g425g45g475gG
#   ____
#   ____  __> end_ah_pattern_4 = +125+15+175+2+225+25H
#   ____  __> end_ah_pattern_mirror_4 = -25-225-2-175-15-125H
#   ____  __> end_gou_pattern_4 = 35g375g40g425g45g475g50gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [12/28]
#   ____  > fixtureapi_id = 1085892
#   ____  __> end_ah_pattern = -175-15-125-1-075H
#   ____  __> end_ah_pattern_mirror = +075+1+125+15+175H
#   ____  __> end_gou_pattern = 35gG
#   ____
#   ____  __> end_ah_pattern_4 = -175-15-125-1-075H
#   ____  __> end_ah_pattern_mirror_4 = +075+1+125+15+175H
#   ____  __> end_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [13/28]
#   ____  > fixtureapi_id = 1085893
#   ____  __> end_ah_pattern = -075-05-025H
#   ____  __> end_ah_pattern_mirror = +025+05+075H
#   ____  __> end_gou_pattern = 25gG
#   ____
#   ____  __> end_ah_pattern_4 = -075-05-025+0H
#   ____  __> end_ah_pattern_mirror_4 = +0+025+05+075H
#   ____  __> end_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [14/28]
#   ____  > fixtureapi_id = 1085896
#   ____  __> end_ah_pattern = -1-075-05-025H
#   ____  __> end_ah_pattern_mirror = +025+05+075+1H
#   ____  __> end_gou_pattern = 25gG
#   ____
#   ____  __> end_ah_pattern_4 = -1-075-05-025H
#   ____  __> end_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> end_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [15/28]
#   ____  > fixtureapi_id = 1086201
#   ____  __> end_ah_pattern = -025+0+025+05+075H
#   ____  __> end_ah_pattern_mirror = -075-05-025+0+025H
#   ____  __> end_gou_pattern = 35gG
#   ____
#   ____  __> end_ah_pattern_4 = -025+0+025+05+075H
#   ____  __> end_ah_pattern_mirror_4 = -075-05-025+0+025H
#   ____  __> end_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [16/28]
#   ____  > fixtureapi_id = 1086202
#   ____  __> end_ah_pattern = -175-15-125-1H
#   ____  __> end_ah_pattern_mirror = +1+125+15+175H
#   ____  __> end_gou_pattern = 35gG
#   ____
#   ____  __> end_ah_pattern_4 = -2-175-15-125-1H
#   ____  __> end_ah_pattern_mirror_4 = +1+125+15+175+2H
#   ____  __> end_gou_pattern_4 = 35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [17/28]
#   ____  > fixtureapi_id = 1086203
#   ____  __> end_ah_pattern = +075+1+125+15H
#   ____  __> end_ah_pattern_mirror = -15-125-1-075H
#   ____  __> end_gou_pattern = 35gG
#   ____
#   ____  __> end_ah_pattern_4 = +075+1+125+15+175H
#   ____  __> end_ah_pattern_mirror_4 = -175-15-125-1-075H
#   ____  __> end_gou_pattern_4 = 35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [18/28]
#   ____  > fixtureapi_id = 1086509
#   ____  __> end_ah_pattern = -05-025+0+025H
#   ____  __> end_ah_pattern_mirror = -025+0+025+05H
#   ____  __> end_gou_pattern = 25g35gG
#   ____
#   ____  __> end_ah_pattern_4 = -05-025+0+025H
#   ____  __> end_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> end_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [19/28]
#   ____  > fixtureapi_id = 1092790
#   ____  __> end_ah_pattern = -1-075H
#   ____  __> end_ah_pattern_mirror = +075+1H
#   ____  __> end_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> end_ah_pattern_4 = -1-075H
#   ____  __> end_ah_pattern_mirror_4 = +075+1H
#   ____  __> end_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [20/28]
#   ____  > fixtureapi_id = 1030046
#   ____  __> end_ah_pattern = +0+025+075H
#   ____  __> end_ah_pattern_mirror = -075-025+0H
#   ____  __> end_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> end_ah_pattern_4 = +0+025+075H
#   ____  __> end_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> end_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [21/28]
#   ____  > fixtureapi_id = 1030047
#   ____  __> end_ah_pattern = -125-1-075-025H
#   ____  __> end_ah_pattern_mirror = +025+075+1+125H
#   ____  __> end_gou_pattern = 225g25g275g30g325g35gG
#   ____
#   ____  __> end_ah_pattern_4 = -125-1-075-025H
#   ____  __> end_ah_pattern_mirror_4 = +025+075+1+125H
#   ____  __> end_gou_pattern_4 = 225g25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [22/28]
#   ____  > fixtureapi_id = 1018935
#   ____  __> end_ah_pattern = +125+15+175+2+225H
#   ____  __> end_ah_pattern_mirror = -225-2-175-15-125H
#   ____  __> end_gou_pattern = 30g325g35g375g40gG
#   ____
#   ____  __> end_ah_pattern_4 = +125+15+175+2+225H
#   ____  __> end_ah_pattern_mirror_4 = -225-2-175-15-125H
#   ____  __> end_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [23/28]
#   ____  > fixtureapi_id = 1089352
#   ____  __> end_ah_pattern = -1-075-025H
#   ____  __> end_ah_pattern_mirror = +025+075+1H
#   ____  __> end_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> end_ah_pattern_4 = -1-075-025H
#   ____  __> end_ah_pattern_mirror_4 = +025+075+1H
#   ____  __> end_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [24/28]
#   ____  > fixtureapi_id = 1089591
#   ____  __> end_ah_pattern = +025+075+1H
#   ____  __> end_ah_pattern_mirror = -1-075-025H
#   ____  __> end_gou_pattern = 30g325g35g375g40g425gG
#   ____
#   ____  __> end_ah_pattern_4 = +025+075+1H
#   ____  __> end_ah_pattern_mirror_4 = -1-075-025H
#   ____  __> end_gou_pattern_4 = 30g325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [25/28]
#   ____  > fixtureapi_id = 1090724
#   ____  __> end_ah_pattern = +0+025+075H
#   ____  __> end_ah_pattern_mirror = -075-025+0H
#   ____  __> end_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> end_ah_pattern_4 = +0+025+075H
#   ____  __> end_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> end_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [26/28]
#   ____  > fixtureapi_id = 1095139
#   ____  __> end_ah_pattern = -075-025+0+025H
#   ____  __> end_ah_pattern_mirror = -025+0+025+075H
#   ____  __> end_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> end_ah_pattern_4 = -075-025+0+025H
#   ____  __> end_ah_pattern_mirror_4 = -025+0+025+075H
#   ____  __> end_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [27/28]
#   ____  > fixtureapi_id = 1095141
#   ____  __> end_ah_pattern = -075-025+0H
#   ____  __> end_ah_pattern_mirror = +0+025+075H
#   ____  __> end_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> end_ah_pattern_4 = -075-025+0+025H
#   ____  __> end_ah_pattern_mirror_4 = -025+0+025+075H
#   ____  __> end_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [28/28]
#   ____  > fixtureapi_id = 1094836
#   ____  __> end_ah_pattern = -025+0+025H
#   ____  __> end_ah_pattern_mirror = -025+0+025H
#   ____  __> end_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> end_ah_pattern_4 = -025+0+025H
#   ____  __> end_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> end_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-09-03 18:06:38

# %%
from a_settings.messages import *  
from a_models.one import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # -------------------------------------------------- 
    one_on_one_for_advices(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 18:06:38
#   __main()
#   ____one_on_one_for_advices()
#   ______Select  leagueapi_id   , season   , fixtureapi_id   from football_set_ones  where status = 1
#   ________Total Row(s) : 28
#   __________[1/28]  #84 __ 2023 __ 1086201
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '84'  and season = '2023'  and fixtureapi_id = '1086201'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #84 __ 2023 __ 1086201
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[2/28]  #84 __ 2023 __ 1086202
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '84'  and season = '2023'  and fixtureapi_id = '1086202'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #84 __ 2023 __ 1086202
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[3/28]  #84 __ 2023 __ 1086203
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '84'  and season = '2023'  and fixtureapi_id = '1086203'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #84 __ 2023 __ 1086203
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[4/28]  #86 __ 2023 __ 1085892
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '86'  and season = '2023'  and fixtureapi_id = '1085892'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #86 __ 2023 __ 1085892
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[5/28]  #86 __ 2023 __ 1085893
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '86'  and season = '2023'  and fixtureapi_id = '1085893'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #86 __ 2023 __ 1085893
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[6/28]  #86 __ 2023 __ 1085896
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '86'  and season = '2023'  and fixtureapi_id = '1085896'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #86 __ 2023 __ 1085896
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[7/28]  #87 __ 2023 __ 1086509
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '87'  and season = '2023'  and fixtureapi_id = '1086509'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #87 __ 2023 __ 1086509
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[8/28]  #92 __ 2023 __ 1094836
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '92'  and season = '2023'  and fixtureapi_id = '1094836'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #92 __ 2023 __ 1094836
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[9/28]  #93 __ 2023 __ 1095139
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '93'  and season = '2023'  and fixtureapi_id = '1095139'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #93 __ 2023 __ 1095139
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[10/28]  #93 __ 2023 __ 1095141
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '93'  and season = '2023'  and fixtureapi_id = '1095141'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #93 __ 2023 __ 1095141
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[11/28]  #116 __ 2023 __ 1009640
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '116'  and season = '2023'  and fixtureapi_id = '1009640'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #116 __ 2023 __ 1009640
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[12/28]  #119 __ 2023 __ 1034916
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '119'  and season = '2023'  and fixtureapi_id = '1034916'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #119 __ 2023 __ 1034916
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[13/28]  #119 __ 2023 __ 1034917
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '119'  and season = '2023'  and fixtureapi_id = '1034917'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #119 __ 2023 __ 1034917
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[14/28]  #120 __ 2023 __ 1037472
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '120'  and season = '2023'  and fixtureapi_id = '1037472'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #120 __ 2023 __ 1037472
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[15/28]  #140 __ 2023 __ 1037986
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '140'  and season = '2023'  and fixtureapi_id = '1037986'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #140 __ 2023 __ 1037986
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[16/28]  #141 __ 2023 __ 1045222
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '141'  and season = '2023'  and fixtureapi_id = '1045222'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #141 __ 2023 __ 1045222
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 1
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[17/28]  #236 __ 2023 __ 1092790
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '236'  and season = '2023'  and fixtureapi_id = '1092790'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #236 __ 2023 __ 1092790
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[18/28]  #274 __ 2023 __ 1030046
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '274'  and season = '2023'  and fixtureapi_id = '1030046'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #274 __ 2023 __ 1030046
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 7
#   ____________________one_update_type_of_pattern()
#   ________________________football_fixtures UPDATED
#   ____________________fP_DELETE_football_pattern_from()
#   ______________________DELETE FROM `football_pattern_from`   where leagueapi_id = 274  and pre_ah_pattern = '+0+025+075H'  and pre_gou_pattern = '20g225g25g275gG'  and end_ah_pattern = '+0+025+075H'  and end_gou_pattern = '20g225g25g275gG'
#   ________________________football_pattern_from's DELETED
#   ____________________fpa_group_pattern_to_assess()
#   ______________________status: Pre-End
#   ______________________pre_ah_pattern: +0+025+075H
#   ______________________pre_ah_pattern_mirror: -075-025+0H
#   ______________________pre_gou_pattern: 20g225g25g275gG
#   ______________________end_ah_pattern: +0+025+075H
#   ______________________end_ah_pattern_mirror: -075-025+0H
#   ______________________end_gou_pattern: 20g225g25g275gG
#   ________________________(Select  fo.leagueapi_id   , fo.pre_ah_pattern as pre_ah , fo.pre_gou_pattern   , fo.end_ah_pattern as end_ah , fo.end_gou_pattern   , fo.fixtureapi_id   , 'Original' as statusx   , ff.goals_home as gHome   , ff.goals_away as gAway   , ff.score_halftime_home as hHome   , ff.score_halftime_away as hAway   , ff.score_secondtime_home as sHome   , ff.score_secondtime_away as sAway   from football_odds as fo  inner join football_fixtures as ff  on fo.leagueapi_id = ff.leagueapi_id  and fo.season = ff.season  and fo.fixtureapi_id = ff.fixtureapi_id  where ff.fixture_status IN ('Match Finished', 'Match Finished Ended')  and fo.leagueapi_id = '274'  and fo.pre_ah_pattern = '+0+025+075H'  and fo.pre_gou_pattern = '20g225g25g275gG'  and fo.end_ah_pattern = '+0+025+075H'  and fo.end_gou_pattern = '20g225g25g275gG' )union(Select  fo.leagueapi_id   , fo.pre_ah_pattern_mirror as pre_ah , fo.pre_gou_pattern   , fo.end_ah_pattern_mirror as end_ah  , fo.end_gou_pattern   , fo.fixtureapi_id   , 'Mirror' as statusx   , ff.goals_away as gHome   , ff.goals_home as gAway   , ff.score_halftime_away as hHome   , ff.score_halftime_home as hAway   , ff.score_secondtime_away as sHome   , ff.score_secondtime_home as sAway   from football_odds as fo  inner join football_fixtures as ff  on fo.leagueapi_id = ff.leagueapi_id  and fo.season = ff.season  and fo.fixtureapi_id = ff.fixtureapi_id  where ff.fixture_status IN ('Match Finished', 'Match Finished Ended')  and fo.leagueapi_id = '274'  and pre_ah_pattern = '-075-025+0H'  and pre_gou_pattern = '20g225g25g275gG'  and end_ah_pattern = '-075-025+0H'  and end_gou_pattern = '20g225g25g275gG' )
#   __________________________Total Row(s) to_assess : 7
#   __________________________[1/7]  #274 __ 899561 _|_ 1 __ 1 _|_ 1 __ 1 _|_ 0 __ 0
#   __________________________[2/7]  #274 __ 899775 _|_ 2 __ 0 _|_ 1 __ 0 _|_ 1 __ 0
#   __________________________[3/7]  #274 __ 899603 _|_ 1 __ 2 _|_ 0 __ 0 _|_ 1 __ 2
#   __________________________[4/7]  #274 __ 899694 _|_ 0 __ 2 _|_ 0 __ 1 _|_ 0 __ 1
#   __________________________[5/7]  #274 __ 899711 _|_ 2 __ 1 _|_ 1 __ 0 _|_ 1 __ 1
#   __________________________[6/7]  #274 __ 899738 _|_ 1 __ 1 _|_ 0 __ 1 _|_ 1 __ 0
#   __________________________[7/7]  #274 __ 1029972 _|_ 2 __ 5 _|_ 1 __ 2 _|_ 1 __ 3
#   __________________________asian_handicap_away_min_55_perc: 7 __ 100.0
#   __________________________asian_handicap_away_min_65_perc: 7 __ 100.0
#   __________________________asian_handicap_away_min_2_perc: 6 __ 85.71428571428571
#   __________________________asian_handicap_away_min_3_perc: 7 __ 100.0
#   __________________________asian_handicap_away_min_4_perc: 7 __ 100.0
#   __________________________asian_handicap_away_min_5_perc: 7 __ 100.0
#   __________________________asian_handicap_away_min_6_perc: 7 __ 100.0
#   __________________________asian_handicap_home_plus_25_perc: 6 __ 85.71428571428571
#   __________________________asian_handicap_home_plus_35_perc: 7 __ 100.0
#   __________________________asian_handicap_home_plus_3_perc: 6 __ 85.71428571428571
#   __________________________asian_handicap_home_plus_4_perc: 7 __ 100.0
#   __________________________asian_handicap_home_plus_45_perc: 7 __ 100.0
#   __________________________asian_handicap_home_plus_5_perc: 7 __ 100.0
#   __________________________asian_handicap_home_plus_55_perc: 7 __ 100.0
#   __________________________asian_handicap_home_plus_6_perc: 7 __ 100.0
#   __________________________asian_handicap_home_plus_65_perc: 7 __ 100.0
#   __________________________asian_handicap_away_min_15_perc: 6 __ 85.71428571428571
#   __________________________asian_handicap_away_min_25_perc: 7 __ 100.0
#   __________________________asian_handicap_away_min_35_perc: 7 __ 100.0
#   __________________________asian_handicap_away_min_45_perc: 7 __ 100.0
#   __________________________goals_overunder_under_35_perc: 6 __ 85.71428571428571
#   __________________________goals_overunder_over_15_perc: 7 __ 100.0
#   __________________________goals_overunder_under_45_perc: 6 __ 85.71428571428571
#   __________________________goals_overunder_over_05_perc: 7 __ 100.0
#   __________________________goals_overunder_under_55_perc: 6 __ 85.71428571428571
#   __________________________clean_sheet__home_no_perc: 6 __ 85.71428571428571
#   __________________________clean_sheet__away_no_perc: 6 __ 85.71428571428571
#   ____________________________ INSERT INTO `football_pattern_from`(  `leagueapi_id`,  `total_fixtures`,  `pre_ah_pattern`,  `pre_gou_pattern`,  `end_ah_pattern`,  `end_gou_pattern`,  `match_winner_home_data`,  `match_winner_home_perc`,  `match_winner_draw_data`,  `match_winner_draw_perc`,  `match_winner_away_data`,  `match_winner_away_perc`,  `homeaway_home_data`,  `homeaway_home_perc`,  `homeaway_away_data`,  `homeaway_away_perc`,  `second_half_winner_home_data`,  `second_half_winner_home_perc`,  `second_half_winner_draw_data`,  `second_half_winner_draw_perc`,  `second_half_winner_away_data`,  `second_half_winner_away_perc`,  `asian_handicap_home_min_65_data`,  `asian_handicap_home_min_65_perc`,  `asian_handicap_away_min_65_data`,  `asian_handicap_away_min_65_perc`,  `asian_handicap_home_min_6_data`,  `asian_handicap_home_min_6_perc`,  `asian_handicap_away_min_6_data`,  `asian_handicap_away_min_6_perc`,  `asian_handicap_home_min_55_data`,  `asian_handicap_home_min_55_perc`,  `asian_handicap_away_min_55_data`,  `asian_handicap_away_min_55_perc`,  `asian_handicap_home_min_5_data`,  `asian_handicap_home_min_5_perc`,  `asian_handicap_away_min_5_data`,  `asian_handicap_away_min_5_perc`,  `asian_handicap_home_min_45_data`,  `asian_handicap_home_min_45_perc`,  `asian_handicap_away_min_45_data`,  `asian_handicap_away_min_45_perc`,  `asian_handicap_home_min_4_data`,  `asian_handicap_home_min_4_perc`,  `asian_handicap_away_min_4_data`,  `asian_handicap_away_min_4_perc`,  `asian_handicap_home_min_35_data`,  `asian_handicap_home_min_35_perc`,  `asian_handicap_away_min_35_data`,  `asian_handicap_away_min_35_perc`,  `asian_handicap_home_min_3_data`,  `asian_handicap_home_min_3_perc`,  `asian_handicap_away_min_3_data`,  `asian_handicap_away_min_3_perc`,  `asian_handicap_home_min_25_data`,  `asian_handicap_home_min_25_perc`,  `asian_handicap_away_min_25_data`,  `asian_handicap_away_min_25_perc`,  `asian_handicap_home_min_2_data`,  `asian_handicap_home_min_2_perc`,  `asian_handicap_away_min_2_data`,  `asian_handicap_away_min_2_perc`,  `asian_handicap_home_min_15_data`,  `asian_handicap_home_min_15_perc`,  `asian_handicap_away_min_15_data`,  `asian_handicap_away_min_15_perc`,  `asian_handicap_home_min_1_data`,  `asian_handicap_home_min_1_perc`,  `asian_handicap_away_min_1_data`,  `asian_handicap_away_min_1_perc`,  `asian_handicap_home_min_05_data`,  `asian_handicap_home_min_05_perc`,  `asian_handicap_away_min_05_data`,  `asian_handicap_away_min_05_perc`,  `asian_handicap_home_plus_0_data`,  `asian_handicap_home_plus_0_perc`,  `asian_handicap_away_plus_0_data`,  `asian_handicap_away_plus_0_perc`,  `asian_handicap_home_plus_05_data`,  `asian_handicap_home_plus_05_perc`,  `asian_handicap_away_plus_05_data`,  `asian_handicap_away_plus_05_perc`,  `asian_handicap_home_plus_1_data`,  `asian_handicap_home_plus_1_perc`,  `asian_handicap_away_plus_1_data`,  `asian_handicap_away_plus_1_perc`,  `asian_handicap_home_plus_15_data`,  `asian_handicap_home_plus_15_perc`,  `asian_handicap_away_plus_15_data`,  `asian_handicap_away_plus_15_perc`,  `asian_handicap_home_plus_2_data`,  `asian_handicap_home_plus_2_perc`,  `asian_handicap_away_plus_2_data`,  `asian_handicap_away_plus_2_perc`,  `asian_handicap_home_plus_25_data`,  `asian_handicap_home_plus_25_perc`,  `asian_handicap_away_plus_25_data`,  `asian_handicap_away_plus_25_perc`,  `asian_handicap_home_plus_3_data`,  `asian_handicap_home_plus_3_perc`,  `asian_handicap_away_plus_3_data`,  `asian_handicap_away_plus_3_perc`,  `asian_handicap_home_plus_35_data`,  `asian_handicap_home_plus_35_perc`,  `asian_handicap_away_plus_35_data`,  `asian_handicap_away_plus_35_perc`,  `asian_handicap_home_plus_4_data`,  `asian_handicap_home_plus_4_perc`,  `asian_handicap_away_plus_4_data`,  `asian_handicap_away_plus_4_perc`,  `asian_handicap_home_plus_45_data`,  `asian_handicap_home_plus_45_perc`,  `asian_handicap_away_plus_45_data`,  `asian_handicap_away_plus_45_perc`,  `asian_handicap_home_plus_5_data`,  `asian_handicap_home_ ...
#   ____________________________pattern INSERTED
#   ______________________________fpa_football_pattern_from_updated_at()
#   ________________________________leagueapi_id : 274
#   __________________________________ UPDATE `football_odds` SET   football_pattern_from_only_updated_at = now()  where leagueapi_id = 274  and pre_ah_pattern = '+0+025+075H'  and pre_gou_pattern = '20g225g25g275gG'  and end_ah_pattern = '+0+025+075H'  and end_gou_pattern = '20g225g25g275gG'
#   ____________________________
#   __________[19/28]  #274 __ 2023 __ 1030047
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '274'  and season = '2023'  and fixtureapi_id = '1030047'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #274 __ 2023 __ 1030047
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[20/28]  #364 __ 2023 __ 1018935
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '364'  and season = '2023'  and fixtureapi_id = '1018935'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #364 __ 2023 __ 1018935
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[21/28]  #474 __ 2023 __ 980031
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '474'  and season = '2023'  and fixtureapi_id = '980031'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #474 __ 2023 __ 980031
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 1
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[22/28]  #592 __ 2023 __ 993095
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '592'  and season = '2023'  and fixtureapi_id = '993095'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #592 __ 2023 __ 993095
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[23/28]  #592 __ 2023 __ 993096
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '592'  and season = '2023'  and fixtureapi_id = '993096'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #592 __ 2023 __ 993096
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[24/28]  #744 __ 2023 __ 1090147
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '744'  and season = '2023'  and fixtureapi_id = '1090147'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #744 __ 2023 __ 1090147
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 1
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[25/28]  #752 __ 2023 __ 1090724
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '752'  and season = '2023'  and fixtureapi_id = '1090724'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #752 __ 2023 __ 1090724
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[26/28]  #754 __ 2023 __ 1089352
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '754'  and season = '2023'  and fixtureapi_id = '1089352'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #754 __ 2023 __ 1089352
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 1
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[27/28]  #755 __ 2023 __ 1089591
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '755'  and season = '2023'  and fixtureapi_id = '1089591'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #755 __ 2023 __ 1089591
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
#   __________[28/28]  #783 __ 2023 __ 1057410
#   ____________one_on_football_odds()
#   ______________Select  leagueapi_id   , season   , fixtureapi_id   , pre_ah_pattern   , pre_ah_pattern_mirror   , pre_gou_pattern   , end_ah_pattern   , end_ah_pattern_mirror   , end_gou_pattern   from football_odds  where leagueapi_id = '783'  and season = '2023'  and fixtureapi_id = '1057410'
#   ________________Total Row(s) : 1
#   __________________[1/1]  #783 __ 2023 __ 1057410
#   ____________________one_on_count_league_football_odds()
#   ________________________Total league Row(s) : 0
#   ____________________one_update_zero()
#   ________________________football_fixtures UPDATED
# # -------------------------------------------------- End at 2023-09-03 18:09:18
