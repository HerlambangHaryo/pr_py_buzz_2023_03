# %%
import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *    
from a_models.api_standings import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    season   = input(space + "Enter your season :  ") 
    # ----------------------------------------------------------   
    DICT = {
        'leagueapi_id' :leagueapi_id,
        'season' :season, 
    }
    # ------------------------------------------------------ 
    as_controll_match_update(DICT, "Null", space) 
    # ------------------------------------------------------ 
    print("  ___________________________________________________", flush=True)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-26 23:48:16
#   ____main__
#   ________as_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api5@ariondigitalmedia.com counter is 79
#   ____________APIkey: 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________as_response_odds()
#   ____________DICTleagueapi_id : 61
#   ____________DICTseason : 2023
#   ____________APIkey : 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   ____________Total API Response(s) : 1
#
#   ______________teamapi_id:91
#   ________________aFLS_update_or_insert()
#   ________________leagueapi_id : 61
#   ________________season : 2023
#   ________________teamapi_id : 91
#   __________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 91
#   __________________total_rows: 1
#   ______________api_football_league_standings UPDATED
#   ________________league_standing_updated_at UPDATED 61
#   ________________teamapi_id:106
#   __________________aFLS_update_or_insert()
#   __________________leagueapi_id : 61
#   __________________season : 2023
#   __________________teamapi_id : 106
#   ____________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 106
#   ____________________total_rows: 1
#   ________________api_football_league_standings UPDATED
#   __________________league_standing_updated_at UPDATED 61
#   __________________teamapi_id:94
#   ____________________aFLS_update_or_insert()
#   ____________________leagueapi_id : 61
#   ____________________season : 2023
#   ____________________teamapi_id : 94
#   ______________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 94
#   ______________________total_rows: 1
#   __________________api_football_league_standings UPDATED
#   ____________________league_standing_updated_at UPDATED 61
#   ____________________teamapi_id:82
#   ______________________aFLS_update_or_insert()
#   ______________________leagueapi_id : 61
#   ______________________season : 2023
#   ______________________teamapi_id : 82
#   ________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 82
#   ________________________total_rows: 1
#   ____________________api_football_league_standings UPDATED
#   ______________________league_standing_updated_at UPDATED 61
#   ______________________teamapi_id:79
#   ________________________aFLS_update_or_insert()
#   ________________________leagueapi_id : 61
#   ________________________season : 2023
#   ________________________teamapi_id : 79
#   __________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 79
#   __________________________total_rows: 1
#   ______________________api_football_league_standings UPDATED
#   ________________________league_standing_updated_at UPDATED 61
#   ________________________teamapi_id:81
#   __________________________aFLS_update_or_insert()
#   __________________________leagueapi_id : 61
#   __________________________season : 2023
#   __________________________teamapi_id : 81
#   ____________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 81
#   ____________________________total_rows: 1
#   ________________________api_football_league_standings UPDATED
#   __________________________league_standing_updated_at UPDATED 61
#   __________________________teamapi_id:96
#   ____________________________aFLS_update_or_insert()
#   ____________________________leagueapi_id : 61
#   ____________________________season : 2023
#   ____________________________teamapi_id : 96
#   ______________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 96
#   ______________________________total_rows: 1
#   __________________________api_football_league_standings UPDATED
#   ____________________________league_standing_updated_at UPDATED 61
#   ____________________________teamapi_id:93
#   ______________________________aFLS_update_or_insert()
#   ______________________________leagueapi_id : 61
#   ______________________________season : 2023
#   ______________________________teamapi_id : 93
#   ________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 93
#   ________________________________total_rows: 1
#   ____________________________api_football_league_standings UPDATED
#   ______________________________league_standing_updated_at UPDATED 61
#   ______________________________teamapi_id:95
#   ________________________________aFLS_update_or_insert()
#   ________________________________leagueapi_id : 61
#   ________________________________season : 2023
#   ________________________________teamapi_id : 95
#   __________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 95
#   __________________________________total_rows: 1
#   ______________________________api_football_league_standings UPDATED
#   ________________________________league_standing_updated_at UPDATED 61
#   ________________________________teamapi_id:84
#   __________________________________aFLS_update_or_insert()
#   __________________________________leagueapi_id : 61
#   __________________________________season : 2023
#   __________________________________teamapi_id : 84
#   ____________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 84
#   ____________________________________total_rows: 1
#   ________________________________api_football_league_standings UPDATED
#   __________________________________league_standing_updated_at UPDATED 61
#   __________________________________teamapi_id:97
#   ____________________________________aFLS_update_or_insert()
#   ____________________________________leagueapi_id : 61
#   ____________________________________season : 2023
#   ____________________________________teamapi_id : 97
#   ______________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 97
#   ______________________________________total_rows: 1
#   __________________________________api_football_league_standings UPDATED
#   ____________________________________league_standing_updated_at UPDATED 61
#   ____________________________________teamapi_id:85
#   ______________________________________aFLS_update_or_insert()
#   ______________________________________leagueapi_id : 61
#   ______________________________________season : 2023
#   ______________________________________teamapi_id : 85
#   ________________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 85
#   ________________________________________total_rows: 1
#   ____________________________________api_football_league_standings UPDATED
#   ______________________________________league_standing_updated_at UPDATED 61
#   ______________________________________teamapi_id:111
#   ________________________________________aFLS_update_or_insert()
#   ________________________________________leagueapi_id : 61
#   ________________________________________season : 2023
#   ________________________________________teamapi_id : 111
#   __________________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 111
#   __________________________________________total_rows: 1
#   ______________________________________api_football_league_standings UPDATED
#   ________________________________________league_standing_updated_at UPDATED 61
#   ________________________________________teamapi_id:116
#   __________________________________________aFLS_update_or_insert()
#   __________________________________________leagueapi_id : 61
#   __________________________________________season : 2023
#   __________________________________________teamapi_id : 116
#   ____________________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 116
#   ____________________________________________total_rows: 1
#   ________________________________________api_football_league_standings UPDATED
#   __________________________________________league_standing_updated_at UPDATED 61
#   __________________________________________teamapi_id:83
#   ____________________________________________aFLS_update_or_insert()
#   ____________________________________________leagueapi_id : 61
#   ____________________________________________season : 2023
#   ____________________________________________teamapi_id : 83
#   ______________________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 83
#   ______________________________________________total_rows: 1
#   __________________________________________api_football_league_standings UPDATED
#   ____________________________________________league_standing_updated_at UPDATED 61
#   ____________________________________________teamapi_id:112
#   ______________________________________________aFLS_update_or_insert()
#   ______________________________________________leagueapi_id : 61
#   ______________________________________________season : 2023
#   ______________________________________________teamapi_id : 112
#   ________________________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 112
#   ________________________________________________total_rows: 1
#   ____________________________________________api_football_league_standings UPDATED
#   ______________________________________________league_standing_updated_at UPDATED 61
#   ______________________________________________teamapi_id:99
#   ________________________________________________aFLS_update_or_insert()
#   ________________________________________________leagueapi_id : 61
#   ________________________________________________season : 2023
#   ________________________________________________teamapi_id : 99
#   __________________________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 99
#   __________________________________________________total_rows: 1
#   ______________________________________________api_football_league_standings UPDATED
#   ________________________________________________league_standing_updated_at UPDATED 61
#   ________________________________________________teamapi_id:80
#   __________________________________________________aFLS_update_or_insert()
#   __________________________________________________leagueapi_id : 61
#   __________________________________________________season : 2023
#   __________________________________________________teamapi_id : 80
#   ____________________________________________________ Select  *  from api_football_league_standings  where leagueapi_id = 61  and season = 2023  and teamapi_id = 80
#   ____________________________________________________total_rows: 1
#   ________________________________________________api_football_league_standings UPDATED
#   __________________________________________________league_standing_updated_at UPDATED 61
#   ___________________________________________________
# # -------------------------------------------------- End at 2023-08-26 23:48:22
