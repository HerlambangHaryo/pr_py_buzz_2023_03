# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *    
from a_models.api_fixtures import *    

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    space += "__"
    # --------------------------------------------------   
    leagueapi_id   = input(space + "Enter your leagueapi id :  ")
    season         = input(space + "Enter your season :  ")   
    # --------------------------------------------------  
    DICT = {
        'leagueapi_id' :leagueapi_id,
        'season' :season, 
    }
    # --------------------------------------------------- 
    ROUTES = 'all_match'
    af_controll_match_update(DICT, ROUTES, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-08 21:44:18
#   __main()
#   ____Enter your leagueapi id :  242
#   ____Enter your season :  2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API digitalmedia.arion@gmail.com counter is 77
#   __________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : all_match
#   __________leagueapi_id : 242
#   __________season : 2023
#   ____________Total API Response(s) : 240
#   ________________fV_insert_new()
#   __________________Venue Row(s) : 1
#   ________________fT_insert_new()
#   __________________Venue Row(s) : 1
#   ________________fT_insert_new()
#   __________________Venue Row(s) : 1
#   ______________football_odds: 1. /Time to be defined/ 996099 / Barcelona SC vs Gualaceo SC /2023-08-06 00:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 1. /Time to be defined/ 996099 / Barcelona SC vs Gualaceo SC /2023-08-06 00:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#
#   ________________fV_insert_new()
#   __________________Venue Row(s) : 0
#   ________________fT_insert_new()
#   __________________Venue Row(s) : 1
#   ________________fT_insert_new()
#   __________________Venue Row(s) : 1
#   ______________football_odds: 2. /Time to be defined/ 996100 / LDU de Quito vs Deportivo Cuenca /2023-08-06 00:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 2. /Time to be defined/ 996100 / LDU de Quito vs Deportivo Cuenca /2023-08-06 00:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#
#   ________________fV_insert_new()
#   __________________Venue Row(s) : 1
#   ________________fT_insert_new()
#   __________________Venue Row(s) : 1
#   ________________fT_insert_new()
#   __________________Venue Row(s) : 1
#   ______________football_odds: 3. /Time to be defined/ 996101 / Universidad Catolica vs Tecnico Universitario /2023-08-06 00:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 3. /Time to be defined/ 996101 / Universidad Catolica vs Tecnico Universitario /2023-08-06 00:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#
#   ________________fV_insert_new()
#   __________________Venue Row(s) : 1
#   ________________fT_insert_new()
#   __________________Venue Row(s) : 1
#   ________________fT_insert_new()
#   __________________Venue Row(s) : 1
#   ______________football_odds: 4. /Time to be defined/ 996102 / El Nacional vs Aucas /2023-08-06 00:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 4. /Time to be defined/ 996102 / El Nacional vs Aucas /2023-08-06 00:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#
#   ________________fV_insert_new()
#   __________________Venue Row(s) : 1
#   ________________fT_insert_new()
#   __________________Venue Row(s) : 1
#   ________________fT_insert_new()
#   __________________Venue Row(s) : 1
