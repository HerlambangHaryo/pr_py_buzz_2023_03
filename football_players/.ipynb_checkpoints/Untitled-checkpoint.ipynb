# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/players"

querystring = {"league":"39","season":"2022","team":"33"}

headers = {
	"X-RapidAPI-Key": "0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
print(response.json())
# Out:
# {'get': 'players', 'parameters': {'league': '39', 'season': '2022', 'team': '33'}, 'errors': [], 'results': 20, 'paging': {'current': 1, 'total': 3}, 'response': [{'player': {'id': 883, 'name': 'Lee Grant', 'firstname': 'Lee', 'lastname': 'Grant', 'age': 39, 'birth': {'date': '1983-01-27', 'place': 'Hemel Hempstead', 'country': 'England'}, 'nationality': 'England', 'height': '193 cm', 'weight': '83 kg', 'injured': False, 'photo': 'https://media-3.api-sports.io/football/players/883.png'}, 'statistics': [{'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-3.api-sports.io/football/teams/33.png'}, 'league': {'id': 39, 'name': 'Premier League', 'country': 'England', 'logo': 'https://media-2.api-sports.io/football/leagues/39.png', 'flag': 'https://media-2.api-sports.io/flags/gb.svg', 'season': 2022}, 'games': {'appearences': None, 'lineups': None, 'minutes': None, 'number': None, 'position': 'Goalkeeper', 'rating': None, 'captain': False}, 'substitutes': {'in': None, 'o
# ...

# %%
data = response.json()

# %%
players = data['response']

for player_data in players:
    player_info = player_data['player']
    
    player_id = player_info['id']
    player_name = player_info['name']
    player_firstname = player_info['firstname']
    player_lastname = player_info['lastname']
    player_age = player_info['age']
    
    
#     print(f"ID: {player_id}")
#     print(f"name: {player_name}")
#     print(f"firstname: {player_firstname}")
#     print(f"lastname: {player_lastname}")
#     print(f"age: {player_age}")
    
    
#     print("")
    # Extracting the birth date
    player_birth_info = player_info['birth'] 
    player_birth_date = player_birth_info['date'] 
    player_birth_place = player_birth_info['place'] 
    player_birth_country = player_birth_info['country'] 
    # Print the birth date
#     print(f"Birth Date: {player_birth_date}")  
#     print(f"Birth place: {player_birth_place}")  
#     print(f"Birth country: {player_birth_country}")  
    
    
#     print("") 
    player_nationality = player_info['nationality']
    player_height = player_info['height']
    player_weight = player_info['weight']
    player_injured = player_info['injured']
    player_photo = player_info['photo']
    
#     print(f"nationality: {player_nationality}")  
#     print(f"height: {player_height}")  
#     print(f"weight: {player_weight}")  
#     print(f"injured: {player_injured}")  
#     print(f"photo: {player_photo}")  
    
    
    
    statistics = player_data['statistics'][0]  # Assuming only one set of statistics is provided
    
    team_ID = statistics['team']['id']
    position = statistics['games']['position']
    goals = statistics['goals']['total']
    assists = statistics['goals']['assists']
    yellow_cards = statistics['cards']['yellow']
    red_cards = statistics['cards']['red']
    
#     print("")
#     print(f"team_ID: {team_ID}")
    
    
#     print(f"Position: {position}")
#     print(f"Goals: {goals}")
#     print(f"Assists: {assists}")
#     print(f"Yellow Cards: {yellow_cards}")
#     print(f"Red Cards: {red_cards}")
    
    
#     print("") # -------------------------------------------------------------------------
    fouls = statistics['fouls']  # Assuming foul data is nested under 'fouls'
    fouls_drawn = fouls['drawn']
    fouls_committed = fouls['committed']
     
#     print("") # -------------------------- ====================================
    cards = statistics['cards'] 
    yellow_cards = cards['yellow']
    yellowred_cards = cards['yellowred']
    red_cards = cards['red']
    
#     print("") # -------------------------------------------------------------------------
    games = statistics['games']   # Assuming game data is nested under 'games'
    games_appearences = games['appearences']
    games_lineups = games['lineups']
    games_minutes = games['minutes']
    games_number = games['number']
    games_position = games['position']
    games_rating = games['rating']
    games_captain = games['captain']
    
#     print("") # -------------------------------------------------------------------------
    substitutes = statistics['substitutes']  # Assuming substitute data is nested under 'substitutes' 
    substitute_in = substitutes['in']
    substitute_out = substitutes['out']
    substitute_bench = substitutes['bench']
    
    
#     print("") # -------------------------------------------------------------------------
    shots = statistics['shots']  # Assuming shot data is nested under 'shots'
    shots_total = shots['total']
    shots_on = shots['on'] 
    
#     print("") # -------------------------------------------------------------------------
    goals = statistics['goals']  # Assuming goal data is nested under 'goals'
    goals_total = goals['total']
    goals_conceded = goals['conceded']
    goals_assists = goals['assists']
    goals_saves = goals['saves']
    
#     print("") # -------------------------------------------------------------------------
    passes = statistics['passes']  # Assuming pass data is nested under 'passes'
    passes_total = passes['total']
    passes_key = passes['key']
    passes_accuracy = passes['accuracy']
    
#     print("") # -------------------------------------------------------------------------
    tackles = statistics['tackles']  # Assuming tackle data is nested under 'tackles'
    tackles_total = tackles['total']
    tackles_blocks = tackles['blocks']
    tackles_interceptions = tackles['interceptions'] 
    
#     print("") # -------------------------------------------------------------------------
    duels = statistics['duels']  # Assuming duel data is nested under 'duels'
    duels_total = duels['total']
    duels_won = duels['won'] 
    
    
#     print("") # -------------------------------------------------------------------------
    dribbles = statistics['dribbles']  # Assuming dribble data is nested under 'dribbles'
    dribbles_attempts = dribbles['attempts']
    dribbles_success = dribbles['success']
    dribbles_past = dribbles['past']
    
#     print("") # -------------------------------------------------------------------------
    penalties = statistics['penalty']   
    penalties_won = penalties['won']
    penalties_commited = penalties['commited']
    penalties_scored = penalties['scored']
    penalties_missed = penalties['missed']
    penalties_saved = penalties['saved']
     
#     print("") # -------------------------------------------------------------------------
    
    
 
    
    print(f"Games appearences: {games_appearences}")
#     print(f"Games lineups: {games_lineups}")
#     print(f"Games minutes: {games_minutes}")
#     print(f"Games number: {games_number}")
#     print(f"Games position: {games_position}") 
#     print(f"Games rating: {games_rating}")
#     print(f"Games captain: {games_captain}") 
      
#     print(f"Substitute In: {substitute_in}")
#     print(f"Substitute Out: {substitute_out}")
#     print(f"Substitute bench: {substitute_bench}")
    
#     print(f"Shots Total: {shots_total}")
#     print(f"Shots on Target: {shots_on}") 
    
#     print(f"Goals Total: {goals_total}")
#     print(f"Goals Converted: {goals_conceded}") 
#     print(f"Goals assists: {goals_assists}")
#     print(f"Goals saves: {goals_saves}")
    
#     print(f"Passes Total: {passes_total}")
#     print(f"Key Passes: {passes_key}")
#     print(f"Passes Accuracy: {passes_accuracy}%") 
    
#     print(f"Tackles Total: {tackles_total}")
#     print(f"Tackles Blocks: {tackles_blocks}")
#     print(f"Tackles Interceptions: {tackles_interceptions}") 
    
#     print(f"Duels Total: {duels_total}")
#     print(f"Duels Won: {duels_won}") 
    
#     print(f"Dribbles Attempts: {dribbles_attempts}")
#     print(f"Dribbles Success: {dribbles_success}")
#     print(f"Dribbles past: {dribbles_past}")
    
#     print(f"Penalties won: {penalties_won}")
#     print(f"Penalties commited: {penalties_commited}")
#     print(f"Penalties scored: {penalties_scored}")
#     print(f"Penalties missed: {penalties_missed}")
#     print(f"Penalties Saved: {penalties_saved}")
    
     
#     print("-" * 40) # -------------------------------------------------------------------------
#     print("")
#     print("")
# Out:
# Games appearences: None
# Games appearences: None
# Games appearences: None
# Games appearences: None
# Games appearences: 0
# Games appearences: 38
# Games appearences: 0
# Games appearences: 26
# Games appearences: 20
# Games appearences: 0
# Games appearences: 0
# Games appearences: 0
# Games appearences: 27
# Games appearences: 24
# Games appearences: 19
# Games appearences: 0
# Games appearences: 0
# Games appearences: 0
# Games appearences: 0
# Games appearences: 35
