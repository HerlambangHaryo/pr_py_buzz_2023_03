# %%
# Import 
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *   
from a_models.api_odds_new import *   
from a_models.api_players import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    leagueapi_id    = input(space + "Enter your leagueapi id :  ") 
    season          = input(space + "Enter your season :  ")  
    # --------------------------------------------------   
    DICT = {
        'leagueapi_id' : leagueapi_id,
        'season' : season, 
        'page' : 1, 
    } 
    # --------------------------------------------------  
    PREP_ = "Null"
    # -------------------------------------------------- 
    ap_controll_match_update(DICT, PREP_, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-10 23:59:38
#   __main()
#   ______ap_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 24
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________ap_response_odds()
#   __________leagueapi_id : 39
#   __________season : 2022
#   __________page : 1
#   ____________Total API Response(s) : 20
#   ____________total_MAX_PAGE : 45
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 50
#   ________________playerapi_id : 623
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 50  and playerapi_id = 623
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 45
#   ________________playerapi_id : 630
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 45  and playerapi_id = 630
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 33
#   ________________playerapi_id : 883
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 33  and playerapi_id = 883
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 35
#   ________________playerapi_id : 2281
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 35  and playerapi_id = 2281
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 49
#   ________________playerapi_id : 2288
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 49  and playerapi_id = 2288
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 48
#   ________________playerapi_id : 18826
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 48  and playerapi_id = 18826
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 50
#   ________________playerapi_id : 158696
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 50  and playerapi_id = 158696
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 51
#   ________________playerapi_id : 162517
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 51  and playerapi_id = 162517
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 66
#   ________________playerapi_id : 283289
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 66  and playerapi_id = 283289
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 40
#   ________________playerapi_id : 284247
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 40  and playerapi_id = 284247
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 52
#   ________________playerapi_id : 284464
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 52  and playerapi_id = 284464
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 39
#   ________________playerapi_id : 288115
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 39  and playerapi_id = 288115
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 47
#   ________________playerapi_id : 291022
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 47  and playerapi_id = 291022
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 52
#   ________________playerapi_id : 293162
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 52  and playerapi_id = 293162
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 52
#   ________________playerapi_id : 293167
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 52  and playerapi_id = 293167
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 46
#   ________________playerapi_id : 305732
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 46  and playerapi_id = 305732
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 33
#   ________________playerapi_id : 328101
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 33  and playerapi_id = 328101
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 52
#   ________________playerapi_id : 344908
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 52  and playerapi_id = 344908
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 35
#   ________________playerapi_id : 350590
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 35  and playerapi_id = 350590
#   __________________total_rows: 0
#   ________________aFPS_update_or_insert()
#   ________________leagueapi_id : 39
#   ________________season : 2022
#   ________________teamapi_id : 52
#   ________________playerapi_id : 350627
#   __________________ Select  *  from api_football_player_seasons  where leagueapi_id = 39  and season = 2022  and teamapi_id = 52  and playerapi_id = 350627
#   __________________total_rows: 0
# # -------------------------------------------------- End at 2023-08-10 23:59:45
