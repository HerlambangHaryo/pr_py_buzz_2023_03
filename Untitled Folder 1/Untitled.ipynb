# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " Select "
# ---------------------------------------------------------- 
query += ' leagueapi_id '   
query += ' , pre_ah_pattern '   
query += ' , pre_gou_pattern '      
query += ' , end_ah_pattern '   
query += ' , end_gou_pattern '  
# ---------------------------------------------------------- 
query += " from football_odds "      
# ---------------------------------------------------------- 
query += " where leagueapi_id = 39 "      
query += " and fixture_status in ('Match Finished', 'Match Finished Ended') " 
query += " and pre_ah_pattern is not null "            
query += " and pre_gou_pattern is not null "            
query += " and end_ah_pattern is not null "            
query += " and end_gou_pattern is not null "    
# ---------------------------------------------------------- 
query += " and pre_ah_pattern != 'H' " 
query += " and pre_gou_pattern != 'G' "  
query += " and end_ah_pattern != 'H' " 
query += " and end_gou_pattern != 'G' "   
# ---------------------------------------------------------- 
query += " group by " 
query += ' leagueapi_id '   
query += ' , pre_ah_pattern '   
query += ' , pre_gou_pattern '      
query += ' , end_ah_pattern '   
query += ' , end_gou_pattern '  
# ---------------------------------------------------------- 
print(space + query, flush=True)
# query 1
# ---------------------------------------------------------- 
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ---------------------------------------------------------- 
space += "__"
# ---------------------------------------------------------- 
total_rows = len(result)
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------    
# print("", flush=True)
# counter = 0
# # ----------------------------------------------------------  
# space += "__"
# # ---------------------------------------------------------- 
# for x in result:   
#     # ------------------------------------------------------
#     counter        += 1
#     # ------------------------------------------------------
#     leagueapi_id = str(x[0])
#     season = str(x[1]) 
#     fixtureapi_id = str(x[2]) 
#     fixture_status = str(x[3]) 
#     # ------------------------------------------------------
#     word = space + "#"  + str(counter) + " >" + leagueapi_id
#     word += " - " + season 
#     word += " > " + fixtureapi_id 
#     word += " => " + fixture_status 
#     print(word, flush=True)
# Out:
# __ Select  leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  from football_odds  where leagueapi_id = 39  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  and pre_ah_pattern != 'H'  and pre_gou_pattern != 'G'  and end_ah_pattern != 'H'  and end_gou_pattern != 'G'  group by  leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern
# ____Total Row(s) : 350

# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " Select "
# ---------------------------------------------------------- 
query += ' leagueapi_id '   
query += ' , pre_ah_pattern '   
query += ' , pre_gou_pattern '      
query += ' , end_ah_pattern '   
query += ' , end_gou_pattern '  
# ---------------------------------------------------------- 
query += " from football_pattern_from "      
# ---------------------------------------------------------- 
query += " where leagueapi_id = 39 "      
# ---------------------------------------------------------- 
query += " group by " 
query += ' leagueapi_id '   
query += ' , pre_ah_pattern '   
query += ' , pre_gou_pattern '      
query += ' , end_ah_pattern '   
query += ' , end_gou_pattern '  
# ---------------------------------------------------------- 
print(space + query, flush=True)
# query 1
# ---------------------------------------------------------- 
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ---------------------------------------------------------- 
space += "__"
# ---------------------------------------------------------- 
total_rows = len(result)
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------    
# print("", flush=True)
# counter = 0
# # ----------------------------------------------------------  
# space += "__"
# # ---------------------------------------------------------- 
# for x in result:   
#     # ------------------------------------------------------
#     counter        += 1
#     # ------------------------------------------------------
#     leagueapi_id = str(x[0])
#     season = str(x[1]) 
#     fixtureapi_id = str(x[2]) 
#     fixture_status = str(x[3]) 
#     # ------------------------------------------------------
#     word = space + "#"  + str(counter) + " >" + leagueapi_id
#     word += " - " + season 
#     word += " > " + fixtureapi_id 
#     word += " => " + fixture_status 
#     print(word, flush=True)
# Out:
# __ Select  leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  from football_pattern_from  where leagueapi_id = 39  group by  leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern
# ____Total Row(s) : 98
