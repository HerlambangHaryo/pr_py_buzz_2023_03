# %%
# Import 
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *   
from a_models.research_on_player_to_be_booked import *    
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    leagueapi_id    = input(space + "Enter your leagueapi id :  ")  
    # --------------------------------------------------     
    today           = get_today_adds(5, space) 
    # -------------------------------------------------- 
    roptbb_get(leagueapi_id, today, space) 
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-24 15:05:13
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 5
#   ________today_raw : 2023-08-29 15:05:15.138149
#   ______roptbb_get()
#   ________Select  leagueapi_id  , season   , fixtureapi_id   from football_fixtures  where leagueapi_id = '39'  and Date(date) <= Date('2023-08-29 15:05:15.138149')  and research_on_player_to_be_booked_updated_at is null  order by date desc
#   __________Total Row(s) : 790
#   ____________[1/790]  #39 - 2023 __ 1035065
#   ______________roptbb_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_player_to_be_booked   , end_player_to_be_booked   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035065'
#   __________________Total Row(s) : 1
#   ______________________roptbb_array()
#   ______________________Callum Wilson - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Callum Wilson',  '4.33',  current_timestamp )
#   ______________________Diogo Jota - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Diogo Jota',  '3.75',  current_timestamp )
#   ______________________Curtis Jones - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Curtis Jones',  '3.75',  current_timestamp )
#   ______________________Trent Alexander-Arnold - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Trent Alexander-Arnold',  '3.75',  current_timestamp )
#   ______________________Virgil van Dijk - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Virgil van Dijk',  '3.75',  current_timestamp )
#   ______________________Ibrahima Konate - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Ibrahima Konate',  '3.75',  current_timestamp )
#   ______________________Joel Matip - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Joel Matip',  '3.75',  current_timestamp )
#   ______________________Andrew Robertson - 2.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Andrew Robertson',  '2.75',  current_timestamp )
#   ______________________Konstantinos Tsimikas - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Konstantinos Tsimikas',  '3.75',  current_timestamp )
#   ______________________Nathaniel Phillips - 4.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Nathaniel Phillips',  '4.75',  current_timestamp )
#   ______________________Joe Gomez - 3.10
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Joe Gomez',  '3.10',  current_timestamp )
#   ______________________Dan Burn - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Dan Burn',  '3.75',  current_timestamp )
#   ______________________Anthony Gordon - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Anthony Gordon',  '3.75',  current_timestamp )
#   ______________________de Lira Joelinton - 2.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'de Lira Joelinton',  '2.75',  current_timestamp )
#   ______________________Jacob Murphy - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Jacob Murphy',  '4.33',  current_timestamp )
#   ______________________Fabian Schar - 3.10
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Fabian Schar',  '3.10',  current_timestamp )
#   ______________________Matt Ritchie - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Matt Ritchie',  '3.75',  current_timestamp )
#   ______________________Emil Krafth - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Emil Krafth',  '4.33',  current_timestamp )
#   ______________________Jamaal Lascelles - 3.10
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Jamaal Lascelles',  '3.10',  current_timestamp )
#   ______________________Javier Manquillo - 2.88
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Javier Manquillo',  '2.88',  current_timestamp )
#   ______________________Matt Targett - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Matt Targett',  '4.33',  current_timestamp )
#   ______________________Dominik Szoboszlai - 4.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Dominik Szoboszlai',  '4.75',  current_timestamp )
#   ______________________Wataru Endo - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Wataru Endo',  '3.75',  current_timestamp )
#   ______________________Sandro Tonali - 2.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Sandro Tonali',  '2.40',  current_timestamp )
#   ______________________Moura Bruno Guimaraes - 3.10
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Moura Bruno Guimaraes',  '3.10',  current_timestamp )
#   ______________________Kieran Trippier - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Kieran Trippier',  '3.75',  current_timestamp )
#   ______________________Darwin Nunez - 2.88
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Darwin Nunez',  '2.88',  current_timestamp )
#   ______________________Alcantara Thiago - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Alcantara Thiago',  '3.75',  current_timestamp )
#   ______________________Nick Pope - 4.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Nick Pope',  '4.75',  current_timestamp )
#   ______________________Paul Dummett - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Paul Dummett',  '4.33',  current_timestamp )
#   ______________________Lewis Hall - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Lewis Hall',  '3.75',  current_timestamp )
#   ______________________Stefan Bajcetic - 3.10
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'Stefan Bajcetic',  '3.10',  current_timestamp )
#   ______________________James McConnell - 4.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035065',  'James McConnell',  '4.75',  current_timestamp )
#   ______________________roptbb_array()
#   ____________[2/790]  #39 - 2023 __ 1035066
#   ______________roptbb_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_player_to_be_booked   , end_player_to_be_booked   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035066'
#   __________________Total Row(s) : 1
#   ______________________roptbb_array()
#   ______________________Gustavo Hamer - 2.63
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Gustavo Hamer',  '2.63',  current_timestamp )
#   ______________________Max Lowe - 4.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Max Lowe',  '4.50',  current_timestamp )
#   ______________________Oliver McBurnie - 3.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Oliver McBurnie',  '3.00',  current_timestamp )
#   ______________________Oliver Norwood - 3.10
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Oliver Norwood',  '3.10',  current_timestamp )
#   ______________________Chris Basham - 4.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Chris Basham',  '4.50',  current_timestamp )
#   ______________________John Egan - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'John Egan',  '3.40',  current_timestamp )
#   ______________________George Baldock - 3.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'George Baldock',  '3.50',  current_timestamp )
#   ______________________Jack Robinson - 3.10
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Jack Robinson',  '3.10',  current_timestamp )
#   ______________________Kalvin Phillips - 4.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Kalvin Phillips',  '4.50',  current_timestamp )
#   ______________________Anel Ahmedhodzic - 2.63
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Anel Ahmedhodzic',  '2.63',  current_timestamp )
#   ______________________Auston Trusty - 3.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Auston Trusty',  '3.50',  current_timestamp )
#   ______________________Costa Vinicius Souza - 2.63
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Costa Vinicius Souza',  '2.63',  current_timestamp )
#   ______________________Anis Ben Slimane - 2.63
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Anis Ben Slimane',  '2.63',  current_timestamp )
#   ______________________Daniel Jebbison - 4.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Daniel Jebbison',  '4.50',  current_timestamp )
#   ______________________Benie Traore - 4.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Benie Traore',  '4.50',  current_timestamp )
#   ______________________William Osula - 4.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'William Osula',  '4.50',  current_timestamp )
#   ______________________Yasser Larouci - 4.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Yasser Larouci',  '4.50',  current_timestamp )
#   ______________________Maximo Perrone - 4.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035066',  'Maximo Perrone',  '4.00',  current_timestamp )
#   ______________________roptbb_array()
#   ____________[3/790]  #39 - 2023 __ 1035061
#   ______________roptbb_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_player_to_be_booked   , end_player_to_be_booked   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035061'
#   __________________Total Row(s) : 1
#   ______________________roptbb_array()
#   ______________________Josh Brownhill - 3.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Josh Brownhill',  '3.00',  current_timestamp )
#   ______________________Jack Cork - 2.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Jack Cork',  '2.50',  current_timestamp )
#   ______________________Charlie Taylor - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Charlie Taylor',  '4.33',  current_timestamp )
#   ______________________Connor Roberts - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Connor Roberts',  '3.40',  current_timestamp )
#   ______________________Youri Tielemans - 3.20
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Youri Tielemans',  '3.20',  current_timestamp )
#   ______________________Calum Chambers - 3.20
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Calum Chambers',  '3.20',  current_timestamp )
#   ______________________Leander Dendoncker - 3.20
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Leander Dendoncker',  '3.20',  current_timestamp )
#   ______________________Lucas Digne - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Lucas Digne',  '4.33',  current_timestamp )
#   ______________________Ollie Watkins - 4.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Ollie Watkins',  '4.75',  current_timestamp )
#   ______________________Bertrand Traore - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Bertrand Traore',  '4.33',  current_timestamp )
#   ______________________Leon Bailey - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Leon Bailey',  '3.40',  current_timestamp )
#   ______________________Aaron Ramsey - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Aaron Ramsey',  '3.75',  current_timestamp )
#   ______________________John McGinn - 3.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'John McGinn',  '3.00',  current_timestamp )
#   ______________________de Paulo Douglas Luiz - 2.30
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'de Paulo Douglas Luiz',  '2.30',  current_timestamp )
#   ______________________Matty Cash - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Matty Cash',  '3.40',  current_timestamp )
#   ______________________Ezri Konsa - 3.20
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Ezri Konsa',  '3.20',  current_timestamp )
#   ______________________Moussa Diaby - 2.30
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Moussa Diaby',  '2.30',  current_timestamp )
#   ______________________Hjalmar Ekdal - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Hjalmar Ekdal',  '4.33',  current_timestamp )
#   ______________________Samuel Bastien - 4.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Samuel Bastien',  '4.75',  current_timestamp )
#   ______________________Josh Cullen - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Josh Cullen',  '3.40',  current_timestamp )
#   ______________________Boubacar Kamara - 2.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Boubacar Kamara',  '2.50',  current_timestamp )
#   ______________________Pau Torres - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Pau Torres',  '3.40',  current_timestamp )
#   ______________________Silva Diego Carlos - 2.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Silva Diego Carlos',  '2.50',  current_timestamp )
#   ______________________Dara O'Shea - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Dara O\'Shea',  '3.40',  current_timestamp )
#   ______________________Jhon Duran - 2.30
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Jhon Duran',  '2.30',  current_timestamp )
#   ______________________Lyle Foster - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Lyle Foster',  '3.40',  current_timestamp )
#   ______________________Damian Martinez - 3.75
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Damian Martinez',  '3.75',  current_timestamp )
#   ______________________Jordan Beyer - 3.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Jordan Beyer',  '3.00',  current_timestamp )
#   ______________________Zeki Amdouni - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Zeki Amdouni',  '4.33',  current_timestamp )
#   ______________________Ameen Al Dakhil - 3.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035061',  'Ameen Al Dakhil',  '3.00',  current_timestamp )
#   ______________________roptbb_array()
#   ____________[4/790]  #39 - 2023 __ 1035060
#   ______________roptbb_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_player_to_be_booked   , end_player_to_be_booked   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035060'
#   __________________Total Row(s) : 1
#   ______________________roptbb_array()
#   ______________________Jan Paul van Hecke - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Jan Paul van Hecke',  '3.40',  current_timestamp )
#   ______________________Conor Coventry - 4.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Conor Coventry',  '4.00',  current_timestamp )
#   ______________________Maxwel Cornet - 4.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Maxwel Cornet',  '4.00',  current_timestamp )
#   ______________________James Milner - 4.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'James Milner',  '4.50',  current_timestamp )
#   ______________________Lewis Dunk - 3.60
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Lewis Dunk',  '3.60',  current_timestamp )
#   ______________________Joel Veltman - 4.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Joel Veltman',  '4.00',  current_timestamp )
#   ______________________Danny Ings - 4.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Danny Ings',  '4.50',  current_timestamp )
#   ______________________Michail Antonio - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Michail Antonio',  '3.40',  current_timestamp )
#   ______________________Pablo Fornals - 3.60
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Pablo Fornals',  '3.60',  current_timestamp )
#   ______________________Tomas Soucek - 4.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Tomas Soucek',  '4.00',  current_timestamp )
#   ______________________Kurt Zouma - 3.60
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Kurt Zouma',  '3.60',  current_timestamp )
#   ______________________Aaron Cresswell - 4.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Aaron Cresswell',  '4.00',  current_timestamp )
#   ______________________Ben Johnson - 3.60
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Ben Johnson',  '3.60',  current_timestamp )
#   ______________________Angelo Ogbonna - 3.60
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Angelo Ogbonna',  '3.60',  current_timestamp )
#   ______________________Vladimir Coufal - 3.10
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Vladimir Coufal',  '3.10',  current_timestamp )
#   ______________________de Paulo Igor - 2.88
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'de Paulo Igor',  '2.88',  current_timestamp )
#   ______________________Edson Alvarez - 2.20
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Edson Alvarez',  '2.20',  current_timestamp )
#   ______________________Thilo Kehrer - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Thilo Kehrer',  '3.40',  current_timestamp )
#   ______________________de Lima Lucas Paqueta - 2.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'de Lima Lucas Paqueta',  '2.40',  current_timestamp )
#   ______________________dos Santos Emerson Palmieri - 3.60
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'dos Santos Emerson Palmieri',  '3.60',  current_timestamp )
#   ______________________Nayef Aguerd - 3.60
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Nayef Aguerd',  '3.60',  current_timestamp )
#   ______________________James Ward-Prowse - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'James Ward-Prowse',  '3.40',  current_timestamp )
#   ______________________Mahmoud Dahoud - 4.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Mahmoud Dahoud',  '4.00',  current_timestamp )
#   ______________________Facundo Buonanotte - 4.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Facundo Buonanotte',  '4.50',  current_timestamp )
#   ______________________Divin Mubama - 3.60
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035060',  'Divin Mubama',  '3.60',  current_timestamp )
#   ______________________roptbb_array()
#   ____________[5/790]  #39 - 2023 __ 1035058
#   ______________roptbb_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_player_to_be_booked   , end_player_to_be_booked   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035058'
#   __________________Total Row(s) : 1
#   ______________________roptbb_array()
#   ______________________Carvalho Rodrigo Muniz - 3.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Carvalho Rodrigo Muniz',  '3.00',  current_timestamp )
#   ______________________Jay Stansfield - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Jay Stansfield',  '4.33',  current_timestamp )
#   ______________________Bobby Reid - 3.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Bobby Reid',  '3.00',  current_timestamp )
#   ______________________Harry Wilson - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Harry Wilson',  '3.40',  current_timestamp )
#   ______________________Ricardo Ivan Cavaleiro - 4.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Ricardo Ivan Cavaleiro',  '4.00',  current_timestamp )
#   ______________________Tyrese Francois - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Tyrese Francois',  '4.33',  current_timestamp )
#   ______________________Tom Cairney - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Tom Cairney',  '4.33',  current_timestamp )
#   ______________________Harrison Reed - 2.88
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Harrison Reed',  '2.88',  current_timestamp )
#   ______________________Kenny Tete - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Kenny Tete',  '3.40',  current_timestamp )
#   ______________________Antonee Robinson - 3.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Antonee Robinson',  '3.00',  current_timestamp )
#   ______________________Tim Ream - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Tim Ream',  '3.40',  current_timestamp )
#   ______________________Raul Jimenez - 3.40
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Raul Jimenez',  '3.40',  current_timestamp )
#   ______________________Adama Traore - 3.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Adama Traore',  '3.00',  current_timestamp )
#   ______________________Issa Diop - 2.88
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Issa Diop',  '2.88',  current_timestamp )
#   ______________________Kevin Mbabu - 2.60
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Kevin Mbabu',  '2.60',  current_timestamp )
#   ______________________Sasa Lukic - 2.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Sasa Lukic',  '2.50',  current_timestamp )
#   ______________________Carlos Vinicius - 2.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Carlos Vinicius',  '2.50',  current_timestamp )
#   ______________________Calvin Bassey - 4.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Calvin Bassey',  '4.00',  current_timestamp )
#   ______________________Maria Joao Palhinha - 2.50
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Maria Joao Palhinha',  '2.50',  current_timestamp )
#   ______________________Hoelgebaum Andreas Pereira - 2.60
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Hoelgebaum Andreas Pereira',  '2.60',  current_timestamp )
#   ______________________Terence Kongolo - 4.00
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Terence Kongolo',  '4.00',  current_timestamp )
#   ______________________Thomas Partey - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1035058',  'Thomas Partey',  '4.33',  current_timestamp )
#   ______________________Matthew Dibley-Dias - 4.33
#   ________________________roptbb_insert_or_update()
#   ________________________INSERT INTO `research_on_player_to_be_booked`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  39,  '2023',  '1