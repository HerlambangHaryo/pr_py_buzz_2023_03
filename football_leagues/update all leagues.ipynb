# %%
# Import 
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *     
from a_models.football_leagues import *     
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__"   
    # --------------------------------------------------   
    fl_all_leagues(space) 
    # --------------------------------------------------    
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-10 10:03:45
#   __main()
#   ______fl_all_leagues()
#   ______Select  name   from countries
#   ______Total Row(s) : 163
#   ______[1/163]  #Albania
#   ________al_controll_match_update()
#   __________aa_check_acccount()
#   ____________API hariyant2410@gmail.com counter is 30
#   ____________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________al_response_odds()
#   ____________country : Albania
#   ______________Total API Response(s) : 7
#   __________________al_update_or_insert()
#   ____________________UPDATE `football_leagues` SET  `country_name` = 'Albania',  `name` = '2nd Division - Group B',  `type` = 'League',  `logo` = 'https://media-3.api-sports.io/football/leagues/513.png',  `api_league_updated_at` = now()  where leagueapi_id = 513
#   __________________al_update_or_insert()
# ...
