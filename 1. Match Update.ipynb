# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.match_update import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    today       = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    mu_fixtures(day1, day2, today, space) 
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 09:59:40
#   __main()
#   ____get_today_subs()
#   ______subs date_diff : 7
#   ______today_raw : 2023-08-27 09:59:40.919124
#   ____get_today_subs()
#   ______subs date_diff : 1
#   ______today_raw : 2023-09-02 09:59:40.920203
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-09-03 09:59:40.921204
#   ____mu_league_group()
#   ____Select  leagueapi_id  , season   , count(*)   , fixtureapi_id   from football_fixtures  where date <= Date('2023-09-02')  and date >= Date('2023-08-27')  and fixture_updated_at != Date('2023-09-03')  and deleted_at is null  and fixture_status not in ('Match Finished', 'Match Finished Ended' )  group by leagueapi_id, season  HAVING COUNT(*) = 1   order by date, leagueapi_id asc
#   ____Total Row(s) : 35
#   ____[1/35]  #207 - 2023 -> 1048470
#                countrows: 1
#                day1: 2023-08-27
#                day2: 2023-09-02
# ...

# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.match_update import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    today       = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    mu_league_group(day1, day2, today, space) 
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 11:10:36
#   __main()
#   ____get_today_subs()
#   ______subs date_diff : 7
#   ______today_raw : 2023-08-27 11:10:36.273547
#   ____get_today_subs()
#   ______subs date_diff : 1
#   ______today_raw : 2023-09-02 11:10:36.274551
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-09-03 11:10:36.275549
#   ____mu_league_group()
#   ____Select  leagueapi_id  , season   , count(*)   from football_fixtures  where date <= Date('2023-09-02')  and date >= Date('2023-08-27')  and fixture_updated_at != Date('2023-09-03')  and deleted_at is null  and fixture_status not in ('Match Finished', 'Match Finished Ended' )  group by leagueapi_id, season  HAVING COUNT(*) > 1   order by date, leagueapi_id asc
#   ____Total Row(s) : 51
#   ____[1/51]  #118 - 2023
#                countrows: 5
#                day1: 2023-08-27
#                day2: 2023-09-02
#                ROUTES: leagueapi_id
# ...

# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.match_update import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    today       = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    mu_fixtures_odds(day1, day2, today, space) 
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 11:21:30
#   __main()
#   ____get_today_subs()
#   ______subs date_diff : 7
#   ______today_raw : 2023-08-27 11:21:30.029716
#   ____get_today_subs()
#   ______subs date_diff : 1
#   ______today_raw : 2023-09-02 11:21:30.030720
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-09-03 11:21:30.031715
#   ____mu_fixtures_odds()
#   ____Select  leagueapi_id  , season   , count(*)   , fixtureapi_id   , (select bookmakersapi_id from football_leagues where leagueapi_id = football_fixtures.leagueapi_id)  , fixture_status   , DATE(date)  from football_fixtures  where date <= Date('2023-09-02')  and date >= Date('2023-08-27')  and deleted_at is null  and fixture_status like 'Match Finished'  group by leagueapi_id, season  HAVING COUNT(*) = 1   order by date, leagueapi_id asc
#   ____Total Row(s) : 34
#   ____[1/34]  #874 - 2023 -> 1119493
#                bookmakersapi_id: 8
# ...

# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.match_update import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    today       = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    mu_league_group_odds(day1, day2, today, space) 
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 11:26:01
#   __main()
#   ____get_today_subs()
#   ______subs date_diff : 7
#   ______today_raw : 2023-08-27 11:26:01.966255
#   ____get_today_subs()
#   ______subs date_diff : 1
#   ______today_raw : 2023-09-02 11:26:01.967255
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-09-03 11:26:01.968255
#   ____mu_league_group_odds()
#   ____Select  leagueapi_id  , season   , count(*)   , (select bookmakersapi_id from football_leagues where leagueapi_id = football_fixtures.leagueapi_id)  , fixture_status   , DATE(date)  from football_fixtures  where date <= Date('2023-09-02')  and date >= Date('2023-08-27')  and deleted_at is null  and fixture_status like 'Match Finished'  group by leagueapi_id, season, date(date)  HAVING COUNT(*) > 1   order by  leagueapi_id, date asc
#   ____Total Row(s) : 138
#   ____[1/138]  #3 - 2023
#   ______mu_league_group_odds_but_detailed()
# ...

# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.xpattern_new_auto import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------      
    xpNa_set_pattern('end_', 4, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 11:29:35
#   __main()
#   ____xpNa_set_pattern()
#   ____Total Row(s) : 98
#   ____
#   ____ [1/98]
#   ____  > fixtureapi_id = 1035074
#   ____  __> end_ah_pattern = +05+075+1H
#   ____  __> end_ah_pattern_mirror = -1-075-05H
#   ____  __> end_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> end_ah_pattern_4 = +025+05+075+1+125H
#   ____  __> end_ah_pattern_mirror_4 = -125-1-075-05-025H
#   ____  __> end_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [2/98]
#   ____  > fixtureapi_id = 1086194
#   ____  __> end_ah_pattern = -075-05-025H
#   ____  __> end_ah_pattern_mirror = +025+05+075H
#   ____  __> end_gou_pattern = 35gG
#   ____
#   ____  __> end_ah_pattern_4 = -075-05-025H
#   ____  __> end_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> end_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
# ...
