# %%
# Import
from a_settings.messages import *   

today = datetime.datetime.now()  
days0 = 7
days1 = 1
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 7 - 1 --> 2023-05-27 09:02:19.124063

# %%
# Import
from a_settings.messages import *  
from a_models.football_odds import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    fO_get_group_league_status_match_finished_DETAILED(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-27 09:02:20
#   __main()
#   ____get_date()
#   ______days : 7
#   ______days : 1
#   ______tgl_awal : 2023-05-20
#   ______tgl_akhir : 2023-05-26
#   ________fO_get_group_league_status_match_finished_DETAILED()
#   ________Select  DATE(date),  leagueapi_id,  (select bookmakersapi_id from football_leagues where football_leagues.leagueapi_id = football_odds.leagueapi_id),  season,   fixtureapi_id,   pre_ah_pattern,   pre_gou_pattern,   fixture_status   from football_odds  where fixture_status like 'Match Finished Ended'  and deleted_at is null  and end_response = 1  order by date, leagueapi_id, fixtureapi_id  desc
#   __________Total Row(s) : 482
#   __________1. 2023-05-20 // 344 // 8 // 2023 // 1001033 // 05_025_0#H // 2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001033
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-05-20 // 240 // 8 // 2023 // 1027230 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1027230
#   ____________> end_ah_pattern = 075_H
#   ____________> end_ah_pattern_mirror = 075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-05-20 // 673 // 8 // 2022 // 1027180 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1027180
#   ____________> end_ah_pattern = 1+H
#   ____________> end_ah_pattern_mirror = 1_H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________4. 2023-05-20 // 295 // 8 // 2023 // 1003960 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1003960
#   ____________> end_ah_pattern = 025+H
#   ____________> end_ah_pattern_mirror = 025_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________5. 2023-05-20 // 673 // 8 // 2022 // 1027176 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1027176
#   ____________> end_ah_pattern = 075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_H
#   ____________> end_gou_pattern = G
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________6. 2023-05-20 // 295 // 8 // 2023 // 1003838 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1003838
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________7. 2023-05-20 // 295 // 8 // 2023 // 1003840 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1003840
#   ____________> end_ah_pattern = 025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________8. 2023-05-20 // 295 // 8 // 2023 // 1003839 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1003839
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________9. 2023-05-20 // 170 // 8 // 2023 // 1022675 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1022675
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________10. 2023-05-20 // 192 // 11 // 2023 // 982361 // 0#025+075+H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 982361
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________11. 2023-05-20 // 196 // 11 // 2023 // 1013271 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1013271
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________12. 2023-05-20 // 196 // 11 // 2023 // 1013219 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1013219
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________13. 2023-05-20 // 196 // 11 // 2023 // 1013218 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1013218
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________14. 2023-05-20 // 196 // 11 // 2023 // 1013216 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1013216
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________15. 2023-05-20 // 196 // 11 // 2023 // 1013215 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1013215
#   ____________> end_ah_pattern = 025+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_025_H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________16. 2023-05-20 // 196 // 11 // 2023 // 1013214 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1013214
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________17. 2023-05-20 // 192 // 11 // 2023 // 982359 // 15_125_1_075_H // 25g275g3g325g35g375gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 982359
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________18. 2023-05-20 // 170 // 8 // 2023 // 1022676 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1022676
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________19. 2023-05-20 // 349 // 11 // 2022 // 969658 // 2_175_15_125_H // 225g25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 969658
#   ____________> end_ah_pattern = 175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________20. 2023-05-20 // 685 // 11 // 2022 // 1007122 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1007122
#   ____________> end_ah_pattern = 2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________21. 2023-05-20 // 685 // 11 // 2022 // 1007121 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1007121
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________22. 2023-05-20 // 192 // 11 // 2023 // 982360 // 025+075+1+H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 982360
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________23. 2023-05-20 // 685 // 11 // 2022 // 1007116 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1007116
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________24. 2023-05-20 // 192 // 11 // 2023 // 982364 // 075_025_0#025+H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 982364
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________25. 2023-05-20 // 192 // 11 // 2023 // 982363 // 0#025+075+H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 982363
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________26. 2023-05-20 // 192 // 11 // 2023 // 982362 // 15_125_1_075_H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 982362
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________27. 2023-05-20 // 488 // 11 // 2022 // 1023527 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023527
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 3g325g35g375g4gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________28. 2023-05-20 // 488 // 11 // 2022 // 1023490 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023490
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 3g325g35g375g4g425gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________29. 2023-05-20 // 488 // 11 // 2022 // 1023488 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023488
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________30. 2023-05-20 // 95 // 8 // 2022 // 899200 // 05_025_0#025+H // 2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 899200
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________31. 2023-05-20 // 205 // 11 // 2022 // 889574 // 025_0#025+H // 175g2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889574
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________32. 2023-05-20 // 295 // 8 // 2023 // 1003841 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1003841
#   ____________> end_ah_pattern = 05_H
#   ____________> end_ah_pattern_mirror = 05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________33. 2023-05-20 // 488 // 11 // 2022 // 1023528 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023528
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________34. 2023-05-20 // 510 // 11 // 2022 // 898590 // 0#H // 3g35g4gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 898590
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 35g4gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________35. 2023-05-20 // 782 // 11 // 2022 // 968796 // 075+1+125+15+H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 968796
#   ____________> end_ah_pattern = 075+1+125+15+175+H
#   ____________> end_ah_pattern_mirror = 175_15_125_1_075_H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________36. 2023-05-20 // 783 // 11 // 2022 // 968944 // 15_125_1_075_H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 968944
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________37. 2023-05-20 // 783 // 11 // 2022 // 968943 // 25_225_2_175_15_H // 275g3g325g35g375g4gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 968943
#   ____________> end_ah_pattern = 3_275_25_225_2_175_H
#   ____________> end_ah_pattern_mirror = 175+2+225+25+275+3+H
#   ____________> end_gou_pattern = 3g325g35g375g4g425gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________38. 2023-05-20 // 327 // 11 // 2023 // 1000642 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1000642
#   ____________> end_ah_pattern = 025+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_025_H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________39. 2023-05-20 // 122 // 8 // 2022 // 1022440 // 05_025_0#025+H // 25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1022440
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________40. 2023-05-20 // 122 // 8 // 2022 // 1022439 // 025_0#025+05+H // 25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1022439
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________41. 2023-05-20 // 488 // 11 // 2022 // 1023487 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023487
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________42. 2023-05-20 // 592 // 8 // 2023 // 993013 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 993013
#   ____________> end_ah_pattern = 15_125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+15+H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________43. 2023-05-20 // 597 // 8 // 2023 // 993742 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 993742
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________44. 2023-05-20 // 754 // 11 // 2022 // 905610 // 125+15+175+2+225+25+H // 3g325g35g375g4gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 905610
#   ____________> end_ah_pattern = 125+15+175+2+225+25+H
#   ____________> end_ah_pattern_mirror = 25_225_2_175_15_125_H
#   ____________> end_gou_pattern = 3g325g35g375g4g425gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________45. 2023-05-20 // 780 // 11 // 2022 // 969338 // 075_025_0#H // 225g25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 969338
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________46. 2023-05-20 // 39 // 8 // 2022 // 868313 // 1_075_05_025_H // 225g25g275g3gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 868313
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________47. 2023-05-20 // 170 // 8 // 2023 // 1023127 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023127
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 15gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________48. 2023-05-20 // 83 // 8 // 2022 // 904382 // 05_025_0#025+H // 25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 904382
#   ____________> end_ah_pattern = 075_05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________49. 2023-05-20 // 83 // 8 // 2022 // 904380 // 05_025_0#025+05+H // 35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 904380
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________50. 2023-05-20 // 83 // 8 // 2022 // 904379 // 15_125_1_075_05_H // 25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 904379
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________51. 2023-05-20 // 83 // 8 // 2022 // 904378 // 075+1+125+15+175+H // 35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 904378
#   ____________> end_ah_pattern = 075+1+125+15+175+H
#   ____________> end_ah_pattern_mirror = 175_15_125_1_075_H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________52. 2023-05-20 // 83 // 8 // 2022 // 904376 // 025+05+075+1+H // 25g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 904376
#   ____________> end_ah_pattern = 05+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_05_H
#   ____________> end_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________53. 2023-05-20 // 83 // 8 // 2022 // 904375 // 175_15_125_1_075_H // 25g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 904375
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 25g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________54. 2023-05-20 // 83 // 8 // 2022 // 904374 // 25_225_2_175_15_025+H // 35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 904374
#   ____________> end_ah_pattern = 275_25_225_2_175_025+H
#   ____________> end_ah_pattern_mirror = 025_175+2+225+25+275+H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________55. 2023-05-20 // 83 // 8 // 2022 // 904373 // 025_0#025+05+H // 25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 904373
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________56. 2023-05-20 // 122 // 8 // 2022 // 1022412 // 075_05_025_0#H // 25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1022412
#   ____________> end_ah_pattern = 075_05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________57. 2023-05-20 // 140 // 8 // 2022 // 878287 // 025_0#025+05+H // 25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 878287
#   ____________> end_ah_pattern = 05_025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+05+H
#   ____________> end_gou_pattern = 275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________58. 2023-05-20 // 205 // 11 // 2022 // 889580 // 175_15_125_1_H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889580
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________59. 2023-05-20 // 205 // 11 // 2022 // 889579 // 25_2_15_H // 4g45g5gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889579
#   ____________> end_ah_pattern = 25_2_15_H
#   ____________> end_ah_pattern_mirror = 15+2+25+H
#   ____________> end_gou_pattern = 4g45g5gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________60. 2023-05-20 // 205 // 11 // 2022 // 889578 // 25_225_2_175_15_H // 25g275g3g325g35g375gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889578
#   ____________> end_ah_pattern = 25_225_2_175_15_H
#   ____________> end_ah_pattern_mirror = 15+175+2+225+25+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________61. 2023-05-20 // 205 // 11 // 2022 // 889577 // H // 25g3gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889577
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 25g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________62. 2023-05-20 // 205 // 11 // 2022 // 889576 // 025_0#025+H // 2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889576
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________63. 2023-05-20 // 205 // 11 // 2022 // 889573 // 25_2_15_H // 3g35g4gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889573
#   ____________> end_ah_pattern = 2_15_H
#   ____________> end_ah_pattern_mirror = 15+2+H
#   ____________> end_gou_pattern = 25g3g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________64. 2023-05-20 // 205 // 11 // 2022 // 889571 // 175_15_125_1_H // 225g25g275g3gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889571
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________65. 2023-05-20 // 205 // 11 // 2022 // 889200 // 175_15_125_1_075_H // 25g275g3g325g35g375gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889200
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________66. 2023-05-20 // 205 // 11 // 2022 // 889199 // 025_0#025+H // 2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889199
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________67. 2023-05-20 // 205 // 11 // 2022 // 889198 // 35_3_H // 45g5g55gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889198
#   ____________> end_ah_pattern = 35_3_H
#   ____________> end_ah_pattern_mirror = 3+35+H
#   ____________> end_gou_pattern = 45g5g55gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________68. 2023-05-20 // 205 // 11 // 2022 // 889197 // H // 2g25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889197
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 2g25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________69. 2023-05-20 // 205 // 11 // 2022 // 889196 // 025_0#025+H // 175g2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889196
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________70. 2023-05-20 // 205 // 11 // 2022 // 889195 // 15_125_1_075_H // 2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889195
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________71. 2023-05-20 // 205 // 11 // 2022 // 889194 // 025_0#025+H // 225g25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889194
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________72. 2023-05-20 // 205 // 11 // 2022 // 889192 // 0#025+H // 225g25g275g3gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889192
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________73. 2023-05-20 // 327 // 11 // 2023 // 1000640 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1000640
#   ____________> end_ah_pattern = 025+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_025_H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________74. 2023-05-20 // 328 // 11 // 2023 // 1001449 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001449
#   ____________> end_ah_pattern = 35_325_3_275_25_225_H
#   ____________> end_ah_pattern_mirror = 225+25+275+3+325+35+H
#   ____________> end_gou_pattern = 35g375g4g425g45g475gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________75. 2023-05-20 // 328 // 11 // 2023 // 1001448 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001448
#   ____________> end_ah_pattern = 15+175+2+225+25+275+H
#   ____________> end_ah_pattern_mirror = 275_25_225_2_175_15_H
#   ____________> end_gou_pattern = 325g35g375g4g425g45gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________76. 2023-05-20 // 328 // 11 // 2023 // 1001447 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001447
#   ____________> end_ah_pattern = 125+15+175+2+225+25+H
#   ____________> end_ah_pattern_mirror = 25_225_2_175_15_125_H
#   ____________> end_gou_pattern = 4g425g45g475g5g525g55gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________77. 2023-05-20 // 552 // 11 // 2022 // 893393 // 2_175_15_125_H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 893393
#   ____________> end_ah_pattern = 225_2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+225+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________78. 2023-05-20 // 596 // 8 // 2023 // 993377 // 0#025+05+075+H // 35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 993377
#   ____________> end_ah_pattern = 0#025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_0#H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________79. 2023-05-20 // 597 // 8 // 2023 // 993741 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 993741
#   ____________> end_ah_pattern = 125_1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+125+H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________80. 2023-05-20 // 688 // 11 // 2022 // 1020582 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1020582
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________81. 2023-05-20 // 754 // 11 // 2022 // 905614 // 125_1_075_025_H // 275g3g325g35g375gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 905614
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________82. 2023-05-20 // 754 // 11 // 2022 // 905607 // 075_025_0#025+H // 275g3g325g35g375g4gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 905607
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 275g3g325g35g375g4gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________83. 2023-05-20 // 755 // 11 // 2022 // 905915 // H // G // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 905915
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________84. 2023-05-20 // 780 // 11 // 2022 // 969337 // 075_025_H // 225g25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 969337
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________85. 2023-05-20 // 783 // 11 // 2022 // 968951 // 075_025_0#H // 225g25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 968951
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________86. 2023-05-20 // 278 // 11 // 2023 // 997492 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 997492
#   ____________> end_ah_pattern = 125+15+175+2+H
#   ____________> end_ah_pattern_mirror = 2_175_15_125_H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________87. 2023-05-20 // 328 // 11 // 2023 // 1001450 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001450
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________88. 2023-05-20 // 488 // 11 // 2022 // 1023486 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023486
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________89. 2023-05-20 // 95 // 8 // 2022 // 899206 // 075_05_025_H // 225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 899206
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________90. 2023-05-20 // 113 // 8 // 2023 // 1001871 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001871
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________91. 2023-05-20 // 203 // 8 // 2022 // 884652 // 125_1_075_05_025_H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 884652
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________92. 2023-05-20 // 245 // 8 // 2023 // 998979 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998979
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________93. 2023-05-20 // 245 // 8 // 2023 // 998978 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998978
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________94. 2023-05-20 // 247 // 8 // 2023 // 999983 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 999983
#   ____________> end_ah_pattern = 0#025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________95. 2023-05-20 // 278 // 11 // 2023 // 997493 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 997493
#   ____________> end_ah_pattern = 025+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_025_H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________96. 2023-05-20 // 487 // 11 // 2022 // 941989 // 025+075+1+125+H // 225g25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 941989
#   ____________> end_ah_pattern = 025+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_025_H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________97. 2023-05-20 // 510 // 11 // 2022 // 898592 // 15_1_H // 3g35g4gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 898592
#   ____________> end_ah_pattern = 15_1_H
#   ____________> end_ah_pattern_mirror = 1+15+H
#   ____________> end_gou_pattern = 35g4g45gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________98. 2023-05-20 // 688 // 11 // 2022 // 1020581 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1020581
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________99. 2023-05-20 // 754 // 11 // 2022 // 905606 // 0#025+075+1+H // 325g35g375g4g425gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 905606
#   ____________> end_ah_pattern = 025_0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#025+H
#   ____________> end_gou_pattern = 325g35g375g4g425gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________100. 2023-05-20 // 781 // 11 // 2022 // 969506 // 025_0#025+H // 225g25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 969506
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________101. 2023-05-20 // 782 // 11 // 2022 // 968793 // 075_025_0#025+H // 225g25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 968793
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________102. 2023-05-20 // 488 // 11 // 2022 // 1023489 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023489
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________103. 2023-05-20 // 492 // 11 // 2022 // 900129 // 025_0#025+H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 900129
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________104. 2023-05-20 // 492 // 11 // 2022 // 900128 // 125+15+175+2+225+H // 275g3g325g35g375gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 900128
#   ____________> end_ah_pattern = 125+15+175+2+225+25+H
#   ____________> end_ah_pattern_mirror = 25_225_2_175_15_125_H
#   ____________> end_gou_pattern = 3g325g35g375g4gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________105. 2023-05-20 // 492 // 11 // 2022 // 900127 // 025+075+1+H // 25g275g3g325g35g375gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 900127
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________106. 2023-05-20 // 492 // 11 // 2022 // 900126 // 075_025_0#025+H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 900126
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________107. 2023-05-20 // 492 // 11 // 2022 // 900125 // 075_025_0#H // 275g3g325g35g375gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 900125
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________108. 2023-05-20 // 492 // 11 // 2022 // 900124 // 1_075_025_H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 900124
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________109. 2023-05-20 // 492 // 11 // 2022 // 900123 // 0#025+075+1+H // 3g325g35g375g4gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 900123
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 275g3g325g35g375g4gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________110. 2023-05-20 // 492 // 11 // 2022 // 900122 // 075+1+125+15+175+H // 3g325g35g375g4gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 900122
#   ____________> end_ah_pattern = 075+1+125+15+175+H
#   ____________> end_ah_pattern_mirror = 175_15_125_1_075_H
#   ____________> end_gou_pattern = 325g35g375g4g425g45gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________111. 2023-05-20 // 39 // 8 // 2022 // 868315 // 025_0#025+H // 2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 868315
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
# ...
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001455
#   ____________> end_ah_pattern = 25_225_2_175_15_H
#   ____________> end_ah_pattern_mirror = 15+175+2+225+25+H
#   ____________> end_gou_pattern = 35g375g4g425g45gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________447. 2023-05-25 // 328 // 11 // 2023 // 1001454 // 125_1_075_025_H // 275g3g325g35g375gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001454
#   ____________> end_ah_pattern = 15_125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+15+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________448. 2023-05-25 // 688 // 11 // 2022 // 1020586 // None // None // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1020586
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________449. 2023-05-25 // 755 // 11 // 2022 // 905928 // 1_075_025_H // 275g3g325g35g375gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 905928
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________450. 2023-05-25 // 755 // 11 // 2022 // 905893 // 225_2_175_15_125_H // 3g325g35g375g4g425gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 905893
#   ____________> end_ah_pattern = 35_325_3_275_25_225_H
#   ____________> end_ah_pattern_mirror = 225+25+275+3+325+35+H
#   ____________> end_gou_pattern = 4g425g45g475g5g525g55gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________451. 2023-05-25 // 113 // 8 // 2023 // 1001949 // 025+05+075+H // 225g25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001949
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________452. 2023-05-25 // 172 // 8 // 2022 // 1026745 // 125_1_075_05_H // 225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1026745
#   ____________> end_ah_pattern = 075_05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+075+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________453. 2023-05-25 // 751 // 11 // 2022 // 906582 // 075+1+125+15+175+H // 325g35g375g4g425g45gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906582
#   ____________> end_ah_pattern = 025+075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_025_H
#   ____________> end_gou_pattern = 375g4g425g45g475g5gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________454. 2023-05-25 // 140 // 8 // 2022 // 878295 // 0#025+05+H // 175g2g225gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 878295
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________455. 2023-05-25 // 206 // 8 // 2022 // 1020817 // 05_025_0#025+H // 225g25g275g3gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1020817
#   ____________> end_ah_pattern = 075_05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+075+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________456. 2023-05-25 // 164 // 8 // 2023 // 981506 // 025+05+075+H // 25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981506
#   ____________> end_ah_pattern = 0#025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________457. 2023-05-25 // 490 // 8 // 2023 // 1023434 // H // G // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023434
#   ____________> end_ah_pattern = 2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________458. 2023-05-25 // 490 // 8 // 2023 // 1023432 // H // G // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023432
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________459. 2023-05-25 // 136 // 8 // 2022 // 1028184 // 05_025_0#025+H // 2g225g25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1028184
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________460. 2023-05-25 // 207 // 8 // 2022 // 872704 // 025_0#025+05+H // 225g25g275g3gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 872704
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________461. 2023-05-25 // 207 // 8 // 2022 // 872703 // 025+05+075+H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 872703
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________462. 2023-05-25 // 207 // 8 // 2022 // 872702 // 125_1_075_05_H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 872702
#   ____________> end_ah_pattern = 125_1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+125+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________463. 2023-05-25 // 207 // 8 // 2022 // 872701 // 025+05+075+H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 872701
#   ____________> end_ah_pattern = 05_025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+05+H
#   ____________> end_gou_pattern = 275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________464. 2023-05-25 // 207 // 8 // 2022 // 872700 // 025_0#025+05+H // 275g3g325g35g375gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 872700
#   ____________> end_ah_pattern = 025+05+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_05_025_H
#   ____________> end_gou_pattern = 325g35g375g4gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________465. 2023-05-25 // 39 // 8 // 2022 // 868264 // 125_1_075_05_H // 25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 868264
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________466. 2023-05-25 // 95 // 8 // 2022 // 899210 // 15_125_1_H // 225g25g275g3gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 899210
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________467. 2023-05-25 // 164 // 8 // 2023 // 981507 // 075_05_025_0#H // 35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981507
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________468. 2023-05-25 // 140 // 8 // 2022 // 878296 // 0#025+05+H // 2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 878296
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________469. 2023-05-25 // 240 // 8 // 2023 // 1027236 // 1_H // 25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1027236
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________470. 2023-05-25 // 490 // 8 // 2023 // 1023435 // H // G // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023435
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________471. 2023-05-25 // 490 // 8 // 2023 // 1023433 // H // G // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1023433
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________472. 2023-05-25 // 11 // 8 // 2023 // 1019443 // 075+1+125+15+H // 2g225g25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1019443
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________473. 2023-05-25 // 13 // 8 // 2023 // 1019322 // 025_0#025+05+H // 225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1019322
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________474. 2023-05-25 // 13 // 8 // 2023 // 1019317 // 025_0#025+H // 2g225g25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1019317
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________475. 2023-05-25 // 256 // 11 // 2023 // 1024092 // 025_0#025+H // 25g275g3g325g35gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1024092
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________476. 2023-05-26 // 11 // 8 // 2023 // 1019447 // 05+075+1+H // 2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1019447
#   ____________> end_ah_pattern = 05+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_05_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________477. 2023-05-26 // 11 // 8 // 2023 // 1019446 // 1+125+15+175+H // 225g25g275g3g325gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1019446
#   ____________> end_ah_pattern = 125+15+175+H
#   ____________> end_ah_pattern_mirror = 175_15_125_H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________478. 2023-05-26 // 11 // 8 // 2023 // 1019445 // 025+05+075+H // 2g225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1019445
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________479. 2023-05-26 // 11 // 8 // 2023 // 1019444 // 1_075_05_025_H // 2g225g25gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1019444
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________480. 2023-05-26 // 13 // 8 // 2023 // 1019324 // 05+075+1+125+H // 225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1019324
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________481. 2023-05-26 // 13 // 8 // 2023 // 1019323 // 075+1+125+15+H // 225g25g275gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1019323
#   ____________> end_ah_pattern = 05+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_05_H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
#   __________482. 2023-05-26 // 243 // 11 // 2023 // 1011828 // 125_1_075_H // 15g175g2g225gG // Match Finished Ended
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011828
#   ____________> end_ah_pattern = 125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_odds update pattern commited
#   ____________> no PL predates get advices
# # -------------------------------------------------- End at 2023-05-27 09:22:42
