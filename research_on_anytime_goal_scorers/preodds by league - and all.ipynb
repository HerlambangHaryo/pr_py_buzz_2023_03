# %%
# Import 
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *   
from a_models.api_odds_new import *   
from a_models.football_leagues import *   
from a_models.xpattern_new_auto import *  
from a_models.research_on_anytime_goal_scorers import *    
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    leagueapi_id    = input(space + "Enter your leagueapi id :  ") 
    season          = input(space + "Enter your season :  ") 
    # --------------------------------------------------    
    date_0          = get_today_adds(0, space).strftime("%Y-%m-%d") 
    date_raw        = get_today_adds(0, space) 
    # -------------------------------------------------- 
    bookmaker       = fl_check_league(leagueapi_id, "bookmakersapi_id", space)
    # --------------------------------------------------  
    DICT = {
        'date' : date_0,
        'date_raw' : date_raw,
        'league' : leagueapi_id,
        'season' : season,
        'bookmaker' : bookmaker,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 0, 
        'max_page' : 0, 
    } 
    # --------------------------------------------------  
    PREP_ = "preleague_"
    # -------------------------------------------------- 
    aoN_controll_match_update(DICT, PREP_, space)
    # --------------------------------------------------  
    xpNa_set_pattern('pre_', 4, space)
    # --------------------------------------------------   
    # --------------------------------------------------     
    today           = get_today_adds(5, space) 
    # -------------------------------------------------- 
    roags_get(leagueapi_id, today, space) 
    # --------------------------------------------------  
    print(space + "leagueapi_id: " + str(leagueapi_id), flush=True)
    # --------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-01 21:26:20
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-01 21:26:29.513531
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-01 21:26:29.515044
#   ______fl_check_league()
#   ______bookmakersapi_id: 8
#   ______aoN_controll_match_update()
#   ________aa_check_acccount()
#   __________API api4@ariondigitalmedia.com counter is 33
#   __________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________aoN_response_odds()
#   __________date : 2023-09-01
#   __________date_raw : 2023-09-01 21:26:29.515044
#   __________bookmaker : 8
#   __________season : 2023
#   __________league : 39
#   __________page : 1
#   ____________Total API Response(s) : 10
#   ____________total_MAX_PAGE : 3
#   ______________
#   ______________1/10
#   ______________England,  Premier League  #39 - 2023
#   ______________2023-08-25 19:00:00+00:00 // UTC // 1035062
#   ________________aoN_football_statistics_check()
#   ____________________England,  Premier League - 2023 __ 1035062 __ 2023-08-26 02:00:00 __ 8
#   ______________________________Chelsea vs Luton
#   __________________________Kurang 2023-08-26 02:00:00 < 2023-09-01 21:26:29
#   ________________PREP_check_date is not valid
#   ________________
#   ________________2/10
#   ________________England,  Premier League  #39 - 2023
#   ________________2023-08-26 11:30:00+00:00 // UTC // 1035057
#   __________________aoN_football_statistics_check()
#   ______________________England,  Premier League - 2023 __ 1035057 __ 2023-08-26 18:30:00 __ 8
#   ________________________________Bournemouth vs Tottenham
#   ____________________________Kurang 2023-08-26 18:30:00 < 2023-09-01 21:26:29
#   __________________PREP_check_date is not valid
#   __________________
#   __________________3/10
#   __________________England,  Premier League  #39 - 2023
#   __________________2023-08-26 14:00:00+00:00 // UTC // 1035064
#   ____________________aoN_football_statistics_check()
#   ________________________England,  Premier League - 2023 __ 1035064 __ 2023-08-26 21:00:00 __ 8
#   __________________________________Manchester United vs Nottingham Forest
#   ______________________________Kurang 2023-08-26 21:00:00 < 2023-09-01 21:26:29
#   ____________________PREP_check_date is not valid
#   ____________________
#   ____________________4/10
#   ____________________England,  Premier League  #39 - 2023
#   ____________________2023-08-26 14:00:00+00:00 // UTC // 1035063
#   ______________________aoN_football_statistics_check()
#   __________________________England,  Premier League - 2023 __ 1035063 __ 2023-08-26 21:00:00 __ 8
#   ____________________________________Everton vs Wolves
#   ________________________________Kurang 2023-08-26 21:00:00 < 2023-09-01 21:26:29
#   ______________________PREP_check_date is not valid
#   ______________________
#   ______________________5/10
#   ______________________England,  Premier League  #39 - 2023
#   ______________________2023-08-26 14:00:00+00:00 // UTC // 1035059
#   ________________________aoN_football_statistics_check()
#   ____________________________England,  Premier League - 2023 __ 1035059 __ 2023-08-26 21:00:00 __ 8
#   ______________________________________Brentford vs Crystal Palace
#   __________________________________Kurang 2023-08-26 21:00:00 < 2023-09-01 21:26:29
#   ________________________PREP_check_date is not valid
#   ________________________
#   ________________________6/10
#   ________________________England,  Premier League  #39 - 2023
#   ________________________2023-08-26 14:00:00+00:00 // UTC // 1035058
#   __________________________aoN_football_statistics_check()
#   ______________________________England,  Premier League - 2023 __ 1035058 __ 2023-08-26 21:00:00 __ 8
#   ________________________________________Arsenal vs Fulham
#   ____________________________________Kurang 2023-08-26 21:00:00 < 2023-09-01 21:26:29
#   __________________________PREP_check_date is not valid
#   __________________________
#   __________________________7/10
#   __________________________England,  Premier League  #39 - 2023
#   __________________________2023-08-26 16:30:00+00:00 // UTC // 1035060
#   ____________________________aoN_football_statistics_check()
#   ________________________________England,  Premier League - 2023 __ 1035060 __ 2023-08-26 23:30:00 __ 8
#   __________________________________________Brighton vs West Ham
#   ______________________________________Kurang 2023-08-26 23:30:00 < 2023-09-01 21:26:29
#   ____________________________PREP_check_date is not valid
#   ____________________________
#   ____________________________8/10
#   ____________________________England,  Premier League  #39 - 2023
#   ____________________________2023-08-27 13:00:00+00:00 // UTC // 1035066
#   ______________________________aoN_football_statistics_check()
#   __________________________________England,  Premier League - 2023 __ 1035066 __ 2023-08-27 20:00:00 __ 8
#   ____________________________________________Sheffield Utd vs Manchester City
#   ________________________________________Kurang 2023-08-27 20:00:00 < 2023-09-01 21:26:29
#   ______________________________PREP_check_date is not valid
#   ______________________________
#   ______________________________9/10
#   ______________________________England,  Premier League  #39 - 2023
#   ______________________________2023-08-27 13:00:00+00:00 // UTC // 1035061
#   ________________________________aoN_football_statistics_check()
#   ____________________________________England,  Premier League - 2023 __ 1035061 __ 2023-08-27 20:00:00 __ 8
#   ______________________________________________Burnley vs Aston Villa
#   __________________________________________Kurang 2023-08-27 20:00:00 < 2023-09-01 21:26:29
#   ________________________________PREP_check_date is not valid
#   ________________________________
#   ________________________________10/10
#   ________________________________England,  Premier League  #39 - 2023
#   ________________________________2023-08-27 15:30:00+00:00 // UTC // 1035065
#   __________________________________aoN_football_statistics_check()
#   ______________________________________England,  Premier League - 2023 __ 1035065 __ 2023-08-27 22:30:00 __ 8
#   ________________________________________________Newcastle vs Liverpool
#   ____________________________________________Kurang 2023-08-27 22:30:00 < 2023-09-01 21:26:29
#   __________________________________PREP_check_date is not valid
#   __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________
APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date : 2023-09-01
# __________date_raw : 2023-09-01 21:26:29.515044
# __________bookmaker : 8
# __________season : 2023
# __________league : 39
# __________page : 4
# ____________Total API Response(s) : 0
# ____________total_MAX_PAGE : 3
# ______________SKIPPED because its Nothing total_API_response:0
#   ______xpNa_set_pattern()
#   ______Total Row(s) : 20
#   ______
#   ______ [1/20]
#   ______  > fixtureapi_id = 1035071
#   ______  __> pre_ah_pattern = -175-15-125-1H
#   ______  __> pre_ah_pattern_mirror = +1+125+15+175H
#   ______  __> pre_gou_pattern = 25g275g30g325gG
#   ______
#   ______  __> pre_ah_pattern_4 = -175-15-125-1H
#   ______  __> pre_ah_pattern_mirror_4 = +1+125+15+175H
#   ______  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [2/20]
#   ______  > fixtureapi_id = 1035069
#   ______  __> pre_ah_pattern = -05-025+0+025+05H
#   ______  __> pre_ah_pattern_mirror = -05-025+0+025+05H
#   ______  __> pre_gou_pattern = 275g30g325g35gG
#   ______
#   ______  __> pre_ah_pattern_4 = -05-025+0+025+05H
#   ______  __> pre_ah_pattern_mirror_4 = -05-025+0+025+05H
#   ______  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [3/20]
#   ______  > fixtureapi_id = 1035072
#   ______  __> pre_ah_pattern = -075-05-025H
#   ______  __> pre_ah_pattern_mirror = +025+05+075H
#   ______  __> pre_gou_pattern = 20g225g25gG
#   ______
#   ______  __> pre_ah_pattern_4 = -075-05-025H
#   ______  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ______  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [4/20]
#   ______  > fixtureapi_id = 1035068
#   ______  __> pre_ah_pattern = -1-075-05H
#   ______  __> pre_ah_pattern_mirror = +05+075+1H
#   ______  __> pre_gou_pattern = 225g25g275g30g325gG
#   ______
#   ______  __> pre_ah_pattern_4 = -125-1-075-05-025H
#   ______  __> pre_ah_pattern_mirror_4 = +025+05+075+1+125H
#   ______  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [5/20]
#   ______  > fixtureapi_id = 1035073
#   ______  __> pre_ah_pattern = -125-1-075-05H
#   ______  __> pre_ah_pattern_mirror = +05+075+1+125H
#   ______  __> pre_gou_pattern = 30g325g35g375gG
#   ______
#   ______  __> pre_ah_pattern_4 = -15-125-1-075-05H
#   ______  __> pre_ah_pattern_mirror_4 = +05+075+1+125+15H
#   ______  __> pre_gou_pattern_4 = 30g325g35g375gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [6/20]
#   ______  > fixtureapi_id = 1035067
#   ______  __> pre_ah_pattern = -1-075-05-025H
#   ______  __> pre_ah_pattern_mirror = +025+05+075+1H
#   ______  __> pre_gou_pattern = 25g275g30g325g35gG
#   ______
#   ______  __> pre_ah_pattern_4 = -125-1-075-05-025H
#   ______  __> pre_ah_pattern_mirror_4 = +025+05+075+1+125H
#   ______  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [7/20]
#   ______  > fixtureapi_id = 1035075
#   ______  __> pre_ah_pattern = -275-25-225-2-175H
#   ______  __> pre_ah_pattern_mirror = +175+2+225+25+275H
#   ______  __> pre_gou_pattern = 30g325g35g375gG
#   ______
#   ______  __> pre_ah_pattern_4 = -275-25-225-2-175H
#   ______  __> pre_ah_pattern_mirror_4 = +175+2+225+25+275H
#   ______  __> pre_gou_pattern_4 = 30g325g35g375gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [8/20]
#   ______  > fixtureapi_id = 1035076
#   ______  __> pre_ah_pattern = -025+0+025+05H
#   ______  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ______  __> pre_gou_pattern = 20g225g25gG
#   ______
#   ______  __> pre_ah_pattern_4 = -025+0+025+05H
#   ______  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ______  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [9/20]
#   ______  > fixtureapi_id = 1035070
#   ______  __> pre_ah_pattern = +025+05+075+1H
#   ______  __> pre_ah_pattern_mirror = -1-075-05-025H
#   ______  __> pre_gou_pattern = 25g275g30g325gG
#   ______
#   ______  __> pre_ah_pattern_4 = +025+05+075+1H
#   ______  __> pre_ah_pattern_mirror_4 = -1-075-05-025H
#   ______  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [10/20]
#   ______  > fixtureapi_id = 1035074
#   ______  __> pre_ah_pattern = +05+075+1H
#   ______  __> pre_ah_pattern_mirror = -1-075-05H
#   ______  __> pre_gou_pattern = 225g25g275g30gG
#   ______
#   ______  __> pre_ah_pattern_4 = +025+05+075+1H
#   ______  __> pre_ah_pattern_mirror_4 = -1-075-05-025H
#   ______  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [11/20]
#   ______  > fixtureapi_id = 1035082
#   ______  __> pre_ah_pattern = -15-125-1-075-05H
#   ______  __> pre_ah_pattern_mirror = +05+075+1+125+15H
#   ______  __> pre_gou_pattern = 25g275g30g325gG
#   ______
#   ______  __> pre_ah_pattern_4 = -15-125-1-075-05H
#   ______  __> pre_ah_pattern_mirror_4 = +05+075+1+125+15H
#   ______  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [12/20]
#   ______  > fixtureapi_id = 1035079
#   ______  __> pre_ah_pattern = +05+075+1+125+15H
#   ______  __> pre_ah_pattern_mirror = -15-125-1-075-05H
#   ______  __> pre_gou_pattern = 25g275g30g325gG
#   ______
#   ______  __> pre_ah_pattern_4 = +05+075+1+125+15H
#   ______  __> pre_ah_pattern_mirror_4 = -15-125-1-075-05H
#   ______  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [13/20]
#   ______  > fixtureapi_id = 1035077
#   ______  __> pre_ah_pattern = +05+075+1+125H
#   ______  __> pre_ah_pattern_mirror = -125-1-075-05H
#   ______  __> pre_gou_pattern = 25g275g30g325gG
#   ______
#   ______  __> pre_ah_pattern_4 = +05+075+1+125H
#   ______  __> pre_ah_pattern_mirror_4 = -125-1-075-05H
#   ______  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [14/20]
#   ______  > fixtureapi_id = 1035086
#   ______  __> pre_ah_pattern = +05+075+1+125+15H
#   ______  __> pre_ah_pattern_mirror = -15-125-1-075-05H
#   ______  __> pre_gou_pattern = 275g30g325g35gG
#   ______
#   ______  __> pre_ah_pattern_4 = +05+075+1+125+15H
#   ______  __> pre_ah_pattern_mirror_4 = -15-125-1-075-05H
#   ______  __> pre_gou_pattern_4 = 275g30g325g35gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [15/20]
#   ______  > fixtureapi_id = 1035085
#   ______  __> pre_ah_pattern = +075+1+125+15H
#   ______  __> pre_ah_pattern_mirror = -15-125-1-075H
#   ______  __> pre_gou_pattern = 25g275g30g325g35gG
#   ______
#   ______  __> pre_ah_pattern_4 = +075+1+125+15H
#   ______  __> pre_ah_pattern_mirror_4 = -15-125-1-075H
#   ______  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [16/20]
#   ______  > fixtureapi_id = 1035084
#   ______  __> pre_ah_pattern = -175-15-125-1H
#   ______  __> pre_ah_pattern_mirror = +1+125+15+175H
#   ______  __> pre_gou_pattern = 25g275g30g325gG
#   ______
#   ______  __> pre_ah_pattern_4 = -175-15-125-1H
#   ______  __> pre_ah_pattern_mirror_4 = +1+125+15+175H
#   ______  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [17/20]
#   ______  > fixtureapi_id = 1035080
#   ______  __> pre_ah_pattern = -1-075-05H
#   ______  __> pre_ah_pattern_mirror = +05+075+1H
#   ______  __> pre_gou_pattern = 225g25g275gG
#   ______
#   ______  __> pre_ah_pattern_4 = -1-075-05-025H
#   ______  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ______  __> pre_gou_pattern_4 = 225g25g275gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [18/20]
#   ______  > fixtureapi_id = 1035081
#   ______  __> pre_ah_pattern = -075-05-025H
#   ______  __> pre_ah_pattern_mirror = +025+05+075H
#   ______  __> pre_gou_pattern = 25g275g30g325g35gG
#   ______
#   ______  __> pre_ah_pattern_4 = -075-05-025H
#   ______  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ______  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [19/20]
#   ______  > fixtureapi_id = 1035078
#   ______  __> pre_ah_pattern = -075-05-025H
#   ______  __> pre_ah_pattern_mirror = +025+05+075H
#   ______  __> pre_gou_pattern = 225g25g275gG
#   ______
#   ______  __> pre_ah_pattern_4 = -1-075-05-025H
#   ______  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ______  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______
#   ______ [20/20]
#   ______  > fixtureapi_id = 1035083
#   ______  __> pre_ah_pattern = -05-025+0H
#   ______  __> pre_ah_pattern_mirror = +0+025+05H
#   ______  __> pre_gou_pattern = 20g225g25g275gG
#   ______
#   ______  __> pre_ah_pattern_4 = -05-025+0+025H
#   ______  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ______  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ______
#   ______  ____> football_odds update pattern commited
#   ______get_today_adds()
#   ________adds date_diff : 5
#   ________today_raw : 2023-09-06 21:29:26.709794
#   ______roags_get()
#   ________Select  leagueapi_id  , season   , fixtureapi_id   from football_fixtures  where leagueapi_id = '39'  and Date(date) <= Date('2023-09-06 21:29:26.709794')  and research_on_anytime_goal_scorers_updated_at is null  order by date desc
#   __________Total Row(s) : 538
#   ____________[1/538]  #39 - 2023 __ 1035067
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035067'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[2/538]  #39 - 2023 __ 1035073
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035073'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________Mohamed Salah - 2.05
#   ________________________roags_insert_or_update()
#   ________________________UPDATE `research_on_anytime_goal_scorers` SET  `pre_odd` = '2.05',  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035073  and value = 'Mohamed Salah'
#   ______________________roags_array()
#   ____________[3/538]  #39 - 2023 __ 1035072
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035072'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[4/538]  #39 - 2023 __ 1035069
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035069'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[5/538]  #39 - 2023 __ 1035075
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035075'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________Julian Alvarez - 2.10
#   ________________________roags_insert_or_update()
#   ________________________UPDATE `research_on_anytime_goal_scorers` SET  `pre_odd` = '2.10',  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035075  and value = 'Julian Alvarez'
#   ______________________Erling Braut Haaland - 1.44
#   ________________________roags_insert_or_update()
#   ________________________UPDATE `research_on_anytime_goal_scorers` SET  `pre_odd` = '1.44',  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035075  and value = 'Erling Braut Haaland'
#   ______________________roags_array()
#   ____________[6/538]  #39 - 2023 __ 1035071
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035071'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________Nicolas Jackson - 1.91
#   ________________________roags_insert_or_update()
#   ________________________UPDATE `research_on_anytime_goal_scorers` SET  `pre_odd` = '1.91',  `updated_at` = now()  where leagueapi_id = 39  and season = 2023  and fixtureapi_id = 1035071  and value = 'Nicolas Jackson'
#   ______________________roags_array()
#   ____________[7/538]  #39 - 2023 __ 1035070
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '39'  and season = '2023'  and fixtureapi_id = '1035070'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________