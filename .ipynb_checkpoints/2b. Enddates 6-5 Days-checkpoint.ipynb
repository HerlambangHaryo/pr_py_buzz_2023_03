# %%
# Import
from a_settings.messages import *  

today = datetime.datetime.now()  
days0 = 6
days1 = 5
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 6 - 5 --> 2023-03-15 07:38:53.924631

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-15 07:38:54
#   __main()
#   ____get_date()
#   ______days : 6
#   ______days : 5
#   ______tgl_awal : 2023-03-09
#   ______tgl_akhir : 2023-03-10
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-10'  and date >= '2023-03-09'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 6
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 25
#   ______________1. 2023-03-09 // 20 // 8 // 2022 // 978761 // None // None
#   ______________2. 2023-03-09 // 168 // 8 // 2023 // 976082 // H // G
#   ______________3. 2023-03-09 // 204 // 8 // 2022 // 884988 // 0#025+05+H // 225g25g275gG
#   ______________4. 2023-03-09 // 204 // 8 // 2022 // 884993 // 025+05+075+H // 225g25g275g3gG
#   ______________5. 2023-03-09 // 240 // 8 // 2023 // 989575 // 05_025_H // 25gG
#   ______________6. 2023-03-09 // 240 // 8 // 2023 // 989574 // H // G
#   ______________7. 2023-03-09 // 240 // 8 // 2023 // 989569 // 05_H // G
#   ______________8. 2023-03-09 // 240 // 8 // 2023 // 989568 // 0#H // 25gG
#   ______________9. 2023-03-09 // 274 // 11 // 2022 // 899780 // 025_0#025+H // 2g225g25g275gG
#   ______________10. 2023-03-09 // 274 // 11 // 2022 // 899782 // 025_0#025+H // 225g25g275g3gG
#   ______________11. 2023-03-09 // 328 // 11 // 2023 // 1001392 // None // None
#   ______________12. 2023-03-09 // 328 // 11 // 2023 // 1001393 // None // None
#   ______________13. 2023-03-09 // 328 // 11 // 2023 // 1001394 // None // None
#   ______________14. 2023-03-09 // 330 // 8 // 2022 // 991145 // None // None
#   ______________15. 2023-03-09 // 330 // 8 // 2022 // 991142 // None // None
#   ______________16. 2023-03-09 // 382 // 8 // 2022 // 877731 // H // 25gG
#   ______________17. 2023-03-09 // 417 // 8 // 2022 // 997657 // None // None
#   ______________18. 2023-03-09 // 667 // 8 // 2023 // 1014171 // None // None
#   ______________19. 2023-03-09 // 667 // 8 // 2023 // 1014172 // None // None
#   ______________20. 2023-03-09 // 667 // 8 // 2023 // 1014173 // None // None
#   ______________21. 2023-03-10 // 667 // 8 // 2023 // 1014174 // None // None
#   ______________22. 2023-03-09 // 740 // 11 // 2023 // 1010631 // None // None
#   ______________23. 2023-03-09 // 740 // 11 // 2023 // 1010632 // None // None
#   ______________24. 2023-03-09 // 887 // 11 // 2022 // 964781 // H // G
#   ______________25. 2023-03-09 // 887 // 11 // 2022 // 964783 // H // G
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-03-09 // 20 // 8 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@live.com counter is 31
#   __________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-09
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 20
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________2. 2023-03-09 // 417 // 8 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@live.com counter is 30
#   __________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-09
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 417
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Bahrain,  Premier League  #417 - 2022 / 997660
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '15.00',
#   ____________________________end_match_winner_draw = '5.25',
#   ____________________________end_match_winner_away = '1.20',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '8.50',
#   ____________________________end_homeaway_away = '1.05',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '9.50',
#   ____________________________end_second_half_winner_draw = '3.00',
#   ____________________________end_second_half_winner_away = '1.44',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '2.63',
#   ____________________________end_goals_overunder_under_35 = '1.44',
#   ____________________________end_goals_overunder_over_15 = '1.20',
#   ____________________________end_goals_overunder_under_15 = '4.33',
#   ____________________________end_goals_overunder_over_45 = '4.50',
#   ____________________________end_goals_overunder_under_45 = '1.17',
#   ____________________________end_goals_overunder_over_25 = '1.67',
#   ____________________________end_goals_overunder_under_25 = '2.15',
#   ____________________________end_goals_overunder_over_05 = '1.02',
#   ____________________________end_goals_overunder_under_05 = '11.00',
#   ____________________________end_goals_overunder_over_55 = '8.00',
#   ____________________________end_goals_overunder_under_55 = '1.06',
#   ____________________________end_goals_overunder_over_65 = '12.00',
#   ____________________________end_goals_overunder_under_65 = '1.02',
#   ____________________________end_goals_overunder_over_75 = '17.00',
#   ____________________________end_goals_overunder_under_75 = '1.01',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '17.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.03',
#   ____________________________end_goals_overunder_first_half_over_15 = '2.50',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.50',
#   ____________________________end_goals_overunder_first_half_over_25 = '6.00',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.13',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.33',
#   ____________________________end_goals_overunder_first_half_under_05 = '3.25',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '9.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.07',
#   ____________________________end_goals_overunder__second_half_over_15 = '1.83',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.83',
#   ____________________________end_goals_overunder__second_half_over_25 = '3.75',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.25',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.18',
#   ____________________________end_goals_overunder__second_half_under_05 = '4.50',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________end_clean_sheet__home_yes = '8.00',
#   ____________________________end_clean_sheet__home_no = '1.06',
#   __________________________28 Clean Sheet - Away
#   ____________________________end_clean_sheet__away_yes = '1.62',
#   ____________________________end_clean_sheet__away_no = '2.20',
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '2.38',
#   ____________________________end_both_teams_score_no = '1.53',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 1.67
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 2.05
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 2.63
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 4.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +4 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +4 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +4 --- bets_odd: 9.50
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.25
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 151.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '4.33',
#   ____________________________end_double_chance_home_away = '1.14',
#   ____________________________end_double_chance_draw_away = '1.01',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '9.50',
#   ____________________________end_first_half_winner_draw = '2.50',
#   ____________________________end_first_half_winner_away = '1.67',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 1.17
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 1.17
#   __________________________32 Win Both Halves
#   ____________________________end_win_both_halves_home = '51.00',
#   ____________________________end_win_both_halves_away = '2.50',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.08
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.01
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 1.36
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.08
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.67
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 5.5 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 5.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 6.5 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 6.5 --- bets_odd: 1.01
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 3.60
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +2 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +2 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +2 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +3 --- bets_odd: 1.05
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +3 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +3 --- bets_odd: 26.00
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________end_win_to_nil_home = '21.00',
#   ____________________________end_win_to_nil_away = '1.73',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.80
#   __________________________23 Home Odd/Even
#   ______________________  ______________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.40
#   __________________________60 Away Odd/Even
#   ______________________  ______________________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.83
#   ______________________  ______________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.83
#   __________________________39 To Win Either Half
#   ____________________________end_to_win_either_half_home = '5.50',
#   ____________________________end_to_win_either_half_away = '1.14',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________24 Results/Both Teams Score
#   ____________________________end_results_both_teams_score_home_yes = '26.00',
#   ____________________________end_results_both_teams_score_draw_yes = '8.00',
#   ____________________________end_results_both_teams_score_away_yes = '3.50',
#   ____________________________end_results_both_teams_score_home_no = '21.00',
#   ____________________________end_results_both_teams_score_draw_no = '11.00',
#   ____________________________end_results_both_teams_score_away_no = '1.73',
#   __________________________25 Result/Total Goals
#   ____________________________end_result_total_goals_home_over_25 = '26.00',
#   ____________________________end_result_total_goals_draw_over_25 = '23.00',
#   ____________________________end_result_total_goals_away_over_25 = '1.83',
#   ____________________________end_result_total_goals_home_under_25 = '23.00',
#   ____________________________end_result_total_goals_draw_under_25 = '6.50',
#   ____________________________end_result_total_goals_away_under_25 = '3.20',
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 10 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 10 --- bets_odd: 1.80
#   __________________________63 Odd/Even - Second Half
#   ______________________  ______________________bet_id: 63 --- bets_value: Odd --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.80
#   __________________________48 To Score In Both Halves By Teams
#   __________________________85 Total Corners (3 way)
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 4 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 4 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 4 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 5 --- bets_odd: 1.05
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 5 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 5 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 6 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 6 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 6 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 7 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 7 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 7 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 8 --- bets_odd: 1.44
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 8 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 8 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 9 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 9 --- bets_odd: 2.63
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 9 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 10 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 10 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 10 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 11 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 11 --- bets_odd: 1.62
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 11 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 13 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 13 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 13 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 14 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 14 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 14 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 17 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 17 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 17 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 12 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 12 --- bets_odd: 1.36
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 12 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 15 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 15 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 15 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 16 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 16 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 16 --- bets_odd: 21.00
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   __________________________77 Total Corners (1st Half)
#   ______________________  ______________________bet_id: 77 --- bets_value: Over 4.5 --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 77 --- bets_value: Under 4.5 --- bets_odd: 2.00
#   __________________________84 Total Corners (3 way) (1st Half)
#   ______________________  ______________________bet_id: 84 --- bets_value: Over 5 --- bets_odd: 2.60
#   ______________________  ______________________bet_id: 84 --- bets_value: Under 5 --- bets_odd: 1.95
#   ______________________  ______________________bet_id: 84 --- bets_value: Exactly 5 --- bets_odd: 5.50
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
#   ____________3. 2023-03-09 // 667 // 8 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@live.com counter is 29
#   __________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-09
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 667
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________4. 2023-03-10 // 667 // 8 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@live.com counter is 28
#   __________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-10
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 667
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 3
#
#   ____________________1. World,  Friendlies Clubs  #667 - 2023 / 992139
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.45',
#   ____________________________end_match_winner_draw = '4.20',
#   ____________________________end_match_winner_away = '5.25',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '1.20',
#   ____________________________end_homeaway_away = '4.33',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_min_1 = '1.80',
#   ____________________________end_asian_handicap_away_min_1 = '2.00',
#   ____________________________end_asian_handicap_home_min_125 = '2.00',
#   ____________________________end_asian_handicap_away_min_125 = '1.80',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_25 = '1.40',
#   ____________________________end_goals_overunder_under_25 = '2.88',
#   __________________________7 HT/FT Double
#   __________________________10 Exact Score
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 126.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.11',
#   ____________________________end_double_chance_home_away = '1.17',
#   ____________________________end_double_chance_draw_away = '2.40',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '1.91',
#   ____________________________end_first_half_winner_draw = '2.60',
#   ____________________________end_first_half_winner_away = '4.75',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.36
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 3.10
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.80
#   __________________________63 Odd/Even - Second Half
#   ______________________  ______________________bet_id: 63 --- bets_value: Odd --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.80
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 1.83
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.98
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 1.75
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 2.05
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ______________________2. World,  Friendlies Clubs  #667 - 2023 / 994338
#   ______________________good to Go 1
#   ____________________________1 Match Winner
#   ______________________________end_match_winner_home = '2.55',
#   ______________________________end_match_winner_draw = '3.50',
#   ______________________________end_match_winner_away = '2.30',
#   ____________________________2 Home/Away
#   ______________________________end_homeaway_home = '2.00',
#   ______________________________end_homeaway_away = '1.73',
#   ____________________________4 Asian Handicap
#   ______________________________end_asian_handicap_home_plus_0 = '2.03',
#   ______________________________end_asian_handicap_away_plus_0 = '1.78',
#   ____________________________5 Goals Over/Under
#   ______________________________end_goals_overunder_over_25 = '1.62',
#   ______________________________end_goals_overunder_under_25 = '2.25',
#   ____________________________7 HT/FT Double
#   ____________________________10 Exact Score
#   ____________________________31 Correct Score - First Half
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 21.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 101.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 126.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.25
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 7.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.75
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 12.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 101.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 19.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 151.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 101.00
#   ____________________________12 Double Chance
#   ______________________________end_double_chance_home_draw = '1.50',
#   ______________________________end_double_chance_home_away = '1.22',
#   ______________________________end_double_chance_draw_away = '1.44',
#   ____________________________13 First Half Winner
#   ______________________________end_first_half_winner_home = '3.10',
#   ______________________________end_first_half_winner_draw = '2.30',
#   ______________________________end_first_half_winner_away = '2.88',
#   ____________________________14 Team To Score First
#   ________________________  ________________________bet_id: 14 --- bets_value: Home --- bets_odd: 2.10
#   ________________________  ________________________bet_id: 14 --- bets_value: Draw --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 14 --- bets_value: Away --- bets_odd: 1.80
#   ____________________________19 Asian Handicap First Half
#   ____________________________20 Double Chance - First Half
#   ____________________________21 Odd/Even
#   ____________________________22 Odd/Even - First Half
#   ________________________  ________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   ________________________  ________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.80
#   ____________________________45 Corners Over Under
#   ________________________  ________________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 1.85
#   ________________________  ________________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 1.95
#   ____________________________63 Odd/Even - Second Half
#   ________________________  ________________________bet_id: 63 --- bets_value: Odd --- bets_odd: 1.91
#   ________________________  ________________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.80
#   ____________________________50 Goal Line
#   ________________________  ________________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 1.75
#   ________________________  ________________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 2.05
#   ____________________________72 Goal Line (1st Half)
#   ________________________  ________________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.03
#   ________________________  ________________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.78
#   ____________________________85 Total Corners (3 way)
#   ________________________  ________________________bet_id: 85 --- bets_value: Over 10 --- bets_odd: 2.38
#   ________________________  ________________________bet_id: 85 --- bets_value: Under 10 --- bets_odd: 1.83
#   ________________________  ________________________bet_id: 85 --- bets_value: Exactly 10 --- bets_odd: 8.00
#   ____________________________77 Total Corners (1st Half)
#   ________________________  ________________________bet_id: 77 --- bets_value: Over 4.5 --- bets_odd: 1.88
#   ________________________  ________________________bet_id: 77 --- bets_value: Under 4.5 --- bets_odd: 1.93
#   ____________________________84 Total Corners (3 way) (1st Half)
#   ________________________  ________________________bet_id: 84 --- bets_value: Over 5 --- bets_odd: 2.75
#   ________________________  ________________________bet_id: 84 --- bets_value: Under 5 --- bets_odd: 1.91
#   ________________________  ________________________bet_id: 84 --- bets_value: Exactly 5 --- bets_odd: 5.50
#   ________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ________________________3. World,  Friendlies Clubs  #667 - 2023 / 999291
#   ________________________good to Go 1
#   ______________________________1 Match Winner
#   ________________________________end_match_winner_home = '2.20',
#   ________________________________end_match_winner_draw = '4.20',
#   ________________________________end_match_winner_away = '2.38',
#   ______________________________2 Home/Away
#   ________________________________end_homeaway_home = '1.80',
#   ________________________________end_homeaway_away = '1.91',
#   ______________________________4 Asian Handicap
#   ________________________________end_asian_handicap_home_min_025 = '2.05',
#   ________________________________end_asian_handicap_away_min_025 = '1.75',
#   ______________________________5 Goals Over/Under
#   ________________________________end_goals_overunder_over_25 = '1.40',
#   ________________________________end_goals_overunder_under_25 = '2.88',
#   ______________________________7 HT/FT Double
#   ______________________________10 Exact Score
#   ______________________________31 Correct Score - First Half
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 12.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 17.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 34.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 41.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 81.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 81.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 126.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 4.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 7.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 41.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 5.50
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 13.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 101.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 17.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 41.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 126.00
#   __________________________  __________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 81.00
#   ______________________________13 First Half Winner
#   ________________________________end_first_half_winner_home = '2.75',
#   ________________________________end_first_half_winner_draw = '2.50',
#   ________________________________end_first_half_winner_away = '3.00',
#   ______________________________14 Team To Score First
#   __________________________  __________________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.73
#   __________________________  __________________________bet_id: 14 --- bets_value: Draw --- bets_odd: 23.00
#   __________________________  __________________________bet_id: 14 --- bets_value: Away --- bets_odd: 2.00
#   ______________________________19 Asian Handicap First Half
#   ______________________________20 Double Chance - First Half
#   ______________________________21 Odd/Even
#   ______________________________22 Odd/Even - First Half
#   __________________________  __________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   __________________________  __________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.80
#   ______________________________63 Odd/Even - Second Half
#   __________________________  __________________________bet_id: 63 --- bets_value: Odd --- bets_odd: 1.83
#   __________________________  __________________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.83
#   ______________________________50 Goal Line
#   __________________________  __________________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 1.85
#   __________________________  __________________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.95
#   ______________________________72 Goal Line (1st Half)
#   __________________________  __________________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 1.80
#   __________________________  __________________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 2.00
#   __________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ____________________________ff_update_unfinished__
#   __________________________  > No longer get supported
#   ____________5. 2023-03-09 // 740 // 11 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@live.com counter is 27
#   __________________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-09
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 740
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 3
#
#   ____________________1. Brazil,  CBF Brasileiro U20  #740 - 2023 / 1010627
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '2.01',
#   ____________________________end_match_winner_draw = '3.44',
#   ____________________________end_match_winner_away = '3.44',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '2.35',
#   ____________________________end_second_half_winner_draw = '2.46',
#   ____________________________end_second_half_winner_away = '3.64',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.50',
#   ____________________________end_asian_handicap_away_plus_0 = '2.54',
#   ____________________________end_asian_handicap_home_min_025 = '1.76',
#   ____________________________end_asian_handicap_away_min_025 = '2.04',
#   ____________________________end_asian_handicap_home_plus_025 = '1.35',
#   ____________________________end_asian_handicap_away_plus_025 = '2.86',
#   ____________________________end_asian_handicap_home_min_075 = '2.25',
#   ____________________________end_asian_handicap_away_min_075 = '1.55',
#   ____________________________end_asian_handicap_home_plus_075 = '1.18',
#   ____________________________end_asian_handicap_away_plus_075 = '4.18',
#   ____________________________end_asian_handicap_home_min_1 = '2.84',
#   ____________________________end_asian_handicap_away_min_1 = '1.35',
#   ____________________________end_asian_handicap_home_plus_1 = '1.07',
#   ____________________________end_asian_handicap_away_plus_1 = '6.25',
#   ____________________________end_asian_handicap_home_min_15 = '3.56',
#   ____________________________end_asian_handicap_away_min_15 = '1.23',
#   ____________________________end_asian_handicap_home_plus_15 = '1.05',
#   ____________________________end_asian_handicap_away_plus_15 = '7.20',
#   ____________________________end_asian_handicap_home_min_125 = '3.20',
#   ____________________________end_asian_handicap_away_min_125 = '1.29',
#   ____________________________end_asian_handicap_home_plus_125 = '1.08',
#   ____________________________end_asian_handicap_away_plus_125 = '6.20',
#   ____________________________end_asian_handicap_home_min_2 = '6.65',
#   ____________________________end_asian_handicap_away_min_2 = '1.06',
#   ____________________________end_asian_handicap_home_min_25 = '7.50',
#   ____________________________end_asian_handicap_away_min_25 = '1.04',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '3.08',
#   ____________________________end_goals_overunder_under_35 = '1.30',
#   ____________________________end_goals_overunder_over_15 = '1.26',
#   ____________________________end_goals_overunder_under_15 = '3.34',
#   ____________________________end_goals_overunder_over_45 = '5.90',
#   ____________________________end_goals_overunder_under_45 = '1.10',
#   ____________________________end_goals_overunder_over_25 = '1.89',
#   ____________________________end_goals_overunder_under_25 = '1.89',
#   ____________________________end_goals_overunder_over_225 = '1.62',
#   ____________________________end_goals_overunder_under_225 = '2.13',
#   ____________________________end_goals_overunder_over_325 = '2.79',
#   ____________________________end_goals_overunder_under_325 = '1.37',
#   ____________________________end_goals_overunder_over_275 = '2.13',
#   ____________________________end_goals_overunder_under_275 = '1.70',
#   ____________________________end_goals_overunder_over_425 = '5.25',
#   ____________________________end_goals_overunder_under_425 = '1.11',
#   ____________________________end_goals_overunder_over_175 = '1.33',
#   ____________________________end_goals_overunder_under_175 = '3.00',
#   ____________________________end_goals_overunder_over_375 = '3.76',
#   ____________________________end_goals_overunder_under_375 = '1.22',
#   ____________________________end_goals_overunder_over_30 = '2.48',
#   ____________________________end_goals_overunder_under_30 = '1.46',
#   ____________________________end_goals_overunder_over_20 = '1.41',
#   ____________________________end_goals_overunder_under_20 = '2.64',
#   ____________________________end_goals_overunder_over_40 = '5.05',
#   ____________________________end_goals_overunder_under_40 = '1.12',
#   ____________________________end_goals_overunder_over_10 = '1.03',
#   ____________________________end_goals_overunder_under_10 = '8.20',
#   __________________________6 Goals Over/Under First Half
# ...
#   __________________________________end_asian_handicap_away_plus_15 = '4.54',
#   __________________________________end_asian_handicap_home_plus_125 = '1.18',
#   __________________________________end_asian_handicap_away_plus_125 = '4.16',
#   __________________________________end_asian_handicap_home_plus_2 = '1.02',
#   __________________________________end_asian_handicap_away_plus_2 = '9.00',
#   __________________________________end_asian_handicap_home_plus_25 = '1.01',
#   __________________________________end_asian_handicap_away_plus_25 = '9.70',
#   ________________________________5 Goals Over/Under
#   __________________________________end_goals_overunder_over_35 = '3.34',
#   __________________________________end_goals_overunder_under_35 = '1.26',
#   __________________________________end_goals_overunder_over_15 = '1.30',
#   __________________________________end_goals_overunder_under_15 = '3.08',
#   __________________________________end_goals_overunder_over_45 = '6.70',
#   __________________________________end_goals_overunder_under_45 = '1.07',
#   __________________________________end_goals_overunder_over_25 = '2.00',
#   __________________________________end_goals_overunder_under_25 = '1.79',
#   __________________________________end_goals_overunder_over_05 = '1.04',
#   __________________________________end_goals_overunder_under_05 = '8.50',
#   __________________________________end_goals_overunder_over_55 = '13.00',
#   __________________________________end_goals_overunder_under_55 = '1.02',
#   __________________________________end_goals_overunder_over_225 = '1.77',
#   __________________________________end_goals_overunder_under_225 = '2.03',
#   __________________________________end_goals_overunder_over_325 = '3.05',
#   __________________________________end_goals_overunder_under_325 = '1.32',
#   __________________________________end_goals_overunder_over_275 = '2.24',
#   __________________________________end_goals_overunder_under_275 = '1.56',
#   __________________________________end_goals_overunder_over_125 = '1.21',
#   __________________________________end_goals_overunder_under_125 = '3.86',
#   __________________________________end_goals_overunder_over_175 = '1.38',
#   __________________________________end_goals_overunder_under_175 = '2.77',
#   __________________________________end_goals_overunder_over_375 = '4.20',
#   __________________________________end_goals_overunder_under_375 = '1.18',
#   __________________________________end_goals_overunder_over_30 = '2.75',
#   __________________________________end_goals_overunder_under_30 = '1.38',
#   __________________________________end_goals_overunder_over_20 = '1.49',
#   __________________________________end_goals_overunder_under_20 = '2.40',
#   __________________________________end_goals_overunder_over_40 = '5.75',
#   __________________________________end_goals_overunder_under_40 = '1.09',
#   __________________________________end_goals_overunder_over_10 = '1.05',
#   __________________________________end_goals_overunder_under_10 = '7.30',
#   ________________________________6 Goals Over/Under First Half
#   __________________________________end_goals_overunder_first_half_over_35 = '21.00',
#   __________________________________end_goals_overunder_first_half_over_15 = '2.90',
#   __________________________________end_goals_overunder_first_half_under_15 = '1.36',
#   __________________________________end_goals_overunder_first_half_over_25 = '6.80',
#   __________________________________end_goals_overunder_first_half_under_25 = '1.07',
#   __________________________________end_goals_overunder_first_half_over_05 = '1.40',
#   __________________________________end_goals_overunder_first_half_under_05 = '2.73',
#   __________________________________end_goals_overunder_first_half_over_125 = '2.40',
#   __________________________________end_goals_overunder_first_half_under_125 = '1.51',
#   __________________________________end_goals_overunder_first_half_over_075 = '1.56',
#   __________________________________end_goals_overunder_first_half_under_075 = '2.28',
#   __________________________________end_goals_overunder_first_half_over_10 = '1.90',
#   __________________________________end_goals_overunder_first_half_under_10 = '1.81',
#   ________________________________26 Goals Over/Under - Second Half
#   __________________________________end_goals_overunder__second_half_over_15 = '2.18',
#   __________________________________end_goals_overunder__second_half_under_15 = '1.61',
#   __________________________________end_goals_overunder__second_half_over_25 = '4.70',
#   __________________________________end_goals_overunder__second_half_under_25 = '1.15',
#   __________________________________end_goals_overunder__second_half_over_05 = '1.26',
#   __________________________________end_goals_overunder__second_half_under_05 = '3.50',
#   __________________________________end_goals_overunder__second_half_over_125 = '1.84',
#   __________________________________end_goals_overunder__second_half_under_125 = '1.87',
#   __________________________________end_goals_overunder__second_half_over_175 = '2.66',
#   __________________________________end_goals_overunder__second_half_under_175 = '1.42',
#   __________________________________end_goals_overunder__second_half_over_075 = '1.39',
#   __________________________________end_goals_overunder__second_half_under_075 = '2.77',
#   __________________________________end_goals_overunder__second_half_over_20 = '3.74',
#   __________________________________end_goals_overunder__second_half_under_20 = '1.23',
#   __________________________________end_goals_overunder__second_half_over_10 = '1.48',
#   __________________________________end_goals_overunder__second_half_under_10 = '2.47',
#   ________________________________7 HT/FT Double
#   ________________________________8 Both Teams Score
#   __________________________________end_both_teams_score_yes = '1.75',
#   __________________________________end_both_teams_score_no = '2.03',
#   ________________________________9 Handicap Result
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.90
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.37
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.30
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.53
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 4.54
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.74
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.12
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 7.50
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 13.00
#   ________________________________10 Exact Score
#   ________________________________11 Highest Scoring Half
#   ________________________________31 Correct Score - First Half
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 17.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 81.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.73
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 67.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.50
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 13.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 26.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 67.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   ________________________________12 Double Chance
#   __________________________________end_double_chance_home_draw = '1.53',
#   __________________________________end_double_chance_home_away = '1.29',
#   __________________________________end_double_chance_draw_away = '1.37',
#   ________________________________13 First Half Winner
#   __________________________________end_first_half_winner_home = '3.60',
#   __________________________________end_first_half_winner_draw = '2.06',
#   __________________________________end_first_half_winner_away = '2.92',
#   ________________________________16 Total - Home
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.64
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.40
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.33
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 2.93
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 5.25
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.11
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.74
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 1.93
#   ________________________________17 Total - Away
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.28
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.53
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.26
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 3.34
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 4.14
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.18
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.53
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 2.28
#   ________________________________18 Handicap Result - First Half
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.30
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 8.80
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.94
#   ________________________________19 Asian Handicap First Half
#   ________________________________20 Double Chance - First Half
#   ________________________________33 Double Chance - Second Half
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.36
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.44
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.25
#   ________________________________34 Both Teams Score - First Half
#   ________________________________35 Both Teams To Score - Second Half
#   ________________________________21 Odd/Even
#   ________________________________22 Odd/Even - First Half
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.03
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.67
#   ________________________________23 Home Odd/Even
#   ____________________________  ____________________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.98
#   ____________________________  ____________________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.70
#   ________________________________60 Away Odd/Even
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.93
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.74
#   ____________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ______________________________ff_update_unfinished__
#   ____________________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-15 07:51:27

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-15 07:51:27
#   __main()
#   ____get_date()
#   ______days : 6
#   ______days : 5
#   ______tgl_awal : 2023-03-09
#   ______tgl_akhir : 2023-03-10
#   ________ff_get_fixture_status_match_finished()
#   __________Total Row(s) : 59
#   __________1. 2023-03-09 // 3 // 8 // 2022 // 1010834 // 175_15_125_1_075_H // 25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010834
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-03-09 // 3 // 8 // 2022 // 1010822 // 125_1_075_05_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010822
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-03-09 // 3 // 8 // 2022 // 1010824 // 175_15_125_H // 25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010824
#   ____________> end_ah_pattern = 2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________4. 2023-03-09 // 3 // 8 // 2022 // 1010826 // 0#025+05+075+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010826
#   ____________> end_ah_pattern = 0#025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_0#H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________5. 2023-03-09 // 3 // 8 // 2022 // 1010828 // 05_025_H // 2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010828
#   ____________> end_ah_pattern = 05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+H
#   ____________> end_gou_pattern = 2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________6. 2023-03-09 // 3 // 8 // 2022 // 1010830 // 125_1_075_05_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010830
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________7. 2023-03-09 // 3 // 8 // 2022 // 1010832 // 1_075_05_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010832
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________8. 2023-03-09 // 3 // 8 // 2022 // 1010836 // 0#025+05+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010836
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________9. 2023-03-09 // 11 // 8 // 2023 // 981707 // 05_025_0#H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981707
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________10. 2023-03-09 // 11 // 8 // 2023 // 981708 // 0#025+05+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981708
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________11. 2023-03-09 // 11 // 8 // 2023 // 981704 // 05_025_0#H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981704
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________12. 2023-03-09 // 11 // 8 // 2023 // 981705 // 0#025+05+H // 2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981705
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________13. 2023-03-09 // 11 // 8 // 2023 // 981706 // 125_1_075_05_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981706
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________14. 2023-03-10 // 11 // 8 // 2023 // 981709 // 05_025_0#H // 175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981709
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________15. 2023-03-10 // 11 // 8 // 2023 // 981710 // 15_125_1_075_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981710
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________16. 2023-03-10 // 13 // 8 // 2023 // 1011460 // 15_125_1_075_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011460
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________17. 2023-03-09 // 13 // 8 // 2023 // 1011464 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011464
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________18. 2023-03-09 // 13 // 8 // 2023 // 1011466 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011466
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________19. 2023-03-09 // 16 // 8 // 2023 // 972944 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 972944
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________20. 2023-03-09 // 16 // 8 // 2023 // 972947 // 0#025+05+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 972947
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________21. 2023-03-09 // 73 // 8 // 2023 // 1011454 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011454
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________22. 2023-03-09 // 73 // 8 // 2023 // 1011457 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011457
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________23. 2023-03-09 // 73 // 8 // 2023 // 1011458 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011458
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________24. 2023-03-09 // 130 // 8 // 2023 // 979191 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 979191
#   ____________> end_ah_pattern = 225_2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+225+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________25. 2023-03-09 // 263 // 8 // 2022 // 975947 // 0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975947
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________26. 2023-03-09 // 263 // 8 // 2022 // 975948 // 025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975948
#   ____________> end_ah_pattern = 05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________27. 2023-03-09 // 307 // 8 // 2022 // 976686 // 025+05+075+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 976686
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________28. 2023-03-09 // 307 // 8 // 2022 // 976688 // 0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 976688
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________29. 2023-03-09 // 307 // 8 // 2022 // 976689 // 075_05_025_0#H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 976689
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________30. 2023-03-09 // 307 // 8 // 2022 // 976690 // 125_1_075_05_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 976690
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________31. 2023-03-09 // 323 // 8 // 2022 // 1012132 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1012132
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________32. 2023-03-09 // 417 // 8 // 2022 // 997660 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 997660
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________33. 2023-03-09 // 496 // 11 // 2022 // 934819 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934819
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________34. 2023-03-09 // 496 // 11 // 2022 // 934822 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934822
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________35. 2023-03-09 // 496 // 11 // 2022 // 934824 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934824
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________36. 2023-03-09 // 496 // 11 // 2022 // 934825 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934825
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 2g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________37. 2023-03-09 // 624 // 8 // 2023 // 973688 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 973688
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________38. 2023-03-09 // 624 // 8 // 2023 // 973689 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 973689
#   ____________> end_ah_pattern = 25_225_2_175_15_H
#   ____________> end_ah_pattern_mirror = 15+175+2+225+25+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________39. 2023-03-09 // 624 // 8 // 2023 // 973690 // 175_15_125_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 973690
#   ____________> end_ah_pattern = 175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________40. 2023-03-09 // 624 // 8 // 2023 // 973691 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 973691
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________41. 2023-03-09 // 624 // 8 // 2023 // 973692 // 025_0#025+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 973692
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________42. 2023-03-09 // 624 // 8 // 2023 // 973693 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 973693
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________43. 2023-03-09 // 701 // 11 // 2022 // 992384 // 075_025_0#025+H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992384
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________44. 2023-03-09 // 701 // 11 // 2022 // 992385 // 025_0#025+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992385
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________45. 2023-03-09 // 740 // 11 // 2023 // 1010627 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010627
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________46. 2023-03-09 // 740 // 11 // 2023 // 1010630 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010630
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________47. 2023-03-09 // 740 // 11 // 2023 // 1010633 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010633
#   ____________> end_ah_pattern = 025+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_025_H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________48. 2023-03-09 // 848 // 8 // 2022 // 1010844 // 05+075+1+125+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010844
#   ____________> end_ah_pattern = 05+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_05_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________49. 2023-03-09 // 848 // 8 // 2022 // 1010846 // 025+05+075+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010846
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________50. 2023-03-09 // 848 // 8 // 2022 // 1010848 // 025+05+075+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010848
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________51. 2023-03-09 // 848 // 8 // 2022 // 1010850 // 075_05_025_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010850
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________52. 2023-03-09 // 848 // 8 // 2022 // 1010852 // 175_15_125_1_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010852
#   ____________> end_ah_pattern = 175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________53. 2023-03-09 // 848 // 8 // 2022 // 1010854 // 075_05_025_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010854
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________54. 2023-03-09 // 848 // 8 // 2022 // 1010856 // 1_075_05_025_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010856
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________55. 2023-03-09 // 887 // 11 // 2022 // 964780 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964780
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________56. 2023-03-09 // 887 // 11 // 2022 // 964782 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964782
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________57. 2023-03-09 // 887 // 11 // 2022 // 964784 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964784
#   ____________> end_ah_pattern = 125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________58. 2023-03-09 // 887 // 11 // 2022 // 964785 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964785
#   ____________> end_ah_pattern = 075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________59. 2023-03-09 // 888 // 11 // 2022 // 965027 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965027
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
# # -------------------------------------------------- End at 2023-03-15 07:53:43

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
