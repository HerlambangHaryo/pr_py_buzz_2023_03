# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

leagueapi_id = input( "Enter your leagueapi id :  ")
season = input( "Enter your season :  ")

today = datetime.datetime.now()  
days0 = 7
days1 = 1
# Out:
# Enter your leagueapi id :  41
# Enter your season :  2022

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "leagueapi_id : " + str(leagueapi_id))
    print(space + "season : " + str(season))
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir)  
    # --------------------------------------------------   
    ff_get_group_date_league_status_match_finished(leagueapi_id, season, tgl_awal, tgl_akhir, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-02 01:55:21
#   __main()
#   ____leagueapi_id : 41
#   ____season : 2022
#   ____days : 7
#   ____days : 1
#   ____tgl_awal : 2023-03-26
#   ____tgl_akhir : 2023-04-01
#   ______ff_get_group_date_league_status_match_finished()
#   ______Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where leagueapi_id = '41'  and season = '2022'  and date <= '2023-04-01'  and date >= '2023-03-26'  and fixture_status like 'Match Finished'  and deleted_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   ________Total Row(s) : 3
#   __________ff_get_fixture_status_match_finished_by_league()
#   ____________Total Row(s) : 3
#   ____________1. 2023-03-29 // 41 // 8 // 2022 // 875805 // 05+075+1+H // 2g225g25gG // Match Finished
#   ____________2. 2023-03-28 // 41 // 8 // 2022 // 875806 // 0#025+05+H // 225g25g275gG // Match Finished
#   ____________3. 2023-03-26 // 41 // 8 // 2022 // 875950 // 1+125+15+175+H // 225g25g275g3gG // Match Finished
#   ________Are you sure want to continue? :  yes
#   __________1. 2023-03-29 // 41 // 8 // 2022
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@gmail.com counter is 13
#   ________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-29
#   ________________bookmaker : 8
#   ________________season : 2022
#   ________________league : 41
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 1
#
#   __________________1. England,  League One  #41 - 2022 / 875805
#   __________________good to Go 1
#   ________________________1 Match Winner
#   __________________________end_match_winner_home = '5.25',
#   __________________________end_match_winner_draw = '3.50',
#   __________________________end_match_winner_away = '1.73',
#   ________________________2 Home/Away
#   __________________________end_homeaway_home = '3.75',
#   __________________________end_homeaway_away = '1.25',
#   ________________________3 Second Half Winner
#   __________________________end_second_half_winner_home = '4.75',
#   __________________________end_second_half_winner_draw = '2.40',
#   __________________________end_second_half_winner_away = '2.05',
#   ________________________4 Asian Handicap
#   __________________________end_asian_handicap_home_plus_0 = '3.70',
#   __________________________end_asian_handicap_away_plus_0 = '1.26',
#   __________________________end_asian_handicap_home_min_025 = '4.25',
#   __________________________end_asian_handicap_away_min_025 = '1.21',
#   __________________________end_asian_handicap_home_plus_025 = '2.60',
#   __________________________end_asian_handicap_away_plus_025 = '1.48',
#   __________________________end_asian_handicap_home_min_05 = '4.80',
#   __________________________end_asian_handicap_away_min_05 = '1.18',
#   __________________________end_asian_handicap_home_plus_05 = '2.10',
#   __________________________end_asian_handicap_away_plus_05 = '1.70',
#   __________________________end_asian_handicap_home_min_075 = '6.80',
#   __________________________end_asian_handicap_away_min_075 = '1.10',
#   __________________________end_asian_handicap_home_plus_075 = '1.88',
#   __________________________end_asian_handicap_away_plus_075 = '1.98',
#   __________________________end_asian_handicap_home_plus_1 = '1.58',
#   __________________________end_asian_handicap_away_plus_1 = '2.35',
#   __________________________end_asian_handicap_home_plus_15 = '1.35',
#   __________________________end_asian_handicap_away_plus_15 = '3.10',
#   __________________________end_asian_handicap_home_plus_125 = '1.45',
#   __________________________end_asian_handicap_away_plus_125 = '2.67',
#   __________________________end_asian_handicap_home_plus_175 = '1.25',
#   __________________________end_asian_handicap_away_plus_175 = '3.80',
#   __________________________end_asian_handicap_home_plus_2 = '1.14',
#   __________________________end_asian_handicap_away_plus_2 = '5.75',
#   __________________________end_asian_handicap_home_plus_25 = '1.11',
#   __________________________end_asian_handicap_away_plus_25 = '6.60',
#   __________________________end_asian_handicap_home_plus_225 = '1.13',
#   __________________________end_asian_handicap_away_plus_225 = '6.00',
#   ________________________5 Goals Over/Under
#   __________________________end_goals_overunder_over_35 = '3.75',
#   __________________________end_goals_overunder_under_35 = '1.25',
#   __________________________end_goals_overunder_over_15 = '1.36',
#   __________________________end_goals_overunder_under_15 = '3.00',
#   __________________________end_goals_overunder_over_45 = '9.00',
#   __________________________end_goals_overunder_under_45 = '1.07',
#   __________________________end_goals_overunder_over_25 = '2.15',
#   __________________________end_goals_overunder_under_25 = '1.67',
#   __________________________end_goals_overunder_over_05 = '1.08',
#   __________________________end_goals_overunder_under_05 = '8.00',
#   __________________________end_goals_overunder_over_55 = '19.00',
#   __________________________end_goals_overunder_under_55 = '1.02',
#   __________________________end_goals_overunder_over_225 = '1.93',
#   __________________________end_goals_overunder_under_225 = '1.93',
#   __________________________end_goals_overunder_over_325 = '3.55',
#   __________________________end_goals_overunder_under_325 = '1.27',
#   __________________________end_goals_overunder_over_275 = '2.50',
#   __________________________end_goals_overunder_under_275 = '1.50',
#   __________________________end_goals_overunder_over_125 = '1.23',
#   __________________________end_goals_overunder_under_125 = '4.00',
#   __________________________end_goals_overunder_over_425 = '7.00',
#   __________________________end_goals_overunder_under_425 = '1.10',
#   __________________________end_goals_overunder_over_175 = '1.45',
#   __________________________end_goals_overunder_under_175 = '2.67',
#   __________________________end_goals_overunder_over_375 = '5.00',
#   __________________________end_goals_overunder_under_375 = '1.17',
#   __________________________end_goals_overunder_over_65 = '41.00',
#   __________________________end_goals_overunder_under_65 = '1.00',
#   __________________________end_goals_overunder_over_30 = '3.10',
#   __________________________end_goals_overunder_under_30 = '1.35',
#   __________________________end_goals_overunder_over_20 = '1.60',
#   __________________________end_goals_overunder_under_20 = '2.30',
#   __________________________end_goals_overunder_over_40 = '6.60',
#   __________________________end_goals_overunder_under_40 = '1.11',
#   __________________________end_goals_overunder_over_10 = '1.10',
#   __________________________end_goals_overunder_under_10 = '7.00',
#   ________________________6 Goals Over/Under First Half
#   __________________________end_goals_overunder_first_half_over_35 = '26.00',
#   __________________________end_goals_overunder_first_half_under_35 = '1.01',
#   __________________________end_goals_overunder_first_half_over_15 = '3.25',
#   __________________________end_goals_overunder_first_half_under_15 = '1.33',
#   __________________________end_goals_overunder_first_half_over_25 = '10.00',
#   __________________________end_goals_overunder_first_half_under_25 = '1.06',
#   __________________________end_goals_overunder_first_half_over_05 = '1.44',
#   __________________________end_goals_overunder_first_half_under_05 = '2.63',
#   __________________________end_goals_overunder_first_half_over_125 = '2.67',
#   __________________________end_goals_overunder_first_half_under_125 = '1.45',
#   __________________________end_goals_overunder_first_half_over_175 = '4.25',
#   __________________________end_goals_overunder_first_half_under_175 = '1.21',
#   __________________________end_goals_overunder_first_half_over_075 = '1.68',
#   __________________________end_goals_overunder_first_half_under_075 = '2.15',
#   __________________________end_goals_overunder_first_half_over_20 = '6.80',
#   __________________________end_goals_overunder_first_half_under_20 = '1.10',
#   __________________________end_goals_overunder_first_half_over_10 = '2.08',
#   __________________________end_goals_overunder_first_half_under_10 = '1.73',
#   ________________________26 Goals Over/Under - Second Half
#   __________________________end_goals_overunder__second_half_over_35 = '15.00',
#   __________________________end_goals_overunder__second_half_under_35 = '1.03',
#   __________________________end_goals_overunder__second_half_over_15 = '2.25',
#   __________________________end_goals_overunder__second_half_under_15 = '1.57',
#   __________________________end_goals_overunder__second_half_over_25 = '5.50',
#   __________________________end_goals_overunder__second_half_under_25 = '1.14',
#   __________________________end_goals_overunder__second_half_over_05 = '1.29',
#   __________________________end_goals_overunder__second_half_under_05 = '3.50',
#   ________________________7 HT/FT Double
#   ________________________27 Clean Sheet - Home
#   __________________________end_clean_sheet__home_yes = '4.33',
#   __________________________end_clean_sheet__home_no = '1.20',
#   ________________________28 Clean Sheet - Away
#   __________________________end_clean_sheet__away_yes = '2.10',
#   __________________________end_clean_sheet__away_no = '1.67',
#   ________________________8 Both Teams Score
#   __________________________end_both_teams_score_yes = '2.00',
#   __________________________end_both_teams_score_no = '1.75',
#   ________________________9 Handicap Result
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.17
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 2.05
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 3.10
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.36
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.04
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.10
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 9.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 15.00
#   ________________________10 Exact Score
#   ________________________11 Highest Scoring Half
#   ________________________31 Correct Score - First Half
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 29.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 101.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 151.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 301.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.63
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 3.60
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 451.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 23.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 201.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 201.00
#   ________________________12 Double Chance
#   __________________________end_double_chance_home_draw = '2.05',
#   __________________________end_double_chance_home_away = '1.29',
#   __________________________end_double_chance_draw_away = '1.17',
#   ________________________13 First Half Winner
#   __________________________end_first_half_winner_home = '5.50',
#   __________________________end_first_half_winner_draw = '2.10',
#   __________________________end_first_half_winner_away = '2.38',
#   ________________________14 Team To Score First
#   ____________________  ____________________bet_id: 14 --- bets_value: Home --- bets_odd: 3.20
#   ____________________  ____________________bet_id: 14 --- bets_value: Draw --- bets_odd: 8.00
#   ____________________  ____________________bet_id: 14 --- bets_value: Away --- bets_odd: 1.50
#   ________________________15 Team To Score Last
#   ____________________  ____________________bet_id: 15 --- bets_value: Home --- bets_odd: 3.20
#   ____________________  ____________________bet_id: 15 --- bets_value: Draw --- bets_odd: 8.00
#   ____________________  ____________________bet_id: 15 --- bets_value: Away --- bets_odd: 1.50
#   ________________________32 Win Both Halves
#   __________________________end_win_both_halves_home = '21.00',
#   __________________________end_win_both_halves_away = '5.00',
#   ________________________16 Total - Home
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 4.50
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.18
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.03
#   ________________________17 Total - Away
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 1.91
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.80
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 26.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.22
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 5.5 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 5.5 --- bets_odd: 1.00
#   ________________________18 Handicap Result - First Half
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 21.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.13
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.53
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 7.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.10
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +2 --- bets_odd: 1.08
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +2 --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +2 --- bets_odd: 26.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +3 --- bets_odd: 1.02
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +3 --- bets_odd: 29.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +3 --- bets_odd: 67.00
#   ________________________19 Asian Handicap First Half
#   ________________________20 Double Chance - First Half
#   ________________________34 Both Teams Score - First Half
#   ________________________35 Both Teams To Score - Second Half
#   ________________________36 Win To Nil
#   __________________________end_win_to_nil_home = '8.00',
#   __________________________end_win_to_nil_away = '2.63',
#   ________________________21 Odd/Even
#   ________________________22 Odd/Even - First Half
#   ____________________  ____________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.20
#   ____________________  ____________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.67
#   ________________________39 To Win Either Half
#   __________________________end_to_win_either_half_home = '2.75',
#   __________________________end_to_win_either_half_away = '1.44',
#   ________________________40 Home Team Exact Goals Number
#   ________________________41 Away Team Exact Goals Number
#   ________________________24 Results/Both Teams Score
#   __________________________end_results_both_teams_score_home_yes = '11.00',
#   __________________________end_results_both_teams_score_draw_yes = '5.00',
#   __________________________end_results_both_teams_score_away_yes = '4.33',
#   __________________________end_results_both_teams_score_home_no = '8.00',
#   __________________________end_results_both_teams_score_draw_no = '8.00',
#   __________________________end_results_both_teams_score_away_no = '2.63',
#   ________________________25 Result/Total Goals
#   __________________________end_result_total_goals_home_over_25 = '10.00',
#   __________________________end_result_total_goals_draw_over_25 = '17.00',
#   __________________________end_result_total_goals_away_over_25 = '3.00',
#   __________________________end_result_total_goals_home_under_25 = '9.00',
#   __________________________end_result_total_goals_draw_under_25 = '4.00',
#   __________________________end_result_total_goals_away_under_25 = '3.50',
#   ________________________43 Home Team Score a Goal
#   ____________________  ____________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.67
#   ____________________  ____________________bet_id: 43 --- bets_value: No --- bets_odd: 2.10
#   ________________________44 Away Team Score a Goal
#   ____________________  ____________________bet_id: 44 --- bets_value: Yes --- bets_odd: 1.20
#   ____________________  ____________________bet_id: 44 --- bets_value: No --- bets_odd: 4.33
#   ________________________54 First 10 min Winner
#   ____________________  ____________________bet_id: 54 --- bets_value: Home --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 54 --- bets_value: Draw --- bets_odd: 1.14
#   ____________________  ____________________bet_id: 54 --- bets_value: Away --- bets_odd: 7.00
#   ________________________55 Corners 1x2
#   ________________________45 Corners Over Under
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 1.83
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 1.83
#   ________________________47 Winning Margin
#   ____________________  ____________________bet_id: 47 --- bets_value: Draw --- bets_odd: 8.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 3.50
#   ____________________  ____________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 9.50
#   ____________________  ____________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 126.00
#   ____________________  ____________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 5.00
#   ________________________48 To Score In Both Halves By Teams
#   ________________________49 Total Goals/Both Teams To Score
#   __________________________end_total_goals_both_teams_to_score_over_yes_25 = '2.75',
#   __________________________end_total_goals_both_teams_to_score_over_no_25 = '8.00',
#   __________________________end_total_goals_both_teams_to_score_under_yes_25 = '6.50',
#   __________________________end_total_goals_both_teams_to_score_under_no_25 = '2.05',
#   ________________________91 Total Goals (3 way)
#   ____________________  ____________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 1.95
#   ____________________  ____________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 3.75
#   ________________________50 Goal Line
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 3.80
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.25
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.38
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 2.15
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.68
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.60
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.30
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 3.10
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.35
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 6.60
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.11
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.93
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 1.93
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 3.55
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.27
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.50
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.50
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.23
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 4.25 --- bets_odd: 7.00
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 4.25 --- bets_odd: 1.10
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.45
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 2.67
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.17
#   ____________________  ____________________bet_id: 50 --- bets_value: Over 1 --- bets_odd: 1.10
#   ____________________  ____________________bet_id: 50 --- bets_value: Under 1 --- bets_odd: 7.00
#   ________________________72 Goal Line (1st Half)
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 3.30
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.32
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 0.5 --- bets_odd: 1.48
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 0.5 --- bets_odd: 2.60
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 6.80
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.10
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.67
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.45
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 4.25
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.21
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 2.08
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.73
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.68
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.15
#   ________________________97 First Goal Method
#   ____________________  ____________________bet_id: 97 --- bets_value: Shot --- bets_odd: 1.50
#   ____________________  ____________________bet_id: 97 --- bets_value: Header --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 97 --- bets_value: Penalty --- bets_odd: 8.00
#   ____________________  ____________________bet_id: 97 --- bets_value: FreeKick --- bets_odd: 23.00
#   ____________________  ____________________bet_id: 97 --- bets_value: OwnGoal --- bets_odd: 29.00
#   ____________________  ____________________bet_id: 97 --- bets_value: Draw --- bets_odd: 8.00
#   ________________________52 Halftime Result/Both Teams Score
#   ________________________56 Corners Asian Handicap
#   ____________________  ____________________bet_id: 56 --- bets_value: Home +2 --- bets_odd: 1.85
#   ____________________  ____________________bet_id: 56 --- bets_value: Away +2 --- bets_odd: 1.95
#   ________________________57 Home Corners Over/Under
#   ____________________  ____________________bet_id: 57 --- bets_value: Over 3.5 --- bets_odd: 1.80
#   ____________________  ____________________bet_id: 57 --- bets_value: Under 3.5 --- bets_odd: 1.91
#   ________________________58 Away Corners Over/Under
#   ____________________  ____________________bet_id: 58 --- bets_value: Over 5.5 --- bets_odd: 1.83
#   ____________________  ____________________bet_id: 58 --- bets_value: Under 5.5 --- bets_odd: 1.83
#   ________________________59 Own Goal
#   ____________________  ____________________bet_id: 59 --- bets_value: Yes --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 59 --- bets_value: No --- bets_odd: 1.04
#   ________________________92 Anytime Goal Scorer
#   ________________________93 First Goal Scorer
#   ________________________94 Last Goal Scorer
#   ________________________95 To Score Two or More Goals
#   ________________________96 Last Goal Scorer
#   ________________________85 Total Corners (3 way)
#   ____________________  ____________________bet_id: 85 --- bets_value: Over 10 --- bets_odd: 2.38
#   ____________________  ____________________bet_id: 85 --- bets_value: Under 10 --- bets_odd: 1.83
#   ____________________  ____________________bet_id: 85 --- bets_value: Exactly 10 --- bets_odd: 8.00
#   ________________________73 Both Teams to Score 1st Half - 2nd Half
#   ________________________74 10 Over/Under
#   ________________________75 Last Corner
#   ____________________  ____________________bet_id: 75 --- bets_value: Home --- bets_odd: 2.50
#   ____________________  ____________________bet_id: 75 --- bets_value: Away --- bets_odd: 1.50
#   ________________________76 First Corner
#   ____________________  ____________________bet_id: 76 --- bets_value: Home --- bets_odd: 2.50
#   ____________________  ____________________bet_id: 76 --- bets_value: Away --- bets_odd: 1.50
#   ________________________78 RTG_H1
#   ____________________  ____________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 6.00
#   ____________________  ____________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 2.63
#   ____________________  ____________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 3.60
#   ________________________99 To Score A Penalty
#   ____________________  ____________________bet_id: 99 --- bets_value: Home --- bets_odd: 10.00
#   ____________________  ____________________bet_id: 99 --- bets_value: Away --- bets_odd: 5.50
#   ________________________100 To Miss A Penalty
#   ____________________  ____________________bet_id: 100 --- bets_value: Home --- bets_odd: 26.00
#   ____________________  ____________________bet_id: 100 --- bets_value: Away --- bets_odd: 17.00
#   ____________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   __________2. 2023-03-28 // 41 // 8 // 2022
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@gmail.com counter is 12
#   ________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-28
#   ________________bookmaker : 8
#   ________________season : 2022
#   ________________league : 41
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 1
#
#   __________________1. England,  League One  #41 - 2022 / 875806
#   __________________good to Go 1
#   ________________________1 Match Winner
#   __________________________end_match_winner_home = '3.30',
#   __________________________end_match_winner_draw = '3.30',
#   __________________________end_match_winner_away = '2.20',
#   ________________________2 Home/Away
#   __________________________end_homeaway_home = '2.25',
#   __________________________end_homeaway_away = '1.57',
#   ________________________3 Second Half Winner
#   __________________________end_second_half_winner_home = '3.40',
#   __________________________end_second_half_winner_draw = '2.38',
#   __________________________end_second_half_winner_away = '2.50',
#   ________________________4 Asian Handicap
#   __________________________end_asian_handicap_home_plus_0 = '2.38',
#   __________________________end_asian_handicap_away_plus_0 = '1.55',
#   __________________________end_asian_handicap_home_min_025 = '2.75',
#   __________________________end_asian_handicap_away_min_025 = '1.43',
#   __________________________end_asian_handicap_home_plus_025 = '1.98',
#   __________________________end_asian_handicap_away_plus_025 = '1.88',
#   __________________________end_asian_handicap_home_min_05 = '3.30',
#   __________________________end_asian_handicap_away_min_05 = '1.32',
#   __________________________end_asian_handicap_home_plus_05 = '1.70',
#   __________________________end_asian_handicap_away_plus_05 = '2.10',
#   __________________________end_asian_handicap_home_min_075 = '4.10',
#   __________________________end_asian_handicap_away_min_075 = '1.23',
#   __________________________end_asian_handicap_home_plus_075 = '1.50',
#   __________________________end_asian_handicap_away_plus_075 = '2.50',
#   __________________________end_asian_handicap_home_min_1 = '6.25',
#   __________________________end_asian_handicap_away_min_1 = '1.12',
#   __________________________end_asian_handicap_home_plus_1 = '1.32',
#   __________________________end_asian_handicap_away_plus_1 = '3.30',
#   __________________________end_asian_handicap_home_min_15 = '7.00',
#   __________________________end_asian_handicap_away_min_15 = '1.10',
#   __________________________end_asian_handicap_home_plus_15 = '1.22',
#   __________________________end_asian_handicap_away_plus_15 = '4.15',
#   __________________________end_asian_handicap_home_min_125 = '6.80',
#   __________________________end_asian_handicap_away_min_125 = '1.10',
#   __________________________end_asian_handicap_home_plus_125 = '1.26',
#   __________________________end_asian_handicap_away_plus_125 = '3.70',
#   __________________________end_asian_handicap_home_plus_175 = '1.15',
#   __________________________end_asian_handicap_away_plus_175 = '5.50',
#   ________________________5 Goals Over/Under
#   __________________________end_goals_overunder_over_35 = '3.50',
#   __________________________end_goals_overunder_under_35 = '1.29',
#   __________________________end_goals_overunder_over_15 = '1.30',
#   __________________________end_goals_overunder_under_15 = '3.40',
#   __________________________end_goals_overunder_over_45 = '8.00',
#   __________________________end_goals_overunder_under_45 = '1.08',
#   __________________________end_goals_overunder_over_25 = '2.05',
#   __________________________end_goals_overunder_under_25 = '1.75',
#   __________________________end_goals_overunder_over_05 = '1.06',
#   __________________________end_goals_overunder_under_05 = '10.00',
#   __________________________end_goals_overunder_over_55 = '17.00',
#   __________________________end_goals_overunder_under_55 = '1.02',
#   __________________________end_goals_overunder_over_225 = '1.80',
#   __________________________end_goals_overunder_under_225 = '2.05',
#   __________________________end_goals_overunder_over_325 = '3.30',
#   __________________________end_goals_overunder_under_325 = '1.32',
#   __________________________end_goals_overunder_over_275 = '2.35',
#   __________________________end_goals_overunder_under_275 = '1.58',
#   __________________________end_goals_overunder_over_125 = '1.20',
#   __________________________end_goals_overunder_under_125 = '4.40',
#   __________________________end_goals_overunder_over_425 = '6.80',
#   __________________________end_goals_overunder_under_425 = '1.10',
#   __________________________end_goals_overunder_over_175 = '1.40',
#   __________________________end_goals_overunder_under_175 = '2.85',
#   __________________________end_goals_overunder_over_375 = '4.40',
#   __________________________end_goals_overunder_under_375 = '1.20',
#   __________________________end_goals_overunder_over_65 = '34.00',
#   __________________________end_goals_overunder_under_65 = '1.00',
#   __________________________end_goals_overunder_over_30 = '2.85',
#   __________________________end_goals_overunder_under_30 = '1.40',
#   __________________________end_goals_overunder_over_20 = '1.52',
#   __________________________end_goals_overunder_under_20 = '2.42',
#   __________________________end_goals_overunder_over_40 = '6.40',
#   __________________________end_goals_overunder_under_40 = '1.11',
#   ________________________6 Goals Over/Under First Half
#   __________________________end_goals_overunder_first_half_over_35 = '26.00',
#   __________________________end_goals_overunder_first_half_under_35 = '1.01',
#   __________________________end_goals_overunder_first_half_over_15 = '3.25',
#   __________________________end_goals_overunder_first_half_under_15 = '1.33',
#   __________________________end_goals_overunder_first_half_over_25 = '9.00',
#   __________________________end_goals_overunder_first_half_under_25 = '1.07',
#   __________________________end_goals_overunder_first_half_over_05 = '1.44',
#   __________________________end_goals_overunder_first_half_under_05 = '2.63',
#   __________________________end_goals_overunder_first_half_over_225 = '7.00',
#   __________________________end_goals_overunder_first_half_under_225 = '1.10',
#   __________________________end_goals_overunder_first_half_over_125 = '2.50',
#   __________________________end_goals_overunder_first_half_under_125 = '1.50',
#   __________________________end_goals_overunder_first_half_over_175 = '3.90',
#   __________________________end_goals_overunder_first_half_under_175 = '1.24',
#   __________________________end_goals_overunder_first_half_over_075 = '1.60',
#   __________________________end_goals_overunder_first_half_under_075 = '2.30',
#   __________________________end_goals_overunder_first_half_over_20 = '6.80',
#   __________________________end_goals_overunder_first_half_under_20 = '1.10',
#   __________________________end_goals_overunder_first_half_over_10 = '2.00',
#   __________________________end_goals_overunder_first_half_under_10 = '1.80',
#   ________________________26 Goals Over/Under - Second Half
#   __________________________end_goals_overunder__second_half_over_35 = '13.00',
#   __________________________end_goals_overunder__second_half_under_35 = '1.04',
#   __________________________end_goals_overunder__second_half_over_15 = '2.20',
#   __________________________end_goals_overunder__second_half_under_15 = '1.62',
#   __________________________end_goals_overunder__second_half_over_25 = '5.00',
#   __________________________end_goals_overunder__second_half_under_25 = '1.17',
#   __________________________end_goals_overunder__second_half_over_05 = '1.25',
#   __________________________end_goals_overunder__second_half_under_05 = '3.75',
#   ________________________7 HT/FT Double
#   ________________________27 Clean Sheet - Home
#   __________________________end_clean_sheet__home_yes = '3.75',
#   __________________________end_clean_sheet__home_no = '1.25',
#   ________________________28 Clean Sheet - Away
#   __________________________end_clean_sheet__away_yes = '2.75',
#   __________________________end_clean_sheet__away_no = '1.40',
#   ________________________8 Both Teams Score
#   __________________________end_both_teams_score_yes = '1.80',
#   __________________________end_both_teams_score_no = '1.95',
#   ________________________9 Handicap Result
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 7.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.33
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.67
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.20
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 10.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 19.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 10.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.08
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 26.00
#   ________________________10 Exact Score
#   ________________________11 Highest Scoring Half
#   ________________________31 Correct Score - First Half
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 19.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 201.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 301.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 451.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.63
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 12.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 151.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 23.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 251.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 151.00
#   ________________________12 Double Chance
#   __________________________end_double_chance_home_draw = '1.67',
#   __________________________end_double_chance_home_away = '1.33',
#   __________________________end_double_chance_draw_away = '1.33',
#   ________________________13 First Half Winner
#   __________________________end_first_half_winner_home = '3.75',
#   __________________________end_first_half_winner_draw = '2.10',
#   __________________________end_first_half_winner_away = '2.88',
#   ________________________14 Team To Score First
#   ____________________  ____________________bet_id: 14 --- bets_value: Home --- bets_odd: 2.38
#   ____________________  ____________________bet_id: 14 --- bets_value: Draw --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 14 --- bets_value: Away --- bets_odd: 1.73
#   ________________________15 Team To Score Last
#   ____________________  ____________________bet_id: 15 --- bets_value: Home --- bets_odd: 2.38
#   ____________________  ____________________bet_id: 15 --- bets_value: Draw --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 15 --- bets_value: Away --- bets_odd: 1.73
#   ________________________32 Win Both Halves
#   __________________________end_win_both_halves_home = '13.00',
#   __________________________end_win_both_halves_away = '8.00',
#   ________________________16 Total - Home
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 23.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.36
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 8.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.08
#   ________________________17 Total - Away
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 15.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.03
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.25
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.57
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.14
#   ________________________18 Handicap Result - First Half
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.25
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.40
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 9.50
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.60
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +2 --- bets_odd: 1.05
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +2 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +2 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +3 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +3 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +3 --- bets_odd: 126.00
#   ________________________19 Asian Handicap First Half
#   ________________________20 Double Chance - First Half
#   ________________________34 Both Teams Score - First Half
#   ________________________35 Both Teams To Score - Second Half
#   ________________________36 Win To Nil
#   __________________________end_win_to_nil_home = '5.50',
#   __________________________end_win_to_nil_away = '3.75',
#   ________________________21 Odd/Even
#   ________________________22 Odd/Even - First Half
#   ____________________  ____________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.10
#   ____________________  ____________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   ________________________39 To Win Either Half
# ...
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.14
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 6.25
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.12
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.30
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.60
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 3.55
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.27
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.80
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 2.00
#   ____________________  ____________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.52
#   ____________________  ____________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.42
#   ________________________97 First Goal Method
#   ____________________  ____________________bet_id: 97 --- bets_value: Shot --- bets_odd: 1.50
#   ____________________  ____________________bet_id: 97 --- bets_value: Header --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 97 --- bets_value: Penalty --- bets_odd: 7.50
#   ____________________  ____________________bet_id: 97 --- bets_value: FreeKick --- bets_odd: 21.00
#   ____________________  ____________________bet_id: 97 --- bets_value: OwnGoal --- bets_odd: 29.00
#   ____________________  ____________________bet_id: 97 --- bets_value: Draw --- bets_odd: 11.00
#   ________________________52 Halftime Result/Both Teams Score
#   ________________________56 Corners Asian Handicap
#   ____________________  ____________________bet_id: 56 --- bets_value: Home +3 --- bets_odd: 1.90
#   ____________________  ____________________bet_id: 56 --- bets_value: Away +3 --- bets_odd: 1.90
#   ________________________57 Home Corners Over/Under
#   ____________________  ____________________bet_id: 57 --- bets_value: Over 2.5 --- bets_odd: 1.62
#   ____________________  ____________________bet_id: 57 --- bets_value: Under 2.5 --- bets_odd: 2.20
#   ________________________58 Away Corners Over/Under
#   ____________________  ____________________bet_id: 58 --- bets_value: Over 5.5 --- bets_odd: 1.67
#   ____________________  ____________________bet_id: 58 --- bets_value: Under 5.5 --- bets_odd: 2.10
#   ________________________59 Own Goal
#   ____________________  ____________________bet_id: 59 --- bets_value: Yes --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 59 --- bets_value: No --- bets_odd: 1.05
#   ________________________92 Anytime Goal Scorer
#   ________________________93 First Goal Scorer
#   ________________________94 Last Goal Scorer
#   ________________________95 To Score Two or More Goals
#   ________________________96 Last Goal Scorer
#   ________________________85 Total Corners (3 way)
#   ____________________  ____________________bet_id: 85 --- bets_value: Over 9 --- bets_odd: 1.91
#   ____________________  ____________________bet_id: 85 --- bets_value: Under 9 --- bets_odd: 2.25
#   ____________________  ____________________bet_id: 85 --- bets_value: Exactly 9 --- bets_odd: 7.50
#   ________________________73 Both Teams to Score 1st Half - 2nd Half
#   ________________________74 10 Over/Under
#   ________________________75 Last Corner
#   ____________________  ____________________bet_id: 75 --- bets_value: Home --- bets_odd: 3.25
#   ____________________  ____________________bet_id: 75 --- bets_value: Away --- bets_odd: 1.33
#   ________________________76 First Corner
#   ____________________  ____________________bet_id: 76 --- bets_value: Home --- bets_odd: 3.25
#   ____________________  ____________________bet_id: 76 --- bets_value: Away --- bets_odd: 1.33
#   ________________________78 RTG_H1
#   ____________________  ____________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 21.00
#   ____________________  ____________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 4.00
#   ____________________  ____________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 9.00
#   ____________________  ____________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 3.00
#   ____________________  ____________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 8.50
#   ____________________  ____________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 3.25
#   ________________________79 Cards European Handicap
#   ________________________80 Cards Over/Under
#   ____________________  ____________________bet_id: 80 --- bets_value: Over 3.5 --- bets_odd: 1.62
#   ____________________  ____________________bet_id: 80 --- bets_value: Under 3.5 --- bets_odd: 2.20
#   ________________________81 Cards Asian Handicap
#   ____________________  ____________________bet_id: 81 --- bets_value: Home +0 --- bets_odd: 1.70
#   ____________________  ____________________bet_id: 81 --- bets_value: Away +0 --- bets_odd: 2.10
#   ________________________82 Home Team Total Cards
#   ____________________  ____________________bet_id: 82 --- bets_value: Over 2.5 --- bets_odd: 2.50
#   ____________________  ____________________bet_id: 82 --- bets_value: Under 2.5 --- bets_odd: 1.50
#   ________________________83 Away Team Total Cards
#   ____________________  ____________________bet_id: 83 --- bets_value: Over 1.5 --- bets_odd: 1.57
#   ____________________  ____________________bet_id: 83 --- bets_value: Under 1.5 --- bets_odd: 2.25
#   ________________________86 RCARD
#   ________________________99 To Score A Penalty
#   ____________________  ____________________bet_id: 99 --- bets_value: Home --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 99 --- bets_value: Away --- bets_odd: 4.33
#   ________________________100 To Miss A Penalty
#   ____________________  ____________________bet_id: 100 --- bets_value: Home --- bets_odd: 29.00
#   ____________________  ____________________bet_id: 100 --- bets_value: Away --- bets_odd: 15.00
#   ________________________102 Player to be booked
#   ____________________  ____________________bet_id: 102 --- bets_value: Lee Gregory --- bets_odd: 3.75
#   ____________________  ____________________bet_id: 102 --- bets_value: Barry Bannan --- bets_odd: 2.88
#   ____________________  ____________________bet_id: 102 --- bets_value: Marvin Johnson --- bets_odd: 6.00
#   ____________________  ____________________bet_id: 102 --- bets_value: Dennis Adeniran --- bets_odd: 4.75
#   ____________________  ____________________bet_id: 102 --- bets_value: Jaden Brown --- bets_odd: 4.75
#   ____________________  ____________________bet_id: 102 --- bets_value: Fisayo Dele-Bashiru --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 102 --- bets_value: Dominic Iorfa --- bets_odd: 4.75
#   ____________________  ____________________bet_id: 102 --- bets_value: Jack Hunt --- bets_odd: 4.75
#   ____________________  ____________________bet_id: 102 --- bets_value: Liam Palmer --- bets_odd: 6.00
#   ____________________  ____________________bet_id: 102 --- bets_value: Jamie Robson --- bets_odd: 3.60
#   ____________________  ____________________bet_id: 102 --- bets_value: Jordon Garrick --- bets_odd: 3.75
#   ____________________  ____________________bet_id: 102 --- bets_value: Akin Famewo --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 102 --- bets_value: Tyrese Omotoye --- bets_odd: 6.00
#   ____________________  ____________________bet_id: 102 --- bets_value: Baily Cargill --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 102 --- bets_value: Dominic Bernard --- bets_odd: 4.75
#   ____________________  ____________________bet_id: 102 --- bets_value: Udoka Godwin-Malife --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 102 --- bets_value: Corey O'Keeffe --- bets_odd: 2.30
#   ____________________  ____________________bet_id: 102 --- bets_value: Reece Brown --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 102 --- bets_value: Tyreeq Bakinson --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 102 --- bets_value: Aden Flint --- bets_odd: 3.10
#   ____________________  ____________________bet_id: 102 --- bets_value: Will Vaulks --- bets_odd: 3.25
#   ____________________  ____________________bet_id: 102 --- bets_value: Mallik Wilks --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 102 --- bets_value: Jahmari Clarke --- bets_odd: 3.60
#   ____________________  ____________________bet_id: 102 --- bets_value: Brandon Cooper --- bets_odd: 3.75
#   ____________________  ____________________bet_id: 102 --- bets_value: Sean O'Brien --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 102 --- bets_value: Reece James --- bets_odd: 6.00
#   ____________________  ____________________bet_id: 102 --- bets_value: Dylan McGeouch --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 102 --- bets_value: Michael Smith --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 102 --- bets_value: Kyle McAllister --- bets_odd: 4.33
#   ____________________  ____________________bet_id: 102 --- bets_value: Amadou Bakayoko --- bets_odd: 3.75
#   ____________________  ____________________bet_id: 102 --- bets_value: Josh Windass --- bets_odd: 3.75
#   ____________________  ____________________bet_id: 102 --- bets_value: George Byers --- bets_odd: 3.10
#   ____________________  ____________________bet_id: 102 --- bets_value: Harvey Bunker --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 102 --- bets_value: Charlie Savage --- bets_odd: 3.75
#   ____________________  ____________________bet_id: 102 --- bets_value: Myles Peart-Harris --- bets_odd: 3.60
#   ____________________  ____________________bet_id: 102 --- bets_value: Bryan Fiabema --- bets_odd: 6.50
#   ____________________  ____________________bet_id: 102 --- bets_value: Rio Shipston --- bets_odd: 3.25
#   ____________________  ____________________bet_id: 102 --- bets_value: David Stockdale --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 102 --- bets_value: Cameron Dawson --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 102 --- bets_value: Pierce Charles --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 102 --- bets_value: Ross Doohan --- bets_odd: 8.00
#   ____________________  ____________________bet_id: 102 --- bets_value: Lewis Thomas --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 102 --- bets_value: Luke Jackson --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 102 --- bets_value: Adam Alimi-Adetoro --- bets_odd: 3.25
#   ____________________  ____________________bet_id: 102 --- bets_value: Zachariah McKenzie --- bets_odd: 4.33
#   ________________________103 Player to be Sent Off
#   ____________________  ____________________bet_id: 103 --- bets_value: Lee Gregory --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Barry Bannan --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Marvin Johnson --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Dennis Adeniran --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Jaden Brown --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Fisayo Dele-Bashiru --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Dominic Iorfa --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Jack Hunt --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Liam Palmer --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Jamie Robson --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Jordon Garrick --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Akin Famewo --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Tyrese Omotoye --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Baily Cargill --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Dominic Bernard --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Udoka Godwin-Malife --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Corey O'Keeffe --- bets_odd: 26.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Reece Brown --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Tyreeq Bakinson --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Aden Flint --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Will Vaulks --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Mallik Wilks --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Jahmari Clarke --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Brandon Cooper --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Sean O'Brien --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Reece James --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Dylan McGeouch --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Michael Smith --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Kyle McAllister --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Amadou Bakayoko --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Josh Windass --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: George Byers --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Harvey Bunker --- bets_odd: 51.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Charlie Savage --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Myles Peart-Harris --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Bryan Fiabema --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Rio Shipston --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: David Stockdale --- bets_odd: 101.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Cameron Dawson --- bets_odd: 101.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Ross Doohan --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Lewis Thomas --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Luke Jackson --- bets_odd: 101.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Adam Alimi-Adetoro --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 103 --- bets_value: Zachariah McKenzie --- bets_odd: 41.00
#   ____________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
# # -------------------------------------------------- End at 2023-04-02 01:55:35

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------    
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "leagueapi_id : " + str(leagueapi_id))
    print(space + "season : " + str(season))
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir)   
    # --------------------------------------------------   
    ff_get_fixture_status_match_finished_by_league(leagueapi_id, season, tgl_awal, tgl_akhir, 'xpattern', space) 
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-02 01:55:35
#   __main()
#   ____leagueapi_id : 41
#   ____season : 2022
#   ____days : 7
#   ____days : 1
#   ____tgl_awal : 2023-03-26
#   ____tgl_akhir : 2023-04-01
#   ______ff_get_fixture_status_match_finished_by_league()
#   ________Total Row(s) : 3
#   ________1. 2023-03-29 // 41 // 8 // 2022 // 875805 // 05+075+1+H // 2g225g25gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 875805
#   __________> end_ah_pattern = 05+075+1+H
#   __________> end_ah_pattern_mirror = 1_075_05_H
#   __________> end_gou_pattern = 2g225g25gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________2. 2023-03-28 // 41 // 8 // 2022 // 875806 // 0#025+05+H // 225g25g275gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 875806
#   __________> end_ah_pattern = 0#025+05+H
#   __________> end_ah_pattern_mirror = 05_025_0#H
#   __________> end_gou_pattern = 2g225g25g275gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________3. 2023-03-26 // 41 // 8 // 2022 // 875950 // 1+125+15+175+H // 225g25g275g3gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 875950
#   __________> end_ah_pattern = 1+125+15+175+H
#   __________> end_ah_pattern_mirror = 175_15_125_1_H
#   __________> end_gou_pattern = 225g25g275g3gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
# # -------------------------------------------------- End at 2023-04-02 01:55:43

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------    
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "leagueapi_id : " + str(leagueapi_id))
    print(space + "season : " + str(season))
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir)   
    # --------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist_by_leagueapi_id(leagueapi_id, 
                                                                                      season, tgl_awal, tgl_akhir, space) 
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-02 01:55:43
#   __main()
#   ____leagueapi_id : 41
#   ____season : 2022
#   ____days : 7
#   ____days : 1
#   ____tgl_awal : 2023-03-26
#   ____tgl_akhir : 2023-04-01
#   ______ff_get_fixture_status_match_finished_for_daily_update_patternlist_by_leagueapi_id()
#   ______Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date = '41'  and season = '2022'  and date <= '2023-04-01'  and date >= '2023-03-26'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   ________Total Row(s) : 0
# # -------------------------------------------------- End at 2023-04-02 01:55:44
