# %%
# Import
from a_settings.messages import *  
from a_models.predefine import *  

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------   
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=1)
    preday1 = today + DD
    day1 = preday1.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    print(space + "> day1 : " +  str(preday1) ) 
    # --------------------------------------------------   
    pd_get_fixtures_next_match(day0, preday1, 'one', space) 
    # --------------------------------------------------  
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 21:10:58
#   __main()
#   ____get_date()
#   ______> day0 : 2023-03-25
#   ______> day1 : 2023-03-26 21:10:58.168221
#   ________pd_get_fixtures_next_match()
#   __________Total Row(s) : 33
#   ____________[1/33] 41 - 2022 -----#Fleetwood Town 1336 - Lincoln 1379 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:2.0
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.95
#   ____________good_to_go: 1
#
#   ____________[2/33] 41 - 2022 -----#Milton Keynes Dons 1348 - Morecambe 1375 - 2023-03-25 15:00:00
#   ____________good_to_go: 0
#
#   ____________[3/33] 41 - 2022 -----#Peterborough 1350 - Derby 69 - 2023-03-25 15:00:00
#   ____________good_to_go: 0
#
#   ____________[4/33] 41 - 2022 -----#Portsmouth 1355 - Port Vale 1351 - 2023-03-25 15:00:00
#   ____________good_to_go: 1
#
#   ____________[5/33] 41 - 2022 -----#Shrewsbury 1352 - Bristol Rovers 1334 - 2023-03-25 15:00:00
#   ____________good_to_go: 1
#
#   ____________[6/33] 42 - 2022 -----#Barrow 1819 - AFC Wimbledon 1333 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#   ____________good_to_go: 1
#
#   ____________[7/33] 42 - 2022 -----#Colchester 1361 - Tranmere 1381 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#   ____________good_to_go: 1
#
#   ____________[8/33] 42 - 2022 -----#Crawley Town 1362 - Rochdale 1339 - 2023-03-25 15:00:00
#   ____________good_to_go: 1
#
#   ____________[9/33] 42 - 2022 -----#Crewe 1363 - Bradford 1343 - 2023-03-25 15:00:00
#   ____________good_to_go: 0
#
#   ____________[10/33] 42 - 2022 -----#Doncaster 1354 - Northampton 1337 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:2.0
#   ______________pre_total_goals_both_teams_to_score_under_no_25:2.0
#   ____________good_to_go: 1
#
#   ____________[11/33] 42 - 2022 -----#Gillingham 1347 - Carlisle 1371 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#   ____________good_to_go: 1
#
#   ____________[12/33] 42 - 2022 -----#Grimsby 1365 - Walsall 1342 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.91
#   ____________good_to_go: 1
#
#   ____________[13/33] 42 - 2022 -----#Hartlepool 1366 - Leyton Orient 1373 - 2023-03-25 15:00:00
#   ______________pre_total_goals_both_teams_to_score_under_no_25:2.0
#   ____________good_to_go: 1
#
#   ____________[14/33] 42 - 2022 -----#Mansfield Town 1374 - Sutton Utd 1835 - 2023-03-25 15:00:00
#   ____________good_to_go: 1
#
#   ____________[15/33] 42 - 2022 -----#Stevenage 1368 - Salford City 1844 - 2023-03-25 15:00:00
#   ____________good_to_go: 0
#
#   ____________[16/33] 42 - 2022 -----#Swindon Town 1353 - Stockport County 4686 - 2023-03-25 15:00:00
#   ____________good_to_go: 1
#
#   ____________[17/33] 43 - 2022 -----#Notts County 1376 - Scunthorpe 1340 - 2023-03-25 15:00:00
#   ______________pre_first_half_winner_home:1.62
#   ______________pre_second_half_winner_home:1.44
#   ______________pre_to_win_either_half_home:1.13
#   ______________pre_double_chance_draw_away:4.0
#   ______________pre_clean_sheet__away_yes:11.0
#   ______________pre_to_win_either_half_away:4.5
#   ____________good_to_go: 1
