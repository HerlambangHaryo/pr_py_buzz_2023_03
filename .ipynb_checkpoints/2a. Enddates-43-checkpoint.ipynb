# %%
# Import
from a_settings.messages import *   

today = datetime.datetime.now()  
days0 = 4
days1 = 3
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 4 - 3 --> 2023-05-29 10:29:37.162289

# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    day0         = get_today_subs(days0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(days1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_check_enddates(day0, day1, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 10:29:38
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 4
#   ________today_raw : 2023-05-25 10:29:38.586028
#   ______get_today_subs()
#   ________subs date_diff : 3
#   ________today_raw : 2023-05-26 10:29:38.586028
#   ______fO_check_enddates()
#   ________Select  leagueapi_id as lg  , season as ss  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_homeapi_id) as home  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_awayapi_id) as away  , SUBSTR(fixture_status, 1, 15)  as fs  , end_response as er  , end_ah_pattern as ah  , end_gou_pattern as gou  from football_odds  where date >= '2023-05-25'  and date <= '2023-05-26'  and end_response is null  and deleted_at is null  and fixture_status like 'Match Finished'  order by leagueapi_id, date asc
#   ________Total Row(s) : 13
#
#      lg    ss     home     away              fs    er    ah   gou
# 0    11  2023  Danubio  Club Gu  Match Finished  None  None  None
# 1   222  2022  Gleisdo  LASK Ju  Match Finished  None  None  None
# 2   256  2023  Midwest  Lansing  Match Finished  None  None  None
# 3   256  2023  Patuxen  Lionsbr  Match Finished  None  None  None
# 4   256  2023  Arizona   Tucson  Match Finished  None  None  None
# 5   256  2023  Manhatt  FC Moto  Match Finished  None  None  None
# 6   386  2022  ASEC Mi  Stade d  Match Finished  None  None  None
# 7   521  2023  Indepen  São Pau  Match Finished  None  None  None
# 8   747  2022  Paderbo  Gievenb  Match Finished  None  None  None
# 9   887  2022  Asyut P  Shoban   Match Finished  None  None  None
# 10  887  2022  Alumini  Asmant   Match Finished  None  None  None
# 11  887  2022  Mallawi    Tamya  Match Finished  None  None  None
# 12  887  2022  El Madi  El Goun  Match Finished  None  None  None
#
# # -------------------------------------------------- End at 2023-05-29 10:29:40

# %%
from a_settings.messages import *  
from a_models.football_odds import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    today_day = today.strftime("%Y-%m-%d")   
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "today : " + str(today_day))
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    fO_get_group_league_status_match_finished(tgl_awal, tgl_akhir, today_day, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 10:29:40
#   __main()
#   ____get_date()
#   ______today : 2023-05-29
#   ______days : 4
#   ______days : 3
#   ______tgl_awal : 2023-05-25
#   ______tgl_akhir : 2023-05-26
#   ________fO_get_group_league_status_match_finished()
#   ________Select  DATE(date)  , leagueapi_id , (select bookmakersapi_id from football_leagues where leagueapi_id = football_odds.leagueapi_id)  , season , DATE(end_odd_updated_at)  , fixture_status   from football_odds  where  date <= '2023-05-26'  and date >= '2023-05-25'  and fixture_status like 'Match Finished'  and deleted_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 19
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-05-25 // 11 // 8 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 24
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 11
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 4
#
#   ____________________1. World,  CONMEBOL Sudamericana  #11 - 2023 / 1019439
#   ____________________good to Go 1
#
#   ____________________2. World,  CONMEBOL Sudamericana  #11 - 2023 / 1019440
#   ____________________good to Go 1
#
#   ____________________3. World,  CONMEBOL Sudamericana  #11 - 2023 / 1019441
#   ____________________good to Go 1
#
#   ____________________4. World,  CONMEBOL Sudamericana  #11 - 2023 / 1019443
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________2. 2023-05-25 // 72 // 8 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 23
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 72
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 3
#
#   ____________________1. Brazil,  Serie B  #72 - 2023 / 1006517
#   ____________________good to Go 1
#
#   ____________________2. Brazil,  Serie B  #72 - 2023 / 1006519
#   ____________________good to Go 1
#
#   ____________________3. Brazil,  Serie B  #72 - 2023 / 1006523
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________3. 2023-05-25 // 95 // 8 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 22
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 95
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Portugal,  Segunda Liga  #95 - 2022 / 899210
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________4. 2023-05-25 // 113 // 8 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 21
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 113
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Sweden,  Allsvenskan  #113 - 2023 / 1001949
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________5. 2023-05-25 // 136 // 8 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 20
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 136
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Italy,  Serie B  #136 - 2022 / 1028184
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________6. 2023-05-25 // 140 // 8 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 19
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 140
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. Spain,  La Liga  #140 - 2022 / 878295
#   ____________________good to Go 1
#
#   ____________________2. Spain,  La Liga  #140 - 2022 / 878296
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________7. 2023-05-25 // 172 // 8 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 18
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 172
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Bulgaria,  First League  #172 - 2022 / 1026745
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________8. 2023-05-25 // 222 // 11 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 17
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 222
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________________> FUCKIN ZERO !
#   ____________9. 2023-05-25 // 240 // 8 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 16
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 240
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. Colombia,  Primera B  #240 - 2023 / 1027234
#   ____________________good to Go 1
#
#   ____________________2. Colombia,  Primera B  #240 - 2023 / 1027236
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________10. 2023-05-25 // 245 // 8 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 15
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 245
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Finland,  Ykkönen  #245 - 2023 / 998984
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________11. 2023-05-25 // 256 // 11 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 14
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 256
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. USA,  USL League Two  #256 - 2023 / 1024090
#   ____________________good to Go 1
#
#   ____________________2. USA,  USL League Two  #256 - 2023 / 1024092
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________12. 2023-05-25 // 257 // 8 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 13
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 257
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. USA,  US Open Cup  #257 - 2023 / 1026894
#   ____________________good to Go 1
#
#   ____________________2. USA,  US Open Cup  #257 - 2023 / 1026895
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________13. 2023-05-25 // 386 // 11 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 12
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 386
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________________> FUCKIN ZERO !
#   ____________14. 2023-05-25 // 489 // 11 // 2023 // 2023-05-26 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 11
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 489
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. USA,  USL League One  #489 - 2023 / 1008782
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________15. 2023-05-25 // 490 // 8 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 10
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 490
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 4
#
#   ____________________1. World,  World Cup - U20  #490 - 2023 / 1023432
#   ____________________good to Go 1
#
#   ____________________2. World,  World Cup - U20  #490 - 2023 / 1023433
#   ____________________good to Go 1
#
#   ____________________3. World,  World Cup - U20  #490 - 2023 / 1023434
#   ____________________good to Go 1
#
#   ____________________4. World,  World Cup - U20  #490 - 2023 / 1023435
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________16. 2023-05-25 // 521 // 11 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 9
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 521
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________________> FUCKIN ZERO !
#   ____________17. 2023-05-25 // 595 // 8 // 2023 // None // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 8
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 595
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________________> FUCKIN ZERO !
#   ____________18. 2023-05-25 // 747 // 11 // 2022 // 2023-05-05 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 7
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 747
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________________> FUCKIN ZERO !
#   ____________19. 2023-05-25 // 887 // 11 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 6
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-25
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 887
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 3
#
#   ____________________1. Egypt,  Second League - Group A  #887 - 2022 / 964829
#   ____________________good to Go 1
#
#   ____________________2. Egypt,  Second League - Group A  #887 - 2022 / 964832
#   ____________________good to Go 1
#
#   ____________________3. Egypt,  Second League - Group A  #887 - 2022 / 964830
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
# # -------------------------------------------------- End at 2023-05-29 10:32:31

# %%
from a_settings.messages import *  
from a_models.date import *   
from a_models.football_odds import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    space += "__" 
    # --------------------------------------------------   
    tgl_awal         = get_today_subs(days0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    tgl_akhir        = get_today_subs(days1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    today_day        = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_get_fixture_status_match_finished(tgl_awal, tgl_akhir, today_day, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 10:32:31
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 4
#   ________today_raw : 2023-05-25 10:32:31.868728
#   ______get_today_subs()
#   ________subs date_diff : 3
#   ________today_raw : 2023-05-26 10:32:31.872619
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-05-29 10:32:31.872619
#   ______fO_get_fixture_status_match_finished()
#   ______Select  DATE(date)  , leagueapi_id , (select bookmakersapi_id from football_leagues where leagueapi_id = football_odds.leagueapi_id)  , season , DATE(end_odd_updated_at)  , fixture_status   , fixtureapi_id   from football_odds  where  date <= '2023-05-26'  and date >= '2023-05-25'  and end_response is null  and deleted_at is null  and fixture_status = 'Match Finished'  order by date
#   ________Total Row(s) : 13
#   __________fO_get_fixture_status_match_finished_DETAILED()
#   __________Total Row(s) : 13
#
#           Date              fs       fx  bm    er
# 0   2023-05-25  Match Finished   964828  11  None
# 1   2023-05-25  Match Finished  1024091  11  None
# 2   2023-05-25  Match Finished  1024089  11  None
# 3   2023-05-25  Match Finished  1023911  11  None
# 4   2023-05-25  Match Finished  1025278  11  None
# 5   2023-05-25  Match Finished  1016496  11  None
# 6   2023-05-25  Match Finished   906898  11  None
# 7   2023-05-25  Match Finished   896495  11  None
# 8   2023-05-25  Match Finished  1019442   8  None
# 9   2023-05-25  Match Finished   964834  11  None
# 10  2023-05-25  Match Finished   964833  11  None
# 11  2023-05-25  Match Finished   964831  11  None
# 12  2023-05-25  Match Finished  1024519  11  None
#
#   ________Are you sure want to continue? :  yes
#   __________1. 2023-05-25 // 1023911 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 5
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 1023911
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________2. 2023-05-25 // 1024089 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 4
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 1024089
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________3. 2023-05-25 // 1024519 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 3
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 1024519
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________4. 2023-05-25 // 906898 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 2
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 906898
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________5. 2023-05-25 // 964834 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 1
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 964834
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________6. 2023-05-25 // 964833 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API hariyant2410@gmail.com counter is 99
#   ________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 964833
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________7. 2023-05-25 // 964831 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API hariyant2410@gmail.com counter is 98
#   ________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 964831
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________8. 2023-05-25 // 964828 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API hariyant2410@gmail.com counter is 97
#   ________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 964828
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________9. 2023-05-25 // 1025278 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API hariyant2410@gmail.com counter is 96
#   ________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 1025278
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________10. 2023-05-25 // 896495 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API hariyant2410@gmail.com counter is 95
#   ________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 896495
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________11. 2023-05-25 // 1019442 // 8 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API hariyant2410@gmail.com counter is 94
#   ________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 1019442
#   ________________bookmaker : 8
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________12. 2023-05-25 // 1016496 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API hariyant2410@gmail.com counter is 93
#   ________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 1016496
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________13. 2023-05-25 // 1024091 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API hariyant2410@gmail.com counter is 92
#   ________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 1024091
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
# # -------------------------------------------------- End at 2023-05-29 10:37:04

# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    day0         = get_today_subs(days0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(days1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_check_enddates(day0, day1, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 10:37:04
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 4
#   ________today_raw : 2023-05-25 10:37:04.264695
#   ______get_today_subs()
#   ________subs date_diff : 3
#   ________today_raw : 2023-05-26 10:37:04.267703
#   ______fO_check_enddates()
#   ________Select  leagueapi_id as lg  , season as ss  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_homeapi_id) as home  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_awayapi_id) as away  , SUBSTR(fixture_status, 1, 15)  as fs  , end_response as er  , end_ah_pattern as ah  , end_gou_pattern as gou  from football_odds  where date >= '2023-05-25'  and date <= '2023-05-26'  and end_response is null  and deleted_at is null  and fixture_status like 'Match Finished'  order by leagueapi_id, date asc
#   ________Total Row(s) : 13
#
#      lg    ss     home     away              fs    er    ah   gou
# 0    11  2023  Danubio  Club Gu  Match Finished  None  None  None
# 1   222  2022  Gleisdo  LASK Ju  Match Finished  None  None  None
# 2   256  2023  Midwest  Lansing  Match Finished  None  None  None
# 3   256  2023  Patuxen  Lionsbr  Match Finished  None  None  None
# 4   256  2023  Arizona   Tucson  Match Finished  None  None  None
# 5   256  2023  Manhatt  FC Moto  Match Finished  None  None  None
# 6   386  2022  ASEC Mi  Stade d  Match Finished  None  None  None
# 7   521  2023  Indepen  São Pau  Match Finished  None  None  None
# 8   747  2022  Paderbo  Gievenb  Match Finished  None  None  None
# 9   887  2022  Asyut P  Shoban   Match Finished  None  None  None
# 10  887  2022  Alumini  Asmant   Match Finished  None  None  None
# 11  887  2022  Mallawi    Tamya  Match Finished  None  None  None
# 12  887  2022  El Madi  El Goun  Match Finished  None  None  None
#
# # -------------------------------------------------- End at 2023-05-29 10:37:06
