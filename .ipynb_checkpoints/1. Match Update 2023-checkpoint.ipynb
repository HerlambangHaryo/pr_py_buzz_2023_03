# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.football_odds import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    todayx       = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    fO_get_league_group_fixture_status_not_in_match_finished(day1, day2, todayx, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-27 10:18:04
#   __main()
#   ____get_today_subs()
#   ______subs date_diff : 7
#   ______today_raw : 2023-07-20 10:18:04.047157
#   ____get_today_subs()
#   ______subs date_diff : 1
#   ______today_raw : 2023-07-26 10:18:04.051177
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-07-27 10:18:04.051177
#   ____fO_get_league_group_fixture_status_not_in_match_finished()
#   ____ Select  leagueapi_id  , season   from football_odds  where date <= Date('2023-07-26')  and date >= Date('2023-07-20')  and deleted_at is null  and fixture_status not in ('Match Finished', 'Match Finished Ended' )  group by leagueapi_id, season  order by date, leagueapi_id asc
#   ____Total Row(s) : 14
#   ____[1/14]  #269 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API arya6792@gmail.com counter is 13
#   __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 269
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 7
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ___________________________________________________
#   ____[2/14]  #295 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API arya6792@gmail.com counter is 9
#   __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 295
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 8
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ___________________________________________________
#   ____[3/14]  #667 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API arya6792@gmail.com counter is 5
#   __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 667
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 700
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Time to be defined
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Time to be defined
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Time to be defined
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Time to be defined
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#   ______________fixture_status: Match Cancelled
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Not Started
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Cancelled
# ...
#   ____[7/14]  #657 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 47
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 657
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 5
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Walkover
#   ______________football_odds UPDATED
#
#   ___________________________________________________
#   ____[8/14]  #2 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 46
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 2
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 12
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds: 10. /Match Finished/ 1074594 / Aris vs Bate Borisov /2023-07-26 17:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 10. /Match Finished/ 1074594 / Aris vs Bate Borisov /2023-07-26 17:00:00+00:00/  INSERTED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ___________________________________________________
#   ____[9/14]  #165 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 45
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 165
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 8
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ___________________________________________________
#   ____[10/14]  #130 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 44
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 130
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 8
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ___________________________________________________
#   ____[11/14]  #133 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 43
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 133
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 5
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ___________________________________________________
#   ____[12/14]  #185 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 42
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 185
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 32
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ___________________________________________________
#   ____[13/14]  #740 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 41
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 740
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 7
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ___________________________________________________
#   ____[14/14]  #772 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API herlambangharyo@live.com counter is 40
#   __________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 772
#   __________season : 2023
#   __________day1 : 2023-07-20
#   __________day2 : 2023-07-26
#   ____________Total API Response(s) : 23
#   ______________fixture_status: Match Finished
#   ______________football_odds: 1. /Match Finished/ 1013766 / Austin vs Mazatlán /2023-07-22 00:30:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 1. /Match Finished/ 1013766 / Austin vs Mazatlán /2023-07-22 00:30:00+00:00/  INSERTED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds: 2. /Match Finished/ 1013767 / Orlando City SC vs Houston Dynamo /2023-07-22 00:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 2. /Match Finished/ 1013767 / Orlando City SC vs Houston Dynamo /2023-07-22 00:00:00+00:00/  INSERTED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds: 3. /Match Finished/ 1013768 / Cruz Azul vs Inter Miami /2023-07-22 00:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 3. /Match Finished/ 1013768 / Cruz Azul vs Inter Miami /2023-07-22 00:00:00+00:00/  INSERTED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds: 4. /Match Finished/ 1013769 / FC Dallas vs Charlotte /2023-07-22 01:00:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 4. /Match Finished/ 1013769 / FC Dallas vs Charlotte /2023-07-22 01:00:00+00:00/  INSERTED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds: 5. /Match Finished/ 1013770 / Leon vs Vancouver Whitecaps /2023-07-22 02:30:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 5. /Match Finished/ 1013770 / Leon vs Vancouver Whitecaps /2023-07-22 02:30:00+00:00/  INSERTED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds: 7. /Match Finished/ 1013772 / Montreal Impact vs U.N.A.M. - Pumas /2023-07-22 23:30:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 7. /Match Finished/ 1013772 / Montreal Impact vs U.N.A.M. - Pumas /2023-07-22 23:30:00+00:00/  INSERTED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds: 8. /Match Finished/ 1013773 / New York Red Bulls vs New England Revolution /2023-07-22 23:30:00+00:00/  INSERTED
#   ______________football_odds INSERTED
#   ______________football_statistics: 8. /Match Finished/ 1013773 / New York Red Bulls vs New England Revolution /2023-07-22 23:30:00+00:00/  INSERTED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   __________________football_venues INSERTED
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ______________fixture_status: Match Finished
#   ______________football_odds UPDATED
#
#   ___________________________________________________
# # -------------------------------------------------- End at 2023-07-27 14:08:37
