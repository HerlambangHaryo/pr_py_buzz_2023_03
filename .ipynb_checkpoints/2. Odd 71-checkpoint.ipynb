# %%
from a_settings.messages import *  
from a_models.date import *   
from a_models.football_odds import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------    
    day0         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    today_day    = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_get_group_league_status_match_finished(day0, day1, today_day, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-22 15:51:36
#   __main()
#   ____get_today_subs()
#   ______subs date_diff : 7
#   ______today_raw : 2023-07-15 15:51:36.955842
#   ____get_today_subs()
#   ______subs date_diff : 1
#   ______today_raw : 2023-07-21 15:51:36.955842
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-07-22 15:51:36.955842
#   ____fO_get_group_league_status_match_finished()
#   ____Select  DATE(date)  , leagueapi_id , (select bookmakersapi_id from football_leagues where leagueapi_id = football_odds.leagueapi_id)  , season , DATE(end_odd_updated_at)  , fixture_status   , count(*) as count_rows   from football_odds  where  date <= '2023-07-21'  and date >= '2023-07-15'  and fixture_status like 'Match Finished'  and deleted_at is null  group by DATE(date), leagueapi_id, season  order by date
#   ______Total Row(s) : 95
#   ______Are you sure want to continue? :  yes
#   ________1. 2023-07-15 // 299 // 11 // 2023 // 2023-07-21 // Match Finished == 3
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 14
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 299
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 2
#
#   ________________1. Venezuela,  Primera División  #299 - 2023 / 998175
#   ________________good to Go 1
#
#   ________________2. Venezuela,  Primera División  #299 - 2023 / 998176
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________2. 2023-07-15 // 239 // 8 // 2023 // 2023-07-21 // Match Finished == 3
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 13
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 239
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 2
#
#   ________________1. Colombia,  Primera A  #239 - 2023 / 990311
#   ________________good to Go 1
#
#   ________________2. Colombia,  Primera A  #239 - 2023 / 990314
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________3. 2023-07-15 // 255 // 11 // 2023 // 2023-07-17 // Match Finished == 5
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 12
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 255
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 4
#
#   ________________1. USA,  USL Championship  #255 - 2023 / 1008556
#   ________________good to Go 1
#
#   ________________2. USA,  USL Championship  #255 - 2023 / 1008557
#   ________________good to Go 1
#
#   ________________3. USA,  USL Championship  #255 - 2023 / 1008558
#   ________________good to Go 1
#
#   ________________4. USA,  USL Championship  #255 - 2023 / 1008559
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________4. 2023-07-15 // 909 // 11 // 2023 // 2023-07-21 // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 11
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 909
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. USA,  MLS Next Pro  #909 - 2023 / 1015441
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________5. 2023-07-15 // 295 // 8 // 2023 // 2023-07-21 // Match Finished == 4
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 10
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 295
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 4
#
#   ________________1. South-Korea,  K3 League  #295 - 2023 / 1003903
#   ________________good to Go 1
#
#   ________________2. South-Korea,  K3 League  #295 - 2023 / 1003904
#   ________________good to Go 1
#
#   ________________3. South-Korea,  K3 League  #295 - 2023 / 1003907
#   ________________good to Go 1
#
#   ________________4. South-Korea,  K3 League  #295 - 2023 / 1003905
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________6. 2023-07-15 // 667 // 8 // 2023 // 2023-07-21 // Match Finished == 297
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 9
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 667
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. World,  Friendlies Clubs  #667 - 2023 / 1031707
#   ________________good to Go 1
#
#   ________________2. World,  Friendlies Clubs  #667 - 2023 / 1036299
#   ________________good to Go 1
#
#   ________________3. World,  Friendlies Clubs  #667 - 2023 / 1040988
#   ________________good to Go 1
#
#   ________________4. World,  Friendlies Clubs  #667 - 2023 / 1051808
#   ________________good to Go 1
#
#   ________________5. World,  Friendlies Clubs  #667 - 2023 / 1058413
#   ________________good to Go 1
#
#   ________________6. World,  Friendlies Clubs  #667 - 2023 / 1058429
#   ________________good to Go 1
#
#   ________________7. World,  Friendlies Clubs  #667 - 2023 / 1064410
#   ________________good to Go 1
#
#   ________________8. World,  Friendlies Clubs  #667 - 2023 / 1064411
#   ________________good to Go 1
#
#   ________________9. World,  Friendlies Clubs  #667 - 2023 / 1064415
#   ________________good to Go 1
#
#   ________________10. World,  Friendlies Clubs  #667 - 2023 / 1064426
#   ________________good to Go 1
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 8
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 667
#   ______________page : 2
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. World,  Friendlies Clubs  #667 - 2023 / 1030490
#   ________________good to Go 1
#
#   ________________2. World,  Friendlies Clubs  #667 - 2023 / 1030737
#   ________________good to Go 1
#
#   ________________3. World,  Friendlies Clubs  #667 - 2023 / 1036311
#   ________________good to Go 1
#
#   ________________4. World,  Friendlies Clubs  #667 - 2023 / 1036805
#   ________________good to Go 1
#
#   ________________5. World,  Friendlies Clubs  #667 - 2023 / 1039050
#   ________________good to Go 1
#
#   ________________6. World,  Friendlies Clubs  #667 - 2023 / 1039051
#   ________________good to Go 1
#
#   ________________7. World,  Friendlies Clubs  #667 - 2023 / 1047215
#   ________________good to Go 1
#
#   ________________8. World,  Friendlies Clubs  #667 - 2023 / 1058354
#   ________________good to Go 1
#
#   ________________9. World,  Friendlies Clubs  #667 - 2023 / 1058419
#   ________________good to Go 1
#
#   ________________10. World,  Friendlies Clubs  #667 - 2023 / 1061387
#   ________________good to Go 1
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 7
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 667
#   ______________page : 3
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. World,  Friendlies Clubs  #667 - 2023 / 1030492
#   ________________good to Go 1
#
#   ________________2. World,  Friendlies Clubs  #667 - 2023 / 1031089
#   ________________good to Go 1
#
#   ________________3. World,  Friendlies Clubs  #667 - 2023 / 1031716
#   ________________good to Go 1
#
#   ________________4. World,  Friendlies Clubs  #667 - 2023 / 1039049
#   ________________good to Go 1
#
#   ________________5. World,  Friendlies Clubs  #667 - 2023 / 1040989
#   ________________good to Go 1
#
#   ________________6. World,  Friendlies Clubs  #667 - 2023 / 1040990
#   ________________good to Go 1
#
#   ________________7. World,  Friendlies Clubs  #667 - 2023 / 1047220
#   ________________good to Go 1
#
#   ________________8. World,  Friendlies Clubs  #667 - 2023 / 1058416
#   ________________good to Go 1
#
#   ________________9. World,  Friendlies Clubs  #667 - 2023 / 1061376
#   ________________good to Go 1
#
#   ________________10. World,  Friendlies Clubs  #667 - 2023 / 1064412
#   ________________good to Go 1
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 6
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 667
#   ______________page : 4
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. World,  Friendlies Clubs  #667 - 2023 / 1030497
#   ________________good to Go 1
#
#   ________________2. World,  Friendlies Clubs  #667 - 2023 / 1030501
#   ________________good to Go 1
#
#   ________________3. World,  Friendlies Clubs  #667 - 2023 / 1031721
#   ________________good to Go 1
#
#   ________________4. World,  Friendlies Clubs  #667 - 2023 / 1036312
#   ________________good to Go 1
#
#   ________________5. World,  Friendlies Clubs  #667 - 2023 / 1036314
#   ________________good to Go 1
#
#   ________________6. World,  Friendlies Clubs  #667 - 2023 / 1036460
#   ________________good to Go 1
#
#   ________________7. World,  Friendlies Clubs  #667 - 2023 / 1037390
#   ________________good to Go 1
#
#   ________________8. World,  Friendlies Clubs  #667 - 2023 / 1047198
#   ________________good to Go 1
#
#   ________________9. World,  Friendlies Clubs  #667 - 2023 / 1047221
#   ________________good to Go 1
#
#   ________________10. World,  Friendlies Clubs  #667 - 2023 / 1061234
#   ________________good to Go 1
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 5
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 667
#   ______________page : 5
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. World,  Friendlies Clubs  #667 - 2023 / 1031718
#   ________________good to Go 1
#
#   ________________2. World,  Friendlies Clubs  #667 - 2023 / 1036309
#   ________________good to Go 1
#
#   ________________3. World,  Friendlies Clubs  #667 - 2023 / 1036315
#   ________________good to Go 1
#
#   ________________4. World,  Friendlies Clubs  #667 - 2023 / 1036317
#   ________________good to Go 1
#
#   ________________5. World,  Friendlies Clubs  #667 - 2023 / 1036319
#   ________________good to Go 1
#
#   ________________6. World,  Friendlies Clubs  #667 - 2023 / 1042514
#   ________________good to Go 1
#
#   ________________7. World,  Friendlies Clubs  #667 - 2023 / 1042622
#   ________________good to Go 1
#
#   ________________8. World,  Friendlies Clubs  #667 - 2023 / 1058355
#   ________________good to Go 1
#
#   ________________9. World,  Friendlies Clubs  #667 - 2023 / 1061235
#   ________________good to Go 1
#
#   ________________10. World,  Friendlies Clubs  #667 - 2023 / 1064419
#   ________________good to Go 1
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API digitalmedia.arion@gmail.com counter is 4
#   ______________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 667
#   ______________page : 6
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. World,  Friendlies Clubs  #667 - 2023 / 1030491
#   ________________good to Go 1
#
#   ________________2. World,  Friendlies Clubs  #667 - 2023 / 1030495
#   ________________good to Go 1
#
#   ________________3. World,  Friendlies Clubs  #667 - 2023 / 1034612
#   ________________good to Go 1
#
#   ________________4. World,  Friendlies Clubs  #667 - 2023 / 1036316
#   ________________good to Go 1
#
#   ________________5. World,  Friendlies Clubs  #667 - 2023 / 1036458
#   ________________good to Go 1
#
#   ________________6. World,  Friendlies Clubs  #667 - 2023 / 1036815
#   ________________good to Go 1
#
#   ________________7. World,  Friendlies Clubs  #667 - 2023 / 1036820
#   ________________good to Go 1
#
#   ________________8. World,  Friendlies Clubs  #667 - 2023 / 
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________14. 2023-07-15 // 166 // 11 // 2023 // 2023-07-21 // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 87
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 166
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 4
#
#   ________________1. Iceland,  2. Deild  #166 - 2023 / 985313
#   ________________good to Go 1
#
#   ________________2. Iceland,  2. Deild  #166 - 2023 / 985314
#   ________________good to Go 1
#
#   ________________3. Iceland,  2. Deild  #166 - 2023 / 985315
#   ________________good to Go 1
#
#   ________________4. Iceland,  2. Deild  #166 - 2023 / 985316
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________15. 2023-07-15 // 906 // 11 // 2023 // 2023-07-20 // Match Finished == 5
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 86
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 906
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 5
#
#   ________________1. Argentina,  Reserve League  #906 - 2023 / 997069
#   ________________good to Go 1
#
#   ________________2. Argentina,  Reserve League  #906 - 2023 / 997070
#   ________________good to Go 1
#
#   ________________3. Argentina,  Reserve League  #906 - 2023 / 997071
#   ________________good to Go 1
#
#   ________________4. Argentina,  Reserve League  #906 - 2023 / 997075
#   ________________good to Go 1
#
#   ________________5. Argentina,  Reserve League  #906 - 2023 / 997077
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________16. 2023-07-15 // 173 // 11 // 2023 // 2023-07-20 // Match Finished == 6
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 85
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 173
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 6
#
#   ________________1. Bulgaria,  Second League  #173 - 2023 / 1039110
#   ________________good to Go 1
#
#   ________________2. Bulgaria,  Second League  #173 - 2023 / 1039111
#   ________________good to Go 1
#
#   ________________3. Bulgaria,  Second League  #173 - 2023 / 1039113
#   ________________good to Go 1
#
#   ________________4. Bulgaria,  Second League  #173 - 2023 / 1039115
#   ________________good to Go 1
#
#   ________________5. Bulgaria,  Second League  #173 - 2023 / 1039116
#   ________________good to Go 1
#
#   ________________6. Bulgaria,  Second League  #173 - 2023 / 1039117
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________17. 2023-07-15 // 233 // 8 // 2022 // 2023-07-17 // Match Finished == 3
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 84
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2022
#   ______________league : 233
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 3
#
#   ________________1. Egypt,  Premier League  #233 - 2022 / 1047074
#   ________________good to Go 1
#
#   ________________2. Egypt,  Premier League  #233 - 2022 / 1047076
#   ________________good to Go 1
#
#   ________________3. Egypt,  Premier League  #233 - 2022 / 1047077
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________18. 2023-07-15 // 103 // 8 // 2023 // 2023-07-17 // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 83
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 103
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. Norway,  Eliteserien  #103 - 2023 / 1001671
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________19. 2023-07-15 // 521 // 11 // 2023 // 2023-07-21 // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 82
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 521
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 0
#   ________________> FUCKIN ZERO !
#   ________20. 2023-07-15 // 256 // 11 // 2023 // 2023-07-21 // Match Finished == 17
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 81
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 256
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 8
#
#   ________________1. USA,  USL League Two  #256 - 2023 / 1024388
#   ________________good to Go 1
#
#   ________________2. USA,  USL League Two  #256 - 2023 / 1024496
#   ________________good to Go 1
#
#   ________________3. USA,  USL League Two  #256 - 2023 / 1024044
#   ________________good to Go 1
#
#   ________________4. USA,  USL League Two  #256 - 2023 / 1024308
#   ________________good to Go 1
#
#   ________________5. USA,  USL League Two  #256 - 2023 / 1024309
#   ________________good to Go 1
#
#   ________________6. USA,  USL League Two  #256 - 2023 / 1024497
#   ________________good to Go 1
#
#   ________________7. USA,  USL League Two  #256 - 2023 / 1024043
#   ________________good to Go 1
#
#   ________________8. USA,  USL League Two  #256 - 2023 / 1024045
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________21. 2023-07-15 // 523 // 11 // 2023 // 2023-07-20 // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 80
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 523
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. USA,  NISA  #523 - 2023 / 1016119
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________22. 2023-07-15 // 673 // 8 // 2023 // 2023-07-21 // Match Finished == 3
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 79
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-15
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 673
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 0
#   ________________> FUCKIN ZERO !
#   ________23. 2023-07-16 // 256 // 11 // 2023 // 2023-07-21 // Match Finished == 14
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 78
# ...
#   ________________good to Go 1
#
#   ________________4. World,  UEFA Europa Conference League  #848 - 2023 / 1036994
#   ________________good to Go 1
#
#   ________________5. World,  UEFA Europa Conference League  #848 - 2023 / 1036988
#   ________________good to Go 1
#
#   ________________6. World,  UEFA Europa Conference League  #848 - 2023 / 1036984
#   ________________good to Go 1
#
#   ________________7. World,  UEFA Europa Conference League  #848 - 2023 / 1036992
#   ________________good to Go 1
#
#   ________________8. World,  UEFA Europa Conference League  #848 - 2023 / 1036978
#   ________________good to Go 1
#
#   ________________9. World,  UEFA Europa Conference League  #848 - 2023 / 1036980
#   ________________good to Go 1
#
#   ________________10. World,  UEFA Europa Conference League  #848 - 2023 / 1036982
#   ________________good to Go 1
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 98
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-20
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 848
#   ______________page : 4
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 0
#   ________________> FUCKIN ZERO !
#   ________________> FUCKIN END !
#   ________________> FUCKIN END !
#   ________________> FUCKIN END !
#   ________85. 2023-07-20 // 173 // 11 // 2023 // None // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 97
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-20
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 173
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. Bulgaria,  Second League  #173 - 2023 / 1039125
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________86. 2023-07-20 // 385 // 8 // 2023 // None // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 96
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-20
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 385
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. Israel,  Toto Cup Ligat Al  #385 - 2023 / 1037331
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________87. 2023-07-20 // 220 // 8 // 2023 // None // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 95
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-20
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 220
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. Austria,  Cup  #220 - 2023 / 1042872
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________88. 2023-07-20 // 740 // 11 // 2023 // None // Match Finished == 3
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 94
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-20
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 740
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 3
#
#   ________________1. Brazil,  CBF Brasileiro U20  #740 - 2023 / 1025337
#   ________________good to Go 1
#
#   ________________2. Brazil,  CBF Brasileiro U20  #740 - 2023 / 1025339
#   ________________good to Go 1
#
#   ________________3. Brazil,  CBF Brasileiro U20  #740 - 2023 / 1025335
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________89. 2023-07-20 // 165 // 11 // 2023 // None // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 93
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-20
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 165
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. Iceland,  1. Deild  #165 - 2023 / 985449
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________90. 2023-07-20 // 240 // 8 // 2023 // None // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 92
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-20
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 240
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. Colombia,  Primera B  #240 - 2023 / 1028005
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________91. 2023-07-20 // 130 // 8 // 2023 // None // Match Finished == 4
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 91
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-20
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 130
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 4
#
#   ________________1. Argentina,  Copa Argentina  #130 - 2023 / 1036646
#   ________________good to Go 1
#
#   ________________2. Argentina,  Copa Argentina  #130 - 2023 / 1036655
#   ________________good to Go 1
#
#   ________________3. Argentina,  Copa Argentina  #130 - 2023 / 1043109
#   ________________good to Go 1
#
#   ________________4. Argentina,  Copa Argentina  #130 - 2023 / 1036645
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________92. 2023-07-21 // 11 // 8 // 2023 // None // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 90
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-21
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 11
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 2
#
#   ________________1. World,  CONMEBOL Sudamericana  #11 - 2023 / 1046430
#   ________________good to Go 1
#
#   ________________2. World,  CONMEBOL Sudamericana  #11 - 2023 / 1046428
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________93. 2023-07-21 // 667 // 8 // 2023 // None // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 89
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-21
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 667
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. World,  Friendlies Clubs  #667 - 2023 / 1030745
#   ________________good to Go 1
#
#   ________________2. World,  Friendlies Clubs  #667 - 2023 / 1030746
#   ________________good to Go 1
#
#   ________________3. World,  Friendlies Clubs  #667 - 2023 / 1031749
#   ________________good to Go 1
#
#   ________________4. World,  Friendlies Clubs  #667 - 2023 / 1031751
#   ________________good to Go 1
#
#   ________________5. World,  Friendlies Clubs  #667 - 2023 / 1036343
#   ________________good to Go 1
#
#   ________________6. World,  Friendlies Clubs  #667 - 2023 / 1036345
#   ________________good to Go 1
#
#   ________________7. World,  Friendlies Clubs  #667 - 2023 / 1036480
#   ________________good to Go 1
#
#   ________________8. World,  Friendlies Clubs  #667 - 2023 / 1036839
#   ________________good to Go 1
#
#   ________________9. World,  Friendlies Clubs  #667 - 2023 / 1036842
#   ________________good to Go 1
#
#   ________________10. World,  Friendlies Clubs  #667 - 2023 / 1040930
#   ________________good to Go 1
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 88
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-21
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 667
#   ______________page : 2
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. World,  Friendlies Clubs  #667 - 2023 / 1041010
#   ________________good to Go 1
#
#   ________________2. World,  Friendlies Clubs  #667 - 2023 / 1042526
#   ________________good to Go 1
#
#   ________________3. World,  Friendlies Clubs  #667 - 2023 / 1042527
#   ________________good to Go 1
#
#   ________________4. World,  Friendlies Clubs  #667 - 2023 / 1043299
#   ________________good to Go 1
#
#   ________________5. World,  Friendlies Clubs  #667 - 2023 / 1047245
#   ________________good to Go 1
#
#   ________________6. World,  Friendlies Clubs  #667 - 2023 / 1047246
#   ________________good to Go 1
#
#   ________________7. World,  Friendlies Clubs  #667 - 2023 / 1054062
#   ________________good to Go 1
#
#   ________________8. World,  Friendlies Clubs  #667 - 2023 / 1054073
#   ________________good to Go 1
#
#   ________________9. World,  Friendlies Clubs  #667 - 2023 / 1058363
#   ________________good to Go 1
#
#   ________________10. World,  Friendlies Clubs  #667 - 2023 / 1072490
#   ________________good to Go 1
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 87
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-21
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 667
#   ______________page : 3
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 3
#
#   ________________1. World,  Friendlies Clubs  #667 - 2023 / 1072610
#   ________________good to Go 1
#
#   ________________2. World,  Friendlies Clubs  #667 - 2023 / 1072618
#   ________________good to Go 1
#
#   ________________3. World,  Friendlies Clubs  #667 - 2023 / 1072624
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________________> FUCKIN END !
#   ________________> FUCKIN END !
#   ________94. 2023-07-21 // 240 // 8 // 2023 // None // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 86
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-21
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 240
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. Colombia,  Primera B  #240 - 2023 / 1028006
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
#   ________95. 2023-07-21 // 243 // 11 // 2023 // 2023-05-05 // Match Finished == 1
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api1@ariondigitalmedia.com counter is 85
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-21
#   ______________bookmaker : 11
#   ______________season : 2023
#   ______________league : 243
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. Ecuador,  Liga Pro Serie B  #243 - 2023 / 1011876
#   ________________good to Go 1
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
#   ________________  > FUCKIN END !
# # -------------------------------------------------- End at 2023-07-22 19:31:46

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.date import * 
from a_models.football_odds import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    day0         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(1, space).strftime("%Y-%m-%d")   
    # --------------------------------------------------    
    fO_get_group_league_status_match_finished_DETAILED(day0, day1, "all_end_xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-22 19:31:46
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 7
#   ________today_raw : 2023-07-15 19:31:46.573651
#   ______get_today_subs()
#   ________subs date_diff : 1
#   ________today_raw : 2023-07-21 19:31:46.573651
#   ______fO_get_group_league_status_match_finished_DETAILED()
#   ______Select  DATE(date),  leagueapi_id,  (select bookmakersapi_id from football_leagues where football_leagues.leagueapi_id = football_odds.leagueapi_id),  season,   fixtureapi_id,   pre_ah_pattern,   pre_gou_pattern,   fixture_status   from football_odds  where date <= '2023-07-21'  and date >= '2023-07-15'  and  deleted_at is null  and end_response != 3  and fixture_status like 'Match Finished'  order by date, leagueapi_id, fixtureapi_id  desc
#   ________Total Row(s) : 9
#   ________1. 2023-07-15 // 299 // 11 // 2023 // 998173 // H // G // Match Finished
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 998173
#   __________> end_ah_pattern = -025+0+025H
#   __________> end_ah_pattern_mirror = -025+0+025H
#   __________> end_gou_pattern = 175g20g225g25gG
#   __________> football_odds update pattern commited
#   ________2. 2023-07-15 // 239 // 8 // 2023 // 990307 // H // G // Match Finished
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 990307
#   __________> end_ah_pattern = -075-05-025H
#   __________> end_ah_pattern_mirror = +025+05+075H
#   __________> end_gou_pattern = 20g225g25gG
#   __________> football_odds update pattern commited
#   ________3. 2023-07-15 // 673 // 8 // 2023 // 1041162 // +15+175H // G // Match Finished
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1041162
#   __________> end_ah_pattern = +15+175H
#   __________> end_ah_pattern_mirror = -175-15H
#   __________> end_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________4. 2023-07-20 // 667 // 8 // 2023 // 1014225 // H // G // Match Finished
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1014225
#   __________> end_ah_pattern = H
#   __________> end_ah_pattern_mirror = H
#   __________> end_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________5. 2023-07-20 // 667 // 8 // 2023 // 1061189 // H // G // Match Finished
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1061189
#   __________> end_ah_pattern = H
#   __________> end_ah_pattern_mirror = H
#   __________> end_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________6. 2023-07-20 // 667 // 8 // 2023 // 1072485 // H // G // Match Finished
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1072485
#   __________> end_ah_pattern = H
#   __________> end_ah_pattern_mirror = H
#   __________> end_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________7. 2023-07-20 // 667 // 8 // 2023 // 1072606 // H // G // Match Finished
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1072606
#   __________> end_ah_pattern = H
#   __________> end_ah_pattern_mirror = H
#   __________> end_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________8. 2023-07-20 // 667 // 8 // 2023 // 1073473 // H // G // Match Finished
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1073473
#   __________> end_ah_pattern = H
#   __________> end_ah_pattern_mirror = H
#   __________> end_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________9. 2023-07-20 // 667 // 8 // 2023 // 1072609 // H // G // Match Finished
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1072609
#   __________> end_ah_pattern = H
#   __________> end_ah_pattern_mirror = H
#   __________> end_gou_pattern = G
#   __________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-22 19:32:14

# %%
from a_settings.messages import *  
from a_models.date import *   
from a_models.football_odds import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()")  
    # --------------------------------------------------    
    today_day    = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_pattern_match_finished(today_day, 'pattern_from', space)
    fO_pattern_match_finished(today_day, 'pattern_only', space)
#     fO_get_group_league_status_match_finished(day0, day1, today_day, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-22 23:15:30
#   __main()
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-07-22 23:15:30.227760
#   ____fO_pattern_match_finished()
#   ____ Select  leagueapi_id  from football_odds  where date <= Date('2023-07-22')  and pattern_from is null  and deleted_at is null  group by leagueapi_id
#   ____Total Row(s) : 435
#   ____[1/435]  #1
#   ____[2/435]  #2
#   ____[3/435]  #3
#   ____[4/435]  #5
#   ____[5/435]  #8
#   ____[6/435]  #10
#   ____[7/435]  #11
#   ____[8/435]  #12
#   ____[9/435]  #13
#   ____[10/435]  #14
#   ____[11/435]  #16
#   ____[12/435]  #18
#   ____[13/435]  #19
#   ____[14/435]  #20
#   ____[15/435]  #22
#   ____[16/435]  #24
#   ____[17/435]  #25
#   ____[18/435]  #29
#   ____[19/435]  #30
#   ____[20/435]  #31
#   ____[21/435]  #33
#   ____[22/435]  #34
#   ____[23/435]  #38
#   ____[24/435]  #39
#   ____[25/435]  #40
#   ____[26/435]  #41
#   ____[27/435]  #42
#   ____[28/435]  #43
#   ____[29/435]  #44
#   ____[30/435]  #45
#   ____[31/435]  #46
#   ____[32/435]  #47
#   ____[33/435]  #48
#   ____[34/435]  #50
#   ____[35/435]  #51
#   ____[36/435]  #58
#   ____[37/435]  #59
#   ____[38/435]  #60
#   ____[39/435]  #61
#   ____[40/435]  #62
#   ____[41/435]  #63
#   ____[42/435]  #64
#   ____[43/435]  #66
#   ____[44/435]  #67
#   ____[45/435]  #68
#   ____[46/435]  #69
#   ____[47/435]  #71
#   ____[48/435]  #72
#   ____[49/435]  #73
#   ____[50/435]  #74
#   ____[51/435]  #75
#   ____[52/435]  #76
#   ____[53/435]  #77
#   ____[54/435]  #78
#   ____[55/435]  #79
#   ____[56/435]  #80
#   ____[57/435]  #81
#   ____[58/435]  #82
#   ____[59/435]  #83
#   ____[60/435]  #84
#   ____[61/435]  #85
#   ____[62/435]  #86
#   ____[63/435]  #87
#   ____[64/435]  #88
#   ____[65/435]  #89
#   ____[66/435]  #90
#   ____[67/435]  #91
#   ____[68/435]  #94
#   ____[69/435]  #95
#   ____[70/435]  #96
#   ____[71/435]  #97
#   ____[72/435]  #98
#   ____[73/435]  #99
