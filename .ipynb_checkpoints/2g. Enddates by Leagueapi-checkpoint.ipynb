# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

leagueapi_id = input( "Enter your leagueapi id :  ")
season = input( "Enter your season :  ")

today = datetime.datetime.now()  
days0 = 7
days1 = 1
# Out:
# Enter your leagueapi id :  879
# Enter your season :  2022

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir)  
    # --------------------------------------------------   
    ff_get_group_date_league_status_match_finished(leagueapi_id, season, tgl_awal, tgl_akhir, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-02 01:19:35
#   __main()
#   ____days : 7
#   ____days : 1
#   ____tgl_awal : 2023-03-26
#   ____tgl_akhir : 2023-04-01
#   ______ff_get_group_date_league_status_match_finished()
#   ______Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where leagueapi_id = '879'  and season = '2022'  and date <= '2023-04-01'  and date >= '2023-03-26'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   ________Total Row(s) : 1
#   __________ff_get_fixture_status_match_finished_by_league()
#   ____________Total Row(s) : 8
#   ____________1. 2023-03-26 // 879 // 11 // 2022 // 936627 // 025_0#025+H // 15g175g2g225gG // Match Finished
#   ____________2. 2023-03-26 // 879 // 11 // 2022 // 936628 // H // G // Match Finished
#   ____________3. 2023-03-26 // 879 // 11 // 2022 // 936629 // 075_025_H // 175g2g225g25gG // Match Finished
#   ____________4. 2023-03-26 // 879 // 11 // 2022 // 936630 // 025_0#025+H // 175g2g225g25gG // Match Finished
#   ____________5. 2023-03-26 // 879 // 11 // 2022 // 936631 // 125_1_075_H // 175g2g225g25g275gG // Match Finished
#   ____________6. 2023-03-26 // 879 // 11 // 2022 // 936632 // 1_075_025_H // 15g175g2g225gG // Match Finished
#   ____________7. 2023-03-26 // 879 // 11 // 2022 // 936634 // 025_0#025+H // 175g2g225g25g275gG // Match Finished
#   ____________8. 2023-03-26 // 879 // 11 // 2022 // 947925 // 025_0#H // 15g175g2g225gG // Match Finished
#   ________Are you sure want to continue? :  yes
#   __________1. 2023-03-26 // 879 // 11 // 2022
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API herlambangharyo@gmail.com counter is 19
#   ________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-03-26
#   ________________bookmaker : 11
#   ________________season : 2022
#   ________________league : 879
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 5
#
#   __________________1. Spain,  Segunda División RFEF - Group 5  #879 - 2022 / 936629
#   __________________good to Go 1
#   ________________________1 Match Winner
#   __________________________end_match_winner_home = '1.84',
#   __________________________end_match_winner_draw = '3.22',
#   __________________________end_match_winner_away = '4.46',
#   ________________________3 Second Half Winner
#   __________________________end_second_half_winner_home = '2.22',
#   __________________________end_second_half_winner_draw = '2.20',
#   __________________________end_second_half_winner_away = '4.98',
#   ________________________4 Asian Handicap
#   __________________________end_asian_handicap_home_plus_0 = '1.30',
#   __________________________end_asian_handicap_away_plus_0 = '3.08',
#   __________________________end_asian_handicap_home_min_025 = '1.55',
#   __________________________end_asian_handicap_away_min_025 = '2.25',
#   __________________________end_asian_handicap_home_plus_025 = '1.24',
#   __________________________end_asian_handicap_away_plus_025 = '3.56',
#   __________________________end_asian_handicap_home_min_075 = '2.13',
#   __________________________end_asian_handicap_away_min_075 = '1.70',
#   __________________________end_asian_handicap_home_plus_075 = '1.10',
#   __________________________end_asian_handicap_away_plus_075 = '5.60',
#   __________________________end_asian_handicap_home_min_1 = '2.73',
#   __________________________end_asian_handicap_away_min_1 = '1.44',
#   __________________________end_asian_handicap_home_plus_1 = '1.01',
#   __________________________end_asian_handicap_away_plus_1 = '9.50',
#   __________________________end_asian_handicap_home_min_15 = '3.44',
#   __________________________end_asian_handicap_away_min_15 = '1.25',
#   __________________________end_asian_handicap_home_plus_15 = '1.00',
#   __________________________end_asian_handicap_away_plus_15 = '10.50',
#   __________________________end_asian_handicap_home_min_125 = '3.06',
#   __________________________end_asian_handicap_away_min_125 = '1.31',
#   __________________________end_asian_handicap_home_min_175 = '4.50',
#   __________________________end_asian_handicap_away_min_175 = '1.15',
#   __________________________end_asian_handicap_home_min_2 = '6.70',
#   __________________________end_asian_handicap_away_min_2 = '1.06',
#   __________________________end_asian_handicap_home_min_25 = '7.60',
#   __________________________end_asian_handicap_away_min_25 = '1.04',
#   __________________________end_asian_handicap_home_min_225 = '7.20',
#   __________________________end_asian_handicap_away_min_225 = '1.05',
#   __________________________end_asian_handicap_home_min_275 = '10.00',
#   __________________________end_asian_handicap_away_min_275 = '1.01',
#   ________________________5 Goals Over/Under
#   __________________________end_goals_overunder_over_35 = '4.74',
#   __________________________end_goals_overunder_under_35 = '1.13',
#   __________________________end_goals_overunder_over_15 = '1.51',
#   __________________________end_goals_overunder_under_15 = '2.52',
#   __________________________end_goals_overunder_over_45 = '9.50',
#   __________________________end_goals_overunder_under_45 = '1.01',
#   __________________________end_goals_overunder_over_25 = '2.45',
#   __________________________end_goals_overunder_under_25 = '1.46',
#   __________________________end_goals_overunder_over_05 = '1.06',
#   __________________________end_goals_overunder_under_05 = '6.45',
#   __________________________end_goals_overunder_over_55 = '17.00',
#   __________________________end_goals_overunder_under_55 = '1.01',
#   __________________________end_goals_overunder_over_225 = '2.15',
#   __________________________end_goals_overunder_under_225 = '1.61',
#   __________________________end_goals_overunder_over_325 = '4.40',
#   __________________________end_goals_overunder_under_325 = '1.16',
#   __________________________end_goals_overunder_over_275 = '2.94',
#   __________________________end_goals_overunder_under_275 = '1.34',
#   __________________________end_goals_overunder_over_125 = '1.30',
#   __________________________end_goals_overunder_under_125 = '3.12',
#   __________________________end_goals_overunder_over_175 = '1.66',
#   __________________________end_goals_overunder_under_175 = '2.20',
#   __________________________end_goals_overunder_over_375 = '6.05',
#   __________________________end_goals_overunder_under_375 = '1.08',
#   __________________________end_goals_overunder_over_075 = '1.09',
#   __________________________end_goals_overunder_under_075 = '5.80',
#   __________________________end_goals_overunder_over_30 = '3.96',
#   __________________________end_goals_overunder_under_30 = '1.19',
#   __________________________end_goals_overunder_over_20 = '1.85',
#   __________________________end_goals_overunder_under_20 = '1.83',
#   __________________________end_goals_overunder_over_40 = '8.80',
#   __________________________end_goals_overunder_under_40 = '1.02',
#   __________________________end_goals_overunder_over_10 = '1.12',
#   __________________________end_goals_overunder_under_10 = '5.15',
#   ________________________6 Goals Over/Under First Half
#   __________________________end_goals_overunder_first_half_over_35 = '41.00',
#   __________________________end_goals_overunder_first_half_over_15 = '3.56',
#   __________________________end_goals_overunder_first_half_under_15 = '1.25',
#   __________________________end_goals_overunder_first_half_over_25 = '9.40',
#   __________________________end_goals_overunder_first_half_under_25 = '1.03',
#   __________________________end_goals_overunder_first_half_over_05 = '1.53',
#   __________________________end_goals_overunder_first_half_under_05 = '2.34',
#   __________________________end_goals_overunder_first_half_over_125 = '2.94',
#   __________________________end_goals_overunder_first_half_under_125 = '1.35',
#   __________________________end_goals_overunder_first_half_over_175 = '4.84',
#   __________________________end_goals_overunder_first_half_under_175 = '1.14',
#   __________________________end_goals_overunder_first_half_over_075 = '1.78',
#   __________________________end_goals_overunder_first_half_under_075 = '1.93',
#   __________________________end_goals_overunder_first_half_over_10 = '2.34',
#   __________________________end_goals_overunder_first_half_under_10 = '1.53',
#   ________________________26 Goals Over/Under - Second Half
#   __________________________end_goals_overunder__second_half_over_35 = '13.00',
#   __________________________end_goals_overunder__second_half_under_35 = '1.02',
#   __________________________end_goals_overunder__second_half_over_15 = '2.62',
#   __________________________end_goals_overunder__second_half_under_15 = '1.43',
#   __________________________end_goals_overunder__second_half_over_25 = '6.20',
#   __________________________end_goals_overunder__second_half_under_25 = '1.09',
#   __________________________end_goals_overunder__second_half_over_05 = '1.35',
#   __________________________end_goals_overunder__second_half_under_05 = '2.94',
#   __________________________end_goals_overunder__second_half_over_125 = '2.20',
#   __________________________end_goals_overunder__second_half_under_125 = '1.60',
#   __________________________end_goals_overunder__second_half_over_175 = '3.34',
#   __________________________end_goals_overunder__second_half_under_175 = '1.28',
#   __________________________end_goals_overunder__second_half_over_075 = '1.48',
#   __________________________end_goals_overunder__second_half_under_075 = '2.47',
#   __________________________end_goals_overunder__second_half_over_10 = '1.75',
#   __________________________end_goals_overunder__second_half_under_10 = '1.97',
#   ________________________7 HT/FT Double
#   ________________________8 Both Teams Score
#   __________________________end_both_teams_score_yes = '2.19',
#   __________________________end_both_teams_score_no = '1.64',
#   ________________________9 Handicap Result
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 3.44
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.87
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.20
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.16
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 10.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.02
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 26.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 7.60
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 5.20
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.25
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.03
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 29.00
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.01
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 21.00
#   ________________________10 Exact Score
#   ________________________11 Highest Scoring Half
#   ________________________31 Correct Score - First Half
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.74
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 10.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 34.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 67.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.34
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 10.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 6.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 26.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 81.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 41.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   ________________________12 Double Chance
#   __________________________end_double_chance_home_draw = '1.16',
#   __________________________end_double_chance_home_away = '1.30',
#   __________________________end_double_chance_draw_away = '1.87',
#   ________________________13 First Half Winner
#   __________________________end_first_half_winner_home = '2.49',
#   __________________________end_first_half_winner_draw = '1.92',
#   __________________________end_first_half_winner_away = '5.45',
#   ________________________16 Total - Home
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 10.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.04
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.23
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.55
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.12
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.24
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 3.48
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 3.98
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.19
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.50
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 2.35
#   ________________________17 Total - Away
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 4.60
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.14
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.02
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.71
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 1.97
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 3.08
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 1.30
#   ________________________18 Handicap Result - First Half
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 7.70
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.41
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.44
#   ________________________19 Asian Handicap First Half
#   ________________________20 Double Chance - First Half
#   ________________________33 Double Chance - Second Half
#   ____________________  ____________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.10
#   ____________________  ____________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.51
#   ____________________  ____________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.51
#   ________________________34 Both Teams Score - First Half
#   ________________________35 Both Teams To Score - Second Half
#   ________________________21 Odd/Even
#   ________________________22 Odd/Even - First Half
#   ____________________  ____________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.12
#   ____________________  ____________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.61
#   ________________________23 Home Odd/Even
#   ____________________  ____________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.92
#   ____________________  ____________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.75
#   ________________________60 Away Odd/Even
#   ____________________  ____________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.27
#   ____________________  ____________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.53
#   ____________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ____________________2. Spain,  Segunda División RFEF - Group 5  #879 - 2022 / 936631
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.62',
#   ____________________________end_match_winner_draw = '3.64',
#   ____________________________end_match_winner_away = '5.30',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '1.99',
#   ____________________________end_second_half_winner_draw = '2.40',
#   ____________________________end_second_half_winner_away = '5.35',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.20',
#   ____________________________end_asian_handicap_away_plus_0 = '3.88',
#   ____________________________end_asian_handicap_home_min_025 = '1.40',
#   ____________________________end_asian_handicap_away_min_025 = '2.67',
#   ____________________________end_asian_handicap_home_plus_025 = '1.16',
#   ____________________________end_asian_handicap_away_plus_025 = '4.46',
#   ____________________________end_asian_handicap_home_min_075 = '1.82',
#   ____________________________end_asian_handicap_away_min_075 = '1.96',
#   ____________________________end_asian_handicap_home_plus_075 = '1.06',
#   ____________________________end_asian_handicap_away_plus_075 = '6.70',
#   ____________________________end_asian_handicap_home_min_1 = '2.15',
#   ____________________________end_asian_handicap_away_min_1 = '1.68',
#   ____________________________end_asian_handicap_home_min_15 = '2.78',
#   ____________________________end_asian_handicap_away_min_15 = '1.37',
#   ____________________________end_asian_handicap_home_min_125 = '2.44',
#   ____________________________end_asian_handicap_away_min_125 = '1.48',
#   ____________________________end_asian_handicap_home_min_175 = '3.42',
#   ____________________________end_asian_handicap_away_min_175 = '1.26',
#   ____________________________end_asian_handicap_home_min_2 = '4.80',
#   ____________________________end_asian_handicap_away_min_2 = '1.13',
#   ____________________________end_asian_handicap_home_min_3 = '10.50',
#   ____________________________end_asian_handicap_away_min_3 = '1.00',
#   ____________________________end_asian_handicap_home_min_25 = '5.60',
#   ____________________________end_asian_handicap_away_min_25 = '1.09',
#   ____________________________end_asian_handicap_home_min_225 = '5.20',
#   ____________________________end_asian_handicap_away_min_225 = '1.12',
#   ____________________________end_asian_handicap_home_min_275 = '7.30',
#   ____________________________end_asian_handicap_away_min_275 = '1.05',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '3.74',
#   ____________________________end_goals_overunder_under_35 = '1.21',
#   ____________________________end_goals_overunder_over_15 = '1.36',
#   ____________________________end_goals_overunder_under_15 = '2.79',
#   ____________________________end_goals_overunder_over_45 = '7.40',
#   ____________________________end_goals_overunder_under_45 = '1.04',
#   ____________________________end_goals_overunder_over_25 = '2.18',
#   ____________________________end_goals_overunder_under_25 = '1.67',
#   ____________________________end_goals_overunder_over_05 = '1.04',
#   ____________________________end_goals_overunder_under_05 = '7.80',
#   ____________________________end_goals_overunder_over_55 = '13.00',
#   ____________________________end_goals_overunder_under_55 = '1.02',
#   ____________________________end_goals_overunder_over_225 = '1.91',
#   ____________________________end_goals_overunder_under_225 = '1.87',
#   ____________________________end_goals_overunder_over_325 = '3.42',
#   ____________________________end_goals_overunder_under_325 = '1.26',
#   ____________________________end_goals_overunder_over_275 = '2.48',
#   ____________________________end_goals_overunder_under_275 = '1.46',
#   ____________________________end_goals_overunder_over_125 = '1.22',
#   ____________________________end_goals_overunder_under_125 = '3.76',
#   ____________________________end_goals_overunder_over_425 = '7.10',
#   ____________________________end_goals_overunder_under_425 = '1.06',
#   ____________________________end_goals_overunder_over_175 = '1.45',
#   ____________________________end_goals_overunder_under_175 = '2.51',
#   ____________________________end_goals_overunder_over_375 = '4.82',
#   ____________________________end_goals_overunder_under_375 = '1.14',
#   ____________________________end_goals_overunder_over_075 = '1.06',
#   ____________________________end_goals_overunder_under_075 = '7.10',
#   ____________________________end_goals_overunder_over_30 = '3.14',
#   ____________________________end_goals_overunder_under_30 = '1.30',
#   ____________________________end_goals_overunder_over_20 = '1.60',
#   ____________________________end_goals_overunder_under_20 = '2.16',
#   ____________________________end_goals_overunder_over_40 = '6.75',
#   ____________________________end_goals_overunder_under_40 = '1.06',
#   ____________________________end_goals_overunder_over_10 = '1.06',
#   ____________________________end_goals_overunder_under_10 = '6.45',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '17.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.01',
#   ____________________________end_goals_overunder_first_half_over_15 = '3.10',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.32',
#   ____________________________end_goals_overunder_first_half_over_25 = '7.90',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.05',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.45',
#   ____________________________end_goals_overunder_first_half_under_05 = '2.58',
#   ____________________________end_goals_overunder_first_half_over_125 = '2.59',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.44',
#   ____________________________end_goals_overunder_first_half_over_175 = '4.14',
#   ____________________________end_goals_overunder_first_half_under_175 = '1.19',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.63',
#   ____________________________end_goals_overunder_first_half_under_075 = '2.14',
#   ____________________________end_goals_overunder_first_half_over_10 = '2.05',
#   ____________________________end_goals_overunder_first_half_under_10 = '1.69',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '12.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.03',
#   ____________________________end_goals_overunder__second_half_over_15 = '2.34',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.53',
#   ____________________________end_goals_overunder__second_half_over_25 = '5.20',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.13',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.28',
#   ____________________________end_goals_overunder__second_half_under_05 = '3.34',
#   ____________________________end_goals_overunder__second_half_over_125 = '1.95',
#   ____________________________end_goals_overunder__second_half_under_125 = '1.76',
#   ____________________________end_goals_overunder__second_half_over_175 = '2.90',
#   ____________________________end_goals_overunder__second_half_under_175 = '1.36',
#   ____________________________end_goals_overunder__second_half_over_075 = '1.38',
#   ____________________________end_goals_overunder__second_half_under_075 = '2.81',
#   ____________________________end_goals_overunder__second_half_over_10 = '1.57',
#   ____________________________end_goals_overunder__second_half_under_10 = '2.26',
#   __________________________7 HT/FT Double
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '2.07',
#   ____________________________end_both_teams_score_no = '1.72',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 2.78
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 2.18
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.18
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.08
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 5.60
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 4.60
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.37
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 15.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.60
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.58
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.11',
#   ____________________________end_double_chance_home_away = '1.24',
#   ____________________________end_double_chance_draw_away = '2.18',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '2.19',
#   ____________________________end_first_half_winner_draw = '2.06',
#   ____________________________end_first_half_winner_away = '6.10',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.87
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.79
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 3.74
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.21
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.16
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 4.40
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 2.84
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.35
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 3.08
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 4.70
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 1.94
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 3.20
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 1.28
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 6.15
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.53
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.15
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________33 Double Chance - Second Half
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.08
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.43
#   ______________________  ______________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.65
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.05
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.65
#   __________________________23 Home Odd/Even
#   ______________________  ______________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.87
#   ______________________  ______________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.79
#   __________________________60 Away Odd/Even
#   ______________________  ______________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.28
#   ______________________  ______________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.53
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ______________________3. Spain,  Segunda División RFEF - Group 5  #879 - 2022 / 936627
#   ______________________good to Go 1
#   ____________________________1 Match Winner
#   ______________________________end_match_winner_home = '2.52',
#   ______________________________end_match_winner_draw = '2.90',
#   ______________________________end_match_winner_away = '2.90',
#   ____________________________3 Second Half Winner
#   ______________________________end_second_half_winner_home = '2.93',
#   ______________________________end_second_half_winner_draw = '2.09',
#   ______________________________end_second_half_winner_away = '3.48',
#   ____________________________4 Asian Handicap
#   ______________________________end_asian_handicap_home_plus_0 = '1.77',
#   ______________________________end_asian_handicap_away_plus_0 = '2.02',
#   ______________________________end_asian_handicap_home_min_025 = '2.13',
#   ______________________________end_asian_handicap_away_min_025 = '1.70',
#   ______________________________end_asian_handicap_home_plus_025 = '1.50',
#   ______________________________end_asian_handicap_away_plus_025 = '2.39',
#   ______________________________end_asian_handicap_home_min_075 = '3.03',
#   ______________________________end_asian_handicap_away_min_075 = '1.32',
#   ______________________________end_asian_handicap_home_plus_075 = '1.24',
#   ______________________________end_asian_handicap_away_plus_075 = '3.54',
#   ______________________________end_asian_handicap_home_min_1 = '4.50',
#   ______________________________end_asian_handicap_away_min_1 = '1.15',
#   ______________________________end_asian_handicap_home_plus_1 = '1.10',
#   ______________________________end_asian_handicap_away_plus_1 = '5.55',
#   ______________________________end_asian_handicap_home_min_15 = '5.55',
#   ______________________________end_asian_handicap_away_min_15 = '1.10',
#   ______________________________end_asian_handicap_home_plus_15 = '1.06',
#   ______________________________end_asian_handicap_away_plus_15 = '6.60',
#   ______________________________end_asian_handicap_home_min_125 = '5.05',
#   ______________________________end_asian_handicap_away_min_125 = '1.12',
#   ______________________________end_asian_handicap_home_min_175 = '7.50',
#   ______________________________end_asian_handicap_away_min_175 = '1.05',
#   ______________________________end_asian_handicap_home_plus_125 = '1.08',
#   ______________________________end_asian_handicap_away_plus_125 = '6.10',
#   ______________________________end_asian_handicap_home_plus_175 = '1.02',
#   ______________________________end_asian_handicap_away_plus_175 = '9.20',
#   ____________________________5 Goals Over/Under
#   ______________________________end_goals_overunder_over_35 = '5.35',
#   ______________________________end_goals_overunder_under_35 = '1.10',
#   ______________________________end_goals_overunder_over_15 = '1.59',
#   ______________________________end_goals_overunder_under_15 = '2.33',
#   ______________________________end_goals_overunder_over_45 = '12.00',
#   ______________________________end_goals_overunder_under_45 = '1.03',
#   ______________________________end_goals_overunder_over_25 = '2.67',
#   ______________________________end_goals_overunder_under_25 = '1.39',
#   ______________________________end_goals_overunder_over_05 = '1.09',
#   ______________________________end_goals_overunder_under_05 = '5.80',
#   ______________________________end_goals_overunder_over_225 = '2.36',
#   ______________________________end_goals_overunder_under_225 = '1.51',
#   ______________________________end_goals_overunder_over_325 = '4.96',
#   ______________________________end_goals_overunder_under_325 = '1.13',
#   ______________________________end_goals_overunder_over_275 = '3.28',
#   ______________________________end_goals_overunder_under_275 = '1.28',
#   ______________________________end_goals_overunder_over_125 = '1.36',
#   ______________________________end_goals_overunder_under_125 = '2.87',
#   ______________________________end_goals_overunder_over_175 = '1.77',
#   ______________________________end_goals_overunder_under_175 = '2.04',
#   ______________________________end_goals_overunder_over_375 = '6.95',
#   ______________________________end_goals_overunder_under_375 = '1.06',
#   ______________________________end_goals_overunder_over_075 = '1.12',
#   ______________________________end_goals_overunder_under_075 = '5.20',
#   ______________________________end_goals_overunder_over_30 = '4.54',
#   ______________________________end_goals_overunder_under_30 = '1.15',
#   ______________________________end_goals_overunder_over_20 = '2.02',
#   ______________________________end_goals_overunder_under_20 = '1.69',
#   ______________________________end_goals_overunder_over_40 = '10.00',
#   ______________________________end_goals_overunder_under_40 = '1.01',
#   ______________________________end_goals_overunder_over_10 = '1.15',
#   ______________________________end_goals_overunder_under_10 = '4.60',
#   ____________________________6 Goals Over/Under First Half
#   ______________________________end_goals_overunder_first_half_over_35 = '41.00',
#   ______________________________end_goals_overunder_first_half_over_15 = '3.84',
#   ______________________________end_goals_overunder_first_half_under_15 = '1.22',
#   ______________________________end_goals_overunder_first_half_over_25 = '10.50',
#   ______________________________end_goals_overunder_first_half_under_25 = '1.01',
#   ______________________________end_goals_overunder_first_half_over_05 = '1.59',
#   ______________________________end_goals_overunder_first_half_under_05 = '2.22',
#   ______________________________end_goals_overunder_first_half_over_125 = '3.20',
#   ______________________________end_goals_overunder_first_half_under_125 = '1.30',
#   ______________________________end_goals_overunder_first_half_over_175 = '5.25',
#   ______________________________end_goals_overunder_first_half_under_175 = '1.12',
#   ______________________________end_goals_overunder_first_half_over_075 = '1.86',
#   ______________________________end_goals_overunder_first_half_under_075 = '1.85',
#   ______________________________end_goals_overunder_first_half_over_10 = '2.56',
#   ______________________________end_goals_overunder_first_half_under_10 = '1.45',
#   ____________________________26 Goals Over/Under - Second Half
#   ______________________________end_goals_overunder__second_half_over_35 = '15.00',
#   ______________________________end_goals_overunder__second_half_under_35 = '1.02',
#   ______________________________end_goals_overunder__second_half_over_15 = '2.81',
#   ______________________________end_goals_overunder__second_half_under_15 = '1.38',
#   ______________________________end_goals_overunder__second_half_over_25 = '6.90',
#   ______________________________end_goals_overunder__second_half_under_25 = '1.07',
#   ______________________________end_goals_overunder__second_half_over_05 = '1.39',
#   ______________________________end_goals_overunder__second_half_under_05 = '2.77',
#   ______________________________end_goals_overunder__second_half_over_125 = '2.34',
#   ______________________________end_goals_overunder__second_half_under_125 = '1.53',
#   ______________________________end_goals_overunder__second_half_over_175 = '3.64',
#   ______________________________end_goals_overunder__second_half_under_175 = '1.24',
#   ______________________________end_goals_overunder__second_half_over_075 = '1.55',
#   ______________________________end_goals_overunder__second_half_under_075 = '2.30',
#   ______________________________end_goals_overunder__second_half_over_10 = '1.87',
#   ______________________________end_goals_overunder__second_half_under_10 = '1.84',
#   ____________________________7 HT/FT Double
#   ____________________________8 Both Teams Score
#   ______________________________end_both_teams_score_yes = '2.17',
#   ______________________________end_both_teams_score_no = '1.66',
#   ____________________________9 Handicap Result
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.55
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.46
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.64
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.35
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 6.60
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.10
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.04
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 9.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 19.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.07
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 26.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 17.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.01
# ...
#   __________________________________end_goals_overunder_under_375 = '1.08',
#   __________________________________end_goals_overunder_over_075 = '1.10',
#   __________________________________end_goals_overunder_under_075 = '5.65',
#   __________________________________end_goals_overunder_over_30 = '4.10',
#   __________________________________end_goals_overunder_under_30 = '1.18',
#   __________________________________end_goals_overunder_over_20 = '1.88',
#   __________________________________end_goals_overunder_under_20 = '1.80',
#   __________________________________end_goals_overunder_over_40 = '9.20',
#   __________________________________end_goals_overunder_under_40 = '1.02',
#   __________________________________end_goals_overunder_over_10 = '1.13',
#   __________________________________end_goals_overunder_under_10 = '5.05',
#   ________________________________6 Goals Over/Under First Half
#   __________________________________end_goals_overunder_first_half_over_15 = '3.56',
#   __________________________________end_goals_overunder_first_half_under_15 = '1.25',
#   __________________________________end_goals_overunder_first_half_over_25 = '10.00',
#   __________________________________end_goals_overunder_first_half_under_25 = '1.02',
#   __________________________________end_goals_overunder_first_half_over_05 = '1.55',
#   __________________________________end_goals_overunder_first_half_under_05 = '2.30',
#   __________________________________end_goals_overunder_first_half_over_125 = '3.04',
#   __________________________________end_goals_overunder_first_half_under_125 = '1.33',
#   __________________________________end_goals_overunder_first_half_over_175 = '4.94',
#   __________________________________end_goals_overunder_first_half_under_175 = '1.14',
#   __________________________________end_goals_overunder_first_half_over_075 = '1.80',
#   __________________________________end_goals_overunder_first_half_under_075 = '1.91',
#   __________________________________end_goals_overunder_first_half_over_10 = '2.39',
#   __________________________________end_goals_overunder_first_half_under_10 = '1.51',
#   ________________________________26 Goals Over/Under - Second Half
#   __________________________________end_goals_overunder__second_half_over_35 = '15.00',
#   __________________________________end_goals_overunder__second_half_under_35 = '1.02',
#   __________________________________end_goals_overunder__second_half_over_15 = '2.69',
#   __________________________________end_goals_overunder__second_half_under_15 = '1.41',
#   __________________________________end_goals_overunder__second_half_over_25 = '6.70',
#   __________________________________end_goals_overunder__second_half_under_25 = '1.07',
#   __________________________________end_goals_overunder__second_half_over_05 = '1.36',
#   __________________________________end_goals_overunder__second_half_under_05 = '2.90',
#   __________________________________end_goals_overunder__second_half_over_125 = '2.24',
#   __________________________________end_goals_overunder__second_half_under_125 = '1.58',
#   __________________________________end_goals_overunder__second_half_over_175 = '3.42',
#   __________________________________end_goals_overunder__second_half_under_175 = '1.27',
#   __________________________________end_goals_overunder__second_half_over_075 = '1.50',
#   __________________________________end_goals_overunder__second_half_under_075 = '2.42',
#   __________________________________end_goals_overunder__second_half_over_10 = '1.78',
#   __________________________________end_goals_overunder__second_half_under_10 = '1.93',
#   ________________________________7 HT/FT Double
#   ________________________________8 Both Teams Score
#   __________________________________end_both_teams_score_yes = '2.07',
#   __________________________________end_both_teams_score_no = '1.72',
#   ________________________________9 Handicap Result
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.40
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.46
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.74
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.36
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 6.35
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.10
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.04
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 9.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 19.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 13.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 7.50
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.08
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 26.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 15.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.02
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.01
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 19.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 29.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 29.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.01
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 23.00
#   ________________________________10 Exact Score
#   ________________________________11 Highest Scoring Half
#   ________________________________31 Correct Score - First Half
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.32
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 13.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 41.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 81.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.30
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.50
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 5.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 19.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 67.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 34.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   ________________________________12 Double Chance
#   __________________________________end_double_chance_home_draw = '1.36',
#   __________________________________end_double_chance_home_away = '1.34',
#   __________________________________end_double_chance_draw_away = '1.46',
#   ________________________________13 First Half Winner
#   __________________________________end_first_half_winner_home = '3.24',
#   __________________________________end_first_half_winner_draw = '1.87',
#   __________________________________end_first_half_winner_away = '3.82',
#   ________________________________16 Total - Home
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 13.00
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.02
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.88
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.34
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 7.30
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.05
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.39
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 2.67
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 6.15
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.08
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.89
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 1.77
#   ________________________________17 Total - Away
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 3.20
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.28
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 8.40
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.03
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.45
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 2.48
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 7.20
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.05
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 2.11
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 1.62
#   ________________________________18 Handicap Result - First Half
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 10.00
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.26
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 4.04
#   ________________________________19 Asian Handicap First Half
#   ________________________________20 Double Chance - First Half
#   ________________________________33 Double Chance - Second Half
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.23
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.54
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.30
#   ________________________________34 Both Teams Score - First Half
#   ________________________________35 Both Teams To Score - Second Half
#   ________________________________21 Odd/Even
#   ________________________________22 Odd/Even - First Half
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.14
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.60
#   ________________________________23 Home Odd/Even
#   ____________________________  ____________________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.01
#   ____________________________  ____________________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.68
#   ________________________________60 Away Odd/Even
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.05
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.65
#   ____________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ______________________________ff_update_unfinished__
#   ____________________________  > No longer get supported
# # -------------------------------------------------- End at 2023-04-02 01:19:54

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------    
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir)   
    # --------------------------------------------------   
    ff_get_fixture_status_match_finished_by_league(leagueapi_id, season, tgl_awal, tgl_akhir, 'xpattern', space) 
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-02 01:19:54
#   __main()
#   ____days : 7
#   ____days : 1
#   ____tgl_awal : 2023-03-26
#   ____tgl_akhir : 2023-04-01
#   ______ff_get_fixture_status_match_finished_by_league()
#   ________Total Row(s) : 5
#   ________1. 2023-03-26 // 879 // 11 // 2022 // 936627 // 025_0#025+H // 15g175g2g225gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 936627
#   __________> end_ah_pattern = 025_0#025+H
#   __________> end_ah_pattern_mirror = 025_0#025+H
#   __________> end_gou_pattern = 15g175g2g225gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________2. 2023-03-26 // 879 // 11 // 2022 // 936629 // 075_025_H // 175g2g225g25gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 936629
#   __________> end_ah_pattern = 075_025_H
#   __________> end_ah_pattern_mirror = 025+075+H
#   __________> end_gou_pattern = 175g2g225g25gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________3. 2023-03-26 // 879 // 11 // 2022 // 936630 // 025_0#025+H // 175g2g225g25gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 936630
#   __________> end_ah_pattern = 025_0#025+H
#   __________> end_ah_pattern_mirror = 025_0#025+H
#   __________> end_gou_pattern = 175g2g225g25gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________4. 2023-03-26 // 879 // 11 // 2022 // 936631 // 125_1_075_H // 175g2g225g25g275gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 936631
#   __________> end_ah_pattern = 125_1_075_H
#   __________> end_ah_pattern_mirror = 075+1+125+H
#   __________> end_gou_pattern = 175g2g225g25g275gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________5. 2023-03-26 // 879 // 11 // 2022 // 936632 // 1_075_025_H // 15g175g2g225gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 936632
#   __________> end_ah_pattern = 1_075_025_H
#   __________> end_ah_pattern_mirror = 025+075+1+H
#   __________> end_gou_pattern = 15g175g2g225gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
# # -------------------------------------------------- End at 2023-04-02 01:20:14

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------    
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "leagueapi_id : " + str(leagueapi_id))
    print(space + "season : " + str(season))
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir)   
    # --------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist_by_leagueapi_id(leagueapi_id, 
                                                                                      season, tgl_awal, tgl_akhir, space) 
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-02 01:20:14
#   __main()
#   ____days : 7
#   ____days : 1
#   ____tgl_awal : 2023-03-26
#   ____tgl_akhir : 2023-04-01
#   ______ff_get_fixture_status_match_finished_for_daily_update_patternlist_by_leagueapi_id()
#   ______Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date = '879'  and season = '2022'  and date <= '2023-04-01'  and date >= '2023-03-26'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   ________Total Row(s) : 0
# # -------------------------------------------------- End at 2023-04-02 01:20:15
