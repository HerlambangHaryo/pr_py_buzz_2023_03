# %%
# Import
from a_settings.messages import *  

today = datetime.datetime.now()  
days0 = 2
days1 = 1
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 2 - 1 --> 2023-03-24 19:23:53.668521

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 19:23:54
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-22
#   ______tgl_akhir : 2023-03-23
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-23'  and date >= '2023-03-22'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 20
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 59
#   ______________1. 2023-03-22 // 10 // 8 // 2023 // 984804 // 175_15_125_H // 225g25g275gG
#   ______________2. 2023-03-22 // 10 // 8 // 2023 // 1012368 // 125_075_H // 325gG
#   ______________3. 2023-03-22 // 10 // 8 // 2023 // 1012360 // None // None
#   ______________4. 2023-03-22 // 36 // 0 // 2023 // 859164 // H // G
#   ______________5. 2023-03-22 // 36 // 0 // 2023 // 859186 // H // G
#   ______________6. 2023-03-22 // 42 // 8 // 2022 // 876311 // 1_075_05_025_H // 225g25g275gG
#   ______________7. 2023-03-22 // 146 // 11 // 2022 // 1010514 // 025+075+H // 25g275g3g325g35gG
#   ______________8. 2023-03-22 // 167 // 11 // 2023 // 1010597 // H // 35g45gG
#   ______________9. 2023-03-22 // 243 // 11 // 2023 // 1011779 // 025_0#025+H // 225g25g275g3g325g35gG
#   ______________10. 2023-03-22 // 243 // 11 // 2023 // 1011780 // 025_0#025+H // 15g175g2g225g25gG
#   ______________11. 2023-03-22 // 243 // 11 // 2023 // 1011776 // None // None
#   ______________12. 2023-03-23 // 243 // 11 // 2023 // 1011777 // None // None
#   ______________13. 2023-03-22 // 263 // 8 // 2022 // 975962 // H // G
#   ______________14. 2023-03-22 // 263 // 8 // 2022 // 975963 // H // G
#   ______________15. 2023-03-22 // 263 // 8 // 2022 // 975964 // H // G
#   ______________16. 2023-03-22 // 263 // 8 // 2022 // 975965 // 025_H // 25gG
#   ______________17. 2023-03-22 // 287 // 11 // 2022 // 869175 // 075_025_H // 15g175g2g225gG
#   ______________18. 2023-03-22 // 287 // 11 // 2022 // 869179 // 175_15_125_1_075_H // 2g225g25g275gG
#   ______________19. 2023-03-22 // 287 // 11 // 2022 // 869180 // 1_075_025_H // 175g2g225g25gG
#   ______________20. 2023-03-22 // 487 // 11 // 2022 // 941785 // 1+125+15+175+H // 25g275g3g325g35gG
#   ______________21. 2023-03-22 // 487 // 11 // 2022 // 941811 // 1_075_025_H // 225g25g275g3g325g35gG
#   ______________22. 2023-03-22 // 487 // 11 // 2022 // 941819 // 15_125_1_075_H // 25g275g3g325g35g375gG
#   ______________23. 2023-03-22 // 510 // 11 // 2022 // 898490 // H // G
#   ______________24. 2023-03-22 // 510 // 11 // 2022 // 898494 // 075_025_0#025+H // 25g275g3g325g35gG
#   ______________25. 2023-03-22 // 525 // 11 // 2022 // 1004755 // 075_025_0#H // 2g225g25g275gG
#   ______________26. 2023-03-22 // 525 // 11 // 2022 // 1004757 // 0#025+075+H // 225g25g275g3g325gG
#   ______________27. 2023-03-22 // 604 // 8 // 2023 // 1015131 // H // G
#   ______________28. 2023-03-22 // 604 // 8 // 2023 // 1015125 // None // None
#   ______________29. 2023-03-22 // 701 // 11 // 2022 // 992372 // H // G
#   ______________30. 2023-03-22 // 701 // 11 // 2022 // 992389 // 125_1_075_025_H // 225g25g275g3g325gG
#   ______________31. 2023-03-22 // 740 // 11 // 2023 // 1010648 // None // None
#   ______________32. 2023-03-22 // 740 // 11 // 2023 // 1010649 // None // None
#   ______________33. 2023-03-22 // 740 // 11 // 2023 // 1010655 // None // None
#   ______________34. 2023-03-22 // 744 // 11 // 2022 // 908105 // 2_175_15_125_1_075_H // 325g35g375g4g425g45gG
#   ______________35. 2023-03-22 // 747 // 11 // 2022 // 906758 // 075_025_0#H // 225g25g275g3gG
#   ______________36. 2023-03-22 // 750 // 11 // 2022 // 907439 // 025_0#025+H // 25g275g3g325g35g375gG
#   ______________37. 2023-03-22 // 751 // 11 // 2022 // 906469 // 175+2+225+25+275+H // 275g3g325g35g375g4gG
#   ______________38. 2023-03-22 // 751 // 11 // 2022 // 906470 // 025_0#025+H // 25g275g3g325g35g375gG
#   ______________39. 2023-03-22 // 751 // 11 // 2022 // 906471 // 075_025_0#H // 25g275g3g325g35g375gG
#   ______________40. 2023-03-22 // 751 // 11 // 2022 // 906472 // 025+075+1+125+H // 25g275g3g325g35g375gG
#   ______________41. 2023-03-22 // 751 // 11 // 2022 // 906473 // 075+1+125+15+H // 25g275g3g325g35g375gG
#   ______________42. 2023-03-22 // 751 // 11 // 2022 // 906474 // 15_125_1_075_H // 25g275g3g325g35g375gG
#   ______________43. 2023-03-22 // 751 // 11 // 2022 // 906475 // 15_125_1_075_H // 275g3g325g35g375gG
#   ______________44. 2023-03-22 // 751 // 11 // 2022 // 906477 // 0#025+075+H // 25g275g3g325g35gG
#   ______________45. 2023-03-22 // 751 // 11 // 2022 // 906478 // 125_1_075_025_H // 25g275g3g325g35gG
#   ______________46. 2023-03-22 // 893 // 11 // 2023 // 978664 // 0#025+075+H // 225g25g275g3g325gG
#   ______________47. 2023-03-22 // 893 // 11 // 2023 // 978665 // 25_225_2_175_15_H // 275g3g325g35g375gG
#   ______________48. 2023-03-22 // 893 // 11 // 2023 // 978666 // 0#025+H // 225g25g275g3gG
#   ______________49. 2023-03-22 // 893 // 11 // 2023 // 978668 // 275_25_225_2_175_15_H // 275g3g325g35g375gG
#   ______________50. 2023-03-22 // 893 // 11 // 2023 // 978669 // 1_075_025_H // 2g225g25g275gG
#   ______________51. 2023-03-22 // 893 // 11 // 2023 // 978671 // 125_1_075_025_H // 25g275g3g325g35gG
#   ______________52. 2023-03-22 // 893 // 11 // 2023 // 978672 // 175_15_125_1_H // 25g275g3g325g35gG
#   ______________53. 2023-03-22 // 893 // 11 // 2023 // 978673 // 15_125_1_075_H // 25g275g3g325g35gG
#   ______________54. 2023-03-22 // 893 // 11 // 2023 // 978674 // 175_15_125_1_075_H // 25g275g3g325g35gG
#   ______________55. 2023-03-22 // 893 // 11 // 2023 // 978676 // 075_025_H // 225g25g275g3gG
#   ______________56. 2023-03-22 // 893 // 11 // 2023 // 978677 // 125+15+175+2+H // 25g275g3g325g35gG
#   ______________57. 2023-03-22 // 893 // 11 // 2023 // 978667 // None // None
#   ______________58. 2023-03-22 // 893 // 11 // 2023 // 978670 // None // None
#   ______________59. 2023-03-22 // 893 // 11 // 2023 // 978675 // None // None
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-03-22 // 10 // 8 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 64
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-22
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 10
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. World,  Friendlies  #10 - 2023 / 984804
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.18',
#   ____________________________end_match_winner_draw = '6.50',
#   ____________________________end_match_winner_away = '19.00',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '1.04',
#   ____________________________end_homeaway_away = '13.00',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '1.40',
#   ____________________________end_second_half_winner_draw = '3.00',
#   ____________________________end_second_half_winner_away = '13.00',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_min_025 = '1.11',
#   ____________________________end_asian_handicap_away_min_025 = '6.60',
#   ____________________________end_asian_handicap_home_min_05 = '1.19',
#   ____________________________end_asian_handicap_away_min_05 = '4.50',
#   ____________________________end_asian_handicap_home_min_075 = '1.23',
#   ____________________________end_asian_handicap_away_min_075 = '4.10',
#   ____________________________end_asian_handicap_home_min_1 = '1.27',
#   ____________________________end_asian_handicap_away_min_1 = '3.55',
#   ____________________________end_asian_handicap_home_min_15 = '1.63',
#   ____________________________end_asian_handicap_away_min_15 = '2.25',
#   ____________________________end_asian_handicap_home_min_125 = '1.45',
#   ____________________________end_asian_handicap_away_min_125 = '2.67',
#   ____________________________end_asian_handicap_home_min_175 = '1.83',
#   ____________________________end_asian_handicap_away_min_175 = '2.02',
#   ____________________________end_asian_handicap_home_min_2 = '2.08',
#   ____________________________end_asian_handicap_away_min_2 = '1.73',
#   ____________________________end_asian_handicap_home_min_3 = '4.25',
#   ____________________________end_asian_handicap_away_min_3 = '1.21',
#   ____________________________end_asian_handicap_home_min_25 = '2.67',
#   ____________________________end_asian_handicap_away_min_25 = '1.45',
#   ____________________________end_asian_handicap_home_min_225 = '2.38',
#   ____________________________end_asian_handicap_away_min_225 = '1.55',
#   ____________________________end_asian_handicap_home_min_275 = '3.30',
#   ____________________________end_asian_handicap_away_min_275 = '1.32',
#   ____________________________end_asian_handicap_home_min_325 = '4.50',
#   ____________________________end_asian_handicap_away_min_325 = '1.19',
#   ____________________________end_asian_handicap_home_min_375 = '6.60',
#   ____________________________end_asian_handicap_away_min_375 = '1.11',
#   ____________________________end_asian_handicap_home_min_35 = '5.25',
#   ____________________________end_asian_handicap_away_min_35 = '1.16',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '3.00',
#   ____________________________end_goals_overunder_under_35 = '1.36',
#   ____________________________end_goals_overunder_over_15 = '1.25',
#   ____________________________end_goals_overunder_under_15 = '3.75',
#   ____________________________end_goals_overunder_over_45 = '6.00',
#   ____________________________end_goals_overunder_under_45 = '1.13',
#   ____________________________end_goals_overunder_over_25 = '1.80',
#   ____________________________end_goals_overunder_under_25 = '2.00',
#   ____________________________end_goals_overunder_over_05 = '1.04',
#   ____________________________end_goals_overunder_under_05 = '13.00',
#   ____________________________end_goals_overunder_over_55 = '13.00',
#   ____________________________end_goals_overunder_under_55 = '1.04',
#   ____________________________end_goals_overunder_over_225 = '1.60',
#   ____________________________end_goals_overunder_under_225 = '2.30',
#   ____________________________end_goals_overunder_over_325 = '2.67',
#   ____________________________end_goals_overunder_under_325 = '1.45',
#   ____________________________end_goals_overunder_over_275 = '2.02',
#   ____________________________end_goals_overunder_under_275 = '1.77',
#   ____________________________end_goals_overunder_over_125 = '1.15',
#   ____________________________end_goals_overunder_under_125 = '5.50',
#   ____________________________end_goals_overunder_over_425 = '5.50',
#   ____________________________end_goals_overunder_under_425 = '1.15',
#   ____________________________end_goals_overunder_over_175 = '1.30',
#   ____________________________end_goals_overunder_under_175 = '3.45',
#   ____________________________end_goals_overunder_over_375 = '3.55',
#   ____________________________end_goals_overunder_under_375 = '1.27',
#   ____________________________end_goals_overunder_over_475 = '7.00',
#   ____________________________end_goals_overunder_under_475 = '1.10',
#   ____________________________end_goals_overunder_over_65 = '26.00',
#   ____________________________end_goals_overunder_under_65 = '1.01',
#   ____________________________end_goals_overunder_over_75 = '51.00',
#   ____________________________end_goals_overunder_under_75 = '1.00',
#   ____________________________end_goals_overunder_over_30 = '2.38',
#   ____________________________end_goals_overunder_under_30 = '1.55',
#   ____________________________end_goals_overunder_over_20 = '1.38',
#   ____________________________end_goals_overunder_under_20 = '3.00',
#   ____________________________end_goals_overunder_over_40 = '5.00',
#   ____________________________end_goals_overunder_under_40 = '1.17',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '19.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.02',
#   ____________________________end_goals_overunder_first_half_over_15 = '2.63',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.44',
#   ____________________________end_goals_overunder_first_half_over_25 = '7.00',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.10',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.36',
#   ____________________________end_goals_overunder_first_half_under_05 = '3.00',
#   ____________________________end_goals_overunder_first_half_over_225 = '5.90',
#   ____________________________end_goals_overunder_first_half_under_225 = '1.13',
#   ____________________________end_goals_overunder_first_half_over_125 = '2.20',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.65',
#   ____________________________end_goals_overunder_first_half_over_175 = '3.45',
#   ____________________________end_goals_overunder_first_half_under_175 = '1.30',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.50',
#   ____________________________end_goals_overunder_first_half_under_075 = '2.50',
#   ____________________________end_goals_overunder_first_half_over_20 = '5.50',
#   ____________________________end_goals_overunder_first_half_under_20 = '1.15',
#   ____________________________end_goals_overunder_first_half_over_10 = '1.77',
#   ____________________________end_goals_overunder_first_half_under_10 = '2.10',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '11.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.05',
#   ____________________________end_goals_overunder__second_half_over_15 = '2.00',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.73',
#   ____________________________end_goals_overunder__second_half_over_25 = '4.33',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.20',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.22',
#   ____________________________end_goals_overunder__second_half_under_05 = '4.00',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________end_clean_sheet__home_yes = '1.40',
#   ____________________________end_clean_sheet__home_no = '2.75',
#   __________________________28 Clean Sheet - Away
#   ____________________________end_clean_sheet__away_yes = '9.00',
#   ____________________________end_clean_sheet__away_no = '1.07',
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '3.25',
#   ____________________________end_both_teams_score_no = '1.33',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 1.62
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 2.63
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.44
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 8.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 2.88
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 251.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 6:0 --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 351.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.02',
#   ____________________________end_double_chance_home_away = '1.11',
#   ____________________________end_double_chance_draw_away = '4.50',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '1.62',
#   ____________________________end_first_half_winner_draw = '2.60',
#   ____________________________end_first_half_winner_away = '15.00',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 7.50
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 7.50
#   __________________________32 Win Both Halves
#   ____________________________end_win_both_halves_home = '2.38',
#   ____________________________end_win_both_halves_away = '101.00',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.62
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 5.5 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 5.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 6.5 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 6.5 --- bets_odd: 1.00
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.00
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 3.60
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 2.63
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 4.75
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.05
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________end_win_to_nil_home = '1.53',
#   ____________________________end_win_to_nil_away = '21.00',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.73
#   __________________________39 To Win Either Half
#   ____________________________end_to_win_either_half_home = '1.13',
#   ____________________________end_to_win_either_half_away = '7.00',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________24 Results/Both Teams Score
#   ____________________________end_results_both_teams_score_home_yes = '4.33',
#   ____________________________end_results_both_teams_score_draw_yes = '10.00',
#   ____________________________end_results_both_teams_score_away_yes = '34.00',
#   ____________________________end_results_both_teams_score_home_no = '1.53',
#   ____________________________end_results_both_teams_score_draw_no = '10.00',
#   ____________________________end_results_both_teams_score_away_no = '21.00',
#   __________________________25 Result/Total Goals
#   ____________________________end_result_total_goals_home_over_25 = '1.91',
#   ____________________________end_result_total_goals_draw_over_25 = '41.00',
#   ____________________________end_result_total_goals_away_over_25 = '34.00',
#   ____________________________end_result_total_goals_home_under_25 = '2.75',
#   ____________________________end_result_total_goals_draw_under_25 = '6.50',
#   ____________________________end_result_total_goals_away_under_25 = '21.00',
#   __________________________43 Home Team Score a Goal
#   ______________________  ______________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 43 --- bets_value: No --- bets_odd: 9.00
#   __________________________44 Away Team Score a Goal
#   ______________________  ______________________bet_id: 44 --- bets_value: Yes --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 44 --- bets_value: No --- bets_odd: 1.40
#   __________________________54 First 10 min Winner
#   ______________________  ______________________bet_id: 54 --- bets_value: Home --- bets_odd: 4.75
#   ______________________  ______________________bet_id: 54 --- bets_value: Draw --- bets_odd: 1.17
#   ______________________  ______________________bet_id: 54 --- bets_value: Away --- bets_odd: 21.00
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 8.5 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 8.5 --- bets_odd: 2.00
#   __________________________47 Winning Margin
#   ______________________  ______________________bet_id: 47 --- bets_value: Draw --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 251.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 11.00
#   __________________________48 To Score In Both Halves By Teams
#   __________________________49 Total Goals/Both Teams To Score
#   ____________________________end_total_goals_both_teams_to_score_over_yes_25 = '3.75',
#   ____________________________end_total_goals_both_teams_to_score_over_no_25 = '3.10',
#   ____________________________end_total_goals_both_teams_to_score_under_yes_25 = '15.00',
#   ____________________________end_total_goals_both_teams_to_score_under_no_25 = '2.20',
#   __________________________91 Total Goals (3 way)
#   ______________________  ______________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 3.00
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.38
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.26
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 3.70
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.5 --- bets_odd: 5.75
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.5 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 1.83
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 2.02
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.38
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.55
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.17
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.60
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 2.30
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 2.67
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.45
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.02
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.77
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.15
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.25 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.25 --- bets_odd: 1.15
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 3.45
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 3.55
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.27
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.75 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.75 --- bets_odd: 1.10
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 2.67
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.45
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2.5 --- bets_odd: 6.60
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2.5 --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.5 --- bets_odd: 1.35
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.5 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.15
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 5.90
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.65
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 3.45
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.77
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.50
#   __________________________52 Halftime Result/Both Teams Score
#   __________________________59 Own Goal
#   ______________________  ______________________bet_id: 59 --- bets_value: Yes --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 59 --- bets_value: No --- bets_odd: 1.05
#   __________________________92 Anytime Goal Scorer
#   __________________________93 First Goal Scorer
#   __________________________94 Last Goal Scorer
#   __________________________95 To Score Two or More Goals
#   __________________________96 Last Goal Scorer
#   __________________________85 Total Corners (3 way)
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 9 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 9 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 9 --- bets_odd: 8.00
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   __________________________74 10 Over/Under
#   __________________________78 RTG_H1
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 3.25
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 2.88
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 15.00
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ______________________2. World,  Friendlies  #10 - 2023 / 1012368
#   ______________________good to Go 1
#   ____________________________1 Match Winner
#   ______________________________end_match_winner_home = '1.40',
#   ______________________________end_match_winner_draw = '4.00',
#   ______________________________end_match_winner_away = '6.50',
#   ____________________________2 Home/Away
#   ______________________________end_homeaway_home = '1.14',
#   ______________________________end_homeaway_away = '5.50',
#   ____________________________4 Asian Handicap
#   ______________________________end_asian_handicap_home_min_075 = '1.80',
#   ______________________________end_asian_handicap_away_min_075 = '2.05',
#   ______________________________end_asian_handicap_home_min_125 = '2.00',
#   ______________________________end_asian_handicap_away_min_125 = '1.85',
#   ____________________________5 Goals Over/Under
#   ______________________________end_goals_overunder_over_25 = '1.60',
#   ______________________________end_goals_overunder_under_25 = '2.30',
#   ______________________________end_goals_overunder_over_325 = '2.02',
#   ______________________________end_goals_overunder_under_325 = '1.83',
#   ______________________________end_goals_overunder_over_30 = '2.00',
#   ______________________________end_goals_overunder_under_30 = '1.85',
#   ____________________________6 Goals Over/Under First Half
#   ______________________________end_goals_overunder_first_half_over_225 = '3.45',
#   ______________________________end_goals_overunder_first_half_under_225 = '1.30',
#   ______________________________end_goals_overunder_first_half_over_275 = '5.25',
#   ______________________________end_goals_overunder_first_half_under_275 = '1.16',
#   ______________________________end_goals_overunder_first_half_over_125 = '2.02',
#   ______________________________end_goals_overunder_first_half_under_125 = '1.83',
#   ______________________________end_goals_overunder_first_half_over_175 = '2.30',
#   ______________________________end_goals_overunder_first_half_under_175 = '1.60',
#   ______________________________end_goals_overunder_first_half_over_075 = '1.25',
#   ______________________________end_goals_overunder_first_half_under_075 = '3.80',
#   ______________________________end_goals_overunder_first_half_over_20 = '3.00',
#   ______________________________end_goals_overunder_first_half_under_20 = '1.38',
#   ______________________________end_goals_overunder_first_half_over_10 = '1.35',
#   ______________________________end_goals_overunder_first_half_under_10 = '3.10',
#   ____________________________7 HT/FT Double
#   ____________________________10 Exact Score
#   ____________________________31 Correct Score - First Half
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.60
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 7.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 17.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 19.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 101.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 301.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 151.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 301.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 351.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 29.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 101.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 251.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 34.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 101.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 251.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 201.00
#   ____________________________12 Double Chance
#   ______________________________end_double_chance_home_draw = '1.10',
#   ______________________________end_double_chance_home_away = '1.20',
#   ______________________________end_double_chance_draw_away = '2.63',
#   ____________________________13 First Half Winner
#   ______________________________end_first_half_winner_home = '1.95',
#   ______________________________end_first_half_winner_draw = '2.50',
#   ______________________________end_first_half_winner_away = '6.00',
#   ____________________________14 Team To Score First
#   ________________________  ________________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.30
#   ________________________  ________________________bet_id: 14 --- bets_value: Draw --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 14 --- bets_value: Away --- bets_odd: 3.50
#   ____________________________19 Asian Handicap First Half
#   ____________________________20 Double Chance - First Half
#   ____________________________21 Odd/Even
#   ____________________________22 Odd/Even - First Half
#   ________________________  ________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   ________________________  ________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.80
#   ____________________________50 Goal Line
#   ________________________  ________________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 2.13
#   ________________________  ________________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.75
#   ________________________  ________________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 2.00
#   ________________________  ________________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.85
#   ________________________  ________________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 2.02
#   ________________________  ________________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.83
#   ____________________________72 Goal Line (1st Half)
#   ________________________  ________________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 2.10
#   ________________________  ________________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.77
#   ________________________  ________________________bet_id: 72 --- bets_value: Over 2.5 --- bets_odd: 3.90
#   ________________________  ________________________bet_id: 72 --- bets_value: Under 2.5 --- bets_odd: 1.24
#   ________________________  ________________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 3.00
#   ________________________  ________________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.38
#   ________________________  ________________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 3.45
#   ________________________  ________________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.30
#   ________________________  ________________________bet_id: 72 --- bets_value: Over 2.75 --- bets_odd: 5.25
#   ________________________  ________________________bet_id: 72 --- bets_value: Under 2.75 --- bets_odd: 1.16
#   ________________________  ________________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.02
#   ________________________  ________________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.83
#   ________________________  ________________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 2.30
#   ________________________  ________________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.60
#   ________________________  ________________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.35
#   ________________________  ________________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 3.10
#   ________________________  ________________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.25
#   ________________________  ________________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 3.80
#   ________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   __________________________ff_update_unfinished__
#   ________________________  > No longer get supported
#   ____________2. 2023-03-22 // 36 // 0 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 60
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-22
#   __________________bookmaker : 0
#   __________________season : 2023
#   __________________league : 36
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________3. 2023-03-22 // 42 // 8 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 58
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 42
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. England,  League Two  #42 - 2022 / 876311
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.83',
#   ____________________________end_match_winner_draw = '3.60',
#   ____________________________end_match_winner_away = '4.33',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '1.33',
#   ____________________________end_homeaway_away = '3.25',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '2.10',
#   ____________________________end_second_half_winner_draw = '2.40',
#   ____________________________end_second_half_winner_away = '4.33',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.35',
#   ____________________________end_asian_handicap_away_plus_0 = '3.10',
#   ____________________________end_asian_handicap_home_min_025 = '1.58',
#   ____________________________end_asian_handicap_away_min_025 = '2.35',
#   ____________________________end_asian_handicap_home_plus_025 = '1.27',
# ...
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.39
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 8.90
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.13
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 7.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -5 --- bets_odd: 19.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -5 --- bets_odd: 1.02
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -5 --- bets_odd: 13.00
#   ____________________________10 Exact Score
#   ____________________________11 Highest Scoring Half
#   ____________________________31 Correct Score - First Half
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.10
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 5.80
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 17.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 34.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 71.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 36.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 61.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 71.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.80
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 10.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 91.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 91.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 91.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   ____________________________62 Correct Score - Second Half
#   ________________________  ________________________bet_id: 62 --- bets_value: 1:0 --- bets_odd: 3.60
#   ________________________  ________________________bet_id: 62 --- bets_value: 2:0 --- bets_odd: 5.50
#   ________________________  ________________________bet_id: 62 --- bets_value: 2:1 --- bets_odd: 12.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 3:0 --- bets_odd: 11.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 3:1 --- bets_odd: 23.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 3:2 --- bets_odd: 56.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 4:0 --- bets_odd: 29.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 4:1 --- bets_odd: 46.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 4:2 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 4:3 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 5:0 --- bets_odd: 56.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 5:1 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 5:2 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 5:3 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 5:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 0:0 --- bets_odd: 5.30
#   ________________________  ________________________bet_id: 62 --- bets_value: 1:1 --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 2:2 --- bets_odd: 36.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 3:3 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 4:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 0:1 --- bets_odd: 11.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 0:2 --- bets_odd: 36.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 0:3 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 0:4 --- bets_odd: 91.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 0:5 --- bets_odd: 91.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 1:2 --- bets_odd: 29.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 1:3 --- bets_odd: 71.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 1:4 --- bets_odd: 91.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 1:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 2:3 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 2:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 2:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 3:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 3:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 4:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 62 --- bets_value: 5:5 --- bets_odd: 100.00
#   ____________________________12 Double Chance
#   ______________________________end_double_chance_home_draw = '1.03',
#   ______________________________end_double_chance_home_away = '1.11',
#   ______________________________end_double_chance_draw_away = '3.64',
#   ____________________________13 First Half Winner
#   ______________________________end_first_half_winner_home = '1.65',
#   ______________________________end_first_half_winner_draw = '2.69',
#   ______________________________end_first_half_winner_away = '7.80',
#   ____________________________16 Total - Home
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 3.24
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.30
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.35
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 3.00
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 5.80
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.10
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 2.05
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.68
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.05
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 1.55
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 2.30
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 3 --- bets_odd: 2.75
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 3 --- bets_odd: 1.40
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 4 --- bets_odd: 4.90
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 4 --- bets_odd: 1.14
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.08
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 6.50
#   ____________________________17 Total - Away
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 5.20
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.12
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 9.70
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.02
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.75
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 1.95
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 7.90
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.05
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 3.50
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 1.25
#   ____________________________18 Handicap Result - First Half
#   ________________________  ________________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 3.48
#   ________________________  ________________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.99
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 2.88
#   ________________________  ________________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.03
#   ________________________  ________________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 26.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 8.50
#   ________________________  ________________________bet_id: 18 --- bets_value: Home +2 --- bets_odd: 1.01
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw +2 --- bets_odd: 21.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Away +2 --- bets_odd: 36.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 8.40
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 5.35
#   ________________________  ________________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.24
#   ________________________  ________________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 21.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 11.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.03
#   ________________________  ________________________bet_id: 18 --- bets_value: Home -4 --- bets_odd: 34.00
#   ________________________  ________________________bet_id: 18 --- bets_value: Away -4 --- bets_odd: 1.01
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw -4 --- bets_odd: 23.00
#   ____________________________19 Asian Handicap First Half
#   ____________________________20 Double Chance - First Half
#   ____________________________33 Double Chance - Second Half
#   ________________________  ________________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.02
#   ________________________  ________________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.23
#   ________________________  ________________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 2.29
#   ____________________________34 Both Teams Score - First Half
#   ____________________________35 Both Teams To Score - Second Half
#   ____________________________21 Odd/Even
#   ____________________________22 Odd/Even - First Half
#   ________________________  ________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 1.92
#   ________________________  ________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.75
#   ____________________________23 Home Odd/Even
#   ________________________  ________________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.83
#   ________________________  ________________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.83
#   ____________________________60 Away Odd/Even
#   ________________________  ________________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.30
#   ________________________  ________________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.52
#   ____________________________45 Corners Over Under
#   ________________________  ________________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 1.90
#   ________________________  ________________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 1.90
#   ________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   __________________________ff_update_unfinished__
#   ________________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-24 19:29:32

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 19:29:32
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-22
#   ______tgl_akhir : 2023-03-23
#   ________ff_get_fixture_status_match_finished()
#   __________Total Row(s) : 60
#   __________1. 2023-03-22 // 10 // 8 // 2023 // 984804 // 175_15_125_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 984804
#   ____________> end_ah_pattern = 225_2_175_15_H
#   ____________> end_ah_pattern_mirror = 15+175+2+225+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-03-22 // 10 // 8 // 2023 // 1012368 // 125_075_H // 325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1012368
#   ____________> end_ah_pattern = 125_075_H
#   ____________> end_ah_pattern_mirror = 075+125+H
#   ____________> end_gou_pattern = 25g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-03-22 // 42 // 8 // 2022 // 876311 // 1_075_05_025_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 876311
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________4. 2023-03-22 // 128 // 8 // 2023 // 971435 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971435
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________5. 2023-03-22 // 146 // 11 // 2022 // 1010514 // 025+075+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010514
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________6. 2023-03-22 // 167 // 11 // 2023 // 1010597 // H // 35g45gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010597
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 325g35g375g4g425g45gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________7. 2023-03-22 // 243 // 11 // 2023 // 1011779 // 025_0#025+H // 225g25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011779
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________8. 2023-03-22 // 243 // 11 // 2023 // 1011780 // 025_0#025+H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011780
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________9. 2023-03-22 // 243 // 11 // 2023 // 1011776 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011776
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________10. 2023-03-23 // 243 // 11 // 2023 // 1011777 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011777
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________11. 2023-03-22 // 263 // 8 // 2022 // 975962 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975962
#   ____________> end_ah_pattern = 05_H
#   ____________> end_ah_pattern_mirror = 05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________12. 2023-03-22 // 263 // 8 // 2022 // 975963 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975963
#   ____________> end_ah_pattern = 025_H
#   ____________> end_ah_pattern_mirror = 025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________13. 2023-03-22 // 263 // 8 // 2022 // 975964 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975964
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________14. 2023-03-22 // 263 // 8 // 2022 // 975965 // 025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975965
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________15. 2023-03-22 // 287 // 11 // 2022 // 869175 // 075_025_H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 869175
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________16. 2023-03-22 // 287 // 11 // 2022 // 869179 // 175_15_125_1_075_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 869179
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________17. 2023-03-22 // 287 // 11 // 2022 // 869180 // 1_075_025_H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 869180
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________18. 2023-03-22 // 487 // 11 // 2022 // 941785 // 1+125+15+175+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 941785
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________19. 2023-03-22 // 487 // 11 // 2022 // 941811 // 1_075_025_H // 225g25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 941811
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________20. 2023-03-22 // 487 // 11 // 2022 // 941819 // 15_125_1_075_H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 941819
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________21. 2023-03-22 // 510 // 11 // 2022 // 898490 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 898490
#   ____________> end_ah_pattern = 2_175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+2+H
#   ____________> end_gou_pattern = 3g325g35g375g4gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________22. 2023-03-22 // 510 // 11 // 2022 // 898494 // 075_025_0#025+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 898494
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________23. 2023-03-22 // 525 // 11 // 2022 // 1004755 // 075_025_0#H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1004755
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________24. 2023-03-22 // 525 // 11 // 2022 // 1004757 // 0#025+075+H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1004757
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________25. 2023-03-22 // 604 // 8 // 2023 // 1015131 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1015131
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 15gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________26. 2023-03-22 // 604 // 8 // 2023 // 1015125 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1015125
#   ____________> end_ah_pattern = 025_H
#   ____________> end_ah_pattern_mirror = 025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________27. 2023-03-22 // 701 // 11 // 2022 // 992372 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992372
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________28. 2023-03-22 // 701 // 11 // 2022 // 992389 // 125_1_075_025_H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992389
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________29. 2023-03-22 // 740 // 11 // 2023 // 1010648 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010648
#   ____________> end_ah_pattern = 075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________30. 2023-03-22 // 740 // 11 // 2023 // 1010649 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010649
#   ____________> end_ah_pattern = 225_2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+225+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________31. 2023-03-22 // 740 // 11 // 2023 // 1010655 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010655
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________32. 2023-03-22 // 744 // 11 // 2022 // 908105 // 2_175_15_125_1_075_H // 325g35g375g4g425g45gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 908105
#   ____________> end_ah_pattern = 2_175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+2+H
#   ____________> end_gou_pattern = 325g35g375g4g425g45gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________33. 2023-03-22 // 747 // 11 // 2022 // 906758 // 075_025_0#H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906758
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________34. 2023-03-22 // 750 // 11 // 2022 // 907439 // 025_0#025+H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 907439
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________35. 2023-03-22 // 751 // 11 // 2022 // 906469 // 175+2+225+25+275+H // 275g3g325g35g375g4gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906469
#   ____________> end_ah_pattern = 15+175+2+225+25+275+H
#   ____________> end_ah_pattern_mirror = 275_25_225_2_175_15_H
#   ____________> end_gou_pattern = 3g325g35g375g4gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________36. 2023-03-22 // 751 // 11 // 2022 // 906470 // 025_0#025+H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906470
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________37. 2023-03-22 // 751 // 11 // 2022 // 906471 // 075_025_0#H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906471
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________38. 2023-03-22 // 751 // 11 // 2022 // 906472 // 025+075+1+125+H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906472
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________39. 2023-03-22 // 751 // 11 // 2022 // 906473 // 075+1+125+15+H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906473
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________40. 2023-03-22 // 751 // 11 // 2022 // 906474 // 15_125_1_075_H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906474
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________41. 2023-03-22 // 751 // 11 // 2022 // 906475 // 15_125_1_075_H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906475
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________42. 2023-03-22 // 751 // 11 // 2022 // 906476 // 075+1+125+15+H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906476
#   ____________> end_ah_pattern = 025+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_025_H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________43. 2023-03-22 // 751 // 11 // 2022 // 906477 // 0#025+075+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906477
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________44. 2023-03-22 // 751 // 11 // 2022 // 906478 // 125_1_075_025_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906478
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________45. 2023-03-22 // 782 // 11 // 2022 // 921228 // 025+1+H // 25g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 921228
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 25g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________46. 2023-03-22 // 782 // 11 // 2022 // 968702 // 075_025_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 968702
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________47. 2023-03-22 // 893 // 11 // 2023 // 978664 // 0#025+075+H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978664
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________48. 2023-03-22 // 893 // 11 // 2023 // 978665 // 25_225_2_175_15_H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978665
#   ____________> end_ah_pattern = 275_25_225_2_175_H
#   ____________> end_ah_pattern_mirror = 175+2+225+25+275+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________49. 2023-03-22 // 893 // 11 // 2023 // 978666 // 0#025+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978666
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________50. 2023-03-22 // 893 // 11 // 2023 // 978668 // 275_25_225_2_175_15_H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978668
#   ____________> end_ah_pattern = 275_25_225_2_175_15_H
#   ____________> end_ah_pattern_mirror = 15+175+2+225+25+275+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________51. 2023-03-22 // 893 // 11 // 2023 // 978669 // 1_075_025_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978669
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________52. 2023-03-22 // 893 // 11 // 2023 // 978671 // 125_1_075_025_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978671
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________53. 2023-03-22 // 893 // 11 // 2023 // 978672 // 175_15_125_1_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978672
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________54. 2023-03-22 // 893 // 11 // 2023 // 978673 // 15_125_1_075_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978673
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________55. 2023-03-22 // 893 // 11 // 2023 // 978674 // 175_15_125_1_075_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978674
#   ____________> end_ah_pattern = 225_2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+225+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________56. 2023-03-22 // 893 // 11 // 2023 // 978676 // 075_025_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978676
#   ____________> end_ah_pattern = 125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________57. 2023-03-22 // 893 // 11 // 2023 // 978677 // 125+15+175+2+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978677
#   ____________> end_ah_pattern = 15+175+2+225+25+H
#   ____________> end_ah_pattern_mirror = 25_225_2_175_15_H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________58. 2023-03-22 // 893 // 11 // 2023 // 978667 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978667
#   ____________> end_ah_pattern = 2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________59. 2023-03-22 // 893 // 11 // 2023 // 978670 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978670
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________60. 2023-03-22 // 893 // 11 // 2023 // 978675 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 978675
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
# # -------------------------------------------------- End at 2023-03-24 19:34:42

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 19:34:42
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-22
#   ______tgl_akhir : 2023-03-23
#   ________ff_get_fixture_status_match_finished_for_daily_update_patternlist()
#   ________Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date <= '2023-03-23'  and date >= '2023-03-22'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 59
#   ____________[1/59] #876311 #England 42-2022 / Mansfield Town vs Grimsby
#   ____________pre-ah:1_075_05_025_H -- pre-gou:225g25g275gG -/- end-ah:075_05_025_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:25:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '42'  and league_country = 'England'  and pre_ah_pattern = '1_075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+1+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[2/59] #869175 #Serbia 287-2022 / FK Trayal vs Radnički Novi Beograd
#   ____________pre-ah:075_025_H -- pre-gou:15g175g2g225gG -/- end-ah:075_025_H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:49
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '287'  and league_country = 'Serbia'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '15g175g2g225gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[3/59] #869179 #Serbia 287-2022 / IMT Novi Beograd vs Macva
#   ____________pre-ah:175_15_125_1_075_H -- pre-gou:2g225g25g275gG -/- end-ah:175_15_125_1_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '287'  and league_country = 'Serbia'  and pre_ah_pattern = '175_15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+175+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[4/59] #869180 #Serbia 287-2022 / RAD vs Loznica
#   ____________pre-ah:1_075_025_H -- pre-gou:175g2g225g25gG -/- end-ah:1_075_025_H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:55
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '287'  and league_country = 'Serbia'  and pre_ah_pattern = '1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[5/59] #906469 #Germany 751-2022 / FSV Duisburg vs Hilden
#   ____________pre-ah:175+2+225+25+275+H -- pre-gou:275g3g325g35g375g4gG -/- end-ah:15+175+2+225+25+275+H -- end-gou:3g325g35g375g4gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '751'  and league_country = 'Germany'  and pre_ah_pattern = '175+2+225+25+275+H'  and pre_ah_pattern_mirror = '275_25_225_2_175_H'  and pre_gou_pattern = '275g3g325g35g375g4gG'  and end_ah_pattern = '15+175+2+225+25+275+H'  and end_ah_pattern_mirror = '275_25_225_2_175_15_H'  and end_gou_pattern = '3g325g35g375g4gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[6/59] #906470 #Germany 751-2022 / TVD Velbert vs SW Essen
#   ____________pre-ah:025_0#025+H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:025_0#025+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:21
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '751'  and league_country = 'Germany'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[7/59] #906471 #Germany 751-2022 / SF Baumberg vs Homberg
#   ____________pre-ah:075_025_0#H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:075_025_0#025+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:13
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '751'  and league_country = 'Germany'  and pre_ah_pattern = '075_025_0#H'  and pre_ah_pattern_mirror = '0#025+075+H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '075_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+075+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[8/59] #906472 #Germany 751-2022 / Union Nettetal vs Meerbusch
#   ____________pre-ah:025+075+1+125+H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:075+1+125+15+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:24
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '751'  and league_country = 'Germany'  and pre_ah_pattern = '025+075+1+125+H'  and pre_ah_pattern_mirror = '125_1_075_025_H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '075+1+125+15+H'  and end_ah_pattern_mirror = '15_125_1_075_H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[9/59] #906473 #Germany 751-2022 / SC St. Tönis vs SSVg Velbert
#   ____________pre-ah:075+1+125+15+H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:075+1+125+15+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:34
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '751'  and league_country = 'Germany'  and pre_ah_pattern = '075+1+125+15+H'  and pre_ah_pattern_mirror = '15_125_1_075_H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '075+1+125+15+H'  and end_ah_pattern_mirror = '15_125_1_075_H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[10/59] #906474 #Germany 751-2022 / Germania Ratingen vs SF Hamborn
#   ____________pre-ah:15_125_1_075_H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:10
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '751'  and league_country = 'Germany'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[11/59] #906475 #Germany 751-2022 / MSV Düsseldorf vs Kray
#   ____________pre-ah:15_125_1_075_H -- pre-gou:275g3g325g35g375gG -/- end-ah:15_125_1_075_H -- end-gou:275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:26
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '751'  and league_country = 'Germany'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[12/59] #906476 #Germany 751-2022 / Cronenberger SC vs Monheim
#   ____________pre-ah:075+1+125+15+H -- pre-gou:275g3g325g35g375gG -/- end-ah:025+075+1+125+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '751'  and league_country = 'Germany'  and pre_ah_pattern = '075+1+125+15+H'  and pre_ah_pattern_mirror = '15_125_1_075_H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '025+075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_025_H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[13/59] #906477 #Germany 751-2022 / Sonsbeck vs Kleve
#   ____________pre-ah:0#025+075+H -- pre-gou:25g275g3g325g35gG -/- end-ah:025+075+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:31
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '751'  and league_country = 'Germany'  and pre_ah_pattern = '0#025+075+H'  and pre_ah_pattern_mirror = '075_025_0#H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[14/59] #906478 #Germany 751-2022 / Schonnebeck vs TuRU 1880 Düsseldorf
#   ____________pre-ah:125_1_075_025_H -- pre-gou:25g275g3g325g35gG -/- end-ah:125_1_075_025_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:15
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '751'  and league_country = 'Germany'  and pre_ah_pattern = '125_1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+125+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '125_1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+125+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[15/59] #906758 #Germany 747-2022 / Westfalia Rhynern vs Paderborn II
#   ____________pre-ah:075_025_0#H -- pre-gou:225g25g275g3gG -/- end-ah:075_025_0#025+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:02
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '747'  and league_country = 'Germany'  and pre_ah_pattern = '075_025_0#H'  and pre_ah_pattern_mirror = '0#025+075+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '075_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+075+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[16/59] #907439 #Germany 750-2022 / Neuhof vs Hadamar
#   ____________pre-ah:025_0#025+H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:025_0#025+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:05
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '750'  and league_country = 'Germany'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[17/59] #908105 #Germany 744-2022 / Oldenburger SV vs Dornbreite Lübeck
#   ____________pre-ah:2_175_15_125_1_075_H -- pre-gou:325g35g375g4g425g45gG -/- end-ah:2_175_15_125_1_H -- end-gou:325g35g375g4g425g45gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '744'  and league_country = 'Germany'  and pre_ah_pattern = '2_175_15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+175+2+H'  and pre_gou_pattern = '325g35g375g4g425g45gG'  and end_ah_pattern = '2_175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+2+H'  and end_gou_pattern = '325g35g375g4g425g45gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[18/59] #898490 #Switzerland 510-2022 / Luzern II vs SC Kriens
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:2_175_15_125_1_H -- end-gou:3g325g35g375g4gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:09
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '510'  and league_country = 'Switzerland'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '2_175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+2+H'  and end_gou_pattern = '3g325g35g375g4gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[19/59] #898494 #Switzerland 510-2022 / Rapperswil vs Baden
#   ____________pre-ah:075_025_0#025+H -- pre-gou:25g275g3g325g35gG -/- end-ah:075_025_0#025+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '510'  and league_country = 'Switzerland'  and pre_ah_pattern = '075_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+075+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '075_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+075+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[20/59] #941785 #Belgium 487-2022 / Rupel Boom vs Francs Borains
#   ____________pre-ah:1+125+15+175+H -- pre-gou:25g275g3g325g35gG -/- end-ah:075+1+125+15+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:59
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '487'  and league_country = 'Belgium'  and pre_ah_pattern = '1+125+15+175+H'  and pre_ah_pattern_mirror = '175_15_125_1_H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '075+1+125+15+H'  and end_ah_pattern_mirror = '15_125_1_075_H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[21/59] #941811 #Belgium 487-2022 / Thes Sport vs Sporting Charleroi II
#   ____________pre-ah:1_075_025_H -- pre-gou:225g25g275g3g325g35gG -/- end-ah:1_075_025_H -- end-gou:225g25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '487'  and league_country = 'Belgium'  and pre_ah_pattern = '1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+H'  and pre_gou_pattern = '225g25g275g3g325g35gG'  and end_ah_pattern = '1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+H'  and end_gou_pattern = '225g25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[22/59] #941819 #Belgium 487-2022 / Liège vs URSL Visé
#   ____________pre-ah:15_125_1_075_H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:02
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '487'  and league_country = 'Belgium'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[23/59] #968702 #Poland 782-2022 / Polonia Bytom vs Rekord Bielsko-Biała
#   ____________pre-ah:075_025_H -- pre-gou:25g275g3g325g35gG -/- end-ah:075_025_H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-15 08:10:31
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '782'  and league_country = 'Poland'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[24/59] #975962 #Mexico 263-2022 / Mineros de Zacatecas vs Alebrijes de Oaxaca
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:34
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_H'  and end_ah_pattern_mirror = '05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[25/59] #975963 #Mexico 263-2022 / Cimarrones vs Celaya
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_H'  and end_ah_pattern_mirror = '025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 6
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 6
#   ____________________patternlists updated
#
#   ____________[26/59] #975964 #Mexico 263-2022 / CA La Paz vs Dorados
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:1_075_05_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[27/59] #975965 #Mexico 263-2022 / Durango vs Pumas Tabasco
#   ____________pre-ah:025_H -- pre-gou:25gG -/- end-ah:075_05_025_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = '025_H'  and pre_ah_pattern_mirror = '025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[28/59] #971435 #Argentina 128-2023 / Velez Sarsfield vs Central Cordoba de Santiago
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:1_075_05_H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:53:53
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '128'  and league_country = 'Argentina'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[29/59] #992372 #Portugal 701-2022 / Marítimo U23 vs Portimonense U23
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_0#025+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:36
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '701'  and league_country = 'Portugal'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[30/59] #992389 #Portugal 701-2022 / Leixões U23 vs Mafra U23
#   ____________pre-ah:125_1_075_025_H -- pre-gou:225g25g275g3g325gG -/- end-ah:125_1_075_025_H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:42
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '701'  and league_country = 'Portugal'  and pre_ah_pattern = '125_1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+125+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '125_1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+125+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[31/59] #984804 #World 10-2023 / Rep. Of Ireland vs Latvia
#   ____________pre-ah:175_15_125_H -- pre-gou:225g25g275gG -/- end-ah:225_2_175_15_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:25:48
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '10'  and league_country = 'World'  and pre_ah_pattern = '175_15_125_H'  and pre_ah_pattern_mirror = '125+15+175+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '225_2_175_15_H'  and end_ah_pattern_mirror = '15+175+2+225+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[32/59] #978664 #World 893-2023 / Iceland U19 vs Turkey U19
#   ____________pre-ah:0#025+075+H -- pre-gou:225g25g275g3g325gG -/- end-ah:025+075+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = '0#025+075+H'  and pre_ah_pattern_mirror = '075_025_0#H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[33/59] #978665 #World 893-2023 / England U19 vs Hungary U19
#   ____________pre-ah:25_225_2_175_15_H -- pre-gou:275g3g325g35g375gG -/- end-ah:275_25_225_2_175_H -- end-gou:275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:29:11
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = '25_225_2_175_15_H'  and pre_ah_pattern_mirror = '15+175+2+225+25+H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '275_25_225_2_175_H'  and end_ah_pattern_mirror = '175+2+225+25+275+H'  and end_gou_pattern = '275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[34/59] #978666 #World 893-2023 / Israel U19 vs Poland U19
#   ____________pre-ah:0#025+H -- pre-gou:225g25g275g3gG -/- end-ah:0#025+075+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:50
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = '0#025+H'  and pre_ah_pattern_mirror = '025_0#H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[35/59] #978668 #World 893-2023 / France U19 vs Northern Ireland U19
#   ____________pre-ah:275_25_225_2_175_15_H -- pre-gou:275g3g325g35g375gG -/- end-ah:275_25_225_2_175_15_H -- end-gou:275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:29:09
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = '275_25_225_2_175_15_H'  and pre_ah_pattern_mirror = '15+175+2+225+25+275+H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '275_25_225_2_175_15_H'  and end_ah_pattern_mirror = '15+175+2+225+25+275+H'  and end_gou_pattern = '275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[36/59] #978669 #World 893-2023 / Norway U19 vs Romania U19
#   ____________pre-ah:1_075_025_H -- pre-gou:2g225g25g275gG -/- end-ah:1_075_025_H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:53
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = '1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[37/59] #978671 #World 893-2023 / Belgium U19 vs Slovenia U19
#   ____________pre-ah:125_1_075_025_H -- pre-gou:25g275g3g325g35gG -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:29:04
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = '125_1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+125+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[38/59] #978672 #World 893-2023 / Ukraine U19 vs Luxembourg U19
#   ____________pre-ah:175_15_125_1_H -- pre-gou:25g275g3g325g35gG -/- end-ah:175_15_125_1_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:29:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = '175_15_125_1_H'  and pre_ah_pattern_mirror = '1+125+15+175+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[39/59] #978673 #World 893-2023 / Denmark U19 vs Spain U19
#   ____________pre-ah:15_125_1_075_H -- pre-gou:25g275g3g325g35gG -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[40/59] #978674 #World 893-2023 / Portugal U19 vs Sweden U19
#   ____________pre-ah:175_15_125_1_075_H -- pre-gou:25g275g3g325g35gG -/- end-ah:225_2_175_15_125_H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:29:29
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = '175_15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+175+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '225_2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+225+H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[41/59] #978676 #World 893-2023 / Republic of Ireland U19 vs Slovakia U19
#   ____________pre-ah:075_025_H -- pre-gou:225g25g275g3gG -/- end-ah:125_1_075_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:29:23
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[42/59] #978677 #World 893-2023 / Estonia U19 vs Greece U19
#   ____________pre-ah:125+15+175+2+H -- pre-gou:25g275g3g325g35gG -/- end-ah:15+175+2+225+25+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:29:26
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
# ...
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[45/59] #1010514 #Belgium 146-2022 / Standard Liege W vs Anderlecht W
#   ____________pre-ah:025+075+H -- pre-gou:25g275g3g325g35gG -/- end-ah:0#025+075+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '146'  and league_country = 'Belgium'  and pre_ah_pattern = '025+075+H'  and pre_ah_pattern_mirror = '075_025_H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[46/59] #1010597 #Iceland 167-2023 / Ellidi vs Árborg
#   ____________pre-ah:H -- pre-gou:35g45gG -/- end-ah:175_15_125_1_075_H -- end-gou:325g35g375g4g425g45gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:07
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '167'  and league_country = 'Iceland'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '35g45gG'  and end_ah_pattern = '175_15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+175+H'  and end_gou_pattern = '325g35g375g4g425g45gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[47/59] #1011779 #Ecuador 243-2023 / Vargas Torres vs Manta FC
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275g3g325g35gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:23
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '243'  and league_country = 'Ecuador'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275g3g325g35gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[48/59] #1011780 #Ecuador 243-2023 / Guayaquil vs 9 de Octubre
#   ____________pre-ah:025_0#025+H -- pre-gou:15g175g2g225g25gG -/- end-ah:025_0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:28
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '243'  and league_country = 'Ecuador'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '15g175g2g225g25gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[49/59] #1012368 #World 10-2023 / Bhutan vs Laos
#   ____________pre-ah:125_075_H -- pre-gou:325gG -/- end-ah:125_075_H -- end-gou:25g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:25:50
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '10'  and league_country = 'World'  and pre_ah_pattern = '125_075_H'  and pre_ah_pattern_mirror = '075+125+H'  and pre_gou_pattern = '325gG'  and end_ah_pattern = '125_075_H'  and end_ah_pattern_mirror = '075+125+H'  and end_gou_pattern = '25g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[50/59] #1015131 #Brazil 604-2023 / Hercílio Luz vs Figueirense
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05_025_0#H -- end-gou:15gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:31
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '604'  and league_country = 'Brazil'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '15gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[51/59] #1010648 #Brazil 740-2023 / Ceará U20 vs Corinthians U20
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075+1+125+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:45
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[52/59] #1010649 #Brazil 740-2023 / Flamengo U20 vs RB Bragantino U20
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:225_2_175_15_125_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:48
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '225_2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+225+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[53/59] #1010655 #Brazil 740-2023 / Atlético Mineiro U20 vs Botafogo SP U20
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_025_0#H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:53
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_025_0#H'  and end_ah_pattern_mirror = '0#025+075+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[54/59] #978667 #World 893-2023 / Serbia U19 vs Latvia U19
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:2_175_15_125_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:43
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[55/59] #978670 #World 893-2023 / Germany U19 vs Italy U19
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_025_H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:28:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[56/59] #978675 #World 893-2023 / Czech Republic U19 vs Croatia U19
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#025+075+H -- end-gou:225g25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:29:16
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '893'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '225g25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[57/59] #1011776 #Ecuador 243-2023 / Cuniburo vs America de Quito
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025+075+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:19
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '243'  and league_country = 'Ecuador'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[58/59] #1011777 #Ecuador 243-2023 / UT Cotopaxi vs Imbabura
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_025_H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:14
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '243'  and league_country = 'Ecuador'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[59/59] #1015125 #Brazil 604-2023 / Criciuma vs Avai
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:28
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '604'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_H'  and end_ah_pattern_mirror = '025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
# # -------------------------------------------------- End at 2023-03-24 19:49:31
