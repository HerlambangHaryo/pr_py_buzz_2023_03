# %%
# Import
from a_settings.messages import *  

today = datetime.datetime.now()  
days0 = 3
days1 = 2
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 3 - 2 --> 2023-03-24 19:23:51.808872

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 19:23:52
#   __main()
#   ____get_date()
#   ______days : 3
#   ______days : 2
#   ______tgl_awal : 2023-03-21
#   ______tgl_akhir : 2023-03-22
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-22'  and date >= '2023-03-21'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 7
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 43
#   ______________1. 2023-03-21 // 10 // 8 // 2023 // 1013398 // None // None
#   ______________2. 2023-03-21 // 10 // 8 // 2023 // 1016624 // None // None
#   ______________3. 2023-03-21 // 42 // 8 // 2022 // 876355 // 1_075_05_025_H // 175g2g225g25gG
#   ______________4. 2023-03-21 // 42 // 8 // 2022 // 876366 // 05_025_0#025+H // 225g25g275gG
#   ______________5. 2023-03-21 // 42 // 8 // 2022 // 876377 // 05_025_0#H // 2g225g25gG
#   ______________6. 2023-03-21 // 51 // 8 // 2022 // 891654 // 15_125_1_075_05_1+125+15+H // 25gG
#   ______________7. 2023-03-21 // 51 // 8 // 2022 // 891759 // 05_025_0#025+H // 25gG
#   ______________8. 2023-03-21 // 51 // 8 // 2022 // 891779 // 05_025_0#H // 25gG
#   ______________9. 2023-03-21 // 51 // 8 // 2022 // 891850 // 125_1_075_05_H // 25gG
#   ______________10. 2023-03-21 // 58 // 11 // 2022 // 911066 // 025_0#025+H // 225g25g275g3g325gG
#   ______________11. 2023-03-21 // 58 // 11 // 2022 // 911135 // 025_0#025+H // 25g275g3g325g35gG
#   ______________12. 2023-03-21 // 59 // 11 // 2022 // 911516 // 075_025_0#025+H // 25g275g3g325g35gG
#   ______________13. 2023-03-21 // 59 // 11 // 2022 // 911611 // 075_025_0#H // 225g25g275g3gG
#   ______________14. 2023-03-21 // 82 // 11 // 2022 // 885869 // 025+075+1+125+H // 25g275g3g325g35g375gG
#   ______________15. 2023-03-21 // 85 // 8 // 2022 // 904564 // 15_125_1_075_05_H // 25gG
#   ______________16. 2023-03-21 // 85 // 8 // 2022 // 904605 // 225_2_175_15_H // 25g35gG
#   ______________17. 2023-03-21 // 85 // 8 // 2022 // 904606 // 1_075_05_025_H // 25gG
#   ______________18. 2023-03-21 // 91 // 11 // 2022 // 913335 // 575_55_525_5_475_H // 525g55g575g6g625g65g675gG
#   ______________19. 2023-03-21 // 122 // 8 // 2022 // 884160 // 15_125_1_075_H // 25gG
#   ______________20. 2023-03-21 // 128 // 8 // 2023 // 971442 // H // G
#   ______________21. 2023-03-21 // 128 // 8 // 2023 // 971445 // H // G
#   ______________22. 2023-03-21 // 146 // 11 // 2022 // 1010512 // 025_0#H // 25g3gG
#   ______________23. 2023-03-21 // 146 // 11 // 2022 // 1010513 // 35_325_H // 4gG
#   ______________24. 2023-03-21 // 146 // 11 // 2022 // 1010541 // 0#025+H // 25g3gG
#   ______________25. 2023-03-21 // 146 // 11 // 2022 // 1010542 // H // 25g3gG
#   ______________26. 2023-03-21 // 184 // 8 // 2022 // 873585 // 1_075_05_025_H // 225g25g275g3gG
#   ______________27. 2023-03-21 // 184 // 8 // 2022 // 873636 // 05_025_0#H // 225g25g275gG
#   ______________28. 2023-03-21 // 242 // 8 // 2023 // 996238 // 1_075_05_H // 2g225g25gG
#   ______________29. 2023-03-22 // 243 // 11 // 2023 // 1011776 // None // None
#   ______________30. 2023-03-21 // 263 // 8 // 2022 // 975961 // 05_H // 25gG
#   ______________31. 2023-03-21 // 525 // 11 // 2022 // 1004751 // 075_025_0#H // 225g25g275g3g325gG
#   ______________32. 2023-03-21 // 525 // 11 // 2022 // 1004753 // 2+225+25+275+3+H // 275g3g325g35g375gG
#   ______________33. 2023-03-22 // 604 // 8 // 2023 // 1015125 // None // None
#   ______________34. 2023-03-21 // 673 // 8 // 2022 // 976344 // H // G
#   ______________35. 2023-03-21 // 740 // 11 // 2023 // 1010652 // 025_0#025+H // 2g225g25g275gG
#   ______________36. 2023-03-21 // 745 // 11 // 2022 // 907837 // 225_2_175_15_125_H // 3g325g35g375g4gG
#   ______________37. 2023-03-21 // 887 // 11 // 2022 // 964802 // H // G
#   ______________38. 2023-03-21 // 887 // 11 // 2022 // 964803 // H // G
#   ______________39. 2023-03-21 // 888 // 11 // 2022 // 965040 // H // G
#   ______________40. 2023-03-21 // 888 // 11 // 2022 // 965041 // H // G
#   ______________41. 2023-03-21 // 888 // 11 // 2022 // 965042 // H // G
#   ______________42. 2023-03-21 // 889 // 11 // 2022 // 965279 // None // None
#   ______________43. 2023-03-21 // 889 // 11 // 2022 // 965283 // None // None
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-03-21 // 10 // 8 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 61
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-21
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 10
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________2. 2023-03-22 // 243 // 11 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 59
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-22
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 243
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 3
#
#   ____________________1. Ecuador,  Liga Pro Serie B  #243 - 2023 / 1011776
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '3.58',
#   ____________________________end_match_winner_draw = '3.22',
#   ____________________________end_match_winner_away = '2.04',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '4.06',
#   ____________________________end_second_half_winner_draw = '2.28',
#   ____________________________end_second_half_winner_away = '2.38',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '2.60',
#   ____________________________end_asian_handicap_away_plus_0 = '1.48',
#   ____________________________end_asian_handicap_home_min_025 = '3.07',
#   ____________________________end_asian_handicap_away_min_025 = '1.36',
#   ____________________________end_asian_handicap_home_plus_025 = '1.99',
#   ____________________________end_asian_handicap_away_plus_025 = '1.71',
#   ____________________________end_asian_handicap_home_min_075 = '4.50',
#   ____________________________end_asian_handicap_away_min_075 = '1.16',
#   ____________________________end_asian_handicap_home_plus_075 = '1.52',
#   ____________________________end_asian_handicap_away_plus_075 = '2.32',
#   ____________________________end_asian_handicap_home_min_1 = '7.10',
#   ____________________________end_asian_handicap_away_min_1 = '1.05',
#   ____________________________end_asian_handicap_home_plus_1 = '1.31',
#   ____________________________end_asian_handicap_away_plus_1 = '3.04',
#   ____________________________end_asian_handicap_home_min_15 = '8.00',
#   ____________________________end_asian_handicap_away_min_15 = '1.03',
#   ____________________________end_asian_handicap_home_plus_15 = '1.20',
#   ____________________________end_asian_handicap_away_plus_15 = '3.88',
#   ____________________________end_asian_handicap_home_plus_125 = '1.26',
#   ____________________________end_asian_handicap_away_plus_125 = '3.42',
#   ____________________________end_asian_handicap_home_plus_175 = '1.14',
#   ____________________________end_asian_handicap_away_plus_175 = '4.74',
#   ____________________________end_asian_handicap_home_plus_2 = '1.04',
#   ____________________________end_asian_handicap_away_plus_2 = '7.60',
#   ____________________________end_asian_handicap_home_plus_25 = '1.03',
#   ____________________________end_asian_handicap_away_plus_25 = '8.40',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '4.10',
#   ____________________________end_goals_overunder_under_35 = '1.18',
#   ____________________________end_goals_overunder_over_15 = '1.39',
#   ____________________________end_goals_overunder_under_15 = '2.67',
#   ____________________________end_goals_overunder_over_45 = '8.60',
#   ____________________________end_goals_overunder_under_45 = '1.04',
#   ____________________________end_goals_overunder_over_25 = '2.27',
#   ____________________________end_goals_overunder_under_25 = '1.62',
#   ____________________________end_goals_overunder_over_05 = '1.05',
#   ____________________________end_goals_overunder_under_05 = '7.70',
#   ____________________________end_goals_overunder_over_55 = '15.00',
#   ____________________________end_goals_overunder_under_55 = '1.02',
#   ____________________________end_goals_overunder_over_225 = '1.99',
#   ____________________________end_goals_overunder_under_225 = '1.80',
#   ____________________________end_goals_overunder_over_325 = '3.66',
#   ____________________________end_goals_overunder_under_325 = '1.23',
#   ____________________________end_goals_overunder_over_275 = '2.60',
#   ____________________________end_goals_overunder_under_275 = '1.42',
#   ____________________________end_goals_overunder_over_125 = '1.25',
#   ____________________________end_goals_overunder_under_125 = '3.48',
#   ____________________________end_goals_overunder_over_175 = '1.50',
#   ____________________________end_goals_overunder_under_175 = '2.38',
#   ____________________________end_goals_overunder_over_375 = '4.98',
#   ____________________________end_goals_overunder_under_375 = '1.13',
#   ____________________________end_goals_overunder_over_30 = '3.32',
#   ____________________________end_goals_overunder_under_30 = '1.27',
#   ____________________________end_goals_overunder_over_20 = '1.67',
#   ____________________________end_goals_overunder_under_20 = '2.05',
#   ____________________________end_goals_overunder_over_40 = '7.30',
#   ____________________________end_goals_overunder_under_40 = '1.05',
#   ____________________________end_goals_overunder_over_10 = '1.08',
#   ____________________________end_goals_overunder_under_10 = '6.00',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_15 = '3.22',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.30',
#   ____________________________end_goals_overunder_first_half_over_25 = '8.40',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.04',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.47',
#   ____________________________end_goals_overunder_first_half_under_05 = '2.50',
#   ____________________________end_goals_overunder_first_half_over_125 = '2.70',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.41',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.68',
#   ____________________________end_goals_overunder_first_half_under_075 = '2.06',
#   ____________________________end_goals_overunder_first_half_over_20 = '7.20',
#   ____________________________end_goals_overunder_first_half_under_20 = '1.06',
#   ____________________________end_goals_overunder_first_half_over_10 = '2.13',
#   ____________________________end_goals_overunder_first_half_under_10 = '1.64',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '12.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.03',
#   ____________________________end_goals_overunder__second_half_over_15 = '2.42',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.50',
#   ____________________________end_goals_overunder__second_half_over_25 = '5.50',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.11',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.30',
#   ____________________________end_goals_overunder__second_half_under_05 = '3.22',
#   ____________________________end_goals_overunder__second_half_over_125 = '2.02',
#   ____________________________end_goals_overunder__second_half_under_125 = '1.71',
#   ____________________________end_goals_overunder__second_half_over_075 = '1.41',
#   ____________________________end_goals_overunder__second_half_under_075 = '2.69',
#   ____________________________end_goals_overunder__second_half_over_10 = '1.62',
#   ____________________________end_goals_overunder__second_half_under_10 = '2.17',
#   __________________________7 HT/FT Double
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '1.95',
#   ____________________________end_both_teams_score_no = '1.81',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.84
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.70
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 3.88
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.42
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.17
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.03
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.03
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +4 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +4 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +4 --- bets_odd: 29.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.70',
#   ____________________________end_double_chance_home_away = '1.30',
#   ____________________________end_double_chance_draw_away = '1.25',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '4.50',
#   ____________________________end_first_half_winner_draw = '1.97',
#   ____________________________end_first_half_winner_away = '2.66',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 3.40
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.27
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.53
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 2.34
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 8.20
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 2.26
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 1.57
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.23
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.58
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 5.10
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.26
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 3.92
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.19
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 2.40
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.36
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 8.20
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.64
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________33 Double Chance - Second Half
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.45
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.48
#   ______________________  ______________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.16
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.07
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.64
#   __________________________23 Home Odd/Even
#   ______________________  ______________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.62
#   __________________________60 Away Odd/Even
#   ______________________  ______________________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.92
#   ______________________  ______________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.75
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 9 --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 9 --- bets_odd: 2.00
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ______________________2. Ecuador,  Liga Pro Serie B  #243 - 2023 / 1011779
#   ______________________good to Go 1
#   ____________________________1 Match Winner
#   ______________________________end_match_winner_home = '2.56',
#   ______________________________end_match_winner_draw = '3.46',
#   ______________________________end_match_winner_away = '2.46',
#   ____________________________3 Second Half Winner
#   ______________________________end_second_half_winner_home = '2.85',
#   ______________________________end_second_half_winner_draw = '2.52',
#   ______________________________end_second_half_winner_away = '2.70',
#   ____________________________4 Asian Handicap
#   ______________________________end_asian_handicap_home_plus_0 = '1.93',
#   ______________________________end_asian_handicap_away_plus_0 = '1.85',
#   ______________________________end_asian_handicap_home_min_025 = '2.23',
#   ______________________________end_asian_handicap_away_min_025 = '1.64',
#   ______________________________end_asian_handicap_home_plus_025 = '1.64',
#   ______________________________end_asian_handicap_away_plus_025 = '2.09',
#   ______________________________end_asian_handicap_home_min_075 = '3.02',
#   ______________________________end_asian_handicap_away_min_075 = '1.32',
#   ______________________________end_asian_handicap_home_plus_075 = '1.35',
#   ______________________________end_asian_handicap_away_plus_075 = '2.88',
#   ______________________________end_asian_handicap_home_min_1 = '4.14',
#   ______________________________end_asian_handicap_away_min_1 = '1.18',
#   ______________________________end_asian_handicap_home_plus_1 = '1.20',
#   ______________________________end_asian_handicap_away_plus_1 = '3.88',
#   ______________________________end_asian_handicap_home_min_15 = '4.94',
#   ______________________________end_asian_handicap_away_min_15 = '1.12',
#   ______________________________end_asian_handicap_home_plus_15 = '1.14',
#   ______________________________end_asian_handicap_away_plus_15 = '4.70',
#   ______________________________end_asian_handicap_home_min_125 = '4.26',
#   ______________________________end_asian_handicap_away_min_125 = '1.17',
#   ______________________________end_asian_handicap_home_min_175 = '5.70',
#   ______________________________end_asian_handicap_away_min_175 = '1.10',
#   ______________________________end_asian_handicap_home_plus_125 = '1.17',
#   ______________________________end_asian_handicap_away_plus_125 = '4.30',
#   ______________________________end_asian_handicap_home_plus_175 = '1.10',
#   ______________________________end_asian_handicap_away_plus_175 = '5.55',
#   ______________________________end_asian_handicap_home_plus_2 = '1.02',
#   ______________________________end_asian_handicap_away_plus_2 = '9.10',
#   ______________________________end_asian_handicap_home_min_2 = '9.60',
#   ______________________________end_asian_handicap_away_min_2 = '1.01',
#   ______________________________end_asian_handicap_home_plus_25 = '1.03',
#   ______________________________end_asian_handicap_away_plus_25 = '9.10',
#   ______________________________end_asian_handicap_home_min_25 = '9.80',
#   ______________________________end_asian_handicap_away_min_25 = '1.02',
#   ____________________________5 Goals Over/Under
#   ______________________________end_goals_overunder_over_35 = '2.75',
#   ______________________________end_goals_overunder_under_35 = '1.37',
#   ______________________________end_goals_overunder_over_15 = '1.21',
#   ______________________________end_goals_overunder_under_15 = '3.74',
#   ______________________________end_goals_overunder_over_45 = '4.70',
#   ______________________________end_goals_overunder_under_45 = '1.15',
#   ______________________________end_goals_overunder_over_25 = '1.76',
#   ______________________________end_goals_overunder_under_25 = '2.04',
#   ______________________________end_goals_overunder_over_05 = '1.05',
#   ______________________________end_goals_overunder_under_05 = '12.50',
#   ______________________________end_goals_overunder_over_55 = '9.00',
#   ______________________________end_goals_overunder_under_55 = '1.05',
#   ______________________________end_goals_overunder_over_225 = '1.52',
#   ______________________________end_goals_overunder_under_225 = '2.32',
#   ______________________________end_goals_overunder_over_325 = '2.51',
#   ______________________________end_goals_overunder_under_325 = '1.45',
#   ______________________________end_goals_overunder_over_275 = '1.95',
#   ______________________________end_goals_overunder_under_275 = '1.83',
#   ______________________________end_goals_overunder_over_425 = '4.18',
#   ______________________________end_goals_overunder_under_425 = '1.18',
#   ______________________________end_goals_overunder_over_175 = '1.26',
#   ______________________________end_goals_overunder_under_175 = '3.34',
#   ______________________________end_goals_overunder_over_375 = '3.28',
#   ______________________________end_goals_overunder_under_375 = '1.28',
#   ______________________________end_goals_overunder_over_30 = '2.22',
#   ______________________________end_goals_overunder_under_30 = '1.57',
#   ______________________________end_goals_overunder_over_20 = '1.33',
#   ______________________________end_goals_overunder_under_20 = '2.97',
#   ______________________________end_goals_overunder_over_40 = '4.40',
#   ______________________________end_goals_overunder_under_40 = '1.16',
#   ______________________________end_goals_overunder_over_10 = '1.02',
#   ______________________________end_goals_overunder_under_10 = '9.20',
#   ______________________________end_goals_overunder_over_50 = '7.10',
#   ______________________________end_goals_overunder_under_50 = '1.06',
#   ____________________________6 Goals Over/Under First Half
#   ______________________________end_goals_overunder_first_half_over_35 = '13.00',
#   ______________________________end_goals_overunder_first_half_under_35 = '1.02',
#   ______________________________end_goals_overunder_first_half_over_15 = '2.53',
#   ______________________________end_goals_overunder_first_half_under_15 = '1.46',
#   ______________________________end_goals_overunder_first_half_over_25 = '5.40',
#   ______________________________end_goals_overunder_first_half_under_25 = '1.12',
#   ______________________________end_goals_overunder_first_half_over_05 = '1.33',
#   ______________________________end_goals_overunder_first_half_under_05 = '3.04',
#   ______________________________end_goals_overunder_first_half_over_125 = '2.13',
#   ______________________________end_goals_overunder_first_half_under_125 = '1.64',
#   ______________________________end_goals_overunder_first_half_over_075 = '1.45',
#   ______________________________end_goals_overunder_first_half_under_075 = '2.56',
#   ______________________________end_goals_overunder_first_half_over_20 = '4.50',
#   ______________________________end_goals_overunder_first_half_under_20 = '1.16',
#   ______________________________end_goals_overunder_first_half_over_10 = '1.69',
#   ______________________________end_goals_overunder_first_half_under_10 = '2.05',
#   ____________________________26 Goals Over/Under - Second Half
#   ______________________________end_goals_overunder__second_half_over_35 = '8.00',
#   ______________________________end_goals_overunder__second_half_under_35 = '1.06',
#   ______________________________end_goals_overunder__second_half_over_15 = '1.94',
#   ______________________________end_goals_overunder__second_half_under_15 = '1.77',
#   ______________________________end_goals_overunder__second_half_over_25 = '3.60',
#   ______________________________end_goals_overunder__second_half_under_25 = '1.24',
#   ______________________________end_goals_overunder__second_half_over_05 = '1.16',
#   ______________________________end_goals_overunder__second_half_under_05 = '4.60',
#   ______________________________end_goals_overunder__second_half_over_125 = '1.66',
#   ______________________________end_goals_overunder__second_half_under_125 = '2.09',
#   ______________________________end_goals_overunder__second_half_over_175 = '2.30',
#   ______________________________end_goals_overunder__second_half_under_175 = '1.55',
#   ______________________________end_goals_overunder__second_half_over_30 = '6.90',
#   ______________________________end_goals_overunder__second_half_under_30 = '1.07',
#   ______________________________end_goals_overunder__second_half_over_20 = '3.04',
#   ______________________________end_goals_overunder__second_half_under_20 = '1.33',
#   ______________________________end_goals_overunder__second_half_over_10 = '1.35',
#   ______________________________end_goals_overunder__second_half_under_10 = '2.94',
#   ____________________________7 HT/FT Double
#   ____________________________8 Both Teams Score
#   ______________________________end_both_teams_score_yes = '1.58',
#   ______________________________end_both_teams_score_no = '2.32',
#   ____________________________9 Handicap Result
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 4.94
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.44
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.20
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.48
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 4.70
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.10
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.11
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 7.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 11.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 12.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 7.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.10
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 21.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 13.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.02
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.02
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 13.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 21.00
#   ____________________________10 Exact Score
#   ____________________________11 Highest Scoring Half
#   ____________________________31 Correct Score - First Half
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.74
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 13.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.04
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.74
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 13.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 23.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   ____________________________12 Double Chance
#   ______________________________end_double_chance_home_draw = '1.48',
#   ______________________________end_double_chance_home_away = '1.26',
#   ______________________________end_double_chance_draw_away = '1.44',
#   ____________________________13 First Half Winner
#   ______________________________end_first_half_winner_home = '3.13',
#   ______________________________end_first_half_winner_draw = '2.17',
#   ______________________________end_first_half_winner_away = '2.97',
#   ____________________________16 Total - Home
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 11.00
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.01
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.10
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.65
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 4.60
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.16
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.23
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 3.80
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 3.54
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.25
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.43
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 2.60
#   ____________________________17 Total - Away
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 10.50
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.01
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.04
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.69
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 4.40
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.17
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.21
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 3.90
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 3.44
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.27
#   ________________________  ________________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.39
#   ________________________  ________________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 2.75
#   ____________________________18 Handicap Result - First Half
#   ________________________  ________________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.29
#   ________________________  ________________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 8.70
#   ________________________  ________________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 4.04
#   ____________________________19 Asian Handicap First Half
#   ____________________________20 Double Chance - First Half
#   ____________________________33 Double Chance - Second Half
#   ________________________  ________________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.34
#   ________________________  ________________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.39
#   ________________________  ________________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.31
#   ____________________________34 Both Teams Score - First Half
#   ____________________________35 Both Teams To Score - Second Half
#   ____________________________21 Odd/Even
#   ____________________________22 Odd/Even - First Half
#   ________________________  ________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 1.98
#   ________________________  ________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.70
#   ____________________________23 Home Odd/Even
#   ________________________  ________________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.92
#   ________________________  ________________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.75
#   ____________________________60 Away Odd/Even
#   ________________________  ________________________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.92
#   ________________________  ________________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.75
#   ________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ________________________3. Ecuador,  Liga Pro Serie B  #243 - 2023 / 1011780
#   ________________________good to Go 1
#   ______________________________1 Match Winner
#   ________________________________end_match_winner_home = '2.87',
#   ________________________________end_match_winner_draw = '2.90',
#   ________________________________end_match_winner_away = '2.54',
#   ______________________________3 Second Half Winner
#   ________________________________end_second_half_winner_home = '3.20',
#   ________________________________end_second_half_winner_draw = '2.23',
#   ________________________________end_second_half_winner_away = '2.81',
#   ______________________________4 Asian Handicap
#   ________________________________end_asian_handicap_home_plus_0 = '2.01',
#   ________________________________end_asian_handicap_away_plus_0 = '1.78',
#   ________________________________end_asian_handicap_home_min_025 = '2.38',
#   ________________________________end_asian_handicap_away_min_025 = '1.56',
#   ________________________________end_asian_handicap_home_plus_025 = '1.66',
#   ________________________________end_asian_handicap_away_plus_025 = '2.06',
#   ________________________________end_asian_handicap_home_min_075 = '3.38',
#   ________________________________end_asian_handicap_away_min_075 = '1.26',
#   ________________________________end_asian_handicap_home_plus_075 = '1.34',
#   ________________________________end_asian_handicap_away_plus_075 = '2.93',
#   ________________________________end_asian_handicap_home_min_1 = '5.00',
#   ________________________________end_asian_handicap_away_min_1 = '1.12',
#   ________________________________end_asian_handicap_home_plus_1 = '1.17',
#   ________________________________end_asian_handicap_away_plus_1 = '4.20',
#   ________________________________end_asian_handicap_home_min_15 = '6.00',
#   ________________________________end_asian_handicap_away_min_15 = '1.08',
#   ________________________________end_asian_handicap_home_plus_15 = '1.11',
#   ________________________________end_asian_handicap_away_plus_15 = '5.15',
#   ________________________________end_asian_handicap_home_min_125 = '5.05',
#   ________________________________end_asian_handicap_away_min_125 = '1.13',
#   ________________________________end_asian_handicap_home_plus_125 = '1.14',
#   ________________________________end_asian_handicap_away_plus_125 = '4.68',
#   ________________________________end_asian_handicap_home_plus_175 = '1.09',
#   ________________________________end_asian_handicap_away_plus_175 = '6.05',
#   ________________________________end_asian_handicap_home_plus_2 = '1.00',
#   ________________________________end_asian_handicap_away_plus_2 = '10.50',
#   ________________________________end_asian_handicap_home_min_2 = '11.50',
#   ________________________________end_asian_handicap_away_min_2 = '1.01',
#   ______________________________5 Goals Over/Under
#   ________________________________end_goals_overunder_over_35 = '4.20',
#   ________________________________end_goals_overunder_under_35 = '1.17',
#   ________________________________end_goals_overunder_over_15 = '1.40',
#   ________________________________end_goals_overunder_under_15 = '2.64',
#   ________________________________end_goals_overunder_over_45 = '9.30',
#   ________________________________end_goals_overunder_under_45 = '1.03',
#   ________________________________end_goals_overunder_over_25 = '2.30',
#   ________________________________end_goals_overunder_under_25 = '1.60',
#   ________________________________end_goals_overunder_over_05 = '1.06',
#   ________________________________end_goals_overunder_under_05 = '7.30',
#   ________________________________end_goals_overunder_over_55 = '15.00',
#   ________________________________end_goals_overunder_under_55 = '1.02',
#   ________________________________end_goals_overunder_over_225 = '2.01',
#   ________________________________end_goals_overunder_under_225 = '1.78',
#   ________________________________end_goals_overunder_over_325 = '3.76',
# ...
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-21
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 889
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Egypt,  Second League - Group C  #889 - 2022 / 965278
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.94',
#   ____________________________end_match_winner_draw = '2.91',
#   ____________________________end_match_winner_away = '4.52',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '2.30',
#   ____________________________end_second_half_winner_draw = '2.12',
#   ____________________________end_second_half_winner_away = '5.05',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.35',
#   ____________________________end_asian_handicap_away_plus_0 = '3.13',
#   ____________________________end_asian_handicap_home_min_025 = '1.65',
#   ____________________________end_asian_handicap_away_min_025 = '2.22',
#   ____________________________end_asian_handicap_home_plus_025 = '1.23',
#   ____________________________end_asian_handicap_away_plus_025 = '3.68',
#   ____________________________end_asian_handicap_home_min_075 = '2.19',
#   ____________________________end_asian_handicap_away_min_075 = '1.58',
#   ____________________________end_asian_handicap_home_plus_075 = '1.09',
#   ____________________________end_asian_handicap_away_plus_075 = '5.75',
#   ____________________________end_asian_handicap_home_min_1 = '2.84',
#   ____________________________end_asian_handicap_away_min_1 = '1.35',
#   ____________________________end_asian_handicap_home_plus_1 = '1.01',
#   ____________________________end_asian_handicap_away_plus_1 = '9.80',
#   ____________________________end_asian_handicap_home_min_15 = '3.64',
#   ____________________________end_asian_handicap_away_min_15 = '1.22',
#   ____________________________end_asian_handicap_home_plus_15 = '1.02',
#   ____________________________end_asian_handicap_away_plus_15 = '9.70',
#   ____________________________end_asian_handicap_home_min_125 = '3.28',
#   ____________________________end_asian_handicap_away_min_125 = '1.28',
#   ____________________________end_asian_handicap_home_min_2 = '7.20',
#   ____________________________end_asian_handicap_away_min_2 = '1.05',
#   ____________________________end_asian_handicap_home_min_25 = '8.00',
#   ____________________________end_asian_handicap_away_min_25 = '1.03',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '5.20',
#   ____________________________end_goals_overunder_under_35 = '1.11',
#   ____________________________end_goals_overunder_over_15 = '1.59',
#   ____________________________end_goals_overunder_under_15 = '2.33',
#   ____________________________end_goals_overunder_over_45 = '10.00',
#   ____________________________end_goals_overunder_under_45 = '1.02',
#   ____________________________end_goals_overunder_over_25 = '2.64',
#   ____________________________end_goals_overunder_under_25 = '1.40',
#   ____________________________end_goals_overunder_over_05 = '1.10',
#   ____________________________end_goals_overunder_under_05 = '5.45',
#   ____________________________end_goals_overunder_over_225 = '2.33',
#   ____________________________end_goals_overunder_under_225 = '1.52',
#   ____________________________end_goals_overunder_over_275 = '3.20',
#   ____________________________end_goals_overunder_under_275 = '1.29',
#   ____________________________end_goals_overunder_over_125 = '1.36',
#   ____________________________end_goals_overunder_under_125 = '2.83',
#   ____________________________end_goals_overunder_over_175 = '1.77',
#   ____________________________end_goals_overunder_under_175 = '2.04',
#   ____________________________end_goals_overunder_over_075 = '1.13',
#   ____________________________end_goals_overunder_under_075 = '4.86',
#   ____________________________end_goals_overunder_over_30 = '4.40',
#   ____________________________end_goals_overunder_under_30 = '1.16',
#   ____________________________end_goals_overunder_over_20 = '2.00',
#   ____________________________end_goals_overunder_under_20 = '1.70',
#   ____________________________end_goals_overunder_over_40 = '8.20',
#   ____________________________end_goals_overunder_under_40 = '1.04',
#   ____________________________end_goals_overunder_over_10 = '1.17',
#   ____________________________end_goals_overunder_under_10 = '4.30',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_15 = '3.84',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.22',
#   ____________________________end_goals_overunder_first_half_over_25 = '9.20',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.03',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.64',
#   ____________________________end_goals_overunder_first_half_under_05 = '2.13',
#   ____________________________end_goals_overunder_first_half_over_125 = '3.20',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.30',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.91',
#   ____________________________end_goals_overunder_first_half_under_075 = '1.80',
#   ____________________________end_goals_overunder_first_half_over_10 = '2.59',
#   ____________________________end_goals_overunder_first_half_under_10 = '1.44',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_15 = '2.77',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.39',
#   ____________________________end_goals_overunder__second_half_over_25 = '6.50',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.08',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.39',
#   ____________________________end_goals_overunder__second_half_under_05 = '2.77',
#   ____________________________end_goals_overunder__second_half_over_125 = '2.33',
#   ____________________________end_goals_overunder__second_half_under_125 = '1.54',
#   ____________________________end_goals_overunder__second_half_over_075 = '1.54',
#   ____________________________end_goals_overunder__second_half_under_075 = '2.32',
#   ____________________________end_goals_overunder__second_half_over_10 = '1.85',
#   ____________________________end_goals_overunder__second_half_under_10 = '1.86',
#   __________________________7 HT/FT Double
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '2.30',
#   ____________________________end_both_teams_score_no = '1.59',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 3.64
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.78
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.28
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.22
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.74
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.13
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.16',
#   ____________________________end_double_chance_home_away = '1.35',
#   ____________________________end_double_chance_draw_away = '1.78',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '2.68',
#   ____________________________end_first_half_winner_draw = '1.79',
#   ____________________________end_first_half_winner_away = '5.75',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.40
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.48
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 3.14
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 4.44
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.15
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.61
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 2.12
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 4.90
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.77
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 1.89
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 3.34
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 1.26
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 8.20
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.35
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.68
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________33 Double Chance - Second Half
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.55
#   ______________________  ______________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.48
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.25
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.54
#   __________________________23 Home Odd/Even
#   ______________________  ______________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.95
#   ______________________  ______________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.72
#   __________________________60 Away Odd/Even
#   ______________________  ______________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.32
#   ______________________  ______________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.51
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 8.5 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 8.5 --- bets_odd: 1.80
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-24 19:26:52

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 19:26:53
#   __main()
#   ____get_date()
#   ______days : 3
#   ______days : 2
#   ______tgl_awal : 2023-03-21
#   ______tgl_akhir : 2023-03-22
#   ________ff_get_fixture_status_match_finished()
#   __________Total Row(s) : 48
#   __________1. 2023-03-21 // 41 // 8 // 2022 // 875800 // 025+05+075+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 875800
#   ____________> end_ah_pattern = 05+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_05_H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-03-21 // 41 // 8 // 2022 // 875836 // 025_0#025+05+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 875836
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-03-21 // 50 // 8 // 2022 // 892257 // 05_025_0#H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 892257
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________4. 2023-03-21 // 50 // 8 // 2022 // 892321 // 05_025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 892321
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________5. 2023-03-21 // 50 // 8 // 2022 // 892385 // 0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 892385
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________6. 2023-03-21 // 50 // 8 // 2022 // 892403 // 05_025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 892403
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________7. 2023-03-21 // 50 // 8 // 2022 // 892404 // 075_05_025_0#H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 892404
#   ____________> end_ah_pattern = 05_H
#   ____________> end_ah_pattern_mirror = 05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________8. 2023-03-21 // 60 // 11 // 2022 // 911978 // 025_0#025+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 911978
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________9. 2023-03-21 // 60 // 11 // 2022 // 911986 // 075+1+125+15+H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 911986
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________10. 2023-03-21 // 60 // 11 // 2022 // 912017 // 075_025_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 912017
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________11. 2023-03-21 // 60 // 11 // 2022 // 912035 // 025_0#025+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 912035
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________12. 2023-03-21 // 60 // 11 // 2022 // 912074 // 0#025+075+H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 912074
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________13. 2023-03-21 // 83 // 8 // 2022 // 904261 // 025_0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 904261
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________14. 2023-03-21 // 86 // 8 // 2022 // 904895 // 05_025_0#H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 904895
#   ____________> end_ah_pattern = 075_05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________15. 2023-03-21 // 111 // 11 // 2022 // 892978 // 0#025+075+H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 892978
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________16. 2023-03-21 // 111 // 11 // 2022 // 893011 // 1+125+15+175+2+H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 893011
#   ____________> end_ah_pattern = 1+125+15+175+H
#   ____________> end_ah_pattern_mirror = 175_15_125_1_H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________17. 2023-03-21 // 111 // 11 // 2022 // 893014 // 025+075+1+125+H // 25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 893014
#   ____________> end_ah_pattern = 025_0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________18. 2023-03-22 // 128 // 8 // 2023 // 971435 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971435
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________19. 2023-03-21 // 129 // 8 // 2023 // 992496 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992496
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 15g175g2gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________20. 2023-03-21 // 131 // 11 // 2023 // 987037 // 075_025_H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 987037
#   ____________> end_ah_pattern = 025_H
#   ____________> end_ah_pattern_mirror = 025+H
#   ____________> end_gou_pattern = 15g175g2gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________21. 2023-03-21 // 132 // 11 // 2023 // 988069 // 075_025_H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988069
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________22. 2023-03-21 // 180 // 8 // 2022 // 873457 // 1_075_05_025_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 873457
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________23. 2023-03-21 // 239 // 8 // 2023 // 989355 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 989355
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________24. 2023-03-21 // 240 // 8 // 2023 // 989590 // 025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 989590
#   ____________> end_ah_pattern = 025+H
#   ____________> end_ah_pattern_mirror = 025_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________25. 2023-03-22 // 243 // 11 // 2023 // 1011776 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011776
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________26. 2023-03-21 // 266 // 11 // 2023 // 987782 // 075_025_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 987782
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________27. 2023-03-21 // 274 // 11 // 2022 // 899798 // 075_025_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 899798
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________28. 2023-03-21 // 304 // 11 // 2023 // 984862 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 984862
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________29. 2023-03-21 // 322 // 11 // 2022 // 968393 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 968393
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________30. 2023-03-21 // 407 // 11 // 2022 // 877298 // 025_0#025+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877298
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________31. 2023-03-21 // 407 // 11 // 2022 // 877347 // 1_075_025_H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877347
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________32. 2023-03-22 // 604 // 8 // 2023 // 1015125 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1015125
#   ____________> end_ah_pattern = 025_H
#   ____________> end_ah_pattern_mirror = 025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________33. 2023-03-21 // 673 // 8 // 2022 // 976345 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 976345
#   ____________> end_ah_pattern = 35_325_H
#   ____________> end_ah_pattern_mirror = 325+35+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________34. 2023-03-21 // 703 // 11 // 2022 // 948505 // 0#025+075+H // 3g325g35g375g4g425gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 948505
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 3g325g35g375g4gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________35. 2023-03-21 // 703 // 11 // 2022 // 948601 // 025+075+1+H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 948601
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 3g325g35g375g4gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________36. 2023-03-21 // 703 // 11 // 2022 // 948602 // 15_125_1_075_H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 948602
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________37. 2023-03-21 // 862 // 11 // 2022 // 883726 // 025_0#025+H // 225g25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 883726
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________38. 2023-03-21 // 862 // 11 // 2022 // 883727 // 1_H // 25g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 883727
#   ____________> end_ah_pattern = 1_H
#   ____________> end_ah_pattern_mirror = 1+H
#   ____________> end_gou_pattern = 25g3g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________39. 2023-03-21 // 887 // 11 // 2022 // 964799 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964799
#   ____________> end_ah_pattern = 125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________40. 2023-03-21 // 888 // 11 // 2022 // 965036 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965036
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________41. 2023-03-21 // 888 // 11 // 2022 // 965037 // 0#H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965037
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________42. 2023-03-21 // 888 // 11 // 2022 // 965038 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965038
#   ____________> end_ah_pattern = 025+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_025_H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________43. 2023-03-21 // 888 // 11 // 2022 // 965039 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965039
#   ____________> end_ah_pattern = 025+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_025_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________44. 2023-03-21 // 888 // 11 // 2022 // 965043 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965043
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________45. 2023-03-21 // 889 // 11 // 2022 // 965278 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965278
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________46. 2023-03-21 // 931 // 11 // 2022 // 912522 // 075_025_0#025+H // 225g25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 912522
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________47. 2023-03-21 // 931 // 11 // 2022 // 912547 // 15_125_1_075_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 912547
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________48. 2023-03-21 // 931 // 11 // 2022 // 912553 // 025_0#025+H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 912553
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
# # -------------------------------------------------- End at 2023-03-24 19:33:23

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 19:33:23
#   __main()
#   ____get_date()
#   ______days : 3
#   ______days : 2
#   ______tgl_awal : 2023-03-21
#   ______tgl_akhir : 2023-03-22
#   ________ff_get_fixture_status_match_finished_for_daily_update_patternlist()
#   ________Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date <= '2023-03-22'  and date >= '2023-03-21'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 79
#   ____________[1/79] #904261 #Germany 83-2022 / Heimstetten vs Buchbach
#   ____________pre-ah:025_0#025+05+H -- pre-gou:25gG -/- end-ah:025_0#025+05+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:53:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '83'  and league_country = 'Germany'  and pre_ah_pattern = '025_0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[2/79] #875800 #England 41-2022 / Accrington ST vs Plymouth
#   ____________pre-ah:025+05+075+H -- pre-gou:225g25g275g3gG -/- end-ah:05+075+1+125+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:51:12
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '41'  and league_country = 'England'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '05+075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_05_H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[3/79] #875836 #England 41-2022 / Barnsley vs Sheffield Wednesday
#   ____________pre-ah:025_0#025+05+H -- pre-gou:2g225g25g275gG -/- end-ah:025_0#025+H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:51:17
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '41'  and league_country = 'England'  and pre_ah_pattern = '025_0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#025+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[4/79] #876355 #England 42-2022 / Gillingham vs Crewe
#   ____________pre-ah:1_075_05_025_H -- pre-gou:175g2g225g25gG -/- end-ah:1_075_05_025_H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:51:24
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '42'  and league_country = 'England'  and pre_ah_pattern = '1_075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+1+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[5/79] #876366 #England 42-2022 / Crawley Town vs Doncaster
#   ____________pre-ah:05_025_0#025+H -- pre-gou:225g25g275gG -/- end-ah:05_025_0#H -- end-gou:225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:51:30
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '42'  and league_country = 'England'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[6/79] #876377 #England 42-2022 / Bradford vs Carlisle
#   ____________pre-ah:05_025_0#H -- pre-gou:2g225g25gG -/- end-ah:05_025_0#H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:51:33
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '42'  and league_country = 'England'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '2g225g25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 8
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 8
#   ____________________patternlists updated
#
#   ____________[7/79] #899798 #Indonesia 274-2022 / Barito Putera vs Persis Solo
#   ____________pre-ah:075_025_H -- pre-gou:225g25g275g3gG -/- end-ah:075_025_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:54:50
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '274'  and league_country = 'Indonesia'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[8/79] #873457 #Scotland 180-2022 / Dundee vs Ayr Utd
#   ____________pre-ah:1_075_05_025_H -- pre-gou:225g25g275g3gG -/- end-ah:1_075_05_025_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:54:23
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '180'  and league_country = 'Scotland'  and pre_ah_pattern = '1_075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+1+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[9/79] #873585 #Scotland 184-2022 / Stirling Albion vs Forfar Athletic
#   ____________pre-ah:1_075_05_025_H -- pre-gou:225g25g275g3gG -/- end-ah:1_075_05_025_H -- end-gou:225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:54:26
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '184'  and league_country = 'Scotland'  and pre_ah_pattern = '1_075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+1+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[10/79] #873636 #Scotland 184-2022 / Albion Rovers vs Stranraer
#   ____________pre-ah:05_025_0#H -- pre-gou:225g25g275gG -/- end-ah:05_025_0#H -- end-gou:225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:54:30
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '184'  and league_country = 'Scotland'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[11/79] #907837 #Germany 745-2022 / Altona 93 vs Buchholz
#   ____________pre-ah:225_2_175_15_125_H -- pre-gou:3g325g35g375g4gG -/- end-ah:225_2_175_15_125_H -- end-gou:3g325g35g375g4gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:55:32
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '745'  and league_country = 'Germany'  and pre_ah_pattern = '225_2_175_15_125_H'  and pre_ah_pattern_mirror = '125+15+175+2+225+H'  and pre_gou_pattern = '3g325g35g375g4gG'  and end_ah_pattern = '225_2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+225+H'  and end_gou_pattern = '3g325g35g375g4gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[12/79] #904564 #Germany 85-2022 / Altglienicke vs SV Babelsberg 03
#   ____________pre-ah:15_125_1_075_05_H -- pre-gou:25gG -/- end-ah:175_15_125_1_H -- end-gou:25g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:53:23
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '85'  and league_country = 'Germany'  and pre_ah_pattern = '15_125_1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+125+15+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '25g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[13/79] #904605 #Germany 85-2022 / Greifswalder FC vs Tennis Borussia
#   ____________pre-ah:225_2_175_15_H -- pre-gou:25g35gG -/- end-ah:225_2_175_15_125_H -- end-gou:25g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:53:26
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '85'  and league_country = 'Germany'  and pre_ah_pattern = '225_2_175_15_H'  and pre_ah_pattern_mirror = '15+175+2+225+H'  and pre_gou_pattern = '25g35gG'  and end_ah_pattern = '225_2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+225+H'  and end_gou_pattern = '25g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[14/79] #904606 #Germany 85-2022 / BFC Dynamo vs Viktoria Berlin
#   ____________pre-ah:1_075_05_025_H -- pre-gou:25gG -/- end-ah:1_075_05_025_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:53:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '85'  and league_country = 'Germany'  and pre_ah_pattern = '1_075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+1+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[15/79] #877298 #Northern-Ireland 407-2022 / Institute vs Ballinamallard United
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275g3gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:55:03
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '407'  and league_country = 'Northern-Ireland'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[16/79] #877347 #Northern-Ireland 407-2022 / Loughgall vs Annagh United
#   ____________pre-ah:1_075_025_H -- pre-gou:225g25g275g3g325gG -/- end-ah:125_1_075_025_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:55:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '407'  and league_country = 'Northern-Ireland'  and pre_ah_pattern = '1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '125_1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+125+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[17/79] #883726 #Denmark 862-2022 / Ishøj vs Næsby
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275g3g325g35gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:55:36
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '862'  and league_country = 'Denmark'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275g3g325g35gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[18/79] #883727 #Denmark 862-2022 / Middelfart vs FA 2000
#   ____________pre-ah:1_H -- pre-gou:25g3gG -/- end-ah:1_H -- end-gou:25g3g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:55:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '862'  and league_country = 'Denmark'  and pre_ah_pattern = '1_H'  and pre_ah_pattern_mirror = '1+H'  and pre_gou_pattern = '25g3gG'  and end_ah_pattern = '1_H'  and end_ah_pattern_mirror = '1+H'  and end_gou_pattern = '25g3g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[19/79] #884160 #Denmark 122-2022 / Kolding IF vs HIK
#   ____________pre-ah:15_125_1_075_H -- pre-gou:25gG -/- end-ah:125_1_075_05_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:53:49
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '122'  and league_country = 'Denmark'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[20/79] #904895 #Germany 86-2022 / Hessen Kassel vs VfR Aalen
#   ____________pre-ah:05_025_0#H -- pre-gou:25gG -/- end-ah:075_05_025_0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:53:32
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '86'  and league_country = 'Germany'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '075_05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[21/79] #911066 #England 58-2022 / Lewes vs Canvey Island
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275g3g325gG -/- end-ah:025_0#025+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:52:28
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '58'  and league_country = 'England'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 12
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 12
#   ____________________patternlists updated
#
#   ____________[22/79] #911135 #England 58-2022 / Potters Bar Town vs Bognor Regis Town
#   ____________pre-ah:025_0#025+H -- pre-gou:25g275g3g325g35gG -/- end-ah:025_0#025+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:52:32
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '58'  and league_country = 'England'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 18
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 18
#   ____________________patternlists updated
#
#   ____________[23/79] #911516 #England 59-2022 / Marske United vs Liversedge
#   ____________pre-ah:075_025_0#025+H -- pre-gou:25g275g3g325g35gG -/- end-ah:075_025_0#025+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:52:36
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '59'  and league_country = 'England'  and pre_ah_pattern = '075_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+075+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '075_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+075+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[24/79] #911611 #England 59-2022 / Gainsborough Trinity vs Marine
#   ____________pre-ah:075_025_0#H -- pre-gou:225g25g275g3gG -/- end-ah:075_025_0#H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:52:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '59'  and league_country = 'England'  and pre_ah_pattern = '075_025_0#H'  and pre_ah_pattern_mirror = '0#025+075+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '075_025_0#H'  and end_ah_pattern_mirror = '0#025+075+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 5
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 5
#   ____________________patternlists updated
#
#   ____________[25/79] #911978 #England 60-2022 / Metropolitan Police vs Swindon Supermarine
#   ____________pre-ah:025_0#025+H -- pre-gou:25g275g3g325g35gG -/- end-ah:025_0#025+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:52:43
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '60'  and league_country = 'England'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 24
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 24
#   ____________________patternlists updated
#
#   ____________[26/79] #911986 #England 60-2022 / Harrow Borough vs Bracknell Town
#   ____________pre-ah:075+1+125+15+H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:075+1+125+15+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:52:48
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '60'  and league_country = 'England'  and pre_ah_pattern = '075+1+125+15+H'  and pre_ah_pattern_mirror = '15_125_1_075_H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '075+1+125+15+H'  and end_ah_pattern_mirror = '15_125_1_075_H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[27/79] #912017 #England 60-2022 / Chesham United vs Plymouth Parkway
#   ____________pre-ah:075_025_H -- pre-gou:25g275g3g325g35gG -/- end-ah:1_075_025_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:52:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '60'  and league_country = 'England'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[28/79] #912035 #England 60-2022 / Salisbury vs Hayes & Yeading United
#   ____________pre-ah:025_0#025+H -- pre-gou:25g275g3g325g35gG -/- end-ah:025+075+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:52:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '60'  and league_country = 'England'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[29/79] #987782 #Chile 266-2023 / Santiago Wanderers vs Union San Felipe
#   ____________pre-ah:075_025_H -- pre-gou:2g225g25g275gG -/- end-ah:075_025_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:54:46
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '266'  and league_country = 'Chile'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 6
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 6
#   ____________________patternlists updated
#
#   ____________[30/79] #912074 #England 60-2022 / Hanwell Town vs Poole Town
#   ____________pre-ah:0#025+075+H -- pre-gou:225g25g275g3g325gG -/- end-ah:0#025+075+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:53:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '60'  and league_country = 'England'  and pre_ah_pattern = '0#025+075+H'  and pre_ah_pattern_mirror = '075_025_0#H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[31/79] #892257 #England 50-2022 / King's Lynn Town vs AFC Fylde
#   ____________pre-ah:05_025_0#H -- pre-gou:25gG -/- end-ah:05_025_0#025+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:51:46
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '50'  and league_country = 'England'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 6
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 6
#   ____________________patternlists updated
#
#   ____________[32/79] #892321 #England 50-2022 / Banbury United vs Curzon Ashton
#   ____________pre-ah:05_025_0#025+H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:51:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '50'  and league_country = 'England'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 6
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 6
#   ____________________patternlists updated
#
#   ____________[33/79] #892385 #England 50-2022 / Farsley Celtic FC vs Darlington 1883
#   ____________pre-ah:0#025+05+H -- pre-gou:25gG -/- end-ah:025_0#025+05+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:51:52
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '50'  and league_country = 'England'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[34/79] #892403 #England 50-2022 / Southport vs Alfreton Town
#   ____________pre-ah:05_025_0#025+H -- pre-gou:25gG -/- end-ah:05_025_0#025+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:51:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '50'  and league_country = 'England'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 12
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 12
#   ____________________patternlists updated
#
#   ____________[35/79] #892404 #England 50-2022 / Spennymoor Town vs Leamington
#   ____________pre-ah:075_05_025_0#H -- pre-gou:25gG -/- end-ah:05_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:51:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '50'  and league_country = 'England'  and pre_ah_pattern = '075_05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+075+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_H'  and end_ah_pattern_mirror = '05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[36/79] #891654 #England 51-2022 / Farnborough vs Slough Town
#   ____________pre-ah:15_125_1_075_05_1+125+15+H -- pre-gou:25gG -/- end-ah:125_1_075_05_1+125+15+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:52:17
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '51'  and league_country = 'England'  and pre_ah_pattern = '15_125_1_075_05_1+125+15+H'  and pre_ah_pattern_mirror = '15_125_1_05+075+1+125+15+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '125_1_075_05_1+125+15+H'  and end_ah_pattern_mirror = '15_125_1_05+075+1+125+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[37/79] #891759 #England 51-2022 / Chippenham Town vs Weymouth
#   ____________pre-ah:05_025_0#025+H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:52:24
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '51'  and league_country = 'England'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 10
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 10
#   ____________________patternlists updated
#
#   ____________[38/79] #891779 #England 51-2022 / Welling United vs Taunton Town
#   ____________pre-ah:05_025_0#H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:52:12
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '51'  and league_country = 'England'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 17
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 17
#   ____________________patternlists updated
#
#   ____________[39/79] #891850 #England 51-2022 / St Albans City vs Cheshunt
#   ____________pre-ah:125_1_075_05_H -- pre-gou:25gG -/- end-ah:15_125_1_075_05_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:52:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '51'  and league_country = 'England'  and pre_ah_pattern = '125_1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+125+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '15_125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+15+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 5
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 5
#   ____________________patternlists updated
#
#   ____________[40/79] #948505 #England 703-2022 / Colchester United U21 vs Millwall U21
#   ____________pre-ah:0#025+075+H -- pre-gou:3g325g35g375g4g425gG -/- end-ah:0#025+075+H -- end-gou:3g325g35g375g4gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:55:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '703'  and league_country = 'England'  and pre_ah_pattern = '0#025+075+H'  and pre_ah_pattern_mirror = '075_025_0#H'  and pre_gou_pattern = '3g325g35g375g4g425gG'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '3g325g35g375g4gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[41/79] #948601 #England 703-2022 / Coventry City U21 vs Peterborough United U21
#   ____________pre-ah:025+075+1+H -- pre-gou:275g3g325g35g375gG -/- end-ah:025_0#025+H -- end-gou:3g325g35g375g4gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:55:21
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '703'  and league_country = 'England'  and pre_ah_pattern = '025+075+1+H'  and pre_ah_pattern_mirror = '1_075_025_H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '3g325g35g375g4gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[42/79] #948602 #England 703-2022 / Sheffield United U21 vs Burnley U21
#   ____________pre-ah:15_125_1_075_H -- pre-gou:275g3g325g35g375gG -/- end-ah:175_15_125_1_075_H -- end-gou:275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:55:23
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '703'  and league_country = 'England'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '175_15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+175+H'  and end_gou_pattern = '275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[43/79] #885869 #Germany 82-2022 / Turbine Potsdam W vs FC Koln W
# ...
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '888'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025+075+1+H'  and end_ah_pattern_mirror = '1_075_025_H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[66/79] #965039 #Egypt 888-2022 / AL Nasr SC vs Wadi Degla
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:025+075+1+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:33
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '888'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025+075+1+H'  and end_ah_pattern_mirror = '1_075_025_H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[67/79] #965043 #Egypt 888-2022 / El Seka El Hadid vs Petrojet
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:075_025_H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:45
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '888'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[68/79] #996238 #Ecuador 242-2023 / Deportivo Cuenca vs Cumbayá
#   ____________pre-ah:1_075_05_H -- pre-gou:2g225g25gG -/- end-ah:125_1_075_05_H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-22 15:43:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '242'  and league_country = 'Ecuador'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '2g225g25gG'  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[69/79] #965278 #Egypt 889-2022 / Sporting Alexandria vs Helal Aldabaa
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_025_H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:50
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '889'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[70/79] #987037 #Argentina 131-2023 / Los Andes vs Ituzaingó
#   ____________pre-ah:075_025_H -- pre-gou:15g175g2g225gG -/- end-ah:025_H -- end-gou:15g175g2gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-23 02:54:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '131'  and league_country = 'Argentina'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '15g175g2g225gG'  and end_ah_pattern = '025_H'  and end_ah_pattern_mirror = '025+H'  and end_gou_pattern = '15g175g2gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[71/79] #1004751 #World 525-2022 / Bayern Munich W vs Arsenal W
#   ____________pre-ah:075_025_0#H -- pre-gou:225g25g275g3g325gG -/- end-ah:1_075_025_H -- end-gou:225g25g275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:55:09
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '525'  and league_country = 'World'  and pre_ah_pattern = '075_025_0#H'  and pre_ah_pattern_mirror = '0#025+075+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+H'  and end_gou_pattern = '225g25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[72/79] #1004753 #World 525-2022 / Roma W vs Barcelona W
#   ____________pre-ah:2+225+25+275+3+H -- pre-gou:275g3g325g35g375gG -/- end-ah:2+225+25+275+3+H -- end-gou:325g35g375g4g425g45gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:55:11
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '525'  and league_country = 'World'  and pre_ah_pattern = '2+225+25+275+3+H'  and pre_ah_pattern_mirror = '3_275_25_225_2_H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '2+225+25+275+3+H'  and end_ah_pattern_mirror = '3_275_25_225_2_H'  and end_gou_pattern = '325g35g375g4g425g45gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[73/79] #1010512 #Belgium 146-2022 / Club Brugge W vs Genk W
#   ____________pre-ah:025_0#H -- pre-gou:25g3gG -/- end-ah:075_025_0#H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:54:10
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '146'  and league_country = 'Belgium'  and pre_ah_pattern = '025_0#H'  and pre_ah_pattern_mirror = '0#025+H'  and pre_gou_pattern = '25g3gG'  and end_ah_pattern = '075_025_0#H'  and end_ah_pattern_mirror = '0#025+075+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[74/79] #1010513 #Belgium 146-2022 / OH Leuven W vs Gent W
#   ____________pre-ah:35_325_H -- pre-gou:4gG -/- end-ah:35_325_3_275_25_H -- end-gou:3g325g35g375g4gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:54:14
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '146'  and league_country = 'Belgium'  and pre_ah_pattern = '35_325_H'  and pre_ah_pattern_mirror = '325+35+H'  and pre_gou_pattern = '4gG'  and end_ah_pattern = '35_325_3_275_25_H'  and end_ah_pattern_mirror = '25+275+3+325+35+H'  and end_gou_pattern = '3g325g35g375g4gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[75/79] #1010541 #Belgium 146-2022 / Mechelen vs White Star Woluwe W
#   ____________pre-ah:0#025+H -- pre-gou:25g3gG -/- end-ah:0#025+075+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:54:16
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '146'  and league_country = 'Belgium'  and pre_ah_pattern = '0#025+H'  and pre_ah_pattern_mirror = '025_0#H'  and pre_gou_pattern = '25g3gG'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[76/79] #1010542 #Belgium 146-2022 / Charleroi W vs Eendracht Aalst W
#   ____________pre-ah:H -- pre-gou:25g3gG -/- end-ah:125_1_075_H -- end-gou:225g25g275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:54:20
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '146'  and league_country = 'Belgium'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25g3gG'  and end_ah_pattern = '125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+H'  and end_gou_pattern = '225g25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[77/79] #1010652 #Brazil 740-2023 / Fluminense U20 vs Internacional U20
#   ____________pre-ah:025_0#025+H -- pre-gou:2g225g25g275gG -/- end-ah:025_0#025+H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-23 02:55:27
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[78/79] #1011776 #Ecuador 243-2023 / Cuniburo vs America de Quito
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025+075+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:19
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '243'  and league_country = 'Ecuador'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[79/79] #1015125 #Brazil 604-2023 / Criciuma vs Avai
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:27:28
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '604'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_H'  and end_ah_pattern_mirror = '025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
# # -------------------------------------------------- End at 2023-03-24 19:52:30
