# %%
# Import
from a_settings.messages import *  

today = datetime.datetime.now()  
days0 = 5
days1 = 4
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 5 - 4 --> 2023-03-25 02:28:09.093644

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 02:28:09
#   __main()
#   ____get_date()
#   ______days : 5
#   ______days : 4
#   ______tgl_awal : 2023-03-20
#   ______tgl_akhir : 2023-03-21
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-21'  and date >= '2023-03-20'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 9
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 43
#   ______________1. 2023-03-20 // 10 // 8 // 2023 // 1014507 // None // None
#   ______________2. 2023-03-20 // 128 // 8 // 2023 // 971437 // H // G
#   ______________3. 2023-03-20 // 128 // 8 // 2023 // 971440 // 05_025_0#H // 15g175g2gG
#   ______________4. 2023-03-21 // 128 // 8 // 2023 // 971442 // H // G
#   ______________5. 2023-03-21 // 128 // 8 // 2023 // 971445 // H // G
#   ______________6. 2023-03-20 // 128 // 8 // 2023 // 988711 // H // G
#   ______________7. 2023-03-20 // 129 // 8 // 2023 // 992652 // H // 25gG
#   ______________8. 2023-03-20 // 132 // 11 // 2023 // 988065 // 025+075+H // 15g175g2g225g25gG
#   ______________9. 2023-03-20 // 132 // 11 // 2023 // 988071 // 025_0#H // 175g225g25gG
#   ______________10. 2023-03-20 // 173 // 11 // 2022 // 882799 // 025+075+H // 175g2g225g25g275gG
#   ______________11. 2023-03-20 // 173 // 11 // 2022 // 882803 // 025_0#H // 175g2g225g25gG
#   ______________12. 2023-03-20 // 204 // 8 // 2022 // 885005 // 025_0#025+05+H // 225g25g275gG
#   ______________13. 2023-03-20 // 205 // 11 // 2022 // 889094 // H // 2gG
#   ______________14. 2023-03-20 // 205 // 11 // 2022 // 889461 // 275_25_225_2_175_15_H // 275g3g325g35g375gG
#   ______________15. 2023-03-20 // 239 // 8 // 2023 // 989354 // H // G
#   ______________16. 2023-03-20 // 240 // 8 // 2023 // 989589 // 025+H // 25gG
#   ______________17. 2023-03-20 // 240 // 8 // 2023 // 989587 // 025_H // 25gG
#   ______________18. 2023-03-20 // 240 // 8 // 2023 // 989586 // 025_H // 25gG
#   ______________19. 2023-03-20 // 242 // 8 // 2023 // 996239 // 175_15_125_1_H // 2g225g25g275gG
#   ______________20. 2023-03-21 // 242 // 8 // 2023 // 996238 // 1_075_05_H // 2g225g25gG
#   ______________21. 2023-03-20 // 250 // 8 // 2023 // 986901 // 075+H // 25gG
#   ______________22. 2023-03-20 // 250 // 8 // 2023 // 986905 // 05_025_0#H // 225g25g275gG
#   ______________23. 2023-03-20 // 266 // 11 // 2023 // 987780 // 025_0#025+H // 2g225g25g275gG
#   ______________24. 2023-03-20 // 266 // 11 // 2023 // 987783 // 025_0#025+H // 2g225g25g275gG
#   ______________25. 2023-03-20 // 266 // 11 // 2023 // 987785 // 075_025_H // 15g175g2g225gG
#   ______________26. 2023-03-20 // 266 // 11 // 2023 // 987786 // 025_0#025+H // 2g225g25g275gG
#   ______________27. 2023-03-20 // 269 // 8 // 2023 // 1009264 // H // G
#   ______________28. 2023-03-20 // 283 // 8 // 2022 // 1015982 // H // G
#   ______________29. 2023-03-20 // 322 // 11 // 2022 // 968392 // H // G
#   ______________30. 2023-03-20 // 361 // 11 // 2023 // 1011578 // 1+H // 25g3gG
#   ______________31. 2023-03-20 // 361 // 11 // 2023 // 1011579 // 0#H // 25g3gG
#   ______________32. 2023-03-20 // 494 // 11 // 2022 // 966783 // None // None
#   ______________33. 2023-03-20 // 518 // 8 // 2022 // 913669 // H // G
#   ______________34. 2023-03-20 // 667 // 8 // 2023 // 1017785 // None // None
#   ______________35. 2023-03-20 // 673 // 8 // 2022 // 976342 // H // G
#   ______________36. 2023-03-20 // 673 // 8 // 2022 // 976343 // 0#H // 25gG
#   ______________37. 2023-03-20 // 703 // 11 // 2022 // 948596 // 025_0#025+H // 275g3g325g35g375gG
#   ______________38. 2023-03-20 // 703 // 11 // 2022 // 948597 // 025_0#025+H // 25g275g3g325g35g375gG
#   ______________39. 2023-03-20 // 703 // 11 // 2022 // 948598 // 025_0#025+H // 3g325g35g375g4g425gG
#   ______________40. 2023-03-20 // 703 // 11 // 2022 // 948599 // 025+075+1+125+H // 275g3g325g35g375gG
#   ______________41. 2023-03-20 // 740 // 11 // 2023 // 1010646 // None // None
#   ______________42. 2023-03-20 // 887 // 11 // 2022 // 964801 // H // G
#   ______________43. 2023-03-20 // 931 // 11 // 2022 // 912420 // 025_0#025+H // 25g275g3g325g35gG

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
