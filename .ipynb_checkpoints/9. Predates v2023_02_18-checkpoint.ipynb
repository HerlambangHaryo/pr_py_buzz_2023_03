# %%
# Import
from a_settings.messages import *   
from a_models.api_odds import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(0, space).strftime("%Y-%m-%d")
    date_raw       = get_today(0, space)  
    # -------------------------------------------------- 
    DICT = {
        'date_0' : date_0,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 0,
        'date_raw' : date_raw,
    }
    # --------------------------------------------------  
    PREP_ = "pre_"
    # -------------------------------------------------- 
    ao_controll_match_update(DICT, PREP_, space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 08:11:33
#   __main()
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-16 08:11:33.046767
#   ______get_today()
#   ________date_diff : 0
#   ________today_raw : 2023-03-16 08:11:33.051144
#   ______ao_controll_match_update()
#   ________aa_check_acccount()
#   __________API digitalmedia.arion@gmail.com counter is 99
#   __________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________ao_response_odds()
#   __________date_0 : 2023-03-16
#   __________page : 1
#   __________counter_loop : 0
#   __________date_diff : 0
#   __________date_raw : 2023-03-16 08:11:33.051144
#   ____________________________________________________________________________________
#   __________Total API Response(s) : 10
#
#   ____________1. Serbia,  Prva Liga  #287 - 2022 / 869147
#   ____________fixt date 2023-03-16 13:00:00+00:00
#   ____________fix local 2023-03-16 20:00:00
#   ____________local dat 2023-03-16 08:11:33
#   ____________Lebih
#   ______________league_rLeagues_id : 287
#   ______________league_rLeagues_name : Prva Liga
#   ______________bookmakersapi_rLeagues_id : 11
#   ______________bookmakers_rLeagues_name : 1xBet
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ______________11==11
#   __________________1 Match Winner
#   ____________________pre_match_winner_home = '4.64',
#   ____________________pre_match_winner_draw = '3.72',
#   ____________________pre_match_winner_away = '1.68',
#   __________________3 Second Half Winner
#   ____________________pre_second_half_winner_home = '4.70',
#   ____________________pre_second_half_winner_draw = '2.53',
#   ____________________pre_second_half_winner_away = '2.01',
#   __________________4 Asian Handicap
#   ____________________pre_asian_handicap_home_plus_0 = '3.42',
#   ____________________pre_asian_handicap_away_plus_0 = '1.25',
#   ____________________pre_asian_handicap_home_min_025 = '3.92',
#   ____________________pre_asian_handicap_away_min_025 = '1.20',
#   ____________________pre_asian_handicap_home_plus_025 = '2.54',
#   ____________________pre_asian_handicap_away_plus_025 = '1.44',
#   ____________________pre_asian_handicap_home_plus_075 = '1.91',
#   ____________________pre_asian_handicap_away_plus_075 = '1.87',
#   ____________________pre_asian_handicap_home_min_1 = '9.30',
#   ____________________pre_asian_handicap_away_min_1 = '1.02',
#   ____________________pre_asian_handicap_home_plus_1 = '1.64',
#   ____________________pre_asian_handicap_away_plus_1 = '2.22',
#   ____________________pre_asian_handicap_home_min_15 = '10.00',
#   ____________________pre_asian_handicap_away_min_15 = '1.01',
#   ____________________pre_asian_handicap_home_plus_15 = '1.36',
#   ____________________pre_asian_handicap_away_plus_15 = '2.81',
#   ____________________pre_asian_handicap_home_plus_125 = '1.46',
#   ____________________pre_asian_handicap_away_plus_125 = '2.50',
#   ____________________pre_asian_handicap_home_plus_175 = '1.26',
#   ____________________pre_asian_handicap_away_plus_175 = '3.42',
#   ____________________pre_asian_handicap_home_plus_2 = '1.13',
#   ____________________pre_asian_handicap_away_plus_2 = '4.74',
#   ____________________pre_asian_handicap_home_plus_25 = '1.10',
#   ____________________pre_asian_handicap_away_plus_25 = '5.50',
#   __________________5 Goals Over/Under
#   ____________________pre_goals_overunder_over_35 = '3.08',
#   ____________________pre_goals_overunder_under_35 = '1.30',
#   ____________________pre_goals_overunder_over_15 = '1.26',
#   ____________________pre_goals_overunder_under_15 = '3.34',
#   ____________________pre_goals_overunder_over_45 = '6.50',
#   ____________________pre_goals_overunder_under_45 = '1.08',
#   ____________________pre_goals_overunder_over_25 = '1.89',
#   ____________________pre_goals_overunder_under_25 = '1.89',
#   ____________________pre_goals_overunder_over_55 = '9.10',
#   ____________________pre_goals_overunder_under_55 = '1.03',
#   ____________________pre_goals_overunder_over_225 = '1.63',
#   ____________________pre_goals_overunder_under_225 = '2.11',
#   ____________________pre_goals_overunder_over_325 = '2.81',
#   ____________________pre_goals_overunder_under_325 = '1.37',
#   ____________________pre_goals_overunder_over_275 = '2.14',
#   ____________________pre_goals_overunder_under_275 = '1.70',
#   ____________________pre_goals_overunder_over_175 = '1.33',
#   ____________________pre_goals_overunder_under_175 = '3.00',
#   ____________________pre_goals_overunder_over_375 = '3.76',
#   ____________________pre_goals_overunder_under_375 = '1.22',
#   ____________________pre_goals_overunder_over_30 = '2.48',
#   ____________________pre_goals_overunder_under_30 = '1.46',
#   ____________________pre_goals_overunder_over_20 = '1.42',
#   ____________________pre_goals_overunder_under_20 = '2.61',
#   ____________________pre_goals_overunder_over_40 = '5.15',
#   ____________________pre_goals_overunder_under_40 = '1.11',
#   ____________________pre_goals_overunder_over_10 = '1.03',
#   ____________________pre_goals_overunder_under_10 = '8.10',
#   __________________6 Goals Over/Under First Half
#   ____________________pre_goals_overunder_first_half_over_15 = '2.73',
#   ____________________pre_goals_overunder_first_half_under_15 = '1.40',
#   ____________________pre_goals_overunder_first_half_over_25 = '6.90',
#   ____________________pre_goals_overunder_first_half_under_25 = '1.07',
#   ____________________pre_goals_overunder_first_half_over_05 = '1.36',
#   ____________________pre_goals_overunder_first_half_under_05 = '2.88',
#   ____________________pre_goals_overunder_first_half_over_125 = '2.28',
#   ____________________pre_goals_overunder_first_half_under_125 = '1.56',
#   ____________________pre_goals_overunder_first_half_over_075 = '1.51',
#   ____________________pre_goals_overunder_first_half_under_075 = '2.40',
#   ____________________pre_goals_overunder_first_half_over_10 = '1.81',
#   ____________________pre_goals_overunder_first_half_under_10 = '1.90',
#   __________________26 Goals Over/Under - Second Half
#   ____________________pre_goals_overunder__second_half_over_15 = '2.08',
#   ____________________pre_goals_overunder__second_half_under_15 = '1.67',
#   ____________________pre_goals_overunder__second_half_over_25 = '4.50',
#   ____________________pre_goals_overunder__second_half_under_25 = '1.16',
#   ____________________pre_goals_overunder__second_half_over_05 = '1.23',
#   ____________________pre_goals_overunder__second_half_under_05 = '3.70',
#   ____________________pre_goals_overunder__second_half_over_125 = '1.76',
#   ____________________pre_goals_overunder__second_half_under_125 = '1.95',
#   ____________________pre_goals_overunder__second_half_over_175 = '2.50',
#   ____________________pre_goals_overunder__second_half_under_175 = '1.47',
#   ____________________pre_goals_overunder__second_half_over_20 = '3.42',
#   ____________________pre_goals_overunder__second_half_under_20 = '1.27',
#   ____________________pre_goals_overunder__second_half_over_10 = '1.42',
#   ____________________pre_goals_overunder__second_half_under_10 = '2.66',
#   __________________7 HT/FT Double
#   __________________8 Both Teams Score
#   ____________________pre_both_teams_score_yes = '1.82',
#   ____________________pre_both_teams_score_no = '1.94',
#   __________________9 Handicap Result
#   ______________  ______________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 2.07
#   ______________  ______________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 2.81
#   ______________  ______________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.34
#   ______________  ______________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.36
#   ______________  ______________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 4.74
#   ______________  ______________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 5.50
#   __________________10 Exact Score
#   __________________11 Highest Scoring Half
#   __________________31 Correct Score - First Half
#   ______________  ______________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 6.50
#   ______________  ______________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 23.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 67.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.88
#   ______________  ______________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ______________  ______________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 8.50
#   ______________  ______________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 23.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 51.00
#   ______________  ______________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 21.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 41.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________62 Correct Score - Second Half
#   ______________  ______________bet_id: 62 --- bets_value: 1:0 --- bets_odd: 6.40
#   ______________  ______________bet_id: 62 --- bets_value: 2:0 --- bets_odd: 24.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:1 --- bets_odd: 27.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:0 --- bets_odd: 3.70
#   ______________  ______________bet_id: 62 --- bets_value: 1:1 --- bets_odd: 6.80
#   ______________  ______________bet_id: 62 --- bets_value: 2:2 --- bets_odd: 60.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:1 --- bets_odd: 3.50
#   ______________  ______________bet_id: 62 --- bets_value: 0:2 --- bets_odd: 6.80
#   ______________  ______________bet_id: 62 --- bets_value: 0:3 --- bets_odd: 26.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:2 --- bets_odd: 14.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:3 --- bets_odd: 55.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________  ______________bet_id: 62 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________12 Double Chance
#   ____________________pre_double_chance_home_draw = '2.07',
#   ____________________pre_double_chance_home_away = '1.23',
#   ____________________pre_double_chance_draw_away = '1.15',
#   __________________13 First Half Winner
#   ____________________pre_first_half_winner_home = '5.25',
#   ____________________pre_first_half_winner_draw = '2.17',
#   ____________________pre_first_half_winner_away = '2.20',
#   __________________16 Total - Home
#   ______________  ______________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 3.64
#   ______________  ______________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.22
#   ______________  ______________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.53
#   ______________  ______________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 2.27
#   ______________  ______________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 8.60
#   ______________  ______________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.02
#   ______________  ______________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 2.40
#   ______________  ______________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 1.48
#   __________________17 Total - Away
#   ______________  ______________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 1.76
#   ______________  ______________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.91
#   ______________  ______________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.13
#   ______________  ______________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 4.80
#   ______________  ______________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 2.54
#   ______________  ______________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.43
#   ______________  ______________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.24
#   ______________  ______________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 3.48
#   __________________18 Handicap Result - First Half
#   ______________  ______________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.52
#   ______________  ______________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 5.95
#   ______________  ______________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.26
#   __________________19 Asian Handicap First Half
#   __________________20 Double Chance - First Half
#   __________________33 Double Chance - Second Half
#   ______________  ______________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.63
#   ______________  ______________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.39
#   ______________  ______________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.12
#   __________________34 Both Teams Score - First Half
#   __________________35 Both Teams To Score - Second Half
#   __________________21 Odd/Even
#   __________________22 Odd/Even - First Half
#   ______________  ______________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   ______________  ______________bet_id: 22 --- bets_value: Even --- bets_odd: 1.69
#   __________________23 Home Odd/Even
#   ______________  ______________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.12
#   ______________  ______________bet_id: 23 --- bets_value: Even --- bets_odd: 1.61
#   __________________60 Away Odd/Even
#   ______________  ______________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.86
#   ______________  ______________bet_id: 60 --- bets_value: Even --- bets_odd: 1.80
#   ______________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ______________2. Slovenia,  1. SNL  #373 - 2022 / 876868
#   ______________fixt date 2023-03-16 16:30:00+00:00
#   ______________fix local 2023-03-16 23:30:00
#   ______________local dat 2023-03-16 08:11:33
#   ______________Lebih
#   ________________league_rLeagues_id : 373
#   ________________league_rLeagues_name : 1. SNL
#   ________________bookmakersapi_rLeagues_id : 8
#   ________________bookmakers_rLeagues_name : Bet365
#   ______________Total fixtureapi_id Row(s) : 1
#   ______________good to Go 1
#   ________________8==8
#   ____________________1 Match Winner
#   ______________________pre_match_winner_home = '2.20',
#   ______________________pre_match_winner_draw = '3.00',
#   ______________________pre_match_winner_away = '3.25',
#   ____________________2 Home/Away
#   ______________________pre_homeaway_home = '1.62',
#   ______________________pre_homeaway_away = '2.20',
#   ____________________3 Second Half Winner
#   ______________________pre_second_half_winner_home = '2.63',
#   ______________________pre_second_half_winner_draw = '2.38',
#   ______________________pre_second_half_winner_away = '3.20',
#   ____________________4 Asian Handicap
#   ______________________pre_asian_handicap_home_plus_0 = '1.63',
#   ______________________pre_asian_handicap_away_plus_0 = '2.25',
#   ______________________pre_asian_handicap_home_min_025 = '1.98',
#   ______________________pre_asian_handicap_away_min_025 = '1.83',
#   ______________________pre_asian_handicap_home_plus_025 = '1.45',
#   ______________________pre_asian_handicap_away_plus_025 = '2.68',
#   ______________________pre_asian_handicap_home_min_05 = '2.30',
#   ______________________pre_asian_handicap_away_min_05 = '1.60',
#   ______________________pre_asian_handicap_home_plus_05 = '1.35',
#   ______________________pre_asian_handicap_away_plus_05 = '3.10',
#   ______________________pre_asian_handicap_home_min_075 = '2.68',
#   ______________________pre_asian_handicap_away_min_075 = '1.45',
#   ______________________pre_asian_handicap_home_plus_075 = '1.24',
#   ______________________pre_asian_handicap_away_plus_075 = '3.90',
#   ______________________pre_asian_handicap_home_min_1 = '3.55',
#   ______________________pre_asian_handicap_away_min_1 = '1.28',
#   ______________________pre_asian_handicap_home_plus_1 = '1.13',
#   ______________________pre_asian_handicap_away_plus_1 = '5.90',
#   ______________________pre_asian_handicap_home_min_15 = '4.50',
#   ______________________pre_asian_handicap_away_min_15 = '1.19',
#   ______________________pre_asian_handicap_home_plus_15 = '1.11',
#   ______________________pre_asian_handicap_away_plus_15 = '6.80',
#   ______________________pre_asian_handicap_home_min_125 = '4.10',
#   ______________________pre_asian_handicap_away_min_125 = '1.23',
#   ______________________pre_asian_handicap_home_min_175 = '6.00',
#   ______________________pre_asian_handicap_away_min_175 = '1.13',
#   ______________________pre_asian_handicap_home_plus_125 = '1.12',
#   ______________________pre_asian_handicap_away_plus_125 = '6.40',
#   ____________________5 Goals Over/Under
#   ______________________pre_goals_overunder_over_35 = '3.75',
#   ______________________pre_goals_overunder_under_35 = '1.25',
#   ______________________pre_goals_overunder_over_15 = '1.33',
#   ______________________pre_goals_overunder_under_15 = '3.25',
#   ______________________pre_goals_overunder_over_45 = '7.00',
#   ______________________pre_goals_overunder_under_45 = '1.08',
#   ______________________pre_goals_overunder_over_25 = '2.10',
#   ______________________pre_goals_overunder_under_25 = '1.70',
#   ______________________pre_goals_overunder_over_05 = '1.06',
#   ______________________pre_goals_overunder_under_05 = '8.00',
#   ______________________pre_goals_overunder_over_55 = '10.50',
#   ______________________pre_goals_overunder_under_55 = '1.03',
#   ______________________pre_goals_overunder_over_65 = '17.00',
#   ______________________pre_goals_overunder_under_65 = '1.01',
#   ______________________pre_goals_overunder_over_75 = '21.00',
#   ______________________pre_goals_overunder_under_75 = '1.00',
#   ____________________6 Goals Over/Under First Half
#   ______________________pre_goals_overunder_first_half_over_35 = '26.00',
#   ______________________pre_goals_overunder_first_half_under_35 = '1.01',
#   ______________________pre_goals_overunder_first_half_over_15 = '3.25',
#   ______________________pre_goals_overunder_first_half_under_15 = '1.33',
#   ______________________pre_goals_overunder_first_half_over_25 = '9.00',
#   ______________________pre_goals_overunder_first_half_under_25 = '1.07',
#   ______________________pre_goals_overunder_first_half_over_05 = '1.44',
#   ______________________pre_goals_overunder_first_half_under_05 = '2.63',
#   ____________________26 Goals Over/Under - Second Half
#   ______________________pre_goals_overunder__second_half_over_35 = '13.00',
#   ______________________pre_goals_overunder__second_half_under_35 = '1.04',
#   ______________________pre_goals_overunder__second_half_over_15 = '2.20',
#   ______________________pre_goals_overunder__second_half_under_15 = '1.62',
#   ______________________pre_goals_overunder__second_half_over_25 = '5.00',
#   ______________________pre_goals_overunder__second_half_under_25 = '1.17',
#   ______________________pre_goals_overunder__second_half_over_05 = '1.29',
#   ______________________pre_goals_overunder__second_half_under_05 = '3.50',
#   ____________________7 HT/FT Double
#   ____________________27 Clean Sheet - Home
#   ______________________pre_clean_sheet__home_yes = '2.63',
#   ______________________pre_clean_sheet__home_no = '1.44',
#   ____________________28 Clean Sheet - Away
#   ______________________pre_clean_sheet__away_yes = '3.50',
#   ______________________pre_clean_sheet__away_no = '1.29',
#   ____________________8 Both Teams Score
#   ______________________pre_both_teams_score_yes = '1.83',
#   ______________________pre_both_teams_score_no = '1.83',
#   ____________________9 Handicap Result
#   ________________  ________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 4.33
#   ________________  ________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.55
#   ________________  ________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.00
#   ________________  ________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.25
#   ________________  ________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 6.50
#   ________________  ________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.75
#   ________________  ________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.09
#   ________________  ________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 10.00
#   ________________  ________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 17.00
#   ________________  ________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 9.50
#   ________________  ________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 6.50
#   ________________  ________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.17
#   ________________  ________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 26.00
#   ________________  ________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 15.00
#   ________________  ________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.05
#   ____________________10 Exact Score
#   ____________________11 Highest Scoring Half
#   ____________________31 Correct Score - First Half
#   ________________  ________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.33
#   ________________  ________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 13.00
#   ________________  ________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 41.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 67.00
#   ________________  ________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 151.00
#   ________________  ________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 151.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.63
#   ________________  ________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ________________  ________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 5.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 17.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ________________  ________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 151.00
#   ________________  ________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 29.00
#   ________________  ________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   ________________  ________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 151.00
#   ____________________12 Double Chance
#   ______________________pre_double_chance_home_draw = '1.25',
#   ______________________pre_double_chance_home_away = '1.30',
#   ______________________pre_double_chance_draw_away = '1.55',
#   ____________________13 First Half Winner
#   ______________________pre_first_half_winner_home = '3.00',
#   ______________________pre_first_half_winner_draw = '2.05',
#   ______________________pre_first_half_winner_away = '3.60',
#   ____________________14 Team To Score First
#   ________________  ________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.80
#   ________________  ________________bet_id: 14 --- bets_value: Draw --- bets_odd: 8.00
#   ________________  ________________bet_id: 14 --- bets_value: Away --- bets_odd: 2.38
#   ____________________15 Team To Score Last
#   ________________  ________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.80
#   ________________  ________________bet_id: 15 --- bets_value: Draw --- bets_odd: 8.00
#   ________________  ________________bet_id: 15 --- bets_value: Away --- bets_odd: 2.38
#   ____________________32 Win Both Halves
#   ______________________pre_win_both_halves_home = '8.00',
#   ______________________pre_win_both_halves_away = '11.00',
#   ____________________16 Total - Home
#   ________________  ________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 10.00
#   ________________  ________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.03
#   ________________  ________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.38
#   ________________  ________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.53
#   ________________  ________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 17.00
#   ________________  ________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   ________________  ________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 5.00
#   ________________  ________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.14
#   ____________________17 Total - Away
#   ________________  ________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 12.00
#   ________________  ________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.02
#   ________________  ________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 3.00
#   ________________  ________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.36
#   ________________  ________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 21.00
#   ________________  ________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   ________________  ________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 7.00
#   ________________  ________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.08
#   ____________________18 Handicap Result - First Half
#   ________________  ________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 10.00
#   ________________  ________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.36
#   ________________  ________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.75
#   ________________  ________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.29
#   ________________  ________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 13.00
#   ________________  ________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 4.33
#   ________________  ________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 34.00
#   ________________  ________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 12.00
#   ________________  ________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.05
#   ________________  ________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 151.00
#   ________________  ________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 41.00
#   ________________  ________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.01
#   ____________________19 Asian Handicap First Half
#   ____________________20 Double Chance - First Half
#   ____________________34 Both Teams Score - First Half
#   ____________________35 Both Teams To Score - Second Half
#   ____________________36 Win To Nil
#   ______________________pre_win_to_nil_home = '3.75',
#   ______________________pre_win_to_nil_away = '5.50',
#   ____________________21 Odd/Even
#   ____________________22 Odd/Even - First Half
#   ________________  ________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.20
#   ________________  ________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.67
#   ____________________23 Home Odd/Even
#   ________________  ________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.00
#   ________________  ________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.73
#   ____________________60 Away Odd/Even
#   ________________  ________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.10
#   ________________  ________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.67
#   ____________________39 To Win Either Half
#   ______________________pre_to_win_either_half_home = '1.73',
#   ______________________pre_to_win_either_half_away = '2.00',
#   ____________________40 Home Team Exact Goals Number
#   ____________________41 Away Team Exact Goals Number
#   ____________________24 Results/Both Teams Score
#   ______________________pre_results_both_teams_score_home_yes = '5.00',
#   ______________________pre_results_both_teams_score_draw_yes = '4.33',
#   ______________________pre_results_both_teams_score_away_yes = '7.00',
#   ______________________pre_results_both_teams_score_home_no = '3.75',
#   ______________________pre_results_both_teams_score_draw_no = '8.00',
#   ______________________pre_results_both_teams_score_away_no = '5.50',
#   ____________________25 Result/Total Goals
#   ______________________pre_result_total_goals_home_over_25 = '4.00',
#   ______________________pre_result_total_goals_draw_over_25 = '13.00',
#   ______________________pre_result_total_goals_away_over_25 = '5.50',
#   ______________________pre_result_total_goals_home_under_25 = '4.75',
#   ______________________pre_result_total_goals_draw_under_25 = '3.75',
#   ______________________pre_result_total_goals_away_under_25 = '6.50',
#   ____________________45 Corners Over Under
#   ________________  ________________bet_id: 45 --- bets_value: Over 10.5 --- bets_odd: 1.98
#   ________________  ________________bet_id: 45 --- bets_value: Under 10.5 --- bets_odd: 1.83
#   ____________________63 Odd/Even - Second Half
#   ________________  ________________bet_id: 63 --- bets_value: Odd --- bets_odd: 2.00
#   ________________  ________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.73
#   ____________________48 To Score In Both Halves By Teams
#   ____________________50 Goal Line
#   ________________  ________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 3.70
#   ________________  ________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.26
#   ________________  ________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.35
#   ________________  ________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 3.10
#   ________________  ________________bet_id: 50 --- bets_value: Over 4.5 --- bets_odd: 7.00
#   ________________  ________________bet_id: 50 --- bets_value: Under 4.5 --- bets_odd: 1.10
#   ________________  ________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 2.15
#   ________________  ________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.68
#   ________________  ________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.60
#   ________________  ________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.30
#   ________________  ________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 3.10
#   ________________  ________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.35
#   ________________  ________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 6.80
#   ________________  ________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.11
#   ________________  ________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.88
#   ________________  ________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 1.93
#   ________________  ________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 3.45
#   ________________  ________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.30
#   ________________  ________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.43
#   ________________  ________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.53
#   ________________  ________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.23
#   ________________  ________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 4.00
#   ________________  ________________bet_id: 50 --- bets_value: Over 4.25 --- bets_odd: 6.60
#   ________________  ________________bet_id: 50 --- bets_value: Under 4.25 --- bets_odd: 1.11
#   ________________  ________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.45
#   ________________  ________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 2.68
#   ________________  ________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 4.65
#   ________________  ________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.18
#   ________________  ________________bet_id: 50 --- bets_value: Over 1 --- bets_odd: 1.11
#   ________________  ________________bet_id: 50 --- bets_value: Under 1 --- bets_odd: 6.80
#   ____________________72 Goal Line (1st Half)
#   ________________  ________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 3.10
#   ________________  ________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.35
#   ________________  ________________bet_id: 72 --- bets_value: Over 0.5 --- bets_odd: 1.48
#   ________________  ________________bet_id: 72 --- bets_value: Under 0.5 --- bets_odd: 2.60
#   ________________  ________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 6.80
#   ________________  ________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.11
#   ________________  ________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 6.60
#   ________________  ________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.11
#   ________________  ________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.60
#   ________________  ________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.48
#   ________________  ________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 4.15
#   ________________  ________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.22
#   ________________  ________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 2.08
#   ________________  ________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.73
#   ________________  ________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.65
#   ________________  ________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.20
#   ____________________85 Total Corners (3 way)
#   ________________  ________________bet_id: 85 --- bets_value: Over 5 --- bets_odd: 1.04
#   ________________  ________________bet_id: 85 --- bets_value: Under 5 --- bets_odd: 21.00
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 5 --- bets_odd: 19.00
#   ________________  ________________bet_id: 85 --- bets_value: Over 6 --- bets_odd: 1.08
#   ________________  ________________bet_id: 85 --- bets_value: Under 6 --- bets_odd: 13.00
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 6 --- bets_odd: 15.00
#   ________________  ________________bet_id: 85 --- bets_value: Over 7 --- bets_odd: 1.18
#   ________________  ________________bet_id: 85 --- bets_value: Under 7 --- bets_odd: 8.00
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 7 --- bets_odd: 11.00
#   ________________  ________________bet_id: 85 --- bets_value: Over 8 --- bets_odd: 1.33
#   ________________  ________________bet_id: 85 --- bets_value: Under 8 --- bets_odd: 4.50
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 8 --- bets_odd: 9.00
#   ________________  ________________bet_id: 85 --- bets_value: Over 9 --- bets_odd: 1.57
#   ________________  ________________bet_id: 85 --- bets_value: Under 9 --- bets_odd: 3.25
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 9 --- bets_odd: 8.50
#   ________________  ________________bet_id: 85 --- bets_value: Over 10 --- bets_odd: 1.91
#   ________________  ________________bet_id: 85 --- bets_value: Under 10 --- bets_odd: 2.25
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 10 --- bets_odd: 8.00
#   ________________  ________________bet_id: 85 --- bets_value: Over 11 --- bets_odd: 2.50
#   ________________  ________________bet_id: 85 --- bets_value: Under 11 --- bets_odd: 1.80
#   ________________  ________________bet_id: 85 --- bets_value: Exactly 11 --- bets_odd: 8.50
#   ____________________73 Both Teams to Score 1st Half - 2nd Half
#   ____________________77 Total Corners (1st Half)
#   ________________  ________________bet_id: 77 --- bets_value: Over 5 --- bets_odd: 1.98
#   ________________  ________________bet_id: 77 --- bets_value: Under 5 --- bets_odd: 1.83
#   ____________________84 Total Corners (3 way) (1st Half)
#   ________________  ________________bet_id: 84 --- bets_value: Over 5 --- bets_odd: 2.30
#   ________________  ________________bet_id: 84 --- bets_value: Under 5 --- bets_odd: 2.10
#   ________________  ________________bet_id: 84 --- bets_value: Exactly 5 --- bets_odd: 5.50
#   ________________fixture_status_update: , pre_odd_updated_at = current_timestamp
#
#   ________________3. Slovenia,  1. SNL  #373 - 2022 / 876869
#   ________________fixt date 2023-03-16 14:00:00+00:00
#   ________________fix local 2023-03-16 21:00:00
#   ________________local dat 2023-03-16 08:11:33
#   ________________Lebih
#   __________________league_rLeagues_id : 373
#   __________________league_rLeagues_name : 1. SNL
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   __________________8==8
#   ______________________1 Match Winner
#   ________________________pre_match_winner_home = '2.55',
#   ________________________pre_match_winner_draw = '3.10',
#   ________________________pre_match_winner_away = '2.55',
#   ______________________2 Home/Away
#   ________________________pre_homeaway_home = '1.83',
#   ________________________pre_homeaway_away = '1.83',
#   ______________________3 Second Half Winner
#   ________________________pre_second_half_winner_home = '2.88',
#   ________________________pre_second_half_winner_draw = '2.38',
#   ________________________pre_second_half_winner_away = '2.88',
#   ______________________4 Asian Handicap
#   ________________________pre_asian_handicap_home_plus_0 = '1.88',
#   ________________________pre_asian_handicap_away_plus_0 = '1.93',
#   ________________________pre_asian_handicap_home_min_025 = '2.25',
#   ________________________pre_asian_handicap_away_min_025 = '1.63',
#   ________________________pre_asian_handicap_home_plus_025 = '1.63',
#   ________________________pre_asian_handicap_away_plus_025 = '2.25',
#   ________________________pre_asian_handicap_home_min_05 = '2.50',
#   ________________________pre_asian_handicap_away_min_05 = '1.50',
#   ________________________pre_asian_handicap_home_plus_05 = '1.48',
#   ________________________pre_asian_handicap_away_plus_05 = '2.60',
#   ________________________pre_asian_handicap_home_min_075 = '3.10',
#   ________________________pre_asian_handicap_away_min_075 = '1.35',
#   ________________________pre_asian_handicap_home_plus_075 = '1.33',
#   ________________________pre_asian_handicap_away_plus_075 = '3.30',
#   ________________________pre_asian_handicap_home_min_1 = '4.40',
#   ________________________pre_asian_handicap_away_min_1 = '1.20',
#   ________________________pre_asian_handicap_home_plus_1 = '1.20',
#   ________________________pre_asian_handicap_away_plus_1 = '4.40',
#   ________________________pre_asian_handicap_home_min_15 = '5.50',
#   ________________________pre_asian_handicap_away_min_15 = '1.15',
#   ________________________pre_asian_handicap_home_plus_15 = '1.15',
#   ________________________pre_asian_handicap_away_plus_15 = '5.50',
#   ________________________pre_asian_handicap_home_min_125 = '4.80',
#   ________________________pre_asian_handicap_away_min_125 = '1.18',
#   ________________________pre_asian_handicap_home_min_175 = '7.00',
#   ________________________pre_asian_handicap_away_min_175 = '1.10',
#   ________________________pre_asian_handicap_home_plus_125 = '1.17',
#   ________________________pre_asian_handicap_away_plus_125 = '5.00',
#   ______________________5 Goals Over/Under
#   ________________________pre_goals_overunder_over_35 = '3.75',
#   ________________________pre_goals_overunder_under_35 = '1.25',
#   ________________________pre_goals_overunder_over_15 = '1.33',
#   ________________________pre_goals_overunder_under_15 = '3.25',
#   ________________________pre_goals_overunder_over_45 = '7.00',
#   ________________________pre_goals_overunder_under_45 = '1.08',
#   ________________________pre_goals_overunder_over_25 = '2.10',
#   ________________________pre_goals_overunder_under_25 = '1.70',
#   ________________________pre_goals_overunder_over_05 = '1.07',
#   ________________________pre_goals_overunder_under_05 = '7.50',
#   ________________________pre_goals_overunder_over_55 = '10.50',
#   ________________________pre_goals_overunder_under_55 = '1.03',
#   ________________________pre_goals_overunder_over_65 = '17.00',
#   ________________________pre_goals_overunder_under_65 = '1.01',
#   ______________________6 Goals Over/Under First Half
#   ________________________pre_goals_overunder_first_half_over_35 = '26.00',
#   ________________________pre_goals_overunder_first_half_under_35 = '1.01',
#   ________________________pre_goals_overunder_first_half_over_15 = '3.25',
#   ________________________pre_goals_overunder_first_half_under_15 = '1.33',
#   ________________________pre_goals_overunder_first_half_over_25 = '9.00',
#   ________________________pre_goals_overunder_first_half_under_25 = '1.07',
#   ________________________pre_goals_overunder_first_half_over_05 = '1.44',
#   ________________________pre_goals_overunder_first_half_under_05 = '2.63',
#   ______________________26 Goals Over/Under - Second Half
#   ________________________pre_goals_overunder__second_half_over_35 = '13.00',
#   ________________________pre_goals_overunder__second_half_under_35 = '1.04',
#   ________________________pre_goals_overunder__second_half_over_15 = '2.20',
#   ________________________pre_goals_overunder__second_half_under_15 = '1.62',
#   ________________________pre_goals_overunder__second_half_over_25 = '5.00',
#   ________________________pre_goals_overunder__second_half_under_25 = '1.17',
#   ________________________pre_goals_overunder__second_half_over_05 = '1.25',
#   ________________________pre_goals_overunder__second_half_under_05 = '3.75',
#   ______________________7 HT/FT Double
#   ______________________27 Clean Sheet - Home
#   ________________________pre_clean_sheet__home_yes = '3.00',
#   ________________________pre_clean_sheet__home_no = '1.36',
#   ______________________28 Clean Sheet - Away
#   ________________________pre_clean_sheet__away_yes = '3.00',
#   ________________________pre_clean_sheet__away_no = '1.36',
#   ______________________8 Both Teams Score
#   ________________________pre_both_teams_score_yes = '1.83',
#   ________________________pre_both_teams_score_no = '1.83',
#   ______________________9 Handicap Result
#   __________________  __________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.00
#   __________________  __________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.44
#   __________________  __________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.33
#   __________________  __________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.44
#   __________________  __________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 5.00
#   __________________  __________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.33
#   __________________  __________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.11
#   __________________  __________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 7.50
#   __________________  __________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 12.00
#   __________________  __________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 12.00
#   __________________  __________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 7.50
#   __________________  __________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.11
#   __________________  __________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 29.00
#   __________________  __________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 17.00
#   __________________  __________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.04
#   __________________  __________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.04
#   __________________  __________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 17.00
#   __________________  __________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 29.00
#   ______________________10 Exact Score
#   ______________________11 Highest Scoring Half
#   ______________________31 Correct Score - First Half
# ...
#   ________________________8 Both Teams Score
#   __________________________pre_both_teams_score_yes = '1.89',
#   __________________________pre_both_teams_score_no = '1.87',
#   ________________________9 Handicap Result
#   ____________________  ____________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.35
#   ____________________  ____________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.48
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.10
#   ____________________  ____________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.45
#   ____________________  ____________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 5.55
#   ____________________  ____________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.10
#   ________________________10 Exact Score
#   ________________________11 Highest Scoring Half
#   ________________________31 Correct Score - First Half
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.80
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 16.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 27.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.52
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.80
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 17.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 29.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 500.00
#   ________________________62 Correct Score - Second Half
#   ____________________  ____________________bet_id: 62 --- bets_value: 1:0 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 2:0 --- bets_odd: 14.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 2:1 --- bets_odd: 20.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 3:0 --- bets_odd: 45.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 3:1 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 3:2 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 4:0 --- bets_odd: 447.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 4:1 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 4:2 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 4:3 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 5:0 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 5:1 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 5:2 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 5:3 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 5:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 0:0 --- bets_odd: 3.34
#   ____________________  ____________________bet_id: 62 --- bets_value: 1:1 --- bets_odd: 7.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 2:2 --- bets_odd: 45.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 3:3 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 4:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 0:1 --- bets_odd: 5.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 0:2 --- bets_odd: 13.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 0:3 --- bets_odd: 45.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 0:4 --- bets_odd: 492.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 0:5 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 1:2 --- bets_odd: 18.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 1:3 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 1:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 1:5 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 2:3 --- bets_odd: 60.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 2:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 2:5 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 3:4 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 3:5 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 4:5 --- bets_odd: 500.00
#   ____________________  ____________________bet_id: 62 --- bets_value: 5:5 --- bets_odd: 500.00
#   ________________________12 Double Chance
#   __________________________pre_double_chance_home_draw = '1.45',
#   __________________________pre_double_chance_home_away = '1.35',
#   __________________________pre_double_chance_draw_away = '1.48',
#   ________________________13 First Half Winner
#   __________________________pre_first_half_winner_home = '3.30',
#   __________________________pre_first_half_winner_draw = '1.99',
#   __________________________pre_first_half_winner_away = '3.48',
#   ________________________16 Total - Home
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.70
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.47
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 7.10
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.10
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.37
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 3.10
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 5.50
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.15
#   ____________________  ____________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.77
#   ____________________  ____________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 2.00
#   ________________________17 Total - Away
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.80
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.43
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 7.70
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.08
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.40
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 2.90
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 6.00
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.13
#   ____________________  ____________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.85
#   ____________________  ____________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 1.90
#   ________________________18 Handicap Result - First Half
#   ____________________  ____________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 11.00
#   ____________________  ____________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.27
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 4.24
#   ____________________  ____________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.25
#   ____________________  ____________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 11.50
#   ____________________  ____________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 4.30
#   ________________________19 Asian Handicap First Half
#   ________________________20 Double Chance - First Half
#   ________________________33 Double Chance - Second Half
#   ____________________  ____________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.30
#   ____________________  ____________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.52
#   ____________________  ____________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.33
#   ________________________34 Both Teams Score - First Half
#   ________________________35 Both Teams To Score - Second Half
#   ________________________21 Odd/Even
#   ________________________22 Odd/Even - First Half
#   ____________________  ____________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.14
#   ____________________  ____________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.66
#   ________________________23 Home Odd/Even
#   ____________________  ____________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.02
#   ____________________  ____________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.74
#   ________________________60 Away Odd/Even
#   ____________________  ____________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.04
#   ____________________  ____________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.73
#   ________________________55 Corners 1x2
#   ________________________45 Corners Over Under
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 5.5 --- bets_odd: 1.02
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 5.5 --- bets_odd: 9.20
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 6.5 --- bets_odd: 1.09
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 6.5 --- bets_odd: 5.70
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 1.81
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 1.94
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 10.5 --- bets_odd: 2.29
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 10.5 --- bets_odd: 1.55
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 7.5 --- bets_odd: 1.23
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 7.5 --- bets_odd: 3.56
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 11.5 --- bets_odd: 3.08
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 11.5 --- bets_odd: 1.30
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 8.5 --- bets_odd: 1.45
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 8.5 --- bets_odd: 2.57
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 13.5 --- bets_odd: 6.35
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 13.5 --- bets_odd: 1.07
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 12.5 --- bets_odd: 4.40
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 12.5 --- bets_odd: 1.16
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 7.75 --- bets_odd: 1.26
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 7.75 --- bets_odd: 3.44
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 8.25 --- bets_odd: 1.37
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 8.25 --- bets_odd: 2.86
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 10.75 --- bets_odd: 2.50
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 10.75 --- bets_odd: 1.47
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 10.25 --- bets_odd: 2.17
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 10.25 --- bets_odd: 1.61
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 9.25 --- bets_odd: 1.68
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 9.25 --- bets_odd: 2.06
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 8.75 --- bets_odd: 1.50
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 8.75 --- bets_odd: 2.41
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 9.75 --- bets_odd: 1.91
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 9.75 --- bets_odd: 1.83
#   ____________________  ____________________bet_id: 45 --- bets_value: Over 11.25 --- bets_odd: 2.96
#   ____________________  ____________________bet_id: 45 --- bets_value: Under 11.25 --- bets_odd: 1.34
#   ____________________fixture_status_update: , pre_odd_updated_at = current_timestamp

# %%
# Import
from a_settings.messages import *   
from a_models.api_odds import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(1, space).strftime("%Y-%m-%d")
    date_raw       = get_today(1, space)  
    # -------------------------------------------------- 
    DICT = {
        'date_0' : date_0,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 1,
        'date_raw' : date_raw,
    }
    # --------------------------------------------------  
    PREP_ = "pre_"
    # -------------------------------------------------- 
    ao_controll_match_update(DICT, PREP_, space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################

# %%
# Import
from a_settings.messages import *   
from a_models.football_fixtures import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(0, space).strftime("%Y-%m-%d")  
    date_raw         = get_today(0, space)
    # --------------------------------------------------   
    ff_gak_sempet_predates(date_0, date_raw, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################

# %%
# Import
from a_settings.messages import *   
from a_models.football_fixtures import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(1, space).strftime("%Y-%m-%d")  
    date_raw         = get_today(0, space)
    # --------------------------------------------------   
    ff_gak_sempet_predates(date_0, date_raw, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################

# %%
# Import
from a_settings.messages import *   
from a_models.football_fixtures import *   
    
def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today(0, space).strftime("%Y-%m-%d")
    date_0_raw       = get_today(0, space)  
    # --------------------------------------------------  
    date_1         = get_today(1, space).strftime("%Y-%m-%d")
    date_1_raw       = get_today(1, space)  
    # --------------------------------------------------   
    # --------------------------------------------------  
    ff_get_fixture_today_xpattern_advices(date_0, date_1, "xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
