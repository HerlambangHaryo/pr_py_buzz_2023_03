# %%
# Import
from a_settings.messages import *  
from a_models.predefine import *  

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------   
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=1)
    preday1 = today + DD
    day1 = preday1.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    print(space + "> day1 : " +  str(preday1) ) 
    # --------------------------------------------------   
    pd_get_fixtures_next_match(day0, preday1, 'fixture', space) 
#     pd_get_fixtures_next_match(day0, day1, ROUTES, space)
    # --------------------------------------------------  
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 09:17:37
#   __main()
#   ____get_date()
#   ______> day0 : 2023-03-16
#   ______> day1 : 2023-03-17 09:17:37.720436
#   ________pd_get_fixtures_next_match()
#   __________Select   teams_home_id,  teams_away_id,  leagueapi_id,  season,  fixtureapi_id,  teams_home,  teams_away,  date  , pre_both_teams_score_yes  , pre_both_teams_score_no  , pre_rcard_yes  , pre_rcard_no  , pre_first_half_winner_home  , pre_first_half_winner_draw  , pre_first_half_winner_away  , pre_second_half_winner_home  , pre_second_half_winner_draw  , pre_second_half_winner_away  , pre_htft_double_home_home  , pre_htft_double_home_draw  , pre_htft_double_home_away  , pre_htft_double_draw_home  , pre_htft_double_draw_draw  , pre_htft_double_draw_away  , pre_htft_double_away_home  , pre_htft_double_away_draw  , pre_htft_double_away_away  , pre_both_teams_score__first_half_yes  , pre_both_teams_score__first_half_no  , pre_both_teams_to_score__second_half_yes  , pre_both_teams_to_score__second_half_no  , pre_results_both_teams_score_home_yes  , pre_results_both_teams_score_draw_yes  , pre_results_both_teams_score_away_yes  , pre_results_both_teams_score_home_no  , pre_results_both_teams_score_draw_no  , pre_results_both_teams_score_away_no  , pre_to_score_in_both_halves_by_teams_home , pre_to_score_in_both_halves_by_teams_away , pre_total_goals_both_teams_to_score_over_yes_25 , pre_total_goals_both_teams_to_score_over_no_25 , pre_total_goals_both_teams_to_score_under_yes_25 , pre_total_goals_both_teams_to_score_under_no_25 , pre_both_teams_to_score_1st_half__2nd_half_yes_yes , pre_both_teams_to_score_1st_half__2nd_half_yes_no , pre_both_teams_to_score_1st_half__2nd_half_no_yes , pre_both_teams_to_score_1st_half__2nd_half_no_no , pre_highest_scoring_half_first , pre_highest_scoring_half_draw , pre_highest_scoring_half_second , pre_double_chance_home_draw , pre_double_chance_home_away , pre_double_chance_draw_away , pre_double_chance__first_half_home_draw , pre_double_chance__first_half_home_away , pre_double_chance__first_half_draw_away , pre_oddeven_odd , pre_oddeven_even , pre_result_total_goals_home_over_35 , pre_result_total_goals_draw_over_35 , pre_result_total_goals_away_over_35 , pre_result_total_goals_home_under_35 , pre_result_total_goals_draw_under_35 , pre_result_total_goals_away_under_35 , pre_result_total_goals_home_over_25 , pre_result_total_goals_draw_over_25 , pre_result_total_goals_away_over_25 , pre_result_total_goals_home_under_25 , pre_result_total_goals_draw_under_25 , pre_result_total_goals_away_under_25 , pre_clean_sheet__home_yes , pre_clean_sheet__home_no , pre_clean_sheet__away_yes , pre_clean_sheet__away_no , pre_win_both_halves_home , pre_win_both_halves_away , pre_win_to_nil_home , pre_win_to_nil_away , pre_to_win_either_half_home , pre_to_win_either_half_away , pre_halftime_result_both_teams_score_home_yes , pre_halftime_result_both_teams_score_draw_yes , pre_halftime_result_both_teams_score_away_yes , pre_halftime_result_both_teams_score_home_no , pre_halftime_result_both_teams_score_draw_no , pre_halftime_result_both_teams_score_away_no , pre_exact_goals_number__first_half_0 , pre_exact_goals_number__first_half_1 , pre_exact_goals_number__first_half_2 , pre_exact_goals_number__first_half_3 , pre_exact_goals_number__first_half_4 , pre_exact_goals_number__first_half_more_5 , pre_second_half_exact_goals_number_0 , pre_second_half_exact_goals_number_1 , pre_second_half_exact_goals_number_2 , pre_second_half_exact_goals_number_3 , pre_second_half_exact_goals_number_4 , pre_second_half_exact_goals_number_more_5 , pre_home_team_exact_goals_number_0 , pre_home_team_exact_goals_number_1 , pre_home_team_exact_goals_number_2 , pre_home_team_exact_goals_number_more_3 , pre_away_team_exact_goals_number_0 , pre_away_team_exact_goals_number_1 , pre_away_team_exact_goals_number_2 , pre_away_team_exact_goals_number_more_3 from football_fixtures  where date >= '2023-03-16'  and date <= '2023-03-17 09:17:37.720436'  and fixture_status like 'Not Started'  and deleted_at is null  order by date asc
#   __________Total Row(s) : 62
#   ____________[1/62] 16 - 2023 -----#Orlando City SC 1598 - Tigres UANL 2279 - 2023-03-16 00:15:00
#
#   ____________[2/62] 263 - 2022 -----#Monarcas 2284 - Raya2 16850 - 2023-03-16 01:05:00
#
#   ____________[3/62] 16 - 2023 -----#Los Angeles FC 1616 - LD Alajuelense 822 - 2023-03-16 02:30:00
#   ______________pre_first_half_winner_home:1.91
#   ______________pre_second_half_winner_home:1.67
#   ______________pre_to_win_either_half_home:1.22
#   ______________pre_result_total_goals_home_over_25:2.1
#   ______________pre_clean_sheet__away_yes:8.0
#
#   ____________[4/62] 263 - 2022 -----#Dorados 2297 - Atlante FC 2312 - 2023-03-16 03:05:00
#
#   ____________[5/62] 274 - 2022 -----#Persija 10134 - PSIS Semarang 2451 - 2023-03-16 08:00:00
#
#   ____________[6/62] 274 - 2022 -----#Bali United 2448 - Persepam Madura Utd 2444 - 2023-03-16 10:00:00
#
#   ____________[7/62] 701 - 2022 -----#Farense U23 17474 - Marítimo U23 15466 - 2023-03-16 11:00:00
#
#   ____________[8/62] 291 - 2022 -----#Kheybar Khorramabad 2716 - Khalij Fars 18300 - 2023-03-16 11:15:00
#   ______________pre_first_half_winner_draw:1.97
#   ______________pre_second_half_winner_home:1.98
#   ______________pre_both_teams_score_yes:3.0
#
#   ____________[9/62] 291 - 2022 -----#Darya Babol 19965 - Esteghlal Mollasani 15540 - 2023-03-16 11:30:00
#   ______________pre_first_half_winner_draw:1.77
#
#   ____________[10/62] 291 - 2022 -----#Saipa 2736 - Shams Azar Qazvin 18159 - 2023-03-16 11:30:00
#   ______________pre_first_half_winner_draw:1.83
#
#   ____________[11/62] 291 - 2022 -----#Fajr Sepasi 2713 - Chooka Talesh 10387 - 2023-03-16 11:30:00
#   ______________pre_first_half_winner_home:1.93
#   ______________pre_double_chance_draw_away:3.0
#
#   ____________[12/62] 291 - 2022 -----#Shahrdari Hamedan 18014 - Khooshe Talaee Saveh 7501 - 2023-03-16 11:30:00
#   ______________pre_first_half_winner_draw:1.86
#   ______________pre_both_teams_score_yes:2.5
#
#   ____________[13/62] 278 - 2023 -----#Negeri Sembilan 2502 - Terengganu 2518 - 2023-03-16 12:15:00
#
#   ____________[14/62] 887 - 2022 -----#Telephonaat Beni Suef 13823 - Asmant Asyut 20455 - 2023-03-16 13:00:00
#
#   ____________[15/62] 887 - 2022 -----#Al Nasr Taaden 1047 - El Minya 13821 - 2023-03-16 13:00:00
#
#   ____________[16/62] 887 - 2022 -----#Shoban Moslemen Qena 20456 - Misr EL Makasa 1038 - 2023-03-16 13:00:00
#
#   ____________[17/62] 887 - 2022 -----#Tamya 18027 - Aluminium Nag Hammadi 18020 - 2023-03-16 13:00:00
#
#   ____________[18/62] 887 - 2022 -----#Mallawi 18026 - Dayrout 18022 - 2023-03-16 13:00:00
#
#   ____________[19/62] 887 - 2022 -----#Asyut Petrol 18021 - Kima Aswan 16435 - 2023-03-16 13:00:00
#
#   ____________[20/62] 887 - 2022 -----#El Gouna FC 1574 - La Viena FC 16436 - 2023-03-16 13:00:00
#
#   ____________[21/62] 307 - 2022 -----#Al Khaleej Saihat 2928 - Al Taee 2942 - 2023-03-16 13:00:00
#
#   ____________[22/62] 889 - 2022 -----#Helal Aldabaa 20460 - Kafr El Sheikh 18041 - 2023-03-16 13:00:00
#   ______________pre_first_half_winner_draw:1.83
#
#   ____________[23/62] 278 - 2023 -----#Perak 2524 - Pahang 2525 - 2023-03-16 13:00:00
#
#   ____________[24/62] 943 - 2022 -----#Fidelis Andria 1695 - Crotone 501 - 2023-03-16 13:30:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_both_teams_score_yes:2.5
#
#   ____________[25/62] 233 - 2022 -----#Ghazl El Mehalla 13819 - Al Ittihad 1572 - 2023-03-16 15:00:00
#
#   ____________[26/62] 237 - 2022 -----#Nizhny Novgorod 2011 - FC Rostov 779 - 2023-03-16 15:00:00
#   ______________pre_first_half_winner_draw:1.99
#
#   ____________[27/62] 307 - 2022 -----#Al-Raed 2935 - Al Shabab 2940 - 2023-03-16 16:30:00
#
#   ____________[28/62] 943 - 2022 -----#Catanzaro 1687 - Monterosi 882 - 2023-03-16 16:30:00
#   ______________pre_first_half_winner_home:1.57
#   ______________pre_second_half_winner_home:1.4
#   ______________pre_to_win_either_half_home:1.13
#   ______________pre_win_to_nil_home:1.62
#   ______________pre_result_total_goals_home_over_25:1.83
#   ______________pre_both_teams_score_yes:2.75
#   ______________pre_double_chance_draw_away:4.0
#   ______________pre_clean_sheet__away_yes:7.5
#   ______________pre_to_win_either_half_away:6.5
#   ____________[29/62] 233 - 2022 -----#Smouha SC 1044 - Ismaily SC 1030 - 2023-03-16 17:00:00
#
#   ____________[30/62] 318 - 2022 -----#Doxa 3398 - Karmiotissa 3413 - 2023-03-16 17:00:00
#
#   ____________[31/62] 3 - 2022 -----#SC Freiburg 160 - Juventus 496 - 2023-03-16 17:45:00
#   ______________pre_first_half_winner_draw:2.0
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.95
#
#   ____________[32/62] 3 - 2022 -----#Fenerbahce 611 - Sevilla 536 - 2023-03-16 17:45:00
#
#   ____________[33/62] 3 - 2022 -----#Real Betis 543 - Manchester United 33 - 2023-03-16 17:45:00
#
#   ____________[34/62] 3 - 2022 -----#Feyenoord 209 - Shakhtar Donetsk 550 - 2023-03-16 17:45:00
#   ______________pre_first_half_winner_home:2.0
#   ______________pre_second_half_winner_home:1.73
#   ______________pre_to_win_either_half_home:1.29
#
#   ____________[35/62] 848 - 2022 -----#Sivasspor 1002 - Fiorentina 502 - 2023-03-16 17:45:00
#   ______________pre_second_half_winner_away:1.83
#
#   ____________[36/62] 848 - 2022 -----#Djurgardens IF 364 - Lech Poznan 347 - 2023-03-16 17:45:00
#
#   ____________[37/62] 848 - 2022 -----#Slovan Bratislava 656 - FC Basel 1893 551 - 2023-03-16 17:45:00
#
#   ____________[38/62] 740 - 2023 -----#Corinthians U20 12998 - RB Bragantino U20 18345 - 2023-03-16 18:00:00
#   ______________pre_second_half_winner_home:1.83
#
#   ____________[39/62] 740 - 2023 -----#Fortaleza U20 13009 - Athletico PR U20 12984 - 2023-03-16 18:00:00
#
#   ____________[40/62] 703 - 2022 -----#Queens Park Rangers U21 20085 - Charlton Athletic U21 20082 - 2023-03-16 19:00:00
#   ______________pre_both_teams_score_no:3.3
#
#   ____________[41/62] 357 - 2023 -----#Drogheda United 3850 - Dundalk 584 - 2023-03-16 19:45:00
#
#   ____________[42/62] 3 - 2022 -----#Union St. Gilloise 1393 - Union Berlin 182 - 2023-03-16 20:00:00
#
#   ____________[43/62] 3 - 2022 -----#Ferencvarosi TC 651 - Bayer Leverkusen 168 - 2023-03-16 20:00:00
#
#   ____________[44/62] 3 - 2022 -----#Arsenal 42 - Sporting CP 228 - 2023-03-16 20:00:00
#   ______________pre_first_half_winner_home:1.83
#   ______________pre_second_half_winner_home:1.62
#   ______________pre_to_win_either_half_home:1.22
#   ______________pre_result_total_goals_home_over_25:2.05
#   ______________pre_clean_sheet__away_yes:7.0
#
#   ____________[45/62] 3 - 2022 -----#Real Sociedad 548 - AS Roma 497 - 2023-03-16 20:00:00
#   ______________pre_first_half_winner_draw:1.95
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.83
#
#   ____________[46/62] 848 - 2022 -----#AZ Alkmaar 201 - Lazio 487 - 2023-03-16 20:00:00
#
#   ____________[47/62] 848 - 2022 -----#West Ham 48 - AEK Larnaca 614 - 2023-03-16 20:00:00
#   ______________pre_first_half_winner_home:1.73
#   ______________pre_second_half_winner_home:1.5
#   ______________pre_to_win_either_half_home:1.14
#   ______________pre_win_to_nil_home:1.8
#   ______________pre_result_total_goals_home_over_25:1.95
#   ______________pre_both_teams_score_yes:2.5
#   ______________pre_double_chance_draw_away:3.75
#   ______________pre_clean_sheet__away_yes:8.0
#   ______________pre_to_win_either_half_away:5.5
#
#   ____________[48/62] 848 - 2022 -----#Nice 84 - Sheriff Tiraspol 568 - 2023-03-16 20:00:00
#   ______________pre_first_half_winner_home:1.91
#   ______________pre_second_half_winner_home:1.67
#   ______________pre_to_win_either_half_home:1.25
#   ______________pre_to_win_either_half_away:4.0
#
#   ____________[49/62] 848 - 2022 -----#Villarreal 533 - Anderlecht 554 - 2023-03-16 20:00:00
#   ______________pre_first_half_winner_home:1.91
#   ______________pre_second_half_winner_home:1.67
#   ______________pre_to_win_either_half_home:1.25
#   ______________pre_result_total_goals_home_over_25:2.2
#   ______________pre_clean_sheet__away_yes:7.0
#
#   ____________[50/62] 740 - 2023 -----#Palmeiras U20 12968 - Goiás U20 12961 - 2023-03-16 21:30:00
#   ______________pre_first_half_winner_home:1.7
#   ______________pre_second_half_winner_home:1.53
#   ______________pre_double_chance_draw_away:3.52
#
#   ____________[51/62] 13 - 2023 -----#Cerro Porteno 1176 - Fortaleza EC 154 - 2023-03-16 22:00:00
#   ______________pre_first_half_winner_draw:2.0
#   ______________pre_total_goals_both_teams_to_score_under_no_25:2.0
#
#   ____________[52/62] 73 - 2023 -----#CSA 150 - Brusque 1211 - 2023-03-16 22:00:00
#   ______________pre_first_half_winner_draw:2.0
#
#   ____________[53/62] 73 - 2023 -----#Gremio 130 - Ferroviario 1195 - 2023-03-16 23:00:00
#   ______________pre_first_half_winner_home:1.67
#   ______________pre_double_chance_draw_away:4.0
#
#   ____________[54/62] 16 - 2023 -----#Leon 2289 - Tauro FC 2885 - 2023-03-17 00:00:00
#   ______________pre_first_half_winner_home:1.62
#   ______________pre_second_half_winner_home:1.44
#   ______________pre_to_win_either_half_home:1.13
#   ______________pre_win_to_nil_home:1.73
#   ______________pre_result_total_goals_home_over_25:1.83
#   ______________pre_both_teams_score_yes:2.5
#   ______________pre_double_chance_draw_away:4.0
#   ______________pre_clean_sheet__away_yes:9.0
#   ______________pre_to_win_either_half_away:6.0
#
#   ____________[55/62] 263 - 2022 -----#Cancún 14276 - Mineros de Zacatecas 2299 - 2023-03-17 01:05:00
#
#   ____________[56/62] 16 - 2023 -----#Pachuca 2292 - CD Motagua 1055 - 2023-03-17 02:15:00
#   ______________pre_first_half_winner_home:1.73
#   ______________pre_second_half_winner_home:1.5
#   ______________pre_to_win_either_half_home:1.14
#   ______________pre_win_to_nil_home:1.83
#   ______________pre_result_total_goals_home_over_25:1.91
#   ______________pre_double_chance_draw_away:3.75
#   ______________pre_clean_sheet__away_yes:9.0
#   ______________pre_to_win_either_half_away:5.0
#
#   ____________[57/62] 263 - 2022 -----#Tapatío 14278 - Cimarrones 2301 - 2023-03-17 03:05:00
#
#   ____________[58/62] 190 - 2022 -----#Adelaide United W 1972 - Newcastle Jets FC W 1975 - 2023-03-17 06:05:00
#
#   ____________[59/62] 274 - 2022 -----#PSM Makassar 2441 - Bhayangkara FC 2443 - 2023-03-17 08:00:00
#
#   ____________[60/62] 195 - 2023 -----#Bentleigh Greens 3799 - Dandenong Thunder 3801 - 2023-03-17 08:30:00
#
#   ____________[61/62] 195 - 2023 -----#South Melbourne 3811 - Heidelberg United 3803 - 2023-03-17 08:30:00
#   ______________pre_second_half_winner_home:1.95
#
#   ____________[62/62] 188 - 2022 -----#Adelaide United 948 - Wellington Phoenix 942 - 2023-03-17 08:45:00
#   ______________pre_total_goals_both_teams_to_score_over_yes_25:1.73
#   ______________pre_both_teams_score_no:2.5
#
# # -------------------------------------------------- End at 2023-03-16 09:18:11
