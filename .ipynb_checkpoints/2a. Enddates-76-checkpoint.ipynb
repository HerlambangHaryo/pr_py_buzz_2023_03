# %%
# Import
from a_settings.messages import *   

today = datetime.datetime.now()  
days0 = 7
days1 = 6
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 7 - 6 --> 2023-05-29 10:03:26.921983

# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    day0         = get_today_subs(days0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(days1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_check_enddates(day0, day1, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 10:03:27
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 7
#   ________today_raw : 2023-05-22 10:03:27.996694
#   ______get_today_subs()
#   ________subs date_diff : 6
#   ________today_raw : 2023-05-23 10:03:27.996694
#   ______fO_check_enddates()
#   ________Select  leagueapi_id as lg  , season as ss  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_homeapi_id) as home  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_awayapi_id) as away  , SUBSTR(fixture_status, 1, 15)  as fs  , end_response as er  , end_ah_pattern as ah  , end_gou_pattern as gou  from football_odds  where date >= '2023-05-22'  and date <= '2023-05-23'  and end_response is null  and deleted_at is null  and fixture_status like 'Match Finished'  order by leagueapi_id, date asc
#   ________Total Row(s) : 4
#
#     lg    ss     home     away              fs    er    ah   gou
# 0  256  2023  Patuxen  Christo  Match Finished  None  None  None
# 1  256  2023  Montere  SF Glen  Match Finished  None  None  None
# 2  318  2022  Olympia  Akritas  Match Finished  None  None  None
# 3  334  2022  Kremin'  Nyva Te  Match Finished  None  None  None
#
# # -------------------------------------------------- End at 2023-05-29 10:03:29

# %%
from a_settings.messages import *  
from a_models.football_odds import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    today_day = today.strftime("%Y-%m-%d")   
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "today : " + str(today_day))
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    fO_get_group_league_status_match_finished(tgl_awal, tgl_akhir, today_day, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 10:03:29
#   __main()
#   ____get_date()
#   ______today : 2023-05-29
#   ______days : 7
#   ______days : 6
#   ______tgl_awal : 2023-05-22
#   ______tgl_akhir : 2023-05-23
#   ________fO_get_group_league_status_match_finished()
#   ________Select  DATE(date)  , leagueapi_id , (select bookmakersapi_id from football_leagues where leagueapi_id = football_odds.leagueapi_id)  , season , DATE(end_odd_updated_at)  , fixture_status   from football_odds  where  date <= '2023-05-23'  and date >= '2023-05-22'  and fixture_status like 'Match Finished'  and deleted_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 43
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-05-22 // 62 // 11 // 2022 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API lincahlogistik@gmail.com counter is 7
#   __________________APIkey: 405acb0deemsha32f06ee6179f6bp1cce74jsnf61631260341
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 62
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. France,  Ligue 2  #62 - 2022 / 872204
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________2. 2023-05-22 // 71 // 8 // 2023 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API lincahlogistik@gmail.com counter is 6
#   __________________APIkey: 405acb0deemsha32f06ee6179f6bp1cce74jsnf61631260341
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 71
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Brazil,  Serie A  #71 - 2023 / 1005714
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________3. 2023-05-22 // 80 // 8 // 2022 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API lincahlogistik@gmail.com counter is 5
#   __________________APIkey: 405acb0deemsha32f06ee6179f6bp1cce74jsnf61631260341
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 80
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Germany,  3. Liga  #80 - 2022 / 879479
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________4. 2023-05-22 // 88 // 8 // 2022 // None // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API lincahlogistik@gmail.com counter is 4
#   __________________APIkey: 405acb0deemsha32f06ee6179f6bp1cce74jsnf61631260341
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 88
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________________> FUCKIN ZERO !
#   ____________5. 2023-05-22 // 95 // 8 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API lincahlogistik@gmail.com counter is 3
#   __________________APIkey: 405acb0deemsha32f06ee6179f6bp1cce74jsnf61631260341
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 95
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Portugal,  Segunda Liga  #95 - 2022 / 899204
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________6. 2023-05-22 // 106 // 8 // 2022 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API lincahlogistik@gmail.com counter is 2
#   __________________APIkey: 405acb0deemsha32f06ee6179f6bp1cce74jsnf61631260341
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 106
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Poland,  Ekstraklasa  #106 - 2022 / 865375
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________7. 2023-05-22 // 107 // 8 // 2022 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API lincahlogistik@gmail.com counter is 1
#   __________________APIkey: 405acb0deemsha32f06ee6179f6bp1cce74jsnf61631260341
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 107
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Poland,  I Liga  #107 - 2022 / 867154
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________8. 2023-05-22 // 113 // 8 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 99
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 113
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. Sweden,  Allsvenskan  #113 - 2023 / 1001877
#   ____________________good to Go 1
#
#   ____________________2. Sweden,  Allsvenskan  #113 - 2023 / 1001878
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________9. 2023-05-22 // 114 // 8 // 2023 // 2023-05-25 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 98
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 114
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Sweden,  Superettan  #114 - 2023 / 1002349
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________10. 2023-05-22 // 119 // 8 // 2022 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 97
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 119
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Denmark,  Superliga  #119 - 2022 / 1017261
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________11. 2023-05-22 // 129 // 8 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 96
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 129
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. Argentina,  Primera Nacional  #129 - 2023 / 992730
#   ____________________good to Go 1
#
#   ____________________2. Argentina,  Primera Nacional  #129 - 2023 / 992731
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________12. 2023-05-22 // 132 // 11 // 2023 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 95
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 132
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Argentina,  Primera C  #132 - 2023 / 988145
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________13. 2023-05-22 // 135 // 8 // 2022 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 94
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 135
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. Italy,  Serie A  #135 - 2022 / 882131
#   ____________________good to Go 1
#
#   ____________________2. Italy,  Serie A  #135 - 2022 / 882134
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________14. 2023-05-22 // 165 // 11 // 2023 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 93
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 165
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1.
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________30. 2023-05-22 // 307 // 8 // 2022 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 77
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 307
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 5
#
#   ____________________1. Saudi-Arabia,  Pro League  #307 - 2022 / 976753
#   ____________________good to Go 1
#
#   ____________________2. Saudi-Arabia,  Pro League  #307 - 2022 / 976750
#   ____________________good to Go 1
#
#   ____________________3. Saudi-Arabia,  Pro League  #307 - 2022 / 976751
#   ____________________good to Go 1
#
#   ____________________4. Saudi-Arabia,  Pro League  #307 - 2022 / 976747
#   ____________________good to Go 1
#
#   ____________________5. Saudi-Arabia,  Pro League  #307 - 2022 / 976748
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________31. 2023-05-22 // 318 // 8 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 76
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 318
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________________> FUCKIN ZERO !
#   ____________32. 2023-05-22 // 334 // 11 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 75
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 334
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 3
#
#   ____________________1. Ukraine,  Persha Liga  #334 - 2022 / 977406
#   ____________________good to Go 1
#
#   ____________________2. Ukraine,  Persha Liga  #334 - 2022 / 977407
#   ____________________good to Go 1
#
#   ____________________3. Ukraine,  Persha Liga  #334 - 2022 / 977408
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________33. 2023-05-22 // 340 // 11 // 2023 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 74
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 340
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Vietnam,  V.League 1  #340 - 2023 / 1004704
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________34. 2023-05-22 // 361 // 11 // 2023 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 73
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 361
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. Lithuania,  1 Lyga  #361 - 2023 / 1011634
#   ____________________good to Go 1
#
#   ____________________2. Lithuania,  1 Lyga  #361 - 2023 / 1011635
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________35. 2023-05-22 // 363 // 11 // 2022 // 2023-05-25 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 72
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 363
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. Ethiopia,  Premier League  #363 - 2022 / 1019805
#   ____________________good to Go 1
#
#   ____________________2. Ethiopia,  Premier League  #363 - 2022 / 1019806
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________36. 2023-05-22 // 365 // 8 // 2023 // 2023-05-25 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 71
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 365
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. Latvia,  Virsliga  #365 - 2023 / 1009360
#   ____________________good to Go 1
#
#   ____________________2. Latvia,  Virsliga  #365 - 2023 / 1009361
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________37. 2023-05-22 // 369 // 11 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 70
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 369
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 2
#
#   ____________________1. Uzbekistan,  Super League  #369 - 2023 / 1005615
#   ____________________good to Go 1
#
#   ____________________2. Uzbekistan,  Super League  #369 - 2023 / 1005620
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________38. 2023-05-22 // 419 // 11 // 2022 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 69
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 419
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 4
#
#   ____________________1. Azerbaidjan,  Premyer Liqa  #419 - 2022 / 923356
#   ____________________good to Go 1
#
#   ____________________2. Azerbaidjan,  Premyer Liqa  #419 - 2022 / 923357
#   ____________________good to Go 1
#
#   ____________________3. Azerbaidjan,  Premyer Liqa  #419 - 2022 / 923359
#   ____________________good to Go 1
#
#   ____________________4. Azerbaidjan,  Premyer Liqa  #419 - 2022 / 923360
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________39. 2023-05-22 // 490 // 8 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 68
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 490
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 4
#   ____________________1. World,  World Cup - U20  #490 - 2023 / 1023420
#   ____________________good to Go 1
#
#   ____________________2. World,  World Cup - U20  #490 - 2023 / 1023421
#   ____________________good to Go 1
#
#   ____________________3. World,  World Cup - U20  #490 - 2023 / 1023422
#   ____________________good to Go 1
#
#   ____________________4. World,  World Cup - U20  #490 - 2023 / 1023423
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________40. 2023-05-22 // 494 // 11 // 2022 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 67
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 494
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 3
#
#   ____________________1. Greece,  Super League 2  #494 - 2022 / 966659
#   ____________________good to Go 1
#
#   ____________________2. Greece,  Super League 2  #494 - 2022 / 966859
#   ____________________good to Go 1
#
#   ____________________3. Greece,  Super League 2  #494 - 2022 / 966860
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________41. 2023-05-22 // 521 // 11 // 2023 // 2023-05-27 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 66
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 11
#   __________________season : 2023
#   __________________league : 521
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Brazil,  Amapaense  #521 - 2023 / 1016494
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________42. 2023-05-22 // 549 // 8 // 2023 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 65
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 549
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Sweden,  Damallsvenskan  #549 - 2023 / 988238
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
#   ____________43. 2023-05-22 // 705 // 8 // 2022 // 2023-05-24 // Match Finished
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 64
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-05-22
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 705
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 4
#
#   ____________________1. Italy,  Campionato Primavera - 1  #705 - 2022 / 915608
#   ____________________good to Go 1
#
#   ____________________2. Italy,  Campionato Primavera - 1  #705 - 2022 / 915611
#   ____________________good to Go 1
#
#   ____________________3. Italy,  Campionato Primavera - 1  #705 - 2022 / 915609
#   ____________________good to Go 1
#
#   ____________________4. Italy,  Campionato Primavera - 1  #705 - 2022 / 915606
#   ____________________good to Go 1
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________________  > FUCKIN END !
# # -------------------------------------------------- End at 2023-05-29 10:08:14

# %%
from a_settings.messages import *  
from a_models.date import *   
from a_models.football_odds import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    space += "__" 
    # --------------------------------------------------   
    tgl_awal         = get_today_subs(days0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    tgl_akhir        = get_today_subs(days1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    today_day        = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_get_fixture_status_match_finished(tgl_awal, tgl_akhir, today_day, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 10:08:14
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 7
#   ________today_raw : 2023-05-22 10:08:14.325222
#   ______get_today_subs()
#   ________subs date_diff : 6
#   ________today_raw : 2023-05-23 10:08:14.325222
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-05-29 10:08:14.329231
#   ______fO_get_fixture_status_match_finished()
#   ______Select  DATE(date)  , leagueapi_id , (select bookmakersapi_id from football_leagues where leagueapi_id = football_odds.leagueapi_id)  , season , DATE(end_odd_updated_at)  , fixture_status   , fixtureapi_id   from football_odds  where  date <= '2023-05-23'  and date >= '2023-05-22'  and end_response is null  and deleted_at is null  and fixture_status = 'Match Finished'  order by date
#   ________Total Row(s) : 4
#   __________fO_get_fixture_status_match_finished_DETAILED()
#   __________Total Row(s) : 4
#
#          Date              fs       fx  bm    er
# 0  2023-05-22  Match Finished   977409  11  None
# 1  2023-05-22  Match Finished  1024078  11  None
# 2  2023-05-22  Match Finished  1024518  11  None
# 3  2023-05-22  Match Finished  1026927   8  None
#
#   ________Are you sure want to continue? :  yes
#   __________1. 2023-05-22 // 1024078 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 63
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 1024078
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________2. 2023-05-22 // 1024518 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 62
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 1024518
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________3. 2023-05-22 // 977409 // 11 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 61
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 977409
#   ________________bookmaker : 11
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
#   __________4. 2023-05-22 // 1026927 // 8 // 2023-05-29 // Match Finished
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 60
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________fixture : 1026927
#   ________________bookmaker : 8
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 0
# # -------------------------------------------------- End at 2023-05-29 10:16:02

# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    day0         = get_today_subs(days0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(days1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_check_enddates(day0, day1, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-29 10:16:02
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 7
#   ________today_raw : 2023-05-22 10:16:02.397474
#   ______get_today_subs()
#   ________subs date_diff : 6
#   ________today_raw : 2023-05-23 10:16:02.397474
#   ______fO_check_enddates()
#   ________Select  leagueapi_id as lg  , season as ss  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_homeapi_id) as home  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_awayapi_id) as away  , SUBSTR(fixture_status, 1, 15)  as fs  , end_response as er  , end_ah_pattern as ah  , end_gou_pattern as gou  from football_odds  where date >= '2023-05-22'  and date <= '2023-05-23'  and end_response is null  and deleted_at is null  and fixture_status like 'Match Finished'  order by leagueapi_id, date asc
#   ________Total Row(s) : 4
#
#     lg    ss     home     away              fs    er    ah   gou
# 0  256  2023  Patuxen  Christo  Match Finished  None  None  None
# 1  256  2023  Montere  SF Glen  Match Finished  None  None  None
# 2  318  2022  Olympia  Akritas  Match Finished  None  None  None
# 3  334  2022  Kremin'  Nyva Te  Match Finished  None  None  None
#
# # -------------------------------------------------- End at 2023-05-29 10:16:03
