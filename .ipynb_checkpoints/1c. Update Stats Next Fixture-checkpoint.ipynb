# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------   
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=1)
    preday1 = today + DD
    day1 = preday1.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    print(space + "> day1 : " +  str(preday1) ) 
    # --------------------------------------------------  
    ff_get_fixtures_next_match(day0, preday1, space) 
    # --------------------------------------------------
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-03 22:48:15
#   __main()
#   ____get_date()
#   ______> day0 : 2023-04-03
#   ______> day1 : 2023-04-04 22:48:15.220894
#   ________ff_get_fixtures_next_match()
#   __________Select   teams_home_id,  teams_away_id,  leagueapi_id,  season,  fixtureapi_id,  teams_home,  teams_away,  date  from football_fixtures  where date >= '2023-04-03'  and date <= '2023-04-04 22:48:15.220894'  and fixture_status like 'Not Started'  and deleted_at is null  order by date asc
#   __________Total Row(s) : 116
#   ____________[1/116] 322 - 2022
#   ____________2023-04-03 00:00:00 fx:968405
#   ____________Arnett Gardens [3436]  vs Chapelton [20597]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '322'  and season = '2022'  and teamapi_id = '3436'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.789473684210526',  `goals_for_home_ratio` = '1.7894736842105263',  `goals_againts_home_ratio` = '1.0',  `rank_home` = '1',  `home_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-secondary"></i> '  WHERE teams_home_id = '3436'  AND leagueapi_id = '322'  AND season = '2022'  AND fixtureapi_id = '968405'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '322'  and season = '2022'  and teamapi_id = '20597'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.210526315789474',  `goals_for_away_ratio` = '0.47368421052631576',  `goals_againts_away_ratio` = '1.736842105263158',  `rank_away` = '13',  `away_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-secondary"></i> <i class="fas fa-flag text-danger"></i> '  WHERE teams_away_id = '20597'  AND leagueapi_id = '322'  AND season = '2022'  AND fixtureapi_id = '968405'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[2/116] 673 - 2022
#   ____________2023-04-03 01:00:00 fx:976362
#   ____________Mazatlán W [14878]  vs León W [14877]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '673'  and season = '2022'  and teamapi_id = '14878'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.814814814814815',  `goals_for_home_ratio` = '0.7037037037037037',  `goals_againts_home_ratio` = '3.111111111111111',  `rank_home` = '17',  `home_fx_status` = ''  WHERE teams_home_id = '14878'  AND leagueapi_id = '673'  AND season = '2022'  AND fixtureapi_id = '976362'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '673'  and season = '2022'  and teamapi_id = '14877'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.8518518518518516',  `goals_for_away_ratio` = '1.1481481481481481',  `goals_againts_away_ratio` = '1.7037037037037037',  `rank_away` = '13',  `away_fx_status` = ''  WHERE teams_away_id = '14877'  AND leagueapi_id = '673'  AND season = '2022'  AND fixtureapi_id = '976362'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[3/116] 262 - 2022
#   ____________2023-04-03 01:10:00 fx:974421
#   ____________Club Queretaro [2290]  vs U.N.A.M. - Pumas [2286]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '262'  and season = '2022'  and teamapi_id = '2290'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.8214285714285716',  `goals_for_home_ratio` = '0.9642857142857143',  `goals_againts_home_ratio` = '1.8571428571428572',  `rank_home` = '18',  `home_fx_status` = ''  WHERE teams_home_id = '2290'  AND leagueapi_id = '262'  AND season = '2022'  AND fixtureapi_id = '974421'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '262'  and season = '2022'  and teamapi_id = '2286'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.1724137931034484',  `goals_for_away_ratio` = '1.2758620689655173',  `goals_againts_away_ratio` = '1.896551724137931',  `rank_away` = '16',  `away_fx_status` = '<i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> '  WHERE teams_away_id = '2286'  AND leagueapi_id = '262'  AND season = '2022'  AND fixtureapi_id = '974421'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[4/116] 673 - 2022
#   ____________2023-04-03 03:00:00 fx:976363
#   ____________Juárez W [14869]  vs América W [14868]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '673'  and season = '2022'  and teamapi_id = '14869'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.037037037037037',  `goals_for_home_ratio` = '1.6296296296296295',  `goals_againts_home_ratio` = '1.4074074074074074',  `rank_home` = '7',  `home_fx_status` = ''  WHERE teams_home_id = '14869'  AND leagueapi_id = '673'  AND season = '2022'  AND fixtureapi_id = '976363'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '673'  and season = '2022'  and teamapi_id = '14868'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.242424242424242',  `goals_for_away_ratio` = '2.393939393939394',  `goals_againts_away_ratio` = '0.8484848484848485',  `rank_away` = '4',  `away_fx_status` = ''  WHERE teams_away_id = '14868'  AND leagueapi_id = '673'  AND season = '2022'  AND fixtureapi_id = '976363'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[5/116] 263 - 2022
#   ____________2023-04-03 03:05:00 fx:975987
#   ____________Monarcas [2284]  vs Celaya [2308]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '263'  and season = '2022'  and teamapi_id = '2284'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.21875',  `goals_for_home_ratio` = '1.25',  `goals_againts_home_ratio` = '0.96875',  `rank_home` = '4',  `home_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '2284'  AND leagueapi_id = '263'  AND season = '2022'  AND fixtureapi_id = '975987'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '263'  and season = '2022'  and teamapi_id = '2308'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.2777777777777777',  `goals_for_away_ratio` = '1.5',  `goals_againts_away_ratio` = '0.7777777777777778',  `rank_away` = '1',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '2308'  AND leagueapi_id = '263'  AND season = '2022'  AND fixtureapi_id = '975987'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[6/116] 703 - 2022
#   ____________2023-04-03 11:00:00 fx:948608
#   ____________Swansea City U21 [11912]  vs Hull City U21 [20084]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '11912'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '4.238095238095238',  `goals_for_home_ratio` = '2.5714285714285716',  `goals_againts_home_ratio` = '1.6666666666666667',  `rank_home` = '4',  `home_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '11912'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948608'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20084'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.8260869565217392',  `goals_for_away_ratio` = '2.0434782608695654',  `goals_againts_away_ratio` = '1.7826086956521738',  `rank_away` = '8',  `away_fx_status` = ''  WHERE teams_away_id = '20084'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948608'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[7/116] 667 - 2023
#   ____________2023-04-03 11:00:00 fx:1019201
#   ____________Levski Sofia [646]  vs Maritsa Plovdiv [1423]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '667'  and season = '2023'  and teamapi_id = '646'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = 'None',  `goals_for_home_ratio` = 'None',  `goals_againts_home_ratio` = 'None',  `rank_home` = '113',  `home_fx_status` = ''  WHERE teams_home_id = '646'  AND leagueapi_id = '667'  AND season = '2023'  AND fixtureapi_id = '1019201'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '667'  and season = '2023'  and teamapi_id = '1423'
#   ______________________Total Row(s) : 0
#
#   ____________[8/116] 667 - 2023
#   ____________2023-04-03 11:00:00 fx:1020354
#   ____________Ranheim [322]  vs hodd [2150]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '667'  and season = '2023'  and teamapi_id = '322'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '667'  and season = '2023'  and teamapi_id = '2150'
#   ______________________Total Row(s) : 0
#
#   ____________[9/116] 705 - 2022
#   ____________2023-04-03 12:30:00 fx:915541
#   ____________Milan U19 [15670]  vs Udinese U19 [15684]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '705'  and season = '2022'  and teamapi_id = '15670'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.0',  `goals_for_home_ratio` = '1.4782608695652173',  `goals_againts_home_ratio` = '1.5217391304347827',  `rank_home` = '13',  `home_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_home_id = '15670'  AND leagueapi_id = '705'  AND season = '2022'  AND fixtureapi_id = '915541'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '705'  and season = '2022'  and teamapi_id = '15684'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.4782608695652173',  `goals_for_away_ratio` = '0.782608695652174',  `goals_againts_away_ratio` = '1.6956521739130435',  `rank_away` = '17',  `away_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> '  WHERE teams_away_id = '15684'  AND leagueapi_id = '705'  AND season = '2022'  AND fixtureapi_id = '915541'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[10/116] 703 - 2022
#   ____________2023-04-03 12:30:00 fx:948610
#   ____________Millwall U21 [20095]  vs Burnley U21 [20081]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20095'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.727272727272727',  `goals_for_home_ratio` = '2.4545454545454546',  `goals_againts_home_ratio` = '1.2727272727272727',  `rank_home` = '2',  `home_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '20095'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948610'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20081'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.6956521739130435',  `goals_for_away_ratio` = '1.608695652173913',  `goals_againts_away_ratio` = '2.0869565217391304',  `rank_away` = '10',  `away_fx_status` = ''  WHERE teams_away_id = '20081'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948610'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[11/116] 703 - 2022
#   ____________2023-04-03 13:00:00 fx:948609
#   ____________Charlton Athletic U21 [20082]  vs Wigan Athletic U21 [20097]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20082'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.869565217391304',  `goals_for_home_ratio` = '2.0',  `goals_againts_home_ratio` = '1.8695652173913044',  `rank_home` = '11',  `home_fx_status` = '<i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_home_id = '20082'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948609'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20097'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.347826086956522',  `goals_for_away_ratio` = '1.8695652173913044',  `goals_againts_away_ratio` = '1.4782608695652173',  `rank_away` = '6',  `away_fx_status` = ''  WHERE teams_away_id = '20097'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948609'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[12/116] 702 - 2022
#   ____________2023-04-03 13:00:00 fx:924960
#   ____________Liverpool U21 [7196]  vs Brighton U21 [7191]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '702'  and season = '2022'  and teamapi_id = '7196'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.0',  `goals_for_home_ratio` = '1.7619047619047619',  `goals_againts_home_ratio` = '1.2380952380952381',  `rank_home` = '5',  `home_fx_status` = ''  WHERE teams_home_id = '7196'  AND leagueapi_id = '702'  AND season = '2022'  AND fixtureapi_id = '924960'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '702'  and season = '2022'  and teamapi_id = '7191'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.85',  `goals_for_away_ratio` = '2.05',  `goals_againts_away_ratio` = '1.8',  `rank_away` = '10',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '7191'  AND leagueapi_id = '702'  AND season = '2022'  AND fixtureapi_id = '924960'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[13/116] 667 - 2023
#   ____________2023-04-03 13:00:00 fx:992222
#   ____________Valerenga [326]  vs jerv [2151]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '667'  and season = '2023'  and teamapi_id = '326'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '667'  and season = '2023'  and teamapi_id = '2151'
#   ______________________Total Row(s) : 0
#
#   ____________[14/116] 667 - 2023
#   ____________2023-04-03 13:00:00 fx:1020355
#   ____________Asane [2148]  vs Bryne [2142]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '667'  and season = '2023'  and teamapi_id = '2148'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '667'  and season = '2023'  and teamapi_id = '2142'
#   ______________________Total Row(s) : 0
#   ____________[15/116] 274 - 2022
#   ____________2023-04-03 13:30:00 fx:899812
#   ____________Pusamania Borneo [2442]  vs Bali United [2448]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '274'  and season = '2022'  and teamapi_id = '2442'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.870967741935484',  `goals_for_home_ratio` = '1.7741935483870968',  `goals_againts_home_ratio` = '1.096774193548387',  `rank_home` = '4',  `home_fx_status` = ''  WHERE teams_home_id = '2442'  AND leagueapi_id = '274'  AND season = '2022'  AND fixtureapi_id = '899812'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '274'  and season = '2022'  and teamapi_id = '2448'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.4516129032258065',  `goals_for_away_ratio` = '2.032258064516129',  `goals_againts_away_ratio` = '1.4193548387096775',  `rank_away` = '5',  `away_fx_status` = ''  WHERE teams_away_id = '2448'  AND leagueapi_id = '274'  AND season = '2022'  AND fixtureapi_id = '899812'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[16/116] 705 - 2022
#   ____________2023-04-03 14:30:00 fx:915535
#   ____________Juventus U19 [7904]  vs Bologna U19 [15656]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '705'  and season = '2022'  and teamapi_id = '7904'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.869565217391304',  `goals_for_home_ratio` = '2.217391304347826',  `goals_againts_home_ratio` = '1.6521739130434783',  `rank_home` = '6',  `home_fx_status` = ''  WHERE teams_home_id = '7904'  AND leagueapi_id = '705'  AND season = '2022'  AND fixtureapi_id = '915535'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '705'  and season = '2022'  and teamapi_id = '15656'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.652173913043478',  `goals_for_away_ratio` = '1.3043478260869565',  `goals_againts_away_ratio` = '1.3478260869565217',  `rank_away` = '8',  `away_fx_status` = ''  WHERE teams_away_id = '15656'  AND leagueapi_id = '705'  AND season = '2022'  AND fixtureapi_id = '915535'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[17/116] 283 - 2022
#   ____________2023-04-03 14:30:00 fx:1015987
#   ____________CS Mioveni [2594]  vs Chindia Targoviste [2586]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '283'  and season = '2022'  and teamapi_id = '2594'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.2666666666666666',  `goals_for_home_ratio` = '0.7666666666666667',  `goals_againts_home_ratio` = '1.5',  `rank_home` = '16',  `home_fx_status` = ''  WHERE teams_home_id = '2594'  AND leagueapi_id = '283'  AND season = '2022'  AND fixtureapi_id = '1015987'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '283'  and season = '2022'  and teamapi_id = '2586'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.466666666666667',  `goals_for_away_ratio` = '1.0666666666666667',  `goals_againts_away_ratio` = '1.4',  `rank_away` = '12',  `away_fx_status` = ''  WHERE teams_away_id = '2586'  AND leagueapi_id = '283'  AND season = '2022'  AND fixtureapi_id = '1015987'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[18/116] 174 - 2022
#   ____________2023-04-03 15:30:00 fx:978717
#   ____________Lokomotiv Sofia [1416]  vs Slavia Sofia [854]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '174'  and season = '2022'  and teamapi_id = '1416'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = 'None',  `goals_for_home_ratio` = 'None',  `goals_againts_home_ratio` = 'None',  `rank_home` = '50',  `home_fx_status` = ''  WHERE teams_home_id = '1416'  AND leagueapi_id = '174'  AND season = '2022'  AND fixtureapi_id = '978717'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '174'  and season = '2022'  and teamapi_id = '854'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = 'None',  `goals_for_away_ratio` = 'None',  `goals_againts_away_ratio` = 'None',  `rank_away` = '11',  `away_fx_status` = ''  WHERE teams_away_id = '854'  AND leagueapi_id = '174'  AND season = '2022'  AND fixtureapi_id = '978717'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[19/116] 63 - 2022
#   ____________2023-04-03 16:00:00 fx:914122
#   ____________Versailles [3131]  vs Chateauroux [107]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '63'  and season = '2022'  and teamapi_id = '3131'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.3461538461538463',  `goals_for_home_ratio` = '1.3076923076923077',  `goals_againts_home_ratio` = '1.0384615384615385',  `rank_home` = '5',  `home_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '3131'  AND leagueapi_id = '63'  AND season = '2022'  AND fixtureapi_id = '914122'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '63'  and season = '2022'  and teamapi_id = '107'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.3846153846153846',  `goals_for_away_ratio` = '1.1538461538461537',  `goals_againts_away_ratio` = '1.2307692307692308',  `rank_away` = '12',  `away_fx_status` = ''  WHERE teams_away_id = '107'  AND leagueapi_id = '63'  AND season = '2022'  AND fixtureapi_id = '914122'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[20/116] 328 - 2023
#   ____________2023-04-03 16:00:00 fx:1001411
#   ____________Paide II [16402]  vs FCI Levadia II [3517]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '328'  and season = '2023'  and teamapi_id = '16402'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '5.5',  `goals_for_home_ratio` = '3.0',  `goals_againts_home_ratio` = '2.5',  `rank_home` = '5',  `home_fx_status` = ''  WHERE teams_home_id = '16402'  AND leagueapi_id = '328'  AND season = '2023'  AND fixtureapi_id = '1001411'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '328'  and season = '2023'  and teamapi_id = '3517'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '4.333333333333333',  `goals_for_away_ratio` = '3.6666666666666665',  `goals_againts_away_ratio` = '0.6666666666666666',  `rank_away` = '3',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '3517'  AND leagueapi_id = '328'  AND season = '2023'  AND fixtureapi_id = '1001411'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[21/116] 382 - 2022
#   ____________2023-04-03 16:00:00 fx:1017119
#   ____________Maccabi Petah Tikva [4495]  vs Hapoel Acre [4482]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '382'  and season = '2022'  and teamapi_id = '4495'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.9',  `goals_for_home_ratio` = '1.9',  `goals_againts_home_ratio` = '1.0',  `rank_home` = '1',  `home_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '4495'  AND leagueapi_id = '382'  AND season = '2022'  AND fixtureapi_id = '1017119'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '382'  and season = '2022'  and teamapi_id = '4482'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.3',  `goals_for_away_ratio` = '1.2666666666666666',  `goals_againts_away_ratio` = '1.0333333333333334',  `rank_away` = '5',  `away_fx_status` = ''  WHERE teams_away_id = '4482'  AND leagueapi_id = '382'  AND season = '2022'  AND fixtureapi_id = '1017119'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[22/116] 318 - 2022
#   ____________2023-04-03 16:00:00 fx:1017817
#   ____________AEK Larnaca [614]  vs Apoel Nicosia [2247]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '318'  and season = '2022'  and teamapi_id = '614'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.5714285714285716',  `goals_for_home_ratio` = '1.6428571428571428',  `goals_againts_home_ratio` = '0.9285714285714286',  `rank_home` = '3',  `home_fx_status` = ''  WHERE teams_home_id = '614'  AND leagueapi_id = '318'  AND season = '2022'  AND fixtureapi_id = '1017817'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '318'  and season = '2022'  and teamapi_id = '2247'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '1.9642857142857142',  `goals_for_away_ratio` = '1.4642857142857142',  `goals_againts_away_ratio` = '0.5',  `rank_away` = '1',  `away_fx_status` = '<i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '2247'  AND leagueapi_id = '318'  AND season = '2022'  AND fixtureapi_id = '1017817'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[23/116] 318 - 2022
#   ____________2023-04-03 16:00:00 fx:1017830
#   ____________Enosis [3399]  vs Doxa [3398]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '318'  and season = '2022'  and teamapi_id = '3399'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.392857142857143',  `goals_for_home_ratio` = '0.8928571428571429',  `goals_againts_home_ratio` = '1.5',  `rank_home` = '12',  `home_fx_status` = ''  WHERE teams_home_id = '3399'  AND leagueapi_id = '318'  AND season = '2022'  AND fixtureapi_id = '1017830'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '318'  and season = '2022'  and teamapi_id = '3398'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.142857142857143',  `goals_for_away_ratio` = '0.75',  `goals_againts_away_ratio` = '1.3928571428571428',  `rank_away` = '11',  `away_fx_status` = ''  WHERE teams_away_id = '3398'  AND leagueapi_id = '318'  AND season = '2022'  AND fixtureapi_id = '1017830'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[24/116] 63 - 2022
#   ____________2023-04-03 16:30:00 fx:914120
#   ____________Concarneau [1300]  vs Sedan [1310]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '63'  and season = '2022'  and teamapi_id = '1300'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.6538461538461537',  `goals_for_home_ratio` = '1.5384615384615385',  `goals_againts_home_ratio` = '1.1153846153846154',  `rank_home` = '4',  `home_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '1300'  AND leagueapi_id = '63'  AND season = '2022'  AND fixtureapi_id = '914120'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '63'  and season = '2022'  and teamapi_id = '1310'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.6153846153846154',  `goals_for_away_ratio` = '1.2307692307692308',  `goals_againts_away_ratio` = '1.3846153846153846',  `rank_away` = '10',  `away_fx_status` = ''  WHERE teams_away_id = '1310'  AND leagueapi_id = '63'  AND season = '2022'  AND fixtureapi_id = '914120'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[25/116] 135 - 2022
#   ____________2023-04-03 16:30:00 fx:882051
#   ____________Empoli [511]  vs Lecce [867]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '135'  and season = '2022'  and teamapi_id = '511'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.2222222222222223',  `goals_for_home_ratio` = '0.8888888888888888',  `goals_againts_home_ratio` = '1.3333333333333333',  `rank_home` = '14',  `home_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-secondary"></i> '  WHERE teams_home_id = '511'  AND leagueapi_id = '135'  AND season = '2022'  AND fixtureapi_id = '882051'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '135'  and season = '2022'  and teamapi_id = '867'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.1153846153846154',  `goals_for_away_ratio` = '0.9230769230769231',  `goals_againts_away_ratio` = '1.1923076923076923',  `rank_away` = '15',  `away_fx_status` = '<i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> '  WHERE teams_away_id = '867'  AND leagueapi_id = '135'  AND season = '2022'  AND fixtureapi_id = '882051'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[26/116] 106 - 2022
#   ____________2023-04-03 17:00:00 fx:865313
#   ____________Stal Mielec [3493]  vs Jagiellonia [336]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
# ...
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.64',  `goals_for_away_ratio` = '1.72',  `goals_againts_away_ratio` = '0.92',  `rank_away` = '3',  `away_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '2977'  AND leagueapi_id = '308'  AND season = '2022'  AND fixtureapi_id = '984720'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[109/116] 39 - 2022
#   ____________2023-04-04 19:00:00 fx:868019
#   ____________Chelsea [49]  vs Liverpool [40]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '39'  and season = '2022'  and teamapi_id = '49'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.107142857142857',  `goals_for_home_ratio` = '1.0357142857142858',  `goals_againts_home_ratio` = '1.0714285714285714',  `rank_home` = '11',  `home_fx_status` = ''  WHERE teams_home_id = '49'  AND leagueapi_id = '39'  AND season = '2022'  AND fixtureapi_id = '868019'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '39'  and season = '2022'  and teamapi_id = '40'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.0',  `goals_for_away_ratio` = '1.7777777777777777',  `goals_againts_away_ratio` = '1.2222222222222223',  `rank_away` = '8',  `away_fx_status` = ''  WHERE teams_away_id = '40'  AND leagueapi_id = '39'  AND season = '2022'  AND fixtureapi_id = '868019'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[110/116] 307 - 2022
#   ____________2023-04-04 19:00:00 fx:976699
#   ____________Al-Ettifaq [2934]  vs Al-Fayha [2944]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '307'  and season = '2022'  and teamapi_id = '2934'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.05',  `goals_for_home_ratio` = '0.9',  `goals_againts_home_ratio` = '1.15',  `rank_home` = '11',  `home_fx_status` = ''  WHERE teams_home_id = '2934'  AND leagueapi_id = '307'  AND season = '2022'  AND fixtureapi_id = '976699'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '307'  and season = '2022'  and teamapi_id = '2944'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.8',  `goals_for_away_ratio` = '1.25',  `goals_againts_away_ratio` = '1.55',  `rank_away` = '10',  `away_fx_status` = ''  WHERE teams_away_id = '2944'  AND leagueapi_id = '307'  AND season = '2022'  AND fixtureapi_id = '976699'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[111/116] 307 - 2022
#   ____________2023-04-04 19:00:00 fx:976701
#   ____________Al-Adalah [2950]  vs Al-Nassr [2939]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '307'  and season = '2022'  and teamapi_id = '2950'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.6666666666666665',  `goals_for_home_ratio` = '0.8095238095238095',  `goals_againts_home_ratio` = '1.8571428571428572',  `rank_home` = '15',  `home_fx_status` = ''  WHERE teams_home_id = '2950'  AND leagueapi_id = '307'  AND season = '2022'  AND fixtureapi_id = '976701'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '307'  and season = '2022'  and teamapi_id = '2939'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.65',  `goals_for_away_ratio` = '2.1',  `goals_againts_away_ratio` = '0.55',  `rank_away` = '2',  `away_fx_status` = ''  WHERE teams_away_id = '2939'  AND leagueapi_id = '307'  AND season = '2022'  AND fixtureapi_id = '976701'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[112/116] 307 - 2022
#   ____________2023-04-04 19:00:00 fx:976704
#   ____________Al-Ittihad FC [2938]  vs Dhamk [2956]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '307'  and season = '2022'  and teamapi_id = '2938'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.05',  `goals_for_home_ratio` = '1.75',  `goals_againts_home_ratio` = '0.3',  `rank_home` = '1',  `home_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_home_id = '2938'  AND leagueapi_id = '307'  AND season = '2022'  AND fixtureapi_id = '976704'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '307'  and season = '2022'  and teamapi_id = '2956'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.4285714285714284',  `goals_for_away_ratio` = '1.2380952380952381',  `goals_againts_away_ratio` = '1.1904761904761905',  `rank_away` = '7',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '2956'  AND leagueapi_id = '307'  AND season = '2022'  AND fixtureapi_id = '976704'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[113/116] 308 - 2022
#   ____________2023-04-04 19:00:00 fx:984721
#   ____________Jeddah Club [2947]  vs Al Kholood [10509]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '308'  and season = '2022'  and teamapi_id = '2947'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.04',  `goals_for_home_ratio` = '0.96',  `goals_againts_home_ratio` = '1.08',  `rank_home` = '11',  `home_fx_status` = ''  WHERE teams_home_id = '2947'  AND leagueapi_id = '308'  AND season = '2022'  AND fixtureapi_id = '984721'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '308'  and season = '2022'  and teamapi_id = '10509'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '1.84',  `goals_for_away_ratio` = '1.0',  `goals_againts_away_ratio` = '0.84',  `rank_away` = '7',  `away_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '10509'  AND leagueapi_id = '308'  AND season = '2022'  AND fixtureapi_id = '984721'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[114/116] 304 - 2023
#   ____________2023-04-04 21:00:00 fx:984875
#   ____________Atlético Chiriquí [4675]  vs Deportivo Universitario [2888]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '304'  and season = '2023'  and teamapi_id = '4675'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.9',  `goals_for_home_ratio` = '0.8',  `goals_againts_home_ratio` = '2.1',  `rank_home` = '12',  `home_fx_status` = ''  WHERE teams_home_id = '4675'  AND leagueapi_id = '304'  AND season = '2023'  AND fixtureapi_id = '984875'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '304'  and season = '2023'  and teamapi_id = '2888'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.1',  `goals_for_away_ratio` = '1.4',  `goals_againts_away_ratio` = '1.7',  `rank_away` = '4',  `away_fx_status` = ''  WHERE teams_away_id = '2888'  AND leagueapi_id = '304'  AND season = '2023'  AND fixtureapi_id = '984875'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[115/116] 200 - 2022
#   ____________2023-04-04 22:00:00 fx:1014784
#   ____________Renaissance Berkane [962]  vs Riadi Salmi [3456]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '200'  and season = '2022'  and teamapi_id = '962'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '1.9473684210526316',  `goals_for_home_ratio` = '0.9473684210526315',  `goals_againts_home_ratio` = '1.0',  `rank_home` = '6',  `home_fx_status` = ''  WHERE teams_home_id = '962'  AND leagueapi_id = '200'  AND season = '2022'  AND fixtureapi_id = '1014784'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '200'  and season = '2022'  and teamapi_id = '3456'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.1666666666666665',  `goals_for_away_ratio` = '1.0555555555555556',  `goals_againts_away_ratio` = '1.1111111111111112',  `rank_away` = '9',  `away_fx_status` = ''  WHERE teams_away_id = '3456'  AND leagueapi_id = '200'  AND season = '2022'  AND fixtureapi_id = '1014784'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[116/116] 200 - 2022
#   ____________2023-04-04 22:00:00 fx:1014786
#   ____________Olympique Khouribga [972]  vs Maghreb Fès [3453]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '200'  and season = '2022'  and teamapi_id = '972'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '1.8',  `goals_for_home_ratio` = '0.7',  `goals_againts_home_ratio` = '1.1',  `rank_home` = '15',  `home_fx_status` = ''  WHERE teams_home_id = '972'  AND leagueapi_id = '200'  AND season = '2022'  AND fixtureapi_id = '1014786'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '200'  and season = '2022'  and teamapi_id = '3453'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.0',  `goals_for_away_ratio` = '1.1111111111111112',  `goals_againts_away_ratio` = '0.8888888888888888',  `rank_away` = '7',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_away_id = '3453'  AND leagueapi_id = '200'  AND season = '2022'  AND fixtureapi_id = '1014786'
#   ________________________> football_fixture STATS UPDATED
#
# # -------------------------------------------------- End at 2023-04-03 22:56:29
