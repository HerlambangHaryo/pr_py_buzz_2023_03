# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------   
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=1)
    preday1 = today + DD
    day1 = preday1.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    print(space + "> day1 : " +  str(preday1) ) 
    # --------------------------------------------------  
    ff_get_fixtures_next_match(day0, preday1, space) 
    # --------------------------------------------------
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-16 19:11:52
#   __main()
#   ____get_date()
#   ______> day0 : 2023-03-16
#   ______> day1 : 2023-03-17 19:11:52.470416
#   ________ff_get_fixtures_next_match()
#   __________Select   teams_home_id,  teams_away_id,  leagueapi_id,  season,  fixtureapi_id,  teams_home,  teams_away,  date  from football_fixtures  where date >= '2023-03-16'  and date <= '2023-03-17 19:11:52.470416'  and fixture_status like 'Not Started'  and deleted_at is null  order by date asc
#   __________Total Row(s) : 129
#   ____________[1/129] 16 - 2023
#   ____________2023-03-16 00:15:00 fx:972940
#   ____________Orlando City SC [1598]  vs Tigres UANL [2279]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[2/129] 263 - 2022
#   ____________2023-03-16 01:05:00 fx:975956
#   ____________Monarcas [2284]  vs Raya2 [16850]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.3',  `goals_for_home_ratio` = '1.2666666666666666',  `goals_againts_home_ratio` = '1.0333333333333334',  `rank_home` = '7',  `home_fx_status` = '<i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_home_id = '2284'  AND leagueapi_id = '263'  AND season = '2022'  AND fixtureapi_id = '975956'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.1481481481481484',  `goals_for_away_ratio` = '1.0740740740740742',  `goals_againts_away_ratio` = '1.0740740740740742',  `rank_away` = '9',  `away_fx_status` = ''  WHERE teams_away_id = '16850'  AND leagueapi_id = '263'  AND season = '2022'  AND fixtureapi_id = '975956'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[3/129] 16 - 2023
#   ____________2023-03-16 02:30:00 fx:972946
#   ____________Los Angeles FC [1616]  vs LD Alajuelense [822]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[4/129] 263 - 2022
#   ____________2023-03-16 03:05:00 fx:975957
#   ____________Dorados [2297]  vs Atlante FC [2312]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.7777777777777777',  `goals_for_home_ratio` = '1.1851851851851851',  `goals_againts_home_ratio` = '1.5925925925925926',  `rank_home` = '13',  `home_fx_status` = ''  WHERE teams_home_id = '2297'  AND leagueapi_id = '263'  AND season = '2022'  AND fixtureapi_id = '975957'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.6363636363636362',  `goals_for_away_ratio` = '1.8181818181818181',  `goals_againts_away_ratio` = '0.8181818181818182',  `rank_away` = '2',  `away_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '2312'  AND leagueapi_id = '263'  AND season = '2022'  AND fixtureapi_id = '975957'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[5/129] 274 - 2022
#   ____________2023-03-16 08:00:00 fx:899803
#   ____________Persija [10134]  vs PSIS Semarang [2451]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.25',  `goals_for_home_ratio` = '1.3214285714285714',  `goals_againts_home_ratio` = '0.9285714285714286',  `rank_home` = '3',  `home_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_home_id = '10134'  AND leagueapi_id = '274'  AND season = '2022'  AND fixtureapi_id = '899803'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.642857142857143',  `goals_for_away_ratio` = '1.1428571428571428',  `goals_againts_away_ratio` = '1.5',  `rank_away` = '11',  `away_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-secondary"></i> '  WHERE teams_away_id = '2451'  AND leagueapi_id = '274'  AND season = '2022'  AND fixtureapi_id = '899803'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[6/129] 274 - 2022
#   ____________2023-03-16 10:00:00 fx:899805
#   ____________Bali United [2448]  vs Persepam Madura Utd [2444]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.4827586206896552',  `goals_for_home_ratio` = '2.0344827586206895',  `goals_againts_home_ratio` = '1.4482758620689655',  `rank_home` = '6',  `home_fx_status` = ''  WHERE teams_home_id = '2448'  AND leagueapi_id = '274'  AND season = '2022'  AND fixtureapi_id = '899805'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.2333333333333334',  `goals_for_away_ratio` = '1.2',  `goals_againts_away_ratio` = '1.0333333333333334',  `rank_away` = '5',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '2444'  AND leagueapi_id = '274'  AND season = '2022'  AND fixtureapi_id = '899805'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[7/129] 701 - 2022
#   ____________2023-03-16 11:00:00 fx:992352
#   ____________Farense U23 [17474]  vs Marítimo U23 [15466]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.590909090909091',  `goals_for_home_ratio` = '1.1818181818181819',  `goals_againts_home_ratio` = '1.4090909090909092',  `rank_home` = '9',  `home_fx_status` = ''  WHERE teams_home_id = '17474'  AND leagueapi_id = '701'  AND season = '2022'  AND fixtureapi_id = '992352'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.3636363636363638',  `goals_for_away_ratio` = '1.0909090909090908',  `goals_againts_away_ratio` = '1.2727272727272727',  `rank_away` = '11',  `away_fx_status` = '<i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '15466'  AND leagueapi_id = '701'  AND season = '2022'  AND fixtureapi_id = '992352'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[8/129] 291 - 2022
#   ____________2023-03-16 11:15:00 fx:998368
#   ____________Kheybar Khorramabad [2716]  vs Khalij Fars [18300]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '1.1818181818181819',  `goals_for_home_ratio` = '0.8181818181818182',  `goals_againts_home_ratio` = '0.36363636363636365',  `rank_home` = '5',  `home_fx_status` = ''  WHERE teams_home_id = '2716'  AND leagueapi_id = '291'  AND season = '2022'  AND fixtureapi_id = '998368'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '1.8421052631578947',  `goals_for_away_ratio` = '0.5789473684210527',  `goals_againts_away_ratio` = '1.263157894736842',  `rank_away` = '12',  `away_fx_status` = ''  WHERE teams_away_id = '18300'  AND leagueapi_id = '291'  AND season = '2022'  AND fixtureapi_id = '998368'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[9/129] 291 - 2022
#   ____________2023-03-16 11:30:00 fx:998363
#   ____________Darya Babol [19965]  vs Esteghlal Mollasani [15540]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[10/129] 291 - 2022
#   ____________2023-03-16 11:30:00 fx:998365
#   ____________Saipa [2736]  vs Shams Azar Qazvin [18159]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '1.5217391304347827',  `goals_for_home_ratio` = '0.782608695652174',  `goals_againts_home_ratio` = '0.7391304347826086',  `rank_home` = '2',  `home_fx_status` = ''  WHERE teams_home_id = '2736'  AND leagueapi_id = '291'  AND season = '2022'  AND fixtureapi_id = '998365'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[11/129] 291 - 2022
#   ____________2023-03-16 11:30:00 fx:998366
#   ____________Fajr Sepasi [2713]  vs Chooka Talesh [10387]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.0454545454545454',  `goals_for_home_ratio` = '1.3636363636363635',  `goals_againts_home_ratio` = '0.6818181818181818',  `rank_home` = '3',  `home_fx_status` = ''  WHERE teams_home_id = '2713'  AND leagueapi_id = '291'  AND season = '2022'  AND fixtureapi_id = '998366'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.5238095238095237',  `goals_for_away_ratio` = '0.9523809523809523',  `goals_againts_away_ratio` = '1.5714285714285714',  `rank_away` = '11',  `away_fx_status` = ''  WHERE teams_away_id = '10387'  AND leagueapi_id = '291'  AND season = '2022'  AND fixtureapi_id = '998366'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[12/129] 291 - 2022
#   ____________2023-03-16 11:30:00 fx:998367
#   ____________Shahrdari Hamedan [18014]  vs Khooshe Talaee Saveh [7501]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '1.6666666666666667',  `goals_for_away_ratio` = '0.6666666666666666',  `goals_againts_away_ratio` = '1.0',  `rank_away` = '9',  `away_fx_status` = ''  WHERE teams_away_id = '7501'  AND leagueapi_id = '291'  AND season = '2022'  AND fixtureapi_id = '998367'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[13/129] 278 - 2023
#   ____________2023-03-16 12:15:00 fx:997445
#   ____________Negeri Sembilan [2502]  vs Terengganu [2518]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[14/129] 887 - 2022
#   ____________2023-03-16 13:00:00 fx:964788
#   ____________Telephonaat Beni Suef [13823]  vs Asmant Asyut [20455]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.2857142857142856',  `goals_for_home_ratio` = '0.7142857142857143',  `goals_againts_home_ratio` = '1.5714285714285714',  `rank_home` = '15',  `home_fx_status` = ''  WHERE teams_home_id = '13823'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964788'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.1904761904761907',  `goals_for_away_ratio` = '0.9523809523809523',  `goals_againts_away_ratio` = '1.2380952380952381',  `rank_away` = '9',  `away_fx_status` = ''  WHERE teams_away_id = '20455'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964788'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[15/129] 887 - 2022
#   ____________2023-03-16 13:00:00 fx:964789
#   ____________Al Nasr Taaden [1047]  vs El Minya [13821]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.3333333333333335',  `goals_for_home_ratio` = '1.4761904761904763',  `goals_againts_home_ratio` = '0.8571428571428571',  `rank_home` = '4',  `home_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-secondary"></i> '  WHERE teams_home_id = '1047'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964789'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '1.7619047619047619',  `goals_for_away_ratio` = '1.0',  `goals_againts_away_ratio` = '0.7619047619047619',  `rank_away` = '7',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '13821'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964789'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[16/129] 887 - 2022
#   ____________2023-03-16 13:00:00 fx:964790
#   ____________Shoban Moslemen Qena [20456]  vs Misr EL Makasa [1038]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.238095238095238',  `goals_for_home_ratio` = '1.0',  `goals_againts_home_ratio` = '1.2380952380952381',  `rank_home` = '11',  `home_fx_status` = ''  WHERE teams_home_id = '20456'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964790'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.8095238095238093',  `goals_for_away_ratio` = '1.5714285714285714',  `goals_againts_away_ratio` = '1.2380952380952381',  `rank_away` = '5',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '1038'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964790'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[17/129] 887 - 2022
#   ____________2023-03-16 13:00:00 fx:964791
#   ____________Tamya [18027]  vs Aluminium Nag Hammadi [18020]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.1904761904761907',  `goals_for_home_ratio` = '0.8095238095238095',  `goals_againts_home_ratio` = '1.380952380952381',  `rank_home` = '14',  `home_fx_status` = ''  WHERE teams_home_id = '18027'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964791'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.0476190476190474',  `goals_for_away_ratio` = '1.2380952380952381',  `goals_againts_away_ratio` = '0.8095238095238095',  `rank_away` = '6',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '18020'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964791'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[18/129] 887 - 2022
#   ____________2023-03-16 13:00:00 fx:964792
#   ____________Mallawi [18026]  vs Dayrout [18022]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.4761904761904763',  `goals_for_home_ratio` = '0.8095238095238095',  `goals_againts_home_ratio` = '1.6666666666666667',  `rank_home` = '13',  `home_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> '  WHERE teams_home_id = '18026'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964792'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.1904761904761907',  `goals_for_away_ratio` = '1.0952380952380953',  `goals_againts_away_ratio` = '1.0952380952380953',  `rank_away` = '10',  `away_fx_status` = '<i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fas fa-flag text-danger"></i> '  WHERE teams_away_id = '18022'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964792'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[19/129] 887 - 2022
#   ____________2023-03-16 13:00:00 fx:964793
#   ____________Asyut Petrol [18021]  vs Kima Aswan [16435]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.0952380952380953',  `goals_for_home_ratio` = '1.4761904761904763',  `goals_againts_home_ratio` = '0.6190476190476191',  `rank_home` = '2',  `home_fx_status` = ''  WHERE teams_home_id = '18021'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964793'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.3333333333333335',  `goals_for_away_ratio` = '1.1904761904761905',  `goals_againts_away_ratio` = '1.1428571428571428',  `rank_away` = '8',  `away_fx_status` = ''  WHERE teams_away_id = '16435'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964793'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[20/129] 887 - 2022
#   ____________2023-03-16 13:00:00 fx:964794
#   ____________El Gouna FC [1574]  vs La Viena FC [16436]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.5238095238095237',  `goals_for_home_ratio` = '1.619047619047619',  `goals_againts_home_ratio` = '0.9047619047619048',  `rank_home` = '3',  `home_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '1574'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964794'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.4285714285714284',  `goals_for_away_ratio` = '1.7619047619047619',  `goals_againts_away_ratio` = '0.6666666666666666',  `rank_away` = '1',  `away_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '16436'  AND leagueapi_id = '887'  AND season = '2022'  AND fixtureapi_id = '964794'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[21/129] 307 - 2022
#   ____________2023-03-16 13:00:00 fx:976691
#   ____________Al Khaleej Saihat [2928]  vs Al Taee [2942]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.210526315789474',  `goals_for_home_ratio` = '0.6842105263157895',  `goals_againts_home_ratio` = '1.5263157894736843',  `rank_home` = '14',  `home_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> '  WHERE teams_home_id = '2928'  AND leagueapi_id = '307'  AND season = '2022'  AND fixtureapi_id = '976691'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.85',  `goals_for_away_ratio` = '1.35',  `goals_againts_away_ratio` = '1.5',  `rank_away` = '8',  `away_fx_status` = ''  WHERE teams_away_id = '2942'  AND leagueapi_id = '307'  AND season = '2022'  AND fixtureapi_id = '976691'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[22/129] 889 - 2022
#   ____________2023-03-16 13:00:00 fx:965269
#   ____________Helal Aldabaa [20460]  vs Kafr El Sheikh [18041]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[23/129] 278 - 2023
#   ____________2023-03-16 13:00:00 fx:997446
#   ____________Perak [2524]  vs Pahang [2525]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[24/129] 943 - 2022
#   ____________2023-03-16 13:30:00 fx:953103
#   ____________Fidelis Andria [1695]  vs Crotone [501]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[25/129] 233 - 2022
#   ____________2023-03-16 15:00:00 fx:967402
#   ____________Ghazl El Mehalla [13819]  vs Al Ittihad [1572]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.380952380952381',  `goals_for_home_ratio` = '1.0',  `goals_againts_home_ratio` = '1.380952380952381',  `rank_home` = '10',  `home_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_home_id = '13819'  AND leagueapi_id = '233'  AND season = '2022'  AND fixtureapi_id = '967402'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.3',  `goals_for_away_ratio` = '1.25',  `goals_againts_away_ratio` = '1.05',  `rank_away` = '4',  `away_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '1572'  AND leagueapi_id = '233'  AND season = '2022'  AND fixtureapi_id = '967402'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[26/129] 237 - 2022
#   ____________2023-03-16 15:00:00 fx:1011977
#   ____________Nizhny Novgorod [2011]  vs FC Rostov [779]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.142857142857143',  `goals_for_home_ratio` = '1.1428571428571428',  `goals_againts_home_ratio` = '1.0',  `rank_home` = '9',  `home_fx_status` = ''  WHERE teams_home_id = '2011'  AND leagueapi_id = '237'  AND season = '2022'  AND fixtureapi_id = '1011977'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.5',  `goals_for_away_ratio` = '1.75',  `goals_againts_away_ratio` = '1.75',  `rank_away` = '13',  `away_fx_status` = ''  WHERE teams_away_id = '779'  AND leagueapi_id = '237'  AND season = '2022'  AND fixtureapi_id = '1011977'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[27/129] 307 - 2022
#   ____________2023-03-16 16:30:00 fx:976694
#   ____________Al-Raed [2935]  vs Al Shabab [2940]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.8',  `goals_for_home_ratio` = '1.25',  `goals_againts_home_ratio` = '1.55',  `rank_home` = '9',  `home_fx_status` = ''  WHERE teams_home_id = '2935'  AND leagueapi_id = '307'  AND season = '2022'  AND fixtureapi_id = '976694'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.95',  `goals_for_away_ratio` = '2.05',  `goals_againts_away_ratio` = '0.9',  `rank_away` = '3',  `away_fx_status` = ''  WHERE teams_away_id = '2940'  AND leagueapi_id = '307'  AND season = '2022'  AND fixtureapi_id = '976694'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[28/129] 943 - 2022
#   ____________2023-03-16 16:30:00 fx:953107
#   ____________Catanzaro [1687]  vs Monterosi [882]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[29/129] 233 - 2022
#   ____________2023-03-16 17:00:00 fx:967403
#   ____________Smouha SC [1044]  vs Ismaily SC [1030]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '1.8095238095238095',  `goals_for_home_ratio` = '0.9047619047619048',  `goals_againts_home_ratio` = '0.9047619047619048',  `rank_home` = '9',  `home_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '1044'  AND leagueapi_id = '233'  AND season = '2022'  AND fixtureapi_id = '967403'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '1.8',  `goals_for_away_ratio` = '0.7',  `goals_againts_away_ratio` = '1.1',  `rank_away` = '17',  `away_fx_status` = '<i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_away_id = '1030'  AND leagueapi_id = '233'  AND season = '2022'  AND fixtureapi_id = '967403'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[30/129] 318 - 2022
#   ____________2023-03-16 17:00:00 fx:1014329
#   ____________Doxa [3398]  vs Karmiotissa [3413]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.1481481481481484',  `goals_for_home_ratio` = '0.7037037037037037',  `goals_againts_home_ratio` = '1.4444444444444444',  `rank_home` = '12',  `home_fx_status` = ''  WHERE teams_home_id = '3398'  AND leagueapi_id = '318'  AND season = '2022'  AND fixtureapi_id = '1014329'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.4814814814814814',  `goals_for_away_ratio` = '0.9629629629629629',  `goals_againts_away_ratio` = '1.5185185185185186',  `rank_away` = '10',  `away_fx_status` = ''  WHERE teams_away_id = '3413'  AND leagueapi_id = '318'  AND season = '2022'  AND fixtureapi_id = '1014329'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[31/129] 3 - 2022
#   ____________2023-03-16 17:45:00 fx:1010831
#   ____________SC Freiburg [160]  vs Juventus [496]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.4285714285714284',  `goals_for_home_ratio` = '1.8571428571428572',  `goals_againts_home_ratio` = '0.5714285714285714',  `rank_home` = '22',  `home_fx_status` = ''  WHERE teams_home_id = '160'  AND leagueapi_id = '3'  AND season = '2022'  AND fixtureapi_id = '1010831'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.111111111111111',  `goals_for_away_ratio` = '1.5555555555555556',  `goals_againts_away_ratio` = '1.5555555555555556',  `rank_away` = '41',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '496'  AND leagueapi_id = '3'  AND season = '2022'  AND fixtureapi_id = '1010831'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[32/129] 3 - 2022
#   ____________2023-03-16 17:45:00 fx:1010833
#   ____________Fenerbahce [611]  vs Sevilla [536]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.8461538461538463',  `goals_for_home_ratio` = '1.8461538461538463',  `goals_againts_home_ratio` = '1.0',  `rank_home` = '1',  `home_fx_status` = ''  WHERE teams_home_id = '611'  AND leagueapi_id = '3'  AND season = '2022'  AND fixtureapi_id = '1010833'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.7777777777777777',  `goals_for_away_ratio` = '1.2222222222222223',  `goals_againts_away_ratio` = '1.5555555555555556',  `rank_away` = '37',  `away_fx_status` = ''  WHERE teams_away_id = '536'  AND leagueapi_id = '3'  AND season = '2022'  AND fixtureapi_id = '1010833'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[33/129] 3 - 2022
#   ____________2023-03-16 17:45:00 fx:1010835
#   ____________Real Betis [543]  vs Manchester United [33]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.0',  `goals_for_home_ratio` = '1.8571428571428572',  `goals_againts_home_ratio` = '1.1428571428571428',  `rank_home` = '18',  `home_fx_status` = ''  WHERE teams_home_id = '543'  AND leagueapi_id = '3'  AND season = '2022'  AND fixtureapi_id = '1010835'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.7777777777777777',  `goals_for_away_ratio` = '2.0',  `goals_againts_away_ratio` = '0.7777777777777778',  `rank_away` = '5',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '33'  AND leagueapi_id = '3'  AND season = '2022'  AND fixtureapi_id = '1010835'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[34/129] 3 - 2022
#   ____________2023-03-16 17:45:00 fx:1010837
#   ____________Feyenoord [209]  vs Shakhtar Donetsk [550]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.4285714285714284',  `goals_for_home_ratio` = '2.0',  `goals_againts_home_ratio` = '1.4285714285714286',  `rank_home` = '45',  `home_fx_status` = ''  WHERE teams_home_id = '209'  AND leagueapi_id = '3'  AND season = '2022'  AND fixtureapi_id = '1010837'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.888888888888889',  `goals_for_away_ratio` = '1.3333333333333333',  `goals_againts_away_ratio` = '1.5555555555555556',  `rank_away` = '42',  `away_fx_status` = ''  WHERE teams_away_id = '550'  AND leagueapi_id = '3'  AND season = '2022'  AND fixtureapi_id = '1010837'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[35/129] 848 - 2022
#   ____________2023-03-16 17:45:00 fx:1010853
#   ____________Sivasspor [1002]  vs Fiorentina [502]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.7777777777777777',  `goals_for_home_ratio` = '1.3333333333333333',  `goals_againts_home_ratio` = '1.4444444444444444',  `rank_home` = '47',  `home_fx_status` = ''  WHERE teams_home_id = '1002'  AND leagueapi_id = '848'  AND season = '2022'  AND fixtureapi_id = '1010853'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.0',  `goals_for_away_ratio` = '2.1818181818181817',  `goals_againts_away_ratio` = '0.8181818181818182',  `rank_away` = '6',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '502'  AND leagueapi_id = '848'  AND season = '2022'  AND fixtureapi_id = '1010853'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[36/129] 848 - 2022
#   ____________2023-03-16 17:45:00 fx:1010855
#   ____________Djurgardens IF [364]  vs Lech Poznan [347]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.1538461538461537',  `goals_for_home_ratio` = '2.076923076923077',  `goals_againts_home_ratio` = '1.0769230769230769',  `rank_home` = '2',  `home_fx_status` = ''  WHERE teams_home_id = '364'  AND leagueapi_id = '848'  AND season = '2022'  AND fixtureapi_id = '1010855'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.7058823529411766',  `goals_for_away_ratio` = '1.7647058823529411',  `goals_againts_away_ratio` = '0.9411764705882353',  `rank_away` = '3',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '347'  AND leagueapi_id = '848'  AND season = '2022'  AND fixtureapi_id = '1010855'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[37/129] 848 - 2022
#   ____________2023-03-16 17:45:00 fx:1010857
#   ____________Slovan Bratislava [656]  vs FC Basel 1893 [551]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.7333333333333334',  `goals_for_home_ratio` = '1.4',  `goals_againts_home_ratio` = '1.3333333333333333',  `rank_home` = '9',  `home_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_home_id = '656'  AND leagueapi_id = '848'  AND season = '2022'  AND fixtureapi_id = '1010857'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.533333333333333',  `goals_for_away_ratio` = '1.4666666666666666',  `goals_againts_away_ratio` = '1.0666666666666667',  `rank_away` = '7',  `away_fx_status` = ''  WHERE teams_away_id = '551'  AND leagueapi_id = '848'  AND season = '2022'  AND fixtureapi_id = '1010857'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[38/129] 740 - 2023
#   ____________2023-03-16 18:00:00 fx:1010641
#   ____________Corinthians U20 [12998]  vs RB Bragantino U20 [18345]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[39/129] 740 - 2023
#   ____________2023-03-16 18:00:00 fx:1010642
#   ____________Fortaleza U20 [13009]  vs Athletico PR U20 [12984]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[40/129] 703 - 2022
#   ____________2023-03-16 19:00:00 fx:948532
#   ____________Queens Park Rangers U21 [20085]  vs Charlton Athletic U21 [20082]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '4.111111111111111',  `goals_for_home_ratio` = '2.1666666666666665',  `goals_againts_home_ratio` = '1.9444444444444444',  `rank_home` = '12',  `home_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_home_id = '20085'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948532'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.9047619047619047',  `goals_for_away_ratio` = '2.0952380952380953',  `goals_againts_away_ratio` = '1.8095238095238095',  `rank_away` = '8',  `away_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-secondary"></i> '  WHERE teams_away_id = '20082'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948532'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[41/129] 357 - 2023
#   ____________2023-03-16 19:45:00 fx:1002552
#   ____________Drogheda United [3850]  vs Dundalk [584]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Total Row(s) : 0
#
#   ____________[42/129] 3 - 2022
#   ____________2023-03-16 20:00:00 fx:1010823
#   ____________Union St. Gilloise [1393]  vs Union Berlin [182]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
