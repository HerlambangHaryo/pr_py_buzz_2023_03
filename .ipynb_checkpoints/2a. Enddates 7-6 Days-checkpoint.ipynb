# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

today = datetime.datetime.now()  
days0 = 7
days1 = 6
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 7 - 6 --> 2023-03-24 19:21:48.860416

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 19:21:48
#   __main()
#   ____get_date()
#   ______days : 7
#   ______days : 6
#   ______tgl_awal : 2023-03-17
#   ______tgl_akhir : 2023-03-18
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-18'  and date >= '2023-03-17'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 11
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 170
#   ______________1. 2023-03-17 // 12 // 8 // 2022 // 978817 // H // G
#   ______________2. 2023-03-17 // 12 // 8 // 2022 // 978819 // H // G
#   ______________3. 2023-03-17 // 12 // 8 // 2022 // 978820 // H // G
#   ______________4. 2023-03-17 // 39 // 8 // 2022 // 868223 // 05+075+1+125+H // 2g225g25g275gG
#   ______________5. 2023-03-17 // 41 // 8 // 2022 // 875942 // 1_075_05_H // 225g25g275gG
#   ______________6. 2023-03-17 // 61 // 8 // 2022 // 871743 // 1_075_05_H // 225g25g275g3gG
#   ______________7. 2023-03-17 // 63 // 11 // 2022 // 914099 // 0#025+075+H // 175g2g225g25g275gG
#   ______________8. 2023-03-17 // 63 // 11 // 2022 // 914100 // 1_075_025_H // 2g225g25g275gG
#   ______________9. 2023-03-17 // 63 // 11 // 2022 // 914102 // 025_0#H // 15g175g2g225gG
#   ______________10. 2023-03-17 // 63 // 11 // 2022 // 914103 // 025_0#025+H // 15g175g2g225gG
#   ______________11. 2023-03-17 // 63 // 11 // 2022 // 914105 // 1_075_025_H // 175g2g225g25gG
#   ______________12. 2023-03-17 // 63 // 11 // 2022 // 914106 // 075_025_H // 175g2g225g25gG
#   ______________13. 2023-03-17 // 63 // 11 // 2022 // 924499 // 075_025_0#H // 175g2g225g25g275gG
#   ______________14. 2023-03-17 // 69 // 11 // 2022 // 917043 // None // None
#   ______________15. 2023-03-17 // 78 // 8 // 2022 // 871385 // 1_075_05_025_H // 25g275g3g325g35gG
#   ______________16. 2023-03-17 // 80 // 8 // 2022 // 879389 // H // G
#   ______________17. 2023-03-17 // 82 // 11 // 2022 // 885873 // H // G
#   ______________18. 2023-03-17 // 83 // 8 // 2022 // 904283 // H // G
#   ______________19. 2023-03-17 // 83 // 8 // 2022 // 904287 // H // G
#   ______________20. 2023-03-17 // 84 // 8 // 2022 // 909350 // H // G
#   ______________21. 2023-03-17 // 85 // 8 // 2022 // 904610 // H // G
#   ______________22. 2023-03-17 // 85 // 8 // 2022 // 904611 // H // G
#   ______________23. 2023-03-17 // 85 // 8 // 2022 // 904616 // H // G
#   ______________24. 2023-03-17 // 86 // 8 // 2022 // 904902 // H // G
#   ______________25. 2023-03-17 // 88 // 8 // 2022 // 872455 // 05_025_0#025+H // 225g25g275g3g325gG
#   ______________26. 2023-03-17 // 89 // 11 // 2022 // 867844 // 025+075+H // 225g25g275g3gG
#   ______________27. 2023-03-17 // 89 // 11 // 2022 // 867845 // 075_025_0#H // 225g25g275g3g325gG
#   ______________28. 2023-03-17 // 89 // 11 // 2022 // 867846 // 025_0#025+H // 2g225g25g275gG
#   ______________29. 2023-03-17 // 89 // 11 // 2022 // 867847 // 075_025_0#025+H // 25g275g3g325g35g375gG
#   ______________30. 2023-03-17 // 89 // 11 // 2022 // 867848 // 075+1+125+15+H // 25g275g3g325g35gG
#   ______________31. 2023-03-17 // 89 // 11 // 2022 // 867849 // 2_175_15_125_H // 275g3g325g35g375gG
#   ______________32. 2023-03-17 // 89 // 11 // 2022 // 867851 // 025+075+H // 25g275g3g325g35g375gG
#   ______________33. 2023-03-17 // 89 // 11 // 2022 // 867852 // 0#025+H // 225g25g275g3gG
#   ______________34. 2023-03-17 // 89 // 11 // 2022 // 867853 // 025+075+H // 225g25g275g3g325gG
#   ______________35. 2023-03-17 // 94 // 8 // 2022 // 898823 // 025_0#025+H // 175g2g225g25gG
#   ______________36. 2023-03-17 // 107 // 8 // 2022 // 867079 // 1+125+15+H // 225g25g275g3gG
#   ______________37. 2023-03-17 // 111 // 11 // 2022 // 892984 // H // G
#   ______________38. 2023-03-17 // 116 // 11 // 2023 // 1009510 // 025+075+1+H // 225g25g275g3gG
#   ______________39. 2023-03-17 // 122 // 8 // 2022 // 884178 // H // G
#   ______________40. 2023-03-17 // 122 // 8 // 2022 // 884179 // H // G
#   ______________41. 2023-03-17 // 122 // 8 // 2022 // 884180 // H // G
#   ______________42. 2023-03-18 // 128 // 8 // 2023 // 971443 // 025_0#025+H // 175g2g225g25gG
#   ______________43. 2023-03-17 // 129 // 8 // 2023 // 992655 // 05_025_0#H // 15g175g2g225gG
#   ______________44. 2023-03-17 // 135 // 8 // 2022 // 882040 // 175_15_125_1_H // 25g275g3g325gG
#   ______________45. 2023-03-17 // 135 // 8 // 2022 // 882044 // 1_075_05_H // 25g275g3g325gG
#   ______________46. 2023-03-17 // 136 // 8 // 2022 // 903837 // 05_025_0#H // 2g225g25gG
#   ______________47. 2023-03-17 // 140 // 8 // 2022 // 878198 // 025+05+075+H // 2g225g25g275gG
#   ______________48. 2023-03-17 // 141 // 8 // 2022 // 878673 // 025+05+075+H // 2g225g25gG
#   ______________49. 2023-03-17 // 144 // 8 // 2022 // 874994 // 0#025+05+H // 225g25g275g3g325gG
#   ______________50. 2023-03-17 // 145 // 8 // 2022 // 1005165 // 15_125_1_075_05_H // 275g3g325g35gG
#   ______________51. 2023-03-17 // 145 // 8 // 2022 // 1005195 // 075_05_025_H // 225g25g275g3gG
#   ______________52. 2023-03-17 // 146 // 11 // 2022 // 1010509 // 2_175_15_125_1_H // 3g325g35g375g4gG
#   ______________53. 2023-03-17 // 146 // 11 // 2022 // 1010510 // 15+H // 35gG
#   ______________54. 2023-03-17 // 146 // 11 // 2022 // 1010539 // 1+H // 3g35gG
#   ______________55. 2023-03-17 // 172 // 8 // 2022 // 883502 // 125_1_075_H // 2g225g25gG
#   ______________56. 2023-03-17 // 172 // 8 // 2022 // 883506 // 025_0#025+H // 175g2g225g25gG
#   ______________57. 2023-03-17 // 173 // 11 // 2022 // 882797 // 025_0#025+H // 175g2g225g25g275gG
#   ______________58. 2023-03-17 // 173 // 11 // 2022 // 882800 // 075_025_H // 15g175g2g225g25gG
#   ______________59. 2023-03-17 // 173 // 11 // 2022 // 882802 // 175_15_125_1_075_H // 2g225g25g275gG
#   ______________60. 2023-03-17 // 180 // 8 // 2022 // 873461 // 025_0#025+H // 2g225g25gG
#   ______________61. 2023-03-17 // 188 // 8 // 2022 // 924634 // 075_05_025_0#H // 275g3g325g35gG
#   ______________62. 2023-03-17 // 190 // 8 // 2022 // 961721 // H // G
#   ______________63. 2023-03-17 // 195 // 8 // 2023 // 978883 // 025_0#025+05+H // 25gG
#   ______________64. 2023-03-17 // 195 // 8 // 2023 // 978884 // 125_1_075_05_H // 25gG
#   ______________65. 2023-03-17 // 203 // 8 // 2022 // 884567 // H // G
#   ______________66. 2023-03-17 // 204 // 8 // 2022 // 885008 // None // None
#   ______________67. 2023-03-17 // 208 // 11 // 2022 // 869399 // 075_025_H // 25g275g3g325g35gG
#   ______________68. 2023-03-17 // 208 // 11 // 2022 // 869400 // 075_025_H // 25g275g3g325g35gG
#   ______________69. 2023-03-17 // 211 // 11 // 2022 // 930341 // 125_1_075_H // 2g225g25g275gG
#   ______________70. 2023-03-17 // 219 // 8 // 2022 // 878992 // H // G
#   ______________71. 2023-03-17 // 219 // 8 // 2022 // 878993 // H // G
#   ______________72. 2023-03-17 // 219 // 8 // 2022 // 878995 // H // G
#   ______________73. 2023-03-17 // 219 // 8 // 2022 // 878997 // H // G
#   ______________74. 2023-03-17 // 221 // 11 // 2022 // 896671 // H // G
#   ______________75. 2023-03-17 // 221 // 11 // 2022 // 896673 // H // G
#   ______________76. 2023-03-17 // 221 // 11 // 2022 // 896674 // H // G
#   ______________77. 2023-03-17 // 221 // 11 // 2022 // 896675 // H // G
#   ______________78. 2023-03-17 // 221 // 11 // 2022 // 896676 // H // G
#   ______________79. 2023-03-17 // 221 // 11 // 2022 // 896678 // H // G
#   ______________80. 2023-03-17 // 222 // 11 // 2022 // 896420 // H // G
#   ______________81. 2023-03-17 // 223 // 11 // 2022 // 896875 // H // G
#   ______________82. 2023-03-17 // 236 // 11 // 2022 // 881514 // 075_025_0#H // 2g225g25g275gG
#   ______________83. 2023-03-18 // 242 // 8 // 2023 // 996241 // None // None
#   ______________84. 2023-03-18 // 255 // 11 // 2023 // 1008358 // 15_125_1_075_H // 25g275g3g325g35gG
#   ______________85. 2023-03-17 // 263 // 8 // 2022 // 975958 // H // G
#   ______________86. 2023-03-17 // 263 // 8 // 2022 // 975959 // 025_0#H // 25gG
#   ______________87. 2023-03-17 // 265 // 8 // 2023 // 983732 // 1_075_05_025_H // 225g25g275g3gG
#   ______________88. 2023-03-17 // 268 // 8 // 2023 // 1003368 // 075_05_025_H // 2g225g25gG
#   ______________89. 2023-03-17 // 274 // 11 // 2022 // 899802 // 075_025_H // 225g25g275g3gG
#   ______________90. 2023-03-17 // 278 // 11 // 2023 // 997447 // 2_175_15_125_H // 25g275g3g325g35gG
#   ______________91. 2023-03-17 // 278 // 11 // 2023 // 997449 // 075+1+125+15+175+H // 225g25g275g3g325gG
#   ______________92. 2023-03-17 // 278 // 11 // 2023 // 997448 // None // None
#   ______________93. 2023-03-17 // 278 // 11 // 2023 // 997450 // None // None
#   ______________94. 2023-03-17 // 281 // 8 // 2023 // 985153 // H // 25gG
#   ______________95. 2023-03-17 // 286 // 11 // 2022 // 877125 // 0#025+H // 175g2g225g25g275gG
#   ______________96. 2023-03-17 // 286 // 11 // 2022 // 877129 // 225_2_175_15_125_H // 225g25g275g3g325gG
#   ______________97. 2023-03-17 // 288 // 8 // 2022 // 930547 // H // G
#   ______________98. 2023-03-17 // 288 // 8 // 2022 // 930550 // H // G
#   ______________99. 2023-03-17 // 299 // 11 // 2023 // 998089 // 025+075+1+H // 2g225g25g275gG
#   ______________100. 2023-03-17 // 299 // 11 // 2023 // 998087 // None // None
#   ______________101. 2023-03-17 // 301 // 8 // 2022 // 986029 // 125_1_075_05_H // 25gG
#   ______________102. 2023-03-17 // 301 // 8 // 2022 // 986031 // 175_15_125_1_H // 25gG
#   ______________103. 2023-03-17 // 301 // 8 // 2022 // 986032 // 125+15+175+H // 25gG
#   ______________104. 2023-03-17 // 301 // 8 // 2022 // 986034 // 175_15_125_1_H // 25gG
#   ______________105. 2023-03-17 // 303 // 11 // 2022 // 946531 // 025+075+1+125+H // 225g25g275g3gG
#   ______________106. 2023-03-17 // 305 // 11 // 2022 // 980364 // H // G
#   ______________107. 2023-03-17 // 305 // 11 // 2022 // 980365 // 125+15+175+2+225+H // 275g3g325g35g375gG
#   ______________108. 2023-03-17 // 305 // 11 // 2022 // 980366 // H // G
#   ______________109. 2023-03-17 // 307 // 8 // 2022 // 976692 // 0#025+05+075+H // 25gG
#   ______________110. 2023-03-17 // 307 // 8 // 2022 // 976697 // 1_075_05_025_H // 25gG
#   ______________111. 2023-03-17 // 307 // 8 // 2022 // 976698 // 125_1_075_05_H // 25gG
#   ______________112. 2023-03-17 // 318 // 8 // 2022 // 1014326 // None // None
#   ______________113. 2023-03-17 // 318 // 8 // 2022 // 1014330 // None // None
#   ______________114. 2023-03-17 // 326 // 11 // 2023 // 1000767 // None // None
#   ______________115. 2023-03-17 // 333 // 8 // 2022 // 942314 // H // 25gG
#   ______________116. 2023-03-17 // 349 // 11 // 2022 // 969571 // None // None
#   ______________117. 2023-03-17 // 358 // 8 // 2023 // 998570 // H // G
#   ______________118. 2023-03-17 // 358 // 8 // 2023 // 998571 // H // G
#   ______________119. 2023-03-17 // 358 // 8 // 2023 // 998572 // H // G
#   ______________120. 2023-03-17 // 361 // 11 // 2023 // 1011574 // 0#H // 3g35gG
#   ______________121. 2023-03-17 // 361 // 11 // 2023 // 1011575 // None // None
#   ______________122. 2023-03-17 // 369 // 11 // 2023 // 1005559 // 075_025_H // 175g2g225g25gG
#   ______________123. 2023-03-17 // 369 // 11 // 2023 // 1005560 // 0#025+075+H // 2g225g25g275gG
#   ______________124. 2023-03-17 // 369 // 11 // 2023 // 1005561 // None // None
#   ______________125. 2023-03-17 // 374 // 11 // 2022 // 885710 // H // G
#   ______________126. 2023-03-17 // 374 // 11 // 2022 // 885714 // H // G
#   ______________127. 2023-03-17 // 386 // 11 // 2022 // 1015650 // None // None
#   ______________128. 2023-03-17 // 386 // 11 // 2022 // 1015651 // None // None
#   ______________129. 2023-03-17 // 406 // 11 // 2022 // 986802 // H // 2gG
#   ______________130. 2023-03-17 // 406 // 11 // 2022 // 986804 // 0#H // 15g2gG
#   ______________131. 2023-03-17 // 450 // 11 // 2022 // 956769 // H // G
#   ______________132. 2023-03-17 // 450 // 11 // 2022 // 956770 // H // G
#   ______________133. 2023-03-17 // 475 // 8 // 2023 // 1014794 // None // None
#   ______________134. 2023-03-17 // 489 // 11 // 2023 // 985975 // 025+075+H // 225g25g275gG
#   ______________135. 2023-03-17 // 494 // 11 // 2022 // 966782 // 025+075+H // 15g175g2g225gG
#   ______________136. 2023-03-17 // 496 // 11 // 2022 // 934588 // H // G
#   ______________137. 2023-03-17 // 496 // 11 // 2022 // 934589 // 0#H // 2g25gG
#   ______________138. 2023-03-17 // 496 // 11 // 2022 // 934590 // 0#H // 25g3gG
#   ______________139. 2023-03-17 // 496 // 11 // 2022 // 934591 // H // G
#   ______________140. 2023-03-17 // 496 // 11 // 2022 // 934593 // H // 2g25gG
#   ______________141. 2023-03-17 // 496 // 11 // 2022 // 934594 // H // G
#   ______________142. 2023-03-17 // 496 // 11 // 2022 // 934595 // 0#H // 2g25gG
#   ______________143. 2023-03-17 // 496 // 11 // 2022 // 934826 // H // 2g25gG
#   ______________144. 2023-03-17 // 496 // 11 // 2022 // 934830 // 025_0#H // 175g2g225g25g275gG
#   ______________145. 2023-03-17 // 506 // 11 // 2022 // 887975 // H // G
#   ______________146. 2023-03-17 // 506 // 11 // 2022 // 887977 // H // G
#   ______________147. 2023-03-17 // 673 // 8 // 2022 // 976337 // H // G
#   ______________148. 2023-03-17 // 702 // 11 // 2022 // 924950 // H // G
#   ______________149. 2023-03-17 // 702 // 11 // 2022 // 924951 // 025_0#025+H // 25g275g3g325g35gG
#   ______________150. 2023-03-17 // 702 // 11 // 2022 // 924952 // H // G
#   ______________151. 2023-03-17 // 702 // 11 // 2022 // 925075 // H // G
#   ______________152. 2023-03-17 // 703 // 11 // 2022 // 948595 // 025_0#025+H // 275g3g325g35g375gG
#   ______________153. 2023-03-17 // 703 // 11 // 2022 // 948600 // 075_025_0#025+H // 3g325g35g375g4gG
#   ______________154. 2023-03-17 // 722 // 11 // 2022 // 938855 // H // G
#   ______________155. 2023-03-17 // 722 // 11 // 2022 // 938858 // H // G
#   ______________156. 2023-03-17 // 740 // 11 // 2023 // 1010640 // None // None
#   ______________157. 2023-03-17 // 745 // 11 // 2022 // 907861 // H // G
#   ______________158. 2023-03-17 // 745 // 11 // 2022 // 907862 // H // G
#   ______________159. 2023-03-17 // 745 // 11 // 2022 // 907864 // H // G
#   ______________160. 2023-03-17 // 747 // 11 // 2022 // 906802 // None // None
#   ______________161. 2023-03-17 // 747 // 11 // 2022 // 906803 // None // None
#   ______________162. 2023-03-17 // 749 // 11 // 2022 // 926161 // H // G
#   ______________163. 2023-03-17 // 751 // 11 // 2022 // 906459 // H // G
#   ______________164. 2023-03-17 // 751 // 11 // 2022 // 906467 // H // G
#   ______________165. 2023-03-17 // 754 // 11 // 2022 // 905551 // None // None
#   ______________166. 2023-03-17 // 755 // 11 // 2022 // 905853 // H // G
#   ______________167. 2023-03-17 // 781 // 11 // 2022 // 969421 // H // G
#   ______________168. 2023-03-17 // 888 // 11 // 2022 // 965029 // H // G
#   ______________169. 2023-03-17 // 888 // 11 // 2022 // 965033 // H // G
#   ______________170. 2023-03-17 // 888 // 11 // 2022 // 965034 // H // G
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-03-17 // 69 // 11 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 99
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-17
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 69
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________2. 2023-03-17 // 129 // 8 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 98
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-17
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 129
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Argentina,  Primera Nacional  #129 - 2023 / 992651
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.85',
#   ____________________________end_match_winner_draw = '3.20',
#   ____________________________end_match_winner_away = '4.75',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '1.33',
#   ____________________________end_homeaway_away = '3.25',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '2.20',
#   ____________________________end_second_half_winner_draw = '2.20',
#   ____________________________end_second_half_winner_away = '4.75',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.32',
#   ____________________________end_asian_handicap_away_plus_0 = '3.30',
#   ____________________________end_asian_handicap_home_min_025 = '1.60',
#   ____________________________end_asian_handicap_away_min_025 = '2.30',
#   ____________________________end_asian_handicap_home_plus_025 = '1.25',
#   ____________________________end_asian_handicap_away_plus_025 = '3.80',
#   ____________________________end_asian_handicap_home_min_05 = '1.88',
#   ____________________________end_asian_handicap_away_min_05 = '1.98',
#   ____________________________end_asian_handicap_home_plus_05 = '1.20',
#   ____________________________end_asian_handicap_away_plus_05 = '4.40',
#   ____________________________end_asian_handicap_home_min_075 = '2.15',
#   ____________________________end_asian_handicap_away_min_075 = '1.68',
#   ____________________________end_asian_handicap_home_plus_075 = '1.13',
#   ____________________________end_asian_handicap_away_plus_075 = '6.00',
#   ____________________________end_asian_handicap_home_min_1 = '2.67',
#   ____________________________end_asian_handicap_away_min_1 = '1.45',
#   ____________________________end_asian_handicap_home_min_15 = '3.55',
#   ____________________________end_asian_handicap_away_min_15 = '1.27',
#   ____________________________end_asian_handicap_home_min_125 = '3.10',
#   ____________________________end_asian_handicap_away_min_125 = '1.35',
#   ____________________________end_asian_handicap_home_min_175 = '4.50',
#   ____________________________end_asian_handicap_away_min_175 = '1.19',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '5.00',
#   ____________________________end_goals_overunder_under_35 = '1.17',
#   ____________________________end_goals_overunder_over_15 = '1.50',
#   ____________________________end_goals_overunder_under_15 = '2.50',
#   ____________________________end_goals_overunder_over_45 = '13.00',
#   ____________________________end_goals_overunder_under_45 = '1.04',
#   ____________________________end_goals_overunder_over_25 = '2.60',
#   ____________________________end_goals_overunder_under_25 = '1.48',
#   ____________________________end_goals_overunder_over_05 = '1.11',
#   ____________________________end_goals_overunder_under_05 = '6.50',
#   ____________________________end_goals_overunder_over_55 = '26.00',
#   ____________________________end_goals_overunder_under_55 = '1.01',
#   ____________________________end_goals_overunder_over_225 = '2.25',
#   ____________________________end_goals_overunder_under_225 = '1.63',
#   ____________________________end_goals_overunder_over_325 = '4.65',
#   ____________________________end_goals_overunder_under_325 = '1.18',
#   ____________________________end_goals_overunder_over_275 = '3.10',
#   ____________________________end_goals_overunder_under_275 = '1.35',
#   ____________________________end_goals_overunder_over_125 = '1.32',
#   ____________________________end_goals_overunder_under_125 = '3.30',
#   ____________________________end_goals_overunder_over_175 = '1.68',
#   ____________________________end_goals_overunder_under_175 = '2.15',
#   ____________________________end_goals_overunder_over_375 = '6.80',
#   ____________________________end_goals_overunder_under_375 = '1.10',
#   ____________________________end_goals_overunder_over_65 = '51.00',
#   ____________________________end_goals_overunder_under_65 = '1.00',
#   ____________________________end_goals_overunder_over_075 = '1.13',
#   ____________________________end_goals_overunder_under_075 = '5.90',
#   ____________________________end_goals_overunder_over_30 = '4.25',
#   ____________________________end_goals_overunder_under_30 = '1.21',
#   ____________________________end_goals_overunder_over_20 = '1.98',
#   ____________________________end_goals_overunder_under_20 = '1.88',
#   ____________________________end_goals_overunder_over_10 = '1.16',
#   ____________________________end_goals_overunder_under_10 = '5.25',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_15 = '3.75',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.25',
#   ____________________________end_goals_overunder_first_half_over_25 = '11.00',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.05',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.57',
#   ____________________________end_goals_overunder_first_half_under_05 = '2.25',
#   ____________________________end_goals_overunder_first_half_over_125 = '3.10',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.35',
#   ____________________________end_goals_overunder_first_half_over_175 = '5.25',
#   ____________________________end_goals_overunder_first_half_under_175 = '1.16',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.85',
#   ____________________________end_goals_overunder_first_half_under_075 = '1.95',
#   ____________________________end_goals_overunder_first_half_over_10 = '2.42',
#   ____________________________end_goals_overunder_first_half_under_10 = '1.52',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '19.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.02',
#   ____________________________end_goals_overunder__second_half_over_15 = '2.63',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.44',
#   ____________________________end_goals_overunder__second_half_over_25 = '7.00',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.10',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.36',
#   ____________________________end_goals_overunder__second_half_under_05 = '3.00',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________end_clean_sheet__home_yes = '1.91',
#   ____________________________end_clean_sheet__home_no = '1.80',
#   __________________________28 Clean Sheet - Away
#   ____________________________end_clean_sheet__away_yes = '3.50',
#   ____________________________end_clean_sheet__away_no = '1.29',
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '2.25',
#   ____________________________end_both_teams_score_no = '1.57',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 3.60
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.18
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.06
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.60
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 251.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 301.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.25
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 301.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 351.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.18',
#   ____________________________end_double_chance_home_away = '1.36',
#   ____________________________end_double_chance_draw_away = '1.91',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '2.60',
#   ____________________________end_first_half_winner_draw = '1.95',
#   ____________________________end_first_half_winner_away = '5.50',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.57
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 3.10
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.57
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 3.10
#   __________________________32 Win Both Halves
#   ____________________________end_win_both_halves_home = '6.00',
#   ____________________________end_win_both_halves_away = '21.00',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.03
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.25
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.57
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.14
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.17
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.02
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.25
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.06
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.01
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________end_win_to_nil_home = '2.63',
#   ____________________________end_win_to_nil_away = '6.50',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.67
#   __________________________39 To Win Either Half
#   ____________________________end_to_win_either_half_home = '1.53',
#   ____________________________end_to_win_either_half_away = '2.75',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________24 Results/Both Teams Score
#   ____________________________end_results_both_teams_score_home_yes = '5.50',
#   ____________________________end_results_both_teams_score_draw_yes = '5.00',
#   ____________________________end_results_both_teams_score_away_yes = '12.00',
#   ____________________________end_results_both_teams_score_home_no = '2.63',
#   ____________________________end_results_both_teams_score_draw_no = '6.50',
#   ____________________________end_results_both_teams_score_away_no = '6.50',
#   __________________________25 Result/Total Goals
#   ____________________________end_result_total_goals_home_over_25 = '3.75',
#   ____________________________end_result_total_goals_draw_over_25 = '21.00',
#   ____________________________end_result_total_goals_away_over_25 = '10.00',
#   ____________________________end_result_total_goals_home_under_25 = '3.25',
#   ____________________________end_result_total_goals_draw_under_25 = '3.50',
#   ____________________________end_result_total_goals_away_under_25 = '7.00',
#   __________________________43 Home Team Score a Goal
#   ______________________  ______________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 43 --- bets_value: No --- bets_odd: 3.50
#   __________________________44 Away Team Score a Goal
#   ______________________  ______________________bet_id: 44 --- bets_value: Yes --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 44 --- bets_value: No --- bets_odd: 1.91
#   __________________________54 First 10 min Winner
#   ______________________  ______________________bet_id: 54 --- bets_value: Home --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 54 --- bets_value: Draw --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 54 --- bets_value: Away --- bets_odd: 12.00
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 1.67
#   __________________________47 Winning Margin
#   ______________________  ______________________bet_id: 47 --- bets_value: Draw --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 5.00
#   __________________________48 To Score In Both Halves By Teams
#   __________________________49 Total Goals/Both Teams To Score
#   ____________________________end_total_goals_both_teams_to_score_over_yes_25 = '3.25',
#   ____________________________end_total_goals_both_teams_to_score_over_no_25 = '9.50',
#   ____________________________end_total_goals_both_teams_to_score_under_yes_25 = '6.50',
#   ____________________________end_total_goals_both_teams_to_score_under_no_25 = '1.80',
#   __________________________91 Total Goals (3 way)
#   ______________________  ______________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 5.00
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 5.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.16
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.52
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 2.42
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 2.60
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.48
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 0.5 --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 0.5 --- bets_odd: 6.60
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.98
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 1.88
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 4.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.21
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 2.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 1.63
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 4.65
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.18
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.35
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.32
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 3.30
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.68
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 2.15
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 6.80
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1 --- bets_odd: 1.16
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1 --- bets_odd: 5.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 0.75 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 0.75 --- bets_odd: 5.90
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 3.70
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.26
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.5 --- bets_odd: 1.58
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.5 --- bets_odd: 2.35
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.35
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 5.25
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.16
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 2.42
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.52
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.85
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 1.95
#   __________________________52 Halftime Result/Both Teams Score
#   __________________________85 Total Corners (3 way)
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 9 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 9 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 9 --- bets_odd: 7.50
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   __________________________74 10 Over/Under
#   __________________________78 RTG_H1
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 10.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 2.25
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 3.60
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 6.50
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
#   ____________3. 2023-03-17 // 190 // 8 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 97
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-17
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 190
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________4. 2023-03-17 // 222 // 11 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 96
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-17
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 222
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 5
#
#   ____________________1. Austria,  Regionalliga - Mitte  #222 - 2022 / 896417
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.44',
#   ____________________________end_match_winner_draw = '4.74',
#   ____________________________end_match_winner_away = '5.70',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '1.71',
#   ____________________________end_second_half_winner_draw = '3.13',
#   ____________________________end_second_half_winner_away = '4.98',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.16',
#   ____________________________end_asian_handicap_away_plus_0 = '4.34',
#   ____________________________end_asian_handicap_home_min_025 = '1.29',
#   ____________________________end_asian_handicap_away_min_025 = '3.20',
#   ____________________________end_asian_handicap_home_plus_025 = '1.14',
#   ____________________________end_asian_handicap_away_plus_025 = '4.76',
#   ____________________________end_asian_handicap_home_min_075 = '1.52',
#   ____________________________end_asian_handicap_away_min_075 = '2.33',
#   ____________________________end_asian_handicap_home_plus_075 = '1.08',
#   ____________________________end_asian_handicap_away_plus_075 = '6.35',
#   ____________________________end_asian_handicap_home_min_1 = '1.66',
#   ____________________________end_asian_handicap_away_min_1 = '2.06',
#   ____________________________end_asian_handicap_home_plus_1 = '1.01',
#   ____________________________end_asian_handicap_away_plus_1 = '10.00',
#   ____________________________end_asian_handicap_home_min_15 = '2.17',
#   ____________________________end_asian_handicap_away_min_15 = '1.67',
#   ____________________________end_asian_handicap_home_plus_15 = '1.02',
#   ____________________________end_asian_handicap_away_plus_15 = '9.70',
#   ____________________________end_asian_handicap_home_min_125 = '1.93',
#   ____________________________end_asian_handicap_away_min_125 = '1.85',
#   ____________________________end_asian_handicap_home_min_175 = '2.42',
#   ____________________________end_asian_handicap_away_min_175 = '1.48',
#   ____________________________end_asian_handicap_home_min_2 = '2.92',
#   ____________________________end_asian_handicap_away_min_2 = '1.34',
#   ____________________________end_asian_handicap_home_min_3 = '5.80',
#   ____________________________end_asian_handicap_away_min_3 = '1.09',
#   ____________________________end_asian_handicap_home_min_25 = '3.48',
#   ____________________________end_asian_handicap_away_min_25 = '1.24',
#   ____________________________end_asian_handicap_home_min_225 = '3.20',
#   ____________________________end_asian_handicap_away_min_225 = '1.29',
#   ____________________________end_asian_handicap_home_min_275 = '4.32',
#   ____________________________end_asian_handicap_away_min_275 = '1.17',
#   ____________________________end_asian_handicap_home_min_325 = '6.15',
#   ____________________________end_asian_handicap_away_min_325 = '1.08',
#   ____________________________end_asian_handicap_home_min_4 = '9.80',
#   ____________________________end_asian_handicap_away_min_4 = '1.01',
#   ____________________________end_asian_handicap_home_min_45 = '10.00',
#   ____________________________end_asian_handicap_away_min_45 = '1.00',
#   ____________________________end_asian_handicap_home_min_35 = '6.45',
#   ____________________________end_asian_handicap_away_min_35 = '1.06',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '1.99',
#   ____________________________end_goals_overunder_under_35 = '1.80',
#   ____________________________end_goals_overunder_over_15 = '1.08',
#   ____________________________end_goals_overunder_under_15 = '5.85',
#   ____________________________end_goals_overunder_over_45 = '3.04',
#   ____________________________end_goals_overunder_under_45 = '1.31',
#   ____________________________end_goals_overunder_over_25 = '1.36',
#   ____________________________end_goals_overunder_under_25 = '2.79',
#   ____________________________end_goals_overunder_over_55 = '5.30',
#   ____________________________end_goals_overunder_under_55 = '1.10',
#   ____________________________end_goals_overunder_over_225 = '1.25',
#   ____________________________end_goals_overunder_under_225 = '3.50',
# ...
#   __________________________________end_asian_handicap_away_min_1 = '1.14',
#   __________________________________end_asian_handicap_home_plus_1 = '1.08',
#   __________________________________end_asian_handicap_away_plus_1 = '6.00',
#   __________________________________end_asian_handicap_home_min_15 = '5.70',
#   __________________________________end_asian_handicap_away_min_15 = '1.09',
#   __________________________________end_asian_handicap_home_plus_15 = '1.05',
#   __________________________________end_asian_handicap_away_plus_15 = '7.20',
#   __________________________________end_asian_handicap_home_min_125 = '5.15',
#   __________________________________end_asian_handicap_away_min_125 = '1.12',
#   __________________________________end_asian_handicap_home_plus_125 = '1.12',
#   __________________________________end_asian_handicap_away_plus_125 = '5.20',
#   ________________________________5 Goals Over/Under
#   __________________________________end_goals_overunder_over_35 = '6.15',
#   __________________________________end_goals_overunder_under_35 = '1.08',
#   __________________________________end_goals_overunder_over_15 = '1.69',
#   __________________________________end_goals_overunder_under_15 = '2.14',
#   __________________________________end_goals_overunder_over_45 = '11.50',
#   __________________________________end_goals_overunder_under_45 = '1.03',
#   __________________________________end_goals_overunder_over_25 = '2.98',
#   __________________________________end_goals_overunder_under_25 = '1.32',
#   __________________________________end_goals_overunder_over_05 = '1.11',
#   __________________________________end_goals_overunder_under_05 = '5.20',
#   __________________________________end_goals_overunder_over_225 = '2.61',
#   __________________________________end_goals_overunder_under_225 = '1.42',
#   __________________________________end_goals_overunder_over_275 = '3.66',
#   __________________________________end_goals_overunder_under_275 = '1.23',
#   __________________________________end_goals_overunder_over_125 = '1.42',
#   __________________________________end_goals_overunder_under_125 = '2.60',
#   __________________________________end_goals_overunder_over_175 = '1.91',
#   __________________________________end_goals_overunder_under_175 = '1.87',
#   __________________________________end_goals_overunder_over_075 = '1.15',
#   __________________________________end_goals_overunder_under_075 = '4.62',
#   __________________________________end_goals_overunder_over_30 = '5.30',
#   __________________________________end_goals_overunder_under_30 = '1.10',
#   __________________________________end_goals_overunder_over_20 = '2.24',
#   __________________________________end_goals_overunder_under_20 = '1.56',
#   __________________________________end_goals_overunder_over_40 = '9.20',
#   __________________________________end_goals_overunder_under_40 = '1.03',
#   __________________________________end_goals_overunder_over_10 = '1.20',
#   __________________________________end_goals_overunder_under_10 = '3.98',
#   ________________________________6 Goals Over/Under First Half
#   __________________________________end_goals_overunder_first_half_over_35 = '67.00',
#   __________________________________end_goals_overunder_first_half_over_15 = '4.24',
#   __________________________________end_goals_overunder_first_half_under_15 = '1.18',
#   __________________________________end_goals_overunder_first_half_over_25 = '10.00',
#   __________________________________end_goals_overunder_first_half_under_25 = '1.02',
#   __________________________________end_goals_overunder_first_half_over_05 = '1.66',
#   __________________________________end_goals_overunder_first_half_under_05 = '2.09',
#   __________________________________end_goals_overunder_first_half_over_125 = '3.48',
#   __________________________________end_goals_overunder_first_half_under_125 = '1.26',
#   __________________________________end_goals_overunder_first_half_over_075 = '1.97',
#   __________________________________end_goals_overunder_first_half_under_075 = '1.75',
#   __________________________________end_goals_overunder_first_half_over_10 = '2.81',
#   __________________________________end_goals_overunder_first_half_under_10 = '1.38',
#   ________________________________26 Goals Over/Under - Second Half
#   __________________________________end_goals_overunder__second_half_over_15 = '3.04',
#   __________________________________end_goals_overunder__second_half_under_15 = '1.33',
#   __________________________________end_goals_overunder__second_half_over_25 = '7.20',
#   __________________________________end_goals_overunder__second_half_under_25 = '1.06',
#   __________________________________end_goals_overunder__second_half_over_05 = '1.44',
#   __________________________________end_goals_overunder__second_half_under_05 = '2.59',
#   __________________________________end_goals_overunder__second_half_over_125 = '2.56',
#   __________________________________end_goals_overunder__second_half_under_125 = '1.45',
#   __________________________________end_goals_overunder__second_half_over_075 = '1.63',
#   __________________________________end_goals_overunder__second_half_under_075 = '2.14',
#   __________________________________end_goals_overunder__second_half_over_10 = '2.03',
#   __________________________________end_goals_overunder__second_half_under_10 = '1.70',
#   ________________________________7 HT/FT Double
#   ________________________________8 Both Teams Score
#   __________________________________end_both_teams_score_yes = '2.35',
#   __________________________________end_both_teams_score_no = '1.56',
#   ________________________________9 Handicap Result
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 5.70
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.46
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.64
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.33
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 7.20
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.10
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 18.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 9.00
#   ____________________________  ____________________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.07
#   ________________________________10 Exact Score
#   ________________________________11 Highest Scoring Half
#   ________________________________31 Correct Score - First Half
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.74
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 19.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 41.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 67.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.09
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 11.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.50
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 17.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 41.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ____________________________  ____________________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   ________________________________12 Double Chance
#   __________________________________end_double_chance_home_draw = '1.33',
#   __________________________________end_double_chance_home_away = '1.38',
#   __________________________________end_double_chance_draw_away = '1.46',
#   ________________________________13 First Half Winner
#   __________________________________end_first_half_winner_home = '3.36',
#   __________________________________end_first_half_winner_draw = '1.77',
#   __________________________________end_first_half_winner_away = '4.12',
#   ________________________________16 Total - Home
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 3.28
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.27
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.46
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 2.45
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 7.40
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.05
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 2.14
#   ____________________________  ____________________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 1.60
#   ________________________________17 Total - Away
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 3.74
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.21
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.57
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 2.19
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 9.20
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.02
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 2.51
#   ____________________________  ____________________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 1.44
#   ________________________________18 Handicap Result - First Half
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 15.00
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.22
#   ____________________________  ____________________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 4.32
#   ________________________________19 Asian Handicap First Half
#   ________________________________20 Double Chance - First Half
#   ________________________________33 Double Chance - Second Half
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.20
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.62
#   ____________________________  ____________________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.29
#   ________________________________34 Both Teams Score - First Half
#   ________________________________35 Both Teams To Score - Second Half
#   ________________________________21 Odd/Even
#   ________________________________22 Odd/Even - First Half
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.21
#   ____________________________  ____________________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.56
#   ________________________________23 Home Odd/Even
#   ____________________________  ____________________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.05
#   ____________________________  ____________________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.65
#   ________________________________60 Away Odd/Even
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.14
#   ____________________________  ____________________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.60
#   ________________________________45 Corners Over Under
#   ____________________________  ____________________________bet_id: 45 --- bets_value: Over 8.5 --- bets_odd: 2.00
#   ____________________________  ____________________________bet_id: 45 --- bets_value: Under 8.5 --- bets_odd: 1.80
#   ____________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ______________________________ff_update_unfinished__
#   ____________________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-24 19:22:40

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 19:22:40
#   __main()
#   ____get_date()
#   ______days : 7
#   ______days : 6
#   ______tgl_awal : 2023-03-17
#   ______tgl_akhir : 2023-03-18
#   ________ff_get_fixture_status_match_finished()
#   __________Total Row(s) : 53
#   __________1. 2023-03-17 // 13 // 8 // 2023 // 1011461 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011461
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-03-17 // 16 // 8 // 2023 // 972938 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 972938
#   ____________> end_ah_pattern = 275_25_225_2_175_H
#   ____________> end_ah_pattern_mirror = 175+2+225+25+275+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-03-17 // 16 // 8 // 2023 // 972942 // 25_225_2_175_H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 972942
#   ____________> end_ah_pattern = 275_25_225_2_175_H
#   ____________> end_ah_pattern_mirror = 175+2+225+25+275+H
#   ____________> end_gou_pattern = 3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________4. 2023-03-17 // 67 // 11 // 2022 // 916562 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 916562
#   ____________> end_ah_pattern = 075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_H
#   ____________> end_gou_pattern = 25g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________5. 2023-03-17 // 68 // 11 // 2022 // 916804 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 916804
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 2g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________6. 2023-03-17 // 79 // 8 // 2022 // 873078 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 873078
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________7. 2023-03-17 // 79 // 8 // 2022 // 873082 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 873082
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________8. 2023-03-17 // 106 // 8 // 2022 // 865299 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 865299
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________9. 2023-03-17 // 106 // 8 // 2022 // 865301 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 865301
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________10. 2023-03-17 // 110 // 8 // 2022 // 990903 // 075+1+125+15+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 990903
#   ____________> end_ah_pattern = 1+125+15+175+H
#   ____________> end_ah_pattern_mirror = 175_15_125_1_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________11. 2023-03-17 // 110 // 8 // 2022 // 990933 // 1_075_05_025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 990933
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 25g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________12. 2023-03-17 // 129 // 8 // 2023 // 992651 // 075_05_025_H // 175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992651
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________13. 2023-03-17 // 139 // 8 // 2022 // 1011374 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011374
#   ____________> end_ah_pattern = 15+H
#   ____________> end_ah_pattern_mirror = 15_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________14. 2023-03-17 // 196 // 11 // 2023 // 1013166 // 1_075_025_0#H // 3g325g35g375g4gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1013166
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________15. 2023-03-17 // 210 // 8 // 2022 // 866503 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 866503
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________16. 2023-03-17 // 222 // 11 // 2022 // 896415 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896415
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________17. 2023-03-17 // 222 // 11 // 2022 // 896416 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896416
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________18. 2023-03-17 // 222 // 11 // 2022 // 896417 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896417
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 275g3g325g35g375g4gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________19. 2023-03-17 // 222 // 11 // 2022 // 896418 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896418
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________20. 2023-03-17 // 222 // 11 // 2022 // 896421 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896421
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________21. 2023-03-17 // 269 // 8 // 2023 // 1009267 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1009267
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________22. 2023-03-17 // 283 // 8 // 2022 // 1015111 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1015111
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________23. 2023-03-17 // 283 // 8 // 2022 // 1015112 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1015112
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________24. 2023-03-17 // 291 // 11 // 2022 // 998369 // 025_0#025+H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998369
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________25. 2023-03-17 // 291 // 11 // 2022 // 998370 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998370
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 125g15g175g2gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________26. 2023-03-17 // 295 // 8 // 2023 // 1003767 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1003767
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________27. 2023-03-17 // 332 // 8 // 2022 // 1012025 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1012025
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________28. 2023-03-17 // 357 // 8 // 2023 // 1002553 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1002553
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________29. 2023-03-17 // 357 // 8 // 2023 // 1002554 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1002554
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________30. 2023-03-17 // 357 // 8 // 2023 // 1002555 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1002555
#   ____________> end_ah_pattern = 2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________31. 2023-03-17 // 357 // 8 // 2023 // 1002556 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1002556
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________32. 2023-03-17 // 365 // 8 // 2023 // 1009298 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1009298
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________33. 2023-03-17 // 382 // 8 // 2022 // 877784 // 05_025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877784
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________34. 2023-03-17 // 382 // 8 // 2022 // 877785 // 05_025_0#H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877785
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________35. 2023-03-17 // 382 // 8 // 2022 // 877786 // 025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877786
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________36. 2023-03-17 // 382 // 8 // 2022 // 877787 // 05_025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877787
#   ____________> end_ah_pattern = 075_05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________37. 2023-03-17 // 382 // 8 // 2022 // 877788 // 025_0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877788
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________38. 2023-03-17 // 382 // 8 // 2022 // 877789 // 025_0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877789
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________39. 2023-03-17 // 382 // 8 // 2022 // 877790 // 075_05_025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877790
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________40. 2023-03-17 // 382 // 8 // 2022 // 877791 // 025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877791
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________41. 2023-03-17 // 408 // 11 // 2022 // 877543 // 275_25_225_2_175_H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 877543
#   ____________> end_ah_pattern = 25_225_2_175_15_H
#   ____________> end_ah_pattern_mirror = 15+175+2+225+25+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________42. 2023-03-17 // 419 // 11 // 2022 // 923318 // 125_1_075_H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 923318
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________43. 2023-03-17 // 444 // 11 // 2022 // 955596 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 955596
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________44. 2023-03-17 // 453 // 11 // 2022 // 957521 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 957521
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________45. 2023-03-17 // 481 // 8 // 2023 // 981878 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981878
#   ____________> end_ah_pattern = 175_H
#   ____________> end_ah_pattern_mirror = 175+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________46. 2023-03-17 // 481 // 8 // 2023 // 981879 // 0#H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 981879
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________47. 2023-03-17 // 688 // 11 // 2022 // 896263 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896263
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________48. 2023-03-17 // 688 // 11 // 2022 // 896266 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 896266
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________49. 2023-03-17 // 753 // 11 // 2022 // 907109 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 907109
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________50. 2023-03-17 // 888 // 11 // 2022 // 965028 // 025_0#025+H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965028
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________51. 2023-03-17 // 888 // 11 // 2022 // 965031 // 0#H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965031
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________52. 2023-03-17 // 888 // 11 // 2022 // 965032 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965032
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________53. 2023-03-17 // 888 // 11 // 2022 // 965035 // 0#025+H // 15g175g2gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 965035
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
# # -------------------------------------------------- End at 2023-03-24 19:25:02

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-24 19:25:02
#   __main()
#   ____get_date()
#   ______days : 7
#   ______days : 6
#   ______tgl_awal : 2023-03-17
#   ______tgl_akhir : 2023-03-18
#   ________ff_get_fixture_status_match_finished_for_daily_update_patternlist()
#   ________Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date <= '2023-03-18'  and date >= '2023-03-17'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 209
#   ____________[1/209] #865299 #Poland 106-2022 / Gornik Zabrze vs Wisla Plock
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-20 02:38:11
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '106'  and league_country = 'Poland'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[2/209] #865301 #Poland 106-2022 / Radomiak Radom vs Legia Warszawa
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:0#025+05+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-20 02:38:15
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '106'  and league_country = 'Poland'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[3/209] #866503 #Croatia 210-2022 / NK Varazdin vs HNK Gorica
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-20 02:38:25
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '210'  and league_country = 'Croatia'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[4/209] #877125 #Serbia 286-2022 / Mladost Novi Sad vs Radnicki 1923
#   ____________pre-ah:0#025+H -- pre-gou:175g2g225g25g275gG -/- end-ah:025_0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:06:17
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '286'  and league_country = 'Serbia'  and pre_ah_pattern = '0#025+H'  and pre_ah_pattern_mirror = '025_0#H'  and pre_gou_pattern = '175g2g225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[5/209] #877129 #Serbia 286-2022 / FK Partizan vs Radnik Surdulica
#   ____________pre-ah:225_2_175_15_125_H -- pre-gou:225g25g275g3g325gG -/- end-ah:25_225_2_175_15_H -- end-gou:225g25g275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:06:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '286'  and league_country = 'Serbia'  and pre_ah_pattern = '225_2_175_15_125_H'  and pre_ah_pattern_mirror = '125+15+175+2+225+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '25_225_2_175_15_H'  and end_ah_pattern_mirror = '15+175+2+225+25+H'  and end_gou_pattern = '225g25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[6/209] #873078 #Germany 79-2022 / Arminia Bielefeld vs FC Nurnberg
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05_025_0#H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-20 02:37:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '79'  and league_country = 'Germany'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[7/209] #873082 #Germany 79-2022 / FC Heidenheim vs Karlsruher SC
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05_025_0#H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-20 02:38:02
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '79'  and league_country = 'Germany'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[8/209] #867079 #Poland 107-2022 / SKRA Częstochowa vs Wisla Krakow
#   ____________pre-ah:1+125+15+H -- pre-gou:225g25g275g3gG -/- end-ah:1+125+15+175+H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:59
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '107'  and league_country = 'Poland'  and pre_ah_pattern = '1+125+15+H'  and pre_ah_pattern_mirror = '15_125_1_H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '1+125+15+175+H'  and end_ah_pattern_mirror = '175_15_125_1_H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[9/209] #883502 #Bulgaria 172-2022 / Cherno More Varna vs Septemvri Sofia
#   ____________pre-ah:125_1_075_H -- pre-gou:2g225g25gG -/- end-ah:125_1_075_05_H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:04:52
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '172'  and league_country = 'Bulgaria'  and pre_ah_pattern = '125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+H'  and pre_gou_pattern = '2g225g25gG'  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[10/209] #883506 #Bulgaria 172-2022 / Lokomotiv Sofia vs Slavia Sofia
#   ____________pre-ah:025_0#025+H -- pre-gou:175g2g225g25gG -/- end-ah:025_0#025+H -- end-gou:15g175g2g225gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:04:53
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '172'  and league_country = 'Bulgaria'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[11/209] #882797 #Bulgaria 173-2022 / Dunav Ruse vs Ludogorets II
#   ____________pre-ah:025_0#025+H -- pre-gou:175g2g225g25g275gG -/- end-ah:075_025_H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:04:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '173'  and league_country = 'Bulgaria'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '175g2g225g25g275gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[12/209] #882800 #Bulgaria 173-2022 / Strumska Slava vs Botev Plovdiv II
#   ____________pre-ah:075_025_H -- pre-gou:15g175g2g225g25gG -/- end-ah:1_075_025_H -- end-gou:15g175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:04:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '173'  and league_country = 'Bulgaria'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '15g175g2g225g25gG'  and end_ah_pattern = '1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+H'  and end_gou_pattern = '15g175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[13/209] #882802 #Bulgaria 173-2022 / FK Minyor Pernik vs Vitosha Bistritsa
#   ____________pre-ah:175_15_125_1_075_H -- pre-gou:2g225g25g275gG -/- end-ah:1_075_025_H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:04:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '173'  and league_country = 'Bulgaria'  and pre_ah_pattern = '175_15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+175+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[14/209] #874994 #Belgium 144-2022 / Cercle Brugge vs Genk
#   ____________pre-ah:0#025+05+H -- pre-gou:225g25g275g3g325gG -/- end-ah:025_0#025+05+H -- end-gou:25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:04:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '144'  and league_country = 'Belgium'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[15/209] #879389 #Germany 80-2022 / FC Viktoria Koln vs SV Meppen
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:12
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '80'  and league_country = 'Germany'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[16/209] #869399 #Switzerland 208-2022 / FC WIL 1900 vs FC Aarau
#   ____________pre-ah:075_025_H -- pre-gou:25g275g3g325g35gG -/- end-ah:075_025_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:05:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '208'  and league_country = 'Switzerland'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 6
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 6
#   ____________________patternlists updated
#
#   ____________[17/209] #869400 #Switzerland 208-2022 / Yverdon Sport vs FC Schaffhausen
#   ____________pre-ah:075_025_H -- pre-gou:25g275g3g325g35gG -/- end-ah:075_025_H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:05:19
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '208'  and league_country = 'Switzerland'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[18/209] #878992 #Austria 219-2022 / SV Horn vs SK Vorwarts Steyr
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:125_1_075_05_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:05:27
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '219'  and league_country = 'Austria'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[19/209] #878993 #Austria 219-2022 / Floridsdorfer AC vs Admira Wacker
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05_025_0#025+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:05:31
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '219'  and league_country = 'Austria'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[20/209] #878995 #Austria 219-2022 / SV Kapfenberg vs Sturm Graz II
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025+05+075+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:05:32
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '219'  and league_country = 'Austria'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[21/209] #878997 #Austria 219-2022 / SKN ST. Polten vs FC Liefering
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:05:29
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '219'  and league_country = 'Austria'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[22/209] #904283 #Germany 83-2022 / Heimstetten vs Rain / Lech
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05_025_0#025+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:17
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '83'  and league_country = 'Germany'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[23/209] #904287 #Germany 83-2022 / Augsburg II vs Wacker Burghausen
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '83'  and league_country = 'Germany'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[24/209] #868223 #England 39-2022 / Nottingham Forest vs Newcastle
#   ____________pre-ah:05+075+1+125+H -- pre-gou:2g225g25g275gG -/- end-ah:05+075+1+125+H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:02:49
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '39'  and league_country = 'England'  and pre_ah_pattern = '05+075+1+125+H'  and pre_ah_pattern_mirror = '125_1_075_05_H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '05+075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_05_H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[25/209] #875942 #England 41-2022 / Sheffield Wednesday vs Bolton
#   ____________pre-ah:1_075_05_H -- pre-gou:225g25g275gG -/- end-ah:1_075_05_025_H -- end-gou:2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:02:52
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '41'  and league_country = 'England'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[26/209] #871743 #France 61-2022 / Lyon vs Nantes
#   ____________pre-ah:1_075_05_H -- pre-gou:225g25g275g3gG -/- end-ah:15_125_1_075_05_H -- end-gou:25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:02:54
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '61'  and league_country = 'France'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '15_125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+15+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[27/209] #914099 #France 63-2022 / Bourg-en-bresse 01 vs RED Star FC 93
#   ____________pre-ah:0#025+075+H -- pre-gou:175g2g225g25g275gG -/- end-ah:0#025+H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:03
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '0#025+075+H'  and pre_ah_pattern_mirror = '075_025_0#H'  and pre_gou_pattern = '175g2g225g25g275gG'  and end_ah_pattern = '0#025+H'  and end_ah_pattern_mirror = '025_0#H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[28/209] #914100 #France 63-2022 / Martigues vs Avranches
#   ____________pre-ah:1_075_025_H -- pre-gou:2g225g25g275gG -/- end-ah:075_025_H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:02:59
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[29/209] #914102 #France 63-2022 / Le Puy Foot vs Gobelins
#   ____________pre-ah:025_0#H -- pre-gou:15g175g2g225gG -/- end-ah:025_0#H -- end-gou:15g175g2g225gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:05
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '025_0#H'  and pre_ah_pattern_mirror = '0#025+H'  and pre_gou_pattern = '15g175g2g225gG'  and end_ah_pattern = '025_0#H'  and end_ah_pattern_mirror = '0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[30/209] #914103 #France 63-2022 / Nancy vs Chateauroux
#   ____________pre-ah:025_0#025+H -- pre-gou:15g175g2g225gG -/- end-ah:025_0#025+H -- end-gou:15g175g2g225gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '15g175g2g225gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[31/209] #914105 #France 63-2022 / Concarneau vs Stade Briochin
#   ____________pre-ah:1_075_025_H -- pre-gou:175g2g225g25gG -/- end-ah:1_075_025_H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[32/209] #914106 #France 63-2022 / Orleans vs Sedan
#   ____________pre-ah:075_025_H -- pre-gou:175g2g225g25gG -/- end-ah:075_025_H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:07
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 11
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 11
#   ____________________patternlists updated
#
#   ____________[33/209] #924499 #France 63-2022 / Dunkerque vs Villefranche
#   ____________pre-ah:075_025_0#H -- pre-gou:175g2g225g25g275gG -/- end-ah:075_025_H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:04
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '075_025_0#H'  and pre_ah_pattern_mirror = '0#025+075+H'  and pre_gou_pattern = '175g2g225g25g275gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[34/209] #899802 #Indonesia 274-2022 / PSM Makassar vs Bhayangkara FC
#   ____________pre-ah:075_025_H -- pre-gou:225g25g275g3gG -/- end-ah:125_1_075_H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:06:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '274'  and league_country = 'Indonesia'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[35/209] #903837 #Italy 136-2022 / Palermo vs Modena
#   ____________pre-ah:05_025_0#H -- pre-gou:2g225g25gG -/- end-ah:05_025_0#H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:04:33
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '136'  and league_country = 'Italy'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '2g225g25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[36/209] #882040 #Italy 135-2022 / Atalanta vs Empoli
#   ____________pre-ah:175_15_125_1_H -- pre-gou:25g275g3g325gG -/- end-ah:175_15_125_1_H -- end-gou:25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:04:28
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '135'  and league_country = 'Italy'  and pre_ah_pattern = '175_15_125_1_H'  and pre_ah_pattern_mirror = '1+125+15+175+H'  and pre_gou_pattern = '25g275g3g325gG'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[37/209] #882044 #Italy 135-2022 / Sassuolo vs Spezia
#   ____________pre-ah:1_075_05_H -- pre-gou:25g275g3g325gG -/- end-ah:1_075_05_H -- end-gou:25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:04:30
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '135'  and league_country = 'Italy'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '25g275g3g325gG'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[38/209] #873461 #Scotland 180-2022 / Arbroath vs Morton
#   ____________pre-ah:025_0#025+H -- pre-gou:2g225g25gG -/- end-ah:025_0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:05:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '180'  and league_country = 'Scotland'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '2g225g25gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[39/209] #872455 #Netherlands 88-2022 / FC Volendam vs Fortuna Sittard
#   ____________pre-ah:05_025_0#025+H -- pre-gou:225g25g275g3g325gG -/- end-ah:05_025_0#025+H -- end-gou:25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:31
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '88'  and league_country = 'Netherlands'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[40/209] #867844 #Netherlands 89-2022 / ADO Den Haag vs Willem II
#   ____________pre-ah:025+075+H -- pre-gou:225g25g275g3gG -/- end-ah:025+075+H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '89'  and league_country = 'Netherlands'  and pre_ah_pattern = '025+075+H'  and pre_ah_pattern_mirror = '075_025_H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[41/209] #867845 #Netherlands 89-2022 / Den Bosch vs Dordrecht
#   ____________pre-ah:075_025_0#H -- pre-gou:225g25g275g3g325gG -/- end-ah:075_025_0#025+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:38
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '89'  and league_country = 'Netherlands'  and pre_ah_pattern = '075_025_0#H'  and pre_ah_pattern_mirror = '0#025+075+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '075_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+075+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[42/209] #867846 #Netherlands 89-2022 / Helmond Sport vs Telstar
#   ____________pre-ah:025_0#025+H -- pre-gou:2g225g25g275gG -/- end-ah:025_0#025+H -- end-gou:2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:36
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '89'  and league_country = 'Netherlands'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[43/209] #867847 #Netherlands 89-2022 / MVV vs Jong Utrecht
#   ____________pre-ah:075_025_0#025+H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:075_025_0#H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:03:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
# ...
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 09:07:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '357'  and league_country = 'Ireland'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[194/209] #1002556 #Ireland 357-2023 / Derry City vs Sligo Rovers
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:15_125_1_075_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 09:07:09
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '357'  and league_country = 'Ireland'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[195/209] #1011461 #World 13-2023 / Sporting Cristal vs Huracan
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#025+05+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-19 11:04:55
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '13'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[196/209] #1008358 #USA 255-2023 / Birmingham Legion vs FC Tulsa
#   ____________pre-ah:15_125_1_075_H -- pre-gou:25g275g3g325g35gG -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:05:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '255'  and league_country = 'USA'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[197/209] #1011575 #Lithuania 361-2023 / Trakai II vs Neptūną Klaipėda
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:1+15+H -- end-gou:25g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:07:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '361'  and league_country = 'Lithuania'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '1+15+H'  and end_ah_pattern_mirror = '15_1_H'  and end_gou_pattern = '25g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[198/209] #1005561 #Uzbekistan 369-2023 / Buxoro vs Nasaf
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025+075+H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:07:24
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '369'  and league_country = 'Uzbekistan'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[199/209] #998087 #Venezuela 299-2023 / CD Hermanos Colmenarez vs Carabobo FC
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-19 09:06:31
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '299'  and league_country = 'Venezuela'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#025+H'  and end_ah_pattern_mirror = '025_0#H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[200/209] #1009298 #Latvia 365-2023 / FS Jelgava vs BFC Daugavpils
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#025+05+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-20 02:38:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '365'  and league_country = 'Latvia'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[201/209] #1011374 #Italy 139-2022 / Fiorentina W vs Roma W
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:15+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-20 02:38:19
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '139'  and league_country = 'Italy'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '15+H'  and end_ah_pattern_mirror = '15_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[202/209] #1012025 #Slovakia 332-2022 / Žilina vs Dukla Banská Bystrica
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:125_1_075_05_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-20 02:38:53
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '332'  and league_country = 'Slovakia'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[203/209] #1015650 #Ivory-Coast 386-2022 / Korhogo vs Bouaké
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:H -- end-gou:G
#   ____________Match Finished -- end_odd_updated_at:2023-03-20 02:39:12
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '386'  and league_country = 'Ivory-Coast'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = 'H'  and end_ah_pattern_mirror = 'H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[204/209] #1015651 #Ivory-Coast 386-2022 / Bassam vs Stella
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:H -- end-gou:G
#   ____________Match Finished -- end_odd_updated_at:2023-03-20 02:39:16
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '386'  and league_country = 'Ivory-Coast'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = 'H'  and end_ah_pattern_mirror = 'H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[205/209] #916562 #France 67-2022 / C' Chartres vs Racing Colombes 92
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075+1+H -- end-gou:25g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-20 02:37:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '67'  and league_country = 'France'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075+1+H'  and end_ah_pattern_mirror = '1_075_H'  and end_gou_pattern = '25g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[206/209] #916804 #France 68-2022 / Boulogne vs St Maur Lusitanos
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#H -- end-gou:2g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-20 02:37:52
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '68'  and league_country = 'France'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#H'  and end_ah_pattern_mirror = '0#H'  and end_gou_pattern = '2g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[207/209] #1015111 #Romania 283-2022 / FC Voluntari vs AFC Hermannstadt
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:05_025_0#H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-21 13:14:42
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '283'  and league_country = 'Romania'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[208/209] #1015112 #Romania 283-2022 / Petrolul Ploiesti vs Uta Arad
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_0#025+H -- end-gou:175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-21 13:14:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '283'  and league_country = 'Romania'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[209/209] #1009267 #Uruguay 269-2023 / Juventud vs Miramar
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-21 13:14:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '269'  and league_country = 'Uruguay'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#H'  and end_ah_pattern_mirror = '0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
# # -------------------------------------------------- End at 2023-03-24 20:07:06
