# %%
# Import
from a_settings.messages import *  

today = datetime.datetime.now()  
days0 = 2
days1 = 1
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 2 - 1 --> 2023-03-17 23:23:41.021498

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-17 23:23:41
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-15
#   ______tgl_akhir : 2023-03-16
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-16'  and date >= '2023-03-15'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 8
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 30
#   ______________1. 2023-03-15 // 16 // 8 // 2023 // 972948 // H // G
#   ______________2. 2023-03-15 // 83 // 8 // 2022 // 904227 // 0#025+05+075+H // 35gG
#   ______________3. 2023-03-15 // 86 // 8 // 2022 // 904876 // 125_1_075_05_H // 25gG
#   ______________4. 2023-03-15 // 205 // 11 // 2022 // 889066 // 125_1_075_H // 175g2g225g25g275gG
#   ______________5. 2023-03-15 // 205 // 11 // 2022 // 889067 // 025_0#H // 175g2g225g25g275gG
#   ______________6. 2023-03-15 // 205 // 11 // 2022 // 889068 // 0#H // 2g25gG
#   ______________7. 2023-03-15 // 205 // 11 // 2022 // 889069 // 025+075+H // 175g2g225g25gG
#   ______________8. 2023-03-15 // 205 // 11 // 2022 // 889070 // 1_H // 2g25gG
#   ______________9. 2023-03-15 // 205 // 11 // 2022 // 889071 // None // None
#   ______________10. 2023-03-15 // 205 // 11 // 2022 // 889072 // 0#H // 2g25gG
#   ______________11. 2023-03-15 // 205 // 11 // 2022 // 889073 // 15_1_H // 2g25gG
#   ______________12. 2023-03-15 // 205 // 11 // 2022 // 889074 // 1+H // 2g25gG
#   ______________13. 2023-03-15 // 205 // 11 // 2022 // 889431 // 125_1_075_H // 2g225g25g275gG
#   ______________14. 2023-03-15 // 205 // 11 // 2022 // 889432 // 025+075+H // 175g2g225g25g275gG
#   ______________15. 2023-03-15 // 205 // 11 // 2022 // 889433 // 075_025_H // 15g175g2g225g25gG
#   ______________16. 2023-03-15 // 205 // 11 // 2022 // 889434 // 0#025+075+H // 175g2g225g25g275gG
#   ______________17. 2023-03-15 // 205 // 11 // 2022 // 889436 // 025_0#025+H // 175g2g225g25g275gG
#   ______________18. 2023-03-15 // 205 // 11 // 2022 // 889437 // 025_0#025+H // 175g2g225g25g275gG
#   ______________19. 2023-03-15 // 205 // 11 // 2022 // 889438 // 025_0#025+H // 15g175g2g225gG
#   ______________20. 2023-03-15 // 205 // 11 // 2022 // 889439 // H // 2g25gG
#   ______________21. 2023-03-15 // 241 // 8 // 2023 // 1010865 // None // None
#   ______________22. 2023-03-15 // 328 // 11 // 2023 // 1001399 // None // None
#   ______________23. 2023-03-15 // 487 // 11 // 2022 // 941816 // None // None
#   ______________24. 2023-03-15 // 510 // 11 // 2022 // 898493 // H // G
#   ______________25. 2023-03-15 // 667 // 8 // 2023 // 992157 // None // None
#   ______________26. 2023-03-15 // 667 // 8 // 2023 // 1014312 // None // None
#   ______________27. 2023-03-15 // 749 // 11 // 2022 // 926166 // 125+15+175+2+225+H // 325g35g375g4g425g45gG
#   ______________28. 2023-03-15 // 780 // 11 // 2022 // 969239 // 0#H // 25g3gG
#   ______________29. 2023-03-15 // 780 // 11 // 2022 // 969255 // H // G
#   ______________30. 2023-03-15 // 781 // 11 // 2022 // 921057 // 1_075_H // 25g3gG
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-03-15 // 16 // 8 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API arya6792@gmail.com counter is 69
#   __________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-15
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 16
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 3
#
#   ____________________1. World,  CONCACAF Champions League  #16 - 2023 / 972950
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.17',
#   ____________________________end_match_winner_draw = '7.00',
#   ____________________________end_match_winner_away = '19.00',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '1.03',
#   ____________________________end_homeaway_away = '15.00',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '1.36',
#   ____________________________end_second_half_winner_draw = '3.40',
#   ____________________________end_second_half_winner_away = '12.00',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.10',
#   ____________________________end_asian_handicap_away_plus_0 = '7.00',
#   ____________________________end_asian_handicap_home_min_025 = '1.10',
#   ____________________________end_asian_handicap_away_min_025 = '7.00',
#   ____________________________end_asian_handicap_home_min_05 = '1.17',
#   ____________________________end_asian_handicap_away_min_05 = '5.00',
#   ____________________________end_asian_handicap_home_min_075 = '1.20',
#   ____________________________end_asian_handicap_away_min_075 = '4.40',
#   ____________________________end_asian_handicap_home_min_1 = '1.24',
#   ____________________________end_asian_handicap_away_min_1 = '3.90',
#   ____________________________end_asian_handicap_home_min_15 = '1.55',
#   ____________________________end_asian_handicap_away_min_15 = '2.38',
#   ____________________________end_asian_handicap_home_min_125 = '1.40',
#   ____________________________end_asian_handicap_away_min_125 = '2.85',
#   ____________________________end_asian_handicap_home_min_175 = '1.68',
#   ____________________________end_asian_handicap_away_min_175 = '2.15',
#   ____________________________end_asian_handicap_home_min_2 = '1.93',
#   ____________________________end_asian_handicap_away_min_2 = '1.93',
#   ____________________________end_asian_handicap_home_min_3 = '3.55',
#   ____________________________end_asian_handicap_away_min_3 = '1.27',
#   ____________________________end_asian_handicap_home_min_25 = '2.38',
#   ____________________________end_asian_handicap_away_min_25 = '1.55',
#   ____________________________end_asian_handicap_home_min_225 = '2.15',
#   ____________________________end_asian_handicap_away_min_225 = '1.68',
#   ____________________________end_asian_handicap_home_min_275 = '2.75',
#   ____________________________end_asian_handicap_away_min_275 = '1.43',
#   ____________________________end_asian_handicap_home_min_325 = '3.90',
#   ____________________________end_asian_handicap_away_min_325 = '1.24',
#   ____________________________end_asian_handicap_home_min_375 = '5.50',
#   ____________________________end_asian_handicap_away_min_375 = '1.15',
#   ____________________________end_asian_handicap_home_min_35 = '4.25',
#   ____________________________end_asian_handicap_away_min_35 = '1.21',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '2.38',
#   ____________________________end_goals_overunder_under_35 = '1.53',
#   ____________________________end_goals_overunder_over_15 = '1.17',
#   ____________________________end_goals_overunder_under_15 = '5.00',
#   ____________________________end_goals_overunder_over_45 = '4.33',
#   ____________________________end_goals_overunder_under_45 = '1.20',
#   ____________________________end_goals_overunder_over_25 = '1.57',
#   ____________________________end_goals_overunder_under_25 = '2.35',
#   ____________________________end_goals_overunder_over_05 = '1.02',
#   ____________________________end_goals_overunder_under_05 = '17.00',
#   ____________________________end_goals_overunder_over_55 = '9.00',
#   ____________________________end_goals_overunder_under_55 = '1.07',
#   ____________________________end_goals_overunder_over_225 = '1.40',
#   ____________________________end_goals_overunder_under_225 = '2.85',
#   ____________________________end_goals_overunder_over_325 = '2.15',
#   ____________________________end_goals_overunder_under_325 = '1.68',
#   ____________________________end_goals_overunder_over_275 = '1.70',
#   ____________________________end_goals_overunder_under_275 = '2.10',
#   ____________________________end_goals_overunder_over_125 = '1.10',
#   ____________________________end_goals_overunder_under_125 = '6.80',
#   ____________________________end_goals_overunder_over_425 = '3.80',
#   ____________________________end_goals_overunder_under_425 = '1.25',
#   ____________________________end_goals_overunder_over_175 = '1.21',
#   ____________________________end_goals_overunder_under_175 = '4.25',
#   ____________________________end_goals_overunder_over_375 = '2.75',
#   ____________________________end_goals_overunder_under_375 = '1.43',
#   ____________________________end_goals_overunder_over_475 = '5.25',
#   ____________________________end_goals_overunder_under_475 = '1.16',
#   ____________________________end_goals_overunder_over_65 = '17.00',
#   ____________________________end_goals_overunder_under_65 = '1.02',
#   ____________________________end_goals_overunder_over_75 = '34.00',
#   ____________________________end_goals_overunder_under_75 = '1.00',
#   ____________________________end_goals_overunder_over_30 = '1.95',
#   ____________________________end_goals_overunder_under_30 = '1.90',
#   ____________________________end_goals_overunder_over_20 = '1.25',
#   ____________________________end_goals_overunder_under_20 = '3.80',
#   ____________________________end_goals_overunder_over_40 = '3.55',
#   ____________________________end_goals_overunder_under_40 = '1.27',
#   ____________________________end_goals_overunder_over_50 = '7.00',
#   ____________________________end_goals_overunder_under_50 = '1.10',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '15.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.03',
#   ____________________________end_goals_overunder_first_half_over_15 = '2.25',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.57',
#   ____________________________end_goals_overunder_first_half_over_25 = '5.50',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.14',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.29',
#   ____________________________end_goals_overunder_first_half_under_05 = '3.50',
#   ____________________________end_goals_overunder_first_half_over_225 = '4.65',
#   ____________________________end_goals_overunder_first_half_under_225 = '1.18',
#   ____________________________end_goals_overunder_first_half_over_275 = '7.00',
#   ____________________________end_goals_overunder_first_half_under_275 = '1.10',
#   ____________________________end_goals_overunder_first_half_over_125 = '1.95',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.85',
#   ____________________________end_goals_overunder_first_half_over_175 = '2.85',
#   ____________________________end_goals_overunder_first_half_under_175 = '1.40',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.38',
#   ____________________________end_goals_overunder_first_half_under_075 = '3.00',
#   ____________________________end_goals_overunder_first_half_over_20 = '4.10',
#   ____________________________end_goals_overunder_first_half_under_20 = '1.23',
#   ____________________________end_goals_overunder_first_half_over_10 = '1.55',
#   ____________________________end_goals_overunder_first_half_under_10 = '2.38',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '8.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.08',
#   ____________________________end_goals_overunder__second_half_over_15 = '1.80',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.91',
#   ____________________________end_goals_overunder__second_half_over_25 = '3.50',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.29',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.17',
#   ____________________________end_goals_overunder__second_half_under_05 = '5.00',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________end_clean_sheet__home_yes = '1.57',
#   ____________________________end_clean_sheet__home_no = '2.25',
#   __________________________28 Clean Sheet - Away
#   ____________________________end_clean_sheet__away_yes = '11.00',
#   ____________________________end_clean_sheet__away_no = '1.05',
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '2.50',
#   ____________________________end_both_teams_score_no = '1.50',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 1.53
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 2.40
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 4.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.57
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 7.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 201.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 6:0 --- bets_odd: 251.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 351.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.02',
#   ____________________________end_double_chance_home_away = '1.10',
#   ____________________________end_double_chance_draw_away = '5.00',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '1.53',
#   ____________________________end_first_half_winner_draw = '2.88',
#   ____________________________end_first_half_winner_away = '13.00',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 6.00
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 6.00
#   __________________________32 Win Both Halves
#   ____________________________end_win_both_halves_home = '2.20',
#   ____________________________end_win_both_halves_away = '67.00',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 3.40
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 1.83
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.83
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 5.5 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 5.5 --- bets_odd: 1.03
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 6.5 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 6.5 --- bets_odd: 1.01
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.00
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.06
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________end_win_to_nil_home = '1.67',
#   ____________________________end_win_to_nil_away = '23.00',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.80
#   __________________________39 To Win Either Half
#   ____________________________end_to_win_either_half_home = '1.10',
#   ____________________________end_to_win_either_half_away = '6.50',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________24 Results/Both Teams Score
#   ____________________________end_results_both_teams_score_home_yes = '3.25',
#   ____________________________end_results_both_teams_score_draw_yes = '9.50',
#   ____________________________end_results_both_teams_score_away_yes = '29.00',
#   ____________________________end_results_both_teams_score_home_no = '1.67',
#   ____________________________end_results_both_teams_score_draw_no = '13.00',
#   ____________________________end_results_both_teams_score_away_no = '23.00',
#   __________________________25 Result/Total Goals
#   ____________________________end_result_total_goals_home_over_25 = '1.67',
#   ____________________________end_result_total_goals_draw_over_25 = '26.00',
#   ____________________________end_result_total_goals_away_over_25 = '29.00',
#   ____________________________end_result_total_goals_home_under_25 = '3.40',
#   ____________________________end_result_total_goals_draw_under_25 = '7.50',
#   ____________________________end_result_total_goals_away_under_25 = '26.00',
#   __________________________43 Home Team Score a Goal
#   ______________________  ______________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.05
#   ______________________  ______________________bet_id: 43 --- bets_value: No --- bets_odd: 11.00
#   __________________________44 Away Team Score a Goal
#   ______________________  ______________________bet_id: 44 --- bets_value: Yes --- bets_odd: 2.25
#   ______________________  ______________________bet_id: 44 --- bets_value: No --- bets_odd: 1.57
#   __________________________54 First 10 min Winner
#   ______________________  ______________________bet_id: 54 --- bets_value: Home --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 54 --- bets_value: Draw --- bets_odd: 1.20
#   ______________________  ______________________bet_id: 54 --- bets_value: Away --- bets_odd: 17.00
#   __________________________47 Winning Margin
#   ______________________  ______________________bet_id: 47 --- bets_value: Draw --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 4.75
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 201.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 10.00
#   __________________________48 To Score In Both Halves By Teams
#   __________________________49 Total Goals/Both Teams To Score
#   ____________________________end_total_goals_both_teams_to_score_over_yes_25 = '2.88',
#   ____________________________end_total_goals_both_teams_to_score_over_no_25 = '3.00',
#   ____________________________end_total_goals_both_teams_to_score_under_yes_25 = '15.00',
#   ____________________________end_total_goals_both_teams_to_score_under_no_25 = '2.75',
#   __________________________91 Total Goals (3 way)
#   ______________________  ______________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 2.38
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.55
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.18
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 4.80
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.5 --- bets_odd: 4.15
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.5 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 1.58
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 2.35
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 3.80
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 1.95
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.90
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4 --- bets_odd: 3.55
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4 --- bets_odd: 1.27
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 2.85
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 2.15
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.68
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 1.70
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 6.80
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.25 --- bets_odd: 3.80
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.25 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.21
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 4.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.43
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 4.75 --- bets_odd: 5.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 4.75 --- bets_odd: 1.16
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 5 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 5 --- bets_odd: 1.10
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 2.30
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.60
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2.5 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2.5 --- bets_odd: 1.15
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2 --- bets_odd: 4.10
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2 --- bets_odd: 1.23
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2.25 --- bets_odd: 4.65
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2.25 --- bets_odd: 1.18
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 2.75 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 2.75 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 1.95
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.85
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 2.85
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 1.55
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.38
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 3.00
#   __________________________52 Halftime Result/Both Teams Score
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   __________________________74 10 Over/Under
#   __________________________78 RTG_H1
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 2.88
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 13.00
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ______________________2. World,  CONCACAF Champions League  #16 - 2023 / 972936
#   ______________________good to Go 1
#   ____________________________1 Match Winner
#   ______________________________end_match_winner_home = '1.06',
#   ______________________________end_match_winner_draw = '13.00',
#   ______________________________end_match_winner_away = '23.00',
#   ____________________________2 Home/Away
#   ______________________________end_homeaway_home = '1.02',
#   ______________________________end_homeaway_away = '21.00',
#   ____________________________3 Second Half Winner
#   ______________________________end_second_half_winner_home = '1.20',
#   ______________________________end_second_half_winner_draw = '5.00',
#   ______________________________end_second_half_winner_away = '13.00',
#   ____________________________4 Asian Handicap
#   ______________________________end_asian_handicap_home_min_075 = '1.11',
#   ______________________________end_asian_handicap_away_min_075 = '6.40',
#   ______________________________end_asian_handicap_home_min_1 = '1.10',
#   ______________________________end_asian_handicap_away_min_1 = '6.80',
#   ______________________________end_asian_handicap_home_min_15 = '1.24',
#   ______________________________end_asian_handicap_away_min_15 = '3.90',
#   ______________________________end_asian_handicap_home_min_125 = '1.16',
#   ______________________________end_asian_handicap_away_min_125 = '5.25',
#   ______________________________end_asian_handicap_home_min_175 = '1.27',
#   ______________________________end_asian_handicap_away_min_175 = '3.55',
#   ______________________________end_asian_handicap_home_min_2 = '1.32',
#   ______________________________end_asian_handicap_away_min_2 = '3.30',
#   ______________________________end_asian_handicap_home_min_3 = '1.95',
#   ______________________________end_asian_handicap_away_min_3 = '1.90',
#   ______________________________end_asian_handicap_home_min_25 = '1.60',
#   ______________________________end_asian_handicap_away_min_25 = '2.30',
#   ______________________________end_asian_handicap_home_min_225 = '1.45',
#   ______________________________end_asian_handicap_away_min_225 = '2.67',
#   ______________________________end_asian_handicap_home_min_275 = '1.73',
#   ______________________________end_asian_handicap_away_min_275 = '2.08',
#   ______________________________end_asian_handicap_home_min_325 = '2.10',
#   ______________________________end_asian_handicap_away_min_325 = '1.70',
#   ______________________________end_asian_handicap_home_min_375 = '2.67',
#   ______________________________end_asian_handicap_away_min_375 = '1.45',
#   ______________________________end_asian_handicap_home_min_4 = '3.30',
#   ______________________________end_asian_handicap_away_min_4 = '1.32',
#   ______________________________end_asian_handicap_home_min_45 = '3.70',
#   ______________________________end_asian_handicap_away_min_45 = '1.26',
#   ______________________________end_asian_handicap_home_min_35 = '2.35',
#   ______________________________end_asian_handicap_away_min_35 = '1.58',
#   ______________________________end_asian_handicap_home_min_425 = '3.45',
#   ______________________________end_asian_handicap_away_min_425 = '1.30',
#   ______________________________end_asian_handicap_home_min_5 = '6.00',
#   ______________________________end_asian_handicap_away_min_5 = '1.13',
#   ______________________________end_asian_handicap_home_min_475 = '4.50',
#   ______________________________end_asian_handicap_away_min_475 = '1.19',
#   ______________________________end_asian_handicap_home_min_525 = '5.25',
#   ______________________________end_asian_handicap_away_min_525 = '1.16',
#   ____________________________5 Goals Over/Under
#   ______________________________end_goals_overunder_over_35 = '1.53',
#   ______________________________end_goals_overunder_under_35 = '2.38',
#   ______________________________end_goals_overunder_over_15 = '1.05',
#   ______________________________end_goals_overunder_under_15 = '11.00',
#   ______________________________end_goals_overunder_over_45 = '2.20',
#   ______________________________end_goals_overunder_under_45 = '1.62',
#   ______________________________end_goals_overunder_over_25 = '1.20',
#   ______________________________end_goals_overunder_under_25 = '4.33',
#   ______________________________end_goals_overunder_over_05 = '1.00',
#   ______________________________end_goals_overunder_under_05 = '34.00',
#   ______________________________end_goals_overunder_over_55 = '3.50',
#   ______________________________end_goals_overunder_under_55 = '1.29',
#   ______________________________end_goals_overunder_over_225 = '1.14',
#   ______________________________end_goals_overunder_under_225 = '5.75',
#   ______________________________end_goals_overunder_over_325 = '1.43',
#   ______________________________end_goals_overunder_under_325 = '2.75',
#   ______________________________end_goals_overunder_over_275 = '1.24',
#   ______________________________end_goals_overunder_under_275 = '3.90',
#   ______________________________end_goals_overunder_over_425 = '2.05',
#   ______________________________end_goals_overunder_under_425 = '1.75',
#   ______________________________end_goals_overunder_over_375 = '1.68',
#   ______________________________end_goals_overunder_under_375 = '2.15',
#   ______________________________end_goals_overunder_over_475 = '2.50',
#   ______________________________end_goals_overunder_under_475 = '1.50',
#   ______________________________end_goals_overunder_over_65 = '6.50',
#   ______________________________end_goals_overunder_under_65 = '1.11',
#   ______________________________end_goals_overunder_over_95 = '41.00',
#   ______________________________end_goals_overunder_under_95 = '1.00',
#   ______________________________end_goals_overunder_over_75 = '13.00',
#   ______________________________end_goals_overunder_under_75 = '1.04',
#   ______________________________end_goals_overunder_over_525 = '3.30',
#   ______________________________end_goals_overunder_under_525 = '1.32',
#   ______________________________end_goals_overunder_over_575 = '4.25',
#   ______________________________end_goals_overunder_under_575 = '1.21',
#   ______________________________end_goals_overunder_over_85 = '21.00',
#   ______________________________end_goals_overunder_under_85 = '1.02',
#   ______________________________end_goals_overunder_over_625 = '5.90',
#   ______________________________end_goals_overunder_under_625 = '1.13',
#   ______________________________end_goals_overunder_over_30 = '1.27',
#   ______________________________end_goals_overunder_under_30 = '3.55',
#   ______________________________end_goals_overunder_over_20 = '1.10',
#   ______________________________end_goals_overunder_under_20 = '7.00',
#   ______________________________end_goals_overunder_over_40 = '1.85',
#   ______________________________end_goals_overunder_under_40 = '2.00',
#   ______________________________end_goals_overunder_over_50 = '3.00',
#   ______________________________end_goals_overunder_under_50 = '1.38',
#   ______________________________end_goals_overunder_under_60 = '1.14',
#   ______________________________end_goals_overunder_over_60 = '5.75',
#   ____________________________6 Goals Over/Under First Half
#   ______________________________end_goals_overunder_first_half_over_35 = '7.00',
#   ______________________________end_goals_overunder_first_half_under_35 = '1.10',
#   ______________________________end_goals_overunder_first_half_over_15 = '1.67',
#   ______________________________end_goals_overunder_first_half_under_15 = '2.10',
#   ______________________________end_goals_overunder_first_half_over_25 = '3.25',
#   ______________________________end_goals_overunder_first_half_under_25 = '1.33',
#   ______________________________end_goals_overunder_first_half_over_05 = '1.14',
#   ______________________________end_goals_overunder_first_half_under_05 = '5.50',
#   ______________________________end_goals_overunder_first_half_over_225 = '2.67',
#   ______________________________end_goals_overunder_first_half_under_225 = '1.45',
#   ______________________________end_goals_overunder_first_half_over_325 = '6.25',
#   ______________________________end_goals_overunder_first_half_under_325 = '1.12',
#   ______________________________end_goals_overunder_first_half_over_275 = '3.90',
#   ______________________________end_goals_overunder_first_half_under_275 = '1.24',
#   ______________________________end_goals_overunder_first_half_over_125 = '1.45',
#   ______________________________end_goals_overunder_first_half_under_125 = '2.67',
#   ______________________________end_goals_overunder_first_half_over_175 = '1.93',
#   ______________________________end_goals_overunder_first_half_under_175 = '1.88',
#   ______________________________end_goals_overunder_first_half_over_075 = '1.18',
#   ______________________________end_goals_overunder_first_half_under_075 = '4.80',
#   ______________________________end_goals_overunder_first_half_over_30 = '5.75',
#   ______________________________end_goals_overunder_first_half_under_30 = '1.14',
#   ______________________________end_goals_overunder_first_half_over_20 = '2.35',
#   ______________________________end_goals_overunder_first_half_under_20 = '1.58',
#   ______________________________end_goals_overunder_first_half_over_10 = '1.23',
#   ______________________________end_goals_overunder_first_half_under_10 = '4.10',
#   ____________________________26 Goals Over/Under - Second Half
#   ______________________________end_goals_overunder__second_half_over_35 = '4.00',
#   ______________________________end_goals_overunder__second_half_under_35 = '1.22',
#   ______________________________end_goals_overunder__second_half_over_15 = '1.40',
#   ______________________________end_goals_overunder__second_half_under_15 = '2.75',
#   ______________________________end_goals_overunder__second_half_over_25 = '2.20',
#   ______________________________end_goals_overunder__second_half_under_25 = '1.62',
#   ______________________________end_goals_overunder__second_half_over_05 = '1.07',
#   ______________________________end_goals_overunder__second_half_under_05 = '9.00',
#   ____________________________7 HT/FT Double
#   ____________________________27 Clean Sheet - Home
#   ______________________________end_clean_sheet__home_yes = '1.67',
#   ______________________________end_clean_sheet__home_no = '2.10',
#   ____________________________28 Clean Sheet - Away
#   ______________________________end_clean_sheet__away_yes = '23.00',
#   ______________________________end_clean_sheet__away_no = '1.01',
#   ____________________________8 Both Teams Score
#   ______________________________end_both_teams_score_yes = '2.20',
#   ______________________________end_both_teams_score_no = '1.62',
#   ____________________________9 Handicap Result
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 1.22
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 10.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 6.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.03
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 34.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 19.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 1.57
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 4.75
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 4.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 2.30
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 4.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 2.25
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 3.75
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.57
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 5.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -5 --- bets_odd: 6.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -5 --- bets_odd: 1.25
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -5 --- bets_odd: 7.00
#   ____________________________10 Exact Score
#   ____________________________11 Highest Scoring Half
#   ____________________________31 Correct Score - First Half
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.60
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 4.33
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 7.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 26.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 101.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 17.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 201.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 6:0 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 6:1 --- bets_odd: 251.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 5.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 13.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 67.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 19.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 67.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 351.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 351.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 351.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 7:0 --- bets_odd: 251.00
#   ____________________________12 Double Chance
#   ______________________________end_double_chance_home_draw = '1.01',
#   ______________________________end_double_chance_home_away = '1.04',
# ...
#   ____________________________end_goals_overunder_over_50 = '8.40',
#   ____________________________end_goals_overunder_under_50 = '1.04',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '12.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.02',
#   ____________________________end_goals_overunder_first_half_over_15 = '2.53',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.46',
#   ____________________________end_goals_overunder_first_half_over_25 = '6.00',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.10',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.32',
#   ____________________________end_goals_overunder_first_half_under_05 = '3.10',
#   ____________________________end_goals_overunder_first_half_over_125 = '2.09',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.66',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.44',
#   ____________________________end_goals_overunder_first_half_under_075 = '2.59',
#   ____________________________end_goals_overunder_first_half_over_30 = '10.00',
#   ____________________________end_goals_overunder_first_half_under_30 = '1.02',
#   ____________________________end_goals_overunder_first_half_over_20 = '4.84',
#   ____________________________end_goals_overunder_first_half_under_20 = '1.13',
#   ____________________________end_goals_overunder_first_half_over_10 = '1.68',
#   ____________________________end_goals_overunder_first_half_under_10 = '2.06',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_15 = '1.93',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.78',
#   ____________________________end_goals_overunder__second_half_over_25 = '3.90',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.20',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.18',
#   ____________________________end_goals_overunder__second_half_under_05 = '4.30',
#   ____________________________end_goals_overunder__second_half_over_125 = '1.65',
#   ____________________________end_goals_overunder__second_half_under_125 = '2.11',
#   ____________________________end_goals_overunder__second_half_over_175 = '2.28',
#   ____________________________end_goals_overunder__second_half_under_175 = '1.56',
#   ____________________________end_goals_overunder__second_half_over_30 = '7.30',
#   ____________________________end_goals_overunder__second_half_under_30 = '1.06',
#   ____________________________end_goals_overunder__second_half_over_20 = '2.99',
#   ____________________________end_goals_overunder__second_half_under_20 = '1.34',
#   ____________________________end_goals_overunder__second_half_over_10 = '1.34',
#   ____________________________end_goals_overunder__second_half_under_10 = '2.99',
#   __________________________7 HT/FT Double
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '1.60',
#   ____________________________end_both_teams_score_no = '2.27',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 6.60
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.80
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.71
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 3.56
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 3.64
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 8.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.32
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________________62 Correct Score - Second Half
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:0 --- bets_odd: 5.40
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:0 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:1 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:0 --- bets_odd: 89.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:0 --- bets_odd: 4.30
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:1 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:2 --- bets_odd: 40.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:1 --- bets_odd: 4.30
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:2 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:3 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:2 --- bets_odd: 14.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:3 --- bets_odd: 56.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.71',
#   ____________________________end_double_chance_home_away = '1.25',
#   ____________________________end_double_chance_draw_away = '1.29',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '3.88',
#   ____________________________end_first_half_winner_draw = '2.20',
#   ____________________________end_first_half_winner_away = '2.54',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.54
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.43
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 4.70
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.32
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 2.98
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.12
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.69
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 2.00
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 1.87
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.79
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 4.40
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.16
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.16
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 4.32
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 2.88
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.34
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 3.08
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.39
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 7.10
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.64
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________33 Double Chance - Second Half
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.46
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.38
#   ______________________  ______________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.22
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 1.97
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.71
#   __________________________23 Home Odd/Even
#   ______________________  ______________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.97
#   ______________________  ______________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.71
#   __________________________60 Away Odd/Even
#   ______________________  ______________________bet_id: 60 --- bets_value: Odd --- bets_odd: 1.88
#   ______________________  ______________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.78
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-17 23:25:52

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-17 23:25:52
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-15
#   ______tgl_akhir : 2023-03-16
#   ________ff_get_fixture_status_match_finished()
#   __________Total Row(s) : 129
#   __________1. 2023-03-15 // 2 // 8 // 2022 // 971802 // 05_025_0#025+H // 275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971802
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-03-15 // 2 // 8 // 2022 // 971804 // 15_125_1_075_H // 25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971804
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-03-15 // 14 // 8 // 2022 // 1011486 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011486
#   ____________> end_ah_pattern = 025+05+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_05_025_H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________4. 2023-03-15 // 14 // 8 // 2022 // 1011489 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011489
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________5. 2023-03-15 // 16 // 8 // 2023 // 972936 // 375_35_325_3_275_H // 35g375g4g425g45g475gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 972936
#   ____________> end_ah_pattern = 35_325_3_275_25_H
#   ____________> end_ah_pattern_mirror = 25+275+3+325+35+H
#   ____________> end_gou_pattern = 35g375g4g425g45gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________6. 2023-03-15 // 16 // 8 // 2023 // 972943 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 972943
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________7. 2023-03-15 // 16 // 8 // 2023 // 972950 // 225_2_175_15_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 972950
#   ____________> end_ah_pattern = 25_225_2_175_15_H
#   ____________> end_ah_pattern_mirror = 15+175+2+225+25+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________8. 2023-03-15 // 40 // 8 // 2022 // 881157 // 1_075_05_025_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 881157
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________9. 2023-03-15 // 40 // 8 // 2022 // 881158 // 0#025+05+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 881158
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________10. 2023-03-15 // 40 // 8 // 2022 // 881159 // 025+05+075+H // 2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 881159
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________11. 2023-03-15 // 40 // 8 // 2022 // 881160 // 025+05+075+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 881160
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________12. 2023-03-15 // 40 // 8 // 2022 // 881161 // 1_075_05_025_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 881161
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________13. 2023-03-15 // 40 // 8 // 2022 // 881162 // 0#025+05+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 881162
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________14. 2023-03-15 // 44 // 8 // 2022 // 898188 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 898188
#   ____________> end_ah_pattern = 15_125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+15+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________15. 2023-03-15 // 60 // 11 // 2022 // 911946 // 0#025+075+H // 225g25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 911946
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________16. 2023-03-15 // 60 // 11 // 2022 // 911992 // 15_125_1_075_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 911992
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________17. 2023-03-15 // 73 // 8 // 2023 // 1011357 // 2_175_15_H // 25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011357
#   ____________> end_ah_pattern = 2_175_15_H
#   ____________> end_ah_pattern_mirror = 15+175+2+H
#   ____________> end_gou_pattern = 25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________18. 2023-03-15 // 73 // 8 // 2023 // 1011453 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011453
#   ____________> end_ah_pattern = 05_H
#   ____________> end_ah_pattern_mirror = 05+H
#   ____________> end_gou_pattern = 225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________19. 2023-03-15 // 73 // 8 // 2023 // 1011447 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011447
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________20. 2023-03-15 // 73 // 8 // 2023 // 1011448 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011448
#   ____________> end_ah_pattern = 175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________21. 2023-03-15 // 73 // 8 // 2023 // 1011449 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011449
#   ____________> end_ah_pattern = 05+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_05_H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________22. 2023-03-15 // 73 // 8 // 2023 // 1011459 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011459
#   ____________> end_ah_pattern = 1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+H
#   ____________> end_gou_pattern = 225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________23. 2023-03-15 // 73 // 8 // 2023 // 1012103 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1012103
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________24. 2023-03-15 // 80 // 8 // 2022 // 879372 // 0#025+05+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 879372
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________25. 2023-03-15 // 80 // 8 // 2022 // 879374 // 075_05_025_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 879374
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________26. 2023-03-15 // 80 // 8 // 2022 // 879378 // 1_075_05_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 879378
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________27. 2023-03-15 // 80 // 8 // 2022 // 879380 // 15_125_1_075_H // 25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 879380
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________28. 2023-03-15 // 80 // 8 // 2022 // 879381 // 05_025_0#025+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 879381
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________29. 2023-03-15 // 84 // 8 // 2022 // 909284 // 075_05_025_H // 25g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 909284
#   ____________> end_ah_pattern = 075_05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+075+H
#   ____________> end_gou_pattern = 25g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________30. 2023-03-15 // 84 // 8 // 2022 // 909320 // 025_0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 909320
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________31. 2023-03-16 // 130 // 8 // 2023 // 979214 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 979214
#   ____________> end_ah_pattern = 175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________32. 2023-03-15 // 130 // 8 // 2023 // 979220 // 125_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 979220
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________33. 2023-03-15 // 132 // 11 // 2023 // 988055 // 075_025_0#H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988055
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________34. 2023-03-15 // 132 // 11 // 2023 // 988056 // 025_0#025+H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988056
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________35. 2023-03-15 // 132 // 11 // 2023 // 988057 // 025_0#H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988057
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________36. 2023-03-15 // 132 // 11 // 2023 // 988058 // 0#025+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988058
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________37. 2023-03-15 // 132 // 11 // 2023 // 988059 // 0#025+H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988059
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________38. 2023-03-15 // 132 // 11 // 2023 // 988060 // 025_0#025+H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988060
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________39. 2023-03-15 // 132 // 11 // 2023 // 988061 // 1_075_H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988061
#   ____________> end_ah_pattern = 1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________40. 2023-03-15 // 132 // 11 // 2023 // 988062 // 025_0#025+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988062
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________41. 2023-03-15 // 132 // 11 // 2023 // 988063 // 0#025+H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988063
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________42. 2023-03-15 // 138 // 8 // 2022 // 952341 // 025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952341
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________43. 2023-03-15 // 138 // 8 // 2022 // 952342 // 025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952342
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________44. 2023-03-15 // 138 // 8 // 2022 // 952343 // 025_0#025+H // 15gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952343
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________45. 2023-03-15 // 138 // 8 // 2022 // 952344 // 025_0#025+H // 15gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952344
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________46. 2023-03-15 // 138 // 8 // 2022 // 952345 // 025_0#025+H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952345
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________47. 2023-03-15 // 138 // 8 // 2022 // 952346 // 025_0#025+H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952346
#   ____________> end_ah_pattern = 05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+H
#   ____________> end_gou_pattern = 15gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________48. 2023-03-15 // 138 // 8 // 2022 // 952347 // 15_125_1_075_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952347
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________49. 2023-03-15 // 138 // 8 // 2022 // 952348 // 075_05_025_H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952348
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________50. 2023-03-15 // 138 // 8 // 2022 // 952349 // 1_075_05_H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952349
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________51. 2023-03-15 // 138 // 8 // 2022 // 952350 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952350
#   ____________> end_ah_pattern = 05_H
#   ____________> end_ah_pattern_mirror = 05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________52. 2023-03-15 // 205 // 11 // 2022 // 889066 // 125_1_075_H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889066
#   ____________> end_ah_pattern = 125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________53. 2023-03-15 // 205 // 11 // 2022 // 889067 // 025_0#H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889067
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________54. 2023-03-15 // 205 // 11 // 2022 // 889068 // 0#H // 2g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889068
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________55. 2023-03-15 // 205 // 11 // 2022 // 889069 // 025+075+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889069
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________56. 2023-03-15 // 205 // 11 // 2022 // 889070 // 1_H // 2g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889070
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________57. 2023-03-15 // 205 // 11 // 2022 // 889072 // 0#H // 2g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889072
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________58. 2023-03-15 // 205 // 11 // 2022 // 889073 // 15_1_H // 2g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889073
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________59. 2023-03-15 // 205 // 11 // 2022 // 889074 // 1+H // 2g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889074
#   ____________> end_ah_pattern = 025+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_025_H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________60. 2023-03-15 // 205 // 11 // 2022 // 889431 // 125_1_075_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889431
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________61. 2023-03-15 // 205 // 11 // 2022 // 889432 // 025+075+H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889432
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________62. 2023-03-15 // 205 // 11 // 2022 // 889433 // 075_025_H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889433
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________63. 2023-03-15 // 205 // 11 // 2022 // 889434 // 0#025+075+H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889434
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________64. 2023-03-15 // 205 // 11 // 2022 // 889436 // 025_0#025+H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889436
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________65. 2023-03-15 // 205 // 11 // 2022 // 889437 // 025_0#025+H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889437
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________66. 2023-03-15 // 205 // 11 // 2022 // 889438 // 025_0#025+H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889438
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________67. 2023-03-15 // 205 // 11 // 2022 // 889439 // H // 2g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889439
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 15g2g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________68. 2023-03-15 // 210 // 8 // 2022 // 866432 // 075+1+125+15+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 866432
#   ____________> end_ah_pattern = 1+125+15+175+H
#   ____________> end_ah_pattern_mirror = 175_15_125_1_H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________69. 2023-03-15 // 237 // 11 // 2022 // 1011484 // 0#025+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011484
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________70. 2023-03-15 // 237 // 11 // 2022 // 1011974 // 175_15_125_1_H // 275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011974
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________71. 2023-03-15 // 237 // 11 // 2022 // 1011976 // 025_0#025+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011976
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________72. 2023-03-15 // 239 // 8 // 2023 // 989352 // 075_05_025_H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 989352
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________73. 2023-03-15 // 241 // 8 // 2023 // 1010860 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010860
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________74. 2023-03-15 // 241 // 8 // 2023 // 1010861 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010861
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________75. 2023-03-15 // 241 // 8 // 2023 // 1010863 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010863
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________76. 2023-03-15 // 263 // 8 // 2022 // 975953 // 05_025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975953
#   ____________> end_ah_pattern = 05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________77. 2023-03-15 // 263 // 8 // 2022 // 975954 // 025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975954
#   ____________> end_ah_pattern = 025_H
#   ____________> end_ah_pattern_mirror = 025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________78. 2023-03-15 // 263 // 8 // 2022 // 975955 // 025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975955
#   ____________> end_ah_pattern = 075_05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________79. 2023-03-15 // 274 // 11 // 2022 // 899789 // 025_0#025+H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 899789
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________80. 2023-03-15 // 297 // 11 // 2022 // 974668 // 075_025_0#H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974668
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________81. 2023-03-15 // 297 // 11 // 2022 // 974669 // 025_0#025+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974669
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________82. 2023-03-15 // 297 // 11 // 2022 // 974670 // 025_0#025+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974670
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________83. 2023-03-15 // 297 // 11 // 2022 // 974671 // 075_025_H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974671
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________84. 2023-03-15 // 297 // 11 // 2022 // 974672 // 1_075_H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974672
#   ____________> end_ah_pattern = 125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________85. 2023-03-15 // 297 // 11 // 2022 // 974673 // 025_0#025+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974673
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________86. 2023-03-15 // 297 // 11 // 2022 // 974674 // 025_0#025+H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974674
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________87. 2023-03-15 // 297 // 11 // 2022 // 974675 // 025_0#025+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974675
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________88. 2023-03-15 // 297 // 11 // 2022 // 974676 // 075+1+125+15+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974676
#   ____________> end_ah_pattern = 075+1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_075_H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________89. 2023-03-15 // 306 // 11 // 2022 // 992777 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992777
#   ____________> end_ah_pattern = 025+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_025_H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________90. 2023-03-15 // 306 // 11 // 2022 // 992779 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992779
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________91. 2023-03-15 // 329 // 11 // 2023 // 1001211 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001211
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________92. 2023-03-15 // 329 // 11 // 2023 // 1001213 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001213
#   ____________> end_ah_pattern = 125_1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+125+H
#   ____________> end_gou_pattern = 225g25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________93. 2023-03-15 // 329 // 11 // 2023 // 1001214 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1001214
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________94. 2023-03-15 // 362 // 8 // 2023 // 998391 // 05_025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998391
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________95. 2023-03-15 // 362 // 8 // 2023 // 998392 // 1+125+15+175+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998392
#   ____________> end_ah_pattern = 1+125+15+H
#   ____________> end_ah_pattern_mirror = 15_125_1_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________96. 2023-03-15 // 362 // 8 // 2023 // 998393 // 025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 998393
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________97. 2023-03-15 // 368 // 11 // 2023 // 997875 // 175_15_125_1_075_H // 325g35g375g4g425g45gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 997875
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 325g35g375g4g425g45g475gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________98. 2023-03-15 // 368 // 11 // 2023 // 997876 // 175_15_125_1_075_H // 325g35g375g4g425g45g475gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 997876
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 325g35g375g4g425gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________99. 2023-03-15 // 373 // 8 // 2022 // 876866 // 1_075_05_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 876866
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________100. 2023-03-15 // 373 // 8 // 2022 // 876867 // 025_0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 876867
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________101. 2023-03-15 // 373 // 8 // 2022 // 876870 // 025+05+075+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 876870
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________102. 2023-03-15 // 417 // 8 // 2022 // 997665 // 1_075_05_025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 997665
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________103. 2023-03-15 // 417 // 8 // 2022 // 997666 // 075_05_025_H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 997666
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________104. 2023-03-15 // 419 // 11 // 2022 // 923316 // 125+15+175+2+H // 225g25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 923316
#   ____________> end_ah_pattern = 15+175+2+225+25+H
#   ____________> end_ah_pattern_mirror = 25_225_2_175_15_H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________105. 2023-03-15 // 419 // 11 // 2022 // 923320 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 923320
#   ____________> end_ah_pattern = 075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________106. 2023-03-15 // 426 // 11 // 2022 // 949655 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 949655
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________107. 2023-03-15 // 426 // 11 // 2022 // 949661 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 949661
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________108. 2023-03-15 // 430 // 11 // 2022 // 950965 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 950965
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________109. 2023-03-15 // 433 // 11 // 2022 // 951878 // 0#H // 15g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 951878
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________110. 2023-03-15 // 487 // 11 // 2022 // 941810 // H // 25g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 941810
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________111. 2023-03-15 // 667 // 8 // 2023 // 1014198 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1014198
#   ____________> end_ah_pattern = 05+H
#   ____________> end_ah_pattern_mirror = 05_H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________112. 2023-03-15 // 680 // 8 // 2022 // 1013020 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1013020
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________113. 2023-03-15 // 701 // 11 // 2022 // 992360 // 0#025+075+H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992360
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________114. 2023-03-15 // 732 // 11 // 2022 // 971125 // 2+225+25+275+3+H // 3g325g35g375g4g425gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971125
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________115. 2023-03-15 // 732 // 11 // 2022 // 971127 // 075+1+125+15+H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971127
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________116. 2023-03-15 // 732 // 11 // 2022 // 971131 // 025_0#025+H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971131
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________117. 2023-03-15 // 746 // 11 // 2022 // 906078 // 025_0#025+075+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906078
#   ____________> end_ah_pattern = 025_0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________118. 2023-03-15 // 747 // 11 // 2022 // 906744 // 175_15_125_1_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 906744
#   ____________> end_ah_pattern = 175_15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+175+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________119. 2023-03-15 // 750 // 11 // 2022 // 907432 // 0#025+075+H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 907432
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________120. 2023-03-15 // 780 // 11 // 2022 // 969239 // 0#H // 25g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 969239
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________121. 2023-03-15 // 848 // 8 // 2022 // 1010851 // 075_05_025_H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010851
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________122. 2023-03-15 // 943 // 8 // 2022 // 953101 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 953101
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 15gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________123. 2023-03-15 // 943 // 8 // 2022 // 953102 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 953102
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________124. 2023-03-15 // 943 // 8 // 2022 // 953104 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 953104
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________125. 2023-03-15 // 943 // 8 // 2022 // 953105 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 953105
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________126. 2023-03-15 // 943 // 8 // 2022 // 953106 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 953106
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________127. 2023-03-15 // 943 // 8 // 2022 // 953108 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 953108
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________128. 2023-03-15 // 943 // 8 // 2022 // 953109 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 953109
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________129. 2023-03-15 // 943 // 8 // 2022 // 953110 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 953110
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 15gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
# # -------------------------------------------------- End at 2023-03-17 23:40:35

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-17 23:40:35
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-15
#   ______tgl_akhir : 2023-03-16
#   ________ff_get_fixture_status_match_finished_for_daily_update_patternlist()
#   ________Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date <= '2023-03-16'  and date >= '2023-03-15'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 130
#   ____________[1/130] #866432 #Croatia 210-2022 / Istra 1961 vs Dinamo Zagreb
#   ____________pre-ah:075+1+125+15+H -- pre-gou:225g25g275gG -/- end-ah:1+125+15+175+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:27:09
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '210'  and league_country = 'Croatia'  and pre_ah_pattern = '075+1+125+15+H'  and pre_ah_pattern_mirror = '15_125_1_075_H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '1+125+15+175+H'  and end_ah_pattern_mirror = '175_15_125_1_H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[2/130] #876866 #Slovenia 373-2022 / NK Domzale vs Radomlje
#   ____________pre-ah:1_075_05_H -- pre-gou:25gG -/- end-ah:1_075_05_025_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:29:29
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '373'  and league_country = 'Slovenia'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[3/130] #876867 #Slovenia 373-2022 / Celje vs Olimpija Ljubljana
#   ____________pre-ah:025_0#025+05+H -- pre-gou:25gG -/- end-ah:025_0#025+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:29:33
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '373'  and league_country = 'Slovenia'  and pre_ah_pattern = '025_0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[4/130] #876870 #Slovenia 373-2022 / Bravo vs Maribor
#   ____________pre-ah:025+05+075+H -- pre-gou:25gG -/- end-ah:025+05+075+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:29:36
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '373'  and league_country = 'Slovenia'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 5
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 5
#   ____________________patternlists updated
#
#   ____________[5/130] #879372 #Germany 80-2022 / VfB Oldenburg vs Borussia Dortmund II
#   ____________pre-ah:0#025+05+H -- pre-gou:225g25g275gG -/- end-ah:0#025+05+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '80'  and league_country = 'Germany'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[6/130] #879374 #Germany 80-2022 / Waldhof Mannheim vs FC Ingolstadt 04
#   ____________pre-ah:075_05_025_H -- pre-gou:225g25g275g3gG -/- end-ah:1_075_05_025_H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:22
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '80'  and league_country = 'Germany'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[7/130] #879378 #Germany 80-2022 / Dynamo Dresden vs MSV Duisburg
#   ____________pre-ah:1_075_05_H -- pre-gou:225g25g275gG -/- end-ah:125_1_075_05_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:34
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '80'  and league_country = 'Germany'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[8/130] #879380 #Germany 80-2022 / FC Saarbrucken vs Bayreuth
#   ____________pre-ah:15_125_1_075_H -- pre-gou:25g275g3g325gG -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:27
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '80'  and league_country = 'Germany'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '25g275g3g325gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[9/130] #879381 #Germany 80-2022 / Freiburg II vs SV Wehen
#   ____________pre-ah:05_025_0#025+H -- pre-gou:225g25g275g3gG -/- end-ah:05_025_0#025+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:28
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '80'  and league_country = 'Germany'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[10/130] #904227 #Germany 83-2022 / Türkgücü-Ataspor vs Bayern München II
#   ____________pre-ah:0#025+05+075+H -- pre-gou:35gG -/- end-ah:025+05+075+H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-17 08:24:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '83'  and league_country = 'Germany'  and pre_ah_pattern = '0#025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_0#H'  and pre_gou_pattern = '35gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[11/130] #881157 #England 40-2022 / Blackburn vs Reading
#   ____________pre-ah:1_075_05_025_H -- pre-gou:2g225g25g275gG -/- end-ah:1_075_05_H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:29
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '40'  and league_country = 'England'  and pre_ah_pattern = '1_075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+1+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[12/130] #881158 #England 40-2022 / Cardiff vs West Brom
#   ____________pre-ah:0#025+05+H -- pre-gou:175g2g225g25gG -/- end-ah:0#025+05+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '40'  and league_country = 'England'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[13/130] #881159 #England 40-2022 / Huddersfield vs Norwich
#   ____________pre-ah:025+05+075+H -- pre-gou:2g225g25gG -/- end-ah:025+05+075+H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:34
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '40'  and league_country = 'England'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '2g225g25gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[14/130] #881160 #England 40-2022 / Hull City vs Burnley
#   ____________pre-ah:025+05+075+H -- pre-gou:175g2g225g25gG -/- end-ah:025+05+075+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:23
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '40'  and league_country = 'England'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[15/130] #881161 #England 40-2022 / Luton vs Bristol City
#   ____________pre-ah:1_075_05_025_H -- pre-gou:2g225g25g275gG -/- end-ah:075_05_025_H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:32
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '40'  and league_country = 'England'  and pre_ah_pattern = '1_075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+1+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[16/130] #881162 #England 40-2022 / Sunderland vs Sheffield Utd
#   ____________pre-ah:0#025+05+H -- pre-gou:225g25g275gG -/- end-ah:0#025+05+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '40'  and league_country = 'England'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 10
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 10
#   ____________________patternlists updated
#
#   ____________[17/130] #899789 #Indonesia 274-2022 / Persis Solo vs Arema FC
#   ____________pre-ah:025_0#025+H -- pre-gou:175g2g225g25g275gG -/- end-ah:025_0#025+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:27:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '274'  and league_country = 'Indonesia'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '175g2g225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[18/130] #909284 #Germany 84-2022 / Weiche Flensburg vs Hannover 96 II
#   ____________pre-ah:075_05_025_H -- pre-gou:25g35gG -/- end-ah:075_05_025_0#H -- end-gou:25g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '84'  and league_country = 'Germany'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '25g35gG'  and end_ah_pattern = '075_05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+075+H'  and end_gou_pattern = '25g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[19/130] #909320 #Germany 84-2022 / Schwarz-Weiß Rehden vs Werder Bremen II
#   ____________pre-ah:025_0#025+05+H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '84'  and league_country = 'Germany'  and pre_ah_pattern = '025_0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[20/130] #898188 #England 44-2022 / Tottenham Hotspur W vs Leicester City WFC
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:15_125_1_075_05_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:43
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '44'  and league_country = 'England'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '15_125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+15+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[21/130] #904876 #Germany 86-2022 / TSV Steinbach vs Bahlinger SC
#   ____________pre-ah:125_1_075_05_H -- pre-gou:25gG -/- end-ah:175_15_125_1_H -- end-gou:25gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-17 08:24:52
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '86'  and league_country = 'Germany'  and pre_ah_pattern = '125_1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+125+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[22/130] #906078 #Germany 746-2022 / Viktoria Arnoldsweiler vs Hürth
#   ____________pre-ah:025_0#025+075+H -- pre-gou:25g275g3g325g35gG -/- end-ah:025_0#025+075+H -- end-gou:25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:30:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '746'  and league_country = 'Germany'  and pre_ah_pattern = '025_0#025+075+H'  and pre_ah_pattern_mirror = '075_025_0#025+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '025_0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#025+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[23/130] #906744 #Germany 747-2022 / Westfalia Rhynern vs Ennepetal
#   ____________pre-ah:175_15_125_1_H -- pre-gou:25g275g3g325g35gG -/- end-ah:175_15_125_1_075_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:30:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '747'  and league_country = 'Germany'  and pre_ah_pattern = '175_15_125_1_H'  and pre_ah_pattern_mirror = '1+125+15+175+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '175_15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+175+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[24/130] #907432 #Germany 750-2022 / Weidenhausen vs SV Steinbach
#   ____________pre-ah:0#025+075+H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:0#025+075+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:30:59
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '750'  and league_country = 'Germany'  and pre_ah_pattern = '0#025+075+H'  and pre_ah_pattern_mirror = '075_025_0#H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[25/130] #911946 #England 60-2022 / Tiverton Town vs Hayes & Yeading United
#   ____________pre-ah:0#025+075+H -- pre-gou:225g25g275g3g325g35gG -/- end-ah:0#025+075+H -- end-gou:225g25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '60'  and league_country = 'England'  and pre_ah_pattern = '0#025+075+H'  and pre_ah_pattern_mirror = '075_025_0#H'  and pre_gou_pattern = '225g25g275g3g325g35gG'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '225g25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[26/130] #911992 #England 60-2022 / Swindon Supermarine vs Gosport Borough
#   ____________pre-ah:15_125_1_075_H -- pre-gou:25g275g3g325g35gG -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '60'  and league_country = 'England'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 7
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 7
#   ____________________patternlists updated
#
#   ____________[27/130] #949655 #Italy 426-2022 / Borgosesia vs Gozzano
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:0#025+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:29:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '426'  and league_country = 'Italy'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '0#025+H'  and end_ah_pattern_mirror = '025_0#H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[28/130] #949661 #Italy 426-2022 / Ligorna vs Sestri Levante
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#025+075+H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:30:03
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '426'  and league_country = 'Italy'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[29/130] #921057 #Poland 781-2022 / Starogard Gdański vs Jarota Jarocin
#   ____________pre-ah:1_075_H -- pre-gou:25g3gG -/- end-ah:125_1_075_H -- end-gou:225g25g275g3gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-17 08:31:11
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '781'  and league_country = 'Poland'  and pre_ah_pattern = '1_075_H'  and pre_ah_pattern_mirror = '075+1+H'  and pre_gou_pattern = '25g3gG'  and end_ah_pattern = '125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[30/130] #926166 #Germany 749-2022 / TuSpo Surheide vs Hemelingen
#   ____________pre-ah:125+15+175+2+225+H -- pre-gou:325g35g375g4g425g45gG -/- end-ah:125+15+175+2+225+25+H -- end-gou:35g375g4g425g45gG
#   ____________Match Finished -- end_odd_updated_at:2023-03-17 08:30:53
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '749'  and league_country = 'Germany'  and pre_ah_pattern = '125+15+175+2+225+H'  and pre_ah_pattern_mirror = '225_2_175_15_125_H'  and pre_gou_pattern = '325g35g375g4g425g45gG'  and end_ah_pattern = '125+15+175+2+225+25+H'  and end_ah_pattern_mirror = '25_225_2_175_15_125_H'  and end_gou_pattern = '35g375g4g425g45gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[31/130] #952341 #Italy 138-2022 / Sangiuliano City vs Albinoleffe
#   ____________pre-ah:025_0#025+H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:25:42
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '138'  and league_country = 'Italy'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[32/130] #952342 #Italy 138-2022 / Mantova vs Arzignano Valchiampo
#   ____________pre-ah:025_0#025+H -- pre-gou:25gG -/- end-ah:025_0#025+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:25:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '138'  and league_country = 'Italy'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 17
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 17
#   ____________________patternlists updated
#
#   ____________[33/130] #952343 #Italy 138-2022 / Lecco vs Feralpisalo
#   ____________pre-ah:025_0#025+H -- pre-gou:15gG -/- end-ah:025_0#025+H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:25:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '138'  and league_country = 'Italy'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '15gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[34/130] #952344 #Italy 138-2022 / PRO Vercelli vs Juventus U23
#   ____________pre-ah:025_0#025+H -- pre-gou:15gG -/- end-ah:05_025_0#H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:25:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '138'  and league_country = 'Italy'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '15gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[35/130] #952345 #Italy 138-2022 / Pro Patria vs Novara
#   ____________pre-ah:025_0#025+H -- pre-gou:G -/- end-ah:025_0#025+H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:25:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '138'  and league_country = 'Italy'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 6
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 6
#   ____________________patternlists updated
#
#   ____________[36/130] #952346 #Italy 138-2022 / Trento vs Pergolettese
#   ____________pre-ah:025_0#025+H -- pre-gou:G -/- end-ah:05_025_H -- end-gou:15gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:26:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '138'  and league_country = 'Italy'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_025_H'  and end_ah_pattern_mirror = '025+05+H'  and end_gou_pattern = '15gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[37/130] #952347 #Italy 138-2022 / Pordenone vs Piacenza
#   ____________pre-ah:15_125_1_075_H -- pre-gou:25gG -/- end-ah:15_125_1_075_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:25:55
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '138'  and league_country = 'Italy'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 5
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 5
#   ____________________patternlists updated
#
#   ____________[38/130] #952348 #Italy 138-2022 / Padova vs Pro Sesto
#   ____________pre-ah:075_05_025_H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:25:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '138'  and league_country = 'Italy'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[39/130] #952349 #Italy 138-2022 / Renate vs Triestina
#   ____________pre-ah:1_075_05_H -- pre-gou:G -/- end-ah:05_025_0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:25:34
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '138'  and league_country = 'Italy'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[40/130] #952350 #Italy 138-2022 / Vicenza Virtus vs Virtus Verona
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:25:45
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '138'  and league_country = 'Italy'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_H'  and end_ah_pattern_mirror = '05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[41/130] #971802 #World 2-2022 / Real Madrid vs Liverpool
#   ____________pre-ah:05_025_0#025+H -- pre-gou:275g3g325g35gG -/- end-ah:05_025_0#025+H -- end-gou:275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:22:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '2'  and league_country = 'World'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '275g3g325g35gG'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[42/130] #971804 #World 2-2022 / Napoli vs Eintracht Frankfurt
#   ____________pre-ah:15_125_1_075_H -- pre-gou:25g275g3g325gG -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:22:52
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '2'  and league_country = 'World'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '25g275g3g325gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[43/130] #889066 #Turkey 205-2022 / Erokspor vs Somaspor
#   ____________pre-ah:125_1_075_H -- pre-gou:175g2g225g25g275gG -/- end-ah:125_1_075_H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 23:24:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
# ...
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[115/130] #998393 #Lithuania 362-2023 / FK Trakai vs Dainava
#   ____________pre-ah:025_H -- pre-gou:25gG -/- end-ah:075_05_025_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:29:14
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '362'  and league_country = 'Lithuania'  and pre_ah_pattern = '025_H'  and pre_ah_pattern_mirror = '025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[116/130] #1010860 #Colombia 241-2023 / Fortaleza FC vs Union Magdalena
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 23:25:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '241'  and league_country = 'Colombia'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = 'H'  and end_ah_pattern_mirror = 'H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[117/130] #1010861 #Colombia 241-2023 / Llaneros vs Jaguares
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 23:25:31
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '241'  and league_country = 'Colombia'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = 'H'  and end_ah_pattern_mirror = 'H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[118/130] #1010863 #Colombia 241-2023 / Tigres FC vs Envigado
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 23:25:33
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '241'  and league_country = 'Colombia'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = 'H'  and end_ah_pattern_mirror = 'H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[119/130] #1011357 #Brazil 73-2023 / America Mineiro vs Santa Cruz
#   ____________pre-ah:2_175_15_H -- pre-gou:25g275g3gG -/- end-ah:2_175_15_H -- end-gou:25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:55
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = '2_175_15_H'  and pre_ah_pattern_mirror = '15+175+2+H'  and pre_gou_pattern = '25g275g3gG'  and end_ah_pattern = '2_175_15_H'  and end_ah_pattern_mirror = '15+175+2+H'  and end_gou_pattern = '25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[120/130] #1011453 #Brazil 73-2023 / Atletico Goianiense vs Volta Redonda
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05_H -- end-gou:225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:02
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_H'  and end_ah_pattern_mirror = '05+H'  and end_gou_pattern = '225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[121/130] #1014198 #World 667-2023 / SalPa vs Ilves Tampere
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:05+H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 23:25:46
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '05+H'  and end_ah_pattern_mirror = '05_H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[122/130] #1011486 #World 14-2022 / AZ U19 vs Real Madrid U19
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025+05+075+1+H -- end-gou:35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '14'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025+05+075+1+H'  and end_ah_pattern_mirror = '1_075_05_025_H'  and end_gou_pattern = '35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[123/130] #1011489 #World 14-2022 / Borussia Dortmund U19 vs Hajduk Split U19
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:15_125_1_075_H -- end-gou:35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:02
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '14'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[124/130] #992777 #Qatar 306-2022 / Al Shahaniya vs Al-Khor
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025+075+1+125+H -- end-gou:275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:28:43
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '306'  and league_country = 'Qatar'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025+075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_025_H'  and end_gou_pattern = '275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[125/130] #992779 #Qatar 306-2022 / Lusail City vs Al Kharaitiyat
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_0#025+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:28:48
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '306'  and league_country = 'Qatar'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[126/130] #1011447 #Brazil 73-2023 / Ituano vs Ceara
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:025_0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:09
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[127/130] #1011448 #Brazil 73-2023 / CRB vs Operario Ferroviario
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:175_15_125_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:07
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[128/130] #1011449 #Brazil 73-2023 / Águia de Marabá vs Goias
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:05+075+1+125+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:12
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '05+075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_05_H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[129/130] #1011459 #Brazil 73-2023 / Nova Iguaçu vs Nova Mutum EC
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:1_075_H -- end-gou:225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:23:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '1_075_H'  and end_ah_pattern_mirror = '075+1+H'  and end_gou_pattern = '225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[130/130] #1012103 #Brazil 73-2023 / Botafogo vs Brasiliense
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:175_15_125_1_H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-17 08:24:04
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '73'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
# # -------------------------------------------------- End at 2023-03-18 00:41:23
