# %%
# Import
from a_settings.messages import *  

today = datetime.datetime.now()  
days0 = 2
days1 = 1
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 2 - 1 --> 2023-03-22 15:42:36.107078

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-22 15:42:36
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-20
#   ______tgl_akhir : 2023-03-21
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-21'  and date >= '2023-03-20'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 35
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 68
#   ______________1. 2023-03-20 // 63 // 11 // 2022 // 914101 // 075_025_H // 175g2g225g25gG
#   ______________2. 2023-03-20 // 80 // 8 // 2022 // 879386 // 025+05+075+H // 225g25g275g3gG
#   ______________3. 2023-03-20 // 128 // 8 // 2023 // 971437 // H // G
#   ______________4. 2023-03-20 // 128 // 8 // 2023 // 971440 // 05_025_0#H // 15g175g2gG
#   ______________5. 2023-03-21 // 128 // 8 // 2023 // 971442 // H // G
#   ______________6. 2023-03-21 // 128 // 8 // 2023 // 971445 // H // G
#   ______________7. 2023-03-20 // 128 // 8 // 2023 // 988711 // H // G
#   ______________8. 2023-03-20 // 129 // 8 // 2023 // 992652 // H // 25gG
#   ______________9. 2023-03-20 // 132 // 11 // 2023 // 988065 // 025+075+H // 15g175g2g225g25gG
#   ______________10. 2023-03-20 // 132 // 11 // 2023 // 988071 // 025_0#H // 175g225g25gG
#   ______________11. 2023-03-20 // 133 // 11 // 2023 // 1004349 // 075_025_H // 175g2g225gG
#   ______________12. 2023-03-20 // 133 // 11 // 2023 // 1004351 // 0#025+H // 15g175g225g25gG
#   ______________13. 2023-03-20 // 141 // 8 // 2022 // 878671 // 0#025+05+H // 175g2g225gG
#   ______________14. 2023-03-20 // 173 // 11 // 2022 // 882799 // 025+075+H // 175g2g225g25g275gG
#   ______________15. 2023-03-20 // 173 // 11 // 2022 // 882803 // 025_0#H // 175g2g225g25gG
#   ______________16. 2023-03-20 // 204 // 8 // 2022 // 885005 // 025_0#025+05+H // 225g25g275gG
#   ______________17. 2023-03-20 // 205 // 11 // 2022 // 889094 // H // 2gG
#   ______________18. 2023-03-20 // 205 // 11 // 2022 // 889461 // 275_25_225_2_175_15_H // 275g3g325g35g375gG
#   ______________19. 2023-03-20 // 239 // 8 // 2023 // 989354 // H // G
#   ______________20. 2023-03-20 // 239 // 8 // 2023 // 989359 // 025_0#025+H // 175g2g225g25gG
#   ______________21. 2023-03-20 // 240 // 8 // 2023 // 989589 // 025+H // 25gG
#   ______________22. 2023-03-20 // 240 // 8 // 2023 // 989587 // 025_H // 25gG
#   ______________23. 2023-03-20 // 240 // 8 // 2023 // 989586 // 025_H // 25gG
#   ______________24. 2023-03-20 // 242 // 8 // 2023 // 996239 // 175_15_125_1_H // 2g225g25g275gG
#   ______________25. 2023-03-21 // 242 // 8 // 2023 // 996238 // 1_075_05_H // 2g225g25gG
#   ______________26. 2023-03-20 // 250 // 8 // 2023 // 986901 // 075+H // 25gG
#   ______________27. 2023-03-20 // 250 // 8 // 2023 // 986905 // 05_025_0#H // 225g25g275gG
#   ______________28. 2023-03-20 // 262 // 8 // 2022 // 974411 // H // G
#   ______________29. 2023-03-20 // 262 // 8 // 2022 // 974412 // H // G
#   ______________30. 2023-03-20 // 266 // 11 // 2023 // 987780 // 025_0#025+H // 2g225g25g275gG
#   ______________31. 2023-03-20 // 266 // 11 // 2023 // 987783 // 025_0#025+H // 2g225g25g275gG
#   ______________32. 2023-03-20 // 266 // 11 // 2023 // 987785 // 075_025_H // 15g175g2g225gG
#   ______________33. 2023-03-20 // 266 // 11 // 2023 // 987786 // 025_0#025+H // 2g225g25g275gG
#   ______________34. 2023-03-20 // 268 // 8 // 2023 // 1003364 // 025_0#025+05+H // 2g225g25gG
#   ______________35. 2023-03-20 // 269 // 8 // 2023 // 1009264 // H // G
#   ______________36. 2023-03-20 // 274 // 11 // 2022 // 899799 // 15_125_1_075_H // 225g25g275g3g325gG
#   ______________37. 2023-03-20 // 281 // 8 // 2023 // 985146 // 15_125_1_075_05_H // 225g25g275g3gG
#   ______________38. 2023-03-20 // 283 // 8 // 2022 // 1015114 // 1_075_05_H // 175g2g225g25gG
#   ______________39. 2023-03-20 // 283 // 8 // 2022 // 1015982 // H // G
#   ______________40. 2023-03-20 // 318 // 8 // 2022 // 1014328 // 05_025_0#025+H // 25gG
#   ______________41. 2023-03-20 // 322 // 11 // 2022 // 968392 // H // G
#   ______________42. 2023-03-20 // 361 // 11 // 2023 // 1011578 // 1+H // 25g3gG
#   ______________43. 2023-03-20 // 361 // 11 // 2023 // 1011579 // 0#H // 25g3gG
#   ______________44. 2023-03-20 // 386 // 11 // 2022 // 1015654 // 025_0#025+H // 15g175g2g225gG
#   ______________45. 2023-03-20 // 429 // 11 // 2022 // 950650 // 025_0#025+H // 175g2g225g25g275gG
#   ______________46. 2023-03-20 // 494 // 11 // 2022 // 966783 // None // None
#   ______________47. 2023-03-20 // 518 // 8 // 2022 // 913668 // 1+H // G
#   ______________48. 2023-03-20 // 518 // 8 // 2022 // 913669 // H // G
#   ______________49. 2023-03-20 // 518 // 8 // 2022 // 913670 // H // 25gG
#   ______________50. 2023-03-20 // 518 // 8 // 2022 // 913671 // 05+H // G
#   ______________51. 2023-03-20 // 518 // 8 // 2022 // 913672 // 05_H // 25gG
#   ______________52. 2023-03-20 // 518 // 8 // 2022 // 913673 // 05_H // G
#   ______________53. 2023-03-20 // 673 // 8 // 2022 // 976342 // H // G
#   ______________54. 2023-03-20 // 673 // 8 // 2022 // 976343 // 0#H // 25gG
#   ______________55. 2023-03-20 // 702 // 11 // 2022 // 924955 // 075_025_0#025+H // 25g275g3g325g35gG
#   ______________56. 2023-03-20 // 702 // 11 // 2022 // 925076 // 0#025+075+H // 275g3g325g35g375gG
#   ______________57. 2023-03-20 // 702 // 11 // 2022 // 925078 // 025_0#025+H // 25g275g3g325g35g375gG
#   ______________58. 2023-03-20 // 703 // 11 // 2022 // 948596 // 025_0#025+H // 275g3g325g35g375gG
#   ______________59. 2023-03-20 // 703 // 11 // 2022 // 948597 // 025_0#025+H // 25g275g3g325g35g375gG
#   ______________60. 2023-03-20 // 703 // 11 // 2022 // 948598 // 025_0#025+H // 3g325g35g375g4g425gG
#   ______________61. 2023-03-20 // 703 // 11 // 2022 // 948599 // 025+075+1+125+H // 275g3g325g35g375gG
#   ______________62. 2023-03-20 // 887 // 11 // 2022 // 964796 // H // 15gG
#   ______________63. 2023-03-20 // 887 // 11 // 2022 // 964797 // H // G
#   ______________64. 2023-03-20 // 887 // 11 // 2022 // 964798 // H // G
#   ______________65. 2023-03-20 // 887 // 11 // 2022 // 964800 // H // G
#   ______________66. 2023-03-20 // 887 // 11 // 2022 // 964801 // H // G
#   ______________67. 2023-03-20 // 931 // 11 // 2022 // 912420 // 025_0#025+H // 25g275g3g325g35gG
#   ______________68. 2023-03-20 // 942 // 8 // 2022 // 952733 // 0#025+05+H // 25gG
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-03-20 // 63 // 11 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 98
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-20
#   __________________bookmaker : 11
#   __________________season : 2022
#   __________________league : 63
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. France,  National 1  #63 - 2022 / 914101
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '2.14',
#   ____________________________end_match_winner_draw = '3.22',
#   ____________________________end_match_winner_away = '3.42',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '2.48',
#   ____________________________end_second_half_winner_draw = '2.26',
#   ____________________________end_second_half_winner_away = '3.84',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.54',
#   ____________________________end_asian_handicap_away_plus_0 = '2.46',
#   ____________________________end_asian_handicap_home_min_025 = '1.84',
#   ____________________________end_asian_handicap_away_min_025 = '1.96',
#   ____________________________end_asian_handicap_home_plus_025 = '1.38',
#   ____________________________end_asian_handicap_away_plus_025 = '2.81',
#   ____________________________end_asian_handicap_home_min_075 = '2.45',
#   ____________________________end_asian_handicap_away_min_075 = '1.48',
#   ____________________________end_asian_handicap_home_plus_075 = '1.18',
#   ____________________________end_asian_handicap_away_plus_075 = '4.24',
#   ____________________________end_asian_handicap_home_min_1 = '3.24',
#   ____________________________end_asian_handicap_away_min_1 = '1.28',
#   ____________________________end_asian_handicap_home_plus_1 = '1.06',
#   ____________________________end_asian_handicap_away_plus_1 = '6.55',
#   ____________________________end_asian_handicap_home_min_15 = '4.14',
#   ____________________________end_asian_handicap_away_min_15 = '1.18',
#   ____________________________end_asian_handicap_home_plus_15 = '1.04',
#   ____________________________end_asian_handicap_away_plus_15 = '7.50',
#   ____________________________end_asian_handicap_home_min_125 = '3.68',
#   ____________________________end_asian_handicap_away_min_125 = '1.23',
#   ____________________________end_asian_handicap_home_min_175 = '5.40',
#   ____________________________end_asian_handicap_away_min_175 = '1.11',
#   ____________________________end_asian_handicap_home_plus_125 = '1.06',
#   ____________________________end_asian_handicap_away_plus_125 = '7.30',
#   ____________________________end_asian_handicap_home_plus_175 = '1.01',
#   ____________________________end_asian_handicap_away_plus_175 = '10.50',
#   ____________________________end_asian_handicap_home_min_2 = '8.20',
#   ____________________________end_asian_handicap_away_min_2 = '1.03',
#   ____________________________end_asian_handicap_home_min_25 = '9.00',
#   ____________________________end_asian_handicap_away_min_25 = '1.02',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '4.10',
#   ____________________________end_goals_overunder_under_35 = '1.18',
#   ____________________________end_goals_overunder_over_15 = '1.39',
#   ____________________________end_goals_overunder_under_15 = '2.67',
#   ____________________________end_goals_overunder_over_45 = '8.10',
#   ____________________________end_goals_overunder_under_45 = '1.03',
#   ____________________________end_goals_overunder_over_25 = '2.30',
#   ____________________________end_goals_overunder_under_25 = '1.62',
#   ____________________________end_goals_overunder_over_05 = '1.05',
#   ____________________________end_goals_overunder_under_05 = '7.20',
#   ____________________________end_goals_overunder_over_55 = '13.00',
#   ____________________________end_goals_overunder_under_55 = '1.02',
#   ____________________________end_goals_overunder_over_225 = '2.01',
#   ____________________________end_goals_overunder_under_225 = '1.80',
#   ____________________________end_goals_overunder_over_325 = '3.72',
#   ____________________________end_goals_overunder_under_325 = '1.23',
#   ____________________________end_goals_overunder_over_275 = '2.63',
#   ____________________________end_goals_overunder_under_275 = '1.42',
#   ____________________________end_goals_overunder_over_125 = '1.25',
#   ____________________________end_goals_overunder_under_125 = '3.50',
#   ____________________________end_goals_overunder_over_425 = '8.10',
#   ____________________________end_goals_overunder_under_425 = '1.04',
#   ____________________________end_goals_overunder_over_175 = '1.51',
#   ____________________________end_goals_overunder_under_175 = '2.38',
#   ____________________________end_goals_overunder_over_375 = '5.20',
#   ____________________________end_goals_overunder_under_375 = '1.12',
#   ____________________________end_goals_overunder_over_075 = '1.07',
#   ____________________________end_goals_overunder_under_075 = '6.85',
#   ____________________________end_goals_overunder_over_30 = '3.38',
#   ____________________________end_goals_overunder_under_30 = '1.27',
#   ____________________________end_goals_overunder_over_20 = '1.68',
#   ____________________________end_goals_overunder_under_20 = '2.05',
#   ____________________________end_goals_overunder_over_40 = '7.40',
#   ____________________________end_goals_overunder_under_40 = '1.05',
#   ____________________________end_goals_overunder_over_10 = '1.08',
#   ____________________________end_goals_overunder_under_10 = '5.95',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '17.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.01',
#   ____________________________end_goals_overunder_first_half_over_15 = '3.26',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.31',
#   ____________________________end_goals_overunder_first_half_over_25 = '8.80',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.05',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.49',
#   ____________________________end_goals_overunder_first_half_under_05 = '2.51',
#   ____________________________end_goals_overunder_first_half_over_225 = '8.20',
#   ____________________________end_goals_overunder_first_half_under_225 = '1.06',
#   ____________________________end_goals_overunder_first_half_over_125 = '2.73',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.42',
#   ____________________________end_goals_overunder_first_half_over_175 = '4.44',
#   ____________________________end_goals_overunder_first_half_under_175 = '1.18',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.70',
#   ____________________________end_goals_overunder_first_half_under_075 = '2.08',
#   ____________________________end_goals_overunder_first_half_over_20 = '7.60',
#   ____________________________end_goals_overunder_first_half_under_20 = '1.06',
#   ____________________________end_goals_overunder_first_half_over_10 = '2.16',
#   ____________________________end_goals_overunder_first_half_under_10 = '1.65',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '12.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.03',
#   ____________________________end_goals_overunder__second_half_over_15 = '2.45',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.51',
#   ____________________________end_goals_overunder__second_half_over_25 = '5.80',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.12',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.31',
#   ____________________________end_goals_overunder__second_half_under_05 = '3.26',
#   ____________________________end_goals_overunder__second_half_over_225 = '5.20',
#   ____________________________end_goals_overunder__second_half_under_225 = '1.14',
#   ____________________________end_goals_overunder__second_half_over_125 = '2.05',
#   ____________________________end_goals_overunder__second_half_under_125 = '1.72',
#   ____________________________end_goals_overunder__second_half_over_175 = '3.10',
#   ____________________________end_goals_overunder__second_half_under_175 = '1.34',
#   ____________________________end_goals_overunder__second_half_over_075 = '1.42',
#   ____________________________end_goals_overunder__second_half_under_075 = '2.74',
#   ____________________________end_goals_overunder__second_half_over_20 = '4.64',
#   ____________________________end_goals_overunder__second_half_under_20 = '1.17',
#   ____________________________end_goals_overunder__second_half_over_10 = '1.64',
#   ____________________________end_goals_overunder__second_half_under_10 = '2.18',
#   __________________________7 HT/FT Double
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '1.93',
#   ____________________________end_both_teams_score_no = '1.83',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 4.14
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.66
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.48
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.28
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.64
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 5.95
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.18
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -4 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -4 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -4 --- bets_odd: 23.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 4.32
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.51
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________________62 Correct Score - Second Half
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:0 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:0 --- bets_odd: 10.50
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:1 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:0 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:1 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:0 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:1 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:2 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:0 --- bets_odd: 3.26
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:1 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:2 --- bets_odd: 46.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:1 --- bets_odd: 5.40
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:2 --- bets_odd: 18.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:3 --- bets_odd: 64.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 0:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:2 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:3 --- bets_odd: 71.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 1:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:3 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 2:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:4 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 3:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 4:5 --- bets_odd: 100.00
#   ______________________  ______________________bet_id: 62 --- bets_value: 5:5 --- bets_odd: 100.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.28',
#   ____________________________end_double_chance_home_away = '1.31',
#   ____________________________end_double_chance_draw_away = '1.66',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '2.76',
#   ____________________________end_first_half_winner_draw = '1.96',
#   ____________________________end_first_half_winner_away = '4.30',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.03
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.36
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.52
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 5.60
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 0.5 --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 0.5 --- bets_odd: 3.30
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2 --- bets_odd: 3.96
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2 --- bets_odd: 1.19
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3 --- bets_odd: 10.50
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3 --- bets_odd: 1.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1 --- bets_odd: 1.58
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1 --- bets_odd: 2.23
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 3.30
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 9.60
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 0.5 --- bets_odd: 1.51
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 0.5 --- bets_odd: 2.40
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2 --- bets_odd: 7.80
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2 --- bets_odd: 1.05
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1 --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1 --- bets_odd: 1.60
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 8.60
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.33
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.68
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________33 Double Chance - Second Half
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Draw --- bets_odd: 1.18
#   ______________________  ______________________bet_id: 33 --- bets_value: Home/Away --- bets_odd: 1.49
#   ______________________  ______________________bet_id: 33 --- bets_value: Draw/Away --- bets_odd: 1.41
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.09
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.63
#   __________________________23 Home Odd/Even
#   ______________________  ______________________bet_id: 23 --- bets_value: Odd --- bets_odd: 1.93
#   ______________________  ______________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.74
#   __________________________60 Away Odd/Even
#   ______________________  ______________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.09
#   ______________________  ______________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.63
#   __________________________55 Corners 1x2
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 6.5 --- bets_odd: 1.26
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 6.5 --- bets_odd: 3.34
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 9.5 --- bets_odd: 2.60
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 9.5 --- bets_odd: 1.41
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 10.5 --- bets_odd: 3.64
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 10.5 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 7.5 --- bets_odd: 1.52
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 7.5 --- bets_odd: 2.30
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 8.5 --- bets_odd: 1.92
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 8.5 --- bets_odd: 1.75
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 7.75 --- bets_odd: 1.59
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 7.75 --- bets_odd: 2.16
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 7.25 --- bets_odd: 1.42
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 7.25 --- bets_odd: 2.57
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 8.25 --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 8.25 --- bets_odd: 1.86
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 9.25 --- bets_odd: 2.42
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 9.25 --- bets_odd: 1.47
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 8.75 --- bets_odd: 2.07
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 8.75 --- bets_odd: 1.64
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
#   ____________2. 2023-03-20 // 80 // 8 // 2022
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API herlambangharyo@gmail.com counter is 97
#   __________________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-20
#   __________________bookmaker : 8
#   __________________season : 2022
#   __________________league : 80
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. Germany,  3. Liga  #80 - 2022 / 879386
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '3.40',
#   ____________________________end_match_winner_draw = '3.10',
#   ____________________________end_match_winner_away = '2.00',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '2.50',
#   ____________________________end_homeaway_away = '1.50',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '3.40',
#   ____________________________end_second_half_winner_draw = '2.50',
#   ____________________________end_second_half_winner_away = '2.30',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '2.50',
#   ____________________________end_asian_handicap_away_plus_0 = '1.50',
#   ____________________________end_asian_handicap_home_min_025 = '3.00',
#   ____________________________end_asian_handicap_away_min_025 = '1.38',
#   ____________________________end_asian_handicap_home_plus_025 = '2.05',
#   ____________________________end_asian_handicap_away_plus_025 = '1.80',
#   ____________________________end_asian_handicap_home_min_05 = '3.45',
#   ____________________________end_asian_handicap_away_min_05 = '1.30',
#   ____________________________end_asian_handicap_home_plus_05 = '1.75',
#   ____________________________end_asian_handicap_away_plus_05 = '2.05',
#   ____________________________end_asian_handicap_home_min_075 = '4.40',
#   ____________________________end_asian_handicap_away_min_075 = '1.20',
#   ____________________________end_asian_handicap_home_plus_075 = '1.55',
#   ____________________________end_asian_handicap_away_plus_075 = '2.38',
#   ____________________________end_asian_handicap_home_min_1 = '6.40',
#   ____________________________end_asian_handicap_away_min_1 = '1.11',
#   ____________________________end_asian_handicap_home_plus_1 = '1.38',
#   ____________________________end_asian_handicap_away_plus_1 = '3.00',
#   ____________________________end_asian_handicap_home_min_15 = '7.00',
#   ____________________________end_asian_handicap_away_min_15 = '1.10',
#   ____________________________end_asian_handicap_home_plus_15 = '1.26',
#   ____________________________end_asian_handicap_away_plus_15 = '3.70',
#   ____________________________end_asian_handicap_home_min_125 = '7.00',
#   ____________________________end_asian_handicap_away_min_125 = '1.10',
#   ____________________________end_asian_handicap_home_plus_125 = '1.30',
#   ____________________________end_asian_handicap_away_plus_125 = '3.45',
#   ____________________________end_asian_handicap_home_plus_175 = '1.18',
#   ____________________________end_asian_handicap_away_plus_175 = '4.65',
#   ____________________________end_asian_handicap_home_plus_2 = '1.10',
#   ____________________________end_asian_handicap_away_plus_2 = '7.00',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '2.75',
#   ____________________________end_goals_overunder_under_35 = '1.40',
#   ____________________________end_goals_overunder_over_15 = '1.22',
#   ____________________________end_goals_overunder_under_15 = '4.00',
#   ____________________________end_goals_overunder_over_45 = '5.50',
#   ____________________________end_goals_overunder_under_45 = '1.14',
#   ____________________________end_goals_overunder_over_25 = '1.80',
#   ____________________________end_goals_overunder_under_25 = '2.00',
#   ____________________________end_goals_overunder_over_05 = '1.05',
#   ____________________________end_goals_overunder_under_05 = '11.00',
#   ____________________________end_goals_overunder_over_55 = '11.00',
#   ____________________________end_goals_overunder_under_55 = '1.05',
#   ____________________________end_goals_overunder_over_225 = '1.58',
#   ____________________________end_goals_overunder_under_225 = '2.35',
#   ____________________________end_goals_overunder_over_325 = '2.60',
#   ____________________________end_goals_overunder_under_325 = '1.48',
#   ____________________________end_goals_overunder_over_275 = '2.02',
#   ____________________________end_goals_overunder_under_275 = '1.83',
#   ____________________________end_goals_overunder_over_125 = '1.15',
#   ____________________________end_goals_overunder_under_125 = '5.50',
#   ____________________________end_goals_overunder_over_425 = '5.25',
#   ____________________________end_goals_overunder_under_425 = '1.16',
#   ____________________________end_goals_overunder_over_175 = '1.27',
#   ____________________________end_goals_overunder_under_175 = '3.55',
#   ____________________________end_goals_overunder_over_375 = '3.45',
#   ____________________________end_goals_overunder_under_375 = '1.30',
#   ____________________________end_goals_overunder_over_475 = '7.00',
#   ____________________________end_goals_overunder_under_475 = '1.10',
#   ____________________________end_goals_overunder_over_65 = '23.00',
#   ____________________________end_goals_overunder_under_65 = '1.01',
#   ____________________________end_goals_overunder_over_75 = '51.00',
#   ____________________________end_goals_overunder_under_75 = '1.00',
#   ____________________________end_goals_overunder_over_30 = '2.30',
#   ____________________________end_goals_overunder_under_30 = '1.60',
#   ____________________________end_goals_overunder_over_20 = '1.35',
#   ____________________________end_goals_overunder_under_20 = '3.10',
#   ____________________________end_goals_overunder_over_40 = '4.50',
#   ____________________________end_goals_overunder_under_40 = '1.19',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '19.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.02',
#   ____________________________end_goals_overunder_first_half_over_15 = '2.63',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.44',
#   ____________________________end_goals_overunder_first_half_over_25 = '7.00',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.10',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.36',
#   ____________________________end_goals_overunder_first_half_under_05 = '3.00',
#   ____________________________end_goals_overunder_first_half_over_225 = '6.00',
#   ____________________________end_goals_overunder_first_half_under_225 = '1.13',
#   ____________________________end_goals_overunder_first_half_over_125 = '2.25',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.63',
#   ____________________________end_goals_overunder_first_half_over_175 = '3.45',
#   ____________________________end_goals_overunder_first_half_under_175 = '1.30',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.50',
#   ____________________________end_goals_overunder_first_half_under_075 = '2.50',
#   ____________________________end_goals_overunder_first_half_over_20 = '5.50',
#   ____________________________end_goals_overunder_first_half_under_20 = '1.15',
#   ____________________________end_goals_overunder_first_half_over_10 = '1.77',
#   ____________________________end_goals_overunder_first_half_under_10 = '2.02',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '10.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.06',
#   ____________________________end_goals_overunder__second_half_over_15 = '1.91',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.80',
#   ____________________________end_goals_overunder__second_half_over_25 = '4.00',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.22',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.20',
#   ____________________________end_goals_overunder__second_half_under_05 = '4.33',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________end_clean_sheet__home_yes = '4.50',
#   ____________________________end_clean_sheet__home_no = '1.18',
#   __________________________28 Clean Sheet - Away
#   ____________________________end_clean_sheet__away_yes = '3.00',
#   ____________________________end_clean_sheet__away_no = '1.36',
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '1.62',
#   ____________________________end_both_teams_score_no = '2.20',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.29
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.67
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 8.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.08
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.07
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 12.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 19.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 251.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:4 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:4 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 126.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.67',
#   ____________________________end_double_chance_home_away = '1.33',
#   ____________________________end_double_chance_draw_away = '1.29',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '3.75',
#   ____________________________end_first_half_winner_draw = '2.25',
#   ____________________________end_first_half_winner_away = '2.63',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 2.40
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 1.62
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 2.40
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 1.62
#   __________________________32 Win Both Halves
#   ____________________________end_win_both_halves_home = '13.00',
#   ____________________________end_win_both_halves_away = '6.50',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.63
# ...
#   ____________________________end_goals_overunder_first_half_over_05 = '1.53',
#   ____________________________end_goals_overunder_first_half_under_05 = '2.38',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '17.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.03',
#   ____________________________end_goals_overunder__second_half_over_15 = '2.50',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.50',
#   ____________________________end_goals_overunder__second_half_over_25 = '6.00',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.13',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.33',
#   ____________________________end_goals_overunder__second_half_under_05 = '3.25',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________end_clean_sheet__home_yes = '3.00',
#   ____________________________end_clean_sheet__home_no = '1.36',
#   __________________________28 Clean Sheet - Away
#   ____________________________end_clean_sheet__away_yes = '2.50',
#   ____________________________end_clean_sheet__away_no = '1.50',
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '2.00',
#   ____________________________end_both_teams_score_no = '1.73',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 4.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.09
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +3 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +3 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +3 --- bets_odd: 29.00
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 19.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 101.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 81.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.50',
#   ____________________________end_double_chance_home_away = '1.33',
#   ____________________________end_double_chance_draw_away = '1.30',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '3.75',
#   ____________________________end_first_half_winner_draw = '1.91',
#   ____________________________end_first_half_winner_away = '3.10',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 1.83
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 1.83
#   __________________________32 Win Both Halves
#   ____________________________end_win_both_halves_home = '13.00',
#   ____________________________end_win_both_halves_away = '10.00',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 3.40
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.07
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.02
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 4.5 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 4.5 --- bets_odd: 1.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.10
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.25
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.36
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 3.75
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +2 --- bets_odd: 1.04
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +2 --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +3 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +3 --- bets_odd: 251.00
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________end_win_to_nil_home = '4.50',
#   ____________________________end_win_to_nil_away = '3.75',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.67
#   __________________________23 Home Odd/Even
#   ______________________  ______________________bet_id: 23 --- bets_value: Odd --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 23 --- bets_value: Even --- bets_odd: 1.67
#   __________________________60 Away Odd/Even
#   ______________________  ______________________bet_id: 60 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 60 --- bets_value: Even --- bets_odd: 1.73
#   __________________________39 To Win Either Half
#   ____________________________end_to_win_either_half_home = '2.00',
#   ____________________________end_to_win_either_half_away = '1.83',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________24 Results/Both Teams Score
#   ____________________________end_results_both_teams_score_home_yes = '7.00',
#   ____________________________end_results_both_teams_score_draw_yes = '4.50',
#   ____________________________end_results_both_teams_score_away_yes = '6.00',
#   ____________________________end_results_both_teams_score_home_no = '4.50',
#   ____________________________end_results_both_teams_score_draw_no = '7.00',
#   ____________________________end_results_both_teams_score_away_no = '3.75',
#   __________________________25 Result/Total Goals
#   ____________________________end_result_total_goals_home_over_25 = '6.00',
#   ____________________________end_result_total_goals_draw_over_25 = '15.00',
#   ____________________________end_result_total_goals_away_over_25 = '4.75',
#   ____________________________end_result_total_goals_home_under_25 = '5.50',
#   ____________________________end_result_total_goals_draw_under_25 = '3.50',
#   ____________________________end_result_total_goals_away_under_25 = '4.50',
#   __________________________63 Odd/Even - Second Half
#   ______________________  ______________________bet_id: 63 --- bets_value: Odd --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 63 --- bets_value: Even --- bets_odd: 1.73
#   __________________________48 To Score In Both Halves By Teams
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.19
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.45
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 2.68
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.55
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 3.70
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.26
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 1.70
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 4.15
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.22
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.85
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.40
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 3.45
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.58
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 2.35
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 5.90
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1 --- bets_odd: 5.75
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 0.75 --- bets_odd: 1.12
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 0.75 --- bets_odd: 6.25
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 3.55
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.28
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.38
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 4.80
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.18
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 2.35
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.58
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.78
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.03
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ________________________ff_update_unfinished__
#   ______________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-22 15:46:01

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-22 15:46:01
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-20
#   ______tgl_akhir : 2023-03-21
#   ________ff_get_fixture_status_match_finished()
#   __________Total Row(s) : 61
#   __________1. 2023-03-20 // 63 // 11 // 2022 // 914101 // 075_025_H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 914101
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-03-20 // 80 // 8 // 2022 // 879386 // 025+05+075+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 879386
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-03-20 // 128 // 8 // 2023 // 971437 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971437
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________4. 2023-03-20 // 128 // 8 // 2023 // 971440 // 05_025_0#H // 15g175g2gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971440
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 15g175g2gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________5. 2023-03-21 // 128 // 8 // 2023 // 971442 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971442
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________6. 2023-03-21 // 128 // 8 // 2023 // 971445 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 971445
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________7. 2023-03-20 // 128 // 8 // 2023 // 988711 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988711
#   ____________> end_ah_pattern = 05+075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_05_H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________8. 2023-03-20 // 132 // 11 // 2023 // 988065 // 025+075+H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988065
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 15g175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________9. 2023-03-20 // 132 // 11 // 2023 // 988071 // 025_0#H // 175g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 988071
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 175g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________10. 2023-03-20 // 133 // 11 // 2023 // 1004349 // 075_025_H // 175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1004349
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________11. 2023-03-20 // 133 // 11 // 2023 // 1004351 // 0#025+H // 15g175g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1004351
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 15g175g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________12. 2023-03-20 // 141 // 8 // 2022 // 878671 // 0#025+05+H // 175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 878671
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________13. 2023-03-20 // 173 // 11 // 2022 // 882799 // 025+075+H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 882799
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________14. 2023-03-20 // 173 // 11 // 2022 // 882803 // 025_0#H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 882803
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________15. 2023-03-20 // 204 // 8 // 2022 // 885005 // 025_0#025+05+H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 885005
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________16. 2023-03-20 // 205 // 11 // 2022 // 889094 // H // 2gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889094
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 2g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________17. 2023-03-20 // 205 // 11 // 2022 // 889461 // 275_25_225_2_175_15_H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 889461
#   ____________> end_ah_pattern = 275_25_225_2_175_15_H
#   ____________> end_ah_pattern_mirror = 15+175+2+225+25+275+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________18. 2023-03-20 // 239 // 8 // 2023 // 989354 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 989354
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________19. 2023-03-20 // 240 // 8 // 2023 // 989589 // 025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 989589
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________20. 2023-03-20 // 240 // 8 // 2023 // 989587 // 025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 989587
#   ____________> end_ah_pattern = 025_H
#   ____________> end_ah_pattern_mirror = 025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________21. 2023-03-20 // 240 // 8 // 2023 // 989586 // 025_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 989586
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________22. 2023-03-21 // 242 // 8 // 2023 // 996238 // 1_075_05_H // 2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 996238
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________23. 2023-03-20 // 250 // 8 // 2023 // 986901 // 075+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 986901
#   ____________> end_ah_pattern = 075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_H
#   ____________> end_gou_pattern = 225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________24. 2023-03-20 // 250 // 8 // 2023 // 986905 // 05_025_0#H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 986905
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________25. 2023-03-20 // 255 // 11 // 2023 // 1008365 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1008365
#   ____________> end_ah_pattern = 1_075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+1+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________26. 2023-03-20 // 262 // 8 // 2022 // 974411 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974411
#   ____________> end_ah_pattern = 05_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+05+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________27. 2023-03-20 // 262 // 8 // 2022 // 974412 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 974412
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________28. 2023-03-20 // 266 // 11 // 2023 // 987780 // 025_0#025+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 987780
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________29. 2023-03-20 // 266 // 11 // 2023 // 987783 // 025_0#025+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 987783
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________30. 2023-03-20 // 266 // 11 // 2023 // 987785 // 075_025_H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 987785
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________31. 2023-03-20 // 266 // 11 // 2023 // 987786 // 025_0#025+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 987786
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________32. 2023-03-20 // 268 // 8 // 2023 // 1003364 // 025_0#025+05+H // 2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1003364
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________33. 2023-03-20 // 274 // 11 // 2022 // 899799 // 15_125_1_075_H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 899799
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________34. 2023-03-20 // 281 // 8 // 2023 // 985146 // 15_125_1_075_05_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 985146
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________35. 2023-03-20 // 283 // 8 // 2022 // 1015114 // 1_075_05_H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1015114
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________36. 2023-03-20 // 318 // 8 // 2022 // 1014328 // 05_025_0#025+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1014328
#   ____________> end_ah_pattern = 05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________37. 2023-03-20 // 322 // 11 // 2022 // 968392 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 968392
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________38. 2023-03-20 // 361 // 11 // 2023 // 1011578 // 1+H // 25g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011578
#   ____________> end_ah_pattern = 075+1+125+15+175+H
#   ____________> end_ah_pattern_mirror = 175_15_125_1_075_H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________39. 2023-03-20 // 361 // 11 // 2023 // 1011579 // 0#H // 25g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011579
#   ____________> end_ah_pattern = 1_H
#   ____________> end_ah_pattern_mirror = 1+H
#   ____________> end_gou_pattern = 25g3g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________40. 2023-03-20 // 386 // 11 // 2022 // 1015654 // 025_0#025+H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1015654
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________41. 2023-03-20 // 429 // 11 // 2022 // 950650 // 025_0#025+H // 175g2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 950650
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________42. 2023-03-20 // 518 // 8 // 2022 // 913668 // 1+H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 913668
#   ____________> end_ah_pattern = 1+H
#   ____________> end_ah_pattern_mirror = 1_H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________43. 2023-03-20 // 518 // 8 // 2022 // 913670 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 913670
#   ____________> end_ah_pattern = H
#   ____________> end_ah_pattern_mirror = H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________44. 2023-03-20 // 518 // 8 // 2022 // 913671 // 05+H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 913671
#   ____________> end_ah_pattern = 05+H
#   ____________> end_ah_pattern_mirror = 05_H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________45. 2023-03-20 // 518 // 8 // 2022 // 913672 // 05_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 913672
#   ____________> end_ah_pattern = 05_H
#   ____________> end_ah_pattern_mirror = 05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________46. 2023-03-20 // 518 // 8 // 2022 // 913673 // 05_H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 913673
#   ____________> end_ah_pattern = 05_H
#   ____________> end_ah_pattern_mirror = 05+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________47. 2023-03-20 // 673 // 8 // 2022 // 976342 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 976342
#   ____________> end_ah_pattern = 075+1+H
#   ____________> end_ah_pattern_mirror = 1_075_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________48. 2023-03-20 // 673 // 8 // 2022 // 976343 // 0#H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 976343
#   ____________> end_ah_pattern = 025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________49. 2023-03-20 // 702 // 11 // 2022 // 924955 // 075_025_0#025+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 924955
#   ____________> end_ah_pattern = 075_025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+075+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________50. 2023-03-20 // 702 // 11 // 2022 // 925076 // 0#025+075+H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 925076
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________51. 2023-03-20 // 702 // 11 // 2022 // 925078 // 025_0#025+H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 925078
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________52. 2023-03-20 // 703 // 11 // 2022 // 948596 // 025_0#025+H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 948596
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________53. 2023-03-20 // 703 // 11 // 2022 // 948597 // 025_0#025+H // 25g275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 948597
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________54. 2023-03-20 // 703 // 11 // 2022 // 948598 // 025_0#025+H // 3g325g35g375g4g425gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 948598
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 325g35g375g4g425gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________55. 2023-03-20 // 703 // 11 // 2022 // 948599 // 025+075+1+125+H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 948599
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 3g325g35g375g4gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________56. 2023-03-20 // 887 // 11 // 2022 // 964796 // H // 15gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964796
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________57. 2023-03-20 // 887 // 11 // 2022 // 964797 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964797
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________58. 2023-03-20 // 887 // 11 // 2022 // 964798 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964798
#   ____________> end_ah_pattern = 075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________59. 2023-03-20 // 887 // 11 // 2022 // 964800 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 964800
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________60. 2023-03-20 // 931 // 11 // 2022 // 912420 // 025_0#025+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 912420
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________61. 2023-03-20 // 942 // 8 // 2022 // 952733 // 0#025+05+H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 952733
#   ____________> end_ah_pattern = 0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
# # -------------------------------------------------- End at 2023-03-22 15:50:05

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-22 15:50:05
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-20
#   ______tgl_akhir : 2023-03-21
#   ________ff_get_fixture_status_match_finished_for_daily_update_patternlist()
#   ________Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date <= '2023-03-21'  and date >= '2023-03-20'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 62
#   ____________[1/62] #882799 #Bulgaria 173-2022 / Spartak Pleven vs Levski Krumovgrad
#   ____________pre-ah:025+075+H -- pre-gou:175g2g225g25g275gG -/- end-ah:025+075+H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:28
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '173'  and league_country = 'Bulgaria'  and pre_ah_pattern = '025+075+H'  and pre_ah_pattern_mirror = '075_025_H'  and pre_gou_pattern = '175g2g225g25g275gG'  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[2/62] #882803 #Bulgaria 173-2022 / Belasitsa vs Sportist Svoge
#   ____________pre-ah:025_0#H -- pre-gou:175g2g225g25gG -/- end-ah:025_0#H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:29
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '173'  and league_country = 'Bulgaria'  and pre_ah_pattern = '025_0#H'  and pre_ah_pattern_mirror = '0#025+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '025_0#H'  and end_ah_pattern_mirror = '0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[3/62] #879386 #Germany 80-2022 / FC Ingolstadt 04 vs Dynamo Dresden
#   ____________pre-ah:025+05+075+H -- pre-gou:225g25g275g3gG -/- end-ah:025+05+075+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:42:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '80'  and league_country = 'Germany'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 5
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 5
#   ____________________patternlists updated
#
#   ____________[4/62] #914101 #France 63-2022 / Le Mans vs Versailles
#   ____________pre-ah:075_025_H -- pre-gou:175g2g225g25gG -/- end-ah:075_025_H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:42:54
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '63'  and league_country = 'France'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 11
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 11
#   ____________________patternlists updated
#
#   ____________[5/62] #899799 #Indonesia 274-2022 / Persib Bandung vs Dewa United
#   ____________pre-ah:15_125_1_075_H -- pre-gou:225g25g275g3g325gG -/- end-ah:15_125_1_075_H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:28
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '274'  and league_country = 'Indonesia'  and pre_ah_pattern = '15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[6/62] #885005 #Turkey 204-2022 / Sakaryaspor vs BB Bodrumspor
#   ____________pre-ah:025_0#025+05+H -- pre-gou:225g25g275gG -/- end-ah:025_0#025+05+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:33
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '204'  and league_country = 'Turkey'  and pre_ah_pattern = '025_0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#025+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[7/62] #878671 #Spain 141-2022 / Mirandes vs Eibar
#   ____________pre-ah:0#025+05+H -- pre-gou:175g2g225gG -/- end-ah:0#025+05+H -- end-gou:175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:24
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '141'  and league_country = 'Spain'  and pre_ah_pattern = '0#025+05+H'  and pre_ah_pattern_mirror = '05_025_0#H'  and pre_gou_pattern = '175g2g225gG'  and end_ah_pattern = '0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#H'  and end_gou_pattern = '175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[8/62] #950650 #Italy 429-2022 / Crema vs United Riccione
#   ____________pre-ah:025_0#025+H -- pre-gou:175g2g225g25g275gG -/- end-ah:025_0#025+H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '429'  and league_country = 'Italy'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '175g2g225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[9/62] #948596 #England 703-2022 / Sheffield Wednesday U21 vs Birmingham City U21
#   ____________pre-ah:025_0#025+H -- pre-gou:275g3g325g35g375gG -/- end-ah:025_0#025+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:36
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '703'  and league_country = 'England'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[10/62] #948597 #England 703-2022 / Wigan Athletic U21 vs Hull City U21
#   ____________pre-ah:025_0#025+H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:025_0#025+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '703'  and league_country = 'England'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[11/62] #948598 #England 703-2022 / Charlton Athletic U21 vs Bristol City U21
#   ____________pre-ah:025_0#025+H -- pre-gou:3g325g35g375g4g425gG -/- end-ah:025_0#025+H -- end-gou:325g35g375g4g425gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '703'  and league_country = 'England'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '3g325g35g375g4g425gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '325g35g375g4g425gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[12/62] #948599 #England 703-2022 / Watford U21 vs Queens Park Rangers U21
#   ____________pre-ah:025+075+1+125+H -- pre-gou:275g3g325g35g375gG -/- end-ah:0#025+075+H -- end-gou:3g325g35g375g4gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:42
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '703'  and league_country = 'England'  and pre_ah_pattern = '025+075+1+125+H'  and pre_ah_pattern_mirror = '125_1_075_025_H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '3g325g35g375g4gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[13/62] #924955 #England 702-2022 / Wolves U21 vs West Ham United U21
#   ____________pre-ah:075_025_0#025+H -- pre-gou:25g275g3g325g35gG -/- end-ah:075_025_0#025+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:29
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '702'  and league_country = 'England'  and pre_ah_pattern = '075_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+075+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '075_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+075+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[14/62] #925076 #England 702-2022 / Derby County U21 vs Stoke City U21
#   ____________pre-ah:0#025+075+H -- pre-gou:275g3g325g35g375gG -/- end-ah:0#025+075+H -- end-gou:275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:30
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '702'  and league_country = 'England'  and pre_ah_pattern = '0#025+075+H'  and pre_ah_pattern_mirror = '075_025_0#H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[15/62] #925078 #England 702-2022 / West Bromwich Albion U21 vs Norwich City U21
#   ____________pre-ah:025_0#025+H -- pre-gou:25g275g3g325g35g375gG -/- end-ah:025_0#025+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:33
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '702'  and league_country = 'England'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25g275g3g325g35g375gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 6
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 6
#   ____________________patternlists updated
#
#   ____________[16/62] #889094 #Turkey 205-2022 / Batman Petrolspor vs Amed
#   ____________pre-ah:H -- pre-gou:2gG -/- end-ah:H -- end-gou:2g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:35
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '205'  and league_country = 'Turkey'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '2gG'  and end_ah_pattern = 'H'  and end_ah_pattern_mirror = 'H'  and end_gou_pattern = '2g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[17/62] #889461 #Turkey 205-2022 / Kocaelispor vs Pazarspor
#   ____________pre-ah:275_25_225_2_175_15_H -- pre-gou:275g3g325g35g375gG -/- end-ah:275_25_225_2_175_15_H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '205'  and league_country = 'Turkey'  and pre_ah_pattern = '275_25_225_2_175_15_H'  and pre_ah_pattern_mirror = '15+175+2+225+25+275+H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '275_25_225_2_175_15_H'  and end_ah_pattern_mirror = '15+175+2+225+25+275+H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[18/62] #964796 #Egypt 887-2022 / Aluminium Nag Hammadi vs Shoban Moslemen Qena
#   ____________pre-ah:H -- pre-gou:15gG -/- end-ah:075_025_H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:49
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '887'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '15gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[19/62] #964797 #Egypt 887-2022 / Misr EL Makasa vs Fayoum
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:15_125_1_075_H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:46
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '887'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[20/62] #964798 #Egypt 887-2022 / El Madina El Monowara vs Al Nasr Taaden
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075+1+125+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:53
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '887'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[21/62] #964800 #Egypt 887-2022 / La Viena FC vs Asyut Petrol
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_025_H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '887'  and league_country = 'Egypt'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[22/62] #913668 #Belgium 518-2022 / Waasland-Beveren U21 vs KV Oostende U21
#   ____________pre-ah:1+H -- pre-gou:G -/- end-ah:1+H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '518'  and league_country = 'Belgium'  and pre_ah_pattern = '1+H'  and pre_ah_pattern_mirror = '1_H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '1+H'  and end_ah_pattern_mirror = '1_H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[23/62] #913670 #Belgium 518-2022 / Sint-Truiden U21 vs AS Eupen U21
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:20
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '518'  and league_country = 'Belgium'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = 'H'  and end_ah_pattern_mirror = 'H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[24/62] #913671 #Belgium 518-2022 / Deinze U21 vs Lommel U21
#   ____________pre-ah:05+H -- pre-gou:G -/- end-ah:05+H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:10
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '518'  and league_country = 'Belgium'  and pre_ah_pattern = '05+H'  and pre_ah_pattern_mirror = '05_H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05+H'  and end_ah_pattern_mirror = '05_H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[25/62] #913672 #Belgium 518-2022 / Westerlo U21 vs Excelsior Virton U21
#   ____________pre-ah:05_H -- pre-gou:25gG -/- end-ah:05_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '518'  and league_country = 'Belgium'  and pre_ah_pattern = '05_H'  and pre_ah_pattern_mirror = '05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_H'  and end_ah_pattern_mirror = '05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[26/62] #913673 #Belgium 518-2022 / RWDM U21 vs Dender U21
#   ____________pre-ah:05_H -- pre-gou:G -/- end-ah:05_H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:15
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '518'  and league_country = 'Belgium'  and pre_ah_pattern = '05_H'  and pre_ah_pattern_mirror = '05+H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_H'  and end_ah_pattern_mirror = '05+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[27/62] #974411 #Mexico 262-2022 / Club Queretaro vs FC Juarez
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05_025_0#025+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '262'  and league_country = 'Mexico'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+05+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[28/62] #974412 #Mexico 262-2022 / Leon vs Santos Laguna
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:04
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '262'  and league_country = 'Mexico'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[29/62] #989589 #Colombia 240-2023 / Barranquilla vs Patriotas
#   ____________pre-ah:025+H -- pre-gou:25gG -/- end-ah:025+05+075+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '240'  and league_country = 'Colombia'  and pre_ah_pattern = '025+H'  and pre_ah_pattern_mirror = '025_H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[30/62] #989587 #Colombia 240-2023 / Fortaleza FC vs Llaneros
#   ____________pre-ah:025_H -- pre-gou:25gG -/- end-ah:025_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:43
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '240'  and league_country = 'Colombia'  and pre_ah_pattern = '025_H'  and pre_ah_pattern_mirror = '025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_H'  and end_ah_pattern_mirror = '025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[31/62] #989586 #Colombia 240-2023 / Cucuta vs Quindio
#   ____________pre-ah:025_H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:45
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '240'  and league_country = 'Colombia'  and pre_ah_pattern = '025_H'  and pre_ah_pattern_mirror = '025+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[32/62] #912420 #England 931-2022 / Stourbridge vs Coalville Town
#   ____________pre-ah:025_0#025+H -- pre-gou:25g275g3g325g35gG -/- end-ah:025_0#025+H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '931'  and league_country = 'England'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 9
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 9
#   ____________________patternlists updated
#
#   ____________[33/62] #968392 #Jamaica 322-2022 / Molynes United vs Chapelton
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_025_0#H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:43
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '322'  and league_country = 'Jamaica'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_025_0#H'  and end_ah_pattern_mirror = '0#025+075+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[34/62] #976342 #Mexico 673-2022 / Necaxa W vs Tijuana W
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075+1+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:24
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '673'  and league_country = 'Mexico'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075+1+H'  and end_ah_pattern_mirror = '1_075_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[35/62] #976343 #Mexico 673-2022 / Santos Laguna W vs Toluca W
#   ____________pre-ah:0#H -- pre-gou:25gG -/- end-ah:025_0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:45:26
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '673'  and league_country = 'Mexico'  and pre_ah_pattern = '0#H'  and pre_ah_pattern_mirror = '0#H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '025_0#H'  and end_ah_pattern_mirror = '0#025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[36/62] #989354 #Colombia 239-2023 / Independiente Medellin vs Jaguares
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:1_075_05_025_H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '239'  and league_country = 'Colombia'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[37/62] #971437 #Argentina 128-2023 / Talleres Cordoba vs Banfield
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:02
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '128'  and league_country = 'Argentina'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 4
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 4
#   ____________________patternlists updated
#
#   ____________[38/62] #971440 #Argentina 128-2023 / Newells Old Boys vs San Lorenzo
#   ____________pre-ah:05_025_0#H -- pre-gou:15g175g2gG -/- end-ah:05_025_0#H -- end-gou:15g175g2gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:04
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '128'  and league_country = 'Argentina'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '15g175g2gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '15g175g2gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[39/62] #971442 #Argentina 128-2023 / Huracan vs Rosario Central
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:125_1_075_05_H -- end-gou:175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:10
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '128'  and league_country = 'Argentina'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[40/62] #971445 #Argentina 128-2023 / Lanus vs Argentinos JRS
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_0#025+H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '128'  and league_country = 'Argentina'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[41/62] #988711 #Argentina 128-2023 / Sarmiento Junin vs River Plate
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05+075+1+H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '128'  and league_country = 'Argentina'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05+075+1+H'  and end_ah_pattern_mirror = '1_075_05_H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[42/62] #986901 #Paraguay 250-2023 / General Caballero vs Cerro Porteno
#   ____________pre-ah:075+H -- pre-gou:25gG -/- end-ah:075+1+H -- end-gou:225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '250'  and league_country = 'Paraguay'  and pre_ah_pattern = '075+H'  and pre_ah_pattern_mirror = '075_H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '075+1+H'  and end_ah_pattern_mirror = '1_075_H'  and end_gou_pattern = '225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[43/62] #986905 #Paraguay 250-2023 / Tacuary vs Resistencia
#   ____________pre-ah:05_025_0#H -- pre-gou:225g25g275gG -/- end-ah:05_025_0#H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:54
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '250'  and league_country = 'Paraguay'  and pre_ah_pattern = '05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
# ...
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[49/62] #996239 #Ecuador 242-2023 / Emelec vs Tecnico Universitario
#   ____________pre-ah:175_15_125_1_H -- pre-gou:2g225g25g275gG -/- end-ah:None -- end-gou:None
#   ____________Match Finished -- end_odd_updated_at:2023-03-21 04:20:57
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '242'  and league_country = 'Ecuador'  and pre_ah_pattern = '175_15_125_1_H'  and pre_ah_pattern_mirror = '1+125+15+175+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = Null  and end_ah_pattern_mirror = Null  and end_gou_pattern = Null  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[50/62] #996238 #Ecuador 242-2023 / Deportivo Cuenca vs Cumbayá
#   ____________pre-ah:1_075_05_H -- pre-gou:2g225g25gG -/- end-ah:125_1_075_05_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '242'  and league_country = 'Ecuador'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '2g225g25gG'  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[51/62] #987780 #Chile 266-2023 / Universidad de Concepcion vs Deportes Iquique
#   ____________pre-ah:025_0#025+H -- pre-gou:2g225g25g275gG -/- end-ah:025_0#025+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:13
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '266'  and league_country = 'Chile'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 8
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 8
#   ____________________patternlists updated
#
#   ____________[52/62] #987783 #Chile 266-2023 / San Marcos de Arica vs San Luis
#   ____________pre-ah:025_0#025+H -- pre-gou:2g225g25g275gG -/- end-ah:025_0#025+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '266'  and league_country = 'Chile'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 8
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 8
#   ____________________patternlists updated
#
#   ____________[53/62] #987785 #Chile 266-2023 / D. Puerto Montt vs Deportes Santa Cruz
#   ____________pre-ah:075_025_H -- pre-gou:15g175g2g225gG -/- end-ah:075_025_H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:17
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '266'  and league_country = 'Chile'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '15g175g2g225gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[54/62] #987786 #Chile 266-2023 / Barnechea vs Rangers de Talca
#   ____________pre-ah:025_0#025+H -- pre-gou:2g225g25g275gG -/- end-ah:025_0#H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:10
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '266'  and league_country = 'Chile'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '025_0#H'  and end_ah_pattern_mirror = '0#025+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[55/62] #1004349 #Argentina 133-2023 / Defensores de Cambaceres vs Sportivo Barracas
#   ____________pre-ah:075_025_H -- pre-gou:175g2g225gG -/- end-ah:075_025_H -- end-gou:175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:19
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '133'  and league_country = 'Argentina'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '175g2g225gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[56/62] #1004351 #Argentina 133-2023 / Deportivo Muñiz vs Argentino Rosario
#   ____________pre-ah:0#025+H -- pre-gou:15g175g225g25gG -/- end-ah:0#025+H -- end-gou:15g175g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:43:21
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '133'  and league_country = 'Argentina'  and pre_ah_pattern = '0#025+H'  and pre_ah_pattern_mirror = '025_0#H'  and pre_gou_pattern = '15g175g225g25gG'  and end_ah_pattern = '0#025+H'  and end_ah_pattern_mirror = '025_0#H'  and end_gou_pattern = '15g175g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[57/62] #1011578 #Lithuania 361-2023 / FA Šiauliai II vs Be1 NFA
#   ____________pre-ah:1+H -- pre-gou:25g3gG -/- end-ah:075+1+125+15+175+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '361'  and league_country = 'Lithuania'  and pre_ah_pattern = '1+H'  and pre_ah_pattern_mirror = '1_H'  and pre_gou_pattern = '25g3gG'  and end_ah_pattern = '075+1+125+15+175+H'  and end_ah_pattern_mirror = '175_15_125_1_075_H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[58/62] #1011579 #Lithuania 361-2023 / Ekranas vs Kauno Žalgiris II
#   ____________pre-ah:0#H -- pre-gou:25g3gG -/- end-ah:1_H -- end-gou:25g3g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:50
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '361'  and league_country = 'Lithuania'  and pre_ah_pattern = '0#H'  and pre_ah_pattern_mirror = '0#H'  and pre_gou_pattern = '25g3gG'  and end_ah_pattern = '1_H'  and end_ah_pattern_mirror = '1+H'  and end_gou_pattern = '25g3g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[59/62] #1014328 #Cyprus 318-2022 / Aris vs AEK Larnaca
#   ____________pre-ah:05_025_0#025+H -- pre-gou:25gG -/- end-ah:05_025_0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '318'  and league_country = 'Cyprus'  and pre_ah_pattern = '05_025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+05+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[60/62] #1015114 #Romania 283-2022 / Universitatea Cluj vs Arges Pitesti
#   ____________pre-ah:1_075_05_H -- pre-gou:175g2g225g25gG -/- end-ah:1_075_05_H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:36
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '283'  and league_country = 'Romania'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[61/62] #1015654 #Ivory-Coast 386-2022 / ES Bafing vs Denguélé
#   ____________pre-ah:025_0#025+H -- pre-gou:15g175g2g225gG -/- end-ah:025_0#025+H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-22 15:44:55
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '386'  and league_country = 'Ivory-Coast'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '15g175g2g225gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[62/62] #1008365 #USA 255-2023 / Rio Grande Valley vs Oakland Roots
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:1_075_025_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-21 13:45:53
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '255'  and league_country = 'USA'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '1_075_025_H'  and end_ah_pattern_mirror = '025+075+1+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
# # -------------------------------------------------- End at 2023-03-22 15:58:19
