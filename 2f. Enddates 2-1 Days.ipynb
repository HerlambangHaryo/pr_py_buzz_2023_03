# %%
# Import
from a_settings.messages import *  

today = datetime.datetime.now()  
days0 = 2
days1 = 1
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 2 - 1 --> 2023-03-25 02:28:18.756181

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    ff_get_group_league_status_match_finished(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 02:28:18
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-23
#   ______tgl_akhir : 2023-03-24
#   ________ff_get_group_league_status_match_finished()
#   ________Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where date <= '2023-03-24'  and date >= '2023-03-23'  and fixture_status like 'Match Finished'  and deleted_at is null  and end_odd_updated_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 19
#   ____________ff_get_fixture_status_match_finished()
#   ______________Total Row(s) : 75
#   ______________1. 2023-03-23 // 10 // 8 // 2023 // 984805 // 175_15_125_1_H // 225g25g275gG
#   ______________2. 2023-03-23 // 10 // 8 // 2023 // 1012325 // 1_075_05_H // 175g2g225g25gG
#   ______________3. 2023-03-23 // 10 // 8 // 2023 // 1012369 // 1_075_05_H // 2g225g25g275gG
#   ______________4. 2023-03-23 // 10 // 8 // 2023 // 1012370 // 1_075_05_H // 2g225g25gG
#   ______________5. 2023-03-23 // 10 // 8 // 2023 // 1012323 // None // None
#   ______________6. 2023-03-23 // 10 // 8 // 2023 // 1012324 // None // None
#   ______________7. 2023-03-23 // 10 // 8 // 2023 // 1014508 // None // None
#   ______________8. 2023-03-23 // 10 // 8 // 2023 // 1014777 // None // None
#   ______________9. 2023-03-23 // 36 // 0 // 2023 // 859171 // H // G
#   ______________10. 2023-03-23 // 36 // 0 // 2023 // 859172 // H // G
#   ______________11. 2023-03-23 // 36 // 0 // 2023 // 859173 // H // G
#   ______________12. 2023-03-23 // 36 // 0 // 2023 // 859176 // H // G
#   ______________13. 2023-03-23 // 36 // 0 // 2023 // 859178 // H // G
#   ______________14. 2023-03-23 // 36 // 0 // 2023 // 859180 // H // G
#   ______________15. 2023-03-23 // 239 // 8 // 2023 // 987696 // H // G
#   ______________16. 2023-03-23 // 239 // 8 // 2023 // 989296 // 075_05_025_H // 175g2g225gG
#   ______________17. 2023-03-23 // 263 // 8 // 2022 // 975966 // H // G
#   ______________18. 2023-03-23 // 263 // 8 // 2022 // 975967 // H // G
#   ______________19. 2023-03-23 // 263 // 8 // 2022 // 975968 // 15_125_H // 25gG
#   ______________20. 2023-03-23 // 287 // 11 // 2022 // 869174 // 1_075_025_H // 2g225g25g275gG
#   ______________21. 2023-03-23 // 287 // 11 // 2022 // 869176 // 075_025_H // 15g175g2g225g25gG
#   ______________22. 2023-03-23 // 287 // 11 // 2022 // 869177 // 025_0#025+H // 175g2g225g25gG
#   ______________23. 2023-03-23 // 287 // 11 // 2022 // 869178 // 075_025_H // 15g175g2g225gG
#   ______________24. 2023-03-23 // 287 // 11 // 2022 // 898111 // 075_025_H // 15g175g2g225g25gG
#   ______________25. 2023-03-23 // 361 // 11 // 2023 // 1011580 // 0#H // 25g3gG
#   ______________26. 2023-03-23 // 496 // 11 // 2022 // 934837 // H // 25gG
#   ______________27. 2023-03-23 // 496 // 11 // 2022 // 934839 // 1_075_025_H // 225g25g275g3gG
#   ______________28. 2023-03-23 // 496 // 11 // 2022 // 934841 // 025_0#025+H // 2g225g25g275gG
#   ______________29. 2023-03-24 // 536 // 8 // 2022 // 856816 // 175+2+225+25+H // 275g3g325g35g375gG
#   ______________30. 2023-03-23 // 536 // 8 // 2022 // 856856 // 075+1+125+15+H // 225g25g275g3g325gG
#   ______________31. 2023-03-23 // 536 // 8 // 2022 // 856857 // 175_15_125_1_H // 225g25g275g3g325gG
#   ______________32. 2023-03-23 // 536 // 8 // 2022 // 856861 // 075_05_025_H // 225g25g275g3gG
#   ______________33. 2023-03-23 // 536 // 8 // 2022 // 856892 // H // G
#   ______________34. 2023-03-23 // 536 // 8 // 2022 // 856893 // H // G
#   ______________35. 2023-03-23 // 604 // 8 // 2023 // 1015129 // 075_05_025_H // 15gG
#   ______________36. 2023-03-24 // 604 // 8 // 2023 // 1015127 // None // None
#   ______________37. 2023-03-23 // 667 // 8 // 2023 // 999298 // 175_15_125_H // G
#   ______________38. 2023-03-23 // 667 // 8 // 2023 // 1008045 // H // G
#   ______________39. 2023-03-23 // 667 // 8 // 2023 // 1014212 // 125_H // 25gG
#   ______________40. 2023-03-23 // 667 // 8 // 2023 // 1017674 // None // None
#   ______________41. 2023-03-23 // 667 // 8 // 2023 // 1017698 // None // None
#   ______________42. 2023-03-23 // 667 // 8 // 2023 // 1017699 // None // None
#   ______________43. 2023-03-23 // 667 // 8 // 2023 // 1017700 // None // None
#   ______________44. 2023-03-23 // 667 // 8 // 2023 // 1017701 // None // None
#   ______________45. 2023-03-23 // 667 // 8 // 2023 // 1017702 // None // None
#   ______________46. 2023-03-23 // 667 // 8 // 2023 // 1017703 // None // None
#   ______________47. 2023-03-23 // 667 // 8 // 2023 // 1017705 // None // None
#   ______________48. 2023-03-23 // 667 // 8 // 2023 // 1017707 // None // None
#   ______________49. 2023-03-23 // 667 // 8 // 2023 // 1017708 // None // None
#   ______________50. 2023-03-23 // 667 // 8 // 2023 // 1017709 // None // None
#   ______________51. 2023-03-23 // 667 // 8 // 2023 // 1017710 // None // None
#   ______________52. 2023-03-23 // 667 // 8 // 2023 // 1017712 // None // None
#   ______________53. 2023-03-23 // 667 // 8 // 2023 // 1017714 // None // None
#   ______________54. 2023-03-23 // 667 // 8 // 2023 // 1017716 // None // None
#   ______________55. 2023-03-23 // 667 // 8 // 2023 // 1017717 // None // None
#   ______________56. 2023-03-23 // 667 // 8 // 2023 // 1017718 // None // None
#   ______________57. 2023-03-23 // 667 // 8 // 2023 // 1017786 // None // None
#   ______________58. 2023-03-23 // 677 // 11 // 2022 // 967076 // 025_0#025+H // 25g275g3g325gG
#   ______________59. 2023-03-23 // 677 // 11 // 2022 // 967075 // None // None
#   ______________60. 2023-03-23 // 701 // 11 // 2022 // 992370 // 025_0#025+H // 225g25g275g3gG
#   ______________61. 2023-03-23 // 703 // 11 // 2022 // 948587 // 025+075+H // 25g275g3g325g35gG
#   ______________62. 2023-03-23 // 740 // 11 // 2023 // 1010651 // 025+075+H // 2g225g25g275gG
#   ______________63. 2023-03-23 // 740 // 11 // 2023 // 1010653 // 075_05_025_0#H // 225g25g275g3g325g35gG
#   ______________64. 2023-03-23 // 740 // 11 // 2023 // 1010654 // 175_15_125_1_075_H // 25g275g3g325g35gG
#   ______________65. 2023-03-23 // 890 // 8 // 2022 // 1017408 // None // None
#   ______________66. 2023-03-23 // 890 // 8 // 2022 // 1017409 // None // None
#   ______________67. 2023-03-23 // 892 // 11 // 2022 // 1013652 // 075_025_0#H // 2g225g25g275gG
#   ______________68. 2023-03-23 // 960 // 8 // 2023 // 980456 // 025+05+075+H // 175g2g225g25gG
#   ______________69. 2023-03-23 // 960 // 8 // 2023 // 980457 // 025_0#025+H // 175g2g225g25gG
#   ______________70. 2023-03-23 // 960 // 8 // 2023 // 980458 // 175_15_125_1_H // 225g25g275gG
#   ______________71. 2023-03-23 // 960 // 8 // 2023 // 980459 // 175_15_125_H // 2g225g25g275gG
#   ______________72. 2023-03-23 // 960 // 8 // 2023 // 980460 // 225+25+275+3+325+H // 275g3g325g35g375gG
#   ______________73. 2023-03-23 // 960 // 8 // 2023 // 980461 // 575_55_525_H // 55g575g6g625g65g675gG
#   ______________74. 2023-03-23 // 960 // 8 // 2023 // 980462 // 125_1_075_05_H // 225g25g275gG
#   ______________75. 2023-03-23 // 960 // 8 // 2023 // 980463 // 1_075_05_025_H // 2g225g25gG
#   __________Are you sure want to continue? :  yes
#   ____________1. 2023-03-23 // 10 // 8 // 2023
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API digitalmedia.arion@gmail.com counter is 75
#   __________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________date : 2023-03-23
#   __________________bookmaker : 8
#   __________________season : 2023
#   __________________league : 10
#   __________________page : 1
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 5
#
#   ____________________1. World,  Friendlies  #10 - 2023 / 1012325
#   ____________________good to Go 1
#   __________________________1 Match Winner
#   ____________________________end_match_winner_home = '1.70',
#   ____________________________end_match_winner_draw = '3.50',
#   ____________________________end_match_winner_away = '5.50',
#   __________________________2 Home/Away
#   ____________________________end_homeaway_home = '1.25',
#   ____________________________end_homeaway_away = '3.75',
#   __________________________3 Second Half Winner
#   ____________________________end_second_half_winner_home = '2.05',
#   ____________________________end_second_half_winner_draw = '2.38',
#   ____________________________end_second_half_winner_away = '5.00',
#   __________________________4 Asian Handicap
#   ____________________________end_asian_handicap_home_plus_0 = '1.26',
#   ____________________________end_asian_handicap_away_plus_0 = '3.70',
#   ____________________________end_asian_handicap_home_min_025 = '1.48',
#   ____________________________end_asian_handicap_away_min_025 = '2.60',
#   ____________________________end_asian_handicap_home_plus_025 = '1.20',
#   ____________________________end_asian_handicap_away_plus_025 = '4.40',
#   ____________________________end_asian_handicap_home_min_05 = '1.70',
#   ____________________________end_asian_handicap_away_min_05 = '2.10',
#   ____________________________end_asian_handicap_home_plus_05 = '1.17',
#   ____________________________end_asian_handicap_away_plus_05 = '5.00',
#   ____________________________end_asian_handicap_home_min_075 = '1.95',
#   ____________________________end_asian_handicap_away_min_075 = '1.90',
#   ____________________________end_asian_handicap_home_plus_075 = '1.10',
#   ____________________________end_asian_handicap_away_plus_075 = '7.00',
#   ____________________________end_asian_handicap_home_min_1 = '2.30',
#   ____________________________end_asian_handicap_away_min_1 = '1.60',
#   ____________________________end_asian_handicap_home_min_15 = '3.00',
#   ____________________________end_asian_handicap_away_min_15 = '1.38',
#   ____________________________end_asian_handicap_home_min_125 = '2.67',
#   ____________________________end_asian_handicap_away_min_125 = '1.45',
#   ____________________________end_asian_handicap_home_min_175 = '3.80',
#   ____________________________end_asian_handicap_away_min_175 = '1.25',
#   ____________________________end_asian_handicap_home_min_2 = '5.75',
#   ____________________________end_asian_handicap_away_min_2 = '1.14',
#   ____________________________end_asian_handicap_home_min_25 = '6.60',
#   ____________________________end_asian_handicap_away_min_25 = '1.11',
#   ____________________________end_asian_handicap_home_min_225 = '6.00',
#   ____________________________end_asian_handicap_away_min_225 = '1.13',
#   __________________________5 Goals Over/Under
#   ____________________________end_goals_overunder_over_35 = '4.33',
#   ____________________________end_goals_overunder_under_35 = '1.20',
#   ____________________________end_goals_overunder_over_15 = '1.40',
#   ____________________________end_goals_overunder_under_15 = '2.75',
#   ____________________________end_goals_overunder_over_45 = '10.00',
#   ____________________________end_goals_overunder_under_45 = '1.06',
#   ____________________________end_goals_overunder_over_25 = '2.30',
#   ____________________________end_goals_overunder_under_25 = '1.60',
#   ____________________________end_goals_overunder_over_05 = '1.08',
#   ____________________________end_goals_overunder_under_05 = '7.50',
#   ____________________________end_goals_overunder_over_55 = '21.00',
#   ____________________________end_goals_overunder_under_55 = '1.02',
#   ____________________________end_goals_overunder_over_225 = '2.05',
#   ____________________________end_goals_overunder_under_225 = '1.80',
#   ____________________________end_goals_overunder_over_325 = '3.90',
#   ____________________________end_goals_overunder_under_325 = '1.24',
#   ____________________________end_goals_overunder_over_275 = '2.67',
#   ____________________________end_goals_overunder_under_275 = '1.45',
#   ____________________________end_goals_overunder_over_125 = '1.27',
#   ____________________________end_goals_overunder_under_125 = '3.55',
#   ____________________________end_goals_overunder_over_175 = '1.52',
#   ____________________________end_goals_overunder_under_175 = '2.42',
#   ____________________________end_goals_overunder_over_375 = '5.75',
#   ____________________________end_goals_overunder_under_375 = '1.14',
#   ____________________________end_goals_overunder_over_65 = '51.00',
#   ____________________________end_goals_overunder_under_65 = '1.00',
#   ____________________________end_goals_overunder_over_075 = '1.10',
#   ____________________________end_goals_overunder_under_075 = '7.00',
#   ____________________________end_goals_overunder_over_30 = '3.45',
#   ____________________________end_goals_overunder_under_30 = '1.30',
#   ____________________________end_goals_overunder_over_20 = '1.70',
#   ____________________________end_goals_overunder_under_20 = '2.10',
#   ____________________________end_goals_overunder_over_10 = '1.12',
#   ____________________________end_goals_overunder_under_10 = '6.25',
#   __________________________6 Goals Over/Under First Half
#   ____________________________end_goals_overunder_first_half_over_35 = '26.00',
#   ____________________________end_goals_overunder_first_half_under_35 = '1.01',
#   ____________________________end_goals_overunder_first_half_over_15 = '3.40',
#   ____________________________end_goals_overunder_first_half_under_15 = '1.30',
#   ____________________________end_goals_overunder_first_half_over_25 = '10.00',
#   ____________________________end_goals_overunder_first_half_under_25 = '1.06',
#   ____________________________end_goals_overunder_first_half_over_05 = '1.50',
#   ____________________________end_goals_overunder_first_half_under_05 = '2.50',
#   ____________________________end_goals_overunder_first_half_over_125 = '2.75',
#   ____________________________end_goals_overunder_first_half_under_125 = '1.43',
#   ____________________________end_goals_overunder_first_half_over_175 = '4.50',
#   ____________________________end_goals_overunder_first_half_under_175 = '1.19',
#   ____________________________end_goals_overunder_first_half_over_075 = '1.75',
#   ____________________________end_goals_overunder_first_half_under_075 = '2.13',
#   ____________________________end_goals_overunder_first_half_over_10 = '2.25',
#   ____________________________end_goals_overunder_first_half_under_10 = '1.63',
#   __________________________26 Goals Over/Under - Second Half
#   ____________________________end_goals_overunder__second_half_over_35 = '17.00',
#   ____________________________end_goals_overunder__second_half_under_35 = '1.02',
#   ____________________________end_goals_overunder__second_half_over_15 = '2.50',
#   ____________________________end_goals_overunder__second_half_under_15 = '1.50',
#   ____________________________end_goals_overunder__second_half_over_25 = '6.00',
#   ____________________________end_goals_overunder__second_half_under_25 = '1.13',
#   ____________________________end_goals_overunder__second_half_over_05 = '1.30',
#   ____________________________end_goals_overunder__second_half_under_05 = '3.40',
#   __________________________7 HT/FT Double
#   __________________________27 Clean Sheet - Home
#   ____________________________end_clean_sheet__home_yes = '1.91',
#   ____________________________end_clean_sheet__home_no = '1.80',
#   __________________________28 Clean Sheet - Away
#   ____________________________end_clean_sheet__away_yes = '4.33',
#   ____________________________end_clean_sheet__away_no = '1.20',
#   __________________________8 Both Teams Score
#   ____________________________end_both_teams_score_yes = '2.20',
#   ____________________________end_both_teams_score_no = '1.62',
#   __________________________9 Handicap Result
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 3.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 15.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.03
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.36
#   ______________________  ______________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.09
#   __________________________10 Exact Score
#   __________________________11 Highest Scoring Half
#   __________________________31 Correct Score - First Half
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 34.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 201.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 81.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 201.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 5:0 --- bets_odd: 351.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 6.50
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 126.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 41.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 351.00
#   __________________________12 Double Chance
#   ____________________________end_double_chance_home_draw = '1.14',
#   ____________________________end_double_chance_home_away = '1.29',
#   ____________________________end_double_chance_draw_away = '2.10',
#   __________________________13 First Half Winner
#   ____________________________end_first_half_winner_home = '2.38',
#   ____________________________end_first_half_winner_draw = '2.05',
#   ____________________________end_first_half_winner_away = '6.00',
#   __________________________14 Team To Score First
#   ______________________  ______________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 14 --- bets_value: Draw --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 14 --- bets_value: Away --- bets_odd: 3.25
#   __________________________15 Team To Score Last
#   ______________________  ______________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 15 --- bets_value: Draw --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 15 --- bets_value: Away --- bets_odd: 3.25
#   __________________________32 Win Both Halves
#   ____________________________end_win_both_halves_home = '5.00',
#   ____________________________end_win_both_halves_away = '23.00',
#   __________________________16 Total - Home
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 11.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.05
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 2.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 1.5 --- bets_odd: 1.73
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 4.5 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 4.5 --- bets_odd: 1.01
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 2.5 --- bets_odd: 4.33
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 2.5 --- bets_odd: 1.20
#   ______________________  ______________________bet_id: 16 --- bets_value: Over 5.5 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 16 --- bets_value: Under 5.5 --- bets_odd: 1.00
#   __________________________17 Total - Away
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 3.5 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 3.5 --- bets_odd: 1.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 1.5 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 1.5 --- bets_odd: 1.17
#   ______________________  ______________________bet_id: 17 --- bets_value: Over 2.5 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 17 --- bets_value: Under 2.5 --- bets_odd: 1.02
#   __________________________18 Handicap Result - First Half
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -1 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -1 --- bets_odd: 1.53
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -1 --- bets_odd: 3.10
#   ______________________  ______________________bet_id: 18 --- bets_value: Home +1 --- bets_odd: 1.11
#   ______________________  ______________________bet_id: 18 --- bets_value: Away +1 --- bets_odd: 23.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw +1 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -2 --- bets_odd: 26.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -2 --- bets_odd: 9.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -2 --- bets_odd: 1.08
#   ______________________  ______________________bet_id: 18 --- bets_value: Home -3 --- bets_odd: 67.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Draw -3 --- bets_odd: 29.00
#   ______________________  ______________________bet_id: 18 --- bets_value: Away -3 --- bets_odd: 1.02
#   __________________________19 Asian Handicap First Half
#   __________________________20 Double Chance - First Half
#   __________________________34 Both Teams Score - First Half
#   __________________________35 Both Teams To Score - Second Half
#   __________________________36 Win To Nil
#   ____________________________end_win_to_nil_home = '2.50',
#   ____________________________end_win_to_nil_away = '8.00',
#   __________________________21 Odd/Even
#   __________________________22 Odd/Even - First Half
#   ______________________  ______________________bet_id: 22 --- bets_value: Odd --- bets_odd: 2.20
#   ______________________  ______________________bet_id: 22 --- bets_value: Even --- bets_odd: 1.67
#   __________________________39 To Win Either Half
#   ____________________________end_to_win_either_half_home = '1.44',
#   ____________________________end_to_win_either_half_away = '3.00',
#   __________________________40 Home Team Exact Goals Number
#   __________________________41 Away Team Exact Goals Number
#   __________________________24 Results/Both Teams Score
#   ____________________________end_results_both_teams_score_home_yes = '4.50',
#   ____________________________end_results_both_teams_score_draw_yes = '5.50',
#   ____________________________end_results_both_teams_score_away_yes = '12.00',
#   ____________________________end_results_both_teams_score_home_no = '2.50',
#   ____________________________end_results_both_teams_score_draw_no = '7.50',
#   ____________________________end_results_both_teams_score_away_no = '8.00',
#   __________________________25 Result/Total Goals
#   ____________________________end_result_total_goals_home_over_25 = '3.10',
#   ____________________________end_result_total_goals_draw_over_25 = '19.00',
#   ____________________________end_result_total_goals_away_over_25 = '11.00',
#   ____________________________end_result_total_goals_home_under_25 = '3.25',
#   ____________________________end_result_total_goals_draw_under_25 = '4.00',
#   ____________________________end_result_total_goals_away_under_25 = '8.50',
#   __________________________43 Home Team Score a Goal
#   ______________________  ______________________bet_id: 43 --- bets_value: Yes --- bets_odd: 1.20
#   ______________________  ______________________bet_id: 43 --- bets_value: No --- bets_odd: 4.33
#   __________________________44 Away Team Score a Goal
#   ______________________  ______________________bet_id: 44 --- bets_value: Yes --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 44 --- bets_value: No --- bets_odd: 1.91
#   __________________________54 First 10 min Winner
#   ______________________  ______________________bet_id: 54 --- bets_value: Home --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 54 --- bets_value: Draw --- bets_odd: 1.13
#   ______________________  ______________________bet_id: 54 --- bets_value: Away --- bets_odd: 12.00
#   __________________________45 Corners Over Under
#   ______________________  ______________________bet_id: 45 --- bets_value: Over 8.5 --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 45 --- bets_value: Under 8.5 --- bets_odd: 1.80
#   __________________________47 Winning Margin
#   ______________________  ______________________bet_id: 47 --- bets_value: Draw --- bets_odd: 7.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 1 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 1 --- bets_odd: 7.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 2 --- bets_odd: 5.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 2 --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 3 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 3 --- bets_odd: 51.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 1 by 4+ --- bets_odd: 17.00
#   ______________________  ______________________bet_id: 47 --- bets_value: 2 by 4+ --- bets_odd: 151.00
#   ______________________  ______________________bet_id: 47 --- bets_value: Score Draw --- bets_odd: 5.50
#   __________________________48 To Score In Both Halves By Teams
#   __________________________49 Total Goals/Both Teams To Score
#   ____________________________end_total_goals_both_teams_to_score_over_yes_25 = '3.00',
#   ____________________________end_total_goals_both_teams_to_score_over_no_25 = '8.00',
#   ____________________________end_total_goals_both_teams_to_score_under_yes_25 = '7.00',
#   ____________________________end_total_goals_both_teams_to_score_under_no_25 = '1.95',
#   __________________________91 Total Goals (3 way)
#   ______________________  ______________________bet_id: 91 --- bets_value: Under 2  --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 91 --- bets_value: 2 Or 3  --- bets_odd: 1.95
#   ______________________  ______________________bet_id: 91 --- bets_value: Over 3  --- bets_odd: 4.33
#   __________________________50 Goal Line
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.5 --- bets_odd: 4.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.5 --- bets_odd: 1.21
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.5 --- bets_odd: 1.43
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.5 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.5 --- bets_odd: 2.30
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.5 --- bets_odd: 1.60
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2 --- bets_odd: 1.70
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2 --- bets_odd: 2.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3 --- bets_odd: 3.45
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.25 --- bets_odd: 2.05
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.25 --- bets_odd: 1.80
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.25 --- bets_odd: 3.90
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.25 --- bets_odd: 1.24
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 2.75 --- bets_odd: 2.67
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 2.75 --- bets_odd: 1.45
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.25 --- bets_odd: 1.27
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.25 --- bets_odd: 3.55
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1.75 --- bets_odd: 1.52
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1.75 --- bets_odd: 2.42
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 3.75 --- bets_odd: 5.75
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 3.75 --- bets_odd: 1.14
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 1 --- bets_odd: 1.12
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 1 --- bets_odd: 6.25
#   ______________________  ______________________bet_id: 50 --- bets_value: Over 0.75 --- bets_odd: 1.10
#   ______________________  ______________________bet_id: 50 --- bets_value: Under 0.75 --- bets_odd: 7.00
#   __________________________72 Goal Line (1st Half)
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.5 --- bets_odd: 3.45
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.5 --- bets_odd: 1.30
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.5 --- bets_odd: 1.50
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.5 --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.25 --- bets_odd: 2.75
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.25 --- bets_odd: 1.43
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1.75 --- bets_odd: 4.50
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1.75 --- bets_odd: 1.19
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 1 --- bets_odd: 2.25
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 1 --- bets_odd: 1.63
#   ______________________  ______________________bet_id: 72 --- bets_value: Over 0.75 --- bets_odd: 1.75
#   ______________________  ______________________bet_id: 72 --- bets_value: Under 0.75 --- bets_odd: 2.13
#   __________________________52 Halftime Result/Both Teams Score
#   __________________________59 Own Goal
#   ______________________  ______________________bet_id: 59 --- bets_value: Yes --- bets_odd: 13.00
#   ______________________  ______________________bet_id: 59 --- bets_value: No --- bets_odd: 1.04
#   __________________________92 Anytime Goal Scorer
#   __________________________93 First Goal Scorer
#   __________________________94 Last Goal Scorer
#   __________________________95 To Score Two or More Goals
#   __________________________96 Last Goal Scorer
#   __________________________85 Total Corners (3 way)
#   ______________________  ______________________bet_id: 85 --- bets_value: Over 8 --- bets_odd: 1.91
#   ______________________  ______________________bet_id: 85 --- bets_value: Under 8 --- bets_odd: 2.38
#   ______________________  ______________________bet_id: 85 --- bets_value: Exactly 8 --- bets_odd: 7.00
#   __________________________73 Both Teams to Score 1st Half - 2nd Half
#   __________________________74 10 Over/Under
#   __________________________78 RTG_H1
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 6.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 21.00
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 9.50
#   ______________________  ______________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 2.50
#   ______________________  ______________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 3.50
#   ______________________  ______________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 6.50
#   ______________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#
#   ______________________2. World,  Friendlies  #10 - 2023 / 1012370
#   ______________________good to Go 1
#   ____________________________1 Match Winner
#   ______________________________end_match_winner_home = '1.70',
#   ______________________________end_match_winner_draw = '3.50',
#   ______________________________end_match_winner_away = '4.75',
#   ____________________________2 Home/Away
#   ______________________________end_homeaway_home = '1.29',
#   ______________________________end_homeaway_away = '3.50',
#   ____________________________3 Second Half Winner
#   ______________________________end_second_half_winner_home = '2.05',
#   ______________________________end_second_half_winner_draw = '2.40',
#   ______________________________end_second_half_winner_away = '4.75',
#   ____________________________4 Asian Handicap
#   ______________________________end_asian_handicap_home_plus_0 = '1.26',
#   ______________________________end_asian_handicap_away_plus_0 = '3.70',
#   ______________________________end_asian_handicap_home_min_025 = '1.48',
#   ______________________________end_asian_handicap_away_min_025 = '2.60',
#   ______________________________end_asian_handicap_home_plus_025 = '1.21',
#   ______________________________end_asian_handicap_away_plus_025 = '4.25',
#   ______________________________end_asian_handicap_home_min_05 = '1.68',
#   ______________________________end_asian_handicap_away_min_05 = '2.15',
#   ______________________________end_asian_handicap_home_plus_05 = '1.18',
#   ______________________________end_asian_handicap_away_plus_05 = '4.80',
#   ______________________________end_asian_handicap_home_min_075 = '1.93',
#   ______________________________end_asian_handicap_away_min_075 = '1.93',
#   ______________________________end_asian_handicap_home_plus_075 = '1.11',
#   ______________________________end_asian_handicap_away_plus_075 = '6.60',
#   ______________________________end_asian_handicap_home_min_1 = '2.25',
#   ______________________________end_asian_handicap_away_min_1 = '1.63',
#   ______________________________end_asian_handicap_home_min_15 = '3.00',
#   ______________________________end_asian_handicap_away_min_15 = '1.38',
#   ______________________________end_asian_handicap_home_min_125 = '2.60',
#   ______________________________end_asian_handicap_away_min_125 = '1.48',
#   ______________________________end_asian_handicap_home_min_175 = '3.70',
#   ______________________________end_asian_handicap_away_min_175 = '1.26',
#   ______________________________end_asian_handicap_home_min_2 = '5.50',
#   ______________________________end_asian_handicap_away_min_2 = '1.15',
#   ______________________________end_asian_handicap_home_min_25 = '6.40',
#   ______________________________end_asian_handicap_away_min_25 = '1.11',
#   ______________________________end_asian_handicap_home_min_225 = '5.90',
#   ______________________________end_asian_handicap_away_min_225 = '1.13',
#   ____________________________5 Goals Over/Under
#   ______________________________end_goals_overunder_over_35 = '4.00',
#   ______________________________end_goals_overunder_under_35 = '1.22',
#   ______________________________end_goals_overunder_over_15 = '1.36',
#   ______________________________end_goals_overunder_under_15 = '3.00',
#   ______________________________end_goals_overunder_over_45 = '9.00',
#   ______________________________end_goals_overunder_under_45 = '1.07',
#   ______________________________end_goals_overunder_over_25 = '2.15',
#   ______________________________end_goals_overunder_under_25 = '1.67',
#   ______________________________end_goals_overunder_over_05 = '1.07',
#   ______________________________end_goals_overunder_under_05 = '9.00',
#   ______________________________end_goals_overunder_over_55 = '19.00',
#   ______________________________end_goals_overunder_under_55 = '1.02',
#   ______________________________end_goals_overunder_over_225 = '1.93',
#   ______________________________end_goals_overunder_under_225 = '1.93',
#   ______________________________end_goals_overunder_over_325 = '3.55',
#   ______________________________end_goals_overunder_under_325 = '1.27',
#   ______________________________end_goals_overunder_over_275 = '2.50',
#   ______________________________end_goals_overunder_under_275 = '1.50',
#   ______________________________end_goals_overunder_over_125 = '1.23',
#   ______________________________end_goals_overunder_under_125 = '4.00',
#   ______________________________end_goals_overunder_over_175 = '1.48',
#   ______________________________end_goals_overunder_under_175 = '2.60',
#   ______________________________end_goals_overunder_over_375 = '5.00',
#   ______________________________end_goals_overunder_under_375 = '1.17',
#   ______________________________end_goals_overunder_over_65 = '41.00',
#   ______________________________end_goals_overunder_under_65 = '1.00',
#   ______________________________end_goals_overunder_over_30 = '3.10',
#   ______________________________end_goals_overunder_under_30 = '1.35',
#   ______________________________end_goals_overunder_over_20 = '1.60',
#   ______________________________end_goals_overunder_under_20 = '2.30',
#   ______________________________end_goals_overunder_over_10 = '1.10',
#   ______________________________end_goals_overunder_under_10 = '7.00',
#   ____________________________6 Goals Over/Under First Half
#   ______________________________end_goals_overunder_first_half_over_35 = '26.00',
#   ______________________________end_goals_overunder_first_half_under_35 = '1.01',
#   ______________________________end_goals_overunder_first_half_over_15 = '3.25',
#   ______________________________end_goals_overunder_first_half_under_15 = '1.33',
#   ______________________________end_goals_overunder_first_half_over_25 = '10.00',
#   ______________________________end_goals_overunder_first_half_under_25 = '1.06',
#   ______________________________end_goals_overunder_first_half_over_05 = '1.44',
#   ______________________________end_goals_overunder_first_half_under_05 = '2.63',
#   ______________________________end_goals_overunder_first_half_over_125 = '2.67',
#   ______________________________end_goals_overunder_first_half_under_125 = '1.45',
#   ______________________________end_goals_overunder_first_half_over_175 = '4.25',
#   ______________________________end_goals_overunder_first_half_under_175 = '1.21',
#   ______________________________end_goals_overunder_first_half_over_075 = '1.65',
#   ______________________________end_goals_overunder_first_half_under_075 = '2.20',
#   ______________________________end_goals_overunder_first_half_over_10 = '2.15',
#   ______________________________end_goals_overunder_first_half_under_10 = '1.73',
#   ____________________________26 Goals Over/Under - Second Half
#   ______________________________end_goals_overunder__second_half_over_35 = '15.00',
#   ______________________________end_goals_overunder__second_half_under_35 = '1.03',
#   ______________________________end_goals_overunder__second_half_over_15 = '2.25',
#   ______________________________end_goals_overunder__second_half_under_15 = '1.57',
#   ______________________________end_goals_overunder__second_half_over_25 = '5.50',
#   ______________________________end_goals_overunder__second_half_under_25 = '1.14',
#   ______________________________end_goals_overunder__second_half_over_05 = '1.29',
#   ______________________________end_goals_overunder__second_half_under_05 = '3.50',
#   ____________________________7 HT/FT Double
#   ____________________________27 Clean Sheet - Home
#   ______________________________end_clean_sheet__home_yes = '2.10',
#   ______________________________end_clean_sheet__home_no = '1.67',
#   ____________________________28 Clean Sheet - Away
#   ______________________________end_clean_sheet__away_yes = '4.33',
#   ______________________________end_clean_sheet__away_no = '1.20',
#   ____________________________8 Both Teams Score
#   ______________________________end_both_teams_score_yes = '2.10',
#   ______________________________end_both_teams_score_no = '1.67',
#   ____________________________9 Handicap Result
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -1 --- bets_odd: 3.10
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -1 --- bets_odd: 2.10
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -1 --- bets_odd: 3.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +1 --- bets_odd: 1.18
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +1 --- bets_odd: 13.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +1 --- bets_odd: 6.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Home +2 --- bets_odd: 1.04
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw +2 --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away +2 --- bets_odd: 34.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -2 --- bets_odd: 6.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -2 --- bets_odd: 5.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -2 --- bets_odd: 1.36
#   ________________________  ________________________bet_id: 9 --- bets_value: Home -3 --- bets_odd: 15.00
#   ________________________  ________________________bet_id: 9 --- bets_value: Draw -3 --- bets_odd: 9.50
#   ________________________  ________________________bet_id: 9 --- bets_value: Away -3 --- bets_odd: 1.10
#   ____________________________10 Exact Score
#   ____________________________11 Highest Scoring Half
#   ____________________________31 Correct Score - First Half
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:0 --- bets_odd: 3.60
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:0 --- bets_odd: 9.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:1 --- bets_odd: 23.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:0 --- bets_odd: 34.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:1 --- bets_odd: 51.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 3:2 --- bets_odd: 201.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:0 --- bets_odd: 81.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 4:1 --- bets_odd: 201.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:0 --- bets_odd: 2.63
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:1 --- bets_odd: 9.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:2 --- bets_odd: 67.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:1 --- bets_odd: 6.50
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:2 --- bets_odd: 29.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 0:3 --- bets_odd: 101.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:2 --- bets_odd: 41.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 1:3 --- bets_odd: 151.00
#   ________________________  ________________________bet_id: 31 --- bets_value: 2:3 --- bets_odd: 351.00
#   ____________________________12 Double Chance
#   ______________________________end_double_chance_home_draw = '1.18',
#   ______________________________end_double_chance_home_away = '1.29',
#   ______________________________end_double_chance_draw_away = '2.10',
#   ____________________________13 First Half Winner
#   ______________________________end_first_half_winner_home = '2.40',
#   ______________________________end_first_half_winner_draw = '2.10',
#   ______________________________end_first_half_winner_away = '5.50',
#   ____________________________14 Team To Score First
#   ________________________  ________________________bet_id: 14 --- bets_value: Home --- bets_odd: 1.50
#   ________________________  ________________________bet_id: 14 --- bets_value: Draw --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 14 --- bets_value: Away --- bets_odd: 3.10
#   ____________________________15 Team To Score Last
#   ________________________  ________________________bet_id: 15 --- bets_value: Home --- bets_odd: 1.50
#   ________________________  ________________________bet_id: 15 --- bets_value: Draw --- bets_odd: 8.00
#   ________________________  ________________________bet_id: 15 --- bets_value: Away --- bets_odd: 3.10
#   ____________________________32 Win Both Halves
#   ______________________________end_win_both_halves_home = '5.00',
#   ______________________________end_win_both_halves_away = '21.00',
#   ____________________________16 Total - Home
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 3.5 --- bets_odd: 11.00
#   ________________________  ________________________bet_id: 16 --- bets_value: Under 3.5 --- bets_odd: 1.05
#   ________________________  ________________________bet_id: 16 --- bets_value: Over 1.5 --- bets_odd: 1.91
# ...
#   ________________________________________75 Last Corner
#   ____________________________________  ____________________________________bet_id: 75 --- bets_value: Home --- bets_odd: 1.04
#   ____________________________________  ____________________________________bet_id: 75 --- bets_value: Away --- bets_odd: 13.00
#   ________________________________________76 First Corner
#   ____________________________________  ____________________________________bet_id: 76 --- bets_value: Home --- bets_odd: 1.04
#   ____________________________________  ____________________________________bet_id: 76 --- bets_value: Away --- bets_odd: 13.00
#   ________________________________________78 RTG_H1
#   ____________________________________  ____________________________________bet_id: 78 --- bets_value: Home/Over 1.5 --- bets_odd: 1.25
#   ____________________________________  ____________________________________bet_id: 78 --- bets_value: Away/Over 1.5 --- bets_odd: 201.00
#   ____________________________________  ____________________________________bet_id: 78 --- bets_value: Draw/Over 1.5 --- bets_odd: 34.00
#   ____________________________________  ____________________________________bet_id: 78 --- bets_value: Draw/Under 1.5 --- bets_odd: 13.00
#   ____________________________________  ____________________________________bet_id: 78 --- bets_value: Home/Under 1.5 --- bets_odd: 5.00
#   ____________________________________  ____________________________________bet_id: 78 --- bets_value: Away/Under 1.5 --- bets_odd: 81.00
#   ________________________________________102 Player to be booked
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Diogo Jota --- bets_odd: 8.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Ruben Neves --- bets_odd: 4.75
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Mota Bernardo Silva --- bets_odd: 6.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Ruben Dias --- bets_odd: 6.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Cavaco Joao Cancelo --- bets_odd: 5.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Cristiano Ronaldo --- bets_odd: 12.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Miguel Bruno Fernandes --- bets_odd: 4.75
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Diogo Dalot --- bets_odd: 7.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Rafael Leao --- bets_odd: 12.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Luis Danilo Pereira --- bets_odd: 8.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Alexandre Nuno Mendes --- bets_odd: 8.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Sequeira Joao Felix --- bets_odd: 6.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Matias Goncalo Ramos --- bets_odd: 8.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Eduardo Joao Mario --- bets_odd: 8.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Filipe Diogo Leite --- bets_odd: 5.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Nunes Matheus Luiz --- bets_odd: 8.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Maria Joao Palhinha --- bets_odd: 7.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Goncalo Inacio --- bets_odd: 12.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Ferreira Vitinha --- bets_odd: 12.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Monteiro Otavio --- bets_odd: 5.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Kleper Pepe --- bets_odd: 5.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Noah Frick --- bets_odd: 6.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Ridvan Kardesoglu --- bets_odd: 4.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Livio Meier --- bets_odd: 3.20
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Nicolas Hasler --- bets_odd: 6.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Niklas Beck --- bets_odd: 4.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Noah Frommelt --- bets_odd: 2.38
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Andrin Netzer --- bets_odd: 4.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Fabio Wolfinger --- bets_odd: 3.60
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Simon Luchinger --- bets_odd: 3.20
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Aron Sele --- bets_odd: 2.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Martin Marxer --- bets_odd: 2.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Sandro Wolfinger --- bets_odd: 3.60
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Andreas Malin --- bets_odd: 4.33
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Jens Hofer --- bets_odd: 2.75
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Seyhan Yildiz --- bets_odd: 5.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Raphael Guerreiro --- bets_odd: 8.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Antonio Silva --- bets_odd: 7.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Pedro Jose Sa --- bets_odd: 26.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Pedro Rui Patricio --- bets_odd: 26.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Diogo Costa --- bets_odd: 26.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Marco Wolfinger --- bets_odd: 4.33
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Sandro Wieser --- bets_odd: 2.38
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Philipp Gassner --- bets_odd: 4.75
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Jakob Lorenz --- bets_odd: 6.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Lars Traber --- bets_odd: 3.20
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Justin Ospelt --- bets_odd: 10.00
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Lorenzo Lo Russo --- bets_odd: 8.50
#   ____________________________________  ____________________________________bet_id: 102 --- bets_value: Benjamin Buchel --- bets_odd: 10.00
#   ________________________________________103 Player to be Sent Off
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Diogo Jota --- bets_odd: 81.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Ruben Neves --- bets_odd: 51.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Mota Bernardo Silva --- bets_odd: 67.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Ruben Dias --- bets_odd: 67.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Cavaco Joao Cancelo --- bets_odd: 67.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Cristiano Ronaldo --- bets_odd: 126.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Miguel Bruno Fernandes --- bets_odd: 51.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Diogo Dalot --- bets_odd: 81.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Rafael Leao --- bets_odd: 126.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Luis Danilo Pereira --- bets_odd: 81.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Alexandre Nuno Mendes --- bets_odd: 81.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Sequeira Joao Felix --- bets_odd: 81.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Matias Goncalo Ramos --- bets_odd: 81.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Eduardo Joao Mario --- bets_odd: 101.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Filipe Diogo Leite --- bets_odd: 51.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Nunes Matheus Luiz --- bets_odd: 81.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Maria Joao Palhinha --- bets_odd: 81.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Goncalo Inacio --- bets_odd: 126.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Ferreira Vitinha --- bets_odd: 126.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Monteiro Otavio --- bets_odd: 67.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Kleper Pepe --- bets_odd: 67.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Noah Frick --- bets_odd: 51.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Ridvan Kardesoglu --- bets_odd: 34.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Livio Meier --- bets_odd: 29.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Nicolas Hasler --- bets_odd: 51.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Niklas Beck --- bets_odd: 34.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Noah Frommelt --- bets_odd: 23.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Andrin Netzer --- bets_odd: 34.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Fabio Wolfinger --- bets_odd: 34.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Simon Luchinger --- bets_odd: 29.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Aron Sele --- bets_odd: 23.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Martin Marxer --- bets_odd: 23.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Sandro Wolfinger --- bets_odd: 34.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Andreas Malin --- bets_odd: 41.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Jens Hofer --- bets_odd: 29.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Seyhan Yildiz --- bets_odd: 41.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Raphael Guerreiro --- bets_odd: 101.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Antonio Silva --- bets_odd: 81.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Pedro Jose Sa --- bets_odd: 151.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Pedro Rui Patricio --- bets_odd: 151.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Diogo Costa --- bets_odd: 151.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Alexandre Nuno Mendes - Yes --- bets_odd: 67.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Marco Wolfinger --- bets_odd: 41.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Sandro Wieser --- bets_odd: 23.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Philipp Gassner --- bets_odd: 41.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Jakob Lorenz --- bets_odd: 51.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Lars Traber --- bets_odd: 29.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Nunes Matheus Luiz - Yes --- bets_odd: 67.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Justin Ospelt --- bets_odd: 67.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Lorenzo Lo Russo --- bets_odd: 67.00
#   ____________________________________  ____________________________________bet_id: 103 --- bets_value: Benjamin Buchel --- bets_odd: 67.00
#   ____________________________________fixture_status_update: , end_odd_updated_at = current_timestamp , fixture_status = 'Match Finished Ended'
#   ______________________________________ff_update_unfinished__
#   ____________________________________  > No longer get supported
# # -------------------------------------------------- End at 2023-03-25 02:42:03

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------  
    ff_get_fixture_status_match_finished(tgl_awal, tgl_akhir, 'xpattern', space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 02:42:03
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-23
#   ______tgl_akhir : 2023-03-24
#   ________ff_get_fixture_status_match_finished()
#   __________Total Row(s) : 61
#   __________1. 2023-03-23 // 10 // 8 // 2023 // 984805 // 175_15_125_1_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 984805
#   ____________> end_ah_pattern = 15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________2. 2023-03-23 // 10 // 8 // 2023 // 1012325 // 1_075_05_H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1012325
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________3. 2023-03-23 // 10 // 8 // 2023 // 1012369 // 1_075_05_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1012369
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________4. 2023-03-23 // 10 // 8 // 2023 // 1012370 // 1_075_05_H // 2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1012370
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________5. 2023-03-23 // 10 // 8 // 2023 // 1012323 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1012323
#   ____________> end_ah_pattern = 55_525_5_475_45_425_H
#   ____________> end_ah_pattern_mirror = 425+45+475+5+525+55+H
#   ____________> end_gou_pattern = 45g475g5g525g55g575gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________6. 2023-03-23 // 239 // 8 // 2023 // 987696 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 987696
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________7. 2023-03-23 // 239 // 8 // 2023 // 989296 // 075_05_025_H // 175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 989296
#   ____________> end_ah_pattern = 05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+H
#   ____________> end_gou_pattern = 15g175g2gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________8. 2023-03-23 // 243 // 11 // 2023 // 1011777 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011777
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________9. 2023-03-23 // 263 // 8 // 2022 // 975966 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975966
#   ____________> end_ah_pattern = 05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________10. 2023-03-23 // 263 // 8 // 2022 // 975967 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975967
#   ____________> end_ah_pattern = 025_H
#   ____________> end_ah_pattern_mirror = 025+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________11. 2023-03-23 // 263 // 8 // 2022 // 975968 // 15_125_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 975968
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________12. 2023-03-23 // 287 // 11 // 2022 // 869174 // 1_075_025_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 869174
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________13. 2023-03-23 // 287 // 11 // 2022 // 869176 // 075_025_H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 869176
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 15g175g2g225gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________14. 2023-03-23 // 287 // 11 // 2022 // 869177 // 025_0#025+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 869177
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________15. 2023-03-23 // 287 // 11 // 2022 // 869178 // 075_025_H // 15g175g2g225gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 869178
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________16. 2023-03-23 // 287 // 11 // 2022 // 898111 // 075_025_H // 15g175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 898111
#   ____________> end_ah_pattern = 075_025_H
#   ____________> end_ah_pattern_mirror = 025+075+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________17. 2023-03-23 // 361 // 11 // 2023 // 1011580 // 0#H // 25g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1011580
#   ____________> end_ah_pattern = 1_H
#   ____________> end_ah_pattern_mirror = 1+H
#   ____________> end_gou_pattern = 25g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________18. 2023-03-23 // 496 // 11 // 2022 // 934837 // H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934837
#   ____________> end_ah_pattern = 175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+H
#   ____________> end_gou_pattern = 25g3g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________19. 2023-03-23 // 496 // 11 // 2022 // 934839 // 1_075_025_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934839
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________20. 2023-03-23 // 496 // 11 // 2022 // 934841 // 025_0#025+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 934841
#   ____________> end_ah_pattern = 0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________21. 2023-03-24 // 536 // 8 // 2022 // 856816 // 175+2+225+25+H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 856816
#   ____________> end_ah_pattern = 2+225+25+275+3+H
#   ____________> end_ah_pattern_mirror = 3_275_25_225_2_H
#   ____________> end_gou_pattern = 3g325g35g375g4gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________22. 2023-03-23 // 536 // 8 // 2022 // 856856 // 075+1+125+15+H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 856856
#   ____________> end_ah_pattern = 1+125+15+175+H
#   ____________> end_ah_pattern_mirror = 175_15_125_1_H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________23. 2023-03-23 // 536 // 8 // 2022 // 856857 // 175_15_125_1_H // 225g25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 856857
#   ____________> end_ah_pattern = 2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________24. 2023-03-23 // 536 // 8 // 2022 // 856861 // 075_05_025_H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 856861
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________25. 2023-03-23 // 536 // 8 // 2022 // 856892 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 856892
#   ____________> end_ah_pattern = 05+075+1+125+H
#   ____________> end_ah_pattern_mirror = 125_1_075_05_H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________26. 2023-03-23 // 536 // 8 // 2022 // 856893 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 856893
#   ____________> end_ah_pattern = 35+375+4+425+45+H
#   ____________> end_ah_pattern_mirror = 45_425_4_375_35_H
#   ____________> end_gou_pattern = 4g425g45g475g5gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________27. 2023-03-23 // 604 // 8 // 2023 // 1015129 // 075_05_025_H // 15gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1015129
#   ____________> end_ah_pattern = 075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+H
#   ____________> end_gou_pattern = 15gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________28. 2023-03-24 // 604 // 8 // 2023 // 1015127 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1015127
#   ____________> end_ah_pattern = 1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________29. 2023-03-23 // 667 // 8 // 2023 // 999298 // 175_15_125_H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 999298
#   ____________> end_ah_pattern = 175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________30. 2023-03-23 // 667 // 8 // 2023 // 1008045 // H // G
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1008045
#   ____________> end_ah_pattern = 075_05_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+05+075+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________31. 2023-03-23 // 667 // 8 // 2023 // 1014212 // 125_H // 25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1014212
#   ____________> end_ah_pattern = 125_H
#   ____________> end_ah_pattern_mirror = 125+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________32. 2023-03-23 // 667 // 8 // 2023 // 1017699 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017699
#   ____________> end_ah_pattern = 05_H
#   ____________> end_ah_pattern_mirror = 05+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________33. 2023-03-23 // 667 // 8 // 2023 // 1017701 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017701
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________34. 2023-03-23 // 667 // 8 // 2023 // 1017705 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017705
#   ____________> end_ah_pattern = 05+H
#   ____________> end_ah_pattern_mirror = 05_H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________35. 2023-03-23 // 667 // 8 // 2023 // 1017707 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017707
#   ____________> end_ah_pattern = 075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________36. 2023-03-23 // 667 // 8 // 2023 // 1017708 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017708
#   ____________> end_ah_pattern = 075_H
#   ____________> end_ah_pattern_mirror = 075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________37. 2023-03-23 // 667 // 8 // 2023 // 1017709 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017709
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________38. 2023-03-23 // 667 // 8 // 2023 // 1017710 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017710
#   ____________> end_ah_pattern = 075+H
#   ____________> end_ah_pattern_mirror = 075_H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________39. 2023-03-23 // 667 // 8 // 2023 // 1017712 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017712
#   ____________> end_ah_pattern = 2_H
#   ____________> end_ah_pattern_mirror = 2+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________40. 2023-03-23 // 667 // 8 // 2023 // 1017716 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017716
#   ____________> end_ah_pattern = 075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________41. 2023-03-23 // 667 // 8 // 2023 // 1017717 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017717
#   ____________> end_ah_pattern = 1_H
#   ____________> end_ah_pattern_mirror = 1+H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________42. 2023-03-23 // 667 // 8 // 2023 // 1017718 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017718
#   ____________> end_ah_pattern = 25+275+H
#   ____________> end_ah_pattern_mirror = 275_25_H
#   ____________> end_gou_pattern = G
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________43. 2023-03-23 // 667 // 8 // 2023 // 1017786 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017786
#   ____________> end_ah_pattern = 0#H
#   ____________> end_ah_pattern_mirror = 0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________44. 2023-03-23 // 677 // 11 // 2022 // 967076 // 025_0#025+H // 25g275g3g325gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 967076
#   ____________> end_ah_pattern = 025_0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#025+H
#   ____________> end_gou_pattern = 25g275g3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________45. 2023-03-23 // 677 // 11 // 2022 // 967075 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 967075
#   ____________> end_ah_pattern = 0#025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_0#H
#   ____________> end_gou_pattern = 225g25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________46. 2023-03-23 // 701 // 11 // 2022 // 992370 // 025_0#025+H // 225g25g275g3gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 992370
#   ____________> end_ah_pattern = 025_0#025+H
#   ____________> end_ah_pattern_mirror = 025_0#025+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________47. 2023-03-23 // 703 // 11 // 2022 // 948587 // 025+075+H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 948587
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 275g3g325g35gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________48. 2023-03-23 // 740 // 11 // 2023 // 1010651 // 025+075+H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010651
#   ____________> end_ah_pattern = 025+075+H
#   ____________> end_ah_pattern_mirror = 075_025_H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________49. 2023-03-23 // 740 // 11 // 2023 // 1010653 // 075_05_025_0#H // 225g25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010653
#   ____________> end_ah_pattern = 1_075_05_025_H
#   ____________> end_ah_pattern_mirror = 025+05+075+1+H
#   ____________> end_gou_pattern = 225g25g275g3gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________50. 2023-03-23 // 740 // 11 // 2023 // 1010654 // 175_15_125_1_075_H // 25g275g3g325g35gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1010654
#   ____________> end_ah_pattern = 15_125_1_075_H
#   ____________> end_ah_pattern_mirror = 075+1+125+15+H
#   ____________> end_gou_pattern = 25g275g3g325gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________51. 2023-03-23 // 890 // 8 // 2022 // 1017408 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017408
#   ____________> end_ah_pattern = 2_175_15_125_H
#   ____________> end_ah_pattern_mirror = 125+15+175+2+H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________52. 2023-03-23 // 890 // 8 // 2022 // 1017409 // None // None
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1017409
#   ____________> end_ah_pattern = 0#025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_0#H
#   ____________> end_gou_pattern = 25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________53. 2023-03-23 // 892 // 11 // 2022 // 1013652 // 075_025_0#H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 1013652
#   ____________> end_ah_pattern = 075_025_0#H
#   ____________> end_ah_pattern_mirror = 0#025+075+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________54. 2023-03-23 // 960 // 8 // 2023 // 980456 // 025+05+075+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 980456
#   ____________> end_ah_pattern = 025+05+075+H
#   ____________> end_ah_pattern_mirror = 075_05_025_H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________55. 2023-03-23 // 960 // 8 // 2023 // 980457 // 025_0#025+H // 175g2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 980457
#   ____________> end_ah_pattern = 025_0#025+05+H
#   ____________> end_ah_pattern_mirror = 05_025_0#025+H
#   ____________> end_gou_pattern = 175g2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________56. 2023-03-23 // 960 // 8 // 2023 // 980458 // 175_15_125_1_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 980458
#   ____________> end_ah_pattern = 175_15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+175+H
#   ____________> end_gou_pattern = 225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________57. 2023-03-23 // 960 // 8 // 2023 // 980459 // 175_15_125_H // 2g225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 980459
#   ____________> end_ah_pattern = 15_125_1_H
#   ____________> end_ah_pattern_mirror = 1+125+15+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________58. 2023-03-23 // 960 // 8 // 2023 // 980460 // 225+25+275+3+325+H // 275g3g325g35g375gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 980460
#   ____________> end_ah_pattern = 25+275+3+325+H
#   ____________> end_ah_pattern_mirror = 325_3_275_25_H
#   ____________> end_gou_pattern = 3g325g35g375gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________59. 2023-03-23 // 960 // 8 // 2023 // 980461 // 575_55_525_H // 55g575g6g625g65g675gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 980461
#   ____________> end_ah_pattern = 65_625_6_575_55_525_H
#   ____________> end_ah_pattern_mirror = 525+55+575+6+625+65+H
#   ____________> end_gou_pattern = 55g575g6g625g65g675gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________60. 2023-03-23 // 960 // 8 // 2023 // 980462 // 125_1_075_05_H // 225g25g275gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 980462
#   ____________> end_ah_pattern = 125_1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+125+H
#   ____________> end_gou_pattern = 2g225g25g275gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
#   __________61. 2023-03-23 // 960 // 8 // 2023 // 980463 // 1_075_05_025_H // 2g225g25gG
#   ____________xp_set_pattern()
#   ____________> fixtureapi_id = 980463
#   ____________> end_ah_pattern = 1_075_05_H
#   ____________> end_ah_pattern_mirror = 05+075+1+H
#   ____________> end_gou_pattern = 2g225g25gG
#   ____________> football_fixtures update pattern commited
#   ____________> no PL predates get advices
# # -------------------------------------------------- End at 2023-03-25 02:50:36

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now() 
    # ----------------------------------------------------------   
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ----------------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist(tgl_awal, tgl_akhir, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-03-25 02:50:36
#   __main()
#   ____get_date()
#   ______days : 2
#   ______days : 1
#   ______tgl_awal : 2023-03-23
#   ______tgl_akhir : 2023-03-24
#   ________ff_get_fixture_status_match_finished_for_daily_update_patternlist()
#   ________Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date <= '2023-03-24'  and date >= '2023-03-23'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 61
#   ____________[1/61] #869174 #Serbia 287-2022 / Grafičar vs OFK Vršac
#   ____________pre-ah:1_075_025_H -- pre-gou:2g225g25g275gG -/- end-ah:075_025_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:04
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '287'  and league_country = 'Serbia'  and pre_ah_pattern = '1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[2/61] #869176 #Serbia 287-2022 / Proleter Novi SAD vs Indjija
#   ____________pre-ah:075_025_H -- pre-gou:15g175g2g225g25gG -/- end-ah:075_025_0#H -- end-gou:15g175g2g225gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '287'  and league_country = 'Serbia'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '15g175g2g225g25gG'  and end_ah_pattern = '075_025_0#H'  and end_ah_pattern_mirror = '0#025+075+H'  and end_gou_pattern = '15g175g2g225gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 2
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 2
#   ____________________patternlists updated
#
#   ____________[3/61] #869177 #Serbia 287-2022 / FK Zlatibor vs Metalac GM
#   ____________pre-ah:025_0#025+H -- pre-gou:175g2g225g25gG -/- end-ah:025_0#025+H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:12
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '287'  and league_country = 'Serbia'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[4/61] #869178 #Serbia 287-2022 / Železničar Pančevo vs Radnički Sr. Mitrovica
#   ____________pre-ah:075_025_H -- pre-gou:15g175g2g225gG -/- end-ah:15_125_1_075_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:14
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '287'  and league_country = 'Serbia'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '15g175g2g225gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[5/61] #898111 #Serbia 287-2022 / Jedinstvo Ub vs Sloboda Uzice
#   ____________pre-ah:075_025_H -- pre-gou:15g175g2g225g25gG -/- end-ah:075_025_H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:22
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '287'  and league_country = 'Serbia'  and pre_ah_pattern = '075_025_H'  and pre_ah_pattern_mirror = '025+075+H'  and pre_gou_pattern = '15g175g2g225g25gG'  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[6/61] #948587 #England 703-2022 / Birmingham City U21 vs Crewe Alexandra U21
#   ____________pre-ah:025+075+H -- pre-gou:25g275g3g325g35gG -/- end-ah:025+075+H -- end-gou:275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:40:28
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '703'  and league_country = 'England'  and pre_ah_pattern = '025+075+H'  and pre_ah_pattern_mirror = '075_025_H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[7/61] #934837 #Israel 496-2022 / Maccabi Herzliya vs Holon Yermiyahu
#   ____________pre-ah:H -- pre-gou:25gG -/- end-ah:175_15_125_H -- end-gou:25g3g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:30
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '496'  and league_country = 'Israel'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+H'  and end_gou_pattern = '25g3g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[8/61] #934839 #Israel 496-2022 / Hapoel Kfar Shalem vs Hapoel Herzliya
#   ____________pre-ah:1_075_025_H -- pre-gou:225g25g275g3gG -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325g35gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '496'  and league_country = 'Israel'  and pre_ah_pattern = '1_075_025_H'  and pre_ah_pattern_mirror = '025+075+1+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325g35gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[9/61] #934841 #Israel 496-2022 / Shimshon Tel Aviv vs Maccabi Shaarayim
#   ____________pre-ah:025_0#025+H -- pre-gou:2g225g25g275gG -/- end-ah:0#025+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '496'  and league_country = 'Israel'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '0#025+H'  and end_ah_pattern_mirror = '025_0#H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[10/61] #975966 #Mexico 263-2022 / Raya2 vs Correcaminos Uat
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05_025_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:36:55
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05_025_H'  and end_ah_pattern_mirror = '025+05+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 8
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 8
#   ____________________patternlists updated
#
#   ____________[11/61] #975967 #Mexico 263-2022 / Venados FC vs Tapatío
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:025_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:36:58
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '025_H'  and end_ah_pattern_mirror = '025+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 7
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 7
#   ____________________patternlists updated
#
#   ____________[12/61] #975968 #Mexico 263-2022 / Atlante FC vs Tlaxcala
#   ____________pre-ah:15_125_H -- pre-gou:25gG -/- end-ah:175_15_125_1_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '263'  and league_country = 'Mexico'  and pre_ah_pattern = '15_125_H'  and pre_ah_pattern_mirror = '125+15+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[13/61] #987696 #Colombia 239-2023 / Millonarios vs Deportivo Pasto
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:1_075_05_H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:36:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '239'  and league_country = 'Colombia'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 3
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 3
#   ____________________patternlists updated
#
#   ____________[14/61] #989296 #Colombia 239-2023 / La Equidad vs Chico
#   ____________pre-ah:075_05_025_H -- pre-gou:175g2g225gG -/- end-ah:05_025_H -- end-gou:15g175g2gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:36:49
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '239'  and league_country = 'Colombia'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '175g2g225gG'  and end_ah_pattern = '05_025_H'  and end_ah_pattern_mirror = '025+05+H'  and end_gou_pattern = '15g175g2gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[15/61] #992370 #Portugal 701-2022 / Rio Ave U23 vs Farense U23
#   ____________pre-ah:025_0#025+H -- pre-gou:225g25g275g3gG -/- end-ah:025_0#025+H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:40:20
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '701'  and league_country = 'Portugal'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '025_0#025+H'  and end_ah_pattern_mirror = '025_0#025+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[16/61] #1011580 #Lithuania 361-2023 / Babrungas vs Žalgiris II
#   ____________pre-ah:0#H -- pre-gou:25g3gG -/- end-ah:1_H -- end-gou:25g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:26
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '361'  and league_country = 'Lithuania'  and pre_ah_pattern = '0#H'  and pre_ah_pattern_mirror = '0#H'  and pre_gou_pattern = '25g3gG'  and end_ah_pattern = '1_H'  and end_ah_pattern_mirror = '1+H'  and end_gou_pattern = '25g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[17/61] #984805 #World 10-2023 / Hungary vs Estonia
#   ____________pre-ah:175_15_125_1_H -- pre-gou:225g25g275gG -/- end-ah:15_125_1_H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:36:17
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '10'  and league_country = 'World'  and pre_ah_pattern = '175_15_125_1_H'  and pre_ah_pattern_mirror = '1+125+15+175+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[18/61] #856816 #World 536-2022 / Suriname vs Mexico
#   ____________pre-ah:175+2+225+25+H -- pre-gou:275g3g325g35g375gG -/- end-ah:2+225+25+275+3+H -- end-gou:3g325g35g375g4gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:37:44
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '536'  and league_country = 'World'  and pre_ah_pattern = '175+2+225+25+H'  and pre_ah_pattern_mirror = '25_225_2_175_H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '2+225+25+275+3+H'  and end_ah_pattern_mirror = '3_275_25_225_2_H'  and end_gou_pattern = '3g325g35g375g4gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[19/61] #856856 #World 536-2022 / Barbados vs Cuba
#   ____________pre-ah:075+1+125+15+H -- pre-gou:225g25g275g3g325gG -/- end-ah:1+125+15+175+H -- end-gou:25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:38:20
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '536'  and league_country = 'World'  and pre_ah_pattern = '075+1+125+15+H'  and pre_ah_pattern_mirror = '15_125_1_075_H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '1+125+15+175+H'  and end_ah_pattern_mirror = '175_15_125_1_H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[20/61] #856857 #World 536-2022 / Guadeloupe vs Antigua and Barbuda
#   ____________pre-ah:175_15_125_1_H -- pre-gou:225g25g275g3g325gG -/- end-ah:2_175_15_125_H -- end-gou:25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:38:18
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '536'  and league_country = 'World'  and pre_ah_pattern = '175_15_125_1_H'  and pre_ah_pattern_mirror = '1+125+15+175+H'  and pre_gou_pattern = '225g25g275g3g325gG'  and end_ah_pattern = '2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[21/61] #856861 #World 536-2022 / French Guyana vs Dominican Republic
#   ____________pre-ah:075_05_025_H -- pre-gou:225g25g275g3gG -/- end-ah:1_075_05_025_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:38:11
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '536'  and league_country = 'World'  and pre_ah_pattern = '075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+H'  and pre_gou_pattern = '225g25g275g3gG'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[22/61] #980456 #World 960-2023 / Kazakhstan vs Slovenia
#   ____________pre-ah:025+05+075+H -- pre-gou:175g2g225g25gG -/- end-ah:025+05+075+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:41:40
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '960'  and league_country = 'World'  and pre_ah_pattern = '025+05+075+H'  and pre_ah_pattern_mirror = '075_05_025_H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[23/61] #980457 #World 960-2023 / Italy vs England
#   ____________pre-ah:025_0#025+H -- pre-gou:175g2g225g25gG -/- end-ah:025_0#025+05+H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:41:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '960'  and league_country = 'World'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '025_0#025+05+H'  and end_ah_pattern_mirror = '05_025_0#025+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[24/61] #980458 #World 960-2023 / FYR Macedonia vs Malta
#   ____________pre-ah:175_15_125_1_H -- pre-gou:225g25g275gG -/- end-ah:175_15_125_1_H -- end-gou:225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:41:48
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '960'  and league_country = 'World'  and pre_ah_pattern = '175_15_125_1_H'  and pre_ah_pattern_mirror = '1+125+15+175+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '175_15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+175+H'  and end_gou_pattern = '225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[25/61] #980459 #World 960-2023 / Denmark vs Finland
#   ____________pre-ah:175_15_125_H -- pre-gou:2g225g25g275gG -/- end-ah:15_125_1_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:41:27
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '960'  and league_country = 'World'  and pre_ah_pattern = '175_15_125_H'  and pre_ah_pattern_mirror = '125+15+175+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '15_125_1_H'  and end_ah_pattern_mirror = '1+125+15+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[26/61] #980460 #World 960-2023 / San Marino vs Northern Ireland
#   ____________pre-ah:225+25+275+3+325+H -- pre-gou:275g3g325g35g375gG -/- end-ah:25+275+3+325+H -- end-gou:3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:41:51
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '960'  and league_country = 'World'  and pre_ah_pattern = '225+25+275+3+325+H'  and pre_ah_pattern_mirror = '325_3_275_25_225_H'  and pre_gou_pattern = '275g3g325g35g375gG'  and end_ah_pattern = '25+275+3+325+H'  and end_ah_pattern_mirror = '325_3_275_25_H'  and end_gou_pattern = '3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[27/61] #980461 #World 960-2023 / Portugal vs Liechtenstein
#   ____________pre-ah:575_55_525_H -- pre-gou:55g575g6g625g65g675gG -/- end-ah:65_625_6_575_55_525_H -- end-gou:55g575g6g625g65g675gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:42:01
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '960'  and league_country = 'World'  and pre_ah_pattern = '575_55_525_H'  and pre_ah_pattern_mirror = '525+55+575+H'  and pre_gou_pattern = '55g575g6g625g65g675gG'  and end_ah_pattern = '65_625_6_575_55_525_H'  and end_ah_pattern_mirror = '525+55+575+6+625+65+H'  and end_gou_pattern = '55g575g6g625g65g675gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[28/61] #980462 #World 960-2023 / Slovakia vs Luxembourg
#   ____________pre-ah:125_1_075_05_H -- pre-gou:225g25g275gG -/- end-ah:125_1_075_05_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:41:17
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '960'  and league_country = 'World'  and pre_ah_pattern = '125_1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+125+H'  and pre_gou_pattern = '225g25g275gG'  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[29/61] #980463 #World 960-2023 / Bosnia & Herzegovina vs Iceland
#   ____________pre-ah:1_075_05_025_H -- pre-gou:2g225g25gG -/- end-ah:1_075_05_H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:41:24
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '960'  and league_country = 'World'  and pre_ah_pattern = '1_075_05_025_H'  and pre_ah_pattern_mirror = '025+05+075+1+H'  and pre_gou_pattern = '2g225g25gG'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[30/61] #856892 #World 536-2022 / Saint Martin vs St. Kitts and Nevis
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:05+075+1+125+H -- end-gou:25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:38:00
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '536'  and league_country = 'World'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '05+075+1+125+H'  and end_ah_pattern_mirror = '125_1_075_05_H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[31/61] #856893 #World 536-2022 / British Virgin Islands vs Puerto Rico
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:35+375+4+425+45+H -- end-gou:4g425g45g475g5gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:38:09
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '536'  and league_country = 'World'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '35+375+4+425+45+H'  and end_ah_pattern_mirror = '45_425_4_375_35_H'  and end_gou_pattern = '4g425g45g475g5gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[32/61] #967076 #Qatar 677-2022 / Al-Duhail SC vs Al Sadd
#   ____________pre-ah:025_0#025+H -- pre-gou:25g275g3g325gG -/- end-ah:025_0#025+075+H -- end-gou:25g275g3g325g35g375gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:40:17
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '677'  and league_country = 'Qatar'  and pre_ah_pattern = '025_0#025+H'  and pre_ah_pattern_mirror = '025_0#025+H'  and pre_gou_pattern = '25g275g3g325gG'  and end_ah_pattern = '025_0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#025+H'  and end_gou_pattern = '25g275g3g325g35g375gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[33/61] #999298 #World 667-2023 / Red Bull Salzburg vs FC BW Linz
#   ____________pre-ah:175_15_125_H -- pre-gou:G -/- end-ah:175_15_125_H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:35
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = '175_15_125_H'  and pre_ah_pattern_mirror = '125+15+175+H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[34/61] #1008045 #World 667-2023 / LDU de Quito vs Deportivo Cuenca
#   ____________pre-ah:H -- pre-gou:G -/- end-ah:075_05_025_0#H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:17
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = 'H'  and pre_ah_pattern_mirror = 'H'  and pre_gou_pattern = 'G'  and end_ah_pattern = '075_05_025_0#H'  and end_ah_pattern_mirror = '0#025+05+075+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[35/61] #1010651 #Brazil 740-2023 / Cuiabá U20 vs América Mineiro U20
#   ____________pre-ah:025+075+H -- pre-gou:2g225g25g275gG -/- end-ah:025+075+H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:40:37
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = '025+075+H'  and pre_ah_pattern_mirror = '075_025_H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '025+075+H'  and end_ah_pattern_mirror = '075_025_H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[36/61] #1010653 #Brazil 740-2023 / Athletico PR U20 vs Bahia U20
#   ____________pre-ah:075_05_025_0#H -- pre-gou:225g25g275g3g325g35gG -/- end-ah:1_075_05_025_H -- end-gou:225g25g275g3gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:40:45
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = '075_05_025_0#H'  and pre_ah_pattern_mirror = '0#025+05+075+H'  and pre_gou_pattern = '225g25g275g3g325g35gG'  and end_ah_pattern = '1_075_05_025_H'  and end_ah_pattern_mirror = '025+05+075+1+H'  and end_gou_pattern = '225g25g275g3gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[37/61] #1010654 #Brazil 740-2023 / São Paulo U20 vs Atlético GO U20
#   ____________pre-ah:175_15_125_1_075_H -- pre-gou:25g275g3g325g35gG -/- end-ah:15_125_1_075_H -- end-gou:25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:40:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '740'  and league_country = 'Brazil'  and pre_ah_pattern = '175_15_125_1_075_H'  and pre_ah_pattern_mirror = '075+1+125+15+175+H'  and pre_gou_pattern = '25g275g3g325g35gG'  and end_ah_pattern = '15_125_1_075_H'  and end_ah_pattern_mirror = '075+1+125+15+H'  and end_gou_pattern = '25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[38/61] #1012325 #World 10-2023 / New Zealand vs China
#   ____________pre-ah:1_075_05_H -- pre-gou:175g2g225g25gG -/- end-ah:1_075_05_H -- end-gou:175g2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:36:02
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '10'  and league_country = 'World'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '175g2g225g25gG'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '175g2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[39/61] #1012369 #World 10-2023 / Malaysia vs Turkmenistan
#   ____________pre-ah:1_075_05_H -- pre-gou:2g225g25g275gG -/- end-ah:125_1_075_05_H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:36:25
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '10'  and league_country = 'World'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '125_1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+125+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[40/61] #1012370 #World 10-2023 / Hong Kong vs Singapore
#   ____________pre-ah:1_075_05_H -- pre-gou:2g225g25gG -/- end-ah:1_075_05_H -- end-gou:2g225g25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:36:08
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '10'  and league_country = 'World'  and pre_ah_pattern = '1_075_05_H'  and pre_ah_pattern_mirror = '05+075+1+H'  and pre_gou_pattern = '2g225g25gG'  and end_ah_pattern = '1_075_05_H'  and end_ah_pattern_mirror = '05+075+1+H'  and end_gou_pattern = '2g225g25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[41/61] #1013652 #Italy 892-2022 / Giana Erminio vs Adriese
#   ____________pre-ah:075_025_0#H -- pre-gou:2g225g25g275gG -/- end-ah:075_025_0#H -- end-gou:2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:41:07
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '892'  and league_country = 'Italy'  and pre_ah_pattern = '075_025_0#H'  and pre_ah_pattern_mirror = '0#025+075+H'  and pre_gou_pattern = '2g225g25g275gG'  and end_ah_pattern = '075_025_0#H'  and end_ah_pattern_mirror = '0#025+075+H'  and end_gou_pattern = '2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[42/61] #1014212 #World 667-2023 / Karlsruher SC vs FC Schaffhausen
#   ____________pre-ah:125_H -- pre-gou:25gG -/- end-ah:125_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:38:47
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = '125_H'  and pre_ah_pattern_mirror = '125+H'  and pre_gou_pattern = '25gG'  and end_ah_pattern = '125_H'  and end_ah_pattern_mirror = '125+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 1
#   __________________pa_final_assestment()
#   ____________________Total Row(s) : 1
#   ____________________patternlists updated
#
#   ____________[43/61] #1015129 #Brazil 604-2023 / Brusque vs Concórdia
#   ____________pre-ah:075_05_025_H -- pre-gou:15gG -/- end-ah:075_05_025_H -- end-gou:15gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:38:29
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
# ...
#   ________________Total Row(s) : 0
#
#   ____________[45/61] #1011777 #Ecuador 243-2023 / UT Cotopaxi vs Imbabura
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_025_H -- end-gou:175g2g225g25g275gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-24 19:26:14
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '243'  and league_country = 'Ecuador'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_025_H'  and end_ah_pattern_mirror = '025+075+H'  and end_gou_pattern = '175g2g225g25g275gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[46/61] #1017408 #World 890-2022 / Portugal U20 vs Romania U20
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:2_175_15_125_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:41:04
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '890'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '2_175_15_125_H'  and end_ah_pattern_mirror = '125+15+175+2+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[47/61] #1017409 #World 890-2022 / Norway U20 vs Italy U20
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#025+05+075+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:40:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '890'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#025+05+075+H'  and end_ah_pattern_mirror = '075_05_025_0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[48/61] #1017699 #World 667-2023 / Austria Lustenau vs FC Vaduz
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:05_H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:38:54
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '05_H'  and end_ah_pattern_mirror = '05+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[49/61] #1017701 #World 667-2023 / Vyškov vs AS Trencin
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:04
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#H'  and end_ah_pattern_mirror = '0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[50/61] #1017705 #World 667-2023 / Kazincbarcikai vs Zemplín Michalovce
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:05+H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:38:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '05+H'  and end_ah_pattern_mirror = '05_H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[51/61] #1017707 #World 667-2023 / FC Augsburg vs FC ST. Gallen
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_05_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:25
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_05_H'  and end_ah_pattern_mirror = '05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[52/61] #1017708 #World 667-2023 / Eintracht Frankfurt vs SpVgg Greuther Furth
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:27
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_H'  and end_ah_pattern_mirror = '075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[53/61] #1017709 #World 667-2023 / Holstein Kiel vs Aarhus
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:06
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#H'  and end_ah_pattern_mirror = '0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[54/61] #1017710 #World 667-2023 / Dornbirn vs WSG Wattens
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075+H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:14
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075+H'  and end_ah_pattern_mirror = '075_H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[55/61] #1017712 #World 667-2023 / Ried vs SK Vorwarts Steyr
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:2_H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:39
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '2_H'  and end_ah_pattern_mirror = '2+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[56/61] #1017716 #World 667-2023 / SV Darmstadt 98 vs SV Sandhausen
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:075_05_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:46
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '075_05_H'  and end_ah_pattern_mirror = '05+075+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[57/61] #1017717 #World 667-2023 / FC Koln vs St. Truiden
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:1_H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:48
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '1_H'  and end_ah_pattern_mirror = '1+H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[58/61] #1017718 #World 667-2023 / Real Jaén vs Getafe
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:25+275+H -- end-gou:G
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:56
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '25+275+H'  and end_ah_pattern_mirror = '275_25_H'  and end_gou_pattern = 'G'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[59/61] #1017786 #World 667-2023 / Velež vs Asane
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:39:59
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 1
#   __________________Already Data
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '667'  and league_country = 'World'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#H'  and end_ah_pattern_mirror = '0#H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[60/61] #967075 #Qatar 677-2022 / UMM Salal vs Al-Arabi SC
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:0#025+075+H -- end-gou:225g25g275g3g325gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:40:09
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '677'  and league_country = 'Qatar'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '0#025+075+H'  and end_ah_pattern_mirror = '075_025_0#H'  and end_gou_pattern = '225g25g275g3g325gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
#   ____________[61/61] #1015127 #Brazil 604-2023 / Chapecoense-sc vs Barra
#   ____________pre-ah:None -- pre-gou:None -/- end-ah:1_075_H -- end-gou:25gG
#   ____________Match Finished Ended -- end_odd_updated_at:2023-03-25 02:38:38
#
#   ______________pl_check_patternlist()
#   ________________Total Row(s) : 0
#   ____________________insert commited
#
#   ______________pa_assestment_daily_update()
#   ________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_fixtures  where leagueapi_id = '604'  and league_country = 'Brazil'  and pre_ah_pattern = Null  and pre_ah_pattern_mirror = Null  and pre_gou_pattern = Null  and end_ah_pattern = '1_075_H'  and end_ah_pattern_mirror = '075+1+H'  and end_gou_pattern = '25gG'  and `goals_home` is not null  and `goals_away` is not null  and `fixture_status` in ('Match Finished Ended', 'Match Finished')
#   ________________Total Row(s) : 0
#
# # -------------------------------------------------- End at 2023-03-25 03:01:25
