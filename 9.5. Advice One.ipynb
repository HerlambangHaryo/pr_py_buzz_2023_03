# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # -------------------------------------------------- 
    ff_get_fixture_one(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-14 01:48:29
#   __main()
#   ____ff_get_fixture_one()
#   ____Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues  where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season,  DATE(end_odd_updated_at),  fixture_status,  fixtureapi_id   from football_fixtures  where one = 1  order by date
#   ______Total Row(s) : 6
#   ________1. 2023-04-13 // 3 // 8 // 2022 // None // Not Started // 1016041
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API herlambangharyo@gmail.com counter is 54
#   ______________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________fixture : 1016041
#   ______________bookmaker : 8
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. World,  UEFA Europa League  #3 - 2022 / 1016041
#   ________________good to Go 1
#   __________________<tr><td>Corners Over Under Over 9.5</td><td>1.83</td></tr>
#   __________________<tr><td>Corners Over Under Under 9.5</td><td>1.83</td></tr>
#   __________________<tr><td>Total Corners (3 way) Under 10</td><td>1.83</td></tr>
#   __________________<tr><td>Cards European Handicap Away +0</td><td>1.83</td></tr>
#   __________________<tr><td>Cards European Handicap Home +1</td><td>1.83</td></tr>
#   __________________<tr><td>Cards Over/Under Over 4.5</td><td>1.83</td></tr>
#   __________________<tr><td>Cards Over/Under Under 4.5</td><td>1.83</td></tr>
#   __________________<tr><td>Away Team Total Cards Over 2.5</td><td>1.83</td></tr>
#   __________________<tr><td>Away Team Total Cards Under 2.5</td><td>1.83</td></tr>
#   __________________ end_special_odds = '<tr><td>Corners Over Under Over 9.5</td><td>1.83</td></tr><tr><td>Corners Over Under Under 9.5</td><td>1.83</td></tr><tr><td>Total Corners (3 way) Under 10</td><td>1.83</td></tr><tr><td>Cards European Handicap Away +0</td><td>1.83</td></tr><tr><td>Cards European Handicap Home +1</td><td>1.83</td></tr><tr><td>Cards Over/Under Over 4.5</td><td>1.83</td></tr><tr><td>Cards Over/Under Under 4.5</td><td>1.83</td></tr><tr><td>Away Team Total Cards Over 2.5</td><td>1.83</td></tr><tr><td>Away Team Total Cards Under 2.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#   ____________________ff_update_unfinished__
#   __________________  > No longer get supported
#   ________2. 2023-04-13 // 3 // 8 // 2022 // None // Not Started // 1016043
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API herlambangharyo@gmail.com counter is 53
#   ______________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________fixture : 1016043
#   ______________bookmaker : 8
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. World,  UEFA Europa League  #3 - 2022 / 1016043
#   ________________good to Go 1
#   __________________<tr><td>Asian Handicap First Half Home -0.25</td><td>1.98</td></tr>
#   __________________<tr><td>Cards European Handicap Away +0</td><td>1.83</td></tr>
#   __________________<tr><td>Cards European Handicap Home +1</td><td>1.83</td></tr>
#   __________________ end_special_odds = '<tr><td>Asian Handicap First Half Home -0.25</td><td>1.98</td></tr><tr><td>Cards European Handicap Away +0</td><td>1.83</td></tr><tr><td>Cards European Handicap Home +1</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#   ____________________ff_update_unfinished__
#   __________________  > No longer get supported
#   ________3. 2023-04-13 // 3 // 8 // 2022 // None // Not Started // 1016045
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API herlambangharyo@gmail.com counter is 52
#   ______________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________fixture : 1016045
#   ______________bookmaker : 8
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. World,  UEFA Europa League  #3 - 2022 / 1016045
#   ________________good to Go 1
#   __________________<tr><td>Goals Over/Under - Second Half Over 1.5</td><td>1.83</td></tr>
#   __________________<tr><td>Goals Over/Under - Second Half Under 1.5</td><td>1.83</td></tr>
#   __________________<tr><td>Corners Asian Handicap Home -2.5</td><td>1.98</td></tr>
#   __________________<tr><td>Corners Asian Handicap Away -2.5</td><td>1.83</td></tr>
#   __________________<tr><td>Home Corners Over/Under Over 5.5</td><td>1.83</td></tr>
#   __________________<tr><td>Home Corners Over/Under Under 5.5</td><td>1.83</td></tr>
#   __________________ end_special_odds = '<tr><td>Goals Over/Under - Second Half Over 1.5</td><td>1.83</td></tr><tr><td>Goals Over/Under - Second Half Under 1.5</td><td>1.83</td></tr><tr><td>Corners Asian Handicap Home -2.5</td><td>1.98</td></tr><tr><td>Corners Asian Handicap Away -2.5</td><td>1.83</td></tr><tr><td>Home Corners Over/Under Over 5.5</td><td>1.83</td></tr><tr><td>Home Corners Over/Under Under 5.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#   ____________________ff_update_unfinished__
#   __________________  > No longer get supported
#   ________4. 2023-04-13 // 848 // 8 // 2022 // None // Not Started // 1016049
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API herlambangharyo@gmail.com counter is 51
#   ______________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________fixture : 1016049
#   ______________bookmaker : 8
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. World,  UEFA Europa Conference League  #848 - 2022 / 1016049
#   ________________good to Go 1
#   __________________<tr><td>Asian Handicap Home +0.75</td><td>1.98</td></tr>
#   __________________<tr><td>Goals Over/Under Over 2.25</td><td>1.83</td></tr>
#   __________________<tr><td>Total - Away Over 1.5</td><td>1.83</td></tr>
#   __________________<tr><td>Total - Away Under 1.5</td><td>1.83</td></tr>
#   __________________<tr><td>Asian Handicap First Half Home +0.25</td><td>1.98</td></tr>
#   __________________<tr><td>Asian Handicap First Half Away +0.25</td><td>1.83</td></tr>
#   __________________<tr><td>Goal Line Over 2.25</td><td>1.83</td></tr>
#   __________________<tr><td>Away Corners Over/Under Over 5.5</td><td>1.83</td></tr>
#   __________________<tr><td>Away Corners Over/Under Under 5.5</td><td>1.83</td></tr>
#   __________________<tr><td>Home Team Total Cards Over 2.5</td><td>1.83</td></tr>
#   __________________<tr><td>Home Team Total Cards Under 2.5</td><td>1.83</td></tr>
#   __________________ end_special_odds = '<tr><td>Asian Handicap Home +0.75</td><td>1.98</td></tr><tr><td>Goals Over/Under Over 2.25</td><td>1.83</td></tr><tr><td>Total - Away Over 1.5</td><td>1.83</td></tr><tr><td>Total - Away Under 1.5</td><td>1.83</td></tr><tr><td>Asian Handicap First Half Home +0.25</td><td>1.98</td></tr><tr><td>Asian Handicap First Half Away +0.25</td><td>1.83</td></tr><tr><td>Goal Line Over 2.25</td><td>1.83</td></tr><tr><td>Away Corners Over/Under Over 5.5</td><td>1.83</td></tr><tr><td>Away Corners Over/Under Under 5.5</td><td>1.83</td></tr><tr><td>Home Team Total Cards Over 2.5</td><td>1.83</td></tr><tr><td>Home Team Total Cards Under 2.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#   ____________________ff_update_unfinished__
#   __________________  > No longer get supported
#   ________5. 2023-04-13 // 848 // 8 // 2022 // None // Not Started // 1016051
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API herlambangharyo@gmail.com counter is 50
#   ______________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________fixture : 1016051
#   ______________bookmaker : 8
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. World,  UEFA Europa Conference League  #848 - 2022 / 1016051
#   ________________good to Go 1
#   __________________<tr><td>Home/Away Home</td><td>1.83</td></tr>
#   __________________<tr><td>Home/Away Away</td><td>1.83</td></tr>
#   __________________<tr><td>Asian Handicap Home +0</td><td>1.83</td></tr>
#   __________________<tr><td>Asian Handicap First Half Home +0</td><td>1.83</td></tr>
#   __________________<tr><td>Asian Handicap First Half Away +0</td><td>1.98</td></tr>
#   __________________<tr><td>To Win Either Half Home</td><td>1.83</td></tr>
#   __________________<tr><td>To Win Either Half Away</td><td>1.83</td></tr>
#   __________________<tr><td>Corners 1x2 Home</td><td>1.83</td></tr>
#   __________________<tr><td>Home Corners Over/Under Over 4.5</td><td>1.83</td></tr>
#   __________________<tr><td>Home Corners Over/Under Under 4.5</td><td>1.83</td></tr>
#   __________________ end_special_odds = '<tr><td>Home/Away Home</td><td>1.83</td></tr><tr><td>Home/Away Away</td><td>1.83</td></tr><tr><td>Asian Handicap Home +0</td><td>1.83</td></tr><tr><td>Asian Handicap First Half Home +0</td><td>1.83</td></tr><tr><td>Asian Handicap First Half Away +0</td><td>1.98</td></tr><tr><td>To Win Either Half Home</td><td>1.83</td></tr><tr><td>To Win Either Half Away</td><td>1.83</td></tr><tr><td>Corners 1x2 Home</td><td>1.83</td></tr><tr><td>Home Corners Over/Under Over 4.5</td><td>1.83</td></tr><tr><td>Home Corners Over/Under Under 4.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#   ____________________ff_update_unfinished__
#   __________________  > No longer get supported
#   ________6. 2023-04-13 // 848 // 8 // 2022 // None // Not Started // 1016053
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API herlambangharyo@gmail.com counter is 49
#   ______________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________fixture : 1016053
#   ______________bookmaker : 8
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. World,  UEFA Europa Conference League  #848 - 2022 / 1016053
#   ________________good to Go 1
#   __________________<tr><td>Asian Handicap Home +0.5</td><td>1.83</td></tr>
#   __________________ end_special_odds = '<tr><td>Asian Handicap Home +0.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#   ____________________ff_update_unfinished__
#   __________________  > No longer get supported
# # -------------------------------------------------- End at 2023-04-14 01:48:48

# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    ff_get_fixture_status_match_finished('', '', 'one_xpattern', space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-14 01:48:48
#   __main()
#   ____ff_get_fixture_status_match_finished()
#   ______Total Row(s) : 6
#   ______1. 2023-04-13 // 3 // 8 // 2022 // 1016041 // 175_15_125_1_H // 25g275g3g325gG // Not Started
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016041
#   ________> pre_ah_pattern = 175_15_125_1_H
#   ________> pre_ah_pattern_mirror = 1+125+15+175+H
#   ________> pre_gou_pattern = 225g25g275g3g325gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern = '175_15_125_1_H'
#   ________     and pre_gou_pattern = '225g25g275g3g325gG'
#   ________     and end_ah_pattern = '175_15_125_1_H'
#   ________     and end_gou_pattern = '225g25g275g3g325gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136415
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern_mirror = '175_15_125_1_H'
#   ________     and pre_gou_pattern = '225g25g275g3g325gG'
#   ________     and end_ah_pattern_mirror = '175_15_125_1_H'
#   ________     and end_gou_pattern = '225g25g275g3g325gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136415
#   ________       --UPDATED--
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016041
#   ________> end_ah_pattern = 175_15_125_1_H
#   ________> end_ah_pattern_mirror = 1+125+15+175+H
#   ________> end_gou_pattern = 225g25g275g3g325gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern = '175_15_125_1_H'
#   ________     and pre_gou_pattern = '225g25g275g3g325gG'
#   ________     and end_ah_pattern = '175_15_125_1_H'
#   ________     and end_gou_pattern = '225g25g275g3g325gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `end_advices` = Null WHERE `id` = 136415
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern_mirror = '175_15_125_1_H'
#   ________     and pre_gou_pattern = '225g25g275g3g325gG'
#   ________     and end_ah_pattern_mirror = '175_15_125_1_H'
#   ________     and end_gou_pattern = '225g25g275g3g325gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `end_advices_mirror` = Null WHERE `id` = 136415
#   ________       --UPDATED--
#   ______2. 2023-04-13 // 3 // 8 // 2022 // 1016043 // 075_05_025_H // 175g2g225g25gG // Not Started
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016043
#   ________> pre_ah_pattern = 075_05_025_H
#   ________> pre_ah_pattern_mirror = 025+05+075+H
#   ________> pre_gou_pattern = 175g2g225g25gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern = '075_05_025_H'
#   ________     and pre_gou_pattern = '175g2g225g25gG'
#   ________     and end_ah_pattern = '075_05_025_H'
#   ________     and end_gou_pattern = '175g2g225g25gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136417
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern_mirror = '075_05_025_H'
#   ________     and pre_gou_pattern = '175g2g225g25gG'
#   ________     and end_ah_pattern_mirror = '075_05_025_H'
#   ________     and end_gou_pattern = '175g2g225g25gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136417
#   ________       --UPDATED--
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016043
#   ________> end_ah_pattern = 1_075_05_H
#   ________> end_ah_pattern_mirror = 05+075+1+H
#   ________> end_gou_pattern = 175g2g225g25gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern = '075_05_025_H'
#   ________     and pre_gou_pattern = '175g2g225g25gG'
#   ________     and end_ah_pattern = '075_05_025_H'
#   ________     and end_gou_pattern = '175g2g225g25gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `end_advices` = Null WHERE `id` = 136417
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern_mirror = '075_05_025_H'
#   ________     and pre_gou_pattern = '175g2g225g25gG'
#   ________     and end_ah_pattern_mirror = '075_05_025_H'
#   ________     and end_gou_pattern = '175g2g225g25gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `end_advices_mirror` = Null WHERE `id` = 136417
#   ________       --UPDATED--
#   ______3. 2023-04-13 // 3 // 8 // 2022 // 1016045 // 15_125_1_075_05_H // 225g25g275g3g325gG // Not Started
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016045
#   ________> pre_ah_pattern = 15_125_1_075_05_H
#   ________> pre_ah_pattern_mirror = 05+075+1+125+15+H
#   ________> pre_gou_pattern = 25g275g3g325gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern = '15_125_1_075_05_H'
#   ________     and pre_gou_pattern = '25g275g3g325gG'
#   ________     and end_ah_pattern = '15_125_1_075_05_H'
#   ________     and end_gou_pattern = '25g275g3g325gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136419
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern_mirror = '15_125_1_075_05_H'
#   ________     and pre_gou_pattern = '25g275g3g325gG'
#   ________     and end_ah_pattern_mirror = '15_125_1_075_05_H'
#   ________     and end_gou_pattern = '25g275g3g325gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136419
#   ________       --UPDATED--
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016045
#   ________> end_ah_pattern = 15_125_1_075_H
#   ________> end_ah_pattern_mirror = 075+1+125+15+H
#   ________> end_gou_pattern = 25g275g3g325gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern = '15_125_1_075_05_H'
#   ________     and pre_gou_pattern = '25g275g3g325gG'
#   ________     and end_ah_pattern = '15_125_1_075_05_H'
#   ________     and end_gou_pattern = '25g275g3g325gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `end_advices` = Null WHERE `id` = 136419
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '3'
#   ________     and pre_ah_pattern_mirror = '15_125_1_075_05_H'
#   ________     and pre_gou_pattern = '25g275g3g325gG'
#   ________     and end_ah_pattern_mirror = '15_125_1_075_05_H'
#   ________     and end_gou_pattern = '25g275g3g325gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `end_advices_mirror` = Null WHERE `id` = 136419
#   ________       --UPDATED--
#   ______4. 2023-04-13 // 848 // 8 // 2022 // 1016049 // 05+075+1+H // 225g25g275gG // Not Started
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016049
#   ________> pre_ah_pattern = 05+075+1+H
#   ________> pre_ah_pattern_mirror = 1_075_05_H
#   ________> pre_gou_pattern = 225g25g275gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern = '05+075+1+H'
#   ________     and pre_gou_pattern = '225g25g275gG'
#   ________     and end_ah_pattern = '05+075+1+H'
#   ________     and end_gou_pattern = '225g25g275gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136431
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern_mirror = '05+075+1+H'
#   ________     and pre_gou_pattern = '225g25g275gG'
#   ________     and end_ah_pattern_mirror = '05+075+1+H'
#   ________     and end_gou_pattern = '225g25g275gG'
#   ________    Total Row(s) : 1
#
#   ________     idx:136431
#   ________     total_fixtures:4
#   ________       UPDATE `football_fixtures` SET `pre_advices_mirror` = '<span class="badge bg-gray-800">Total pre Mirror Fixture(s) = 4</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o05 - 100%</span> <span class="badge bg-gradient-danger">u35 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-warning">Awin - 0%</span> <span class="badge bg-gradient-warning">Away0 - 0%</span> <span class="badge bg-gradient-warning">A-eithr - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-custom-teal">csn-H - 50%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136431
#   ________       --UPDATED--
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016049
#   ________> end_ah_pattern = 05+075+1+H
#   ________> end_ah_pattern_mirror = 1_075_05_H
#   ________> end_gou_pattern = 2g225g25g275gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern = '05+075+1+H'
#   ________     and pre_gou_pattern = '225g25g275gG'
#   ________     and end_ah_pattern = '05+075+1+H'
#   ________     and end_gou_pattern = '225g25g275gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `end_advices` = Null WHERE `id` = 136431
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern_mirror = '05+075+1+H'
#   ________     and pre_gou_pattern = '225g25g275gG'
#   ________     and end_ah_pattern_mirror = '05+075+1+H'
#   ________     and end_gou_pattern = '225g25g275gG'
#   ________    Total Row(s) : 1
#
#   ________     idx:136431
#   ________     total_fixtures:4
#   ________       UPDATE `football_fixtures` SET `end_advices_mirror` = '<span class="badge bg-gray-800">Total end Mirror Fixture(s) = 4</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o05 - 100%</span> <span class="badge bg-gradient-danger">u35 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-warning">Awin - 0%</span> <span class="badge bg-gradient-warning">Away0 - 0%</span> <span class="badge bg-gradient-warning">A-eithr - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-custom-teal">csn-H - 50%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136431
#   ________       --UPDATED--
#   ______5. 2023-04-13 // 848 // 8 // 2022 // 1016051 // 025_0#025+H // 2g225g25g275gG // Not Started
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016051
#   ________> pre_ah_pattern = 025_0#025+H
#   ________> pre_ah_pattern_mirror = 025_0#025+H
#   ________> pre_gou_pattern = 2g225g25g275gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern = '025_0#025+H'
#   ________     and pre_gou_pattern = '2g225g25g275gG'
#   ________     and end_ah_pattern = '025_0#025+H'
#   ________     and end_gou_pattern = '2g225g25g275gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136433
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern_mirror = '025_0#025+H'
#   ________     and pre_gou_pattern = '2g225g25g275gG'
#   ________     and end_ah_pattern_mirror = '025_0#025+H'
#   ________     and end_gou_pattern = '2g225g25g275gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136433
#   ________       --UPDATED--
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016051
#   ________> end_ah_pattern = 025_0#025+H
#   ________> end_ah_pattern_mirror = 025_0#025+H
#   ________> end_gou_pattern = 2g225g25g275gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern = '025_0#025+H'
#   ________     and pre_gou_pattern = '2g225g25g275gG'
#   ________     and end_ah_pattern = '025_0#025+H'
#   ________     and end_gou_pattern = '2g225g25g275gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `end_advices` = Null WHERE `id` = 136433
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern_mirror = '025_0#025+H'
#   ________     and pre_gou_pattern = '2g225g25g275gG'
#   ________     and end_ah_pattern_mirror = '025_0#025+H'
#   ________     and end_gou_pattern = '2g225g25g275gG'
#   ________    Total Row(s) : 0
#
#   ________       UPDATE `football_fixtures` SET `end_advices_mirror` = Null WHERE `id` = 136433
#   ________       --UPDATED--
#   ______6. 2023-04-13 // 848 // 8 // 2022 // 1016053 // 025+05+075+H // 2g225g25g275gG // Not Started
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016053
#   ________> pre_ah_pattern = 025+05+075+H
#   ________> pre_ah_pattern_mirror = 075_05_025_H
#   ________> pre_gou_pattern = 2g225g25g275gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern = '025+05+075+H'
#   ________     and pre_gou_pattern = '2g225g25g275gG'
#   ________     and end_ah_pattern = '025+05+075+H'
#   ________     and end_gou_pattern = '2g225g25g275gG'
#   ________    Total Row(s) : 1
#
#   ________     idx:136435
#   ________     total_fixtures:2
#   ________       UPDATE `football_fixtures` SET `pre_advices` = '<span class="badge bg-dark">Total pre  Fixture(s) = 2</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o05 - 100%</span> <span class="badge bg-gradient-danger">u35 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-warning">Awin - 100%</span> <span class="badge bg-gradient-warning">Away0 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-custom-teal">csn-H - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-orange-red">odd - 100%</span> <span class="badge bg-gradient-warning">o2nd - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136435
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern_mirror = '025+05+075+H'
#   ________     and pre_gou_pattern = '2g225g25g275gG'
#   ________     and end_ah_pattern_mirror = '025+05+075+H'
#   ________     and end_gou_pattern = '2g225g25g275gG'
#   ________    Total Row(s) : 1
#
#   ________     idx:136435
#   ________     total_fixtures:1
#   ________       UPDATE `football_fixtures` SET `pre_advices_mirror` = '<span class="badge bg-gray-800">Total pre Mirror Fixture(s) = 1</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o45 - 100%</span> <span class="badge bg-gradient-danger">u55 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-warning">Awin - 0%</span> <span class="badge bg-gradient-warning">Away0 - 0%</span> <span class="badge bg-gradient-warning">A-eithr - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-gray-700">xG-5 - 100%</span> <span class="badge bg-gradient-gray-700">xgA->3 - 0%</span> <span class="badge bg-gradient-gray-700">xgH-2 - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-custom-teal">Bty - 100%</span> <span class="badge bg-gradient-custom-teal">csn-A - 100%</span> <span class="badge bg-gradient-custom-teal">csn-H - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-orange-red">odd - 100%</span> <span class="badge bg-gradient-purple">o1st - 100%</span> <span class="badge bg-gradient-purple">xG1st-3 - 100%</span> <span class="badge bg-gradient-warning">xG2nd-2 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136435
#   ________       --UPDATED--
#   ________xp_set_pattern()
#   ________> fixtureapi_id = 1016053
#   ________> end_ah_pattern = 025+05+075+H
#   ________> end_ah_pattern_mirror = 075_05_025_H
#   ________> end_gou_pattern = 2g225g25gG
#   ________> football_fixtures update pattern commited
#   __________pl_predates_get_advice__no
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern = '025+05+075+H'
#   ________     and pre_gou_pattern = '2g225g25g275gG'
#   ________     and end_ah_pattern = '025+05+075+H'
#   ________     and end_gou_pattern = '2g225g25g275gG'
#   ________    Total Row(s) : 1
#
#   ________     idx:136435
#   ________     total_fixtures:2
#   ________       UPDATE `football_fixtures` SET `end_advices` = '<span class="badge bg-dark">Total end  Fixture(s) = 2</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o05 - 100%</span> <span class="badge bg-gradient-danger">u35 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-warning">Awin - 100%</span> <span class="badge bg-gradient-warning">Away0 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-custom-teal">csn-H - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-orange-red">odd - 100%</span> <span class="badge bg-gradient-warning">o2nd - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136435
#   ________       --UPDATED--
#   __________pl_predates_get_advice__yes
#   ________  __pl_get_leagueapi_for_advice__
#   ________     where leagueapi_id = '848'
#   ________     and pre_ah_pattern_mirror = '025+05+075+H'
#   ________     and pre_gou_pattern = '2g225g25g275gG'
#   ________     and end_ah_pattern_mirror = '025+05+075+H'
#   ________     and end_gou_pattern = '2g225g25g275gG'
#   ________    Total Row(s) : 1
#
#   ________     idx:136435
#   ________     total_fixtures:1
#   ________       UPDATE `football_fixtures` SET `end_advices_mirror` = '<span class="badge bg-gray-800">Total end Mirror Fixture(s) = 1</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o45 - 100%</span> <span class="badge bg-gradient-danger">u55 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-warning">Awin - 0%</span> <span class="badge bg-gradient-warning">Away0 - 0%</span> <span class="badge bg-gradient-warning">A-eithr - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-gray-700">xG-5 - 100%</span> <span class="badge bg-gradient-gray-700">xgA->3 - 0%</span> <span class="badge bg-gradient-gray-700">xgH-2 - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-custom-teal">Bty - 100%</span> <span class="badge bg-gradient-custom-teal">csn-A - 100%</span> <span class="badge bg-gradient-custom-teal">csn-H - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-orange-red">odd - 100%</span> <span class="badge bg-gradient-purple">o1st - 100%</span> <span class="badge bg-gradient-purple">xG1st-3 - 100%</span> <span class="badge bg-gradient-warning">xG2nd-2 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136435
#   ________       --UPDATED--
# # -------------------------------------------------- End at 2023-04-14 01:52:57

# %%
# Import
from a_settings.messages import *  
from a_models.predefine import *  

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------   
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=1)
    preday1 = today + DD
    day1 = preday1.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    print(space + "> day1 : " +  str(preday1) ) 
    # --------------------------------------------------   
    pd_get_fixtures_next_match(day0, preday1, 'one', space) 
    # --------------------------------------------------  
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-14 01:52:57
#   __main()
#   ____get_date()
#   ______> day0 : 2023-04-14
#   ______> day1 : 2023-04-15 01:52:57.824333
#   ________pd_get_fixtures_next_match()
#   __________Total Row(s) : 6
#   ____________[1/6] 3 - 2022 -----#Manchester United 33 - Sevilla 536 - 2023-04-13 19:00:00
#   ______________pre_first_half_winner_home:1.91
#   ______________pre_second_half_winner_home:1.67
#   ______________pre_to_win_either_half_home:1.22
#   ______________pre_result_total_goals_home_over_25:2.05
#   ______________pre_clean_sheet__away_yes:7.0
#   ____________good_to_go: 1
#
#   ____________[2/6] 3 - 2022 -----#Juventus 496 - Sporting CP 228 - 2023-04-13 19:00:00
#   ______________pre_total_goals_both_teams_to_score_under_no_25:1.95
#   ____________good_to_go: 1
#
#   ____________[3/6] 3 - 2022 -----#Bayer Leverkusen 168 - Union St. Gilloise 1393 - 2023-04-13 19:00:00
#   ______________pre_first_half_winner_home:1.95
#   ______________pre_second_half_winner_home:1.73
#   ______________pre_to_win_either_half_home:1.25
#   ______________pre_result_total_goals_home_over_25:2.1
#   ______________pre_clean_sheet__away_yes:7.0
#   ____________good_to_go: 1
#
#   ____________[4/6] 848 - 2022 -----#Lech Poznan 347 - Fiorentina 502 - 2023-04-13 19:00:00
#   ______________pre_second_half_winner_away:2.0
#   ____________good_to_go: 1
#
#   ____________[5/6] 848 - 2022 -----#Anderlecht 554 - AZ Alkmaar 201 - 2023-04-13 19:00:00
#   ____________good_to_go: 0
#
#   ____________[6/6] 848 - 2022 -----#FC Basel 1893 551 - Nice 84 - 2023-04-13 19:00:00
#   ____________good_to_go: 0
#
# # -------------------------------------------------- End at 2023-04-14 01:53:05
