# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  

leagueapi_id = input( "Enter your leagueapi id :  ")
season = input( "Enter your season :  ")

today = datetime.datetime.now()  
days0 = 7
days1 = 1
# Out:
# Enter your leagueapi id :  39
# Enter your season :  2022

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "leagueapi_id : " + str(leagueapi_id))
    print(space + "season : " + str(season))
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir)  
    # --------------------------------------------------   
    ff_get_group_date_league_status_match_finished(leagueapi_id, season, tgl_awal, tgl_akhir, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-02 12:50:15
#   __main()
#   ____leagueapi_id : 39
#   ____season : 2022
#   ____days : 7
#   ____days : 1
#   ____tgl_awal : 2023-04-25
#   ____tgl_akhir : 2023-05-01
#   ______ff_get_group_date_league_status_match_finished()
#   ______Select DATE(date), leagueapi_id,  (select bookmakersapi_id from leagues   where leagues.leagueapi_id = football_fixtures.leagueapi_id),  season   from football_fixtures  where leagueapi_id = '39'  and season = '2022'  and date <= '2023-05-01'  and date >= '2023-04-25'  and fixture_status like 'Match Finished'  and deleted_at is null  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   ________Total Row(s) : 1
#   __________1. 2023-04-30 // 39 // 8 // 2022
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 47
#   ________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-04-30
#   ________________bookmaker : 8
#   ________________season : 2022
#   ________________league : 39
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 5
#
#   __________________1. England,  Premier League  #39 - 2022 / 868276
#   __________________good to Go 1
#   ____________________<tr><td>To Win Either Half Away</td><td>1.83</td></tr>
#   ____________________<tr><td>Goal Line Over 2.5</td><td>1.98</td></tr>
#   ____________________<tr><td>Cards European Handicap Away +0</td><td>1.83</td></tr>
#   ____________________<tr><td>Cards European Handicap Home +1</td><td>1.83</td></tr>
#   ____________________ end_special_odds = '<tr><td>To Win Either Half Away</td><td>1.83</td></tr><tr><td>Goal Line Over 2.5</td><td>1.98</td></tr><tr><td>Cards European Handicap Away +0</td><td>1.83</td></tr><tr><td>Cards European Handicap Home +1</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#
#   ____________________2. England,  Premier League  #39 - 2022 / 868281
#   ____________________good to Go 1
#   ______________________<tr><td>Asian Handicap Home +1.5</td><td>1.98</td></tr>
#   ______________________<tr><td>Handicap Result Away +1</td><td>1.83</td></tr>
#   ______________________<tr><td>Result/Total Goals Away/Over 2.5</td><td>1.83</td></tr>
#   ______________________<tr><td>Corners Over Under Over 9.5</td><td>1.83</td></tr>
#   ______________________<tr><td>Corners Over Under Under 9.5</td><td>1.83</td></tr>
#   ______________________<tr><td>Away Corners Over/Under Over 6.5</td><td>1.83</td></tr>
#   ______________________<tr><td>Away Corners Over/Under Under 6.5</td><td>1.83</td></tr>
#   ______________________<tr><td>Total Corners (3 way) Under 10</td><td>1.83</td></tr>
#   ______________________ end_special_odds = '<tr><td>Asian Handicap Home +1.5</td><td>1.98</td></tr><tr><td>Handicap Result Away +1</td><td>1.83</td></tr><tr><td>Result/Total Goals Away/Over 2.5</td><td>1.83</td></tr><tr><td>Corners Over Under Over 9.5</td><td>1.83</td></tr><tr><td>Corners Over Under Under 9.5</td><td>1.83</td></tr><tr><td>Away Corners Over/Under Over 6.5</td><td>1.83</td></tr><tr><td>Away Corners Over/Under Under 6.5</td><td>1.83</td></tr><tr><td>Total Corners (3 way) Under 10</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#
#   ______________________3. England,  Premier League  #39 - 2022 / 868285
#   ______________________good to Go 1
#   ________________________<tr><td>Goals Over/Under First Half Over 1.25</td><td>1.98</td></tr>
#   ________________________<tr><td>HT/FT Double Home/Home</td><td>1.83</td></tr>
#   ________________________<tr><td>Clean Sheet - Home Yes</td><td>1.83</td></tr>
#   ________________________<tr><td>Clean Sheet - Home No</td><td>1.83</td></tr>
#   ________________________<tr><td>Away Team Exact Goals Number 0</td><td>1.83</td></tr>
#   ________________________<tr><td>Away Team Score a Goal Yes</td><td>1.83</td></tr>
#   ________________________<tr><td>Away Team Score a Goal No</td><td>1.83</td></tr>
#   ________________________<tr><td>To Score In Both Halves By Teams Home</td><td>1.83</td></tr>
#   ________________________<tr><td>Goal Line (1st Half) Over 1.25</td><td>1.98</td></tr>
#   ________________________<tr><td>Home Corners Over/Under Over 6.5</td><td>1.83</td></tr>
#   ________________________<tr><td>Home Corners Over/Under Under 6.5</td><td>1.83</td></tr>
#   ________________________ end_special_odds = '<tr><td>Goals Over/Under First Half Over 1.25</td><td>1.98</td></tr><tr><td>HT/FT Double Home/Home</td><td>1.83</td></tr><tr><td>Clean Sheet - Home Yes</td><td>1.83</td></tr><tr><td>Clean Sheet - Home No</td><td>1.83</td></tr><tr><td>Away Team Exact Goals Number 0</td><td>1.83</td></tr><tr><td>Away Team Score a Goal Yes</td><td>1.83</td></tr><tr><td>Away Team Score a Goal No</td><td>1.83</td></tr><tr><td>To Score In Both Halves By Teams Home</td><td>1.83</td></tr><tr><td>Goal Line (1st Half) Over 1.25</td><td>1.98</td></tr><tr><td>Home Corners Over/Under Over 6.5</td><td>1.83</td></tr><tr><td>Home Corners Over/Under Under 6.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#
#   ________________________4. England,  Premier League  #39 - 2022 / 868284
#   ________________________good to Go 1
#   __________________________<tr><td>Asian Handicap First Half Away -0.25</td><td>1.98</td></tr>
#   __________________________<tr><td>Corners Over Under Over 10.5</td><td>1.83</td></tr>
#   __________________________<tr><td>Corners Over Under Under 10.5</td><td>1.83</td></tr>
#   __________________________<tr><td>Total Corners (3 way) Under 11</td><td>1.83</td></tr>
#   __________________________ end_special_odds = '<tr><td>Asian Handicap First Half Away -0.25</td><td>1.98</td></tr><tr><td>Corners Over Under Over 10.5</td><td>1.83</td></tr><tr><td>Corners Over Under Under 10.5</td><td>1.83</td></tr><tr><td>Total Corners (3 way) Under 11</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#
#   __________________________5. England,  Premier League  #39 - 2022 / 868283
#   __________________________good to Go 1
#   ____________________________<tr><td>Home Team Total Cards Over 1.5</td><td>1.83</td></tr>
#   ____________________________<tr><td>Home Team Total Cards Under 1.5</td><td>1.83</td></tr>
#   ____________________________ end_special_odds = '<tr><td>Home Team Total Cards Over 1.5</td><td>1.83</td></tr><tr><td>Home Team Total Cards Under 1.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#   ______________________________ff_update_unfinished__
#   ____________________________  > No longer get supported
#   ____________________________  > FUCKIN END !
# # -------------------------------------------------- End at 2023-05-02 12:50:43

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------    
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "leagueapi_id : " + str(leagueapi_id))
    print(space + "season : " + str(season))
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir)   
    # --------------------------------------------------   
    ff_get_fixture_status_match_finished_by_league(leagueapi_id, season, tgl_awal, tgl_akhir, 'xpattern', space) 
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-02 12:50:43
#   __main()
#   ____leagueapi_id : 39
#   ____season : 2022
#   ____days : 7
#   ____days : 1
#   ____tgl_awal : 2023-04-25
#   ____tgl_akhir : 2023-05-01
#   ______ff_get_fixture_status_match_finished_by_league()
#   ________Total Row(s) : 18
#   ________1. 2023-04-27 // 39 // 8 // 2022 // 868266 // 05+075+1+H // 225g25g275gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868266
#   __________> end_ah_pattern = 025+05+075+1+H
#   __________> end_ah_pattern_mirror = 1_075_05_025_H
#   __________> end_gou_pattern = 225g25g275gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________2. 2023-04-25 // 39 // 8 // 2022 // 868267 // 075_05_025_0#H // 225g25g275g3gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868267
#   __________> end_ah_pattern = 05_025_0#025+H
#   __________> end_ah_pattern_mirror = 025_0#025+05+H
#   __________> end_gou_pattern = 25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________3. 2023-04-26 // 39 // 8 // 2022 // 868268 // 05+075+1+125+15+H // 225g25g275g3gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868268
#   __________> end_ah_pattern = 05+075+1+125+H
#   __________> end_ah_pattern_mirror = 125_1_075_05_H
#   __________> end_gou_pattern = 225g25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________4. 2023-04-27 // 39 // 8 // 2022 // 868269 // 025_0#025+05+H // 25g275g3g325gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868269
#   __________> end_ah_pattern = 025_0#025+05+H
#   __________> end_ah_pattern_mirror = 05_025_0#025+H
#   __________> end_gou_pattern = 25g275g3g325g35gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________5. 2023-04-26 // 39 // 8 // 2022 // 868270 // 025+05+075+H // 25g275g3g325gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868270
#   __________> end_ah_pattern = 025+05+075+H
#   __________> end_ah_pattern_mirror = 075_05_025_H
#   __________> end_gou_pattern = 25g275g3g325g35gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________6. 2023-04-25 // 39 // 8 // 2022 // 868271 // 05_025_0#H // 175g2g225g25gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868271
#   __________> end_ah_pattern = 05_025_0#H
#   __________> end_ah_pattern_mirror = 0#025+05+H
#   __________> end_gou_pattern = 175g2g225gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________7. 2023-04-25 // 39 // 8 // 2022 // 868272 // 1_075_05_025_H // 225g25g275g3gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868272
#   __________> end_ah_pattern = 1_075_05_025_H
#   __________> end_ah_pattern_mirror = 025+05+075+1+H
#   __________> end_gou_pattern = 225g25g275gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________8. 2023-04-26 // 39 // 8 // 2022 // 868273 // 1_075_05_025_H // 225g25g275gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868273
#   __________> end_ah_pattern = 1_075_05_H
#   __________> end_ah_pattern_mirror = 05+075+1+H
#   __________> end_gou_pattern = 2g225g25g275gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________9. 2023-04-27 // 39 // 8 // 2022 // 868274 // 05_025_0#H // 2g225g25g275gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868274
#   __________> end_ah_pattern = 05_025_0#025+H
#   __________> end_ah_pattern_mirror = 025_0#025+05+H
#   __________> end_gou_pattern = 225g25g275gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________10. 2023-04-26 // 39 // 8 // 2022 // 868275 // 15_125_1_075_05_H // 25g275g3g325gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868275
#   __________> end_ah_pattern = 125_1_075_05_H
#   __________> end_ah_pattern_mirror = 05+075+1+125+H
#   __________> end_gou_pattern = 225g25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________11. 2023-04-30 // 39 // 8 // 2022 // 868276 // 05_025_0#025+H // 225g25g275g3g325gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868276
#   __________> end_ah_pattern = 05_025_0#025+H
#   __________> end_ah_pattern_mirror = 025_0#025+05+H
#   __________> end_gou_pattern = 225g25g275gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________12. 2023-04-29 // 39 // 8 // 2022 // 868278 // 125_1_075_05_H // 225g25g275gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868278
#   __________> end_ah_pattern = 125_1_075_05_H
#   __________> end_ah_pattern_mirror = 05+075+1+125+H
#   __________> end_gou_pattern = 225g25g275gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________13. 2023-04-29 // 39 // 8 // 2022 // 868279 // 15_125_1_075_H // 25g275g3g325gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868279
#   __________> end_ah_pattern = 15_125_1_075_H
#   __________> end_ah_pattern_mirror = 075+1+125+15+H
#   __________> end_gou_pattern = 25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________14. 2023-04-29 // 39 // 8 // 2022 // 868280 // 025_0#025+H // 2g225g25gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868280
#   __________> end_ah_pattern = 025_0#025+H
#   __________> end_ah_pattern_mirror = 025_0#025+H
#   __________> end_gou_pattern = 175g2g225g25gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________15. 2023-04-30 // 39 // 8 // 2022 // 868281 // 125+15+175+2+225+H // 275g3g325g35gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868281
#   __________> end_ah_pattern = 125+15+175+H
#   __________> end_ah_pattern_mirror = 175_15_125_H
#   __________> end_gou_pattern = 25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________16. 2023-04-30 // 39 // 8 // 2022 // 868283 // 15_125_1_075_H // 275g3g325g35g375gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868283
#   __________> end_ah_pattern = 15_125_1_075_05_H
#   __________> end_ah_pattern_mirror = 05+075+1+125+15+H
#   __________> end_gou_pattern = 3g325g35g375gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________17. 2023-04-30 // 39 // 8 // 2022 // 868284 // 1_075_05_H // 25g275g3g325gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868284
#   __________> end_ah_pattern = 125_1_075_05_025_H
#   __________> end_ah_pattern_mirror = 025+05+075+1+125+H
#   __________> end_gou_pattern = 25g275g3g325g35gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
#   ________18. 2023-04-30 // 39 // 8 // 2022 // 868285 // 2_175_15_125_H // 25g275g3g325gG // Match Finished Ended
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 868285
#   __________> end_ah_pattern = 2_175_15_125_H
#   __________> end_ah_pattern_mirror = 125+15+175+2+H
#   __________> end_gou_pattern = 25g275g3g325g35gG
#   __________> football_fixtures update pattern commited
#   __________> no PL predates get advices
# # -------------------------------------------------- End at 2023-05-02 12:53:22

# %%
from a_settings.messages import *  
from a_models.football_fixtures import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------    
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "leagueapi_id : " + str(leagueapi_id))
    print(space + "season : " + str(season))
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir)   
    # --------------------------------------------------   
    ff_get_fixture_status_match_finished_for_daily_update_patternlist_by_leagueapi_id(leagueapi_id, 
                                                                                      season, tgl_awal, tgl_akhir, space) 
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-02 12:53:22
#   __main()
#   ____leagueapi_id : 39
#   ____season : 2022
#   ____days : 7
#   ____days : 1
#   ____tgl_awal : 2023-04-25
#   ____tgl_akhir : 2023-05-01
#   ______ff_get_fixture_status_match_finished_for_daily_update_patternlist_by_leagueapi_id()
#   ______Select   fixtureapi_id   , teams_home   , teams_away  , leagueapi_id  , pre_ah_pattern  , pre_gou_pattern  , end_ah_pattern  , end_gou_pattern  , season  , pre_ah_pattern_mirror  , end_ah_pattern_mirror  , league_country  , end_odd_updated_at  , fixture_status  from football_fixtures  where date = '39'  and season = '2022'  and date <= '2023-05-01'  and date >= '2023-04-25'  and end_odd_updated_at is not null  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   ________Total Row(s) : 0
# # -------------------------------------------------- End at 2023-05-02 12:53:27
