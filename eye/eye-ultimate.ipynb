# %%
# Import 
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.eye import *      
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    EYE_on_eye(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-27 10:24:03
#   __main()
#   ______EYE_on_eye()
#   ________EYE_delete_duplicate()
#   __________DELETE t1 FROM football_set_eyes t1 INNER JOIN football_set_eyes t2 WHERE t1.id < t2.id AND t1.leagueapi_id = t2.leagueapi_id AND t1.season = t2.season AND t1.fixtureapi_id = t2.fixtureapi_id
#   ________Select  leagueapi_id   , season   , fixtureapi_id   from football_set_eyes  where status = 1
#   __________Total Row(s) : 155
#   ____________[1/155]  #235 __ 2023 __ 1042061
#   ______________EYE_check_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   from football_odds  where leagueapi_id = '235'  and season = '2023'  and fixtureapi_id = '1042061'
#   __________________Total Row(s) : 1
#   ____________________fp_fixtureapi_id()
# ...
