# %%
# Import 

# Import
import sys
sys.path.append('../')


from a_settings.messages import *    
from a_models.football_forecast_pattern import *     
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    leagueapi_id   = input(space + "Enter your leagueapi id :  ")
    season         = input(space + "Enter your season :  ")   
    # --------------------------------------------------    
    ffp_get_fixtures_by_league(leagueapi_id, season, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-26 12:54:33
#   __main()
#   ____Enter your leagueapi id :  39
#   ____Enter your season :  2022
#   ______ffp_get_fixtures_by_league()
#   ________Select  date  , fixtureapi_id  , pre_ah_pattern  , pre_ah_pattern_mirror  , pre_gou_pattern  , end_ah_pattern  , end_ah_pattern_mirror  , end_gou_pattern  from football_odds  where leagueapi_id = '39'  and season = '2022'  and fixture_status in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 380
#   ____________[1/380] 867946 -> 2022-08-05 19:00:00
#   ____________          +025+05+075+1H / -1-075-05-025H / 225g25g275gG
#   ____________          +025+05+075H / -075-05-025H / 20g225g25g275gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 7
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 23
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 26
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 7
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 65
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 46
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 94
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 105
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 14
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 206
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 188
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867946
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[2/380] 867947 -> 2022-08-06 11:30:00
#   ____________          +125+15+175+2+225H / -225-2-175-15-125H / 275g30g325g35g375gG
#   ____________          +125+15+175+2+225H / -225-2-175-15-125H / 275g30g325g35g375gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867947
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867947
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 16
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867947
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 18
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867947
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 10
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867947
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 37
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867947
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 53
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867947
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[3/380] 867948 -> 2022-08-06 14:00:00
#   ____________          +025+05+075H / -075-05-025H / 20g225g25g275gG
#   ____________          +025+05+075H / -075-05-025H / 20g225g25g275gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 8
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 11
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 20
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 55
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 39
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 40
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 113
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 88
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 73
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 206
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 212
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 137
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 446
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 440
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867948
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[4/380] 867949 -> 2022-08-06 14:00:00
#   ____________          -05-025+0H / +0+025+05H / 225g25g275gG
#   ____________          -05-025+0+025H / -025+0+025+05H / 225g25g275gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 13
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 8
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 9
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 14
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 104
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 92
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 73
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 61
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 55
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 542
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 542
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 19
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 250
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 252
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867949
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[5/380] 867951 -> 2022-08-06 14:00:00
#   ____________          -125-1-075-05H / +05+075+1+125H / 225g25g275gG
#   ____________          -1-075-05H / +05+075+1H / 225g25g275gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 12
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 11
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 7
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 82
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 79
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 16
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 16
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 23
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 336
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 340
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 9
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 86
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 79
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867951
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[6/380] 867952 -> 2022-08-06 14:00:00
#   ____________          -15-125H / +125+15H / 25g275g30gG
#   ____________          -15-125H / +125+15H / 25g275g30g35gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ____________[7/380] 867953 -> 2022-08-06 16:30:00
#   ____________          +05+075+1+125H / -125-1-075-05H / 225g25g275gG
#   ____________          +05+075+1+125H / -125-1-075-05H / 20g225g25g275gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 12
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 11
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 19
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 17
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 78
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 66
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 7
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 103
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 89
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 16
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 286
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 279
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867953
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[8/380] 867950 -> 2022-08-07 13:00:00
#   ____________          -075-05-025H / +025+05+075H / 225g25g275g30gG
#   ____________          -075-05-025H / +025+05+075H / 225g25g275g30gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 11
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 7
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 7
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 21
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 62
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 56
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 26
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 16
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 158
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 500
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 434
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 50
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 182
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 156
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867950
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[9/380] 867954 -> 2022-08-07 13:00:00
#   ____________          -125-1-075-05H / +05+075+1+125H / 225g25g275gG
#   ____________          -125-1-075-05H / +05+075+1+125H / 225g25g275g30gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 12
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 11
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 7
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 82
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 79
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 16
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 16
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 23
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 336
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 340
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 86
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 79
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867954
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[10/380] 867955 -> 2022-08-07 15:30:00
#   ____________          +1+125+15+175H / -175-15-125-1H / 25g275g30g325g35gG
#   ____________          +1+125+15+175H / -175-15-125-1H / 275g30g325g35gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 9
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867955
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867955
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 9
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867955
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 11
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867955
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 35
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867955
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 41
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867955
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867955
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 105
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867955
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 111
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 867955
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[11/380] 867957 -> 2022-08-13 11:30:00
#   ____________          -1-075-05-025H / +025+05+075+1H / 20g225g25gG
# ...
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868321
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 16
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868321
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 301
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868321
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 272
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868321
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868321
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 74
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868321
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 76
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868321
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[377/380] 868322 -> 2023-05-28 15:30:00
#   ____________          -025+0+025+05H / -05-025+0+025H / 275g30g325g35g375gG
#   ____________          -025+0+025+05H / -05-025+0+025H / 275g30g325g35gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 7
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868322
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 19
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868322
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 9
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868322
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868322
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[378/380] 868323 -> 2023-05-28 15:30:00
#   ____________          -075-05-025+0H / +0+025+05+075H / 25g275g30g325g35gG
#   ____________          -075-05-025+0H / +0+025+05+075H / 275g30g325g35gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868323
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868323
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868323
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868323
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 44
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868323
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 48
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868323
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 33
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868323
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 31
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868323
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[379/380] 868324 -> 2023-05-28 15:30:00
#   ____________          -15-125-1-075H / +075+1+125+15H / 275g30g325g35g375gG
#   ____________          -175-15-125-1-075H / +075+1+125+15+175H / 30g325g35g375gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 11
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868324
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868324
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868324
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868324
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868324
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 90
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868324
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 134
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868324
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 51
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868324
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 57
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868324
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[380/380] 868325 -> 2023-05-28 15:30:00
#   ____________          +075+1+125+15+175H / -175-15-125-1-075H / 30g325g35g375g40gG
#   ____________          +075+1+125+15+175H / -175-15-125-1-075H / 30g325g35g375g40gG
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868325
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868325
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868325
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 9
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868325
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 15
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868325
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 33
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868325
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 36
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868325
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 23
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868325
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 56
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868325
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 57
#   ____________________ffp_check()
#   ____________________leagueapi_id : 39
#   ____________________season : 2022
#   ____________________fixtureapi_id : 868325
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
# # -------------------------------------------------- End at 2023-07-26 21:28:18
