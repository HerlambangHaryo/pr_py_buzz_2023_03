# %%
# Import
from a_settings.messages import *   

today = datetime.datetime.now()  
days0 = 6
days1 = 5
print("Date ready " + str(days0) + " - " + str(days1) + " --> " + str(today) )
# Out:
# Date ready 6 - 5 --> 2023-05-11 21:32:32.521651

# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    day0         = get_today_subs(days0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(days1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_check_enddates(day0, day1, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-11 21:32:33
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 6
#   ________today_raw : 2023-05-05 21:32:33.968772
#   ______get_today_subs()
#   ________subs date_diff : 5
#   ________today_raw : 2023-05-06 21:32:33.969773
#   ______fO_check_enddates()
#   ________Select  leagueapi_id as lg  , season as ss  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_homeapi_id) as home  , (select SUBSTR(name, 1, 7) from football_teams where teamapi_id = teams_awayapi_id) as away  , SUBSTR(fixture_status, 1, 15)  as fs  , end_response as pr  , end_ah_pattern as ah  , end_gou_pattern as gou  from football_odds  where date >= '2023-05-05'  and date <= '2023-05-06'  and end_response is null  and deleted_at is null  order by date asc
#   ________Total Row(s) : 90
#
#      lg    ss     home     away               fs    pr    ah   gou
# ...

# %%
from a_settings.messages import *  
from a_models.football_odds import *  

def get_date(space):  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "get_date()")
    # ----------------------------------------------------------  
    today = datetime.datetime.now()  
    today_day = today.strftime("%Y-%m-%d")   
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days0)
    week = today - DD
    tgl_awal = week.strftime("%Y-%m-%d") 
    # ----------------------------------------------------------  
    DD = datetime.timedelta(days=days1)
    yesterday = today - DD
    tgl_akhir = yesterday.strftime("%Y-%m-%d")  
    # ----------------------------------------------------------  
    space += "__"
    # ----------------------------------------------------------  
    print(space + "today : " + str(today_day))
    print(space + "days : " + str(days0))
    print(space + "days : " + str(days1))
    print(space + "tgl_awal : " + tgl_awal)
    print(space + "tgl_akhir : " + tgl_akhir) 
    # ---------------------------------------------------------- 
    fO_get_group_league_status_match_finished(tgl_awal, tgl_akhir, today_day, space)
    # ---------------------------------------------------------- 
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-11 21:32:36
#   __main()
#   ____get_date()
#   ______today : 2023-05-11
#   ______days : 6
#   ______days : 5
#   ______tgl_awal : 2023-05-05
#   ______tgl_akhir : 2023-05-06
#   ________fO_get_group_league_status_match_finished()
#   ________Select  DATE(date)  , leagueapi_id , (select bookmakersapi_id from football_leagues where leagueapi_id = football_odds.leagueapi_id)  , season , DATE(end_odd_updated_at)  , fixture_status   from football_odds  where  date <= '2023-05-06'  and date >= '2023-05-05'  and fixture_status like 'Match Finished'  and deleted_at is null  and DATE(end_odd_updated_at) < DATE('2023-05-11')  group by DATE(date), leagueapi_id, season  order by leagueapi_id
#   __________Total Row(s) : 0
#   __________Are you sure want to continue? :  yes
# # -------------------------------------------------- End at 2023-05-11 21:34:18

# %%
from a_settings.messages import *  
from a_models.date import *   
from a_models.football_odds import *  
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    space += "__" 
    # --------------------------------------------------   
    tgl_awal         = get_today_subs(days0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    tgl_akhir        = get_today_subs(days1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    today_day        = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_get_fixture_status_match_finished(tgl_awal, tgl_akhir, today_day, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-11 21:34:18
#   __main()
#   ______get_today_subs()
#   ________subs date_diff : 6
#   ________today_raw : 2023-05-05 21:34:18.340137
#   ______get_today_subs()
#   ________subs date_diff : 5
#   ________today_raw : 2023-05-06 21:34:18.342138
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-05-11 21:34:18.344647
#   ______fO_get_fixture_status_match_finished()
#   ______Select  DATE(date)  , leagueapi_id , (select bookmakersapi_id from football_leagues where leagueapi_id = football_odds.leagueapi_id)  , season , DATE(end_odd_updated_at)  , fixture_status   , fixtureapi_id   from football_odds  where  date <= '2023-05-06'  and date >= '2023-05-05'  and end_response is null  and deleted_at is null  order by date
#   ________Total Row(s) : 90
#   __________fO_get_fixture_status_match_finished_DETAILED()
#   __________Total Row(s) : 90
#
# ...

# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    day0         = get_today_subs(days0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_subs(days1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------   
    fO_check_enddates(day0, day1, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
