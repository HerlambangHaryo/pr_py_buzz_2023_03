# %%
# 1. kalibrasi end pattern
# 2. delete patternlist only ends
# 3. insert and kalibrasi patternlist
###

# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "____"  
    # ----------------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
    ff_get_fixtures_group_by_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-28 21:44:06
#   ____main__
#   ______Enter your leagueapi id :  39
#   ________ff_get_fixtures_group_by_end_patternlists()
#   __________Select  end_ah_pattern  , end_gou_pattern  , count(*)  from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and pre_ah_pattern is not null  and pre_gou_pattern is not null  and end_ah_pattern is not null  and end_gou_pattern is not null  group by pre_ah_pattern, pre_gou_pattern, end_ah_pattern, end_gou_pattern  order by count(*) desc
#   ____________Total Row(s) : 417
#   ______________214. H // G
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like 'H'  and end_gou_pattern like 'G'
#   ________________________Total Row(s) : 242
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 242
#   ____________________________patternlists updated
#   ______________10. 075_05_025_H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 15
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 15
#   ____________________________patternlists updated
#   ______________6. 125_1_075_05_H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '125_1_075_05_H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 11
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 11
#   ____________________________patternlists updated
#   ______________6. 025+05+075+H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025+05+075+H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 9
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 9
#   ____________________________patternlists updated
#   ______________5. 025_0#025+H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025_0#025+H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 5
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 5
#   ____________________________patternlists updated
#   ______________4. 125_1_075_05_H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '125_1_075_05_H'  and end_gou_pattern like '25g275g3g325gG'
#   ________________________Total Row(s) : 6
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 6
#   ____________________________patternlists updated
#   ______________4. 05_025_0#H // 2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#H'  and end_gou_pattern like '2g225g25gG'
#   ________________________Total Row(s) : 10
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 10
#   ____________________________patternlists updated
#   ______________4. 075_05_025_H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_H'  and end_gou_pattern like '2g225g25g275gG'
#   ________________________Total Row(s) : 11
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 11
#   ____________________________patternlists updated
#   ______________4. 05_025_0#025+H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#025+H'  and end_gou_pattern like '25g275g3g325gG'
#   ________________________Total Row(s) : 7
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 7
#   ____________________________patternlists updated
#   ______________3. 05_025_0#025+H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#025+H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 6
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 6
#   ____________________________patternlists updated
#   ______________3. 025+05+075+1+H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025+05+075+1+H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 5
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 5
#   ____________________________patternlists updated
#   ______________3. 1_075_05_H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '1_075_05_H'  and end_gou_pattern like '2g225g25g275gG'
#   ________________________Total Row(s) : 6
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 6
#   ____________________________patternlists updated
#   ______________3. 025+05+075+H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025+05+075+H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 5
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 5
#   ____________________________patternlists updated
#   ______________3. 1_075_05_025_H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '1_075_05_025_H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 5
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 5
#   ____________________________patternlists updated
#   ______________3. 0#025+05+075+H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '0#025+05+075+H'  and end_gou_pattern like '25g275g3g325gG'
#   ________________________Total Row(s) : 3
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 3
#   ____________________________patternlists updated
#   ______________3. 05_025_0#H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 8
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 8
#   ____________________________patternlists updated
#   ______________3. 125_1_075_05_H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '125_1_075_05_H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 11
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 11
#   ____________________________patternlists updated
#   ______________3. 05_025_0#H // 2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#H'  and end_gou_pattern like '2g225g25gG'
#   ______________________Total Row(s) : 10
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 10
#   __________________________patternlists updated
#   ______________3. 15_125_1_075_H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '15_125_1_075_H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 7
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 7
#   ____________________________patternlists updated
#   ______________3. 125_1_075_05_H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '125_1_075_05_H'  and end_gou_pattern like '225g25g275g3gG'
#   ______________________Total Row(s) : 11
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 11
#   __________________________patternlists updated
#   ______________3. 025+05+075+H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025+05+075+H'  and end_gou_pattern like '2g225g25g275gG'
#   ________________________Total Row(s) : 6
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 6
#   ____________________________patternlists updated
#   ______________3. 0#025+05+H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '0#025+05+H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 6
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 6
#   ____________________________patternlists updated
#   ______________3. 075_05_025_H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_H'  and end_gou_pattern like '2g225g25g275gG'
#   ______________________Total Row(s) : 11
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 11
#   __________________________patternlists updated
#   ______________3. 075_05_025_H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_H'  and end_gou_pattern like '225g25g275gG'
#   ______________________Total Row(s) : 15
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 15
#   __________________________patternlists updated
#   ______________3. 075_05_025_H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 7
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 7
#   ____________________________patternlists updated
#   ______________3. 025_0#025+05+H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025_0#025+05+H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 7
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 7
#   ____________________________patternlists updated
#   ______________3. 025_0#025+H // 175g2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025_0#025+H'  and end_gou_pattern like '175g2g225g25gG'
#   ________________________Total Row(s) : 7
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 7
#   ____________________________patternlists updated
#   ______________3. 025_0#025+05+H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025_0#025+05+H'  and end_gou_pattern like '2g225g25g275gG'
#   ________________________Total Row(s) : 5
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 5
#   ____________________________patternlists updated
#   ______________2. 125+15+175+2+H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '125+15+175+2+H'  and end_gou_pattern like '25g275g3g325gG'
#   ________________________Total Row(s) : 2
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 2
#   ____________________________patternlists updated
#   ______________2. 05_025_0#H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#H'  and end_gou_pattern like '2g225g25g275gG'
#   ________________________Total Row(s) : 4
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 4
#   ____________________________patternlists updated
#   ______________2. H // G
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like 'H'  and end_gou_pattern like 'G'
#   ______________________Total Row(s) : 242
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 242
#   __________________________patternlists updated
#   ______________2. 05_025_0#025+H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#025+H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 8
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 8
#   ____________________________patternlists updated
#   ______________2. 15_125_1_H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '15_125_1_H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 3
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 3
#   ____________________________patternlists updated
#   ______________2. 1_075_05_H // 2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '1_075_05_H'  and end_gou_pattern like '2g225g25gG'
#   ________________________Total Row(s) : 3
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 3
#   ____________________________patternlists updated
#   ______________2. 15_125_1_075_H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '15_125_1_075_H'  and end_gou_pattern like '225g25g275g3gG'
#   ______________________Total Row(s) : 7
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 7
#   __________________________patternlists updated
#   ______________2. 025_0#025+H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025_0#025+H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 3
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 3
#   ____________________________patternlists updated
#   ______________2. 025_0#025+05+H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025_0#025+05+H'  and end_gou_pattern like '225g25g275gG'
#   ______________________Total Row(s) : 7
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 7
#   __________________________patternlists updated
#   ______________2. 1_075_05_H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '1_075_05_H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 6
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 6
#   ____________________________patternlists updated
#   ______________2. 0#025+05+H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '0#025+05+H'  and end_gou_pattern like '2g225g25g275gG'
#   ________________________Total Row(s) : 8
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 8
#   ____________________________patternlists updated
#   ______________2. 075_05_025_H // 175g2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_H'  and end_gou_pattern like '175g2g225g25gG'
#   ________________________Total Row(s) : 2
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 2
#   ____________________________patternlists updated
#   ______________2. 025_0#025+H // 175g2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025_0#025+H'  and end_gou_pattern like '175g2g225g25gG'
#   ______________________Total Row(s) : 7
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 7
#   __________________________patternlists updated
#   ______________2. 225_2_175_15_H // 25g275g3g325g35gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '225_2_175_15_H'  and end_gou_pattern like '25g275g3g325g35gG'
#   ________________________Total Row(s) : 4
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 4
#   ____________________________patternlists updated
#   ______________2. 075_05_025_H // 2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_H'  and end_gou_pattern like '2g225g25gG'
#   ________________________Total Row(s) : 6
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 6
#   ____________________________patternlists updated
#   ______________2. 175_15_125_1_H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '175_15_125_1_H'  and end_gou_pattern like '25g275g3g325gG'
#   ________________________Total Row(s) : 7
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 7
#   ____________________________patternlists updated
#   ______________2. H // G
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like 'H'  and end_gou_pattern like 'G'
#   ______________________Total Row(s) : 242
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 242
#   __________________________patternlists updated
#   ______________2. 15_125_1_075_H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '15_125_1_075_H'  and end_gou_pattern like '25g275g3g325gG'
#   ________________________Total Row(s) : 7
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 7
#   ____________________________patternlists updated
#   ______________2. 05_025_0#025+H // 2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#025+H'  and end_gou_pattern like '2g225g25gG'
#   ________________________Total Row(s) : 4
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 4
#   ____________________________patternlists updated
#   ______________2. 15_125_1_075_H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '15_125_1_075_H'  and end_gou_pattern like '25g275g3g325gG'
#   ______________________Total Row(s) : 7
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 7
#   __________________________patternlists updated
#   ______________2. 1_075_05_025_H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '1_075_05_025_H'  and end_gou_pattern like '25g275g3g325gG'
#   ________________________Total Row(s) : 3
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 3
#   ____________________________patternlists updated
#   ______________2. 125_1_075_05_H // 2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '125_1_075_05_H'  and end_gou_pattern like '2g225g25gG'
#   ________________________Total Row(s) : 2
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 2
#   ____________________________patternlists updated
#   ______________2. H // G
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like 'H'  and end_gou_pattern like 'G'
#   ______________________Total Row(s) : 242
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 242
#   __________________________patternlists updated
#   ______________2. 05_025_0#H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 4
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 4
#   ____________________________patternlists updated
#   ______________2. 125_1_075_05_H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '125_1_075_05_H'  and end_gou_pattern like '225g25g275g3gG'
#   ______________________Total Row(s) : 11
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 11
#   __________________________patternlists updated
#   ______________2. 075_05_025_H // 2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_H'  and end_gou_pattern like '2g225g25gG'
#   ______________________Total Row(s) : 6
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 6
#   __________________________patternlists updated
#   ______________2. 075_05_025_0#H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_0#H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 6
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 6
#   ____________________________patternlists updated
#   ______________2. 1_075_05_025_H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '1_075_05_025_H'  and end_gou_pattern like '2g225g25g275gG'
#   ________________________Total Row(s) : 2
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 2
#   ____________________________patternlists updated
#   ______________2. 125_1_075_05_H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '125_1_075_05_H'  and end_gou_pattern like '225g25g275gG'
#   ______________________Total Row(s) : 11
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 11
#   __________________________patternlists updated
#   ______________2. 25_225_2_175_15_H // 275g3g325g35gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '25_225_2_175_15_H'  and end_gou_pattern like '275g3g325g35gG'
#   ________________________Total Row(s) : 3
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 3
#   ____________________________patternlists updated
#   ______________2. 025_0#025+05+H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025_0#025+05+H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 3
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 3
#   ____________________________patternlists updated
#   ______________2. 025+05+075+H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025+05+075+H'  and end_gou_pattern like '25g275g3g325gG'
#   ________________________Total Row(s) : 5
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 5
#   ____________________________patternlists updated
#   ______________2. 05_025_0#H // 225g25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#H'  and end_gou_pattern like '225g25g275g3g325gG'
#   ________________________Total Row(s) : 3
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 3
#   ____________________________patternlists updated
#   ______________2. 1_075_05_025_H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '1_075_05_025_H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 4
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 4
#   ____________________________patternlists updated
#   ______________2. 075_05_025_0#H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_0#H'  and end_gou_pattern like '225g25g275g3gG'
#   ________________________Total Row(s) : 2
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 2
#   ____________________________patternlists updated
#   ______________2. 0#025+05+H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '0#025+05+H'  and end_gou_pattern like '225g25g275gG'
#   ______________________Total Row(s) : 6
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 6
#   __________________________patternlists updated
#   ______________2. 05+075+1+125+H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05+075+1+125+H'  and end_gou_pattern like '225g25g275gG'
#   ________________________Total Row(s) : 3
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 3
#   ____________________________patternlists updated
#   ______________2. 05+075+1+125+H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05+075+1+125+H'  and end_gou_pattern like '25g275g3g325gG'
#   ________________________Total Row(s) : 3
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 3
# ...
#   ______________________Total Row(s) : 5
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 5
#   __________________________patternlists updated
#   ______________1. 175_15_125_1_H // 275g3g325g35gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '175_15_125_1_H'  and end_gou_pattern like '275g3g325g35gG'
#   ______________________Total Row(s) : 6
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 6
#   __________________________patternlists updated
#   ______________1. 025+05+075+H // 2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025+05+075+H'  and end_gou_pattern like '2g225g25gG'
#   ______________________Total Row(s) : 2
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 2
#   __________________________patternlists updated
#   ______________1. 0#025+05+075+H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '0#025+05+075+H'  and end_gou_pattern like '225g25g275gG'
#   ______________________Total Row(s) : 3
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 3
#   __________________________patternlists updated
#   ______________1. 075_05_025_H // 225g25g275g3gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_H'  and end_gou_pattern like '225g25g275g3gG'
#   ______________________Total Row(s) : 7
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 7
#   __________________________patternlists updated
#   ______________1. 125+15+175+H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '125+15+175+H'  and end_gou_pattern like '25g275g3g325gG'
#   ________________________Total Row(s) : 1
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 1
#   ____________________________patternlists updated
#   ______________1. 05+075+1+125+H // 275g3g325g35g375gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05+075+1+125+H'  and end_gou_pattern like '275g3g325g35g375gG'
#   ________________________Total Row(s) : 1
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 1
#   ____________________________patternlists updated
#   ______________1. 05+075+1+125+H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05+075+1+125+H'  and end_gou_pattern like '2g225g25g275gG'
#   ______________________Total Row(s) : 3
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 3
#   __________________________patternlists updated
#   ______________1. H // G
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like 'H'  and end_gou_pattern like 'G'
#   ______________________Total Row(s) : 242
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 242
#   __________________________patternlists updated
#   ______________1. 15_125_1_075_05_H // 25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '15_125_1_075_05_H'  and end_gou_pattern like '25g275g3g325gG'
#   ______________________Total Row(s) : 5
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 5
#   __________________________patternlists updated
#   ______________1. 0#025+05+H // 2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '0#025+05+H'  and end_gou_pattern like '2g225g25gG'
#   ______________________Total Row(s) : 3
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 3
#   __________________________patternlists updated
#   ______________1. H // G
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like 'H'  and end_gou_pattern like 'G'
#   ______________________Total Row(s) : 242
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 242
#   __________________________patternlists updated
#   ______________1. 05_025_0#025+H // 25g275g3g325g35gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#025+H'  and end_gou_pattern like '25g275g3g325g35gG'
#   ______________________Total Row(s) : 2
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 2
#   __________________________patternlists updated
#   ______________1. 225_2_175_15_125_H // 275g3g325g35gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '225_2_175_15_125_H'  and end_gou_pattern like '275g3g325g35gG'
#   ________________________Total Row(s) : 1
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 1
#   ____________________________patternlists updated
#   ______________1. 075_05_025_H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '075_05_025_H'  and end_gou_pattern like '2g225g25g275gG'
#   ______________________Total Row(s) : 11
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 11
#   __________________________patternlists updated
#   ______________1. 15_125_1_075_H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '15_125_1_075_H'  and end_gou_pattern like '225g25g275gG'
#   ______________________Total Row(s) : 3
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 3
#   __________________________patternlists updated
#   ______________1. 0#025+05+075+H // 2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '0#025+05+075+H'  and end_gou_pattern like '2g225g25gG'
#   ________________________Total Row(s) : 1
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 1
#   ____________________________patternlists updated
#   ______________1. 05_025_0#H // 175g2g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '05_025_0#H'  and end_gou_pattern like '175g2g225g25gG'
#   ______________________Total Row(s) : 4
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 4
#   __________________________patternlists updated
#   ______________1. 025_0#025+H // 175g225g25gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 0
#   ______________________insert commited
#   ______________________paN_get_fixtures_only_ends()
#   ________________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '025_0#025+H'  and end_gou_pattern like '175g225g25gG'
#   ________________________Total Row(s) : 1
#   __________________________paN_final_assestment()
#   ____________________________Total Row(s) : 1
#   ____________________________patternlists updated
#   ______________1. 125_1_075_05_H // 225g25g275g3g325gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '125_1_075_05_H'  and end_gou_pattern like '225g25g275g3g325gG'
#   ______________________Total Row(s) : 4
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 4
#   __________________________patternlists updated
#   ______________1. 15_125_1_H // 225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '15_125_1_H'  and end_gou_pattern like '225g25g275gG'
#   ______________________Total Row(s) : 2
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 2
#   __________________________patternlists updated
#   ______________1. 0#025+05+075+H // 2g225g25g275gG
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like '0#025+05+075+H'  and end_gou_pattern like '2g225g25g275gG'
#   ______________________Total Row(s) : 2
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 2
#   __________________________patternlists updated
#   ______________1. H // G
#   ________________plN_check_patternlist_only_ends()
#   __________________Total Row(s) : 1
#   ____________________Already Data
#   ____________________paN_get_fixtures_only_ends()
#   ______________________Select   goals_home,  goals_away,  score_halftime_home,  score_halftime_away   from football_odds  where leagueapi_id = '39'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and end_ah_pattern like 'H'  and end_gou_pattern like 'G'
#   ______________________Total Row(s) : 242
#   ________________________paN_final_assestment()
#   __________________________Total Row(s) : 242
#   __________________________patternlists updated
# # -------------------------------------------------- End at 2023-05-28 21:51:27
