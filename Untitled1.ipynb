# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.prematch_odds import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_adds(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    today       = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    po_league_group(day1, day2, today, space) 
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-05 11:34:36
#   __main()
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-08-05 11:34:36.364033
#   ____get_today_adds()
#   ______adds date_diff : 1
#   ______today_raw : 2023-08-06 11:34:36.364033
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-08-05 11:34:36.366539
#   ____po_league_group()
#   ____Select  leagueapi_id  , season   , count(*)   from football_fixtures  where date >= Date('2023-08-05')  and date <= Date('2023-08-06')  and deleted_at is null  and fixture_status not in ('Not Started', 'Not Started Goto' )  group by leagueapi_id, season  order by date, leagueapi_id asc
#   ____Total Row(s) : 8
#   ____[1/8]  #131 - 2023
#                countrows: 2
#                day1: 2023-08-05
#                day2: 2023-08-06
#                ROUTES: leagueapi_id
#   ___________________________________________________
#   ____[2/8]  #132 - 2023
#                countrows: 9
#                day1: 2023-08-05
#                day2: 2023-08-06
#                ROUTES: leagueapi_id
#   ___________________________________________________
#   ____[3/8]  #667 - 2023
#                countrows: 8
#                day1: 2023-08-05
#                day2: 2023-08-06
#                ROUTES: leagueapi_id
#   ___________________________________________________
#   ____[4/8]  #315 - 2023
#                countrows: 3
#                day1: 2023-08-05
#                day2: 2023-08-06
#                ROUTES: leagueapi_id
#   ___________________________________________________
#   ____[5/8]  #374 - 2023
#                countrows: 4
#                day1: 2023-08-05
#                day2: 2023-08-06
#                ROUTES: leagueapi_id
#   ___________________________________________________
#   ____[6/8]  #134 - 2023
#                countrows: 1
#                day1: 2023-08-05
#                day2: 2023-08-06
#                ROUTES: leagueapi_id
#   ___________________________________________________
#   ____[7/8]  #242 - 2023
#                countrows: 2
#                day1: 2023-08-05
#                day2: 2023-08-06
#                ROUTES: leagueapi_id
#   ___________________________________________________
#   ____[8/8]  #772 - 2023
#                countrows: 1
#                day1: 2023-08-05
#                day2: 2023-08-06
#                ROUTES: leagueapi_id
#   ___________________________________________________
# # -------------------------------------------------- End at 2023-08-05 11:34:36
