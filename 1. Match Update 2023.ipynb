# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.football_odds import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_subs(7, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_subs(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    todayx       = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    fO_get_league_group_fixture_status_not_in_match_finished(day1, day2, todayx, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-31 10:29:29
#   __main()
#   ____get_today_subs()
#   ______subs date_diff : 7
#   ______today_raw : 2023-07-24 10:29:29.325401
#   ____get_today_subs()
#   ______subs date_diff : 1
#   ______today_raw : 2023-07-30 10:29:29.325401
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-07-31 10:29:29.327406
#   ____fO_get_league_group_fixture_status_not_in_match_finished()
#   ____ Select  leagueapi_id  , season   from football_odds  where date <= Date('2023-07-30')  and date >= Date('2023-07-24')  and deleted_at is null  and fixture_status not in ('Match Finished', 'Match Finished Ended' )  group by leagueapi_id, season  order by date, leagueapi_id asc
#   ____Total Row(s) : 81
#   ____[1/81]  #667 - 2023 - 2023
#   ______af_controll_match_update()
#   ________aa_check_acccount()
#   __________API api1@ariondigitalmedia.com counter is 36
# ...
