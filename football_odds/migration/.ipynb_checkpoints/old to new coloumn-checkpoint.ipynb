# %%
# update fixture_status

# %%
import mysql.connector 

# ------------------------------------------------------
space = "__"
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " leagueapi_id "
query += " , season  "
query += " , fixtureapi_id  " 
query += " from football_odds_xx "  
# ------------------------------------------------------   
print(query, flush=True)
# ------------------------------------------------------    
mycursor.execute(query)
result =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result)
# ------------------------------------------------------    
mycursor.close()
mydb.close()  
# ------------------------------------------------------
for x in result: 
    # -------------------------------------------------- 
    leagueapi_id = str(x[0])
    season = str(x[1])
    fixtureapi_id = str(x[2]) 
    # --------------------------------------------------    
    word = space + '__#' + str(leagueapi_id)
    word += ' - ' + str(season)
    word += ' => ' + str(fixtureapi_id)
    # --------------------------------------------------    
    print(word, flush=True)  
    # --------------------------------------------------
    # --------------------------------------------------   
    host="localhost"
    user="root" 
    database="pr_mmbuzz_2022_06"
    mydb2 = mysql.connector.connect(host=host,user=user,password="",database=database)
    mycursor2 = mydb2.cursor()
    # --------------------------------------------------   
    query2 = "select "
    query2 += " leagueapi_id "
    query2 += " , season  "
    query2 += " , fixtureapi_id  " 
    query2 += " , fixture_status  " 
    query2 += " , count(*)  " 
    query2 += " from football_fixtures "   
    query2 += " where leagueapi_id = '"+str(leagueapi_id)+"' "   
    query2 += " and season = '"+str(season)+"' "   
    query2 += " and fixtureapi_id = '"+str(fixtureapi_id)+"' "   
    # --------------------------------------------------   
    print("____" + query2, flush=True)
    # --------------------------------------------------    
    mycursor2.execute(query2) 
    result2 = mycursor2.fetchone()
    # --------------------------------------------------   
    mycursor2.close()
    mydb2.close()  
    # --------------------------------------------------      
    total_rows2 = result2[4]
    fixture_status = result2[3]
    # --------------------------------------------------     
    word = space + '______total_rows2: ' + str(total_rows2)      
    print(word, flush=True)   
    # --------------------------------------------------     
    word = space + '______fixture_status: ' + str(fixture_status)      
    print(word, flush=True)   
    # --------------------------------------------------  
    # --------------------------------------------------   
    # --------------------------------------------------   
    host="localhost"
    user="root" 
    database="pr_mmbuzz_2022_06"
    mydb3 = mysql.connector.connect(host=host,user=user,password="",database=database)
    mycursor3 = mydb3.cursor()
    # --------------------------------------------------    
    unfinished = " UPDATE `football_odds_xx` SET "   
    unfinished += " fixture_status  = '"+str(fixture_status)+"' " 
    unfinished += " WHERE fixtureapi_id = '"+str(fixtureapi_id)+"' " 
    unfinished += " AND leagueapi_id = '"+str(leagueapi_id)+"' " 
    unfinished += " AND season = '"+str(season)+"' " 
    # --------------------------------------------------  
    mycursor3.execute(unfinished)
    mydb3.commit()      
    # --------------------------------------------------   
    mycursor3.close()
    mydb3.close()  
    # --------------------------------------------------  
    # --------------------------------------------------  
    # --------------------------------------------------       
    word = ''
    print(word, flush=True)   
    # --------------------------------------------------   
# ------------------------------------------------------
# Out:
# select  leagueapi_id  , season   , fixtureapi_id   from football_odds_xx
# ____#474 - 2023 => 980001
# ____select  leagueapi_id  , season   , fixtureapi_id   , fixture_status   , count(*)   from football_fixtures  where leagueapi_id = '474'  and season = '2023'  and fixtureapi_id = '980001'
# ________total_rows2: 1
# ________fixture_status: Not Started
#
# ____#474 - 2023 => 980002
# ____select  leagueapi_id  , season   , fixtureapi_id   , fixture_status   , count(*)   from football_fixtures  where leagueapi_id = '474'  and season = '2023'  and fixtureapi_id = '980002'
# ________total_rows2: 1
# ________fixture_status: Not Started
#
# ____#164 - 2023 => 981557
# ____select  leagueapi_id  , season   , fixtureapi_id   , fixture_status   , count(*)   from football_fixtures  where leagueapi_id = '164'  and season = '2023'  and fixtureapi_id = '981557'
# ________total_rows2: 1
# ________fixture_status: Not Started
#
# ____#164 - 2023 => 981559
# ...

# %%
import mysql.connector 

# Import
import sys
sys.path.append('../../')
 
from a_models.array_col import *  

# ------------------------------------------------------
space = "__"
# ------------------------------------------------------ 
array_col = array_col_football_odds()
# ------------------------------------------------------
counter = 0
# ------------------------------------------------------
for x in array_col:  
    # --------------------------------------------------   
    # query += " leagueapi_id " 
    # --------------------------------------------------  
    counter += 1
    # --------------------------------------------------  
    helper = "'"
    word = 'query += " , ' + str(x) + ' "' + " #" + str(counter)
    print(word, flush=True)  
    # --------------------------------------------------   
    # --------------------------------------------------   
    # --------------------------------------------------   
# ------------------------------------------------------
# Out:
# query += " , pre_match_winner_home " #1
# query += " , pre_match_winner_draw " #2
# query += " , pre_match_winner_away " #3
# query += " , end_match_winner_home " #4
# query += " , end_match_winner_draw " #5
# query += " , end_match_winner_away " #6
# query += " , pre_homeaway_home " #7
# query += " , pre_homeaway_away " #8
# query += " , end_homeaway_home " #9
# query += " , end_homeaway_away " #10
# query += " , pre_first_half_winner_home " #11
# query += " , pre_first_half_winner_draw " #12
# query += " , pre_first_half_winner_away " #13
# query += " , end_first_half_winner_home " #14
# query += " , end_first_half_winner_draw " #15
# query += " , end_first_half_winner_away " #16
# query += " , pre_second_half_winner_home " #17
# query += " , pre_second_half_winner_draw " #18
# query += " , pre_second_half_winner_away " #19
# query += " , end_second_half_winner_home " #20
# query += " , end_second_half_winner_draw " #21
# query += " , end_second_half_winner_away " #22
# ...

# %%
import mysql.connector 

# Import
import sys
sys.path.append('../../')
 
from a_models.array_col import *  

# ------------------------------------------------------
space = "__"
# ------------------------------------------------------ 
array_col = array_col_football_odds()
# ------------------------------------------------------
counter = 0
# ------------------------------------------------------
for x in array_col:  
    # --------------------------------------------------   
    # counter_col += 1
    # if(rs1[counter_col] is None):
    #     asian_handicap_away_min_5 = 'Null'
    # elif(rs1[counter_col] is not None):
    #     asian_handicap_away_min_5 = "'" + str(rs1[counter_col]).replace("'", "\\'") + "'" 
    
    # --------------------------------------------------  
    counter += 1
    # --------------------------------------------------  
    helper = "'"
    helper2 = '"'
    # --------------------------------------------------  
    word = 'counter_col += 1'  + ' #' + str(counter)
    print(word, flush=True)  
    # --------------------------------------------------  
    word = 'if(rs1[counter_col] is None):' 
    print(word, flush=True)  
    # --------------------------------------------------  
    word = '    '+str(x)+' = "Null"' 
    print(word, flush=True)  
    # --------------------------------------------------  
    word = 'elif(rs1[counter_col] is not None):' 
    print(word, flush=True)  
    # --------------------------------------------------  
    word = '    ' + str(x) + ' = '+helper +helper2 +helper+' + str(rs1[counter_col])'
    word += '.replace("'+helper+'", "\\'+helper+'") + '+helper +helper2 +helper
    print(word, flush=True)   
    # --------------------------------------------------  
    word = ''
    print(word, flush=True)  
    # --------------------------------------------------   
    # --------------------------------------------------   
    # --------------------------------------------------   
# ------------------------------------------------------
# Out:
# counter_col += 1 #1
# if(rs1[counter_col] is None):
#     pre_match_winner_home = "Null"
# elif(rs1[counter_col] is not None):
#     pre_match_winner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'
#
# counter_col += 1 #2
# if(rs1[counter_col] is None):
#     pre_match_winner_draw = "Null"
# elif(rs1[counter_col] is not None):
#     pre_match_winner_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'
#
# counter_col += 1 #3
# if(rs1[counter_col] is None):
#     pre_match_winner_away = "Null"
# elif(rs1[counter_col] is not None):
#     pre_match_winner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'
#
# counter_col += 1 #4
# if(rs1[counter_col] is None):
#     end_match_winner_home = "Null"
# elif(rs1[counter_col] is not None):
#     end_match_winner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'
#
# counter_col += 1 #5
# if(rs1[counter_col] is None):
#     end_match_winner_draw = "Null"
# elif(rs1[counter_col] is not None):
# ...

# %%
import mysql.connector 

# Import
import sys
sys.path.append('../../')
 
from a_models.array_col import *  

# ------------------------------------------------------
space = "__"
# ------------------------------------------------------ 
array_col = array_col_football_odds()
# ------------------------------------------------------
counter = 0
# ------------------------------------------------------
for x in array_col:  
    # --------------------------------------------------   
    # query_commit += " date = '"+str(fixture_date)+"', " 
    # --------------------------------------------------   
    counter += 1
    # --------------------------------------------------   
    helper = "'"
    # --------------------------------------------------   
    word = 'query_commit += " ' + str(x) + ' = ' + helper + '"+' + str(x) + '+"' + helper + ', "' + " #" + str(counter)
    print(word, flush=True)  
    # --------------------------------------------------   
    # --------------------------------------------------   
    # --------------------------------------------------   
# ------------------------------------------------------
# Out:
# query_commit += " pre_match_winner_home = '"+pre_match_winner_home+"', " #1
# query_commit += " pre_match_winner_draw = '"+pre_match_winner_draw+"', " #2
# query_commit += " pre_match_winner_away = '"+pre_match_winner_away+"', " #3
# query_commit += " end_match_winner_home = '"+end_match_winner_home+"', " #4
# query_commit += " end_match_winner_draw = '"+end_match_winner_draw+"', " #5
# query_commit += " end_match_winner_away = '"+end_match_winner_away+"', " #6
# query_commit += " pre_homeaway_home = '"+pre_homeaway_home+"', " #7
# query_commit += " pre_homeaway_away = '"+pre_homeaway_away+"', " #8
# query_commit += " end_homeaway_home = '"+end_homeaway_home+"', " #9
# query_commit += " end_homeaway_away = '"+end_homeaway_away+"', " #10
# query_commit += " pre_first_half_winner_home = '"+pre_first_half_winner_home+"', " #11
# query_commit += " pre_first_half_winner_draw = '"+pre_first_half_winner_draw+"', " #12
# ...

# %%
import mysql.connector 

# Import
import sys
sys.path.append('../../')
 
from a_models.array_col import *  

# ------------------------------------------------------
space = "__"
# ------------------------------------------------------ 
array_col = array_col_football_odds()
# ------------------------------------------------------
counter = 0
# ------------------------------------------------------
for x in array_col:  
    # --------------------------------------------------   
    # query_commit += " `fixtureapi_id`, " 
    # --------------------------------------------------   
    counter += 1
    # --------------------------------------------------   
    helper = "'"
    # --------------------------------------------------   
    word = 'query_commit += " `'+str(x)+'`, "' + " #" + str(counter)
    print(word, flush=True)  
    # --------------------------------------------------   
    # --------------------------------------------------   
    # --------------------------------------------------   
# ------------------------------------------------------
# Out:
# query_commit += " `pre_match_winner_home`, " #1
# query_commit += " `pre_match_winner_draw`, " #2
# query_commit += " `pre_match_winner_away`, " #3
# query_commit += " `end_match_winner_home`, " #4
# query_commit += " `end_match_winner_draw`, " #5
# query_commit += " `end_match_winner_away`, " #6
# query_commit += " `pre_homeaway_home`, " #7
# query_commit += " `pre_homeaway_away`, " #8
# query_commit += " `end_homeaway_home`, " #9
# query_commit += " `end_homeaway_away`, " #10
# query_commit += " `pre_first_half_winner_home`, " #11
# query_commit += " `pre_first_half_winner_draw`, " #12
# query_commit += " `pre_first_half_winner_away`, " #13
# query_commit += " `end_first_half_winner_home`, " #14
# query_commit += " `end_first_half_winner_draw`, " #15
# query_commit += " `end_first_half_winner_away`, " #16
# query_commit += " `pre_second_half_winner_home`, " #17
# query_commit += " `pre_second_half_winner_draw`, " #18
# query_commit += " `pre_second_half_winner_away`, " #19
# ...

# %%
import mysql.connector 

# ------------------------------------------------------
space = "__"
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------ 
query = "select "

query += " pre_match_winner_home " #1
query += " , pre_match_winner_draw " #2
query += " , pre_match_winner_away " #3
query += " , end_match_winner_home " #4
query += " , end_match_winner_draw " #5
query += " , end_match_winner_away " #6
query += " , pre_homeaway_home " #7
query += " , pre_homeaway_away " #8
query += " , end_homeaway_home " #9
query += " , end_homeaway_away " #10
query += " , pre_first_half_winner_home " #11
query += " , pre_first_half_winner_draw " #12
query += " , pre_first_half_winner_away " #13
query += " , end_first_half_winner_home " #14
query += " , end_first_half_winner_draw " #15
query += " , end_first_half_winner_away " #16
query += " , pre_second_half_winner_home " #17
query += " , pre_second_half_winner_draw " #18
query += " , pre_second_half_winner_away " #19
query += " , end_second_half_winner_home " #20
query += " , end_second_half_winner_draw " #21
query += " , end_second_half_winner_away " #22
query += " , pre_asian_handicap_home_min_675 " #23
query += " , pre_asian_handicap_away_min_675 " #24
query += " , pre_asian_handicap_home_min_65 " #25
query += " , pre_asian_handicap_away_min_65 " #26
query += " , pre_asian_handicap_home_min_625 " #27
query += " , pre_asian_handicap_away_min_625 " #28
query += " , pre_asian_handicap_home_min_6 " #29
query += " , pre_asian_handicap_away_min_6 " #30
query += " , pre_asian_handicap_home_min_575 " #31
query += " , pre_asian_handicap_away_min_575 " #32
query += " , pre_asian_handicap_home_min_55 " #33
query += " , pre_asian_handicap_away_min_55 " #34
query += " , pre_asian_handicap_home_min_525 " #35
query += " , pre_asian_handicap_away_min_525 " #36
query += " , pre_asian_handicap_home_min_5 " #37
query += " , pre_asian_handicap_away_min_5 " #38
query += " , pre_asian_handicap_home_min_475 " #39
query += " , pre_asian_handicap_away_min_475 " #40
query += " , pre_asian_handicap_home_min_45 " #41
query += " , pre_asian_handicap_away_min_45 " #42
query += " , pre_asian_handicap_home_min_425 " #43
query += " , pre_asian_handicap_away_min_425 " #44
query += " , pre_asian_handicap_home_min_4 " #45
query += " , pre_asian_handicap_away_min_4 " #46
query += " , pre_asian_handicap_home_min_375 " #47
query += " , pre_asian_handicap_away_min_375 " #48
query += " , pre_asian_handicap_home_min_35 " #49
query += " , pre_asian_handicap_away_min_35 " #50
query += " , pre_asian_handicap_home_min_325 " #51
query += " , pre_asian_handicap_away_min_325 " #52
query += " , pre_asian_handicap_home_min_3 " #53
query += " , pre_asian_handicap_away_min_3 " #54
query += " , pre_asian_handicap_home_min_275 " #55
query += " , pre_asian_handicap_away_min_275 " #56
query += " , pre_asian_handicap_home_min_25 " #57
query += " , pre_asian_handicap_away_min_25 " #58
query += " , pre_asian_handicap_home_min_225 " #59
query += " , pre_asian_handicap_away_min_225 " #60
query += " , pre_asian_handicap_home_min_2 " #61
query += " , pre_asian_handicap_away_min_2 " #62
query += " , pre_asian_handicap_home_min_175 " #63
query += " , pre_asian_handicap_away_min_175 " #64
query += " , pre_asian_handicap_home_min_15 " #65
query += " , pre_asian_handicap_away_min_15 " #66
query += " , pre_asian_handicap_home_min_125 " #67
query += " , pre_asian_handicap_away_min_125 " #68
query += " , pre_asian_handicap_home_min_1 " #69
query += " , pre_asian_handicap_away_min_1 " #70
query += " , pre_asian_handicap_home_min_075 " #71
query += " , pre_asian_handicap_away_min_075 " #72
query += " , pre_asian_handicap_home_min_05 " #73
query += " , pre_asian_handicap_away_min_05 " #74
query += " , pre_asian_handicap_home_min_025 " #75
query += " , pre_asian_handicap_away_min_025 " #76
query += " , pre_asian_handicap_home_plus_0 " #77
query += " , pre_asian_handicap_away_plus_0 " #78
query += " , pre_asian_handicap_home_plus_025 " #79
query += " , pre_asian_handicap_away_plus_025 " #80
query += " , pre_asian_handicap_home_plus_05 " #81
query += " , pre_asian_handicap_away_plus_05 " #82
query += " , pre_asian_handicap_home_plus_075 " #83
query += " , pre_asian_handicap_away_plus_075 " #84
query += " , pre_asian_handicap_home_plus_1 " #85
query += " , pre_asian_handicap_away_plus_1 " #86
query += " , pre_asian_handicap_home_plus_125 " #87
query += " , pre_asian_handicap_away_plus_125 " #88
query += " , pre_asian_handicap_home_plus_15 " #89
query += " , pre_asian_handicap_away_plus_15 " #90
query += " , pre_asian_handicap_home_plus_175 " #91
query += " , pre_asian_handicap_away_plus_175 " #92
query += " , pre_asian_handicap_home_plus_2 " #93
query += " , pre_asian_handicap_away_plus_2 " #94
query += " , pre_asian_handicap_home_plus_225 " #95
query += " , pre_asian_handicap_away_plus_225 " #96
query += " , pre_asian_handicap_home_plus_25 " #97
query += " , pre_asian_handicap_away_plus_25 " #98
query += " , pre_asian_handicap_home_plus_275 " #99
query += " , pre_asian_handicap_away_plus_275 " #100
query += " , pre_asian_handicap_home_plus_3 " #101
query += " , pre_asian_handicap_away_plus_3 " #102
query += " , pre_asian_handicap_home_plus_325 " #103
query += " , pre_asian_handicap_away_plus_325 " #104
query += " , pre_asian_handicap_home_plus_35 " #105
query += " , pre_asian_handicap_away_plus_35 " #106
query += " , pre_asian_handicap_home_plus_375 " #107
query += " , pre_asian_handicap_away_plus_375 " #108
query += " , pre_asian_handicap_home_plus_4 " #109
query += " , pre_asian_handicap_away_plus_4 " #110
query += " , pre_asian_handicap_home_plus_425 " #111
query += " , pre_asian_handicap_away_plus_425 " #112
query += " , pre_asian_handicap_home_plus_45 " #113
query += " , pre_asian_handicap_away_plus_45 " #114
query += " , pre_asian_handicap_home_plus_475 " #115
query += " , pre_asian_handicap_away_plus_475 " #116
query += " , pre_asian_handicap_home_plus_5 " #117
query += " , pre_asian_handicap_away_plus_5 " #118
query += " , pre_asian_handicap_home_plus_525 " #119
query += " , pre_asian_handicap_away_plus_525 " #120
query += " , pre_asian_handicap_home_plus_55 " #121
query += " , pre_asian_handicap_away_plus_55 " #122
query += " , pre_asian_handicap_home_plus_575 " #123
query += " , pre_asian_handicap_away_plus_575 " #124
query += " , pre_asian_handicap_home_plus_6 " #125
query += " , pre_asian_handicap_away_plus_6 " #126
query += " , pre_asian_handicap_home_plus_625 " #127
query += " , pre_asian_handicap_away_plus_625 " #128
query += " , pre_asian_handicap_home_plus_65 " #129
query += " , pre_asian_handicap_away_plus_65 " #130
query += " , pre_asian_handicap_home_plus_675 " #131
query += " , pre_asian_handicap_away_plus_675 " #132
query += " , end_asian_handicap_home_min_675 " #133
query += " , end_asian_handicap_away_min_675 " #134
query += " , end_asian_handicap_home_min_65 " #135
query += " , end_asian_handicap_away_min_65 " #136
query += " , end_asian_handicap_home_min_625 " #137
query += " , end_asian_handicap_away_min_625 " #138
query += " , end_asian_handicap_home_min_6 " #139
query += " , end_asian_handicap_away_min_6 " #140
query += " , end_asian_handicap_home_min_575 " #141
query += " , end_asian_handicap_away_min_575 " #142
query += " , end_asian_handicap_home_min_55 " #143
query += " , end_asian_handicap_away_min_55 " #144
query += " , end_asian_handicap_home_min_525 " #145
query += " , end_asian_handicap_away_min_525 " #146
query += " , end_asian_handicap_home_min_5 " #147
query += " , end_asian_handicap_away_min_5 " #148
query += " , end_asian_handicap_home_min_475 " #149
query += " , end_asian_handicap_away_min_475 " #150
query += " , end_asian_handicap_home_min_45 " #151
query += " , end_asian_handicap_away_min_45 " #152
query += " , end_asian_handicap_home_min_425 " #153
query += " , end_asian_handicap_away_min_425 " #154
query += " , end_asian_handicap_home_min_4 " #155
query += " , end_asian_handicap_away_min_4 " #156
query += " , end_asian_handicap_home_min_375 " #157
query += " , end_asian_handicap_away_min_375 " #158
query += " , end_asian_handicap_home_min_35 " #159
query += " , end_asian_handicap_away_min_35 " #160
query += " , end_asian_handicap_home_min_325 " #161
query += " , end_asian_handicap_away_min_325 " #162
query += " , end_asian_handicap_home_min_3 " #163
query += " , end_asian_handicap_away_min_3 " #164

query += " , end_asian_handicap_home_min_275 " #165
query += " , end_asian_handicap_away_min_275 " #166
query += " , end_asian_handicap_home_min_25 " #167
query += " , end_asian_handicap_away_min_25 " #168
query += " , end_asian_handicap_home_min_225 " #169
query += " , end_asian_handicap_away_min_225 " #170
query += " , end_asian_handicap_home_min_2 " #171
query += " , end_asian_handicap_away_min_2 " #172
query += " , end_asian_handicap_home_min_175 " #173
query += " , end_asian_handicap_away_min_175 " #174
query += " , end_asian_handicap_home_min_15 " #175
query += " , end_asian_handicap_away_min_15 " #176
query += " , end_asian_handicap_home_min_125 " #177
query += " , end_asian_handicap_away_min_125 " #178
query += " , end_asian_handicap_home_min_1 " #179
query += " , end_asian_handicap_away_min_1 " #180
query += " , end_asian_handicap_home_min_075 " #181
query += " , end_asian_handicap_away_min_075 " #182
query += " , end_asian_handicap_home_min_05 " #183
query += " , end_asian_handicap_away_min_05 " #184
query += " , end_asian_handicap_home_min_025 " #185
query += " , end_asian_handicap_away_min_025 " #186
query += " , end_asian_handicap_home_plus_0 " #187
query += " , end_asian_handicap_away_plus_0 " #188
query += " , end_asian_handicap_home_plus_025 " #189
query += " , end_asian_handicap_away_plus_025 " #190
query += " , end_asian_handicap_home_plus_05 " #191
query += " , end_asian_handicap_away_plus_05 " #192
query += " , end_asian_handicap_home_plus_075 " #193
query += " , end_asian_handicap_away_plus_075 " #194
query += " , end_asian_handicap_home_plus_1 " #195
query += " , end_asian_handicap_away_plus_1 " #196
query += " , end_asian_handicap_home_plus_125 " #197
query += " , end_asian_handicap_away_plus_125 " #198
query += " , end_asian_handicap_home_plus_15 " #199
query += " , end_asian_handicap_away_plus_15 " #200
query += " , end_asian_handicap_home_plus_175 " #201
query += " , end_asian_handicap_away_plus_175 " #202
query += " , end_asian_handicap_home_plus_2 " #203
query += " , end_asian_handicap_away_plus_2 " #204
query += " , end_asian_handicap_home_plus_225 " #205
query += " , end_asian_handicap_away_plus_225 " #206
query += " , end_asian_handicap_home_plus_25 " #207
query += " , end_asian_handicap_away_plus_25 " #208
query += " , end_asian_handicap_home_plus_275 " #209
query += " , end_asian_handicap_away_plus_275 " #210
query += " , end_asian_handicap_home_plus_3 " #211
query += " , end_asian_handicap_away_plus_3 " #212
query += " , end_asian_handicap_home_plus_325 " #213
query += " , end_asian_handicap_away_plus_325 " #214
query += " , end_asian_handicap_home_plus_35 " #215
query += " , end_asian_handicap_away_plus_35 " #216
query += " , end_asian_handicap_home_plus_375 " #217
query += " , end_asian_handicap_away_plus_375 " #218
query += " , end_asian_handicap_home_plus_4 " #219
query += " , end_asian_handicap_away_plus_4 " #220
query += " , end_asian_handicap_home_plus_425 " #221
query += " , end_asian_handicap_away_plus_425 " #222
query += " , end_asian_handicap_home_plus_45 " #223
query += " , end_asian_handicap_away_plus_45 " #224
query += " , end_asian_handicap_home_plus_475 " #225
query += " , end_asian_handicap_away_plus_475 " #226
query += " , end_asian_handicap_home_plus_5 " #227
query += " , end_asian_handicap_away_plus_5 " #228
query += " , end_asian_handicap_home_plus_525 " #229
query += " , end_asian_handicap_away_plus_525 " #230
query += " , end_asian_handicap_home_plus_55 " #231
query += " , end_asian_handicap_away_plus_55 " #232
query += " , end_asian_handicap_home_plus_575 " #233
query += " , end_asian_handicap_away_plus_575 " #234
query += " , end_asian_handicap_home_plus_6 " #235
query += " , end_asian_handicap_away_plus_6 " #236
query += " , end_asian_handicap_home_plus_625 " #237
query += " , end_asian_handicap_away_plus_625 " #238
query += " , end_asian_handicap_home_plus_65 " #239
query += " , end_asian_handicap_away_plus_65 " #240
query += " , end_asian_handicap_home_plus_675 " #241
query += " , end_asian_handicap_away_plus_675 " #242
query += " , pre_goals_overunder_over_05 " #243
query += " , pre_goals_overunder_under_05 " #244
query += " , pre_goals_overunder_over_075 " #245
query += " , pre_goals_overunder_under_075 " #246
query += " , pre_goals_overunder_over_10 " #247
query += " , pre_goals_overunder_under_10 " #248
query += " , pre_goals_overunder_over_125 " #249
query += " , pre_goals_overunder_under_125 " #250
query += " , pre_goals_overunder_over_15 " #251
query += " , pre_goals_overunder_under_15 " #252
query += " , pre_goals_overunder_over_175 " #253
query += " , pre_goals_overunder_under_175 " #254
query += " , pre_goals_overunder_over_20 " #255
query += " , pre_goals_overunder_under_20 " #256
query += " , pre_goals_overunder_over_225 " #257
query += " , pre_goals_overunder_under_225 " #258
query += " , pre_goals_overunder_over_25 " #259
query += " , pre_goals_overunder_under_25 " #260
query += " , pre_goals_overunder_over_275 " #261
query += " , pre_goals_overunder_under_275 " #262
query += " , pre_goals_overunder_over_30 " #263
query += " , pre_goals_overunder_under_30 " #264
query += " , pre_goals_overunder_over_325 " #265
query += " , pre_goals_overunder_under_325 " #266
query += " , pre_goals_overunder_over_35 " #267
query += " , pre_goals_overunder_under_35 " #268
query += " , pre_goals_overunder_over_375 " #269
query += " , pre_goals_overunder_under_375 " #270
query += " , pre_goals_overunder_over_40 " #271
query += " , pre_goals_overunder_under_40 " #272
query += " , pre_goals_overunder_over_425 " #273
query += " , pre_goals_overunder_under_425 " #274
query += " , pre_goals_overunder_over_45 " #275
query += " , pre_goals_overunder_under_45 " #276
query += " , pre_goals_overunder_over_475 " #277
query += " , pre_goals_overunder_under_475 " #278
query += " , pre_goals_overunder_over_50 " #279
query += " , pre_goals_overunder_under_50 " #280
query += " , pre_goals_overunder_over_525 " #281
query += " , pre_goals_overunder_under_525 " #282
query += " , pre_goals_overunder_over_55 " #283
query += " , pre_goals_overunder_under_55 " #284
query += " , pre_goals_overunder_over_575 " #285
query += " , pre_goals_overunder_under_575 " #286
query += " , pre_goals_overunder_over_60 " #287
query += " , pre_goals_overunder_under_60 " #288
query += " , pre_goals_overunder_over_625 " #289
query += " , pre_goals_overunder_under_625 " #290
query += " , pre_goals_overunder_over_65 " #291
query += " , pre_goals_overunder_under_65 " #292
query += " , pre_goals_overunder_over_675 " #293
query += " , pre_goals_overunder_under_675 " #294
query += " , pre_goals_overunder_over_70 " #295
query += " , pre_goals_overunder_under_70 " #296
query += " , pre_goals_overunder_over_75 " #297
query += " , pre_goals_overunder_under_75 " #298
query += " , pre_goals_overunder_over_85 " #299
query += " , pre_goals_overunder_under_85 " #300
query += " , pre_goals_overunder_over_95 " #301
query += " , pre_goals_overunder_under_95 " #302
query += " , end_goals_overunder_over_05 " #303
query += " , end_goals_overunder_under_05 " #304
query += " , end_goals_overunder_over_075 " #305
query += " , end_goals_overunder_under_075 " #306
query += " , end_goals_overunder_over_10 " #307
query += " , end_goals_overunder_under_10 " #308
query += " , end_goals_overunder_over_125 " #309
query += " , end_goals_overunder_under_125 " #310
query += " , end_goals_overunder_over_15 " #311
query += " , end_goals_overunder_under_15 " #312
query += " , end_goals_overunder_over_175 " #313
query += " , end_goals_overunder_under_175 " #314
query += " , end_goals_overunder_over_20 " #315
query += " , end_goals_overunder_under_20 " #316
query += " , end_goals_overunder_over_225 " #317
query += " , end_goals_overunder_under_225 " #318
query += " , end_goals_overunder_over_25 " #319
query += " , end_goals_overunder_under_25 " #320
query += " , end_goals_overunder_over_275 " #321
query += " , end_goals_overunder_under_275 " #322
query += " , end_goals_overunder_over_30 " #323
query += " , end_goals_overunder_under_30 " #324
query += " , end_goals_overunder_over_325 " #325
query += " , end_goals_overunder_under_325 " #326
query += " , end_goals_overunder_over_35 " #327

query += " , end_goals_overunder_under_35 " #328
query += " , end_goals_overunder_over_375 " #329
query += " , end_goals_overunder_under_375 " #330
query += " , end_goals_overunder_over_40 " #331
query += " , end_goals_overunder_under_40 " #332
query += " , end_goals_overunder_over_425 " #333
query += " , end_goals_overunder_under_425 " #334
query += " , end_goals_overunder_over_45 " #335
query += " , end_goals_overunder_under_45 " #336
query += " , end_goals_overunder_over_475 " #337
query += " , end_goals_overunder_under_475 " #338
query += " , end_goals_overunder_over_50 " #339
query += " , end_goals_overunder_under_50 " #340
query += " , end_goals_overunder_over_525 " #341
query += " , end_goals_overunder_under_525 " #342
query += " , end_goals_overunder_over_55 " #343
query += " , end_goals_overunder_under_55 " #344
query += " , end_goals_overunder_over_575 " #345
query += " , end_goals_overunder_under_575 " #346
query += " , end_goals_overunder_over_60 " #347
query += " , end_goals_overunder_under_60 " #348
query += " , end_goals_overunder_over_625 " #349
query += " , end_goals_overunder_under_625 " #350
query += " , end_goals_overunder_over_65 " #351
query += " , end_goals_overunder_under_65 " #352
query += " , end_goals_overunder_over_675 " #353
query += " , end_goals_overunder_under_675 " #354
query += " , end_goals_overunder_over_70 " #355
query += " , end_goals_overunder_under_70 " #356
query += " , end_goals_overunder_over_75 " #357
query += " , end_goals_overunder_under_75 " #358
query += " , end_goals_overunder_over_85 " #359
query += " , end_goals_overunder_under_85 " #360
query += " , end_goals_overunder_over_95 " #361
query += " , end_goals_overunder_under_95 " #362
query += " , pre_asian_handicap_first_half_home_min_175 " #363
query += " , pre_asian_handicap_first_half_away_min_175 " #364
query += " , pre_asian_handicap_first_half_home_min_15 " #365
query += " , pre_asian_handicap_first_half_away_min_15 " #366
query += " , pre_asian_handicap_first_half_home_min_125 " #367
query += " , pre_asian_handicap_first_half_away_min_125 " #368
query += " , pre_asian_handicap_first_half_home_min_1 " #369
query += " , pre_asian_handicap_first_half_away_min_1 " #370
query += " , pre_asian_handicap_first_half_home_min_075 " #371
query += " , pre_asian_handicap_first_half_away_min_075 " #372
query += " , pre_asian_handicap_first_half_home_min_05 " #373
query += " , pre_asian_handicap_first_half_away_min_05 " #374
query += " , pre_asian_handicap_first_half_home_min_025 " #375
query += " , pre_asian_handicap_first_half_away_min_025 " #376
query += " , pre_asian_handicap_first_half_home_plus_0 " #377
query += " , pre_asian_handicap_first_half_away_plus_0 " #378
query += " , pre_asian_handicap_first_half_home_plus_025 " #379
query += " , pre_asian_handicap_first_half_away_plus_025 " #380
query += " , pre_asian_handicap_first_half_home_plus_05 " #381
query += " , pre_asian_handicap_first_half_away_plus_05 " #382
query += " , pre_asian_handicap_first_half_home_plus_075 " #383
query += " , pre_asian_handicap_first_half_away_plus_075 " #384
query += " , pre_asian_handicap_first_half_home_plus_1 " #385
query += " , pre_asian_handicap_first_half_away_plus_1 " #386
query += " , pre_asian_handicap_first_half_home_plus_125 " #387
query += " , pre_asian_handicap_first_half_away_plus_125 " #388
query += " , pre_asian_handicap_first_half_home_plus_15 " #389
query += " , pre_asian_handicap_first_half_away_plus_15 " #390
query += " , pre_asian_handicap_first_half_home_plus_175 " #391
query += " , pre_asian_handicap_first_half_away_plus_175 " #392
query += " , end_asian_handicap_first_half_home_min_175 " #393
query += " , end_asian_handicap_first_half_away_min_175 " #394
query += " , end_asian_handicap_first_half_home_min_15 " #395
query += " , end_asian_handicap_first_half_away_min_15 " #396
query += " , end_asian_handicap_first_half_home_min_125 " #397
query += " , end_asian_handicap_first_half_away_min_125 " #398
query += " , end_asian_handicap_first_half_home_min_1 " #399
query += " , end_asian_handicap_first_half_away_min_1 " #400
query += " , end_asian_handicap_first_half_home_min_075 " #401
query += " , end_asian_handicap_first_half_away_min_075 " #402
query += " , end_asian_handicap_first_half_home_min_05 " #403
query += " , end_asian_handicap_first_half_away_min_05 " #404
query += " , end_asian_handicap_first_half_home_min_025 " #405
query += " , end_asian_handicap_first_half_away_min_025 " #406
query += " , end_asian_handicap_first_half_home_plus_0 " #407
query += " , end_asian_handicap_first_half_away_plus_0 " #408
query += " , end_asian_handicap_first_half_home_plus_025 " #409
query += " , end_asian_handicap_first_half_away_plus_025 " #410
query += " , end_asian_handicap_first_half_home_plus_05 " #411
query += " , end_asian_handicap_first_half_away_plus_05 " #412
query += " , end_asian_handicap_first_half_home_plus_075 " #413
query += " , end_asian_handicap_first_half_away_plus_075 " #414
query += " , end_asian_handicap_first_half_home_plus_1 " #415
query += " , end_asian_handicap_first_half_away_plus_1 " #416
query += " , end_asian_handicap_first_half_home_plus_125 " #417
query += " , end_asian_handicap_first_half_away_plus_125 " #418
query += " , end_asian_handicap_first_half_home_plus_15 " #419
query += " , end_asian_handicap_first_half_away_plus_15 " #420
query += " , end_asian_handicap_first_half_home_plus_175 " #421
query += " , end_asian_handicap_first_half_away_plus_175 " #422
query += " , pre_goals_overunder_first_half_over_05 " #423
query += " , pre_goals_overunder_first_half_under_05 " #424
query += " , pre_goals_overunder_first_half_over_075 " #425
query += " , pre_goals_overunder_first_half_under_075 " #426
query += " , pre_goals_overunder_first_half_over_10 " #427
query += " , pre_goals_overunder_first_half_under_10 " #428
query += " , pre_goals_overunder_first_half_over_125 " #429
query += " , pre_goals_overunder_first_half_under_125 " #430
query += " , pre_goals_overunder_first_half_over_15 " #431
query += " , pre_goals_overunder_first_half_under_15 " #432
query += " , pre_goals_overunder_first_half_over_175 " #433
query += " , pre_goals_overunder_first_half_under_175 " #434
query += " , pre_goals_overunder_first_half_over_20 " #435
query += " , pre_goals_overunder_first_half_under_20 " #436
query += " , pre_goals_overunder_first_half_over_225 " #437
query += " , pre_goals_overunder_first_half_under_225 " #438
query += " , pre_goals_overunder_first_half_over_25 " #439
query += " , pre_goals_overunder_first_half_under_25 " #440
query += " , pre_goals_overunder_first_half_over_275 " #441
query += " , pre_goals_overunder_first_half_under_275 " #442
query += " , pre_goals_overunder_first_half_over_30 " #443
query += " , pre_goals_overunder_first_half_under_30 " #444
query += " , pre_goals_overunder_first_half_over_325 " #445
query += " , pre_goals_overunder_first_half_under_325 " #446
query += " , pre_goals_overunder_first_half_over_35 " #447
query += " , pre_goals_overunder_first_half_under_35 " #448
query += " , pre_goals_overunder_first_half_over_375 " #449
query += " , pre_goals_overunder_first_half_under_375 " #450
query += " , end_goals_overunder_first_half_over_05 " #451
query += " , end_goals_overunder_first_half_under_05 " #452
query += " , end_goals_overunder_first_half_over_075 " #453
query += " , end_goals_overunder_first_half_under_075 " #454
query += " , end_goals_overunder_first_half_over_10 " #455
query += " , end_goals_overunder_first_half_under_10 " #456
query += " , end_goals_overunder_first_half_over_125 " #457
query += " , end_goals_overunder_first_half_under_125 " #458
query += " , end_goals_overunder_first_half_over_15 " #459
query += " , end_goals_overunder_first_half_under_15 " #460
query += " , end_goals_overunder_first_half_over_175 " #461
query += " , end_goals_overunder_first_half_under_175 " #462
query += " , end_goals_overunder_first_half_over_20 " #463
query += " , end_goals_overunder_first_half_under_20 " #464
query += " , end_goals_overunder_first_half_over_225 " #465
query += " , end_goals_overunder_first_half_under_225 " #466
query += " , end_goals_overunder_first_half_over_25 " #467
query += " , end_goals_overunder_first_half_under_25 " #468

query += " , end_goals_overunder_first_half_over_275 " #469
query += " , end_goals_overunder_first_half_under_275 " #470
query += " , end_goals_overunder_first_half_over_30 " #471
query += " , end_goals_overunder_first_half_under_30 " #472
query += " , end_goals_overunder_first_half_over_325 " #473
query += " , end_goals_overunder_first_half_under_325 " #474
query += " , end_goals_overunder_first_half_over_35 " #475
query += " , end_goals_overunder_first_half_under_35 " #476
query += " , end_goals_overunder_first_half_over_375 " #477
query += " , end_goals_overunder_first_half_under_375 " #478
query += " , pre_goals_overunder__second_half_over_05 " #479
query += " , pre_goals_overunder__second_half_under_05 " #480
query += " , pre_goals_overunder__second_half_over_075 " #481
query += " , pre_goals_overunder__second_half_under_075 " #482
query += " , pre_goals_overunder__second_half_over_10 " #483
query += " , pre_goals_overunder__second_half_under_10 " #484
query += " , pre_goals_overunder__second_half_over_125 " #485
query += " , pre_goals_overunder__second_half_under_125 " #486
query += " , pre_goals_overunder__second_half_over_15 " #487
query += " , pre_goals_overunder__second_half_under_15 " #488
query += " , pre_goals_overunder__second_half_over_175 " #489
query += " , pre_goals_overunder__second_half_under_175 " #490
query += " , pre_goals_overunder__second_half_over_20 " #491
query += " , pre_goals_overunder__second_half_under_20 " #492
query += " , pre_goals_overunder__second_half_over_225 " #493
query += " , pre_goals_overunder__second_half_under_225 " #494
query += " , pre_goals_overunder__second_half_over_25 " #495
query += " , pre_goals_overunder__second_half_under_25 " #496
query += " , pre_goals_overunder__second_half_over_275 " #497
query += " , pre_goals_overunder__second_half_under_275 " #498
query += " , pre_goals_overunder__second_half_over_30 " #499
query += " , pre_goals_overunder__second_half_under_30 " #500
query += " , pre_goals_overunder__second_half_over_325 " #501
query += " , pre_goals_overunder__second_half_under_325 " #502
query += " , pre_goals_overunder__second_half_over_35 " #503
query += " , pre_goals_overunder__second_half_under_35 " #504
query += " , pre_goals_overunder__second_half_over_375 " #505
query += " , pre_goals_overunder__second_half_under_375 " #506
query += " , end_goals_overunder__second_half_over_05 " #507
query += " , end_goals_overunder__second_half_under_05 " #508
query += " , end_goals_overunder__second_half_over_075 " #509
query += " , end_goals_overunder__second_half_under_075 " #510
query += " , end_goals_overunder__second_half_over_10 " #511
query += " , end_goals_overunder__second_half_under_10 " #512
query += " , end_goals_overunder__second_half_over_125 " #513
query += " , end_goals_overunder__second_half_under_125 " #514
query += " , end_goals_overunder__second_half_over_15 " #515
query += " , end_goals_overunder__second_half_under_15 " #516
query += " , end_goals_overunder__second_half_over_175 " #517
query += " , end_goals_overunder__second_half_under_175 " #518
query += " , end_goals_overunder__second_half_over_20 " #519
query += " , end_goals_overunder__second_half_under_20 " #520
query += " , end_goals_overunder__second_half_over_225 " #521
query += " , end_goals_overunder__second_half_under_225 " #522
query += " , end_goals_overunder__second_half_over_25 " #523
query += " , end_goals_overunder__second_half_under_25 " #524
query += " , end_goals_overunder__second_half_over_275 " #525
query += " , end_goals_overunder__second_half_under_275 " #526
query += " , end_goals_overunder__second_half_over_30 " #527
query += " , end_goals_overunder__second_half_under_30 " #528
query += " , end_goals_overunder__second_half_over_325 " #529
query += " , end_goals_overunder__second_half_under_325 " #530
query += " , end_goals_overunder__second_half_over_35 " #531
query += " , end_goals_overunder__second_half_under_35 " #532
query += " , end_goals_overunder__second_half_over_375 " #533
query += " , end_goals_overunder__second_half_under_375 " #534
query += " , pre_htft_double_home_home " #535
query += " , pre_htft_double_home_draw " #536
query += " , pre_htft_double_home_away " #537
query += " , pre_htft_double_draw_home " #538
query += " , pre_htft_double_draw_draw " #539
query += " , pre_htft_double_draw_away " #540
query += " , pre_htft_double_away_home " #541
query += " , pre_htft_double_away_draw " #542
query += " , pre_htft_double_away_away " #543
query += " , end_htft_double_home_home " #544
query += " , end_htft_double_home_draw " #545
query += " , end_htft_double_home_away " #546
query += " , end_htft_double_draw_home " #547
query += " , end_htft_double_draw_draw " #548
query += " , end_htft_double_draw_away " #549
query += " , end_htft_double_away_home " #550
query += " , end_htft_double_away_draw " #551
query += " , end_htft_double_away_away " #552
query += " , pre_both_teams_score_yes " #553
query += " , pre_both_teams_score_no " #554
query += " , end_both_teams_score_yes " #555
query += " , end_both_teams_score_no " #556
query += " , pre_both_teams_score__first_half_yes " #557
query += " , pre_both_teams_score__first_half_no " #558
query += " , end_both_teams_score__first_half_yes " #559
query += " , end_both_teams_score__first_half_no " #560
query += " , pre_both_teams_to_score__second_half_yes " #561
query += " , pre_both_teams_to_score__second_half_no " #562
query += " , end_both_teams_to_score__second_half_yes " #563
query += " , end_both_teams_to_score__second_half_no " #564
query += " , pre_results_both_teams_score_home_yes " #565
query += " , pre_results_both_teams_score_draw_yes " #566
query += " , pre_results_both_teams_score_away_yes " #567
query += " , pre_results_both_teams_score_home_no " #568
query += " , pre_results_both_teams_score_draw_no " #569
query += " , pre_results_both_teams_score_away_no " #570
query += " , end_results_both_teams_score_home_yes " #571
query += " , end_results_both_teams_score_draw_yes " #572
query += " , end_results_both_teams_score_away_yes " #573
query += " , end_results_both_teams_score_home_no " #574
query += " , end_results_both_teams_score_draw_no " #575
query += " , end_results_both_teams_score_away_no " #576
query += " , pre_to_score_in_both_halves_by_teams_home " #577
query += " , pre_to_score_in_both_halves_by_teams_away " #578
query += " , end_to_score_in_both_halves_by_teams_home " #579
query += " , end_to_score_in_both_halves_by_teams_away " #580
query += " , pre_total_goals_both_teams_to_score_over_yes_25 " #581
query += " , pre_total_goals_both_teams_to_score_over_no_25 " #582
query += " , pre_total_goals_both_teams_to_score_under_yes_25 " #583
query += " , pre_total_goals_both_teams_to_score_under_no_25 " #584
query += " , end_total_goals_both_teams_to_score_over_yes_25 " #585
query += " , end_total_goals_both_teams_to_score_over_no_25 " #586
query += " , end_total_goals_both_teams_to_score_under_yes_25 " #587
query += " , end_total_goals_both_teams_to_score_under_no_25 " #588
query += " , pre_both_teams_to_score_1st_half__2nd_half_yes_yes " #589
query += " , pre_both_teams_to_score_1st_half__2nd_half_yes_no " #590
query += " , pre_both_teams_to_score_1st_half__2nd_half_no_yes " #591
query += " , pre_both_teams_to_score_1st_half__2nd_half_no_no " #592
query += " , end_both_teams_to_score_1st_half__2nd_half_yes_yes " #593
query += " , end_both_teams_to_score_1st_half__2nd_half_yes_no " #594
query += " , end_both_teams_to_score_1st_half__2nd_half_no_yes " #595
query += " , end_both_teams_to_score_1st_half__2nd_half_no_no " #596
query += " , pre_highest_scoring_half_first " #597
query += " , pre_highest_scoring_half_draw " #598
query += " , pre_highest_scoring_half_second " #599
query += " , end_highest_scoring_half_first " #600
query += " , end_highest_scoring_half_draw " #601
query += " , end_highest_scoring_half_second " #602
query += " , pre_double_chance_home_draw " #603
query += " , pre_double_chance_home_away " #604
query += " , pre_double_chance_draw_away " #605
query += " , end_double_chance_home_draw " #606
query += " , end_double_chance_home_away " #607
query += " , end_double_chance_draw_away " #608
query += " , pre_double_chance__first_half_home_draw " #609

query += " , pre_double_chance__first_half_home_away " #610
query += " , pre_double_chance__first_half_draw_away " #611
query += " , end_double_chance__first_half_home_draw " #612
query += " , end_double_chance__first_half_home_away " #613
query += " , end_double_chance__first_half_draw_away " #614
query += " , pre_oddeven_odd " #615
query += " , pre_oddeven_even " #616
query += " , end_oddeven_odd " #617
query += " , end_oddeven_even " #618
query += " , pre_result_total_goals_home_over_35 " #619
query += " , pre_result_total_goals_draw_over_35 " #620
query += " , pre_result_total_goals_away_over_35 " #621
query += " , pre_result_total_goals_home_under_35 " #622
query += " , pre_result_total_goals_draw_under_35 " #623
query += " , pre_result_total_goals_away_under_35 " #624
query += " , pre_result_total_goals_home_over_25 " #625
query += " , pre_result_total_goals_draw_over_25 " #626
query += " , pre_result_total_goals_away_over_25 " #627
query += " , pre_result_total_goals_home_under_25 " #628
query += " , pre_result_total_goals_draw_under_25 " #629
query += " , pre_result_total_goals_away_under_25 " #630
query += " , end_result_total_goals_home_over_35 " #631
query += " , end_result_total_goals_draw_over_35 " #632
query += " , end_result_total_goals_away_over_35 " #633
query += " , end_result_total_goals_home_under_35 " #634
query += " , end_result_total_goals_draw_under_35 " #635
query += " , end_result_total_goals_away_under_35 " #636
query += " , end_result_total_goals_home_over_25 " #637
query += " , end_result_total_goals_draw_over_25 " #638
query += " , end_result_total_goals_away_over_25 " #639
query += " , end_result_total_goals_home_under_25 " #640
query += " , end_result_total_goals_draw_under_25 " #641
query += " , end_result_total_goals_away_under_25 " #642
query += " , pre_clean_sheet__home_yes " #643
query += " , pre_clean_sheet__home_no " #644
query += " , end_clean_sheet__home_yes " #645
query += " , end_clean_sheet__home_no " #646
query += " , pre_clean_sheet__away_yes " #647
query += " , pre_clean_sheet__away_no " #648
query += " , end_clean_sheet__away_yes " #649
query += " , end_clean_sheet__away_no " #650
query += " , pre_win_both_halves_home " #651
query += " , pre_win_both_halves_away " #652
query += " , end_win_both_halves_home " #653
query += " , end_win_both_halves_away " #654
query += " , pre_win_to_nil_home " #655
query += " , pre_win_to_nil_away " #656
query += " , end_win_to_nil_home " #657
query += " , end_win_to_nil_away " #658
query += " , pre_to_win_either_half_home " #659
query += " , pre_to_win_either_half_away " #660
query += " , end_to_win_either_half_home " #661
query += " , end_to_win_either_half_away " #662
query += " , pre_halftime_result_both_teams_score_home_yes " #663
query += " , pre_halftime_result_both_teams_score_draw_yes " #664
query += " , pre_halftime_result_both_teams_score_away_yes " #665
query += " , pre_halftime_result_both_teams_score_home_no " #666
query += " , pre_halftime_result_both_teams_score_draw_no " #667
query += " , pre_halftime_result_both_teams_score_away_no " #668
query += " , end_halftime_result_both_teams_score_home_yes " #669
query += " , end_halftime_result_both_teams_score_draw_yes " #670
query += " , end_halftime_result_both_teams_score_away_yes " #671
query += " , end_halftime_result_both_teams_score_home_no " #672
query += " , end_halftime_result_both_teams_score_draw_no " #673
query += " , end_halftime_result_both_teams_score_away_no " #674
query += " , pre_exact_goals_number_0 " #675
query += " , pre_exact_goals_number_1 " #676
query += " , pre_exact_goals_number_2 " #677
query += " , pre_exact_goals_number_3 " #678
query += " , pre_exact_goals_number_4 " #679
query += " , pre_exact_goals_number_5 " #680
query += " , pre_exact_goals_number_6 " #681
query += " , pre_exact_goals_number_more_7 " #682
query += " , end_exact_goals_number_0 " #683
query += " , end_exact_goals_number_1 " #684
query += " , end_exact_goals_number_2 " #685
query += " , end_exact_goals_number_3 " #686
query += " , end_exact_goals_number_4 " #687
query += " , end_exact_goals_number_5 " #688
query += " , end_exact_goals_number_6 " #689
query += " , end_exact_goals_number_more_7 " #690
query += " , pre_exact_goals_number__first_half_0 " #691
query += " , pre_exact_goals_number__first_half_1 " #692
query += " , pre_exact_goals_number__first_half_2 " #693
query += " , pre_exact_goals_number__first_half_3 " #694
query += " , pre_exact_goals_number__first_half_4 " #695
query += " , pre_exact_goals_number__first_half_more_5 " #696
query += " , end_exact_goals_number__first_half_0 " #697
query += " , end_exact_goals_number__first_half_1 " #698
query += " , end_exact_goals_number__first_half_2 " #699
query += " , end_exact_goals_number__first_half_3 " #700
query += " , end_exact_goals_number__first_half_4 " #701
query += " , end_exact_goals_number__first_half_more_5 " #702
query += " , pre_second_half_exact_goals_number_0 " #703
query += " , pre_second_half_exact_goals_number_1 " #704
query += " , pre_second_half_exact_goals_number_2 " #705
query += " , pre_second_half_exact_goals_number_3 " #706
query += " , pre_second_half_exact_goals_number_4 " #707
query += " , pre_second_half_exact_goals_number_more_5 " #708
query += " , end_second_half_exact_goals_number_0 " #709
query += " , end_second_half_exact_goals_number_1 " #710
query += " , end_second_half_exact_goals_number_2 " #711
query += " , end_second_half_exact_goals_number_3 " #712
query += " , end_second_half_exact_goals_number_4 " #713
query += " , end_second_half_exact_goals_number_more_5 " #714
query += " , pre_home_team_exact_goals_number_0 " #715
query += " , pre_home_team_exact_goals_number_1 " #716
query += " , pre_home_team_exact_goals_number_2 " #717
query += " , pre_home_team_exact_goals_number_more_3 " #718
query += " , end_home_team_exact_goals_number_0 " #719
query += " , end_home_team_exact_goals_number_1 " #720
query += " , end_home_team_exact_goals_number_2 " #721
query += " , end_home_team_exact_goals_number_more_3 " #722
query += " , pre_away_team_exact_goals_number_0 " #723
query += " , pre_away_team_exact_goals_number_1 " #724
query += " , pre_away_team_exact_goals_number_2 " #725
query += " , pre_away_team_exact_goals_number_more_3 " #726
query += " , end_away_team_exact_goals_number_0 " #727
query += " , end_away_team_exact_goals_number_1 " #728
query += " , end_away_team_exact_goals_number_2 " #729
query += " , end_away_team_exact_goals_number_more_3 " #730
query += " , pre_corners_winner_home " #731
query += " , pre_corners_winner_draw " #732
query += " , pre_corners_winner_away " #733
query += " , end_corners_winner_home " #734
query += " , end_corners_winner_draw " #735
query += " , end_corners_winner_away " #736
query += " , pre_10_overunder_over_05 " #737
query += " , pre_10_overunder_under_05 " #738
query += " , end_10_overunder_over_05 " #739
query += " , end_10_overunder_under_05 " #740
query += " , pre_cards_european_handicap_home_min_2 " #741
query += " , pre_cards_european_handicap_draw_min_2 " #742
query += " , pre_cards_european_handicap_away_min_2 " #743
query += " , pre_cards_european_handicap_home_min_1 " #744
query += " , pre_cards_european_handicap_draw_min_1 " #745
query += " , pre_cards_european_handicap_away_min_1 " #746
query += " , pre_cards_european_handicap_home_plus_0 " #747
query += " , pre_cards_european_handicap_draw_plus_0 " #748
query += " , pre_cards_european_handicap_away_plus_0 " #749
query += " , pre_cards_european_handicap_home_plus_1 " #750
query += " , pre_cards_european_handicap_draw_plus_1 " #751
query += " , pre_cards_european_handicap_away_plus_1 " #752
query += " , pre_cards_european_handicap_home_plus_2 " #753
query += " , pre_cards_european_handicap_draw_plus_2 " #754
query += " , pre_cards_european_handicap_away_plus_2 " #755
query += " , end_cards_european_handicap_home_min_2 " #756
query += " , end_cards_european_handicap_draw_min_2 " #757
query += " , end_cards_european_handicap_away_min_2 " #758
query += " , end_cards_european_handicap_home_min_1 " #759
query += " , end_cards_european_handicap_draw_min_1 " #760
query += " , end_cards_european_handicap_away_min_1 " #761 
query += " , end_cards_european_handicap_home_plus_0 " #762
query += " , end_cards_european_handicap_draw_plus_0 " #763
query += " , end_cards_european_handicap_away_plus_0 " #764
query += " , end_cards_european_handicap_home_plus_1 " #765
query += " , end_cards_european_handicap_draw_plus_1 " #766
query += " , end_cards_european_handicap_away_plus_1 " #767
query += " , end_cards_european_handicap_home_plus_2 " #768
query += " , end_cards_european_handicap_draw_plus_2 " #769
query += " , end_cards_european_handicap_away_plus_2 " #770
query += " , pre_rcard_yes " #771
query += " , pre_rcard_no " #772
query += " , end_rcard_yes " #773
query += " , end_rcard_no " #774
query += " , pre_team_to_score_first_home " #775
query += " , pre_team_to_score_first_draw " #776
query += " , pre_team_to_score_first_away " #777
query += " , end_team_to_score_first_home " #778
query += " , end_team_to_score_first_draw " #779
query += " , end_team_to_score_first_away " #780
query += " , pre_team_to_score_last_home " #781
query += " , pre_team_to_score_last_draw " #782
query += " , pre_team_to_score_last_away " #783
query += " , end_team_to_score_last_home " #784
query += " , end_team_to_score_last_draw " #785
query += " , end_team_to_score_last_away " #786
query += " , pre_total_home_over_15 " #787
query += " , pre_total_home_under_15 " #788
query += " , pre_total_home_over_25 " #789
query += " , pre_total_home_under_25 " #790
query += " , pre_total_home_over_35 " #791
query += " , pre_total_home_under_35 " #792
query += " , pre_total_home_over_45 " #793
query += " , pre_total_home_under_45 " #794
query += " , pre_total_home_over_55 " #795
query += " , pre_total_home_under_55 " #796
query += " , pre_total_home_over_65 " #797
query += " , pre_total_home_under_65 " #798
query += " , end_total_home_over_15 " #799
query += " , end_total_home_under_15 " #800
query += " , end_total_home_over_25 " #801
query += " , end_total_home_under_25 " #802
query += " , end_total_home_over_35 " #803
query += " , end_total_home_under_35 " #804
query += " , end_total_home_over_45 " #805
query += " , end_total_home_under_45 " #806
query += " , end_total_home_over_55 " #807
query += " , end_total_home_under_55 " #808
query += " , end_total_home_over_65 " #809
query += " , end_total_home_under_65 " #810
query += " , pre_total_away_over_15 " #811
query += " , pre_total_away_under_15 " #812
query += " , pre_total_away_over_25 " #813
query += " , pre_total_away_under_25 " #814
query += " , pre_total_away_over_35 " #815
query += " , pre_total_away_under_35 " #816
query += " , pre_total_away_over_45 " #817
query += " , pre_total_away_under_45 " #818
query += " , pre_total_away_over_55 " #819
query += " , pre_total_away_under_55 " #820
query += " , pre_total_away_over_65 " #821
query += " , pre_total_away_under_65 " #822
query += " , end_total_away_over_15 " #823
query += " , end_total_away_under_15 " #824
query += " , end_total_away_over_25 " #825
query += " , end_total_away_under_25 " #826
query += " , end_total_away_over_35 " #827
query += " , end_total_away_under_35 " #828
query += " , end_total_away_over_45 " #829
query += " , end_total_away_under_45 " #830
query += " , end_total_away_over_55 " #831
query += " , end_total_away_under_55 " #832
query += " , end_total_away_over_65 " #833
query += " , end_total_away_under_65 " #834
query += " , pre_corners_asian_handicap_home_min_65 " #835
query += " , pre_corners_asian_handicap_away_min_65 " #836
query += " , pre_corners_asian_handicap_home_min_6 " #837
query += " , pre_corners_asian_handicap_away_min_6 " #838
query += " , pre_corners_asian_handicap_home_min_55 " #839
query += " , pre_corners_asian_handicap_away_min_55 " #840
query += " , pre_corners_asian_handicap_home_min_5 " #841
query += " , pre_corners_asian_handicap_away_min_5 " #842
query += " , pre_corners_asian_handicap_home_min_45 " #843
query += " , pre_corners_asian_handicap_away_min_45 " #844
query += " , pre_corners_asian_handicap_home_min_4 " #845
query += " , pre_corners_asian_handicap_away_min_4 " #846
query += " , pre_corners_asian_handicap_home_min_35 " #847
query += " , pre_corners_asian_handicap_away_min_35 " #848
query += " , pre_corners_asian_handicap_home_min_3 " #849
query += " , pre_corners_asian_handicap_away_min_3 " #850
query += " , pre_corners_asian_handicap_home_min_25 " #851
query += " , pre_corners_asian_handicap_away_min_25 " #852
query += " , pre_corners_asian_handicap_home_min_2 " #853
query += " , pre_corners_asian_handicap_away_min_2 " #854
query += " , pre_corners_asian_handicap_home_min_15 " #855
query += " , pre_corners_asian_handicap_away_min_15 " #856
query += " , pre_corners_asian_handicap_home_min_1 " #857
query += " , pre_corners_asian_handicap_home_min_05 " #858
query += " , pre_corners_asian_handicap_away_min_1 " #859
query += " , pre_corners_asian_handicap_away_min_05 " #860
query += " , pre_corners_asian_handicap_home_plus_0 " #861
query += " , pre_corners_asian_handicap_away_plus_0 " #862
query += " , pre_corners_asian_handicap_home_plus_05 " #863
query += " , pre_corners_asian_handicap_away_plus_05 " #864
query += " , pre_corners_asian_handicap_home_plus_1 " #865
query += " , pre_corners_asian_handicap_away_plus_1 " #866
query += " , pre_corners_asian_handicap_home_plus_15 " #867
query += " , pre_corners_asian_handicap_away_plus_15 " #868
query += " , pre_corners_asian_handicap_home_plus_2 " #869
query += " , pre_corners_asian_handicap_away_plus_2 " #870
query += " , pre_corners_asian_handicap_home_plus_25 " #871
query += " , pre_corners_asian_handicap_away_plus_25 " #872
query += " , pre_corners_asian_handicap_home_plus_3 " #873
query += " , pre_corners_asian_handicap_away_plus_3 " #874
query += " , pre_corners_asian_handicap_home_plus_35 " #875
query += " , pre_corners_asian_handicap_away_plus_35 " #876
query += " , pre_corners_asian_handicap_home_plus_4 " #877
query += " , pre_corners_asian_handicap_away_plus_4 " #878
query += " , pre_corners_asian_handicap_home_plus_45 " #879
query += " , pre_corners_asian_handicap_away_plus_45 " #880
query += " , pre_corners_asian_handicap_home_plus_5 " #881
query += " , pre_corners_asian_handicap_away_plus_5 " #882
query += " , pre_corners_asian_handicap_home_plus_55 " #883
query += " , pre_corners_asian_handicap_away_plus_55 " #884
query += " , pre_corners_asian_handicap_home_plus_6 " #885
query += " , pre_corners_asian_handicap_away_plus_6 " #886
query += " , pre_corners_asian_handicap_home_plus_65 " #887
query += " , pre_corners_asian_handicap_away_plus_65 " #888
query += " , end_corners_asian_handicap_home_min_65 " #889
query += " , end_corners_asian_handicap_away_min_65 " #890
query += " , end_corners_asian_handicap_home_min_6 " #891
query += " , end_corners_asian_handicap_away_min_6 " #892
query += " , end_corners_asian_handicap_home_min_55 " #893
query += " , end_corners_asian_handicap_away_min_55 " #894
query += " , end_corners_asian_handicap_home_min_5 " #895
query += " , end_corners_asian_handicap_away_min_5 " #896
query += " , end_corners_asian_handicap_home_min_45 " #897
query += " , end_corners_asian_handicap_away_min_45 " #898
query += " , end_corners_asian_handicap_home_min_4 " #899
query += " , end_corners_asian_handicap_away_min_4 " #900
query += " , end_corners_asian_handicap_home_min_35 " #901
query += " , end_corners_asian_handicap_away_min_35 " #902
query += " , end_corners_asian_handicap_home_min_3 " #903
query += " , end_corners_asian_handicap_away_min_3 " #904
query += " , end_corners_asian_handicap_home_min_25 " #905
query += " , end_corners_asian_handicap_away_min_25 " #906
query += " , end_corners_asian_handicap_home_min_2 " #907
query += " , end_corners_asian_handicap_away_min_2 " #908
query += " , end_corners_asian_handicap_home_min_15 " #909
query += " , end_corners_asian_handicap_away_min_15 " #910
query += " , end_corners_asian_handicap_home_min_1 " #911
query += " , end_corners_asian_handicap_home_min_05 " #912
query += " , end_corners_asian_handicap_away_min_1 " #913
query += " , end_corners_asian_handicap_away_min_05 " #914
query += " , end_corners_asian_handicap_home_plus_0 " #915
query += " , end_corners_asian_handicap_away_plus_0 " #916
query += " , end_corners_asian_handicap_home_plus_05 " #917 
query += " , end_corners_asian_handicap_away_plus_05 " #918
query += " , end_corners_asian_handicap_home_plus_1 " #919
query += " , end_corners_asian_handicap_away_plus_1 " #920
query += " , end_corners_asian_handicap_home_plus_15 " #921
query += " , end_corners_asian_handicap_away_plus_15 " #922
query += " , end_corners_asian_handicap_home_plus_2 " #923
query += " , end_corners_asian_handicap_away_plus_2 " #924
query += " , end_corners_asian_handicap_home_plus_25 " #925
query += " , end_corners_asian_handicap_away_plus_25 " #926
query += " , end_corners_asian_handicap_home_plus_3 " #927
query += " , end_corners_asian_handicap_away_plus_3 " #928
query += " , end_corners_asian_handicap_home_plus_35 " #929
query += " , end_corners_asian_handicap_away_plus_35 " #930
query += " , end_corners_asian_handicap_home_plus_4 " #931
query += " , end_corners_asian_handicap_away_plus_4 " #932
query += " , end_corners_asian_handicap_home_plus_45 " #933
query += " , end_corners_asian_handicap_away_plus_45 " #934
query += " , end_corners_asian_handicap_home_plus_5 " #935
query += " , end_corners_asian_handicap_away_plus_5 " #936
query += " , end_corners_asian_handicap_home_plus_55 " #937
query += " , end_corners_asian_handicap_away_plus_55 " #938
query += " , end_corners_asian_handicap_home_plus_6 " #939
query += " , end_corners_asian_handicap_away_plus_6 " #940
query += " , end_corners_asian_handicap_home_plus_65 " #941
query += " , end_corners_asian_handicap_away_plus_65 " #942
query += " , pre_corners_over_under_over_700 " #943
query += " , pre_corners_over_under_under_700 " #944
query += " , pre_corners_over_under_over_725 " #945
query += " , pre_corners_over_under_under_725 " #946
query += " , pre_corners_over_under_over_750 " #947
query += " , pre_corners_over_under_under_750 " #948
query += " , pre_corners_over_under_over_775 " #949
query += " , pre_corners_over_under_under_775 " #950
query += " , pre_corners_over_under_over_800 " #951
query += " , pre_corners_over_under_under_800 " #952
query += " , pre_corners_over_under_over_825 " #953
query += " , pre_corners_over_under_under_825 " #954
query += " , pre_corners_over_under_over_850 " #955
query += " , pre_corners_over_under_under_850 " #956
query += " , pre_corners_over_under_over_875 " #957
query += " , pre_corners_over_under_under_875 " #958
query += " , pre_corners_over_under_over_900 " #959
query += " , pre_corners_over_under_under_900 " #960
query += " , pre_corners_over_under_over_925 " #961
query += " , pre_corners_over_under_under_925 " #962
query += " , pre_corners_over_under_over_950 " #963
query += " , pre_corners_over_under_under_950 " #964
query += " , pre_corners_over_under_over_975 " #965
query += " , pre_corners_over_under_under_975 " #966
query += " , pre_corners_over_under_over_1000 " #967
query += " , pre_corners_over_under_under_1000 " #968
query += " , pre_corners_over_under_over_1025 " #969
query += " , pre_corners_over_under_under_1025 " #970
query += " , pre_corners_over_under_over_1050 " #971
query += " , pre_corners_over_under_under_1050 " #972
query += " , pre_corners_over_under_over_1075 " #973
query += " , pre_corners_over_under_under_1075 " #974
query += " , pre_corners_over_under_over_1100 " #975
query += " , pre_corners_over_under_under_1100 " #976
query += " , pre_corners_over_under_over_1125 " #977
query += " , pre_corners_over_under_under_1125 " #978
query += " , pre_corners_over_under_over_1150 " #979
query += " , pre_corners_over_under_under_1150 " #980
query += " , pre_corners_over_under_over_1175 " #981
query += " , pre_corners_over_under_under_1175 " #982
query += " , pre_corners_over_under_over_1200 " #983
query += " , pre_corners_over_under_under_1200 " #984
query += " , pre_corners_over_under_over_1225 " #985
query += " , pre_corners_over_under_under_1225 " #986
query += " , pre_corners_over_under_over_1250 " #987
query += " , pre_corners_over_under_under_1250 " #988
query += " , pre_corners_over_under_over_1275 " #989
query += " , pre_corners_over_under_under_1275 " #990
query += " , end_corners_over_under_over_700 " #991
query += " , end_corners_over_under_under_700 " #992
query += " , end_corners_over_under_over_725 " #993
query += " , end_corners_over_under_under_725 " #994
query += " , end_corners_over_under_over_750 " #995
query += " , end_corners_over_under_under_750 " #996
query += " , end_corners_over_under_over_775 " #997
query += " , end_corners_over_under_under_775 " #998
query += " , end_corners_over_under_over_800 " #999
query += " , end_corners_over_under_under_800 " #1000
query += " , end_corners_over_under_over_825 " #1001
query += " , end_corners_over_under_under_825 " #1002
query += " , end_corners_over_under_over_850 " #1003
query += " , end_corners_over_under_under_850 " #1004
query += " , end_corners_over_under_over_875 " #1005
query += " , end_corners_over_under_under_875 " #1006
query += " , end_corners_over_under_over_900 " #1007
query += " , end_corners_over_under_under_900 " #1008
query += " , end_corners_over_under_over_925 " #1009
query += " , end_corners_over_under_under_925 " #1010
query += " , end_corners_over_under_over_950 " #1011
query += " , end_corners_over_under_under_950 " #1012
query += " , end_corners_over_under_over_975 " #1013
query += " , end_corners_over_under_under_975 " #1014
query += " , end_corners_over_under_over_1000 " #1015
query += " , end_corners_over_under_under_1000 " #1016
query += " , end_corners_over_under_over_1025 " #1017
query += " , end_corners_over_under_under_1025 " #1018
query += " , end_corners_over_under_over_1050 " #1019
query += " , end_corners_over_under_under_1050 " #1020
query += " , end_corners_over_under_over_1075 " #1021
query += " , end_corners_over_under_under_1075 " #1022
query += " , end_corners_over_under_over_1100 " #1023
query += " , end_corners_over_under_under_1100 " #1024
query += " , end_corners_over_under_over_1125 " #1025
query += " , end_corners_over_under_under_1125 " #1026
query += " , end_corners_over_under_over_1150 " #1027
query += " , end_corners_over_under_under_1150 " #1028
query += " , end_corners_over_under_over_1175 " #1029
query += " , end_corners_over_under_under_1175 " #1030
query += " , end_corners_over_under_over_1200 " #1031
query += " , end_corners_over_under_under_1200 " #1032
query += " , end_corners_over_under_over_1225 " #1033
query += " , end_corners_over_under_under_1225 " #1034
query += " , end_corners_over_under_over_1250 " #1035
query += " , end_corners_over_under_under_1250 " #1036
query += " , end_corners_over_under_over_1275 " #1037
query += " , end_corners_over_under_under_1275 " #1038
query += " , pre_home_corners_overunder_over_25 " #1039
query += " , pre_home_corners_overunder_under_25 " #1040
query += " , pre_home_corners_overunder_over_35 " #1041
query += " , pre_home_corners_overunder_under_35 " #1042
query += " , pre_home_corners_overunder_over_45 " #1043
query += " , pre_home_corners_overunder_under_45 " #1044
query += " , pre_home_corners_overunder_over_55 " #1045
query += " , pre_home_corners_overunder_under_55 " #1046
query += " , pre_home_corners_overunder_over_65 " #1047
query += " , pre_home_corners_overunder_under_65 " #1048
query += " , pre_home_corners_overunder_over_75 " #1049
query += " , pre_home_corners_overunder_under_75 " #1050
query += " , pre_home_corners_overunder_over_85 " #1051
query += " , pre_home_corners_overunder_under_85 " #1052
query += " , end_home_corners_overunder_over_25 " #1053
query += " , end_home_corners_overunder_under_25 " #1054
query += " , end_home_corners_overunder_over_35 " #1055
query += " , end_home_corners_overunder_under_35 " #1056
query += " , end_home_corners_overunder_over_45 " #1057
query += " , end_home_corners_overunder_under_45 " #1058
query += " , end_home_corners_overunder_over_55 " #1059
query += " , end_home_corners_overunder_under_55 " #1060
query += " , end_home_corners_overunder_over_65 " #1061
query += " , end_home_corners_overunder_under_65 " #1062
query += " , end_home_corners_overunder_over_75 " #1063
query += " , end_home_corners_overunder_under_75 " #1064
query += " , end_home_corners_overunder_over_85 " #1065
query += " , end_home_corners_overunder_under_85 " #1066

query += " , pre_away_corners_overunder_over_25 " #1067
query += " , pre_away_corners_overunder_under_25 " #1068
query += " , pre_away_corners_overunder_over_35 " #1069
query += " , pre_away_corners_overunder_under_35 " #1070
query += " , pre_away_corners_overunder_over_45 " #1071
query += " , pre_away_corners_overunder_under_45 " #1072
query += " , pre_away_corners_overunder_over_55 " #1073
query += " , pre_away_corners_overunder_under_55 " #1074
query += " , pre_away_corners_overunder_over_65 " #1075
query += " , pre_away_corners_overunder_under_65 " #1076
query += " , pre_away_corners_overunder_over_75 " #1077
query += " , pre_away_corners_overunder_under_75 " #1078
query += " , pre_away_corners_overunder_over_85 " #1079
query += " , pre_away_corners_overunder_under_85 " #1080
query += " , end_away_corners_overunder_over_25 " #1081
query += " , end_away_corners_overunder_under_25 " #1082
query += " , end_away_corners_overunder_over_35 " #1083
query += " , end_away_corners_overunder_under_35 " #1084
query += " , end_away_corners_overunder_over_45 " #1085
query += " , end_away_corners_overunder_under_45 " #1086
query += " , end_away_corners_overunder_over_55 " #1087
query += " , end_away_corners_overunder_under_55 " #1088
query += " , end_away_corners_overunder_over_65 " #1089
query += " , end_away_corners_overunder_under_65 " #1090
query += " , end_away_corners_overunder_over_75 " #1091
query += " , end_away_corners_overunder_under_75 " #1092
query += " , end_away_corners_overunder_over_85 " #1093
query += " , end_away_corners_overunder_under_85 " #1094
query += " , pre_first_corner_home " #1095
query += " , pre_first_corner_away " #1096
query += " , end_first_corner_home " #1097
query += " , end_first_corner_away " #1098
query += " , pre_last_corner_home " #1099
query += " , pre_last_corner_away " #1100
query += " , end_last_corner_home " #1101
query += " , end_last_corner_away " #1102
query += " , pre_cards_asian_handicap_home_min_05 " #1103
query += " , pre_cards_asian_handicap_away_min_05 " #1104
query += " , pre_cards_asian_handicap_home_plus_0 " #1105
query += " , pre_cards_asian_handicap_away_plus_0 " #1106
query += " , pre_cards_asian_handicap_home_plus_05 " #1107
query += " , pre_cards_asian_handicap_away_plus_05 " #1108
query += " , end_cards_asian_handicap_home_min_05 " #1109
query += " , end_cards_asian_handicap_away_min_05 " #1110
query += " , end_cards_asian_handicap_home_plus_0 " #1111
query += " , end_cards_asian_handicap_away_plus_0 " #1112
query += " , end_cards_asian_handicap_home_plus_05 " #1113
query += " , end_cards_asian_handicap_away_plus_05 " #1114
query += " , pre_cards_overunder_over_25 " #1115
query += " , pre_cards_overunder_under_25 " #1116
query += " , pre_cards_overunder_over_35 " #1117
query += " , pre_cards_overunder_under_35 " #1118
query += " , pre_cards_overunder_over_45 " #1119
query += " , pre_cards_overunder_under_45 " #1120
query += " , pre_cards_overunder_over_55 " #1121
query += " , pre_cards_overunder_under_55 " #1122
query += " , pre_cards_overunder_over_65 " #1123
query += " , pre_cards_overunder_under_65 " #1124
query += " , pre_cards_overunder_over_75 " #1125
query += " , pre_cards_overunder_under_75 " #1126
query += " , end_cards_overunder_over_25 " #1127
query += " , end_cards_overunder_under_25 " #1128
query += " , end_cards_overunder_over_35 " #1129
query += " , end_cards_overunder_under_35 " #1130
query += " , end_cards_overunder_over_45 " #1131
query += " , end_cards_overunder_under_45 " #1132
query += " , end_cards_overunder_over_55 " #1133
query += " , end_cards_overunder_under_55 " #1134
query += " , end_cards_overunder_over_65 " #1135
query += " , end_cards_overunder_under_65 " #1136
query += " , end_cards_overunder_over_75 " #1137
query += " , end_cards_overunder_under_75 " #1138
query += " , pre_home_team_total_cards_over_15 " #1139
query += " , pre_home_team_total_cards_under_15 " #1140
query += " , pre_home_team_total_cards_over_25 " #1141
query += " , pre_home_team_total_cards_under_25 " #1142
query += " , pre_home_team_total_cards_over_35 " #1143
query += " , pre_home_team_total_cards_under_35 " #1144
query += " , end_home_team_total_cards_over_15 " #1145
query += " , end_home_team_total_cards_under_15 " #1146
query += " , end_home_team_total_cards_over_25 " #1147
query += " , end_home_team_total_cards_under_25 " #1148
query += " , end_home_team_total_cards_over_35 " #1149
query += " , end_home_team_total_cards_under_35 " #1150
query += " , pre_away_team_total_cards_over_15 " #1151
query += " , pre_away_team_total_cards_under_15 " #1152
query += " , pre_away_team_total_cards_over_25 " #1153
query += " , pre_away_team_total_cards_under_25 " #1154
query += " , pre_away_team_total_cards_over_35 " #1155
query += " , pre_away_team_total_cards_under_35 " #1156
query += " , end_away_team_total_cards_over_15 " #1157
query += " , end_away_team_total_cards_under_15 " #1158
query += " , end_away_team_total_cards_over_25 " #1159
query += " , end_away_team_total_cards_under_25 " #1160
query += " , end_away_team_total_cards_over_35 " #1161
query += " , end_away_team_total_cards_under_35 " #1162
query += " , pre_total_goals_under_2 " #1163
query += " , pre_total_goals_2_or_3 " #1164
query += " , pre_total_goals_over_3 " #1165
query += " , end_total_goals_under_2 " #1166
query += " , end_total_goals_2_or_3 " #1167
query += " , end_total_goals_over_3 " #1168
query += " , pre_first_goal_method_shot " #1169
query += " , pre_first_goal_method_header " #1170
query += " , pre_first_goal_method_penalty " #1171
query += " , pre_first_goal_method_freekick " #1172
query += " , pre_first_goal_method_owngoal " #1173
query += " , pre_first_goal_method_draw " #1174
query += " , end_first_goal_method_shot " #1175
query += " , end_first_goal_method_header " #1176
query += " , end_first_goal_method_penalty " #1177
query += " , end_first_goal_method_freekick " #1178
query += " , end_first_goal_method_owngoal " #1179
query += " , end_first_goal_method_draw " #1180
query += " , pre_to_score_a_penalty_home " #1181
query += " , pre_to_score_a_penalty_away " #1182
query += " , end_to_score_a_penalty_home " #1183
query += " , end_to_score_a_penalty_away " #1184
query += " , pre_to_miss_a_penalty_home " #1185
query += " , pre_to_miss_a_penalty_away " #1186
query += " , end_to_miss_a_penalty_home " #1187
query += " , end_to_miss_a_penalty_away " #1188
query += " , pre_anytime_goal_scorer " #1189
query += " , end_anytime_goal_scorer " #1190
query += " , pre_first_goal_scorer " #1191
query += " , end_first_goal_scorer " #1192
query += " , pre_last_goal_scorer " #1193
query += " , end_last_goal_scorer " #1194
query += " , pre_to_score_two_or_more_goals " #1195
query += " , end_to_score_two_or_more_goals " #1196
query += " , pre_last_goal_scorer2 " #1197
query += " , end_last_goal_scorer2 " #1198
query += " , pre_exact_score " #1199
query += " , end_exact_score " #1200
query += " , pre_player_to_be_booked " #1201
query += " , end_player_to_be_booked " #1202
query += " , pre_ah_pattern " #1203
query += " , pre_ah_pattern_mirror " #1204
query += " , pre_gou_pattern " #1205
query += " , end_ah_pattern " #1206
query += " , end_ah_pattern_mirror " #1207
query += " , end_gou_pattern " #1208
query += " , pre_response " #1209
query += " , end_response " #1210
query += " , pre_odd_updated_at " #1211
query += " , end_odd_updated_at " #1212
query += " , pre_ah_pattern_4 " #1213
query += " , pre_ah_pattern_mirror_4 " #1214
query += " , pre_gou_pattern_4 " #1215
query += " , end_ah_pattern_4 " #1216
query += " , end_ah_pattern_mirror_4 " #1217
query += " , end_gou_pattern_4 " #1218
query += " , special_odds " #1219

query += " , leagueapi_id " #
query += " , season " #
query += " , fixtureapi_id " #

query += " from football_odds_xx "  
# ------------------------------------------------------   
# print(query, flush=True)
# ------------------------------------------------------    
mycursor.execute(query)
result =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result)
# ------------------------------------------------------    
mycursor.close()
mydb.close()  
# ------------------------------------------------------ 
for rs1 in result: 
    # --------------------------------------------------    
    counter_col = 0 
    if(rs1[counter_col] is None):
        pre_match_winner_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_match_winner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #2
    if(rs1[counter_col] is None):
        pre_match_winner_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_match_winner_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #3
    if(rs1[counter_col] is None):
        pre_match_winner_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_match_winner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #4
    if(rs1[counter_col] is None):
        end_match_winner_home = "Null"
    elif(rs1[counter_col] is not None):
        end_match_winner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #5
    if(rs1[counter_col] is None):
        end_match_winner_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_match_winner_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #6
    if(rs1[counter_col] is None):
        end_match_winner_away = "Null"
    elif(rs1[counter_col] is not None):
        end_match_winner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #7
    if(rs1[counter_col] is None):
        pre_homeaway_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_homeaway_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #8
    if(rs1[counter_col] is None):
        pre_homeaway_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_homeaway_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #9
    if(rs1[counter_col] is None):
        end_homeaway_home = "Null"
    elif(rs1[counter_col] is not None):
        end_homeaway_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #10
    if(rs1[counter_col] is None):
        end_homeaway_away = "Null"
    elif(rs1[counter_col] is not None):
        end_homeaway_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #11
    if(rs1[counter_col] is None):
        pre_first_half_winner_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_half_winner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #12
    if(rs1[counter_col] is None):
        pre_first_half_winner_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_half_winner_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #13
    if(rs1[counter_col] is None):
        pre_first_half_winner_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_half_winner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #14
    if(rs1[counter_col] is None):
        end_first_half_winner_home = "Null"
    elif(rs1[counter_col] is not None):
        end_first_half_winner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #15
    if(rs1[counter_col] is None):
        end_first_half_winner_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_first_half_winner_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #16
    if(rs1[counter_col] is None):
        end_first_half_winner_away = "Null"
    elif(rs1[counter_col] is not None):
        end_first_half_winner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #17
    if(rs1[counter_col] is None):
        pre_second_half_winner_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_second_half_winner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #18
    if(rs1[counter_col] is None):
        pre_second_half_winner_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_second_half_winner_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #19
    if(rs1[counter_col] is None):
        pre_second_half_winner_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_second_half_winner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #20
    if(rs1[counter_col] is None):
        end_second_half_winner_home = "Null"
    elif(rs1[counter_col] is not None):
        end_second_half_winner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #21
    if(rs1[counter_col] is None):
        end_second_half_winner_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_second_half_winner_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #22
    if(rs1[counter_col] is None):
        end_second_half_winner_away = "Null"
    elif(rs1[counter_col] is not None):
        end_second_half_winner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #23
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_675 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #24
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_675 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #25
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #26
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #27
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_625 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #28
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_625 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #29
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_6 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #30
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_6 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #31
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_575 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #32
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_575 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #33
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #34
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #35
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_525 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #36
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_525 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #37
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #38
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #39
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_475 = "Null"

    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #40
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_475 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #41
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #42
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #43
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_425 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #44
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_425 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #45
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #46
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #47
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_375 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #48
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_375 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #49
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #50
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #51
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_325 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #52
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_325 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #53
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #54
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #55
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #56
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #57
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #58
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #59
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #60
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #61
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #62
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #63
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #64
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #65
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #66
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #67
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #68
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #69
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #70
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #71
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #72
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #73
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #74
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #75
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_min_025 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_min_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #76
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_min_025 = "Null"

    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_min_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #77
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #78
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #79
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_025 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #80
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_025 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #81
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #82
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #83
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #84
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #85
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #86
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #87
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #88
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #89
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #90
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #91
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #92
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #93
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #94
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #95
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #96
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #97
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #98
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #99
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #100
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #101
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #102
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #103
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_325 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #104
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_325 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #105
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #106
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #107
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_375 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #108
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_375 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #109
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #110
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #111
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_425 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #112
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_425 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #113
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #114
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #115
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_475 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #116
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_475 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #117
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #118
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #119
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_525 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #120
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_525 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #121
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #122
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #123
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_575 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #124
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_575 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #125
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_6 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #126
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_6 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #127
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_625 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #128
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_625 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #129
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #130
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #131
    if(rs1[counter_col] is None):
        pre_asian_handicap_home_plus_675 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_home_plus_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #132
    if(rs1[counter_col] is None):
        pre_asian_handicap_away_plus_675 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_away_plus_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #133
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_675 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #134
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_675 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #135
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #136
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #137
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_625 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #138
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_625 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #139
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_6 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #140
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_6 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #141
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_575 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #142
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_575 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #143
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #144
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #145
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_525 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #146
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_525 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #147
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_5 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #148
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_5 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #149
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_475 = "Null"
    elif(rs1[counter_col] is not None):

        end_asian_handicap_home_min_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #150
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_475 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #151
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #152
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #153
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_425 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #154
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_425 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #155
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #156
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #157
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_375 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #158
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_375 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #159
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #160
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #161
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_325 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #162
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_325 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #163
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #164
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #165
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_275 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #166
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_275 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #167
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #168
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #169
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_225 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #170
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_225 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #171
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #172
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #173
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #174
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #175
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #176
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #177
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #178
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #179
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #180
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #181
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #182
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #183
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #184
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #185
    if(rs1[counter_col] is None):
        end_asian_handicap_home_min_025 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_min_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #186
    if(rs1[counter_col] is None):
        end_asian_handicap_away_min_025 = "Null"

    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_min_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #187
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #188
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #189
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_025 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #190
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_025 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #191
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #192
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #193
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #194
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #195
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #196
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #197
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #198
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #199
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #200
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #201
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #202
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #203
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #204
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #205
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_225 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #206
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_225 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #207
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #208
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #209
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_275 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #210
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_275 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #211
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #212
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #213
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_325 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #214
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_325 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #215
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #216
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #217
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_375 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #218
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_375 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #219
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #220
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #221
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_425 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #222
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_425 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #223
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #224
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #225
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_475 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #226
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_475 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #227
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_5 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #228
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_5 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #229
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_525 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #230
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_525 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #231
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #232
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #233
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_575 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #234
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_575 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #235
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_6 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #236
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_6 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #237
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_625 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #238
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_625 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #239
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #240
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #241
    if(rs1[counter_col] is None):
        end_asian_handicap_home_plus_675 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_home_plus_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #242
    if(rs1[counter_col] is None):
        end_asian_handicap_away_plus_675 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_away_plus_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #243
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #244
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #245
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #246
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #247
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_10 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #248
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_10 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #249
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #250
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #251
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #252
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #253
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #254
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #255
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_20 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #256
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_20 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #257
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #258
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #259
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #260
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #261
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #262
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #263
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_30 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #264
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_30 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #265
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_325 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #266
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_325 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #267
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #268
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #269
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_375 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #270
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_375 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #271
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_40 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_40 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #272
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_40 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_40 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #273
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_425 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #274
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_425 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #275
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #276
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #277
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_475 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #278
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_475 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #279
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_50 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_50 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #280
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_50 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_50 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #281
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_525 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #282
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_525 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #283
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #284
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #285
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_575 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #286
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_575 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #287
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_60 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_60 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #288
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_60 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_60 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #289
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_625 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #290
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_625 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #291
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #292
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #293
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_675 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #294
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_675 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #295
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_70 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_70 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #296
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_70 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_70 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #297
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_75 = "Null"

    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #298
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_75 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #299
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_85 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #300
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_85 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #301
    if(rs1[counter_col] is None):
        pre_goals_overunder_over_95 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_over_95 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #302
    if(rs1[counter_col] is None):
        pre_goals_overunder_under_95 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_under_95 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #303
    if(rs1[counter_col] is None):
        end_goals_overunder_over_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #304
    if(rs1[counter_col] is None):
        end_goals_overunder_under_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #305
    if(rs1[counter_col] is None):
        end_goals_overunder_over_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #306
    if(rs1[counter_col] is None):
        end_goals_overunder_under_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #307
    if(rs1[counter_col] is None):
        end_goals_overunder_over_10 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #308
    if(rs1[counter_col] is None):
        end_goals_overunder_under_10 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #309
    if(rs1[counter_col] is None):
        end_goals_overunder_over_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #310
    if(rs1[counter_col] is None):
        end_goals_overunder_under_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #311
    if(rs1[counter_col] is None):
        end_goals_overunder_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #312
    if(rs1[counter_col] is None):
        end_goals_overunder_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #313
    if(rs1[counter_col] is None):
        end_goals_overunder_over_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #314
    if(rs1[counter_col] is None):
        end_goals_overunder_under_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #315
    if(rs1[counter_col] is None):
        end_goals_overunder_over_20 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #316
    if(rs1[counter_col] is None):
        end_goals_overunder_under_20 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #317
    if(rs1[counter_col] is None):
        end_goals_overunder_over_225 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #318
    if(rs1[counter_col] is None):
        end_goals_overunder_under_225 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #319
    if(rs1[counter_col] is None):
        end_goals_overunder_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #320
    if(rs1[counter_col] is None):
        end_goals_overunder_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #321
    if(rs1[counter_col] is None):
        end_goals_overunder_over_275 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #322
    if(rs1[counter_col] is None):
        end_goals_overunder_under_275 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #323
    if(rs1[counter_col] is None):
        end_goals_overunder_over_30 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #324
    if(rs1[counter_col] is None):
        end_goals_overunder_under_30 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #325
    if(rs1[counter_col] is None):
        end_goals_overunder_over_325 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #326
    if(rs1[counter_col] is None):
        end_goals_overunder_under_325 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #327
    if(rs1[counter_col] is None):
        end_goals_overunder_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #328
    if(rs1[counter_col] is None):
        end_goals_overunder_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #329
    if(rs1[counter_col] is None):
        end_goals_overunder_over_375 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #330
    if(rs1[counter_col] is None):
        end_goals_overunder_under_375 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #331
    if(rs1[counter_col] is None):
        end_goals_overunder_over_40 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_40 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #332
    if(rs1[counter_col] is None):
        end_goals_overunder_under_40 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_40 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #333
    if(rs1[counter_col] is None):
        end_goals_overunder_over_425 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #334
    if(rs1[counter_col] is None):
        end_goals_overunder_under_425 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_425 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #335
    if(rs1[counter_col] is None):
        end_goals_overunder_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #336
    if(rs1[counter_col] is None):
        end_goals_overunder_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #337
    if(rs1[counter_col] is None):
        end_goals_overunder_over_475 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #338
    if(rs1[counter_col] is None):
        end_goals_overunder_under_475 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_475 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #339
    if(rs1[counter_col] is None):
        end_goals_overunder_over_50 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_50 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #340
    if(rs1[counter_col] is None):
        end_goals_overunder_under_50 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_50 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #341
    if(rs1[counter_col] is None):
        end_goals_overunder_over_525 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #342
    if(rs1[counter_col] is None):
        end_goals_overunder_under_525 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_525 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #343
    if(rs1[counter_col] is None):
        end_goals_overunder_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #344
    if(rs1[counter_col] is None):
        end_goals_overunder_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #345
    if(rs1[counter_col] is None):
        end_goals_overunder_over_575 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #346
    if(rs1[counter_col] is None):
        end_goals_overunder_under_575 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_575 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #347
    if(rs1[counter_col] is None):
        end_goals_overunder_over_60 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_60 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #348
    if(rs1[counter_col] is None):
        end_goals_overunder_under_60 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_60 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #349
    if(rs1[counter_col] is None):
        end_goals_overunder_over_625 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #350
    if(rs1[counter_col] is None):
        end_goals_overunder_under_625 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_625 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #351
    if(rs1[counter_col] is None):
        end_goals_overunder_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #352
    if(rs1[counter_col] is None):
        end_goals_overunder_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #353
    if(rs1[counter_col] is None):
        end_goals_overunder_over_675 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #354
    if(rs1[counter_col] is None):
        end_goals_overunder_under_675 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_675 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #355
    if(rs1[counter_col] is None):
        end_goals_overunder_over_70 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_70 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #356
    if(rs1[counter_col] is None):
        end_goals_overunder_under_70 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_70 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #357
    if(rs1[counter_col] is None):
        end_goals_overunder_over_75 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #358
    if(rs1[counter_col] is None):
        end_goals_overunder_under_75 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #359
    if(rs1[counter_col] is None):
        end_goals_overunder_over_85 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #360
    if(rs1[counter_col] is None):
        end_goals_overunder_under_85 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #361
    if(rs1[counter_col] is None):
        end_goals_overunder_over_95 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_over_95 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #362
    if(rs1[counter_col] is None):
        end_goals_overunder_under_95 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_under_95 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #363
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_min_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_min_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #364
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_min_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_min_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #365
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #366
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #367
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_min_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_min_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #368
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_min_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_min_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #369
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #370
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #371
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_min_075 = "Null"

    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_min_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #372
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_min_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_min_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #373
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #374
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #375
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_min_025 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_min_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #376
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_min_025 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_min_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #377
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #378
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #379
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_plus_025 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_plus_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #380
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_plus_025 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_plus_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #381
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #382
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #383
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_plus_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_plus_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #384
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_plus_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_plus_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #385
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #386
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #387
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_plus_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_plus_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #388
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_plus_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_plus_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #389
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #390
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #391
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_home_plus_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_home_plus_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #392
    if(rs1[counter_col] is None):
        pre_asian_handicap_first_half_away_plus_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_asian_handicap_first_half_away_plus_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #393
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_min_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_min_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #394
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_min_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_min_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #395
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #396
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #397
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_min_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_min_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #398
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_min_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_min_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #399
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #400
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #401
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_min_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_min_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #402
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_min_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_min_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #403
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #404
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #405
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_min_025 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_min_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #406
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_min_025 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_min_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #407
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #408
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #409
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_plus_025 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_plus_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #410
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_plus_025 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_plus_025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #411
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #412
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #413
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_plus_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_plus_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #414
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_plus_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_plus_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #415
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #416
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #417
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_plus_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_plus_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #418
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_plus_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_plus_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #419
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #420
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #421
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_home_plus_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_home_plus_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #422
    if(rs1[counter_col] is None):
        end_asian_handicap_first_half_away_plus_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_asian_handicap_first_half_away_plus_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #423
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #424
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #425
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #426
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #427
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_10 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #428
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_10 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #429
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #430
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #431
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #432
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #433
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #434
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #435
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_20 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #436
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_20 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #437
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #438
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_225 = "Null"
    elif(rs1[counter_col] is not None):

        pre_goals_overunder_first_half_under_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #439
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #440
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #441
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #442
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #443
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_30 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #444
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_30 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #445
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_325 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #446
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_325 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #447
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #448
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #449
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_over_375 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_over_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #450
    if(rs1[counter_col] is None):
        pre_goals_overunder_first_half_under_375 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder_first_half_under_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #451
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #452
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #453
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #454
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #455
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_10 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #456
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_10 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #457
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #458
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #459
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #460
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #461
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #462
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #463
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_20 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #464
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_20 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #465
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_225 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #466
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_225 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #467
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #468
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #469
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_275 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #470
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_275 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #471
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_30 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #472
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_30 = "Null"
    elif(rs1[counter_col] is not None):

        end_goals_overunder_first_half_under_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #473
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_325 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #474
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_325 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #475
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #476
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #477
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_over_375 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_over_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #478
    if(rs1[counter_col] is None):
        end_goals_overunder_first_half_under_375 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder_first_half_under_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #479
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #480
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #481
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #482
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #483
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_10 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #484
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_10 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #485
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #486
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #487
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #488
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #489
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #490
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #491
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_20 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #492
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_20 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #493
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #494
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #495
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #496
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #497
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #498
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #499
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_30 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #500
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_30 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #501
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_325 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #502
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_325 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #503
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #504
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #505
    if(rs1[counter_col] is None):
        pre_goals_overunder__second_half_over_375 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_over_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #506
    if(rs1[counter_col] is None):

        pre_goals_overunder__second_half_under_375 = "Null"
    elif(rs1[counter_col] is not None):
        pre_goals_overunder__second_half_under_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #507
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #508
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #509
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #510
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_075 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #511
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_10 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #512
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_10 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_10 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #513
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #514
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_125 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #515
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #516
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #517
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #518
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_175 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #519
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_20 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #520
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_20 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_20 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #521
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_225 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #522
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_225 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #523
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #524
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #525
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_275 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #526
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_275 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #527
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_30 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #528
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_30 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_30 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #529
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_325 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #530
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_325 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_325 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #531
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #532
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #533
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_over_375 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_over_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #534
    if(rs1[counter_col] is None):
        end_goals_overunder__second_half_under_375 = "Null"
    elif(rs1[counter_col] is not None):
        end_goals_overunder__second_half_under_375 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #535
    if(rs1[counter_col] is None):
        pre_htft_double_home_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_htft_double_home_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #536
    if(rs1[counter_col] is None):
        pre_htft_double_home_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_htft_double_home_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #537
    if(rs1[counter_col] is None):
        pre_htft_double_home_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_htft_double_home_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #538
    if(rs1[counter_col] is None):
        pre_htft_double_draw_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_htft_double_draw_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #539
    if(rs1[counter_col] is None):
        pre_htft_double_draw_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_htft_double_draw_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #540
    if(rs1[counter_col] is None):
        pre_htft_double_draw_away = "Null"

    elif(rs1[counter_col] is not None):
        pre_htft_double_draw_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #541
    if(rs1[counter_col] is None):
        pre_htft_double_away_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_htft_double_away_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #542
    if(rs1[counter_col] is None):
        pre_htft_double_away_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_htft_double_away_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #543
    if(rs1[counter_col] is None):
        pre_htft_double_away_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_htft_double_away_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #544
    if(rs1[counter_col] is None):
        end_htft_double_home_home = "Null"
    elif(rs1[counter_col] is not None):
        end_htft_double_home_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #545
    if(rs1[counter_col] is None):
        end_htft_double_home_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_htft_double_home_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #546
    if(rs1[counter_col] is None):
        end_htft_double_home_away = "Null"
    elif(rs1[counter_col] is not None):
        end_htft_double_home_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #547
    if(rs1[counter_col] is None):
        end_htft_double_draw_home = "Null"
    elif(rs1[counter_col] is not None):
        end_htft_double_draw_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #548
    if(rs1[counter_col] is None):
        end_htft_double_draw_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_htft_double_draw_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #549
    if(rs1[counter_col] is None):
        end_htft_double_draw_away = "Null"
    elif(rs1[counter_col] is not None):
        end_htft_double_draw_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #550
    if(rs1[counter_col] is None):
        end_htft_double_away_home = "Null"
    elif(rs1[counter_col] is not None):
        end_htft_double_away_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #551
    if(rs1[counter_col] is None):
        end_htft_double_away_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_htft_double_away_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #552
    if(rs1[counter_col] is None):
        end_htft_double_away_away = "Null"
    elif(rs1[counter_col] is not None):
        end_htft_double_away_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #553
    if(rs1[counter_col] is None):
        pre_both_teams_score_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_both_teams_score_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #554
    if(rs1[counter_col] is None):
        pre_both_teams_score_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_both_teams_score_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #555
    if(rs1[counter_col] is None):
        end_both_teams_score_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_both_teams_score_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #556
    if(rs1[counter_col] is None):
        end_both_teams_score_no = "Null"
    elif(rs1[counter_col] is not None):
        end_both_teams_score_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #557
    if(rs1[counter_col] is None):
        pre_both_teams_score__first_half_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_both_teams_score__first_half_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #558
    if(rs1[counter_col] is None):
        pre_both_teams_score__first_half_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_both_teams_score__first_half_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #559
    if(rs1[counter_col] is None):
        end_both_teams_score__first_half_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_both_teams_score__first_half_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #560
    if(rs1[counter_col] is None):
        end_both_teams_score__first_half_no = "Null"
    elif(rs1[counter_col] is not None):
        end_both_teams_score__first_half_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #561
    if(rs1[counter_col] is None):
        pre_both_teams_to_score__second_half_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_both_teams_to_score__second_half_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #562
    if(rs1[counter_col] is None):
        pre_both_teams_to_score__second_half_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_both_teams_to_score__second_half_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #563
    if(rs1[counter_col] is None):
        end_both_teams_to_score__second_half_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_both_teams_to_score__second_half_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #564
    if(rs1[counter_col] is None):
        end_both_teams_to_score__second_half_no = "Null"
    elif(rs1[counter_col] is not None):
        end_both_teams_to_score__second_half_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #565
    if(rs1[counter_col] is None):
        pre_results_both_teams_score_home_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_results_both_teams_score_home_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #566
    if(rs1[counter_col] is None):
        pre_results_both_teams_score_draw_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_results_both_teams_score_draw_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #567
    if(rs1[counter_col] is None):
        pre_results_both_teams_score_away_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_results_both_teams_score_away_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #568
    if(rs1[counter_col] is None):
        pre_results_both_teams_score_home_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_results_both_teams_score_home_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #569
    if(rs1[counter_col] is None):
        pre_results_both_teams_score_draw_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_results_both_teams_score_draw_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #570
    if(rs1[counter_col] is None):
        pre_results_both_teams_score_away_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_results_both_teams_score_away_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #571
    if(rs1[counter_col] is None):
        end_results_both_teams_score_home_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_results_both_teams_score_home_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #572
    if(rs1[counter_col] is None):
        end_results_both_teams_score_draw_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_results_both_teams_score_draw_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #573
    if(rs1[counter_col] is None):
        end_results_both_teams_score_away_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_results_both_teams_score_away_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #574
    if(rs1[counter_col] is None):
        end_results_both_teams_score_home_no = "Null"
    elif(rs1[counter_col] is not None):
        end_results_both_teams_score_home_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #575
    if(rs1[counter_col] is None):
        end_results_both_teams_score_draw_no = "Null"
    elif(rs1[counter_col] is not None):
        end_results_both_teams_score_draw_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #576
    if(rs1[counter_col] is None):
        end_results_both_teams_score_away_no = "Null"
    elif(rs1[counter_col] is not None):
        end_results_both_teams_score_away_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #577
    if(rs1[counter_col] is None):
        pre_to_score_in_both_halves_by_teams_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_to_score_in_both_halves_by_teams_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #578
    if(rs1[counter_col] is None):
        pre_to_score_in_both_halves_by_teams_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_to_score_in_both_halves_by_teams_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #579
    if(rs1[counter_col] is None):
        end_to_score_in_both_halves_by_teams_home = "Null"
    elif(rs1[counter_col] is not None):
        end_to_score_in_both_halves_by_teams_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #580
    if(rs1[counter_col] is None):
        end_to_score_in_both_halves_by_teams_away = "Null"
    elif(rs1[counter_col] is not None):
        end_to_score_in_both_halves_by_teams_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #581
    if(rs1[counter_col] is None):
        pre_total_goals_both_teams_to_score_over_yes_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_goals_both_teams_to_score_over_yes_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #582
    if(rs1[counter_col] is None):
        pre_total_goals_both_teams_to_score_over_no_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_goals_both_teams_to_score_over_no_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #583
    if(rs1[counter_col] is None):
        pre_total_goals_both_teams_to_score_under_yes_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_goals_both_teams_to_score_under_yes_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #584
    if(rs1[counter_col] is None):
        pre_total_goals_both_teams_to_score_under_no_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_goals_both_teams_to_score_under_no_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #585
    if(rs1[counter_col] is None):
        end_total_goals_both_teams_to_score_over_yes_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_goals_both_teams_to_score_over_yes_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #586
    if(rs1[counter_col] is None):
        end_total_goals_both_teams_to_score_over_no_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_goals_both_teams_to_score_over_no_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #587
    if(rs1[counter_col] is None):
        end_total_goals_both_teams_to_score_under_yes_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_goals_both_teams_to_score_under_yes_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #588
    if(rs1[counter_col] is None):
        end_total_goals_both_teams_to_score_under_no_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_goals_both_teams_to_score_under_no_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #589
    if(rs1[counter_col] is None):
        pre_both_teams_to_score_1st_half__2nd_half_yes_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_both_teams_to_score_1st_half__2nd_half_yes_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #590
    if(rs1[counter_col] is None):
        pre_both_teams_to_score_1st_half__2nd_half_yes_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_both_teams_to_score_1st_half__2nd_half_yes_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #591
    if(rs1[counter_col] is None):
        pre_both_teams_to_score_1st_half__2nd_half_no_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_both_teams_to_score_1st_half__2nd_half_no_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #592
    if(rs1[counter_col] is None):
        pre_both_teams_to_score_1st_half__2nd_half_no_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_both_teams_to_score_1st_half__2nd_half_no_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #593
    if(rs1[counter_col] is None):
        end_both_teams_to_score_1st_half__2nd_half_yes_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_both_teams_to_score_1st_half__2nd_half_yes_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #594
    if(rs1[counter_col] is None):
        end_both_teams_to_score_1st_half__2nd_half_yes_no = "Null"
    elif(rs1[counter_col] is not None):
        end_both_teams_to_score_1st_half__2nd_half_yes_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #595
    if(rs1[counter_col] is None):
        end_both_teams_to_score_1st_half__2nd_half_no_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_both_teams_to_score_1st_half__2nd_half_no_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #596
    if(rs1[counter_col] is None):
        end_both_teams_to_score_1st_half__2nd_half_no_no = "Null"
    elif(rs1[counter_col] is not None):
        end_both_teams_to_score_1st_half__2nd_half_no_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #597
    if(rs1[counter_col] is None):
        pre_highest_scoring_half_first = "Null"
    elif(rs1[counter_col] is not None):
        pre_highest_scoring_half_first = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #598
    if(rs1[counter_col] is None):
        pre_highest_scoring_half_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_highest_scoring_half_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #599
    if(rs1[counter_col] is None):
        pre_highest_scoring_half_second = "Null"
    elif(rs1[counter_col] is not None):
        pre_highest_scoring_half_second = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #600
    if(rs1[counter_col] is None):
        end_highest_scoring_half_first = "Null"
    elif(rs1[counter_col] is not None):
        end_highest_scoring_half_first = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #601
    if(rs1[counter_col] is None):
        end_highest_scoring_half_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_highest_scoring_half_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #602
    if(rs1[counter_col] is None):
        end_highest_scoring_half_second = "Null"
    elif(rs1[counter_col] is not None):
        end_highest_scoring_half_second = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #603
    if(rs1[counter_col] is None):
        pre_double_chance_home_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_double_chance_home_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #604
    if(rs1[counter_col] is None):
        pre_double_chance_home_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_double_chance_home_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #605
    if(rs1[counter_col] is None):
        pre_double_chance_draw_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_double_chance_draw_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #606
    if(rs1[counter_col] is None):
        end_double_chance_home_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_double_chance_home_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #607
    if(rs1[counter_col] is None):
        end_double_chance_home_away = "Null"
    elif(rs1[counter_col] is not None):
        end_double_chance_home_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #608
    if(rs1[counter_col] is None):
        end_double_chance_draw_away = "Null"
    elif(rs1[counter_col] is not None):
        end_double_chance_draw_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #609
    if(rs1[counter_col] is None):
        pre_double_chance__first_half_home_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_double_chance__first_half_home_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #610
    if(rs1[counter_col] is None):
        pre_double_chance__first_half_home_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_double_chance__first_half_home_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #611
    if(rs1[counter_col] is None):
        pre_double_chance__first_half_draw_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_double_chance__first_half_draw_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #612
    if(rs1[counter_col] is None):
        end_double_chance__first_half_home_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_double_chance__first_half_home_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #613
    if(rs1[counter_col] is None):
        end_double_chance__first_half_home_away = "Null"
    elif(rs1[counter_col] is not None):
        end_double_chance__first_half_home_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #614
    if(rs1[counter_col] is None):
        end_double_chance__first_half_draw_away = "Null"
    elif(rs1[counter_col] is not None):
        end_double_chance__first_half_draw_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #615
    if(rs1[counter_col] is None):
        pre_oddeven_odd = "Null"
    elif(rs1[counter_col] is not None):
        pre_oddeven_odd = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #616
    if(rs1[counter_col] is None):
        pre_oddeven_even = "Null"
    elif(rs1[counter_col] is not None):
        pre_oddeven_even = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #617
    if(rs1[counter_col] is None):
        end_oddeven_odd = "Null"
    elif(rs1[counter_col] is not None):
        end_oddeven_odd = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #618
    if(rs1[counter_col] is None):
        end_oddeven_even = "Null"
    elif(rs1[counter_col] is not None):
        end_oddeven_even = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #619
    if(rs1[counter_col] is None):
        pre_result_total_goals_home_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_home_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #620
    if(rs1[counter_col] is None):
        pre_result_total_goals_draw_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_draw_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #621
    if(rs1[counter_col] is None):
        pre_result_total_goals_away_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_away_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #622
    if(rs1[counter_col] is None):
        pre_result_total_goals_home_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_home_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #623
    if(rs1[counter_col] is None):
        pre_result_total_goals_draw_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_draw_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #624
    if(rs1[counter_col] is None):
        pre_result_total_goals_away_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_away_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #625
    if(rs1[counter_col] is None):
        pre_result_total_goals_home_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_home_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #626
    if(rs1[counter_col] is None):
        pre_result_total_goals_draw_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_draw_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #627
    if(rs1[counter_col] is None):
        pre_result_total_goals_away_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_away_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #628
    if(rs1[counter_col] is None):
        pre_result_total_goals_home_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_home_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #629
    if(rs1[counter_col] is None):
        pre_result_total_goals_draw_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_draw_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #630
    if(rs1[counter_col] is None):
        pre_result_total_goals_away_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_result_total_goals_away_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #631
    if(rs1[counter_col] is None):
        end_result_total_goals_home_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_home_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #632
    if(rs1[counter_col] is None):
        end_result_total_goals_draw_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_draw_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #633
    if(rs1[counter_col] is None):
        end_result_total_goals_away_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_away_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #634
    if(rs1[counter_col] is None):
        end_result_total_goals_home_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_home_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #635
    if(rs1[counter_col] is None):
        end_result_total_goals_draw_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_draw_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #636
    if(rs1[counter_col] is None):
        end_result_total_goals_away_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_away_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #637
    if(rs1[counter_col] is None):
        end_result_total_goals_home_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_home_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #638
    if(rs1[counter_col] is None):
        end_result_total_goals_draw_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_draw_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #639
    if(rs1[counter_col] is None):
        end_result_total_goals_away_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_away_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #640
    if(rs1[counter_col] is None):
        end_result_total_goals_home_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_home_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #641
    if(rs1[counter_col] is None):
        end_result_total_goals_draw_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_draw_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #642
    if(rs1[counter_col] is None):
        end_result_total_goals_away_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_result_total_goals_away_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #643
    if(rs1[counter_col] is None):
        pre_clean_sheet__home_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_clean_sheet__home_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #644
    if(rs1[counter_col] is None):
        pre_clean_sheet__home_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_clean_sheet__home_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #645
    if(rs1[counter_col] is None):
        end_clean_sheet__home_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_clean_sheet__home_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #646
    if(rs1[counter_col] is None):
        end_clean_sheet__home_no = "Null"
    elif(rs1[counter_col] is not None):
        end_clean_sheet__home_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #647
    if(rs1[counter_col] is None):
        pre_clean_sheet__away_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_clean_sheet__away_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #648
    if(rs1[counter_col] is None):
        pre_clean_sheet__away_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_clean_sheet__away_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #649
    if(rs1[counter_col] is None):
        end_clean_sheet__away_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_clean_sheet__away_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #650
    if(rs1[counter_col] is None):
        end_clean_sheet__away_no = "Null"
    elif(rs1[counter_col] is not None):
        end_clean_sheet__away_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #651
    if(rs1[counter_col] is None):
        pre_win_both_halves_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_win_both_halves_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #652
    if(rs1[counter_col] is None):
        pre_win_both_halves_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_win_both_halves_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #653
    if(rs1[counter_col] is None):
        end_win_both_halves_home = "Null"
    elif(rs1[counter_col] is not None):
        end_win_both_halves_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #654
    if(rs1[counter_col] is None):
        end_win_both_halves_away = "Null"
    elif(rs1[counter_col] is not None):
        end_win_both_halves_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #655
    if(rs1[counter_col] is None):
        pre_win_to_nil_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_win_to_nil_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #656
    if(rs1[counter_col] is None):
        pre_win_to_nil_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_win_to_nil_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #657
    if(rs1[counter_col] is None):
        end_win_to_nil_home = "Null"
    elif(rs1[counter_col] is not None):
        end_win_to_nil_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #658
    if(rs1[counter_col] is None):
        end_win_to_nil_away = "Null"
    elif(rs1[counter_col] is not None):
        end_win_to_nil_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #659
    if(rs1[counter_col] is None):
        pre_to_win_either_half_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_to_win_either_half_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #660
    if(rs1[counter_col] is None):
        pre_to_win_either_half_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_to_win_either_half_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #661
    if(rs1[counter_col] is None):
        end_to_win_either_half_home = "Null"
    elif(rs1[counter_col] is not None):
        end_to_win_either_half_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #662
    if(rs1[counter_col] is None):
        end_to_win_either_half_away = "Null"
    elif(rs1[counter_col] is not None):
        end_to_win_either_half_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #663
    if(rs1[counter_col] is None):
        pre_halftime_result_both_teams_score_home_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_halftime_result_both_teams_score_home_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #664
    if(rs1[counter_col] is None):
        pre_halftime_result_both_teams_score_draw_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_halftime_result_both_teams_score_draw_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #665
    if(rs1[counter_col] is None):
        pre_halftime_result_both_teams_score_away_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_halftime_result_both_teams_score_away_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #666
    if(rs1[counter_col] is None):
        pre_halftime_result_both_teams_score_home_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_halftime_result_both_teams_score_home_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #667
    if(rs1[counter_col] is None):
        pre_halftime_result_both_teams_score_draw_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_halftime_result_both_teams_score_draw_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #668
    if(rs1[counter_col] is None):
        pre_halftime_result_both_teams_score_away_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_halftime_result_both_teams_score_away_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #669
    if(rs1[counter_col] is None):
        end_halftime_result_both_teams_score_home_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_halftime_result_both_teams_score_home_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #670
    if(rs1[counter_col] is None):
        end_halftime_result_both_teams_score_draw_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_halftime_result_both_teams_score_draw_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #671
    if(rs1[counter_col] is None):
        end_halftime_result_both_teams_score_away_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_halftime_result_both_teams_score_away_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #672
    if(rs1[counter_col] is None):
        end_halftime_result_both_teams_score_home_no = "Null"
    elif(rs1[counter_col] is not None):
        end_halftime_result_both_teams_score_home_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #673
    if(rs1[counter_col] is None):
        end_halftime_result_both_teams_score_draw_no = "Null"
    elif(rs1[counter_col] is not None):
        end_halftime_result_both_teams_score_draw_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #674
    if(rs1[counter_col] is None):
        end_halftime_result_both_teams_score_away_no = "Null"
    elif(rs1[counter_col] is not None):
        end_halftime_result_both_teams_score_away_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #675
    if(rs1[counter_col] is None):
        pre_exact_goals_number_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #676
    if(rs1[counter_col] is None):
        pre_exact_goals_number_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #677
    if(rs1[counter_col] is None):
        pre_exact_goals_number_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #678
    if(rs1[counter_col] is None):
        pre_exact_goals_number_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #679
    if(rs1[counter_col] is None):
        pre_exact_goals_number_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #680
    if(rs1[counter_col] is None):
        pre_exact_goals_number_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #681
    if(rs1[counter_col] is None):
        pre_exact_goals_number_6 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #682
    if(rs1[counter_col] is None):
        pre_exact_goals_number_more_7 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number_more_7 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #683
    if(rs1[counter_col] is None):
        end_exact_goals_number_0 = "Null"
    elif(rs1[counter_col] is not None):

        end_exact_goals_number_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #684
    if(rs1[counter_col] is None):
        end_exact_goals_number_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #685
    if(rs1[counter_col] is None):
        end_exact_goals_number_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #686
    if(rs1[counter_col] is None):
        end_exact_goals_number_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #687
    if(rs1[counter_col] is None):
        end_exact_goals_number_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #688
    if(rs1[counter_col] is None):
        end_exact_goals_number_5 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #689
    if(rs1[counter_col] is None):
        end_exact_goals_number_6 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #690
    if(rs1[counter_col] is None):
        end_exact_goals_number_more_7 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number_more_7 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #691
    if(rs1[counter_col] is None):
        pre_exact_goals_number__first_half_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number__first_half_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #692
    if(rs1[counter_col] is None):
        pre_exact_goals_number__first_half_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number__first_half_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #693
    if(rs1[counter_col] is None):
        pre_exact_goals_number__first_half_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number__first_half_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #694
    if(rs1[counter_col] is None):
        pre_exact_goals_number__first_half_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number__first_half_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #695
    if(rs1[counter_col] is None):
        pre_exact_goals_number__first_half_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number__first_half_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #696
    if(rs1[counter_col] is None):
        pre_exact_goals_number__first_half_more_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_goals_number__first_half_more_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #697
    if(rs1[counter_col] is None):
        end_exact_goals_number__first_half_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number__first_half_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #698
    if(rs1[counter_col] is None):
        end_exact_goals_number__first_half_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number__first_half_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #699
    if(rs1[counter_col] is None):
        end_exact_goals_number__first_half_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number__first_half_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #700
    if(rs1[counter_col] is None):
        end_exact_goals_number__first_half_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number__first_half_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #701
    if(rs1[counter_col] is None):
        end_exact_goals_number__first_half_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number__first_half_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #702
    if(rs1[counter_col] is None):
        end_exact_goals_number__first_half_more_5 = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_goals_number__first_half_more_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #703
    if(rs1[counter_col] is None):
        pre_second_half_exact_goals_number_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_second_half_exact_goals_number_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #704
    if(rs1[counter_col] is None):
        pre_second_half_exact_goals_number_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_second_half_exact_goals_number_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #705
    if(rs1[counter_col] is None):
        pre_second_half_exact_goals_number_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_second_half_exact_goals_number_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #706
    if(rs1[counter_col] is None):
        pre_second_half_exact_goals_number_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_second_half_exact_goals_number_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #707
    if(rs1[counter_col] is None):
        pre_second_half_exact_goals_number_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_second_half_exact_goals_number_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #708
    if(rs1[counter_col] is None):
        pre_second_half_exact_goals_number_more_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_second_half_exact_goals_number_more_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #709
    if(rs1[counter_col] is None):
        end_second_half_exact_goals_number_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_second_half_exact_goals_number_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #710
    if(rs1[counter_col] is None):
        end_second_half_exact_goals_number_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_second_half_exact_goals_number_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #711
    if(rs1[counter_col] is None):
        end_second_half_exact_goals_number_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_second_half_exact_goals_number_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #712
    if(rs1[counter_col] is None):
        end_second_half_exact_goals_number_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_second_half_exact_goals_number_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #713
    if(rs1[counter_col] is None):
        end_second_half_exact_goals_number_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_second_half_exact_goals_number_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #714
    if(rs1[counter_col] is None):
        end_second_half_exact_goals_number_more_5 = "Null"
    elif(rs1[counter_col] is not None):
        end_second_half_exact_goals_number_more_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #715
    if(rs1[counter_col] is None):
        pre_home_team_exact_goals_number_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_team_exact_goals_number_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #716
    if(rs1[counter_col] is None):
        pre_home_team_exact_goals_number_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_team_exact_goals_number_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #717
    if(rs1[counter_col] is None):
        pre_home_team_exact_goals_number_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_team_exact_goals_number_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #718
    if(rs1[counter_col] is None):
        pre_home_team_exact_goals_number_more_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_team_exact_goals_number_more_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #719

    if(rs1[counter_col] is None):
        end_home_team_exact_goals_number_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_team_exact_goals_number_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #720
    if(rs1[counter_col] is None):
        end_home_team_exact_goals_number_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_team_exact_goals_number_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #721
    if(rs1[counter_col] is None):
        end_home_team_exact_goals_number_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_team_exact_goals_number_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #722
    if(rs1[counter_col] is None):
        end_home_team_exact_goals_number_more_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_team_exact_goals_number_more_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #723
    if(rs1[counter_col] is None):
        pre_away_team_exact_goals_number_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_team_exact_goals_number_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #724
    if(rs1[counter_col] is None):
        pre_away_team_exact_goals_number_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_team_exact_goals_number_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #725
    if(rs1[counter_col] is None):
        pre_away_team_exact_goals_number_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_team_exact_goals_number_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #726
    if(rs1[counter_col] is None):
        pre_away_team_exact_goals_number_more_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_team_exact_goals_number_more_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #727
    if(rs1[counter_col] is None):
        end_away_team_exact_goals_number_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_team_exact_goals_number_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #728
    if(rs1[counter_col] is None):
        end_away_team_exact_goals_number_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_team_exact_goals_number_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #729
    if(rs1[counter_col] is None):
        end_away_team_exact_goals_number_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_team_exact_goals_number_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #730
    if(rs1[counter_col] is None):
        end_away_team_exact_goals_number_more_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_team_exact_goals_number_more_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #731
    if(rs1[counter_col] is None):
        pre_corners_winner_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_winner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #732
    if(rs1[counter_col] is None):
        pre_corners_winner_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_winner_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #733
    if(rs1[counter_col] is None):
        pre_corners_winner_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_winner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #734
    if(rs1[counter_col] is None):
        end_corners_winner_home = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_winner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #735
    if(rs1[counter_col] is None):
        end_corners_winner_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_winner_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #736
    if(rs1[counter_col] is None):
        end_corners_winner_away = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_winner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #737
    if(rs1[counter_col] is None):
        pre_10_overunder_over_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_10_overunder_over_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #738
    if(rs1[counter_col] is None):
        pre_10_overunder_under_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_10_overunder_under_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #739
    if(rs1[counter_col] is None):
        end_10_overunder_over_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_10_overunder_over_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #740
    if(rs1[counter_col] is None):
        end_10_overunder_under_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_10_overunder_under_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #741
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_home_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_home_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #742
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_draw_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_draw_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #743
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_away_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_away_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #744
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_home_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_home_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #745
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_draw_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_draw_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #746
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_away_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_away_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #747
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_home_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_home_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #748
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_draw_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_draw_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #749
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_away_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_away_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #750
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_home_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_home_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #751
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_draw_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_draw_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #752
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_away_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_away_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #753
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_home_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_home_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #754
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_draw_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_draw_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #755
    if(rs1[counter_col] is None):
        pre_cards_european_handicap_away_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_european_handicap_away_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #756
    if(rs1[counter_col] is None):
        end_cards_european_handicap_home_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_home_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #757
    if(rs1[counter_col] is None):
        end_cards_european_handicap_draw_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_draw_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #758
    if(rs1[counter_col] is None):
        end_cards_european_handicap_away_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_away_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #759
    if(rs1[counter_col] is None):
        end_cards_european_handicap_home_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_home_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #760
    if(rs1[counter_col] is None):
        end_cards_european_handicap_draw_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_draw_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #761
    if(rs1[counter_col] is None):
        end_cards_european_handicap_away_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_away_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #762
    if(rs1[counter_col] is None):
        end_cards_european_handicap_home_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_home_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #763
    if(rs1[counter_col] is None):
        end_cards_european_handicap_draw_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_draw_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #764
    if(rs1[counter_col] is None):
        end_cards_european_handicap_away_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_away_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #765
    if(rs1[counter_col] is None):
        end_cards_european_handicap_home_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_home_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #766
    if(rs1[counter_col] is None):
        end_cards_european_handicap_draw_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_draw_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #767
    if(rs1[counter_col] is None):
        end_cards_european_handicap_away_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_away_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #768
    if(rs1[counter_col] is None):
        end_cards_european_handicap_home_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_home_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #769
    if(rs1[counter_col] is None):
        end_cards_european_handicap_draw_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_draw_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #770
    if(rs1[counter_col] is None):
        end_cards_european_handicap_away_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_european_handicap_away_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #771
    if(rs1[counter_col] is None):
        pre_rcard_yes = "Null"
    elif(rs1[counter_col] is not None):
        pre_rcard_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #772
    if(rs1[counter_col] is None):
        pre_rcard_no = "Null"
    elif(rs1[counter_col] is not None):
        pre_rcard_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #773
    if(rs1[counter_col] is None):
        end_rcard_yes = "Null"
    elif(rs1[counter_col] is not None):
        end_rcard_yes = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #774
    if(rs1[counter_col] is None):
        end_rcard_no = "Null"
    elif(rs1[counter_col] is not None):
        end_rcard_no = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #775
    if(rs1[counter_col] is None):
        pre_team_to_score_first_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_team_to_score_first_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #776
    if(rs1[counter_col] is None):
        pre_team_to_score_first_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_team_to_score_first_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #777
    if(rs1[counter_col] is None):
        pre_team_to_score_first_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_team_to_score_first_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #778
    if(rs1[counter_col] is None):
        end_team_to_score_first_home = "Null"
    elif(rs1[counter_col] is not None):
        end_team_to_score_first_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #779
    if(rs1[counter_col] is None):
        end_team_to_score_first_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_team_to_score_first_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #780
    if(rs1[counter_col] is None):
        end_team_to_score_first_away = "Null"
    elif(rs1[counter_col] is not None):
        end_team_to_score_first_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #781
    if(rs1[counter_col] is None):
        pre_team_to_score_last_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_team_to_score_last_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #782
    if(rs1[counter_col] is None):
        pre_team_to_score_last_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_team_to_score_last_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #783
    if(rs1[counter_col] is None):
        pre_team_to_score_last_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_team_to_score_last_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #784
    if(rs1[counter_col] is None):
        end_team_to_score_last_home = "Null"
    elif(rs1[counter_col] is not None):
        end_team_to_score_last_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #785
    if(rs1[counter_col] is None):
        end_team_to_score_last_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_team_to_score_last_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #786
    if(rs1[counter_col] is None):
        end_team_to_score_last_away = "Null"
    elif(rs1[counter_col] is not None):
        end_team_to_score_last_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #787
    if(rs1[counter_col] is None):
        pre_total_home_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #788
    if(rs1[counter_col] is None):
        pre_total_home_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #789
    if(rs1[counter_col] is None):
        pre_total_home_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #790
    if(rs1[counter_col] is None):
        pre_total_home_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #791
    if(rs1[counter_col] is None):
        pre_total_home_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #792
    if(rs1[counter_col] is None):
        pre_total_home_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #793
    if(rs1[counter_col] is None):
        pre_total_home_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #794
    if(rs1[counter_col] is None):
        pre_total_home_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #795
    if(rs1[counter_col] is None):
        pre_total_home_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #796
    if(rs1[counter_col] is None):
        pre_total_home_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #797
    if(rs1[counter_col] is None):
        pre_total_home_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #798
    if(rs1[counter_col] is None):
        pre_total_home_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_home_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #799
    if(rs1[counter_col] is None):
        end_total_home_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #800
    if(rs1[counter_col] is None):
        end_total_home_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #801
    if(rs1[counter_col] is None):
        end_total_home_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #802
    if(rs1[counter_col] is None):
        end_total_home_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #803
    if(rs1[counter_col] is None):
        end_total_home_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #804
    if(rs1[counter_col] is None):
        end_total_home_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #805
    if(rs1[counter_col] is None):
        end_total_home_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #806
    if(rs1[counter_col] is None):
        end_total_home_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #807
    if(rs1[counter_col] is None):
        end_total_home_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #808
    if(rs1[counter_col] is None):
        end_total_home_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #809
    if(rs1[counter_col] is None):
        end_total_home_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #810
    if(rs1[counter_col] is None):
        end_total_home_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_home_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #811
    if(rs1[counter_col] is None):
        pre_total_away_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #812
    if(rs1[counter_col] is None):
        pre_total_away_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #813
    if(rs1[counter_col] is None):
        pre_total_away_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #814
    if(rs1[counter_col] is None):
        pre_total_away_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #815
    if(rs1[counter_col] is None):
        pre_total_away_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #816
    if(rs1[counter_col] is None):
        pre_total_away_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #817
    if(rs1[counter_col] is None):
        pre_total_away_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #818
    if(rs1[counter_col] is None):
        pre_total_away_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #819
    if(rs1[counter_col] is None):
        pre_total_away_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #820
    if(rs1[counter_col] is None):
        pre_total_away_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #821
    if(rs1[counter_col] is None):
        pre_total_away_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #822
    if(rs1[counter_col] is None):
        pre_total_away_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_away_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #823
    if(rs1[counter_col] is None):
        end_total_away_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #824
    if(rs1[counter_col] is None):
        end_total_away_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #825
    if(rs1[counter_col] is None):
        end_total_away_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #826
    if(rs1[counter_col] is None):
        end_total_away_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #827
    if(rs1[counter_col] is None):
        end_total_away_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #828
    if(rs1[counter_col] is None):
        end_total_away_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #829
    if(rs1[counter_col] is None):
        end_total_away_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #830
    if(rs1[counter_col] is None):
        end_total_away_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #831
    if(rs1[counter_col] is None):
        end_total_away_over_55 = "Null"

    elif(rs1[counter_col] is not None):
        end_total_away_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #832
    if(rs1[counter_col] is None):
        end_total_away_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #833
    if(rs1[counter_col] is None):
        end_total_away_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #834
    if(rs1[counter_col] is None):
        end_total_away_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_away_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #835
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #836
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #837
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_6 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #838
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_6 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #839
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #840
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #841
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #842
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #843
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #844
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #845
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #846
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #847
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #848
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #849
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #850
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #851
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #852
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #853
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #854
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #855
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #856
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #857
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #858
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #859
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #860
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #861
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #862
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #863
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #864
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #865
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #866
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_1 = "Null"

    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #867
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #868
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #869
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #870
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #871
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #872
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #873
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #874
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #875
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #876
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #877
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #878
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #879
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #880
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #881
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #882
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_5 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #883
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #884
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #885
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_6 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #886
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_6 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #887
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_home_plus_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_home_plus_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #888
    if(rs1[counter_col] is None):
        pre_corners_asian_handicap_away_plus_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_asian_handicap_away_plus_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #889
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #890
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #891
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_6 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #892
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_6 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #893
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #894
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #895
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_5 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #896
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_5 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #897
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #898
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #899
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #900
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'


    counter_col += 1 #901
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #902
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #903
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #904
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #905
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #906
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #907
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #908
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #909
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #910
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #911
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #912
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #913
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #914
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #915
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #916
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #917
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #918
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #919
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #920
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_1 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_1 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #921
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #922
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #923
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #924
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #925
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #926
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #927
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #928
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #929
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #930
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #931
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #932
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #933
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #934
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #935
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_5 = "Null"

    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #936
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_5 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_5 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #937
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #938
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #939
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_6 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #940
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_6 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_6 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #941
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_home_plus_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_home_plus_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #942
    if(rs1[counter_col] is None):
        end_corners_asian_handicap_away_plus_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_asian_handicap_away_plus_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #943
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_700 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_700 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #944
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_700 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_700 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #945
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_725 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_725 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #946
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_725 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_725 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #947
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_750 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_750 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #948
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_750 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_750 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #949
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_775 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_775 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #950
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_775 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_775 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #951
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_800 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_800 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #952
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_800 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_800 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #953
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_825 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_825 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #954
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_825 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_825 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #955
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_850 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_850 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #956
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_850 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_850 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #957
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_875 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_875 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #958
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_875 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_875 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #959
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_900 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_900 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #960
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_900 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_900 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #961
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_925 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_925 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #962
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_925 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_925 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #963
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_950 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_950 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #964
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_950 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_950 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #965
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_975 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_975 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #966
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_975 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_975 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #967
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1000 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1000 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #968
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1000 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1000 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #969
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1025 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #970
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1025 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #971
    if(rs1[counter_col] is None):

        pre_corners_over_under_over_1050 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1050 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #972
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1050 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1050 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #973
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #974
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1075 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #975
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1100 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1100 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #976
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1100 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1100 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #977
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #978
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1125 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #979
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1150 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1150 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #980
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1150 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1150 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #981
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #982
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1175 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #983
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1200 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1200 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #984
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1200 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1200 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #985
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #986
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1225 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #987
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1250 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1250 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #988
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1250 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1250 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #989
    if(rs1[counter_col] is None):
        pre_corners_over_under_over_1275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_over_1275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #990
    if(rs1[counter_col] is None):
        pre_corners_over_under_under_1275 = "Null"
    elif(rs1[counter_col] is not None):
        pre_corners_over_under_under_1275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #991
    if(rs1[counter_col] is None):
        end_corners_over_under_over_700 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_700 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #992
    if(rs1[counter_col] is None):
        end_corners_over_under_under_700 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_700 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #993
    if(rs1[counter_col] is None):
        end_corners_over_under_over_725 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_725 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #994
    if(rs1[counter_col] is None):
        end_corners_over_under_under_725 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_725 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #995
    if(rs1[counter_col] is None):
        end_corners_over_under_over_750 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_750 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #996
    if(rs1[counter_col] is None):
        end_corners_over_under_under_750 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_750 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #997
    if(rs1[counter_col] is None):
        end_corners_over_under_over_775 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_775 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #998
    if(rs1[counter_col] is None):
        end_corners_over_under_under_775 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_775 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #999
    if(rs1[counter_col] is None):
        end_corners_over_under_over_800 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_800 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1000
    if(rs1[counter_col] is None):
        end_corners_over_under_under_800 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_800 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1001
    if(rs1[counter_col] is None):
        end_corners_over_under_over_825 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_825 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1002
    if(rs1[counter_col] is None):
        end_corners_over_under_under_825 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_825 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1003
    if(rs1[counter_col] is None):
        end_corners_over_under_over_850 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_850 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1004
    if(rs1[counter_col] is None):
        end_corners_over_under_under_850 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_850 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1005
    if(rs1[counter_col] is None):
        end_corners_over_under_over_875 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_875 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1006
    if(rs1[counter_col] is None):
        end_corners_over_under_under_875 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_875 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1007
    if(rs1[counter_col] is None):
        end_corners_over_under_over_900 = "Null"

    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_900 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1008
    if(rs1[counter_col] is None):
        end_corners_over_under_under_900 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_900 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1009
    if(rs1[counter_col] is None):
        end_corners_over_under_over_925 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_925 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1010
    if(rs1[counter_col] is None):
        end_corners_over_under_under_925 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_925 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1011
    if(rs1[counter_col] is None):
        end_corners_over_under_over_950 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_950 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1012
    if(rs1[counter_col] is None):
        end_corners_over_under_under_950 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_950 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1013
    if(rs1[counter_col] is None):
        end_corners_over_under_over_975 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_975 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1014
    if(rs1[counter_col] is None):
        end_corners_over_under_under_975 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_975 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1015
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1000 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1000 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1016
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1000 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1000 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1017
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1025 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1018
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1025 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1025 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1019
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1050 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1050 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1020
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1050 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1050 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1021
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1075 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1022
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1075 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1075 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1023
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1100 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1100 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1024
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1100 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1100 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1025
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1125 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1026
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1125 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1125 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1027
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1150 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1150 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1028
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1150 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1150 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1029
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1175 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1030
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1175 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1175 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1031
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1200 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1200 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1032
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1200 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1200 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1033
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1225 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1034
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1225 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1225 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1035
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1250 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1250 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1036
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1250 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1250 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1037
    if(rs1[counter_col] is None):
        end_corners_over_under_over_1275 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_over_1275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1038
    if(rs1[counter_col] is None):
        end_corners_over_under_under_1275 = "Null"
    elif(rs1[counter_col] is not None):
        end_corners_over_under_under_1275 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1039
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1040
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1041
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1042
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1043
    if(rs1[counter_col] is None):

        pre_home_corners_overunder_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1044
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1045
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1046
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1047
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1048
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1049
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_over_75 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_over_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1050
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_under_75 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_under_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1051
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_over_85 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_over_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1052
    if(rs1[counter_col] is None):
        pre_home_corners_overunder_under_85 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_corners_overunder_under_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1053
    if(rs1[counter_col] is None):
        end_home_corners_overunder_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1054
    if(rs1[counter_col] is None):
        end_home_corners_overunder_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1055
    if(rs1[counter_col] is None):
        end_home_corners_overunder_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1056
    if(rs1[counter_col] is None):
        end_home_corners_overunder_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1057
    if(rs1[counter_col] is None):
        end_home_corners_overunder_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1058
    if(rs1[counter_col] is None):
        end_home_corners_overunder_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1059
    if(rs1[counter_col] is None):
        end_home_corners_overunder_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1060
    if(rs1[counter_col] is None):
        end_home_corners_overunder_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1061
    if(rs1[counter_col] is None):
        end_home_corners_overunder_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1062
    if(rs1[counter_col] is None):
        end_home_corners_overunder_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1063
    if(rs1[counter_col] is None):
        end_home_corners_overunder_over_75 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_over_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1064
    if(rs1[counter_col] is None):
        end_home_corners_overunder_under_75 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_under_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1065
    if(rs1[counter_col] is None):
        end_home_corners_overunder_over_85 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_over_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1066
    if(rs1[counter_col] is None):
        end_home_corners_overunder_under_85 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_corners_overunder_under_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1067
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1068
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1069
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1070
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1071
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1072
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1073
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1074
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1075
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1076
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1077
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_over_75 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_over_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1078
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_under_75 = "Null"

    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_under_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1079
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_over_85 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_over_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1080
    if(rs1[counter_col] is None):
        pre_away_corners_overunder_under_85 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_corners_overunder_under_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1081
    if(rs1[counter_col] is None):
        end_away_corners_overunder_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1082
    if(rs1[counter_col] is None):
        end_away_corners_overunder_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1083
    if(rs1[counter_col] is None):
        end_away_corners_overunder_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1084
    if(rs1[counter_col] is None):
        end_away_corners_overunder_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1085
    if(rs1[counter_col] is None):
        end_away_corners_overunder_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1086
    if(rs1[counter_col] is None):
        end_away_corners_overunder_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1087
    if(rs1[counter_col] is None):
        end_away_corners_overunder_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1088
    if(rs1[counter_col] is None):
        end_away_corners_overunder_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1089
    if(rs1[counter_col] is None):
        end_away_corners_overunder_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1090
    if(rs1[counter_col] is None):
        end_away_corners_overunder_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1091
    if(rs1[counter_col] is None):
        end_away_corners_overunder_over_75 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_over_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1092
    if(rs1[counter_col] is None):
        end_away_corners_overunder_under_75 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_under_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1093
    if(rs1[counter_col] is None):
        end_away_corners_overunder_over_85 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_over_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1094
    if(rs1[counter_col] is None):
        end_away_corners_overunder_under_85 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_corners_overunder_under_85 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1095
    if(rs1[counter_col] is None):
        pre_first_corner_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_corner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1096
    if(rs1[counter_col] is None):
        pre_first_corner_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_corner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1097
    if(rs1[counter_col] is None):
        end_first_corner_home = "Null"
    elif(rs1[counter_col] is not None):
        end_first_corner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1098
    if(rs1[counter_col] is None):
        end_first_corner_away = "Null"
    elif(rs1[counter_col] is not None):
        end_first_corner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1099
    if(rs1[counter_col] is None):
        pre_last_corner_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_last_corner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1100
    if(rs1[counter_col] is None):
        pre_last_corner_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_last_corner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1101
    if(rs1[counter_col] is None):
        end_last_corner_home = "Null"
    elif(rs1[counter_col] is not None):
        end_last_corner_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1102
    if(rs1[counter_col] is None):
        end_last_corner_away = "Null"
    elif(rs1[counter_col] is not None):
        end_last_corner_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1103
    if(rs1[counter_col] is None):
        pre_cards_asian_handicap_home_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_asian_handicap_home_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1104
    if(rs1[counter_col] is None):
        pre_cards_asian_handicap_away_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_asian_handicap_away_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1105
    if(rs1[counter_col] is None):
        pre_cards_asian_handicap_home_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_asian_handicap_home_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1106
    if(rs1[counter_col] is None):
        pre_cards_asian_handicap_away_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_asian_handicap_away_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1107
    if(rs1[counter_col] is None):
        pre_cards_asian_handicap_home_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_asian_handicap_home_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1108
    if(rs1[counter_col] is None):
        pre_cards_asian_handicap_away_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_asian_handicap_away_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1109
    if(rs1[counter_col] is None):
        end_cards_asian_handicap_home_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_asian_handicap_home_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1110
    if(rs1[counter_col] is None):
        end_cards_asian_handicap_away_min_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_asian_handicap_away_min_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1111
    if(rs1[counter_col] is None):
        end_cards_asian_handicap_home_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_asian_handicap_home_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1112
    if(rs1[counter_col] is None):
        end_cards_asian_handicap_away_plus_0 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_asian_handicap_away_plus_0 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1113
    if(rs1[counter_col] is None):
        end_cards_asian_handicap_home_plus_05 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_asian_handicap_home_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1114
    if(rs1[counter_col] is None):
        end_cards_asian_handicap_away_plus_05 = "Null"

    elif(rs1[counter_col] is not None):
        end_cards_asian_handicap_away_plus_05 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1115
    if(rs1[counter_col] is None):
        pre_cards_overunder_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1116
    if(rs1[counter_col] is None):
        pre_cards_overunder_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1117
    if(rs1[counter_col] is None):
        pre_cards_overunder_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1118
    if(rs1[counter_col] is None):
        pre_cards_overunder_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1119
    if(rs1[counter_col] is None):
        pre_cards_overunder_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1120
    if(rs1[counter_col] is None):
        pre_cards_overunder_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1121
    if(rs1[counter_col] is None):
        pre_cards_overunder_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1122
    if(rs1[counter_col] is None):
        pre_cards_overunder_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1123
    if(rs1[counter_col] is None):
        pre_cards_overunder_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1124
    if(rs1[counter_col] is None):
        pre_cards_overunder_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1125
    if(rs1[counter_col] is None):
        pre_cards_overunder_over_75 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_over_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1126
    if(rs1[counter_col] is None):
        pre_cards_overunder_under_75 = "Null"
    elif(rs1[counter_col] is not None):
        pre_cards_overunder_under_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1127
    if(rs1[counter_col] is None):
        end_cards_overunder_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1128
    if(rs1[counter_col] is None):
        end_cards_overunder_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1129
    if(rs1[counter_col] is None):
        end_cards_overunder_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1130
    if(rs1[counter_col] is None):
        end_cards_overunder_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1131
    if(rs1[counter_col] is None):
        end_cards_overunder_over_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_over_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1132
    if(rs1[counter_col] is None):
        end_cards_overunder_under_45 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_under_45 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1133
    if(rs1[counter_col] is None):
        end_cards_overunder_over_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_over_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1134
    if(rs1[counter_col] is None):
        end_cards_overunder_under_55 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_under_55 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1135
    if(rs1[counter_col] is None):
        end_cards_overunder_over_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_over_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1136
    if(rs1[counter_col] is None):
        end_cards_overunder_under_65 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_under_65 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1137
    if(rs1[counter_col] is None):
        end_cards_overunder_over_75 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_over_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1138
    if(rs1[counter_col] is None):
        end_cards_overunder_under_75 = "Null"
    elif(rs1[counter_col] is not None):
        end_cards_overunder_under_75 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1139
    if(rs1[counter_col] is None):
        pre_home_team_total_cards_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_team_total_cards_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1140
    if(rs1[counter_col] is None):
        pre_home_team_total_cards_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_team_total_cards_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1141
    if(rs1[counter_col] is None):
        pre_home_team_total_cards_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_team_total_cards_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1142
    if(rs1[counter_col] is None):
        pre_home_team_total_cards_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_team_total_cards_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1143
    if(rs1[counter_col] is None):
        pre_home_team_total_cards_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_team_total_cards_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1144
    if(rs1[counter_col] is None):
        pre_home_team_total_cards_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_home_team_total_cards_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1145
    if(rs1[counter_col] is None):
        end_home_team_total_cards_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_team_total_cards_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1146
    if(rs1[counter_col] is None):
        end_home_team_total_cards_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_team_total_cards_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1147
    if(rs1[counter_col] is None):
        end_home_team_total_cards_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_team_total_cards_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1148
    if(rs1[counter_col] is None):
        end_home_team_total_cards_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_team_total_cards_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1149
    if(rs1[counter_col] is None):
        end_home_team_total_cards_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_team_total_cards_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1150
    if(rs1[counter_col] is None):
        end_home_team_total_cards_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_home_team_total_cards_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1151
    if(rs1[counter_col] is None):

        pre_away_team_total_cards_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_team_total_cards_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1152
    if(rs1[counter_col] is None):
        pre_away_team_total_cards_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_team_total_cards_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1153
    if(rs1[counter_col] is None):
        pre_away_team_total_cards_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_team_total_cards_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1154
    if(rs1[counter_col] is None):
        pre_away_team_total_cards_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_team_total_cards_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1155
    if(rs1[counter_col] is None):
        pre_away_team_total_cards_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_team_total_cards_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1156
    if(rs1[counter_col] is None):
        pre_away_team_total_cards_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        pre_away_team_total_cards_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1157
    if(rs1[counter_col] is None):
        end_away_team_total_cards_over_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_team_total_cards_over_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1158
    if(rs1[counter_col] is None):
        end_away_team_total_cards_under_15 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_team_total_cards_under_15 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1159
    if(rs1[counter_col] is None):
        end_away_team_total_cards_over_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_team_total_cards_over_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1160
    if(rs1[counter_col] is None):
        end_away_team_total_cards_under_25 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_team_total_cards_under_25 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1161
    if(rs1[counter_col] is None):
        end_away_team_total_cards_over_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_team_total_cards_over_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1162
    if(rs1[counter_col] is None):
        end_away_team_total_cards_under_35 = "Null"
    elif(rs1[counter_col] is not None):
        end_away_team_total_cards_under_35 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1163
    if(rs1[counter_col] is None):
        pre_total_goals_under_2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_goals_under_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1164
    if(rs1[counter_col] is None):
        pre_total_goals_2_or_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_goals_2_or_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1165
    if(rs1[counter_col] is None):
        pre_total_goals_over_3 = "Null"
    elif(rs1[counter_col] is not None):
        pre_total_goals_over_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1166
    if(rs1[counter_col] is None):
        end_total_goals_under_2 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_goals_under_2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1167
    if(rs1[counter_col] is None):
        end_total_goals_2_or_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_goals_2_or_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1168
    if(rs1[counter_col] is None):
        end_total_goals_over_3 = "Null"
    elif(rs1[counter_col] is not None):
        end_total_goals_over_3 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1169
    if(rs1[counter_col] is None):
        pre_first_goal_method_shot = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_goal_method_shot = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1170
    if(rs1[counter_col] is None):
        pre_first_goal_method_header = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_goal_method_header = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1171
    if(rs1[counter_col] is None):
        pre_first_goal_method_penalty = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_goal_method_penalty = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1172
    if(rs1[counter_col] is None):
        pre_first_goal_method_freekick = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_goal_method_freekick = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1173
    if(rs1[counter_col] is None):
        pre_first_goal_method_owngoal = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_goal_method_owngoal = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1174
    if(rs1[counter_col] is None):
        pre_first_goal_method_draw = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_goal_method_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1175
    if(rs1[counter_col] is None):
        end_first_goal_method_shot = "Null"
    elif(rs1[counter_col] is not None):
        end_first_goal_method_shot = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1176
    if(rs1[counter_col] is None):
        end_first_goal_method_header = "Null"
    elif(rs1[counter_col] is not None):
        end_first_goal_method_header = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1177
    if(rs1[counter_col] is None):
        end_first_goal_method_penalty = "Null"
    elif(rs1[counter_col] is not None):
        end_first_goal_method_penalty = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1178
    if(rs1[counter_col] is None):
        end_first_goal_method_freekick = "Null"
    elif(rs1[counter_col] is not None):
        end_first_goal_method_freekick = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1179
    if(rs1[counter_col] is None):
        end_first_goal_method_owngoal = "Null"
    elif(rs1[counter_col] is not None):
        end_first_goal_method_owngoal = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1180
    if(rs1[counter_col] is None):
        end_first_goal_method_draw = "Null"
    elif(rs1[counter_col] is not None):
        end_first_goal_method_draw = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1181
    if(rs1[counter_col] is None):
        pre_to_score_a_penalty_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_to_score_a_penalty_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1182
    if(rs1[counter_col] is None):
        pre_to_score_a_penalty_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_to_score_a_penalty_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1183
    if(rs1[counter_col] is None):
        end_to_score_a_penalty_home = "Null"
    elif(rs1[counter_col] is not None):
        end_to_score_a_penalty_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1184
    if(rs1[counter_col] is None):
        end_to_score_a_penalty_away = "Null"
    elif(rs1[counter_col] is not None):
        end_to_score_a_penalty_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1185
    if(rs1[counter_col] is None):
        pre_to_miss_a_penalty_home = "Null"
    elif(rs1[counter_col] is not None):
        pre_to_miss_a_penalty_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1186
    if(rs1[counter_col] is None):
        pre_to_miss_a_penalty_away = "Null"
    elif(rs1[counter_col] is not None):
        pre_to_miss_a_penalty_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1187
    if(rs1[counter_col] is None):
        end_to_miss_a_penalty_home = "Null"
    elif(rs1[counter_col] is not None):
        end_to_miss_a_penalty_home = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1188
    if(rs1[counter_col] is None):
        end_to_miss_a_penalty_away = "Null"

    elif(rs1[counter_col] is not None):
        end_to_miss_a_penalty_away = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1189
    if(rs1[counter_col] is None):
        pre_anytime_goal_scorer = "Null"
    elif(rs1[counter_col] is not None):
        pre_anytime_goal_scorer = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1190
    if(rs1[counter_col] is None):
        end_anytime_goal_scorer = "Null"
    elif(rs1[counter_col] is not None):
        end_anytime_goal_scorer = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1191
    if(rs1[counter_col] is None):
        pre_first_goal_scorer = "Null"
    elif(rs1[counter_col] is not None):
        pre_first_goal_scorer = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1192
    if(rs1[counter_col] is None):
        end_first_goal_scorer = "Null"
    elif(rs1[counter_col] is not None):
        end_first_goal_scorer = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1193
    if(rs1[counter_col] is None):
        pre_last_goal_scorer = "Null"
    elif(rs1[counter_col] is not None):
        pre_last_goal_scorer = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1194
    if(rs1[counter_col] is None):
        end_last_goal_scorer = "Null"
    elif(rs1[counter_col] is not None):
        end_last_goal_scorer = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1195
    if(rs1[counter_col] is None):
        pre_to_score_two_or_more_goals = "Null"
    elif(rs1[counter_col] is not None):
        pre_to_score_two_or_more_goals = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1196
    if(rs1[counter_col] is None):
        end_to_score_two_or_more_goals = "Null"
    elif(rs1[counter_col] is not None):
        end_to_score_two_or_more_goals = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1197
    if(rs1[counter_col] is None):
        pre_last_goal_scorer2 = "Null"
    elif(rs1[counter_col] is not None):
        pre_last_goal_scorer2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1198
    if(rs1[counter_col] is None):
        end_last_goal_scorer2 = "Null"
    elif(rs1[counter_col] is not None):
        end_last_goal_scorer2 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1199
    if(rs1[counter_col] is None):
        pre_exact_score = "Null"
    elif(rs1[counter_col] is not None):
        pre_exact_score = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1200
    if(rs1[counter_col] is None):
        end_exact_score = "Null"
    elif(rs1[counter_col] is not None):
        end_exact_score = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1201
    if(rs1[counter_col] is None):
        pre_player_to_be_booked = "Null"
    elif(rs1[counter_col] is not None):
        pre_player_to_be_booked = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1202
    if(rs1[counter_col] is None):
        end_player_to_be_booked = "Null"
    elif(rs1[counter_col] is not None):
        end_player_to_be_booked = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1203
    if(rs1[counter_col] is None):
        pre_ah_pattern = "Null"
    elif(rs1[counter_col] is not None):
        pre_ah_pattern = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1204
    if(rs1[counter_col] is None):
        pre_ah_pattern_mirror = "Null"
    elif(rs1[counter_col] is not None):
        pre_ah_pattern_mirror = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1205
    if(rs1[counter_col] is None):
        pre_gou_pattern = "Null"
    elif(rs1[counter_col] is not None):
        pre_gou_pattern = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1206
    if(rs1[counter_col] is None):
        end_ah_pattern = "Null"
    elif(rs1[counter_col] is not None):
        end_ah_pattern = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1207
    if(rs1[counter_col] is None):
        end_ah_pattern_mirror = "Null"
    elif(rs1[counter_col] is not None):
        end_ah_pattern_mirror = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1208
    if(rs1[counter_col] is None):
        end_gou_pattern = "Null"
    elif(rs1[counter_col] is not None):
        end_gou_pattern = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1209
    if(rs1[counter_col] is None):
        pre_response = "Null"
    elif(rs1[counter_col] is not None):
        pre_response = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1210
    if(rs1[counter_col] is None):
        end_response = "Null"
    elif(rs1[counter_col] is not None):
        end_response = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1211
    if(rs1[counter_col] is None):
        pre_odd_updated_at = "Null"
    elif(rs1[counter_col] is not None):
        pre_odd_updated_at = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1212
    if(rs1[counter_col] is None):
        end_odd_updated_at = "Null"
    elif(rs1[counter_col] is not None):
        end_odd_updated_at = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1213
    if(rs1[counter_col] is None):
        pre_ah_pattern_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_ah_pattern_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1214
    if(rs1[counter_col] is None):
        pre_ah_pattern_mirror_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_ah_pattern_mirror_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1215
    if(rs1[counter_col] is None):
        pre_gou_pattern_4 = "Null"
    elif(rs1[counter_col] is not None):
        pre_gou_pattern_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1216
    if(rs1[counter_col] is None):
        end_ah_pattern_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_ah_pattern_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1217
    if(rs1[counter_col] is None):
        end_ah_pattern_mirror_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_ah_pattern_mirror_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1218
    if(rs1[counter_col] is None):
        end_gou_pattern_4 = "Null"
    elif(rs1[counter_col] is not None):
        end_gou_pattern_4 = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'

    counter_col += 1 #1219
    if(rs1[counter_col] is None):
        special_odds = "Null"
    elif(rs1[counter_col] is not None):
        special_odds = '"' + str(rs1[counter_col]).replace("'", "\'") + '"'




    counter_col += 1
    leagueapi_id = rs1[counter_col] #
    
    counter_col += 1
    season = rs1[counter_col] #
    
    counter_col += 1
    fixtureapi_id = rs1[counter_col] #
    # --------------------------------------------------    
    word = space + '__#' 
    word += ' - ' + str(leagueapi_id)
    word += ' - ' + str(season)
    word += ' => ' + str(fixtureapi_id)
    # --------------------------------------------------    
    print(word, flush=True)  
    # --------------------------------------------------   
    host="localhost"
    user="root" 
    database="pr_mmbuzz_2022_06"
    mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
    mycursor = mydb.cursor()
    # --------------------------------------------------  
    query = "select count(*) "
    query += "from football_odds "
    query += "where leagueapi_id = '"+str(leagueapi_id)+"' "
    query += "and season = '"+str(season)+"' "
    query += "and fixtureapi_id = '"+str(fixtureapi_id)+"' "
    # --------------------------------------------------  
    print(query, flush=True)
    # --------------------------------------------------  
    mycursor = mydb.cursor()
    mycursor.execute(query) 
    result = mycursor.fetchone()
    # --------------------------------------------------  
    total_rows = result[0]
    # --------------------------------------------------  
    print(space + "total_rows: " + str(total_rows), flush=True)    
    # --------------------------------------------------  
    mycursor.close()
    mydb.close() 
    # -------------------------------------------------- 
    if(total_rows == 0):
        # --------------------------------------------------   
        host="localhost"
        user="root" 
        database="pr_mmbuzz_2022_06"
        mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
        mycursor = mydb.cursor()
        # --------------------------------------------------  
        query_commit = "INSERT INTO `football_odds`(  "  
        query_commit += " `pre_match_winner_home`, " #1
        query_commit += " `pre_match_winner_draw`, " #2
        query_commit += " `pre_match_winner_away`, " #3
        query_commit += " `end_match_winner_home`, " #4
        query_commit += " `end_match_winner_draw`, " #5
        query_commit += " `end_match_winner_away`, " #6
        query_commit += " `pre_homeaway_home`, " #7
        query_commit += " `pre_homeaway_away`, " #8
        query_commit += " `end_homeaway_home`, " #9
        query_commit += " `end_homeaway_away`, " #10
        query_commit += " `pre_first_half_winner_home`, " #11
        query_commit += " `pre_first_half_winner_draw`, " #12
        query_commit += " `pre_first_half_winner_away`, " #13
        query_commit += " `end_first_half_winner_home`, " #14
        query_commit += " `end_first_half_winner_draw`, " #15
        query_commit += " `end_first_half_winner_away`, " #16
        query_commit += " `pre_second_half_winner_home`, " #17
        query_commit += " `pre_second_half_winner_draw`, " #18
        query_commit += " `pre_second_half_winner_away`, " #19
        query_commit += " `end_second_half_winner_home`, " #20
        query_commit += " `end_second_half_winner_draw`, " #21
        query_commit += " `end_second_half_winner_away`, " #22
        query_commit += " `pre_asian_handicap_home_min_675`, " #23
        query_commit += " `pre_asian_handicap_away_min_675`, " #24
        query_commit += " `pre_asian_handicap_home_min_65`, " #25
        query_commit += " `pre_asian_handicap_away_min_65`, " #26
        query_commit += " `pre_asian_handicap_home_min_625`, " #27
        query_commit += " `pre_asian_handicap_away_min_625`, " #28
        query_commit += " `pre_asian_handicap_home_min_6`, " #29
        query_commit += " `pre_asian_handicap_away_min_6`, " #30
        query_commit += " `pre_asian_handicap_home_min_575`, " #31
        query_commit += " `pre_asian_handicap_away_min_575`, " #32
        query_commit += " `pre_asian_handicap_home_min_55`, " #33
        query_commit += " `pre_asian_handicap_away_min_55`, " #34
        query_commit += " `pre_asian_handicap_home_min_525`, " #35
        query_commit += " `pre_asian_handicap_away_min_525`, " #36
        query_commit += " `pre_asian_handicap_home_min_5`, " #37
        query_commit += " `pre_asian_handicap_away_min_5`, " #38
        query_commit += " `pre_asian_handicap_home_min_475`, " #39
        query_commit += " `pre_asian_handicap_away_min_475`, " #40
        query_commit += " `pre_asian_handicap_home_min_45`, " #41
        query_commit += " `pre_asian_handicap_away_min_45`, " #42
        query_commit += " `pre_asian_handicap_home_min_425`, " #43
        query_commit += " `pre_asian_handicap_away_min_425`, " #44
        query_commit += " `pre_asian_handicap_home_min_4`, " #45
        query_commit += " `pre_asian_handicap_away_min_4`, " #46
        query_commit += " `pre_asian_handicap_home_min_375`, " #47
        query_commit += " `pre_asian_handicap_away_min_375`, " #48
        query_commit += " `pre_asian_handicap_home_min_35`, " #49
        query_commit += " `pre_asian_handicap_away_min_35`, " #50
        query_commit += " `pre_asian_handicap_home_min_325`, " #51
        query_commit += " `pre_asian_handicap_away_min_325`, " #52
        query_commit += " `pre_asian_handicap_home_min_3`, " #53
        query_commit += " `pre_asian_handicap_away_min_3`, " #54
        query_commit += " `pre_asian_handicap_home_min_275`, " #55
        query_commit += " `pre_asian_handicap_away_min_275`, " #56
        query_commit += " `pre_asian_handicap_home_min_25`, " #57
        query_commit += " `pre_asian_handicap_away_min_25`, " #58
        query_commit += " `pre_asian_handicap_home_min_225`, " #59
        query_commit += " `pre_asian_handicap_away_min_225`, " #60
        query_commit += " `pre_asian_handicap_home_min_2`, " #61
        query_commit += " `pre_asian_handicap_away_min_2`, " #62
        query_commit += " `pre_asian_handicap_home_min_175`, " #63
        query_commit += " `pre_asian_handicap_away_min_175`, " #64
        query_commit += " `pre_asian_handicap_home_min_15`, " #65
        query_commit += " `pre_asian_handicap_away_min_15`, " #66
        query_commit += " `pre_asian_handicap_home_min_125`, " #67
        query_commit += " `pre_asian_handicap_away_min_125`, " #68
        query_commit += " `pre_asian_handicap_home_min_1`, " #69
        query_commit += " `pre_asian_handicap_away_min_1`, " #70
        query_commit += " `pre_asian_handicap_home_min_075`, " #71
        query_commit += " `pre_asian_handicap_away_min_075`, " #72
        query_commit += " `pre_asian_handicap_home_min_05`, " #73
        query_commit += " `pre_asian_handicap_away_min_05`, " #74
        query_commit += " `pre_asian_handicap_home_min_025`, " #75
        query_commit += " `pre_asian_handicap_away_min_025`, " #76
        query_commit += " `pre_asian_handicap_home_plus_0`, " #77
        query_commit += " `pre_asian_handicap_away_plus_0`, " #78
        query_commit += " `pre_asian_handicap_home_plus_025`, " #79
        query_commit += " `pre_asian_handicap_away_plus_025`, " #80
        query_commit += " `pre_asian_handicap_home_plus_05`, " #81
        query_commit += " `pre_asian_handicap_away_plus_05`, " #82
        query_commit += " `pre_asian_handicap_home_plus_075`, " #83
        query_commit += " `pre_asian_handicap_away_plus_075`, " #84
        query_commit += " `pre_asian_handicap_home_plus_1`, " #85
        query_commit += " `pre_asian_handicap_away_plus_1`, " #86
        query_commit += " `pre_asian_handicap_home_plus_125`, " #87
        query_commit += " `pre_asian_handicap_away_plus_125`, " #88
        query_commit += " `pre_asian_handicap_home_plus_15`, " #89
        query_commit += " `pre_asian_handicap_away_plus_15`, " #90
        query_commit += " `pre_asian_handicap_home_plus_175`, " #91
        query_commit += " `pre_asian_handicap_away_plus_175`, " #92
        query_commit += " `pre_asian_handicap_home_plus_2`, " #93
        query_commit += " `pre_asian_handicap_away_plus_2`, " #94
        query_commit += " `pre_asian_handicap_home_plus_225`, " #95
        query_commit += " `pre_asian_handicap_away_plus_225`, " #96
        query_commit += " `pre_asian_handicap_home_plus_25`, " #97
        query_commit += " `pre_asian_handicap_away_plus_25`, " #98
        query_commit += " `pre_asian_handicap_home_plus_275`, " #99
        query_commit += " `pre_asian_handicap_away_plus_275`, " #100
        query_commit += " `pre_asian_handicap_home_plus_3`, " #101
        query_commit += " `pre_asian_handicap_away_plus_3`, " #102
        query_commit += " `pre_asian_handicap_home_plus_325`, " #103
        query_commit += " `pre_asian_handicap_away_plus_325`, " #104
        query_commit += " `pre_asian_handicap_home_plus_35`, " #105
        query_commit += " `pre_asian_handicap_away_plus_35`, " #106
        query_commit += " `pre_asian_handicap_home_plus_375`, " #107
        query_commit += " `pre_asian_handicap_away_plus_375`, " #108
        query_commit += " `pre_asian_handicap_home_plus_4`, " #109
        query_commit += " `pre_asian_handicap_away_plus_4`, " #110
        query_commit += " `pre_asian_handicap_home_plus_425`, " #111
        query_commit += " `pre_asian_handicap_away_plus_425`, " #112
        query_commit += " `pre_asian_handicap_home_plus_45`, " #113
        query_commit += " `pre_asian_handicap_away_plus_45`, " #114
        query_commit += " `pre_asian_handicap_home_plus_475`, " #115
        query_commit += " `pre_asian_handicap_away_plus_475`, " #116
        query_commit += " `pre_asian_handicap_home_plus_5`, " #117
        query_commit += " `pre_asian_handicap_away_plus_5`, " #118
        query_commit += " `pre_asian_handicap_home_plus_525`, " #119
        query_commit += " `pre_asian_handicap_away_plus_525`, " #120
        query_commit += " `pre_asian_handicap_home_plus_55`, " #121
        query_commit += " `pre_asian_handicap_away_plus_55`, " #122
        query_commit += " `pre_asian_handicap_home_plus_575`, " #123
        query_commit += " `pre_asian_handicap_away_plus_575`, " #124
        query_commit += " `pre_asian_handicap_home_plus_6`, " #125
        query_commit += " `pre_asian_handicap_away_plus_6`, " #126
        query_commit += " `pre_asian_handicap_home_plus_625`, " #127
        query_commit += " `pre_asian_handicap_away_plus_625`, " #128
        query_commit += " `pre_asian_handicap_home_plus_65`, " #129
        query_commit += " `pre_asian_handicap_away_plus_65`, " #130
        query_commit += " `pre_asian_handicap_home_plus_675`, " #131
        query_commit += " `pre_asian_handicap_away_plus_675`, " #132
        query_commit += " `end_asian_handicap_home_min_675`, " #133
        query_commit += " `end_asian_handicap_away_min_675`, " #134
        query_commit += " `end_asian_handicap_home_min_65`, " #135
        query_commit += " `end_asian_handicap_away_min_65`, " #136
        query_commit += " `end_asian_handicap_home_min_625`, " #137
        query_commit += " `end_asian_handicap_away_min_625`, " #138
        query_commit += " `end_asian_handicap_home_min_6`, " #139
        query_commit += " `end_asian_handicap_away_min_6`, " #140
        query_commit += " `end_asian_handicap_home_min_575`, " #141
        query_commit += " `end_asian_handicap_away_min_575`, " #142

        query_commit += " `end_asian_handicap_home_min_55`, " #143
        query_commit += " `end_asian_handicap_away_min_55`, " #144
        query_commit += " `end_asian_handicap_home_min_525`, " #145
        query_commit += " `end_asian_handicap_away_min_525`, " #146
        query_commit += " `end_asian_handicap_home_min_5`, " #147
        query_commit += " `end_asian_handicap_away_min_5`, " #148
        query_commit += " `end_asian_handicap_home_min_475`, " #149
        query_commit += " `end_asian_handicap_away_min_475`, " #150
        query_commit += " `end_asian_handicap_home_min_45`, " #151
        query_commit += " `end_asian_handicap_away_min_45`, " #152
        query_commit += " `end_asian_handicap_home_min_425`, " #153
        query_commit += " `end_asian_handicap_away_min_425`, " #154
        query_commit += " `end_asian_handicap_home_min_4`, " #155
        query_commit += " `end_asian_handicap_away_min_4`, " #156
        query_commit += " `end_asian_handicap_home_min_375`, " #157
        query_commit += " `end_asian_handicap_away_min_375`, " #158
        query_commit += " `end_asian_handicap_home_min_35`, " #159
        query_commit += " `end_asian_handicap_away_min_35`, " #160
        query_commit += " `end_asian_handicap_home_min_325`, " #161
        query_commit += " `end_asian_handicap_away_min_325`, " #162
        query_commit += " `end_asian_handicap_home_min_3`, " #163
        query_commit += " `end_asian_handicap_away_min_3`, " #164
        query_commit += " `end_asian_handicap_home_min_275`, " #165
        query_commit += " `end_asian_handicap_away_min_275`, " #166
        query_commit += " `end_asian_handicap_home_min_25`, " #167
        query_commit += " `end_asian_handicap_away_min_25`, " #168
        query_commit += " `end_asian_handicap_home_min_225`, " #169
        query_commit += " `end_asian_handicap_away_min_225`, " #170
        query_commit += " `end_asian_handicap_home_min_2`, " #171
        query_commit += " `end_asian_handicap_away_min_2`, " #172
        query_commit += " `end_asian_handicap_home_min_175`, " #173
        query_commit += " `end_asian_handicap_away_min_175`, " #174
        query_commit += " `end_asian_handicap_home_min_15`, " #175
        query_commit += " `end_asian_handicap_away_min_15`, " #176
        query_commit += " `end_asian_handicap_home_min_125`, " #177
        query_commit += " `end_asian_handicap_away_min_125`, " #178
        query_commit += " `end_asian_handicap_home_min_1`, " #179
        query_commit += " `end_asian_handicap_away_min_1`, " #180
        query_commit += " `end_asian_handicap_home_min_075`, " #181
        query_commit += " `end_asian_handicap_away_min_075`, " #182
        query_commit += " `end_asian_handicap_home_min_05`, " #183
        query_commit += " `end_asian_handicap_away_min_05`, " #184
        query_commit += " `end_asian_handicap_home_min_025`, " #185
        query_commit += " `end_asian_handicap_away_min_025`, " #186
        query_commit += " `end_asian_handicap_home_plus_0`, " #187
        query_commit += " `end_asian_handicap_away_plus_0`, " #188
        query_commit += " `end_asian_handicap_home_plus_025`, " #189
        query_commit += " `end_asian_handicap_away_plus_025`, " #190
        query_commit += " `end_asian_handicap_home_plus_05`, " #191
        query_commit += " `end_asian_handicap_away_plus_05`, " #192
        query_commit += " `end_asian_handicap_home_plus_075`, " #193
        query_commit += " `end_asian_handicap_away_plus_075`, " #194
        query_commit += " `end_asian_handicap_home_plus_1`, " #195
        query_commit += " `end_asian_handicap_away_plus_1`, " #196
        query_commit += " `end_asian_handicap_home_plus_125`, " #197
        query_commit += " `end_asian_handicap_away_plus_125`, " #198
        query_commit += " `end_asian_handicap_home_plus_15`, " #199
        query_commit += " `end_asian_handicap_away_plus_15`, " #200
        query_commit += " `end_asian_handicap_home_plus_175`, " #201
        query_commit += " `end_asian_handicap_away_plus_175`, " #202
        query_commit += " `end_asian_handicap_home_plus_2`, " #203
        query_commit += " `end_asian_handicap_away_plus_2`, " #204
        query_commit += " `end_asian_handicap_home_plus_225`, " #205
        query_commit += " `end_asian_handicap_away_plus_225`, " #206
        query_commit += " `end_asian_handicap_home_plus_25`, " #207
        query_commit += " `end_asian_handicap_away_plus_25`, " #208
        query_commit += " `end_asian_handicap_home_plus_275`, " #209
        query_commit += " `end_asian_handicap_away_plus_275`, " #210
        query_commit += " `end_asian_handicap_home_plus_3`, " #211
        query_commit += " `end_asian_handicap_away_plus_3`, " #212
        query_commit += " `end_asian_handicap_home_plus_325`, " #213
        query_commit += " `end_asian_handicap_away_plus_325`, " #214
        query_commit += " `end_asian_handicap_home_plus_35`, " #215
        query_commit += " `end_asian_handicap_away_plus_35`, " #216
        query_commit += " `end_asian_handicap_home_plus_375`, " #217
        query_commit += " `end_asian_handicap_away_plus_375`, " #218
        query_commit += " `end_asian_handicap_home_plus_4`, " #219
        query_commit += " `end_asian_handicap_away_plus_4`, " #220
        query_commit += " `end_asian_handicap_home_plus_425`, " #221
        query_commit += " `end_asian_handicap_away_plus_425`, " #222
        query_commit += " `end_asian_handicap_home_plus_45`, " #223
        query_commit += " `end_asian_handicap_away_plus_45`, " #224
        query_commit += " `end_asian_handicap_home_plus_475`, " #225
        query_commit += " `end_asian_handicap_away_plus_475`, " #226
        query_commit += " `end_asian_handicap_home_plus_5`, " #227
        query_commit += " `end_asian_handicap_away_plus_5`, " #228
        query_commit += " `end_asian_handicap_home_plus_525`, " #229
        query_commit += " `end_asian_handicap_away_plus_525`, " #230
        query_commit += " `end_asian_handicap_home_plus_55`, " #231
        query_commit += " `end_asian_handicap_away_plus_55`, " #232
        query_commit += " `end_asian_handicap_home_plus_575`, " #233
        query_commit += " `end_asian_handicap_away_plus_575`, " #234
        query_commit += " `end_asian_handicap_home_plus_6`, " #235
        query_commit += " `end_asian_handicap_away_plus_6`, " #236
        query_commit += " `end_asian_handicap_home_plus_625`, " #237
        query_commit += " `end_asian_handicap_away_plus_625`, " #238
        query_commit += " `end_asian_handicap_home_plus_65`, " #239
        query_commit += " `end_asian_handicap_away_plus_65`, " #240
        query_commit += " `end_asian_handicap_home_plus_675`, " #241
        query_commit += " `end_asian_handicap_away_plus_675`, " #242
        query_commit += " `pre_goals_overunder_over_05`, " #243
        query_commit += " `pre_goals_overunder_under_05`, " #244
        query_commit += " `pre_goals_overunder_over_075`, " #245
        query_commit += " `pre_goals_overunder_under_075`, " #246
        query_commit += " `pre_goals_overunder_over_10`, " #247
        query_commit += " `pre_goals_overunder_under_10`, " #248
        query_commit += " `pre_goals_overunder_over_125`, " #249
        query_commit += " `pre_goals_overunder_under_125`, " #250
        query_commit += " `pre_goals_overunder_over_15`, " #251
        query_commit += " `pre_goals_overunder_under_15`, " #252
        query_commit += " `pre_goals_overunder_over_175`, " #253
        query_commit += " `pre_goals_overunder_under_175`, " #254
        query_commit += " `pre_goals_overunder_over_20`, " #255
        query_commit += " `pre_goals_overunder_under_20`, " #256
        query_commit += " `pre_goals_overunder_over_225`, " #257
        query_commit += " `pre_goals_overunder_under_225`, " #258
        query_commit += " `pre_goals_overunder_over_25`, " #259
        query_commit += " `pre_goals_overunder_under_25`, " #260
        query_commit += " `pre_goals_overunder_over_275`, " #261
        query_commit += " `pre_goals_overunder_under_275`, " #262
        query_commit += " `pre_goals_overunder_over_30`, " #263
        query_commit += " `pre_goals_overunder_under_30`, " #264
        query_commit += " `pre_goals_overunder_over_325`, " #265
        query_commit += " `pre_goals_overunder_under_325`, " #266
        query_commit += " `pre_goals_overunder_over_35`, " #267
        query_commit += " `pre_goals_overunder_under_35`, " #268
        query_commit += " `pre_goals_overunder_over_375`, " #269
        query_commit += " `pre_goals_overunder_under_375`, " #270
        query_commit += " `pre_goals_overunder_over_40`, " #271
        query_commit += " `pre_goals_overunder_under_40`, " #272
        query_commit += " `pre_goals_overunder_over_425`, " #273
        query_commit += " `pre_goals_overunder_under_425`, " #274
        query_commit += " `pre_goals_overunder_over_45`, " #275
        query_commit += " `pre_goals_overunder_under_45`, " #276
        query_commit += " `pre_goals_overunder_over_475`, " #277
        query_commit += " `pre_goals_overunder_under_475`, " #278
        query_commit += " `pre_goals_overunder_over_50`, " #279
        query_commit += " `pre_goals_overunder_under_50`, " #280
        query_commit += " `pre_goals_overunder_over_525`, " #281

        query_commit += " `pre_goals_overunder_under_525`, " #282
        query_commit += " `pre_goals_overunder_over_55`, " #283
        query_commit += " `pre_goals_overunder_under_55`, " #284
        query_commit += " `pre_goals_overunder_over_575`, " #285
        query_commit += " `pre_goals_overunder_under_575`, " #286
        query_commit += " `pre_goals_overunder_over_60`, " #287
        query_commit += " `pre_goals_overunder_under_60`, " #288
        query_commit += " `pre_goals_overunder_over_625`, " #289
        query_commit += " `pre_goals_overunder_under_625`, " #290
        query_commit += " `pre_goals_overunder_over_65`, " #291
        query_commit += " `pre_goals_overunder_under_65`, " #292
        query_commit += " `pre_goals_overunder_over_675`, " #293
        query_commit += " `pre_goals_overunder_under_675`, " #294
        query_commit += " `pre_goals_overunder_over_70`, " #295
        query_commit += " `pre_goals_overunder_under_70`, " #296
        query_commit += " `pre_goals_overunder_over_75`, " #297
        query_commit += " `pre_goals_overunder_under_75`, " #298
        query_commit += " `pre_goals_overunder_over_85`, " #299
        query_commit += " `pre_goals_overunder_under_85`, " #300
        query_commit += " `pre_goals_overunder_over_95`, " #301
        query_commit += " `pre_goals_overunder_under_95`, " #302
        query_commit += " `end_goals_overunder_over_05`, " #303
        query_commit += " `end_goals_overunder_under_05`, " #304
        query_commit += " `end_goals_overunder_over_075`, " #305
        query_commit += " `end_goals_overunder_under_075`, " #306
        query_commit += " `end_goals_overunder_over_10`, " #307
        query_commit += " `end_goals_overunder_under_10`, " #308
        query_commit += " `end_goals_overunder_over_125`, " #309
        query_commit += " `end_goals_overunder_under_125`, " #310
        query_commit += " `end_goals_overunder_over_15`, " #311
        query_commit += " `end_goals_overunder_under_15`, " #312
        query_commit += " `end_goals_overunder_over_175`, " #313
        query_commit += " `end_goals_overunder_under_175`, " #314
        query_commit += " `end_goals_overunder_over_20`, " #315
        query_commit += " `end_goals_overunder_under_20`, " #316
        query_commit += " `end_goals_overunder_over_225`, " #317
        query_commit += " `end_goals_overunder_under_225`, " #318
        query_commit += " `end_goals_overunder_over_25`, " #319
        query_commit += " `end_goals_overunder_under_25`, " #320
        query_commit += " `end_goals_overunder_over_275`, " #321
        query_commit += " `end_goals_overunder_under_275`, " #322
        query_commit += " `end_goals_overunder_over_30`, " #323
        query_commit += " `end_goals_overunder_under_30`, " #324
        query_commit += " `end_goals_overunder_over_325`, " #325
        query_commit += " `end_goals_overunder_under_325`, " #326
        query_commit += " `end_goals_overunder_over_35`, " #327
        query_commit += " `end_goals_overunder_under_35`, " #328
        query_commit += " `end_goals_overunder_over_375`, " #329
        query_commit += " `end_goals_overunder_under_375`, " #330
        query_commit += " `end_goals_overunder_over_40`, " #331
        query_commit += " `end_goals_overunder_under_40`, " #332
        query_commit += " `end_goals_overunder_over_425`, " #333
        query_commit += " `end_goals_overunder_under_425`, " #334
        query_commit += " `end_goals_overunder_over_45`, " #335
        query_commit += " `end_goals_overunder_under_45`, " #336
        query_commit += " `end_goals_overunder_over_475`, " #337
        query_commit += " `end_goals_overunder_under_475`, " #338
        query_commit += " `end_goals_overunder_over_50`, " #339
        query_commit += " `end_goals_overunder_under_50`, " #340
        query_commit += " `end_goals_overunder_over_525`, " #341
        query_commit += " `end_goals_overunder_under_525`, " #342
        query_commit += " `end_goals_overunder_over_55`, " #343
        query_commit += " `end_goals_overunder_under_55`, " #344
        query_commit += " `end_goals_overunder_over_575`, " #345
        query_commit += " `end_goals_overunder_under_575`, " #346
        query_commit += " `end_goals_overunder_over_60`, " #347
        query_commit += " `end_goals_overunder_under_60`, " #348
        query_commit += " `end_goals_overunder_over_625`, " #349
        query_commit += " `end_goals_overunder_under_625`, " #350
        query_commit += " `end_goals_overunder_over_65`, " #351
        query_commit += " `end_goals_overunder_under_65`, " #352
        query_commit += " `end_goals_overunder_over_675`, " #353
        query_commit += " `end_goals_overunder_under_675`, " #354
        query_commit += " `end_goals_overunder_over_70`, " #355
        query_commit += " `end_goals_overunder_under_70`, " #356
        query_commit += " `end_goals_overunder_over_75`, " #357
        query_commit += " `end_goals_overunder_under_75`, " #358
        query_commit += " `end_goals_overunder_over_85`, " #359
        query_commit += " `end_goals_overunder_under_85`, " #360
        query_commit += " `end_goals_overunder_over_95`, " #361
        query_commit += " `end_goals_overunder_under_95`, " #362
        query_commit += " `pre_asian_handicap_first_half_home_min_175`, " #363
        query_commit += " `pre_asian_handicap_first_half_away_min_175`, " #364
        query_commit += " `pre_asian_handicap_first_half_home_min_15`, " #365
        query_commit += " `pre_asian_handicap_first_half_away_min_15`, " #366
        query_commit += " `pre_asian_handicap_first_half_home_min_125`, " #367
        query_commit += " `pre_asian_handicap_first_half_away_min_125`, " #368
        query_commit += " `pre_asian_handicap_first_half_home_min_1`, " #369
        query_commit += " `pre_asian_handicap_first_half_away_min_1`, " #370
        query_commit += " `pre_asian_handicap_first_half_home_min_075`, " #371
        query_commit += " `pre_asian_handicap_first_half_away_min_075`, " #372
        query_commit += " `pre_asian_handicap_first_half_home_min_05`, " #373
        query_commit += " `pre_asian_handicap_first_half_away_min_05`, " #374
        query_commit += " `pre_asian_handicap_first_half_home_min_025`, " #375
        query_commit += " `pre_asian_handicap_first_half_away_min_025`, " #376
        query_commit += " `pre_asian_handicap_first_half_home_plus_0`, " #377
        query_commit += " `pre_asian_handicap_first_half_away_plus_0`, " #378
        query_commit += " `pre_asian_handicap_first_half_home_plus_025`, " #379
        query_commit += " `pre_asian_handicap_first_half_away_plus_025`, " #380
        query_commit += " `pre_asian_handicap_first_half_home_plus_05`, " #381
        query_commit += " `pre_asian_handicap_first_half_away_plus_05`, " #382
        query_commit += " `pre_asian_handicap_first_half_home_plus_075`, " #383
        query_commit += " `pre_asian_handicap_first_half_away_plus_075`, " #384
        query_commit += " `pre_asian_handicap_first_half_home_plus_1`, " #385
        query_commit += " `pre_asian_handicap_first_half_away_plus_1`, " #386
        query_commit += " `pre_asian_handicap_first_half_home_plus_125`, " #387
        query_commit += " `pre_asian_handicap_first_half_away_plus_125`, " #388
        query_commit += " `pre_asian_handicap_first_half_home_plus_15`, " #389
        query_commit += " `pre_asian_handicap_first_half_away_plus_15`, " #390
        query_commit += " `pre_asian_handicap_first_half_home_plus_175`, " #391
        query_commit += " `pre_asian_handicap_first_half_away_plus_175`, " #392
        query_commit += " `end_asian_handicap_first_half_home_min_175`, " #393
        query_commit += " `end_asian_handicap_first_half_away_min_175`, " #394
        query_commit += " `end_asian_handicap_first_half_home_min_15`, " #395
        query_commit += " `end_asian_handicap_first_half_away_min_15`, " #396
        query_commit += " `end_asian_handicap_first_half_home_min_125`, " #397
        query_commit += " `end_asian_handicap_first_half_away_min_125`, " #398
        query_commit += " `end_asian_handicap_first_half_home_min_1`, " #399
        query_commit += " `end_asian_handicap_first_half_away_min_1`, " #400
        query_commit += " `end_asian_handicap_first_half_home_min_075`, " #401
        query_commit += " `end_asian_handicap_first_half_away_min_075`, " #402
        query_commit += " `end_asian_handicap_first_half_home_min_05`, " #403
        query_commit += " `end_asian_handicap_first_half_away_min_05`, " #404
        query_commit += " `end_asian_handicap_first_half_home_min_025`, " #405
        query_commit += " `end_asian_handicap_first_half_away_min_025`, " #406
        query_commit += " `end_asian_handicap_first_half_home_plus_0`, " #407
        query_commit += " `end_asian_handicap_first_half_away_plus_0`, " #408
        query_commit += " `end_asian_handicap_first_half_home_plus_025`, " #409
        query_commit += " `end_asian_handicap_first_half_away_plus_025`, " #410
        query_commit += " `end_asian_handicap_first_half_home_plus_05`, " #411
        query_commit += " `end_asian_handicap_first_half_away_plus_05`, " #412
        query_commit += " `end_asian_handicap_first_half_home_plus_075`, " #413

        query_commit += " `end_asian_handicap_first_half_away_plus_075`, " #414
        query_commit += " `end_asian_handicap_first_half_home_plus_1`, " #415
        query_commit += " `end_asian_handicap_first_half_away_plus_1`, " #416
        query_commit += " `end_asian_handicap_first_half_home_plus_125`, " #417
        query_commit += " `end_asian_handicap_first_half_away_plus_125`, " #418
        query_commit += " `end_asian_handicap_first_half_home_plus_15`, " #419
        query_commit += " `end_asian_handicap_first_half_away_plus_15`, " #420
        query_commit += " `end_asian_handicap_first_half_home_plus_175`, " #421
        query_commit += " `end_asian_handicap_first_half_away_plus_175`, " #422
        query_commit += " `pre_goals_overunder_first_half_over_05`, " #423
        query_commit += " `pre_goals_overunder_first_half_under_05`, " #424
        query_commit += " `pre_goals_overunder_first_half_over_075`, " #425
        query_commit += " `pre_goals_overunder_first_half_under_075`, " #426
        query_commit += " `pre_goals_overunder_first_half_over_10`, " #427
        query_commit += " `pre_goals_overunder_first_half_under_10`, " #428
        query_commit += " `pre_goals_overunder_first_half_over_125`, " #429
        query_commit += " `pre_goals_overunder_first_half_under_125`, " #430
        query_commit += " `pre_goals_overunder_first_half_over_15`, " #431
        query_commit += " `pre_goals_overunder_first_half_under_15`, " #432
        query_commit += " `pre_goals_overunder_first_half_over_175`, " #433
        query_commit += " `pre_goals_overunder_first_half_under_175`, " #434
        query_commit += " `pre_goals_overunder_first_half_over_20`, " #435
        query_commit += " `pre_goals_overunder_first_half_under_20`, " #436
        query_commit += " `pre_goals_overunder_first_half_over_225`, " #437
        query_commit += " `pre_goals_overunder_first_half_under_225`, " #438
        query_commit += " `pre_goals_overunder_first_half_over_25`, " #439
        query_commit += " `pre_goals_overunder_first_half_under_25`, " #440
        query_commit += " `pre_goals_overunder_first_half_over_275`, " #441
        query_commit += " `pre_goals_overunder_first_half_under_275`, " #442
        query_commit += " `pre_goals_overunder_first_half_over_30`, " #443
        query_commit += " `pre_goals_overunder_first_half_under_30`, " #444
        query_commit += " `pre_goals_overunder_first_half_over_325`, " #445
        query_commit += " `pre_goals_overunder_first_half_under_325`, " #446
        query_commit += " `pre_goals_overunder_first_half_over_35`, " #447
        query_commit += " `pre_goals_overunder_first_half_under_35`, " #448
        query_commit += " `pre_goals_overunder_first_half_over_375`, " #449
        query_commit += " `pre_goals_overunder_first_half_under_375`, " #450
        query_commit += " `end_goals_overunder_first_half_over_05`, " #451
        query_commit += " `end_goals_overunder_first_half_under_05`, " #452
        query_commit += " `end_goals_overunder_first_half_over_075`, " #453
        query_commit += " `end_goals_overunder_first_half_under_075`, " #454
        query_commit += " `end_goals_overunder_first_half_over_10`, " #455
        query_commit += " `end_goals_overunder_first_half_under_10`, " #456
        query_commit += " `end_goals_overunder_first_half_over_125`, " #457
        query_commit += " `end_goals_overunder_first_half_under_125`, " #458
        query_commit += " `end_goals_overunder_first_half_over_15`, " #459
        query_commit += " `end_goals_overunder_first_half_under_15`, " #460
        query_commit += " `end_goals_overunder_first_half_over_175`, " #461
        query_commit += " `end_goals_overunder_first_half_under_175`, " #462
        query_commit += " `end_goals_overunder_first_half_over_20`, " #463
        query_commit += " `end_goals_overunder_first_half_under_20`, " #464
        query_commit += " `end_goals_overunder_first_half_over_225`, " #465
        query_commit += " `end_goals_overunder_first_half_under_225`, " #466
        query_commit += " `end_goals_overunder_first_half_over_25`, " #467
        query_commit += " `end_goals_overunder_first_half_under_25`, " #468
        query_commit += " `end_goals_overunder_first_half_over_275`, " #469
        query_commit += " `end_goals_overunder_first_half_under_275`, " #470
        query_commit += " `end_goals_overunder_first_half_over_30`, " #471
        query_commit += " `end_goals_overunder_first_half_under_30`, " #472
        query_commit += " `end_goals_overunder_first_half_over_325`, " #473
        query_commit += " `end_goals_overunder_first_half_under_325`, " #474
        query_commit += " `end_goals_overunder_first_half_over_35`, " #475
        query_commit += " `end_goals_overunder_first_half_under_35`, " #476
        query_commit += " `end_goals_overunder_first_half_over_375`, " #477
        query_commit += " `end_goals_overunder_first_half_under_375`, " #478
        query_commit += " `pre_goals_overunder__second_half_over_05`, " #479
        query_commit += " `pre_goals_overunder__second_half_under_05`, " #480
        query_commit += " `pre_goals_overunder__second_half_over_075`, " #481
        query_commit += " `pre_goals_overunder__second_half_under_075`, " #482
        query_commit += " `pre_goals_overunder__second_half_over_10`, " #483
        query_commit += " `pre_goals_overunder__second_half_under_10`, " #484
        query_commit += " `pre_goals_overunder__second_half_over_125`, " #485
        query_commit += " `pre_goals_overunder__second_half_under_125`, " #486
        query_commit += " `pre_goals_overunder__second_half_over_15`, " #487
        query_commit += " `pre_goals_overunder__second_half_under_15`, " #488
        query_commit += " `pre_goals_overunder__second_half_over_175`, " #489
        query_commit += " `pre_goals_overunder__second_half_under_175`, " #490
        query_commit += " `pre_goals_overunder__second_half_over_20`, " #491
        query_commit += " `pre_goals_overunder__second_half_under_20`, " #492
        query_commit += " `pre_goals_overunder__second_half_over_225`, " #493
        query_commit += " `pre_goals_overunder__second_half_under_225`, " #494
        query_commit += " `pre_goals_overunder__second_half_over_25`, " #495
        query_commit += " `pre_goals_overunder__second_half_under_25`, " #496
        query_commit += " `pre_goals_overunder__second_half_over_275`, " #497
        query_commit += " `pre_goals_overunder__second_half_under_275`, " #498
        query_commit += " `pre_goals_overunder__second_half_over_30`, " #499
        query_commit += " `pre_goals_overunder__second_half_under_30`, " #500
        query_commit += " `pre_goals_overunder__second_half_over_325`, " #501
        query_commit += " `pre_goals_overunder__second_half_under_325`, " #502
        query_commit += " `pre_goals_overunder__second_half_over_35`, " #503
        query_commit += " `pre_goals_overunder__second_half_under_35`, " #504
        query_commit += " `pre_goals_overunder__second_half_over_375`, " #505
        query_commit += " `pre_goals_overunder__second_half_under_375`, " #506
        query_commit += " `end_goals_overunder__second_half_over_05`, " #507
        query_commit += " `end_goals_overunder__second_half_under_05`, " #508
        query_commit += " `end_goals_overunder__second_half_over_075`, " #509
        query_commit += " `end_goals_overunder__second_half_under_075`, " #510
        query_commit += " `end_goals_overunder__second_half_over_10`, " #511
        query_commit += " `end_goals_overunder__second_half_under_10`, " #512
        query_commit += " `end_goals_overunder__second_half_over_125`, " #513
        query_commit += " `end_goals_overunder__second_half_under_125`, " #514
        query_commit += " `end_goals_overunder__second_half_over_15`, " #515
        query_commit += " `end_goals_overunder__second_half_under_15`, " #516
        query_commit += " `end_goals_overunder__second_half_over_175`, " #517
        query_commit += " `end_goals_overunder__second_half_under_175`, " #518
        query_commit += " `end_goals_overunder__second_half_over_20`, " #519
        query_commit += " `end_goals_overunder__second_half_under_20`, " #520
        query_commit += " `end_goals_overunder__second_half_over_225`, " #521
        query_commit += " `end_goals_overunder__second_half_under_225`, " #522
        query_commit += " `end_goals_overunder__second_half_over_25`, " #523
        query_commit += " `end_goals_overunder__second_half_under_25`, " #524
        query_commit += " `end_goals_overunder__second_half_over_275`, " #525
        query_commit += " `end_goals_overunder__second_half_under_275`, " #526
        query_commit += " `end_goals_overunder__second_half_over_30`, " #527
        query_commit += " `end_goals_overunder__second_half_under_30`, " #528
        query_commit += " `end_goals_overunder__second_half_over_325`, " #529
        query_commit += " `end_goals_overunder__second_half_under_325`, " #530
        query_commit += " `end_goals_overunder__second_half_over_35`, " #531
        query_commit += " `end_goals_overunder__second_half_under_35`, " #532

        query_commit += " `end_goals_overunder__second_half_over_375`, " #533
        query_commit += " `end_goals_overunder__second_half_under_375`, " #534
        query_commit += " `pre_htft_double_home_home`, " #535
        query_commit += " `pre_htft_double_home_draw`, " #536
        query_commit += " `pre_htft_double_home_away`, " #537
        query_commit += " `pre_htft_double_draw_home`, " #538
        query_commit += " `pre_htft_double_draw_draw`, " #539
        query_commit += " `pre_htft_double_draw_away`, " #540
        query_commit += " `pre_htft_double_away_home`, " #541
        query_commit += " `pre_htft_double_away_draw`, " #542
        query_commit += " `pre_htft_double_away_away`, " #543
        query_commit += " `end_htft_double_home_home`, " #544
        query_commit += " `end_htft_double_home_draw`, " #545
        query_commit += " `end_htft_double_home_away`, " #546
        query_commit += " `end_htft_double_draw_home`, " #547
        query_commit += " `end_htft_double_draw_draw`, " #548
        query_commit += " `end_htft_double_draw_away`, " #549
        query_commit += " `end_htft_double_away_home`, " #550
        query_commit += " `end_htft_double_away_draw`, " #551
        query_commit += " `end_htft_double_away_away`, " #552
        query_commit += " `pre_both_teams_score_yes`, " #553
        query_commit += " `pre_both_teams_score_no`, " #554
        query_commit += " `end_both_teams_score_yes`, " #555
        query_commit += " `end_both_teams_score_no`, " #556
        query_commit += " `pre_both_teams_score__first_half_yes`, " #557
        query_commit += " `pre_both_teams_score__first_half_no`, " #558
        query_commit += " `end_both_teams_score__first_half_yes`, " #559
        query_commit += " `end_both_teams_score__first_half_no`, " #560
        query_commit += " `pre_both_teams_to_score__second_half_yes`, " #561
        query_commit += " `pre_both_teams_to_score__second_half_no`, " #562
        query_commit += " `end_both_teams_to_score__second_half_yes`, " #563
        query_commit += " `end_both_teams_to_score__second_half_no`, " #564
        query_commit += " `pre_results_both_teams_score_home_yes`, " #565
        query_commit += " `pre_results_both_teams_score_draw_yes`, " #566
        query_commit += " `pre_results_both_teams_score_away_yes`, " #567
        query_commit += " `pre_results_both_teams_score_home_no`, " #568
        query_commit += " `pre_results_both_teams_score_draw_no`, " #569
        query_commit += " `pre_results_both_teams_score_away_no`, " #570
        query_commit += " `end_results_both_teams_score_home_yes`, " #571
        query_commit += " `end_results_both_teams_score_draw_yes`, " #572
        query_commit += " `end_results_both_teams_score_away_yes`, " #573
        query_commit += " `end_results_both_teams_score_home_no`, " #574
        query_commit += " `end_results_both_teams_score_draw_no`, " #575
        query_commit += " `end_results_both_teams_score_away_no`, " #576
        query_commit += " `pre_to_score_in_both_halves_by_teams_home`, " #577
        query_commit += " `pre_to_score_in_both_halves_by_teams_away`, " #578
        query_commit += " `end_to_score_in_both_halves_by_teams_home`, " #579
        query_commit += " `end_to_score_in_both_halves_by_teams_away`, " #580
        query_commit += " `pre_total_goals_both_teams_to_score_over_yes_25`, " #581
        query_commit += " `pre_total_goals_both_teams_to_score_over_no_25`, " #582
        query_commit += " `pre_total_goals_both_teams_to_score_under_yes_25`, " #583
        query_commit += " `pre_total_goals_both_teams_to_score_under_no_25`, " #584
        query_commit += " `end_total_goals_both_teams_to_score_over_yes_25`, " #585
        query_commit += " `end_total_goals_both_teams_to_score_over_no_25`, " #586
        query_commit += " `end_total_goals_both_teams_to_score_under_yes_25`, " #587
        query_commit += " `end_total_goals_both_teams_to_score_under_no_25`, " #588
        query_commit += " `pre_both_teams_to_score_1st_half__2nd_half_yes_yes`, " #589
        query_commit += " `pre_both_teams_to_score_1st_half__2nd_half_yes_no`, " #590
        query_commit += " `pre_both_teams_to_score_1st_half__2nd_half_no_yes`, " #591
        query_commit += " `pre_both_teams_to_score_1st_half__2nd_half_no_no`, " #592
        query_commit += " `end_both_teams_to_score_1st_half__2nd_half_yes_yes`, " #593
        query_commit += " `end_both_teams_to_score_1st_half__2nd_half_yes_no`, " #594
        query_commit += " `end_both_teams_to_score_1st_half__2nd_half_no_yes`, " #595
        query_commit += " `end_both_teams_to_score_1st_half__2nd_half_no_no`, " #596
        query_commit += " `pre_highest_scoring_half_first`, " #597
        query_commit += " `pre_highest_scoring_half_draw`, " #598
        query_commit += " `pre_highest_scoring_half_second`, " #599
        query_commit += " `end_highest_scoring_half_first`, " #600
        query_commit += " `end_highest_scoring_half_draw`, " #601
        query_commit += " `end_highest_scoring_half_second`, " #602
        query_commit += " `pre_double_chance_home_draw`, " #603
        query_commit += " `pre_double_chance_home_away`, " #604
        query_commit += " `pre_double_chance_draw_away`, " #605
        query_commit += " `end_double_chance_home_draw`, " #606
        query_commit += " `end_double_chance_home_away`, " #607
        query_commit += " `end_double_chance_draw_away`, " #608
        query_commit += " `pre_double_chance__first_half_home_draw`, " #609
        query_commit += " `pre_double_chance__first_half_home_away`, " #610
        query_commit += " `pre_double_chance__first_half_draw_away`, " #611
        query_commit += " `end_double_chance__first_half_home_draw`, " #612
        query_commit += " `end_double_chance__first_half_home_away`, " #613
        query_commit += " `end_double_chance__first_half_draw_away`, " #614
        query_commit += " `pre_oddeven_odd`, " #615
        query_commit += " `pre_oddeven_even`, " #616
        query_commit += " `end_oddeven_odd`, " #617
        query_commit += " `end_oddeven_even`, " #618
        query_commit += " `pre_result_total_goals_home_over_35`, " #619
        query_commit += " `pre_result_total_goals_draw_over_35`, " #620
        query_commit += " `pre_result_total_goals_away_over_35`, " #621
        query_commit += " `pre_result_total_goals_home_under_35`, " #622
        query_commit += " `pre_result_total_goals_draw_under_35`, " #623
        query_commit += " `pre_result_total_goals_away_under_35`, " #624
        query_commit += " `pre_result_total_goals_home_over_25`, " #625
        query_commit += " `pre_result_total_goals_draw_over_25`, " #626
        query_commit += " `pre_result_total_goals_away_over_25`, " #627
        query_commit += " `pre_result_total_goals_home_under_25`, " #628
        query_commit += " `pre_result_total_goals_draw_under_25`, " #629
        query_commit += " `pre_result_total_goals_away_under_25`, " #630
        query_commit += " `end_result_total_goals_home_over_35`, " #631
        query_commit += " `end_result_total_goals_draw_over_35`, " #632
        query_commit += " `end_result_total_goals_away_over_35`, " #633
        query_commit += " `end_result_total_goals_home_under_35`, " #634
        query_commit += " `end_result_total_goals_draw_under_35`, " #635
        query_commit += " `end_result_total_goals_away_under_35`, " #636
        query_commit += " `end_result_total_goals_home_over_25`, " #637
        query_commit += " `end_result_total_goals_draw_over_25`, " #638
        query_commit += " `end_result_total_goals_away_over_25`, " #639
        query_commit += " `end_result_total_goals_home_under_25`, " #640
        query_commit += " `end_result_total_goals_draw_under_25`, " #641
        query_commit += " `end_result_total_goals_away_under_25`, " #642
        query_commit += " `pre_clean_sheet__home_yes`, " #643
        query_commit += " `pre_clean_sheet__home_no`, " #644
        query_commit += " `end_clean_sheet__home_yes`, " #645
        query_commit += " `end_clean_sheet__home_no`, " #646
        query_commit += " `pre_clean_sheet__away_yes`, " #647
        query_commit += " `pre_clean_sheet__away_no`, " #648
        query_commit += " `end_clean_sheet__away_yes`, " #649
        query_commit += " `end_clean_sheet__away_no`, " #650
        query_commit += " `pre_win_both_halves_home`, " #651
        query_commit += " `pre_win_both_halves_away`, " #652
        query_commit += " `end_win_both_halves_home`, " #653
        query_commit += " `end_win_both_halves_away`, " #654
        query_commit += " `pre_win_to_nil_home`, " #655
        query_commit += " `pre_win_to_nil_away`, " #656
        query_commit += " `end_win_to_nil_home`, " #657
        query_commit += " `end_win_to_nil_away`, " #658
        query_commit += " `pre_to_win_either_half_home`, " #659
        query_commit += " `pre_to_win_either_half_away`, " #660
        query_commit += " `end_to_win_either_half_home`, " #661
        query_commit += " `end_to_win_either_half_away`, " #662
        query_commit += " `pre_halftime_result_both_teams_score_home_yes`, " #663
        query_commit += " `pre_halftime_result_both_teams_score_draw_yes`, " #664
        query_commit += " `pre_halftime_result_both_teams_score_away_yes`, " #665

        query_commit += " `pre_halftime_result_both_teams_score_home_no`, " #666
        query_commit += " `pre_halftime_result_both_teams_score_draw_no`, " #667
        query_commit += " `pre_halftime_result_both_teams_score_away_no`, " #668
        query_commit += " `end_halftime_result_both_teams_score_home_yes`, " #669
        query_commit += " `end_halftime_result_both_teams_score_draw_yes`, " #670
        query_commit += " `end_halftime_result_both_teams_score_away_yes`, " #671
        query_commit += " `end_halftime_result_both_teams_score_home_no`, " #672
        query_commit += " `end_halftime_result_both_teams_score_draw_no`, " #673
        query_commit += " `end_halftime_result_both_teams_score_away_no`, " #674
        query_commit += " `pre_exact_goals_number_0`, " #675
        query_commit += " `pre_exact_goals_number_1`, " #676
        query_commit += " `pre_exact_goals_number_2`, " #677
        query_commit += " `pre_exact_goals_number_3`, " #678
        query_commit += " `pre_exact_goals_number_4`, " #679
        query_commit += " `pre_exact_goals_number_5`, " #680
        query_commit += " `pre_exact_goals_number_6`, " #681
        query_commit += " `pre_exact_goals_number_more_7`, " #682
        query_commit += " `end_exact_goals_number_0`, " #683
        query_commit += " `end_exact_goals_number_1`, " #684
        query_commit += " `end_exact_goals_number_2`, " #685
        query_commit += " `end_exact_goals_number_3`, " #686
        query_commit += " `end_exact_goals_number_4`, " #687
        query_commit += " `end_exact_goals_number_5`, " #688
        query_commit += " `end_exact_goals_number_6`, " #689
        query_commit += " `end_exact_goals_number_more_7`, " #690
        query_commit += " `pre_exact_goals_number__first_half_0`, " #691
        query_commit += " `pre_exact_goals_number__first_half_1`, " #692
        query_commit += " `pre_exact_goals_number__first_half_2`, " #693
        query_commit += " `pre_exact_goals_number__first_half_3`, " #694
        query_commit += " `pre_exact_goals_number__first_half_4`, " #695
        query_commit += " `pre_exact_goals_number__first_half_more_5`, " #696
        query_commit += " `end_exact_goals_number__first_half_0`, " #697
        query_commit += " `end_exact_goals_number__first_half_1`, " #698
        query_commit += " `end_exact_goals_number__first_half_2`, " #699
        query_commit += " `end_exact_goals_number__first_half_3`, " #700
        query_commit += " `end_exact_goals_number__first_half_4`, " #701
        query_commit += " `end_exact_goals_number__first_half_more_5`, " #702
        query_commit += " `pre_second_half_exact_goals_number_0`, " #703
        query_commit += " `pre_second_half_exact_goals_number_1`, " #704
        query_commit += " `pre_second_half_exact_goals_number_2`, " #705
        query_commit += " `pre_second_half_exact_goals_number_3`, " #706
        query_commit += " `pre_second_half_exact_goals_number_4`, " #707
        query_commit += " `pre_second_half_exact_goals_number_more_5`, " #708
        query_commit += " `end_second_half_exact_goals_number_0`, " #709
        query_commit += " `end_second_half_exact_goals_number_1`, " #710
        query_commit += " `end_second_half_exact_goals_number_2`, " #711
        query_commit += " `end_second_half_exact_goals_number_3`, " #712
        query_commit += " `end_second_half_exact_goals_number_4`, " #713
        query_commit += " `end_second_half_exact_goals_number_more_5`, " #714
        query_commit += " `pre_home_team_exact_goals_number_0`, " #715
        query_commit += " `pre_home_team_exact_goals_number_1`, " #716
        query_commit += " `pre_home_team_exact_goals_number_2`, " #717
        query_commit += " `pre_home_team_exact_goals_number_more_3`, " #718
        query_commit += " `end_home_team_exact_goals_number_0`, " #719
        query_commit += " `end_home_team_exact_goals_number_1`, " #720
        query_commit += " `end_home_team_exact_goals_number_2`, " #721
        query_commit += " `end_home_team_exact_goals_number_more_3`, " #722
        query_commit += " `pre_away_team_exact_goals_number_0`, " #723
        query_commit += " `pre_away_team_exact_goals_number_1`, " #724
        query_commit += " `pre_away_team_exact_goals_number_2`, " #725
        query_commit += " `pre_away_team_exact_goals_number_more_3`, " #726
        query_commit += " `end_away_team_exact_goals_number_0`, " #727
        query_commit += " `end_away_team_exact_goals_number_1`, " #728
        query_commit += " `end_away_team_exact_goals_number_2`, " #729
        query_commit += " `end_away_team_exact_goals_number_more_3`, " #730
        query_commit += " `pre_corners_winner_home`, " #731
        query_commit += " `pre_corners_winner_draw`, " #732
        query_commit += " `pre_corners_winner_away`, " #733
        query_commit += " `end_corners_winner_home`, " #734
        query_commit += " `end_corners_winner_draw`, " #735
        query_commit += " `end_corners_winner_away`, " #736
        query_commit += " `pre_10_overunder_over_05`, " #737
        query_commit += " `pre_10_overunder_under_05`, " #738
        query_commit += " `end_10_overunder_over_05`, " #739
        query_commit += " `end_10_overunder_under_05`, " #740
        query_commit += " `pre_cards_european_handicap_home_min_2`, " #741
        query_commit += " `pre_cards_european_handicap_draw_min_2`, " #742
        query_commit += " `pre_cards_european_handicap_away_min_2`, " #743
        query_commit += " `pre_cards_european_handicap_home_min_1`, " #744
        query_commit += " `pre_cards_european_handicap_draw_min_1`, " #745
        query_commit += " `pre_cards_european_handicap_away_min_1`, " #746
        query_commit += " `pre_cards_european_handicap_home_plus_0`, " #747
        query_commit += " `pre_cards_european_handicap_draw_plus_0`, " #748
        query_commit += " `pre_cards_european_handicap_away_plus_0`, " #749
        query_commit += " `pre_cards_european_handicap_home_plus_1`, " #750
        query_commit += " `pre_cards_european_handicap_draw_plus_1`, " #751
        query_commit += " `pre_cards_european_handicap_away_plus_1`, " #752
        query_commit += " `pre_cards_european_handicap_home_plus_2`, " #753
        query_commit += " `pre_cards_european_handicap_draw_plus_2`, " #754
        query_commit += " `pre_cards_european_handicap_away_plus_2`, " #755
        query_commit += " `end_cards_european_handicap_home_min_2`, " #756
        query_commit += " `end_cards_european_handicap_draw_min_2`, " #757
        query_commit += " `end_cards_european_handicap_away_min_2`, " #758
        query_commit += " `end_cards_european_handicap_home_min_1`, " #759
        query_commit += " `end_cards_european_handicap_draw_min_1`, " #760
        query_commit += " `end_cards_european_handicap_away_min_1`, " #761
        query_commit += " `end_cards_european_handicap_home_plus_0`, " #762
        query_commit += " `end_cards_european_handicap_draw_plus_0`, " #763
        query_commit += " `end_cards_european_handicap_away_plus_0`, " #764
        query_commit += " `end_cards_european_handicap_home_plus_1`, " #765
        query_commit += " `end_cards_european_handicap_draw_plus_1`, " #766
        query_commit += " `end_cards_european_handicap_away_plus_1`, " #767
        query_commit += " `end_cards_european_handicap_home_plus_2`, " #768
        query_commit += " `end_cards_european_handicap_draw_plus_2`, " #769
        query_commit += " `end_cards_european_handicap_away_plus_2`, " #770
        query_commit += " `pre_rcard_yes`, " #771
        query_commit += " `pre_rcard_no`, " #772
        query_commit += " `end_rcard_yes`, " #773
        query_commit += " `end_rcard_no`, " #774
        query_commit += " `pre_team_to_score_first_home`, " #775
        query_commit += " `pre_team_to_score_first_draw`, " #776
        query_commit += " `pre_team_to_score_first_away`, " #777
        query_commit += " `end_team_to_score_first_home`, " #778
        query_commit += " `end_team_to_score_first_draw`, " #779
        query_commit += " `end_team_to_score_first_away`, " #780
        query_commit += " `pre_team_to_score_last_home`, " #781
        query_commit += " `pre_team_to_score_last_draw`, " #782
        query_commit += " `pre_team_to_score_last_away`, " #783
        query_commit += " `end_team_to_score_last_home`, " #784
        query_commit += " `end_team_to_score_last_draw`, " #785
        query_commit += " `end_team_to_score_last_away`, " #786
        query_commit += " `pre_total_home_over_15`, " #787
        query_commit += " `pre_total_home_under_15`, " #788
        query_commit += " `pre_total_home_over_25`, " #789
        query_commit += " `pre_total_home_under_25`, " #790
        query_commit += " `pre_total_home_over_35`, " #791
        query_commit += " `pre_total_home_under_35`, " #792
        query_commit += " `pre_total_home_over_45`, " #793
        query_commit += " `pre_total_home_under_45`, " #794
        query_commit += " `pre_total_home_over_55`, " #795
        query_commit += " `pre_total_home_under_55`, " #796
        query_commit += " `pre_total_home_over_65`, " #797
        query_commit += " `pre_total_home_under_65`, " #798
        query_commit += " `end_total_home_over_15`, " #799

        query_commit += " `end_total_home_under_15`, " #800
        query_commit += " `end_total_home_over_25`, " #801
        query_commit += " `end_total_home_under_25`, " #802
        query_commit += " `end_total_home_over_35`, " #803
        query_commit += " `end_total_home_under_35`, " #804
        query_commit += " `end_total_home_over_45`, " #805
        query_commit += " `end_total_home_under_45`, " #806
        query_commit += " `end_total_home_over_55`, " #807
        query_commit += " `end_total_home_under_55`, " #808
        query_commit += " `end_total_home_over_65`, " #809
        query_commit += " `end_total_home_under_65`, " #810
        query_commit += " `pre_total_away_over_15`, " #811
        query_commit += " `pre_total_away_under_15`, " #812
        query_commit += " `pre_total_away_over_25`, " #813
        query_commit += " `pre_total_away_under_25`, " #814
        query_commit += " `pre_total_away_over_35`, " #815
        query_commit += " `pre_total_away_under_35`, " #816
        query_commit += " `pre_total_away_over_45`, " #817
        query_commit += " `pre_total_away_under_45`, " #818
        query_commit += " `pre_total_away_over_55`, " #819
        query_commit += " `pre_total_away_under_55`, " #820
        query_commit += " `pre_total_away_over_65`, " #821
        query_commit += " `pre_total_away_under_65`, " #822
        query_commit += " `end_total_away_over_15`, " #823
        query_commit += " `end_total_away_under_15`, " #824
        query_commit += " `end_total_away_over_25`, " #825
        query_commit += " `end_total_away_under_25`, " #826
        query_commit += " `end_total_away_over_35`, " #827
        query_commit += " `end_total_away_under_35`, " #828
        query_commit += " `end_total_away_over_45`, " #829
        query_commit += " `end_total_away_under_45`, " #830
        query_commit += " `end_total_away_over_55`, " #831
        query_commit += " `end_total_away_under_55`, " #832
        query_commit += " `end_total_away_over_65`, " #833
        query_commit += " `end_total_away_under_65`, " #834
        query_commit += " `pre_corners_asian_handicap_home_min_65`, " #835
        query_commit += " `pre_corners_asian_handicap_away_min_65`, " #836
        query_commit += " `pre_corners_asian_handicap_home_min_6`, " #837
        query_commit += " `pre_corners_asian_handicap_away_min_6`, " #838
        query_commit += " `pre_corners_asian_handicap_home_min_55`, " #839
        query_commit += " `pre_corners_asian_handicap_away_min_55`, " #840
        query_commit += " `pre_corners_asian_handicap_home_min_5`, " #841
        query_commit += " `pre_corners_asian_handicap_away_min_5`, " #842
        query_commit += " `pre_corners_asian_handicap_home_min_45`, " #843
        query_commit += " `pre_corners_asian_handicap_away_min_45`, " #844
        query_commit += " `pre_corners_asian_handicap_home_min_4`, " #845
        query_commit += " `pre_corners_asian_handicap_away_min_4`, " #846
        query_commit += " `pre_corners_asian_handicap_home_min_35`, " #847
        query_commit += " `pre_corners_asian_handicap_away_min_35`, " #848
        query_commit += " `pre_corners_asian_handicap_home_min_3`, " #849
        query_commit += " `pre_corners_asian_handicap_away_min_3`, " #850
        query_commit += " `pre_corners_asian_handicap_home_min_25`, " #851
        query_commit += " `pre_corners_asian_handicap_away_min_25`, " #852
        query_commit += " `pre_corners_asian_handicap_home_min_2`, " #853
        query_commit += " `pre_corners_asian_handicap_away_min_2`, " #854
        query_commit += " `pre_corners_asian_handicap_home_min_15`, " #855
        query_commit += " `pre_corners_asian_handicap_away_min_15`, " #856
        query_commit += " `pre_corners_asian_handicap_home_min_1`, " #857
        query_commit += " `pre_corners_asian_handicap_home_min_05`, " #858
        query_commit += " `pre_corners_asian_handicap_away_min_1`, " #859
        query_commit += " `pre_corners_asian_handicap_away_min_05`, " #860
        query_commit += " `pre_corners_asian_handicap_home_plus_0`, " #861
        query_commit += " `pre_corners_asian_handicap_away_plus_0`, " #862
        query_commit += " `pre_corners_asian_handicap_home_plus_05`, " #863
        query_commit += " `pre_corners_asian_handicap_away_plus_05`, " #864
        query_commit += " `pre_corners_asian_handicap_home_plus_1`, " #865
        query_commit += " `pre_corners_asian_handicap_away_plus_1`, " #866
        query_commit += " `pre_corners_asian_handicap_home_plus_15`, " #867
        query_commit += " `pre_corners_asian_handicap_away_plus_15`, " #868
        query_commit += " `pre_corners_asian_handicap_home_plus_2`, " #869
        query_commit += " `pre_corners_asian_handicap_away_plus_2`, " #870
        query_commit += " `pre_corners_asian_handicap_home_plus_25`, " #871
        query_commit += " `pre_corners_asian_handicap_away_plus_25`, " #872
        query_commit += " `pre_corners_asian_handicap_home_plus_3`, " #873
        query_commit += " `pre_corners_asian_handicap_away_plus_3`, " #874
        query_commit += " `pre_corners_asian_handicap_home_plus_35`, " #875
        query_commit += " `pre_corners_asian_handicap_away_plus_35`, " #876
        query_commit += " `pre_corners_asian_handicap_home_plus_4`, " #877
        query_commit += " `pre_corners_asian_handicap_away_plus_4`, " #878
        query_commit += " `pre_corners_asian_handicap_home_plus_45`, " #879
        query_commit += " `pre_corners_asian_handicap_away_plus_45`, " #880
        query_commit += " `pre_corners_asian_handicap_home_plus_5`, " #881
        query_commit += " `pre_corners_asian_handicap_away_plus_5`, " #882
        query_commit += " `pre_corners_asian_handicap_home_plus_55`, " #883
        query_commit += " `pre_corners_asian_handicap_away_plus_55`, " #884
        query_commit += " `pre_corners_asian_handicap_home_plus_6`, " #885
        query_commit += " `pre_corners_asian_handicap_away_plus_6`, " #886
        query_commit += " `pre_corners_asian_handicap_home_plus_65`, " #887
        query_commit += " `pre_corners_asian_handicap_away_plus_65`, " #888
        query_commit += " `end_corners_asian_handicap_home_min_65`, " #889
        query_commit += " `end_corners_asian_handicap_away_min_65`, " #890
        query_commit += " `end_corners_asian_handicap_home_min_6`, " #891
        query_commit += " `end_corners_asian_handicap_away_min_6`, " #892
        query_commit += " `end_corners_asian_handicap_home_min_55`, " #893
        query_commit += " `end_corners_asian_handicap_away_min_55`, " #894
        query_commit += " `end_corners_asian_handicap_home_min_5`, " #895
        query_commit += " `end_corners_asian_handicap_away_min_5`, " #896
        query_commit += " `end_corners_asian_handicap_home_min_45`, " #897
        query_commit += " `end_corners_asian_handicap_away_min_45`, " #898
        query_commit += " `end_corners_asian_handicap_home_min_4`, " #899
        query_commit += " `end_corners_asian_handicap_away_min_4`, " #900
        query_commit += " `end_corners_asian_handicap_home_min_35`, " #901
        query_commit += " `end_corners_asian_handicap_away_min_35`, " #902
        query_commit += " `end_corners_asian_handicap_home_min_3`, " #903
        query_commit += " `end_corners_asian_handicap_away_min_3`, " #904
        query_commit += " `end_corners_asian_handicap_home_min_25`, " #905
        query_commit += " `end_corners_asian_handicap_away_min_25`, " #906
        query_commit += " `end_corners_asian_handicap_home_min_2`, " #907
        query_commit += " `end_corners_asian_handicap_away_min_2`, " #908
        query_commit += " `end_corners_asian_handicap_home_min_15`, " #909
        query_commit += " `end_corners_asian_handicap_away_min_15`, " #910
        query_commit += " `end_corners_asian_handicap_home_min_1`, " #911
        query_commit += " `end_corners_asian_handicap_home_min_05`, " #912
        query_commit += " `end_corners_asian_handicap_away_min_1`, " #913
        query_commit += " `end_corners_asian_handicap_away_min_05`, " #914
        query_commit += " `end_corners_asian_handicap_home_plus_0`, " #915
        query_commit += " `end_corners_asian_handicap_away_plus_0`, " #916
        query_commit += " `end_corners_asian_handicap_home_plus_05`, " #917
        query_commit += " `end_corners_asian_handicap_away_plus_05`, " #918
        query_commit += " `end_corners_asian_handicap_home_plus_1`, " #919
        query_commit += " `end_corners_asian_handicap_away_plus_1`, " #920
        query_commit += " `end_corners_asian_handicap_home_plus_15`, " #921
        query_commit += " `end_corners_asian_handicap_away_plus_15`, " #922
        query_commit += " `end_corners_asian_handicap_home_plus_2`, " #923
        query_commit += " `end_corners_asian_handicap_away_plus_2`, " #924
        query_commit += " `end_corners_asian_handicap_home_plus_25`, " #925
        query_commit += " `end_corners_asian_handicap_away_plus_25`, " #926
        query_commit += " `end_corners_asian_handicap_home_plus_3`, " #927
        query_commit += " `end_corners_asian_handicap_away_plus_3`, " #928
        query_commit += " `end_corners_asian_handicap_home_plus_35`, " #929
        query_commit += " `end_corners_asian_handicap_away_plus_35`, " #930

        query_commit += " `end_corners_asian_handicap_home_plus_4`, " #931
        query_commit += " `end_corners_asian_handicap_away_plus_4`, " #932
        query_commit += " `end_corners_asian_handicap_home_plus_45`, " #933
        query_commit += " `end_corners_asian_handicap_away_plus_45`, " #934
        query_commit += " `end_corners_asian_handicap_home_plus_5`, " #935
        query_commit += " `end_corners_asian_handicap_away_plus_5`, " #936
        query_commit += " `end_corners_asian_handicap_home_plus_55`, " #937
        query_commit += " `end_corners_asian_handicap_away_plus_55`, " #938
        query_commit += " `end_corners_asian_handicap_home_plus_6`, " #939
        query_commit += " `end_corners_asian_handicap_away_plus_6`, " #940
        query_commit += " `end_corners_asian_handicap_home_plus_65`, " #941
        query_commit += " `end_corners_asian_handicap_away_plus_65`, " #942
        query_commit += " `pre_corners_over_under_over_700`, " #943
        query_commit += " `pre_corners_over_under_under_700`, " #944
        query_commit += " `pre_corners_over_under_over_725`, " #945
        query_commit += " `pre_corners_over_under_under_725`, " #946
        query_commit += " `pre_corners_over_under_over_750`, " #947
        query_commit += " `pre_corners_over_under_under_750`, " #948
        query_commit += " `pre_corners_over_under_over_775`, " #949
        query_commit += " `pre_corners_over_under_under_775`, " #950
        query_commit += " `pre_corners_over_under_over_800`, " #951
        query_commit += " `pre_corners_over_under_under_800`, " #952
        query_commit += " `pre_corners_over_under_over_825`, " #953
        query_commit += " `pre_corners_over_under_under_825`, " #954
        query_commit += " `pre_corners_over_under_over_850`, " #955
        query_commit += " `pre_corners_over_under_under_850`, " #956
        query_commit += " `pre_corners_over_under_over_875`, " #957
        query_commit += " `pre_corners_over_under_under_875`, " #958
        query_commit += " `pre_corners_over_under_over_900`, " #959
        query_commit += " `pre_corners_over_under_under_900`, " #960
        query_commit += " `pre_corners_over_under_over_925`, " #961
        query_commit += " `pre_corners_over_under_under_925`, " #962
        query_commit += " `pre_corners_over_under_over_950`, " #963
        query_commit += " `pre_corners_over_under_under_950`, " #964
        query_commit += " `pre_corners_over_under_over_975`, " #965
        query_commit += " `pre_corners_over_under_under_975`, " #966
        query_commit += " `pre_corners_over_under_over_1000`, " #967
        query_commit += " `pre_corners_over_under_under_1000`, " #968
        query_commit += " `pre_corners_over_under_over_1025`, " #969
        query_commit += " `pre_corners_over_under_under_1025`, " #970
        query_commit += " `pre_corners_over_under_over_1050`, " #971
        query_commit += " `pre_corners_over_under_under_1050`, " #972
        query_commit += " `pre_corners_over_under_over_1075`, " #973
        query_commit += " `pre_corners_over_under_under_1075`, " #974
        query_commit += " `pre_corners_over_under_over_1100`, " #975
        query_commit += " `pre_corners_over_under_under_1100`, " #976
        query_commit += " `pre_corners_over_under_over_1125`, " #977
        query_commit += " `pre_corners_over_under_under_1125`, " #978
        query_commit += " `pre_corners_over_under_over_1150`, " #979
        query_commit += " `pre_corners_over_under_under_1150`, " #980
        query_commit += " `pre_corners_over_under_over_1175`, " #981
        query_commit += " `pre_corners_over_under_under_1175`, " #982
        query_commit += " `pre_corners_over_under_over_1200`, " #983
        query_commit += " `pre_corners_over_under_under_1200`, " #984
        query_commit += " `pre_corners_over_under_over_1225`, " #985
        query_commit += " `pre_corners_over_under_under_1225`, " #986
        query_commit += " `pre_corners_over_under_over_1250`, " #987
        query_commit += " `pre_corners_over_under_under_1250`, " #988
        query_commit += " `pre_corners_over_under_over_1275`, " #989
        query_commit += " `pre_corners_over_under_under_1275`, " #990
        query_commit += " `end_corners_over_under_over_700`, " #991
        query_commit += " `end_corners_over_under_under_700`, " #992
        query_commit += " `end_corners_over_under_over_725`, " #993
        query_commit += " `end_corners_over_under_under_725`, " #994
        query_commit += " `end_corners_over_under_over_750`, " #995
        query_commit += " `end_corners_over_under_under_750`, " #996
        query_commit += " `end_corners_over_under_over_775`, " #997
        query_commit += " `end_corners_over_under_under_775`, " #998
        query_commit += " `end_corners_over_under_over_800`, " #999
        query_commit += " `end_corners_over_under_under_800`, " #1000
        query_commit += " `end_corners_over_under_over_825`, " #1001
        query_commit += " `end_corners_over_under_under_825`, " #1002
        query_commit += " `end_corners_over_under_over_850`, " #1003
        query_commit += " `end_corners_over_under_under_850`, " #1004
        query_commit += " `end_corners_over_under_over_875`, " #1005
        query_commit += " `end_corners_over_under_under_875`, " #1006
        query_commit += " `end_corners_over_under_over_900`, " #1007
        query_commit += " `end_corners_over_under_under_900`, " #1008
        query_commit += " `end_corners_over_under_over_925`, " #1009
        query_commit += " `end_corners_over_under_under_925`, " #1010
        query_commit += " `end_corners_over_under_over_950`, " #1011
        query_commit += " `end_corners_over_under_under_950`, " #1012
        query_commit += " `end_corners_over_under_over_975`, " #1013
        query_commit += " `end_corners_over_under_under_975`, " #1014
        query_commit += " `end_corners_over_under_over_1000`, " #1015
        query_commit += " `end_corners_over_under_under_1000`, " #1016
        query_commit += " `end_corners_over_under_over_1025`, " #1017
        query_commit += " `end_corners_over_under_under_1025`, " #1018
        query_commit += " `end_corners_over_under_over_1050`, " #1019
        query_commit += " `end_corners_over_under_under_1050`, " #1020
        query_commit += " `end_corners_over_under_over_1075`, " #1021
        query_commit += " `end_corners_over_under_under_1075`, " #1022
        query_commit += " `end_corners_over_under_over_1100`, " #1023
        query_commit += " `end_corners_over_under_under_1100`, " #1024
        query_commit += " `end_corners_over_under_over_1125`, " #1025
        query_commit += " `end_corners_over_under_under_1125`, " #1026
        query_commit += " `end_corners_over_under_over_1150`, " #1027
        query_commit += " `end_corners_over_under_under_1150`, " #1028
        query_commit += " `end_corners_over_under_over_1175`, " #1029
        query_commit += " `end_corners_over_under_under_1175`, " #1030
        query_commit += " `end_corners_over_under_over_1200`, " #1031
        query_commit += " `end_corners_over_under_under_1200`, " #1032
        query_commit += " `end_corners_over_under_over_1225`, " #1033
        query_commit += " `end_corners_over_under_under_1225`, " #1034
        query_commit += " `end_corners_over_under_over_1250`, " #1035
        query_commit += " `end_corners_over_under_under_1250`, " #1036
        query_commit += " `end_corners_over_under_over_1275`, " #1037
        query_commit += " `end_corners_over_under_under_1275`, " #1038
        query_commit += " `pre_home_corners_overunder_over_25`, " #1039
        query_commit += " `pre_home_corners_overunder_under_25`, " #1040
        query_commit += " `pre_home_corners_overunder_over_35`, " #1041
        query_commit += " `pre_home_corners_overunder_under_35`, " #1042
        query_commit += " `pre_home_corners_overunder_over_45`, " #1043
        query_commit += " `pre_home_corners_overunder_under_45`, " #1044
        query_commit += " `pre_home_corners_overunder_over_55`, " #1045
        query_commit += " `pre_home_corners_overunder_under_55`, " #1046
        query_commit += " `pre_home_corners_overunder_over_65`, " #1047
        query_commit += " `pre_home_corners_overunder_under_65`, " #1048
        query_commit += " `pre_home_corners_overunder_over_75`, " #1049
        query_commit += " `pre_home_corners_overunder_under_75`, " #1050
        query_commit += " `pre_home_corners_overunder_over_85`, " #1051
        query_commit += " `pre_home_corners_overunder_under_85`, " #1052
        query_commit += " `end_home_corners_overunder_over_25`, " #1053
        query_commit += " `end_home_corners_overunder_under_25`, " #1054
        query_commit += " `end_home_corners_overunder_over_35`, " #1055
        query_commit += " `end_home_corners_overunder_under_35`, " #1056
        query_commit += " `end_home_corners_overunder_over_45`, " #1057
        query_commit += " `end_home_corners_overunder_under_45`, " #1058
        query_commit += " `end_home_corners_overunder_over_55`, " #1059
        query_commit += " `end_home_corners_overunder_under_55`, " #1060
        query_commit += " `end_home_corners_overunder_over_65`, " #1061
        query_commit += " `end_home_corners_overunder_under_65`, " #1062

        query_commit += " `end_home_corners_overunder_over_75`, " #1063
        query_commit += " `end_home_corners_overunder_under_75`, " #1064
        query_commit += " `end_home_corners_overunder_over_85`, " #1065
        query_commit += " `end_home_corners_overunder_under_85`, " #1066
        query_commit += " `pre_away_corners_overunder_over_25`, " #1067
        query_commit += " `pre_away_corners_overunder_under_25`, " #1068
        query_commit += " `pre_away_corners_overunder_over_35`, " #1069
        query_commit += " `pre_away_corners_overunder_under_35`, " #1070
        query_commit += " `pre_away_corners_overunder_over_45`, " #1071
        query_commit += " `pre_away_corners_overunder_under_45`, " #1072
        query_commit += " `pre_away_corners_overunder_over_55`, " #1073
        query_commit += " `pre_away_corners_overunder_under_55`, " #1074
        query_commit += " `pre_away_corners_overunder_over_65`, " #1075
        query_commit += " `pre_away_corners_overunder_under_65`, " #1076
        query_commit += " `pre_away_corners_overunder_over_75`, " #1077
        query_commit += " `pre_away_corners_overunder_under_75`, " #1078
        query_commit += " `pre_away_corners_overunder_over_85`, " #1079
        query_commit += " `pre_away_corners_overunder_under_85`, " #1080
        query_commit += " `end_away_corners_overunder_over_25`, " #1081
        query_commit += " `end_away_corners_overunder_under_25`, " #1082
        query_commit += " `end_away_corners_overunder_over_35`, " #1083
        query_commit += " `end_away_corners_overunder_under_35`, " #1084
        query_commit += " `end_away_corners_overunder_over_45`, " #1085
        query_commit += " `end_away_corners_overunder_under_45`, " #1086
        query_commit += " `end_away_corners_overunder_over_55`, " #1087
        query_commit += " `end_away_corners_overunder_under_55`, " #1088
        query_commit += " `end_away_corners_overunder_over_65`, " #1089
        query_commit += " `end_away_corners_overunder_under_65`, " #1090
        query_commit += " `end_away_corners_overunder_over_75`, " #1091
        query_commit += " `end_away_corners_overunder_under_75`, " #1092
        query_commit += " `end_away_corners_overunder_over_85`, " #1093
        query_commit += " `end_away_corners_overunder_under_85`, " #1094
        query_commit += " `pre_first_corner_home`, " #1095
        query_commit += " `pre_first_corner_away`, " #1096
        query_commit += " `end_first_corner_home`, " #1097
        query_commit += " `end_first_corner_away`, " #1098
        query_commit += " `pre_last_corner_home`, " #1099
        query_commit += " `pre_last_corner_away`, " #1100
        query_commit += " `end_last_corner_home`, " #1101
        query_commit += " `end_last_corner_away`, " #1102
        query_commit += " `pre_cards_asian_handicap_home_min_05`, " #1103
        query_commit += " `pre_cards_asian_handicap_away_min_05`, " #1104
        query_commit += " `pre_cards_asian_handicap_home_plus_0`, " #1105
        query_commit += " `pre_cards_asian_handicap_away_plus_0`, " #1106
        query_commit += " `pre_cards_asian_handicap_home_plus_05`, " #1107
        query_commit += " `pre_cards_asian_handicap_away_plus_05`, " #1108
        query_commit += " `end_cards_asian_handicap_home_min_05`, " #1109
        query_commit += " `end_cards_asian_handicap_away_min_05`, " #1110
        query_commit += " `end_cards_asian_handicap_home_plus_0`, " #1111
        query_commit += " `end_cards_asian_handicap_away_plus_0`, " #1112
        query_commit += " `end_cards_asian_handicap_home_plus_05`, " #1113
        query_commit += " `end_cards_asian_handicap_away_plus_05`, " #1114
        query_commit += " `pre_cards_overunder_over_25`, " #1115
        query_commit += " `pre_cards_overunder_under_25`, " #1116
        query_commit += " `pre_cards_overunder_over_35`, " #1117
        query_commit += " `pre_cards_overunder_under_35`, " #1118
        query_commit += " `pre_cards_overunder_over_45`, " #1119
        query_commit += " `pre_cards_overunder_under_45`, " #1120
        query_commit += " `pre_cards_overunder_over_55`, " #1121
        query_commit += " `pre_cards_overunder_under_55`, " #1122
        query_commit += " `pre_cards_overunder_over_65`, " #1123
        query_commit += " `pre_cards_overunder_under_65`, " #1124
        query_commit += " `pre_cards_overunder_over_75`, " #1125
        query_commit += " `pre_cards_overunder_under_75`, " #1126
        query_commit += " `end_cards_overunder_over_25`, " #1127
        query_commit += " `end_cards_overunder_under_25`, " #1128
        query_commit += " `end_cards_overunder_over_35`, " #1129
        query_commit += " `end_cards_overunder_under_35`, " #1130
        query_commit += " `end_cards_overunder_over_45`, " #1131
        query_commit += " `end_cards_overunder_under_45`, " #1132
        query_commit += " `end_cards_overunder_over_55`, " #1133
        query_commit += " `end_cards_overunder_under_55`, " #1134
        query_commit += " `end_cards_overunder_over_65`, " #1135
        query_commit += " `end_cards_overunder_under_65`, " #1136
        query_commit += " `end_cards_overunder_over_75`, " #1137
        query_commit += " `end_cards_overunder_under_75`, " #1138
        query_commit += " `pre_home_team_total_cards_over_15`, " #1139
        query_commit += " `pre_home_team_total_cards_under_15`, " #1140
        query_commit += " `pre_home_team_total_cards_over_25`, " #1141
        query_commit += " `pre_home_team_total_cards_under_25`, " #1142
        query_commit += " `pre_home_team_total_cards_over_35`, " #1143
        query_commit += " `pre_home_team_total_cards_under_35`, " #1144
        query_commit += " `end_home_team_total_cards_over_15`, " #1145
        query_commit += " `end_home_team_total_cards_under_15`, " #1146
        query_commit += " `end_home_team_total_cards_over_25`, " #1147
        query_commit += " `end_home_team_total_cards_under_25`, " #1148
        query_commit += " `end_home_team_total_cards_over_35`, " #1149
        query_commit += " `end_home_team_total_cards_under_35`, " #1150
        query_commit += " `pre_away_team_total_cards_over_15`, " #1151
        query_commit += " `pre_away_team_total_cards_under_15`, " #1152
        query_commit += " `pre_away_team_total_cards_over_25`, " #1153
        query_commit += " `pre_away_team_total_cards_under_25`, " #1154
        query_commit += " `pre_away_team_total_cards_over_35`, " #1155
        query_commit += " `pre_away_team_total_cards_under_35`, " #1156
        query_commit += " `end_away_team_total_cards_over_15`, " #1157
        query_commit += " `end_away_team_total_cards_under_15`, " #1158
        query_commit += " `end_away_team_total_cards_over_25`, " #1159
        query_commit += " `end_away_team_total_cards_under_25`, " #1160
        query_commit += " `end_away_team_total_cards_over_35`, " #1161
        query_commit += " `end_away_team_total_cards_under_35`, " #1162
        query_commit += " `pre_total_goals_under_2`, " #1163
        query_commit += " `pre_total_goals_2_or_3`, " #1164
        query_commit += " `pre_total_goals_over_3`, " #1165
        query_commit += " `end_total_goals_under_2`, " #1166
        query_commit += " `end_total_goals_2_or_3`, " #1167
        query_commit += " `end_total_goals_over_3`, " #1168
        query_commit += " `pre_first_goal_method_shot`, " #1169
        query_commit += " `pre_first_goal_method_header`, " #1170
        query_commit += " `pre_first_goal_method_penalty`, " #1171
        query_commit += " `pre_first_goal_method_freekick`, " #1172
        query_commit += " `pre_first_goal_method_owngoal`, " #1173
        query_commit += " `pre_first_goal_method_draw`, " #1174
        query_commit += " `end_first_goal_method_shot`, " #1175
        query_commit += " `end_first_goal_method_header`, " #1176
        query_commit += " `end_first_goal_method_penalty`, " #1177
        query_commit += " `end_first_goal_method_freekick`, " #1178
        query_commit += " `end_first_goal_method_owngoal`, " #1179
        query_commit += " `end_first_goal_method_draw`, " #1180
        query_commit += " `pre_to_score_a_penalty_home`, " #1181
        query_commit += " `pre_to_score_a_penalty_away`, " #1182
        query_commit += " `end_to_score_a_penalty_home`, " #1183
        query_commit += " `end_to_score_a_penalty_away`, " #1184
        query_commit += " `pre_to_miss_a_penalty_home`, " #1185
        query_commit += " `pre_to_miss_a_penalty_away`, " #1186
        query_commit += " `end_to_miss_a_penalty_home`, " #1187
        query_commit += " `end_to_miss_a_penalty_away`, " #1188
        query_commit += " `pre_anytime_goal_scorer`, " #1189
        query_commit += " `end_anytime_goal_scorer`, " #1190
        query_commit += " `pre_first_goal_scorer`, " #1191
        query_commit += " `end_first_goal_scorer`, " #1192
        query_commit += " `pre_last_goal_scorer`, " #1193
        query_commit += " `end_last_goal_scorer`, " #1194
        query_commit += " `pre_to_score_two_or_more_goals`, " #1195
        query_commit += " `end_to_score_two_or_more_goals`, " #1196
        query_commit += " `pre_last_goal_scorer2`, " #1197
        query_commit += " `end_last_goal_scorer2`, " #1198
        query_commit += " `pre_exact_score`, " #1199

        query_commit += " `end_exact_score`, " #1200
        query_commit += " `pre_player_to_be_booked`, " #1201
        query_commit += " `end_player_to_be_booked`, " #1202
        query_commit += " `pre_ah_pattern`, " #1203
        query_commit += " `pre_ah_pattern_mirror`, " #1204
        query_commit += " `pre_gou_pattern`, " #1205
        query_commit += " `end_ah_pattern`, " #1206
        query_commit += " `end_ah_pattern_mirror`, " #1207
        query_commit += " `end_gou_pattern`, " #1208
        query_commit += " `pre_response`, " #1209
        query_commit += " `end_response`, " #1210
        query_commit += " `pre_odd_updated_at`, " #1211
        query_commit += " `end_odd_updated_at`, " #1212
        query_commit += " `pre_ah_pattern_4`, " #1213
        query_commit += " `pre_ah_pattern_mirror_4`, " #1214
        query_commit += " `pre_gou_pattern_4`, " #1215
        query_commit += " `end_ah_pattern_4`, " #1216
        query_commit += " `end_ah_pattern_mirror_4`, " #1217
        query_commit += " `end_gou_pattern_4`, " #1218
        query_commit += " `special_odds` " #1219
        query_commit += " ) VALUES ( "
        # --------------------------------------------------  
    elif(total_rows == 1):
        # --------------------------------------------------   
        host="localhost"
        user="root" 
        database="pr_mmbuzz_2022_06"
        mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
        mycursor = mydb.cursor()
        # --------------------------------------------------   
        query_commit = "update football_odds set  "  
        query_commit += " pre_match_winner_home = '"+pre_match_winner_home+"', " #1
        query_commit += " pre_match_winner_draw = '"+pre_match_winner_draw+"', " #2
        query_commit += " pre_match_winner_away = '"+pre_match_winner_away+"', " #3
        query_commit += " end_match_winner_home = '"+end_match_winner_home+"', " #4
        query_commit += " end_match_winner_draw = '"+end_match_winner_draw+"', " #5
        query_commit += " end_match_winner_away = '"+end_match_winner_away+"', " #6
        query_commit += " pre_homeaway_home = '"+pre_homeaway_home+"', " #7
        query_commit += " pre_homeaway_away = '"+pre_homeaway_away+"', " #8
        query_commit += " end_homeaway_home = '"+end_homeaway_home+"', " #9
        query_commit += " end_homeaway_away = '"+end_homeaway_away+"', " #10
        query_commit += " pre_first_half_winner_home = '"+pre_first_half_winner_home+"', " #11
        query_commit += " pre_first_half_winner_draw = '"+pre_first_half_winner_draw+"', " #12
        query_commit += " pre_first_half_winner_away = '"+pre_first_half_winner_away+"', " #13
        query_commit += " end_first_half_winner_home = '"+end_first_half_winner_home+"', " #14
        query_commit += " end_first_half_winner_draw = '"+end_first_half_winner_draw+"', " #15
        query_commit += " end_first_half_winner_away = '"+end_first_half_winner_away+"', " #16
        query_commit += " pre_second_half_winner_home = '"+pre_second_half_winner_home+"', " #17
        query_commit += " pre_second_half_winner_draw = '"+pre_second_half_winner_draw+"', " #18
        query_commit += " pre_second_half_winner_away = '"+pre_second_half_winner_away+"', " #19
        query_commit += " end_second_half_winner_home = '"+end_second_half_winner_home+"', " #20
        query_commit += " end_second_half_winner_draw = '"+end_second_half_winner_draw+"', " #21
        query_commit += " end_second_half_winner_away = '"+end_second_half_winner_away+"', " #22
        query_commit += " pre_asian_handicap_home_min_675 = '"+pre_asian_handicap_home_min_675+"', " #23
        query_commit += " pre_asian_handicap_away_min_675 = '"+pre_asian_handicap_away_min_675+"', " #24
        query_commit += " pre_asian_handicap_home_min_65 = '"+pre_asian_handicap_home_min_65+"', " #25
        query_commit += " pre_asian_handicap_away_min_65 = '"+pre_asian_handicap_away_min_65+"', " #26
        query_commit += " pre_asian_handicap_home_min_625 = '"+pre_asian_handicap_home_min_625+"', " #27
        query_commit += " pre_asian_handicap_away_min_625 = '"+pre_asian_handicap_away_min_625+"', " #28
        query_commit += " pre_asian_handicap_home_min_6 = '"+pre_asian_handicap_home_min_6+"', " #29
        query_commit += " pre_asian_handicap_away_min_6 = '"+pre_asian_handicap_away_min_6+"', " #30
        query_commit += " pre_asian_handicap_home_min_575 = '"+pre_asian_handicap_home_min_575+"', " #31
        query_commit += " pre_asian_handicap_away_min_575 = '"+pre_asian_handicap_away_min_575+"', " #32
        query_commit += " pre_asian_handicap_home_min_55 = '"+pre_asian_handicap_home_min_55+"', " #33
        query_commit += " pre_asian_handicap_away_min_55 = '"+pre_asian_handicap_away_min_55+"', " #34
        query_commit += " pre_asian_handicap_home_min_525 = '"+pre_asian_handicap_home_min_525+"', " #35
        query_commit += " pre_asian_handicap_away_min_525 = '"+pre_asian_handicap_away_min_525+"', " #36
        query_commit += " pre_asian_handicap_home_min_5 = '"+pre_asian_handicap_home_min_5+"', " #37
        query_commit += " pre_asian_handicap_away_min_5 = '"+pre_asian_handicap_away_min_5+"', " #38
        query_commit += " pre_asian_handicap_home_min_475 = '"+pre_asian_handicap_home_min_475+"', " #39
        query_commit += " pre_asian_handicap_away_min_475 = '"+pre_asian_handicap_away_min_475+"', " #40
        query_commit += " pre_asian_handicap_home_min_45 = '"+pre_asian_handicap_home_min_45+"', " #41
        query_commit += " pre_asian_handicap_away_min_45 = '"+pre_asian_handicap_away_min_45+"', " #42
        query_commit += " pre_asian_handicap_home_min_425 = '"+pre_asian_handicap_home_min_425+"', " #43
        query_commit += " pre_asian_handicap_away_min_425 = '"+pre_asian_handicap_away_min_425+"', " #44
        query_commit += " pre_asian_handicap_home_min_4 = '"+pre_asian_handicap_home_min_4+"', " #45
        query_commit += " pre_asian_handicap_away_min_4 = '"+pre_asian_handicap_away_min_4+"', " #46
        query_commit += " pre_asian_handicap_home_min_375 = '"+pre_asian_handicap_home_min_375+"', " #47
        query_commit += " pre_asian_handicap_away_min_375 = '"+pre_asian_handicap_away_min_375+"', " #48
        query_commit += " pre_asian_handicap_home_min_35 = '"+pre_asian_handicap_home_min_35+"', " #49
        query_commit += " pre_asian_handicap_away_min_35 = '"+pre_asian_handicap_away_min_35+"', " #50
        query_commit += " pre_asian_handicap_home_min_325 = '"+pre_asian_handicap_home_min_325+"', " #51
        query_commit += " pre_asian_handicap_away_min_325 = '"+pre_asian_handicap_away_min_325+"', " #52
        query_commit += " pre_asian_handicap_home_min_3 = '"+pre_asian_handicap_home_min_3+"', " #53
        query_commit += " pre_asian_handicap_away_min_3 = '"+pre_asian_handicap_away_min_3+"', " #54
        query_commit += " pre_asian_handicap_home_min_275 = '"+pre_asian_handicap_home_min_275+"', " #55
        query_commit += " pre_asian_handicap_away_min_275 = '"+pre_asian_handicap_away_min_275+"', " #56
        query_commit += " pre_asian_handicap_home_min_25 = '"+pre_asian_handicap_home_min_25+"', " #57
        query_commit += " pre_asian_handicap_away_min_25 = '"+pre_asian_handicap_away_min_25+"', " #58
        query_commit += " pre_asian_handicap_home_min_225 = '"+pre_asian_handicap_home_min_225+"', " #59
        query_commit += " pre_asian_handicap_away_min_225 = '"+pre_asian_handicap_away_min_225+"', " #60
        query_commit += " pre_asian_handicap_home_min_2 = '"+pre_asian_handicap_home_min_2+"', " #61
        query_commit += " pre_asian_handicap_away_min_2 = '"+pre_asian_handicap_away_min_2+"', " #62
        query_commit += " pre_asian_handicap_home_min_175 = '"+pre_asian_handicap_home_min_175+"', " #63
        query_commit += " pre_asian_handicap_away_min_175 = '"+pre_asian_handicap_away_min_175+"', " #64
        query_commit += " pre_asian_handicap_home_min_15 = '"+pre_asian_handicap_home_min_15+"', " #65
        query_commit += " pre_asian_handicap_away_min_15 = '"+pre_asian_handicap_away_min_15+"', " #66
        query_commit += " pre_asian_handicap_home_min_125 = '"+pre_asian_handicap_home_min_125+"', " #67
        query_commit += " pre_asian_handicap_away_min_125 = '"+pre_asian_handicap_away_min_125+"', " #68
        query_commit += " pre_asian_handicap_home_min_1 = '"+pre_asian_handicap_home_min_1+"', " #69
        query_commit += " pre_asian_handicap_away_min_1 = '"+pre_asian_handicap_away_min_1+"', " #70
        query_commit += " pre_asian_handicap_home_min_075 = '"+pre_asian_handicap_home_min_075+"', " #71
        query_commit += " pre_asian_handicap_away_min_075 = '"+pre_asian_handicap_away_min_075+"', " #72
        query_commit += " pre_asian_handicap_home_min_05 = '"+pre_asian_handicap_home_min_05+"', " #73
        query_commit += " pre_asian_handicap_away_min_05 = '"+pre_asian_handicap_away_min_05+"', " #74
        query_commit += " pre_asian_handicap_home_min_025 = '"+pre_asian_handicap_home_min_025+"', " #75
        query_commit += " pre_asian_handicap_away_min_025 = '"+pre_asian_handicap_away_min_025+"', " #76
        query_commit += " pre_asian_handicap_home_plus_0 = '"+pre_asian_handicap_home_plus_0+"', " #77
        query_commit += " pre_asian_handicap_away_plus_0 = '"+pre_asian_handicap_away_plus_0+"', " #78
        query_commit += " pre_asian_handicap_home_plus_025 = '"+pre_asian_handicap_home_plus_025+"', " #79
        query_commit += " pre_asian_handicap_away_plus_025 = '"+pre_asian_handicap_away_plus_025+"', " #80
        query_commit += " pre_asian_handicap_home_plus_05 = '"+pre_asian_handicap_home_plus_05+"', " #81
        query_commit += " pre_asian_handicap_away_plus_05 = '"+pre_asian_handicap_away_plus_05+"', " #82
        query_commit += " pre_asian_handicap_home_plus_075 = '"+pre_asian_handicap_home_plus_075+"', " #83
        query_commit += " pre_asian_handicap_away_plus_075 = '"+pre_asian_handicap_away_plus_075+"', " #84
        query_commit += " pre_asian_handicap_home_plus_1 = '"+pre_asian_handicap_home_plus_1+"', " #85
        query_commit += " pre_asian_handicap_away_plus_1 = '"+pre_asian_handicap_away_plus_1+"', " #86
        query_commit += " pre_asian_handicap_home_plus_125 = '"+pre_asian_handicap_home_plus_125+"', " #87
        query_commit += " pre_asian_handicap_away_plus_125 = '"+pre_asian_handicap_away_plus_125+"', " #88
        query_commit += " pre_asian_handicap_home_plus_15 = '"+pre_asian_handicap_home_plus_15+"', " #89

        query_commit += " pre_asian_handicap_away_plus_15 = '"+pre_asian_handicap_away_plus_15+"', " #90
        query_commit += " pre_asian_handicap_home_plus_175 = '"+pre_asian_handicap_home_plus_175+"', " #91
        query_commit += " pre_asian_handicap_away_plus_175 = '"+pre_asian_handicap_away_plus_175+"', " #92
        query_commit += " pre_asian_handicap_home_plus_2 = '"+pre_asian_handicap_home_plus_2+"', " #93
        query_commit += " pre_asian_handicap_away_plus_2 = '"+pre_asian_handicap_away_plus_2+"', " #94
        query_commit += " pre_asian_handicap_home_plus_225 = '"+pre_asian_handicap_home_plus_225+"', " #95
        query_commit += " pre_asian_handicap_away_plus_225 = '"+pre_asian_handicap_away_plus_225+"', " #96
        query_commit += " pre_asian_handicap_home_plus_25 = '"+pre_asian_handicap_home_plus_25+"', " #97
        query_commit += " pre_asian_handicap_away_plus_25 = '"+pre_asian_handicap_away_plus_25+"', " #98
        query_commit += " pre_asian_handicap_home_plus_275 = '"+pre_asian_handicap_home_plus_275+"', " #99
        query_commit += " pre_asian_handicap_away_plus_275 = '"+pre_asian_handicap_away_plus_275+"', " #100
        query_commit += " pre_asian_handicap_home_plus_3 = '"+pre_asian_handicap_home_plus_3+"', " #101
        query_commit += " pre_asian_handicap_away_plus_3 = '"+pre_asian_handicap_away_plus_3+"', " #102
        query_commit += " pre_asian_handicap_home_plus_325 = '"+pre_asian_handicap_home_plus_325+"', " #103
        query_commit += " pre_asian_handicap_away_plus_325 = '"+pre_asian_handicap_away_plus_325+"', " #104
        query_commit += " pre_asian_handicap_home_plus_35 = '"+pre_asian_handicap_home_plus_35+"', " #105
        query_commit += " pre_asian_handicap_away_plus_35 = '"+pre_asian_handicap_away_plus_35+"', " #106
        query_commit += " pre_asian_handicap_home_plus_375 = '"+pre_asian_handicap_home_plus_375+"', " #107
        query_commit += " pre_asian_handicap_away_plus_375 = '"+pre_asian_handicap_away_plus_375+"', " #108
        query_commit += " pre_asian_handicap_home_plus_4 = '"+pre_asian_handicap_home_plus_4+"', " #109
        query_commit += " pre_asian_handicap_away_plus_4 = '"+pre_asian_handicap_away_plus_4+"', " #110
        query_commit += " pre_asian_handicap_home_plus_425 = '"+pre_asian_handicap_home_plus_425+"', " #111
        query_commit += " pre_asian_handicap_away_plus_425 = '"+pre_asian_handicap_away_plus_425+"', " #112
        query_commit += " pre_asian_handicap_home_plus_45 = '"+pre_asian_handicap_home_plus_45+"', " #113
        query_commit += " pre_asian_handicap_away_plus_45 = '"+pre_asian_handicap_away_plus_45+"', " #114
        query_commit += " pre_asian_handicap_home_plus_475 = '"+pre_asian_handicap_home_plus_475+"', " #115
        query_commit += " pre_asian_handicap_away_plus_475 = '"+pre_asian_handicap_away_plus_475+"', " #116
        query_commit += " pre_asian_handicap_home_plus_5 = '"+pre_asian_handicap_home_plus_5+"', " #117
        query_commit += " pre_asian_handicap_away_plus_5 = '"+pre_asian_handicap_away_plus_5+"', " #118
        query_commit += " pre_asian_handicap_home_plus_525 = '"+pre_asian_handicap_home_plus_525+"', " #119
        query_commit += " pre_asian_handicap_away_plus_525 = '"+pre_asian_handicap_away_plus_525+"', " #120
        query_commit += " pre_asian_handicap_home_plus_55 = '"+pre_asian_handicap_home_plus_55+"', " #121
        query_commit += " pre_asian_handicap_away_plus_55 = '"+pre_asian_handicap_away_plus_55+"', " #122
        query_commit += " pre_asian_handicap_home_plus_575 = '"+pre_asian_handicap_home_plus_575+"', " #123
        query_commit += " pre_asian_handicap_away_plus_575 = '"+pre_asian_handicap_away_plus_575+"', " #124
        query_commit += " pre_asian_handicap_home_plus_6 = '"+pre_asian_handicap_home_plus_6+"', " #125
        query_commit += " pre_asian_handicap_away_plus_6 = '"+pre_asian_handicap_away_plus_6+"', " #126
        query_commit += " pre_asian_handicap_home_plus_625 = '"+pre_asian_handicap_home_plus_625+"', " #127
        query_commit += " pre_asian_handicap_away_plus_625 = '"+pre_asian_handicap_away_plus_625+"', " #128
        query_commit += " pre_asian_handicap_home_plus_65 = '"+pre_asian_handicap_home_plus_65+"', " #129
        query_commit += " pre_asian_handicap_away_plus_65 = '"+pre_asian_handicap_away_plus_65+"', " #130
        query_commit += " pre_asian_handicap_home_plus_675 = '"+pre_asian_handicap_home_plus_675+"', " #131
        query_commit += " pre_asian_handicap_away_plus_675 = '"+pre_asian_handicap_away_plus_675+"', " #132
        query_commit += " end_asian_handicap_home_min_675 = '"+end_asian_handicap_home_min_675+"', " #133
        query_commit += " end_asian_handicap_away_min_675 = '"+end_asian_handicap_away_min_675+"', " #134
        query_commit += " end_asian_handicap_home_min_65 = '"+end_asian_handicap_home_min_65+"', " #135
        query_commit += " end_asian_handicap_away_min_65 = '"+end_asian_handicap_away_min_65+"', " #136
        query_commit += " end_asian_handicap_home_min_625 = '"+end_asian_handicap_home_min_625+"', " #137
        query_commit += " end_asian_handicap_away_min_625 = '"+end_asian_handicap_away_min_625+"', " #138
        query_commit += " end_asian_handicap_home_min_6 = '"+end_asian_handicap_home_min_6+"', " #139
        query_commit += " end_asian_handicap_away_min_6 = '"+end_asian_handicap_away_min_6+"', " #140
        query_commit += " end_asian_handicap_home_min_575 = '"+end_asian_handicap_home_min_575+"', " #141
        query_commit += " end_asian_handicap_away_min_575 = '"+end_asian_handicap_away_min_575+"', " #142
        query_commit += " end_asian_handicap_home_min_55 = '"+end_asian_handicap_home_min_55+"', " #143
        query_commit += " end_asian_handicap_away_min_55 = '"+end_asian_handicap_away_min_55+"', " #144
        query_commit += " end_asian_handicap_home_min_525 = '"+end_asian_handicap_home_min_525+"', " #145
        query_commit += " end_asian_handicap_away_min_525 = '"+end_asian_handicap_away_min_525+"', " #146
        query_commit += " end_asian_handicap_home_min_5 = '"+end_asian_handicap_home_min_5+"', " #147
        query_commit += " end_asian_handicap_away_min_5 = '"+end_asian_handicap_away_min_5+"', " #148
        query_commit += " end_asian_handicap_home_min_475 = '"+end_asian_handicap_home_min_475+"', " #149
        query_commit += " end_asian_handicap_away_min_475 = '"+end_asian_handicap_away_min_475+"', " #150
        query_commit += " end_asian_handicap_home_min_45 = '"+end_asian_handicap_home_min_45+"', " #151
        query_commit += " end_asian_handicap_away_min_45 = '"+end_asian_handicap_away_min_45+"', " #152
        query_commit += " end_asian_handicap_home_min_425 = '"+end_asian_handicap_home_min_425+"', " #153
        query_commit += " end_asian_handicap_away_min_425 = '"+end_asian_handicap_away_min_425+"', " #154
        query_commit += " end_asian_handicap_home_min_4 = '"+end_asian_handicap_home_min_4+"', " #155
        query_commit += " end_asian_handicap_away_min_4 = '"+end_asian_handicap_away_min_4+"', " #156
        query_commit += " end_asian_handicap_home_min_375 = '"+end_asian_handicap_home_min_375+"', " #157
        query_commit += " end_asian_handicap_away_min_375 = '"+end_asian_handicap_away_min_375+"', " #158
        query_commit += " end_asian_handicap_home_min_35 = '"+end_asian_handicap_home_min_35+"', " #159
        query_commit += " end_asian_handicap_away_min_35 = '"+end_asian_handicap_away_min_35+"', " #160
        query_commit += " end_asian_handicap_home_min_325 = '"+end_asian_handicap_home_min_325+"', " #161
        query_commit += " end_asian_handicap_away_min_325 = '"+end_asian_handicap_away_min_325+"', " #162
        query_commit += " end_asian_handicap_home_min_3 = '"+end_asian_handicap_home_min_3+"', " #163
        query_commit += " end_asian_handicap_away_min_3 = '"+end_asian_handicap_away_min_3+"', " #164
        query_commit += " end_asian_handicap_home_min_275 = '"+end_asian_handicap_home_min_275+"', " #165
        query_commit += " end_asian_handicap_away_min_275 = '"+end_asian_handicap_away_min_275+"', " #166
        query_commit += " end_asian_handicap_home_min_25 = '"+end_asian_handicap_home_min_25+"', " #167
        query_commit += " end_asian_handicap_away_min_25 = '"+end_asian_handicap_away_min_25+"', " #168
        query_commit += " end_asian_handicap_home_min_225 = '"+end_asian_handicap_home_min_225+"', " #169
        query_commit += " end_asian_handicap_away_min_225 = '"+end_asian_handicap_away_min_225+"', " #170
        query_commit += " end_asian_handicap_home_min_2 = '"+end_asian_handicap_home_min_2+"', " #171
        query_commit += " end_asian_handicap_away_min_2 = '"+end_asian_handicap_away_min_2+"', " #172
        query_commit += " end_asian_handicap_home_min_175 = '"+end_asian_handicap_home_min_175+"', " #173
        query_commit += " end_asian_handicap_away_min_175 = '"+end_asian_handicap_away_min_175+"', " #174

        query_commit += " end_asian_handicap_home_min_15 = '"+end_asian_handicap_home_min_15+"', " #175
        query_commit += " end_asian_handicap_away_min_15 = '"+end_asian_handicap_away_min_15+"', " #176
        query_commit += " end_asian_handicap_home_min_125 = '"+end_asian_handicap_home_min_125+"', " #177
        query_commit += " end_asian_handicap_away_min_125 = '"+end_asian_handicap_away_min_125+"', " #178
        query_commit += " end_asian_handicap_home_min_1 = '"+end_asian_handicap_home_min_1+"', " #179
        query_commit += " end_asian_handicap_away_min_1 = '"+end_asian_handicap_away_min_1+"', " #180
        query_commit += " end_asian_handicap_home_min_075 = '"+end_asian_handicap_home_min_075+"', " #181
        query_commit += " end_asian_handicap_away_min_075 = '"+end_asian_handicap_away_min_075+"', " #182
        query_commit += " end_asian_handicap_home_min_05 = '"+end_asian_handicap_home_min_05+"', " #183
        query_commit += " end_asian_handicap_away_min_05 = '"+end_asian_handicap_away_min_05+"', " #184
        query_commit += " end_asian_handicap_home_min_025 = '"+end_asian_handicap_home_min_025+"', " #185
        query_commit += " end_asian_handicap_away_min_025 = '"+end_asian_handicap_away_min_025+"', " #186
        query_commit += " end_asian_handicap_home_plus_0 = '"+end_asian_handicap_home_plus_0+"', " #187
        query_commit += " end_asian_handicap_away_plus_0 = '"+end_asian_handicap_away_plus_0+"', " #188
        query_commit += " end_asian_handicap_home_plus_025 = '"+end_asian_handicap_home_plus_025+"', " #189
        query_commit += " end_asian_handicap_away_plus_025 = '"+end_asian_handicap_away_plus_025+"', " #190
        query_commit += " end_asian_handicap_home_plus_05 = '"+end_asian_handicap_home_plus_05+"', " #191
        query_commit += " end_asian_handicap_away_plus_05 = '"+end_asian_handicap_away_plus_05+"', " #192
        query_commit += " end_asian_handicap_home_plus_075 = '"+end_asian_handicap_home_plus_075+"', " #193
        query_commit += " end_asian_handicap_away_plus_075 = '"+end_asian_handicap_away_plus_075+"', " #194
        query_commit += " end_asian_handicap_home_plus_1 = '"+end_asian_handicap_home_plus_1+"', " #195
        query_commit += " end_asian_handicap_away_plus_1 = '"+end_asian_handicap_away_plus_1+"', " #196
        query_commit += " end_asian_handicap_home_plus_125 = '"+end_asian_handicap_home_plus_125+"', " #197
        query_commit += " end_asian_handicap_away_plus_125 = '"+end_asian_handicap_away_plus_125+"', " #198
        query_commit += " end_asian_handicap_home_plus_15 = '"+end_asian_handicap_home_plus_15+"', " #199
        query_commit += " end_asian_handicap_away_plus_15 = '"+end_asian_handicap_away_plus_15+"', " #200
        query_commit += " end_asian_handicap_home_plus_175 = '"+end_asian_handicap_home_plus_175+"', " #201
        query_commit += " end_asian_handicap_away_plus_175 = '"+end_asian_handicap_away_plus_175+"', " #202
        query_commit += " end_asian_handicap_home_plus_2 = '"+end_asian_handicap_home_plus_2+"', " #203
        query_commit += " end_asian_handicap_away_plus_2 = '"+end_asian_handicap_away_plus_2+"', " #204
        query_commit += " end_asian_handicap_home_plus_225 = '"+end_asian_handicap_home_plus_225+"', " #205
        query_commit += " end_asian_handicap_away_plus_225 = '"+end_asian_handicap_away_plus_225+"', " #206
        query_commit += " end_asian_handicap_home_plus_25 = '"+end_asian_handicap_home_plus_25+"', " #207
        query_commit += " end_asian_handicap_away_plus_25 = '"+end_asian_handicap_away_plus_25+"', " #208
        query_commit += " end_asian_handicap_home_plus_275 = '"+end_asian_handicap_home_plus_275+"', " #209
        query_commit += " end_asian_handicap_away_plus_275 = '"+end_asian_handicap_away_plus_275+"', " #210
        query_commit += " end_asian_handicap_home_plus_3 = '"+end_asian_handicap_home_plus_3+"', " #211
        query_commit += " end_asian_handicap_away_plus_3 = '"+end_asian_handicap_away_plus_3+"', " #212
        query_commit += " end_asian_handicap_home_plus_325 = '"+end_asian_handicap_home_plus_325+"', " #213
        query_commit += " end_asian_handicap_away_plus_325 = '"+end_asian_handicap_away_plus_325+"', " #214
        query_commit += " end_asian_handicap_home_plus_35 = '"+end_asian_handicap_home_plus_35+"', " #215
        query_commit += " end_asian_handicap_away_plus_35 = '"+end_asian_handicap_away_plus_35+"', " #216
        query_commit += " end_asian_handicap_home_plus_375 = '"+end_asian_handicap_home_plus_375+"', " #217
        query_commit += " end_asian_handicap_away_plus_375 = '"+end_asian_handicap_away_plus_375+"', " #218
        query_commit += " end_asian_handicap_home_plus_4 = '"+end_asian_handicap_home_plus_4+"', " #219
        query_commit += " end_asian_handicap_away_plus_4 = '"+end_asian_handicap_away_plus_4+"', " #220
        query_commit += " end_asian_handicap_home_plus_425 = '"+end_asian_handicap_home_plus_425+"', " #221
        query_commit += " end_asian_handicap_away_plus_425 = '"+end_asian_handicap_away_plus_425+"', " #222
        query_commit += " end_asian_handicap_home_plus_45 = '"+end_asian_handicap_home_plus_45+"', " #223
        query_commit += " end_asian_handicap_away_plus_45 = '"+end_asian_handicap_away_plus_45+"', " #224
        query_commit += " end_asian_handicap_home_plus_475 = '"+end_asian_handicap_home_plus_475+"', " #225
        query_commit += " end_asian_handicap_away_plus_475 = '"+end_asian_handicap_away_plus_475+"', " #226
        query_commit += " end_asian_handicap_home_plus_5 = '"+end_asian_handicap_home_plus_5+"', " #227
        query_commit += " end_asian_handicap_away_plus_5 = '"+end_asian_handicap_away_plus_5+"', " #228
        query_commit += " end_asian_handicap_home_plus_525 = '"+end_asian_handicap_home_plus_525+"', " #229
        query_commit += " end_asian_handicap_away_plus_525 = '"+end_asian_handicap_away_plus_525+"', " #230
        query_commit += " end_asian_handicap_home_plus_55 = '"+end_asian_handicap_home_plus_55+"', " #231
        query_commit += " end_asian_handicap_away_plus_55 = '"+end_asian_handicap_away_plus_55+"', " #232
        query_commit += " end_asian_handicap_home_plus_575 = '"+end_asian_handicap_home_plus_575+"', " #233
        query_commit += " end_asian_handicap_away_plus_575 = '"+end_asian_handicap_away_plus_575+"', " #234
        query_commit += " end_asian_handicap_home_plus_6 = '"+end_asian_handicap_home_plus_6+"', " #235
        query_commit += " end_asian_handicap_away_plus_6 = '"+end_asian_handicap_away_plus_6+"', " #236
        query_commit += " end_asian_handicap_home_plus_625 = '"+end_asian_handicap_home_plus_625+"', " #237
        query_commit += " end_asian_handicap_away_plus_625 = '"+end_asian_handicap_away_plus_625+"', " #238
        query_commit += " end_asian_handicap_home_plus_65 = '"+end_asian_handicap_home_plus_65+"', " #239
        query_commit += " end_asian_handicap_away_plus_65 = '"+end_asian_handicap_away_plus_65+"', " #240
        query_commit += " end_asian_handicap_home_plus_675 = '"+end_asian_handicap_home_plus_675+"', " #241
        query_commit += " end_asian_handicap_away_plus_675 = '"+end_asian_handicap_away_plus_675+"', " #242
        query_commit += " pre_goals_overunder_over_05 = '"+pre_goals_overunder_over_05+"', " #243
        query_commit += " pre_goals_overunder_under_05 = '"+pre_goals_overunder_under_05+"', " #244
        query_commit += " pre_goals_overunder_over_075 = '"+pre_goals_overunder_over_075+"', " #245
        query_commit += " pre_goals_overunder_under_075 = '"+pre_goals_overunder_under_075+"', " #246
        query_commit += " pre_goals_overunder_over_10 = '"+pre_goals_overunder_over_10+"', " #247
        query_commit += " pre_goals_overunder_under_10 = '"+pre_goals_overunder_under_10+"', " #248
        query_commit += " pre_goals_overunder_over_125 = '"+pre_goals_overunder_over_125+"', " #249
        query_commit += " pre_goals_overunder_under_125 = '"+pre_goals_overunder_under_125+"', " #250
        query_commit += " pre_goals_overunder_over_15 = '"+pre_goals_overunder_over_15+"', " #251
        query_commit += " pre_goals_overunder_under_15 = '"+pre_goals_overunder_under_15+"', " #252
        query_commit += " pre_goals_overunder_over_175 = '"+pre_goals_overunder_over_175+"', " #253
        query_commit += " pre_goals_overunder_under_175 = '"+pre_goals_overunder_under_175+"', " #254
        query_commit += " pre_goals_overunder_over_20 = '"+pre_goals_overunder_over_20+"', " #255
        query_commit += " pre_goals_overunder_under_20 = '"+pre_goals_overunder_under_20+"', " #256
        query_commit += " pre_goals_overunder_over_225 = '"+pre_goals_overunder_over_225+"', " #257
        query_commit += " pre_goals_overunder_under_225 = '"+pre_goals_overunder_under_225+"', " #258
        query_commit += " pre_goals_overunder_over_25 = '"+pre_goals_overunder_over_25+"', " #259

        query_commit += " pre_goals_overunder_under_25 = '"+pre_goals_overunder_under_25+"', " #260
        query_commit += " pre_goals_overunder_over_275 = '"+pre_goals_overunder_over_275+"', " #261
        query_commit += " pre_goals_overunder_under_275 = '"+pre_goals_overunder_under_275+"', " #262
        query_commit += " pre_goals_overunder_over_30 = '"+pre_goals_overunder_over_30+"', " #263
        query_commit += " pre_goals_overunder_under_30 = '"+pre_goals_overunder_under_30+"', " #264
        query_commit += " pre_goals_overunder_over_325 = '"+pre_goals_overunder_over_325+"', " #265
        query_commit += " pre_goals_overunder_under_325 = '"+pre_goals_overunder_under_325+"', " #266
        query_commit += " pre_goals_overunder_over_35 = '"+pre_goals_overunder_over_35+"', " #267
        query_commit += " pre_goals_overunder_under_35 = '"+pre_goals_overunder_under_35+"', " #268
        query_commit += " pre_goals_overunder_over_375 = '"+pre_goals_overunder_over_375+"', " #269
        query_commit += " pre_goals_overunder_under_375 = '"+pre_goals_overunder_under_375+"', " #270
        query_commit += " pre_goals_overunder_over_40 = '"+pre_goals_overunder_over_40+"', " #271
        query_commit += " pre_goals_overunder_under_40 = '"+pre_goals_overunder_under_40+"', " #272
        query_commit += " pre_goals_overunder_over_425 = '"+pre_goals_overunder_over_425+"', " #273
        query_commit += " pre_goals_overunder_under_425 = '"+pre_goals_overunder_under_425+"', " #274
        query_commit += " pre_goals_overunder_over_45 = '"+pre_goals_overunder_over_45+"', " #275
        query_commit += " pre_goals_overunder_under_45 = '"+pre_goals_overunder_under_45+"', " #276
        query_commit += " pre_goals_overunder_over_475 = '"+pre_goals_overunder_over_475+"', " #277
        query_commit += " pre_goals_overunder_under_475 = '"+pre_goals_overunder_under_475+"', " #278
        query_commit += " pre_goals_overunder_over_50 = '"+pre_goals_overunder_over_50+"', " #279
        query_commit += " pre_goals_overunder_under_50 = '"+pre_goals_overunder_under_50+"', " #280
        query_commit += " pre_goals_overunder_over_525 = '"+pre_goals_overunder_over_525+"', " #281
        query_commit += " pre_goals_overunder_under_525 = '"+pre_goals_overunder_under_525+"', " #282
        query_commit += " pre_goals_overunder_over_55 = '"+pre_goals_overunder_over_55+"', " #283
        query_commit += " pre_goals_overunder_under_55 = '"+pre_goals_overunder_under_55+"', " #284
        query_commit += " pre_goals_overunder_over_575 = '"+pre_goals_overunder_over_575+"', " #285
        query_commit += " pre_goals_overunder_under_575 = '"+pre_goals_overunder_under_575+"', " #286
        query_commit += " pre_goals_overunder_over_60 = '"+pre_goals_overunder_over_60+"', " #287
        query_commit += " pre_goals_overunder_under_60 = '"+pre_goals_overunder_under_60+"', " #288
        query_commit += " pre_goals_overunder_over_625 = '"+pre_goals_overunder_over_625+"', " #289
        query_commit += " pre_goals_overunder_under_625 = '"+pre_goals_overunder_under_625+"', " #290
        query_commit += " pre_goals_overunder_over_65 = '"+pre_goals_overunder_over_65+"', " #291
        query_commit += " pre_goals_overunder_under_65 = '"+pre_goals_overunder_under_65+"', " #292
        query_commit += " pre_goals_overunder_over_675 = '"+pre_goals_overunder_over_675+"', " #293
        query_commit += " pre_goals_overunder_under_675 = '"+pre_goals_overunder_under_675+"', " #294
        query_commit += " pre_goals_overunder_over_70 = '"+pre_goals_overunder_over_70+"', " #295
        query_commit += " pre_goals_overunder_under_70 = '"+pre_goals_overunder_under_70+"', " #296
        query_commit += " pre_goals_overunder_over_75 = '"+pre_goals_overunder_over_75+"', " #297
        query_commit += " pre_goals_overunder_under_75 = '"+pre_goals_overunder_under_75+"', " #298
        query_commit += " pre_goals_overunder_over_85 = '"+pre_goals_overunder_over_85+"', " #299
        query_commit += " pre_goals_overunder_under_85 = '"+pre_goals_overunder_under_85+"', " #300
        query_commit += " pre_goals_overunder_over_95 = '"+pre_goals_overunder_over_95+"', " #301
        query_commit += " pre_goals_overunder_under_95 = '"+pre_goals_overunder_under_95+"', " #302
        query_commit += " end_goals_overunder_over_05 = '"+end_goals_overunder_over_05+"', " #303
        query_commit += " end_goals_overunder_under_05 = '"+end_goals_overunder_under_05+"', " #304
        query_commit += " end_goals_overunder_over_075 = '"+end_goals_overunder_over_075+"', " #305
        query_commit += " end_goals_overunder_under_075 = '"+end_goals_overunder_under_075+"', " #306
        query_commit += " end_goals_overunder_over_10 = '"+end_goals_overunder_over_10+"', " #307
        query_commit += " end_goals_overunder_under_10 = '"+end_goals_overunder_under_10+"', " #308
        query_commit += " end_goals_overunder_over_125 = '"+end_goals_overunder_over_125+"', " #309
        query_commit += " end_goals_overunder_under_125 = '"+end_goals_overunder_under_125+"', " #310
        query_commit += " end_goals_overunder_over_15 = '"+end_goals_overunder_over_15+"', " #311
        query_commit += " end_goals_overunder_under_15 = '"+end_goals_overunder_under_15+"', " #312
        query_commit += " end_goals_overunder_over_175 = '"+end_goals_overunder_over_175+"', " #313
        query_commit += " end_goals_overunder_under_175 = '"+end_goals_overunder_under_175+"', " #314
        query_commit += " end_goals_overunder_over_20 = '"+end_goals_overunder_over_20+"', " #315
        query_commit += " end_goals_overunder_under_20 = '"+end_goals_overunder_under_20+"', " #316
        query_commit += " end_goals_overunder_over_225 = '"+end_goals_overunder_over_225+"', " #317
        query_commit += " end_goals_overunder_under_225 = '"+end_goals_overunder_under_225+"', " #318
        query_commit += " end_goals_overunder_over_25 = '"+end_goals_overunder_over_25+"', " #319
        query_commit += " end_goals_overunder_under_25 = '"+end_goals_overunder_under_25+"', " #320
        query_commit += " end_goals_overunder_over_275 = '"+end_goals_overunder_over_275+"', " #321
        query_commit += " end_goals_overunder_under_275 = '"+end_goals_overunder_under_275+"', " #322
        query_commit += " end_goals_overunder_over_30 = '"+end_goals_overunder_over_30+"', " #323
        query_commit += " end_goals_overunder_under_30 = '"+end_goals_overunder_under_30+"', " #324
        query_commit += " end_goals_overunder_over_325 = '"+end_goals_overunder_over_325+"', " #325
        query_commit += " end_goals_overunder_under_325 = '"+end_goals_overunder_under_325+"', " #326
        query_commit += " end_goals_overunder_over_35 = '"+end_goals_overunder_over_35+"', " #327
        query_commit += " end_goals_overunder_under_35 = '"+end_goals_overunder_under_35+"', " #328
        query_commit += " end_goals_overunder_over_375 = '"+end_goals_overunder_over_375+"', " #329
        query_commit += " end_goals_overunder_under_375 = '"+end_goals_overunder_under_375+"', " #330
        query_commit += " end_goals_overunder_over_40 = '"+end_goals_overunder_over_40+"', " #331
        query_commit += " end_goals_overunder_under_40 = '"+end_goals_overunder_under_40+"', " #332
        query_commit += " end_goals_overunder_over_425 = '"+end_goals_overunder_over_425+"', " #333
        query_commit += " end_goals_overunder_under_425 = '"+end_goals_overunder_under_425+"', " #334
        query_commit += " end_goals_overunder_over_45 = '"+end_goals_overunder_over_45+"', " #335
        query_commit += " end_goals_overunder_under_45 = '"+end_goals_overunder_under_45+"', " #336
        query_commit += " end_goals_overunder_over_475 = '"+end_goals_overunder_over_475+"', " #337
        query_commit += " end_goals_overunder_under_475 = '"+end_goals_overunder_under_475+"', " #338
        query_commit += " end_goals_overunder_over_50 = '"+end_goals_overunder_over_50+"', " #339
        query_commit += " end_goals_overunder_under_50 = '"+end_goals_overunder_under_50+"', " #340
        query_commit += " end_goals_overunder_over_525 = '"+end_goals_overunder_over_525+"', " #341
        query_commit += " end_goals_overunder_under_525 = '"+end_goals_overunder_under_525+"', " #342
        query_commit += " end_goals_overunder_over_55 = '"+end_goals_overunder_over_55+"', " #343
        query_commit += " end_goals_overunder_under_55 = '"+end_goals_overunder_under_55+"', " #344
        query_commit += " end_goals_overunder_over_575 = '"+end_goals_overunder_over_575+"', " #345
        query_commit += " end_goals_overunder_under_575 = '"+end_goals_overunder_under_575+"', " #346
        query_commit += " end_goals_overunder_over_60 = '"+end_goals_overunder_over_60+"', " #347
        query_commit += " end_goals_overunder_under_60 = '"+end_goals_overunder_under_60+"', " #348
        query_commit += " end_goals_overunder_over_625 = '"+end_goals_overunder_over_625+"', " #349

        query_commit += " end_goals_overunder_under_625 = '"+end_goals_overunder_under_625+"', " #350
        query_commit += " end_goals_overunder_over_65 = '"+end_goals_overunder_over_65+"', " #351
        query_commit += " end_goals_overunder_under_65 = '"+end_goals_overunder_under_65+"', " #352
        query_commit += " end_goals_overunder_over_675 = '"+end_goals_overunder_over_675+"', " #353
        query_commit += " end_goals_overunder_under_675 = '"+end_goals_overunder_under_675+"', " #354
        query_commit += " end_goals_overunder_over_70 = '"+end_goals_overunder_over_70+"', " #355
        query_commit += " end_goals_overunder_under_70 = '"+end_goals_overunder_under_70+"', " #356
        query_commit += " end_goals_overunder_over_75 = '"+end_goals_overunder_over_75+"', " #357
        query_commit += " end_goals_overunder_under_75 = '"+end_goals_overunder_under_75+"', " #358
        query_commit += " end_goals_overunder_over_85 = '"+end_goals_overunder_over_85+"', " #359
        query_commit += " end_goals_overunder_under_85 = '"+end_goals_overunder_under_85+"', " #360
        query_commit += " end_goals_overunder_over_95 = '"+end_goals_overunder_over_95+"', " #361
        query_commit += " end_goals_overunder_under_95 = '"+end_goals_overunder_under_95+"', " #362
        query_commit += " pre_asian_handicap_first_half_home_min_175 = '"+pre_asian_handicap_first_half_home_min_175+"', " #363
        query_commit += " pre_asian_handicap_first_half_away_min_175 = '"+pre_asian_handicap_first_half_away_min_175+"', " #364
        query_commit += " pre_asian_handicap_first_half_home_min_15 = '"+pre_asian_handicap_first_half_home_min_15+"', " #365
        query_commit += " pre_asian_handicap_first_half_away_min_15 = '"+pre_asian_handicap_first_half_away_min_15+"', " #366
        query_commit += " pre_asian_handicap_first_half_home_min_125 = '"+pre_asian_handicap_first_half_home_min_125+"', " #367
        query_commit += " pre_asian_handicap_first_half_away_min_125 = '"+pre_asian_handicap_first_half_away_min_125+"', " #368
        query_commit += " pre_asian_handicap_first_half_home_min_1 = '"+pre_asian_handicap_first_half_home_min_1+"', " #369
        query_commit += " pre_asian_handicap_first_half_away_min_1 = '"+pre_asian_handicap_first_half_away_min_1+"', " #370
        query_commit += " pre_asian_handicap_first_half_home_min_075 = '"+pre_asian_handicap_first_half_home_min_075+"', " #371
        query_commit += " pre_asian_handicap_first_half_away_min_075 = '"+pre_asian_handicap_first_half_away_min_075+"', " #372
        query_commit += " pre_asian_handicap_first_half_home_min_05 = '"+pre_asian_handicap_first_half_home_min_05+"', " #373
        query_commit += " pre_asian_handicap_first_half_away_min_05 = '"+pre_asian_handicap_first_half_away_min_05+"', " #374
        query_commit += " pre_asian_handicap_first_half_home_min_025 = '"+pre_asian_handicap_first_half_home_min_025+"', " #375
        query_commit += " pre_asian_handicap_first_half_away_min_025 = '"+pre_asian_handicap_first_half_away_min_025+"', " #376
        query_commit += " pre_asian_handicap_first_half_home_plus_0 = '"+pre_asian_handicap_first_half_home_plus_0+"', " #377
        query_commit += " pre_asian_handicap_first_half_away_plus_0 = '"+pre_asian_handicap_first_half_away_plus_0+"', " #378
        query_commit += " pre_asian_handicap_first_half_home_plus_025 = '"+pre_asian_handicap_first_half_home_plus_025+"', " #379
        query_commit += " pre_asian_handicap_first_half_away_plus_025 = '"+pre_asian_handicap_first_half_away_plus_025+"', " #380
        query_commit += " pre_asian_handicap_first_half_home_plus_05 = '"+pre_asian_handicap_first_half_home_plus_05+"', " #381
        query_commit += " pre_asian_handicap_first_half_away_plus_05 = '"+pre_asian_handicap_first_half_away_plus_05+"', " #382
        query_commit += " pre_asian_handicap_first_half_home_plus_075 = '"+pre_asian_handicap_first_half_home_plus_075+"', " #383
        query_commit += " pre_asian_handicap_first_half_away_plus_075 = '"+pre_asian_handicap_first_half_away_plus_075+"', " #384
        query_commit += " pre_asian_handicap_first_half_home_plus_1 = '"+pre_asian_handicap_first_half_home_plus_1+"', " #385
        query_commit += " pre_asian_handicap_first_half_away_plus_1 = '"+pre_asian_handicap_first_half_away_plus_1+"', " #386
        query_commit += " pre_asian_handicap_first_half_home_plus_125 = '"+pre_asian_handicap_first_half_home_plus_125+"', " #387
        query_commit += " pre_asian_handicap_first_half_away_plus_125 = '"+pre_asian_handicap_first_half_away_plus_125+"', " #388
        query_commit += " pre_asian_handicap_first_half_home_plus_15 = '"+pre_asian_handicap_first_half_home_plus_15+"', " #389
        query_commit += " pre_asian_handicap_first_half_away_plus_15 = '"+pre_asian_handicap_first_half_away_plus_15+"', " #390
        query_commit += " pre_asian_handicap_first_half_home_plus_175 = '"+pre_asian_handicap_first_half_home_plus_175+"', " #391
        query_commit += " pre_asian_handicap_first_half_away_plus_175 = '"+pre_asian_handicap_first_half_away_plus_175+"', " #392
        query_commit += " end_asian_handicap_first_half_home_min_175 = '"+end_asian_handicap_first_half_home_min_175+"', " #393
        query_commit += " end_asian_handicap_first_half_away_min_175 = '"+end_asian_handicap_first_half_away_min_175+"', " #394
        query_commit += " end_asian_handicap_first_half_home_min_15 = '"+end_asian_handicap_first_half_home_min_15+"', " #395
        query_commit += " end_asian_handicap_first_half_away_min_15 = '"+end_asian_handicap_first_half_away_min_15+"', " #396
        query_commit += " end_asian_handicap_first_half_home_min_125 = '"+end_asian_handicap_first_half_home_min_125+"', " #397
        query_commit += " end_asian_handicap_first_half_away_min_125 = '"+end_asian_handicap_first_half_away_min_125+"', " #398
        query_commit += " end_asian_handicap_first_half_home_min_1 = '"+end_asian_handicap_first_half_home_min_1+"', " #399
        query_commit += " end_asian_handicap_first_half_away_min_1 = '"+end_asian_handicap_first_half_away_min_1+"', " #400
        query_commit += " end_asian_handicap_first_half_home_min_075 = '"+end_asian_handicap_first_half_home_min_075+"', " #401
        query_commit += " end_asian_handicap_first_half_away_min_075 = '"+end_asian_handicap_first_half_away_min_075+"', " #402
        query_commit += " end_asian_handicap_first_half_home_min_05 = '"+end_asian_handicap_first_half_home_min_05+"', " #403
        query_commit += " end_asian_handicap_first_half_away_min_05 = '"+end_asian_handicap_first_half_away_min_05+"', " #404
        query_commit += " end_asian_handicap_first_half_home_min_025 = '"+end_asian_handicap_first_half_home_min_025+"', " #405
        query_commit += " end_asian_handicap_first_half_away_min_025 = '"+end_asian_handicap_first_half_away_min_025+"', " #406
        query_commit += " end_asian_handicap_first_half_home_plus_0 = '"+end_asian_handicap_first_half_home_plus_0+"', " #407
        query_commit += " end_asian_handicap_first_half_away_plus_0 = '"+end_asian_handicap_first_half_away_plus_0+"', " #408
        query_commit += " end_asian_handicap_first_half_home_plus_025 = '"+end_asian_handicap_first_half_home_plus_025+"', " #409
        query_commit += " end_asian_handicap_first_half_away_plus_025 = '"+end_asian_handicap_first_half_away_plus_025+"', " #410
        query_commit += " end_asian_handicap_first_half_home_plus_05 = '"+end_asian_handicap_first_half_home_plus_05+"', " #411
        query_commit += " end_asian_handicap_first_half_away_plus_05 = '"+end_asian_handicap_first_half_away_plus_05+"', " #412
        query_commit += " end_asian_handicap_first_half_home_plus_075 = '"+end_asian_handicap_first_half_home_plus_075+"', " #413
        query_commit += " end_asian_handicap_first_half_away_plus_075 = '"+end_asian_handicap_first_half_away_plus_075+"', " #414
        query_commit += " end_asian_handicap_first_half_home_plus_1 = '"+end_asian_handicap_first_half_home_plus_1+"', " #415
        query_commit += " end_asian_handicap_first_half_away_plus_1 = '"+end_asian_handicap_first_half_away_plus_1+"', " #416
        query_commit += " end_asian_handicap_first_half_home_plus_125 = '"+end_asian_handicap_first_half_home_plus_125+"', " #417
        query_commit += " end_asian_handicap_first_half_away_plus_125 = '"+end_asian_handicap_first_half_away_plus_125+"', " #418
        query_commit += " end_asian_handicap_first_half_home_plus_15 = '"+end_asian_handicap_first_half_home_plus_15+"', " #419
        query_commit += " end_asian_handicap_first_half_away_plus_15 = '"+end_asian_handicap_first_half_away_plus_15+"', " #420
        query_commit += " end_asian_handicap_first_half_home_plus_175 = '"+end_asian_handicap_first_half_home_plus_175+"', " #421

        query_commit += " end_asian_handicap_first_half_away_plus_175 = '"+end_asian_handicap_first_half_away_plus_175+"', " #422
        query_commit += " pre_goals_overunder_first_half_over_05 = '"+pre_goals_overunder_first_half_over_05+"', " #423
        query_commit += " pre_goals_overunder_first_half_under_05 = '"+pre_goals_overunder_first_half_under_05+"', " #424
        query_commit += " pre_goals_overunder_first_half_over_075 = '"+pre_goals_overunder_first_half_over_075+"', " #425
        query_commit += " pre_goals_overunder_first_half_under_075 = '"+pre_goals_overunder_first_half_under_075+"', " #426
        query_commit += " pre_goals_overunder_first_half_over_10 = '"+pre_goals_overunder_first_half_over_10+"', " #427
        query_commit += " pre_goals_overunder_first_half_under_10 = '"+pre_goals_overunder_first_half_under_10+"', " #428
        query_commit += " pre_goals_overunder_first_half_over_125 = '"+pre_goals_overunder_first_half_over_125+"', " #429
        query_commit += " pre_goals_overunder_first_half_under_125 = '"+pre_goals_overunder_first_half_under_125+"', " #430
        query_commit += " pre_goals_overunder_first_half_over_15 = '"+pre_goals_overunder_first_half_over_15+"', " #431
        query_commit += " pre_goals_overunder_first_half_under_15 = '"+pre_goals_overunder_first_half_under_15+"', " #432
        query_commit += " pre_goals_overunder_first_half_over_175 = '"+pre_goals_overunder_first_half_over_175+"', " #433
        query_commit += " pre_goals_overunder_first_half_under_175 = '"+pre_goals_overunder_first_half_under_175+"', " #434
        query_commit += " pre_goals_overunder_first_half_over_20 = '"+pre_goals_overunder_first_half_over_20+"', " #435
        query_commit += " pre_goals_overunder_first_half_under_20 = '"+pre_goals_overunder_first_half_under_20+"', " #436
        query_commit += " pre_goals_overunder_first_half_over_225 = '"+pre_goals_overunder_first_half_over_225+"', " #437
        query_commit += " pre_goals_overunder_first_half_under_225 = '"+pre_goals_overunder_first_half_under_225+"', " #438
        query_commit += " pre_goals_overunder_first_half_over_25 = '"+pre_goals_overunder_first_half_over_25+"', " #439
        query_commit += " pre_goals_overunder_first_half_under_25 = '"+pre_goals_overunder_first_half_under_25+"', " #440
        query_commit += " pre_goals_overunder_first_half_over_275 = '"+pre_goals_overunder_first_half_over_275+"', " #441
        query_commit += " pre_goals_overunder_first_half_under_275 = '"+pre_goals_overunder_first_half_under_275+"', " #442
        query_commit += " pre_goals_overunder_first_half_over_30 = '"+pre_goals_overunder_first_half_over_30+"', " #443
        query_commit += " pre_goals_overunder_first_half_under_30 = '"+pre_goals_overunder_first_half_under_30+"', " #444
        query_commit += " pre_goals_overunder_first_half_over_325 = '"+pre_goals_overunder_first_half_over_325+"', " #445
        query_commit += " pre_goals_overunder_first_half_under_325 = '"+pre_goals_overunder_first_half_under_325+"', " #446
        query_commit += " pre_goals_overunder_first_half_over_35 = '"+pre_goals_overunder_first_half_over_35+"', " #447
        query_commit += " pre_goals_overunder_first_half_under_35 = '"+pre_goals_overunder_first_half_under_35+"', " #448
        query_commit += " pre_goals_overunder_first_half_over_375 = '"+pre_goals_overunder_first_half_over_375+"', " #449
        query_commit += " pre_goals_overunder_first_half_under_375 = '"+pre_goals_overunder_first_half_under_375+"', " #450
        query_commit += " end_goals_overunder_first_half_over_05 = '"+end_goals_overunder_first_half_over_05+"', " #451
        query_commit += " end_goals_overunder_first_half_under_05 = '"+end_goals_overunder_first_half_under_05+"', " #452
        query_commit += " end_goals_overunder_first_half_over_075 = '"+end_goals_overunder_first_half_over_075+"', " #453
        query_commit += " end_goals_overunder_first_half_under_075 = '"+end_goals_overunder_first_half_under_075+"', " #454
        query_commit += " end_goals_overunder_first_half_over_10 = '"+end_goals_overunder_first_half_over_10+"', " #455
        query_commit += " end_goals_overunder_first_half_under_10 = '"+end_goals_overunder_first_half_under_10+"', " #456
        query_commit += " end_goals_overunder_first_half_over_125 = '"+end_goals_overunder_first_half_over_125+"', " #457
        query_commit += " end_goals_overunder_first_half_under_125 = '"+end_goals_overunder_first_half_under_125+"', " #458
        query_commit += " end_goals_overunder_first_half_over_15 = '"+end_goals_overunder_first_half_over_15+"', " #459
        query_commit += " end_goals_overunder_first_half_under_15 = '"+end_goals_overunder_first_half_under_15+"', " #460
        query_commit += " end_goals_overunder_first_half_over_175 = '"+end_goals_overunder_first_half_over_175+"', " #461
        query_commit += " end_goals_overunder_first_half_under_175 = '"+end_goals_overunder_first_half_under_175+"', " #462
        query_commit += " end_goals_overunder_first_half_over_20 = '"+end_goals_overunder_first_half_over_20+"', " #463
        query_commit += " end_goals_overunder_first_half_under_20 = '"+end_goals_overunder_first_half_under_20+"', " #464
        query_commit += " end_goals_overunder_first_half_over_225 = '"+end_goals_overunder_first_half_over_225+"', " #465
        query_commit += " end_goals_overunder_first_half_under_225 = '"+end_goals_overunder_first_half_under_225+"', " #466
        query_commit += " end_goals_overunder_first_half_over_25 = '"+end_goals_overunder_first_half_over_25+"', " #467
        query_commit += " end_goals_overunder_first_half_under_25 = '"+end_goals_overunder_first_half_under_25+"', " #468
        query_commit += " end_goals_overunder_first_half_over_275 = '"+end_goals_overunder_first_half_over_275+"', " #469
        query_commit += " end_goals_overunder_first_half_under_275 = '"+end_goals_overunder_first_half_under_275+"', " #470
        query_commit += " end_goals_overunder_first_half_over_30 = '"+end_goals_overunder_first_half_over_30+"', " #471
        query_commit += " end_goals_overunder_first_half_under_30 = '"+end_goals_overunder_first_half_under_30+"', " #472
        query_commit += " end_goals_overunder_first_half_over_325 = '"+end_goals_overunder_first_half_over_325+"', " #473
        query_commit += " end_goals_overunder_first_half_under_325 = '"+end_goals_overunder_first_half_under_325+"', " #474
        query_commit += " end_goals_overunder_first_half_over_35 = '"+end_goals_overunder_first_half_over_35+"', " #475
        query_commit += " end_goals_overunder_first_half_under_35 = '"+end_goals_overunder_first_half_under_35+"', " #476
        query_commit += " end_goals_overunder_first_half_over_375 = '"+end_goals_overunder_first_half_over_375+"', " #477
        query_commit += " end_goals_overunder_first_half_under_375 = '"+end_goals_overunder_first_half_under_375+"', " #478
        query_commit += " pre_goals_overunder__second_half_over_05 = '"+pre_goals_overunder__second_half_over_05+"', " #479
        query_commit += " pre_goals_overunder__second_half_under_05 = '"+pre_goals_overunder__second_half_under_05+"', " #480
        query_commit += " pre_goals_overunder__second_half_over_075 = '"+pre_goals_overunder__second_half_over_075+"', " #481
        query_commit += " pre_goals_overunder__second_half_under_075 = '"+pre_goals_overunder__second_half_under_075+"', " #482
        query_commit += " pre_goals_overunder__second_half_over_10 = '"+pre_goals_overunder__second_half_over_10+"', " #483
        query_commit += " pre_goals_overunder__second_half_under_10 = '"+pre_goals_overunder__second_half_under_10+"', " #484
        query_commit += " pre_goals_overunder__second_half_over_125 = '"+pre_goals_overunder__second_half_over_125+"', " #485
        query_commit += " pre_goals_overunder__second_half_under_125 = '"+pre_goals_overunder__second_half_under_125+"', " #486
        query_commit += " pre_goals_overunder__second_half_over_15 = '"+pre_goals_overunder__second_half_over_15+"', " #487
        query_commit += " pre_goals_overunder__second_half_under_15 = '"+pre_goals_overunder__second_half_under_15+"', " #488
        query_commit += " pre_goals_overunder__second_half_over_175 = '"+pre_goals_overunder__second_half_over_175+"', " #489
        query_commit += " pre_goals_overunder__second_half_under_175 = '"+pre_goals_overunder__second_half_under_175+"', " #490
        query_commit += " pre_goals_overunder__second_half_over_20 = '"+pre_goals_overunder__second_half_over_20+"', " #491
        query_commit += " pre_goals_overunder__second_half_under_20 = '"+pre_goals_overunder__second_half_under_20+"', " #492
        query_commit += " pre_goals_overunder__second_half_over_225 = '"+pre_goals_overunder__second_half_over_225+"', " #493

        query_commit += " pre_goals_overunder__second_half_under_225 = '"+pre_goals_overunder__second_half_under_225+"', " #494
        query_commit += " pre_goals_overunder__second_half_over_25 = '"+pre_goals_overunder__second_half_over_25+"', " #495
        query_commit += " pre_goals_overunder__second_half_under_25 = '"+pre_goals_overunder__second_half_under_25+"', " #496
        query_commit += " pre_goals_overunder__second_half_over_275 = '"+pre_goals_overunder__second_half_over_275+"', " #497
        query_commit += " pre_goals_overunder__second_half_under_275 = '"+pre_goals_overunder__second_half_under_275+"', " #498
        query_commit += " pre_goals_overunder__second_half_over_30 = '"+pre_goals_overunder__second_half_over_30+"', " #499
        query_commit += " pre_goals_overunder__second_half_under_30 = '"+pre_goals_overunder__second_half_under_30+"', " #500
        query_commit += " pre_goals_overunder__second_half_over_325 = '"+pre_goals_overunder__second_half_over_325+"', " #501
        query_commit += " pre_goals_overunder__second_half_under_325 = '"+pre_goals_overunder__second_half_under_325+"', " #502
        query_commit += " pre_goals_overunder__second_half_over_35 = '"+pre_goals_overunder__second_half_over_35+"', " #503
        query_commit += " pre_goals_overunder__second_half_under_35 = '"+pre_goals_overunder__second_half_under_35+"', " #504
        query_commit += " pre_goals_overunder__second_half_over_375 = '"+pre_goals_overunder__second_half_over_375+"', " #505
        query_commit += " pre_goals_overunder__second_half_under_375 = '"+pre_goals_overunder__second_half_under_375+"', " #506
        query_commit += " end_goals_overunder__second_half_over_05 = '"+end_goals_overunder__second_half_over_05+"', " #507
        query_commit += " end_goals_overunder__second_half_under_05 = '"+end_goals_overunder__second_half_under_05+"', " #508
        query_commit += " end_goals_overunder__second_half_over_075 = '"+end_goals_overunder__second_half_over_075+"', " #509
        query_commit += " end_goals_overunder__second_half_under_075 = '"+end_goals_overunder__second_half_under_075+"', " #510
        query_commit += " end_goals_overunder__second_half_over_10 = '"+end_goals_overunder__second_half_over_10+"', " #511
        query_commit += " end_goals_overunder__second_half_under_10 = '"+end_goals_overunder__second_half_under_10+"', " #512
        query_commit += " end_goals_overunder__second_half_over_125 = '"+end_goals_overunder__second_half_over_125+"', " #513
        query_commit += " end_goals_overunder__second_half_under_125 = '"+end_goals_overunder__second_half_under_125+"', " #514
        query_commit += " end_goals_overunder__second_half_over_15 = '"+end_goals_overunder__second_half_over_15+"', " #515
        query_commit += " end_goals_overunder__second_half_under_15 = '"+end_goals_overunder__second_half_under_15+"', " #516
        query_commit += " end_goals_overunder__second_half_over_175 = '"+end_goals_overunder__second_half_over_175+"', " #517
        query_commit += " end_goals_overunder__second_half_under_175 = '"+end_goals_overunder__second_half_under_175+"', " #518
        query_commit += " end_goals_overunder__second_half_over_20 = '"+end_goals_overunder__second_half_over_20+"', " #519
        query_commit += " end_goals_overunder__second_half_under_20 = '"+end_goals_overunder__second_half_under_20+"', " #520
        query_commit += " end_goals_overunder__second_half_over_225 = '"+end_goals_overunder__second_half_over_225+"', " #521
        query_commit += " end_goals_overunder__second_half_under_225 = '"+end_goals_overunder__second_half_under_225+"', " #522
        query_commit += " end_goals_overunder__second_half_over_25 = '"+end_goals_overunder__second_half_over_25+"', " #523
        query_commit += " end_goals_overunder__second_half_under_25 = '"+end_goals_overunder__second_half_under_25+"', " #524
        query_commit += " end_goals_overunder__second_half_over_275 = '"+end_goals_overunder__second_half_over_275+"', " #525
        query_commit += " end_goals_overunder__second_half_under_275 = '"+end_goals_overunder__second_half_under_275+"', " #526
        query_commit += " end_goals_overunder__second_half_over_30 = '"+end_goals_overunder__second_half_over_30+"', " #527
        query_commit += " end_goals_overunder__second_half_under_30 = '"+end_goals_overunder__second_half_under_30+"', " #528
        query_commit += " end_goals_overunder__second_half_over_325 = '"+end_goals_overunder__second_half_over_325+"', " #529
        query_commit += " end_goals_overunder__second_half_under_325 = '"+end_goals_overunder__second_half_under_325+"', " #530
        query_commit += " end_goals_overunder__second_half_over_35 = '"+end_goals_overunder__second_half_over_35+"', " #531
        query_commit += " end_goals_overunder__second_half_under_35 = '"+end_goals_overunder__second_half_under_35+"', " #532
        query_commit += " end_goals_overunder__second_half_over_375 = '"+end_goals_overunder__second_half_over_375+"', " #533
        query_commit += " end_goals_overunder__second_half_under_375 = '"+end_goals_overunder__second_half_under_375+"', " #534
        query_commit += " pre_htft_double_home_home = '"+pre_htft_double_home_home+"', " #535
        query_commit += " pre_htft_double_home_draw = '"+pre_htft_double_home_draw+"', " #536
        query_commit += " pre_htft_double_home_away = '"+pre_htft_double_home_away+"', " #537
        query_commit += " pre_htft_double_draw_home = '"+pre_htft_double_draw_home+"', " #538
        query_commit += " pre_htft_double_draw_draw = '"+pre_htft_double_draw_draw+"', " #539
        query_commit += " pre_htft_double_draw_away = '"+pre_htft_double_draw_away+"', " #540
        query_commit += " pre_htft_double_away_home = '"+pre_htft_double_away_home+"', " #541
        query_commit += " pre_htft_double_away_draw = '"+pre_htft_double_away_draw+"', " #542
        query_commit += " pre_htft_double_away_away = '"+pre_htft_double_away_away+"', " #543
        query_commit += " end_htft_double_home_home = '"+end_htft_double_home_home+"', " #544
        query_commit += " end_htft_double_home_draw = '"+end_htft_double_home_draw+"', " #545
        query_commit += " end_htft_double_home_away = '"+end_htft_double_home_away+"', " #546
        query_commit += " end_htft_double_draw_home = '"+end_htft_double_draw_home+"', " #547
        query_commit += " end_htft_double_draw_draw = '"+end_htft_double_draw_draw+"', " #548
        query_commit += " end_htft_double_draw_away = '"+end_htft_double_draw_away+"', " #549
        query_commit += " end_htft_double_away_home = '"+end_htft_double_away_home+"', " #550
        query_commit += " end_htft_double_away_draw = '"+end_htft_double_away_draw+"', " #551
        query_commit += " end_htft_double_away_away = '"+end_htft_double_away_away+"', " #552
        query_commit += " pre_both_teams_score_yes = '"+pre_both_teams_score_yes+"', " #553
        query_commit += " pre_both_teams_score_no = '"+pre_both_teams_score_no+"', " #554
        query_commit += " end_both_teams_score_yes = '"+end_both_teams_score_yes+"', " #555
        query_commit += " end_both_teams_score_no = '"+end_both_teams_score_no+"', " #556
        query_commit += " pre_both_teams_score__first_half_yes = '"+pre_both_teams_score__first_half_yes+"', " #557
        query_commit += " pre_both_teams_score__first_half_no = '"+pre_both_teams_score__first_half_no+"', " #558
        query_commit += " end_both_teams_score__first_half_yes = '"+end_both_teams_score__first_half_yes+"', " #559
        query_commit += " end_both_teams_score__first_half_no = '"+end_both_teams_score__first_half_no+"', " #560
        query_commit += " pre_both_teams_to_score__second_half_yes = '"+pre_both_teams_to_score__second_half_yes+"', " #561
        query_commit += " pre_both_teams_to_score__second_half_no = '"+pre_both_teams_to_score__second_half_no+"', " #562
        query_commit += " end_both_teams_to_score__second_half_yes = '"+end_both_teams_to_score__second_half_yes+"', " #563
        query_commit += " end_both_teams_to_score__second_half_no = '"+end_both_teams_to_score__second_half_no+"', " #564
        query_commit += " pre_results_both_teams_score_home_yes = '"+pre_results_both_teams_score_home_yes+"', " #565
        query_commit += " pre_results_both_teams_score_draw_yes = '"+pre_results_both_teams_score_draw_yes+"', " #566
        query_commit += " pre_results_both_teams_score_away_yes = '"+pre_results_both_teams_score_away_yes+"', " #567
        query_commit += " pre_results_both_teams_score_home_no = '"+pre_results_both_teams_score_home_no+"', " #568
        query_commit += " pre_results_both_teams_score_draw_no = '"+pre_results_both_teams_score_draw_no+"', " #569
        query_commit += " pre_results_both_teams_score_away_no = '"+pre_results_both_teams_score_away_no+"', " #570

        query_commit += " end_results_both_teams_score_home_yes = '"+end_results_both_teams_score_home_yes+"', " #571
        query_commit += " end_results_both_teams_score_draw_yes = '"+end_results_both_teams_score_draw_yes+"', " #572
        query_commit += " end_results_both_teams_score_away_yes = '"+end_results_both_teams_score_away_yes+"', " #573
        query_commit += " end_results_both_teams_score_home_no = '"+end_results_both_teams_score_home_no+"', " #574
        query_commit += " end_results_both_teams_score_draw_no = '"+end_results_both_teams_score_draw_no+"', " #575
        query_commit += " end_results_both_teams_score_away_no = '"+end_results_both_teams_score_away_no+"', " #576
        query_commit += " pre_to_score_in_both_halves_by_teams_home = '"+pre_to_score_in_both_halves_by_teams_home+"', " #577
        query_commit += " pre_to_score_in_both_halves_by_teams_away = '"+pre_to_score_in_both_halves_by_teams_away+"', " #578
        query_commit += " end_to_score_in_both_halves_by_teams_home = '"+end_to_score_in_both_halves_by_teams_home+"', " #579
        query_commit += " end_to_score_in_both_halves_by_teams_away = '"+end_to_score_in_both_halves_by_teams_away+"', " #580
        query_commit += " pre_total_goals_both_teams_to_score_over_yes_25 = '"+pre_total_goals_both_teams_to_score_over_yes_25+"', " #581
        query_commit += " pre_total_goals_both_teams_to_score_over_no_25 = '"+pre_total_goals_both_teams_to_score_over_no_25+"', " #582
        query_commit += " pre_total_goals_both_teams_to_score_under_yes_25 = '"+pre_total_goals_both_teams_to_score_under_yes_25+"', " #583
        query_commit += " pre_total_goals_both_teams_to_score_under_no_25 = '"+pre_total_goals_both_teams_to_score_under_no_25+"', " #584
        query_commit += " end_total_goals_both_teams_to_score_over_yes_25 = '"+end_total_goals_both_teams_to_score_over_yes_25+"', " #585
        query_commit += " end_total_goals_both_teams_to_score_over_no_25 = '"+end_total_goals_both_teams_to_score_over_no_25+"', " #586
        query_commit += " end_total_goals_both_teams_to_score_under_yes_25 = '"+end_total_goals_both_teams_to_score_under_yes_25+"', " #587
        query_commit += " end_total_goals_both_teams_to_score_under_no_25 = '"+end_total_goals_both_teams_to_score_under_no_25+"', " #588
        query_commit += " pre_both_teams_to_score_1st_half__2nd_half_yes_yes = '"+pre_both_teams_to_score_1st_half__2nd_half_yes_yes+"', " #589
        query_commit += " pre_both_teams_to_score_1st_half__2nd_half_yes_no = '"+pre_both_teams_to_score_1st_half__2nd_half_yes_no+"', " #590
        query_commit += " pre_both_teams_to_score_1st_half__2nd_half_no_yes = '"+pre_both_teams_to_score_1st_half__2nd_half_no_yes+"', " #591
        query_commit += " pre_both_teams_to_score_1st_half__2nd_half_no_no = '"+pre_both_teams_to_score_1st_half__2nd_half_no_no+"', " #592
        query_commit += " end_both_teams_to_score_1st_half__2nd_half_yes_yes = '"+end_both_teams_to_score_1st_half__2nd_half_yes_yes+"', " #593
        query_commit += " end_both_teams_to_score_1st_half__2nd_half_yes_no = '"+end_both_teams_to_score_1st_half__2nd_half_yes_no+"', " #594
        query_commit += " end_both_teams_to_score_1st_half__2nd_half_no_yes = '"+end_both_teams_to_score_1st_half__2nd_half_no_yes+"', " #595
        query_commit += " end_both_teams_to_score_1st_half__2nd_half_no_no = '"+end_both_teams_to_score_1st_half__2nd_half_no_no+"', " #596
        query_commit += " pre_highest_scoring_half_first = '"+pre_highest_scoring_half_first+"', " #597
        query_commit += " pre_highest_scoring_half_draw = '"+pre_highest_scoring_half_draw+"', " #598
        query_commit += " pre_highest_scoring_half_second = '"+pre_highest_scoring_half_second+"', " #599
        query_commit += " end_highest_scoring_half_first = '"+end_highest_scoring_half_first+"', " #600
        query_commit += " end_highest_scoring_half_draw = '"+end_highest_scoring_half_draw+"', " #601
        query_commit += " end_highest_scoring_half_second = '"+end_highest_scoring_half_second+"', " #602
        query_commit += " pre_double_chance_home_draw = '"+pre_double_chance_home_draw+"', " #603
        query_commit += " pre_double_chance_home_away = '"+pre_double_chance_home_away+"', " #604
        query_commit += " pre_double_chance_draw_away = '"+pre_double_chance_draw_away+"', " #605
        query_commit += " end_double_chance_home_draw = '"+end_double_chance_home_draw+"', " #606
        query_commit += " end_double_chance_home_away = '"+end_double_chance_home_away+"', " #607
        query_commit += " end_double_chance_draw_away = '"+end_double_chance_draw_away+"', " #608
        query_commit += " pre_double_chance__first_half_home_draw = '"+pre_double_chance__first_half_home_draw+"', " #609
        query_commit += " pre_double_chance__first_half_home_away = '"+pre_double_chance__first_half_home_away+"', " #610
        query_commit += " pre_double_chance__first_half_draw_away = '"+pre_double_chance__first_half_draw_away+"', " #611
        query_commit += " end_double_chance__first_half_home_draw = '"+end_double_chance__first_half_home_draw+"', " #612
        query_commit += " end_double_chance__first_half_home_away = '"+end_double_chance__first_half_home_away+"', " #613
        query_commit += " end_double_chance__first_half_draw_away = '"+end_double_chance__first_half_draw_away+"', " #614
        query_commit += " pre_oddeven_odd = '"+pre_oddeven_odd+"', " #615
        query_commit += " pre_oddeven_even = '"+pre_oddeven_even+"', " #616
        query_commit += " end_oddeven_odd = '"+end_oddeven_odd+"', " #617
        query_commit += " end_oddeven_even = '"+end_oddeven_even+"', " #618
        query_commit += " pre_result_total_goals_home_over_35 = '"+pre_result_total_goals_home_over_35+"', " #619
        query_commit += " pre_result_total_goals_draw_over_35 = '"+pre_result_total_goals_draw_over_35+"', " #620
        query_commit += " pre_result_total_goals_away_over_35 = '"+pre_result_total_goals_away_over_35+"', " #621
        query_commit += " pre_result_total_goals_home_under_35 = '"+pre_result_total_goals_home_under_35+"', " #622
        query_commit += " pre_result_total_goals_draw_under_35 = '"+pre_result_total_goals_draw_under_35+"', " #623
        query_commit += " pre_result_total_goals_away_under_35 = '"+pre_result_total_goals_away_under_35+"', " #624
        query_commit += " pre_result_total_goals_home_over_25 = '"+pre_result_total_goals_home_over_25+"', " #625
        query_commit += " pre_result_total_goals_draw_over_25 = '"+pre_result_total_goals_draw_over_25+"', " #626
        query_commit += " pre_result_total_goals_away_over_25 = '"+pre_result_total_goals_away_over_25+"', " #627
        query_commit += " pre_result_total_goals_home_under_25 = '"+pre_result_total_goals_home_under_25+"', " #628
        query_commit += " pre_result_total_goals_draw_under_25 = '"+pre_result_total_goals_draw_under_25+"', " #629
        query_commit += " pre_result_total_goals_away_under_25 = '"+pre_result_total_goals_away_under_25+"', " #630
        query_commit += " end_result_total_goals_home_over_35 = '"+end_result_total_goals_home_over_35+"', " #631
        query_commit += " end_result_total_goals_draw_over_35 = '"+end_result_total_goals_draw_over_35+"', " #632
        query_commit += " end_result_total_goals_away_over_35 = '"+end_result_total_goals_away_over_35+"', " #633
        query_commit += " end_result_total_goals_home_under_35 = '"+end_result_total_goals_home_under_35+"', " #634
        query_commit += " end_result_total_goals_draw_under_35 = '"+end_result_total_goals_draw_under_35+"', " #635
        query_commit += " end_result_total_goals_away_under_35 = '"+end_result_total_goals_away_under_35+"', " #636
        query_commit += " end_result_total_goals_home_over_25 = '"+end_result_total_goals_home_over_25+"', " #637
        query_commit += " end_result_total_goals_draw_over_25 = '"+end_result_total_goals_draw_over_25+"', " #638
        query_commit += " end_result_total_goals_away_over_25 = '"+end_result_total_goals_away_over_25+"', " #639
        query_commit += " end_result_total_goals_home_under_25 = '"+end_result_total_goals_home_under_25+"', " #640
        query_commit += " end_result_total_goals_draw_under_25 = '"+end_result_total_goals_draw_under_25+"', " #641
        query_commit += " end_result_total_goals_away_under_25 = '"+end_result_total_goals_away_under_25+"', " #642
        query_commit += " pre_clean_sheet__home_yes = '"+pre_clean_sheet__home_yes+"', " #643
        query_commit += " pre_clean_sheet__home_no = '"+pre_clean_sheet__home_no+"', " #644
        query_commit += " end_clean_sheet__home_yes = '"+end_clean_sheet__home_yes+"', " #645
        query_commit += " end_clean_sheet__home_no = '"+end_clean_sheet__home_no+"', " #646

        query_commit += " pre_clean_sheet__away_yes = '"+pre_clean_sheet__away_yes+"', " #647
        query_commit += " pre_clean_sheet__away_no = '"+pre_clean_sheet__away_no+"', " #648
        query_commit += " end_clean_sheet__away_yes = '"+end_clean_sheet__away_yes+"', " #649
        query_commit += " end_clean_sheet__away_no = '"+end_clean_sheet__away_no+"', " #650
        query_commit += " pre_win_both_halves_home = '"+pre_win_both_halves_home+"', " #651
        query_commit += " pre_win_both_halves_away = '"+pre_win_both_halves_away+"', " #652
        query_commit += " end_win_both_halves_home = '"+end_win_both_halves_home+"', " #653
        query_commit += " end_win_both_halves_away = '"+end_win_both_halves_away+"', " #654
        query_commit += " pre_win_to_nil_home = '"+pre_win_to_nil_home+"', " #655
        query_commit += " pre_win_to_nil_away = '"+pre_win_to_nil_away+"', " #656
        query_commit += " end_win_to_nil_home = '"+end_win_to_nil_home+"', " #657
        query_commit += " end_win_to_nil_away = '"+end_win_to_nil_away+"', " #658
        query_commit += " pre_to_win_either_half_home = '"+pre_to_win_either_half_home+"', " #659
        query_commit += " pre_to_win_either_half_away = '"+pre_to_win_either_half_away+"', " #660
        query_commit += " end_to_win_either_half_home = '"+end_to_win_either_half_home+"', " #661
        query_commit += " end_to_win_either_half_away = '"+end_to_win_either_half_away+"', " #662
        query_commit += " pre_halftime_result_both_teams_score_home_yes = '"+pre_halftime_result_both_teams_score_home_yes+"', " #663
        query_commit += " pre_halftime_result_both_teams_score_draw_yes = '"+pre_halftime_result_both_teams_score_draw_yes+"', " #664
        query_commit += " pre_halftime_result_both_teams_score_away_yes = '"+pre_halftime_result_both_teams_score_away_yes+"', " #665
        query_commit += " pre_halftime_result_both_teams_score_home_no = '"+pre_halftime_result_both_teams_score_home_no+"', " #666
        query_commit += " pre_halftime_result_both_teams_score_draw_no = '"+pre_halftime_result_both_teams_score_draw_no+"', " #667
        query_commit += " pre_halftime_result_both_teams_score_away_no = '"+pre_halftime_result_both_teams_score_away_no+"', " #668
        query_commit += " end_halftime_result_both_teams_score_home_yes = '"+end_halftime_result_both_teams_score_home_yes+"', " #669
        query_commit += " end_halftime_result_both_teams_score_draw_yes = '"+end_halftime_result_both_teams_score_draw_yes+"', " #670
        query_commit += " end_halftime_result_both_teams_score_away_yes = '"+end_halftime_result_both_teams_score_away_yes+"', " #671
        query_commit += " end_halftime_result_both_teams_score_home_no = '"+end_halftime_result_both_teams_score_home_no+"', " #672
        query_commit += " end_halftime_result_both_teams_score_draw_no = '"+end_halftime_result_both_teams_score_draw_no+"', " #673
        query_commit += " end_halftime_result_both_teams_score_away_no = '"+end_halftime_result_both_teams_score_away_no+"', " #674
        query_commit += " pre_exact_goals_number_0 = '"+pre_exact_goals_number_0+"', " #675
        query_commit += " pre_exact_goals_number_1 = '"+pre_exact_goals_number_1+"', " #676
        query_commit += " pre_exact_goals_number_2 = '"+pre_exact_goals_number_2+"', " #677
        query_commit += " pre_exact_goals_number_3 = '"+pre_exact_goals_number_3+"', " #678
        query_commit += " pre_exact_goals_number_4 = '"+pre_exact_goals_number_4+"', " #679
        query_commit += " pre_exact_goals_number_5 = '"+pre_exact_goals_number_5+"', " #680
        query_commit += " pre_exact_goals_number_6 = '"+pre_exact_goals_number_6+"', " #681
        query_commit += " pre_exact_goals_number_more_7 = '"+pre_exact_goals_number_more_7+"', " #682
        query_commit += " end_exact_goals_number_0 = '"+end_exact_goals_number_0+"', " #683
        query_commit += " end_exact_goals_number_1 = '"+end_exact_goals_number_1+"', " #684
        query_commit += " end_exact_goals_number_2 = '"+end_exact_goals_number_2+"', " #685
        query_commit += " end_exact_goals_number_3 = '"+end_exact_goals_number_3+"', " #686
        query_commit += " end_exact_goals_number_4 = '"+end_exact_goals_number_4+"', " #687
        query_commit += " end_exact_goals_number_5 = '"+end_exact_goals_number_5+"', " #688
        query_commit += " end_exact_goals_number_6 = '"+end_exact_goals_number_6+"', " #689
        query_commit += " end_exact_goals_number_more_7 = '"+end_exact_goals_number_more_7+"', " #690
        query_commit += " pre_exact_goals_number__first_half_0 = '"+pre_exact_goals_number__first_half_0+"', " #691
        query_commit += " pre_exact_goals_number__first_half_1 = '"+pre_exact_goals_number__first_half_1+"', " #692
        query_commit += " pre_exact_goals_number__first_half_2 = '"+pre_exact_goals_number__first_half_2+"', " #693
        query_commit += " pre_exact_goals_number__first_half_3 = '"+pre_exact_goals_number__first_half_3+"', " #694
        query_commit += " pre_exact_goals_number__first_half_4 = '"+pre_exact_goals_number__first_half_4+"', " #695
        query_commit += " pre_exact_goals_number__first_half_more_5 = '"+pre_exact_goals_number__first_half_more_5+"', " #696
        query_commit += " end_exact_goals_number__first_half_0 = '"+end_exact_goals_number__first_half_0+"', " #697
        query_commit += " end_exact_goals_number__first_half_1 = '"+end_exact_goals_number__first_half_1+"', " #698
        query_commit += " end_exact_goals_number__first_half_2 = '"+end_exact_goals_number__first_half_2+"', " #699
        query_commit += " end_exact_goals_number__first_half_3 = '"+end_exact_goals_number__first_half_3+"', " #700
        query_commit += " end_exact_goals_number__first_half_4 = '"+end_exact_goals_number__first_half_4+"', " #701
        query_commit += " end_exact_goals_number__first_half_more_5 = '"+end_exact_goals_number__first_half_more_5+"', " #702
        query_commit += " pre_second_half_exact_goals_number_0 = '"+pre_second_half_exact_goals_number_0+"', " #703
        query_commit += " pre_second_half_exact_goals_number_1 = '"+pre_second_half_exact_goals_number_1+"', " #704
        query_commit += " pre_second_half_exact_goals_number_2 = '"+pre_second_half_exact_goals_number_2+"', " #705
        query_commit += " pre_second_half_exact_goals_number_3 = '"+pre_second_half_exact_goals_number_3+"', " #706
        query_commit += " pre_second_half_exact_goals_number_4 = '"+pre_second_half_exact_goals_number_4+"', " #707
        query_commit += " pre_second_half_exact_goals_number_more_5 = '"+pre_second_half_exact_goals_number_more_5+"', " #708
        query_commit += " end_second_half_exact_goals_number_0 = '"+end_second_half_exact_goals_number_0+"', " #709
        query_commit += " end_second_half_exact_goals_number_1 = '"+end_second_half_exact_goals_number_1+"', " #710
        query_commit += " end_second_half_exact_goals_number_2 = '"+end_second_half_exact_goals_number_2+"', " #711
        query_commit += " end_second_half_exact_goals_number_3 = '"+end_second_half_exact_goals_number_3+"', " #712
        query_commit += " end_second_half_exact_goals_number_4 = '"+end_second_half_exact_goals_number_4+"', " #713
        query_commit += " end_second_half_exact_goals_number_more_5 = '"+end_second_half_exact_goals_number_more_5+"', " #714
        query_commit += " pre_home_team_exact_goals_number_0 = '"+pre_home_team_exact_goals_number_0+"', " #715
        query_commit += " pre_home_team_exact_goals_number_1 = '"+pre_home_team_exact_goals_number_1+"', " #716
        query_commit += " pre_home_team_exact_goals_number_2 = '"+pre_home_team_exact_goals_number_2+"', " #717
        query_commit += " pre_home_team_exact_goals_number_more_3 = '"+pre_home_team_exact_goals_number_more_3+"', " #718
        query_commit += " end_home_team_exact_goals_number_0 = '"+end_home_team_exact_goals_number_0+"', " #719
        query_commit += " end_home_team_exact_goals_number_1 = '"+end_home_team_exact_goals_number_1+"', " #720
        query_commit += " end_home_team_exact_goals_number_2 = '"+end_home_team_exact_goals_number_2+"', " #721
        query_commit += " end_home_team_exact_goals_number_more_3 = '"+end_home_team_exact_goals_number_more_3+"', " #722
        query_commit += " pre_away_team_exact_goals_number_0 = '"+pre_away_team_exact_goals_number_0+"', " #723
        query_commit += " pre_away_team_exact_goals_number_1 = '"+pre_away_team_exact_goals_number_1+"', " #724
        query_commit += " pre_away_team_exact_goals_number_2 = '"+pre_away_team_exact_goals_number_2+"', " #725
        query_commit += " pre_away_team_exact_goals_number_more_3 = '"+pre_away_team_exact_goals_number_more_3+"', " #726
        query_commit += " end_away_team_exact_goals_number_0 = '"+end_away_team_exact_goals_number_0+"', " #727

        query_commit += " end_away_team_exact_goals_number_1 = '"+end_away_team_exact_goals_number_1+"', " #728
        query_commit += " end_away_team_exact_goals_number_2 = '"+end_away_team_exact_goals_number_2+"', " #729
        query_commit += " end_away_team_exact_goals_number_more_3 = '"+end_away_team_exact_goals_number_more_3+"', " #730
        query_commit += " pre_corners_winner_home = '"+pre_corners_winner_home+"', " #731
        query_commit += " pre_corners_winner_draw = '"+pre_corners_winner_draw+"', " #732
        query_commit += " pre_corners_winner_away = '"+pre_corners_winner_away+"', " #733
        query_commit += " end_corners_winner_home = '"+end_corners_winner_home+"', " #734
        query_commit += " end_corners_winner_draw = '"+end_corners_winner_draw+"', " #735
        query_commit += " end_corners_winner_away = '"+end_corners_winner_away+"', " #736
        query_commit += " pre_10_overunder_over_05 = '"+pre_10_overunder_over_05+"', " #737
        query_commit += " pre_10_overunder_under_05 = '"+pre_10_overunder_under_05+"', " #738
        query_commit += " end_10_overunder_over_05 = '"+end_10_overunder_over_05+"', " #739
        query_commit += " end_10_overunder_under_05 = '"+end_10_overunder_under_05+"', " #740
        query_commit += " pre_cards_european_handicap_home_min_2 = '"+pre_cards_european_handicap_home_min_2+"', " #741
        query_commit += " pre_cards_european_handicap_draw_min_2 = '"+pre_cards_european_handicap_draw_min_2+"', " #742
        query_commit += " pre_cards_european_handicap_away_min_2 = '"+pre_cards_european_handicap_away_min_2+"', " #743
        query_commit += " pre_cards_european_handicap_home_min_1 = '"+pre_cards_european_handicap_home_min_1+"', " #744
        query_commit += " pre_cards_european_handicap_draw_min_1 = '"+pre_cards_european_handicap_draw_min_1+"', " #745
        query_commit += " pre_cards_european_handicap_away_min_1 = '"+pre_cards_european_handicap_away_min_1+"', " #746
        query_commit += " pre_cards_european_handicap_home_plus_0 = '"+pre_cards_european_handicap_home_plus_0+"', " #747
        query_commit += " pre_cards_european_handicap_draw_plus_0 = '"+pre_cards_european_handicap_draw_plus_0+"', " #748
        query_commit += " pre_cards_european_handicap_away_plus_0 = '"+pre_cards_european_handicap_away_plus_0+"', " #749
        query_commit += " pre_cards_european_handicap_home_plus_1 = '"+pre_cards_european_handicap_home_plus_1+"', " #750
        query_commit += " pre_cards_european_handicap_draw_plus_1 = '"+pre_cards_european_handicap_draw_plus_1+"', " #751
        query_commit += " pre_cards_european_handicap_away_plus_1 = '"+pre_cards_european_handicap_away_plus_1+"', " #752
        query_commit += " pre_cards_european_handicap_home_plus_2 = '"+pre_cards_european_handicap_home_plus_2+"', " #753
        query_commit += " pre_cards_european_handicap_draw_plus_2 = '"+pre_cards_european_handicap_draw_plus_2+"', " #754
        query_commit += " pre_cards_european_handicap_away_plus_2 = '"+pre_cards_european_handicap_away_plus_2+"', " #755
        query_commit += " end_cards_european_handicap_home_min_2 = '"+end_cards_european_handicap_home_min_2+"', " #756
        query_commit += " end_cards_european_handicap_draw_min_2 = '"+end_cards_european_handicap_draw_min_2+"', " #757
        query_commit += " end_cards_european_handicap_away_min_2 = '"+end_cards_european_handicap_away_min_2+"', " #758
        query_commit += " end_cards_european_handicap_home_min_1 = '"+end_cards_european_handicap_home_min_1+"', " #759
        query_commit += " end_cards_european_handicap_draw_min_1 = '"+end_cards_european_handicap_draw_min_1+"', " #760
        query_commit += " end_cards_european_handicap_away_min_1 = '"+end_cards_european_handicap_away_min_1+"', " #761
        query_commit += " end_cards_european_handicap_home_plus_0 = '"+end_cards_european_handicap_home_plus_0+"', " #762
        query_commit += " end_cards_european_handicap_draw_plus_0 = '"+end_cards_european_handicap_draw_plus_0+"', " #763
        query_commit += " end_cards_european_handicap_away_plus_0 = '"+end_cards_european_handicap_away_plus_0+"', " #764
        query_commit += " end_cards_european_handicap_home_plus_1 = '"+end_cards_european_handicap_home_plus_1+"', " #765
        query_commit += " end_cards_european_handicap_draw_plus_1 = '"+end_cards_european_handicap_draw_plus_1+"', " #766
        query_commit += " end_cards_european_handicap_away_plus_1 = '"+end_cards_european_handicap_away_plus_1+"', " #767
        query_commit += " end_cards_european_handicap_home_plus_2 = '"+end_cards_european_handicap_home_plus_2+"', " #768
        query_commit += " end_cards_european_handicap_draw_plus_2 = '"+end_cards_european_handicap_draw_plus_2+"', " #769
        query_commit += " end_cards_european_handicap_away_plus_2 = '"+end_cards_european_handicap_away_plus_2+"', " #770
        query_commit += " pre_rcard_yes = '"+pre_rcard_yes+"', " #771
        query_commit += " pre_rcard_no = '"+pre_rcard_no+"', " #772
        query_commit += " end_rcard_yes = '"+end_rcard_yes+"', " #773
        query_commit += " end_rcard_no = '"+end_rcard_no+"', " #774
        query_commit += " pre_team_to_score_first_home = '"+pre_team_to_score_first_home+"', " #775
        query_commit += " pre_team_to_score_first_draw = '"+pre_team_to_score_first_draw+"', " #776
        query_commit += " pre_team_to_score_first_away = '"+pre_team_to_score_first_away+"', " #777
        query_commit += " end_team_to_score_first_home = '"+end_team_to_score_first_home+"', " #778
        query_commit += " end_team_to_score_first_draw = '"+end_team_to_score_first_draw+"', " #779
        query_commit += " end_team_to_score_first_away = '"+end_team_to_score_first_away+"', " #780
        query_commit += " pre_team_to_score_last_home = '"+pre_team_to_score_last_home+"', " #781
        query_commit += " pre_team_to_score_last_draw = '"+pre_team_to_score_last_draw+"', " #782
        query_commit += " pre_team_to_score_last_away = '"+pre_team_to_score_last_away+"', " #783
        query_commit += " end_team_to_score_last_home = '"+end_team_to_score_last_home+"', " #784
        query_commit += " end_team_to_score_last_draw = '"+end_team_to_score_last_draw+"', " #785
        query_commit += " end_team_to_score_last_away = '"+end_team_to_score_last_away+"', " #786
        query_commit += " pre_total_home_over_15 = '"+pre_total_home_over_15+"', " #787
        query_commit += " pre_total_home_under_15 = '"+pre_total_home_under_15+"', " #788
        query_commit += " pre_total_home_over_25 = '"+pre_total_home_over_25+"', " #789
        query_commit += " pre_total_home_under_25 = '"+pre_total_home_under_25+"', " #790
        query_commit += " pre_total_home_over_35 = '"+pre_total_home_over_35+"', " #791
        query_commit += " pre_total_home_under_35 = '"+pre_total_home_under_35+"', " #792
        query_commit += " pre_total_home_over_45 = '"+pre_total_home_over_45+"', " #793
        query_commit += " pre_total_home_under_45 = '"+pre_total_home_under_45+"', " #794
        query_commit += " pre_total_home_over_55 = '"+pre_total_home_over_55+"', " #795
        query_commit += " pre_total_home_under_55 = '"+pre_total_home_under_55+"', " #796
        query_commit += " pre_total_home_over_65 = '"+pre_total_home_over_65+"', " #797
        query_commit += " pre_total_home_under_65 = '"+pre_total_home_under_65+"', " #798
        query_commit += " end_total_home_over_15 = '"+end_total_home_over_15+"', " #799
        query_commit += " end_total_home_under_15 = '"+end_total_home_under_15+"', " #800
        query_commit += " end_total_home_over_25 = '"+end_total_home_over_25+"', " #801
        query_commit += " end_total_home_under_25 = '"+end_total_home_under_25+"', " #802
        query_commit += " end_total_home_over_35 = '"+end_total_home_over_35+"', " #803
        query_commit += " end_total_home_under_35 = '"+end_total_home_under_35+"', " #804
        query_commit += " end_total_home_over_45 = '"+end_total_home_over_45+"', " #805
        query_commit += " end_total_home_under_45 = '"+end_total_home_under_45+"', " #806
        query_commit += " end_total_home_over_55 = '"+end_total_home_over_55+"', " #807
        query_commit += " end_total_home_under_55 = '"+end_total_home_under_55+"', " #808
        query_commit += " end_total_home_over_65 = '"+end_total_home_over_65+"', " #809
        query_commit += " end_total_home_under_65 = '"+end_total_home_under_65+"', " #810
        query_commit += " pre_total_away_over_15 = '"+pre_total_away_over_15+"', " #811
        query_commit += " pre_total_away_under_15 = '"+pre_total_away_under_15+"', " #812
        query_commit += " pre_total_away_over_25 = '"+pre_total_away_over_25+"', " #813
        query_commit += " pre_total_away_under_25 = '"+pre_total_away_under_25+"', " #814
        query_commit += " pre_total_away_over_35 = '"+pre_total_away_over_35+"', " #815

        query_commit += " pre_total_away_under_35 = '"+pre_total_away_under_35+"', " #816
        query_commit += " pre_total_away_over_45 = '"+pre_total_away_over_45+"', " #817
        query_commit += " pre_total_away_under_45 = '"+pre_total_away_under_45+"', " #818
        query_commit += " pre_total_away_over_55 = '"+pre_total_away_over_55+"', " #819
        query_commit += " pre_total_away_under_55 = '"+pre_total_away_under_55+"', " #820
        query_commit += " pre_total_away_over_65 = '"+pre_total_away_over_65+"', " #821
        query_commit += " pre_total_away_under_65 = '"+pre_total_away_under_65+"', " #822
        query_commit += " end_total_away_over_15 = '"+end_total_away_over_15+"', " #823
        query_commit += " end_total_away_under_15 = '"+end_total_away_under_15+"', " #824
        query_commit += " end_total_away_over_25 = '"+end_total_away_over_25+"', " #825
        query_commit += " end_total_away_under_25 = '"+end_total_away_under_25+"', " #826
        query_commit += " end_total_away_over_35 = '"+end_total_away_over_35+"', " #827
        query_commit += " end_total_away_under_35 = '"+end_total_away_under_35+"', " #828
        query_commit += " end_total_away_over_45 = '"+end_total_away_over_45+"', " #829
        query_commit += " end_total_away_under_45 = '"+end_total_away_under_45+"', " #830
        query_commit += " end_total_away_over_55 = '"+end_total_away_over_55+"', " #831
        query_commit += " end_total_away_under_55 = '"+end_total_away_under_55+"', " #832
        query_commit += " end_total_away_over_65 = '"+end_total_away_over_65+"', " #833
        query_commit += " end_total_away_under_65 = '"+end_total_away_under_65+"', " #834
        query_commit += " pre_corners_asian_handicap_home_min_65 = '"+pre_corners_asian_handicap_home_min_65+"', " #835
        query_commit += " pre_corners_asian_handicap_away_min_65 = '"+pre_corners_asian_handicap_away_min_65+"', " #836
        query_commit += " pre_corners_asian_handicap_home_min_6 = '"+pre_corners_asian_handicap_home_min_6+"', " #837
        query_commit += " pre_corners_asian_handicap_away_min_6 = '"+pre_corners_asian_handicap_away_min_6+"', " #838
        query_commit += " pre_corners_asian_handicap_home_min_55 = '"+pre_corners_asian_handicap_home_min_55+"', " #839
        query_commit += " pre_corners_asian_handicap_away_min_55 = '"+pre_corners_asian_handicap_away_min_55+"', " #840
        query_commit += " pre_corners_asian_handicap_home_min_5 = '"+pre_corners_asian_handicap_home_min_5+"', " #841
        query_commit += " pre_corners_asian_handicap_away_min_5 = '"+pre_corners_asian_handicap_away_min_5+"', " #842
        query_commit += " pre_corners_asian_handicap_home_min_45 = '"+pre_corners_asian_handicap_home_min_45+"', " #843
        query_commit += " pre_corners_asian_handicap_away_min_45 = '"+pre_corners_asian_handicap_away_min_45+"', " #844
        query_commit += " pre_corners_asian_handicap_home_min_4 = '"+pre_corners_asian_handicap_home_min_4+"', " #845
        query_commit += " pre_corners_asian_handicap_away_min_4 = '"+pre_corners_asian_handicap_away_min_4+"', " #846
        query_commit += " pre_corners_asian_handicap_home_min_35 = '"+pre_corners_asian_handicap_home_min_35+"', " #847
        query_commit += " pre_corners_asian_handicap_away_min_35 = '"+pre_corners_asian_handicap_away_min_35+"', " #848
        query_commit += " pre_corners_asian_handicap_home_min_3 = '"+pre_corners_asian_handicap_home_min_3+"', " #849
        query_commit += " pre_corners_asian_handicap_away_min_3 = '"+pre_corners_asian_handicap_away_min_3+"', " #850
        query_commit += " pre_corners_asian_handicap_home_min_25 = '"+pre_corners_asian_handicap_home_min_25+"', " #851
        query_commit += " pre_corners_asian_handicap_away_min_25 = '"+pre_corners_asian_handicap_away_min_25+"', " #852
        query_commit += " pre_corners_asian_handicap_home_min_2 = '"+pre_corners_asian_handicap_home_min_2+"', " #853
        query_commit += " pre_corners_asian_handicap_away_min_2 = '"+pre_corners_asian_handicap_away_min_2+"', " #854
        query_commit += " pre_corners_asian_handicap_home_min_15 = '"+pre_corners_asian_handicap_home_min_15+"', " #855
        query_commit += " pre_corners_asian_handicap_away_min_15 = '"+pre_corners_asian_handicap_away_min_15+"', " #856
        query_commit += " pre_corners_asian_handicap_home_min_1 = '"+pre_corners_asian_handicap_home_min_1+"', " #857
        query_commit += " pre_corners_asian_handicap_home_min_05 = '"+pre_corners_asian_handicap_home_min_05+"', " #858
        query_commit += " pre_corners_asian_handicap_away_min_1 = '"+pre_corners_asian_handicap_away_min_1+"', " #859
        query_commit += " pre_corners_asian_handicap_away_min_05 = '"+pre_corners_asian_handicap_away_min_05+"', " #860
        query_commit += " pre_corners_asian_handicap_home_plus_0 = '"+pre_corners_asian_handicap_home_plus_0+"', " #861
        query_commit += " pre_corners_asian_handicap_away_plus_0 = '"+pre_corners_asian_handicap_away_plus_0+"', " #862
        query_commit += " pre_corners_asian_handicap_home_plus_05 = '"+pre_corners_asian_handicap_home_plus_05+"', " #863
        query_commit += " pre_corners_asian_handicap_away_plus_05 = '"+pre_corners_asian_handicap_away_plus_05+"', " #864
        query_commit += " pre_corners_asian_handicap_home_plus_1 = '"+pre_corners_asian_handicap_home_plus_1+"', " #865
        query_commit += " pre_corners_asian_handicap_away_plus_1 = '"+pre_corners_asian_handicap_away_plus_1+"', " #866
        query_commit += " pre_corners_asian_handicap_home_plus_15 = '"+pre_corners_asian_handicap_home_plus_15+"', " #867
        query_commit += " pre_corners_asian_handicap_away_plus_15 = '"+pre_corners_asian_handicap_away_plus_15+"', " #868
        query_commit += " pre_corners_asian_handicap_home_plus_2 = '"+pre_corners_asian_handicap_home_plus_2+"', " #869
        query_commit += " pre_corners_asian_handicap_away_plus_2 = '"+pre_corners_asian_handicap_away_plus_2+"', " #870
        query_commit += " pre_corners_asian_handicap_home_plus_25 = '"+pre_corners_asian_handicap_home_plus_25+"', " #871
        query_commit += " pre_corners_asian_handicap_away_plus_25 = '"+pre_corners_asian_handicap_away_plus_25+"', " #872
        query_commit += " pre_corners_asian_handicap_home_plus_3 = '"+pre_corners_asian_handicap_home_plus_3+"', " #873
        query_commit += " pre_corners_asian_handicap_away_plus_3 = '"+pre_corners_asian_handicap_away_plus_3+"', " #874
        query_commit += " pre_corners_asian_handicap_home_plus_35 = '"+pre_corners_asian_handicap_home_plus_35+"', " #875
        query_commit += " pre_corners_asian_handicap_away_plus_35 = '"+pre_corners_asian_handicap_away_plus_35+"', " #876
        query_commit += " pre_corners_asian_handicap_home_plus_4 = '"+pre_corners_asian_handicap_home_plus_4+"', " #877
        query_commit += " pre_corners_asian_handicap_away_plus_4 = '"+pre_corners_asian_handicap_away_plus_4+"', " #878
        query_commit += " pre_corners_asian_handicap_home_plus_45 = '"+pre_corners_asian_handicap_home_plus_45+"', " #879
        query_commit += " pre_corners_asian_handicap_away_plus_45 = '"+pre_corners_asian_handicap_away_plus_45+"', " #880
        query_commit += " pre_corners_asian_handicap_home_plus_5 = '"+pre_corners_asian_handicap_home_plus_5+"', " #881
        query_commit += " pre_corners_asian_handicap_away_plus_5 = '"+pre_corners_asian_handicap_away_plus_5+"', " #882
        query_commit += " pre_corners_asian_handicap_home_plus_55 = '"+pre_corners_asian_handicap_home_plus_55+"', " #883
        query_commit += " pre_corners_asian_handicap_away_plus_55 = '"+pre_corners_asian_handicap_away_plus_55+"', " #884
        query_commit += " pre_corners_asian_handicap_home_plus_6 = '"+pre_corners_asian_handicap_home_plus_6+"', " #885
        query_commit += " pre_corners_asian_handicap_away_plus_6 = '"+pre_corners_asian_handicap_away_plus_6+"', " #886
        query_commit += " pre_corners_asian_handicap_home_plus_65 = '"+pre_corners_asian_handicap_home_plus_65+"', " #887
        query_commit += " pre_corners_asian_handicap_away_plus_65 = '"+pre_corners_asian_handicap_away_plus_65+"', " #888
        query_commit += " end_corners_asian_handicap_home_min_65 = '"+end_corners_asian_handicap_home_min_65+"', " #889
        query_commit += " end_corners_asian_handicap_away_min_65 = '"+end_corners_asian_handicap_away_min_65+"', " #890
        query_commit += " end_corners_asian_handicap_home_min_6 = '"+end_corners_asian_handicap_home_min_6+"', " #891
        query_commit += " end_corners_asian_handicap_away_min_6 = '"+end_corners_asian_handicap_away_min_6+"', " #892
        query_commit += " end_corners_asian_handicap_home_min_55 = '"+end_corners_asian_handicap_home_min_55+"', " #893
        query_commit += " end_corners_asian_handicap_away_min_55 = '"+end_corners_asian_handicap_away_min_55+"', " #894

        query_commit += " end_corners_asian_handicap_home_min_5 = '"+end_corners_asian_handicap_home_min_5+"', " #895
        query_commit += " end_corners_asian_handicap_away_min_5 = '"+end_corners_asian_handicap_away_min_5+"', " #896
        query_commit += " end_corners_asian_handicap_home_min_45 = '"+end_corners_asian_handicap_home_min_45+"', " #897
        query_commit += " end_corners_asian_handicap_away_min_45 = '"+end_corners_asian_handicap_away_min_45+"', " #898
        query_commit += " end_corners_asian_handicap_home_min_4 = '"+end_corners_asian_handicap_home_min_4+"', " #899
        query_commit += " end_corners_asian_handicap_away_min_4 = '"+end_corners_asian_handicap_away_min_4+"', " #900
        query_commit += " end_corners_asian_handicap_home_min_35 = '"+end_corners_asian_handicap_home_min_35+"', " #901
        query_commit += " end_corners_asian_handicap_away_min_35 = '"+end_corners_asian_handicap_away_min_35+"', " #902
        query_commit += " end_corners_asian_handicap_home_min_3 = '"+end_corners_asian_handicap_home_min_3+"', " #903
        query_commit += " end_corners_asian_handicap_away_min_3 = '"+end_corners_asian_handicap_away_min_3+"', " #904
        query_commit += " end_corners_asian_handicap_home_min_25 = '"+end_corners_asian_handicap_home_min_25+"', " #905
        query_commit += " end_corners_asian_handicap_away_min_25 = '"+end_corners_asian_handicap_away_min_25+"', " #906
        query_commit += " end_corners_asian_handicap_home_min_2 = '"+end_corners_asian_handicap_home_min_2+"', " #907
        query_commit += " end_corners_asian_handicap_away_min_2 = '"+end_corners_asian_handicap_away_min_2+"', " #908
        query_commit += " end_corners_asian_handicap_home_min_15 = '"+end_corners_asian_handicap_home_min_15+"', " #909
        query_commit += " end_corners_asian_handicap_away_min_15 = '"+end_corners_asian_handicap_away_min_15+"', " #910
        query_commit += " end_corners_asian_handicap_home_min_1 = '"+end_corners_asian_handicap_home_min_1+"', " #911
        query_commit += " end_corners_asian_handicap_home_min_05 = '"+end_corners_asian_handicap_home_min_05+"', " #912
        query_commit += " end_corners_asian_handicap_away_min_1 = '"+end_corners_asian_handicap_away_min_1+"', " #913
        query_commit += " end_corners_asian_handicap_away_min_05 = '"+end_corners_asian_handicap_away_min_05+"', " #914
        query_commit += " end_corners_asian_handicap_home_plus_0 = '"+end_corners_asian_handicap_home_plus_0+"', " #915
        query_commit += " end_corners_asian_handicap_away_plus_0 = '"+end_corners_asian_handicap_away_plus_0+"', " #916
        query_commit += " end_corners_asian_handicap_home_plus_05 = '"+end_corners_asian_handicap_home_plus_05+"', " #917
        query_commit += " end_corners_asian_handicap_away_plus_05 = '"+end_corners_asian_handicap_away_plus_05+"', " #918
        query_commit += " end_corners_asian_handicap_home_plus_1 = '"+end_corners_asian_handicap_home_plus_1+"', " #919
        query_commit += " end_corners_asian_handicap_away_plus_1 = '"+end_corners_asian_handicap_away_plus_1+"', " #920
        query_commit += " end_corners_asian_handicap_home_plus_15 = '"+end_corners_asian_handicap_home_plus_15+"', " #921
        query_commit += " end_corners_asian_handicap_away_plus_15 = '"+end_corners_asian_handicap_away_plus_15+"', " #922
        query_commit += " end_corners_asian_handicap_home_plus_2 = '"+end_corners_asian_handicap_home_plus_2+"', " #923
        query_commit += " end_corners_asian_handicap_away_plus_2 = '"+end_corners_asian_handicap_away_plus_2+"', " #924
        query_commit += " end_corners_asian_handicap_home_plus_25 = '"+end_corners_asian_handicap_home_plus_25+"', " #925
        query_commit += " end_corners_asian_handicap_away_plus_25 = '"+end_corners_asian_handicap_away_plus_25+"', " #926
        query_commit += " end_corners_asian_handicap_home_plus_3 = '"+end_corners_asian_handicap_home_plus_3+"', " #927
        query_commit += " end_corners_asian_handicap_away_plus_3 = '"+end_corners_asian_handicap_away_plus_3+"', " #928
        query_commit += " end_corners_asian_handicap_home_plus_35 = '"+end_corners_asian_handicap_home_plus_35+"', " #929
        query_commit += " end_corners_asian_handicap_away_plus_35 = '"+end_corners_asian_handicap_away_plus_35+"', " #930
        query_commit += " end_corners_asian_handicap_home_plus_4 = '"+end_corners_asian_handicap_home_plus_4+"', " #931
        query_commit += " end_corners_asian_handicap_away_plus_4 = '"+end_corners_asian_handicap_away_plus_4+"', " #932
        query_commit += " end_corners_asian_handicap_home_plus_45 = '"+end_corners_asian_handicap_home_plus_45+"', " #933
        query_commit += " end_corners_asian_handicap_away_plus_45 = '"+end_corners_asian_handicap_away_plus_45+"', " #934
        query_commit += " end_corners_asian_handicap_home_plus_5 = '"+end_corners_asian_handicap_home_plus_5+"', " #935
        query_commit += " end_corners_asian_handicap_away_plus_5 = '"+end_corners_asian_handicap_away_plus_5+"', " #936
        query_commit += " end_corners_asian_handicap_home_plus_55 = '"+end_corners_asian_handicap_home_plus_55+"', " #937
        query_commit += " end_corners_asian_handicap_away_plus_55 = '"+end_corners_asian_handicap_away_plus_55+"', " #938
        query_commit += " end_corners_asian_handicap_home_plus_6 = '"+end_corners_asian_handicap_home_plus_6+"', " #939
        query_commit += " end_corners_asian_handicap_away_plus_6 = '"+end_corners_asian_handicap_away_plus_6+"', " #940
        query_commit += " end_corners_asian_handicap_home_plus_65 = '"+end_corners_asian_handicap_home_plus_65+"', " #941
        query_commit += " end_corners_asian_handicap_away_plus_65 = '"+end_corners_asian_handicap_away_plus_65+"', " #942
        query_commit += " pre_corners_over_under_over_700 = '"+pre_corners_over_under_over_700+"', " #943
        query_commit += " pre_corners_over_under_under_700 = '"+pre_corners_over_under_under_700+"', " #944
        query_commit += " pre_corners_over_under_over_725 = '"+pre_corners_over_under_over_725+"', " #945
        query_commit += " pre_corners_over_under_under_725 = '"+pre_corners_over_under_under_725+"', " #946
        query_commit += " pre_corners_over_under_over_750 = '"+pre_corners_over_under_over_750+"', " #947
        query_commit += " pre_corners_over_under_under_750 = '"+pre_corners_over_under_under_750+"', " #948
        query_commit += " pre_corners_over_under_over_775 = '"+pre_corners_over_under_over_775+"', " #949
        query_commit += " pre_corners_over_under_under_775 = '"+pre_corners_over_under_under_775+"', " #950
        query_commit += " pre_corners_over_under_over_800 = '"+pre_corners_over_under_over_800+"', " #951
        query_commit += " pre_corners_over_under_under_800 = '"+pre_corners_over_under_under_800+"', " #952
        query_commit += " pre_corners_over_under_over_825 = '"+pre_corners_over_under_over_825+"', " #953
        query_commit += " pre_corners_over_under_under_825 = '"+pre_corners_over_under_under_825+"', " #954
        query_commit += " pre_corners_over_under_over_850 = '"+pre_corners_over_under_over_850+"', " #955
        query_commit += " pre_corners_over_under_under_850 = '"+pre_corners_over_under_under_850+"', " #956
        query_commit += " pre_corners_over_under_over_875 = '"+pre_corners_over_under_over_875+"', " #957
        query_commit += " pre_corners_over_under_under_875 = '"+pre_corners_over_under_under_875+"', " #958
        query_commit += " pre_corners_over_under_over_900 = '"+pre_corners_over_under_over_900+"', " #959
        query_commit += " pre_corners_over_under_under_900 = '"+pre_corners_over_under_under_900+"', " #960
        query_commit += " pre_corners_over_under_over_925 = '"+pre_corners_over_under_over_925+"', " #961
        query_commit += " pre_corners_over_under_under_925 = '"+pre_corners_over_under_under_925+"', " #962
        query_commit += " pre_corners_over_under_over_950 = '"+pre_corners_over_under_over_950+"', " #963
        query_commit += " pre_corners_over_under_under_950 = '"+pre_corners_over_under_under_950+"', " #964
        query_commit += " pre_corners_over_under_over_975 = '"+pre_corners_over_under_over_975+"', " #965
        query_commit += " pre_corners_over_under_under_975 = '"+pre_corners_over_under_under_975+"', " #966
        query_commit += " pre_corners_over_under_over_1000 = '"+pre_corners_over_under_over_1000+"', " #967
        query_commit += " pre_corners_over_under_under_1000 = '"+pre_corners_over_under_under_1000+"', " #968
        query_commit += " pre_corners_over_under_over_1025 = '"+pre_corners_over_under_over_1025+"', " #969
        query_commit += " pre_corners_over_under_under_1025 = '"+pre_corners_over_under_under_1025+"', " #970
        query_commit += " pre_corners_over_under_over_1050 = '"+pre_corners_over_under_over_1050+"', " #971

        query_commit += " pre_corners_over_under_under_1050 = '"+pre_corners_over_under_under_1050+"', " #972
        query_commit += " pre_corners_over_under_over_1075 = '"+pre_corners_over_under_over_1075+"', " #973
        query_commit += " pre_corners_over_under_under_1075 = '"+pre_corners_over_under_under_1075+"', " #974
        query_commit += " pre_corners_over_under_over_1100 = '"+pre_corners_over_under_over_1100+"', " #975
        query_commit += " pre_corners_over_under_under_1100 = '"+pre_corners_over_under_under_1100+"', " #976
        query_commit += " pre_corners_over_under_over_1125 = '"+pre_corners_over_under_over_1125+"', " #977
        query_commit += " pre_corners_over_under_under_1125 = '"+pre_corners_over_under_under_1125+"', " #978
        query_commit += " pre_corners_over_under_over_1150 = '"+pre_corners_over_under_over_1150+"', " #979
        query_commit += " pre_corners_over_under_under_1150 = '"+pre_corners_over_under_under_1150+"', " #980
        query_commit += " pre_corners_over_under_over_1175 = '"+pre_corners_over_under_over_1175+"', " #981
        query_commit += " pre_corners_over_under_under_1175 = '"+pre_corners_over_under_under_1175+"', " #982
        query_commit += " pre_corners_over_under_over_1200 = '"+pre_corners_over_under_over_1200+"', " #983
        query_commit += " pre_corners_over_under_under_1200 = '"+pre_corners_over_under_under_1200+"', " #984
        query_commit += " pre_corners_over_under_over_1225 = '"+pre_corners_over_under_over_1225+"', " #985
        query_commit += " pre_corners_over_under_under_1225 = '"+pre_corners_over_under_under_1225+"', " #986
        query_commit += " pre_corners_over_under_over_1250 = '"+pre_corners_over_under_over_1250+"', " #987
        query_commit += " pre_corners_over_under_under_1250 = '"+pre_corners_over_under_under_1250+"', " #988
        query_commit += " pre_corners_over_under_over_1275 = '"+pre_corners_over_under_over_1275+"', " #989
        query_commit += " pre_corners_over_under_under_1275 = '"+pre_corners_over_under_under_1275+"', " #990
        query_commit += " end_corners_over_under_over_700 = '"+end_corners_over_under_over_700+"', " #991
        query_commit += " end_corners_over_under_under_700 = '"+end_corners_over_under_under_700+"', " #992
        query_commit += " end_corners_over_under_over_725 = '"+end_corners_over_under_over_725+"', " #993
        query_commit += " end_corners_over_under_under_725 = '"+end_corners_over_under_under_725+"', " #994
        query_commit += " end_corners_over_under_over_750 = '"+end_corners_over_under_over_750+"', " #995
        query_commit += " end_corners_over_under_under_750 = '"+end_corners_over_under_under_750+"', " #996
        query_commit += " end_corners_over_under_over_775 = '"+end_corners_over_under_over_775+"', " #997
        query_commit += " end_corners_over_under_under_775 = '"+end_corners_over_under_under_775+"', " #998
        query_commit += " end_corners_over_under_over_800 = '"+end_corners_over_under_over_800+"', " #999
        query_commit += " end_corners_over_under_under_800 = '"+end_corners_over_under_under_800+"', " #1000
        query_commit += " end_corners_over_under_over_825 = '"+end_corners_over_under_over_825+"', " #1001
        query_commit += " end_corners_over_under_under_825 = '"+end_corners_over_under_under_825+"', " #1002
        query_commit += " end_corners_over_under_over_850 = '"+end_corners_over_under_over_850+"', " #1003
        query_commit += " end_corners_over_under_under_850 = '"+end_corners_over_under_under_850+"', " #1004
        query_commit += " end_corners_over_under_over_875 = '"+end_corners_over_under_over_875+"', " #1005
        query_commit += " end_corners_over_under_under_875 = '"+end_corners_over_under_under_875+"', " #1006
        query_commit += " end_corners_over_under_over_900 = '"+end_corners_over_under_over_900+"', " #1007
        query_commit += " end_corners_over_under_under_900 = '"+end_corners_over_under_under_900+"', " #1008
        query_commit += " end_corners_over_under_over_925 = '"+end_corners_over_under_over_925+"', " #1009
        query_commit += " end_corners_over_under_under_925 = '"+end_corners_over_under_under_925+"', " #1010
        query_commit += " end_corners_over_under_over_950 = '"+end_corners_over_under_over_950+"', " #1011
        query_commit += " end_corners_over_under_under_950 = '"+end_corners_over_under_under_950+"', " #1012
        query_commit += " end_corners_over_under_over_975 = '"+end_corners_over_under_over_975+"', " #1013
        query_commit += " end_corners_over_under_under_975 = '"+end_corners_over_under_under_975+"', " #1014
        query_commit += " end_corners_over_under_over_1000 = '"+end_corners_over_under_over_1000+"', " #1015
        query_commit += " end_corners_over_under_under_1000 = '"+end_corners_over_under_under_1000+"', " #1016
        query_commit += " end_corners_over_under_over_1025 = '"+end_corners_over_under_over_1025+"', " #1017
        query_commit += " end_corners_over_under_under_1025 = '"+end_corners_over_under_under_1025+"', " #1018
        query_commit += " end_corners_over_under_over_1050 = '"+end_corners_over_under_over_1050+"', " #1019
        query_commit += " end_corners_over_under_under_1050 = '"+end_corners_over_under_under_1050+"', " #1020
        query_commit += " end_corners_over_under_over_1075 = '"+end_corners_over_under_over_1075+"', " #1021
        query_commit += " end_corners_over_under_under_1075 = '"+end_corners_over_under_under_1075+"', " #1022
        query_commit += " end_corners_over_under_over_1100 = '"+end_corners_over_under_over_1100+"', " #1023
        query_commit += " end_corners_over_under_under_1100 = '"+end_corners_over_under_under_1100+"', " #1024
        query_commit += " end_corners_over_under_over_1125 = '"+end_corners_over_under_over_1125+"', " #1025
        query_commit += " end_corners_over_under_under_1125 = '"+end_corners_over_under_under_1125+"', " #1026
        query_commit += " end_corners_over_under_over_1150 = '"+end_corners_over_under_over_1150+"', " #1027
        query_commit += " end_corners_over_under_under_1150 = '"+end_corners_over_under_under_1150+"', " #1028
        query_commit += " end_corners_over_under_over_1175 = '"+end_corners_over_under_over_1175+"', " #1029
        query_commit += " end_corners_over_under_under_1175 = '"+end_corners_over_under_under_1175+"', " #1030
        query_commit += " end_corners_over_under_over_1200 = '"+end_corners_over_under_over_1200+"', " #1031
        query_commit += " end_corners_over_under_under_1200 = '"+end_corners_over_under_under_1200+"', " #1032
        query_commit += " end_corners_over_under_over_1225 = '"+end_corners_over_under_over_1225+"', " #1033
        query_commit += " end_corners_over_under_under_1225 = '"+end_corners_over_under_under_1225+"', " #1034
        query_commit += " end_corners_over_under_over_1250 = '"+end_corners_over_under_over_1250+"', " #1035
        query_commit += " end_corners_over_under_under_1250 = '"+end_corners_over_under_under_1250+"', " #1036
        query_commit += " end_corners_over_under_over_1275 = '"+end_corners_over_under_over_1275+"', " #1037
        query_commit += " end_corners_over_under_under_1275 = '"+end_corners_over_under_under_1275+"', " #1038
        query_commit += " pre_home_corners_overunder_over_25 = '"+pre_home_corners_overunder_over_25+"', " #1039
        query_commit += " pre_home_corners_overunder_under_25 = '"+pre_home_corners_overunder_under_25+"', " #1040
        query_commit += " pre_home_corners_overunder_over_35 = '"+pre_home_corners_overunder_over_35+"', " #1041
        query_commit += " pre_home_corners_overunder_under_35 = '"+pre_home_corners_overunder_under_35+"', " #1042
        query_commit += " pre_home_corners_overunder_over_45 = '"+pre_home_corners_overunder_over_45+"', " #1043
        query_commit += " pre_home_corners_overunder_under_45 = '"+pre_home_corners_overunder_under_45+"', " #1044
        query_commit += " pre_home_corners_overunder_over_55 = '"+pre_home_corners_overunder_over_55+"', " #1045
        query_commit += " pre_home_corners_overunder_under_55 = '"+pre_home_corners_overunder_under_55+"', " #1046
        query_commit += " pre_home_corners_overunder_over_65 = '"+pre_home_corners_overunder_over_65+"', " #1047
        query_commit += " pre_home_corners_overunder_under_65 = '"+pre_home_corners_overunder_under_65+"', " #1048
        query_commit += " pre_home_corners_overunder_over_75 = '"+pre_home_corners_overunder_over_75+"', " #1049
        query_commit += " pre_home_corners_overunder_under_75 = '"+pre_home_corners_overunder_under_75+"', " #1050
        query_commit += " pre_home_corners_overunder_over_85 = '"+pre_home_corners_overunder_over_85+"', " #1051
        query_commit += " pre_home_corners_overunder_under_85 = '"+pre_home_corners_overunder_under_85+"', " #1052

        query_commit += " end_home_corners_overunder_over_25 = '"+end_home_corners_overunder_over_25+"', " #1053
        query_commit += " end_home_corners_overunder_under_25 = '"+end_home_corners_overunder_under_25+"', " #1054
        query_commit += " end_home_corners_overunder_over_35 = '"+end_home_corners_overunder_over_35+"', " #1055
        query_commit += " end_home_corners_overunder_under_35 = '"+end_home_corners_overunder_under_35+"', " #1056
        query_commit += " end_home_corners_overunder_over_45 = '"+end_home_corners_overunder_over_45+"', " #1057
        query_commit += " end_home_corners_overunder_under_45 = '"+end_home_corners_overunder_under_45+"', " #1058
        query_commit += " end_home_corners_overunder_over_55 = '"+end_home_corners_overunder_over_55+"', " #1059
        query_commit += " end_home_corners_overunder_under_55 = '"+end_home_corners_overunder_under_55+"', " #1060
        query_commit += " end_home_corners_overunder_over_65 = '"+end_home_corners_overunder_over_65+"', " #1061
        query_commit += " end_home_corners_overunder_under_65 = '"+end_home_corners_overunder_under_65+"', " #1062
        query_commit += " end_home_corners_overunder_over_75 = '"+end_home_corners_overunder_over_75+"', " #1063
        query_commit += " end_home_corners_overunder_under_75 = '"+end_home_corners_overunder_under_75+"', " #1064
        query_commit += " end_home_corners_overunder_over_85 = '"+end_home_corners_overunder_over_85+"', " #1065
        query_commit += " end_home_corners_overunder_under_85 = '"+end_home_corners_overunder_under_85+"', " #1066
        query_commit += " pre_away_corners_overunder_over_25 = '"+pre_away_corners_overunder_over_25+"', " #1067
        query_commit += " pre_away_corners_overunder_under_25 = '"+pre_away_corners_overunder_under_25+"', " #1068
        query_commit += " pre_away_corners_overunder_over_35 = '"+pre_away_corners_overunder_over_35+"', " #1069
        query_commit += " pre_away_corners_overunder_under_35 = '"+pre_away_corners_overunder_under_35+"', " #1070
        query_commit += " pre_away_corners_overunder_over_45 = '"+pre_away_corners_overunder_over_45+"', " #1071
        query_commit += " pre_away_corners_overunder_under_45 = '"+pre_away_corners_overunder_under_45+"', " #1072
        query_commit += " pre_away_corners_overunder_over_55 = '"+pre_away_corners_overunder_over_55+"', " #1073
        query_commit += " pre_away_corners_overunder_under_55 = '"+pre_away_corners_overunder_under_55+"', " #1074
        query_commit += " pre_away_corners_overunder_over_65 = '"+pre_away_corners_overunder_over_65+"', " #1075
        query_commit += " pre_away_corners_overunder_under_65 = '"+pre_away_corners_overunder_under_65+"', " #1076
        query_commit += " pre_away_corners_overunder_over_75 = '"+pre_away_corners_overunder_over_75+"', " #1077
        query_commit += " pre_away_corners_overunder_under_75 = '"+pre_away_corners_overunder_under_75+"', " #1078
        query_commit += " pre_away_corners_overunder_over_85 = '"+pre_away_corners_overunder_over_85+"', " #1079
        query_commit += " pre_away_corners_overunder_under_85 = '"+pre_away_corners_overunder_under_85+"', " #1080
        query_commit += " end_away_corners_overunder_over_25 = '"+end_away_corners_overunder_over_25+"', " #1081
        query_commit += " end_away_corners_overunder_under_25 = '"+end_away_corners_overunder_under_25+"', " #1082
        query_commit += " end_away_corners_overunder_over_35 = '"+end_away_corners_overunder_over_35+"', " #1083
        query_commit += " end_away_corners_overunder_under_35 = '"+end_away_corners_overunder_under_35+"', " #1084
        query_commit += " end_away_corners_overunder_over_45 = '"+end_away_corners_overunder_over_45+"', " #1085
        query_commit += " end_away_corners_overunder_under_45 = '"+end_away_corners_overunder_under_45+"', " #1086
        query_commit += " end_away_corners_overunder_over_55 = '"+end_away_corners_overunder_over_55+"', " #1087
        query_commit += " end_away_corners_overunder_under_55 = '"+end_away_corners_overunder_under_55+"', " #1088
        query_commit += " end_away_corners_overunder_over_65 = '"+end_away_corners_overunder_over_65+"', " #1089
        query_commit += " end_away_corners_overunder_under_65 = '"+end_away_corners_overunder_under_65+"', " #1090
        query_commit += " end_away_corners_overunder_over_75 = '"+end_away_corners_overunder_over_75+"', " #1091
        query_commit += " end_away_corners_overunder_under_75 = '"+end_away_corners_overunder_under_75+"', " #1092
        query_commit += " end_away_corners_overunder_over_85 = '"+end_away_corners_overunder_over_85+"', " #1093
        query_commit += " end_away_corners_overunder_under_85 = '"+end_away_corners_overunder_under_85+"', " #1094
        query_commit += " pre_first_corner_home = '"+pre_first_corner_home+"', " #1095
        query_commit += " pre_first_corner_away = '"+pre_first_corner_away+"', " #1096
        query_commit += " end_first_corner_home = '"+end_first_corner_home+"', " #1097
        query_commit += " end_first_corner_away = '"+end_first_corner_away+"', " #1098
        query_commit += " pre_last_corner_home = '"+pre_last_corner_home+"', " #1099
        query_commit += " pre_last_corner_away = '"+pre_last_corner_away+"', " #1100
        query_commit += " end_last_corner_home = '"+end_last_corner_home+"', " #1101
        query_commit += " end_last_corner_away = '"+end_last_corner_away+"', " #1102
        query_commit += " pre_cards_asian_handicap_home_min_05 = '"+pre_cards_asian_handicap_home_min_05+"', " #1103
        query_commit += " pre_cards_asian_handicap_away_min_05 = '"+pre_cards_asian_handicap_away_min_05+"', " #1104
        query_commit += " pre_cards_asian_handicap_home_plus_0 = '"+pre_cards_asian_handicap_home_plus_0+"', " #1105
        query_commit += " pre_cards_asian_handicap_away_plus_0 = '"+pre_cards_asian_handicap_away_plus_0+"', " #1106
        query_commit += " pre_cards_asian_handicap_home_plus_05 = '"+pre_cards_asian_handicap_home_plus_05+"', " #1107
        query_commit += " pre_cards_asian_handicap_away_plus_05 = '"+pre_cards_asian_handicap_away_plus_05+"', " #1108
        query_commit += " end_cards_asian_handicap_home_min_05 = '"+end_cards_asian_handicap_home_min_05+"', " #1109
        query_commit += " end_cards_asian_handicap_away_min_05 = '"+end_cards_asian_handicap_away_min_05+"', " #1110
        query_commit += " end_cards_asian_handicap_home_plus_0 = '"+end_cards_asian_handicap_home_plus_0+"', " #1111
        query_commit += " end_cards_asian_handicap_away_plus_0 = '"+end_cards_asian_handicap_away_plus_0+"', " #1112
        query_commit += " end_cards_asian_handicap_home_plus_05 = '"+end_cards_asian_handicap_home_plus_05+"', " #1113
        query_commit += " end_cards_asian_handicap_away_plus_05 = '"+end_cards_asian_handicap_away_plus_05+"', " #1114
        query_commit += " pre_cards_overunder_over_25 = '"+pre_cards_overunder_over_25+"', " #1115
        query_commit += " pre_cards_overunder_under_25 = '"+pre_cards_overunder_under_25+"', " #1116
        query_commit += " pre_cards_overunder_over_35 = '"+pre_cards_overunder_over_35+"', " #1117
        query_commit += " pre_cards_overunder_under_35 = '"+pre_cards_overunder_under_35+"', " #1118
        query_commit += " pre_cards_overunder_over_45 = '"+pre_cards_overunder_over_45+"', " #1119
        query_commit += " pre_cards_overunder_under_45 = '"+pre_cards_overunder_under_45+"', " #1120
        query_commit += " pre_cards_overunder_over_55 = '"+pre_cards_overunder_over_55+"', " #1121
        query_commit += " pre_cards_overunder_under_55 = '"+pre_cards_overunder_under_55+"', " #1122
        query_commit += " pre_cards_overunder_over_65 = '"+pre_cards_overunder_over_65+"', " #1123
        query_commit += " pre_cards_overunder_under_65 = '"+pre_cards_overunder_under_65+"', " #1124
        query_commit += " pre_cards_overunder_over_75 = '"+pre_cards_overunder_over_75+"', " #1125
        query_commit += " pre_cards_overunder_under_75 = '"+pre_cards_overunder_under_75+"', " #1126
        query_commit += " end_cards_overunder_over_25 = '"+end_cards_overunder_over_25+"', " #1127
        query_commit += " end_cards_overunder_under_25 = '"+end_cards_overunder_under_25+"', " #1128
        query_commit += " end_cards_overunder_over_35 = '"+end_cards_overunder_over_35+"', " #1129
        query_commit += " end_cards_overunder_under_35 = '"+end_cards_overunder_under_35+"', " #1130
        query_commit += " end_cards_overunder_over_45 = '"+end_cards_overunder_over_45+"', " #1131
        query_commit += " end_cards_overunder_under_45 = '"+end_cards_overunder_under_45+"', " #1132
        query_commit += " end_cards_overunder_over_55 = '"+end_cards_overunder_over_55+"', " #1133
        query_commit += " end_cards_overunder_under_55 = '"+end_cards_overunder_under_55+"', " #1134

        query_commit += " end_cards_overunder_over_65 = '"+end_cards_overunder_over_65+"', " #1135
        query_commit += " end_cards_overunder_under_65 = '"+end_cards_overunder_under_65+"', " #1136
        query_commit += " end_cards_overunder_over_75 = '"+end_cards_overunder_over_75+"', " #1137
        query_commit += " end_cards_overunder_under_75 = '"+end_cards_overunder_under_75+"', " #1138
        query_commit += " pre_home_team_total_cards_over_15 = '"+pre_home_team_total_cards_over_15+"', " #1139
        query_commit += " pre_home_team_total_cards_under_15 = '"+pre_home_team_total_cards_under_15+"', " #1140
        query_commit += " pre_home_team_total_cards_over_25 = '"+pre_home_team_total_cards_over_25+"', " #1141
        query_commit += " pre_home_team_total_cards_under_25 = '"+pre_home_team_total_cards_under_25+"', " #1142
        query_commit += " pre_home_team_total_cards_over_35 = '"+pre_home_team_total_cards_over_35+"', " #1143
        query_commit += " pre_home_team_total_cards_under_35 = '"+pre_home_team_total_cards_under_35+"', " #1144
        query_commit += " end_home_team_total_cards_over_15 = '"+end_home_team_total_cards_over_15+"', " #1145
        query_commit += " end_home_team_total_cards_under_15 = '"+end_home_team_total_cards_under_15+"', " #1146
        query_commit += " end_home_team_total_cards_over_25 = '"+end_home_team_total_cards_over_25+"', " #1147
        query_commit += " end_home_team_total_cards_under_25 = '"+end_home_team_total_cards_under_25+"', " #1148
        query_commit += " end_home_team_total_cards_over_35 = '"+end_home_team_total_cards_over_35+"', " #1149
        query_commit += " end_home_team_total_cards_under_35 = '"+end_home_team_total_cards_under_35+"', " #1150
        query_commit += " pre_away_team_total_cards_over_15 = '"+pre_away_team_total_cards_over_15+"', " #1151
        query_commit += " pre_away_team_total_cards_under_15 = '"+pre_away_team_total_cards_under_15+"', " #1152
        query_commit += " pre_away_team_total_cards_over_25 = '"+pre_away_team_total_cards_over_25+"', " #1153
        query_commit += " pre_away_team_total_cards_under_25 = '"+pre_away_team_total_cards_under_25+"', " #1154
        query_commit += " pre_away_team_total_cards_over_35 = '"+pre_away_team_total_cards_over_35+"', " #1155
        query_commit += " pre_away_team_total_cards_under_35 = '"+pre_away_team_total_cards_under_35+"', " #1156
        query_commit += " end_away_team_total_cards_over_15 = '"+end_away_team_total_cards_over_15+"', " #1157
        query_commit += " end_away_team_total_cards_under_15 = '"+end_away_team_total_cards_under_15+"', " #1158
        query_commit += " end_away_team_total_cards_over_25 = '"+end_away_team_total_cards_over_25+"', " #1159
        query_commit += " end_away_team_total_cards_under_25 = '"+end_away_team_total_cards_under_25+"', " #1160
        query_commit += " end_away_team_total_cards_over_35 = '"+end_away_team_total_cards_over_35+"', " #1161
        query_commit += " end_away_team_total_cards_under_35 = '"+end_away_team_total_cards_under_35+"', " #1162
        query_commit += " pre_total_goals_under_2 = '"+pre_total_goals_under_2+"', " #1163
        query_commit += " pre_total_goals_2_or_3 = '"+pre_total_goals_2_or_3+"', " #1164
        query_commit += " pre_total_goals_over_3 = '"+pre_total_goals_over_3+"', " #1165
        query_commit += " end_total_goals_under_2 = '"+end_total_goals_under_2+"', " #1166
        query_commit += " end_total_goals_2_or_3 = '"+end_total_goals_2_or_3+"', " #1167
        query_commit += " end_total_goals_over_3 = '"+end_total_goals_over_3+"', " #1168
        query_commit += " pre_first_goal_method_shot = '"+pre_first_goal_method_shot+"', " #1169
        query_commit += " pre_first_goal_method_header = '"+pre_first_goal_method_header+"', " #1170
        query_commit += " pre_first_goal_method_penalty = '"+pre_first_goal_method_penalty+"', " #1171
        query_commit += " pre_first_goal_method_freekick = '"+pre_first_goal_method_freekick+"', " #1172
        query_commit += " pre_first_goal_method_owngoal = '"+pre_first_goal_method_owngoal+"', " #1173
        query_commit += " pre_first_goal_method_draw = '"+pre_first_goal_method_draw+"', " #1174
        query_commit += " end_first_goal_method_shot = '"+end_first_goal_method_shot+"', " #1175
        query_commit += " end_first_goal_method_header = '"+end_first_goal_method_header+"', " #1176
        query_commit += " end_first_goal_method_penalty = '"+end_first_goal_method_penalty+"', " #1177
        query_commit += " end_first_goal_method_freekick = '"+end_first_goal_method_freekick+"', " #1178
        query_commit += " end_first_goal_method_owngoal = '"+end_first_goal_method_owngoal+"', " #1179
        query_commit += " end_first_goal_method_draw = '"+end_first_goal_method_draw+"', " #1180
        query_commit += " pre_to_score_a_penalty_home = '"+pre_to_score_a_penalty_home+"', " #1181
        query_commit += " pre_to_score_a_penalty_away = '"+pre_to_score_a_penalty_away+"', " #1182
        query_commit += " end_to_score_a_penalty_home = '"+end_to_score_a_penalty_home+"', " #1183
        query_commit += " end_to_score_a_penalty_away = '"+end_to_score_a_penalty_away+"', " #1184
        query_commit += " pre_to_miss_a_penalty_home = '"+pre_to_miss_a_penalty_home+"', " #1185
        query_commit += " pre_to_miss_a_penalty_away = '"+pre_to_miss_a_penalty_away+"', " #1186
        query_commit += " end_to_miss_a_penalty_home = '"+end_to_miss_a_penalty_home+"', " #1187
        query_commit += " end_to_miss_a_penalty_away = '"+end_to_miss_a_penalty_away+"', " #1188
        query_commit += " pre_anytime_goal_scorer = '"+pre_anytime_goal_scorer+"', " #1189
        query_commit += " end_anytime_goal_scorer = '"+end_anytime_goal_scorer+"', " #1190
        query_commit += " pre_first_goal_scorer = '"+pre_first_goal_scorer+"', " #1191
        query_commit += " end_first_goal_scorer = '"+end_first_goal_scorer+"', " #1192
        query_commit += " pre_last_goal_scorer = '"+pre_last_goal_scorer+"', " #1193
        query_commit += " end_last_goal_scorer = '"+end_last_goal_scorer+"', " #1194
        query_commit += " pre_to_score_two_or_more_goals = '"+pre_to_score_two_or_more_goals+"', " #1195
        query_commit += " end_to_score_two_or_more_goals = '"+end_to_score_two_or_more_goals+"', " #1196
        query_commit += " pre_last_goal_scorer2 = '"+pre_last_goal_scorer2+"', " #1197
        query_commit += " end_last_goal_scorer2 = '"+end_last_goal_scorer2+"', " #1198
        query_commit += " pre_exact_score = '"+pre_exact_score+"', " #1199
        query_commit += " end_exact_score = '"+end_exact_score+"', " #1200
        query_commit += " pre_player_to_be_booked = '"+pre_player_to_be_booked+"', " #1201
        query_commit += " end_player_to_be_booked = '"+end_player_to_be_booked+"', " #1202
        query_commit += " pre_ah_pattern = '"+pre_ah_pattern+"', " #1203
        query_commit += " pre_ah_pattern_mirror = '"+pre_ah_pattern_mirror+"', " #1204
        query_commit += " pre_gou_pattern = '"+pre_gou_pattern+"', " #1205
        query_commit += " end_ah_pattern = '"+end_ah_pattern+"', " #1206
        query_commit += " end_ah_pattern_mirror = '"+end_ah_pattern_mirror+"', " #1207
        query_commit += " end_gou_pattern = '"+end_gou_pattern+"', " #1208
        query_commit += " pre_response = '"+pre_response+"', " #1209
        query_commit += " end_response = '"+end_response+"', " #1210
        query_commit += " pre_odd_updated_at = '"+pre_odd_updated_at+"', " #1211
        query_commit += " end_odd_updated_at = '"+end_odd_updated_at+"', " #1212
        query_commit += " pre_ah_pattern_4 = '"+pre_ah_pattern_4+"', " #1213
        query_commit += " pre_ah_pattern_mirror_4 = '"+pre_ah_pattern_mirror_4+"', " #1214
        query_commit += " pre_gou_pattern_4 = '"+pre_gou_pattern_4+"', " #1215
        query_commit += " end_ah_pattern_4 = '"+end_ah_pattern_4+"', " #1216
        query_commit += " end_ah_pattern_mirror_4 = '"+end_ah_pattern_mirror_4+"', " #1217
        query_commit += " end_gou_pattern_4 = '"+end_gou_pattern_4+"', " #1218
        query_commit += " special_odds = '"+special_odds+"' " #1219


        query_commit += " WHERE leagueapi_id = '"+str(leagueapi_id)+"' "
        query_commit += " AND season = '"+str(season)+"' "
        query_commit += " AND fixtureapi_id = '"+str(fixtureapi_id)+"' "
        # --------------------------------------------------
        mycursor.execute(query_commit)
        mydb.commit()     
        # --------------------------------------------------
        mycursor.close()
        mydb.close()  
# ------------------------------------------------------
# Out:
# ____# - 474 - 2023 => 980001
# select count(*) from football_odds where leagueapi_id = '474' and season = '2023' and fixtureapi_id = '980001'
# __total_rows: 1
# ____# - 474 - 2023 => 980002
# select count(*) from football_odds where leagueapi_id = '474' and season = '2023' and fixtureapi_id = '980002'
# __total_rows: 1
# ____# - 164 - 2023 => 981557
# select count(*) from football_odds where leagueapi_id = '164' and season = '2023' and fixtureapi_id = '981557'
# __total_rows: 0
# ____# - 164 - 2023 => 981559
# select count(*) from football_odds where leagueapi_id = '164' and season = '2023' and fixtureapi_id = '981559'
# __total_rows: 0
# ____# - 563 - 2023 => 982968
# select count(*) from football_odds where leagueapi_id = '563' and season = '2023' and fixtureapi_id = '982968'
# __total_rows: 0
# ____# - 564 - 2023 => 983205
# select count(*) from football_odds where leagueapi_id = '564' and season = '2023' and fixtureapi_id = '983205'
# __total_rows: 0
# ...
