# %%
import mysql.connector 

# Import
import sys
sys.path.append('../')
 
from a_models.api_fixtures import *  
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = " select "
query += " * " 
query += " from bets_old " 
query += " where bet_id = 56 "   
query += " order by total asc "  
# ------------------------------------------------------   
# print(query)
# ------------------------------------------------------  
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ------------------------------------------------------ 
# print("Total Row(s) : " + str(len(result)), flush=True)  
# ------------------------------------------------------ 
mycursor.close()
mydb.close()
# ------------------------------------------------------ 
space = ""
# ------------------------------------------------------  
counter = 0
# ------------------------------------------------------
space += "__"
# ------------------------------------------------------
for x in result:   
    # --------------------------------------------------
    counter        += 1
    # --------------------------------------------------
    columnx = str(x[5]) 
    value = str(x[3]) 
    # --------------------------------------------------
    word = 'def sAg_'+columnx+'(leagueapi_id, null_status, space):'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    space += "__"'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    print(space + "sAg_'+columnx+'()", flush=True)'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    space += "__"'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True)  
    # --------------------------------------------------
    word = '    host="localhost"'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    user="root"'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    database="pr_mmbuzz_2022_06"'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    mydb = mysql.connector.connect(host=host,user=user,password="",database=database)'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    mycursor = mydb.cursor()'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    query = " UPDATE `football_statistics` SET  "'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    space += "__"'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    query += " `'+columnx+'` = 1 "'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    if(leagueapi_id == 0):'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '        # ------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    fixture_in = "'Match Finished', 'Match Finished Ended'"
    # --------------------------------------------------
    word = '        query += " where fixture_status in ('+fixture_in+') "'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '        # ------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    else:'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '        # ------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '        query += " where fixture_status in ('+fixture_in+') "'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '        # ------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    connector = "'"
    # --------------------------------------------------
    leagueapi_id = connector + '"+str(leagueapi_id)+"' + connector
    # --------------------------------------------------
    word = '        query += " and leagueapi_id = '+leagueapi_id+' "'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '        # ------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    if(null_status == 1):'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '        # ------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '        query += " and `'+columnx+'` is Null "'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    if("home" in columnx):
        greater = ">" 
    elif("away" in columnx):
        greater = "<" 
    # --------------------------------------------------
    if("plus" in columnx):
        operator = "+" 
    elif("min" in columnx):
        operator = "-" 
    # --------------------------------------------------
    new_value = value.replace("Home", "").replace("Away", "").replace("+", "").replace("-", "")
    # --------------------------------------------------
    word = '    query += " and (`corner_kicks_home` '+operator+' '+new_value+')  '+greater+' `corner_kicks_away` "'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    mycursor.execute(query)'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    mydb.commit()'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    mycursor.close()'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    mydb.close()'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True) 
    # --------------------------------------------------
    word = '    # ----------------------------------------------------------'
    print(word, flush=True)  
    # --------------------------------------------------
    word = ''
    print(word, flush=True) 
    # --------------------------------------------------
# Out:
# def sAg_corners_asian_handicap_home_min_65(leagueapi_id, null_status, space):
#     # ----------------------------------------------------------
#     space += "__"
#     print(space + "sAg_corners_asian_handicap_home_min_65()", flush=True)
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     host="localhost"
#     user="root"
#     database="pr_mmbuzz_2022_06"
#     mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
#     mycursor = mydb.cursor()
#     # ----------------------------------------------------------
#     query = " UPDATE `football_statistics` SET  "
#     # ----------------------------------------------------------
#     space += "__"
#     # ----------------------------------------------------------
#     query += " `corners_asian_handicap_home_min_65` = 1 "
#     # ----------------------------------------------------------
# ...
