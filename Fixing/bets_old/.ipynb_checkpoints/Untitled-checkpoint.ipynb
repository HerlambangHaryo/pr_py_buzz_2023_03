# %%
import mysql.connector 

# ------------------------------------------------------
space = "__"
# ------------------------------------------------------
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ------------------------------------------------------
query = "select "
query += " bet_id "
query += " , value  "
query += " , columnx  " 
query += " from bets_old "  
# ------------------------------------------------------   
# print(query, flush=True)
# ------------------------------------------------------    
mycursor.execute(query)
result =  mycursor.fetchall()
# ------------------------------------------------------    
total_rows = len(result)
# ------------------------------------------------------    
mycursor.close()
mydb.close()  
# ------------------------------------------------------
for x in result: 
    # -------------------------------------------------- 
    bet_id = str(x[0])
    value = str(x[1])
    colx = str(x[2]) 
    # --------------------------------------------------    
    word = '"/' + str(bet_id) + '_' + str(value) + '/' + str(colx) + "", "
    # --------------------------------------------------    
    print(word, flush=True)  
    # --------------------------------------------------
# Out:
# select  bet_id  , value   , columnx   from bets_old
# /1_Home/match_winner_home
# /1_Draw/match_winner_draw
# /1_Away/match_winner_away
# /2_Home/homeaway_home
# /2_Away/homeaway_away
# /3_Home/second_half_winner_home
# /3_Draw/second_half_winner_draw
# /3_Away/second_half_winner_away
# /4_Home +0/asian_handicap_home_plus_0
# /4_Away +0/asian_handicap_away_plus_0
# /4_Home -0.25/asian_handicap_home_min_025
# /4_Away -0.25/asian_handicap_away_min_025
# /4_Home +0.25/asian_handicap_home_plus_025
# /4_Away +0.25/asian_handicap_away_plus_025
# /4_Home +0.5/asian_handicap_home_plus_05
# /4_Away +0.5/asian_handicap_away_plus_05
# /4_Home +0.75/asian_handicap_home_plus_075
# /4_Away +0.75/asian_handicap_away_plus_075
# /4_Home +1/asian_handicap_home_plus_1
# /4_Away +1/asian_handicap_away_plus_1
# /4_Home +1.5/asian_handicap_home_plus_15
# /4_Away +1.5/asian_handicap_away_plus_15
# /4_Home +1.25/asian_handicap_home_plus_125
# /4_Away +1.25/asian_handicap_away_plus_125
# /4_Home +1.75/asian_handicap_home_plus_175
# /4_Away +1.75/asian_handicap_away_plus_175
# /5_Over 3.5/goals_overunder_over_35
# /5_Under 3.5/goals_overunder_under_35
# /5_Over 1.5/goals_overunder_over_15
# /5_Under 1.5/goals_overunder_under_15
# /5_Over 4.5/goals_overunder_over_45
# /5_Under 4.5/goals_overunder_under_45
# /5_Over 2.5/goals_overunder_over_25
# /5_Under 2.5/goals_overunder_under_25
# /5_Over 0.5/goals_overunder_over_05
# /5_Under 0.5/goals_overunder_under_05
# /5_Over 5.5/goals_overunder_over_55
# /5_Under 5.5/goals_overunder_under_55
# /5_Over 3.25/goals_overunder_over_325
# /5_Under 3.25/goals_overunder_under_325
# /5_Over 2.75/goals_overunder_over_275
# /5_Under 2.75/goals_overunder_under_275
# /5_Over 4.25/goals_overunder_over_425
# /5_Under 4.25/goals_overunder_under_425
# /5_Over 1.75/goals_overunder_over_175
# /5_Under 1.75/goals_overunder_under_175
# /5_Over 3.75/goals_overunder_over_375
# /5_Under 3.75/goals_overunder_under_375
# /5_Over 4.75/goals_overunder_over_475
# /5_Under 4.75/goals_overunder_under_475
# /5_Over 6.5/goals_overunder_over_65
# /5_Under 6.5/goals_overunder_under_65
# /5_Over 7.5/goals_overunder_over_75
# /5_Under 7.5/goals_overunder_under_75
# /5_Over 5.25/goals_overunder_over_525
# /5_Under 5.25/goals_overunder_under_525
# /5_Over 8.5/goals_overunder_over_85
# /5_Under 8.5/goals_overunder_under_85
# /5_Over 3.0/goals_overunder_over_30
# /5_Under 3.0/goals_overunder_under_30
# /5_Over 2.0/goals_overunder_over_20
# /5_Under 2.0/goals_overunder_under_20
# /5_Over 4.0/goals_overunder_over_40
# /5_Under 4.0/goals_overunder_under_40
# /5_Over 5.0/goals_overunder_over_50
# /5_Under 5.0/goals_overunder_under_50
# /6_Over 3.5/goals_overunder_first_half_over_35
# /6_Under 3.5/goals_overunder_first_half_under_35
# /6_Over 1.5/goals_overunder_first_half_over_15
# /6_Under 1.5/goals_overunder_first_half_under_15
# /6_Over 2.5/goals_overunder_first_half_over_25
# /6_Under 2.5/goals_overunder_first_half_under_25
# /6_Over 0.5/goals_overunder_first_half_over_05
# /6_Under 0.5/goals_overunder_first_half_under_05
# /6_Over 2.25/goals_overunder_first_half_over_225
# /6_Under 2.25/goals_overunder_first_half_under_225
# /6_Over 2.75/goals_overunder_first_half_over_275
# /6_Under 2.75/goals_overunder_first_half_under_275
# /6_Over 1.25/goals_overunder_first_half_over_125
# /6_Under 1.25/goals_overunder_first_half_under_125
# /6_Over 1.75/goals_overunder_first_half_over_175
# /6_Under 1.75/goals_overunder_first_half_under_175
# /6_Over 0.75/goals_overunder_first_half_over_075
# /6_Under 0.75/goals_overunder_first_half_under_075
# /6_Over 2.0/goals_overunder_first_half_over_20
# /6_Under 2.0/goals_overunder_first_half_under_20
# /6_Over 1.0/goals_overunder_first_half_over_10
# /6_Under 1.0/goals_overunder_first_half_under_10
# /26_Over 3.5/goals_overunder__second_half_over_35
# /26_Under 3.5/goals_overunder__second_half_under_35
# /26_Over 1.5/goals_overunder__second_half_over_15
# /26_Under 1.5/goals_overunder__second_half_under_15
# /26_Over 2.5/goals_overunder__second_half_over_25
# /26_Under 2.5/goals_overunder__second_half_under_25
# /26_Over 0.5/goals_overunder__second_half_over_05
# /26_Under 0.5/goals_overunder__second_half_under_05
# /7_Home/Draw/htft_double_home_draw
# /7_Home/Away/htft_double_home_away
# /7_Draw/Away/htft_double_draw_away
# /7_Draw/Draw/htft_double_draw_draw
# /7_Home/Home/htft_double_home_home
# /7_Draw/Home/htft_double_draw_home
# /7_Away/Home/htft_double_away_home
# /7_Away/Draw/htft_double_away_draw
# /7_Away/Away/htft_double_away_away
# /27_Yes/clean_sheet__home_yes
# /27_No/clean_sheet__home_no
# /28_Yes/clean_sheet__away_yes
# /28_No/clean_sheet__away_no
# /8_Yes/both_teams_score_yes
# /8_No/both_teams_score_no
# /11_Draw/highest_scoring_half_draw
# /11_1st Half/highest_scoring_half_first
# /11_2nd Half/highest_scoring_half_second
# /12_Home/Draw/double_chance_home_draw
# /12_Home/Away/double_chance_home_away
# /12_Draw/Away/double_chance_draw_away
# /13_Home/first_half_winner_home
# /13_Draw/first_half_winner_draw
# /13_Away/first_half_winner_away
# /32_Home/win_both_halves_home
# /32_Away/win_both_halves_away
# /19_Home +0/asian_handicap_first_half_home_plus_0
# /19_Away +0/asian_handicap_first_half_away_plus_0
# /19_Home -0.25/asian_handicap_first_half_home_min_025
# /19_Away -0.25/asian_handicap_first_half_away_min_025
# /19_Home +0.25/asian_handicap_first_half_home_plus_025
# /19_Away +0.25/asian_handicap_first_half_away_plus_025
# /19_Home -0.5/asian_handicap_first_half_home_min_05
# /19_Away -0.5/asian_handicap_first_half_away_min_05
# /19_Home +0.5/asian_handicap_first_half_home_plus_05
# /19_Away +0.5/asian_handicap_first_half_away_plus_05
# /19_Home +0.75/asian_handicap_first_half_home_plus_075
# /19_Away +0.75/asian_handicap_first_half_away_plus_075
# /19_Home +1/asian_handicap_first_half_home_plus_1
# /19_Away +1/asian_handicap_first_half_away_plus_1
# /19_Home +1.5/asian_handicap_first_half_home_plus_15
# /19_Away +1.5/asian_handicap_first_half_away_plus_15
# /19_Home +1.25/asian_handicap_first_half_home_plus_125
# /19_Away +1.25/asian_handicap_first_half_away_plus_125
# /19_Home +1.75/asian_handicap_first_half_home_plus_175
# /19_Away +1.75/asian_handicap_first_half_away_plus_175
# /20_Home/Draw/double_chance__first_half_home_draw
# /20_Home/Away/double_chance__first_half_home_away
# /20_Draw/Away/double_chance__first_half_draw_away
# /34_Yes/both_teams_score__first_half_yes
# /34_No/both_teams_score__first_half_no
# /35_Yes/both_teams_to_score__second_half_yes
# /35_No/both_teams_to_score__second_half_no
# /36_Home/win_to_nil_home
# /36_Away/win_to_nil_away
# /21_Odd/oddeven_odd
# /21_Even/oddeven_even
# /38_2/exact_goals_number_2
# /38_3/exact_goals_number_3
# /38_4/exact_goals_number_4
# /38_1/exact_goals_number_1
# /38_0/exact_goals_number_0
# /38_5/exact_goals_number_5
# /38_6/exact_goals_number_6
# /38_more 7/exact_goals_number_more_7
# /39_Home/to_win_either_half_home
# /39_Away/to_win_either_half_away
# /40_2/home_team_exact_goals_number_2
# /40_1/home_team_exact_goals_number_1
# /40_0/home_team_exact_goals_number_0
# /40_more 3/home_team_exact_goals_number_more_3
# /41_2/away_team_exact_goals_number_2
# /41_1/away_team_exact_goals_number_1
# /41_0/away_team_exact_goals_number_0
# /41_more 3/away_team_exact_goals_number_more_3
# /42_2/second_half_exact_goals_number_2
# /42_3/second_half_exact_goals_number_3
# /42_4/second_half_exact_goals_number_4
# /42_1/second_half_exact_goals_number_1
# /42_0/second_half_exact_goals_number_0
# /42_more 5/second_half_exact_goals_number_more_5
# /24_Home/Yes/results_both_teams_score_home_yes
# /24_Draw/Yes/results_both_teams_score_draw_yes
# /24_Away/Yes/results_both_teams_score_away_yes
# /24_Home/No/results_both_teams_score_home_no
# /24_Draw/No/results_both_teams_score_draw_no
# /24_Away/No/results_both_teams_score_away_no
# /25_Home/Over 3.5/result_total_goals_home_over_35
# /25_Draw/Over 3.5/result_total_goals_draw_over_35
# /25_Away/Over 3.5/result_total_goals_away_over_35
# /25_Home/Under 3.5/result_total_goals_home_under_35
# /25_Draw/Under 3.5/result_total_goals_draw_under_35
# /25_Away/Under 3.5/result_total_goals_away_under_35
# /25_Home/Over 2.5/result_total_goals_home_over_25
# /25_Draw/Over 2.5/result_total_goals_draw_over_25
# /25_Away/Over 2.5/result_total_goals_away_over_25
# /25_Home/Under 2.5/result_total_goals_home_under_25
# /25_Draw/Under 2.5/result_total_goals_draw_under_25
# /25_Away/Under 2.5/result_total_goals_away_under_25
# /55_Home/corners_winner_home
# /55_Draw/corners_winner_draw
# /55_Away/corners_winner_away
# /46_2/exact_goals_number__first_half_2
# /46_3/exact_goals_number__first_half_3
# /46_4/exact_goals_number__first_half_4
# /46_1/exact_goals_number__first_half_1
# /46_0/exact_goals_number__first_half_0
# /46_more 5/exact_goals_number__first_half_more_5
# /48_Home/to_score_in_both_halves_by_teams_home
# /48_Away/to_score_in_both_halves_by_teams_away
# /49_o/yes 2.5/total_goals_both_teams_to_score_over_yes_25
# /49_o/no 2.5/total_goals_both_teams_to_score_over_no_25
# /49_u/yes 2.5/total_goals_both_teams_to_score_under_yes_25
# /49_u/no 2.5/total_goals_both_teams_to_score_under_no_25
# /52_Home/Yes/halftime_result_both_teams_score_home_yes
# /52_Draw/Yes/halftime_result_both_teams_score_draw_yes
# /52_Away/Yes/halftime_result_both_teams_score_away_yes
# /52_Home/No/halftime_result_both_teams_score_home_no
# /52_Draw/No/halftime_result_both_teams_score_draw_no
# /52_Away/No/halftime_result_both_teams_score_away_no
# /73_Yes/Yes/both_teams_to_score_1st_half__2nd_half_yes_yes
# /73_Yes/No/both_teams_to_score_1st_half__2nd_half_yes_no
# /73_No/Yes/both_teams_to_score_1st_half__2nd_half_no_yes
# /73_No/No/both_teams_to_score_1st_half__2nd_half_no_no
# /74_Over 0.5/10_overunder_over_05
# /74_Under 0.5/10_overunder_under_05
# /79_Home +0/cards_european_handicap_home_plus_0
# /79_Away +0/cards_european_handicap_away_plus_0
# /79_Draw +0/cards_european_handicap_draw_plus_0
# /79_Home -1/cards_european_handicap_home_min_1
# /79_Away -1/cards_european_handicap_away_min_1
# /79_Draw -1/cards_european_handicap_draw_min_1
# /79_Home +1/cards_european_handicap_home_plus_1
# /79_Away +1/cards_european_handicap_away_plus_1
# /79_Draw +1/cards_european_handicap_draw_plus_1
# /79_Home +2/cards_european_handicap_home_plus_2
# /79_Draw +2/cards_european_handicap_draw_plus_2
# /79_Away +2/cards_european_handicap_away_plus_2
# /79_Home -2/cards_european_handicap_home_min_2
# /79_Draw -2/cards_european_handicap_draw_min_2
# /79_Away -2/cards_european_handicap_away_min_2
# /86_Yes/rcard_yes
# /86_No/rcard_no
# /5_Over 0.75/goals_overunder_over_075
# /5_Under 0.75/goals_overunder_under_075
# /5_Over 1.0/goals_overunder_over_10
# /5_Under 1.0/goals_overunder_under_10
# /5_Over 1.25/goals_overunder_over_125
# /5_Under 1.25/goals_overunder_under_125
# /5_Over 2.25/goals_overunder_over_225
# /5_Under 2.25/goals_overunder_under_225
# /5_Over 5.75/goals_overunder_over_575
# /5_Under 5.75/goals_overunder_under_575
# /5_Over 6.0/goals_overunder_over_60
# /5_Under 6.0/goals_overunder_under_60
# /5_Over 6.25/goals_overunder_over_625
# /5_Under 6.25/goals_overunder_under_625
# /5_Over 6.75/goals_overunder_over_675
# /5_Under 6.75/goals_overunder_under_675
# /5_Over 7.0/goals_overunder_over_70
# /5_Under 7.0/goals_overunder_under_70
# /5_Over 9.5/goals_overunder_over_95
# /5_Under 9.5/goals_overunder_under_95
# /4_Home -1.25/asian_handicap_home_min_125
# /4_Away -1.25/asian_handicap_away_min_125
# /4_Home -2.25/asian_handicap_home_min_225
# /4_Away -2.25/asian_handicap_away_min_225
# /4_Home -3.25/asian_handicap_home_min_325
# /4_Away -3.25/asian_handicap_away_min_325
# /4_Home -4.25/asian_handicap_home_min_425
# /4_Away -4.25/asian_handicap_away_min_425
# /4_Home -5.25/asian_handicap_home_min_525
# /4_Away -5.25/asian_handicap_away_min_525
# /4_Home -6.25/asian_handicap_home_min_625
# /4_Away -6.25/asian_handicap_away_min_625
# /4_Home -0.75/asian_handicap_home_min_075
# /4_Away -0.75/asian_handicap_away_min_075
# /4_Home -1.75/asian_handicap_home_min_175
# /4_Away -1.75/asian_handicap_away_min_175
# /4_Home -2.75/asian_handicap_home_min_275
# /4_Away -2.75/asian_handicap_away_min_275
# /4_Home -3.75/asian_handicap_home_min_375
# /4_Away -3.75/asian_handicap_away_min_375
# /4_Home -4.75/asian_handicap_home_min_475
# /4_Away -4.75/asian_handicap_away_min_475
# /4_Home -5.75/asian_handicap_home_min_575
# /4_Away -5.75/asian_handicap_away_min_575
# /4_Home -6.75/asian_handicap_home_min_675
# /4_Away -6.75/asian_handicap_away_min_675
# /4_Home -1.5/asian_handicap_home_min_15
# /4_Away -1.5/asian_handicap_away_min_15
# /4_Home -2.5/asian_handicap_home_min_25
# /4_Away -2.5/asian_handicap_away_min_25
# /4_Home -3.5/asian_handicap_home_min_35
# /4_Away -3.5/asian_handicap_away_min_35
# /4_Home -4.5/asian_handicap_home_min_45
# /4_Away -4.5/asian_handicap_away_min_45
# /4_Home -5.5/asian_handicap_home_min_55
# /4_Away -5.5/asian_handicap_away_min_55
# /4_Home -6.5/asian_handicap_home_min_65
# /4_Away -6.5/asian_handicap_away_min_65
# /4_Home -1/asian_handicap_home_min_1
# /4_Away -1/asian_handicap_away_min_1
# /4_Home -2/asian_handicap_home_min_2
# /4_Away -2/asian_handicap_away_min_2
# /4_Home -3/asian_handicap_home_min_3
# /4_Away -3/asian_handicap_away_min_3
# /4_Home -4/asian_handicap_home_min_4
# /4_Away -4/asian_handicap_away_min_4
# /4_Home -5/asian_handicap_home_min_5
# /4_Away -5/asian_handicap_away_min_5
# /4_Home -6/asian_handicap_home_min_6
# /4_Away -6/asian_handicap_away_min_6
# /4_Home -0.5/asian_handicap_home_min_05
# /4_Away -0.5/asian_handicap_away_min_05
# /4_Home +2/asian_handicap_home_plus_2
# /4_Away +2/asian_handicap_away_plus_2
# /4_Home +2.5/asian_handicap_home_plus_25
# /4_Away +2.5/asian_handicap_away_plus_25
# /4_Home +2.25/asian_handicap_home_plus_225
# /4_Away +2.25/asian_handicap_away_plus_225
# /4_Home +2.75/asian_handicap_home_plus_275
# /4_Away +2.75/asian_handicap_away_plus_275
# /4_Away +3.75/asian_handicap_away_plus_375
# /4_Home +3.75/asian_handicap_home_plus_375
# /4_Away +3.25/asian_handicap_away_plus_325
# /4_Home +3.25/asian_handicap_home_plus_325
# /4_Away +3.5/asian_handicap_away_plus_35
# /4_Home +3.5/asian_handicap_home_plus_35
# /4_Away +3/asian_handicap_away_plus_3
# /4_Home +3/asian_handicap_home_plus_3
# /4_Home +4/asian_handicap_home_plus_4
# /4_Away +4/asian_handicap_away_plus_4
# /4_Home +4.5/asian_handicap_home_plus_45
# /4_Away +4.5/asian_handicap_away_plus_45
# /4_Home +4.25/asian_handicap_home_plus_425
# /4_Away +4.25/asian_handicap_away_plus_425
# /4_Home +4.75/asian_handicap_home_plus_475
# /4_Away +4.75/asian_handicap_away_plus_475
# /4_Home +5/asian_handicap_home_plus_5
# /4_Away +5/asian_handicap_away_plus_5
# /4_Home +5.5/asian_handicap_home_plus_55
# /4_Away +5.5/asian_handicap_away_plus_55
# /4_Home +5.25/asian_handicap_home_plus_525
# /4_Away +5.25/asian_handicap_away_plus_525
# /4_Home +5.75/asian_handicap_home_plus_575
# /4_Away +5.75/asian_handicap_away_plus_575
# /4_Home +6/asian_handicap_home_plus_6
# /4_Away +6/asian_handicap_away_plus_6
# /4_Home +6.5/asian_handicap_home_plus_65
# /4_Away +6.5/asian_handicap_away_plus_65
# /4_Home +6.25/asian_handicap_home_plus_625
# /4_Away +6.25/asian_handicap_away_plus_625
# /4_Home +6.75/asian_handicap_home_plus_675
# /4_Away +6.75/asian_handicap_away_plus_675
# /6_Over 3.0/goals_overunder_first_half_over_30
# /6_Over 3.25/goals_overunder_first_half_over_325
# /6_Under 3.75/goals_overunder_first_half_under_375
# /6_Over 3.75/goals_overunder_first_half_over_375
# /6_Under 3.0/goals_overunder_first_half_under_30
# /6_Under 3.25/goals_overunder_first_half_under_325
# /26_Over 0.75/goals_overunder__second_half_over_075
# /26_Over 1.0/goals_overunder__second_half_over_10
# /26_Over 1.25/goals_overunder__second_half_over_125
# /26_Over 1.75/goals_overunder__second_half_over_175
# /26_Over 2.25/goals_overunder__second_half_over_225
# /26_Over 2.75/goals_overunder__second_half_over_275
# /26_Over 3.0/goals_overunder__second_half_over_30
# /26_Over 3.25/goals_overunder__second_half_over_325
# /26_Over 3.75/goals_overunder__second_half_over_375
# /26_Under 0.75/goals_overunder__second_half_under_075
# /26_Under 1.25/goals_overunder__second_half_under_125
# /26_Under 1.75/goals_overunder__second_half_under_175
# /26_Under 2.25/goals_overunder__second_half_under_225
# /26_Under 2.75/goals_overunder__second_half_under_275
# /26_Under 3.25/goals_overunder__second_half_under_325
# /26_Under 3.75/goals_overunder__second_half_under_375
# /26_Under 1.0/goals_overunder__second_half_under_10
# /26_Under 2.0/goals_overunder__second_half_under_20
# /26_Under 3.0/goals_overunder__second_half_under_30
# /26_Over 2.0/goals_overunder__second_half_over_20
# /19_Home -0.75/asian_handicap_first_half_home_min_075
# /19_Away -0.75/asian_handicap_first_half_away_min_075
# /19_Home -1/asian_handicap_first_half_home_min_1
# /19_Away -1/asian_handicap_first_half_away_min_1
# /19_Home -1.25/asian_handicap_first_half_home_min_125
# /19_Away -1.25/asian_handicap_first_half_away_min_125
# /19_Home -1.5/asian_handicap_first_half_home_min_15
# /19_Away -1.5/asian_handicap_first_half_away_min_15
# /19_Home -1.75/asian_handicap_first_half_home_min_175
# /19_Away -1.75/asian_handicap_first_half_away_min_175
# /45_Over 8.5/corners_over_under_over_850
# /45_Under 8.5/corners_over_under_under_850
# /45_Over 8/corners_over_under_over_800
# /45_Under 8/corners_over_under_under_800
# /45_Over 8.25/corners_over_under_over_825
# /45_Under 8.25/corners_over_under_under_825
# /45_Over 8.75/corners_over_under_over_875
# /45_Under 8.75/corners_over_under_under_875
# /45_Over 9/corners_over_under_over_900
# /45_Under 9/corners_over_under_under_900
# /45_Over 9.25/corners_over_under_over_925
# /45_Under 9.25/corners_over_under_under_925
# /45_Over 9.5/corners_over_under_over_950
# /45_Under 9.5/corners_over_under_under_950
# /45_Over 9.75/corners_over_under_over_975
# /45_Under 9.75/corners_over_under_under_975
# /45_Over 10/corners_over_under_over_1000
# /45_Under 10/corners_over_under_under_1000
# /45_Over 10.25/corners_over_under_over_1025
# /45_Under 10.25/corners_over_under_under_1025
# /45_Over 10.5/corners_over_under_over_1050
# /45_Under 10.5/corners_over_under_under_1050
# /45_Over 10.75/corners_over_under_over_1075
# /45_Under 10.75/corners_over_under_under_1075
# /45_Over 11/corners_over_under_over_1100
# /45_Under 11/corners_over_under_under_1100
# /45_Over 11.25/corners_over_under_over_1125
# /45_Under 11.25/corners_over_under_under_1125
# /45_Over 11.5/corners_over_under_over_1150
# /45_Under 11.5/corners_over_under_under_1150
# /45_Over 11.75/corners_over_under_over_1175
# /45_Under 11.75/corners_over_under_under_1175
# /45_Over 12/corners_over_under_over_1200
# /45_Under 12/corners_over_under_under_1200
# /45_Over 12.25/corners_over_under_over_1225
# /45_Under 12.25/corners_over_under_under_1225
# /45_Over 12.5/corners_over_under_over_1250
# /45_Under 12.5/corners_over_under_under_1250
# /45_Over 12.75/corners_over_under_over_1275
# /45_Under 12.75/corners_over_under_under_1275
# /14_Home/team_to_score_first_home
# /14_Draw/team_to_score_first_draw
# /14_Away/team_to_score_first_away
# /15_Home/team_to_score_last_home
# /15_Draw/team_to_score_last_draw
# /15_Away/team_to_score_last_away
# /16_Over 3.5/total_home_over_35
# /16_Under 3.5/total_home_under_35
# /16_Over 1.5/total_home_over_15
# /16_Under 1.5/total_home_under_15
# /16_Over 2.5/total_home_over_25
# /16_Under 2.5/total_home_under_25
# /17_Over 3.5/total_away_over_35
# /17_Under 3.5/total_away_under_35
# /17_Over 1.5/total_away_over_15
# /17_Under 1.5/total_away_under_15
# /17_Over 4.5/total_away_over_45
# /17_Under 4.5/total_away_under_45
# /17_Over 2.5/total_away_over_25
# /17_Under 2.5/total_away_under_25
# /17_Over 5.5/total_away_over_55
# /17_Under 5.5/total_away_under_55
# /17_Over 6.5/total_away_over_65
# /17_Under 6.5/total_away_under_65
# /91_Under 2 /total_goals_under_2
# /91_2 Or 3 /total_goals_2_or_3
# /91_Over 3 /total_goals_over_3
# /97_Shot/first_goal_method_shot
# /97_Header/first_goal_method_header
# /97_Penalty/first_goal_method_penalty
# /97_FreeKick/first_goal_method_freekick
# /97_OwnGoal/first_goal_method_owngoal
# /97_Draw/first_goal_method_draw
# /56_Home +3.5/corners_asian_handicap_home_plus_35
# /56_Away +3.5/corners_asian_handicap_away_plus_35
# /57_Over 2.5/home_corners_overunder_over_25
# /57_Under 2.5/home_corners_overunder_under_25
# /58_Over 6.5/away_corners_overunder_over_65
# /58_Under 6.5/away_corners_overunder_under_65
# /75_Home/last_corner_home
# /75_Away/last_corner_away
# /76_Home/first_corner_home
# /76_Away/first_corner_away
# /80_Over 2.5/cards_overunder_over_25
# /80_Under 2.5/cards_overunder_under_25
# /81_Home -0.5/cards_asian_handicap_home_min_05
# /81_Away -0.5/cards_asian_handicap_away_min_05
# /82_Over 1.5/home_team_total_cards_over_15
# /82_Under 1.5/home_team_total_cards_under_15
# /83_Over 1.5/away_team_total_cards_over_15
# /83_Under 1.5/away_team_total_cards_under_15
# /99_Home/to_score_a_penalty_home
# /99_Away/to_score_a_penalty_away
# /100_Home/to_miss_a_penalty_home
# /100_Away/to_miss_a_penalty_away
# /16_Over 4.5/total_home_over_45
# /16_Under 4.5/total_home_under_45
# /16_Over 5.5/total_home_over_55
# /16_Under 5.5/total_home_under_55
# /16_Over 6.5/total_home_over_65
# /16_Under 6.5/total_home_under_65
# /56_Home -0.5/corners_asian_handicap_home_min_05
# /56_Away -0.5/corners_asian_handicap_away_min_05
# /56_Home -1.5/corners_asian_handicap_home_min_15
# /56_Away -1.5/corners_asian_handicap_away_min_15
# /56_Away +3/corners_asian_handicap_away_plus_3
# /56_Home -3/corners_asian_handicap_home_min_3
# /56_Home +0.5/corners_asian_handicap_home_plus_05
# /56_Away +0.5/corners_asian_handicap_away_plus_05
# /56_Home +0/corners_asian_handicap_home_plus_0
# /56_Home +1/corners_asian_handicap_home_plus_1
# /56_Away +1/corners_asian_handicap_away_plus_1
# /56_Away -2/corners_asian_handicap_away_min_2
# /56_Home +3/corners_asian_handicap_home_plus_3
# /56_Home +2/corners_asian_handicap_home_plus_2
# /56_Away +2/corners_asian_handicap_away_plus_2
# /56_Away +0/corners_asian_handicap_away_plus_0
# /56_Away -1/corners_asian_handicap_away_min_1
# /56_Home -4/corners_asian_handicap_home_min_4
# /56_Away -4/corners_asian_handicap_away_min_4
# /56_Home -4.5/corners_asian_handicap_home_min_45
# /56_Away -2.5/corners_asian_handicap_away_min_25
# /56_Home +1.5/corners_asian_handicap_home_plus_15
# /56_Away -3/corners_asian_handicap_away_min_3
# /56_Home -2.5/corners_asian_handicap_home_min_25
# /56_Home -2/corners_asian_handicap_home_min_2
# /56_Home -1/corners_asian_handicap_home_min_1
# /56_Away +1.5/corners_asian_handicap_away_plus_15
# /56_Away -5.5/corners_asian_handicap_away_min_55
# /56_Away -3.5/corners_asian_handicap_away_min_35
# /56_Away +2.5/corners_asian_handicap_away_plus_25
# /56_Home -6.5/corners_asian_handicap_home_min_65
# /56_Home -5.5/corners_asian_handicap_home_min_55
# /56_Home -3.5/corners_asian_handicap_home_min_35
# /56_Home -5/corners_asian_handicap_home_min_5
# /56_Away -5/corners_asian_handicap_away_min_5
# /56_Away -4.5/corners_asian_handicap_away_min_45
# /56_Away -6.5/corners_asian_handicap_away_min_65
# /57_Over 5.5/home_corners_overunder_over_55
# /57_Under 5.5/home_corners_overunder_under_55
# /57_Over 4.5/home_corners_overunder_over_45
# /57_Under 4.5/home_corners_overunder_under_45
# /57_Over 6.5/home_corners_overunder_over_65
# /57_Under 6.5/home_corners_overunder_under_65
# /57_Over 7.5/home_corners_overunder_over_75
# /57_Under 7.5/home_corners_overunder_under_75
# /57_Over 3.5/home_corners_overunder_over_35
# /57_Under 3.5/home_corners_overunder_under_35
# /57_Over 8.5/home_corners_overunder_over_85
# /57_Under 8.5/home_corners_overunder_under_85
# /58_Over 5.5/away_corners_overunder_over_55
# /58_Under 5.5/away_corners_overunder_under_55
# /58_Over 3.5/away_corners_overunder_over_35
# /58_Under 3.5/away_corners_overunder_under_35
# /58_Over 4.5/away_corners_overunder_over_45
# /58_Under 4.5/away_corners_overunder_under_45
# /58_Over 2.5/away_corners_overunder_over_25
# /58_Under 2.5/away_corners_overunder_under_25
# /58_Over 7.5/away_corners_overunder_over_75
# /58_Under 7.5/away_corners_overunder_under_75
# /58_Over 8.5/away_corners_overunder_over_85
# /58_Under 8.5/away_corners_overunder_under_85
# /80_Over 3.5/cards_overunder_over_35
# /80_Under 3.5/cards_overunder_under_35
# /80_Over 4.5/cards_overunder_over_45
# /80_Under 4.5/cards_overunder_under_45
# /80_Over 5.5/cards_overunder_over_55
# /80_Under 5.5/cards_overunder_under_55
# /80_Over 6.5/cards_overunder_over_65
# /80_Under 6.5/cards_overunder_under_65
# /80_Over 7.5/cards_overunder_over_75
# /80_Under 7.5/cards_overunder_under_75
# /81_Home +0/cards_asian_handicap_home_plus_0
# /81_Away +0/cards_asian_handicap_away_plus_0
# /81_Home +0.5/cards_asian_handicap_home_plus_05
# /81_Away +0.5/cards_asian_handicap_away_plus_05
# /82_Over 2.5/home_team_total_cards_over_25
# /82_Under 2.5/home_team_total_cards_under_25
# /82_Over 3.5/home_team_total_cards_over_35
# /82_Under 3.5/home_team_total_cards_under_35
# /83_Over 2.5/away_team_total_cards_over_25
# /83_Under 2.5/away_team_total_cards_under_25
# /83_Over 3.5/away_team_total_cards_over_35
# /83_Under 3.5/away_team_total_cards_under_35
# /56_Home -6/corners_asian_handicap_home_min_6
# /56_Away -6/corners_asian_handicap_away_min_6
# /56_Home +2.5/corners_asian_handicap_home_plus_25
# /56_Home +4/corners_asian_handicap_home_plus_4
# /56_Away +4/corners_asian_handicap_away_plus_4
# /56_Home +4.5/corners_asian_handicap_home_plus_45
# /56_Away +4.5/corners_asian_handicap_away_plus_45
# /56_Home +5/corners_asian_handicap_home_plus_5
# /56_Away +5/corners_asian_handicap_away_plus_5
# /56_Home +5.5/corners_asian_handicap_home_plus_55
# /56_Away +5.5/corners_asian_handicap_away_plus_55
# /56_Home +6/corners_asian_handicap_home_plus_6
# /56_Away +6/corners_asian_handicap_away_plus_6
# /56_Home +6.5/corners_asian_handicap_home_plus_65
# /56_Away +6.5/corners_asian_handicap_away_plus_65
# /45_Over 7/corners_over_under_over_700
# /45_Under 7/corners_over_under_under_700
# /45_Over 7.25/corners_over_under_over_725
# /45_Under 7.25/corners_over_under_under_725
# /45_Over 7.5/corners_over_under_over_750
# /45_Under 7.5/corners_over_under_under_750
# /45_Over 7.75/corners_over_under_over_775
# /45_Under 7.75/corners_over_under_under_775
