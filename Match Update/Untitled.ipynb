# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.api_fixtures import *   

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------  
    # -------------------------------------------------- 
    today = datetime.datetime.now() 
    todayx = today.strftime("%Y-%m-%d") 
    
    DD = datetime.timedelta(days=1)
    week = today - DD
    day1 = week.strftime("%Y-%m-%d") 

    DD = datetime.timedelta(days=7)
    yesterday = today + DD
    day2 = yesterday.strftime("%Y-%m-%d") 
    
    pre_tw = datetime.timedelta(days=7)
    one_week_later =  today + pre_tw 
    
    aft_tw = datetime.timedelta(days=14)
    two_weeks_before = today - aft_tw
    # -------------------------------------------------- 
    space += "__"
    leagueapi_id   = input(space + "Enter your leagueapi id :  ")
    season         = input(space + "Enter your season :  ")  
    print(space + "> day1 : " +  str(day1) )
    print(space + "> day2 : " + str(day2) )  
    # --------------------------------------------------   
    DICT = {
        'leagueapi_id' :leagueapi_id,
        'season' :season,
        'day1' :day1,
        'day2' :day2,
    }
    # --------------------------------------------------- 
    ROUTES = 'leagueapi_id'
    af_controll_match_update(DICT, ROUTES, space) 
    # --------------------------------------------------
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-24 21:10:25
#   __main()
#   ____get_date()
#   ______Enter your leagueapi id :  772
#   ______Enter your season :  2023
#   ______> day1 : 2023-07-23
#   ______> day2 : 2023-07-31
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API digitalmedia.arion@gmail.com counter is 78
#   ____________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : leagueapi_id
#   ____________leagueapi_id : 772
#   ____________season : 2023
#   ____________day1 : 2023-07-23
#   ____________day2 : 2023-07-31
#   ______________Total API Response(s) : 34
#   ________________fixture_status: Match Finished
#   ________________football_odds: 1. /Match Finished/ 1013771 / Philadelphia Union vs Club Tijuana /2023-07-23 00:00:00+00:00/  INSERTED
#   ________________football_odds INSERTED
#   ________________football_statistics: 1. /Match Finished/ 1013771 / Philadelphia Union vs Club Tijuana /2023-07-23 00:00:00+00:00/  INSERTED
#
#   ________________fixture_status: Match Finished
#   ________________football_odds: 2. /Match Finished/ 1013774 / Portland Timbers vs San Jose Earthquakes /2023-07-23 02:00:00+00:00/  INSERTED
#   ________________football_odds INSERTED
#   ________________football_statistics: 2. /Match Finished/ 1013774 / Portland Timbers vs San Jose Earthquakes /2023-07-23 02:00:00+00:00/  INSERTED
#
#   ________________fixture_status: Match Finished
#   ________________football_odds: 3. /Match Finished/ 1013775 / Real Salt Lake vs Seattle Sounders /2023-07-23 01:30:00+00:00/  INSERTED
#   ________________football_odds INSERTED
#   ________________football_statistics: 3. /Match Finished/ 1013775 / Real Salt Lake vs Seattle Sounders /2023-07-23 01:30:00+00:00/  INSERTED
#
#   ________________fixture_status: Match Finished
#   ________________football_odds: 4. /Match Finished/ 1013776 / Columbus Crew vs St. Louis City /2023-07-23 23:30:00+00:00/  INSERTED
#   ________________football_odds INSERTED
#   ________________football_statistics: 4. /Match Finished/ 1013776 / Columbus Crew vs St. Louis City /2023-07-23 23:30:00+00:00/  INSERTED
#
#   ________________fixture_status: Match Finished
#   ________________football_odds: 5. /Match Finished/ 1013777 / Puebla vs Minnesota United FC /2023-07-24 01:00:00+00:00/  INSERTED
#   ________________football_odds INSERTED
#   ________________football_statistics: