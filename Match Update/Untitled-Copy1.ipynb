# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.api_fixtures import *   

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------  
    # -------------------------------------------------- 
    today = datetime.datetime.now() 
    todayx = today.strftime("%Y-%m-%d") 
    
    DD = datetime.timedelta(days=1)
    week = today - DD
    day1 = week.strftime("%Y-%m-%d") 

    DD = datetime.timedelta(days=7)
    yesterday = today + DD
    day2 = yesterday.strftime("%Y-%m-%d") 
    
    pre_tw = datetime.timedelta(days=7)
    one_week_later =  today + pre_tw 
    
    aft_tw = datetime.timedelta(days=14)
    two_weeks_before = today - aft_tw
    # -------------------------------------------------- 
    space += "__"
    leagueapi_id   = input(space + "Enter your leagueapi id :  ")
    season         = input(space + "Enter your season :  ")  
    print(space + "> day1 : " +  str(day1) )
    print(space + "> day2 : " + str(day2) )  
    # --------------------------------------------------   
    DICT = {
        'leagueapi_id' :leagueapi_id,
        'season' :season,
        'day1' :day1,
        'day2' :day2,
    }
    # --------------------------------------------------- 
    ROUTES = 'leagueapi_id'
    af_controll_match_update(DICT, ROUTES, space) 
    # --------------------------------------------------
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-29 15:35:51
#   __main()
#   ____get_date()
#   ______Enter your leagueapi id :  197
#   ______Enter your season :  2022
#   ______> day1 : 2023-04-28
#   ______> day2 : 2023-05-06
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 71
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 197
#   __________season : 2022
#   __________day1 : 2023-04-28
#   __________day2 : 2023-05-06
#   ____________Total API Response(s) : 14
#   ______________1. /Not Started/ 1014647 / Olympiakos Piraeus vs Volos NFC /2023-04-30 17:00:00+00:00/  UPDATED
#   ______________2. /Not Started/ 1014648 / Panathinaikos vs AEK Athens FC /2023-04-30 17:00:00+00:00/  UPDATED
#   ______________3. /Not Started/ 1014649 / PAOK vs Aris Thessalonikis /2023-04-30 17:00:00+00:00/  UPDATED
#   ______________4. /Not Started/ 1014650 / AEK Athens FC vs Olympiakos Piraeus /2023-05-03 17:00:00+00:00/  UPDATED
#   ______________5. /Not Started/ 1014651 / Aris Thessalonikis vs Volos NFC /2023-05-03 17:00:00+00:00/  UPDATED
#   ______________6. /Not Started/ 1014652 / Panathinaikos vs PAOK /2023-05-03 17:00:00+00:00/  UPDATED
#   ______________7. /Not Started/ 1014675 / Asteras Tripolis vs Lamia /2023-04-29 16:15:00+00:00/  UPDATED
#   ______________8. /Not Started/ 1014676 / Atromitos vs OFI /2023-04-29 16:15:00+00:00/  UPDATED
#   ______________9. /Not Started/ 1014677 / Ionikos vs PAS Giannina /2023-04-29 16:15:00+00:00/  UPDATED
#   ______________10. /Not Started/ 1014678 / Panetolikos vs Levadiakos /2023-04-29 16:15:00+00:00/  UPDATED
#   ______________11. /Not Started/ 1014679 / Atromitos vs Panetolikos /2023-05-06 17:00:00+00:00/  UPDATED
#   ______________12. /Not Started/ 1014680 / OFI vs Ionikos /2023-05-06 17:00:00+00:00/  UPDATED
#   ______________13. /Not Started/ 1014681 / PAS Giannina vs Asteras Tripolis /2023-05-06 17:00:00+00:00/  UPDATED
#   ______________14. /Not Started/ 1014682 / Lamia vs Levadiakos /2023-05-06 17:00:00+00:00/  UPDATED
# # -------------------------------------------------- End at 2023-04-29 15:37:06
