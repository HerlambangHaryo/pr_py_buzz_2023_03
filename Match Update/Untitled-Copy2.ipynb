# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.api_fixtures import *   

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------  
    # -------------------------------------------------- 
    today = datetime.datetime.now() 
    todayx = today.strftime("%Y-%m-%d") 
    
    DD = datetime.timedelta(days=1)
    week = today - DD
    day1 = week.strftime("%Y-%m-%d") 

    DD = datetime.timedelta(days=7)
    yesterday = today + DD
    day2 = yesterday.strftime("%Y-%m-%d") 
    
    pre_tw = datetime.timedelta(days=7)
    one_week_later =  today + pre_tw 
    
    aft_tw = datetime.timedelta(days=14)
    two_weeks_before = today - aft_tw
    # -------------------------------------------------- 
    space += "__"
    leagueapi_id   = input(space + "Enter your leagueapi id :  ")
    season         = input(space + "Enter your season :  ")  
    print(space + "> day1 : " +  str(day1) )
    print(space + "> day2 : " + str(day2) )  
    # --------------------------------------------------   
    DICT = {
        'leagueapi_id' :leagueapi_id,
        'season' :season,
        'day1' :day1,
        'day2' :day2,
    }
    # --------------------------------------------------- 
    ROUTES = 'leagueapi_id'
    af_controll_match_update(DICT, ROUTES, space) 
    # --------------------------------------------------
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-29 15:36:57
#   __main()
#   ____get_date()
#   ______Enter your leagueapi id :  272
#   ______Enter your season :  2022
#   ______> day1 : 2023-04-28
#   ______> day2 : 2023-05-06
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 69
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 272
#   __________season : 2022
#   __________day1 : 2023-04-28
#   __________day2 : 2023-05-06
#   ____________Total API Response(s) : 10
#   ______________1. /Not Started/ 897449 / Szeged 2011 vs Kazincbarcikai /2023-04-30 15:00:00+00:00/  UPDATED
#   ______________2. /Not Started/ 897450 / Gyirmot SE vs Pécsi MFC /2023-04-30 15:00:00+00:00/  UPDATED
#   ______________3. /Not Started/ 897451 / MTK Budapest vs Ajka /2023-04-30 16:00:00+00:00/  UPDATED
#   ______________4. /Not Started/ 897452 / Szentlőrinc SE vs Tiszakecske FC /2023-04-30 15:00:00+00:00/  UPDATED
#   ______________5. /Not Started/ 897453 / Dorogi FC vs Soroksar /2023-04-30 15:00:00+00:00/  UPDATED
#   ______________6. /Not Started/ 897454 / Bekescsaba 1912 vs Siofok /2023-04-30 15:00:00+00:00/  UPDATED
#   ______________7. /Not Started/ 897455 / Budafoki LC vs Szombathelyi Haladas /2023-04-29 15:00:00+00:00/  UPDATED
#   ______________8. /Not Started/ 897456 / MTE 1904 vs Gyori ETO FC /2023-04-30 15:00:00+00:00/  UPDATED
#   ______________9. /Not Started/ 897457 / Kozarmisleny FC vs Nyiregyhaza /2023-04-30 15:00:00+00:00/  UPDATED
#   ______________10. /Not Started/ 897458 / Diosgyori VTK vs Csakvar /2023-04-30 18:00:00+00:00/  UPDATED
# # -------------------------------------------------- End at 2023-04-29 15:37:38
