# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.api_fixtures import *   

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------  
    # -------------------------------------------------- 
    today = datetime.datetime.now() 
    todayx = today.strftime("%Y-%m-%d") 
    
    DD = datetime.timedelta(days=1)
    week = today - DD
    day1 = week.strftime("%Y-%m-%d") 

    DD = datetime.timedelta(days=7)
    yesterday = today + DD
    day2 = yesterday.strftime("%Y-%m-%d") 
    
    pre_tw = datetime.timedelta(days=7)
    one_week_later =  today + pre_tw 
    
    aft_tw = datetime.timedelta(days=14)
    two_weeks_before = today - aft_tw
    # -------------------------------------------------- 
    space += "__"
    leagueapi_id   = input(space + "Enter your leagueapi id :  ")
    season         = input(space + "Enter your season :  ")  
    print(space + "> day1 : " +  str(day1) )
    print(space + "> day2 : " + str(day2) )  
    # --------------------------------------------------   
    DICT = {
        'leagueapi_id' :leagueapi_id,
        'season' :season,
        'day1' :day1,
        'day2' :day2,
    }
    # --------------------------------------------------- 
    ROUTES = 'leagueapi_id'
    af_controll_match_update(DICT, ROUTES, space) 
    # --------------------------------------------------
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-29 15:36:27
#   __main()
#   ____get_date()
#   ______Enter your leagueapi id :  271
#   ______Enter your season :  2022
#   ______> day1 : 2023-04-28
#   ______> day2 : 2023-05-06
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 70
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 271
#   __________season : 2022
#   __________day1 : 2023-04-28
#   __________day2 : 2023-05-06
#   ____________Total API Response(s) : 10
#   ______________1. /Not Started/ 883370 / Mezokovesd-zsory vs Zalaegerszegi TE /2023-04-29 12:15:00+00:00/  UPDATED
#   ______________2. /Not Started/ 883371 / Debreceni VSC vs Videoton FC /2023-04-30 13:30:00+00:00/  UPDATED
#   ______________3. /Match Finished/ 883372 / Kecskeméti TE vs Paks /2023-04-28 18:00:00+00:00/  UPDATED
#   ______________4. /Not Started/ 883373 / Kisvarda FC vs Budapest Honved /2023-04-29 15:00:00+00:00/  UPDATED
#   ______________5. /Not Started/ 883374 / Ujpest vs Ferencvarosi TC /2023-05-01 16:00:00+00:00/  UPDATED
#   ______________6. /Not Started/ 883375 / Vasas vs Puskas Academy /2023-04-29 17:30:00+00:00/  UPDATED
#   ______________7. /Not Started/ 883376 / Ujpest vs Vasas /2023-05-06 12:00:00+00:00/  UPDATED
#   ______________8. /Not Started/ 883377 / Ferencvarosi TC vs Kisvarda FC /2023-05-06 17:45:00+00:00/  UPDATED
#   ______________9. /Not Started/ 883378 / Budapest Honved vs Kecskeméti TE /2023-05-05 16:30:00+00:00/  UPDATED
#   ______________10. /Not Started/ 883379 / Paks vs Debreceni VSC /2023-05-06 14:30:00+00:00/  UPDATED
# # -------------------------------------------------- End at 2023-04-29 15:37:22
