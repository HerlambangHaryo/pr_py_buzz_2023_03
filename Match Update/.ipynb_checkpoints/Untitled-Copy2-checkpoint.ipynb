# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.api_fixtures import *   

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------  
    # -------------------------------------------------- 
    today = datetime.datetime.now() 
    todayx = today.strftime("%Y-%m-%d") 
    
    DD = datetime.timedelta(days=1)
    week = today - DD
    day1 = week.strftime("%Y-%m-%d") 

    DD = datetime.timedelta(days=7)
    yesterday = today + DD
    day2 = yesterday.strftime("%Y-%m-%d") 
    
    pre_tw = datetime.timedelta(days=7)
    one_week_later =  today + pre_tw 
    
    aft_tw = datetime.timedelta(days=14)
    two_weeks_before = today - aft_tw
    # -------------------------------------------------- 
    space += "__"
    leagueapi_id   = input(space + "Enter your leagueapi id :  ")
    season         = input(space + "Enter your season :  ")  
    print(space + "> day1 : " +  str(day1) )
    print(space + "> day2 : " + str(day2) )  
    # --------------------------------------------------   
    DICT = {
        'leagueapi_id' :leagueapi_id,
        'season' :season,
        'day1' :day1,
        'day2' :day2,
    }
    # --------------------------------------------------- 
    ROUTES = 'leagueapi_id'
    af_controll_match_update(DICT, ROUTES, space) 
    # --------------------------------------------------
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-29 15:26:42
#   __main()
#   ____get_date()
#   ______Enter your leagueapi id :  134
#   ______Enter your season :  2023
#   ______> day1 : 2023-04-28
#   ______> day2 : 2023-05-13
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API herlambangharyo@live.com counter is 87
#   ____________APIkey: 2fec23d13fmshf62617efbd47f64p163111jsn9852a0e880ca
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : leagueapi_id
#   __________leagueapi_id : 134
#   __________season : 2023
#   __________day1 : 2023-04-28
#   __________day2 : 2023-05-13
#   ____________Total API Response(s) : 48
#   ______________1. /Not Started/ 1009955 / Cipolletti vs Sol de Mayo /2023-04-30 19:00:00+00:00/  UPDATED
#   ______________2. /Not Started/ 1009956 / Santamarina vs Olimpo Bahia Blanca /2023-04-30 22:00:00+00:00/  UPDATED
#   ______________3. /Match Finished/ 1009957 / Villa Mitre vs Circulo Deportivo /2023-04-28 21:00:00+00:00/  UPDATED
#   ______________4. /Not Started/ 1009958 / Liniers Bahía Blanca vs Sansinena /2023-04-30 19:00:00+00:00/  UPDATED
#   ______________5. /Time to be defined/ 1009959 / Sansinena vs Villa Mitre /2023-05-07 00:00:00+00:00/  UPDATED
#   ______________6. /Time to be defined/ 1009960 / Circulo Deportivo vs Santamarina /2023-05-07 00:00:00+00:00/  UPDATED
#   ______________7. /Time to be defined/ 1009961 / Olimpo Bahia Blanca vs Cipolletti /2023-05-07 00:00:00+00:00/  UPDATED
#   ______________8. /Time to be defined/ 1009962 / Sol de Mayo vs Germinal de Rawson /2023-05-07 00:00:00+00:00/  UPDATED
#   ______________9. /Time to be defined/ 1009963 / Olimpo Bahia Blanca vs Germinal de Rawson /2023-05-13 00:00:00+00:00/  UPDATED
#   ______________10. /Time to be defined/ 1009964 / Circulo Deportivo vs Cipolletti /2023-05-13 00:00:00+00:00/  UPDATED
#   ______________11. /Time to be defined/ 1009965 / Sansinena vs Santamarina /2023-05-13 00:00:00+00:00/  UPDATED
