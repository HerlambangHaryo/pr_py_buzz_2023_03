# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.football_statistics import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------  
    leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    teamapi_id   = input(space + "Enter your leagueapi id :  ") 
    # --------------------------------------------------    
    fS_get_fixture_that_not_update_stats_by_teamapi(leagueapi_id, teamapi_id, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-06-03 19:46:43
#   __main()
#   ____Enter your leagueapi id :  39
#   ______fS_get_fixture_that_not_update_stats_by_league()
#   ______ SELECT   fixtureapi_id  , leagueapi_id  , season FROM football_statistics WHERE leagueapi_id = 39  and fixture_status in ('Match Finished', 'Match Finished Ended')  and shots_on_goal_home is null  and shots_on_goal_away is null  and season >= 2022
#   ______Total Row(s) : 10
#   ______Are you sure want to continue? :  yes
#   ______[1/10] #868316 #39 - 2022
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api2@ariondigitalmedia.com counter is 71
#   ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 868316
# ...
