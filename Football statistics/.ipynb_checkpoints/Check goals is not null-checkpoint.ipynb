# %%
# Import
import mysql.connector 

# Import
import sys
sys.path.append('../')
from a_models.api_fixtures import *    

# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " Select "
# ---------------------------------------------------------- 
# query += ' goals_home '  
# query += ' , goals_away '   
# ---------------------------------------------------------- 
query += ' leagueapi_id '   
query += ' , season '    
query += ' , fixtureapi_id '    
query += ' , fixture_status '    
# ---------------------------------------------------------- 
query += " from football_statistics "    
query += " where fixture_status in ('Match Finished', 'Match Finished Ended') "  
# ---------------------------------------------------------- 
query += " and goals_home is null "
query += " and goals_away is null " 
# query += " limit 10 " 
# ---------------------------------------------------------- 
# query += " group by " 
# query += ' leagueapi_id '   
# query += ' , season '      
# ---------------------------------------------------------- 
print(space + query, flush=True)
# query 1
# ---------------------------------------------------------- 
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ---------------------------------------------------------- 
space += "__"
# ---------------------------------------------------------- 
total_rows = len(result)
print(space + "Total goals_home is null and goals_away is null Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------    
print("", flush=True)
counter = 0
# ----------------------------------------------------------  
space += "__"
# ---------------------------------------------------------- 
for x in result:   
    # ------------------------------------------------------
    counter        += 1
    # ------------------------------------------------------
    leagueapi_id = str(x[0])
    season = str(x[1]) 
    fixtureapi_id = str(x[2]) 
    fixture_status = str(x[3]) 
    # ------------------------------------------------------
    word = space + "#"  + str(counter) + " >" + leagueapi_id
    word += " - " + season 
    word += " > " + fixtureapi_id 
    word += " => " + fixture_status 
    print(word, flush=True)
    # ------------------------------------------------------
#     query1 = " Select "
#     query1 += " goals_home "
#     query1 += " , goals_away "
#     query1 += ' , fixture_status '   
#     query1 += " from football_odds "
#     query1 += " where fixtureapi_id = '"+fixtureapi_id+"' "
#     query1 += " and leagueapi_id = '"+leagueapi_id+"' "
#     query1 += " and season = '"+season+"' "
#     # ------------------------------------------------------
#     mycursor = mydb.cursor()
#     mycursor.execute(query1)
#     result1 =  mycursor.fetchall()
#     # ------------------------------------------------------
# #     space += "__"
#     # ------------------------------------------------------
#     total_rows1 = len(result1)
#     print(space + "   Total Row(s) : " + str(total_rows1), flush=True) 
#     # ------------------------------------------------------
#     counter1 = 0
#     # ------------------------------------------------------
# #     space += "__"
#     # ------------------------------------------------------
#     for y in result1:   
#     # ------------------------------------------------------
#         goals_home =  str(y[0])
#         goals_away =  str(y[1])
#         fixture_status_odd =  str(y[2])
#     # ------------------------------------------------------
#         word = space + "      #"  + str(counter) + " >" 
#         word += " - " + goals_home 
#         word += " vs " + goals_away 
#         word += " => " + fixture_status_odd 
#         print(word, flush=True)
    # ------------------------------------------------------
    print("", flush=True)
    # ------------------------------------------------------
#     DICT = {
#         'leagueapi_id' :leagueapi_id,
#         'season' :season, 
#     }
    # ------------------------------------------------------
#     ROUTES = 'all_match'
#     af_controll_match_update(DICT, ROUTES, space)
# fixtureapi_id
    # ------------------------------------------------------      
    # ------------------------------------------------------
    DICT = {
        'fixtureapi_id' :fixtureapi_id, 
    }
    # ------------------------------------------------------
    ROUTES = 'fixtureapi_id'
    af_controll_match_update(DICT, ROUTES, space)
# Out:
# __ Select  leagueapi_id  , season  , fixtureapi_id  , fixture_status  from football_statistics  where fixture_status in ('Match Finished', 'Match Finished Ended')  and goals_home is null  and goals_away is null  limit 10
# ____Total goals_home is null and goals_away is null Row(s) : 10
#
# ______#1 >880 - 2021 > 799334 => Match Finished
#
# ________af_controll_match_update()
# __________aa_check_acccount()
# ____________API herlambangharyo@gmail.com counter is 77
# ____________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
# __________aa_check_acccount()
# __________aa_update_counter()
# __________af_response_fixtures()
# ____________ROUTES : fixtureapi_id
# ____________fixtureapi_id : 799334
# ______________Total API Response(s) : 1
# ________________fixture_status: Match Cancelled
# __________________fV_insert_new()
# __________________'12388'
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 10810
# __________________name : Y. Krasnozhan
# ____________________ Select  *  from football_coaches  where coachapi_id = 10810
# ____________________coaches Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 13728
# __________________name : S. Əsgərov
# ____________________ Select  *  from football_coaches  where coachapi_id = 13728
# ____________________coaches Row(s) : 1
# ________________football_odds: 1. /Match Cancelled/ 799334 / Russia W vs Azerbaijan W /2021-09-17 00:00:00+00:00/  UPDATED
# ________________football_odds UPDATED
# ________________football_statistics: 1. /Match Cancelled/ 799334 / Russia W vs Azerbaijan W /2021-09-17 00:00:00+00:00/  UPDATED
# ________________football_statistics UPDATED
#
# ______#2 >880 - 2021 > 799346 => Match Finished
#
# ________af_controll_match_update()
# __________aa_check_acccount()
# ____________API herlambangharyo@gmail.com counter is 76
# ____________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
# __________aa_check_acccount()
# __________aa_update_counter()
# __________af_response_fixtures()
# ____________ROUTES : fixtureapi_id
# ____________fixtureapi_id : 799346
# ______________Total API Response(s) : 1
# ________________fixture_status: Match Cancelled
# __________________fV_insert_new()
# __________________'12388'
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 10810
# __________________name : Y. Krasnozhan
# ____________________ Select  *  from football_coaches  where coachapi_id = 10810
# ____________________coaches Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 13706
# __________________name : M. Marić
# ____________________ Select  *  from football_coaches  where coachapi_id = 13706
# ____________________coaches Row(s) : 1
# ________________football_odds: 1. /Match Cancelled/ 799346 / Russia W vs Montenegro W /2021-09-21 14:00:00+00:00/  UPDATED
# ________________football_odds UPDATED
# ________________football_statistics: 1. /Match Cancelled/ 799346 / Russia W vs Montenegro W /2021-09-21 14:00:00+00:00/  UPDATED
# ________________football_statistics UPDATED
#
# ______#3 >880 - 2021 > 799373 => Match Finished
#
# ________af_controll_match_update()
# __________aa_check_acccount()
# ____________API herlambangharyo@gmail.com counter is 75
# ____________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
# __________aa_check_acccount()
# __________aa_update_counter()
# __________af_response_fixtures()
# ____________ROUTES : fixtureapi_id
# ____________fixtureapi_id : 799373
# ______________Total API Response(s) : 1
# ________________fixture_status: Match Cancelled
# __________________fV_insert_new()
# __________________'18629'
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 10810
# __________________name : Y. Krasnozhan
# ____________________ Select  *  from football_coaches  where coachapi_id = 10810
# ____________________coaches Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 13709
# __________________name : M. Gatt
# ____________________ Select  *  from football_coaches  where coachapi_id = 13709
# ____________________coaches Row(s) : 1
# ________________football_odds: 1. /Match Cancelled/ 799373 / Russia W vs Malta W /2021-10-21 14:00:00+00:00/  UPDATED
# ________________football_odds UPDATED
# ________________football_statistics: 1. /Match Cancelled/ 799373 / Russia W vs Malta W /2021-10-21 14:00:00+00:00/  UPDATED
# ________________football_statistics UPDATED
#
# ______#4 >880 - 2021 > 799410 => Match Finished
#
# ________af_controll_match_update()
# __________aa_check_acccount()
# ____________API herlambangharyo@gmail.com counter is 74
# ____________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
# __________aa_check_acccount()
# __________aa_update_counter()
# __________af_response_fixtures()
# ____________ROUTES : fixtureapi_id
# ____________fixtureapi_id : 799410
# ______________Total API Response(s) : 1
# ________________fixture_status: Match Cancelled
# __________________fV_insert_new()
# __________________Null
# ____________________Venue Row(s) : 0
# ____________________football_venues INSERTED
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 8935
# __________________name : S. Hurem
# ____________________ Select  *  from football_coaches  where coachapi_id = 8935
# ____________________coaches Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 10810
# __________________name : Y. Krasnozhan
# ____________________ Select  *  from football_coaches  where coachapi_id = 10810
# ____________________coaches Row(s) : 1
# ________________football_odds: 1. /Match Cancelled/ 799410 / Bosnia-Herzegovina W vs Russia W /2021-10-26 12:00:00+00:00/  UPDATED
# ________________football_odds UPDATED
# ________________football_statistics: 1. /Match Cancelled/ 799410 / Bosnia-Herzegovina W vs Russia W /2021-10-26 12:00:00+00:00/  UPDATED
# ________________football_statistics UPDATED
#
# ______#5 >880 - 2021 > 799418 => Match Finished
#
# ________af_controll_match_update()
# __________aa_check_acccount()
# ____________API herlambangharyo@gmail.com counter is 73
# ____________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
# __________aa_check_acccount()
# __________aa_update_counter()
# __________af_response_fixtures()
# ____________ROUTES : fixtureapi_id
# ____________fixtureapi_id : 799418
# ______________Total API Response(s) : 1
# ________________fixture_status: Match Cancelled
# __________________fV_insert_new()
# __________________Null
# ____________________Venue Row(s) : 0
# ____________________football_venues INSERTED
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 13728
# __________________name : S. Əsgərov
# ____________________ Select  *  from football_coaches  where coachapi_id = 13728
# ____________________coaches Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 10810
# __________________name : Y. Krasnozhan
# ____________________ Select  *  from football_coaches  where coachapi_id = 10810
# ____________________coaches Row(s) : 1
# ________________football_odds: 1. /Match Cancelled/ 799418 / Azerbaijan W vs Russia W /2021-11-25 15:00:00+00:00/  UPDATED
# ________________football_odds UPDATED
# ________________football_statistics: 1. /Match Cancelled/ 799418 / Azerbaijan W vs Russia W /2021-11-25 15:00:00+00:00/  UPDATED
# ________________football_statistics UPDATED
#
# ______#6 >880 - 2021 > 799447 => Match Finished
#
# ________af_controll_match_update()
# __________aa_check_acccount()
# ____________API herlambangharyo@gmail.com counter is 72
# ____________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
# __________aa_check_acccount()
# __________aa_update_counter()
# __________af_response_fixtures()
# ____________ROUTES : fixtureapi_id
# ____________fixtureapi_id : 799447
# ______________Total API Response(s) : 1
# ________________fixture_status: Match Cancelled
# __________________fV_insert_new()
# __________________'463'
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 7257
# __________________name : L. Søndergaard
# ____________________ Select  *  from football_coaches  where coachapi_id = 7257
# ____________________coaches Row(s) : 1
# __________________fC_insert_new()
# __________________coacheapi_id : 10810
# __________________name : Y. Krasnozhan
# ____________________ Select  *  from football_coaches  where coachapi_id = 10810
# ____________________coaches Row(s) : 1
# ________________football_odds: 1. /Match Cancelled/ 799447 / Denmark W vs Russia W /2021-11-30 17:00:00+00:00/  UPDATED
# ________________football_odds UPDATED
# ________________football_statistics: 1. /Match Cancelled/ 799447 / Denmark W vs Russia W /2021-11-30 17:00:00+00:00/  UPDATED
# ________________football_statistics UPDATED
#
# ______#7 >617 - 2022 > 963545 => Match Finished Ended
#
# ________af_controll_match_update()
# __________aa_check_acccount()
# ____________API herlambangharyo@gmail.com counter is 71
# ____________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
# __________aa_check_acccount()
# __________aa_update_counter()
# __________af_response_fixtures()
# ____________ROUTES : fixtureapi_id
# ____________fixtureapi_id : 963545
# ______________Total API Response(s) : 1
# ________________fixture_status: Match Finished
# __________________fV_insert_new()
# __________________Null
# ____________________Venue Row(s) : 0
# ____________________football_venues INSERTED
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# ________________football_odds: 1. /Match Finished/ 963545 / Palmeiras U20 vs Brasil de Pelotas U20 /2022-10-10 18:00:00+00:00/  UPDATED
# ________________football_odds UPDATED
# ________________football_statistics: 1. /Match Finished/ 963545 / Palmeiras U20 vs Brasil de Pelotas U20 /2022-10-10 18:00:00+00:00/  UPDATED
# ________________football_statistics UPDATED
#
# ______#8 >593 - 2022 > 834209 => Match Finished Ended
#
# ________af_controll_match_update()
# __________aa_check_acccount()
# ____________API herlambangharyo@gmail.com counter is 70
# ____________APIkey: 3a67de8c25msha3a34a82f226748p10786ajsn27ba3644d902
# __________aa_check_acccount()
# __________aa_update_counter()
# __________af_response_fixtures()
# ____________ROUTES : fixtureapi_id
# ____________fixtureapi_id : 834209
# ______________Total API Response(s) : 1
# ________________fixture_status: Match Cancelled
# __________________fV_insert_new()
# __________________Null
# ____________________Venue Row(s) : 0
# ____________________football_venues INSERTED
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# ________________football_odds: 1. /Match Cancelled/ 834209 / Akropolis vs Kungsängen /2022-10-15 11:00:00+00:00/  UPDATED
# ________________football_odds UPDATED
# ________________football_statistics: 1. /Match Cancelled/ 834209 / Akropolis vs Kungsängen /2022-10-15 11:00:00+00:00/  UPDATED
# ________________football_statistics UPDATED
#
# ______#9 >523 - 2022 > 840328 => Match Finished Ended
#
# ________af_controll_match_update()
# __________aa_check_acccount()
# ____________API api2@ariondigitalmedia.com counter is 3
# ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
# __________aa_check_acccount()
# __________aa_update_counter()
# __________af_response_fixtures()
# ____________ROUTES : fixtureapi_id
# ____________fixtureapi_id : 840328
# ______________Total API Response(s) : 1
# ________________fixture_status: Match Cancelled
# __________________fV_insert_new()
# __________________Null
# ____________________Venue Row(s) : 0
# ____________________football_venues INSERTED
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# ________________football_odds: 1. /Match Cancelled/ 840328 / Bay Cities vs Albion Pros /2022-10-16 02:00:00+00:00/  UPDATED
# ________________football_odds UPDATED
# ________________football_statistics: 1. /Match Cancelled/ 840328 / Bay Cities vs Albion Pros /2022-10-16 02:00:00+00:00/  UPDATED
# ________________football_statistics UPDATED
#
# ______#10 >212 - 2022 > 958713 => Match Finished Ended
#
# ________af_controll_match_update()
# __________aa_check_acccount()
# ____________API api2@ariondigitalmedia.com counter is 2
# ____________APIkey: 0f5971b410mshc737f7de34dac9ep16aff3jsn20b96d52adec
# __________aa_check_acccount()
# __________aa_update_counter()
# __________af_response_fixtures()
# ____________ROUTES : fixtureapi_id
# ____________fixtureapi_id : 958713
# ______________Total API Response(s) : 1
# ________________fixture_status: Match Cancelled
# __________________fV_insert_new()
# __________________Null
# ____________________Venue Row(s) : 0
# ____________________football_venues INSERTED
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# __________________fT_insert_new()
# ____________________Venue Row(s) : 1
# ________________football_odds: 1. /Match Cancelled/ 958713 / Nedelišće vs Inter Zapresic /2022-10-19 13:00:00+00:00/  UPDATED
# ________________football_odds UPDATED
# ________________football_statistics: 1. /Match Cancelled/ 958713 / Nedelišće vs Inter Zapresic /2022-10-19 13:00:00+00:00/  UPDATED
# ________________football_statistics UPDATED
