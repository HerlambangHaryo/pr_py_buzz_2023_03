# %%
""" 
    Check Predates
"""

# Import
from a_settings.messages import *  
from a_models.date import *   
from a_models.football_odds import *   
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_adds(1, space).strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    fo_controll_predates(day1, day2, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:12:38
#   __main()
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-09-03 08:12:38.732742
#   ____get_today_adds()
#   ______adds date_diff : 1
#   ______today_raw : 2023-09-04 08:12:38.732742
#   ____fo_controll_predates()
#   ______Select  DATE(date) as date_FX  , DATE(pre_odd_updated_at) as date_pre   , count(*) as counter   , fixture_status   from football_odds  where DATE(date) >= '2023-09-03'  and DATE(date) <= '2023-09-04'  group by DATE(pre_odd_updated_at), fixture_status  order by DATE(date) desc
#   ______Total Row(s) : 5
#
#       date_FX    date_pre  counter    fixture_status
# 0  2023-09-04  2023-09-01        4  Not Started Goto
# 1  2023-09-03  2023-08-27        1  Not Started Goto
# 2  2023-09-03  2023-09-02      386  Not Started Goto
# 3  2023-09-03  2023-08-30        6  Not Started Goto
# 4  2023-09-03        None       12              None
#
# # -------------------------------------------------- End at 2023-09-03 08:12:41

# %%
""" 
    Match Updates 0 day
"""

# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.api_odds_new import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    date_0         = get_today_adds(0, space).strftime("%Y-%m-%d") 
    date_raw       = get_today_adds(0, space) 
    # -------------------------------------------------- 
    DICT = {
        'date_0' : date_0,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 0,
        'date_raw' : date_raw,
        'max_page' : 0,
    }
    # --------------------------------------------------  
    PREP_ = "pre_"
    # -------------------------------------------------- 
    aoN_controll_match_update(DICT, PREP_, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:12:41
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:12:41.594534
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:12:41.596537
#   ______aoN_controll_match_update()
#   ________aa_check_acccount()
#   __________API arya6792@gmail.com counter is 99
#   __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________aoN_response_odds()
#   __________date_0 : 2023-09-03
#   __________page : 1
#   __________counter_loop : 0
#   __________date_diff : 0
#   __________date_raw : 2023-09-03 08:12:41.596537
#   __________max_page : 0
#   ____________Total API Response(s) : 10
#   ____________total_MAX_PAGE : 65
#   ______________
#   ______________1/10
#   ______________Argentina,  Copa de la Liga Profesional  #1032 - 2023
#   ______________2023-09-03 00:30:00+00:00 // UTC // 971206
#   ________________aoN_football_statistics_check()
#   ____________________Argentina,  Copa de la Liga Profesional - 2023 __ 971206 __ 2023-09-03 07:30:00 __ 8
#   ______________________________Velez Sarsfield vs River Plate
#   __________________________Kurang 2023-09-03 07:30:00 < 2023-09-03 08:12:41
#   ________________PREP_check_date is not valid
#   ________________
#   ________________2/10
#   ________________Argentina,  Copa de la Liga Profesional  #1032 - 2023
#   ________________2023-09-03 19:15:00+00:00 // UTC // 971208
#   __________________aoN_football_statistics_check()
#   ______________________Argentina,  Copa de la Liga Profesional - 2023 __ 971208 __ 2023-09-04 02:15:00 __ 8
#   ________________________________Argentinos JRS vs Atletico Tucuman
#   ____________________________Lebih 2023-09-04 02:15:00 >= 2023-09-03 08:12:41
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '1032'  and season = '2023'  and fixtureapi_id = '971208'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   ____________________football_fixtures 971208 UPDATED Not Started Goto
#   __________________
#   __________________3/10
#   __________________Argentina,  Copa de la Liga Profesional  #1032 - 2023
#   __________________2023-09-03 19:15:00+00:00 // UTC // 971209
#   ____________________aoN_football_statistics_check()
#   ________________________Argentina,  Copa de la Liga Profesional - 2023 __ 971209 __ 2023-09-04 02:15:00 __ 8
#   __________________________________Rosario Central vs Talleres Cordoba
#   ______________________________Lebih 2023-09-04 02:15:00 >= 2023-09-03 08:12:41
#   ______________________fua_update_or_insert()
#   ________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '1032'  and season = '2023'  and fixtureapi_id = '971209'
#   __________________________Total Row(s) : 1
#   ____________________________football_ultimate_assessments UPDATED
#   ____________________football_odds UPDATED
#   ____________________football_fixtures UPDATED
#   ______________________football_fixtures 971209 UPDATED Not Started Goto
#   ____________________
#   ____________________4/10
#   ____________________Argentina,  Copa de la Liga Profesional  #1032 - 2023
#   ____________________2023-09-03 21:30:00+00:00 // UTC // 971212
#   ______________________aoN_football_statistics_check()
#   __________________________Argentina,  Copa de la Liga Profesional - 2023 __ 971212 __ 2023-09-04 04:30:00 __ 8
#   ____________________________________Boca Juniors vs Tigre
#   ________________________________Lebih 2023-09-04 04:30:00 >= 2023-09-03 08:12:41
#   ________________________fua_update_or_insert()
#   __________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '1032'  and season = '2023'  and fixtureapi_id = '971212'
#   ____________________________Total Row(s) : 1
#   ______________________________football_ultimate_assessments UPDATED
#   ______________________football_odds UPDATED
#   ______________________football_fixtures UPDATED
#   ________________________football_fixtures 971212 UPDATED Not Started Goto
#   ______________________
#   ______________________5/10
#   ______________________Argentina,  Copa de la Liga Profesional  #1032 - 2023
#   ______________________2023-09-03 23:30:00+00:00 // UTC // 971217
#   ________________________aoN_football_statistics_check()
#   ____________________________Argentina,  Copa de la Liga Profesional - 2023 __ 971217 __ 2023-09-04 06:30:00 __ 8
#   ______________________________________Racing Club vs Estudiantes L.P.
#   __________________________________Lebih 2023-09-04 06:30:00 >= 2023-09-03 08:12:41
#   __________________________fua_update_or_insert()
#   ____________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '1032'  and season = '2023'  and fixtureapi_id = '971217'
#   ______________________________Total Row(s) : 1
#   ________________________________football_ultimate_assessments UPDATED
#   ________________________football_odds UPDATED
#   ________________________football_fixtures UPDATED
#   __________________________football_fixtures 971217 UPDATED Not Started Goto
#   ________________________
#   ________________________6/10
#   ________________________Australia,  Capital Territory NPL  #189 - 2023
#   ________________________2023-09-03 05:00:00+00:00 // UTC // 979306
#   __________________________aoN_football_statistics_check()
#   ______________________________Australia,  Capital Territory NPL - 2023 __ 979306 __ 2023-09-03 12:00:00 __ 11
#   ________________________________________Canberra FC vs Canberra Olympic
#   ____________________________________Lebih 2023-09-03 12:00:00 >= 2023-09-03 08:12:41
#   ____________________________fua_update_or_insert()
#   ______________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '189'  and season = '2023'  and fixtureapi_id = '979306'
#   ________________________________Total Row(s) : 1
#   __________________________________football_ultimate_assessments UPDATED
#   __________________________football_odds UPDATED
#   __________________________football_fixtures UPDATED
#   ____________________________football_fixtures 979306 UPDATED Not Started Goto
#   __________________________
#   __________________________7/10
#   __________________________Norway,  2. Division - Group 2  #474 - 2023
#   __________________________2023-09-03 12:00:00+00:00 // UTC // 980031
#   ____________________________aoN_football_statistics_check()
#   ________________________________Norway,  2. Division - Group 2 - 2023 __ 980031 __ 2023-09-03 19:00:00 __ 8
#   __________________________________________Alta vs Bærum
#   ______________________________________Lebih 2023-09-03 19:00:00 >= 2023-09-03 08:12:41
#   ______________________________fua_update_or_insert()
#   ________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '474'  and season = '2023'  and fixtureapi_id = '980031'
#   __________________________________Total Row(s) : 1
#   ____________________________________football_ultimate_assessments UPDATED
#   ____________________________football_odds UPDATED
#   ____________________________football_fixtures UPDATED
#   ______________________________football_fixtures 980031 UPDATED Not Started Goto
#   ____________________________
#   ____________________________8/10
#   ____________________________Norway,  2. Division - Group 2  #474 - 2023
#   ____________________________2023-09-03 14:00:00+00:00 // UTC // 980032
#   ______________________________aoN_football_statistics_check()
#   __________________________________Norway,  2. Division - Group 2 - 2023 __ 980032 __ 2023-09-03 21:00:00 __ 8
#   ____________________________________________Levanger vs Sotra
#   ________________________________________Lebih 2023-09-03 21:00:00 >= 2023-09-03 08:12:41
#   ________________________________fua_update_or_insert()
#   __________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '474'  and season = '2023'  and fixtureapi_id = '980032'
#   ____________________________________Total Row(s) : 1
#   ______________________________________football_ultimate_assessments UPDATED
#   ______________________________football_odds UPDATED
#   ______________________________football_fixtures UPDATED
#   ________________________________football_fixtures 980032 UPDATED Not Started Goto
#   ______________________________
#   ______________________________9/10
#   ______________________________Norway,  2. Division - Group 2  #474 - 2023
#   ______________________________2023-09-03 13:00:00+00:00 // UTC // 980035
#   ________________________________aoN_football_statistics_check()
#   ____________________________________Norway,  2. Division - Group 2 - 2023 __ 980035 __ 2023-09-03 20:00:00 __ 8
#   ______________________________________________Kvik Halden vs Strommen
#   __________________________________________Lebih 2023-09-03 20:00:00 >= 2023-09-03 08:12:41
#   __________________________________fua_update_or_insert()
#   ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '474'  and season = '2023'  and fixtureapi_id = '980035'
#   ______________________________________Total Row(s) : 1
#   ________________________________________football_ultimate_assessments UPDATED
#   ________________________________football_odds UPDATED
#   ________________________________football_fixtures UPDATED
#   __________________________________football_fixtures 980035 UPDATED Not Started Goto
#   ________________________________
#   ________________________________10/10
#   ________________________________Norway,  2. Division - Group 1  #473 - 2023
#   ________________________________2023-09-03 14:00:00+00:00 // UTC // 980213
#   __________________________________aoN_football_statistics_check()
#   ______________________________________Norway,  2. Division - Group 1 - 2023 __ 980213 __ 2023-09-03 21:00:00 __ 8
#   ________________________________________________Brattvåg vs Ørn Horten
#   ____________________________________________Lebih 2023-09-03 21:00:00 >= 2023-09-03 08:12:41
#   ____________________________________fua_update_or_insert()
#   ______________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '473'  and season = '2023'  and fixtureapi_id = '980213'
#   ________________________________________Total Row(s) : 1
#   __________________________________________football_ultimate_assessments UPDATED
#   __________________________________football_odds UPDATED
#   __________________________________football_fixtures UPDATED
#   ____________________________________football_fixtures 980213 UPDATED Not Started Goto
#   __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API arya6792@gmail.com counter is 98
# __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date_0 : 2023-09-03
# __________page : 2
# __________counter_loop : 0
# __________date_diff : 0
# __________date_raw : 2023-09-03 08:12:41.596537
# __________max_page : 65
# ____________Total API Response(s) : 10
# ____________total_MAX_PAGE : 65
# ______________
# ______________1/10
# ______________USA,  Major League Soccer  #253 - 2023
# ______________2023-09-03 00:30:00+00:00 // UTC // 981150
# ________________aoN_football_statistics_check()
# ____________________USA,  Major League Soccer - 2023 __ 981150 __ 2023-09-03 07:30:00 __ 8
# ______________________________FC Dallas vs Atlanta United FC
# __________________________Kurang 2023-09-03 07:30:00 < 2023-09-03 08:12:41
# ________________PREP_check_date is not valid
# ________________
# ________________2/10
# ________________USA,  Major League Soccer  #253 - 2023
# ________________2023-09-03 00:30:00+00:00 // UTC // 981151
# __________________aoN_football_statistics_check()
# ____________________________football_odds UPDATED
# ____________________________football_fixtures UPDATED
# ______________________________football_fixtures 981157 UPDATED Not Started Goto
# ____________________________
# ____________________________8/10
# ____________________________USA,  Major League Soccer  #253 - 2023
# ____________________________2023-09-03 00:30:00+00:00 // UTC // 981278
# ______________________________aoN_football_statistics_check()
# __________________________________USA,  Major League Soccer - 2023 __ 981278 __ 2023-09-03 07:30:00 __ 8
# ____________________________________________Sporting Kansas City vs St. Louis City
# ________________________________________Kurang 2023-09-03 07:30:00 < 2023-09-03 08:12:41
# ______________________________PREP_check_date is not valid
# ______________________________
# ______________________________9/10
# ______________________________Iceland,  Úrvalsdeild  #164 - 2023
# ______________________________2023-09-03 14:00:00+00:00 // UTC // 981584
# ________________________________aoN_football_statistics_check()
# ____________________________________Iceland,  Úrvalsdeild - 2023 __ 981584 __ 2023-09-03 21:00:00 __ 8
# ______________________________________________Fylkir vs KA Akureyri
# __________________________________________Lebih 2023-09-03 21:00:00 >= 2023-09-03 08:12:41
# __________________________________fua_update_or_insert()
# ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '164'  and season = '2023'  and fixtureapi_id = '981584'
# ______________________________________Total Row(s) : 1
# ________________________________________football_ultimate_assessments UPDATED
# ________________________________football_odds UPDATED
# ________________________________football_fixtures UPDATED
# __________________________________football_fixtures 981584 UPDATED Not Started Goto
# ________________________________
# ________________________________10/10
# ________________________________Iceland,  Úrvalsdeild  #164 - 2023
# ________________________________2023-09-03 14:00:00+00:00 // UTC // 981585
# __________________________________aoN_football_statistics_check()
# ______________________________________Iceland,  Úrvalsdeild - 2023 __ 981585 __ 2023-09-03 21:00:00 __ 8
# ________________________________________________Stjarnan vs Keflavik
# ____________________________________________Lebih 2023-09-03 21:00:00 >= 2023-09-03 08:12:41
# ____________________________________fua_update_or_insert()
# ______________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '164'  and season = '2023'  and fixtureapi_id = '981585'
# ________________________________________Total Row(s) : 1
# __________________________________________football_ultimate_assessments UPDATED
# __________________________________football_odds UPDATED
# __________________________________football_fixtures UPDATED
# ____________________________________football_fixtures 981585 UPDATED Not Started Goto
# __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API arya6792@gmail.com counter is 97
# __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date_0 : 2023-09-03
# __________page : 3
# __________counter_loop : 0
# __________date_diff : 0
# __________date_raw : 2023-09-03 08:12:41.596537
# __________max_page : 65
# ____________Total API Response(s) : 10
# ____________total_MAX_PAGE : 65
# ______________
# ______________1/10
# ______________Iceland,  Úrvalsdeild  #164 - 2023
# ______________2023-09-03 14:00:00+00:00 // UTC // 981586
# ________________aoN_football_statistics_check()
# ____________________Iceland,  Úrvalsdeild - 2023 __ 981586 __ 2023-09-03 21:00:00 __ 8
# ______________________________Fram Reykjavik vs Vikingur Reykjavik
# __________________________Lebih 2023-09-03 21:00:00 >= 2023-09-03 08:12:41
# __________________fua_update_or_insert()
# ____________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '164'  and season = '2023'  and fixtureapi_id = '981586'
# ______________________Total Row(s) : 1
# ________________________football_ultimate_assessments UPDATED
# ________________football_odds UPDATED
# ________________football_fixtures UPDATED
# __________________football_fixtures 981586 UPDATED Not Started Goto
# ________________
# ________________2/10
# ________________Iceland,  Úrvalsdeild  #164 - 2023
# ________________2023-09-03 14:00:00+00:00 // UTC // 981587
# __________________aoN_football_statistics_check()
# ______________________Iceland,  Úrvalsdeild - 2023 __ 981587 __ 2023-09-03 21:00:00 __ 8
# ________________________________Breidablik vs FH hafnarfjordur
# ____________________________Lebih 2023-09-03 21:00:00 >= 2023-09-03 08:12:41
# ____________________fua_update_or_insert()
# ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '164'  and season = '2023'  and fixtureapi_id = '981587'
# ________________________Total Row(s) : 1
# __________________________football_ultimate_assessments UPDATED
# __________________football_odds UPDATED
# __________________football_fixtures UPDATED
# ____________________football_fixtures
# ________________________________fua_update_or_insert()
# __________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '265'  and season = '2023'  and fixtureapi_id = '983838'
# ____________________________________Total Row(s) : 1
# ______________________________________football_ultimate_assessments UPDATED
# ______________________________football_odds UPDATED
# ______________________________football_fixtures UPDATED
# ________________________________football_fixtures 983838 UPDATED Not Started Goto
# ______________________________
# ______________________________9/10
# ______________________________Chile,  Primera División  #265 - 2023
# ______________________________2023-09-03 15:30:00+00:00 // UTC // 983841
# ________________________________aoN_football_statistics_check()
# ____________________________________Chile,  Primera División - 2023 __ 983841 __ 2023-09-03 22:30:00 __ 8
# ______________________________________________Magallanes vs Palestino
# __________________________________________Lebih 2023-09-03 22:30:00 >= 2023-09-03 08:12:41
# __________________________________fua_update_or_insert()
# ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '265'  and season = '2023'  and fixtureapi_id = '983841'
# ______________________________________Total Row(s) : 1
# ________________________________________football_ultimate_assessments UPDATED
# ________________________________football_odds UPDATED
# ________________________________football_fixtures UPDATED
# __________________________________football_fixtures 983841 UPDATED Not Started Goto
# ________________________________
# ________________________________10/10
# ________________________________Chile,  Primera División  #265 - 2023
# ________________________________2023-09-03 20:30:00+00:00 // UTC // 983842
# __________________________________aoN_football_statistics_check()
# ______________________________________Chile,  Primera División - 2023 __ 983842 __ 2023-09-04 03:30:00 __ 8
# ________________________________________________O'Higgins vs A. Italiano
# ____________________________________________Lebih 2023-09-04 03:30:00 >= 2023-09-03 08:12:41
# ____________________________________fua_update_or_insert()
# ______________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '265'  and season = '2023'  and fixtureapi_id = '983842'
# ________________________________________Total Row(s) : 1
# __________________________________________football_ultimate_assessments UPDATED
# __________________________________football_odds UPDATED
# __________________________________football_fixtures UPDATED
# ____________________________________football_fixtures 983842 UPDATED Not Started Goto
# __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API arya6792@gmail.com counter is 96
# __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date_0 : 2023-09-03
# __________page : 4
# __________counter_loop : 0
# __________date_diff : 0
# __________date_raw : 2023-09-03 08:12:41.596537
# __________max_page : 65
# ____________Total API Response(s) : 10
# ____________total_MAX_PAGE : 65
# ______________
# ______________1/10
# ______________Chile,  Primera División  #265 - 2023
# ______________2023-09-03 23:00:00+00:00 // UTC // 983843
# ________________aoN_football_statistics_check()
# ____________________Chile,  Primera División - 2023 __ 983843 __ 2023-09-04 06:00:00 __ 8
# ______________________________Nublense vs Everton de Vina
# __________________________Lebih 2023-09-04 06:00:00 >= 2023-09-03 08:12:41
# __________________fua_update_or_insert()
# ____________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '265'  and season = '2023'  and fixtureapi_id = '983843'
# ______________________Total Row(s) : 1
# ________________________football_ultimate_assessments UPDATED
# ________________football_odds UPDATED
# ________________football_fixtures UPDATED
# __________________football_fixtures 983843 UPDATED Not Started Goto
# ________________
# ________________2/10
# ________________Chile,  Primera B  #266 - 2023
# ________________2023-09-03 23:00:00+00:00 // UTC // 987933
# __________________aoN_football_statistics_check()
# ______________________Chile,  Primera B - 2023 __ 987933 __ 2023-09-04 06:00:00 __ 11
# ________________________________Deportes Iquique vs Cobreloa
# ____________________________Lebih 2023-09-04 06:00:00 >= 2023-09-03 08:12:41
# ____________________fua_update_or_insert()
# ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '266'  and season = '2023'  and fixtureapi_id = '987933'
# ________________________Total Row(s) : 1
# __________________________football_ultimate_assessments UPDATED
# __________________football_odds UPDATED
# __________________football_fixtures UPDATED
# ____________________football_fixtures
# ________________________________fua_update_or_insert()
# __________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '239'  and season = '2023'  and fixtureapi_id = '990391'
# ____________________________________Total Row(s) : 1
# ______________________________________football_ultimate_assessments UPDATED
# ______________________________football_odds UPDATED
# ______________________________football_fixtures UPDATED
# ________________________________football_fixtures 990391 UPDATED Not Started Goto
# ______________________________
# ______________________________9/10
# ______________________________Colombia,  Primera A  #239 - 2023
# ______________________________2023-09-03 01:20:00+00:00 // UTC // 990393
# ________________________________aoN_football_statistics_check()
# ____________________________________Colombia,  Primera A - 2023 __ 990393 __ 2023-09-03 08:20:00 __ 8
# ______________________________________________Alianza Petrolera vs America de Cali
# __________________________________________Lebih 2023-09-03 08:20:00 >= 2023-09-03 08:12:41
# __________________________________fua_update_or_insert()
# ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '239'  and season = '2023'  and fixtureapi_id = '990393'
# ______________________________________Total Row(s) : 0
# ________________________________________football_ultimate_assessments INSERTED
# ________________________________football_odds UPDATED
# ________________________________football_fixtures UPDATED
# __________________________________football_fixtures 990393 UPDATED Not Started Goto
# ________________________________
# ________________________________10/10
# ________________________________Colombia,  Primera A  #239 - 2023
# ________________________________2023-09-03 23:10:00+00:00 // UTC // 990394
# __________________________________aoN_football_statistics_check()
# ______________________________________Colombia,  Primera A - 2023 __ 990394 __ 2023-09-04 06:10:00 __ 8
# ________________________________________________Rionegro Aguilas vs Millonarios
# ____________________________________________Lebih 2023-09-04 06:10:00 >= 2023-09-03 08:12:41
# ____________________________________fua_update_or_insert()
# ______________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '239'  and season = '2023'  and fixtureapi_id = '990394'
# ________________________________________Total Row(s) : 1
# __________________________________________football_ultimate_assessments UPDATED
# __________________________________football_odds UPDATED
# __________________________________football_fixtures UPDATED
# ____________________________________football_fixtures 990394 UPDATED Not Started Goto
# __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API arya6792@gmail.com counter is 95
# __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date_0 : 2023-09-03
# __________page : 5
# __________counter_loop : 0
# __________date_diff : 0
# __________date_raw : 2023-09-03 08:12:41.596537
# __________max_page : 65
# ____________Total API Response(s) : 10
# ____________total_MAX_PAGE : 65
# ______________
# ______________1/10
# ______________Sweden,  Division 2 - Norra Götaland  #592 - 2023
# ______________2023-09-03 12:00:00+00:00 // UTC // 993095
# ________________aoN_football_statistics_check()
# ____________________Sweden,  Division 2 - Norra Götaland - 2023 __ 993095 __ 2023-09-03 19:00:00 __ 8
# ______________________________Yxhult vs Stenungsund
# __________________________Lebih 2023-09-03 19:00:00 >= 2023-09-03 08:12:41
# __________________fua_update_or_insert()
# ____________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '592'  and season = '2023'  and fixtureapi_id = '993095'
# ______________________Total Row(s) : 1
# ________________________football_ultimate_assessments UPDATED
# ________________football_odds UPDATED
# ________________football_fixtures UPDATED
# __________________football_fixtures 993095 UPDATED Not Started Goto
# ________________
# ________________2/10
# ________________Sweden,  Division 2 - Norra Götaland  #592 - 2023
# ________________2023-09-03 12:00:00+00:00 // UTC // 993096
# __________________aoN_football_statistics_check()
# ______________________Sweden,  Division 2 - Norra Götaland - 2023 __ 993096 __ 2023-09-03 19:00:00 __ 8
# ________________________________Gauthiod vs Forward
# ____________________________Lebih 2023-09-03 19:00:00 >= 2023-09-03 08:12:41
# ____________________fua_update_or_insert()
# ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '592'  and season = '2023'  and fixtureapi_id = '993096'
# ________________________Total Row(s) : 1
# __________________________football_ultimate_assessments UPDATED
# __________________football_odds UPDATED
# __________________football_fixtures UPDATED
# ____________________football_fixtures 993096 UPDATED Not Started Goto
# __________________
# __________________3/10
# __________________Sweden,  Division 2 - Norra Svealand  #593 - 2023
# __________________2023-09-03 11:00:00+00:00 // UTC // 993276
# ____________________aoN_football_statistics_check()
# ________________________Sweden,  Division 2 - Norra Svealand - 2023 __ 993276 __ 2023-09-03 18:00:00 __ 8
# __________________________________Kvarnsveden vs Karlberg
# ______________________________Lebih 2023-09-03 18:00:00 >= 2023-09-03 08:12:41
# ______________________fua_update_or_insert()
# ________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '593'  and season = '2023'  and fixtureapi_id = '993276'
# __________________________Total Row(s) : 1
# ____________________________football_ultimate_assessments UPDATED
# ____________________football_odds UPDATED
# ____________________football_fixtures UPDATED
# ______________________football_fixtures 993276 UPDATED Not Started Goto
# ____________________
# ____________________4/10
# ____________________Sweden,  Division 2 - Norra Svealand  #593 - 2023
# ____________________2023-09-03 11:00:00+00:00 // UTC // 993277
# __________________________aoN_football_odds_insert_rows()
# __________________________football_odds INSERTED
# ______________________aoN_football_statistics_check()
# __________________________Sweden,  Division 2 - Norra Svealand - 2023 __ 993277 __ 2023-09-03 18:00:00 __ 8
# ____________________________________Kungsängen vs Viggbyholms IK
# ________________________________Lebih 2023-09-03 18:00:00 >= 2023-09-03 08:12:41
# ________________________fua_update_or_insert()
# __________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '593'  and season = '2023'  and fixtureapi_id = '993277'
# ____________________________Total Row(s) : 0
# ______________________________football_ultimate_assessments INSERTED
# ______________________football_odds UPDATED
# ______________________football_fixtures UPDATED
# ________________________football_fixtures 993277 UPDATED Not Started Goto
# ______________________
# ______________________5/10
# ______________________Sweden,  Division 2 - Norra Svealand  #593 - 2023
# ______________________2023-09-03 14:00:00+00:00 // UTC // 993278
# ________________________aoN_football_statistics_check()
# ____________________________Sweden,  Division 2 - Norra Svealand - 2023 __ 993278 __ 2023-09-03 21:00:00 __ 8
# ______________________________________Franke vs IFK Österåker
# __________________________________Lebih 2023-09-03 21:00:00 >= 2023-09-03 08:12:41
# __________________________fua_update_or_insert()
# ____________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '593'  and season = '2023'  and fixtureapi_id = '993278'
# ______________________________Total Row(s) : 1
# ________________________________football_ultimate_assessments UPDATED
# ________________________football_odds UPDATED
# ________________________football_fixtures UPDATED
# __________________________football_fixtures 993278 UPDATED Not Started Goto
# ________________________
# ________________________6/10
# ________________________Sweden,  Division 2 - Västra Götaland  #596 - 2023
# ________________________2023-09-03 11:00:00+00:00 // UTC // 993458
# __________________________aoN_football_statistics_check()
# ______________________________Sweden,  Division 2 - Västra Götaland - 2023 __ 993458 __ 2023-09-03 18:00:00 __ 8
# ________________________________________Västra Frölunda vs Hittarp
# ____________________________________Lebih 2023-09-03 18:00:00 >= 2023-09-03 08:12:41
# ____________________________fua_update_or_insert()
# ______________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '596'  and season = '2023'  and fixtureapi_id = '993458'
# ________________________________Total Row(s) : 1
# __________________________________football_ultimate_assessments UPDATED
# __________________________football_odds UPDATED
# __________________________football_fixtures UPDATED
# ____________________________football_fixtures 993458 UPDATED Not Started Goto
# __________________________
# __________________________7/10
# __________________________Sweden,  Division 2 - Västra Götaland  #596 - 2023
# ...
# __________________________football_fixtures UPDATED
# ____________________________football_fixtures 1022798 UPDATED Not Started Goto
# __________________________
# __________________________7/10
# __________________________China,  League One  #170 - 2023
# __________________________2023-09-03 11:30:00+00:00 // UTC // 1022799
# ________________________________aoN_football_odds_insert_rows()
# ________________________________football_odds INSERTED
# ____________________________aoN_football_statistics_check()
# ________________________________China,  League One - 2023 __ 1022799 __ 2023-09-03 18:30:00 __ 8
# __________________________________________Hebei Kungfu vs Shenyang Urban
# ______________________________________Lebih 2023-09-03 18:30:00 >= 2023-09-03 08:12:41
# ______________________________fua_update_or_insert()
# ________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '170'  and season = '2023'  and fixtureapi_id = '1022799'
# __________________________________Total Row(s) : 0
# ____________________________________football_ultimate_assessments INSERTED
# ____________________________football_odds UPDATED
# ____________________________football_fixtures UPDATED
# ______________________________football_fixtures 1022799 UPDATED Not Started Goto
# ____________________________
# ____________________________8/10
# ____________________________China,  League One  #170 - 2023
# ____________________________2023-09-03 11:30:00+00:00 // UTC // 1022800
# __________________________________aoN_football_odds_insert_rows()
# __________________________________football_odds INSERTED
# ______________________________aoN_football_statistics_check()
# __________________________________China,  League One - 2023 __ 1022800 __ 2023-09-03 18:30:00 __ 8
# ____________________________________________Guangxi Baoyun vs Wuxi Wugou
# ________________________________________Lebih 2023-09-03 18:30:00 >= 2023-09-03 08:12:41
# ________________________________fua_update_or_insert()
# __________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '170'  and season = '2023'  and fixtureapi_id = '1022800'
# ____________________________________Total Row(s) : 0
# ______________________________________football_ultimate_assessments INSERTED
# ______________________________football_odds UPDATED
# ______________________________football_fixtures UPDATED
# ________________________________football_fixtures 1022800 UPDATED Not Started Goto
# ______________________________
# ______________________________9/10
# ______________________________Brazil,  Copa Paulista  #742 - 2023
# ______________________________2023-09-03 13:00:00+00:00 // UTC // 1025934
# ____________________________________aoN_football_odds_insert_rows()
# ____________________________________football_odds INSERTED
# ________________________________aoN_football_statistics_check()
# ____________________________________Brazil,  Copa Paulista - 2023 __ 1025934 __ 2023-09-03 20:00:00 __ 8
# ______________________________________________Noroeste vs Comercial
# __________________________________________Lebih 2023-09-03 20:00:00 >= 2023-09-03 08:12:41
# __________________________________fua_update_or_insert()
# ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '742'  and season = '2023'  and fixtureapi_id = '1025934'
# ______________________________________Total Row(s) : 0
# ________________________________________football_ultimate_assessments INSERTED
# ________________________________football_odds UPDATED
# ________________________________football_fixtures UPDATED
# __________________________________football_fixtures 1025934 UPDATED Not Started Goto
# ________________________________
# ________________________________10/10
# ________________________________Brazil,  Copa Paulista  #742 - 2023
# ________________________________2023-09-03 13:00:00+00:00 // UTC // 1025935
# ______________________________________aoN_football_odds_insert_rows()
# ______________________________________football_odds INSERTED
# __________________________________aoN_football_statistics_check()
# ______________________________________Brazil,  Copa Paulista - 2023 __ 1025935 __ 2023-09-03 20:00:00 __ 8
# ________________________________________________Sao Bento vs Grêmio Prudente
# ____________________________________________Lebih 2023-09-03 20:00:00 >= 2023-09-03 08:12:41
# ____________________________________fua_update_or_insert()
# ______________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '742'  and season = '2023'  and fixtureapi_id = '1025935'
# ________________________________________Total Row(s) : 0
# __________________________________________football_ultimate_assessments INSERTED
# __________________________________football_odds UPDATED
# __________________________________football_fixtures UPDATED
# ____________________________________football_fixtures 1025935 UPDATED Not Started Goto
# __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API arya6792@gmail.com counter is 82
# __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date_0 : 2023-09-03
# __________page : 17
# __________counter_loop : 0
# __________date_diff : 0
# __________date_raw : 2023-09-03 08:12:41.596537
# __________max_page : 65
# ____________Total API Response(s) : 9
# ____________total_MAX_PAGE : 65
# ______________
# ______________1/9
# ______________Faroe-Islands,  Løgmanssteypid  #491 - 2023
# ______________2023-09-03 16:00:00+00:00 // UTC // 1026791
# ____________________aoN_football_odds_insert_rows()
# ____________________football_odds INSERTED
# ________________aoN_football_statistics_check()
# ______________________aoN_football_leagues_check()
# ______________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '491'
# ________________________Total Row(s) : 1
# ______________________get_today_adds()
# ________________________adds date_diff : 0
# ________________________today_raw : 2023-09-03 08:24:46.586650
# ______________________afN_controll_match_update()
# ________________________aa_check_acccount()
# __________________________API arya6792@gmail.com counter is 81
# __________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# 

# ________________________football_odds UPDATED
# ________________________football_fixtures UPDATED
# __________________________football_fixtures 1027677 UPDATED Not Started Goto
# ________________________
# ________________________6/9
# ________________________Argentina,  Primera Nacional  #129 - 2023
# ________________________2023-09-03 21:30:00+00:00 // UTC // 1027681
# __________________________aoN_football_statistics_check()
# ______________________________Argentina,  Primera Nacional - 2023 __ 1027681 __ 2023-09-04 04:30:00 __ 8
# ________________________________________Atletico DE Rafaela vs Deportivo Madryn
# ____________________________________Lebih 2023-09-04 04:30:00 >= 2023-09-03 08:12:41
# ____________________________fua_update_or_insert()
# ______________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '129'  and season = '2023'  and fixtureapi_id = '1027681'
# ________________________________Total Row(s) : 1
# __________________________________football_ultimate_assessments UPDATED
# __________________________football_odds UPDATED
# __________________________football_fixtures UPDATED
# ____________________________football_fixtures 1027681 UPDATED Not Started Goto
# __________________________
# __________________________7/9
# __________________________Argentina,  Primera Nacional  #129 - 2023
# __________________________2023-09-03 18:40:00+00:00 // UTC // 1027844
# ____________________________aoN_football_statistics_check()
# ________________________________Argentina,  Primera Nacional - 2023 __ 1027844 __ 2023-09-04 01:40:00 __ 8
# __________________________________________Deportivo Moron vs Defensores De Belgrano
# ______________________________________Lebih 2023-09-04 01:40:00 >= 2023-09-03 08:12:41
# ______________________________fua_update_or_insert()
# ________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '129'  and season = '2023'  and fixtureapi_id = '1027844'
# __________________________________Total Row(s) : 1
# ____________________________________football_ultimate_assessments UPDATED
# ____________________________football_odds UPDATED
# ____________________________football_fixtures UPDATED
# ______________________________football_fixtures 1027844 UPDATED Not Started Goto
# ____________________________
# ____________________________8/9
# ____________________________Argentina,  Primera Nacional  #129 - 2023
# ____________________________2023-09-03 18:10:00+00:00 // UTC // 1027848
# ______________________________aoN_football_statistics_check()
# __________________________________Argentina,  Primera Nacional - 2023 __ 1027848 __ 2023-09-04 01:10:00 __ 8
# ____________________________________________Alvarado vs San Martin Tucuman
# ________________________________________Lebih 2023-09-04 01:10:00 >= 2023-09-03 08:12:41
# ________________________________fua_update_or_insert()
# __________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '129'  and season = '2023'  and fixtureapi_id = '1027848'
# ____________________________________Total Row(s) : 1
# ______________________________________football_ultimate_assessments UPDATED
# ______________________________football_odds UPDATED
# ______________________________football_fixtures UPDATED
# ________________________________football_fixtures 1027848 UPDATED Not Started Goto
# ______________________________
# ______________________________9/9
# ______________________________Argentina,  Primera Nacional  #129 - 2023
# ______________________________2023-09-03 22:00:00+00:00 // UTC // 1027850
# ________________________________aoN_football_statistics_check()
# ____________________________________Argentina,  Primera Nacional - 2023 __ 1027850 __ 2023-09-04 05:00:00 __ 8
# ______________________________________________San Martin S.J. vs San Telmo
# __________________________________________Lebih 2023-09-04 05:00:00 >= 2023-09-03 08:12:41
# __________________________________fua_update_or_insert()
# ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '129'  and season = '2023'  and fixtureapi_id = '1027850'
# ______________________________________Total Row(s) : 1
# ________________________________________football_ultimate_assessments UPDATED
# ________________________________football_odds UPDATED
# ________________________________football_fixtures UPDATED
# __________________________________football_fixtures 1027850 UPDATED Not Started Goto
# ________________________________STOP RESPONSE
# # -------------------------------------------------- End at 2023-09-03 08:25:26

# %%
""" 
    Match Updates 1 day
"""

# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.api_odds_new import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    date_0         = get_today_adds(1, space).strftime("%Y-%m-%d") 
    date_raw       = get_today_adds(1, space) 
    # -------------------------------------------------- 
    DICT = {
        'date_0' : date_0,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 0,
        'date_raw' : date_raw,
        'max_page' : 0,
    }
    # --------------------------------------------------  
    PREP_ = "pre_"
    # -------------------------------------------------- 
    aoN_controll_match_update(DICT, PREP_, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:25:26
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 1
#   ________today_raw : 2023-09-04 08:25:26.145886
#   ______get_today_adds()
#   ________adds date_diff : 1
#   ________today_raw : 2023-09-04 08:25:26.146885
#   ______aoN_controll_match_update()
#   ________aa_check_acccount()
#   __________API arya6792@gmail.com counter is 80
#   __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________aoN_response_odds()
#   __________date_0 : 2023-09-04
#   __________page : 1
#   __________counter_loop : 0
#   __________date_diff : 0
#   __________date_raw : 2023-09-04 08:25:26.146885
#   __________max_page : 0
#   ____________Total API Response(s) : 10
#   ____________total_MAX_PAGE : 5
#   ______________
#   ______________1/10
#   ______________Argentina,  Copa de la Liga Profesional  #1032 - 2023
#   ______________2023-09-04 21:00:00+00:00 // UTC // 971207
#   ________________aoN_football_statistics_check()
#   ____________________Argentina,  Copa de la Liga Profesional - 2023 __ 971207 __ 2023-09-05 04:00:00 __ 8
#   ______________________________Barracas Central vs Arsenal Sarandi
#   __________________________Lebih 2023-09-05 04:00:00 >= 2023-09-04 08:25:26
#   __________________fua_update_or_insert()
#   ____________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '1032'  and season = '2023'  and fixtureapi_id = '971207'
#   ______________________Total Row(s) : 1
#   ________________________football_ultimate_assessments UPDATED
#   ________________football_odds UPDATED
#   ________________football_fixtures UPDATED
#   __________________football_fixtures 971207 UPDATED Not Started Goto
#   ________________
#   ________________2/10
#   ________________Argentina,  Copa de la Liga Profesional  #1032 - 2023
#   ________________2023-09-04 23:00:00+00:00 // UTC // 971216
#   __________________aoN_football_statistics_check()
#   ______________________Argentina,  Copa de la Liga Profesional - 2023 __ 971216 __ 2023-09-05 06:00:00 __ 8
#   ________________________________Union Santa Fe vs San Lorenzo
#   ____________________________Lebih 2023-09-05 06:00:00 >= 2023-09-04 08:25:26
#   ____________________fua_update_or_insert()
#   ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '1032'  and season = '2023'  and fixtureapi_id = '971216'
#   ________________________Total Row(s) : 1
#   __________________________football_ultimate_assessments UPDATED
#   __________________football_odds UPDATED
#   __________________football_fixtures UPDATED
#   ____________________football_fixtures 971216 UPDATED Not Started Goto
#   __________________
#   __________________3/10
#   __________________Norway,  2. Division - Group 1  #473 - 2023
#   __________________2023-09-04 16:00:00+00:00 // UTC // 980217
#   ____________________aoN_football_statistics_check()
#   ________________________Norway,  2. Division - Group 1 - 2023 __ 980217 __ 2023-09-04 23:00:00 __ 8
#   __________________________________Lyn vs Arendal
#   ______________________________Lebih 2023-09-04 23:00:00 >= 2023-09-04 08:25:26
#   ______________________fua_update_or_insert()
#   ________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '473'  and season = '2023'  and fixtureapi_id = '980217'
#   __________________________Total Row(s) : 1
#   ____________________________football_ultimate_assessments UPDATED
#   ____________________football_odds UPDATED
#   ____________________football_fixtures UPDATED
#   ______________________football_fixtures 980217 UPDATED Not Started Goto
#   ____________________
#   ____________________4/10
#   ____________________USA,  Major League Soccer  #253 - 2023
#   ____________________2023-09-04 02:00:00+00:00 // UTC // 981154
#   __________________________aoN_football_odds_insert_rows()
#   __________________________football_odds INSERTED
#   ______________________aoN_football_statistics_check()
#   __________________________USA,  Major League Soccer - 2023 __ 981154 __ 2023-09-04 09:00:00 __ 8
#   ____________________________________Los Angeles FC vs Inter Miami
#   ________________________________Lebih 2023-09-04 09:00:00 >= 2023-09-04 08:25:26
#   ________________________fua_update_or_insert()
#   __________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '253'  and season = '2023'  and fixtureapi_id = '981154'
#   ____________________________Total Row(s) : 0
#   ______________________________football_ultimate_assessments INSERTED
#   ______________________football_odds UPDATED
#   ______________________football_fixtures UPDATED
#   ________________________football_fixtures 981154 UPDATED Not Started Goto
#   ______________________
#   ______________________5/10
#   ______________________Sweden,  Ettan - Södra  #564 - 2023
#   ______________________2023-09-04 17:00:00+00:00 // UTC // 983246
#   ________________________aoN_football_statistics_check()
#   ____________________________Sweden,  Ettan - Södra - 2023 __ 983246 __ 2023-09-05 00:00:00 __ 8
#   ______________________________________Trollhättan vs ljungSKile SK
#   __________________________________Lebih 2023-09-05 00:00:00 >= 2023-09-04 08:25:26
#   __________________________fua_update_or_insert()
#   ____________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '564'  and season = '2023'  and fixtureapi_id = '983246'
#   ______________________________Total Row(s) : 1
#   ________________________________football_ultimate_assessments UPDATED
#   ________________________football_odds UPDATED
#   ________________________football_fixtures UPDATED
#   __________________________football_fixtures 983246 UPDATED Not Started Goto
#   ________________________
#   ________________________6/10
#   ________________________Chile,  Primera B  #266 - 2023
#   ________________________2023-09-04 22:30:00+00:00 // UTC // 987932
#   ______________________________aoN_football_odds_insert_rows()
#   ______________________________football_odds INSERTED
#   __________________________aoN_football_statistics_check()
#   ______________________________Chile,  Primera B - 2023 __ 987932 __ 2023-09-05 05:30:00 __ 11
#   ________________________________________Universidad de Concepcion vs San Marcos de Arica
#   ____________________________________Lebih 2023-09-05 05:30:00 >= 2023-09-04 08:25:26
#   ____________________________fua_update_or_insert()
#   ______________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '266'  and season = '2023'  and fixtureapi_id = '987932'
#   ________________________________Total Row(s) : 0
#   __________________________________football_ultimate_assessments INSERTED
#   __________________________football_odds UPDATED
#   __________________________football_fixtures UPDATED
#   ____________________________football_fixtures 987932 UPDATED Not Started Goto
#   __________________________
#   __________________________7/10
#   __________________________Colombia,  Primera A  #239 - 2023
#   __________________________2023-09-04 23:10:00+00:00 // UTC // 990389
#   ________________________________aoN_football_odds_insert_rows()
#   ________________________________football_odds INSERTED
#   ____________________________aoN_football_statistics_check()
#   ________________________________Colombia,  Primera A - 2023 __ 990389 __ 2023-09-05 06:10:00 __ 8
#   __________________________________________Union Magdalena vs La Equidad
#   ______________________________________Lebih 2023-09-05 06:10:00 >= 2023-09-04 08:25:26
#   ______________________________fua_update_or_insert()
#   ________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '239'  and season = '2023'  and fixtureapi_id = '990389'
#   __________________________________Total Row(s) : 0
#   ____________________________________football_ultimate_assessments INSERTED
#   ____________________________football_odds UPDATED
#   ____________________________football_fixtures UPDATED
#   ______________________________football_fixtures 990389 UPDATED Not Started Goto
#   ____________________________
#   ____________________________8/10
#   ____________________________Colombia,  Primera A  #239 - 2023
#   ____________________________2023-09-04 01:20:00+00:00 // UTC // 990396
#   __________________________________aoN_football_odds_insert_rows()
#   __________________________________football_odds INSERTED
#   ______________________________aoN_football_statistics_check()
#   __________________________________Colombia,  Primera A - 2023 __ 990396 __ 2023-09-04 08:20:00 __ 8
#   ____________________________________________Deportivo Cali vs Deportivo Pasto
#   ________________________________________Kurang 2023-09-04 08:20:00 < 2023-09-04 08:25:26
#   ______________________________PREP_check_date is not valid
#   ______________________________
#   ______________________________9/10
#   ______________________________USA,  NWSL Women  #254 - 2023
#   ______________________________2023-09-04 00:00:00+00:00 // UTC // 1004192
#   ____________________________________aoN_football_odds_insert_rows()
#   ____________________________________football_odds INSERTED
#   ________________________________aoN_football_statistics_check()
#   ____________________________________USA,  NWSL Women - 2023 __ 1004192 __ 2023-09-04 07:00:00 __ 11
#   ______________________________________________San Diego Wave W vs Houston Dash W
#   __________________________________________Kurang 2023-09-04 07:00:00 < 2023-09-04 08:25:26
#   ________________________________PREP_check_date is not valid
#   ________________________________
#   ________________________________10/10
#   ________________________________USA,  USL Championship  #255 - 2023
#   ________________________________2023-09-04 01:00:00+00:00 // UTC // 1008659
#   __________________________________aoN_football_statistics_check()
#   ______________________________________USA,  USL Championship - 2023 __ 1008659 __ 2023-09-04 08:00:00 __ 11
#   ________________________________________________FC Tulsa vs San Antonio
#   ____________________________________________Kurang 2023-09-04 08:00:00 < 2023-09-04 08:25:26
#   __________________________________PREP_check_date is not valid
#   __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API arya6792@gmail.com counter is 79
# __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date_0 : 2023-09-04
# __________page : 2
# __________counter_loop : 0
# __________date_diff : 0
# __________date_raw : 2023-09-04 08:25:26.146885
# __________max_page : 5
# ____________Total API Response(s) : 10
# ____________total_MAX_PAGE : 5
# ______________
# ______________1/10
# ______________USA,  MLS Next Pro  #909 - 2023
# ______________2023-09-04 01:30:00+00:00 // UTC // 1015547
# ____________________aoN_football_odds_insert_rows()
# ____________________football_odds INSERTED
# ________________aoN_football_statistics_check()
# ____________________USA,  MLS Next Pro - 2023 __ 1015547 __ 2023-09-04 08:30:00 __ 11
# ______________________________North Texas vs Colorado Rapids II
# __________________________Lebih 2023-09-04 08:30:00 >= 2023-09-04 08:25:26
# __________________fua_update_or_insert()
# ____________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '909'  and season = '2023'  and fixtureapi_id = '1015547'
# ______________________Total Row(s) : 0
# ________________________football_ultimate_assessments INSERTED
# ________________football_odds UPDATED
# ________________football_fixtures UPDATED
# __________________football_fixtures 1015547 UPDATED Not Started Goto
# ________________
# ________________2/10
# ________________USA,  MLS Next Pro  #909 - 2023
# ________________2023-09-04 02:00:00+00:00 // UTC // 1015548
# ______________________aoN_football_odds_insert_rows()
# ______________________football_odds INSERTED
# __________________aoN_football_statistics_check()
# ______________________USA,  MLS Next Pro - 2023 __ 1015548 __ 2023-09-04 09:00:00 __ 11
# ________________________________LA Galaxy II vs Swope Park Rangers
# ____________________________Lebih 2023-09-04 09:00:00 >= 2023-09-04 08:25:26
# ____________________fua_update_or_insert()
# ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '909'  and season = '2023'  and fixtureapi_id = '1015548'
# ________________________Total Row(s) : 0
# __________________________football_ultimate_assessments INSERTED
# __________________football_odds UPDATED
# __________________football_fixtures UPDATED
# ____________________football_fixtures 1015548 UPDATED Not Started Goto
# __________________
# __________________3/10
# __________________USA,  MLS Next Pro  #909 - 2023
# __________________2023-09-04 02:00:00+00:00 // UTC // 1015549
# ________________________aoN_football_odds_insert_rows()
# ________________________football_odds INSERTED
# ____________________aoN_football_statistics_check()
# ________________________USA,  MLS Next Pro - 2023 __ 1015549 __ 2023-09-04 09:00:00 __ 11
# __________________________________San Jose Earthquakes II vs Minnesota United II
# ______________________________Lebih 2023-09-04 09:00:00 >= 2023-09-04 08:25:26
# ______________________fua_update_or_insert()
# ________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '909'  and season = '2023'  and fixtureapi_id = '1015549'
# __________________________Total Row(s) : 0
# ____________________________football_ultimate_assessments INSERTED
# ____________________football_odds UPDATED
# ____________________football_fixtures UPDATED
# ______________________football_fixtures 1015549 UPDATED Not Started Goto
# ____________________
# ____________________4/10
# ____________________Argentina,  Primera Nacional  #129 - 2023
# ____________________2023-09-04 23:00:00+00:00 // UTC // 1027676
# __________________________aoN_football_odds_insert_rows()
# __________________________football_odds INSERTED
# ______________________aoN_football_statistics_check()
# __________________________Argentina,  Primera Nacional - 2023 __ 1027676 __ 2023-09-05 06:00:00 __ 8
# ____________________________________Ferro Carril Oeste vs Atletico Mitre
# ________________________________Lebih 2023-09-05 06:00:00 >= 2023-09-04 08:25:26
# ________________________fua_update_or_insert()
# __________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '129'  and season = '2023'  and fixtureapi_id = '1027676'
# ____________________________Total Row(s) : 0
# ______________________________football_ultimate_assessments INSERTED
# ______________________football_odds UPDATED
# ______________________football_fixtures UPDATED
# ________________________football_fixtures 1027676 UPDATED Not Started Goto
# ______________________
# ______________________5/10
# ______________________Colombia,  Primera B  #240 - 2023
# ______________________2023-09-04 21:00:00+00:00 // UTC // 1028064
# ____________________________aoN_football_odds_insert_rows()
# ____________________________football_odds INSERTED
# ________________________aoN_football_statistics_check()
# ____________________________Colombia,  Primera B - 2023 __ 1028064 __ 2023-09-05 04:00:00 __ 8
# ______________________________________Patriotas vs Barranquilla
# __________________________________Lebih 2023-09-05 04:00:00 >= 2023-09-04 08:25:26
# __________________________fua_update_or_insert()
# ____________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '240'  and season = '2023'  and fixtureapi_id = '1028064'
# ______________________________Total Row(s) : 0
# ________________________________football_ultimate_assessments INSERTED
# ________________________football_odds UPDATED
# ________________________football_fixtures UPDATED
# __________________________football_fixtures 1028064 UPDATED Not Started Goto
# ________________________
# ________________________6/10
# ________________________Argentina,  Primera C  #132 - 2023
# ________________________2023-09-04 18:30:00+00:00 // UTC // 1029704
# ______________________________aoN_football_odds_insert_rows()
# ______________________________football_odds INSERTED
# __________________________aoN_football_statistics_check()
# ______________________________Argentina,  Primera C - 2023 __ 1029704 __ 2023-09-05 01:30:00 __ 11
# ________________________________________Deportivo Español vs Berazategui
# ____________________________________Lebih 2023-09-05 01:30:00 >= 2023-09-04 08:25:26
# __________________________football_odds UPDATED
# __________________________football_fixtures UPDATED
# ____________________________football_fixtures 1029704 UPDATED Not Started Goto
# __________________________
# __________________________7/10
# __________________________Mexico,  Liga MX  #262 - 2023
# __________________________2023-09-04 02:00:00+00:00 // UTC // 1031327
# ____________________________aoN_football_statistics_check()
# ________________________________Mexico,  Liga MX - 2023 __ 1031327 __ 2023-09-04 09:00:00 __ 8
# __________________________________________Atletico San Luis vs Atlas
# ______________________________________Lebih 2023-09-04 09:00:00 >= 2023-09-04 08:25:26
# ______________________________fua_update_or_insert()
# ________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '262'  and season = '2023'  and fixtureapi_id = '1031327'
# __________________________________Total Row(s) : 1
# ____________________________________football_ultimate_assessments UPDATED
# ____________________________football_odds UPDATED
# ____________________________football_fixtures UPDATED
# ______________________________football_fixtures 1031327 UPDATED Not Started Goto
# ____________________________
# ____________________________8/10
# ____________________________Guatemala,  Liga Nacional  #339 - 2023
# ____________________________2023-09-04 02:00:00+00:00 // UTC // 1035228
# __________________________________aoN_football_odds_insert_rows()
# __________________________________football_odds INSERTED
# ______________________________aoN_football_statistics_check()
# __________________________________Guatemala,  Liga Nacional - 2023 __ 1035228 __ 2023-09-04 09:00:00 __ 0
# ____________________________________________Xelajú vs Malacateco
# ________________________________________Lebih 2023-09-04 09:00:00 >= 2023-09-04 08:25:26
# ________________________________fua_update_or_insert()
# __________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '339'  and season = '2023'  and fixtureapi_id = '1035228'
# ____________________________________Total Row(s) : 0
# ______________________________________football_ultimate_assessments INSERTED
# ______________________________football_odds UPDATED
# ______________________________football_fixtures UPDATED
# ________________________________football_fixtures 1035228 UPDATED Not Started Goto
# ______________________________
# ______________________________9/10
# ______________________________Israel,  Ligat Ha'al  #383 - 2023
# ______________________________2023-09-04 17:00:00+00:00 // UTC // 1037005
# ____________________________________aoN_football_odds_insert_rows()
# ____________________________________football_odds INSERTED
# ________________________________aoN_football_statistics_check()
# ____________________________________Israel,  Ligat ha'Al - 2023 __ 1037005 __ 2023-09-05 00:00:00 __ 8
# ______________________________________________Ashdod vs Beitar Jerusalem
# __________________________________________Lebih 2023-09-05 00:00:00 >= 2023-09-04 08:25:26
# __________________________________fua_update_or_insert()
# ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '383'  and season = '2023'  and fixtureapi_id = '1037005'
# ______________________________________Total Row(s) : 0
# ________________________________________football_ultimate_assessments INSERTED
# ________________________________football_odds UPDATED
# ________________________________football_fixtures UPDATED
# __________________________________football_fixtures 1037005 UPDATED Not Started Goto
# ________________________________
# ________________________________10/10
# ________________________________Denmark,  1. Division  #120 - 2023
# ________________________________2023-09-04 17:00:00+00:00 // UTC // 1037474
# ______________________________________aoN_football_odds_insert_rows()
# ______________________________________football_odds INSERTED
# __________________________________aoN_football_statistics_check()
# ______________________________________Denmark,  1. Division - 2023 __ 1037474 __ 2023-09-05 00:00:00 __ 8
# ________________________________________________Naestved vs HB Koge
# ____________________________________________Lebih 2023-09-05 00:00:00 >= 2023-09-04 08:25:26
# ____________________________________fua_update_or_insert()
# ______________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '120'  and season = '2023'  and fixtureapi_id = '1037474'
# ________________________________________Total Row(s) : 0
# __________________________________________football_ultimate_assessments INSERTED
# __________________________________football_odds UPDATED
# __________________________________football_fixtures UPDATED
# ____________________________________football_fixtures 1037474 UPDATED Not Started Goto
# __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API arya6792@gmail.com counter is 78
# __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date_0 : 2023-09-04
# __________page : 3
# __________counter_loop : 0
# __________date_diff : 0
# __________date_raw : 2023-09-04 08:25:26.146885
# __________max_page : 5
# ____________Total API Response(s) : 10
# ____________total_MAX_PAGE : 5
# ______________
# ______________1/10
# ______________Poland,  II Liga - East  #109 - 2023
# ______________2023-09-04 16:15:00+00:00 // UTC // 1038753
# ____________________aoN_football_odds_insert_rows()
# ____________________football_odds INSERTED
# ________________aoN_football_statistics_check()
# ____________________Poland,  II Liga - East - 2023 __ 1038753 __ 2023-09-04 23:15:00 __ 8
# ______________________________Kotwica Kołobrzeg vs Radunia Stężyca
# __________________________Lebih 2023-09-04 23:15:00 >= 2023-09-04 08:25:26
# __________________fua_update_or_insert()
# ____________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '109'  and season = '2023'  and fixtureapi_id = '1038753'
# ______________________Total Row(s) : 0
# ________________________football_ultimate_assessments INSERTED
# ________________football_odds UPDATED
# ________________football_fixtures UPDATED
# __________________football_fixtures 1038753 UPDATED Not Started Goto
# ________________
# ________________2/10
# ________________Bulgaria,  Second League  #173 - 2023
# ________________2023-09-04 14:00:00+00:00 // UTC // 1039176
# ______________________aoN_football_odds_insert_rows()
# ______________________football_odds INSERTED
# __________________aoN_football_statistics_check()
# ______________________Bulgaria,  Second League - 2023 __ 1039176 __ 2023-09-04 21:00:00 __ 11
# ________________________________Chernomorets 1919 Burgas vs Dobrudzha
# ____________________________Lebih 2023-09-04 21:00:00 >= 2023-09-04 08:25:26
# ____________________fua_update_or_insert()
# ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '173'  and season = '2023'  and fixtureapi_id = '1039176'
# ________________________Total Row(s) : 0
# __________________________football_ultimate_assessments INSERTED
# __________________football_odds UPDATED
# __________________football_fixtures UPDATED
# ____________________football_fixtures 1039176 UPDATED Not Started Goto
# __________________
# __________________3/10
# __________________England,  League One  #41 - 2023
# __________________2023-09-04 19:00:00+00:00 // UTC // 1039349
# ________________________aoN_football_odds_insert_rows()
# ________________________football_odds INSERTED
# ____________________aoN_football_statistics_check()
# ________________________England,  League One - 2023 __ 1039349 __ 2023-09-05 02:00:00 __ 8
# __________________________________Cambridge United vs Reading
# ______________________________Lebih 2023-09-05 02:00:00 >= 2023-09-04 08:25:26
# ______________________fua_update_or_insert()
# ________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '41'  and season = '2023'  and fixtureapi_id = '1039349'
# __________________________Total Row(s) : 0
# ____________________________football_ultimate_assessments INSERTED
# ____________________football_odds UPDATED
# ____________________football_fixtures UPDATED
# ______________________football_fixtures 1039349 UPDATED Not Started Goto
# ____________________
# ____________________4/10
# ____________________Mexico,  Liga MX Femenil  #673 - 2023
# ____________________2023-09-04 02:06:00+00:00 // UTC // 1041235
# __________________________aoN_football_odds_insert_rows()
# __________________________football_odds INSERTED
# ______________________aoN_football_statistics_check()
# __________________________Mexico,  Liga MX Femenil - 2023 __ 1041235 __ 2023-09-04 09:06:00 __ 8
# ____________________________________Tijuana W vs Monterrey W
# ________________________________Lebih 2023-09-04 09:06:00 >= 2023-09-04 08:25:26
# ________________________fua_update_or_insert()
# __________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '673'  and season = '2023'  and fixtureapi_id = '1041235'
# ____________________________Total Row(s) : 0
# ______________________________football_ultimate_assessments INSERTED
# ______________________football_odds UPDATED
# ______________________football_fixtures UPDATED
# ________________________football_fixtures 1041235 UPDATED Not Started Goto
# ______________________
# ______________________5/10
# ______________________Slovenia,  2. SNL  #374 - 2023
# ______________________2023-09-04 15:00:00+00:00 // UTC // 1041792
# ____________________________aoN_football_odds_insert_rows()
# ____________________________football_odds INSERTED
# ________________________aoN_football_statistics_check()
# ____________________________Slovenia,  2. SNL - 2023 __ 1041792 __ 2023-09-04 22:00:00 __ 11
# ______________________________________Tolmin vs Brinje-Grosuplje
# __________________________________Lebih 2023-09-04 22:00:00 >= 2023-09-04 08:25:26
# ________________________football_odds UPDATED
# ________________________football_fixtures UPDATED
# __________________________football_fixtures 1041792 UPDATED Not Started Goto
# ________________________
# ________________________6/10
# ________________________Paraguay,  Division Profesional - Clausura  #252 - 2023
# ________________________2023-09-04 23:00:00+00:00 // UTC // 1042766
# ______________________________aoN_football_odds_insert_rows()
# ______________________________football_odds INSERTED
# __________________________aoN_football_statistics_check()
# ______________________________Paraguay,  Division Profesional - Clausura - 2023 __ 1042766 __ 2023-09-05 06:00:00 __ 8
# ________________________________________Olimpia vs Sportivo Ameliano
# ____________________________________Lebih 2023-09-05 06:00:00 >= 2023-09-04 08:25:26
# ____________________________fua_update_or_insert()
# ______________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '252'  and season = '2023'  and fixtureapi_id = '1042766'
# ________________________________Total Row(s) : 0
# __________________________________football_ultimate_assessments INSERTED
# __________________________football_odds UPDATED
# __________________________football_fixtures UPDATED
# ____________________________football_fixtures 1042766 UPDATED Not Started Goto
# __________________________
# __________________________7/10
# __________________________Romania,  Liga I  #283 - 2023
# __________________________2023-09-04 15:30:00+00:00 // UTC // 1049821
# ________________________________aoN_football_odds_insert_rows()
# ________________________________football_odds INSERTED
# ____________________________aoN_football_statistics_check()
# ________________________________Romania,  Liga I - 2023 __ 1049821 __ 2023-09-04 22:30:00 __ 8
# __________________________________________FC Botosani vs AFC Hermannstadt
# ______________________________________Lebih 2023-09-04 22:30:00 >= 2023-09-04 08:25:26
# ______________________________fua_update_or_insert()
# ________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '283'  and season = '2023'  and fixtureapi_id = '1049821'
# __________________________________Total Row(s) : 0
# ____________________________________football_ultimate_assessments INSERTED
# ____________________________football_odds UPDATED
# ____________________________football_fixtures UPDATED
# ______________________________football_fixtures 1049821 UPDATED Not Started Goto
# ____________________________
# ____________________________8/10
# ____________________________Romania,  Liga I  #283 - 2023
# ____________________________2023-09-04 18:30:00+00:00 // UTC // 1049825
# __________________________________aoN_football_odds_insert_rows()
# __________________________________football_odds INSERTED
# ______________________________aoN_football_statistics_check()
# __________________________________Romania,  Liga I - 2023 __ 1049825 __ 2023-09-05 01:30:00 __ 8
# ____________________________________________Sepsi OSK Sfantu Gheorghe vs Uta Arad
# ________________________________________Lebih 2023-09-05 01:30:00 >= 2023-09-04 08:25:26
# ________________________________fua_update_or_insert()
# __________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '283'  and season = '2023'  and fixtureapi_id = '1049825'
# ____________________________________Total Row(s) : 0
# ______________________________________football_ultimate_assessments INSERTED
# ______________________________football_odds UPDATED
# ______________________________football_fixtures UPDATED
# ________________________________football_fixtures 1049825 UPDATED Not Started Goto
# ______________________________
# ______________________________9/10
# ______________________________Bosnia,  Premijer Liga  #315 - 2023
# ______________________________2023-09-04 18:00:00+00:00 // UTC // 1050795
# ____________________________________aoN_football_odds_insert_rows()
# ____________________________________football_odds INSERTED
# ________________________________aoN_football_statistics_check()
# ____________________________________Bosnia,  Premijer Liga - 2023 __ 1050795 __ 2023-09-05 01:00:00 __ 8
# ______________________________________________Zrinjski vs Siroki Brijeg
# __________________________________________Lebih 2023-09-05 01:00:00 >= 2023-09-04 08:25:26
# __________________________________fua_update_or_insert()
# ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '315'  and season = '2023'  and fixtureapi_id = '1050795'
# ______________________________________Total Row(s) : 0
# ________________________________________football_ultimate_assessments INSERTED
# ________________________________football_odds UPDATED
# ________________________________football_fixtures UPDATED
# __________________________________football_fixtures 1050795 UPDATED Not Started Goto
# ________________________________
# ________________________________10/10
# ________________________________France,  National 1  #63 - 2023
# ________________________________2023-09-04 19:00:00+00:00 // UTC // 1071967
# __________________________________aoN_football_statistics_check()
# ______________________________________France,  National 1 - 2023 __ 1071967 __ 2023-09-05 02:00:00 __ 11
# ________________________________________________Martigues vs RED Star FC 93
# ____________________________________________Lebih 2023-09-05 02:00:00 >= 2023-09-04 08:25:26
# ____________________________________fua_update_or_insert()
# ______________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '63'  and season = '2023'  and fixtureapi_id = '1071967'
# ________________________________________Total Row(s) : 1
# __________________________________________football_ultimate_assessments UPDATED
# __________________________________football_odds UPDATED
# __________________________________football_fixtures UPDATED
# ____________________________________football_fixtures 1071967 UPDATED Not Started Goto
# __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API arya6792@gmail.com counter is 77
# __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date_0 : 2023-09-04
# __________page : 4
# __________counter_loop : 0
# __________date_diff : 0
# __________date_raw : 2023-09-04 08:25:26.146885
# __________max_page : 5
# ____________Total API Response(s) : 10
# ____________total_MAX_PAGE : 5
# ______________
# ______________1/10
# ______________Honduras,  Liga Nacional  #234 - 2023
# ______________2023-09-04 01:00:00+00:00 // UTC // 1073859
# ____________________aoN_football_odds_insert_rows()
# ____________________football_odds INSERTED
# ________________aoN_football_statistics_check()
# ____________________Honduras,  Liga Nacional - 2023 __ 1073859 __ 2023-09-04 08:00:00 __ 11
# ______________________________Olancho vs Génesis
# __________________________Kurang 2023-09-04 08:00:00 < 2023-09-04 08:25:26
# ________________PREP_check_date is not valid
# ________________
# ________________2/10
# ________________Russia,  First League  #236 - 2023
# ________________2023-09-04 16:30:00+00:00 // UTC // 1092787
# ______________________aoN_football_odds_insert_rows()
# ______________________football_odds INSERTED
# __________________aoN_football_statistics_check()
# ______________________Russia,  First League - 2023 __ 1092787 __ 2023-09-04 23:30:00 __ 11
# ________________________________Rodina Moskva vs Torpedo Moskva
# ____________________________Lebih 2023-09-04 23:30:00 >= 2023-09-04 08:25:26
# ____________________fua_update_or_insert()
# ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '236'  and season = '2023'  and fixtureapi_id = '1092787'
# ________________________Total Row(s) : 0
# __________________________football_ultimate_assessments INSERTED
# __________________football_odds UPDATED
# __________________football_fixtures UPDATED
# ____________________football_fixtures 1092787 UPDATED Not Started Goto
# __________________
# __________________3/10
# __________________Russia,  First League  #236 - 2023
# __________________2023-09-04 14:00:00+00:00 // UTC // 1092793
# ________________________aoN_football_odds_insert_rows()
# ________________________football_odds INSERTED
# ____________________aoN_football_statistics_check()
# ________________________Russia,  First League - 2023 __ 1092793 __ 2023-09-04 21:00:00 __ 11
# __________________________________Tyumen vs Arsenal Tula
# ______________________________Lebih 2023-09-04 21:00:00 >= 2023-09-04 08:25:26
# ______________________fua_update_or_insert()
# ________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '236'  and season = '2023'  and fixtureapi_id = '1092793'
# __________________________Total Row(s) : 0
# ____________________________football_ultimate_assessments INSERTED
# ____________________football_odds UPDATED
# ____________________football_fixtures UPDATED
# ______________________football_fixtures 1092793 UPDATED Not Started Goto
# ____________________
# ____________________4/10
# ____________________Serbia,  Super Liga  #286 - 2023
# ____________________2023-09-04 17:00:00+00:00 // UTC // 1099865
# __________________________aoN_football_odds_insert_rows()
# __________________________football_odds INSERTED
# ______________________aoN_football_statistics_check()
# __________________________Serbia,  Super Liga - 2023 __ 1099865 __ 2023-09-05 00:00:00 __ 11
# ____________________________________Železničar Pančevo vs Cukaricki
# ________________________________Lebih 2023-09-05 00:00:00 >= 2023-09-04 08:25:26
# ________________________fua_update_or_insert()
# __________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '286'  and season = '2023'  and fixtureapi_id = '1099865'
# ____________________________Total Row(s) : 0
# ______________________________football_ultimate_assessments INSERTED
# ______________________football_odds UPDATED
# ______________________football_fixtures UPDATED
# ________________________football_fixtures 1099865 UPDATED Not Started Goto
# ______________________
# ______________________5/10
# ______________________Italy,  Serie C - Girone A  #138 - 2023
# ______________________2023-09-04 18:45:00+00:00 // UTC // 1114160
# ____________________________aoN_football_odds_insert_rows()
# ____________________________football_odds INSERTED
# ________________________aoN_football_statistics_check()
# ______________________________aoN_football_leagues_check()
# ______________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '138'
# ________________________________Total Row(s) : 1
# ______________________________get_today_adds()
# ________________________________adds date_diff : 0
# ________________________________today_raw : 2023-09-03 08:27:49.496975
# ______________________________afN_controll_match_update()
# ________________________________aa_check_acccount()
# __________________________________API arya6792@gmail.com counter is 76
# __________________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________________________________aa_check_acccount()
# ________________________________aa_update_counter()
# ________________________________afN_response_fixtures()
# __________________________________fixtureapi_id : 1114160
# __________________________________fixture_updated_at : 2023-09-03 08:27:49.496975
# __________________________________ROUTES : fixtureapi_id_INSERT
# ____________________________________Total API Response(s) : 1
# ______________________________________
# ______________________________________ [1/1] fixture_status: Not Started __ 138 __ 2023-09-04 18:45:00+00:00
# __________________________________________football_teams UPDATED
# __________________________________________football_teams UPDATED
# ______________________________________football_fixtures INSERTED
# __________________________________Lebih 2023-09-05 01:45:00 >= 2023-09-04 08:25:26
# __________________________fua_update_or_insert()
# ____________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '138'  and season = '2023'  and fixtureapi_id = '1114160'
# ______________________________Total Row(s) : 0
# ________________________________football_ultimate_assessments INSERTED
# ________________________football_odds UPDATED
# ________________________football_fixtures UPDATED
# __________________________football_fixtures 1114160 UPDATED Not Started Goto
# ________________________
# ________________________6/10
# ________________________Italy,  Serie C - Girone A  #138 - 2023
# ________________________2023-09-04 18:45:00+00:00 // UTC // 1114162
# ______________________________aoN_football_odds_insert_rows()
# ______________________________football_odds INSERTED
# __________________________aoN_football_statistics_check()
# ________________________________aoN_football_leagues_check()
# ________________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '138'
# __________________________________Total Row(s) : 1
# ________________________________get_today_adds()
# __________________________________adds date_diff : 0
# __________________________________today_raw : 2023-09-03 08:27:55.285497
# ________________________________afN_controll_match_update()
# __________________________________aa_check_acccount()
# ____________________________________API arya6792@gmail.com counter is 75
# ____________________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# __________________________________aa_check_acccount()
# __________________________________aa_update_counter()
# __________________________________afN_response_fixtures()
# ____________________________________fixtureapi_id : 1114162
# ____________________________________fixture_updated_at : 2023-09-03 08:27:55.285497
# ____________________________________ROUTES : fixtureapi_id_INSERT
# ______________________________________Total API Response(s) : 1
# ________________________________________
# ________________________________________ [1/1] fixture_status: Not Started __ 138 __ 2023-09-04 18:45:00+00:00
# ____________________________________________football_teams UPDATED
# ____________________________________________football_teams UPDATED
# ________________________________________football_fixtures INSERTED
# ____________________________________Lebih 2023-09-05 01:45:00 >= 2023-09-04 08:25:26
# ____________________________fua_update_or_insert()
# ______________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '138'  and season = '2023'  and fixtureapi_id = '1114162'
# ________________________________Total Row(s) : 0
# __________________________________football_ultimate_assessments INSERTED
# __________________________football_odds UPDATED
# __________________________football_fixtures UPDATED
# ____________________________football_fixtures 1114162 UPDATED Not Started Goto
# __________________________
# __________________________7/10
# __________________________Italy,  Serie C - Girone A  #138 - 2023
# __________________________2023-09-04 18:45:00+00:00 // UTC // 1114163
# ________________________________aoN_football_odds_insert_rows()
# ________________________________football_odds INSERTED
# ____________________________aoN_football_statistics_check()
# __________________________________aoN_football_leagues_check()
# __________________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '138'
# ____________________________________Total Row(s) : 1
# __________________________________get_today_adds()
# ____________________________________adds date_diff : 0
# ____________________________________today_raw : 2023-09-03 08:28:00.968875
# __________________________________afN_controll_match_update()
# ____________________________________aa_check_acccount()
# ______________________________________API arya6792@gmail.com counter is 74
# ______________________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ____________________________________aa_check_acccount()
# ____________________________________aa_update_counter()
# ____________________________________afN_response_fixtures()
# ______________________________________fixtureapi_id : 1114163
# ______________________________________fixture_updated_at : 2023-09-03 08:28:00.968875
# ______________________________________ROUTES : fixtureapi_id_INSERT
# ________________________________________Total API Response(s) : 1
# __________________________________________
# __________________________________________ [1/1] fixture_status: Not Started __ 138 __ 2023-09-04 18:45:00+00:00
# ______________________________________________football_teams UPDATED
# ______________________________________________football_teams UPDATED
# __________________________________________football_fixtures INSERTED
# ______________________________________Lebih 2023-09-05 01:45:00 >= 2023-09-04 08:25:26
# ______________________________fua_update_or_insert()
# ________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '138'  and season = '2023'  and fixtureapi_id = '1114163'
# __________________________________Total Row(s) : 0
# ____________________________________football_ultimate_assessments INSERTED
# ____________________________football_odds UPDATED
# ____________________________football_fixtures UPDATED
# ______________________________football_fixtures 1114163 UPDATED Not Started Goto
# ____________________________
# ____________________________8/10
# ____________________________Italy,  Serie C - Girone A  #138 - 2023
# ____________________________2023-09-04 18:45:00+00:00 // UTC // 1114165
# __________________________________aoN_football_odds_insert_rows()
# __________________________________football_odds INSERTED
# ______________________________aoN_football_statistics_check()
# ____________________________________aoN_football_leagues_check()
# ____________________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '138'
# ______________________________________Total Row(s) : 1
# ____________________________________get_today_adds()
# ______________________________________adds date_diff : 0
# ______________________________________today_raw : 2023-09-03 08:28:07.034031
# ____________________________________afN_controll_match_update()
# ______________________________________aa_check_acccount()
# ________________________________________API arya6792@gmail.com counter is 73
# ________________________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ______________________________________aa_check_acccount()
# ______________________________________aa_update_counter()
# ______________________________________afN_response_fixtures()
# ________________________________________fixtureapi_id : 1114165
# ________________________________________fixture_updated_at : 2023-09-03 08:28:07.034031
# ________________________________________ROUTES : fixtureapi_id_INSERT
# __________________________________________Total API Response(s) : 1
# ____________________________________________
# ____________________________________________ [1/1] fixture_status: Not Started __ 138 __ 2023-09-04 18:45:00+00:00
# ________________________________________________football_teams UPDATED
# ________________________________________________football_teams UPDATED
# ____________________________________________football_fixtures INSERTED
# ________________________________________Lebih 2023-09-05 01:45:00 >= 2023-09-04 08:25:26
# ________________________________fua_update_or_insert()
# __________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '138'  and season = '2023'  and fixtureapi_id = '1114165'
# ____________________________________Total Row(s) : 0
# ______________________________________football_ultimate_assessments INSERTED
# ______________________________football_odds UPDATED
# ______________________________football_fixtures UPDATED
# ________________________________football_fixtures 1114165 UPDATED Not Started Goto
# ______________________________
# ______________________________9/10
# ______________________________Italy,  Serie C - Girone A  #138 - 2023
# ______________________________2023-09-04 18:45:00+00:00 // UTC // 1114166
# ____________________________________aoN_football_odds_insert_rows()
# ____________________________________football_odds INSERTED
# ________________________________aoN_football_statistics_check()
# ______________________________________aoN_football_leagues_check()
# ______________________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '138'
# ________________________________________Total Row(s) : 1
# ______________________________________get_today_adds()
# ________________________________________adds date_diff : 0
# ________________________________________today_raw : 2023-09-03 08:28:13.100278
# ______________________________________afN_controll_match_update()
# ________________________________________aa_check_acccount()
# __________________________________________API arya6792@gmail.com counter is 72
# __________________________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________________________________________aa_check_acccount()
# ________________________________________aa_update_counter()
# ________________________________________afN_response_fixtures()
# __________________________________________fixtureapi_id : 1114166
# __________________________________________fixture_updated_at : 2023-09-03 08:28:13.100278
# __________________________________________ROUTES : fixtureapi_id_INSERT
# ____________________________________________Total API Response(s) : 1
# ______________________________________________
# ______________________________________________ [1/1] fixture_status: Not Started __ 138 __ 2023-09-04 18:45:00+00:00
# __________________________________________________football_teams UPDATED
# __________________________________________________football_teams UPDATED
# ______________________________________________football_fixtures INSERTED
# __________________________________________Lebih 2023-09-05 01:45:00 >= 2023-09-04 08:25:26
# __________________________________fua_update_or_insert()
# ____________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '138'  and season = '2023'  and fixtureapi_id = '1114166'
# ______________________________________Total Row(s) : 0
# ________________________________________football_ultimate_assessments INSERTED
# ________________________________football_odds UPDATED
# ________________________________football_fixtures UPDATED
# __________________________________football_fixtures 1114166 UPDATED Not Started Goto
# ________________________________
# ________________________________10/10
# ________________________________Italy,  Serie C - Girone A  #138 - 2023
# ________________________________2023-09-04 18:45:00+00:00 // UTC // 1114168
# ______________________________________aoN_football_odds_insert_rows()
# ______________________________________football_odds INSERTED
# __________________________________aoN_football_statistics_check()
# ________________________________________aoN_football_leagues_check()
# ________________________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '138'
# __________________________________________Total Row(s) : 1
# ________________________________________get_today_adds()
# __________________________________________adds date_diff : 0
# __________________________________________today_raw : 2023-09-03 08:28:19.532632
# ________________________________________afN_controll_match_update()
# __________________________________________aa_check_acccount()
# ____________________________________________API arya6792@gmail.com counter is 71
# ____________________________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# __________________________________________aa_check_acccount()
# __________________________________________aa_update_counter()
# __________________________________________afN_response_fixtures()
# ____________________________________________fixtureapi_id : 1114168
# ____________________________________________fixture_updated_at : 2023-09-03 08:28:19.532632
# ____________________________________________ROUTES : fixtureapi_id_INSERT
# ______________________________________________Total API Response(s) : 1
# ________________________________________________
# ________________________________________________ [1/1] fixture_status: Not Started __ 138 __ 2023-09-04 18:45:00+00:00
# ____________________________________________________football_teams UPDATED
# ____________________________________________________football_teams UPDATED
# ________________________________________________football_fixtures INSERTED
# ____________________________________________Lebih 2023-09-05 01:45:00 >= 2023-09-04 08:25:26
# ____________________________________fua_update_or_insert()
# ______________________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '138'  and season = '2023'  and fixtureapi_id = '1114168'
# ________________________________________Total Row(s) : 0
# __________________________________________football_ultimate_assessments INSERTED
# __________________________________football_odds UPDATED
# __________________________________football_fixtures UPDATED
# ____________________________________football_fixtures 1114168 UPDATED Not Started Goto
# __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API arya6792@gmail.com counter is 70
# __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date_0 : 2023-09-04
# __________page : 5
# __________counter_loop : 0
# __________date_diff : 0
# __________date_raw : 2023-09-04 08:25:26.146885
# __________max_page : 5
# ____________Total API Response(s) : 4
# ____________total_MAX_PAGE : 5
# ______________
# ______________1/4
# ______________Italy,  Serie C - Girone A  #138 - 2023
# ______________2023-09-04 18:45:00+00:00 // UTC // 1114169
# ____________________aoN_football_odds_insert_rows()
# ____________________football_odds INSERTED
# ________________aoN_football_statistics_check()
# ______________________aoN_football_leagues_check()
# ______________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '138'
# ________________________Total Row(s) : 1
# ______________________get_today_adds()
# ________________________adds date_diff : 0
# ________________________today_raw : 2023-09-03 08:28:26.589236
# ______________________afN_controll_match_update()
# ________________________aa_check_acccount()
# __________________________API arya6792@gmail.com counter is 69
# __________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________________________aa_check_acccount()
# ________________________aa_update_counter()
# ________________________afN_response_fixtures()
# __________________________fixtureapi_id : 1114169
# __________________________fixture_updated_at : 2023-09-03 08:28:26.589236
# __________________________ROUTES : fixtureapi_id_INSERT
# ____________________________Total API Response(s) : 1
# ______________________________
# ______________________________ [1/1] fixture_status: Not Started __ 138 __ 2023-09-04 18:45:00+00:00
# __________________________________football_teams UPDATED
# __________________________________football_teams UPDATED
# ______________________________football_fixtures INSERTED
# __________________________Lebih 2023-09-05 01:45:00 >= 2023-09-04 08:25:26
# __________________fua_update_or_insert()
# ____________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '138'  and season = '2023'  and fixtureapi_id = '1114169'
# ______________________Total Row(s) : 0
# ________________________football_ultimate_assessments INSERTED
# ________________football_odds UPDATED
# ________________football_fixtures UPDATED
# __________________football_fixtures 1114169 UPDATED Not Started Goto
# ________________
# ________________2/4
# ________________Nicaragua,  Primera Division  #396 - 2023
# ________________2023-09-04 00:00:00+00:00 // UTC // 1119545
# ______________________aoN_football_odds_insert_rows()
# ______________________football_odds INSERTED
# __________________aoN_football_statistics_check()
# ________________________aoN_football_leagues_check()
# ________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '396'
# __________________________Total Row(s) : 1
# ________________________get_today_adds()
# __________________________adds date_diff : 0
# __________________________today_raw : 2023-09-03 08:28:32.576698
# ________________________afN_controll_match_update()
# __________________________aa_check_acccount()
# ____________________________API arya6792@gmail.com counter is 68
# ____________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# __________________________aa_check_acccount()
# __________________________aa_update_counter()
# __________________________afN_response_fixtures()
# ____________________________fixtureapi_id : 1119545
# ____________________________fixture_updated_at : 2023-09-03 08:28:32.576698
# ____________________________ROUTES : fixtureapi_id_INSERT
# ______________________________Total API Response(s) : 1
# ________________________________
# ________________________________ [1/1] fixture_status: Not Started __ 396 __ 2023-09-04 00:00:00+00:00
# ____________________________________football_venues INSERTED
# ____________________________________football_teams UPDATED
# ____________________________________football_teams UPDATED
# ________________________________football_fixtures INSERTED
# ____________________________Kurang 2023-09-04 07:00:00 < 2023-09-04 08:25:26
# __________________PREP_check_date is not valid
# __________________
# __________________3/4
# __________________Brazil,  Copa do Brasil U20  #617 - 2023
# __________________2023-09-04 23:00:00+00:00 // UTC // 1119669
# ________________________aoN_football_odds_insert_rows()
# ________________________football_odds INSERTED
# ____________________aoN_football_statistics_check()
# __________________________aoN_football_leagues_check()
# __________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '617'
# ____________________________Total Row(s) : 1
# __________________________get_today_adds()
# ____________________________adds date_diff : 0
# ____________________________today_raw : 2023-09-03 08:28:35.429985
# __________________________afN_controll_match_update()
# ____________________________aa_check_acccount()
# ______________________________API arya6792@gmail.com counter is 67
# ______________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ____________________________aa_check_acccount()
# ____________________________aa_update_counter()
# ____________________________afN_response_fixtures()
# ______________________________fixtureapi_id : 1119669
# ______________________________fixture_updated_at : 2023-09-03 08:28:35.429985
# ______________________________ROUTES : fixtureapi_id_INSERT
# ________________________________Total API Response(s) : 1
# __________________________________
# __________________________________ [1/1] fixture_status: Not Started __ 617 __ 2023-09-04 23:00:00+00:00
# ______________________________________football_teams UPDATED
# ______________________________________football_teams UPDATED
# __________________________________football_fixtures INSERTED
# ______________________________Lebih 2023-09-05 06:00:00 >= 2023-09-04 08:25:26
# ______________________fua_update_or_insert()
# ________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '617'  and season = '2023'  and fixtureapi_id = '1119669'
# __________________________Total Row(s) : 0
# ____________________________football_ultimate_assessments INSERTED
# ____________________football_odds UPDATED
# ____________________football_fixtures UPDATED
# ______________________football_fixtures 1119669 UPDATED Not Started Goto
# ____________________
# ____________________4/4
# ____________________Peru,  Primera División  #281 - 2023
# ____________________2023-09-04 20:15:00+00:00 // UTC // 1121893
# __________________________aoN_football_odds_insert_rows()
# __________________________football_odds INSERTED
# ______________________aoN_football_statistics_check()
# ____________________________aoN_football_leagues_check()
# ____________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '281'
# ______________________________Total Row(s) : 1
# ____________________________get_today_adds()
# ______________________________adds date_diff : 0
# ______________________________today_raw : 2023-09-03 08:28:41.015752
# ____________________________afN_controll_match_update()
# ______________________________aa_check_acccount()
# ________________________________API arya6792@gmail.com counter is 66
# ________________________________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ______________________________aa_check_acccount()
# ______________________________aa_update_counter()
# ______________________________afN_response_fixtures()
# ________________________________fixtureapi_id : 1121893
# ________________________________fixture_updated_at : 2023-09-03 08:28:41.015752
# ________________________________ROUTES : fixtureapi_id_INSERT
# __________________________________Total API Response(s) : 1
# ____________________________________
# ____________________________________ [1/1] fixture_status: Not Started __ 281 __ 2023-09-04 20:15:00+00:00
# ________________________________________football_teams UPDATED
# ________________________________________football_teams UPDATED
# ____________________________________football_fixtures INSERTED
# ________________________________Lebih 2023-09-05 03:15:00 >= 2023-09-04 08:25:26
# ________________________fua_update_or_insert()
# __________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '281'  and season = '2023'  and fixtureapi_id = '1121893'
# ____________________________Total Row(s) : 0
# ______________________________football_ultimate_assessments INSERTED
# ______________________football_odds UPDATED
# ______________________football_fixtures UPDATED
# ________________________football_fixtures 1121893 UPDATED Not Started Goto
# ______________________STOP RESPONSE
# # -------------------------------------------------- End at 2023-09-03 08:28:45

# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.xpattern_new_auto import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------      
    xpNa_set_pattern('pre_', 4, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:28:45
#   __main()
#   ____xpNa_set_pattern()
#   ____Total Row(s) : 201
#   ____
#   ____ [1/201]
#   ____  > fixtureapi_id = 1008654
#   ____  __> pre_ah_pattern = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [2/201]
#   ____  > fixtureapi_id = 1008655
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [3/201]
#   ____  > fixtureapi_id = 1008656
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [4/201]
#   ____  > fixtureapi_id = 1008657
#   ____  __> pre_ah_pattern = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [5/201]
#   ____  > fixtureapi_id = 1008658
#   ____  __> pre_ah_pattern = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [6/201]
#   ____  > fixtureapi_id = 971208
#   ____  __> pre_ah_pattern = -075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075H
#   ____  __> pre_gou_pattern = 175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [7/201]
#   ____  > fixtureapi_id = 971207
#   ____  __> pre_ah_pattern = -075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075H
#   ____  __> pre_gou_pattern = 175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [8/201]
#   ____  > fixtureapi_id = 1071967
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [9/201]
#   ____  > fixtureapi_id = 971209
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [10/201]
#   ____  > fixtureapi_id = 1027512
#   ____  __> pre_ah_pattern = -25-225-2-175-15H
#   ____  __> pre_ah_pattern_mirror = +15+175+2+225+25H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -25-225-2-175-15H
#   ____  __> pre_ah_pattern_mirror_4 = +15+175+2+225+25H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [11/201]
#   ____  > fixtureapi_id = 1027513
#   ____  __> pre_ah_pattern = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [12/201]
#   ____  > fixtureapi_id = 971216
#   ____  __> pre_ah_pattern = -025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025H
#   ____  __> pre_gou_pattern = 15g175g20gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025H
#   ____  __> pre_gou_pattern_4 = 15g175g20gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [13/201]
#   ____  > fixtureapi_id = 971210
#   ____  __> pre_ah_pattern = -05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05H
#   ____  __> pre_gou_pattern = 175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05H
#   ____  __> pre_gou_pattern_4 = 175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [14/201]
#   ____  > fixtureapi_id = 971211
#   ____  __> pre_ah_pattern = -025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025H
#   ____  __> pre_gou_pattern = 175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025H
#   ____  __> pre_gou_pattern_4 = 175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [15/201]
#   ____  > fixtureapi_id = 971214
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [16/201]
#   ____  > fixtureapi_id = 1006700
#   ____  __> pre_ah_pattern = +0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0H
#   ____  __> pre_gou_pattern = 15g175g20gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0H
#   ____  __> pre_gou_pattern_4 = 15g175g20gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [17/201]
#   ____  > fixtureapi_id = 988674
#   ____  __> pre_ah_pattern = -075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [18/201]
#   ____  > fixtureapi_id = 971212
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [19/201]
#   ____  > fixtureapi_id = 988673
#   ____  __> pre_ah_pattern = -025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025H
#   ____  __> pre_gou_pattern = 15g175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [20/201]
#   ____  > fixtureapi_id = 971217
#   ____  __> pre_ah_pattern = -025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [21/201]
#   ____  > fixtureapi_id = 983841
#   ____  __> pre_ah_pattern = +0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [22/201]
#   ____  > fixtureapi_id = 983843
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [23/201]
#   ____  > fixtureapi_id = 1006698
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 15g175g20gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [24/201]
#   ____  > fixtureapi_id = 983838
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [25/201]
#   ____  > fixtureapi_id = 983842
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [26/201]
#   ____  > fixtureapi_id = 983246
#   ____  __> pre_ah_pattern = -175-15-125-1H
#   ____  __> pre_ah_pattern_mirror = +1+125+15+175H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1H
#   ____  __> pre_ah_pattern_mirror_4 = +1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [27/201]
#   ____  > fixtureapi_id = 1031327
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [28/201]
#   ____  > fixtureapi_id = 979306
#   ____  __> pre_ah_pattern = -15-125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1+125+15H
#   ____  __> pre_gou_pattern = 30g325g35g375g40g425gG
#   ____
#   ____  __> pre_ah_pattern_4 = -15-125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1+125+15H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [29/201]
#   ____  > fixtureapi_id = 980031
#   ____  __> pre_ah_pattern = -125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1+125H
#   ____  __> pre_gou_pattern = 325g35g375g40g425gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1+125H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [30/201]
#   ____  > fixtureapi_id = 980032
#   ____  __> pre_ah_pattern = -25-225-2-175-15H
#   ____  __> pre_ah_pattern_mirror = +15+175+2+225+25H
#   ____  __> pre_gou_pattern = 325g35g375g40g425gG
#   ____
#   ____  __> pre_ah_pattern_4 = -25-225-2-175-15H
#   ____  __> pre_ah_pattern_mirror_4 = +15+175+2+225+25H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [31/201]
#   ____  > fixtureapi_id = 980035
#   ____  __> pre_ah_pattern = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05+075H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [32/201]
#   ____  > fixtureapi_id = 980213
#   ____  __> pre_ah_pattern = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [33/201]
#   ____  > fixtureapi_id = 981152
#   ____  __> pre_ah_pattern = -125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [34/201]
#   ____  > fixtureapi_id = 981153
#   ____  __> pre_ah_pattern = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05+075H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [35/201]
#   ____  > fixtureapi_id = 981155
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [36/201]
#   ____  > fixtureapi_id = 981156
#   ____  __> pre_ah_pattern = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [37/201]
#   ____  > fixtureapi_id = 981157
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [38/201]
#   ____  > fixtureapi_id = 981584
#   ____  __> pre_ah_pattern = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025+0H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025+0H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [39/201]
#   ____  > fixtureapi_id = 981585
#   ____  __> pre_ah_pattern = -2-175-15-125H
#   ____  __> pre_ah_pattern_mirror = +125+15+175+2H
#   ____  __> pre_gou_pattern = 30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -2-175-15-125H
#   ____  __> pre_ah_pattern_mirror_4 = +125+15+175+2H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [40/201]
#   ____  > fixtureapi_id = 981586
#   ____  __> pre_ah_pattern = +125+15+175+2H
#   ____  __> pre_ah_pattern_mirror = -2-175-15-125H
#   ____  __> pre_gou_pattern = 325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = +125+15+175+2H
#   ____  __> pre_ah_pattern_mirror_4 = -2-175-15-125H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [41/201]
#   ____  > fixtureapi_id = 981587
#   ____  __> pre_ah_pattern = -125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1+125H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1+125H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [42/201]
#   ____  > fixtureapi_id = 981588
#   ____  __> pre_ah_pattern = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [43/201]
#   ____  > fixtureapi_id = 981589
#   ____  __> pre_ah_pattern = -2-175-15-125H
#   ____  __> pre_ah_pattern_mirror = +125+15+175+2H
#   ____  __> pre_gou_pattern = 325g35g375g40g425gG
#   ____
#   ____  __> pre_ah_pattern_4 = -2-175-15-125-1H
#   ____  __> pre_ah_pattern_mirror_4 = +1+125+15+175+2H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [44/201]
#   ____  > fixtureapi_id = 983004
#   ____  __> pre_ah_pattern = +025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [45/201]
#   ____  > fixtureapi_id = 983009
#   ____  __> pre_ah_pattern = -125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1+125H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1+125H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [46/201]
#   ____  > fixtureapi_id = 983010
#   ____  __> pre_ah_pattern = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [47/201]
#   ____  > fixtureapi_id = 987933
#   ____  __> pre_ah_pattern = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [48/201]
#   ____  > fixtureapi_id = 987934
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [49/201]
#   ____  > fixtureapi_id = 990391
#   ____  __> pre_ah_pattern = -075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [50/201]
#   ____  > fixtureapi_id = 990393
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [51/201]
#   ____  > fixtureapi_id = 990394
#   ____  __> pre_ah_pattern = -025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025H
#   ____  __> pre_gou_pattern = 175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025H
#   ____  __> pre_gou_pattern_4 = 175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [52/201]
#   ____  > fixtureapi_id = 993095
#   ____  __> pre_ah_pattern = +0+025+05+075+1H
#   ____  __> pre_ah_pattern_mirror = -1-075-05-025+0H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05+075+1H
#   ____  __> pre_ah_pattern_mirror_4 = -1-075-05-025+0H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [53/201]
#   ____  > fixtureapi_id = 993096
#   ____  __> pre_ah_pattern = -025+0+025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025+0+025H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [54/201]
#   ____  > fixtureapi_id = 993276
#   ____  __> pre_ah_pattern = +175+2+225+25+275H
#   ____  __> pre_ah_pattern_mirror = -275-25-225-2-175H
#   ____  __> pre_gou_pattern = 30g325g35g375g40g425gG
#   ____
#   ____  __> pre_ah_pattern_4 = +175+2+225+25+275+3H
#   ____  __> pre_ah_pattern_mirror_4 = -3-275-25-225-2-175H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [55/201]
#   ____  > fixtureapi_id = 993278
#   ____  __> pre_ah_pattern = -05-025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025+05H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [56/201]
#   ____  > fixtureapi_id = 993458
#   ____  __> pre_ah_pattern = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [57/201]
#   ____  > fixtureapi_id = 993459
#   ____  __> pre_ah_pattern = -125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1+125H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1+125H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [58/201]
#   ____  > fixtureapi_id = 993460
#   ____  __> pre_ah_pattern = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05+075H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [59/201]
#   ____  > fixtureapi_id = 993822
#   ____  __> pre_ah_pattern = -175-15-125-1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1+125+15+175H
#   ____  __> pre_gou_pattern = 25g30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 25g30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [60/201]
#   ____  > fixtureapi_id = 994838
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [61/201]
#   ____  > fixtureapi_id = 994843
#   ____  __> pre_ah_pattern = -125-1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1+125H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1+125H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [62/201]
#   ____  > fixtureapi_id = 995260
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [63/201]
#   ____  > fixtureapi_id = 995261
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [64/201]
#   ____  > fixtureapi_id = 995262
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [65/201]
#   ____  > fixtureapi_id = 995263
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [66/201]
#   ____  > fixtureapi_id = 995264
#   ____  __> pre_ah_pattern = +05+075+1H
#   ____  __> pre_ah_pattern_mirror = -1-075-05H
#   ____  __> pre_gou_pattern = 225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = +05+075+1H
#   ____  __> pre_ah_pattern_mirror_4 = -1-075-05H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [67/201]
#   ____  > fixtureapi_id = 995265
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [68/201]
#   ____  > fixtureapi_id = 995266
#   ____  __> pre_ah_pattern = -175-15-125-1H
#   ____  __> pre_ah_pattern_mirror = +1+125+15+175H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1H
#   ____  __> pre_ah_pattern_mirror_4 = +1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [69/201]
#   ____  > fixtureapi_id = 995267
#   ____  __> pre_ah_pattern = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [70/201]
#   ____  > fixtureapi_id = 995268
#   ____  __> pre_ah_pattern = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [71/201]
#   ____  > fixtureapi_id = 995606
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [72/201]
#   ____  > fixtureapi_id = 996134
#   ____  __> pre_ah_pattern = +025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [73/201]
#   ____  > fixtureapi_id = 996135
#   ____  __> pre_ah_pattern = -1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [74/201]
#   ____  > fixtureapi_id = 996137
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [75/201]
#   ____  > fixtureapi_id = 996500
#   ____  __> pre_ah_pattern = -075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075H
#   ____  __> pre_gou_pattern = 25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [76/201]
#   ____  > fixtureapi_id = 996501
#   ____  __> pre_ah_pattern = +0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [77/201]
#   ____  > fixtureapi_id = 996502
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [78/201]
#   ____  > fixtureapi_id = 996503
#   ____  __> pre_ah_pattern = +025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [79/201]
#   ____  > fixtureapi_id = 996504
#   ____  __> pre_ah_pattern = +025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [80/201]
#   ____  > fixtureapi_id = 996505
#   ____  __> pre_ah_pattern = +0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [81/201]
#   ____  > fixtureapi_id = 997360
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 15g175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [82/201]
#   ____  > fixtureapi_id = 997361
#   ____  __> pre_ah_pattern = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [83/201]
#   ____  > fixtureapi_id = 997362
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [84/201]
#   ____  > fixtureapi_id = 998223
#   ____  __> pre_ah_pattern = +025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [85/201]
#   ____  > fixtureapi_id = 998225
#   ____  __> pre_ah_pattern = +0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [86/201]
#   ____  > fixtureapi_id = 1000327
#   ____  __> pre_ah_pattern = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05+075H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [87/201]
#   ____  > fixtureapi_id = 1000328
#   ____  __> pre_ah_pattern = +05+075+1+125+15H
#   ____  __> pre_ah_pattern_mirror = -15-125-1-075-05H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = +05+075+1+125+15H
#   ____  __> pre_ah_pattern_mirror_4 = -15-125-1-075-05H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [88/201]
#   ____  > fixtureapi_id = 1000329
#   ____  __> pre_ah_pattern = -225-2-175-15-125H
#   ____  __> pre_ah_pattern_mirror = +125+15+175+2+225H
#   ____  __> pre_gou_pattern = 30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = -225-2-175-15-125H
#   ____  __> pre_ah_pattern_mirror_4 = +125+15+175+2+225H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [89/201]
#   ____  > fixtureapi_id = 1000330
#   ____  __> pre_ah_pattern = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025+0H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025+0H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [90/201]
#   ____  > fixtureapi_id = 1001328
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [91/201]
#   ____  > fixtureapi_id = 1001329
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [92/201]
#   ____  > fixtureapi_id = 1001727
#   ____  __> pre_ah_pattern = +05+075+1H
#   ____  __> pre_ah_pattern_mirror = -1-075-05H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = +05+075+1H
#   ____  __> pre_ah_pattern_mirror_4 = -1-075-05H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [93/201]
#   ____  > fixtureapi_id = 1001728
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> pre_gou_pattern_4 = 325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [94/201]
#   ____  > fixtureapi_id = 1001729
#   ____  __> pre_ah_pattern = +1+125+15H
#   ____  __> pre_ah_pattern_mirror = -15-125-1H
#   ____  __> pre_gou_pattern = 30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = +1+125+15H
#   ____  __> pre_ah_pattern_mirror_4 = -15-125-1H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [95/201]
#   ____  > fixtureapi_id = 1001730
#   ____  __> pre_ah_pattern = +05+075+1+125H
#   ____  __> pre_ah_pattern_mirror = -125-1-075-05H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = +05+075+1+125H
#   ____  __> pre_ah_pattern_mirror_4 = -125-1-075-05H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [96/201]
#   ____  > fixtureapi_id = 1001731
#   ____  __> pre_ah_pattern = -1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1H
#   ____  __> pre_gou_pattern = 25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [97/201]
#   ____  > fixtureapi_id = 1001732
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [98/201]
#   ____  > fixtureapi_id = 1001733
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [99/201]
#   ____  > fixtureapi_id = 1001975
#   ____  __> pre_ah_pattern = -05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [100/201]
#   ____  > fixtureapi_id = 1001976
#   ____  __> pre_ah_pattern = -15-125-1H
#   ____  __> pre_ah_pattern_mirror = +1+125+15H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -15-125-1H
#   ____  __> pre_ah_pattern_mirror_4 = +1+125+15H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [101/201]
#   ____  > fixtureapi_id = 1001977
#   ____  __> pre_ah_pattern = +0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [102/201]
#   ____  > fixtureapi_id = 1001979
#   ____  __> pre_ah_pattern = -025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025H
#   ____  __> pre_gou_pattern = 175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [103/201]
#   ____  > fixtureapi_id = 1001981
#   ____  __> pre_ah_pattern = +075+1+125H
#   ____  __> pre_ah_pattern_mirror = -125-1-075H
#   ____  __> pre_gou_pattern = 30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = +075+1+125H
#   ____  __> pre_ah_pattern_mirror_4 = -125-1-075H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [104/201]
#   ____  > fixtureapi_id = 1001982
#   ____  __> pre_ah_pattern = +025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [105/201]
#   ____  > fixtureapi_id = 1002215
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [106/201]
#   ____  > fixtureapi_id = 1002217
#   ____  __> pre_ah_pattern = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15H
#   ____  __> pre_gou_pattern = 275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [107/201]
#   ____  > fixtureapi_id = 1002219
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [108/201]
#   ____  > fixtureapi_id = 1002222
#   ____  __> pre_ah_pattern = +0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [109/201]
#   ____  > fixtureapi_id = 1002450
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [110/201]
#   ____  > fixtureapi_id = 1002453
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [111/201]
#   ____  > fixtureapi_id = 1002879
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [112/201]
#   ____  > fixtureapi_id = 1002880
#   ____  __> pre_ah_pattern = +0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [113/201]
#   ____  > fixtureapi_id = 1003948
#   ____  __> pre_ah_pattern = +0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [114/201]
#   ____  > fixtureapi_id = 1003949
#   ____  __> pre_ah_pattern = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [115/201]
#   ____  > fixtureapi_id = 1005859
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [116/201]
#   ____  > fixtureapi_id = 1005862
#   ____  __> pre_ah_pattern = +025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025H
#   ____  __> pre_gou_pattern = 175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025H
#   ____  __> pre_gou_pattern_4 = 175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [117/201]
#   ____  > fixtureapi_id = 1005864
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [118/201]
#   ____  > fixtureapi_id = 1005865
#   ____  __> pre_ah_pattern = -1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [119/201]
#   ____  > fixtureapi_id = 1005867
# ...
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [163/201]
#   ____  > fixtureapi_id = 1022798
#   ____  __> pre_ah_pattern = +025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [164/201]
#   ____  > fixtureapi_id = 1022799
#   ____  __> pre_ah_pattern = -175-15-125-1H
#   ____  __> pre_ah_pattern_mirror = +1+125+15+175H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1H
#   ____  __> pre_ah_pattern_mirror_4 = +1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [165/201]
#   ____  > fixtureapi_id = 1022800
#   ____  __> pre_ah_pattern = -175-15-125H
#   ____  __> pre_ah_pattern_mirror = +125+15+175H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -2-175-15-125H
#   ____  __> pre_ah_pattern_mirror_4 = +125+15+175+2H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [166/201]
#   ____  > fixtureapi_id = 1025934
#   ____  __> pre_ah_pattern = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [167/201]
#   ____  > fixtureapi_id = 1025935
#   ____  __> pre_ah_pattern = +025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025H
#   ____  __> pre_gou_pattern = 15g175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [168/201]
#   ____  > fixtureapi_id = 1026791
#   ____  __> pre_ah_pattern = -075-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+075H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [169/201]
#   ____  > fixtureapi_id = 981154
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [170/201]
#   ____  > fixtureapi_id = 987932
#   ____  __> pre_ah_pattern = -075-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+075H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [171/201]
#   ____  > fixtureapi_id = 990389
#   ____  __> pre_ah_pattern = -025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025H
#   ____  __> pre_gou_pattern = 175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025H
#   ____  __> pre_gou_pattern_4 = 175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [172/201]
#   ____  > fixtureapi_id = 1015547
#   ____  __> pre_ah_pattern = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025+0H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025+0H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [173/201]
#   ____  > fixtureapi_id = 1015548
#   ____  __> pre_ah_pattern = +05+075+1+125+15H
#   ____  __> pre_ah_pattern_mirror = -15-125-1-075-05H
#   ____  __> pre_gou_pattern = 30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = +05+075+1+125+15H
#   ____  __> pre_ah_pattern_mirror_4 = -15-125-1-075-05H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [174/201]
#   ____  > fixtureapi_id = 1015549
#   ____  __> pre_ah_pattern = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05+075H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [175/201]
#   ____  > fixtureapi_id = 1027676
#   ____  __> pre_ah_pattern = -05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [176/201]
#   ____  > fixtureapi_id = 1028064
#   ____  __> pre_ah_pattern = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [177/201]
#   ____  > fixtureapi_id = 1029704
#   ____  __> pre_ah_pattern = -075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075H
#   ____  __> pre_gou_pattern = 15g175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [178/201]
#   ____  > fixtureapi_id = 1035228
#   ____  __> pre_ah_pattern = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05+075H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [179/201]
#   ____  > fixtureapi_id = 1037005
#   ____  __> pre_ah_pattern = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [180/201]
#   ____  > fixtureapi_id = 1037474
#   ____  __> pre_ah_pattern = -1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [181/201]
#   ____  > fixtureapi_id = 1038753
#   ____  __> pre_ah_pattern = -075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [182/201]
#   ____  > fixtureapi_id = 1039176
#   ____  __> pre_ah_pattern = +025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [183/201]
#   ____  > fixtureapi_id = 1039349
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [184/201]
#   ____  > fixtureapi_id = 1041235
#   ____  __> pre_ah_pattern = +025+05+075+1+125H
#   ____  __> pre_ah_pattern_mirror = -125-1-075-05-025H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075+1+125H
#   ____  __> pre_ah_pattern_mirror_4 = -125-1-075-05-025H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [185/201]
#   ____  > fixtureapi_id = 1041792
#   ____  __> pre_ah_pattern = +025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [186/201]
#   ____  > fixtureapi_id = 1042766
#   ____  __> pre_ah_pattern = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [187/201]
#   ____  > fixtureapi_id = 1049821
#   ____  __> pre_ah_pattern = +0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0H
#   ____  __> pre_gou_pattern = 175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [188/201]
#   ____  > fixtureapi_id = 1049825
#   ____  __> pre_ah_pattern = -1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [189/201]
#   ____  > fixtureapi_id = 1050795
#   ____  __> pre_ah_pattern = -125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [190/201]
#   ____  > fixtureapi_id = 1092787
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [191/201]
#   ____  > fixtureapi_id = 1092793
#   ____  __> pre_ah_pattern = -025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [192/201]
#   ____  > fixtureapi_id = 1099865
#   ____  __> pre_ah_pattern = +025+05+075+1H
#   ____  __> pre_ah_pattern_mirror = -1-075-05-025H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075+1H
#   ____  __> pre_ah_pattern_mirror_4 = -1-075-05-025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [193/201]
#   ____  > fixtureapi_id = 1114160
#   ____  __> pre_ah_pattern = +025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [194/201]
#   ____  > fixtureapi_id = 1114162
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [195/201]
#   ____  > fixtureapi_id = 1114163
#   ____  __> pre_ah_pattern = -125-1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1+125H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1+125H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [196/201]
#   ____  > fixtureapi_id = 1114165
#   ____  __> pre_ah_pattern = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [197/201]
#   ____  > fixtureapi_id = 1114166
#   ____  __> pre_ah_pattern = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05+075H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [198/201]
#   ____  > fixtureapi_id = 1114168
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [199/201]
#   ____  > fixtureapi_id = 1114169
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 175g20g225gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [200/201]
#   ____  > fixtureapi_id = 1119669
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [201/201]
#   ____  > fixtureapi_id = 1121893
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-09-03 08:33:53

# %%
""" 
    Check Predates
"""

# Import
from a_settings.messages import *  
from a_models.date import *   
from a_models.football_odds import *   
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_adds(1, space).strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    fo_controll_predates(day1, day2, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:33:53
#   __main()
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-09-03 08:33:53.459651
#   ____get_today_adds()
#   ______adds date_diff : 1
#   ______today_raw : 2023-09-04 08:33:53.460645
#   ____fo_controll_predates()
#   ______Select  DATE(date) as date_FX  , DATE(pre_odd_updated_at) as date_pre   , count(*) as counter   , fixture_status   from football_odds  where DATE(date) >= '2023-09-03'  and DATE(date) <= '2023-09-04'  group by DATE(pre_odd_updated_at), fixture_status  order by DATE(date) desc
#   ______Total Row(s) : 6
#
#       date_FX    date_pre  counter    fixture_status
# 0  2023-09-03  2023-08-27        1  Not Started Goto
# 1  2023-09-03  2023-09-03      198  Not Started Goto
# 2  2023-09-03        None       15              None
# 3  2023-09-03  2023-09-02      267  Not Started Goto
# 4  2023-09-03  2023-08-30        3  Not Started Goto
# 5  2023-09-03  2023-09-01        1  Not Started Goto
#
# # -------------------------------------------------- End at 2023-09-03 08:33:54

# %%
# Import  

from a_settings.messages import *  
from a_models.date import *   
from a_models.football_fixtures import *   
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_adds(1, space).strftime("%Y-%m-%d")  
    # --------------------------------------------------   
    ff_predates_league_today(day1, day2, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:33:54
#   __main()
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-09-03 08:33:54.537681
#   ____get_today_adds()
#   ______adds date_diff : 1
#   ______today_raw : 2023-09-04 08:33:54.538681
#   ____ff_predates_league_today()
#   ____Select  leagueapi_id  , season   from football_fixtures  where date <= Date('2023-09-04')  and date >= Date('2023-09-03')  and deleted_at is null  and fixture_status like 'Not Started'   group by leagueapi_id, season  order by date, leagueapi_id asc
#   ____Total Row(s) : 95
#   ____[1/95]  #370 - 2023
#   ______fl_check_league()
#   ______bookmakersapi_id: 0
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:33:54.709128
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:33:54.711105
#   ______aoN_controll_match_update()
#   ________aa_check_acccount()
#   __________API arya6792@gmail.com counter is 65
#   __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________aoN_response_odds()
#   __________date : 2023-09-03
#   __________date_raw : 2023-09-03 08:33:54.711105
#   __________bookmaker : 0
#   __________season : 2023
#   __________league : 370
#   __________page : 1
#   ____________Total API Response(s) : 0
#   ____________total_MAX_PAGE : 1
#   ______________SKIPPED because its Nothing total_API_response:0
#   ___________________________________________________
#   ____[2/95]  #872 - 2023
#   ______fl_check_league()
#   ______bookmakersapi_id: 0
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:33:56.072943
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:33:56.073945
#   ______aoN_controll_match_update()
#   ________aa_check_acccount()
#   __________API arya6792@gmail.com counter is 64
#   __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________aoN_response_odds()
#   __________date : 2023-09-03
#   __________date_raw : 2023-09-03 08:33:56.073945
#   __________bookmaker : 0
#   __________season : 2023
#   __________league : 872
#   __________page : 1
#   ____________Total API Response(s) : 0
#   ____________total_MAX_PAGE : 1
#   ______________SKIPPED because its Nothing total_API_response:0
#   ___________________________________________________
#   ____[3/95]  #253 - 2023
#   ______fl_check_league()
#   ______bookmakersapi_id: 8
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:33:56.953110
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:33:56.955113
#   ______aoN_controll_match_update()
#   ________aa_check_acccount()
#   __________API arya6792@gmail.com counter is 63
#   __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________aoN_response_odds()
#   __________date : 2023-09-03
#   __________date_raw : 2023-09-03 08:33:56.955113
#   __________bookmaker : 8
#   __________season : 2023
#   __________league : 253
#   __________page : 1
#   ____________Total API Response(s) : 10
#   ____________total_MAX_PAGE : 5
#   ______________
#   ______________1/10
#   ______________USA,  Major League Soccer  #253 - 2023
#   ______________2023-08-26 23:30:00+00:00 // UTC // 981126
#   ________________aoN_football_statistics_check()
#   ____________________USA,  Major League Soccer - 2023 __ 981126 __ 2023-08-27 06:30:00 __ 8
#   ______________________________New York Red Bulls vs Inter Miami
#   __________________________Kurang 2023-08-27 06:30:00 < 2023-09-03 08:33:56
#   ________________PREP_check_date is not valid
#   ________________
#   ________________2/10
#   ________________USA,  Major League Soccer  #253 - 2023
#   ________________2023-08-26 23:30:00+00:00 // UTC // 981124
#   __________________aoN_football_statistics_check()
#   ______________________USA,  Major League Soccer - 2023 __ 981124 __ 2023-08-27 06:30:00 __ 8
#   ________________________________DC United vs Philadelphia Union
#   ____________________________Kurang 2023-08-27 06:30:00 < 2023-09-03 08:33:56
#   __________________PREP_check_date is not valid
#   __________________
#   __________________3/10
#   __________________USA,  Major League Soccer  #253 - 2023
#   __________________2023-08-26 23:30:00+00:00 // UTC // 981125
#   ____________________aoN_football_statistics_check()
#   ________________________USA,  Major League Soccer - 2023 __ 981125 __ 2023-08-27 06:30:00 __ 8
#   __________________________________Montreal Impact vs New England Revolution
#   ______________________________Kurang 2023-08-27 06:30:00 < 2023-09-03 08:33:56
#   ____________________PREP_check_date is not valid
#   ____________________
#   ____________________4/10
#   ____________________USA,  Major League Soccer  #253 - 2023
#   ____________________2023-08-26 23:30:00+00:00 // UTC // 981122
#   ______________________aoN_football_statistics_check()
#   __________________________USA,  Major League Soccer - 2023 __ 981122 __ 2023-08-27 06:30:00 __ 8
#   ____________________________________FC Cincinnati vs New York City FC
#   ________________________________Kurang 2023-08-27 06:30:00 < 2023-09-03 08:33:56
#   ______________________PREP_check_date is not valid
#   ______________________
#   ______________________5/10
#   ______________________USA,  Major League Soccer  #253 - 2023
#   ______________________2023-08-26 23:30:00+00:00 // UTC // 981120
#   ________________________aoN_football_statistics_check()
#   ____________________________USA,  Major League Soccer - 2023 __ 981120 __ 2023-08-27 06:30:00 __ 8
#   ______________________________________Atlanta United FC vs Nashville SC
#   __________________________________Kurang 2023-08-27 06:30:00 < 2023-09-03 08:33:56
#   ________________________PREP_check_date is not valid
#   ________________________
#   ________________________6/10
#   ________________________USA,  Major League Soccer  #253 - 2023
#   ________________________2023-08-26 23:30:00+00:00 // UTC // 981121
#   __________________________aoN_football_statistics_check()
#   ______________________________USA,  Major League Soccer - 2023 __ 981121 __ 2023-08-27 06:30:00 __ 8
#   ________________________________________Charlotte vs Los Angeles FC
#   ____________________________________Kurang 2023-08-27 06:30:00 < 2023-09-03 08:33:56
#   __________________________PREP_check_date is not valid
#   __________________________
#   __________________________7/10
#   __________________________USA,  Major League Soccer  #253 - 2023
#   __________________________2023-08-26 23:30:00+00:00 // UTC // 981276
#   ____________________________aoN_football_statistics_check()
________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '253'  and season = '2023'  and fixtureapi_id = '981156'
# ____________________________Total Row(s) : 1
# ______________________________football_ultimate_assessments UPDATED
# ______________________football_odds UPDATED
# ______________________football_fixtures UPDATED
# ________________________football_fixtures 981156 UPDATED Not Started Goto
# ______________________
# ______________________5/6
# ______________________USA,  Major League Soccer  #253 - 2023
# ______________________2023-09-03 23:30:00+00:00 // UTC // 981157
# ________________________aoN_football_statistics_check()
# ____________________________USA,  Major League Soccer - 2023 __ 981157 __ 2023-09-04 06:30:00 __ 8
# ______________________________________Philadelphia Union vs New York Red Bulls
# __________________________________Lebih 2023-09-04 06:30:00 >= 2023-09-03 08:33:56
# __________________________fua_update_or_insert()
# ____________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '253'  and season = '2023'  and fixtureapi_id = '981157'
# ______________________________Total Row(s) : 1
# ________________________________football_ultimate_assessments UPDATED
# ________________________football_odds UPDATED
# ________________________football_fixtures UPDATED
# __________________________football_fixtures 981157 UPDATED Not Started Goto
# ________________________
# ________________________6/6
# ________________________USA,  Major League Soccer  #253 - 2023
# ________________________2023-09-03 00:30:00+00:00 // UTC // 981278
# __________________________aoN_football_statistics_check()
# ______________________________USA,  Major League Soccer - 2023 __ 981278 __ 2023-09-03 07:30:00 __ 8
# ________________________________________Sporting Kansas City vs St. Louis City
# ____________________________________Kurang 2023-09-03 07:30:00 < 2023-09-03 08:33:56
# __________________________PREP_check_date is not valid
# __________________________STOP RESPONSE
#   ___________________________________________________
#   ____[4/95]  #722 - 2023
#   ______fl_check_league()
#   ______bookmakersapi_id: 11
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:35:52.941951
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:35:52.942956
#   ______aoN_controll_match_update()
#   ________aa_check_acccount()
#   __________API arya6792@gmail.com counter is 58
#   __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________aoN_response_odds()
#   __________date : 2023-09-03
#   __________date_raw : 2023-09-03 08:35:52.942956
#   __________bookmaker : 11
#   __________season : 2023
#   __________league : 722
#   __________page : 1
#   ____________Total API Response(s) : 10
#   ____________total_MAX_PAGE : 2
#   ______________
#   ______________1/10
#   ______________Mexico,  Liga Premier Serie A  #722 - 2023
#   ______________2023-08-26 22:00:00+00:00 // UTC // 1103037
#   ________________aoN_football_statistics_check()
#   ____________________Mexico,  Liga Premier Serie A - 2023 __ 1103037 __ 2023-08-27 05:00:00 __ 11
#   ______________________________Yalmakan vs Sporting Canamy
#   __________________________Kurang 2023-08-27 05:00:00 < 2023-09-03 08:35:52
#   ________________PREP_check_date is not valid
#   ________________
#   ________________2/10
#   ________________Mexico,  Liga Premier Serie A  #722 - 2023
#   ________________2023-08-27 00:00:00+00:00 // UTC // 1103347
#   __________________aoN_football_statistics_check()
#   ______________________Mexico,  Liga Premier Serie A - 2023 __ 1103347 __ 2023-08-27 07:00:00 __ 11
#   ________________________________Mexicali FC vs Calor de San Pedro
#   ____________________________Kurang 2023-08-27 07:00:00 < 2023-09-03 08:35:52
#   __________________PREP_check_date is not valid
#   __________________
#   __________________3/10
#   __________________Mexico,  Liga Premier Serie A  #722 - 2023
#   __________________2023-08-26 23:00:00+00:00 // UTC // 1103346
#   ____________________aoN_football_statistics_check()
#   ________________________Mexico,  Liga Premier Serie A - 2023 __ 1103346 __ 2023-08-27 06:00:00 __ 11
#   __________________________________UA Zacatecas vs Correcaminos UAT II
#   ______________________________Kurang 2023-08-27 06:00:00 < 2023-09-03 08:35:52
#   ____________________PREP_check_date is not valid
#   ____________________
#   ____________________4/10
#   ____________________Mexico,  Liga Premier Serie A  #722 - 2023
#   ____________________2023-08-26 22:00:00+00:00 // UTC // 1103036
#   ______________________aoN_football_statistics_check()
#   __________________________Mexico,  Liga Premier Serie A - 2023 __ 1103036 __ 2023-08-27 05:00:00 __ 11
#   ____________________________________Pioneros de Cancún vs Inter Playa del Carmen
#   ________________________________Kurang 2023-08-27 05:00:00 < 2023-09-03 08:35:52
#   ______________________PREP_check_date is not valid
#   ______________________
#   ______________________5/10
#   ______________________Mexico,  Liga Premier Serie A  #722 - 2023
#   ______________________2023-08-27 00:00:00+00:00 // UTC // 1103040
#   ________________________aoN_football_statistics_check()
#   ____________________________Mexico,  Liga Premier Serie A - 2023 __ 1103040 __ 2023-08-27 07:00:00 __ 11
#   ______________________________________Lobos ULMX vs Petroleros de Salamanca
#   __________________________________Kurang 2023-08-27 07:00:00 < 2023-09-03 08:35:52
#   ________________________PREP_check_date is not valid
#   ________________________
#   ________________________6/10
#   ________________________Mexico,  Liga Premier Serie A  #722 - 2023
#   ________________________2023-08-27 01:00:00+00:00 // UTC // 1103041
#   __________________________aoN_football_statistics_check()
#   ______________________________Mexico,  Liga Premier Serie A - 2023 __ 1103041 __ 2023-08-27 08:00:00 __ 11
#   ________________________________________Reboceros La Piedad vs Tapachula
#   ____________________________________Kurang 2023-08-27 08:00:00 < 2023-09-03 08:35:52
#   __________________________PREP_check_date is not valid
#   __________________________
#   __________________________7/10
#   __________________________Mexico,  Liga Premier Serie A  #722 - 2023
#   __________________________2023-08-27 02:00:00+00:00 // UTC // 1103042
#   ____________________________aoN_football_statistics_check()
#   ________________________________Mexico,  Liga Premier Serie A - 2023 __ 1103042 __ 2023-08-27 09:00:00 __ 11
#   __________________________________________CDS Tampico Madero vs Aguacateros de Peribán
#   ______________________________________Kurang 2023-08-27 09:00:00 < 2023-09-03 08:35:52
#   ____________________________PREP_check_date is not valid
#   ____________________________
#   ____________________________8/10
#   ____________________________Mexico,  Liga Premier Serie A  #722 - 2023
#   ____________________________2023-08-27 18:00:00+00:00 // UTC // 1103043
#   ______________________________aoN_football_statistics_check()
#   __________________________________Mexico,  Liga Premier Serie A - 2023 __ 1103043 __ 2023-08-28 01:00:00 __ 11
#   ____________________________________________Montañeses vs Inter de Querétaro
#   ________________________________________Kurang 2023-08-28 01:00:00 < 2023-09-03 08:35:52
#   ______________________________PREP_check_date is not valid
#   ______________________________
#   ______________________________9/10
#   ______________________________Mexico,  Liga Premier Serie A  #722 - 2023
#   ______________________________2023-08-29 02:00:00+00:00 // UTC // 1103349
#   ________________________________aoN_football_statistics_check()
#   ____________________________________Mexico,  Liga Premier Serie A - 2023 __ 1103349 __ 2023-08-29 09:00:00 __ 11
#   ______________________________________________Durango vs Cimarrones de Sonora II
#   __________________________________________Kurang 2023-08-29 09:00:00 < 2023-09-03 08:35:52
#   ________________________________PREP_check_date is not valid
#   ________________________________
#   ________________________________10/10
#   ________________________________Mexico,  Liga Premier Serie A  #722 - 2023
#   ________________________________2023-09-01 23:00:00+00:00 // UTC // 1103044
#   __________________________________aoN_football_statistics_check()
#   ______________________________________Mexico,  Liga Premier Serie A - 2023 __ 1103044 __ 2023-09-02 06:00:00 __ 11
#   ________________________________________________Inter Playa del Carmen vs Reboceros La Piedad
#   ____________________________________________Kurang 2023-09-02 06:00:00 < 2023-09-03 08:35:52
#   __________________________________PREP_check_date is not valid
#   __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API arya6792@gmail.com counter is 57
# __________APIkey: fb0d635ec8msh5e46b55f220ec09p1977fcjsn24c915a7bc07
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date : 2023-09-03
# __________date_raw : 2023-09-03 08:35:52.942956
# __________bookmaker : 11
# __________season : 2023
# __________league : 722
# __________page : 2
# ____________Total API Response(s) : 10
# ____________total_MAX_PAGE : 2
# ______________
# ______________1/10
# ______________Mexico,  Liga Premier Serie A  #722 - 2023
# ______________2023-09-02 01:00:00+00:00 // UTC // 1103351
# ________________aoN_football_statistics_check()
# ____________________Mexico,  Liga Premier Serie A - 2023 __ 1103351 __ 2023-09-02 08:00:00 __ 11
# ______________________________Cimarrones de Sonora II vs UA Zacatecas
# __________________________Kurang 2023-09-02 08:00:00 < 2023-09-03 08:35:52
# ________________PREP_check_date is not valid
# ________________
# ________________2/10
# ________________Mexico,  Liga Premier Serie A  #722 - 2023
# ________________2023-09-02 01:00:00+00:00 // UTC // 1103045
# __________________aoN_football_statistics_check()
# ______________________Mexico,  Liga Premier Serie A - 2023 __ 1103045 __ 2023-09-02 08:00:00 __ 11
# ________________________________Petroleros de Salamanca vs San Juan de Aragón
# ____________________________Kurang 2023-09-02 08:00:00 < 2023-09-03 08:35:52
# __________________PREP_check_date is not valid
# __________________
# __________________3/10
# __________________Mexico,  Liga Premier Serie A  #722 - 2023
# __________________2023-09-02 01:00:00+00:00 // UTC // 1103352
# ____________________aoN_football_statistics_check()
# ________________________Mexico,  Liga Premier Serie A - 2023 __ 1103352 __ 2023-09-02 08:00:00 __ 11
# __________________________________Atlético Saltillo vs Durango
# ______________________________Kurang 2023-09-02 08:00:00 < 2023-09-03 08:35:52
# ____________________PREP_check_date is not valid
# ____________________
# ____________________4/10
# ____________________Mexico,  Liga Premier Serie A  #722 - 2023
# ____________________2023-09-02 17:00:00+00:00 // UTC // 1103046
# ______________________aoN_football_statistics_check()
# __________________________Mexico,  Liga Premier Serie A - 2023 __ 1103046 __ 2023-09-03 00:00:00 __ 11
# ____________________________________Deportiva Venados vs Yalmakan
# ________________________________Kurang 2023-09-03 00:00:00 < 2023-09-03 08:35:52
# ______________________PREP_check_date is not valid
# ______________________
# ______________________5/10
# ______________________Mexico,  Liga Premier Serie A  #722 - 2023
# ______________________2023-09-02 23:00:00+00:00 // UTC // 1103051
# ________________________aoN_football_statistics_check()
# ____________________________Mexico,  Liga Premier Serie A - 2023 __ 1103051 __ 2023-09-03 06:00:00 __ 11
# ______________________________________Tapachula vs Escorpiones
# __________________________________Kurang 2023-09-03 06:00:00 < 2023-09-03 08:35:52
# ________________________PREP_check_date is not valid
# ________________________
# ________________________6/10
# ________________________Mexico,  Liga Premier Serie A  #722 - 2023
# ________________________2023-09-02 22:30:00+00:00 // UTC // 1103355
# __________________________aoN_football_statistics_check()
# ______________________________Mexico,  Liga Premier Serie A - 2023 __ 1103355 __ 2023-09-03 05:30:00 __ 11
# ________________________________________Gavilanes FC Matamoros vs Colima
# ____________________________________Kurang 2023-09-03 05:30:00 < 2023-09-03 08:35:52
# __________________________PREP_check_date is not valid
# __________________________
# __________________________7/10
# __________________________Mexico,  Liga Premier Serie A  #722 - 2023
# __________________________2023-09-02 23:00:00+00:00 // UTC // 1103047
# ____________________________aoN_football_statistics_check()
# ________________________________Mexico,  Liga Premier Serie A - 2023 __ 1103047 __ 2023-09-03 06:00:00 __ 11
# __________________________________________Sporting Canamy vs Pioneros de Cancún
# ______________________________________Kurang 2023-09-03 06:00:00 < 2023-09-03 08:35:52
# ____________________________PREP_check_date is not valid
# ____________________________
# ____________________________8/10
# ____________________________Mexico,  Liga Premier Serie A  #722 - 2023
# ____________________________2023-09-02 23:00:00+00:00 // UTC // 1103049
# ______________________________aoN_football_statistics_check()
# __________________________________Mexico,  Liga Premier Serie A - 2023 __ 1103049 __ 2023-09-03 06:00:00 __ 11
# ____________________________________________Aguacateros de Peribán vs Lobos ULMX
# ________________________________________Kurang 2023-09-03 06:00:00 < 2023-09-03 08:35:52
# ______________________________PREP_check_date is not valid
# ______________________________
# ______________________________9/10
# ______________________________Mexico,  Liga Premier Serie A  #722 - 2023
# ______________________________2023-09-02 23:00:00+00:00 // UTC // 1103048
# ________________________________aoN_football_statistics_check()
# ____________________________________Mexico,  Liga Premier Serie A - 2023 __ 1103048 __ 2023-09-03 06:00:00 __ 11
# ______________________________________________Irapuato vs Deportivo Zap
# __________________________________________Kurang 2023-09-03 06:00:00 < 2023-09-03 08:35:52
# ________________________________PREP_check_date is not valid
# ________________________________
# ________________________________10/10
# ________________________________Mexico,  Liga Premier Serie A  #722 - 2023
# ________________________________2023-09-03 02:00:00+00:00 // UTC // 1103204
# ...
#   ____________________________Kurang 2023-08-27 06:00:00 < 2023-09-03 08:53:35
#   __________________PREP_check_date is not valid
#   __________________
#   __________________3/10
#   __________________Nicaragua,  Primera Division  #396 - 2023
#   __________________2023-08-27 02:00:00+00:00 // UTC // 1119536
#   ________________________aoN_football_odds_insert_rows()
#   ________________________football_odds INSERTED
#   ____________________aoN_football_statistics_check()
#   __________________________aoN_football_leagues_check()
#   __________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '396'
#   ____________________________Total Row(s) : 1
#   __________________________get_today_adds()
#   ____________________________adds date_diff : 0
#   ____________________________today_raw : 2023-09-03 08:53:42.888296
#   __________________________afN_controll_match_update()
#   ____________________________aa_check_acccount()
#   ______________________________API digitalmedia.arion@gmail.com counter is 4
#   ______________________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ____________________________aa_check_acccount()
#   ____________________________aa_update_counter()
#   ____________________________afN_response_fixtures()
#   ______________________________fixtureapi_id : 1119536
#   ______________________________fixture_updated_at : 2023-09-03 08:53:42.888296
#   ______________________________ROUTES : fixtureapi_id_INSERT
#   ________________________________Total API Response(s) : 1
#   __________________________________
#   __________________________________ [1/1] fixture_status: Match Finished __ 396 __ 2023-08-27 02:00:00+00:00
#   ______________________________________football_venues INSERTED
#   ______________________________________football_teams UPDATED
#   ______________________________________football_teams UPDATED
#   __________________________________football_fixtures INSERTED
#   ______________________________Kurang 2023-08-27 09:00:00 < 2023-09-03 08:53:35
#   ____________________PREP_check_date is not valid
#   ____________________
#   ____________________4/10
#   ____________________Nicaragua,  Primera Division  #396 - 2023
#   ____________________2023-08-27 21:00:00+00:00 // UTC // 1119537
#   __________________________aoN_football_odds_insert_rows()
#   __________________________football_odds INSERTED
#   ______________________aoN_football_statistics_check()
#   ____________________________aoN_football_leagues_check()
#   ____________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '396'
#   ______________________________Total Row(s) : 1
#   ____________________________get_today_adds()
#   ______________________________adds date_diff : 0
#   ______________________________today_raw : 2023-09-03 08:53:45.359546
#   ____________________________afN_controll_match_update()
#   ______________________________aa_check_acccount()
#   ________________________________API digitalmedia.arion@gmail.com counter is 3
#   ________________________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   ______________________________aa_check_acccount()
#   ______________________________aa_update_counter()
#   ______________________________afN_response_fixtures()
#   ________________________________fixtureapi_id : 1119537
#   ________________________________fixture_updated_at : 2023-09-03 08:53:45.359546
#   ________________________________ROUTES : fixtureapi_id_INSERT
#   __________________________________Total API Response(s) : 1
#   ____________________________________
#   ____________________________________ [1/1] fixture_status: Match Finished __ 396 __ 2023-08-27 21:00:00+00:00
#   ________________________________________football_teams UPDATED
#   ________________________________________football_teams UPDATED
#   ____________________________________football_fixtures INSERTED
#   ________________________________Kurang 2023-08-28 04:00:00 < 2023-09-03 08:53:35
#   ______________________PREP_check_date is not valid
#   ______________________
#   ______________________5/10
#   ______________________Nicaragua,  Primera Division  #396 - 2023
#   ______________________2023-08-28 01:00:00+00:00 // UTC // 1119538
#   ________________________aoN_football_statistics_check()
#   ____________________________Nicaragua,  Primera Division - 2023 __ 1119538 __ 2023-08-28 08:00:00 __ 11
#   ______________________________________Real Estelí vs Diriangén
#   __________________________________Kurang 2023-08-28 08:00:00 < 2023-09-03 08:53:35
#   ________________________PREP_check_date is not valid
#   ________________________
#   ________________________6/10
#   ________________________Nicaragua,  Primera Division  #396 - 2023
#   ________________________2023-08-30 23:00:00+00:00 // UTC // 1119542
#   __________________________aoN_football_statistics_check()
#   ______________________________Nicaragua,  Primera Division - 2023 __ 1119542 __ 2023-08-31 06:00:00 __ 11
#   ________________________________________Managua vs UNAN Managua
#   ____________________________________Kurang 2023-08-31 06:00:00 < 2023-09-03 08:53:35
#   __________________________PREP_check_date is not valid
#   __________________________
#   __________________________7/10
#   __________________________Nicaragua,  Primera Division  #396 - 2023
#   __________________________2023-08-31 00:00:00+00:00 // UTC // 1119543
#   ____________________________aoN_football_statistics_check()
#   ________________________________Nicaragua,  Primera Division - 2023 __ 1119543 __ 2023-08-31 07:00:00 __ 11
#   __________________________________________Diriangén vs H&H Export
#   ______________________________________Kurang 2023-08-31 07:00:00 < 2023-09-03 08:53:35
#   ____________________________PREP_check_date is not valid
#   ____________________________
#   ____________________________8/10
#   ____________________________Nicaragua,  Primera Division  #396 - 2023
#   ____________________________2023-08-31 02:00:00+00:00 // UTC // 1119541
#   ______________________________aoN_football_statistics_check()
#   __________________________________Nicaragua,  Primera Division - 2023 __ 1119541 __ 2023-08-31 09:00:00 __ 11
#   ____________________________________________Walter Ferretti vs Real Estelí
#   ________________________________________Kurang 2023-08-31 09:00:00 < 2023-09-03 08:53:35
#   ______________________________PREP_check_date is not valid
#   ______________________________
#   ______________________________9/10
#   ______________________________Nicaragua,  Primera Division  #396 - 2023
#   ______________________________2023-08-31 21:00:00+00:00 // UTC // 1119539
#   ________________________________aoN_football_statistics_check()
#   ____________________________________Nicaragua,  Primera Division - 2023 __ 1119539 __ 2023-09-01 04:00:00 __ 11
#   ______________________________________________Matagalpa vs Deportivo Ocotal
#   __________________________________________Kurang 2023-09-01 04:00:00 < 2023-09-03 08:53:35
#   ________________________________PREP_check_date is not valid
#   ________________________________
#   ________________________________10/10
#   ________________________________Nicaragua,  Primera Division  #396 - 2023
#   ________________________________2023-09-03 01:00:00+00:00 // UTC // 1119544
#   ______________________________________aoN_football_odds_insert_rows()
#   ______________________________________football_odds INSERTED
#   __________________________________aoN_football_statistics_check()
#   ________________________________________aoN_football_leagues_check()
#   ________________________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '396'
#   __________________________________________Total Row(s) : 1
#   ________________________________________get_today_adds()
#   __________________________________________adds date_diff : 0
#   __________________________________________today_raw : 2023-09-03 08:53:53.116985
#   ________________________________________afN_controll_match_update()
#   __________________________________________aa_check_acccount()
#   ____________________________________________API digitalmedia.arion@gmail.com counter is 2
#   ____________________________________________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
#   __________________________________________aa_check_acccount()
#   __________________________________________aa_update_counter()
#   __________________________________________afN_response_fixtures()
#   ____________________________________________fixtureapi_id : 1119544
#   ____________________________________________fixture_updated_at : 2023-09-03 08:53:53.116985
#   ____________________________________________ROUTES : fixtureapi_id_INSERT
#   ______________________________________________Total API Response(s) : 1
#   ________________________________________________
#   ________________________________________________ [1/1] fixture_status: Halftime __ 396 __ 2023-09-03 01:00:00+00:00
#   ____________________________________________________football_teams UPDATED
#   ____________________________________________________football_teams UPDATED
#   ________________________________________________football_fixtures INSERTED
#   ____________________________________________Kurang 2023-09-03 08:00:00 < 2023-09-03 08:53:35
#   __________________________________PREP_check_date is not valid
#   __________________________________RE-LOOP RESPONSE
# ______aoN_controll_match_update()
# ________aa_check_acccount()
# __________API digitalmedia.arion@gmail.com counter is 1
# __________APIkey: 0afba27e48msh3210652956535c6p1b4901jsn192c8bb7a4e6
# ________aa_check_acccount()
# ________aa_update_counter()
# ________aoN_response_odds()
# __________date : 2023-09-03
# __________date_raw : 2023-09-03 08:53:35.294856
# __________bookmaker : 11
# __________season : 2023
# __________league : 396
# __________page : 2
# ____________Total API Response(s) : 4
# ____________total_MAX_PAGE : 2
# ______________
# ______________1/4
# ______________Nicaragua,  Primera Division  #396 - 2023
# ______________2023-09-04 00:00:00+00:00 // UTC // 1119545
# ________________aoN_football_statistics_check()
# ____________________Nicaragua,  Primera Division - 2023 __ 1119545 __ 2023-09-04 07:00:00 __ 11
# ______________________________Deportivo Ocotal vs Jalapa
# __________________________Lebih 2023-09-04 07:00:00 >= 2023-09-03 08:53:35
# __________________fua_update_or_insert()
# ____________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '396'  and season = '2023'  and fixtureapi_id = '1119545'
# ______________________Total Row(s) : 0
# ________________________football_ultimate_assessments INSERTED
# ________________football_odds UPDATED
# ________________football_fixtures UPDATED
# __________________football_fixtures 1119545 UPDATED Not Started Goto
# ________________
# ________________2/4
# ________________Nicaragua,  Primera Division  #396 - 2023
# ________________2023-09-03 21:00:00+00:00 // UTC // 1119546
# __________________aoN_football_statistics_check()
# ______________________Nicaragua,  Primera Division - 2023 __ 1119546 __ 2023-09-04 04:00:00 __ 11
# ________________________________H&H Export vs Matagalpa
# ____________________________Lebih 2023-09-04 04:00:00 >= 2023-09-03 08:53:35
# ____________________fua_update_or_insert()
# ______________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '396'  and season = '2023'  and fixtureapi_id = '1119546'
# ________________________Total Row(s) : 1
# __________________________football_ultimate_assessments UPDATED
# __________________football_odds UPDATED
# __________________football_fixtures UPDATED
# ____________________football_fixtures 1119546 UPDATED Not Started Goto
# __________________
# __________________3/4
# __________________Nicaragua,  Primera Division  #396 - 2023
# __________________2023-09-03 02:00:00+00:00 // UTC // 1119547
# ________________________aoN_football_odds_insert_rows()
# ________________________football_odds INSERTED
# ____________________aoN_football_statistics_check()
# __________________________aoN_football_leagues_check()
# __________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '396'
# ____________________________Total Row(s) : 1
# __________________________get_today_adds()
# ____________________________adds date_diff : 0
# ____________________________today_raw : 2023-09-03 08:54:03.883715
# __________________________afN_controll_match_update()
# ____________________________aa_check_acccount()
# ______________________________API hariyant2410@gmail.com counter is 6
# ______________________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
# ____________________________aa_check_acccount()
# ____________________________aa_update_counter()
# ____________________________afN_response_fixtures()
# ______________________________fixtureapi_id : 1119547
# ______________________________fixture_updated_at : 2023-09-03 08:54:03.883715
# ______________________________ROUTES : fixtureapi_id_INSERT
# ________________________________Total API Response(s) : 1
# __________________________________
# __________________________________ [1/1] fixture_status: Not Started __ 396 __ 2023-09-03 02:00:00+00:00
# ______________________________________football_venues INSERTED
# ______________________________________football_teams UPDATED
# ______________________________________football_teams UPDATED
# __________________________________football_fixtures INSERTED
# ______________________________Lebih 2023-09-03 09:00:00 >= 2023-09-03 08:53:35
# ______________________fua_update_or_insert()
# ________________________Select  leagueapi_id   , season   from football_ultimate_assessments  where leagueapi_id = '396'  and season = '2023'  and fixtureapi_id = '1119547'
# __________________________Total Row(s) : 0
# ____________________________football_ultimate_assessments INSERTED
# ____________________football_odds UPDATED
# ____________________football_fixtures UPDATED
# ______________________football_fixtures 1119547 UPDATED Not Started Goto
# ____________________
# ____________________4/4
# ____________________Nicaragua,  Primera Division  #396 - 2023
# ____________________2023-09-02 23:00:00+00:00 // UTC // 1119548
# __________________________aoN_football_odds_insert_rows()
# __________________________football_odds INSERTED
# ______________________aoN_football_statistics_check()
# ____________________________aoN_football_leagues_check()
# ____________________________ select  bookmakersapi_id FROM football_leagues   where leagueapi_id = '396'
# ______________________________Total Row(s) : 1
# ____________________________get_today_adds()
# ______________________________adds date_diff : 0
# ______________________________today_raw : 2023-09-03 08:54:08.955008
# ____________________________afN_controll_match_update()
# ______________________________aa_check_acccount()
# ________________________________API hariyant2410@gmail.com counter is 5
# ________________________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
# ______________________________aa_check_acccount()
# ______________________________aa_update_counter()
# ______________________________afN_response_fixtures()
# ________________________________fixtureapi_id : 1119548
# ________________________________fixture_updated_at : 2023-09-03 08:54:08.955008
# ________________________________ROUTES : fixtureapi_id_INSERT
# __________________________________Total API Response(s) : 1
# ____________________________________
# ____________________________________ [1/1] fixture_status: Match Finished __ 396 __ 2023-09-02 23:00:00+00:00
# ________________________________________football_venues INSERTED
# ________________________________________football_teams UPDATED
# ________________________________________football_teams UPDATED
# ____________________________________football_fixtures INSERTED
# ________________________________Kurang 2023-09-03 06:00:00 < 2023-09-03 08:53:35
# ______________________PREP_check_date is not valid
# ______________________STOP RESPONSE
#   ___________________________________________________
# # -------------------------------------------------- End at 2023-09-03 08:54:10

# %%
# Import
from a_settings.messages import *  
from a_models.date import *  
from a_models.xpattern_new_auto import *  
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------      
    xpNa_set_pattern('pre_', 4, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:54:10
#   __main()
#   ____xpNa_set_pattern()
#   ____Total Row(s) : 127
#   ____
#   ____ [1/127]
#   ____  > fixtureapi_id = 1041215
#   ____  __> pre_ah_pattern = -075H
#   ____  __> pre_ah_pattern_mirror = +075H
#   ____  __> pre_gou_pattern = G
#   ____
#   ____  __> pre_ah_pattern_4 = -075H
#   ____  __> pre_ah_pattern_mirror_4 = +075H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [2/127]
#   ____  > fixtureapi_id = 1119546
#   ____  __> pre_ah_pattern = -125-1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1+125H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1+125H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [3/127]
#   ____  > fixtureapi_id = 981153
#   ____  __> pre_ah_pattern = -05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [4/127]
#   ____  > fixtureapi_id = 981155
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [5/127]
#   ____  > fixtureapi_id = 995615
#   ____  __> pre_ah_pattern = -075-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+075H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [6/127]
#   ____  > fixtureapi_id = 995616
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [7/127]
#   ____  > fixtureapi_id = 981156
#   ____  __> pre_ah_pattern = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [8/127]
#   ____  > fixtureapi_id = 995613
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [9/127]
#   ____  > fixtureapi_id = 995614
#   ____  __> pre_ah_pattern = -125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [10/127]
#   ____  > fixtureapi_id = 981157
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [11/127]
#   ____  > fixtureapi_id = 995610
#   ____  __> pre_ah_pattern = +0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [12/127]
#   ____  > fixtureapi_id = 995611
#   ____  __> pre_ah_pattern = -1-075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075+1H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075+1H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [13/127]
#   ____  > fixtureapi_id = 983004
#   ____  __> pre_ah_pattern = +025+05+075+1H
#   ____  __> pre_ah_pattern_mirror = -1-075-05-025H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075+1H
#   ____  __> pre_ah_pattern_mirror_4 = -1-075-05-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [14/127]
#   ____  > fixtureapi_id = 1107804
#   ____  __> pre_ah_pattern = -25-225-2-175-15-125H
#   ____  __> pre_ah_pattern_mirror = +125+15+175+2+225+25H
#   ____  __> pre_gou_pattern = 325g35g375g40g425g45gG
#   ____
#   ____  __> pre_ah_pattern_4 = -25-225-2-175-15-125H
#   ____  __> pre_ah_pattern_mirror_4 = +125+15+175+2+225+25H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425g45gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [15/127]
#   ____  > fixtureapi_id = 983009
#   ____  __> pre_ah_pattern = -125-1-075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075+1+125H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075+1+125H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [16/127]
#   ____  > fixtureapi_id = 1093474
#   ____  __> pre_ah_pattern = +075+1+125+15H
#   ____  __> pre_ah_pattern_mirror = -15-125-1-075H
#   ____  __> pre_gou_pattern = 35g375g40g425g45g475gG
#   ____
#   ____  __> pre_ah_pattern_4 = +075+1+125+15H
#   ____  __> pre_ah_pattern_mirror_4 = -15-125-1-075H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425g45g475gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [17/127]
#   ____  > fixtureapi_id = 983010
#   ____  __> pre_ah_pattern = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0+025H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0+025H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [18/127]
#   ____  > fixtureapi_id = 1107870
#   ____  __> pre_ah_pattern = +0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0H
#   ____  __> pre_gou_pattern = 325g35g375g40g425gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [19/127]
#   ____  > fixtureapi_id = 995606
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [20/127]
#   ____  > fixtureapi_id = 1030041
#   ____  __> pre_ah_pattern = +0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025+0H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [21/127]
#   ____  > fixtureapi_id = 1030048
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [22/127]
#   ____  > fixtureapi_id = 1042918
#   ____  __> pre_ah_pattern = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [23/127]
#   ____  > fixtureapi_id = 1042919
#   ____  __> pre_ah_pattern = -175-15-125-1H
#   ____  __> pre_ah_pattern_mirror = +1+125+15+175H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1H
#   ____  __> pre_ah_pattern_mirror_4 = +1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [24/127]
#   ____  > fixtureapi_id = 1042921
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [25/127]
#   ____  > fixtureapi_id = 1042922
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [26/127]
#   ____  > fixtureapi_id = 1053862
#   ____  __> pre_ah_pattern = +0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0+025H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [27/127]
#   ____  > fixtureapi_id = 1054511
#   ____  __> pre_ah_pattern = -1H
#   ____  __> pre_ah_pattern_mirror = +1H
#   ____  __> pre_gou_pattern = G
#   ____
#   ____  __> pre_ah_pattern_4 = -1H
#   ____  __> pre_ah_pattern_mirror_4 = +1H
#   ____  __> pre_gou_pattern_4 = G
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [28/127]
#   ____  > fixtureapi_id = 1062342
#   ____  __> pre_ah_pattern = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [29/127]
#   ____  > fixtureapi_id = 1062343
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [30/127]
#   ____  > fixtureapi_id = 1073960
#   ____  __> pre_ah_pattern = +0+025+05H
#   ____  __> pre_ah_pattern_mirror = -05-025+0H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05H
#   ____  __> pre_ah_pattern_mirror_4 = -05-025+0H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [31/127]
#   ____  > fixtureapi_id = 1073968
#   ____  __> pre_ah_pattern = +0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [32/127]
#   ____  > fixtureapi_id = 1073961
#   ____  __> pre_ah_pattern = +025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [33/127]
#   ____  > fixtureapi_id = 1073962
#   ____  __> pre_ah_pattern = +05+075+1+125H
#   ____  __> pre_ah_pattern_mirror = -125-1-075-05H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +05+075+1+125H
#   ____  __> pre_ah_pattern_mirror_4 = -125-1-075-05H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [34/127]
#   ____  > fixtureapi_id = 1073966
#   ____  __> pre_ah_pattern = -075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [35/127]
#   ____  > fixtureapi_id = 1073963
#   ____  __> pre_ah_pattern = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05+075H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [36/127]
#   ____  > fixtureapi_id = 1085279
#   ____  __> pre_ah_pattern = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [37/127]
#   ____  > fixtureapi_id = 1052700
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [38/127]
#   ____  > fixtureapi_id = 1085281
#   ____  __> pre_ah_pattern = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [39/127]
#   ____  > fixtureapi_id = 1090148
#   ____  __> pre_ah_pattern = -025+0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0+025H
#   ____  __> pre_gou_pattern = 325g35g375g40g425g45gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0+025H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425g45gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [40/127]
#   ____  > fixtureapi_id = 1085284
#   ____  __> pre_ah_pattern = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [41/127]
#   ____  > fixtureapi_id = 1090147
#   ____  __> pre_ah_pattern = +125+15+175+2+225+25H
#   ____  __> pre_ah_pattern_mirror = -25-225-2-175-15-125H
#   ____  __> pre_gou_pattern = 35g375g40g425g45g475gG
#   ____
#   ____  __> pre_ah_pattern_4 = +125+15+175+2+225+25H
#   ____  __> pre_ah_pattern_mirror_4 = -25-225-2-175-15-125H
#   ____  __> pre_gou_pattern_4 = 35g375g40g425g45g475g50gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [42/127]
#   ____  > fixtureapi_id = 1085285
#   ____  __> pre_ah_pattern = -075-05-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+05+075H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [43/127]
#   ____  > fixtureapi_id = 1093475
#   ____  __> pre_ah_pattern = +075+1+125+15H
#   ____  __> pre_ah_pattern_mirror = -15-125-1-075H
#   ____  __> pre_gou_pattern = 325g35g375g40g425g45gG
#   ____
#   ____  __> pre_ah_pattern_4 = +075+1+125+15H
#   ____  __> pre_ah_pattern_mirror_4 = -15-125-1-075H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425g45gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [44/127]
#   ____  > fixtureapi_id = 1089847
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [45/127]
#   ____  > fixtureapi_id = 1090389
#   ____  __> pre_ah_pattern = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025+0H
#   ____  __> pre_gou_pattern = 35g375g40g425g45g475gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025+0H
#   ____  __> pre_gou_pattern_4 = 35g375g40g425g45g475gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [46/127]
#   ____  > fixtureapi_id = 1090390
#   ____  __> pre_ah_pattern = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025+0H
#   ____  __> pre_gou_pattern = 35g375g40g425g45gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025+0H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425g45gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [47/127]
#   ____  > fixtureapi_id = 1090393
#   ____  __> pre_ah_pattern = -075-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+075H
#   ____  __> pre_gou_pattern = 275g30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+075H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [48/127]
#   ____  > fixtureapi_id = 1090394
#   ____  __> pre_ah_pattern = +075+1+125+15H
#   ____  __> pre_ah_pattern_mirror = -15-125-1-075H
#   ____  __> pre_gou_pattern = 35g375g40g425g45g475gG
#   ____
#   ____  __> pre_ah_pattern_4 = +075+1+125+15H
#   ____  __> pre_ah_pattern_mirror_4 = -15-125-1-075H
#   ____  __> pre_gou_pattern_4 = 35g375g40g425g45g475gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [49/127]
#   ____  > fixtureapi_id = 1096084
#   ____  __> pre_ah_pattern = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror = -075-05-025+0H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+05+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-05-025+0H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [50/127]
#   ____  > fixtureapi_id = 1096085
#   ____  __> pre_ah_pattern = -05-025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025+05H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+05+075H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [51/127]
#   ____  > fixtureapi_id = 1103204
#   ____  __> pre_ah_pattern = -275-25-225-2-175H
#   ____  __> pre_ah_pattern_mirror = +175+2+225+25+275H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -275-25-225-2-175H
#   ____  __> pre_ah_pattern_mirror_4 = +175+2+225+25+275H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [52/127]
#   ____  > fixtureapi_id = 1107087
#   ____  __> pre_ah_pattern = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____  __> pre_gou_pattern = 30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [53/127]
#   ____  > fixtureapi_id = 1119547
#   ____  __> pre_ah_pattern = +025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [54/127]
#   ____  > fixtureapi_id = 1030046
#   ____  __> pre_ah_pattern = +0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [55/127]
#   ____  > fixtureapi_id = 1042920
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [56/127]
#   ____  > fixtureapi_id = 995609
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [57/127]
#   ____  > fixtureapi_id = 1073965
#   ____  __> pre_ah_pattern = -075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [58/127]
#   ____  > fixtureapi_id = 1107803
#   ____  __> pre_ah_pattern = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____  __> pre_gou_pattern = 30g325g35g375g40g425gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [59/127]
#   ____  > fixtureapi_id = 1030047
#   ____  __> pre_ah_pattern = -125-1-075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075+1+125H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075+1+125H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [60/127]
#   ____  > fixtureapi_id = 1004190
#   ____  __> pre_ah_pattern = -125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1+125H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1+125H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [61/127]
#   ____  > fixtureapi_id = 1004191
#   ____  __> pre_ah_pattern = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075+1H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075+1H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [62/127]
#   ____  > fixtureapi_id = 1018936
#   ____  __> pre_ah_pattern = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [63/127]
#   ____  > fixtureapi_id = 981154
#   ____  __> pre_ah_pattern = -075-05-025H
#   ____  __> pre_ah_pattern_mirror = +025+05+075H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+05+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [64/127]
#   ____  > fixtureapi_id = 981160
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [65/127]
#   ____  > fixtureapi_id = 981158
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [66/127]
#   ____  > fixtureapi_id = 1004192
#   ____  __> pre_ah_pattern = -075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [67/127]
#   ____  > fixtureapi_id = 1041235
#   ____  __> pre_ah_pattern = +025+05+075+1+125H
#   ____  __> pre_ah_pattern_mirror = -125-1-075-05-025H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+05+075+1+125H
#   ____  __> pre_ah_pattern_mirror_4 = -125-1-075-05-025H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [68/127]
#   ____  > fixtureapi_id = 1119545
#   ____  __> pre_ah_pattern = -075-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+075H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [69/127]
#   ____  > fixtureapi_id = 981272
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [70/127]
#   ____  > fixtureapi_id = 981159
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [71/127]
#   ____  > fixtureapi_id = 981037
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [72/127]
#   ____  > fixtureapi_id = 1089352
#   ____  __> pre_ah_pattern = -075-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+075H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+075H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [73/127]
#   ____  > fixtureapi_id = 1089591
#   ____  __> pre_ah_pattern = +025+075+1+125H
#   ____  __> pre_ah_pattern_mirror = -125-1-075-025H
#   ____  __> pre_gou_pattern = 30g325g35g375g40g425gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075+1+125H
#   ____  __> pre_ah_pattern_mirror_4 = -125-1-075-025H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [74/127]
#   ____  > fixtureapi_id = 1032005
#   ____  __> pre_ah_pattern = -35-325-3-275-25-225H
#   ____  __> pre_ah_pattern_mirror = +225+25+275+3+325+35H
#   ____  __> pre_gou_pattern = 375g40g425g45g475g50gG
#   ____
#   ____  __> pre_ah_pattern_4 = -35-325-3-275-25-225H
#   ____  __> pre_ah_pattern_mirror_4 = +225+25+275+3+325+35H
#   ____  __> pre_gou_pattern_4 = 375g40g425g45g475g50gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [75/127]
#   ____  > fixtureapi_id = 1049202
#   ____  __> pre_ah_pattern = +0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0H
#   ____  __> pre_gou_pattern = 225g25g275g30g325gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30g325gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [76/127]
#   ____  > fixtureapi_id = 1049203
#   ____  __> pre_ah_pattern = +075+1+125+15H
#   ____  __> pre_ah_pattern_mirror = -15-125-1-075H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = +075+1+125+15H
#   ____  __> pre_ah_pattern_mirror_4 = -15-125-1-075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [77/127]
#   ____  > fixtureapi_id = 1091056
#   ____  __> pre_ah_pattern = +025+075+1+125H
#   ____  __> pre_ah_pattern_mirror = -125-1-075-025H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075+1+125H
#   ____  __> pre_ah_pattern_mirror_4 = -125-1-075-025H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [78/127]
#   ____  > fixtureapi_id = 1091054
#   ____  __> pre_ah_pattern = -075-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+075H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+075H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [79/127]
#   ____  > fixtureapi_id = 1091058
#   ____  __> pre_ah_pattern = -1-075-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+075+1H
#   ____  __> pre_gou_pattern = 325g35g375g40g425gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+075+1H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [80/127]
#   ____  > fixtureapi_id = 1091605
#   ____  __> pre_ah_pattern = -125-1-075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075+1+125H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075+1+125H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [81/127]
#   ____  > fixtureapi_id = 1091604
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [82/127]
#   ____  > fixtureapi_id = 1091606
#   ____  __> pre_ah_pattern = -025+0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0+025H
#   ____  __> pre_gou_pattern = 275g30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0+025H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [83/127]
#   ____  > fixtureapi_id = 1091607
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [84/127]
#   ____  > fixtureapi_id = 1091601
#   ____  __> pre_ah_pattern = -075-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+075H
#   ____  __> pre_gou_pattern = 30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+075H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [85/127]
#   ____  > fixtureapi_id = 1092227
#   ____  __> pre_ah_pattern = +0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0H
#   ____  __> pre_gou_pattern = 325g35g375g40g425gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [86/127]
#   ____  > fixtureapi_id = 1092223
#   ____  __> pre_ah_pattern = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15+175H
#   ____  __> pre_gou_pattern = 325g35g375g40g425g45gG
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15+175H
#   ____  __> pre_gou_pattern_4 = 325g35g375g40g425g45gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [87/127]
#   ____  > fixtureapi_id = 1092229
#   ____  __> pre_ah_pattern = -125-1-075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075+1+125H
#   ____  __> pre_gou_pattern = 25g275g30g325g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075+1+125H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [88/127]
#   ____  > fixtureapi_id = 1089848
#   ____  __> pre_ah_pattern = +025+075+1+125H
#   ____  __> pre_ah_pattern_mirror = -125-1-075-025H
#   ____  __> pre_gou_pattern = 30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075+1+125H
#   ____  __> pre_ah_pattern_mirror_4 = -125-1-075-025H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [89/127]
#   ____  > fixtureapi_id = 1091297
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025+075H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [90/127]
#   ____  > fixtureapi_id = 1091302
#   ____  __> pre_ah_pattern = +075+1+125+15H
#   ____  __> pre_ah_pattern_mirror = -15-125-1-075H
#   ____  __> pre_gou_pattern = 30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075+1+125+15H
#   ____  __> pre_ah_pattern_mirror_4 = -15-125-1-075-025H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [91/127]
#   ____  > fixtureapi_id = 1091300
#   ____  __> pre_ah_pattern = +0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0H
#   ____  __> pre_gou_pattern = 30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [92/127]
#   ____  > fixtureapi_id = 1091298
#   ____  __> pre_ah_pattern = +025+075+1+125H
#   ____  __> pre_ah_pattern_mirror = -125-1-075-025H
#   ____  __> pre_gou_pattern = 30g325g35g375g40gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075+1+125H
#   ____  __> pre_ah_pattern_mirror_4 = -125-1-075-025H
#   ____  __> pre_gou_pattern_4 = 30g325g35g375g40gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [93/127]
#   ____  > fixtureapi_id = 1090726
#   ____  __> pre_ah_pattern = +025+075+1+125+15H
#   ____  __> pre_ah_pattern_mirror = -15-125-1-075-025H
#   ____  __> pre_gou_pattern = 275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075+1+125+15H
#   ____  __> pre_ah_pattern_mirror_4 = -15-125-1-075-025H
#   ____  __> pre_gou_pattern_4 = 275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [94/127]
#   ____  > fixtureapi_id = 1090724
#   ____  __> pre_ah_pattern = +0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0H
#   ____  __> pre_gou_pattern = 25g275g30g325g35g375gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> pre_gou_pattern_4 = 25g275g30g325g35g375gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [95/127]
#   ____  > fixtureapi_id = 1032717
#   ____  __> pre_ah_pattern = -1-075-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+075+1H
#   ____  __> pre_gou_pattern = 35g375g40g425g45g475gG
#   ____
#   ____  __> pre_ah_pattern_4 = -1-075-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+075+1H
#   ____  __> pre_gou_pattern_4 = 35g375g40g425g45g475gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [96/127]
#   ____  > fixtureapi_id = 1054506
#   ____  __> pre_ah_pattern = -075-05H
#   ____  __> pre_ah_pattern_mirror = +05+075H
#   ____  __> pre_gou_pattern = G
#   ____
#   ____  __> pre_ah_pattern_4 = -075-05H
#   ____  __> pre_ah_pattern_mirror_4 = +05+075H
#   ____  __> pre_gou_pattern_4 = G
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [97/127]
#   ____  > fixtureapi_id = 1054618
#   ____  __> pre_ah_pattern = -025H
#   ____  __> pre_ah_pattern_mirror = +025H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025H
#   ____  __> pre_ah_pattern_mirror_4 = +025H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [98/127]
#   ____  > fixtureapi_id = 1105880
#   ____  __> pre_ah_pattern = +025+075+1H
#   ____  __> pre_ah_pattern_mirror = -1-075-025H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075+1H
#   ____  __> pre_ah_pattern_mirror_4 = -1-075-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [99/127]
#   ____  > fixtureapi_id = 1105791
#   ____  __> pre_ah_pattern = -125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [100/127]
#   ____  > fixtureapi_id = 1105790
#   ____  __> pre_ah_pattern = +025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [101/127]
#   ____  > fixtureapi_id = 1105792
#   ____  __> pre_ah_pattern = +0+025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025+0H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = +0+025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025+0H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [102/127]
#   ____  > fixtureapi_id = 1106155
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [103/127]
#   ____  > fixtureapi_id = 1106156
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [104/127]
#   ____  > fixtureapi_id = 1106152
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 15g175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [105/127]
#   ____  > fixtureapi_id = 1106153
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [106/127]
#   ____  > fixtureapi_id = 1096086
#   ____  __> pre_ah_pattern = -025H
#   ____  __> pre_ah_pattern_mirror = +025H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025H
#   ____  __> pre_ah_pattern_mirror_4 = +025H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [107/127]
#   ____  > fixtureapi_id = 1096087
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [108/127]
#   ____  > fixtureapi_id = 1042923
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25g35gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [109/127]
#   ____  > fixtureapi_id = 1042924
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [110/127]
#   ____  > fixtureapi_id = 1042925
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25g35gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [111/127]
#   ____  > fixtureapi_id = 1043259
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [112/127]
#   ____  > fixtureapi_id = 1105973
#   ____  __> pre_ah_pattern = -075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [113/127]
#   ____  > fixtureapi_id = 1105974
#   ____  __> pre_ah_pattern = +025+075H
#   ____  __> pre_ah_pattern_mirror = -075-025H
#   ____  __> pre_gou_pattern = 225g25g275g30gG
#   ____
#   ____  __> pre_ah_pattern_4 = +025+075H
#   ____  __> pre_ah_pattern_mirror_4 = -075-025H
#   ____  __> pre_gou_pattern_4 = 225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [114/127]
#   ____  > fixtureapi_id = 1105972
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 15g175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [115/127]
#   ____  > fixtureapi_id = 1105968
#   ____  __> pre_ah_pattern = +075+1+125H
#   ____  __> pre_ah_pattern_mirror = -125-1-075H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = +075+1+125H
#   ____  __> pre_ah_pattern_mirror_4 = -125-1-075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [116/127]
#   ____  > fixtureapi_id = 1105969
#   ____  __> pre_ah_pattern = -125-1-075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075+1+125H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075+1+125H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [117/127]
#   ____  > fixtureapi_id = 1105970
#   ____  __> pre_ah_pattern = -075-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+075H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [118/127]
#   ____  > fixtureapi_id = 1106336
#   ____  __> pre_ah_pattern = -025+0+025H
#   ____  __> pre_ah_pattern_mirror = -025+0+025H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -025+0+025H
#   ____  __> pre_ah_pattern_mirror_4 = -025+0+025H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [119/127]
#   ____  > fixtureapi_id = 1106335
#   ____  __> pre_ah_pattern = -075-025+0H
#   ____  __> pre_ah_pattern_mirror = +0+025+075H
#   ____  __> pre_gou_pattern = 175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025+0H
#   ____  __> pre_ah_pattern_mirror_4 = +0+025+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [120/127]
#   ____  > fixtureapi_id = 1106338
#   ____  __> pre_ah_pattern = -075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [121/127]
#   ____  > fixtureapi_id = 1106337
#   ____  __> pre_ah_pattern = -075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [122/127]
#   ____  > fixtureapi_id = 1073969
#   ____  __> pre_ah_pattern = -075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075H
#   ____  __> pre_gou_pattern = 175g20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075H
#   ____  __> pre_gou_pattern_4 = 175g20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [123/127]
#   ____  > fixtureapi_id = 1074131
#   ____  __> pre_ah_pattern = -075-025H
#   ____  __> pre_ah_pattern_mirror = +025+075H
#   ____  __> pre_gou_pattern = 15g175g20g225g25gG
#   ____
#   ____  __> pre_ah_pattern_4 = -075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075H
#   ____  __> pre_gou_pattern_4 = 15g175g20g225g25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [124/127]
#   ____  > fixtureapi_id = 1074132
#   ____  __> pre_ah_pattern = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125+15H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -15-125-1-075H
#   ____  __> pre_ah_pattern_mirror_4 = +075+1+125+15H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [125/127]
#   ____  > fixtureapi_id = 1074133
#   ____  __> pre_ah_pattern = -125-1-075H
#   ____  __> pre_ah_pattern_mirror = +075+1+125H
#   ____  __> pre_gou_pattern = 20g225g25g275gG
#   ____
#   ____  __> pre_ah_pattern_4 = -125-1-075-025H
#   ____  __> pre_ah_pattern_mirror_4 = +025+075+1+125H
#   ____  __> pre_gou_pattern_4 = 20g225g25g275g30gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [126/127]
#   ____  > fixtureapi_id = 1041234
#   ____  __> pre_ah_pattern = -175-15H
#   ____  __> pre_ah_pattern_mirror = +15+175H
#   ____  __> pre_gou_pattern = G
#   ____
#   ____  __> pre_ah_pattern_4 = -175-15H
#   ____  __> pre_ah_pattern_mirror_4 = +15+175H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
#   ____
#   ____ [127/127]
#   ____  > fixtureapi_id = 1041233
#   ____  __> pre_ah_pattern = H
#   ____  __> pre_ah_pattern_mirror = H
#   ____  __> pre_gou_pattern = 25gG
#   ____
#   ____  __> pre_ah_pattern_4 = H
#   ____  __> pre_ah_pattern_mirror_4 = H
#   ____  __> pre_gou_pattern_4 = 25gG
#   ____
#   ____  ____> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-09-03 08:57:05

# %%
""" 
    Check Predates
"""

# Import
from a_settings.messages import *  
from a_models.date import *   
from a_models.football_odds import *   
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_adds(1, space).strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    fo_controll_predates(day1, day2, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:57:05
#   __main()
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-09-03 08:57:05.430400
#   ____get_today_adds()
#   ______adds date_diff : 1
#   ______today_raw : 2023-09-04 08:57:05.430400
#   ____fo_controll_predates()
#   ______Select  DATE(date) as date_FX  , DATE(pre_odd_updated_at) as date_pre   , count(*) as counter   , fixture_status   from football_odds  where DATE(date) >= '2023-09-03'  and DATE(date) <= '2023-09-04'  group by DATE(pre_odd_updated_at), fixture_status  order by DATE(date) desc
#   ______Total Row(s) : 6
#
#       date_FX    date_pre  counter    fixture_status
# 0  2023-09-03  2023-09-03      293  Not Started Goto
# 1  2023-09-03        None       14              None
# 2  2023-09-03  2023-09-02      243  Not Started Goto
# 3  2023-09-03  2023-08-30        3  Not Started Goto
# 4  2023-09-03  2023-09-01        1  Not Started Goto
# 5  2023-09-03  2023-08-27        1  Not Started Goto
#
# # -------------------------------------------------- End at 2023-09-03 08:57:06

# %%
# Import  

from a_settings.messages import *  
from a_models.date import *   
from a_models.standings import *   
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_adds(1, space).strftime("%Y-%m-%d")  
    # --------------------------------------------------   
    s_league_group(day1, day2, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:57:06
#   __main()
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-09-03 08:57:06.417454
#   ____get_today_adds()
#   ______adds date_diff : 1
#   ______today_raw : 2023-09-04 08:57:06.417454
#   ____s_league_group()
# # -------------------------------------------------- End at 2023-09-03 08:57:06

# %%
# Import  

from a_settings.messages import *  
from a_models.date import *   
from a_models.team_reports import *   
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    day1         = get_today_adds(0, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day2         = get_today_adds(1, space).strftime("%Y-%m-%d")  
    # --------------------------------------------------   
    tr_delete_duplicate(space)
    tr_league_group_league_standings(day1, day2, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:57:06
#   __main()
#   ____get_today_adds()
#   ______adds date_diff : 0
#   ______today_raw : 2023-09-03 08:57:06.464356
#   ____get_today_adds()
#   ______adds date_diff : 1
#   ______today_raw : 2023-09-04 08:57:06.464356
#   ____tr_delete_duplicate()
#   ______DELETE t1 FROM api_football_team_reports  t1 INNER JOIN api_football_team_reports  t2 WHERE t1.id < t2.id AND t1.leagueapi_id = t2.leagueapi_id AND t1.season = t2.season AND t1.fixtureapi_id = t2.fixtureapi_id AND t1.teamapi_id  = t2.teamapi_id
#   ____tr_league_group_league_standings()
#   ____Select  leagueapi_id  , DATE(league_standing_updated_at)  from football_leagues  where DATE(league_standing_updated_at) >= DATE('2023-09-03')  and DATE(league_standing_updated_at) <= DATE('2023-09-04')  order by leagueapi_id asc
#   ____Total Row(s) : 0
# # -------------------------------------------------- End at 2023-09-03 08:57:17

# %%
# Import 
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *   
from a_models.research_on_anytime_goal_scorers import *    
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------       
    today           = get_today_adds(0, space) 
    # --------------------------------------------------     
    tommorow        = get_today_adds(1, space) 
    # -------------------------------------------------- 
    roags_today(today, tommorow, space) 
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-09-03 08:57:17
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-09-03 08:57:17.262344
#   ______get_today_adds()
#   ________adds date_diff : 1
#   ________today_raw : 2023-09-04 08:57:17.262344
#   ______roags_today()
#   ________Select  leagueapi_id  , season   , fixtureapi_id   from football_fixtures  where Date(date) >= Date('2023-09-03 08:57:17.262344')   and Date(date) <= Date('2023-09-04 08:57:17.262344')  and research_on_anytime_goal_scorers_updated_at is null  order by date desc
#   __________Total Row(s) : 969
#   ____________[1/969]  #239 - 2023 __ 990389
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '239'  and season = '2023'  and fixtureapi_id = '990389'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[2/969]  #252 - 2023 __ 1042766
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '252'  and season = '2023'  and fixtureapi_id = '1042766'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[3/969]  #617 - 2023 __ 1119669
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '617'  and season = '2023'  and fixtureapi_id = '1119669'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[4/969]  #673 - 2023 __ 1041236
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '673'  and season = '2023'  and fixtureapi_id = '1041236'
#   __________________Total Row(s) : 0
#   ____________[5/969]  #1032 - 2023 __ 971216
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '1032'  and season = '2023'  and fixtureapi_id = '971216'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[6/969]  #129 - 2023 __ 1027676
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '129'  and season = '2023'  and fixtureapi_id = '1027676'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[7/969]  #266 - 2023 __ 987932
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '266'  and season = '2023'  and fixtureapi_id = '987932'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[8/969]  #240 - 2023 __ 1028064
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id =
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '777'  and season = '2023'  and fixtureapi_id = '1032552'
#   __________________Total Row(s) : 0
#   ____________[37/969]  #777 - 2023 __ 1032551
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '777'  and season = '2023'  and fixtureapi_id = '1032551'
#   __________________Total Row(s) : 0
#   ____________[38/969]  #777 - 2023 __ 1032554
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '777'  and season = '2023'  and fixtureapi_id = '1032554'
#   __________________Total Row(s) : 0
#   ____________[39/969]  #473 - 2023 __ 980219
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '473'  and season = '2023'  and fixtureapi_id = '980219'
#   __________________Total Row(s) : 0
#   ____________[40/969]  #383 - 2023 __ 1037005
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '383'  and season = '2023'  and fixtureapi_id = '1037005'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[41/969]  #778 - 2023 __ 1032718
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '778'  and season = '2023'  and fixtureapi_id = '1032718'
#   __________________Total Row(s) : 0
#   ____________[42/969]  #236 - 2023 __ 1092787
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '236'  and season = '2023'  and fixtureapi_id = '1092787'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[43/969]  #109 - 2023 __ 1038753
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '109'  and season = '2023'  and fixtureapi_id = '1038753'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[44/969]  #549 - 2023 __ 988295
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '549'  and season = '2023'  and fixtureapi_id = '988295'
#   __________________Total Row(s) : 0
#   ____________[45/969]  #473 - 2023 __ 980217
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '473'  and season = '2023'  and fixtureapi_id = '980217'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[46/969]  #775 - 2023 __ 1032189
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '775'  and season = '2023'  and fixtureapi_id = '1032189'
#   __________________Total Row(s) : 0
#   ____________[47/969]  #777 - 2023 __ 1032550
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '777'  and season = '2023'  and fixtureapi_id = '1032550'
#   __________________Total Row(s) : 0
#   ____________[48/969]  #283 - 2023 __ 1049821
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '283'  and season = '2023'  and fixtureapi_id = '1049821'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[49/969]  #374 - 2023 __ 1041792
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '374'  and season = '2023'  and fixtureapi_id = '1041792'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[50/969]  #779 - 2023 __ 1032917
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '779'  and season = '2023'  and fixtureapi_id = '1032917'
#   __________________Total Row(s) : 0
#   ____________[51/969]  #473 - 2023 __ 980218
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '473'  and season = '2023'  and fixtureapi_id = '980218'
#   __________________Total Row(s) : 0
#   ____________[52/969]  #236 - 2023 __ 1092793
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '236'  and season = '2023'  and fixtureapi_id = '1092793'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[53/969]  #173 - 2023 __ 1039176
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '173'  and season = '2023'  and fixtureapi_id = '1039176'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[54/969]  #775 - 2023 __ 1032188
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '775'  and season = '2023'  and fixtureapi_id = '1032188'
#   __________________Total Row(s) : 0
#   ____________[55/969]  #278 - 2023 __ 997550
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '278'  and season = '2023'  and fixtureapi_id = '997550'
#   __________________Total Row(s) : 0
#   ____________[56/969]  #673 - 2023 __ 1041235
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '673'  and season = '2023'  and fixtureapi_id = '1041235'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[57/969]  #909 - 2023 __ 1015548
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '909'  and season = '2023'  and fixtureapi_id = '1015548'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[58/969]  #253 - 2023 __ 981154
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '253'  and season = '2023'  and fixtureapi_id = '981154'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________Denis Bouanga - 1.91
#   ________________________roags_insert_or_update()
#   ________________________INSERT INTO `research_on_anytime_goal_scorers`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  253,  '2023',  '981154',  'Denis Bouanga',  '1.91',  current_timestamp )
#   ______________________Lionel Messi - 1.83
#   ________________________roags_insert_or_update()
#   ________________________INSERT INTO `research_on_anytime_goal_scorers`(  `leagueapi_id`,  `season`,  `fixtureapi_id`,  `value`,  `pre_odd`,  `created_at`  ) VALUES (  253,  '2023',  '981154',  'Lionel Messi',  '1.83',  current_timestamp )
#   ______________________roags_array()
#   ____________[59/969]  #909 - 2023 __ 1015549
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '909'  and season = '2023'  and fixtureapi_id = '1015549'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[60/969]  #339 - 2023 __ 1035228
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '339'  and season = '2023'  and fixtureapi_id = '1035228'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '222'  and season = '2023'  and fixtureapi_id = '1053389'
#   __________________Total Row(s) : 0
#   ____________[926/969]  #222 - 2023 __ 1053390
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '222'  and season = '2023'  and fixtureapi_id = '1053390'
#   __________________Total Row(s) : 0
#   ____________[927/969]  #436 - 2023 __ 1084190
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '436'  and season = '2023'  and fixtureapi_id = '1084190'
#   __________________Total Row(s) : 0
#   ____________[928/969]  #236 - 2023 __ 1092789
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '236'  and season = '2023'  and fixtureapi_id = '1092789'
#   __________________Total Row(s) : 0
#   ____________[929/969]  #435 - 2023 __ 1083811
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '435'  and season = '2023'  and fixtureapi_id = '1083811'
#   __________________Total Row(s) : 0
#   ____________[930/969]  #239 - 2023 __ 990388
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '239'  and season = '2023'  and fixtureapi_id = '990388'
#   __________________Total Row(s) : 0
#   ____________[931/969]  #239 - 2023 __ 990396
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '239'  and season = '2023'  and fixtureapi_id = '990396'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[932/969]  #242 - 2023 __ 996132
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '242'  and season = '2023'  and fixtureapi_id = '996132'
#   __________________Total Row(s) : 0
#   ____________[933/969]  #266 - 2023 __ 987935
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '266'  and season = '2023'  and fixtureapi_id = '987935'
#   __________________Total Row(s) : 0
#   ____________[934/969]  #875 - 2023 __ 1087179
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '875'  and season = '2023'  and fixtureapi_id = '1087179'
#   __________________Total Row(s) : 0
#   ____________[935/969]  #222 - 2023 __ 1053387
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '222'  and season = '2023'  and fixtureapi_id = '1053387'
#   __________________Total Row(s) : 0
#   ____________[936/969]  #222 - 2023 __ 1053385
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '222'  and season = '2023'  and fixtureapi_id = '1053385'
#   __________________Total Row(s) : 0
#   ____________[937/969]  #134 - 2023 __ 1010292
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '134'  and season = '2023'  and fixtureapi_id = '1010292'
#   __________________Total Row(s) : 0
#   ____________[938/969]  #877 - 2023 __ 1087787
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '877'  and season = '2023'  and fixtureapi_id = '1087787'
#   __________________Total Row(s) : 0
#   ____________[939/969]  #134 - 2023 __ 1010435
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '134'  and season = '2023'  and fixtureapi_id = '1010435'
#   __________________Total Row(s) : 0
#   ____________[940/969]  #877 - 2023 __ 1087783
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '877'  and season = '2023'  and fixtureapi_id = '1087783'
#   __________________Total Row(s) : 0
#   ____________[941/969]  #162 - 2023 __ 1035716
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '162'  and season = '2023'  and fixtureapi_id = '1035716'
#   __________________Total Row(s) : 0
#   ____________[942/969]  #162 - 2023 __ 1035717
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '162'  and season = '2023'  and fixtureapi_id = '1035717'
#   __________________Total Row(s) : 0
#   ____________[943/969]  #162 - 2023 __ 1035719
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '162'  and season = '2023'  and fixtureapi_id = '1035719'
#   __________________Total Row(s) : 0
#   ____________[944/969]  #875 - 2023 __ 1087184
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '875'  and season = '2023'  and fixtureapi_id = '1087184'
#   __________________Total Row(s) : 0
#   ____________[945/969]  #875 - 2023 __ 1087183
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '875'  and season = '2023'  and fixtureapi_id = '1087183'
#   __________________Total Row(s) : 0
#   ____________[946/969]  #266 - 2023 __ 987938
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '266'  and season = '2023'  and fixtureapi_id = '987938'
#   __________________Total Row(s) : 1
#   ______________________roags_array()
#   ______________________roags_array()
#   ____________[947/969]  #134 - 2023 __ 1010495
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id = '134'  and season = '2023'  and fixtureapi_id = '1010495'
#   __________________Total Row(s) : 0
#   ____________[948/969]  #652 - 2023 __ 1071514
#   ______________roags_odds()
#   ________________Select  leagueapi_id  , season   , fixtureapi_id   , pre_anytime_goal_scorer   , end_anytime_goal_scorer   from football_odds  where leagueapi_id =