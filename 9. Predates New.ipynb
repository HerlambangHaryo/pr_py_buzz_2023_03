# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.api_odds import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    date_0         = get_today_adds(0, space).strftime("%Y-%m-%d") 
    date_raw       = get_today_adds(0, space) 
    # -------------------------------------------------- 
    DICT = {
        'date_0' : date_0,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 0,
        'date_raw' : date_raw,
    }
    # --------------------------------------------------  
    PREP_ = "pre_"
    # -------------------------------------------------- 
    ao_controll_match_update(DICT, PREP_, space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-30 17:10:22
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-07-30 17:10:22.536742
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-07-30 17:10:22.536742
#   ______ao_controll_match_update()
#   ________aa_check_acccount()
#   __________API hariyant2410@gmail.com counter is 71
#   __________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________ao_response_odds()
#   __________date_0 : 2023-07-30
#   __________page : 1
#   __________counter_loop : 0
#   __________date_diff : 0
#   __________date_raw : 2023-07-30 17:10:22.536742
#   ____________________________________________________________________________________
#   __________Total API Response(s) : 10
#
#   ____________1. Argentina,  Liga Profesional Argentina  #128 - 2023 / 971666
#   ____________fixt date 2023-07-30 20:30:00+00:00
#   ____________fix local 2023-07-31 03:30:00
#   ____________local dat 2023-07-30 17:10:22
#   ____________Lebih
#   ______________league_rLeagues_id : 128
#   ______________league_rLeagues_name : Liga Profesional Argentina
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________2. Argentina,  Liga Profesional Argentina  #128 - 2023 / 971667
#   ____________fixt date 2023-07-30 20:30:00+00:00
#   ____________fix local 2023-07-31 03:30:00
#   ____________local dat 2023-07-30 17:10:22
#   ____________Lebih
#   ______________league_rLeagues_id : 128
#   ______________league_rLeagues_name : Liga Profesional Argentina
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________3. Argentina,  Liga Profesional Argentina  #128 - 2023 / 971669
#   ____________fixt date 2023-07-30 18:00:00+00:00
#   ____________fix local 2023-07-31 01:00:00
#   ____________local dat 2023-07-30 17:10:22
#   ____________Lebih
#   ______________league_rLeagues_id : 128
#   ______________league_rLeagues_name : Liga Profesional Argentina
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________4. Argentina,  Liga Profesional Argentina  #128 - 2023 / 971670
#   ____________fixt date 2023-07-30 18:00:00+00:00
#   ____________fix local 2023-07-31 01:00:00
#   ____________local dat 2023-07-30 17:10:22
#   ____________Lebih
#   ______________league_rLeagues_id : 128
#   ______________league_rLeagues_name : Liga Profesional Argentina
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________5. Norway,  2. Division - Group 2  #474 - 2023 / 979996
#   ____________fixt date 2023-07-30 13:00:00+00:00
#   ____________fix local 2023-07-30 20:00:00
#   ____________local dat 2023-07-30 17:10:22
#   ____________Lebih
#   ______________league_rLeagues_id : 474
#   ______________league_rLeagues_name : 2. Division - Group 2
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________6. Norway,  2. Division - Group 2  #474 - 2023 / 979998
#   ____________fixt date 2023-07-30 13:00:00+00:00
#   ____________fix local 2023-07-30 20:00:00
#   ____________local dat 2023-07-30 17:10:22
#   ____________Lebih
#   ______________league_rLeagues_id : 474
#   ______________league_rLeagues_name : 2. Division - Group 2
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________7. Iceland,  Úrvalsdeild  #164 - 2023 / 981554
#   ____________fixt date 2023-07-30 16:00:00+00:00
#   ____________fix local 2023-07-30 23:00:00
#   ____________local dat 2023-07-30 17:10:22
#   ____________Lebih
#   ______________league_rLeagues_id : 164
#   ______________league_rLeagues_name : Úrvalsdeild
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________8. Iceland,  Úrvalsdeild  #164 - 2023 / 981555
#   ____________fixt date 2023-07-30 17:00:00+00:00
#   ____________fix local 2023-07-31 00:00:00
#   ____________local dat 2023-07-30 17:10:22
#   ____________Lebih
#   ______________league_rLeagues_id : 164
#   ______________league_rLeagues_name : Úrvalsdeild
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________9. Australia,  New South Wales NPL  #192 - 2023 / 982444
#   ____________fixt date 2023-07-30 05:00:00+00:00
#   ____________fix local 2023-07-30 12:00:00
#   ____________local dat 2023-07-30 17:10:22
#   ____________Kurang
#   ____________good to Go 0
#
#   ____________10. Australia,  New South Wales NPL  #192 - 2023 / 982445
#   ____________fixt date 2023-07-30 05:00:00+00:00
#   ____________fix local 2023-07-30 12:00:00
#   ____________local dat 2023-07-30 17:10:22
#   ____________Kurang
#   ____________good to Go 0
#   ______________re_looping__
#   ____________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 69
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 2
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Sweden,  Ettan - Norra  #563 - 2023 / 982967
#   ________________fixt date 2023-07-30 15:00:00+00:00
#   ________________fix local 2023-07-30 22:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 563
#   __________________league_rLeagues_name : Ettan - Norra
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________2. Sweden,  Ettan - Norra  #563 - 2023 / 982970
#   ________________fixt date 2023-07-30 15:00:00+00:00
#   ________________fix local 2023-07-30 22:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 563
#   __________________league_rLeagues_name : Ettan - Norra
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________3. Sweden,  Ettan - Södra  #564 - 2023 / 983207
#   ________________fixt date 2023-07-30 14:00:00+00:00
#   ________________fix local 2023-07-30 21:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 564
#   __________________league_rLeagues_name : Ettan - Södra
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________4. Chile,  Primera División  #265 - 2023 / 983808
#   ________________fixt date 2023-07-30 00:00:00+00:00
#   ________________fix local 2023-07-30 07:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#   ________________5. Chile,  Primera División  #265 - 2023 / 983809
#   ________________fixt date 2023-07-30 19:00:00+00:00
#   ________________fix local 2023-07-31 02:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 265
#   __________________league_rLeagues_name : Primera División
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________6. Chile,  Primera División  #265 - 2023 / 983810
#   ________________fixt date 2023-07-30 16:30:00+00:00
#   ________________fix local 2023-07-30 23:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 265
#   __________________league_rLeagues_name : Primera División
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________7. Chile,  Primera División  #265 - 2023 / 983812
#   ________________fixt date 2023-07-30 21:30:00+00:00
#   ________________fix local 2023-07-31 04:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 265
#   __________________league_rLeagues_name : Primera División
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________8. Chile,  Primera B  #266 - 2023 / 987895
#   ________________fixt date 2023-07-30 00:30:00+00:00
#   ________________fix local 2023-07-30 07:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________9. Chile,  Primera B  #266 - 2023 / 987897
#   ________________fixt date 2023-07-30 19:00:00+00:00
#   ________________fix local 2023-07-31 02:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 266
#   __________________league_rLeagues_name : Primera B
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________10. Chile,  Primera B  #266 - 2023 / 987898
#   ________________fixt date 2023-07-30 16:30:00+00:00
#   ________________fix local 2023-07-30 23:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 266
#   __________________league_rLeagues_name : Primera B
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 68
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 3
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Australia,  Queensland NPL  #482 - 2023 / 988643
#   ________________fixt date 2023-07-30 07:30:00+00:00
#   ________________fix local 2023-07-30 14:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________2. Australia,  Queensland NPL  #482 - 2023 / 988644
#   ________________fixt date 2023-07-30 07:00:00+00:00
#   ________________fix local 2023-07-30 14:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________3. Australia,  Queensland NPL  #482 - 2023 / 988645
#   ________________fixt date 2023-07-30 08:00:00+00:00
#   ________________fix local 2023-07-30 15:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________4. Argentina,  Liga Profesional Argentina  #128 - 2023 / 988749
#   ________________fixt date 2023-07-30 23:00:00+00:00
#   ________________fix local 2023-07-31 06:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 128
#   __________________league_rLeagues_name : Liga Profesional Argentina
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________5. Colombia,  Primera A  #239 - 2023 / 990328
#   ________________fixt date 2023-07-30 01:20:00+00:00
#   ________________fix local 2023-07-30 08:20:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________6. Colombia,  Primera A  #239 - 2023 / 990333
#   ________________fixt date 2023-07-30 20:30:00+00:00
#   ________________fix local 2023-07-31 03:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 239
#   __________________league_rLeagues_name : Primera A
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________7. Colombia,  Primera A  #239 - 2023 / 990336
#   ________________fixt date 2023-07-30 22:45:00+00:00
#   ________________fix local 2023-07-31 05:45:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 239
#   __________________league_rLeagues_name : Primera A
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________8. Sweden,  Division 2 - Norra Götaland  #592 - 2023 / 993060
#   ________________fixt date 2023-07-30 11:00:00+00:00
#   ________________fix local 2023-07-30 18:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 592
#   __________________league_rLeagues_name : Division 2 - Norra Götaland
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________9. Sweden,  Division 2 - Norra Götaland  #592 - 2023 / 993061
#   ________________fixt date 2023-07-30 13:00:00+00:00
#   ________________fix local 2023-07-30 20:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 592
#   __________________league_rLeagues_name : Division 2 - Norra Götaland
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#
#   ________________10. Sweden,  Division 2 - Norra Svealand  #593 - 2023 / 993242
#   ________________fixt date 2023-07-30 14:00:00+00:00
#   ________________fix local 2023-07-30 21:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 593
#   __________________league_rLeagues_name : Division 2 - Norra Svealand
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 67
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 4
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Sweden,  Division 2 - Västra Götaland  #596 - 2023 / 993423
#   ________________fixt date 2023-07-30 11:00:00+00:00
#   ________________fix local 2023-07-30 18:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 596
#   __________________league_rLeagues_name : Division 2 - Västra Götaland
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________2. Sweden,  Division 2 - Norrland  #594 - 2023 / 993603
#   ________________fixt date 2023-07-30 13:00:00+00:00
#   ________________fix local 2023-07-30 20:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 594
#   __________________league_rLeagues_name : Division 2 - Norrland
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________3. Sweden,  Division 2 - Norrland  #594 - 2023 / 993606
#   ________________fixt date 2023-07-30 13:00:00+00:00
#   ________________fix local 2023-07-30 20:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 594
#   __________________league_rLeagues_name : Division 2 - Norrland
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#
#   ________________4. Sweden,  Division 2 - Östra Götaland  #597 - 2023 / 993787
#   ________________fixt date 2023-07-30 11:00:00+00:00
#   ________________fix local 2023-07-30 18:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 597
#   __________________league_rLeagues_name : Division 2 - Östra Götaland
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________5. Sweden,  Division 2 - Östra Götaland  #597 - 2023 / 993788
#   ________________fixt date 2023-07-30 17:00:00+00:00
#   ________________fix local 2023-07-31 00:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 597
#   __________________league_rLeagues_name : Division 2 - Östra Götaland
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________6. Japan,  J2 League  #99 - 2023 / 995213
#   ________________fixt date 2023-07-30 10:00:00+00:00
#   ________________fix local 2023-07-30 17:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________7. Japan,  J3 League  #100 - 2023 / 995556
#   ________________fixt date 2023-07-30 09:00:00+00:00
#   ________________fix local 2023-07-30 16:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________8. Japan,  J3 League  #100 - 2023 / 995557
#   ________________fixt date 2023-07-30 08:00:00+00:00
#   ________________fix local 2023-07-30 15:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________9. Finland,  Veikkausliiga  #244 - 2023 / 996474
#   ________________fixt date 2023-07-30 12:00:00+00:00
#   ________________fix local 2023-07-30 19:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 244
#   __________________league_rLeagues_name : Veikkausliiga
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________10. Finland,  Veikkausliiga  #244 - 2023 / 996475
#   ________________fixt date 2023-07-30 13:00:00+00:00
#   ________________fix local 2023-07-30 20:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 244
#   __________________league_rLeagues_name : Veikkausliiga
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 66
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 5
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Finland,  Veikkausliiga  #244 - 2023 / 996476
#   ________________fixt date 2023-07-30 13:00:00+00:00
#   ________________fix local 2023-07-30 20:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 244
#   __________________league_rLeagues_name : Veikkausliiga
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________2. Finland,  Veikkausliiga  #244 - 2023 / 996477
#   ________________fixt date 2023-07-30 15:30:00+00:00
#   ________________fix local 2023-07-30 22:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 244
#   __________________league_rLeagues_name : Veikkausliiga
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________3. South-Korea,  K League 2  #293 - 2023 / 997323
#   ________________fixt date 2023-07-30 10:00:00+00:00
#   ________________fix local 2023-07-30 17:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________4. South-Korea,  K League 2  #293 - 2023 / 997324
#   ________________fixt date 2023-07-30 10:30:00+00:00
#   ________________fix local 2023-07-30 17:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 293
#   __________________league_rLeagues_name : K League 2
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________5. Malaysia,  Super League  #278 - 2023 / 997541
#   ________________fixt date 2023-07-30 09:30:00+00:00
#   ________________fix local 2023-07-30 16:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________6. Malaysia,  Super League  #278 - 2023 / 997542
#   ________________fixt date 2023-07-30 13:00:00+00:00
#   ________________fix local 2023-07-30 20:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 278
#   __________________league_rLeagues_name : Super League
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________7. Canada,  Canadian Premier League  #479 - 2023 / 997817
#   ________________fixt date 2023-07-30 18:00:00+00:00
#   ________________fix local 2023-07-31 01:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 479
#   __________________league_rLeagues_name : Canadian Premier League
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________8. Venezuela,  Primera División  #299 - 2023 / 998188
#   ________________fixt date 2023-07-30 00:30:00+00:00
#   ________________fix local 2023-07-30 07:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________9. Finland,  Ykkönen  #245 - 2023 / 999047
#   ________________fixt date 2023-07-30 15:00:00+00:00
#   ________________fix local 2023-07-30 22:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 245
#   __________________league_rLeagues_name : Ykkönen
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________10. Finland,  Kakkonen - Lohko A  #247 - 2023 / 1000036
#   ________________fixt date 2023-07-30 17:00:00+00:00
#   ________________fix local 2023-07-31 00:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 247
#   __________________league_rLeagues_name : Kakkonen - Lohko A
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 65
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 6
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Finland,  Kakkonen - Lohko B  #248 - 2023 / 1000174
#   ________________fixt date 2023-07-30 15:00:00+00:00
#   ________________fix local 2023-07-30 22:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 248
#   __________________league_rLeagues_name : Kakkonen - Lohko B
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________2. Finland,  Kakkonen - Lohko C  #249 - 2023 / 1000300
#   ________________fixt date 2023-07-30 15:00:00+00:00
#   ________________fix local 2023-07-30 22:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 249
#   __________________league_rLeagues_name : Kakkonen - Lohko C
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________3. Bolivia,  Primera División  #344 - 2023 / 1001090
#   ________________fixt date 2023-07-30 19:00:00+00:00
#   ________________fix local 2023-07-31 02:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 344
#   __________________league_rLeagues_name : Primera División
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________4. Bolivia,  Primera División  #344 - 2023 / 1001091
#   ________________fixt date 2023-07-30 23:30:00+00:00
#   ________________fix local 2023-07-31 06:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 344
#   __________________league_rLeagues_name : Primera División
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________5. Bolivia,  Primera División  #344 - 2023 / 1001092
#   ________________fixt date 2023-07-30 00:00:00+00:00
#   ________________fix local 2023-07-30 07:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________6. Bolivia,  Primera División  #344 - 2023 / 1001095
#   ________________fixt date 2023-07-30 19:00:00+00:00
#   ________________fix local 2023-07-31 02:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 344
#   __________________league_rLeagues_name : Primera División
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________7. Norway,  Eliteserien  #103 - 2023 / 1001687
#   ________________fixt date 2023-07-30 15:00:00+00:00
#   ________________fix local 2023-07-30 22:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 103
#   __________________league_rLeagues_name : Eliteserien
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________8. Norway,  Eliteserien  #103 - 2023 / 1001688
#   ________________fixt date 2023-07-30 17:15:00+00:00
#   ________________fix local 2023-07-31 00:15:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 103
#   __________________league_rLeagues_name : Eliteserien
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________9. Norway,  Eliteserien  #103 - 2023 / 1001689
#   ________________fixt date 2023-07-30 15:00:00+00:00
#   ________________fix local 2023-07-30 22:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 103
#   __________________league_rLeagues_name : Eliteserien
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________10. Norway,  Eliteserien  #103 - 2023 / 1001690
#   ________________fixt date 2023-07-30 15:00:00+00:00
#   ________________fix local 2023-07-30 22:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 103
#   __________________league_rLeagues_name : Eliteserien
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 64
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 7
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Norway,  Eliteserien  #103 - 2023 / 1001691
#   ________________fixt date 2023-07-30 15:00:00+00:00
#   ________________fix local 2023-07-30 22:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 103
#   __________________league_rLeagues_name : Eliteserien
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________2. Norway,  Eliteserien  #103 - 2023 / 1001692
#   ________________fixt date 2023-07-30 15:00:00+00:00
#   ________________fix local 2023-07-30 22:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 103
#   __________________league_rLeagues_name : Eliteserien
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________3. Sweden,  Allsvenskan  #113 - 2023 / 1001935
#   ________________fixt date 2023-07-30 13:00:00+00:00
#   ________________fix local 2023-07-30 20:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 113
#   __________________league_rLeagues_name : Allsvenskan
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________4. Sweden,  Allsvenskan  #113 - 2023 / 1001936
#   ________________fixt date 2023-07-30 15:30:00+00:00
#   ________________fix local 2023-07-30 22:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 113
#   __________________league_rLeagues_name : Allsvenskan
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________5. Sweden,  Allsvenskan  #113 - 2023 / 1001941
#   ________________fixt date 2023-07-30 13:00:00+00:00
#   ________________fix local 2023-07-30 20:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 113
#   __________________league_rLeagues_name : Allsvenskan
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________6. Sweden,  Superettan  #114 - 2023 / 1002411
#   ________________fixt date 2023-07-30 11:00:00+00:00
#   ________________fix local 2023-07-30 18:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 114
#   __________________league_rLeagues_name : Superettan
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________7. Sweden,  Superettan  #114 - 2023 / 1002412
#   ________________fixt date 2023-07-30 13:00:00+00:00
#   ________________fix local 2023-07-30 20:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 114
#   __________________league_rLeagues_name : Superettan
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________8. USA,  NWSL Women - Challenge Cup  #641 - 2023 / 1004254
#   ________________fixt date 2023-07-30 00:00:00+00:00
#   ________________fix local 2023-07-30 07:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________9. USA,  NWSL Women - Challenge Cup  #641 - 2023 / 1004255
#   ________________fixt date 2023-07-30 00:30:00+00:00
#   ________________fix local 2023-07-30 07:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________10. USA,  NWSL Women - Challenge Cup  #641 - 2023 / 1004256
#   ________________fixt date 2023-07-30 02:00:00+00:00
#   ________________fix local 2023-07-30 09:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 63
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 8
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Argentina,  Primera D  #133 - 2023 / 1004293
#   ________________fixt date 2023-07-30 18:30:00+00:00
#   ________________fix local 2023-07-31 01:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 133
#   __________________league_rLeagues_name : Primera D
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________2. Brazil,  Serie A  #71 - 2023 / 1005810
#   ________________fixt date 2023-07-30 19:00:00+00:00
#   ________________fix local 2023-07-31 02:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 71
#   __________________league_rLeagues_name : Serie A
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________3. Brazil,  Serie A  #71 - 2023 / 1005811
#   ________________fixt date 2023-07-30 14:00:00+00:00
#   ________________fix local 2023-07-30 21:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 71
#   __________________league_rLeagues_name : Serie A
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________4. Brazil,  Serie A  #71 - 2023 / 1005813
#   ________________fixt date 2023-07-30 21:30:00+00:00
#   ________________fix local 2023-07-31 04:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 71
#   __________________league_rLeagues_name : Serie A
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________5. Brazil,  Serie A  #71 - 2023 / 1005814
#   ________________fixt date 2023-07-30 00:00:00+00:00
#   ________________fix local 2023-07-30 07:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________6. Brazil,  Serie A  #71 - 2023 / 1005818
#   ________________fixt date 2023-07-30 19:00:00+00:00
#   ________________fix local 2023-07-31 02:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 71
#   __________________league_rLeagues_name : Serie A
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________7. Chile,  Segunda División  #711 - 2023 / 1006151
#   ________________fixt date 2023-07-30 16:00:00+00:00
#   ________________fix local 2023-07-30 23:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 711
#   __________________league_rLeagues_name : Segunda División
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________8. Chile,  Segunda División  #711 - 2023 / 1006153
#   ________________fixt date 2023-07-30 19:00:00+00:00
#   ________________fix local 2023-07-31 02:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 711
#   __________________league_rLeagues_name : Segunda División
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________9. Chile,  Segunda División  #711 - 2023 / 1006155
#   ________________fixt date 2023-07-30 20:00:00+00:00
#   ________________fix local 2023-07-31 03:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 711
#   __________________league_rLeagues_name : Segunda División
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________10. Brazil,  Serie B  #72 - 2023 / 1006637
#   ________________fixt date 2023-07-30 21:00:00+00:00
#   ________________fix local 2023-07-31 04:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 72
#   __________________league_rLeagues_name : Serie B
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 62
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 9
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Brazil,  Serie B  #72 - 2023 / 1006641
#   ________________fixt date 2023-07-30 18:30:00+00:00
#   ________________fix local 2023-07-31 01:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 72
#   __________________league_rLeagues_name : Serie B
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________2. Brazil,  Serie B  #72 - 2023 / 1006645
#   ________________fixt date 2023-07-30 14:00:00+00:00
#   ________________fix local 2023-07-30 21:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 72
#   __________________league_rLeagues_name : Serie B
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________3. Kazakhstan,  Premier League  #389 - 2023 / 1006919
#   ________________fixt date 2023-07-30 12:00:00+00:00
#   ________________fix local 2023-07-30 19:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________11 1xBet = 25
#   ________________good to Go 0
#
#   ________________4. Kazakhstan,  Premier League  #389 - 2023 / 1006922
#   ________________fixt date 2023-07-30 14:00:00+00:00
#   ________________fix local 2023-07-30 21:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 21
#   ________________11 1xBet = 26
#   ________________good to Go 0
#
#   ________________5. Kazakhstan,  Premier League  #389 - 2023 / 1006924
#   ________________fixt date 2023-07-30 13:00:00+00:00
#   ________________fix local 2023-07-30 20:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 21
#   ________________11 1xBet = 26
#   ________________good to Go 0
#
#   ________________6. USA,  USL Championship  #255 - 2023 / 1008583
#   ________________fixt date 2023-07-30 00:00:00+00:00
#   ________________fix local 2023-07-30 07:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________7. USA,  USL Championship  #255 - 2023 / 1008584
# ...
#   ________________good to Go 1
#   ________________11==11
#
#   ________________4. Panama,  Liga Panameña de Fútbol  #304 - 2023 / 1062313
#   ________________fixt date 2023-07-30 23:15:00+00:00
#   ________________fix local 2023-07-31 06:15:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 304
#   __________________league_rLeagues_name : Liga Panameña de Fútbol
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________5. Dominican-Republic,  Liga Mayor  #759 - 2023 / 1062436
#   ________________fixt date 2023-07-30 22:00:00+00:00
#   ________________fix local 2023-07-31 05:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 13
#   ________________11 1xBet = 14
#   ________________good to Go 0
#
#   ________________6. Ukraine,  Premier League  #333 - 2023 / 1062534
#   ________________fixt date 2023-07-30 12:00:00+00:00
#   ________________fix local 2023-07-30 19:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 333
#   __________________league_rLeagues_name : Premier League
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________8==8
#
#   ________________7. Ukraine,  Premier League  #333 - 2023 / 1062536
#   ________________fixt date 2023-07-30 16:00:00+00:00
#   ________________fix local 2023-07-30 23:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 333
#   __________________league_rLeagues_name : Premier League
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________8==8
#
#   ________________8. Ukraine,  Premier League  #333 - 2023 / 1062538
#   ________________fixt date 2023-07-30 14:00:00+00:00
#   ________________fix local 2023-07-30 21:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 333
#   __________________league_rLeagues_name : Premier League
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________8==8
#
#   ________________9. Hungary,  NB III - Northwest  #635 - 2023 / 1072733
#   ________________fixt date 2023-07-30 09:00:00+00:00
#   ________________fix local 2023-07-30 16:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________10. Hungary,  NB III - Northwest  #635 - 2023 / 1072734
#   ________________fixt date 2023-07-30 15:30:00+00:00
#   ________________fix local 2023-07-30 22:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 13
#   ________________11 1xBet = 24
#   ________________good to Go 0
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 42
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 29
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Hungary,  NB III - Northwest  #635 - 2023 / 1072735
#   ________________fixt date 2023-07-30 15:30:00+00:00
#   ________________fix local 2023-07-30 22:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 17
#   ________________11 1xBet = 25
#   ________________good to Go 0
#
#   ________________2. Hungary,  NB III - Northwest  #635 - 2023 / 1072737
#   ________________fixt date 2023-07-30 09:00:00+00:00
#   ________________fix local 2023-07-30 16:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________3. Hungary,  NB III - Northeast  #633 - 2023 / 1072979
#   ________________fixt date 2023-07-30 09:00:00+00:00
#   ________________fix local 2023-07-30 16:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________4. Hungary,  NB III - Southeast  #1023 - 2023 / 1073216
#   ________________fixt date 2023-07-30 15:30:00+00:00
#   ________________fix local 2023-07-30 22:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 13
#   ________________11 1xBet = 24
#   ________________good to Go 0
#
#   ________________5. Hungary,  NB III - Southeast  #1023 - 2023 / 1073218
#   ________________fixt date 2023-07-30 15:30:00+00:00
#   ________________fix local 2023-07-30 22:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 17
#   ________________11 1xBet = 25
#   ________________good to Go 0
#
#   ________________6. Honduras,  Liga Nacional  #234 - 2023 / 1073833
#   ________________fixt date 2023-07-30 22:00:00+00:00
#   ________________fix local 2023-07-31 05:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 17
#   ________________11 1xBet = 25
#   ________________good to Go 0
#
#   ________________7. Brazil,  Gaúcho - 2  #478 - 2023 / 1081965
#   ________________fixt date 2023-07-30 18:00:00+00:00
#   ________________fix local 2023-07-31 01:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 4
#   ________________11 1xBet = 23
#   ________________good to Go 0
#
#   ________________8. Brazil,  Gaúcho - 2  #478 - 2023 / 1081967
#   ________________fixt date 2023-07-30 18:00:00+00:00
#   ________________fix local 2023-07-31 01:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 9
#   ________________11 1xBet = 23
#   ________________good to Go 0
#
#   ________________9. Brazil,  Gaúcho - 2  #478 - 2023 / 1081969
#   ________________fixt date 2023-07-30 18:00:00+00:00
#   ________________fix local 2023-07-31 01:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   ________________gak ready BM
#   ________________8 Bet365 = 11
#   ________________11 1xBet = 19
#   ________________good to Go 0
#
#   ________________10. Hungary,  NB II  #272 - 2023 / 1083484
#   ________________fixt date 2023-07-30 15:30:00+00:00
#   ________________fix local 2023-07-30 22:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 272
#   __________________league_rLeagues_name : NB II
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 41
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 30
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Hungary,  NB II  #272 - 2023 / 1083485
#   ________________fixt date 2023-07-30 15:30:00+00:00
#   ________________fix local 2023-07-30 22:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 272
#   __________________league_rLeagues_name : NB II
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________2. Hungary,  NB II  #272 - 2023 / 1083486
#   ________________fixt date 2023-07-30 15:30:00+00:00
#   ________________fix local 2023-07-30 22:30:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 272
#   __________________league_rLeagues_name : NB II
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________3. Hungary,  NB II  #272 - 2023 / 1083487
#   ________________fixt date 2023-07-30 17:00:00+00:00
#   ________________fix local 2023-07-31 00:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 272
#   __________________league_rLeagues_name : NB II
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________4. Hungary,  NB II  #272 - 2023 / 1083488
#   ________________fixt date 2023-07-30 17:00:00+00:00
#   ________________fix local 2023-07-31 00:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 272
#   __________________league_rLeagues_name : NB II
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________5. Hungary,  NB II  #272 - 2023 / 1083489
#   ________________fixt date 2023-07-30 17:00:00+00:00
#   ________________fix local 2023-07-31 00:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 272
#   __________________league_rLeagues_name : NB II
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________6. Hungary,  NB II  #272 - 2023 / 1083490
#   ________________fixt date 2023-07-30 17:00:00+00:00
#   ________________fix local 2023-07-31 00:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 272
#   __________________league_rLeagues_name : NB II
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________7. Hungary,  NB II  #272 - 2023 / 1083491
#   ________________fixt date 2023-07-30 17:00:00+00:00
#   ________________fix local 2023-07-31 00:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 272
#   __________________league_rLeagues_name : NB II
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________8. Hungary,  NB II  #272 - 2023 / 1083492
#   ________________fixt date 2023-07-30 17:00:00+00:00
#   ________________fix local 2023-07-31 00:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 272
#   __________________league_rLeagues_name : NB II
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________9. Germany,  Regionalliga - Nordost  #85 - 2023 / 1085239
#   ________________fixt date 2023-07-30 11:00:00+00:00
#   ________________fix local 2023-07-30 18:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 85
#   __________________league_rLeagues_name : Regionalliga - Nordost
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________8==8
#
#   ________________10. Germany,  Regionalliga - Nordost  #85 - 2023 / 1085240
#   ________________fixt date 2023-07-30 11:00:00+00:00
#   ________________fix local 2023-07-30 18:00:00
#   ________________local dat 2023-07-30 17:10:22
#   ________________Lebih
#   __________________league_rLeagues_id : 85
#   __________________league_rLeagues_name : Regionalliga - Nordost
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________8==8
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 40
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-30
#   ______________page : 31
#   ______________counter_loop : 0
#   ______________date_diff : 0
#   ______________date_raw : 2023-07-30 17:10:22.536742
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 0
# # -------------------------------------------------- End at 2023-07-30 17:49:44

# %%
# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.api_odds import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    date_0         = get_today_adds(1, space).strftime("%Y-%m-%d") 
    date_raw       = get_today_adds(1, space) 
    # -------------------------------------------------- 
    DICT = {
        'date_0' : date_0,
        'page' : 1,
        'counter_loop' : 0,
        'date_diff' : 1,
        'date_raw' : date_raw,
    }
    # --------------------------------------------------  
    PREP_ = "pre_"
    # -------------------------------------------------- 
    ao_controll_match_update(DICT, PREP_, space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-30 17:49:44
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 1
#   ________today_raw : 2023-07-31 17:49:44.453440
#   ______get_today_adds()
#   ________adds date_diff : 1
#   ________today_raw : 2023-07-31 17:49:44.453440
#   ______ao_controll_match_update()
#   ________aa_check_acccount()
#   __________API hariyant2410@gmail.com counter is 39
#   __________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ________aa_check_acccount()
#   ________aa_update_counter()
#   ________ao_response_odds()
#   __________date_0 : 2023-07-31
#   __________page : 1
#   __________counter_loop : 0
#   __________date_diff : 1
#   __________date_raw : 2023-07-31 17:49:44.453440
#   ____________________________________________________________________________________
#   __________Total API Response(s) : 10
#
#   ____________1. Norway,  2. Division - Group 2  #474 - 2023 / 980001
#   ____________fixt date 2023-07-31 17:00:00+00:00
#   ____________fix local 2023-08-01 00:00:00
#   ____________local dat 2023-07-31 17:49:44
#   ____________Lebih
#   ______________league_rLeagues_id : 474
#   ______________league_rLeagues_name : 2. Division - Group 2
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________2. Norway,  2. Division - Group 2  #474 - 2023 / 980002
#   ____________fixt date 2023-07-31 16:00:00+00:00
#   ____________fix local 2023-07-31 23:00:00
#   ____________local dat 2023-07-31 17:49:44
#   ____________Lebih
#   ______________league_rLeagues_id : 474
#   ______________league_rLeagues_name : 2. Division - Group 2
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________3. Iceland,  Úrvalsdeild  #164 - 2023 / 981557
#   ____________fixt date 2023-07-31 19:15:00+00:00
#   ____________fix local 2023-08-01 02:15:00
#   ____________local dat 2023-07-31 17:49:44
#   ____________Lebih
#   ______________league_rLeagues_id : 164
#   ______________league_rLeagues_name : Úrvalsdeild
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________4. Iceland,  Úrvalsdeild  #164 - 2023 / 981559
#   ____________fixt date 2023-07-31 19:15:00+00:00
#   ____________fix local 2023-08-01 02:15:00
#   ____________local dat 2023-07-31 17:49:44
#   ____________Lebih
#   ______________league_rLeagues_id : 164
#   ______________league_rLeagues_name : Úrvalsdeild
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________5. Sweden,  Ettan - Norra  #563 - 2023 / 982968
#   ____________fixt date 2023-07-31 17:00:00+00:00
#   ____________fix local 2023-08-01 00:00:00
#   ____________local dat 2023-07-31 17:49:44
#   ____________Lebih
#   ______________league_rLeagues_id : 563
#   ______________league_rLeagues_name : Ettan - Norra
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________6. Sweden,  Ettan - Södra  #564 - 2023 / 983205
#   ____________fixt date 2023-07-31 17:00:00+00:00
#   ____________fix local 2023-08-01 00:00:00
#   ____________local dat 2023-07-31 17:49:44
#   ____________Lebih
#   ______________league_rLeagues_id : 564
#   ______________league_rLeagues_name : Ettan - Södra
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________7. Chile,  Primera División  #265 - 2023 / 983807
#   ____________fixt date 2023-07-31 00:00:00+00:00
#   ____________fix local 2023-07-31 07:00:00
#   ____________local dat 2023-07-31 17:49:44
#   ____________Kurang
#   ____________good to Go 0
#
#   ____________8. Chile,  Primera B  #266 - 2023 / 987893
#   ____________fixt date 2023-07-31 22:00:00+00:00
#   ____________fix local 2023-08-01 05:00:00
#   ____________local dat 2023-07-31 17:49:44
#   ____________Lebih
#   ______________league_rLeagues_id : 266
#   ______________league_rLeagues_name : Primera B
#   ______________bookmakersapi_rLeagues_id : 11
#   ______________bookmakers_rLeagues_name : 1xBet
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________11==11
#
#   ____________9. Colombia,  Primera A  #239 - 2023 / 990329
#   ____________fixt date 2023-07-31 23:10:00+00:00
#   ____________fix local 2023-08-01 06:10:00
#   ____________local dat 2023-07-31 17:49:44
#   ____________Lebih
#   ______________league_rLeagues_id : 239
#   ______________league_rLeagues_name : Primera A
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#
#   ____________10. Colombia,  Primera A  #239 - 2023 / 990330
#   ____________fixt date 2023-07-31 21:00:00+00:00
#   ____________fix local 2023-08-01 04:00:00
#   ____________local dat 2023-07-31 17:49:44
#   ____________Lebih
#   ______________league_rLeagues_id : 239
#   ______________league_rLeagues_name : Primera A
#   ______________bookmakersapi_rLeagues_id : 8
#   ______________bookmakers_rLeagues_name : Bet365
#   ____________Total fixtureapi_id Row(s) : 1
#   ____________good to Go 1
#   ____________8==8
#   ______________re_looping__
#   ____________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 38
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-31
#   ______________page : 2
#   ______________counter_loop : 0
#   ______________date_diff : 1
#   ______________date_raw : 2023-07-31 17:49:44.453440
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Colombia,  Primera A  #239 - 2023 / 990331
#   ________________fixt date 2023-07-31 01:00:00+00:00
#   ________________fix local 2023-07-31 08:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________2. Sweden,  Division 2 - Norrland  #594 - 2023 / 993604
#   ________________fixt date 2023-07-31 17:00:00+00:00
#   ________________fix local 2023-08-01 00:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 594
#   __________________league_rLeagues_name : Division 2 - Norrland
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#
#   ________________3. South-Korea,  K League 2  #293 - 2023 / 997325
#   ________________fixt date 2023-07-31 10:00:00+00:00
#   ________________fix local 2023-07-31 17:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________4. South-Korea,  K League 2  #293 - 2023 / 997326
#   ________________fixt date 2023-07-31 10:30:00+00:00
#   ________________fix local 2023-07-31 17:30:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________5. Singapore,  Premier League  #368 - 2023 / 997944
#   ________________fixt date 2023-07-31 11:45:00+00:00
#   ________________fix local 2023-07-31 18:45:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 368
#   __________________league_rLeagues_name : Premier League
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________6. Finland,  Ykkönen  #245 - 2023 / 999048
#   ________________fixt date 2023-07-31 15:30:00+00:00
#   ________________fix local 2023-07-31 22:30:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 245
#   __________________league_rLeagues_name : Ykkönen
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________7. Finland,  Ykkönen  #245 - 2023 / 999049
#   ________________fixt date 2023-07-31 15:30:00+00:00
#   ________________fix local 2023-07-31 22:30:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 245
#   __________________league_rLeagues_name : Ykkönen
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________8. Estonia,  Meistriliiga  #329 - 2023 / 1001201
#   ________________fixt date 2023-07-31 16:45:00+00:00
#   ________________fix local 2023-07-31 23:45:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 329
#   __________________league_rLeagues_name : Meistriliiga
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________9. Estonia,  Esiliiga A  #328 - 2023 / 1001475
#   ________________fixt date 2023-07-31 16:00:00+00:00
#   ________________fix local 2023-07-31 23:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 328
#   __________________league_rLeagues_name : Esiliiga A
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________10. Sweden,  Allsvenskan  #113 - 2023 / 1001937
#   ________________fixt date 2023-07-31 17:00:00+00:00
#   ________________fix local 2023-08-01 00:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 113
#   __________________league_rLeagues_name : Allsvenskan
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 37
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-31
#   ______________page : 3
#   ______________counter_loop : 0
#   ______________date_diff : 1
#   ______________date_raw : 2023-07-31 17:49:44.453440
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Sweden,  Allsvenskan  #113 - 2023 / 1001940
#   ________________fixt date 2023-07-31 17:00:00+00:00
#   ________________fix local 2023-08-01 00:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 113
#   __________________league_rLeagues_name : Allsvenskan
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________2. Sweden,  Superettan  #114 - 2023 / 1002413
#   ________________fixt date 2023-07-31 17:00:00+00:00
#   ________________fix local 2023-08-01 00:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 114
#   __________________league_rLeagues_name : Superettan
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________3. Sweden,  Superettan  #114 - 2023 / 1002414
#   ________________fixt date 2023-07-31 17:00:00+00:00
#   ________________fix local 2023-08-01 00:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 114
#   __________________league_rLeagues_name : Superettan
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________4. Myanmar,  National League  #588 - 2023 / 1003708
#   ________________fixt date 2023-07-31 09:00:00+00:00
#   ________________fix local 2023-07-31 16:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________5. Myanmar,  National League  #588 - 2023 / 1003709
#   ________________fixt date 2023-07-31 09:30:00+00:00
#   ________________fix local 2023-07-31 16:30:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________6. Argentina,  Primera D  #133 - 2023 / 1004294
#   ________________fixt date 2023-07-31 18:30:00+00:00
#   ________________fix local 2023-08-01 01:30:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 133
#   __________________league_rLeagues_name : Primera D
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________7. Argentina,  Primera D  #133 - 2023 / 1004296
#   ________________fixt date 2023-07-31 18:30:00+00:00
#   ________________fix local 2023-08-01 01:30:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 133
#   __________________league_rLeagues_name : Primera D
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________8. Latvia,  Virsliga  #365 - 2023 / 1009408
#   ________________fixt date 2023-07-31 15:00:00+00:00
#   ________________fix local 2023-07-31 22:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 365
#   __________________league_rLeagues_name : Virsliga
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________9. Argentina,  Primera D  #133 - 2023 / 1011988
#   ________________fixt date 2023-07-31 18:30:00+00:00
#   ________________fix local 2023-08-01 01:30:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 133
#   __________________league_rLeagues_name : Primera D
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________10. Brazil,  Serie C  #75 - 2023 / 1012538
#   ________________fixt date 2023-07-31 23:00:00+00:00
#   ________________fix local 2023-08-01 06:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 75
#   __________________league_rLeagues_name : Serie C
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 36
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-31
#   ______________page : 4
#   ______________counter_loop : 0
#   ______________date_diff : 1
#   ______________date_raw : 2023-07-31 17:49:44.453440
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Brazil,  Serie C  #75 - 2023 / 1012540
#   ________________fixt date 2023-07-31 23:00:00+00:00
#   ________________fix local 2023-08-01 06:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 75
#   __________________league_rLeagues_name : Serie C
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________11==11
#
#   ________________2. World,  World Cup - Women  #8 - 2023 / 1013586
#   ________________fixt date 2023-07-31 07:00:00+00:00
#   ________________fix local 2023-07-31 14:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________3. World,  World Cup - Women  #8 - 2023 / 1013587
#   ________________fixt date 2023-07-31 07:00:00+00:00
#   ________________fix local 2023-07-31 14:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________4. World,
00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 76
#   __________________league_rLeagues_name : Serie D
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________9. Brazil,  Serie D  #76 - 2023 / 1094393
#   ________________fixt date 2023-07-31 23:30:00+00:00
#   ________________fix local 2023-08-01 06:30:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Lebih
#   __________________league_rLeagues_id : 76
#   __________________league_rLeagues_name : Serie D
#   __________________bookmakersapi_rLeagues_id : 11
#   __________________bookmakers_rLeagues_name : 1xBet
#   ________________Total fixtureapi_id Row(s) : 0
#   ________________football_odds INSERTED
#   ________________football_odds INSERTED
#   ________________good to Go 1
#   ________________11==11
#
#   ________________10. World,  Friendlies Clubs  #667 - 2023 / 1097395
#   ________________fixt date 2023-07-31 01:00:00+00:00
#   ________________fix local 2023-07-31 08:00:00
#   ________________local dat 2023-07-31 17:49:44
#   ________________Kurang
#   ________________good to Go 0
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 32
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date_0 : 2023-07-31
#   ______________page : 8
#   ______________counter_loop : 0
#   ______________date_diff : 1
#   ______________date_raw : 2023-07-31 17:49:44.453440
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 0
# # -------------------------------------------------- End at 2023-07-30 17:59:08

# %%
# Import
from a_settings.messages import *   
from a_models.date import *    
from a_models.football_odds import *    

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_0         = get_today_adds(1, space).strftime("%Y-%m-%d")  
    date_raw       = get_today_adds(0, space) 
    # --------------------------------------------------   
    fO_gak_sempet_predates(date_0, date_raw, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-30 17:59:09
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 1
#   ________today_raw : 2023-07-31 17:59:09.527920
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-07-30 17:59:09.532148
#   ______fO_gak_sempet_predates()
#   ________Select  leagueapi_id,  season,  DATE(date),   pre_response,   (select bookmakersapi_id from football_leagues where football_leagues.leagueapi_id = football_odds.leagueapi_id)  from football_odds  where date = '2023-07-31'  and deleted_at is null  and pre_odd_updated_at is null  group by leagueapi_id, season, DATE(date), pre_response  order by leagueapi_id asc
#   ________Total Row(s) : 2
#   __________[1/2]  #265 - 2023 > Date: 2023-07-31 > pre_response: 0 > bookmaker: 8
#   __________[2/2]  #667 - 2023 > Date: 2023-07-31 > pre_response: 0 > bookmaker: 8
#   __________Are you sure want to continue? :  yes
#   __________[1/2]  #265 - 2023 > Date: 2023-07-31 > pre_response: 0 > bookmaker: 8
#   ____________ao_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API hariyant2410@gmail.com counter is 31
#   ________________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ______________aa_check_acccount()
#   ______________aa_update_counter()
#   ______________ao_response_odds()
#   ________________date : 2023-07-31
#   ________________date_raw : 2023-07-30 17:59:09.532148
#   ________________bookmaker : 8
#   ________________season : 2023
#   ________________league : 265
#   ________________page : 1
#   __________________________________________________________________________________________
#   ________________Total API Response(s) : 10
#
#   __________________1. Chile,  Primera División  #265 - 2023 / 983801
#   __________________fixt date 2023-07-23 19:00:00+00:00
#   __________________fix local 2023-07-24 02:00:00
#   __________________local dat 2023-07-30 17:59:09
#   __________________Kurang
#   __________________good to Go 0
#
#   __________________2. Chile,  Primera División  #265 - 2023 / 983798
#   __________________fixt date 2023-07-23 22:00:00+00:00
#   __________________fix local 2023-07-24 05:00:00
#   __________________local dat 2023-07-30 17:59:09
#   __________________Kurang
#   __________________good to Go 0
#
#   __________________3. Chile,  Primera División  #265 - 2023 / 983802
#   __________________fixt date 2023-07-25 00:30:00+00:00
#   __________________fix local 2023-07-25 07:30:00
#   __________________local dat 2023-07-30 17:59:09
#   __________________Kurang
#   __________________good to Go 0
#
#   __________________4. Chile,  Primera División  #265 - 2023 / 983803
#   __________________fixt date 2023-07-25 22:00:00+00:00
#   __________________fix local 2023-07-26 05:00:00
#   __________________local dat 2023-07-30 17:59:09
#   __________________Kurang
#   __________________good to Go 0
#
#   __________________5. Chile,  Primera División  #265 - 2023 / 983811
#   __________________fixt date 2023-07-28 22:00:00+00:00
#   __________________fix local 2023-07-29 05:00:00
#   __________________local dat 2023-07-30 17:59:09
#   __________________Kurang
#   __________________good to Go 0
#
#   __________________6. Chile,  Primera División  #265 - 2023 / 983806
#   __________________fixt date 2023-07-29 19:00:00+00:00
#   __________________fix local 2023-07-30 02:00:00
#   __________________local dat 2023-07-30 17:59:09
#   __________________Kurang
#   __________________good to Go 0
#
#   __________________7. Chile,  Primera División  #265 - 2023 / 983808
#   __________________fixt date 2023-07-30 00:00:00+00:00
#   __________________fix local 2023-07-30 07:00:00
#   __________________local dat 2023-07-30 17:59:09
#   __________________Kurang
#   __________________good to Go 0
#
#   __________________8. Chile,  Primera División  #265 - 2023 / 983805
#   __________________fixt date 2023-07-29 21:30:00+00:00
#   __________________fix local 2023-07-30 04:30:00
#   __________________local dat 2023-07-30 17:59:09
#   __________________Kurang
#   __________________good to Go 0
#
#   __________________9. Chile,  Primera División  #265 - 2023 / 983809
#   __________________fixt date 2023-07-30 19:00:00+00:00
#   __________________fix local 2023-07-31 02:00:00
#   __________________local dat 2023-07-30 17:59:09
#   __________________Lebih
#   ____________________league_rLeagues_id : 265
#   ____________________league_rLeagues_name : Primera División
#   ____________________bookmakersapi_rLeagues_id : 8
#   ____________________bookmakers_rLeagues_name : Bet365
#   __________________Total fixtureapi_id Row(s) : 1
#   __________________good to Go 1
#   __________
#   ______________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-31
#   ______________date_raw : 2023-07-30 17:59:09.532148
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 667
#   ______________page : 34
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 0
# # -------------------------------------------------- End at 2023-07-30 19:29:42

# %%
# Import
from a_settings.messages import *   
from a_models.date import *    
from a_models.on_eye import *    

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_1         = get_today_adds(1, space).strftime("%Y-%m-%d")  
    # --------------------------------------------------   
    date_0         = get_today_adds(0, space).strftime("%Y-%m-%d")  
    date_raw       = get_today_adds(0, space) 
    # --------------------------------------------------    
    oy_get_fixtures_today(date_0, date_1, date_raw, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-30 19:29:42
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 1
#   ________today_raw : 2023-07-31 19:29:42.599636
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-07-30 19:29:42.609499
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-07-30 19:29:42.609499
#   ______oy_get_fixtures_today()
#   ________Select  date  , fixtureapi_id  , (select bookmakersapi_id from football_leagues where football_leagues.leagueapi_id = football_odds.leagueapi_id)  from football_odds  where date >= DATE('2023-07-30')  and date <= DATE('2023-07-31')  and oneye is not null
#   __________Total Row(s) : 3
#   ____________[1/3] 1030317 bm:8 -> 2023-07-30 11:00:00
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api1@ariondigitalmedia.com counter is 94
#   __________________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________fixture : 1030317
#   __________________bookmaker : 8
#   __________________date_0 : 2023-07-30
#   __________________page : 1
#   __________________counter_loop : 0
#   __________________date_diff : 0
#   __________________date_raw : 2023-07-30 19:29:42.609499
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 0
#   ____________[2/3] 1030318 bm:8 -> 2023-07-30 09:00:00
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api1@ariondigitalmedia.com counter is 93
#   __________________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________fixture : 1030318
#   __________________bookmaker : 8
#   __________________date_0 : 2023-07-30
#   __________________page : 1
#   __________________counter_loop : 0
#   __________________date_diff : 0
#   __________________date_raw : 2023-07-30 19:29:42.609499
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. World,  Friendlies Clubs  #667 - 2023 / 1030318
#   ____________________fixt date 2023-07-30 09:00:00+00:00
#   ____________________fix local 2023-07-30 16:00:00
#   ____________________local dat 2023-07-30 19:29:42
#   ____________________Kurang
#   ____________________good to Go 0
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
#   ____________[3/3] 1036879 bm:8 -> 2023-07-30 19:00:00
#   ______________ao_controll_match_update()
#   ________________aa_check_acccount()
#   __________________API api1@ariondigitalmedia.com counter is 92
#   __________________APIkey: 4fc723e268msh911a44c8ddfe5c9p1c8231jsn19121830f544
#   ________________aa_check_acccount()
#   ________________aa_update_counter()
#   ________________ao_response_odds()
#   __________________fixture : 1036879
#   __________________bookmaker : 8
#   __________________date_0 : 2023-07-30
#   __________________page : 1
#   __________________counter_loop : 0
#   __________________date_diff : 0
#   __________________date_raw : 2023-07-30 19:29:42.609499
#   ____________________________________________________________________________________________
#   __________________Total API Response(s) : 1
#
#   ____________________1. World,  Friendlies Clubs  #667 - 2023 / 1036879
#   ____________________fixt date 2023-07-30 19:00:00+00:00
#   ____________________fix local 2023-07-31 02:00:00
#   ____________________local dat 2023-07-30 19:29:42
#   ____________________Lebih
#   ______________________league_rLeagues_id : 667
#   ______________________league_rLeagues_name : Friendlies Clubs
#   ______________________bookmakersapi_rLeagues_id : 8
#   ______________________bookmakers_rLeagues_name : Bet365
#   ____________________Total fixtureapi_id Row(s) : 1
#   ____________________good to Go 1
#   ____________________8==8
#   ______________________ff_update_unfinished__
#   ____________________  > No longer get supported
# # -------------------------------------------------- End at 2023-07-30 19:29:50

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    day0         = get_today_adds(0, space) .strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_adds(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------  
    fO_get_group_league_status_match_finished_DETAILED(day0, day1, "pre_xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-30 19:29:50
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-07-30 19:29:50.444062
#   ______get_today_adds()
#   ________adds date_diff : 1
#   ________today_raw : 2023-07-31 19:29:50.444062
#   ______fO_get_group_league_status_match_finished_DETAILED()
#   ______Select  DATE(date),  leagueapi_id,  (select bookmakersapi_id from football_leagues where football_leagues.leagueapi_id = football_odds.leagueapi_id),  season,   fixtureapi_id,   pre_ah_pattern,   pre_gou_pattern,   fixture_status   from football_odds  where date <= '2023-07-31'  and date >= '2023-07-30'  and deleted_at is null  and pre_response != 3  order by date, leagueapi_id, fixtureapi_id  desc
#   ________Total Row(s) : 274
#   ________1. 2023-07-30 // 71 // 8 // 2023 // 1005814 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1005814
#   __________> pre_ah_pattern = -075-05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+
// None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1041321
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________45. 2023-07-30 // 100 // 11 // 2023 // 995556 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 995556
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________46. 2023-07-30 // 667 // 8 // 2023 // 1030318 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1030318
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________47. 2023-07-30 // 8 // 8 // 2023 // 1013583 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1013583
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________48. 2023-07-30 // 278 // 11 // 2023 // 997541 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 997541
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________49. 2023-07-30 // 99 // 8 // 2023 // 995213 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 995213
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________50. 2023-07-30 // 293 // 8 // 2023 // 997323 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 997323
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________51. 2023-07-30 // 293 // 8 // 2023 // 997324 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 997324
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   ________52. 2023-07-30 // 107 // 8 // 2023 // 1037651 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1037651
#   __________> pre_ah_pattern = +025+05+075+1H
#   __________> pre_ah_pattern_mirror = -1-075-05-025H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________53. 2023-07-30 // 85 // 8 // 2023 // 1085240 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1085240
#   __________> pre_ah_pattern = -175-15-125-1-075H
#   __________> pre_ah_pattern_mirror = +075+1+125+15+175H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   ________54. 2023-07-30 // 85 // 8 // 2023 // 1085239 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1085239
#   __________> pre_ah_pattern = +075+1+125+15H
#   __________> pre_ah_pattern_mirror = -15-125-1-075H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________55. 2023-07-30 // 114 // 8 // 2023 // 1002411 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1002411
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________56. 2023-07-30 // 365 // 8 // 2023 // 1009409 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1009409
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________57. 2023-07-30 // 592 // 8 // 2023 // 993060 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 993060
#   __________> pre_ah_pattern = -15-125-1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   ________58. 2023-07-30 // 596 // 8 // 2023 // 993423 // None // None // Time to be defined
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 993423
#   __________> pre_ah_pattern = -15-125-1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   ________59. 2023-07-30 // 597 // 8 // 2023 // 993787 // None // None // Time to be defined
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 993787
#   __________> pre_ah_pattern = -025+0+025+05H
#   __________> pre_ah_pattern_mirror = -05-025+0+025H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________60. 2023-07-30 // 667 // 8 // 2023 // 1097384 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1097384
#   __________> pre_ah_pattern = -175-15-125-1H
#   __________> pre_ah_pattern_mirror = +1+125+15+175H
#   __________> pre_gou_pattern = 25g35gG
#   __________> football_odds update pattern commited
#   ________61. 2023-07-30 // 667 // 8 // 2023 // 1030317 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1030317
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________62. 2023-07-30 // 779 // 11 // 2023 // 1032881 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1032881
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________63. 2023-07-30 // 79 // 8 // 2023 // 1048581 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1048581
#   __________> pre_ah_pattern = -025+0+025+05H
#   __________> pre_ah_pattern_mirror = -05-025+0+025H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________64. 2023-07-30 // 79 // 8 // 2023 // 1048580 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1048580
#   __________> pre_ah_pattern = -025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025H
#   __________> pre_gou_pattern = 175g20g225g25gG
#   __________> football_odds update pattern commited
#   ________65. 2023-07-30 // 79 // 8 // 2023 // 1048579 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1048579
#   __________> pre_ah_pattern = -05-025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025+05H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________66. 2023-07-30 // 144 // 8 // 2023 // 1038425 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1038425
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________67. 2023-07-30 // 170 // 8 // 2023 // 1022760 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1022760
#   __________> pre_ah_pattern = +05+075+1+125H
#   __________> pre_ah_pattern_mirror = -125-1-075-05H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________68. 2023-07-30 // 170 // 8 // 2023 // 1022759 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1022759
#   __________> pre_ah_pattern = -025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________69. 2023-07-30 // 170 // 8 // 2023 // 1022758 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1022758
#   __________> pre_ah_pattern = -175-15-125-1H
#   __________> pre_ah_pattern_mirror = +1+125+15+175H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________70. 2023-07-30 // 170 // 8 // 2023 // 1022757 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1022757
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________71. 2023-07-30 // 929 // 11 // 2023 // 1023662 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1023662
#   __________> pre_ah_pattern = -45-425-4-375-35-325H
#   __________> pre_ah_pattern_mirror = +325+35+375+4+425+45H
#   __________> pre_gou_pattern = 375g40g425g45g475g50gG
#   __________> football_odds update pattern commited
#   ________72. 2023-07-30 // 169 // 8 // 2023 // 1021421 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1021421
#   __________> pre_ah_pattern = -175-15-125H
#   __________> pre_ah_pattern_mirror = +125+15+175H
#   __________> pre_gou_pattern = 25g275g30g325g35gG
#   __________> football_odds update pattern commited
#   ________73. 2023-07-30 // 169 // 8 // 2023 // 1021420 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1021420
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   ________74. 2023-07-30 // 119 // 8 // 2023 // 1034887 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1034887
#   __________> pre_ah_pattern = -1-075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075+1H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________75. 2023-07-30 // 120 // 8 // 2023 // 1037438 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1037438
#   __________> pre_ah_pattern = -1-075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075+1H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________76. 2023-07-30 // 235 // 11 // 2023 // 1042027 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1042027
#   __________> pre_ah_pattern = -075-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+075H
#   __________> pre_gou_pattern = 225g275g30g325gG
#   __________> football_odds update pattern commited
#   ________77. 2023-07-30 // 244 // 8 // 2023 // 996474 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 996474
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________78. 2023-07-30 // 274 // 11 // 2023 // 1029994 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1029994
#   __________> pre_ah_pattern = -075-025H
#   __________> pre_ah_pattern_mirror = +025+075H
#   __________> pre_gou_pattern = 225g25g275g30g325g35gG
#   __________> football_odds update pattern commited
#   ________79. 2023-07-30 // 274 // 11 // 2023 // 1029993 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1029993
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________80. 2023-07-30 // 274 // 11 // 2023 // 1029992 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1029992
#   __________> pre_ah_pattern = -125-1-075H
#   __________> pre_ah_pattern_mirror = +075+1+125H
#   __________> pre_gou_pattern = 225g25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________81. 2023-07-30 // 333 // 8 // 2023 // 1062534 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1062534
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________82. 2023-07-30 // 779 // 11 // 2023 // 1032882 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1032882
#   __________> pre_ah_pattern = +0+025+075+1H
#   __________> pre_ah_pattern_mirror = -1-075-025+0H
#   __________> pre_gou_pattern = 35g375g40g425g45gG
#   __________> football_odds update pattern commited
#   ________83. 2023-07-30 // 207 // 8 // 2023 // 1048452 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1048452
#   __________> pre_ah_pattern = -15-125-1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   __________> pre_gou_pattern = 25g275g30g325g35gG
#   __________> football_odds update pattern commited
#   ________84. 2023-07-30 // 208 // 11 // 2023 // 1038341 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1038341
#   __________> pre_ah_pattern = -075-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+075H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________85. 2023-07-30 // 208 // 11 // 2023 // 1038340 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1038340
#   __________> pre_ah_pattern = -075-025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025+075H
#   __________> pre_gou_pattern = 225g25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________86. 2023-07-30 // 106 // 8 // 2023 // 1035827 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1035827
#   __________> pre_ah_pattern = +025+05+075H
#   __________> pre_ah_pattern_mirror = -075-05-025H
#   __________> pre_gou_pattern = 175g20g225g25gG
#   __________> football_odds update pattern commited
#   ________87. 2023-07-30 // 107 // 8 // 2023 // 1037644 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1037644
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   ________88. 2023-07-30 // 113 // 8 // 2023 // 1001941 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001941
#   __________> pre_ah_pattern = +0+025+05H
#   __________> pre_ah_pattern_mirror = -05-025+0H
#   __________> pre_gou_pattern = 20g225g25gG
#   __________> football_odds update pattern commited
#   ________89. 2023-07-30 // 113 // 8 // 2023 // 1001935 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001935
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________90. 2023-07-30 // 114 // 8 // 2023 // 1002412 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1002412
#   __________> pre_ah_pattern = -225-2-175-15-125H
#   __________> pre_ah_pattern_mirror = +125+15+175+2+225H
#   __________> pre_gou_pattern = 275g30g325g35g375gG
#   __________> football_odds update pattern commited
#   ________91. 2023-07-30 // 236 // 11 // 2023 // 1053136 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1053136
#   __________> pre_ah_pattern = -025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________92. 2023-07-30 // 236 // 11 // 2023 // 1053133 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1053133
#   __________> pre_ah_pattern = -075-025H
#   __________> pre_ah_pattern_mirror = +025+075H
#   __________> pre_gou_pattern = 175g20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________93. 2023-07-30 // 244 // 8 // 2023 // 996476 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 996476
#   __________> pre_ah_pattern = -15-125-1-075H
#   __________> pre_ah_pattern_mirror = +075+1+125+15H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________94. 2023-07-30 // 244 // 8 // 2023 // 996475 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 996475
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________95. 2023-07-30 // 278 // 11 // 2023 // 997542 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 997542
#   __________> pre_ah_pattern = -025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025H
#   __________> pre_gou_pattern = 25g275g30g325g35gG
#   __________> football_odds update pattern commited
#   ________96. 2023-07-30 // 345 // 8 // 2023 // 1049507 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1049507
#   __________> pre_ah_pattern = -1-075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075+1H
#   __________> pre_gou_pattern = 225g25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________97. 2023-07-30 // 345 // 8 // 2023 // 1049506 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1049506
#   __________> pre_ah_pattern = -15-125-1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________98. 2023-07-30 // 345 // 8 // 2023 // 1049505 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1049505
#   __________> pre_ah_pattern = +125+15+175+2H
#   __________> pre_ah_pattern_mirror = -2-175-15-125H
#   __________> pre_gou_pattern = 275g30g325g35g375gG
#   __________> football_odds update pattern commited
#   ________99. 2023-07-30 // 365 // 8 // 2023 // 1009410 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1009410
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________100. 2023-07-30 // 474 // 8 // 2023 // 979998 // H // G // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 979998
#   __________> pre_ah_pattern = -075-05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05+075H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   ________101. 2023-07-30 // 474 // 8 // 2023 // 979996 // H // G // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 979996
#   __________> pre_ah_pattern = -15-125-1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   ________102. 2023-07-30 // 592 // 8 // 2023 // 993061 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 993061
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________103. 2023-07-30 // 594 // 8 // 2023 // 993606 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 993606
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________104. 2023-07-30 // 594 // 8 // 2023 // 993603 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 993603
#   __________> pre_ah_pattern = -1-075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075+1H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________105. 2023-07-30 // 667 // 8 // 2023 // 1097388 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1097388
#   __________> pre_ah_pattern = -2-175-125H
#   __________> pre_ah_pattern_mirror = +125+175+2H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________106. 2023-07-30 // 667 // 8 // 2023 // 1097387 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1097387
#   __________> pre_ah_pattern = -025H
#   __________> pre_ah_pattern_mirror = +025H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________107. 2023-07-30 // 667 // 8 // 2023 // 1041034 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1041034
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________108. 2023-07-30 // 779 // 11 // 2023 // 1032883 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1032883
#   __________> pre_ah_pattern = +025+075+1+125+15H
#   __________> pre_ah_pattern_mirror = -15-125-1-075-025H
#   __________> pre_gou_pattern = 325g35g375g40g425gG
#   __________> football_odds update pattern commited
#   ________109. 2023-07-30 // 778 // 11 // 2023 // 1032686 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1032686
#   __________> pre_ah_pattern = +075+1+125+15+175H
#   __________> pre_ah_pattern_mirror = -175-15-125-1-075H
#   __________> pre_gou_pattern = 325g35g375g40g425g45g475gG
#   __________> football_odds update pattern commited
#   ________110. 2023-07-30 // 71 // 8 // 2023 // 1005811 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1005811
#   __________> pre_ah_pattern = -125-1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1+125H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   ________111. 2023-07-30 // 72 // 8 // 2023 // 1006645 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1006645
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________112. 2023-07-30 // 119 // 8 // 2023 // 1034888 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1034888
#   __________> pre_ah_pattern = -125-1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1+125H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________113. 2023-07-30 // 144 // 8 // 2023 // 1038426 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1038426
#   __________> pre_ah_pattern = -2-175-15-125H
#   __________> pre_ah_pattern_mirror = +125+15+175+2H
#   __________> pre_gou_pattern = 275g30g325g35gG
#   __________> football_odds update pattern commited
#   ________114. 2023-07-30 // 185 // 8 // 2023 // 1031881 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1031881
#   __________> pre_ah_pattern = -15-125-1-075H
#   __________> pre_ah_pattern_mirror = +075+1+125+15H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________115. 2023-07-30 // 236 // 11 // 2023 // 1053140 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1053140
#   __________> pre_ah_pattern = -025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________116. 2023-07-30 // 269 // 8 // 2023 // 1009164 // H // G // Time to be defined
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1009164
#   __________> pre_ah_pattern = +0H
#   __________> pre_ah_pattern_mirror = +0H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________117. 2023-07-30 // 333 // 8 // 2023 // 1062538 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1062538
#   __________> pre_ah_pattern = -25-225-2-175H
#   __________> pre_ah_pattern_mirror = +175+2+225+25H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________118. 2023-07-30 // 564 // 8 // 2023 // 983207 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 983207
#   __________> pre_ah_pattern = -2-175-15-125H
#   __________> pre_ah_pattern_mirror = +125+15+175+2H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   ________119. 2023-07-30 // 593 // 8 // 2023 // 993242 // None // None // Time to be defined
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 993242
#   __________> pre_ah_pattern = -125-1-075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075+1+125H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   ________120. 2023-07-30 // 667 // 8 // 2023 // 1061302 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1061302
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________121. 2023-07-30 // 667 // 8 // 2023 // 1051877 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1051877
#   __________> pre_ah_pattern = +05H
#   __________> pre_ah_pattern_mirror = -05H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________122. 2023-07-30 // 667 // 8 // 2023 // 1036880 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1036880
#   __________> pre_ah_pattern = +0+025+05H
#   __________> pre_ah_pattern_mirror = -05-025+0H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________123. 2023-07-30 // 778 // 11 // 2023 // 1032687 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1032687
#   __________> pre_ah_pattern = +025+075+1+125+15H
#   __________> pre_ah_pattern_mirror = -15-125-1-075-025H
#   __________> pre_gou_pattern = 325g35g375g40g425g45gG
#   __________> football_odds update pattern commited
#   ________124. 2023-07-30 // 207 // 8 // 2023 // 1048454 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1048454
#   __________> pre_ah_pattern = +1+125+15+175H
#   __________> pre_ah_pattern_mirror = -175-15-125-1H
#   __________> pre_gou_pattern = 30g325g35g375gG
#   __________> football_odds update pattern commited
#   ________125. 2023-07-30 // 207 // 8 // 2023 // 1048453 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1048453
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________126. 2023-07-30 // 235 // 11 // 2023 // 1042028 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1042028
#   __________> pre_ah_pattern = +0+025H
#   __________> pre_ah_pattern_mirror = -025+0H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________127. 2023-07-30 // 667 // 8 // 2023 // 1061303 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1061303
#   __________> pre_ah_pattern = +2+225H
#   __________> pre_ah_pattern_mirror = -225-2H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________128. 2023-07-30 // 103 // 8 // 2023 // 1001692 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001692
#   __________> pre_ah_pattern = -175-15-125-1-075H
#   __________> pre_ah_pattern_mirror = +075+1+125+15+175H
#   __________> pre_gou_pattern = 30g325g35g375gG
#   __________> football_odds update pattern commited
#   ________129. 2023-07-30 // 103 // 8 // 2023 // 1001691 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001691
#   __________> pre_ah_pattern = -1-075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075+1H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________130. 2023-07-30 // 103 // 8 // 2023 // 1001690 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001690
#   __________> pre_ah_pattern = -175-15-125-1-075H
#   __________> pre_ah_pattern_mirror = +075+1+125+15+175H
#   __________> pre_gou_pattern = 275g30g325g35gG
#   __________> football_odds update pattern commited
#   ________131. 2023-07-30 // 103 // 8 // 2023 // 1001689 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001689
#   __________> pre_ah_pattern = -1-075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075+1H
#   __________> pre_gou_pattern = 325g35g375g40gG
#   __________> football_odds update pattern commited
#   ________132. 2023-07-30 // 103 // 8 // 2023 // 1001687 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001687
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________133. 2023-07-30 // 109 // 8 // 2023 // 1038709 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1038709
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________134. 2023-07-30 // 109 // 8 // 2023 // 1038708 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1038708
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________135. 2023-07-30 // 218 // 8 // 2023 // 1042892 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1042892
#   __________> pre_ah_pattern = +025+05+075H
#   __________> pre_ah_pattern_mirror = -075-05-025H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________136. 2023-07-30 // 236 // 11 // 2023 // 1053139 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1053139
#   __________> pre_ah_pattern = +0+025H
#   __________> pre_ah_pattern_mirror = -025+0H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________137. 2023-07-30 // 236 // 11 // 2023 // 1053135 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1053135
#   __________> pre_ah_pattern = -025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________138. 2023-07-30 // 245 // 8 // 2023 // 999047 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 999047
#   __________> pre_ah_pattern = -05-025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025+05H
#   __________> pre_gou_pattern = 225g25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________139. 2023-07-30 // 248 // 8 // 2023 // 1000174 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1000174
#   __________> pre_ah_pattern = +05+075+1+125+15H
#   __________> pre_ah_pattern_mirror = -15-125-1-075-05H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   ________140. 2023-07-30 // 249 // 8 // 2023 // 1000300 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1000300
#   __________> pre_ah_pattern = -225-2-175-15-125H
#   __________> pre_ah_pattern_mirror = +125+15+175+2+225H
#   __________> pre_gou_pattern = 35gG
#   __________> football_odds update pattern commited
#   ________141. 2023-07-30 // 346 // 8 // 2023 // 1041322 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1041322
#   __________> pre_ah_pattern = +0+025+05+075H
#   __________> pre_ah_pattern_mirror = -075-05-025+0H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________142. 2023-07-30 // 362 // 8 // 2023 // 1027488 // None // None // Not Started
# ...
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 987897
#   __________> pre_ah_pattern = -075-025H
#   __________> pre_ah_pattern_mirror = +025+075H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________229. 2023-07-30 // 344 // 8 // 2023 // 1001095 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001095
#   __________> pre_ah_pattern = -1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   ________230. 2023-07-30 // 344 // 8 // 2023 // 1001090 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001090
#   __________> pre_ah_pattern = -125-1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1+125H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________231. 2023-07-30 // 667 // 8 // 2023 // 1036879 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1036879
#   __________> pre_ah_pattern = -05H
#   __________> pre_ah_pattern_mirror = +05H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________232. 2023-07-30 // 711 // 11 // 2023 // 1006153 // None // None // Time to be defined
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1006153
#   __________> pre_ah_pattern = -075-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+075H
#   __________> pre_gou_pattern = 175g20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________233. 2023-07-30 // 909 // 11 // 2023 // 1015473 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1015473
#   __________> pre_ah_pattern = -125-1-075-025H
#   __________> pre_ah_pattern_mirror = +025+075+1+125H
#   __________> pre_gou_pattern = 25g275g30g325g35gG
#   __________> football_odds update pattern commited
#   ________234. 2023-07-30 // 210 // 8 // 2023 // 1034687 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1034687
#   __________> pre_ah_pattern = -1-075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075+1H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   ________235. 2023-07-30 // 162 // 8 // 2023 // 1035688 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1035688
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________236. 2023-07-30 // 239 // 8 // 2023 // 990328 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 990328
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________237. 2023-07-30 // 239 // 8 // 2023 // 990327 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 990327
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________238. 2023-07-30 // 252 // 8 // 2023 // 1042740 // None // None // Time to be defined
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1042740
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________239. 2023-07-30 // 711 // 11 // 2023 // 1006155 // None // None // Time to be defined
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1006155
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = 20g25gG
#   __________> football_odds update pattern commited
#   ________240. 2023-07-30 // 282 // 11 // 2023 // 1043041 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1043041
#   __________> pre_ah_pattern = -175-15-125-1-075H
#   __________> pre_ah_pattern_mirror = +075+1+125+15+175H
#   __________> pre_gou_pattern = 225g25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________241. 2023-07-30 // 128 // 8 // 2023 // 971667 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 971667
#   __________> pre_ah_pattern = +0H
#   __________> pre_ah_pattern_mirror = +0H
#   __________> pre_gou_pattern = 15g175gG
#   __________> football_odds update pattern commited
#   ________242. 2023-07-30 // 128 // 8 // 2023 // 971666 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 971666
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = 15g175g20g225gG
#   __________> football_odds update pattern commited
#   ________243. 2023-07-30 // 239 // 8 // 2023 // 990333 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 990333
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = 20g225g25gG
#   __________> football_odds update pattern commited
#   ________244. 2023-07-30 // 240 // 8 // 2023 // 1028013 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1028013
#   __________> pre_ah_pattern = -075-05H
#   __________> pre_ah_pattern_mirror = +05+075H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________245. 2023-07-30 // 240 // 8 // 2023 // 1028012 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1028012
#   __________> pre_ah_pattern = -025+0H
#   __________> pre_ah_pattern_mirror = +0+025H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________246. 2023-07-30 // 282 // 11 // 2023 // 1043039 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1043039
#   __________> pre_ah_pattern = -15-125-1-075H
#   __________> pre_ah_pattern_mirror = +075+1+125+15H
#   __________> pre_gou_pattern = 225g25g275g30g325g35gG
#   __________> football_odds update pattern commited
#   ________247. 2023-07-30 // 129 // 8 // 2023 // 1027640 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1027640
#   __________> pre_ah_pattern = +0+025+05H
#   __________> pre_ah_pattern_mirror = -05-025+0H
#   __________> pre_gou_pattern = 175g20g225g25gG
#   __________> football_odds update pattern commited
#   ________248. 2023-07-30 // 72 // 8 // 2023 // 1006637 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1006637
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________249. 2023-07-30 // 162 // 8 // 2023 // 1035686 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1035686
#   __________> pre_ah_pattern = +025+05+075+1H
#   __________> pre_ah_pattern_mirror = -1-075-05-025H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   ________250. 2023-07-30 // 304 // 11 // 2023 // 1062312 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1062312
#   __________> pre_ah_pattern = -075-025H
#   __________> pre_ah_pattern_mirror = +025+075H
#   __________> pre_gou_pattern = 15g175g20g225g325gG
#   __________> football_odds update pattern commited
#   ________251. 2023-07-30 // 71 // 8 // 2023 // 1005813 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1005813
#   __________> pre_ah_pattern = +0+025+05H
#   __________> pre_ah_pattern_mirror = -05-025+0H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________252. 2023-07-30 // 265 // 8 // 2023 // 983812 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 983812
#   __________> pre_ah_pattern = -025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________253. 2023-07-30 // 75 // 11 // 2023 // 1012539 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1012539
#   __________> pre_ah_pattern = -075-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+075H
#   __________> pre_gou_pattern = 15g175g20g225gG
#   __________> football_odds update pattern commited
#   ________254. 2023-07-30 // 75 // 11 // 2023 // 1012537 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1012537
#   __________> pre_ah_pattern = -125-1-075H
#   __________> pre_ah_pattern_mirror = +075+1+125H
#   __________> pre_gou_pattern = 175g20g225g25gG
#   __________> football_odds update pattern commited
#   ________255. 2023-07-30 // 909 // 11 // 2023 // 1015469 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1015469
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________256. 2023-07-30 // 252 // 8 // 2023 // 1042737 // None // None // Time to be defined
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1042737
#   __________> pre_ah_pattern = +05+075+1+125+15H
#   __________> pre_ah_pattern_mirror = -15-125-1-075-05H
#   __________> pre_gou_pattern = 225g25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________257. 2023-07-30 // 239 // 8 // 2023 // 990336 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 990336
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________258. 2023-07-30 // 128 // 8 // 2023 // 988749 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 988749
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = 175g20g225gG
#   __________> football_odds update pattern commited
#   ________259. 2023-07-30 // 162 // 8 // 2023 // 1035691 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1035691
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_odds update pattern commited
#   ________260. 2023-07-30 // 667 // 8 // 2023 // 1030643 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1030643
#   __________> pre_ah_pattern = +0+025+05H
#   __________> pre_ah_pattern_mirror = -05-025+0H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________261. 2023-07-30 // 673 // 8 // 2023 // 1042005 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1042005
#   __________> pre_ah_pattern = -1H
#   __________> pre_ah_pattern_mirror = +1H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________262. 2023-07-30 // 909 // 11 // 2023 // 1015472 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1015472
#   __________> pre_ah_pattern = -025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025H
#   __________> pre_gou_pattern = 30g325g35g375g40gG
#   __________> football_odds update pattern commited
#   ________263. 2023-07-30 // 909 // 11 // 2023 // 1015471 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1015471
#   __________> pre_ah_pattern = -025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025H
#   __________> pre_gou_pattern = 275g30g325g35g375gG
#   __________> football_odds update pattern commited
#   ________264. 2023-07-30 // 909 // 11 // 2023 // 1015470 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1015470
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________265. 2023-07-30 // 263 // 8 // 2023 // 1053154 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1053154
#   __________> pre_ah_pattern = -075H
#   __________> pre_ah_pattern_mirror = +075H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________266. 2023-07-30 // 304 // 11 // 2023 // 1062313 // None // None // None
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1062313
#   __________> pre_ah_pattern = +0+025H
#   __________> pre_ah_pattern_mirror = -025+0H
#   __________> pre_gou_pattern = 15g175g20g225gG
#   __________> football_odds update pattern commited
#   ________267. 2023-07-30 // 129 // 8 // 2023 // 1027800 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1027800
#   __________> pre_ah_pattern = -075-05-025H
#   __________> pre_ah_pattern_mirror = +025+05+075H
#   __________> pre_gou_pattern = 15g175g20g225gG
#   __________> football_odds update pattern commited
#   ________268. 2023-07-30 // 344 // 8 // 2023 // 1001092 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001092
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________269. 2023-07-30 // 344 // 8 // 2023 // 1001091 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1001091
#   __________> pre_ah_pattern = -15-125-1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1+125+15H
#   __________> pre_gou_pattern = 225g25g275g30gG
#   __________> football_odds update pattern commited
#   ________270. 2023-07-30 // 772 // 8 // 2023 // 1013804 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1013804
#   __________> pre_ah_pattern = -125-1-075-05H
#   __________> pre_ah_pattern_mirror = +05+075+1+125H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________271. 2023-07-30 // 772 // 8 // 2023 // 1013803 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1013803
#   __________> pre_ah_pattern = -05-025+0H
#   __________> pre_ah_pattern_mirror = +0+025+05H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
#   ________272. 2023-07-30 // 772 // 8 // 2023 // 1013801 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1013801
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
#   ________273. 2023-07-31 // 265 // 8 // 2023 // 983807 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 983807
#   __________> pre_ah_pattern = -025+0+025+05H
#   __________> pre_ah_pattern_mirror = -05-025+0+025H
#   __________> pre_gou_pattern = 20g225g25g275gG
#   __________> football_odds update pattern commited
#   ________274. 2023-07-31 // 667 // 8 // 2023 // 1072580 // None // None // Time to be defined
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1072580
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-30 20:04:36

# %%
# Import
from a_settings.messages import *   
from a_models.date import *    
from a_models.football_forecast_pattern import *    

if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    date_1         = get_today_adds(1, space).strftime("%Y-%m-%d")  
    # --------------------------------------------------   
    date_0         = get_today_adds(0, space).strftime("%Y-%m-%d")   
    # --------------------------------------------------    
    ffp_get_fixtures_today(date_0, date_1, space)
    # --------------------------------------------------   
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-30 20:04:36
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 1
#   ________today_raw : 2023-07-31 20:04:36.950843
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-07-30 20:04:36.950843
#   ______ffp_get_fixtures_today()
#   ________Select  date  , fixtureapi_id  , pre_ah_pattern  , pre_ah_pattern_mirror  , pre_gou_pattern  , end_ah_pattern  , end_ah_pattern_mirror  , end_gou_pattern  , leagueapi_id  , season  from football_odds  where date >= DATE('2023-07-30')  and date <= DATE('2023-07-31')  and fixture_status not in ('Match Finished', 'Match Finished Ended')
#   __________Total Row(s) : 214
#   ____________[1/214] 998188 -> 2023-07-30 00:30:00
#   ____________          H / H / 25gG
#   ____________          None / None / None
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1800
#   ____________________ffp_check()
#   ____________________leagueapi_id : 299
#   ____________________season : 2023
#   ____________________fixtureapi_id : 998188
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 567
#   ____________________ffp_check()
#   ____________________leagueapi_id : 299
#   ____________________season : 2023
#   ____________________fixtureapi_id : 998188
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1800
#   ____________________ffp_check()
#   ____________________leagueapi_id : 299
#   ____________________season : 2023
#   ____________________fixtureapi_id : 998188
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 567
#   ____________________ffp_check()
#   ____________________leagueapi_id : 299
#   ____________________season : 2023
#   ____________________fixtureapi_id : 998188
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[2/214] 1009159 -> 2023-07-30 16:30:00
#   ____________          +0H / +0H / G
#   ____________          None / None / None
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 79
#   ____________________ffp_check()
#   ____________________leagueapi_id : 269
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1009159
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 50
#   ____________________ffp_check()
#   ____________________leagueapi_id : 269
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1009159
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 79
#   ____________________ffp_check()
#   ____________________leagueapi_id : 269
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1009159
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 50
#   ____________________ffp_check()
#   ____________________leagueapi_id : 269
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1009159
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[3/214] 1009164 -> 2023-07-30 14:00:00
#   ____________          +0H / +0H / G
#   ____________          None / None / None
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 2
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 79
#   ____________________ffp_check()
#   ____________________leagueapi_id : 269
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1009164
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 50
#   ____________________ffp_check()
#   ____________________leagueapi_id : 269
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1009164
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 79
#   ____________________ffp_check()
#   ____________________leagueapi_id : 269
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1009164
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 50
#   ____________________ffp_check()
#   ____________________leagueapi_id : 269
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1009164
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[4/214] 1006637 -> 2023-07-30 21:00:00
#   ____________          -05-025+0H / +0+025+05H / G
#   ____________          None / None / None
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 14
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 17
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 14
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 17
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 85
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 131
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 41
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 57
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006637
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[5/214] 1006641 -> 2023-07-30 18:30:00
#   ____________          -05-025H / +025+05H / 15gG
#   ____________          None / None / None
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 9
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006641
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 6
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006641
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 9
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006641
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 9
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006641
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 1
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006641
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 19
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006641
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 25
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006641
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 3
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006641
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 8
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006641
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________[6/214] 1006645 -> 2023-07-30 14:00:00
#   ____________          -05-025+0H / +0+025+05H / 25gG
#   ____________          None / None / None
#
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 22
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 0
#   __________________football_forecast_pattern INSERTED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 27
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 22
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 28
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 5
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 4
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 506
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 674
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 0
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 233
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ______________ffp_check_pattern()
#   __________________Total Row(s) : 353
#   ____________________ffp_check()
#   ____________________leagueapi_id : 72
#   ____________________season : 2023
#   ____________________fixtureapi_id : 1006645
#   ______________________total_rows: 1
#   __________________football_forecast_pattern UPDATED
#   ____________