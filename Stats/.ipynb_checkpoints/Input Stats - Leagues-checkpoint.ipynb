# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *  
from a_models.football_fixtures import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    space += "__"
    # --------------------------------------------------  
    leagueapi_id = input(space + "Enter your leagueapi id : ")
    season = input(space + "Enter your season : ")
    # --------------------------------------------------    
    ff_get_fixture_that_not_update_stats(leagueapi_id, season, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-02 15:31:22
#   __main()
#   ____Enter your leagueapi id : 39
#   ____Enter your season : 2022
#   ______ff_get_fixture_that_not_update_stats()
#   ______ SELECT   leagueapi_id  , season  , teams_home  , teams_away  , date  , fixtureapi_id FROM football_fixtures WHERE leagueapi_id = '39'  and season = '2022'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and shots_on_goal_home is null  and shots_on_goal_away is null
#   ______Total Row(s) : 47
#   ______[1/47] #868236 #39 - 2022 - Aston Villa vs Nottingham Forest
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 92
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868236
#   ____________Total API Response(s) : 1
#
# ID :66
# lineups_coach_home_name :Unai Emery
#   ______________1. /Match Finished/ 868236 / Aston Villa vs Nottingham Forest /2023-04-08 14:00:00+00:00/  UPDATED
#   ______[2/47] #868237 #39 - 2022 - Brentford vs Newcastle
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 91
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868237
#   ____________Total API Response(s) : 1
#
# ID :55
# lineups_coach_home_name :T. Frank
#   ______________1. /Match Finished/ 868237 / Brentford vs Newcastle /2023-04-08 14:00:00+00:00/  UPDATED
#   ______[3/47] #868238 #39 - 2022 - Fulham vs West Ham
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 90
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868238
#   ____________Total API Response(s) : 1
#
# ID :36
# lineups_coach_home_name :Marco Silva
#   ______________1. /Match Finished/ 868238 / Fulham vs West Ham /2023-04-08 14:00:00+00:00/  UPDATED
#   ______[4/47] #868239 #39 - 2022 - Leeds vs Crystal Palace
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 89
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868239
#   ____________Total API Response(s) : 1
#
# ID :63
# lineups_coach_home_name :Javi Gracia
#   ______________1. /Match Finished/ 868239 / Leeds vs Crystal Palace /2023-04-09 13:00:00+00:00/  UPDATED
#   ______[5/47] #868240 #39 - 2022 - Leicester vs Bournemouth
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 88
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868240
#   ____________Total API Response(s) : 1
#
# ID :46
# lineups_coach_home_name :A. Sadler
#   ______________1. /Match Finished/ 868240 / Leicester vs Bournemouth /2023-04-08 14:00:00+00:00/  UPDATED
#   ______[6/47] #868241 #39 - 2022 - Liverpool vs Arsenal
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 87
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868241
#   ____________Total API Response(s) : 1
#
# ID :40
# lineups_coach_home_name :J. Klopp
#   ______________1. /Match Finished/ 868241 / Liverpool vs Arsenal /2023-04-09 15:30:00+00:00/  UPDATED
#   ______[7/47] #868242 #39 - 2022 - Manchester United vs Everton
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 86
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868242
#   ____________Total API Response(s) : 1
#
# ID :33
# lineups_coach_home_name :E. ten Hag
#   ______________1. /Match Finished/ 868242 / Manchester United vs Everton /2023-04-08 11:30:00+00:00/  UPDATED
#   ______[8/47] #868243 #39 - 2022 - Southampton vs Manchester City
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 85
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868243
#   ____________Total API Response(s) : 1
#
# ID :41
# lineups_coach_home_name :Rubén Sellés
#   ______________1. /Match Finished/ 868243 / Southampton vs Manchester City /2023-04-08 16:30:00+00:00/  UPDATED
#   ______[9/47] #868244 #39 - 2022 - Tottenham vs Brighton
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 84
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868244
#   ____________Total API Response(s) : 1
#
# ID :47
# lineups_coach_home_name :C. Stellini
#   ______________1. /Match Finished/ 868244 / Tottenham vs Brighton /2023-04-08 14:00:00+00:00/  UPDATED
#   ______[10/47] #868245 #39 - 2022 - Wolves vs Chelsea
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 83
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868245
#   ____________Total API Response(s) : 1
#
# ID :39
# lineups_coach_home_name :Lopetegui
#   ______________1. /Match Finished/ 868245 / Wolves vs Chelsea /2023-04-08 14:00:00+00:00/  UPDATED
#   ______[11/47] #868246 #39 - 2022 - Aston Villa vs Newcastle
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 82
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868246
#   ____________Total API Response(s) : 1
#
# ID :66
# lineups_coach_home_name :Unai Emery
#   ______________1. /Match Finished/ 868246 / Aston Villa vs Newcastle /2023-04-15 11:30:00+00:00/  UPDATED
#   ______[12/47] #868247 #39 - 2022 - Chelsea vs Brighton
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 81
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868247
#   ____________Total API Response(s) : 1
#
# ID :49
# lineups_coach_home_name :F. Lampard
#   ______________1. /Match Finished/ 868247 / Chelsea vs Brighton /2023-04-15 14:00:00+00:00/  UPDATED
#   ______[13/47] #868248 #39 - 2022 - Everton vs Fulham
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 80
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868248
#   ____________Total API Response(s) : 1
#
# ID :45
# lineups_coach_home_name :S. Dyche
#   ______________1. /Match Finished/ 868248 / Everton vs Fulham /2023-04-15 14:00:00+00:00/  UPDATED
#   ______[14/47] #868249 #39 - 2022 - Leeds vs Liverpool
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 79
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868249
#   ____________Total API Response(s) : 1
#
# ID :63
# lineups_coach_home_name :Javi Gracia
#   ______________1. /Match Finished/ 868249 / Leeds vs Liverpool /2023-04-17 19:00:00+00:00/  UPDATED
#   ______[15/47] #868250 #39 - 2022 - Manchester City vs Leicester
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 78
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868250
#   ____________Total API Response(s) : 1
#
# ID :50
# lineups_coach_home_name :Pep Guardiola
#   ______________1. /Match Finished/ 868250 / Manchester City vs Leicester /2023-04-15 16:30:00+00:00/  UPDATED
#   ______[16/47] #868251 #39 - 2022 - Nottingham Forest vs Manchester United
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 77
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868251
#   ____________Total API Response(s) : 1
#
# ID :65
# lineups_coach_home_name :S. Cooper
#   ______________1. /Match Finished/ 868251 / Nottingham Forest vs Manchester United /2023-04-16 15:30:00+00:00/  UPDATED
#   ______[17/47] #868252 #39 - 2022 - Southampton vs Crystal Palace
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 76
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868252
#   ____________Total API Response(s) : 1
#
# ID :41
# lineups_coach_home_name :Rubén Sellés
#   ______________1. /Match Finished/ 868252 / Southampton vs Crystal Palace /2023-04-15 14:00:00+00:00/  UPDATED
#   ______[18/47] #868253 #39 - 2022 - Tottenham vs Bournemouth
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 75
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868253
#   ____________Total API Response(s) : 1
#
# ID :47
# lineups_coach_home_name :C. Stellini
#   ______________1. /Match Finished/ 868253 / Tottenham vs Bournemouth /2023-04-15 14:15:00+00:00/  UPDATED
#   ______[19/47] #868254 #39 - 2022 - West Ham vs Arsenal
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 74
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868254
#   ____________Total API Response(s) : 1
#
# ID :48
# lineups_coach_home_name :D. Moyes
#   ______________1. /Match Finished/ 868254 / West Ham vs Arsenal /2023-04-16 13:00:00+00:00/  UPDATED
#   ______[20/47] #868255 #39 - 2022 - Wolves vs Brentford
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 73
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868255
#   ____________Total API Response(s) : 1
#
# ID :39
# lineups_coach_home_name :Lopetegui
#   ______________1. /Match Finished/ 868255 / Wolves vs Brentford /2023-04-15 14:00:00+00:00/  UPDATED
#   ______[21/47] #868256 #39 - 2022 - Bournemouth vs West Ham
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 72
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868256
#   ____________Total API Response(s) : 1
#
# ID :35
# lineups_coach_home_name :G. O\'Neil
#   ______________1. /Match Finished/ 868256 / Bournemouth vs West Ham /2023-04-23 13:00:00+00:00/  UPDATED
#   ______[22/47] #868257 #39 - 2022 - Arsenal vs Southampton
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 71
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868257
#   ____________Total API Response(s) : 1
#
# ID :42
# lineups_coach_home_name :Mikel Arteta
#   ______________1. /Match Finished/ 868257 / Arsenal vs Southampton /2023-04-21 19:00:00+00:00/  UPDATED
#   ______[23/47] #868258 #39 - 2022 - Brentford vs Aston Villa
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 70
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868258
#   ____________Total API Response(s) : 1
#
# ID :55
# lineups_coach_home_name :T. Frank
#   ______________1. /Match Finished/ 868258 / Brentford vs Aston Villa /2023-04-22 14:00:00+00:00/  UPDATED
#   ______[24/47] #868260 #39 - 2022 - Crystal Palace vs Everton
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 69
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868260
#   ____________Total API Response(s) : 1
#
# ID :52
# lineups_coach_home_name :R. Hodgson
#   ______________1. /Match Finished/ 868260 / Crystal Palace vs Everton /2023-04-22 14:00:00+00:00/  UPDATED
#   ______[25/47] #868261 #39 - 2022 - Fulham vs Leeds
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 68
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868261
#   ____________Total API Response(s) : 1
#
# ID :36
# lineups_coach_home_name :Marco Silva
#   ______________1. /Match Finished/ 868261 / Fulham vs Leeds /2023-04-22 11:30:00+00:00/  UPDATED
#   ______[26/47] #868262 #39 - 2022 - Leicester vs Wolves
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 67
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868262
#   ____________Total API Response(s) : 1
#
# ID :46
# lineups_coach_home_name :D. Smith
#   ______________1. /Match Finished/ 868262 / Leicester vs Wolves /2023-04-22 14:00:00+00:00/  UPDATED
#   ______[27/47] #868263 #39 - 2022 - Liverpool vs Nottingham Forest
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 66
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868263
#   ____________Total API Response(s) : 1
#
# ID :40
# lineups_coach_home_name :J. Klopp
#   ______________1. /Match Finished/ 868263 / Liverpool vs Nottingham Forest /2023-04-22 14:00:00+00:00/  UPDATED
#   ______[28/47] #868265 #39 - 2022 - Newcastle vs Tottenham
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 65
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868265
#   ____________Total API Response(s) : 1
#
# ID :34
# lineups_coach_home_name :E. Howe
#   ______________1. /Match Finished/ 868265 / Newcastle vs Tottenham /2023-04-23 13:00:00+00:00/  UPDATED
#   ______[29/47] #868266 #39 - 2022 - Everton vs Newcastle
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 64
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868266
#   ____________Total API Response(s) : 1
#
# ID :45
# lineups_coach_home_name :S. Dyche
#   ______________1. /Match Finished/ 868266 / Everton vs Newcastle /2023-04-27 18:45:00+00:00/  UPDATED
#   ______[30/47] #868267 #39 - 2022 - Leeds vs Leicester
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 63
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868267
#   ____________Total API Response(s) : 1
#
# ID :63
# lineups_coach_home_name :Javi Gracia
#   ______________1. /Match Finished/ 868267 / Leeds vs Leicester /2023-04-25 19:00:00+00:00/  UPDATED
#   ______[31/47] #868268 #39 - 2022 - Nottingham Forest vs Brighton
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 62
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868268
#   ____________Total API Response(s) : 1
#
# ID :65
# lineups_coach_home_name :S. Cooper
#   ______________1. /Match Finished/ 868268 / Nottingham Forest vs Brighton /2023-04-26 18:30:00+00:00/  UPDATED
#   ______[32/47] #868269 #39 - 2022 - Tottenham vs Manchester United
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 61
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868269
#   ____________Total API Response(s) : 1
#
# ID :47
# lineups_coach_home_name :R. Mason
#   ______________1. /Match Finished/ 868269 / Tottenham vs Manchester United /2023-04-27 19:15:00+00:00/  UPDATED
#   ______[33/47] #868270 #39 - 2022 - West Ham vs Liverpool
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 60
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868270
#   ____________Total API Response(s) : 1
#
# ID :48
# lineups_coach_home_name :D. Moyes
#   ______________1. /Match Finished/ 868270 / West Ham vs Liverpool /2023-04-26 18:45:00+00:00/  UPDATED
#   ______[34/47] #868271 #39 - 2022 - Wolves vs Crystal Palace
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 59
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868271
#   ____________Total API Response(s) : 1
#
# ID :39
# lineups_coach_home_name :Lopetegui
#   ______________1. /Match Finished/ 868271 / Wolves vs Crystal Palace /2023-04-25 18:30:00+00:00/  UPDATED
#   ______[35/47] #868272 #39 - 2022 - Aston Villa vs Fulham
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 58
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868272
#   ____________Total API Response(s) : 1
#
# ID :66
# lineups_coach_home_name :Unai Emery
#   ______________1. /Match Finished/ 868272 / Aston Villa vs Fulham /2023-04-25 18:45:00+00:00/  UPDATED
#   ______[36/47] #868273 #39 - 2022 - Chelsea vs Brentford
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 57
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868273
#   ____________Total API Response(s) : 1
#
# ID :49
# lineups_coach_home_name :F. Lampard
#   ______________1. /Match Finished/ 868273 / Chelsea vs Brentford /2023-04-26 18:45:00+00:00/  UPDATED
#   ______[37/47] #868274 #39 - 2022 - Southampton vs Bournemouth
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 56
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868274
#   ____________Total API Response(s) : 1
#
# ID :41
# lineups_coach_home_name :Rubén Sellés
#   ______________1. /Match Finished/ 868274 / Southampton vs Bournemouth /2023-04-27 18:45:00+00:00/  UPDATED
#   ______[38/47] #868275 #39 - 2022 - Manchester City vs Arsenal
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 55
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868275
#   ____________Total API Response(s) : 1
#
# ID :50
# lineups_coach_home_name :Pep Guardiola
#   ______________1. /Match Finished/ 868275 / Manchester City vs Arsenal /2023-04-26 19:00:00+00:00/  UPDATED
#   ______[39/47] #868276 #39 - 2022 - Bournemouth vs Leeds
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 54
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868276
#   ____________Total API Response(s) : 1
# ID :35
# lineups_coach_home_name :G. O\'Neil
#   ______________1. /Match Finished/ 868276 / Bournemouth vs Leeds /2023-04-30 13:00:00+00:00/  UPDATED
#   ______[40/47] #868278 #39 - 2022 - Brentford vs Nottingham Forest
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 53
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868278
#   ____________Total API Response(s) : 1
#
# ID :55
# lineups_coach_home_name :T. Frank
#   ______________1. /Match Finished/ 868278 / Brentford vs Nottingham Forest /2023-04-29 14:00:00+00:00/  UPDATED
#   ______[41/47] #868279 #39 - 2022 - Brighton vs Wolves
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 52
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868279
#   ____________Total API Response(s) : 1
#
# ID :51
# lineups_coach_home_name :R. De Zerbi
#   ______________1. /Match Finished/ 868279 / Brighton vs Wolves /2023-04-29 14:00:00+00:00/  UPDATED
#   ______[42/47] #868280 #39 - 2022 - Crystal Palace vs West Ham
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 51
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868280
#   ____________Total API Response(s) : 1
#
# ID :52
# lineups_coach_home_name :R. Hodgson
#   ______________1. /Match Finished/ 868280 / Crystal Palace vs West Ham /2023-04-29 11:30:00+00:00/  UPDATED
#   ______[43/47] #868281 #39 - 2022 - Fulham vs Manchester City
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 50
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868281
#   ____________Total API Response(s) : 1
#
# ID :36
# lineups_coach_home_name :Marco Silva
#   ______________1. /Match Finished/ 868281 / Fulham vs Manchester City /2023-04-30 13:00:00+00:00/  UPDATED
#   ______[44/47] #868282 #39 - 2022 - Leicester vs Everton
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 49
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868282
#   ____________Total API Response(s) : 1
#
# ID :46
# lineups_coach_home_name :D. Smith
#   ______________1. /Match Finished/ 868282 / Leicester vs Everton /2023-05-01 19:00:00+00:00/  UPDATED
#   ______[45/47] #868283 #39 - 2022 - Liverpool vs Tottenham
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 48
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868283
#   ____________Total API Response(s) : 1
#
# ID :40
# lineups_coach_home_name :J. Klopp
#   ______________1. /Match Finished/ 868283 / Liverpool vs Tottenham /2023-04-30 15:30:00+00:00/  UPDATED
#   ______[46/47] #868284 #39 - 2022 - Manchester United vs Aston Villa
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 47
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868284
#   ____________Total API Response(s) : 1
#
# ID :33
# lineups_coach_home_name :E. ten Hag
#   ______________1. /Match Finished/ 868284 / Manchester United vs Aston Villa /2023-04-30 13:00:00+00:00/  UPDATED
#   ______[47/47] #868285 #39 - 2022 - Newcastle vs Southampton
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 46
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   __________ROUTES : fixtureapi_id
#   __________fixtureapi_id : 868285
#   ____________Total API Response(s) : 1
#
# ID :34
# lineups_coach_home_name :E. Howe
#   ______________1. /Match Finished/ 868285 / Newcastle vs Southampton /2023-04-30 13:00:00+00:00/  UPDATED
# # -------------------------------------------------- End at 2023-05-02 15:34:35
