# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *  
from a_models.football_fixtures import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    space += "__"
    # --------------------------------------------------  
    leagueapi_id = input(space + "Enter your leagueapi id : ")
    season = input(space + "Enter your season : ")
    # --------------------------------------------------    
    ff_get_fixture_that_not_update_stats(leagueapi_id, season, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-06-07 10:52:09
#   __main()
#   ____Enter your leagueapi id : 2
#   ____Enter your season : 2022
#   ______ff_get_fixture_that_not_update_stats()
#   ______ SELECT   leagueapi_id  , season  ,  	teams_homeapi_id  ,  	teams_awayapi_id  , date  , fixtureapi_id FROM football_statistics WHERE leagueapi_id = '2'  and season = '2022'  and fixture_status in ('Match Finished', 'Match Finished Ended')  and shots_on_goal_home is null  and shots_on_goal_away is null
#   ______Total Row(s) : 69
#   ______[1/69] #865411 #2 - 2022 - 2249 vs 3342
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 8
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 865411
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3459
#   __________________name : O. Lasagni
#   __________________fC_insert_new()
#   __________________coacheapi_id : 17491
#   __________________name : Raul Obiols Rodriguez
#   ________________football_odds UPDATED
#
#   ______[2/69] #865410 #2 - 2022 - 2273 vs 278
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 7
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 865410
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 162
#   __________________name : V. Vassiljev
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  162,  'V. Vassiljev',  'https://media-2.api-sports.io/football/coachs/162.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7382
#   __________________name : A. Gunnlaugsson
#   ________________football_odds UPDATED
#
#   ______[3/69] #871876 #2 - 2022 - 3342 vs 278
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 6
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 871876
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 17491
#   __________________name : Raul Obiols Rodriguez
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7382
#   __________________name : A. Gunnlaugsson
#   ________________football_odds UPDATED
#
#   ______[4/69] #866829 #2 - 2022 - 709 vs 2246
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 5
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866829
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5125
#   __________________name : E. Melikyan
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  5125,  'E. Melikyan',  'https://media-1.api-sports.io/football/coachs/5125.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1195
#   __________________name : D. Petrescu
#   ________________football_odds UPDATED
#
#   ______[5/69] #878836 #2 - 2022 - 375 vs 278
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 4
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 878836
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1352
#   __________________name : M. Milojević
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7382
#   __________________name : A. Gunnlaugsson
#   ________________football_odds UPDATED
#
#   ______[6/69] #866833 #2 - 2022 - 566 vs 673
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 3
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866833
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4614
#   __________________name : A. Šimundža
#   __________________fC_insert_new()
#   __________________coacheapi_id : 12094
#   __________________name : M. Savović
#   ________________football_odds UPDATED
#
#   ______[7/69] #866839 #2 - 2022 - 12733 vs 586
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 2
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866839
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   ____________________football_venues INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4399
#   __________________name : I. Daja
#   __________________fC_insert_new()
#   __________________coacheapi_id : 559
#   __________________name : V. Cheburin
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  559,  'V. Cheburin',  'https://media-3.api-sports.io/football/coachs/559.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   ________________football_odds UPDATED
#
#   ______[8/69] #866845 #2 - 2022 - 354 vs 583
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api3@ariondigitalmedia.com counter is 1
#   ____________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866845
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6477
#   __________________name : A. Limbrick
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1578
#   __________________name : D. Healy
#   ________________football_odds UPDATED
#
#   ______[9/69] #866849 #2 - 2022 - 347 vs 556
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 99
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866849
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2003
#   __________________name : J. van den Brom
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1127
#   __________________name : Q. Qurbanov
#   ________________football_odds UPDATED
#
#   ______[10/69] #866847 #2 - 2022 - 652 vs 3884
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 98
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866847
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1563
#   __________________name : S. Bradley
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  1563,  'S. Bradley',  'https://media-3.api-sports.io/football/coachs/1563.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1305
#   __________________name : S. Sanderra
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  1305,  'S. Sanderra',  'https://media-1.api-sports.io/football/coachs/1305.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   ________________football_odds UPDATED
#
#   ______[11/69] #866837 #2 - 2022 - 2259 vs 651
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 97
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866837
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   ____________________football_venues INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4148
#   __________________name : M. Milanović
#   __________________fC_insert_new()
#   __________________coacheapi_id : 79
#   __________________name : S. Cherchesov
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  79,  'S. Cherchesov',  'https://media-3.api-sports.io/football/coachs/79.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   ________________football_odds UPDATED
#
#   ______[12/69] #866841 #2 - 2022 - 649 vs 4160
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 96
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866841
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1782
#   __________________name : T. Koskela
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  1782,  'T. Koskela',  'https://media-1.api-sports.io/football/coachs/1782.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2040
#   __________________name : V. Morozs
#   ________________football_odds UPDATED
#
#   ______[13/69] #866843 #2 - 2022 - 327 vs 701
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 95
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866843
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1952
#   __________________name : K. Knutsen
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2479
#   __________________name : M. Thomassen
#   ________________football_odds UPDATED
#
#   ______[14/69] #866853 #2 - 2022 - 588 vs 568
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 94
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866853
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2721
#   __________________name : S. Jakirović
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6513
#   __________________name : S. Tomas
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  6513,  'S. Tomas',  'https://media-3.api-sports.io/football/coachs/6513.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   ________________football_odds UPDATED
#
#   ______[15/69] #866831 #2 - 2022 - 552 vs 392
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 93
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866831
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1844
#   __________________name : R. Karanović
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  1844,  'R. Karanović',  'https://media-3.api-sports.io/football/coachs/1844.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2492
#   __________________name : S. Tashuev
#   ________________football_odds UPDATED
#
#   ______[16/69] #866842 #2 - 2022 - 4160 vs 649
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 92
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866842
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2040
#   __________________name : V. Morozs
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1782
#   __________________name : T. Koskela
#   ________________football_odds UPDATED
#
#   ______[17/69] #866852 #2 - 2022 - 667 vs 2265
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 91
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866852
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 15030
#   __________________name : Raúl Castillo
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4416
#   __________________name : G. Sedloski
#   ________________football_odds UPDATED
#
#   ______[18/69] #866840 #2 - 2022 - 586 vs 12733
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 90
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866840
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 559
#   __________________name : V. Cheburin
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4399
#   __________________name : I. Daja
#   ________________football_odds UPDATED
#
#   ______[19/69] #866854 #2 - 2022 - 568 vs 588
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 89
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866854
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6513
#   __________________name : S. Tomas
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2721
#   __________________name : S. Jakirović
#   ________________football_odds UPDATED
#
#   ______[20/69] #866848 #2 - 2022 - 3884 vs 652
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 88
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866848
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7731
#   __________________name : A. Pisanu
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1563
#   __________________name : S. Bradley
#   ________________football_odds UPDATED
#
#   ______[21/69] #866834 #2 - 2022 - 673 vs 566
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 87
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866834
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 12094
#   __________________name : M. Savović
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4614
#   __________________name : A. Šimundža
#   ________________football_odds UPDATED
#
#   ______[22/69] #878837 #2 - 2022 - 278 vs 375
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 86
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 878837
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7382
#   __________________name : A. Gunnlaugsson
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1352
#   __________________name : M. Milojević
#   ________________football_odds UPDATED
#
#   ______[23/69] #866844 #2 - 2022 - 701 vs 327
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 85
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866844
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   ____________________football_venues INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2479
#   __________________name : M. Thomassen
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1952
#   __________________name : K. Knutsen
#   ________________football_odds UPDATED
#
#   ______[24/69] #866832 #2 - 2022 - 392 vs 552
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 84
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866832
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2492
#   __________________name : S. Tashuev
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1844
#   __________________name : R. Karanović
#   ________________football_odds UPDATED
#
#   ______[25/69] #866856 #2 - 2022 - 705 vs 656
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 83
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866856
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   ____________________football_venues INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1721
#   __________________name : G. Geguchadze
#   __________________fC_insert_new()
#   __________________coacheapi_id : 185
#   __________________name : V. Weiss
#   ________________football_odds UPDATED
#
#   ______[26/69] #866830 #2 - 2022 - 2246 vs 709
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 82
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 866830
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1195
#   __________________name : D. Petrescu
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5125
#   __________________name : E. Melikyan
#   ________________football_odds UPDATED
#
#   ______[27/69] #897746 #2 - 2022 - 709 vs 578
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 81
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897746
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5125
#   __________________name : E. Melikyan
#   __________________fC_insert_new()
#   __________________coacheapi_id : 8237
#   __________________name : Fangueiro
#   ________________football_odds UPDATED
#
#   ______[28/69] #897748 #2 - 2022 - 586 vs 375
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 80
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897748
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 559
#   __________________name : V. Cheburin
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1352
#   __________________name : M. Milojević
#   ________________football_odds UPDATED
#
#   ______[29/69] #897752 #2 - 2022 - 566 vs 652
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 79
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897752
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4614
#   __________________name : A. Šimundža
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1563
#   __________________name : S. Bradley
#   ________________football_odds UPDATED
#
#   ______[30/69] #897742 #2 - 2022 - 583 vs 327
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 78
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897742
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1578
#   __________________name : D. Healy
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1952
#   __________________name : K. Knutsen
#   ________________football_odds UPDATED
#
#   ______[31/69] #897754 #2 - 2022 - 620 vs 2265
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 77
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897754
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5736
#   __________________name : A. Čačić
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4416
#   __________________name : G. Sedloski
#   ________________football_odds UPDATED
#
#   ______[32/69] #897756 #2 - 2022 - 649 vs 567
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 76
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897756
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1782
#   __________________name : T. Koskela
#   __________________fC_insert_new()
#   __________________coacheapi_id : 47
#   __________________name : M. Bílek
#   ________________football_odds UPDATED
#
#   ______[33/69] #867213 #2 - 2022 - 4195 vs 553
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 75
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 867213
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2494
#   __________________name : B. Bakhar
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1099
#   __________________name : Pedro Martins
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  1099,  'Pedro Martins',  'https://media-3.api-sports.io/football/coachs/1099.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   ________________football_odds UPDATED
#
#   ______[34/69] #867217 #2 - 2022 - 572 vs 611
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 74
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 867217
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2467
#   __________________name : M. Lucescu
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  2467,  'M. Lucescu',  'https://media-1.api-sports.io/football/coachs/2467.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 123
#   __________________name : Jorge Jesus
#   ________________football_odds UPDATED
#
#   ______[35/69] #897740 #2 - 2022 - 651 vs 656
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 73
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897740
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 79
#   __________________name : S. Cherchesov
#   __________________fC_insert_new()
#   __________________coacheapi_id : 185
#   __________________name : V. Weiss
#   ________________football_odds UPDATED
#
#   ______[36/69] #897744 #2 - 2022 - 552 vs 568
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 72
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897744
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1844
#   __________________name : R. Karanović
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6513
#   __________________name : S. Tomas
#   ________________football_odds UPDATED
#
#   ______[37/69] #897745 #2 - 2022 - 568 vs 552
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 71
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897745
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6513
#   __________________name : S. Tomas
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1844
#   __________________name : R. Karanović
#   ________________football_odds UPDATED
#
#   ______[38/69] #897757 #2 - 2022 - 567 vs 649
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 70
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897757
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 47
#   __________________name : M. Bílek
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1782
#   __________________name : T. Koskela
#   ________________football_odds UPDATED
#
#   ______[39/69] #897747 #2 - 2022 - 578 vs 709
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 69
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897747
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   ____________________football_venues INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 8237
#   __________________name : Fangueiro
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5125
#   __________________name : E. Melikyan
#   ________________football_odds UPDATED
#
#   ______[40/69] #897755 #2 - 2022 - 2265 vs 620
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 68
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897755
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4416
#   __________________name : G. Sedloski
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5736
#   __________________name : A. Čačić
#   ________________football_odds UPDATED
#
#   ______[41/69] #897743 #2 - 2022 - 327 vs 583
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 67
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897743
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1952
#   __________________name : K. Knutsen
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1578
#   __________________name : D. Healy
#   ________________football_odds UPDATED
#
#   ______[42/69] #897741 #2 - 2022 - 656 vs 651
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 66
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 897741
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 185
#   __________________name : V. Weiss
#   __________________fC_insert_new()
#   __________________coacheapi_id : 79
#   __________________name : S. Cherchesov
#   ________________football_odds UPDATED
#
#   ______[43/69] #867214 #2 - 2022 - 553 vs 4195
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 65
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 867214
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   ____________________football_venues INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1099
#   __________________name : Pedro Martins
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2494
#   __________________name : B. Bakhar
#   ________________football_odds UPDATED
#
#   ______[44/69] #923125 #2 - 2022 - 568 vs 567
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 64
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 923125
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 6513
#   __________________name : S. Tomas
#   __________________fC_insert_new()
#   __________________coacheapi_id : 47
#   __________________name : M. Bílek
#   ________________football_odds UPDATED
#
#   ______[45/69] #923123 #2 - 2022 - 566 vs 620
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 63
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 923123
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4614
#   __________________name : A. Šimundža
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5736
#   __________________name : A. Čačić
#   ________________football_odds UPDATED
#
#   ______[46/69] #901886 #2 - 2022 - 1393 vs 257
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 62
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 901886
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 17637
#   __________________name : K. Geraerts
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3102
#   __________________name : G. van Bronckhorst
#   ________________football_odds UPDATED
#
#   ______[47/69] #924399 #2 - 2022 - 327 vs 586
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 61
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 924399
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1952
#   __________________name : K. Knutsen
#   __________________fC_insert_new()
#   __________________coacheapi_id : 559
#   __________________name : V. Cheburin
#   ________________football_odds UPDATED
#
#   ______[48/69] #924401 #2 - 2022 - 4195 vs 602
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 60
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 924401
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2494
#   __________________name : B. Bakhar
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2868
#   __________________name : A. Zorniger
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  2868,  'A. Zorniger',  'https://media-1.api-sports.io/football/coachs/2868.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   ________________football_odds UPDATED
#
#   ______[49/69] #923129 #2 - 2022 - 598 vs 709
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 59
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 923129
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7766
#   __________________name : D. Stanković
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5125
#   __________________name : E. Melikyan
#   ________________football_odds UPDATED
#
#   ______[50/69] #923130 #2 - 2022 - 709 vs 598
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 58
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 923130
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 5125
#   __________________name : E. Melikyan
#   __________________fC_insert_new()
#   __________________coacheapi_id : 7766
#   __________________name : D. Stanković
#   ________________football_odds UPDATED
#
#   ______[51/69] #924402 #2 - 2022 - 602 vs 4195
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 57
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 924402
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   ____________________football_venues INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2868
#   __________________name : A. Zorniger
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2494
#   __________________name : B. Bakhar
#   ________________football_odds UPDATED
#
#   ______[52/69] #971798 #2 - 2022 - 211 vs 569
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 56
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 971798
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   ____________________football_venues INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 57
#   __________________name : R. Schmidt
#   __________________fC_insert_new()
#   __________________coacheapi_id : 87
#   __________________name : S. Parker
#   ________________football_odds UPDATED
#
#   ______[53/69] #971800 #2 - 2022 - 49 vs 165
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 55
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 971800
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 12
#   __________________name : G. Potter
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  12,  'G. Potter',  'https://media-2.api-sports.io/football/coachs/12.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 13491
#   __________________name : E. Terzić
#   ________________football_odds UPDATED
#
#   ______[54/69] #971794 #2 - 2022 - 47 vs 489
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 54
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 971794
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2425
#   __________________name : A. Conte
#   ____________________INSERT INTO `football_coaches`(  `coachapi_id`,  `name`,  `image`,  `created_at`  ) VALUES (  2425,  'A. Conte',  'https://media-2.api-sports.io/football/coachs/2425.png',  current_timestamp )
#   ____________________football_coaches INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3733
#   __________________name : S. Pioli
#   ________________football_odds UPDATED
#
#   ______[55/69] #971796 #2 - 2022 - 157 vs 85
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 53
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 971796
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1545
#   __________________name : J. Nagelsmann
#   __________________fC_insert_new()
#   __________________coacheapi_id : 36
#   __________________name : C. Galtier
#   ________________football_odds UPDATED
#
#   ______[56/69] #971806 #2 - 2022 - 50 vs 173
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 52
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 971806
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4
#   __________________name : Pep Guardiola
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1540
#   __________________name : M. Rose
#   ________________football_odds UPDATED
#
#   ______[57/69] #971808 #2 - 2022 - 212 vs 505
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 51
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 971808
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2204
#   __________________name : Sérgio Conceição
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2392
#   __________________name : S. Inzaghi
#   ________________football_odds UPDATED
#
#   ______[58/69] #971802 #2 - 2022 - 541 vs 40
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 50
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 971802
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2407
#   __________________name : C. Ancelotti
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1
#   __________________name : J. Klopp
#   ________________football_odds UPDATED
#
#   ______[59/69] #971804 #2 - 2022 - 492 vs 169
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 49
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 971804
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2914
#   __________________name : L. Spalletti
#   __________________fC_insert_new()
#   __________________coacheapi_id : 1534
#   __________________name : O. Glasner
#   ________________football_odds UPDATED
#
#   ______[60/69] #1016055 #2 - 2022 - 211 vs 505
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 48
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 1016055
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   ____________________football_venues INSERTED
#   __________________fC_insert_new()
#   __________________coacheapi_id : 57
#   __________________name : R. Schmidt
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2392
#   __________________name : S. Inzaghi
#   ________________football_odds UPDATED
#
#   ______[61/69] #1016057 #2 - 2022 - 50 vs 157
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 47
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 1016057
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4
#   __________________name : Pep Guardiola
#   __________________fC_insert_new()
#   __________________coacheapi_id : 40
#   __________________name : T. Tuchel
#   ________________football_odds UPDATED
#
#   ______[62/69] #1016059 #2 - 2022 - 541 vs 49
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 46
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 1016059
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2407
#   __________________name : C. Ancelotti
#   __________________fC_insert_new()
#   __________________coacheapi_id : 20
#   __________________name : F. Lampard
#   ________________football_odds UPDATED
#
#   ______[63/69] #1016061 #2 - 2022 - 489 vs 492
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 45
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 1016061
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3733
#   __________________name : S. Pioli
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2914
#   __________________name : L. Spalletti
#   ________________football_odds UPDATED
#
#   ______[64/69] #1016056 #2 - 2022 - 505 vs 211
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 44
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 1016056
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2392
#   __________________name : S. Inzaghi
#   __________________fC_insert_new()
#   __________________coacheapi_id : 57
#   __________________name : R. Schmidt
#   ________________football_odds UPDATED
#
#   ______[65/69] #1016058 #2 - 2022 - 157 vs 50
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 43
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 1016058
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 40
#   __________________name : T. Tuchel
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4
#   __________________name : Pep Guardiola
#   ________________football_odds UPDATED
#
#   ______[66/69] #1022983 #2 - 2022 - 489 vs 505
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 42
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 1022983
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3733
#   __________________name : S. Pioli
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2392
#   __________________name : S. Inzaghi
#   ________________football_odds UPDATED
#
#   ______[67/69] #1022981 #2 - 2022 - 541 vs 50
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 41
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 1022981
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2407
#   __________________name : C. Ancelotti
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4
#   __________________name : Pep Guardiola
#   ________________football_odds UPDATED
#
#   ______[68/69] #1022982 #2 - 2022 - 50 vs 541
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 40
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 1022982
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 4
#   __________________name : Pep Guardiola
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2407
#   __________________name : C. Ancelotti
#   ________________football_odds UPDATED
#
#   ______[69/69] #1022984 #2 - 2022 - 505 vs 489
#   ________af_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api4@ariondigitalmedia.com counter is 39
#   ____________APIkey: 03bea24719msh05aea1e5cc15e89p10ac26jsne1f972cc6037
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________af_response_fixtures()
#   ____________ROUTES : fixtureapi_id
#   ____________fixtureapi_id : 1022984
#   ______________Total API Response(s) : 1
#   ________________fixture_status: Match Finished
#   __________________fC_insert_new()
#   __________________coacheapi_id : 2392
#   __________________name : S. Inzaghi
#   __________________fC_insert_new()
#   __________________coacheapi_id : 3733
#   __________________name : S. Pioli
#   ________________football_odds UPDATED
#
# # -------------------------------------------------- End at 2023-06-07 11:11:06
