# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = "Select "
query += " (goals_home + goals_away) as total_goals "
# ---------------------------------------------------------- 
query += " , (select name from football_teams where football_teams.teamapi_id = football_odds.teams_homeapi_id)  "
query += " , (select name from football_teams where football_teams.teamapi_id = football_odds.teams_awayapi_id) "
# ---------------------------------------------------------- 
query += " , goals_home " 
query += " , goals_away "
# ---------------------------------------------------------- 
query += " , pre_goals_overunder_over_95 " 
query += " , pre_goals_overunder_under_95 " 
# ---------------------------------------------------------- 
query += " , end_goals_overunder_over_95 "
query += " , end_goals_overunder_under_95 " 
# ---------------------------------------------------------- 
 
# ---------------------------------------------------------- 
query += " from football_odds " 
query += " where (goals_home + goals_away) > 9 " 
query += " and pre_goals_overunder_over_95 is not null " 
query += " and end_goals_overunder_over_95 is not null " 
query += " order by (goals_home + goals_away) desc " 
query += " limit 10 " 
# ---------------------------------------------------------- 
print(space + query, flush=True) 
# ----------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall() 
# ----------------------------------------------------------     
space += "__"
total_rows = len(result)
# ----------------------------------------------------------    
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------  
count_rows = 0
# ----------------------------------------------------------    
space += "__"
# ----------------------------------------------------------    
counter = 0
# ----------------------------------------------------------    
for x in result: 
    # ------------------------------------------------------   
    counter += 1
    # ------------------------------------------------------   
    total_goals = str(x[0])
    home = str(x[1])
    away = str(x[2])
    # ------------------------------------------------------  
    goals_home = str(x[3])
    goals_away = str(x[4])
    # ------------------------------------------------------  
    pre_o95 = str(x[5])
    pre_u95 = str(x[6])
    # ------------------------------------------------------  
    end_o95 = str(x[7])
    end_u95 = str(x[8])
    # ------------------------------------------------------   
    word = space + str(total_goals)   
    word += " " + home 
    word += " " + goals_home 
    word += " vs " + goals_away 
    word += " " + away 
    # ------------------------------------------------------  
    word += " pre_o95:" + pre_o95 
    word += " pre_u95:" + pre_u95 
    # ------------------------------------------------------  
    word += " end_o95:" + end_o95 
    word += " end_u95:" + end_u95 
    # ------------------------------------------------------  
    print(word, flush=True)
    # ------------------------------------------------------
# Out:
# __Select  (goals_home + goals_away) as total_goals  , (select name from football_teams where football_teams.teamapi_id = football_odds.teams_homeapi_id)   , (select name from football_teams where football_teams.teamapi_id = football_odds.teams_awayapi_id)  , goals_home  , goals_away  , pre_goals_overunder_over_95  , pre_goals_overunder_under_95  , end_goals_overunder_over_95  , end_goals_overunder_under_95  from football_odds  where (goals_home + goals_away) > 9  and pre_goals_overunder_over_95 is not null  and end_goals_overunder_over_95 is not null  order by (goals_home + goals_away) desc  limit 10
# ____Total Row(s) : 4
# ______11 Young Lions 1 vs 10 Home United pre_o95:26.0 pre_u95:1.01 end_o95:26.0 end_u95:1.01
# ______11 Slovan Bystrička 1 vs 10 Považská Bystrica pre_o95:17.0 pre_u95:1.01 end_o95:17.0 end_u95:1.01
# ______11 Arendal 11 vs 0 Millwall pre_o95:17.0 pre_u95:1.01 end_o95:13.0 end_u95:1.01
# ...

# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = "Select "
query += " (goals_home + goals_away) as total_goals "
# ---------------------------------------------------------- 
query += " , (select name from football_teams where football_teams.teamapi_id = football_odds.teams_homeapi_id)  "
query += " , (select name from football_teams where football_teams.teamapi_id = football_odds.teams_awayapi_id) "
# ---------------------------------------------------------- 
query += " , goals_home " 
query += " , goals_away "
# ---------------------------------------------------------- 
query += " , pre_goals_overunder_over_95 " 
query += " , pre_goals_overunder_under_95 " 
# ---------------------------------------------------------- 
query += " , end_goals_overunder_over_95 "
query += " , end_goals_overunder_under_95 " 
# ---------------------------------------------------------- 
 
# ---------------------------------------------------------- 
query += " from football_odds " 
query += " where pre_goals_overunder_over_95 > 17.0 "  
query += " order by (goals_home + goals_away) desc " 
query += " limit 10 " 
# ---------------------------------------------------------- 
print(space + query, flush=True) 
# ----------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall() 
# ----------------------------------------------------------     
space += "__"
total_rows = len(result)
# ----------------------------------------------------------    
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------  
count_rows = 0
# ----------------------------------------------------------    
space += "__"
# ----------------------------------------------------------    
counter = 0
# ----------------------------------------------------------    
for x in result: 
    # ------------------------------------------------------   
    counter += 1
    # ------------------------------------------------------   
    total_goals = str(x[0])
    home = str(x[1])
    away = str(x[2])
    # ------------------------------------------------------  
    goals_home = str(x[3])
    goals_away = str(x[4])
    # ------------------------------------------------------  
    pre_o95 = str(x[5])
    pre_u95 = str(x[6])
    # ------------------------------------------------------  
    end_o95 = str(x[7])
    end_u95 = str(x[8])
    # ------------------------------------------------------   
    word = space + str(total_goals)   
    word += " " + home 
    word += " " + goals_home 
    word += " vs " + goals_away 
    word += " " + away 
    # ------------------------------------------------------  
    word += " pre_o95:" + pre_o95 
    word += " pre_u95:" + pre_u95 
    # ------------------------------------------------------  
    word += " end_o95:" + end_o95 
    word += " end_u95:" + end_u95 
    # ------------------------------------------------------  
    print(word, flush=True)
    # ------------------------------------------------------
