# %%
import datetime 

def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 
    
space = "  __"
leagueapi_id   = input(space + "Enter your leagueapi id :  ")
season         = input(space + "Enter your season :  ")  
 
date_0         = get_today(0, space).strftime("%Y-%m-%d")
print(space + "______date_0 : " + date_0, flush=True)
date_raw       = get_today(0, space)  

date_1         = get_today(1, space).strftime("%Y-%m-%d")
print(space + "______date_1 : " + date_1, flush=True)
date_1_raw     = get_today(1, space)
# Out:
#   __Enter your leagueapi id :  2
#   __Enter your season :  2022
#   ____get_today()
#   ______date_diff : 0
#   ______today_raw : 2023-04-13 01:46:46.344799
#   ________date_0 : 2023-04-13
#   ____get_today()
#   ______date_diff : 0
#   ______today_raw : 2023-04-13 01:46:46.344799
#   ____get_today()
#   ______date_diff : 1
#   ______today_raw : 2023-04-14 01:46:46.344799
#   ________date_1 : 2023-04-14
#   ____get_today()
#   ______date_diff : 1
#   ______today_raw : 2023-04-14 01:46:46.344799

# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.leagues import *  
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "__"  
    # ----------------------------------------------------------  
    lg_get_league_for_predates(leagueapi_id, season, 1, date_0, date_raw, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-13 01:41:35
#   ____main__
#   ______lg_get_league_for_predates()
#   ________bookmakersapi_id : 8
#   ________bookmakersname : Bet365
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 31
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-04-13
#   ______________date_raw : 2023-04-13 01:41:34.958387
#   ______________bookmaker : 8
#   ______________season : 2022
#   ______________league : 2
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 6
#
#   ________________1. World,  UEFA Champions League  #2 - 2022 / 1016057
#   ________________fixt date 2023-04-11 19:00:00+00:00
#   ________________fix local 2023-04-12 02:00:00
#   ________________local dat 2023-04-13 01:41:34
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________2. World,  UEFA Champions League  #2 - 2022 / 1016055
#   ________________fixt date 2023-04-11 19:00:00+00:00
#   ________________fix local 2023-04-12 02:00:00
#   ________________local dat 2023-04-13 01:41:34
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________3. World,  UEFA Champions League  #2 - 2022 / 1016058
#   ________________fixt date 2023-04-19 19:00:00+00:00
#   ________________fix local 2023-04-20 02:00:00
#   ________________local dat 2023-04-13 01:41:34
#   ________________Lebih
#   __________________league_rLeagues_id : 2
#   __________________league_rLeagues_name : UEFA Champions League
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   __________________8==8
#   __________________<tr><td>Home/Away Home</td><td>1.83</td></tr>
#   __________________<tr><td>Home/Away Away</td><td>1.83</td></tr>
#   __________________<tr><td>Asian Handicap Home +0</td><td>1.98</td></tr>
#   __________________<tr><td>Asian Handicap First Half Home +0</td><td>1.98</td></tr>
#   __________________ pre_special_odds = '<tr><td>Home/Away Home</td><td>1.83</td></tr><tr><td>Home/Away Away</td><td>1.83</td></tr><tr><td>Asian Handicap Home +0</td><td>1.98</td></tr><tr><td>Asian Handicap First Half Home +0</td><td>1.98</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#
#   __________________4. World,  UEFA Champions League  #2 - 2022 / 1016056
#   __________________fixt date 2023-04-19 19:00:00+00:00
#   __________________fix local 2023-04-20 02:00:00
#   __________________local dat 2023-04-13 01:41:34
#   __________________Lebih
#   ____________________league_rLeagues_id : 2
#   ____________________league_rLeagues_name : UEFA Champions League
#   ____________________bookmakersapi_rLeagues_id : 8
#   ____________________bookmakers_rLeagues_name : Bet365
#   __________________Total fixtureapi_id Row(s) : 1
#   __________________good to Go 1
#   ____________________8==8
#
#   ____________________5. World,  UEFA Champions League  #2 - 2022 / 1016061
#   ____________________fixt date 2023-04-12 19:00:00+00:00
#   ____________________fix local 2023-04-13 02:00:00
#   ____________________local dat 2023-04-13 01:41:34
#   ____________________Lebih
#   ______________________league_rLeagues_id : 2
#   ______________________league_rLeagues_name : UEFA Champions League
#   ______________________bookmakersapi_rLeagues_id : 8
#   ______________________bookmakers_rLeagues_name : Bet365
#   ____________________Total fixtureapi_id Row(s) : 1
#   ____________________good to Go 1
#   ______________________8==8
#   ______________________<tr><td>Goals Over/Under First Half Over 0.75</td><td>1.83</td></tr>
#   ______________________<tr><td>Asian Handicap First Half Away +0</td><td>1.98</td></tr>
#   ______________________<tr><td>To Win Either Half Home</td><td>1.83</td></tr>
#   ______________________<tr><td>Corners 1x2 Away</td><td>1.83</td></tr>
#   ______________________<tr><td>Goal Line (1st Half) Over 0.75</td><td>1.83</td></tr>
#   ______________________<tr><td>Away Corners Over/Under Over 4.5</td><td>1.83</td></tr>
#   ______________________<tr><td>Away Corners Over/Under Under 4.5</td><td>1.83</td></tr>
#   ______________________<tr><td>Away Team Total Cards Over 2.5</td><td>1.83</td></tr>
#   ______________________<tr><td>Away Team Total Cards Under 2.5</td><td>1.83</td></tr>
#   ______________________ pre_special_odds = '<tr><td>Goals Over/Under First Half Over 0.75</td><td>1.83</td></tr><tr><td>Asian Handicap First Half Away +0</td><td>1.98</td></tr><tr><td>To Win Either Half Home</td><td>1.83</td></tr><tr><td>Corners 1x2 Away</td><td>1.83</td></tr><tr><td>Goal Line (1st Half) Over 0.75</td><td>1.83</td></tr><tr><td>Away Corners Over/Under Over 4.5</td><td>1.83</td></tr><tr><td>Away Corners Over/Under Under 4.5</td><td>1.83</td></tr><tr><td>Away Team Total Cards Over 2.5</td><td>1.83</td></tr><tr><td>Away Team Total Cards Under 2.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#
#   ______________________6. World,  UEFA Champions League  #2 - 2022 / 1016059
#   ______________________fixt date 2023-04-12 19:00:00+00:00
#   ______________________fix local 2023-04-13 02:00:00
#   ______________________local dat 2023-04-13 01:41:34
#   ______________________Lebih
#   ________________________league_rLeagues_id : 2
#   ________________________league_rLeagues_name : UEFA Champions League
#   ________________________bookmakersapi_rLeagues_id : 8
#   ________________________bookmakers_rLeagues_name : Bet365
#   ______________________Total fixtureapi_id Row(s) : 1
#   ______________________good to Go 1
#   ________________________8==8
#   ________________________<tr><td>Goals Over/Under First Half Under 1.0</td><td>1.98</td></tr>
#   ________________________<tr><td>Goal Line (1st Half) Under 1</td><td>1.98</td></tr>
#   ________________________<tr><td>Corners Asian Handicap Home -1</td><td>1.83</td></tr>
#   ________________________<tr><td>Corners Asian Handicap Away -1</td><td>1.98</td></tr>
#   ________________________<tr><td>Away Team Total Cards Over 2.5</td><td>1.83</td></tr>
#   ________________________<tr><td>Away Team Total Cards Under 2.5</td><td>1.83</td></tr>
#   ________________________ pre_special_odds = '<tr><td>Goals Over/Under First Half Under 1.0</td><td>1.98</td></tr><tr><td>Goal Line (1st Half) Under 1</td><td>1.98</td></tr><tr><td>Corners Asian Handicap Home -1</td><td>1.83</td></tr><tr><td>Corners Asian Handicap Away -1</td><td>1.98</td></tr><tr><td>Away Team Total Cards Over 2.5</td><td>1.83</td></tr><tr><td>Away Team Total Cards Under 2.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#   __________________________ff_update_unfinished__
#   ________________________  > No longer get supported
# # -------------------------------------------------- End at 2023-04-13 01:41:50

# %%
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # -------------------------------------------------- 
    ff_get_fixture_today_xpattern_advices_preleague(leagueapi_id, season, date_0, date_1, "xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-13 01:47:06
#   __main()
#   ______ff_get_fixture_today_xpattern_advices_preleague()
#   ________Select  date,   fixtureapi_id,   league_country,   league_name,   season,   teams_home,   teams_away   from football_fixtures  where leagueapi_id = '2'  and season = '2022'  and fixture_status = 'Not Started'  order by date asc
#   ________Total Row(s) : 8
#   ________[1/8] 2023-04-11 19:00:00
#   ________World - UEFA Champions League 2022
# #1016055  Benfica vs Inter
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016055
#   __________> pre_ah_pattern = 05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+H
#   __________> pre_gou_pattern = 2g225g25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern = '05_025_0#H'
#   __________     and pre_gou_pattern = '2g225g25gG'
#   __________     and end_ah_pattern = '05_025_0#H'
#   __________     and end_gou_pattern = '2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136421
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern_mirror = '05_025_0#H'
#   __________     and pre_gou_pattern = '2g225g25gG'
#   __________     and end_ah_pattern_mirror = '05_025_0#H'
#   __________     and end_gou_pattern = '2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136421
#   __________       --UPDATED--
#   ________[2/8] 2023-04-11 19:00:00
#   ________World - UEFA Champions League 2022
# #1016057  Manchester City vs Bayern Munich
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016057
#   __________> pre_ah_pattern = 125_1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+125+H
#   __________> pre_gou_pattern = 25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern = '125_1_075_05_H'
#   __________     and pre_gou_pattern = '25g275g3g325gG'
#   __________     and end_ah_pattern = '125_1_075_05_H'
#   __________     and end_gou_pattern = '25g275g3g325gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136423
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern_mirror = '125_1_075_05_H'
#   __________     and pre_gou_pattern = '25g275g3g325gG'
#   __________     and end_ah_pattern_mirror = '125_1_075_05_H'
#   __________     and end_gou_pattern = '25g275g3g325gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136423
#   __________       --UPDATED--
#   ________[3/8] 2023-04-12 19:00:00
#   ________World - UEFA Champions League 2022
# #1016059  Real Madrid vs Chelsea
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016059
#   __________> pre_ah_pattern = 125_1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+125+H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern = '125_1_075_05_H'
#   __________     and pre_gou_pattern = '225g25g275gG'
#   __________     and end_ah_pattern = '125_1_075_05_H'
#   __________     and end_gou_pattern = '225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136425
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern_mirror = '125_1_075_05_H'
#   __________     and pre_gou_pattern = '225g25g275gG'
#   __________     and end_ah_pattern_mirror = '125_1_075_05_H'
#   __________     and end_gou_pattern = '225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136425
#   __________       --UPDATED--
#   ________[4/8] 2023-04-12 19:00:00
#   ________World - UEFA Champions League 2022
# #1016061  AC Milan vs Napoli
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016061
#   __________> pre_ah_pattern = 025_0#025+H
#   __________> pre_ah_pattern_mirror = 025_0#025+H
#   __________> pre_gou_pattern = 175g2g225gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern = '025_0#025+H'
#   __________     and pre_gou_pattern = '175g2g225gG'
#   __________     and end_ah_pattern = '025_0#025+H'
#   __________     and end_gou_pattern = '175g2g225gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136427
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern_mirror = '025_0#025+H'
#   __________     and pre_gou_pattern = '175g2g225gG'
#   __________     and end_ah_pattern_mirror = '025_0#025+H'
#   __________     and end_gou_pattern = '175g2g225gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136427
#   __________       --UPDATED--
#   ________[5/8] 2023-04-18 19:00:00
#   ________World - UEFA Champions League 2022
# #1016060  Chelsea vs Real Madrid
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016060
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:136426
#   __________     total_fixtures:369
#   __________       UPDATE `football_fixtures` SET `pre_advices` = '<span class="badge bg-dark">Total pre  Fixture(s) = 369</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o15 - 80%</span> <span class="badge bg-gradient-danger">u45 - 84%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136426
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:136426
#   __________     total_fixtures:369
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = '<span class="badge bg-gray-800">Total pre Mirror Fixture(s) = 369</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o15 - 80%</span> <span class="badge bg-gradient-danger">u45 - 84%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136426
#   __________       --UPDATED--
#   ________[6/8] 2023-04-18 19:00:00
#   ________World - UEFA Champions League 2022
# #1016062  Napoli vs AC Milan
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016062
#   __________> pre_ah_pattern = H
#   __________> pre_ah_pattern_mirror = H
#   __________> pre_gou_pattern = G
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:136428
#   __________     total_fixtures:369
#   __________       UPDATE `football_fixtures` SET `pre_advices` = '<span class="badge bg-dark">Total pre  Fixture(s) = 369</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o15 - 80%</span> <span class="badge bg-gradient-danger">u45 - 84%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136428
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern_mirror = 'H'
#   __________     and pre_gou_pattern = 'G'
#   __________     and end_ah_pattern_mirror = 'H'
#   __________     and end_gou_pattern = 'G'
#   __________    Total Row(s) : 1
#
#   __________     idx:136428
#   __________     total_fixtures:369
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = '<span class="badge bg-gray-800">Total pre Mirror Fixture(s) = 369</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o15 - 80%</span> <span class="badge bg-gradient-danger">u45 - 84%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136428
#   __________       --UPDATED--
#   ________[7/8] 2023-04-19 19:00:00
#   ________World - UEFA Champions League 2022
# #1016056  Inter vs Benfica
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016056
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 225g25g275gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern = '075_05_025_H'
#   __________     and pre_gou_pattern = '225g25g275gG'
#   __________     and end_ah_pattern = '075_05_025_H'
#   __________     and end_gou_pattern = '225g25g275gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:136422
#   __________     total_fixtures:1
#   __________       UPDATE `football_fixtures` SET `pre_advices` = '<span class="badge bg-dark">Total pre  Fixture(s) = 1</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o55 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><a href="" class="badge bg-gradient-primary">Hwin - 100%</a> <span class="badge bg-gradient-primary">Home0 - 100%</span> <span class="badge bg-gradient-primary">H-eithr - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-gray-700">xG->7 - 100%</span> <span class="badge bg-gradient-gray-700">xgH->3 - 100%</span> <span class="badge bg-gradient-gray-700">xgA->3 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-custom-teal">Bty - 100%</span> <span class="badge bg-gradient-custom-teal">csn-H - 100%</span> <span class="badge bg-gradient-custom-teal">csn-A - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-orange-red">odd - 100%</span> <span class="badge bg-gradient-purple">o1st - 100%</span> <span class="badge bg-gradient-purple">xG1st-4 - 100%</span> <span class="badge bg-gradient-warning">xG2nd-3 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136422
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern_mirror = '075_05_025_H'
#   __________     and pre_gou_pattern = '225g25g275gG'
#   __________     and end_ah_pattern_mirror = '075_05_025_H'
#   __________     and end_gou_pattern = '225g25g275gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136422
#   __________       --UPDATED--
#   ________[8/8] 2023-04-19 19:00:00
#   ________World - UEFA Champions League 2022
# #1016058  Bayern Munich vs Manchester City
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016058
#   __________> pre_ah_pattern = 025_0#025+05+H
#   __________> pre_ah_pattern_mirror = 05_025_0#025+H
#   __________> pre_gou_pattern = 275g3g325g35gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern = '025_0#025+05+H'
#   __________     and pre_gou_pattern = '275g3g325g35gG'
#   __________     and end_ah_pattern = '025_0#025+05+H'
#   __________     and end_gou_pattern = '275g3g325g35gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136424
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '2'
#   __________     and pre_ah_pattern_mirror = '025_0#025+05+H'
#   __________     and pre_gou_pattern = '275g3g325g35gG'
#   __________     and end_ah_pattern_mirror = '025_0#025+05+H'
#   __________     and end_gou_pattern = '275g3g325g35gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:136424
#   __________     total_fixtures:1
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = '<span class="badge bg-gray-800">Total pre Mirror Fixture(s) = 1</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o05 - 100%</span> <span class="badge bg-gradient-danger">u15 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-warning">Awin - 0%</span> <span class="badge bg-gradient-warning">Away0 - 0%</span> <span class="badge bg-gradient-warning">Anil - 0%</span> <span class="badge bg-gradient-warning">A-eithr - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-gray-700">xG-1 - 100%</span> <span class="badge bg-gradient-gray-700">xgA-1 - 0%</span> <span class="badge bg-gradient-gray-700">xgH-0 - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-custom-pink">Btn - 100%</span> <span class="badge bg-gradient-custom-pink">csy-A - 0%</span> <span class="badge bg-gradient-custom-teal">csn-H - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-orange-red">odd - 100%</span> <span class="badge bg-gradient-warning">o2nd - 100%</span> <span class="badge bg-gradient-purple">xG1st-0 - 100%</span> <span class="badge bg-gradient-warning">xG2nd-1 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136424
#   __________       --UPDATED--
# # -------------------------------------------------- End at 2023-04-13 01:49:09

# %%
import sys
sys.path.append('../')

from a_settings.messages import *    
from a_models.predefine import *  
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------     
    pd_get_fixtures_next_match(leagueapi_id, season, 'preleague', space) 
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-13 01:41:51
#   __main()
#   ______pd_get_fixtures_next_match()
#   ________Total Row(s) : 8
#   __________[1/8] 2 - 2022 -----#Benfica 211 - Inter 505 - 2023-04-11 19:00:00
#   __________good_to_go: 0
#
#   __________[2/8] 2 - 2022 -----#Manchester City 50 - Bayern Munich 157 - 2023-04-11 19:00:00
#   ____________pre_second_half_winner_home:1.91
#   __________good_to_go: 1
#
#   __________[3/8] 2 - 2022 -----#Real Madrid 541 - Chelsea 49 - 2023-04-12 19:00:00
#   ____________pre_second_half_winner_home:1.95
#   __________good_to_go: 1
#
#   __________[4/8] 2 - 2022 -----#AC Milan 489 - Napoli 492 - 2023-04-12 19:00:00
#   ____________pre_first_half_winner_draw:1.95
#   ____________pre_total_goals_both_teams_to_score_under_no_25:1.95
#   __________good_to_go: 1
#
#   __________[5/8] 2 - 2022 -----#Chelsea 49 - Real Madrid 541 - 2023-04-18 19:00:00
#   __________good_to_go: 0
#
#   __________[6/8] 2 - 2022 -----#Napoli 492 - AC Milan 489 - 2023-04-18 19:00:00
#   __________good_to_go: 0
#
#   __________[7/8] 2 - 2022 -----#Inter 505 - Benfica 211 - 2023-04-19 19:00:00
#   __________good_to_go: 0
#
#   __________[8/8] 2 - 2022 -----#Bayern Munich 157 - Manchester City 50 - 2023-04-19 19:00:00
#   ____________pre_total_goals_both_teams_to_score_over_yes_25:1.73
#   ____________pre_both_teams_score_no:2.5
#   __________good_to_go: 1
#
# # -------------------------------------------------- End at 2023-04-13 01:41:56
