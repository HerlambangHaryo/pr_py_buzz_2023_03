# %%
import datetime 

def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 
    
space = "  __"
leagueapi_id   = input(space + "Enter your leagueapi id :  ")
season         = input(space + "Enter your season :  ")  
 
date_0         = get_today(0, space).strftime("%Y-%m-%d")
print(space + "______date_0 : " + date_0, flush=True)
date_raw       = get_today(0, space)  

date_1         = get_today(1, space).strftime("%Y-%m-%d")
print(space + "______date_1 : " + date_1, flush=True)
date_1_raw     = get_today(1, space)
# Out:
#   __Enter your leagueapi id :  128
#   __Enter your season :  2023
#   ____get_today()
#   ______date_diff : 0
#   ______today_raw : 2023-06-12 09:05:59.845611
#   ________date_0 : 2023-06-12
#   ____get_today()
#   ______date_diff : 0
#   ______today_raw : 2023-06-12 09:05:59.845611
#   ____get_today()
#   ______date_diff : 1
#   ______today_raw : 2023-06-13 09:05:59.853621
#   ________date_1 : 2023-06-13
#   ____get_today()
#   ______date_diff : 1
#   ______today_raw : 2023-06-13 09:05:59.853621

# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.leagues import *  
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "__"  
    # ----------------------------------------------------------  
    lg_get_league_for_predates(leagueapi_id, season, 1, date_0, date_raw, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-06-12 09:06:00
#   ____main__
#   ______lg_get_league_for_predates()
#   ________bookmakersapi_id : 8
#   ________bookmakersname : Bet365
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api5@ariondigitalmedia.com counter is 75
#   ______________APIkey: 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-06-12
#   ______________date_raw : 2023-06-12 09:05:59.845611
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 128
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Argentina,  Liga Profesional Argentina  #128 - 2023 / 971568
# ...

# %%
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # -------------------------------------------------- 
    ff_get_fixture_today_xpattern_advices_preleague(leagueapi_id, season, date_0, date_1, "xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-06-12 09:06:03
#   __main()
#   ______ff_get_fixture_today_xpattern_advices_preleague()
#   ________Select  date,   fixtureapi_id,   fixture_status,   leagueapi_id,   season   from football_odds  where leagueapi_id = '128'  and season = '2023'  and fixture_status = 'Not Started'  order by date asc
#   ________Total Row(s) : 9
#   ________[1/9] 2023-06-12 17:00:00
#   ________Not Started - 128 2023
#   ________[2/9] 2023-06-12 20:00:00
#   ________Not Started - 128 2023
#   ________[3/9] 2023-06-12 22:15:00
#   ________Not Started - 128 2023
#   ________[4/9] 2023-06-13 00:45:00
#   ________Not Started - 128 2023
#   ________[5/9] 2023-06-13 00:45:00
#   ________Not Started - 128 2023
#   ________[6/9] 2023-06-13 21:00:00
#   ________Not Started - 128 2023
#   ________[7/9] 2023-06-13 21:00:00
#   ________Not Started - 128 2023
#   ________[8/9] 2023-06-13 23:30:00
#   ________Not Started - 128 2023
# ...

# %%
import sys
sys.path.append('../')

from a_settings.messages import *    
from a_models.predefine import *  
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------     
    pd_get_fixtures_next_match(leagueapi_id, season, 'preleague', space) 
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-06-12 09:06:05
#   __main()
#   ______pd_get_fixtures_next_match()
# -------------------------------------------------------------------------
# MySQLInterfaceError                     Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:535, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     534         query = query.encode('utf-8')
# --> 535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Table 'pr_mmbuzz_2022_06.football_fixturesx' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                        Traceback (most recent call last)
# ...
