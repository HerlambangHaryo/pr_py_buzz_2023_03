# %%
import datetime 

def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 
    
space = "  __"
leagueapi_id   = input(space + "Enter your leagueapi id :  ")
season         = input(space + "Enter your season :  ")  
 
date_0         = get_today(0, space).strftime("%Y-%m-%d")
print(space + "______date_0 : " + date_0, flush=True)
date_raw       = get_today(0, space)  

date_1         = get_today(1, space).strftime("%Y-%m-%d")
print(space + "______date_1 : " + date_1, flush=True)
date_1_raw     = get_today(1, space)
# Out:
#   __Enter your leagueapi id :  385
#   __Enter your season :  2023
#   ____get_today()
#   ______date_diff : 0
#   ______today_raw : 2023-07-20 12:33:59.684178
#   ________date_0 : 2023-07-20
#   ____get_today()
#   ______date_diff : 0
#   ______today_raw : 2023-07-20 12:33:59.686187
#   ____get_today()
#   ______date_diff : 1
#   ______today_raw : 2023-07-21 12:33:59.686187
#   ________date_1 : 2023-07-21
#   ____get_today()
#   ______date_diff : 1
#   ______today_raw : 2023-07-21 12:33:59.686187

# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.leagues import *  
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "__"  
    # ----------------------------------------------------------  
    lg_get_league_for_predates(leagueapi_id, season, 1, date_0, date_raw, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-20 12:34:14
#   ____main__
#   ______lg_get_league_for_predates()
#   ________bookmakersapi_id : 8
#   ________bookmakersname : Bet365
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API hariyant2410@gmail.com counter is 56
#   ______________APIkey: b5a6d9beb2mshb3e0ad9107a86aap1cedccjsna1c0d5c2a42a
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-07-20
#   ______________date_raw : 2023-07-20 12:33:59.686187
#   ______________bookmaker : 8
#   ______________season : 2023
#   ______________league : 385
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 1
#
#   ________________1. Israel,  Toto Cup Ligat Al  #385 - 2023 / 1037331
#   ________________fixt date 2023-07-20 17:00:00+00:00
#   ________________fix local 2023-07-21 00:00:00
#   ________________local dat 2023-07-20 12:33:59
#   ________________Lebih
#   __________________league_rLeagues_id : 385
#   __________________league_rLeagues_name : Toto Cup Ligat Al
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#   __________________ff_update_unfinished__
#   ________________  > No longer get supported
# # -------------------------------------------------- End at 2023-07-20 12:34:43

# %%
# Import
import sys
sys.path.append('../')

# Import
from a_settings.messages import *   
from a_models.date import *   
from a_models.football_odds import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    day0         = get_today_adds(0, space) .strftime("%Y-%m-%d") 
    # --------------------------------------------------    
    day1         = get_today_adds(1, space).strftime("%Y-%m-%d") 
    # --------------------------------------------------  
    fO_get_group_league_status_match_finished_DETAILED(day0, day1, "pre_xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-07-20 12:53:22
#   __main()
#   ______get_today_adds()
#   ________adds date_diff : 0
#   ________today_raw : 2023-07-20 12:53:22.907514
#   ______get_today_adds()
#   ________adds date_diff : 1
#   ________today_raw : 2023-07-21 12:53:22.907514
#   ______fO_get_group_league_status_match_finished_DETAILED()
#   ______Select  DATE(date),  leagueapi_id,  (select bookmakersapi_id from football_leagues where football_leagues.leagueapi_id = football_odds.leagueapi_id),  season,   fixtureapi_id,   pre_ah_pattern,   pre_gou_pattern,   fixture_status   from football_odds  where date <= '2023-07-21'  and date >= '2023-07-20'  and deleted_at is null  and pre_response != 3  order by date, leagueapi_id, fixtureapi_id  desc
#   ________Total Row(s) : 3
#   ________1. 2023-07-20 // 8 // 8 // 2023 // 1013552 // H // G // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1013552
#   __________> pre_ah_pattern = +125+15+175+2H
#   __________> pre_ah_pattern_mirror = -2-175-15-125H
#   __________> pre_gou_pattern = 25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________2. 2023-07-20 // 8 // 8 // 2023 // 1013553 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1013553
#   __________> pre_ah_pattern = -2-175-15-125H
#   __________> pre_ah_pattern_mirror = +125+15+175+2H
#   __________> pre_gou_pattern = 225g25g275g30g325gG
#   __________> football_odds update pattern commited
#   ________3. 2023-07-20 // 385 // 8 // 2023 // 1037331 // None // None // Not Started
#   __________xpN_set_pattern()
#   __________> fixtureapi_id = 1037331
#   __________> pre_ah_pattern = -05-025+0+025H
#   __________> pre_ah_pattern_mirror = -025+0+025+05H
#   __________> pre_gou_pattern = 25gG
#   __________> football_odds update pattern commited
# # -------------------------------------------------- End at 2023-07-20 12:55:08
