# %%
import datetime 

def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 
    
space = "  __"
leagueapi_id   = input(space + "Enter your leagueapi id :  ")
season         = input(space + "Enter your season :  ")  
 
date_0         = get_today(0, space).strftime("%Y-%m-%d")
print(space + "______date_0 : " + date_0, flush=True)
date_raw       = get_today(0, space)  

date_1         = get_today(1, space).strftime("%Y-%m-%d")
print(space + "______date_1 : " + date_1, flush=True)
date_1_raw     = get_today(1, space)
# Out:
#   __Enter your leagueapi id :  976
#   __Enter your season :  2022
#   ____get_today()
#   ______date_diff : 0
#   ______today_raw : 2023-05-22 22:17:18.763458
#   ________date_0 : 2023-05-22
#   ____get_today()
#   ______date_diff : 0
#   ______today_raw : 2023-05-22 22:17:18.763458
#   ____get_today()
#   ______date_diff : 1
#   ______today_raw : 2023-05-23 22:17:18.767468
#   ________date_1 : 2023-05-23
#   ____get_today()
#   ______date_diff : 1
#   ______today_raw : 2023-05-23 22:17:18.767468

# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.leagues import *  
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "__"  
    # ----------------------------------------------------------  
    lg_get_league_for_predates(leagueapi_id, season, 1, date_0, date_raw, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-22 22:10:53
#   ____main__
#   ______lg_get_league_for_predates()
#   ________bookmakersapi_id : 8
#   ________bookmakersname : Bet365
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API lincahlogistik@gmail.com counter is 4
#   ______________APIkey: 405acb0deemsha32f06ee6179f6bp1cce74jsnf61631260341
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-05-22
#   ______________date_raw : 2023-05-22 22:10:53.032158
#   ______________bookmaker : 8
#   ______________season : 2022
#   ______________league : 976
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 10
#
#   ________________1. Italy,  Serie C - Promotion - Play-offs  #976 - 2022 / 1027227
#   ________________fixt date 2023-05-18 18:30:00+00:00
#   ________________fix local 2023-05-19 01:30:00
#   ________________local dat 2023-05-22 22:10:53
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________2. Italy,  Serie C - Promotion - Play-offs  #976 - 2022 / 1027225
#   ________________fixt date 2023-05-18 18:30:00+00:00
#   ________________fix local 2023-05-19 01:30:00
#   ________________local dat 2023-05-22 22:10:53
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________3. Italy,  Serie C - Promotion - Play-offs  #976 - 2022 / 1027223
#   ________________fixt date 2023-05-18 18:30:00+00:00
#   ________________fix local 2023-05-19 01:30:00
#   ________________local dat 2023-05-22 22:10:53
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________4. Italy,  Serie C - Promotion - Play-offs  #976 - 2022 / 1027221
#   ________________fixt date 2023-05-18 18:30:00+00:00
#   ________________fix local 2023-05-19 01:30:00
#   ________________local dat 2023-05-22 22:10:53
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________5. Italy,  Serie C - Promotion - Play-offs  #976 - 2022 / 1027219
#   ________________fixt date 2023-05-18 18:30:00+00:00
#   ________________fix local 2023-05-19 01:30:00
#   ________________local dat 2023-05-22 22:10:53
#   ________________Kurang
#   ________________good to Go 0
#
#   ________________6. Italy,  Serie C - Promotion - Play-offs  #976 - 2022 / 1027226
#   ________________fixt date 2023-05-22 18:30:00+00:00
#   ________________fix local 2023-05-23 01:30:00
#   ________________local dat 2023-05-22 22:10:53
#   ________________Lebih
#   __________________league_rLeagues_id : 976
#   __________________league_rLeagues_name : Serie C - Promotion - Play-offs
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________7. Italy,  Serie C - Promotion - Play-offs  #976 - 2022 / 1027222
#   ________________fixt date 2023-05-22 18:30:00+00:00
#   ________________fix local 2023-05-23 01:30:00
#   ________________local dat 2023-05-22 22:10:53
#   ________________Lebih
#   __________________league_rLeagues_id : 976
#   __________________league_rLeagues_name : Serie C - Promotion - Play-offs
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________8. Italy,  Serie C - Promotion - Play-offs  #976 - 2022 / 1027224
#   ________________fixt date 2023-05-22 18:30:00+00:00
#   ________________fix local 2023-05-23 01:30:00
#   ________________local dat 2023-05-22 22:10:53
#   ________________Lebih
#   __________________league_rLeagues_id : 976
#   __________________league_rLeagues_name : Serie C - Promotion - Play-offs
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________9. Italy,  Serie C - Promotion - Play-offs  #976 - 2022 / 1027220
#   ________________fixt date 2023-05-22 18:30:00+00:00
#   ________________fix local 2023-05-23 01:30:00
#   ________________local dat 2023-05-22 22:10:53
#   ________________Lebih
#   __________________league_rLeagues_id : 976
#   __________________league_rLeagues_name : Serie C - Promotion - Play-offs
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#
#   ________________10. Italy,  Serie C - Promotion - Play-offs  #976 - 2022 / 1027228
#   ________________fixt date 2023-05-22 18:30:00+00:00
#   ________________fix local 2023-05-23 01:30:00
#   ________________local dat 2023-05-22 22:10:53
#   ________________Lebih
#   __________________league_rLeagues_id : 976
#   __________________league_rLeagues_name : Serie C - Promotion - Play-offs
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   ________________8==8
#   __________________re_looping__
#   ________________==========================================================================
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API lincahlogistik@gmail.com counter is 3
#   ______________APIkey: 405acb0deemsha32f06ee6179f6bp1cce74jsnf61631260341
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-05-22
#   ______________date_raw : 2023-05-22 22:10:53.032158
#   ______________bookmaker : 8
#   ______________season : 2022
#   ______________league : 976
#   ______________page : 2
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 0
# # -------------------------------------------------- End at 2023-05-22 22:11:14

# %%
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # -------------------------------------------------- 
    ff_get_fixture_today_xpattern_advices_preleague(leagueapi_id, season, date_0, date_1, "xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-22 22:17:25
#   __main()
#   ______ff_get_fixture_today_xpattern_advices_preleague()
#   ________Select  date,   fixtureapi_id,   fixture_status,   leagueapi_id,   season   from football_odds  where leagueapi_id = '976'  and season = '2022'  and fixture_status = 'Not Started'  order by date asc
#   ________Total Row(s) : 5
#   ________[1/5] 2023-05-22 18:30:00
#   ________Not Started - 976 2022
#   ________[2/5] 2023-05-22 18:30:00
#   ________Not Started - 976 2022
#   ________[3/5] 2023-05-22 18:30:00
#   ________Not Started - 976 2022
#   ________[4/5] 2023-05-22 18:30:00
#   ________Not Started - 976 2022
#   ________[5/5] 2023-05-22 18:30:00
#   ________Not Started - 976 2022
# # -------------------------------------------------- End at 2023-05-22 22:17:26

# %%
import sys
sys.path.append('../')

from a_settings.messages import *    
from a_models.predefine import *  
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------     
    pd_get_fixtures_next_match(leagueapi_id, season, 'preleague', space) 
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-22 22:17:26
#   __main()
#   ______pd_get_fixtures_next_match()
#   ________Total Row(s) : 0
# # -------------------------------------------------- End at 2023-05-22 22:17:27
