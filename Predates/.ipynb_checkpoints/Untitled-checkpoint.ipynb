# %%
import datetime 

def get_today(date_diff, space): 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    print(space + "get_today()") 
    # ---------------------------------------------------------- 
    space += "__" 
    # ---------------------------------------------------------- 
    param = "date_diff : " + str(date_diff)
    print(space + param, flush=True)
    # ----------------------------------------------------------
    today = datetime.datetime.now()
    DD = datetime.timedelta(days=date_diff)
    today_raw = today + DD
    # ---------------------------------------------------------- 
    param = "today_raw : " + str(today_raw)
    print(space + param, flush=True)
    # ---------------------------------------------------------- 
    return today_raw
    # ---------------------------------------------------------- 
    
space = "  __"
leagueapi_id   = input(space + "Enter your leagueapi id :  ")
season         = input(space + "Enter your season :  ")  
 
date_0         = get_today(0, space).strftime("%Y-%m-%d")
print(space + "______date_0 : " + date_0, flush=True)
date_raw       = get_today(0, space)  

date_1         = get_today(1, space).strftime("%Y-%m-%d")
print(space + "______date_1 : " + date_1, flush=True)
date_1_raw     = get_today(1, space)
# Out:
#   __Enter your leagueapi id :  3
#   __Enter your season :  2022
#   ____get_today()
#   ______date_diff : 0
#   ______today_raw : 2023-04-12 13:32:34.393685
#   ________date_0 : 2023-04-12
#   ____get_today()
#   ______date_diff : 0
#   ______today_raw : 2023-04-12 13:32:34.396695
#   ____get_today()
#   ______date_diff : 1
#   ______today_raw : 2023-04-13 13:32:34.397695
#   ________date_1 : 2023-04-13
#   ____get_today()
#   ______date_diff : 1
#   ______today_raw : 2023-04-13 13:32:34.399696

# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.leagues import *  
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    space += "__"  
    # ----------------------------------------------------------  
    lg_get_league_for_predates(leagueapi_id, season, 1, date_0, date_raw, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-12 13:32:34
#   ____main__
#   ______lg_get_league_for_predates()
#   ________bookmakersapi_id : 8
#   ________bookmakersname : Bet365
#   __________ao_controll_match_update()
#   ____________aa_check_acccount()
#   ______________API api3@ariondigitalmedia.com counter is 34
#   ______________APIkey: dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4
#   ____________aa_check_acccount()
#   ____________aa_update_counter()
#   ____________ao_response_odds()
#   ______________date : 2023-04-12
#   ______________date_raw : 2023-04-12 13:32:34.396695
#   ______________bookmaker : 8
#   ______________season : 2022
#   ______________league : 3
#   ______________page : 1
#   ________________________________________________________________________________________
#   ______________Total API Response(s) : 4
#
#   ________________1. World,  UEFA Europa League  #3 - 2022 / 1016041
#   ________________fixt date 2023-04-13 19:00:00+00:00
#   ________________fix local 2023-04-14 02:00:00
#   ________________local dat 2023-04-12 13:32:34
#   ________________Lebih
#   __________________league_rLeagues_id : 3
#   __________________league_rLeagues_name : UEFA Europa League
#   __________________bookmakersapi_rLeagues_id : 8
#   __________________bookmakers_rLeagues_name : Bet365
#   ________________Total fixtureapi_id Row(s) : 1
#   ________________good to Go 1
#   __________________8==8
#   __________________<tr><td>Goals Over/Under - Second Half Over 1.5</td><td>1.83</td></tr>
#   __________________<tr><td>Goals Over/Under - Second Half Under 1.5</td><td>1.83</td></tr>
#   __________________<tr><td>Cards European Handicap Away +0</td><td>1.83</td></tr>
#   __________________<tr><td>Cards European Handicap Home +1</td><td>1.83</td></tr>
#   __________________<tr><td>Cards Over/Under Over 4.5</td><td>1.83</td></tr>
#   __________________<tr><td>Cards Over/Under Under 4.5</td><td>1.83</td></tr>
#   __________________<tr><td>Away Team Total Cards Over 2.5</td><td>1.83</td></tr>
#   __________________<tr><td>Away Team Total Cards Under 2.5</td><td>1.83</td></tr>
#   __________________ pre_special_odds = '<tr><td>Goals Over/Under - Second Half Over 1.5</td><td>1.83</td></tr><tr><td>Goals Over/Under - Second Half Under 1.5</td><td>1.83</td></tr><tr><td>Cards European Handicap Away +0</td><td>1.83</td></tr><tr><td>Cards European Handicap Home +1</td><td>1.83</td></tr><tr><td>Cards Over/Under Over 4.5</td><td>1.83</td></tr><tr><td>Cards Over/Under Under 4.5</td><td>1.83</td></tr><tr><td>Away Team Total Cards Over 2.5</td><td>1.83</td></tr><tr><td>Away Team Total Cards Under 2.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#
#   __________________2. World,  UEFA Europa League  #3 - 2022 / 1016045
#   __________________fixt date 2023-04-13 19:00:00+00:00
#   __________________fix local 2023-04-14 02:00:00
#   __________________local dat 2023-04-12 13:32:34
#   __________________Lebih
#   ____________________league_rLeagues_id : 3
#   ____________________league_rLeagues_name : UEFA Europa League
#   ____________________bookmakersapi_rLeagues_id : 8
#   ____________________bookmakers_rLeagues_name : Bet365
#   __________________Total fixtureapi_id Row(s) : 1
#   __________________good to Go 1
#   ____________________8==8
#   ____________________<tr><td>Second Half Winner Home</td><td>1.83</td></tr>
#   ____________________<tr><td>Goals Over/Under - Second Half Over 1.5</td><td>1.83</td></tr>
#   ____________________<tr><td>Goals Over/Under - Second Half Under 1.5</td><td>1.83</td></tr>
#   ____________________ pre_special_odds = '<tr><td>Second Half Winner Home</td><td>1.83</td></tr><tr><td>Goals Over/Under - Second Half Over 1.5</td><td>1.83</td></tr><tr><td>Goals Over/Under - Second Half Under 1.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#
#   ____________________3. World,  UEFA Europa League  #3 - 2022 / 1016039
#   ____________________fixt date 2023-04-13 16:45:00+00:00
#   ____________________fix local 2023-04-13 23:45:00
#   ____________________local dat 2023-04-12 13:32:34
#   ____________________Lebih
#   ______________________league_rLeagues_id : 3
#   ______________________league_rLeagues_name : UEFA Europa League
#   ______________________bookmakersapi_rLeagues_id : 8
#   ______________________bookmakers_rLeagues_name : Bet365
#   ____________________Total fixtureapi_id Row(s) : 1
#   ____________________good to Go 1
#   ______________________8==8
#   ______________________<tr><td>Asian Handicap Away -0.25</td><td>1.83</td></tr>
#   ______________________<tr><td>Corners Over Under Over 9.5</td><td>1.83</td></tr>
#   ______________________<tr><td>Corners Over Under Under 9.5</td><td>1.83</td></tr>
#   ______________________<tr><td>Total Corners (3 way) Under 10</td><td>1.83</td></tr>
#   ______________________ pre_special_odds = '<tr><td>Asian Handicap Away -0.25</td><td>1.83</td></tr><tr><td>Corners Over Under Over 9.5</td><td>1.83</td></tr><tr><td>Corners Over Under Under 9.5</td><td>1.83</td></tr><tr><td>Total Corners (3 way) Under 10</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#
#   ______________________4. World,  UEFA Europa League  #3 - 2022 / 1016043
#   ______________________fixt date 2023-04-13 19:00:00+00:00
#   ______________________fix local 2023-04-14 02:00:00
#   ______________________local dat 2023-04-12 13:32:34
#   ______________________Lebih
#   ________________________league_rLeagues_id : 3
#   ________________________league_rLeagues_name : UEFA Europa League
#   ________________________bookmakersapi_rLeagues_id : 8
#   ________________________bookmakers_rLeagues_name : Bet365
#   ______________________Total fixtureapi_id Row(s) : 1
#   ______________________good to Go 1
#   ________________________8==8
#   ________________________<tr><td>Match Winner Home</td><td>1.83</td></tr>
#   ________________________<tr><td>Away Team Total Cards Over 2.5</td><td>1.83</td></tr>
#   ________________________<tr><td>Away Team Total Cards Under 2.5</td><td>1.83</td></tr>
#   ________________________ pre_special_odds = '<tr><td>Match Winner Home</td><td>1.83</td></tr><tr><td>Away Team Total Cards Over 2.5</td><td>1.83</td></tr><tr><td>Away Team Total Cards Under 2.5</td><td>1.83</td></tr>',  on_eye= '<i class="fa-solid fa-eye text-primary"></i>',
#   __________________________ff_update_unfinished__
#   ________________________  > No longer get supported
# # -------------------------------------------------- End at 2023-04-12 13:32:48

# %%
# Import
from a_settings.messages import *   
from a_models.football_fixtures import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # -------------------------------------------------- 
    ff_get_fixture_today_xpattern_advices_preleague(leagueapi_id, season, date_0, date_1, "xpattern", space)
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-12 13:33:42
#   __main()
#   ______ff_get_fixture_today_xpattern_advices_preleague()
#   ________Select  date,   fixtureapi_id,   league_country,   league_name,   season,   teams_home,   teams_away   from football_fixtures  where DATE(date) >= '2023-04-12'  and DATE(date) <= '2023-04-13'  and leagueapi_id = '3'  and season = '2022'  order by date asc
#   ________Total Row(s) : 4
#   ________[1/4] 2023-04-13 16:45:00
#   ________World - UEFA Europa League 2022
# #1016039  Feyenoord vs AS Roma
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016039
#   __________> pre_ah_pattern = 05_025_0#H
#   __________> pre_ah_pattern_mirror = 0#025+05+H
#   __________> pre_gou_pattern = 175g2g225g25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '3'
#   __________     and pre_ah_pattern = '05_025_0#H'
#   __________     and pre_gou_pattern = '175g2g225g25gG'
#   __________     and end_ah_pattern = '05_025_0#H'
#   __________     and end_gou_pattern = '175g2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136413
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '3'
#   __________     and pre_ah_pattern_mirror = '05_025_0#H'
#   __________     and pre_gou_pattern = '175g2g225g25gG'
#   __________     and end_ah_pattern_mirror = '05_025_0#H'
#   __________     and end_gou_pattern = '175g2g225g25gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:136413
#   __________     total_fixtures:1
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = '<span class="badge bg-gray-800">Total pre Mirror Fixture(s) = 1</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o15 - 100%</span> <span class="badge bg-gradient-danger">u25 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-primary">Hwin - 0%</span> <span class="badge bg-gradient-primary">Home0 - 0%</span> <span class="badge bg-gradient-primary">Hnil - 0%</span> <span class="badge bg-gradient-primary">H-both - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-gray-700">xG-2 - 100%</span> <span class="badge bg-gradient-gray-700">xgA-0 - 0%</span> <span class="badge bg-gradient-gray-700">xgH-2 - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-custom-pink">Btn - 100%</span> <span class="badge bg-gradient-custom-teal">csn-A - 0%</span> <span class="badge bg-gradient-custom-pink">csy-H - 0%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-yellow-green">Even - 100%</span> <span class="badge bg-gradient-gray-700">=half - 100%</span> <span class="badge bg-gradient-purple">xG1st-1 - 100%</span> <span class="badge bg-gradient-warning">xG2nd-1 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136413
#   __________       --UPDATED--
#   ________[2/4] 2023-04-13 19:00:00
#   ________World - UEFA Europa League 2022
# #1016041  Manchester United vs Sevilla
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016041
#   __________> pre_ah_pattern = 175_15_125_1_H
#   __________> pre_ah_pattern_mirror = 1+125+15+175+H
#   __________> pre_gou_pattern = 25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '3'
#   __________     and pre_ah_pattern = '175_15_125_1_H'
#   __________     and pre_gou_pattern = '25g275g3g325gG'
#   __________     and end_ah_pattern = '175_15_125_1_H'
#   __________     and end_gou_pattern = '25g275g3g325gG'
#   __________    Total Row(s) : 1
#
#   __________     idx:136415
#   __________     total_fixtures:4
#   __________       UPDATE `football_fixtures` SET `pre_advices` = '<span class="badge bg-dark">Total pre  Fixture(s) = 4</span><br/> <br/><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-success">o15 - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"><span class="badge bg-gradient-custom-teal">csn-A - 100%</span> </div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div><div class="border-bottom border-secondary pt-2 pb-2"></div>',   `star` = '<i class="fas fa-star text-yellow"></i>' WHERE `id` = 136415
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '3'
#   __________     and pre_ah_pattern_mirror = '175_15_125_1_H'
#   __________     and pre_gou_pattern = '25g275g3g325gG'
#   __________     and end_ah_pattern_mirror = '175_15_125_1_H'
#   __________     and end_gou_pattern = '25g275g3g325gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136415
#   __________       --UPDATED--
#   ________[3/4] 2023-04-13 19:00:00
#   ________World - UEFA Europa League 2022
# #1016043  Juventus vs Sporting CP
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016043
#   __________> pre_ah_pattern = 075_05_025_H
#   __________> pre_ah_pattern_mirror = 025+05+075+H
#   __________> pre_gou_pattern = 175g2g225g25gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '3'
#   __________     and pre_ah_pattern = '075_05_025_H'
#   __________     and pre_gou_pattern = '175g2g225g25gG'
#   __________     and end_ah_pattern = '075_05_025_H'
#   __________     and end_gou_pattern = '175g2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136417
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '3'
#   __________     and pre_ah_pattern_mirror = '075_05_025_H'
#   __________     and pre_gou_pattern = '175g2g225g25gG'
#   __________     and end_ah_pattern_mirror = '075_05_025_H'
#   __________     and end_gou_pattern = '175g2g225g25gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136417
#   __________       --UPDATED--
#   ________[4/4] 2023-04-13 19:00:00
#   ________World - UEFA Europa League 2022
# #1016045  Bayer Leverkusen vs Union St. Gilloise
#   __________xp_set_pattern()
#   __________> fixtureapi_id = 1016045
#   __________> pre_ah_pattern = 15_125_1_075_05_H
#   __________> pre_ah_pattern_mirror = 05+075+1+125+15+H
#   __________> pre_gou_pattern = 225g25g275g3g325gG
#   __________> football_fixtures update pattern commited
#   ____________pl_predates_get_advice__no
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '3'
#   __________     and pre_ah_pattern = '15_125_1_075_05_H'
#   __________     and pre_gou_pattern = '225g25g275g3g325gG'
#   __________     and end_ah_pattern = '15_125_1_075_05_H'
#   __________     and end_gou_pattern = '225g25g275g3g325gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices` = Null WHERE `id` = 136419
#   __________       --UPDATED--
#   ____________pl_predates_get_advice__yes
#   __________  __pl_get_leagueapi_for_advice__
#   __________     where leagueapi_id = '3'
#   __________     and pre_ah_pattern_mirror = '15_125_1_075_05_H'
#   __________     and pre_gou_pattern = '225g25g275g3g325gG'
#   __________     and end_ah_pattern_mirror = '15_125_1_075_05_H'
#   __________     and end_gou_pattern = '225g25g275g3g325gG'
#   __________    Total Row(s) : 0
#
#   __________       UPDATE `football_fixtures` SET `pre_advices_mirror` = Null WHERE `id` = 136419
#   __________       --UPDATED--
# # -------------------------------------------------- End at 2023-04-12 13:34:59

# %%
# Import
from a_settings.messages import *   
from a_models.predefine import *  
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------     
    pd_get_fixtures_next_match(leagueapi_id, season, 'preleague', space) 
    # ----------------------------------------------------------  
    its_end()  
    ####################################################
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # Import
# ----> 2 from a_settings.messages import *
#       3 from a_models.predefine import *
#       5 if __name__ == '__main__':
#       6     # --------------------------------------------------
#
# ModuleNotFoundError: No module named 'a_settings'
