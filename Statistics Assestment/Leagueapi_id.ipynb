# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *   
from a_models.statistic_assessment_group import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    leagueapi_id   = input(space + "Enter your leagueapi id :  ")  
    # --------------------------------------------------    
    sAg_rounder(leagueapi_id, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-30 11:37:26
#   __main()
#   ____Enter your leagueapi id :  39
#   ______sAg_rounder()
#   ________sA_match_winner_home()
#   ________sA_match_winner_draw()
#   ________sA_match_winner_away()
#   ________sA_homeaway_home()
#   ________sA_homeaway_away()
#   ________sA_asian_handicap_home_min_675()
#   ________sA_asian_handicap_away_min_675()
#   ________sA_asian_handicap_home_min_65()
#   ________sA_asian_handicap_away_min_65()
#   ________sA_asian_handicap_home_min_625()
#   ________sA_asian_handicap_away_min_625()
#   ________sA_asian_handicap_home_min_6()
#   ________sA_asian_handicap_away_min_6()
#   ________sA_asian_handicap_home_min_575()
#   ________sA_asian_handicap_away_min_575()
#   ________sA_asian_handicap_home_min_55()
#   ________sA_asian_handicap_away_min_55()
#   ________sA_asian_handicap_home_min_525()
#   ________sA_asian_handicap_away_min_525()
#   ________sA_asian_handicap_home_min_5()
#   ________sA_asian_handicap_away_min_5()
#   ________sA_asian_handicap_home_min_475()
#   ________sA_asian_handicap_away_min_475()
#   ________sA_asian_handicap_home_min_45()
#   ________sA_asian_handicap_away_min_45()
#   ________sA_asian_handicap_home_min_425()
#   ________sA_asian_handicap_away_min_425()
#   ________sA_asian_handicap_home_min_4()
#   ________sA_asian_handicap_away_min_4()
#   ________sA_asian_handicap_home_min_375()
#   ________sA_asian_handicap_away_min_375()
#   ________sA_asian_handicap_home_min_35()
#   ________sA_asian_handicap_away_min_35()
#   ________sA_asian_handicap_home_min_325()
#   ________sA_asian_handicap_away_min_325()
#   ________sA_asian_handicap_home_min_3()
#   ________sA_asian_handicap_away_min_3()
#   ________sA_asian_handicap_home_min_275()
#   ________sA_asian_handicap_away_min_275()
#   ________sA_asian_handicap_home_min_25()
#   ________sA_asian_handicap_away_min_25()
#   ________sA_asian_handicap_home_min_225()
#   ________sA_asian_handicap_away_min_225()
#   ________sA_asian_handicap_home_min_2()
#   ________sA_asian_handicap_away_min_2()
#   ________sA_asian_handicap_home_min_175()
#   ________sA_asian_handicap_away_min_175()
#   ________sA_asian_handicap_home_min_15()
#   ________sA_asian_handicap_away_min_15()
#   ________sA_asian_handicap_home_min_125()
#   ________sA_asian_handicap_away_min_125()
#   ________sA_asian_handicap_home_min_1()
#   ________sA_asian_handicap_away_min_1()
#   ________sA_asian_handicap_home_min_075()
#   ________sA_asian_handicap_away_min_075()
#   ________sA_asian_handicap_home_min_05()
#   ________sA_asian_handicap_away_min_05()
#   ________sA_asian_handicap_home_min_025()
#   ________sA_asian_handicap_away_min_025()
#   ________sA_asian_handicap_home_plus_0()
#   ________sA_asian_handicap_away_plus_0()
#   ________sA_asian_handicap_home_plus_025()
#   ________sA_asian_handicap_away_plus_025()
#   ________sA_asian_handicap_home_plus_05()
#   ________sA_asian_handicap_away_plus_05()
#   ________sA_asian_handicap_home_plus_075()
#   ________sA_asian_handicap_away_plus_075()
#   ________sA_asian_handicap_home_plus_1()
#   ________sA_asian_handicap_away_plus_1()
#   ________sA_asian_handicap_home_plus_125()
#   ________sA_asian_handicap_away_plus_125()
#   ________sA_asian_handicap_home_plus_15()
#   ________sA_asian_handicap_away_plus_15()
#   ________sA_asian_handicap_home_plus_175()
#   ________sA_asian_handicap_away_plus_175()
#   ________sA_asian_handicap_home_plus_2()
#   ________sA_asian_handicap_away_plus_2()
#   ________sA_asian_handicap_home_plus_225()
#   ________sA_asian_handicap_away_plus_225()
#   ________sA_asian_handicap_home_plus_25()
#   ________sA_asian_handicap_away_plus_25()
#   ________sA_asian_handicap_home_plus_275()
#   ________sA_asian_handicap_away_plus_275()
#   ________sA_asian_handicap_home_plus_3()
#   ________sA_asian_handicap_away_plus_3()
#   ________sA_asian_handicap_home_plus_325()
#   ________sA_asian_handicap_away_plus_325()
#   ________sA_asian_handicap_home_plus_35()
#   ________sA_asian_handicap_away_plus_35()
#   ________sA_asian_handicap_home_plus_375()
#   ________sA_asian_handicap_away_plus_375()
#   ________sA_asian_handicap_home_plus_4()
#   ________sA_asian_handicap_away_plus_4()
#   ________sA_asian_handicap_home_plus_425()
#   ________sA_asian_handicap_away_plus_425()
#   ________sA_asian_handicap_home_plus_45()
#   ________sA_asian_handicap_away_plus_45()
#   ________sA_asian_handicap_home_plus_475()
#   ________sA_asian_handicap_away_plus_475()
#   ________sA_asian_handicap_home_plus_5()
#   ________sA_asian_handicap_away_plus_5()
#   ________sA_asian_handicap_home_plus_525()
#   ________sA_asian_handicap_away_plus_525()
#   ________sA_asian_handicap_home_plus_55()
#   ________sA_asian_handicap_away_plus_55()
#   ________sA_asian_handicap_home_plus_575()
#   ________sA_asian_handicap_away_plus_575()
#   ________sA_asian_handicap_home_plus_6()
#   ________sA_asian_handicap_away_plus_6()
#   ________sA_asian_handicap_home_plus_625()
#   ________sA_asian_handicap_away_plus_625()
#   ________sA_asian_handicap_home_plus_65()
#   ________sA_asian_handicap_away_plus_65()
#   ________sA_asian_handicap_home_plus_675()
#   ________sA_asian_handicap_away_plus_675()
#   ________sA_goals_overunder_over_05()
#   ________sA_goals_overunder_under_05()
#   ________sA_goals_overunder_over_075()
#   ________sA_goals_overunder_under_075()
#   ________sA_goals_overunder_over_10()
#   ________sA_goals_overunder_under_10()
#   ________sA_goals_overunder_over_125()
#   ________sA_goals_overunder_under_125()
#   ________sA_goals_overunder_over_15()
#   ________sA_goals_overunder_under_15()
#   ________sA_goals_overunder_over_175()
#   ________sA_goals_overunder_under_175()
#   ________sA_goals_overunder_over_20()
#   ________sA_goals_overunder_under_20()
#   ________sA_goals_overunder_over_225()
#   ________sA_goals_overunder_under_225()
#   ________sA_goals_overunder_over_25()
#   ________sA_goals_overunder_under_25()
#   ________sA_goals_overunder_over_275()
#   ________sA_goals_overunder_under_275()
#   ________sA_goals_overunder_over_30()
#   ________sA_goals_overunder_under_30()
#   ________sA_goals_overunder_over_325()
#   ________sA_goals_overunder_under_325()
#   ________sA_goals_overunder_over_35()
#   ________sA_goals_overunder_under_35()
#   ________sA_goals_overunder_over_375()
#   ________sA_goals_overunder_under_375()
#   ________sA_goals_overunder_over_40()
#   ________sA_goals_overunder_under_40()
#   ________sA_goals_overunder_over_425()
#   ________sA_goals_overunder_under_425()
#   ________sA_goals_overunder_over_45()
#   ________sA_goals_overunder_under_45()
#   ________sA_goals_overunder_over_475()
#   ________sA_goals_overunder_under_475()
#   ________sA_goals_overunder_over_50()
#   ________sA_goals_overunder_under_50()
#   ________sA_goals_overunder_over_525()
#   ________sA_goals_overunder_under_525()
#   ________sA_goals_overunder_over_55()
#   ________sA_goals_overunder_under_55()
#   ________sA_goals_overunder_over_575()
#   ________sA_goals_overunder_under_575()
#   ________sA_goals_overunder_over_60()
#   ________sA_goals_overunder_under_60()
#   ________sA_goals_overunder_over_625()
#   ________sA_goals_overunder_under_625()
#   ________sA_goals_overunder_over_65()
#   ________sA_goals_overunder_under_65()
#   ________sA_goals_overunder_over_675()
#   ________sA_goals_overunder_under_675()
#   ________sA_goals_overunder_over_70()
#   ________sA_goals_overunder_under_70()
#   ________sA_goals_overunder_over_75()
#   ________sA_goals_overunder_under_75()
#   ________sA_goals_overunder_over_85()
#   ________sA_goals_overunder_under_85()
#   ________sA_goals_overunder_over_95()
#   ________sA_goals_overunder_under_95()
# # -------------------------------------------------- End at 2023-05-30 11:52:14
