# %%
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *   
from a_models.statistic_assestment import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------
    # Match Winner
    # Sudah
#     sA_match_winner_home(space)
#     sA_match_winner_draw(space)
#     sA_match_winner_away(space)
     
    # Match
    # Sudah
#     sA_homeaway_home(space)
#     sA_homeaway_away(space)
    
#     # Match
    sA_second_half_winner_home(space)
    sA_second_half_winner_draw(space)
    sA_second_half_winner_away(space)
    
#     # Match
    # Sudah
#     sA_asian_handicap_home_min_675(space)
#     sA_asian_handicap_away_min_675(space)
#     sA_asian_handicap_home_min_65(space)
#     sA_asian_handicap_away_min_65(space)
#     sA_asian_handicap_home_min_625(space)
#     sA_asian_handicap_away_min_625(space)
#     sA_asian_handicap_home_min_6(space)
#     sA_asian_handicap_away_min_6(space)
#     sA_asian_handicap_home_min_575(space)
#     sA_asian_handicap_away_min_575(space)
#     sA_asian_handicap_home_min_55(space)
#     sA_asian_handicap_away_min_55(space)
#     sA_asian_handicap_home_min_525(space)
#     sA_asian_handicap_away_min_525(space)
#     sA_asian_handicap_home_min_5(space)
#     sA_asian_handicap_away_min_5(space)
#     sA_asian_handicap_home_min_475(space)
#     sA_asian_handicap_away_min_475(space)
#     sA_asian_handicap_home_min_45(space)
#     sA_asian_handicap_away_min_45(space)
#     sA_asian_handicap_home_min_425(space)
#     sA_asian_handicap_away_min_425(space)
#     sA_asian_handicap_home_min_4(space)
#     sA_asian_handicap_away_min_4(space)
#     sA_asian_handicap_home_min_375(space)
#     sA_asian_handicap_away_min_375(space)
#     sA_asian_handicap_home_min_35(space)
#     sA_asian_handicap_away_min_35(space)
#     sA_asian_handicap_home_min_325(space)
#     sA_asian_handicap_away_min_325(space)
#     sA_asian_handicap_home_min_3(space)
#     sA_asian_handicap_away_min_3(space)
#     sA_asian_handicap_home_min_275(space)
#     sA_asian_handicap_away_min_275(space)
#     sA_asian_handicap_home_min_25(space)
#     sA_asian_handicap_away_min_25(space)
#     sA_asian_handicap_home_min_225(space)
#     sA_asian_handicap_away_min_225(space)
#     sA_asian_handicap_home_min_2(space)
#     sA_asian_handicap_away_min_2(space)
#     sA_asian_handicap_home_min_175(space)
#     sA_asian_handicap_away_min_175(space)
#     sA_asian_handicap_home_min_15(space)
#     sA_asian_handicap_away_min_15(space)
#     sA_asian_handicap_home_min_125(space)
#     sA_asian_handicap_away_min_125(space)
#     sA_asian_handicap_home_min_1(space)
#     sA_asian_handicap_away_min_1(space)
#     sA_asian_handicap_home_min_075(space)
#     sA_asian_handicap_away_min_075(space)
#     sA_asian_handicap_home_min_05(space)
#     sA_asian_handicap_away_min_05(space)
#     sA_asian_handicap_home_min_025(space)
#     sA_asian_handicap_away_min_025(space)
#     sA_asian_handicap_home_plus_0(space)
#     sA_asian_handicap_away_plus_0(space)
#     sA_asian_handicap_home_plus_025(space)
#     sA_asian_handicap_away_plus_025(space)
#     sA_asian_handicap_home_plus_05(space)
#     sA_asian_handicap_away_plus_05(space)
#     sA_asian_handicap_home_plus_075(space)
#     sA_asian_handicap_away_plus_075(space)
#     sA_asian_handicap_home_plus_1(space)
#     sA_asian_handicap_away_plus_1(space)
#     sA_asian_handicap_home_plus_125(space)
#     sA_asian_handicap_away_plus_125(space)
#     sA_asian_handicap_home_plus_15(space)
#     sA_asian_handicap_away_plus_15(space)
#     sA_asian_handicap_home_plus_175(space)
#     sA_asian_handicap_away_plus_175(space)
#     sA_asian_handicap_home_plus_2(space)
#     sA_asian_handicap_away_plus_2(space)
#     sA_asian_handicap_home_plus_225(space)
#     sA_asian_handicap_away_plus_225(space)
#     sA_asian_handicap_home_plus_25(space)
#     sA_asian_handicap_away_plus_25(space)
#     sA_asian_handicap_home_plus_275(space)
#     sA_asian_handicap_away_plus_275(space)
#     sA_asian_handicap_home_plus_3(space)
#     sA_asian_handicap_away_plus_3(space)
#     sA_asian_handicap_home_plus_325(space)
#     sA_asian_handicap_away_plus_325(space)
#     sA_asian_handicap_home_plus_35(space)
#     sA_asian_handicap_away_plus_35(space)
#     sA_asian_handicap_home_plus_375(space)
#     sA_asian_handicap_away_plus_375(space)
#     sA_asian_handicap_home_plus_4(space)
#     sA_asian_handicap_away_plus_4(space)
#     sA_asian_handicap_home_plus_425(space)
#     sA_asian_handicap_away_plus_425(space)
#     sA_asian_handicap_home_plus_45(space)
#     sA_asian_handicap_away_plus_45(space)
#     sA_asian_handicap_home_plus_475(space)
#     sA_asian_handicap_away_plus_475(space)
#     sA_asian_handicap_home_plus_5(space)
#     sA_asian_handicap_away_plus_5(space)
#     sA_asian_handicap_home_plus_525(space)
#     sA_asian_handicap_away_plus_525(space)
#     sA_asian_handicap_home_plus_55(space)
#     sA_asian_handicap_away_plus_55(space)
#     sA_asian_handicap_home_plus_575(space)
#     sA_asian_handicap_away_plus_575(space)
#     sA_asian_handicap_home_plus_6(space)
#     sA_asian_handicap_away_plus_6(space)
#     sA_asian_handicap_home_plus_625(space)
#     sA_asian_handicap_away_plus_625(space)
#     sA_asian_handicap_home_plus_65(space)
#     sA_asian_handicap_away_plus_65(space)
#     sA_asian_handicap_home_plus_675(space)
#     sA_asian_handicap_away_plus_675(space)
    
#     # Match
    # Sudah
#     sA_goals_overunder_over_05(space)
#     sA_goals_overunder_under_05(space)
#     sA_goals_overunder_over_075(space)
#     sA_goals_overunder_under_075(space)
#     sA_goals_overunder_over_10(space)
#     sA_goals_overunder_under_10(space)
#     sA_goals_overunder_over_125(space)
#     sA_goals_overunder_under_125(space)
#     sA_goals_overunder_over_15(space)
#     sA_goals_overunder_under_15(space)
#     sA_goals_overunder_over_175(space)
#     sA_goals_overunder_under_175(space)
#     sA_goals_overunder_over_20(space)
#     sA_goals_overunder_under_20(space)
#     sA_goals_overunder_over_225(space)
#     sA_goals_overunder_under_225(space)
#     sA_goals_overunder_over_25(space)
#     sA_goals_overunder_under_25(space)
#     sA_goals_overunder_over_275(space)
#     sA_goals_overunder_under_275(space)
#     sA_goals_overunder_over_30(space)
#     sA_goals_overunder_under_30(space)
#     sA_goals_overunder_over_325(space)
#     sA_goals_overunder_under_325(space)
#     sA_goals_overunder_over_35(space)
#     sA_goals_overunder_under_35(space)
#     sA_goals_overunder_over_375(space)
#     sA_goals_overunder_under_375(space)
#     sA_goals_overunder_over_40(space)
#     sA_goals_overunder_under_40(space)
#     sA_goals_overunder_over_425(space)
#     sA_goals_overunder_under_425(space)
#     sA_goals_overunder_over_45(space)
#     sA_goals_overunder_under_45(space)
#     sA_goals_overunder_over_475(space)
#     sA_goals_overunder_under_475(space)
#     sA_goals_overunder_over_50(space)
#     sA_goals_overunder_under_50(space)
#     sA_goals_overunder_over_525(space)
#     sA_goals_overunder_under_525(space)
#     sA_goals_overunder_over_55(space)
#     sA_goals_overunder_under_55(space)
#     sA_goals_overunder_over_575(space)
#     sA_goals_overunder_under_575(space)
#     sA_goals_overunder_over_60(space)
#     sA_goals_overunder_under_60(space)
#     sA_goals_overunder_over_625(space)
#     sA_goals_overunder_under_625(space)
#     sA_goals_overunder_over_65(space)
#     sA_goals_overunder_under_65(space)
#     sA_goals_overunder_over_675(space)
#     sA_goals_overunder_under_675(space)
#     sA_goals_overunder_over_70(space)
#     sA_goals_overunder_under_70(space)
#     sA_goals_overunder_over_75(space)
#     sA_goals_overunder_under_75(space)
#     sA_goals_overunder_over_85(space)
#     sA_goals_overunder_under_85(space)
#     sA_goals_overunder_over_95(space)
#     sA_goals_overunder_under_95(space)
    
#     # Match
    sA_goals_overunder_first_half_over_05(space)
    sA_goals_overunder_first_half_under_05(space)
    sA_goals_overunder_first_half_over_075(space)
    sA_goals_overunder_first_half_under_075(space)
    sA_goals_overunder_first_half_over_10(space)
    sA_goals_overunder_first_half_under_10(space)
    sA_goals_overunder_first_half_over_125(space)
    sA_goals_overunder_first_half_under_125(space)
    sA_goals_overunder_first_half_over_15(space)
    sA_goals_overunder_first_half_under_15(space)
    sA_goals_overunder_first_half_over_175(space)
    sA_goals_overunder_first_half_under_175(space)
    sA_goals_overunder_first_half_over_20(space)
    sA_goals_overunder_first_half_under_20(space)
    sA_goals_overunder_first_half_over_225(space)
    sA_goals_overunder_first_half_under_225(space)
    sA_goals_overunder_first_half_over_25(space)
    sA_goals_overunder_first_half_under_25(space)
    sA_goals_overunder_first_half_over_275(space)
    sA_goals_overunder_first_half_under_275(space)
    sA_goals_overunder_first_half_over_30(space)
    sA_goals_overunder_first_half_under_30(space)
    sA_goals_overunder_first_half_over_325(space)
    sA_goals_overunder_first_half_under_325(space)
    sA_goals_overunder_first_half_over_35(space)
    sA_goals_overunder_first_half_under_35(space)
    sA_goals_overunder_first_half_over_375(space)
    sA_goals_overunder_first_half_under_375(space)
    
#     # Match
#     sA_htft_double_home_home(space)
#     sA_htft_double_home_draw(space)
#     sA_htft_double_home_away(space)
#     sA_htft_double_draw_home(space)
#     sA_htft_double_draw_draw(space)
#     sA_htft_double_draw_away(space)
#     sA_htft_double_away_home(space)
#     sA_htft_double_away_draw(space)
#     sA_htft_double_away_away(space)
    
#     # Match
    sA_both_teams_score_yes(space) 
    sA_both_teams_score_no(space)
    
#     # Match
    sA_highest_scoring_half_first(space)
    sA_highest_scoring_half_draw(space)
    sA_highest_scoring_half_second(space)
    
#     # Match
#     sA_double_chance_home_draw(space)
#     sA_double_chance_home_away(space)
#     sA_double_chance_draw_away(space)
    
#     # Match
#     sA_first_half_winner_home(space)
#     sA_first_half_winner_draw(space)
#     sA_first_half_winner_away(space)
    
#     # Match
#     sA_team_to_score_first_home(space)
#     sA_team_to_score_first_draw(space)
#     sA_team_to_score_first_away(space)
#     sA_team_to_score_last_home(space)
#     sA_team_to_score_last_draw(space)
#     sA_team_to_score_last_away(space)
    
#     # Match
#     sA_total_home_over_15(space)
#     sA_total_home_under_15(space)
#     sA_total_home_over_25(space)
#     sA_total_home_under_25(space)
#     sA_total_home_over_35(space)
#     sA_total_home_under_35(space)
#     sA_total_home_over_45(space)
#     sA_total_home_under_45(space)
#     sA_total_home_over_55(space)
#     sA_total_home_under_55(space)
#     sA_total_home_over_65(space)
#     sA_total_home_under_65(space)
#     sA_total_away_over_15(space)
#     sA_total_away_under_15(space)
#     sA_total_away_over_25(space)
#     sA_total_away_under_25(space)
#     sA_total_away_over_35(space)
#     sA_total_away_under_35(space)
#     sA_total_away_over_45(space)
#     sA_total_away_under_45(space)
#     sA_total_away_over_55(space)
#     sA_total_away_under_55(space)
#     sA_total_away_over_65(space)
#     sA_total_away_under_65(space)
    
#     # Match
#     sA_asian_handicap_first_half_home_min_175(space)
#     sA_asian_handicap_first_half_away_min_175(space)
#     sA_asian_handicap_first_half_home_min_15(space)
#     sA_asian_handicap_first_half_away_min_15(space)
#     sA_asian_handicap_first_half_home_min_125(space)
#     sA_asian_handicap_first_half_away_min_125(space)
#     sA_asian_handicap_first_half_home_min_1(space)
#     sA_asian_handicap_first_half_away_min_1(space)
#     sA_asian_handicap_first_half_home_min_075(space)
#     sA_asian_handicap_first_half_away_min_075(space)
#     sA_asian_handicap_first_half_home_min_05(space)
#     sA_asian_handicap_first_half_away_min_05(space)
#     sA_asian_handicap_first_half_home_min_025(space)
#     sA_asian_handicap_first_half_away_min_025(space)
#     sA_asian_handicap_first_half_home_plus_0(space)
#     sA_asian_handicap_first_half_away_plus_0(space)
#     sA_asian_handicap_first_half_home_plus_025(space)
#     sA_asian_handicap_first_half_away_plus_025(space)
#     sA_asian_handicap_first_half_home_plus_05(space)
#     sA_asian_handicap_first_half_away_plus_05(space)
#     sA_asian_handicap_first_half_home_plus_075(space)
#     sA_asian_handicap_first_half_away_plus_075(space)
#     sA_asian_handicap_first_half_home_plus_1(space)
#     sA_asian_handicap_first_half_away_plus_1(space)
#     sA_asian_handicap_first_half_home_plus_125(space)
#     sA_asian_handicap_first_half_away_plus_125(space)
#     sA_asian_handicap_first_half_home_plus_15(space)
#     sA_asian_handicap_first_half_away_plus_15(space)
#     sA_asian_handicap_first_half_home_plus_175(space)
#     sA_asian_handicap_first_half_away_plus_175(space)
    
#     # Match
#     sA_double_chance__first_half_home_draw(space)
#     sA_double_chance__first_half_home_away(space)
#     sA_double_chance__first_half_draw_away(space)
    
#     # Match
#     sA_oddeven_odd(space)
#     sA_oddeven_even(space)
    
#     # Match
#     sA_results_both_teams_score_home_yes(space)
#     sA_results_both_teams_score_draw_yes(space)
#     sA_results_both_teams_score_away_yes(space)
#     sA_results_both_teams_score_home_no(space)
#     sA_results_both_teams_score_draw_no(space)
#     sA_results_both_teams_score_away_no(space)
#     sA_result_total_goals_home_over_35(space)
#     sA_result_total_goals_draw_over_35(space)
#     sA_result_total_goals_away_over_35(space)
#     sA_result_total_goals_home_under_35(space)
#     sA_result_total_goals_draw_under_35(space)
#     sA_result_total_goals_away_under_35(space)
#     sA_result_total_goals_home_over_25(space)
#     sA_result_total_goals_draw_over_25(space)
#     sA_result_total_goals_away_over_25(space)
#     sA_result_total_goals_home_under_25(space)
#     sA_result_total_goals_draw_under_25(space)
#     sA_result_total_goals_away_under_25(space)
    
#     # Match
#     sA_goals_overunder__second_half_over_05(space)
#     sA_goals_overunder__second_half_under_05(space)
#     sA_goals_overunder__second_half_over_075(space)
#     sA_goals_overunder__second_half_under_075(space)
#     sA_goals_overunder__second_half_over_10(space)
#     sA_goals_overunder__second_half_under_10(space)
#     sA_goals_overunder__second_half_over_125(space)
#     sA_goals_overunder__second_half_under_125(space)
#     sA_goals_overunder__second_half_over_15(space)
#     sA_goals_overunder__second_half_under_15(space)
#     sA_goals_overunder__second_half_over_175(space)
#     sA_goals_overunder__second_half_under_175(space)
#     sA_goals_overunder__second_half_over_20(space)
#     sA_goals_overunder__second_half_under_20(space)
#     sA_goals_overunder__second_half_over_225(space)
#     sA_goals_overunder__second_half_under_225(space)
#     sA_goals_overunder__second_half_over_25(space)
#     sA_goals_overunder__second_half_under_25(space)
#     sA_goals_overunder__second_half_over_275(space)
#     sA_goals_overunder__second_half_under_275(space)
#     sA_goals_overunder__second_half_over_30(space)
#     sA_goals_overunder__second_half_under_30(space)
#     sA_goals_overunder__second_half_over_325(space)
#     sA_goals_overunder__second_half_under_325(space)
#     sA_goals_overunder__second_half_over_35(space)
#     sA_goals_overunder__second_half_under_35(space)
#     sA_goals_overunder__second_half_over_375(space)
#     sA_goals_overunder__second_half_under_375(space)
    
#     # Match
#     sA_clean_sheet__home_yes(space)
#     sA_clean_sheet__home_no(space)
    
#     # Match
#     sA_clean_sheet__away_yes(space)
#     sA_clean_sheet__away_no(space)
    
#     # Match
#     sA_win_both_halves_home(space)
#     sA_win_both_halves_away(space)
    
#     # Match
#     sA_both_teams_score__first_half_yes(space)
#     sA_both_teams_score__first_half_no(space)
    
#     # Match
#     sA_both_teams_to_score__second_half_yes(space)
#     sA_both_teams_to_score__second_half_no(space)
    
#     # Match
#     sA_win_to_nil_home(space)
#     sA_win_to_nil_away(space)
    
#     # Match
#     sA_exact_goals_number_0(space)
#     sA_exact_goals_number_1(space)
#     sA_exact_goals_number_2(space)
#     sA_exact_goals_number_3(space)
#     sA_exact_goals_number_4(space)
#     sA_exact_goals_number_5(space)
#     sA_exact_goals_number_6(space)
#     sA_exact_goals_number_more_7(space)
    
#     # Match
#     sA_to_win_either_half_home(space)
#     sA_to_win_either_half_away(space)
    
#     # Match
#     sA_home_team_exact_goals_number_0(space)
#     sA_home_team_exact_goals_number_1(space)
#     sA_home_team_exact_goals_number_2(space)
#     sA_home_team_exact_goals_number_more_3(space)
    
#     # Match
#     sA_away_team_exact_goals_number_0(space)
#     sA_away_team_exact_goals_number_1(space)
#     sA_away_team_exact_goals_number_2(space)
#     sA_away_team_exact_goals_number_more_3(space)
    
#     # Match
#     sA_second_half_exact_goals_number_0(space)
#     sA_second_half_exact_goals_number_1(space)
#     sA_second_half_exact_goals_number_2(space)
#     sA_second_half_exact_goals_number_3(space)
#     sA_second_half_exact_goals_number_4(space)
#     sA_second_half_exact_goals_number_more_5(space)
    
#     # Match
#     sA_corners_over_under_over_700(space)
#     sA_corners_over_under_under_700(space)
#     sA_corners_over_under_over_725(space)
#     sA_corners_over_under_under_725(space)
#     sA_corners_over_under_over_750(space)
#     sA_corners_over_under_under_750(space)
#     sA_corners_over_under_over_775(space)
#     sA_corners_over_under_under_775(space)
#     sA_corners_over_under_over_800(space)
#     sA_corners_over_under_under_800(space)
#     sA_corners_over_under_over_825(space)
#     sA_corners_over_under_under_825(space)
#     sA_corners_over_under_over_850(space)
#     sA_corners_over_under_under_850(space)
#     sA_corners_over_under_over_875(space)
#     sA_corners_over_under_under_875(space)
#     sA_corners_over_under_over_900(space)
#     sA_corners_over_under_under_900(space)
#     sA_corners_over_under_over_925(space)
#     sA_corners_over_under_under_925(space)
#     sA_corners_over_under_over_950(space)
#     sA_corners_over_under_under_950(space)
#     sA_corners_over_under_over_975(space)
#     sA_corners_over_under_under_975(space)
#     sA_corners_over_under_over_1000(space)
#     sA_corners_over_under_under_1000(space)
#     sA_corners_over_under_over_1025(space)
#     sA_corners_over_under_under_1025(space)
#     sA_corners_over_under_over_1050(space)
#     sA_corners_over_under_under_1050(space)
#     sA_corners_over_under_over_1075(space)
#     sA_corners_over_under_under_1075(space)
#     sA_corners_over_under_over_1100(space)
#     sA_corners_over_under_under_1100(space)
#     sA_corners_over_under_over_1125(space)
#     sA_corners_over_under_under_1125(space)
#     sA_corners_over_under_over_1150(space)
#     sA_corners_over_under_under_1150(space)
#     sA_corners_over_under_over_1175(space)
#     sA_corners_over_under_under_1175(space)
#     sA_corners_over_under_over_1200(space)
#     sA_corners_over_under_under_1200(space)
#     sA_corners_over_under_over_1225(space)
#     sA_corners_over_under_under_1225(space)
#     sA_corners_over_under_over_1250(space)
#     sA_corners_over_under_under_1250(space)
#     sA_corners_over_under_over_1275(space) 
#     sA_corners_over_under_under_1275(space)
    
#     # Match
#     sA_exact_goals_number__first_half_0(space)
#     sA_exact_goals_number__first_half_1(space)
#     sA_exact_goals_number__first_half_2(space)
#     sA_exact_goals_number__first_half_3(space)
#     sA_exact_goals_number__first_half_4(space)
#     sA_exact_goals_number__first_half_more_5(space)
    
#     # Match
#     sA_to_score_in_both_halves_by_teams_home(space)
#     sA_to_score_in_both_halves_by_teams_away(space)
    
#     # Match
#     sA_total_goals_both_teams_to_score_over_yes_25(space)
#     sA_total_goals_both_teams_to_score_over_no_25(space)
#     sA_total_goals_both_teams_to_score_under_yes_25(space)
#     sA_total_goals_both_teams_to_score_under_no_25(space)
    
#     # Match
#     sA_halftime_result_both_teams_score_home_yes(space)
#     sA_halftime_result_both_teams_score_draw_yes(space)
#     sA_halftime_result_both_teams_score_away_yes(space)
#     sA_halftime_result_both_teams_score_home_no(space)
#     sA_halftime_result_both_teams_score_draw_no(space)
#     sA_halftime_result_both_teams_score_away_no(space)
    
#     # Match
#     sA_corners_winner_home(space)
#     sA_corners_winner_draw(space)
#     sA_corners_winner_away(space)
    
#     # Match
#     sA_corners_asian_handicap_home_min_65(space)
#     sA_corners_asian_handicap_away_min_65(space)
#     sA_corners_asian_handicap_home_min_6(space)
#     sA_corners_asian_handicap_away_min_6(space)
#     sA_corners_asian_handicap_home_min_55(space)
#     sA_corners_asian_handicap_away_min_55(space)
#     sA_corners_asian_handicap_home_min_5(space)
#     sA_corners_asian_handicap_away_min_5(space)
#     sA_corners_asian_handicap_home_min_45(space)
#     sA_corners_asian_handicap_away_min_45(space)
#     sA_corners_asian_handicap_home_min_4(space)
#     sA_corners_asian_handicap_away_min_4(space)
#     sA_corners_asian_handicap_home_min_35(space)
#     sA_corners_asian_handicap_away_min_35(space)
#     sA_corners_asian_handicap_home_min_3(space)
#     sA_corners_asian_handicap_away_min_3(space)
#     sA_corners_asian_handicap_home_min_25(space)
#     sA_corners_asian_handicap_away_min_25(space)
#     sA_corners_asian_handicap_home_min_2(space)
#     sA_corners_asian_handicap_away_min_2(space)
#     sA_corners_asian_handicap_home_min_15(space)
#     sA_corners_asian_handicap_away_min_15(space)
#     sA_corners_asian_handicap_home_min_1(space)
#     sA_corners_asian_handicap_home_min_05(space)
#     sA_corners_asian_handicap_away_min_1(space)
#     sA_corners_asian_handicap_away_min_05(space)
#     sA_corners_asian_handicap_home_plus_0(space)
#     sA_corners_asian_handicap_away_plus_0(space)
#     sA_corners_asian_handicap_home_plus_05(space)
#     sA_corners_asian_handicap_away_plus_05(space)
#     sA_corners_asian_handicap_home_plus_1(space)
#     sA_corners_asian_handicap_away_plus_1(space)
#     sA_corners_asian_handicap_home_plus_15(space)
#     sA_corners_asian_handicap_away_plus_15(space)
#     sA_corners_asian_handicap_home_plus_2(space)
#     sA_corners_asian_handicap_away_plus_2(space)
#     sA_corners_asian_handicap_home_plus_25(space)
#     sA_corners_asian_handicap_away_plus_25(space)
#     sA_corners_asian_handicap_home_plus_3(space)
#     sA_corners_asian_handicap_away_plus_3(space)
#     sA_corners_asian_handicap_home_plus_35(space)
#     sA_corners_asian_handicap_away_plus_35(space)
#     sA_corners_asian_handicap_home_plus_4(space)
#     sA_corners_asian_handicap_away_plus_4(space)
#     sA_corners_asian_handicap_home_plus_45(space)
#     sA_corners_asian_handicap_away_plus_45(space)
#     sA_corners_asian_handicap_home_plus_5(space)
#     sA_corners_asian_handicap_away_plus_5(space)
#     sA_corners_asian_handicap_home_plus_55(space)
#     sA_corners_asian_handicap_away_plus_55(space)
#     sA_corners_asian_handicap_home_plus_6(space)
#     sA_corners_asian_handicap_away_plus_6(space)
#     sA_corners_asian_handicap_home_plus_65(space)
#     sA_corners_asian_handicap_away_plus_65(space)
    
#     # Match
#     sA_home_corners_overunder_over_25(space)
#     sA_home_corners_overunder_under_25(space)
#     sA_home_corners_overunder_over_35(space)
#     sA_home_corners_overunder_under_35(space)
#     sA_home_corners_overunder_over_45(space)
#     sA_home_corners_overunder_under_45(space)
#     sA_home_corners_overunder_over_55(space)
#     sA_home_corners_overunder_under_55(space)
#     sA_home_corners_overunder_over_65(space)
#     sA_home_corners_overunder_under_65(space)
#     sA_home_corners_overunder_over_75(space)
#     sA_home_corners_overunder_under_75(space)
#     sA_home_corners_overunder_over_85(space)
#     sA_home_corners_overunder_under_85(space)
#     sA_away_corners_overunder_over_25(space)
#     sA_away_corners_overunder_under_25(space)
#     sA_away_corners_overunder_over_35(space)
#     sA_away_corners_overunder_under_35(space)
#     sA_away_corners_overunder_over_45(space)
#     sA_away_corners_overunder_under_45(space)
#     sA_away_corners_overunder_over_55(space)
#     sA_away_corners_overunder_under_55(space)
#     sA_away_corners_overunder_over_65(space)
#     sA_away_corners_overunder_under_65(space)
#     sA_away_corners_overunder_over_75(space)
#     sA_away_corners_overunder_under_75(space)
#     sA_away_corners_overunder_over_85(space)
#     sA_away_corners_overunder_under_85(space)
    
#     # Match
#     sA_both_teams_to_score_1st_half__2nd_half_yes_yes(space)
#     sA_both_teams_to_score_1st_half__2nd_half_yes_no(space)
#     sA_both_teams_to_score_1st_half__2nd_half_no_yes(space)
#     sA_both_teams_to_score_1st_half__2nd_half_no_no(space)
    
#     # Match
#     sA_10_overunder_over_05(space)
#     sA_10_overunder_under_05(space)
    
#     # Match
#     sA_last_corner_home(space)
#     sA_last_corner_away(space)
    
#     # Match
#     sA_first_corner_home(space)
#     sA_first_corner_away(space)
    
#     # Match
#     sA_cards_european_handicap_home_min_2(space)
#     sA_cards_european_handicap_draw_min_2(space)
#     sA_cards_european_handicap_away_min_2(space)
#     sA_cards_european_handicap_home_min_1(space)
#     sA_cards_european_handicap_draw_min_1(space)
#     sA_cards_european_handicap_away_min_1(space)
#     sA_cards_european_handicap_home_plus_0(space)
#     sA_cards_european_handicap_draw_plus_0(space)
#     sA_cards_european_handicap_away_plus_0(space)
#     sA_cards_european_handicap_home_plus_1(space)
#     sA_cards_european_handicap_draw_plus_1(space)
#     sA_cards_european_handicap_away_plus_1(space)
#     sA_cards_european_handicap_home_plus_2(space)
#     sA_cards_european_handicap_draw_plus_2(space)
#     sA_cards_european_handicap_away_plus_2(space)
    
#     # Match
#     sA_cards_overunder_over_25(space)
#     sA_cards_overunder_under_25(space)
#     sA_cards_overunder_over_35(space)
#     sA_cards_overunder_under_35(space)
#     sA_cards_overunder_over_45(space)
#     sA_cards_overunder_under_45(space)
#     sA_cards_overunder_over_55(space)
#     sA_cards_overunder_under_55(space)
#     sA_cards_overunder_over_65(space)
#     sA_cards_overunder_under_65(space)
#     sA_cards_overunder_over_75(space)
#     sA_cards_overunder_under_75(space)
    
#     # Match
#     sA_cards_asian_handicap_home_min_05(space)
#     sA_cards_asian_handicap_away_min_05(space)
#     sA_cards_asian_handicap_home_plus_0(space)
#     sA_cards_asian_handicap_away_plus_0(space)
#     sA_cards_asian_handicap_home_plus_05(space)
#     sA_cards_asian_handicap_away_plus_05(space)
    
#     # Match
#     sA_home_team_total_cards_over_15(space)
#     sA_home_team_total_cards_under_15(space)
#     sA_home_team_total_cards_over_25(space)
#     sA_home_team_total_cards_under_25(space)
#     sA_home_team_total_cards_over_35(space)
#     sA_home_team_total_cards_under_35(space)
#     sA_away_team_total_cards_over_15(space)
#     sA_away_team_total_cards_under_15(space)
#     sA_away_team_total_cards_over_25(space)
#     sA_away_team_total_cards_under_25(space)
#     sA_away_team_total_cards_over_35(space)
#     sA_away_team_total_cards_under_35(space)
    
#     # Match
#     sA_rcard_yes(space)
#     sA_rcard_no(space)
    
#     # Match
#     sA_total_goals_under_2(space)
#     sA_total_goals_2_or_3(space)
#     sA_total_goals_over_3(space)
    
#     # Match
#     sA_first_goal_method_shot(space)
#     sA_first_goal_method_header(space)
#     sA_first_goal_method_penalty(space)
#     sA_first_goal_method_freekick(space)
#     sA_first_goal_method_owngoal(space)
#     sA_first_goal_method_draw(space)
    
#     # Match
#     sA_to_score_a_penalty_home(space)
#     sA_to_score_a_penalty_away(space)
#     sA_to_miss_a_penalty_home(space)
#     sA_to_miss_a_penalty_away(space)

    # -------------------------------------------------- 
    its_end()   
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-14 23:39:35
#   __main()
#   ______sA_match_winner_home()
#   ______sA_match_winner_draw()
#   ______sA_match_winner_away()
#   ______sA_homeaway_home()
#   ______sA_homeaway_away()
#   ______sA_asian_handicap_home_min_675()
#   ______sA_asian_handicap_away_min_675()
#   ______sA_asian_handicap_home_min_65()
#   ______sA_asian_handicap_away_min_65()
#   ______sA_asian_handicap_home_min_625()
#   ______sA_asian_handicap_away_min_625()
#   ______sA_asian_handicap_home_min_6()
#   ______sA_asian_handicap_away_min_6()
#   ______sA_asian_handicap_home_min_575()
#   ______sA_asian_handicap_away_min_575()
#   ______sA_asian_handicap_home_min_55()
#   ______sA_asian_handicap_away_min_55()
#   ______sA_asian_handicap_home_min_525()
#   ______sA_asian_handicap_away_min_525()
#   ______sA_asian_handicap_home_min_5()
#   ______sA_asian_handicap_away_min_5()
#   ______sA_asian_handicap_home_min_475()
# ...
