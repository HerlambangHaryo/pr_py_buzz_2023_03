# %%
# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *   
from a_models.statistic_assessment_group import *   
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------    
    # --------------------------------------------------    
    sAg_rounder(0, 0, space)
    # -------------------------------------------------- 
    its_end()   
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-06-08 15:12:40
#   __main()
#   ______sAg_rounder()
#   ________sAg_score_secondtime()
#
#   ________sAg_match_winner_home()
#  UPDATE `football_statistics` SET   `match_winner_home` = 1  where fixture_status in ('Match Finished', 'Match Finished Ended')  and `goals_home` > `goals_away`
#   ________sAg_zero()
#  UPDATE `football_statistics` SET   `match_winner_home` = 0  where fixture_status in ('Match Finished', 'Match Finished Ended')  and `match_winner_home` != 1
#   ________sAg_match_winner_draw()
#  UPDATE `football_statistics` SET   `match_winner_draw` = 1  where fixture_status in ('Match Finished', 'Match Finished Ended')  and `goals_home` = `goals_away`
#   ________sAg_zero()
#  UPDATE `football_statistics` SET   `match_winner_draw` = 0  where fixture_status in ('Match Finished', 'Match Finished Ended')  and `match_winner_draw` != 1
#   ________sAg_match_winner_away()
# ...
