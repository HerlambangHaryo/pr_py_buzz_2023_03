# %%
# 3. insert and kalibrasi patternlist

import datetime 

# Import
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.football_fixtures import *  

if __name__ == '__main__': 
    # ----------------------------------------------------------   
    its_start() 
    # ----------------------------------------------------------  
    space = "  __"
    # ----------------------------------------------------------   
    print(space + "__main__") 
    # ----------------------------------------------------------  
    host="localhost"
    user="root" 
    database="pr_mmbuzz_2022_06"
    mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
    mycursor = mydb.cursor()
    # ----------------------------------------------------------
    query = " Select  leagueapi_id " 
    query += " from football_leagues "    
    query += " where star is not null "   
    # ----------------------------------------------------------
    mycursor = mydb.cursor()
    mycursor.execute(query)
    result =  mycursor.fetchall()
    # ----------------------------------------------------------
    counter = 0
    # ----------------------------------------------------------
    for x in result:    
    # ----------------------------------------------------------
        counter += 1
        print(str(counter) + ". " + str(x[0]) )
    # ----------------------------------------------------------
    space += "____"  
    # ----------------------------------------------------------  
#     leagueapi_id   = input(space + "Enter your leagueapi id :  ") 
    # ----------------------------------------------------------   
#     ff_get_fixtures_group_by_pre_end_patternlists(leagueapi_id, space)
    # ---------------------------------------------------------- 
    its_end()  
    ############################################################
# Out:
# # -------------------------------------------------- Start at 2023-05-27 11:21:41
#   ____main__
# 1. 39
# 2. 40
# 3. 46
# 4. 45
# 5. 47
# 6. 48
# 7. 43
# 8. 41
# 9. 42
# 10. 528
# 11. 88
# 12. 90
# 13. 89
# 14. 78
# 15. 79
# 16. 81
# 17. 135
# 18. 547
# 19. 136
# 20. 137
# 21. 140
# 22. 141
# 23. 143
# 24. 61
# 25. 62
# 26. 63
# 27. 66
# 28. 144
# 29. 145
# 30. 147
# 31. 218
# 32. 71
# 33. 72
# 34. 73
# 35. 244
# 36. 245
# 37. 346
# 38. 345
# 39. 119
# 40. 210
# 41. 211
# 42. 197
# 43. 199
# 44. 271
# 45. 164
# 46. 167
# 47. 168
# 48. 274
# 49. 357
# 50. 358
# 51. 98
# 52. 101
# 53. 262
# 54. 263
# 55. 103
# 56. 104
# 57. 105
# 58. 107
# 59. 106
# 60. 108
# 61. 94
# 62. 95
# 63. 96
# 64. 97
# 65. 235
# 66. 180
# 67. 179
# 68. 181
# 69. 182
# 70. 203
# 71. 206
# 72. 297
# 73. 296
# 74. 207
# 75. 208
# 76. 209
# 77. 114
# 78. 113
# 79. 373
# 80. 1
# 81. 2
# 82. 3
# 83. 5
# 84. 253
# 85. 12
# 86. 536
# 87. 848
# 88. 292
# 89. 293
# 90. 283
# 91. 188
# 92. 128
# 93. 287
# 94. 286
# 95. 265
# 96. 239
# 97. 116
# 98. 250
# 99. 281
# 100. 368
# 101. 365
# 102. 364
# 103. 362
# 104. 361
# 105. 169
# 106. 328
# 107. 242
# 108. 307
# 109. 318
# 110. 288
# 111. 960
# 112. 490
# 113. 340
# # -------------------------------------------------- End at 2023-05-27 11:21:41
