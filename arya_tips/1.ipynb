# %%
# Import
import mysql.connector 

betapi_id = 1
# ----------------------------------------------------------   
space = "__"  
# ----------------------------------------------------------  
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ----------------------------------------------------------  
query = "Select "
query += " * "
query += " from bets_old " 
query += " where bet_id = '"+str(betapi_id)+"' "   
# ----------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ----------------------------------------------------------  
mycursor.close()
mydb.close()
# ----------------------------------------------------------   
space += "__"
# ---------------------------------------------------------- 
total_rows = len(result) 
# ---------------------------------------------------------- 
counter = 0
# ----------------------------------------------------------   
space += "__"
# ----------------------------------------------------------

# %%
# ----------------------------------------------------------
space           = "    "
kurwa_buka      = "{"
kurwa_tutup     = "}"
prep_           = "pre_"
petik           = "'"
petik2          = '"'
# ----------------------------------------------------------
word = '<div class="btn-group mt-2">'  
print(word, flush=True)      
# ----------------------------------------------------------
for x in result:    
    # ------------------------------------------------------ 
    betapi_id           = str(x[0])   
    bet                 = str(x[1])    
    valx                = str(x[3])    
    colx                = str(x[5])    
    # ------------------------------------------------------
    word = space + '<a'  
    print(word, flush=True)      
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------
    word = space + space +  '@if(!is_null($row->' + prep_ + colx + '))'  
    print(word, flush=True)   
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # href="{{ route('Aryatips.tip', 
    #     'leagueapi_id' => $row->leagueapi_id,
    #     'season' => $row->season,
    #     'fixtureapi_id' => $row->fixtureapi_id,
    #     'betapi_id' => 92,
    #     'value' => $val_replace,
    #     'odd' => $row->pre_odd 
    # ------------------------------------------------------ 
    word = space + space + space + 'href=' + petik2 + kurwa_buka + kurwa_buka + ' route(' + petik + "Aryatips.tip" + petik + ','
    print(word, flush=True)    
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    word = space + space + space + space +  '['  
    print(word, flush=True)    
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'leagueapi_id' => $row->leagueapi_id,"  
    print(word, flush=True) 
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'season' => $row->season,"  
    print(word, flush=True) 
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'fixtureapi_id' => $row->fixtureapi_id,"  
    print(word, flush=True) 
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'betapi_id' => "+str(bet)+","  
    print(word, flush=True)   
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'value' => '"+colx+"',"  
    print(word, flush=True)   
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'odd' => $row->" + prep_ + colx
    print(word, flush=True)   
    # ------------------------------------------------------ 
    word = space + space + space + space +  '])'  
    print(word, flush=True)   
    # ------------------------------------------------------ 
    # ------------------------------------------------------
    # ------------------------------------------------------ 
    # ------------------------------------------------------
    word = space + space + space + kurwa_tutup + kurwa_tutup + '"'  
    print(word, flush=True)   
    # ------------------------------------------------------ 
    # ------------------------------------------------------
    # ------------------------------------------------------
    word = space + space +  '@endif'  
    print(word, flush=True)   
    # ------------------------------------------------------
    word = space + space +  'target="_blank"'  
    print(word, flush=True)   
    # ------------------------------------------------------
    word = space + space +  'class="btn bg-gray-700 btn-sm text-white">'  
    print(word, flush=True)    
    # ------------------------------------------------------
    word = space + space + valx
    print(word, flush=True)     
    # ------------------------------------------------------
    word = space + space +  '<br/>'  
    print(word, flush=True)   
    # ------------------------------------------------------
    word = space + space + kurwa_buka + kurwa_buka + ' $row->' + prep_ + colx + ' ' + kurwa_tutup + kurwa_tutup
    print(word, flush=True)    
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    word = space + '</a>'  
    print(word, flush=True)     
    # ------------------------------------------------------ 
    word = ''  
    print(word, flush=True)      
# ----------------------------------------------------------
# ----------------------------------------------------------
word = '</div>'  
print(word, flush=True)      
# ----------------------------------------------------------
# Out:
# <div class="btn-group mt-2">
#     <a
#         @if(!is_null($row->pre_match_winner_home))
#             href="{{ route('Aryatips.tip',
#                 [
#                     'leagueapi_id' => $row->leagueapi_id,
#                     'season' => $row->season,
#                     'fixtureapi_id' => $row->fixtureapi_id,
#                     'betapi_id' => 1,
#                     'value' => 'match_winner_home',
#                     'odd' => $row->pre_match_winner_home
#                 ])
#             }}"
#         @endif
#         target="_blank"
#         class="btn bg-gray-700 btn-sm text-white">
#         Home
#         <br/>
#         {{ $row->pre_match_winner_home }}
#     </a>
#
#     <a
#         @if(!is_null($row->pre_match_winner_draw))
#             href="{{ route('Aryatips.tip',
#                 [
#                     'leagueapi_id' => $row->leagueapi_id,
#                     'season' => $row->season,
# ...

# %%
# ----------------------------------------------------------
space           = "    "
kurwa_buka      = "{"
kurwa_tutup     = "}"
prep_           = "end_"
petik           = "'"
petik2          = '"'
# ----------------------------------------------------------
word = ''  
print(word, flush=True)   
# ----------------------------------------------------------
word = '<br/>'  
print(word, flush=True)      
# ----------------------------------------------------------
word = ''  
print(word, flush=True)   
# ----------------------------------------------------------
word = '<div class="btn-group mt-2">'  
print(word, flush=True)      
# ----------------------------------------------------------
for x in result:    
    # ------------------------------------------------------ 
    betapi_id           = str(x[0])   
    bet                 = str(x[1])    
    valx                = str(x[3])    
    colx                = str(x[5])    
    # ------------------------------------------------------
    word = space + '<a'  
    print(word, flush=True)      
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------
    word = space + space +  '@if(!is_null($row->' + prep_ + colx + '))'  
    print(word, flush=True)   
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # href="{{ route('Aryatips.tip', 
    #     'leagueapi_id' => $row->leagueapi_id,
    #     'season' => $row->season,
    #     'fixtureapi_id' => $row->fixtureapi_id,
    #     'betapi_id' => 92,
    #     'value' => $val_replace,
    #     'odd' => $row->pre_odd 
    # ------------------------------------------------------ 
    word = space + space + space + 'href=' + petik2 + kurwa_buka + kurwa_buka + ' route(' + petik + "Mybets.datacreate" + petik + ','
    print(word, flush=True)    
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    word = space + space + space + space +  '['  
    print(word, flush=True)    
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'leagueapi_id' => $row->leagueapi_id,"  
    print(word, flush=True) 
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'season' => $row->season,"  
    print(word, flush=True) 
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'fixtureapi_id' => $row->fixtureapi_id,"  
    print(word, flush=True) 
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'betapi_id' => "+str(bet)+","  
    print(word, flush=True)   
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'value' => '"+colx+"',"  
    print(word, flush=True)   
    # ------------------------------------------------------ 
    word = space + space + space + space + space + "'odd' => $row->" + prep_ + colx
    print(word, flush=True)   
    # ------------------------------------------------------ 
    word = space + space + space + space +  '])'  
    print(word, flush=True)   
    # ------------------------------------------------------ 
    # ------------------------------------------------------
    # ------------------------------------------------------ 
    # ------------------------------------------------------
    word = space + space + space + kurwa_tutup + kurwa_tutup + '"'  
    print(word, flush=True)   
    # ------------------------------------------------------ 
    # ------------------------------------------------------
    # ------------------------------------------------------
    word = space + space +  '@endif'  
    print(word, flush=True)   
    # ------------------------------------------------------
    word = space + space +  'target="_blank"'  
    print(word, flush=True)   
    # ------------------------------------------------------
    word = space + space +  'class="btn bg-gray-800 btn-sm text-white">'  
    print(word, flush=True)    
    # ------------------------------------------------------
    word = space + space + valx
    print(word, flush=True)     
    # ------------------------------------------------------
    word = space + space +  '<br/>'  
    print(word, flush=True)   
    # ------------------------------------------------------
    word = space + space + kurwa_buka + kurwa_buka + ' $row->' + prep_ + colx + ' ' + kurwa_tutup + kurwa_tutup
    print(word, flush=True)    
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    # ------------------------------------------------------ 
    word = space + '</a>'  
    print(word, flush=True)     
    # ------------------------------------------------------ 
    word = ''  
    print(word, flush=True)      
# ----------------------------------------------------------
# ----------------------------------------------------------
word = '</div>'  
print(word, flush=True)      
# ----------------------------------------------------------
# Out:
# <br/>
#
# <div class="btn-group mt-2">
#     <a
#         @if(!is_null($row->end_match_winner_home))
#             href="{{ route('Mybets.datacreate',
#                 [
#                     'leagueapi_id' => $row->leagueapi_id,
#                     'season' => $row->season,
#                     'fixtureapi_id' => $row->fixtureapi_id,
#                     'betapi_id' => 1,
#                     'value' => 'match_winner_home',
#                     'odd' => $row->end_match_winner_home
#                 ])
#             }}"
#         @endif
#         target="_blank"
#         class="btn bg-gray-800 btn-sm text-white">
#         Home
#         <br/>
#         {{ $row->end_match_winner_home }}
#     </a>
#
#     <a
#         @if(!is_null($row->end_match_winner_draw))
#             href="{{ route('Mybets.datacreate',
#                 [
#                     'leagueapi_id' => $row->leagueapi_id,
#                     'season' => $row->season,
# ...
