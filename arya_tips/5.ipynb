# %%
# Import
import mysql.connector 

betapi_id = 5
# ----------------------------------------------------------   
space = "__"  
# ----------------------------------------------------------  
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ----------------------------------------------------------  
query = "Select "
query += " * "
query += " from bets_old " 
query += " where bet_id = '"+str(betapi_id)+"' "   
query += " order by total asc " 
# ----------------------------------------------------------   
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ----------------------------------------------------------  
mycursor.close()
mydb.close()
# ----------------------------------------------------------   
space += "__"
# ---------------------------------------------------------- 
total_rows = len(result) 
# ---------------------------------------------------------- 
counter = 0
# ----------------------------------------------------------   
space += "__"
# ----------------------------------------------------------

# %%
# ----------------------------------------------------------
space           = "    "
kurwa_buka      = "{"
kurwa_tutup     = "}"
prep_           = "pre_"
petik           = "'"
petik2          = '"'
# ----------------------------------------------------------
counter = 0
# ----------------------------------------------------------
# ----------------------------------------------------------
# ----------------------------------------------------------
for x in result:    
    # ------------------------------------------------------ 
    counter += 1
    # ------------------------------------------------------ 
    betapi_id           = str(x[0])   
    bet                 = str(x[1])    
    valx                = str(x[3])    
    colx                = str(x[5])    
    # ------------------------------------------------------ 
    # ------------------------------------------------------  
    # ------------------------------------------------------  
    if(counter == 1):
        # --------------------------------------------------
        colx_over = colx     
        valx_over = valx
        # --------------------------------------------------
    # ------------------------------------------------------ 
    if(counter == 2):
        # --------------------------------------------------  
        word = '@if(!is_null($row->' + prep_ + colx_over + ') && !is_null($row->' + prep_ + colx + ') )'  
        print(word, flush=True)       
        # --------------------------------------------------  
        word = space + '@if( ($row->' + prep_ + colx_over + ' + $row->' + prep_ + colx + ') < 4 )'  
        print(word, flush=True)     
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        word = space + space + '<div class="btn-group mt-2">'  
        print(word, flush=True)      
        # --------------------------------------------------  
        word = space + space + space + '<a'  
        print(word, flush=True)     

        # -------------------------------------------------- # --------------------------------------------------   
        word = space + space + space + space +  '@if(!is_null($row->' + prep_ + colx_over + '))'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------  
        # ------------------------------------------------------ 
        word = space + space + space + space + space +  'href=' + petik2 + kurwa_buka + kurwa_buka + ' route(' + petik + "Aryatips.tip" + petik + ','
        print(word, flush=True)    
        # ------------------------------------------------------ 
        # ------------------------------------------------------ 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space +   '['  
        print(word, flush=True)    
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'leagueapi_id' => $row->leagueapi_id,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'season' => $row->season,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'fixtureapi_id' => $row->fixtureapi_id,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'betapi_id' => "+str(bet)+","  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'value' => '"+colx_over+"',"  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'odd' => $row->" + prep_ + colx_over
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + '])'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        word = space + space + space + space + space + kurwa_tutup + kurwa_tutup + '"'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        # ------------------------------------------------------
        word = space + space + space + space +  '@endif'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + 'target="_blank"'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + 'class="btn bg-gray-700 btn-sm text-white">'  
        print(word, flush=True)    
        # ------------------------------------------------------
        word = space + space + space + space + valx_over
        print(word, flush=True)     
        # ------------------------------------------------------
        word = space + space + space + space +  '<br/>'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + kurwa_buka + kurwa_buka + ' $row->' + prep_ + colx_over + ' ' + kurwa_tutup + kurwa_tutup
        print(word, flush=True)     
        # -------------------------------------------------- # --------------------------------------------------  
        
        word = space + space + space + '</a>'  
        print(word, flush=True)     
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        word = space + space + space + '<a'  
        print(word, flush=True)     

        # -------------------------------------------------- # --------------------------------------------------   
        word = space + space + space + space +  '@if(!is_null($row->' + prep_ + colx + '))'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------  
        # ------------------------------------------------------ 
        word = space + space + space + space + space +  'href=' + petik2 + kurwa_buka + kurwa_buka + ' route(' + petik + "Aryatips.tip" + petik + ','
        print(word, flush=True)    
        # ------------------------------------------------------ 
        # ------------------------------------------------------ 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space +   '['  
        print(word, flush=True)    
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'leagueapi_id' => $row->leagueapi_id,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'season' => $row->season,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'fixtureapi_id' => $row->fixtureapi_id,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'betapi_id' => "+str(bet)+","  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'value' => '"+colx+"',"  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'odd' => $row->" + prep_ + colx
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + '])'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        word = space + space + space + space + space + kurwa_tutup + kurwa_tutup + '"'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        # ------------------------------------------------------
        word = space + space + space + space +  '@endif'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + 'target="_blank"'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + 'class="btn bg-gray-700 btn-sm text-white">'  
        print(word, flush=True)    
        # ------------------------------------------------------
        word = space + space + space + space + valx
        print(word, flush=True)     
        # ------------------------------------------------------
        word = space + space + space + space +  '<br/>'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + kurwa_buka + kurwa_buka + ' $row->' + prep_ + colx + ' ' + kurwa_tutup + kurwa_tutup
        print(word, flush=True)     
        # -------------------------------------------------- # --------------------------------------------------  

        word = space + space + space + '</a>'  
        print(word, flush=True)     
        # --------------------------------------------------  
        word = space + space + '</div>'  
        print(word, flush=True)      
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        word = space + '@endif'  
        print(word, flush=True)     
        # --------------------------------------------------  
        word = '@endif'  
        print(word, flush=True)     
        # --------------------------------------------------  
        word = ''  
        print(word, flush=True)     
        # --------------------------------------------------
        counter = 0
        # --------------------------------------------------
    # ------------------------------------------------------  
    # ------------------------------------------------------ 
# ----------------------------------------------------------
# ----------------------------------------------------------
# ----------------------------------------------------------
# Out:
# @if(!is_null($row->pre_goals_overunder_over_05) && !is_null($row->pre_goals_overunder_under_05) )
#     @if( ($row->pre_goals_overunder_over_05 + $row->pre_goals_overunder_under_05) < 4 )
#         <div class="btn-group mt-2">
#             <a
#                 @if(!is_null($row->pre_goals_overunder_over_05))
#                     href="{{ route('Aryatips.tip',
#                         [
#                             'leagueapi_id' => $row->leagueapi_id,
#                             'season' => $row->season,
#                             'fixtureapi_id' => $row->fixtureapi_id,
#                             'betapi_id' => 5,
#                             'value' => 'goals_overunder_over_05',
#                             'odd' => $row->pre_goals_overunder_over_05
#                         ])
#                     }}"
#                 @endif
#                 target="_blank"
#                 class="btn bg-gray-700 btn-sm text-white">
#                 Over 0.5
# ...

# %%
# ----------------------------------------------------------
space           = "    "
kurwa_buka      = "{"
kurwa_tutup     = "}"
prep_           = "end_"
petik           = "'"
petik2          = '"'
# ----------------------------------------------------------
counter = 0
# ----------------------------------------------------------
# ----------------------------------------------------------
word = ''  
print(word, flush=True)       
# ----------------------------------------------------------
word = '<br/>'  
print(word, flush=True)       
# ----------------------------------------------------------
word = ''  
print(word, flush=True)       
# ----------------------------------------------------------
for x in result:    
    # ------------------------------------------------------ 
    counter += 1
    # ------------------------------------------------------ 
    betapi_id           = str(x[0])   
    bet                 = str(x[1])    
    valx                = str(x[3])    
    colx                = str(x[5])    
    # ------------------------------------------------------ 
    # ------------------------------------------------------  
    # ------------------------------------------------------  
    if(counter == 1):
        # --------------------------------------------------
        colx_over = colx     
        valx_over = valx
        # --------------------------------------------------
    # ------------------------------------------------------ 
    if(counter == 2):
        # --------------------------------------------------  
        word = '@if(!is_null($row->' + prep_ + colx_over + ') && !is_null($row->' + prep_ + colx + ') )'  
        print(word, flush=True)       
        # --------------------------------------------------  
        word = space + '@if( ($row->' + prep_ + colx_over + ' + $row->' + prep_ + colx + ') < 4 )'  
        print(word, flush=True)     
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        word = space + space + '<div class="btn-group mt-2">'  
        print(word, flush=True)      
        # --------------------------------------------------  
        word = space + space + space + '<a'  
        print(word, flush=True)     

        # -------------------------------------------------- # --------------------------------------------------   
        word = space + space + space + space +  '@if(!is_null($row->' + prep_ + colx_over + '))'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------  
        # ------------------------------------------------------ 
        word = space + space + space + space + space +  'href=' + petik2 + kurwa_buka + kurwa_buka + ' route(' + petik + "Aryatips.tip" + petik + ','
        print(word, flush=True)    
        # ------------------------------------------------------ 
        # ------------------------------------------------------ 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space +   '['  
        print(word, flush=True)    
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'leagueapi_id' => $row->leagueapi_id,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'season' => $row->season,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'fixtureapi_id' => $row->fixtureapi_id,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'betapi_id' => "+str(bet)+","  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'value' => '"+colx_over+"',"  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'odd' => $row->" + prep_ + colx_over
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + '])'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        word = space + space + space + space + space + kurwa_tutup + kurwa_tutup + '"'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        # ------------------------------------------------------
        word = space + space + space + space +  '@endif'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + 'target="_blank"'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + 'class="btn bg-gray-800 btn-sm text-white">'  
        print(word, flush=True)    
        # ------------------------------------------------------
        word = space + space + space + space + valx_over
        print(word, flush=True)     
        # ------------------------------------------------------
        word = space + space + space + space +  '<br/>'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + kurwa_buka + kurwa_buka + ' $row->' + prep_ + colx_over + ' ' + kurwa_tutup + kurwa_tutup
        print(word, flush=True)     
        # -------------------------------------------------- # --------------------------------------------------  
        
        word = space + space + space + '</a>'  
        print(word, flush=True)     
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        word = space + space + space + '<a'  
        print(word, flush=True)     

        # -------------------------------------------------- # --------------------------------------------------   
        word = space + space + space + space +  '@if(!is_null($row->' + prep_ + colx + '))'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------  
        # ------------------------------------------------------ 
        word = space + space + space + space + space +  'href=' + petik2 + kurwa_buka + kurwa_buka + ' route(' + petik + "Aryatips.tip" + petik + ','
        print(word, flush=True)    
        # ------------------------------------------------------ 
        # ------------------------------------------------------ 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space +   '['  
        print(word, flush=True)    
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'leagueapi_id' => $row->leagueapi_id,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'season' => $row->season,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'fixtureapi_id' => $row->fixtureapi_id,"  
        print(word, flush=True) 
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'betapi_id' => "+str(bet)+","  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'value' => '"+colx+"',"  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + space +  "'odd' => $row->" + prep_ + colx
        print(word, flush=True)   
        # ------------------------------------------------------ 
        word = space + space + space + space + space + space + '])'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        word = space + space + space + space + space + kurwa_tutup + kurwa_tutup + '"'  
        print(word, flush=True)   
        # ------------------------------------------------------ 
        # ------------------------------------------------------
        # ------------------------------------------------------
        word = space + space + space + space +  '@endif'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + 'target="_blank"'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + 'class="btn bg-gray-800 btn-sm text-white">'  
        print(word, flush=True)    
        # ------------------------------------------------------
        word = space + space + space + space + valx
        print(word, flush=True)     
        # ------------------------------------------------------
        word = space + space + space + space +  '<br/>'  
        print(word, flush=True)   
        # ------------------------------------------------------
        word = space + space + space + space + kurwa_buka + kurwa_buka + ' $row->' + prep_ + colx + ' ' + kurwa_tutup + kurwa_tutup
        print(word, flush=True)     
        # -------------------------------------------------- # --------------------------------------------------  

        word = space + space + space + '</a>'  
        print(word, flush=True)     
        # --------------------------------------------------  
        word = space + space + '</div>'  
        print(word, flush=True)      
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        # --------------------------------------------------  
        word = space + '@endif'  
        print(word, flush=True)     
        # --------------------------------------------------  
        word = '@endif'  
        print(word, flush=True)     
        # --------------------------------------------------  
        word = ''  
        print(word, flush=True)     
        # --------------------------------------------------
        counter = 0
        # --------------------------------------------------
    # ------------------------------------------------------  
    # ------------------------------------------------------ 
# ----------------------------------------------------------
# ----------------------------------------------------------
# ----------------------------------------------------------
# Out:
# <br/>
#
# @if(!is_null($row->end_goals_overunder_over_05) && !is_null($row->end_goals_overunder_under_05) )
#     @if( ($row->end_goals_overunder_over_05 + $row->end_goals_overunder_under_05) < 4 )
#         <div class="btn-group mt-2">
#             <a
#                 @if(!is_null($row->end_goals_overunder_over_05))
#                     href="{{ route('Aryatips.tip',
#                         [
#                             'leagueapi_id' => $row->leagueapi_id,
#                             'season' => $row->season,
#                             'fixtureapi_id' => $row->fixtureapi_id,
#                             'betapi_id' => 5,
#                             'value' => 'goals_overunder_over_05',
#                             'odd' => $row->end_goals_overunder_over_05
#                         ])
#                     }}"
#                 @endif
#                 target="_blank"
#                 class="btn bg-gray-800 btn-sm text-white">
#                 Over 0.5
# ...
