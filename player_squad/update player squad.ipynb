# %%
# Import 
import sys
sys.path.append('../')

from a_settings.messages import *   
from a_models.date import *   
from a_models.api_odds_new import *   
from a_models.api_player_squad import *   
     
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()", flush=True)  
    # --------------------------------------------------    
    space += "__" 
    # --------------------------------------------------   
    leagueapi_id    = input(space + "Enter your leagueapi id :  ")  
    # --------------------------------------------------  
    aps_group_by_all_team(leagueapi_id, space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-25 21:35:32
#   __main()
#   ______aps_group_by_all_team()
#   ______Select  teams_homeapi_id  from football_fixtures  where leagueapi_id =  '43'  group by teams_homeapi_id
#   ______Total Row(s) : 35
#   ______[1/35]  #1339
#   ________aps_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api5@ariondigitalmedia.com counter is 38
#   ____________APIkey: 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________aps_response_odds()
#   ____________leagueapi_id : 43
#   ____________teamapi_id : 1339
#   ______________Total API Response(s) : 1
#   __________________aps_delete()
#   ____________________teamapi_id : 1339
#   ______________________ delete  from football_player_squads  where teamapi_id = 1339
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  144741,  'L. Moulden',  '21',  '1',  'Goalkeeper',  'https://media-1.api-sports.io/football/players/144741.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  338171,  'B. Kelly',  '23',  '12',  'Goalkeeper',  'https://media-2.api-sports.io/football/players/338171.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18743,  'C. John',  '24',  '3',  'Defender',  'https://media-1.api-sports.io/football/players/18743.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  158699,  'M. Taylor',  '23',  '5',  'Defender',  'https://media-1.api-sports.io/football/players/158699.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20229,  'E. Ebanks-Landell',  '31',  '6',  'Defender',  'https://media-2.api-sports.io/football/players/20229.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  417558,  'G. Nevett',  '17',  '15',  'Defender',  'https://media-2.api-sports.io/football/players/417558.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  284265,  'K. Oduroh',  '21',  '16',  'Defender',  'https://media-3.api-sports.io/football/players/284265.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19237,  'A. Clayton',  '34',  '8',  'Midfielder',  'https://media-3.api-sports.io/football/players/19237.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20246,  'J. Keohane',  '32',  '13',  'Midfielder',  'https://media-1.api-sports.io/football/players/20246.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  428611,  'M. Afuye',  'None',  '17',  'Midfielder',  'https://media-1.api-sports.io/football/players/428611.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17516,  'H. Gilmour',  '25',  '20',  'Midfielder',  'https://media-2.api-sports.io/football/players/17516.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  159007,  'K. Ferguson',  '24',  '24',  'Midfielder',  'https://media-2.api-sports.io/football/players/159007.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  384402,  'K. Dos Santos',  'None',  '28',  'Midfielder',  'https://media-1.api-sports.io/football/players/384402.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  430465,  'John Dunlop',  '17',  '29',  'Midfielder',  'https://media-1.api-sports.io/football/players/430465.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  418632,  'B. Bailey',  '18',  '31',  'Midfielder',  'https://media-1.api-sports.io/football/players/418632.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  350586,  'T. McDermott',  '18',  'None',  'Midfielder',  'https://media-2.api-sports.io/football/players/350586.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  345776,  'J. Uchegbulam',  'None',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/345776.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17464,  'T. Sinclair',  '22',  '7',  'Attacker',  'https://media-1.api-sports.io/football/players/17464.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  155282,  'K. Mitchell',  '26',  '9',  'Attacker',  'https://media-3.api-sports.io/football/players/155282.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18142,  'D. Rodney',  '25',  '10',  'Attacker',  'https://media-3.api-sports.io/football/players/18142.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  375872,  'M. Shubbar',  '20',  '22',  'Attacker',  'https://media-1.api-sports.io/football/players/375872.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  394625,  'O. Kelly',  '16',  '27',  'Attacker',  'https://media-3.api-sports.io/football/players/394625.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  413022,  'D. Ehimamiegho',  '17',  '32',  'Attacker',  'https://media-3.api-sports.io/football/players/413022.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20252,  'I. Henderson',  '38',  '40',  'Attacker',  'https://media-1.api-sports.io/football/players/20252.png',  current_timestamp )
#
#   ____________________football_teams UPDATED
#   ______[2/35]  #1340
#   ________aps_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api5@ariondigitalmedia.com counter is 37
#   ____________APIkey: 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________aps_response_odds()
#   ____________leagueapi_id : 43
#   ____________teamapi_id : 1340
#   ______________Total API Response(s) : 1
#   __________________aps_delete()
#   ____________________teamapi_id : 1340
#   ______________________ delete  from football_player_squads  where teamapi_id = 1340
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19949,  'A. Chapman',  '33',  'None',  'Goalkeeper',  'https://media-2.api-sports.io/football/players/19949.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18000,  'R. Fitzsimons',  '29',  'None',  'Goalkeeper',  'https://media-1.api-sports.io/football/players/18000.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  82647,  'R. Barrows',  '26',  'None',  'Defender',  'https://media-2.api-sports.io/football/players/82647.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18225,  'A. Boyce',  '34',  'None',  'Defender',  'https://media-2.api-sports.io/football/players/18225.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19954,  'T. Denton',  '28',  'None',  'Defender',  'https://media-1.api-sports.io/football/players/19954.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18438,  'W. Evans',  '32',  'None',  'Defender',  'https://media-2.api-sports.io/football/players/18438.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20200,  'M. Kelly',  '26',  'None',  'Defender',  'https://media-2.api-sports.io/football/players/20200.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  69389,  'M. Kouogun',  '26',  'None',  'Defender',  'https://media-1.api-sports.io/football/players/69389.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  68129,  'R. Ogle',  '24',  'None',  'Defender',  'https://media-3.api-sports.io/football/players/68129.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  352780,  'E. Young',  '19',  'None',  'Defender',  'https://media-2.api-sports.io/football/players/352780.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19942,  'A. Beestin',  '26',  'None',  'Midfielder',  'https://media-2.api-sports.io/football/players/19942.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20496,  'J. Butterfield',  '33',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/20496.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  167166,  'M. Clunan',  '29',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/167166.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20465,  'T. Pugh',  '23',  'None',  'Midfielder',  'https://media-3.api-sports.io/football/players/20465.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18262,  'D. Rance',  '32',  'None',  'Midfielder',  'https://media-3.api-sports.io/football/players/18262.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  275564,  'K. Scales',  '21',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/275564.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  273318,  'F. Shrimpton',  '21',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/273318.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  325032,  'C. Wilson',  '21',  'None',  'Midfielder',  'https://media-3.api-sports.io/football/players/325032.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17930,  'D. Elliott',  '28',  'None',  'Attacker',  'https://media-1.api-sports.io/football/players/17930.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17473,  'J. Law',  '24',  'None',  'Attacker',  'https://media-1.api-sports.io/football/players/17473.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17585,  'C. Roberts',  '26',  'None',  'Attacker',  'https://media-3.api-sports.io/football/players/17585.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  82315,  'D. Sembie-Ferris',  '27',  'None',  'Attacker',  'https://media-1.api-sports.io/football/players/82315.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  382343,  'N. Wallace',  '19',  'None',  'Attacker',  'https://media-2.api-sports.io/football/players/382343.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  127121,  'D. Whitehall',  '28',  'None',  'Attacker',  'https://media-1.api-sports.io/football/players/127121.png',  current_timestamp )
#
#   ____________________football_teams UPDATED
#   ______[3/35]  #1341
#   ________aps_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api5@ariondigitalmedia.com counter is 36
#   ____________APIkey: 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________aps_response_odds()
#   ____________leagueapi_id : 43
#   ____________teamapi_id : 1341
#   ______________Total API Response(s) : 1
#   __________________aps_delete()
#   ____________________teamapi_id : 1341
#   ______________________ delete  from football_player_squads  where teamapi_id = 1341
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  334009,  'C. Andeng Ndi',  '20',  '30',  'Goalkeeper',  'https://media-2.api-sports.io/football/players/334009.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  155701,  'G. Scott-Morriss',  '26',  '2',  'Defender',  'https://media-1.api-sports.io/football/players/155701.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  45035,  'N. Ralph',  '30',  '3',  'Defender',  'https://media-2.api-sports.io/football/players/45035.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  153068,  'L. Lomas',  '23',  '4',  'Defender',  'https://media-2.api-sports.io/football/players/153068.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17564,  'O. Kensdale',  '23',  '6',  'Defender',  'https://media-1.api-sports.io/football/players/17564.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18388,  'H. Taylor',  '26',  '16',  'Defender',  'https://media-3.api-sports.io/football/players/18388.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20335,  'J. Demetriou',  '36',  '24',  'Defender',  'https://media-3.api-sports.io/football/players/20335.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17779,  'J. Bridge',  '28',  '7',  'Midfielder',  'https://media-2.api-sports.io/football/players/17779.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18018,  'Noor Husin',  '26',  '8',  'Midfielder',  'https://media-3.api-sports.io/football/players/18018.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  82768,  'C. Powell',  '27',  '11',  'Midfielder',  'https://media-2.api-sports.io/football/players/82768.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  378945,  'J. Wood',  '28',  '14',  'Midfielder',  'https://media-3.api-sports.io/football/players/378945.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18237,  'C. Miley',  '28',  '17',  'Midfielder',  'https://media-1.api-sports.io/football/players/18237.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18394,  'W. Fonguck',  '26',  '18',  'Midfielder',  'https://media-3.api-sports.io/football/players/18394.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  379044,  'J. Crowhurst',  '19',  '27',  'Midfielder',  'https://media-3.api-sports.io/football/players/379044.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  278109,  'O. Coker',  '20',  '28',  'Midfielder',  'https://media-1.api-sports.io/football/players/278109.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20096,  'D. Mooney',  '24',  '10',  'Attacker',  'https://media-1.api-sports.io/football/players/20096.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17848,  'H. Cardwell',  '27',  '23',  'Attacker',  'https://media-3.api-sports.io/football/players/17848.png',  current_timestamp )
#
#   ____________________football_teams UPDATED
#   ______[4/35]  #1345
#   ________aps_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api5@ariondigitalmedia.com counter is 35
#   ____________APIkey: 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________aps_response_odds()
#   ____________leagueapi_id : 43
#   ____________teamapi_id : 1345
#   ______________Total API Response(s) : 1
#   __________________aps_delete()
#   ____________________teamapi_id : 1345
#   ______________________ delete  from football_player_squads  where teamapi_id = 1345
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  138844,  'H. Tyrer',  '22',  '1',  'Goalkeeper',  'https://media-1.api-sports.io/football/players/138844.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  394276,  'L. Chadwick',  '19',  '36',  'Goalkeeper',  'https://media-3.api-sports.io/football/players/394276.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18090,  'R. Boot',  '29',  'None',  'Goalkeeper',  'https://media-3.api-sports.io/football/players/18090.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19928,  'B. Horton',  '23',  '3',  'Defender',  'https://media-2.api-sports.io/football/players/19928.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17975,  'J. Grimes',  '33',  '5',  'Defender',  'https://media-3.api-sports.io/football/players/17975.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18440,  'L. Maguire',  '26',  '6',  'Defender',  'https://media-1.api-sports.io/football/players/18440.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18096,  'T. Williams',  '29',  '12',  'Defender',  'https://media-1.api-sports.io/football/players/18096.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18556,  'R. Sheckleford',  '26',  '16',  'Defender',  'https://media-1.api-sports.io/football/players/18556.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  82568,  'A. Palmer',  '31',  '21',  'Defender',  'https://media-1.api-sports.io/football/players/82568.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  127204,  'B. Clements',  '23',  '33',  'Defender',  'https://media-1.api-sports.io/football/players/127204.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19870,  'T. Naylor',  '32',  '4',  'Midfielder',  'https://media-1.api-sports.io/football/players/19870.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19554,  'M. Jacobs',  '32',  '10',  'Midfielder',  'https://media-2.api-sports.io/football/players/19554.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  127203,  'A. Dobra',  '22',  '17',  'Midfielder',  'https://media-1.api-sports.io/football/players/127203.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  118532,  'J. King',  '28',  '20',  'Midfielder',  'https://media-3.api-sports.io/football/players/118532.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20149,  'D. Oldaker',  '24',  '26',  'Midfielder',  'https://media-2.api-sports.io/football/players/20149.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17514,  'O. Banks',  '31',  '28',  'Midfielder',  'https://media-3.api-sports.io/football/players/17514.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17665,  'M. Jones',  '36',  '35',  'Midfielder',  'https://media-2.api-sports.io/football/players/17665.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  190505,  'J. Berry-McNally',  '21',  'None',  'Midfielder',  'https://media-3.api-sports.io/football/players/190505.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  413130,  'H. Curtis',  '21',  'None',  'Midfielder',  'https://media-3.api-sports.io/football/players/413130.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  328125,  'B. Hobson',  '21',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/328125.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17881,  'L. Mandeville',  '26',  '7',  'Attacker',  'https://media-1.api-sports.io/football/players/17881.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18197,  'D. Rowe',  '34',  '8',  'Attacker',  'https://media-1.api-sports.io/football/players/18197.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19915,  'W. Grigg',  '32',  '9',  'Attacker',  'https://media-2.api-sports.io/football/players/19915.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20476,  'R. Colclough',  '29',  '11',  'Attacker',  'https://media-1.api-sports.io/football/players/20476.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  82145,  'A. Asante',  '31',  '19',  'Attacker',  'https://media-3.api-sports.io/football/players/82145.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18701,  'J. Quigley',  '27',  '27',  'Attacker',  'https://media-2.api-sports.io/football/players/18701.png',  current_timestamp )
#
#   ____________________football_teams UPDATED
#   ______[5/35]  #1349
#   ________aps_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api5@ariondigitalmedia.com counter is 34
#   ____________APIkey: 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________aps_response_odds()
#   ____________leagueapi_id : 43
#   ____________teamapi_id : 1349
#   ______________Total API Response(s) : 1
#   __________________aps_delete()
#   ____________________teamapi_id : 1349
#   ______________________ delete  from football_player_squads  where teamapi_id = 1349
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19013,  'M. Norman',  '26',  '1',  'Goalkeeper',  'https://media-3.api-sports.io/football/players/19013.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19432,  'M. Hudson',  '25',  '13',  'Goalkeeper',  'https://media-3.api-sports.io/football/players/19432.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18500,  'M. Kitching',  '28',  '3',  'Defender',  'https://media-2.api-sports.io/football/players/18500.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18117,  'L. Hogan',  '34',  '4',  'Defender',  'https://media-2.api-sports.io/football/players/18117.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18228,  'S. Hobson',  '25',  '5',  'Defender',  'https://media-1.api-sports.io/football/players/18228.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20078,  'N. Sheron',  '26',  '14',  'Defender',  'https://media-2.api-sports.io/football/players/20078.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17806,  'C. Raglan',  '30',  '16',  'Defender',  'https://media-1.api-sports.io/football/players/17806.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  280693,  'W. Sutton',  '21',  '21',  'Defender',  'https://media-3.api-sports.io/football/players/280693.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  331549,  'Benny Couto',  '20',  'None',  'Defender',  'https://media-3.api-sports.io/football/players/331549.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19094,  'K. Freeman',  '31',  'None',  'Defender',  'https://media-3.api-sports.io/football/players/19094.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20461,  'H. McGahey',  '28',  'None',  'Defender',  'https://media-1.api-sports.io/football/players/20461.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18131,  'M. Shelton',  '27',  '6',  'Midfielder',  'https://media-2.api-sports.io/football/players/18131.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  167147,  'D. Ward',  '26',  '11',  'Midfielder',  'https://media-2.api-sports.io/football/players/167147.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  68119,  'B. Tollitt',  '29',  '18',  'Midfielder',  'https://media-2.api-sports.io/football/players/68119.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17581,  'B. Dickenson',  '30',  '22',  'Midfielder',  'https://media-2.api-sports.io/football/players/17581.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  88450,  'J. Lundstram',  '24',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/88450.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18339,  'J. Rooney',  '33',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/18339.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  122095,  'K. Willoughby',  '26',  '7',  'Attacker',  'https://media-2.api-sports.io/football/players/122095.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18570,  'M. Fondop-Talum',  '30',  '9',  'Attacker',  'https://media-3.api-sports.io/football/players/18570.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19489,  'J. Nuttall',  '26',  '10',  'Attacker',  'https://media-1.api-sports.io/football/players/19489.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17759,  'D. Gardner',  '33',  '19',  'Attacker',  'https://media-1.api-sports.io/football/players/17759.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18196,  'A. Reid',  '28',  '25',  'Attacker',  'https://media-1.api-sports.io/football/players/18196.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17529,  'J. Norwood',  '33',  '30',  'Attacker',  'https://media-1.api-sports.io/football/players/17529.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  82598,  'D. Green',  '27',  'None',  'Attacker',  'https://media-2.api-sports.io/football/players/82598.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17674,  'H. Hope',  '29',  'None',  'Attacker',  'https://media-3.api-sports.io/football/players/17674.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  276991,  'J. Luamba',  '20',  'None',  'Attacker',  'https://media-2.api-sports.io/football/players/276991.png',  current_timestamp )
#
#   ____________________football_teams UPDATED
#   ______[6/35]  #1365
#   ________aps_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api5@ariondigitalmedia.com counter is 33
#   ____________APIkey: 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________aps_response_odds()
#   ____________leagueapi_id : 43
#   ____________teamapi_id : 1365
#   ______________Total API Response(s) : 1
#   __________________aps_delete()
#   ____________________teamapi_id : 1365
#   ______________________ delete  from football_player_squads  where teamapi_id = 1365
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  275573,  'H. Cartwright',  '21',  '1',  'Goalkeeper',  'https://media-3.api-sports.io/football/players/275573.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  82004,  'J. Eastwood',  '27',  '12',  'Goalkeeper',  'https://media-1.api-sports.io/football/players/82004.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  82373,  'M. Efete',  '26',  '2',  'Defender',  'https://media-3.api-sports.io/football/players/82373.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18913,  'A. Driscoll-Glennon',  '24',  '3',  'Defender',  'https://media-1.api-sports.io/football/players/18913.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20174,  'H. Rodgers',  '27',  '5',  'Defender',  'https://media-1.api-sports.io/football/players/20174.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20296,  'L. Waterfall',  '33',  '6',  'Defender',  'https://media-2.api-sports.io/football/players/20296.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18492,  'D. Amos',  '24',  '22',  'Defender',  'https://media-2.api-sports.io/football/players/18492.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18473,  'N. Maher',  '28',  '31',  'Defender',  'https://media-2.api-sports.io/football/players/18473.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  82223,  'K. Green',  '26',  '4',  'Midfielder',  'https://media-1.api-sports.io/football/players/82223.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18508,  'G. Holohan',  '32',  '8',  'Midfielder',  'https://media-1.api-sports.io/football/players/18508.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17844,  'C. Vernam',  '27',  '10',  'Midfielder',  'https://media-1.api-sports.io/football/players/17844.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17835,  'H. Clifton',  '25',  '15',  'Midfielder',  'https://media-2.api-sports.io/football/players/17835.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  119945,  'T. Mullarkey',  '28',  '28',  'Midfielder',  'https://media-2.api-sports.io/football/players/119945.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19389,  'A. Hunt',  '23',  '29',  'Midfielder',  'https://media-2.api-sports.io/football/players/19389.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  138884,  'E. Khouri',  '20',  '30',  'Midfielder',  'https://media-2.api-sports.io/football/players/138884.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  344876,  'A. Braithwaite',  '19',  '34',  'Midfielder',  'https://media-3.api-sports.io/football/players/344876.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  278119,  'H. Tomlinson',  '19',  '37',  'Midfielder',  'https://media-1.api-sports.io/football/players/278119.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  367682,  'J. Bramwell',  '19',  '38',  'Midfielder',  'https://media-3.api-sports.io/football/players/367682.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  350318,  'K. Conteh',  '21',  '42',  'Midfielder',  'https://media-3.api-sports.io/football/players/350318.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17572,  'Abobaker Eisa',  '27',  '7',  'Attacker',  'https://media-2.api-sports.io/football/players/17572.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20254,  'R. Pyke',  '26',  '9',  'Attacker',  'https://media-3.api-sports.io/football/players/20254.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17463,  'Otis Khan',  '28',  '11',  'Attacker',  'https://media-3.api-sports.io/football/players/17463.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17673,  'A. Gnahoua',  '31',  '14',  'Attacker',  'https://media-3.api-sports.io/football/players/17673.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17620,  'D. Wilson',  '26',  '25',  'Attacker',  'https://media-3.api-sports.io/football/players/17620.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17475,  'D. Rose',  '30',  '32',  'Attacker',  'https://media-3.api-sports.io/football/players/17475.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  332506,  'E. Essel',  '19',  '39',  'Attacker',  'https://media-1.api-sports.io/football/players/332506.png',  current_timestamp )
#
#   ____________________football_teams UPDATED
#   ______[7/35]  #1366
#   ________aps_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api5@ariondigitalmedia.com counter is 32
#   ____________APIkey: 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________aps_response_odds()
#   ____________leagueapi_id : 43
#   ____________teamapi_id : 1366
#   ______________Total API Response(s) : 1
#   __________________aps_delete()
#   ____________________teamapi_id : 1366
#   ______________________ delete  from football_player_squads  where teamapi_id = 1366
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18320,  'J. Dixon',  '30',  '1',  'Goalkeeper',  'https://media-1.api-sports.io/football/players/18320.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  119920,  'P. Jameson',  '30',  '13',  'Goalkeeper',  'https://media-3.api-sports.io/football/players/119920.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  231068,  'D. Dodds',  '22',  '2',  'Defender',  'https://media-2.api-sports.io/football/players/231068.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  114844,  'D. Ferguson',  '29',  '3',  'Defender',  'https://media-2.api-sports.io/football/players/114844.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20136,  'A. Lacey',  '30',  '5',  'Defender',  'https://media-2.api-sports.io/football/players/20136.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  346986,  'E. Pruti',  '21',  '15',  'Defender',  'https://media-2.api-sports.io/football/players/346986.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  375905,  'K. Burton',  'None',  '18',  'Defender',  'https://media-2.api-sports.io/football/players/375905.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  45096,  'C. Seaman',  '24',  '21',  'Defender',  'https://media-3.api-sports.io/football/players/45096.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18528,  'E. Onariase',  '27',  '23',  'Defender',  'https://media-1.api-sports.io/football/players/18528.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  138407,  'B. Paterson',  '22',  '24',  'Defender',  'https://media-2.api-sports.io/football/players/138407.png',  current_timestamp )
# ...
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  82910,  'E. Osborne',  '27',  '6',  'Midfielder',  'https://media-3.api-sports.io/football/players/82910.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  125140,  'I. Marriott',  '24',  '8',  'Midfielder',  'https://media-2.api-sports.io/football/players/125140.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  215132,  'C. Conn-Clarke',  '22',  '10',  'Midfielder',  'https://media-1.api-sports.io/football/players/215132.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19671,  'J. Southern-Cooper',  '22',  '15',  'Midfielder',  'https://media-2.api-sports.io/football/players/19671.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  309965,  'G. Wilson',  '22',  '19',  'Midfielder',  'https://media-1.api-sports.io/football/players/309965.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  426642,  'T. Jones',  'None',  '20',  'Midfielder',  'https://media-2.api-sports.io/football/players/426642.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18484,  'M. Kosylo',  '31',  '7',  'Attacker',  'https://media-2.api-sports.io/football/players/18484.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  155102,  'R. Linney',  '26',  '9',  'Attacker',  'https://media-3.api-sports.io/football/players/155102.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18728,  'J. Amaluzor',  '27',  '11',  'Attacker',  'https://media-3.api-sports.io/football/players/18728.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18342,  'D. Angus',  '29',  '14',  'Attacker',  'https://media-3.api-sports.io/football/players/18342.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  123562,  'J. Donawa',  '27',  '17',  'Attacker',  'https://media-2.api-sports.io/football/players/123562.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  426643,  'L. Williams',  'None',  '23',  'Attacker',  'https://media-2.api-sports.io/football/players/426643.png',  current_timestamp )
#
#   ____________________football_teams UPDATED
#   ______[32/35]  #8655
#   ________aps_controll_match_update()
#   __________aa_check_acccount()
#   ____________API api5@ariondigitalmedia.com counter is 7
#   ____________APIkey: 659647a05amsh6edd971d4edbc55p10ab33jsn691d349ab9da
#   __________aa_check_acccount()
#   __________aa_update_counter()
#   __________aps_response_odds()
#   ____________leagueapi_id : 43
#   ____________teamapi_id : 8655
#   ______________Total API Response(s) : 1
#   __________________aps_delete()
#   ____________________teamapi_id : 8655
#   ______________________ delete  from football_player_squads  where teamapi_id = 8655
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  135523,  'T. Dixon-Hodge',  '22',  'None',  'Goalkeeper',  'https://media-1.api-sports.io/football/players/135523.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20070,  'P. Jones',  '37',  'None',  'Goalkeeper',  'https://media-2.api-sports.io/football/players/20070.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  344877,  'R. Sandford',  '18',  'None',  'Goalkeeper',  'https://media-2.api-sports.io/football/players/344877.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  69365,  'K. Callan-McFadden',  '28',  'None',  'Defender',  'https://media-1.api-sports.io/football/players/69365.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20324,  'T. Clifford',  '24',  'None',  'Defender',  'https://media-3.api-sports.io/football/players/20324.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18066,  'J. Coulson',  '34',  'None',  'Defender',  'https://media-2.api-sports.io/football/players/18066.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  428622,  'B. Isaacson',  'None',  'None',  'Defender',  'https://media-3.api-sports.io/football/players/428622.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  18432,  'J. Smith',  '22',  'None',  'Defender',  'https://media-1.api-sports.io/football/players/18432.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  156842,  'A. Crowther',  '22',  'None',  'Midfielder',  'https://media-2.api-sports.io/football/players/156842.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  87796,  'C. Hargreaves',  '25',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/87796.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  428623,  'E. Oke',  'None',  'None',  'Midfielder',  'https://media-2.api-sports.io/football/players/428623.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  169201,  'K. Ronan',  '22',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/169201.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  428624,  'M. Delgado',  'None',  'None',  'Midfielder',  'https://media-3.api-sports.io/football/players/428624.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  145488,  'S. Spence',  '23',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/145488.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  17989,  'B. Stephens',  '26',  'None',  'Midfielder',  'https://media-1.api-sports.io/football/players/17989.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  428625,  'E. Wilson',  'None',  'None',  'Midfielder',  'https://media-2.api-sports.io/football/players/428625.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  19621,  'J. Barrett',  '25',  'None',  'Attacker',  'https://media-1.api-sports.io/football/players/19621.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  333210,  'Q. Bartley',  '20',  'None',  'Attacker',  'https://media-1.api-sports.io/football/players/333210.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  142133,  'Ismael Fatadjo',  '23',  'None',  'Attacker',  'https://media-1.api-sports.io/football/players/142133.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  154808,  'T. Hughes',  '23',  'None',  'Attacker',  'https://media-2.api-sports.io/football/players/154808.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  20011,  'J. Ponticelli',  '25',  'None',  'Attacker',  'https://media-2.api-sports.io/football/players/20011.png',  current_timestamp )
#   ____________________INSERT INTO `football_players`(  `playerapi_id`,  `name`,  `age`,  `number`,  `position`,  `photo`,  `created_at`  ) VALUES (  428626,  'C. Royle',  'None',  'None',  'Attacker',  'https://media-1.api-sports.io/football/players/428626.png',  current_timestamp )
#
#   ____________________football_teams UPDATED
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\ASUS\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:535, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     534         query = query.encode('utf-8')
# --> 535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near 's Lynn Town',  `logo` = 'https://media-1.api-sports.io/football/teams/8655.pn...' at line 1
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# c:\Users\ASUS\AryaDataAnalyst\pr_py_buzz_2023_07\player_squad\update player squad.ipynb Cell 1 in <cell line: 10>()
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/AryaDataAnalyst/pr_py_buzz_2023_07/player_squad/update%20player%20squad.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a> leagueapi_id    = input(space + "Enter your leagueapi id :  ")
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/AryaDataAnalyst/pr_py_buzz_2023_07/player_squad/update%20player%20squad.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a> # --------------------------------------------------
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/AryaDataAnalyst/pr_py_buzz_2023_07/player_squad/update%20player%20squad.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a> aps_group_by_all_team(leagueapi_id, space)
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/AryaDataAnalyst/pr_py_buzz_2023_07/player_squad/update%20player%20squad.ipynb#W0sZmlsZQ%3D%3D?line=21'>22</a> # --------------------------------------------------
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/AryaDataAnalyst/pr_py_buzz_2023_07/player_squad/update%20player%20squad.ipynb#W0sZmlsZQ%3D%3D?line=22'>23</a> its_end()
#
# File c:\Users\ASUS\AryaDataAnalyst\pr_py_buzz_2023_07\player_squad\..\a_models\api_player_squad.py:60, in aps_group_by_all_team(leagueapi_id, space)
#      55 # ------------------------------------------------------
#      56 DICT = {
#      57     'teamapi_id' :teamapi_id,
#      58     'leagueapi_id' :leagueapi_id,
#      59 }
# ---> 60 aps_controll_match_update(DICT, 'Null', space)
#
# File c:\Users\ASUS\AryaDataAnalyst\pr_py_buzz_2023_07\player_squad\..\a_models\api_player_squad.py:82, in aps_controll_match_update(DICT, PREP_, space)
#      79 elif(counterAPI > 0):
#      80     # ------------------------------------------------------
#      81     aa_update_counter(space)
# ---> 82     aps_response_odds(APIkey, DICT, PREP_, space)
#
# File c:\Users\ASUS\AryaDataAnalyst\pr_py_buzz_2023_07\player_squad\..\a_models\api_player_squad.py:201, in aps_response_odds(APIkey, DICT, PREP_, space)
#     198         print()  # Separate each team's data
#     199         # --------------------------------------------------
#     200     # ------------------------------------------------------
# --> 201     fT_insert_new(teamapi_id, team_name, team_logo, space)
#     202     # ------------------------------------------------------
#     203 # ----------------------------------------------------------
#     204 elif(total_API_response == 0):
#     205     # ------------------------------------------------------
#
# File c:\Users\ASUS\AryaDataAnalyst\pr_py_buzz_2023_07\player_squad\..\a_models\football_teams.py:78, in fT_insert_new(teamapi_id, name, logo, space)
#      76     print(space + "football_teams UPDATED", flush=True)
#      77     # ------------------------------------------------------
# ---> 78     mycursor.execute(query_commit)
#      79     mydb.commit()
#      80 # ----------------------------------------------------------
#      81 # ----------------------------------------------------------
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py:269, in CMySQLCursor.execute(self, operation, params, multi)
#     265             raise errors.ProgrammingError(
#     266                 "Not all parameters were used in the SQL statement")
#     268 try:
# --> 269     result = self._cnx.cmd_query(stmt, raw=self._raw,
#     270                                  buffered=self._buffered,
#     271                                  raw_as_string=self._raw_as_string)
#     272 except MySQLInterfaceError as exc:
#     273     raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#     274                                      sqlstate=exc.sqlstate)
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:540, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
# --> 540     raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     541                                      sqlstate=exc.sqlstate)
#     542 except AttributeError:
#     543     if self._unix_socket:
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near 's Lynn Town',  `logo` = 'https://media-1.api-sports.io/football/teams/8655.pn...' at line 1
