# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/fixtures"

querystring = {"id":"157201"}

headers = {
	"X-RapidAPI-Key": "dce4a91806mshf5d2a504cca3665p180723jsn32fcc52b5ea4",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
print(response.json())
# Out:
# {'get': 'fixtures', 'parameters': {'id': '157201'}, 'errors': [], 'results': 1, 'paging': {'current': 1, 'total': 1}, 'response': [{'fixture': {'id': 157201, 'referee': 'Kevin Friend, England', 'timezone': 'UTC', 'date': '2019-12-26T17:30:00+00:00', 'timestamp': 1577381400, 'periods': {'first': 1577381400, 'second': 1577385000}, 'venue': {'id': 556, 'name': 'Old Trafford', 'city': 'Manchester'}, 'status': {'long': 'Match Finished', 'short': 'FT', 'elapsed': 90}}, 'league': {'id': 39, 'name': 'Premier League', 'country': 'England', 'logo': 'https://media-1.api-sports.io/football/leagues/39.png', 'flag': 'https://media-3.api-sports.io/flags/gb.svg', 'season': 2019, 'round': 'Regular Season - 19'}, 'teams': {'home': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-3.api-sports.io/football/teams/33.png', 'winner': True}, 'away': {'id': 34, 'name': 'Newcastle', 'logo': 'https://media-1.api-sports.io/football/teams/34.png', 'winner': False}}, 'goals': {'home': 4, 'away': 1}, 'score': {'halftime': {'home': 3, 'away': 1}, 'fulltime': {'home': 4, 'away': 1}, 'extratime': {'home': None, 'away': None}, 'penalty': {'home': None, 'away': None}}, 'events': [{'time': {'elapsed': 1, 'extra': None}, 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-3.api-sports.io/football/teams/33.png'}, 'player': {'id': 903, 'name': 'Scott McTominay'}, 'assist': {'id': None, 'name': None}, 'type': 'Card', 'detail': 'Yellow Card', 'comments': None}, {'time': {'elapsed': 17, 'extra': None}, 'team': {'id': 34, 'name': 'Newcastle', 'logo': 'https://media-1.api-sports.io/football/teams/34.png'}, 'player': {'id': 130419, 'name': 'M. Longstaff'}, 'assist': {'id': 723, 'name': 'Joelinton'}, 'type': 'Goal', 'detail': 'Normal Goal', 'comments': None}, {'time': {'elapsed': 24, 'extra': None}, 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-3.api-sports.io/football/teams/33.png'}, 'player': {'id': 908, 'name': 'A. Martial'}, 'assist': {'id': 899, 'name': 'Andreas Pereira'}, 'type': 'Goal', 'detail': 'Normal Goal', 'comments': None}, {'time': {'elapsed': 35, 'extra': None}, 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-3.api-sports.io/football/teams/33.png'}, 'player': {'id': 899, 'name': 'Andreas Pereira'}, 'assist': {'id': None, 'name': None}, 'type': 'Card', 'detail': 'Yellow Card', 'comments': None}, {'time': {'elapsed': 36, 'extra': None}, 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-3.api-sports.io/football/teams/33.png'}, 'player': {'id': 897, 'name': 'M. Greenwood'}, 'assist': {'id': None, 'name': None}, 'type': 'Goal', 'detail': 'Normal Goal', 'comments': None}, {'time': {'elapsed': 38, 'extra': None}, 'team': {'id': 34, 'name': 'Newcastle', 'logo': 'https://media-3.api-sports.io/football/teams/34.png'}, 'player': {'id': 2806, 'name': 'Fabian Schär'}, 'assist': {'id': None, 'name': None}, 'type': 'Card', 'detail': 'Yellow Card', 'comments': None}, {'time': {'elapsed': 41, 'extra': None}, 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-3.api-sports.io/football/teams/33.png'}, 'player': {'id': 909, 'name': 'M. Rashford'}, 'assist': {'id': 18846, 'name': 'A. Wan-Bissaka'}, 'type': 'Goal', 'detail': 'Normal Goal', 'comments': None}, {'time': {'elapsed': 46, 'extra': None}, 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-1.api-sports.io/football/teams/33.png'}, 'player': {'id': 903, 'name': 'S. McTominay'}, 'assist': {'id': 904, 'name': 'P. Pogba'}, 'type': 'subst', 'detail': 'Substitution 1', 'comments': None}, {'time': {'elapsed': 51, 'extra': None}, 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-2.api-sports.io/football/teams/33.png'}, 'player': {'id': 908, 'name': 'A. Martial'}, 'assist': {'id': None, 'name': None}, 'type': 'Goal', 'detail': 'Normal Goal', 'comments': None}, {'time': {'elapsed': 59, 'extra': None}, 'team': {'id': 34, 'name': 'Newcastle', 'logo': 'https://media-2.api-spor ...

# %%
import json 
data = json.loads(response.text)

# %%
import json
import requests

# Assuming you have the API endpoint and headers defined before 
data = json.loads(response.text)
space = ""
for row in data['response']:
    fixtureapi_id = str(row['fixture']['id'])
    print("Fixture ID:", fixtureapi_id)  

    for rwpl in row['players']:
        # ----------------------------------------------  
        team_id = rwpl['team']['id'] 
        # ----------------------------------------------  
        print(rwpl['players'])
        # ----------------------------------------------   
        for rwplrs in rwpl['players']: 
            # ----------------------------------- player   
            playerapi_id = str(rwplrs['player']['id']) 
            # ---------------------------------------  
            print(space + "playerapi_id: " + playerapi_id, flush=True) 
            # ---------------------------------------  
            for rwplrsst in rwplrs['statistics']: 
                # ---------------------------- statistics   
                games_minutes = str(rwplrsst['games']['minutes']) 
                print(space + "__" + "games_minutes: " + games_minutes, flush=True)
                # ---------------------------------------
                games_number = str(rwplrsst['games']['number']) 
                print(space + "__" + "games_number: " + games_number, flush=True)
                # ---------------------------------------
                games_position = str(rwplrsst['games']['position']) 
                print(space + "__" + "games_position: " + games_position, flush=True)
                # ---------------------------------------
                games_rating = str(rwplrsst['games']['rating']) 
                print(space + "__" + "games_rating: " + games_rating, flush=True)
                # ---------------------------------------
                games_captain = str(rwplrsst['games']['captain']) 
                print(space + "__" + "games_captain: " + games_captain, flush=True)
                # ---------------------------------------
                games_substitute = str(rwplrsst['games']['substitute']) 
                print(space + "__" + "games_substitute: " + games_substitute, flush=True)
                # ---------------------------------------
                offsides = str(rwplrsst['offsides']) 
                print(space + "__" + "offsides: " + offsides, flush=True)
                # ---------------------------------------
                shots_total = str(rwplrsst['shots']['total']) 
                print(space + "__" + "shots_total: " + shots_total, flush=True)
                # ---------------------------------------
                shots_on = str(rwplrsst['shots']['on']) 
                print(space + "__" + "shots_on: " + shots_on, flush=True)
                # ---------------------------------------
                goals_total = str(rwplrsst['goals']['total']) 
                print(space + "__" + "goals_total: " + goals_total, flush=True)
                # ---------------------------------------
                goals_conceded = str(rwplrsst['goals']['conceded']) 
                print(space + "__" + "goals_conceded: " + goals_conceded, flush=True)
                # ---------------------------------------
                goals_assists = str(rwplrsst['goals']['assists']) 
                print(space + "__" + "goals_assists: " + goals_assists, flush=True)
                # ---------------------------------------
                goals_saves = str(rwplrsst['goals']['saves']) 
                print(space + "__" + "goals_saves: " + goals_saves, flush=True)
                # ---------------------------------------
                passes_total = str(rwplrsst['passes']['total']) 
                print(space + "__" + "passes_total: " + passes_total, flush=True)
                # ---------------------------------------
                passes_key = str(rwplrsst['passes']['key']) 
                print(space + "__" + "passes_key: " + passes_key, flush=True)
                # ---------------------------------------
                passes_accuracy = str(rwplrsst['passes']['accuracy']) 
                print(space + "__" + "passes_accuracy: " + passes_accuracy, flush=True)
                # ---------------------------------------
                tackles_total = str(rwplrsst['tackles']['total']) 
                print(space + "__" + "tackles_total: " + tackles_total, flush=True)
                # ---------------------------------------
                tackles_blocks = str(rwplrsst['tackles']['blocks']) 
                print(space + "__" + "tackles_blocks: " + tackles_blocks, flush=True)
                # ---------------------------------------
                tackles_interceptions = str(rwplrsst['tackles']['interceptions']) 
                print(space + "__" + "tackles_interceptions: " + tackles_interceptions, flush=True)
                # ---------------------------------------
                duels_total = str(rwplrsst['duels']['total']) 
                print(space + "__" + "duels_total: " + duels_total, flush=True)
                # ---------------------------------------
                duels_won = str(rwplrsst['duels']['won']) 
                print(space + "__" + "duels_won: " + duels_won, flush=True)
                # ---------------------------------------
                dribbles_attempts = str(rwplrsst['dribbles']['attempts']) 
                print(space + "__" + "dribbles_attempts: " + dribbles_attempts, flush=True)
                # ---------------------------------------
                dribbles_success = str(rwplrsst['dribbles']['success']) 
                print(space + "__" + "dribbles_success: " + dribbles_success, flush=True)
                # ---------------------------------------
                dribbles_past = str(rwplrsst['dribbles']['past']) 
                print(space + "__" + "dribbles_past: " + dribbles_past, flush=True)
                # ---------------------------------------
                fouls_drawn = str(rwplrsst['fouls']['drawn']) 
                print(space + "__" + "fouls_drawn: " + fouls_drawn, flush=True)
                # ---------------------------------------
                fouls_committed = str(rwplrsst['fouls']['committed']) 
                print(space + "__" + "fouls_committed: " + fouls_committed, flush=True)
                # ---------------------------------------
                cards_yellow = str(rwplrsst['cards']['yellow']) 
                print(space + "__" + "cards_yellow: " + cards_yellow, flush=True)
                # ---------------------------------------
                cards_red = str(rwplrsst['cards']['red']) 
                print(space + "__" + "cards_red: " + cards_red, flush=True)
                # ---------------------------------------
                penalty_won = str(rwplrsst['penalty']['won']) 
                print(space + "__" + "penalty_won: " + penalty_won, flush=True)
                # ---------------------------------------
                penalty_committed = str(rwplrsst['penalty']['commited']) 
                print(space + "__" + "penalty_committed: " + penalty_committed, flush=True)
                # ---------------------------------------
                penalty_scored = str(rwplrsst['penalty']['scored']) 
                print(space + "__" + "penalty_scored: " + penalty_scored, flush=True)
                # ---------------------------------------
                penalty_missed = str(rwplrsst['penalty']['missed']) 
                print(space + "__" + "penalty_missed: " + penalty_missed, flush=True)
                # ---------------------------------------
                penalty_saved = str(rwplrsst['penalty']['saved']) 
                print(space + "__" + "penalty_saved: " + penalty_saved, flush=True)
                # ---------------------------------------
            # ------------------------------------------- 
            print("")
# -------------------------------------------------------
# Out:
# Fixture ID: 157201
# [{'player': {'id': 882, 'name': 'David De Gea', 'photo': 'https://media-3.api-sports.io/football/players/882.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 1, 'position': 'G', 'rating': '6.4', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 0, 'on': 0}, 'goals': {'total': None, 'conceded': 1, 'assists': None, 'saves': 1}, 'passes': {'total': 20, 'key': 0, 'accuracy': '100%'}, 'tackles': {'total': None, 'blocks': 0, 'interceptions': 0}, 'duels': {'total': 0, 'won': 0}, 'dribbles': {'attempts': 0, 'success': 0, 'past': None}, 'fouls': {'drawn': 0, 'committed': 0}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': 0}}]}, {'player': {'id': 18846, 'name': 'Aaron Wan-Bissaka', 'photo': 'https://media-1.api-sports.io/football/players/18846.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 29, 'position': 'D', 'rating': '7.6', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 0, 'on': 0}, 'goals': {'total': None, 'conceded': 0, 'assists': 1, 'saves': None}, 'passes': {'total': 83, 'key': 1, 'accuracy': '88%'}, 'tackles': {'total': 3, 'blocks': 0, 'interceptions': 3}, 'duels': {'total': 7, 'won': 5}, 'dribbles': {'attempts': 1, 'success': 1, 'past': None}, 'fouls': {'drawn': 1, 'committed': 0}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 889, 'name': 'Victor Lindelöf', 'photo': 'https://media-1.api-sports.io/football/players/889.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 2, 'position': 'D', 'rating': '6.7', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 1, 'on': 0}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 76, 'key': 0, 'accuracy': '89%'}, 'tackles': {'total': None, 'blocks': 0, 'interceptions': 1}, 'duels': {'total': 5, 'won': 3}, 'dribbles': {'attempts': 0, 'success': 0, 'past': None}, 'fouls': {'drawn': 0, 'committed': 0}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 2935, 'name': 'Harry Maguire', 'photo': 'https://media-3.api-sports.io/football/players/2935.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 5, 'position': 'D', 'rating': '7.7', 'captain': True, 'substitute': False}, 'offsides': None, 'shots': {'total': 2, 'on': 1}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 87, 'key': 0, 'accuracy': '88%'}, 'tackles': {'total': 4, 'blocks': 0, 'interceptions': 2}, 'duels': {'total': 14, 'won': 12}, 'dribbles': {'attempts': 1, 'success': 1, 'past': None}, 'fouls': {'drawn': 1, 'committed': 0}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 891, 'name': 'Luke Shaw', 'photo': 'https://media-1.api-sports.io/football/players/891.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 23, 'position': 'D', 'rating': '6.9', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 2, 'on': 1}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 90, 'key': 0, 'accuracy': '93%'}, 'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0}, 'duels': {'total': 6, 'won': 3}, 'dribbles': {'attempts': 3, 'success': 2, 'past': None}, 'fouls': {'drawn': 0, 'committed': 0}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 903, 'name': 'Scott McTominay', 'photo': 'https://media-3.api-sports.io/football/players/903.png'}, 'statistics': [{'games': {'minutes': 45, 'number': 39, 'position': 'M', 'rating': '6.6', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 0, 'on': 0}, 'goals': {'total': None, 'conceded': 0, 'ass ...
# playerapi_id: 882
# __games_minutes: 90
# __games_number: 1
# __games_position: G
# __games_rating: 6.4
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 1
# __goals_assists: None
# __goals_saves: 1
# __passes_total: 20
# __passes_key: 0
# __passes_accuracy: 100%
# __tackles_total: None
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 0
# __duels_won: 0
# __dribbles_attempts: 0
# __dribbles_success: 0
# __dribbles_past: None
# __fouls_drawn: 0
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: 0
#
# playerapi_id: 18846
# __games_minutes: 90
# __games_number: 29
# __games_position: D
# __games_rating: 7.6
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: 1
# __goals_saves: None
# __passes_total: 83
# __passes_key: 1
# __passes_accuracy: 88%
# __tackles_total: 3
# __tackles_blocks: 0
# __tackles_interceptions: 3
# __duels_total: 7
# __duels_won: 5
# __dribbles_attempts: 1
# __dribbles_success: 1
# __dribbles_past: None
# __fouls_drawn: 1
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 889
# __games_minutes: 90
# __games_number: 2
# __games_position: D
# __games_rating: 6.7
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 1
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 76
# __passes_key: 0
# __passes_accuracy: 89%
# __tackles_total: None
# __tackles_blocks: 0
# __tackles_interceptions: 1
# __duels_total: 5
# __duels_won: 3
# __dribbles_attempts: 0
# __dribbles_success: 0
# __dribbles_past: None
# __fouls_drawn: 0
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 2935
# __games_minutes: 90
# __games_number: 5
# __games_position: D
# __games_rating: 7.7
# __games_captain: True
# __games_substitute: False
# __offsides: None
# __shots_total: 2
# __shots_on: 1
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 87
# __passes_key: 0
# __passes_accuracy: 88%
# __tackles_total: 4
# __tackles_blocks: 0
# __tackles_interceptions: 2
# __duels_total: 14
# __duels_won: 12
# __dribbles_attempts: 1
# __dribbles_success: 1
# __dribbles_past: None
# __fouls_drawn: 1
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 891
# __games_minutes: 90
# __games_number: 23
# __games_position: D
# __games_rating: 6.9
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 2
# __shots_on: 1
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 90
# __passes_key: 0
# __passes_accuracy: 93%
# __tackles_total: 1
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 6
# __duels_won: 3
# __dribbles_attempts: 3
# __dribbles_success: 2
# __dribbles_past: None
# __fouls_drawn: 0
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 903
# __games_minutes: 45
# __games_number: 39
# __games_position: M
# __games_rating: 6.6
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 24
# __passes_key: 2
# __passes_accuracy: 77%
# __tackles_total: 2
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 9
# __duels_won: 4
# __dribbles_attempts: 1
# __dribbles_success: 0
# __dribbles_past: None
# __fouls_drawn: 0
# __fouls_committed: 2
# __cards_yellow: 1
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 905
# __games_minutes: 90
# __games_number: 17
# __games_position: M
# __games_rating: 7.0
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 2
# __shots_on: 1
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 115
# __passes_key: 3
# __passes_accuracy: 92%
# __tackles_total: None
# __tackles_blocks: 0
# __tackles_interceptions: 1
# __duels_total: 8
# __duels_won: 0
# __dribbles_attempts: 1
# __dribbles_success: 0
# __dribbles_past: 4
# __fouls_drawn: 0
# __fouls_committed: 3
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 897
# __games_minutes: 90
# __games_number: 26
# __games_position: M
# __games_rating: 7.5
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 2
# __shots_on: 1
# __goals_total: 1
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 32
# __passes_key: 2
# __passes_accuracy: 84%
# __tackles_total: 2
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 11
# __duels_won: 5
# __dribbles_attempts: 4
# __dribbles_success: 3
# __dribbles_past: 2
# __fouls_drawn: 0
# __fouls_committed: 1
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 899
# __games_minutes: 90
# __games_number: 15
# __games_position: M
# __games_rating: 6.9
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 3
# __shots_on: 1
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: 1
# __goals_saves: None
# __passes_total: 44
# __passes_key: 2
# __passes_accuracy: 95%
# __tackles_total: None
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 11
# __duels_won: 3
# __dribbles_attempts: 1
# __dribbles_success: 1
# __dribbles_past: 1
# __fouls_drawn: 2
# __fouls_committed: 1
# __cards_yellow: 1
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 909
# __games_minutes: 63
# __games_number: 10
# __games_position: M
# __games_rating: 6.7
# __games_captain: False
# __games_substitute: False
# __offsides: 1
# __shots_total: 4
# __shots_on: 1
# __goals_total: 1
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 30
# __passes_key: 0
# __passes_accuracy: 85%
# __tackles_total: None
# __tackles_blocks: 0
# __tackles_interceptions: 1
# __duels_total: 8
# __duels_won: 2
# __dribbles_attempts: 3
# __dribbles_success: 0
# __dribbles_past: 1
# __fouls_drawn: 1
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 908
# __games_minutes: 67
# __games_number: 9
# __games_position: F
# __games_rating: 8.5
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 3
# __shots_on: 2
# __goals_total: 2
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 15
# __passes_key: 1
# __passes_accuracy: 71%
# __tackles_total: 1
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 8
# __duels_won: 3
# __dribbles_attempts: 3
# __dribbles_success: 2
# __dribbles_past: None
# __fouls_drawn: 0
# __fouls_committed: 1
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 901
# __games_minutes: 23
# __games_number: 8
# __games_position: M
# __games_rating: 7.1
# __games_captain: False
# __games_substitute: True
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 30
# __passes_key: 1
# __passes_accuracy: 90%
# __tackles_total: None
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 2
# __duels_won: 1
# __dribbles_attempts: 1
# __dribbles_success: 1
# __dribbles_past: None
# __fouls_drawn: 0
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 904
# __games_minutes: 45
# __games_number: 6
# __games_position: M
# __games_rating: 7.2
# __games_captain: False
# __games_substitute: True
# __offsides: None
# __shots_total: 3
# __shots_on: 2
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 61
# __passes_key: 2
# __passes_accuracy: 91%
# __tackles_total: 3
# __tackles_blocks: 0
# __tackles_interceptions: 2
# __duels_total: 9
# __duels_won: 5
# __dribbles_attempts: 1
# __dribbles_success: 1
# __dribbles_past: 2
# __fouls_drawn: 0
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 900
# __games_minutes: 27
# __games_number: 14
# __games_position: M
# __games_rating: 6.8
# __games_captain: False
# __games_substitute: True
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 25
# __passes_key: 1
# __passes_accuracy: 92%
# __tackles_total: 1
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 7
# __duels_won: 3
# __dribbles_attempts: 2
# __dribbles_success: 1
# __dribbles_past: None
# __fouls_drawn: 1
# __fouls_committed: 2
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# [{'player': {'id': 18886, 'name': 'Martin Dúbravka', 'photo': 'https://media-2.api-sports.io/football/players/18886.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 1, 'position': 'G', 'rating': '6.1', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 0, 'on': 0}, 'goals': {'total': None, 'conceded': 4, 'assists': None, 'saves': 6}, 'passes': {'total': 15, 'key': 0, 'accuracy': '50%'}, 'tackles': {'total': None, 'blocks': 0, 'interceptions': 0}, 'duels': {'total': 0, 'won': 0}, 'dribbles': {'attempts': 0, 'success': 0, 'past': None}, 'fouls': {'drawn': 0, 'committed': 0}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': 0}}]}, {'player': {'id': 2806, 'name': 'Fabian Schär', 'photo': 'https://media-1.api-sports.io/football/players/2806.png'}, 'statistics': [{'games': {'minutes': 88, 'number': 5, 'position': 'D', 'rating': '6.1', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 1, 'on': 0}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 19, 'key': 0, 'accuracy': '70%'}, 'tackles': {'total': 2, 'blocks': 1, 'interceptions': 3}, 'duels': {'total': 6, 'won': 4}, 'dribbles': {'attempts': 0, 'success': 0, 'past': None}, 'fouls': {'drawn': 2, 'committed': 1}, 'cards': {'yellow': 1, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 18893, 'name': 'Federico Fernández', 'photo': 'https://media-3.api-sports.io/football/players/18893.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 18, 'position': 'D', 'rating': '6.3', 'captain': True, 'substitute': False}, 'offsides': None, 'shots': {'total': 1, 'on': 0}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 10, 'key': 0, 'accuracy': '66%'}, 'tackles': {'total': 1, 'blocks': 1, 'interceptions': 0}, 'duels': {'total': 5, 'won': 3}, 'dribbles': {'attempts': 1, 'success': 1, 'past': 1}, 'fouls': {'drawn': 0, 'committed': 1}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 18895, 'name': 'Florian Lejeune', 'photo': 'https://media-3.api-sports.io/football/players/18895.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 20, 'position': 'D', 'rating': '6.2', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 0, 'on': 0}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 33, 'key': 0, 'accuracy': '80%'}, 'tackles': {'total': 2, 'blocks': 0, 'interceptions': 3}, 'duels': {'total': 6, 'won': 4}, 'dribbles': {'attempts': 1, 'success': 1, 'past': 2}, 'fouls': {'drawn': 1, 'committed': 0}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 18896, 'name': 'Javier Manquillo', 'photo': 'https://media-2.api-sports.io/football/players/18896.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 19, 'position': 'M', 'rating': '6.5', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 0, 'on': 0}, 'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 15, 'key': 0, 'accuracy': '75%'}, 'tackles': {'total': 2, 'blocks': 1, 'interceptions': 0}, 'duels': {'total': 8, 'won': 5}, 'dribbles': {'attempts': 2, 'success': 1, 'past': 1}, 'fouls': {'drawn': 0, 'committed': 1}, 'cards': {'yellow': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 0, 'missed': 0, 'saved': None}}]}, {'player': {'id': 130419, 'name': 'Matthew Longstaff', 'photo': 'https://media-3.api-sports.io/football/players/130419.png'}, 'statistics': [{'games': {'minutes': 90, 'number': 43, 'position': 'M', 'rating': '6.9', 'captain': False, 'substitute': False}, 'offsides': None, 'shots': {'total': 1, 'on': 1}, 'goals': {'total': 1, 'co ...
# playerapi_id: 18886
# __games_minutes: 90
# __games_number: 1
# __games_position: G
# __games_rating: 6.1
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 4
# __goals_assists: None
# __goals_saves: 6
# __passes_total: 15
# __passes_key: 0
# __passes_accuracy: 50%
# __tackles_total: None
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 0
# __duels_won: 0
# __dribbles_attempts: 0
# __dribbles_success: 0
# __dribbles_past: None
# __fouls_drawn: 0
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: 0
#
# playerapi_id: 2806
# __games_minutes: 88
# __games_number: 5
# __games_position: D
# __games_rating: 6.1
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 1
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 19
# __passes_key: 0
# __passes_accuracy: 70%
# __tackles_total: 2
# __tackles_blocks: 1
# __tackles_interceptions: 3
# __duels_total: 6
# __duels_won: 4
# __dribbles_attempts: 0
# __dribbles_success: 0
# __dribbles_past: None
# __fouls_drawn: 2
# __fouls_committed: 1
# __cards_yellow: 1
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 18893
# __games_minutes: 90
# __games_number: 18
# __games_position: D
# __games_rating: 6.3
# __games_captain: True
# __games_substitute: False
# __offsides: None
# __shots_total: 1
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 10
# __passes_key: 0
# __passes_accuracy: 66%
# __tackles_total: 1
# __tackles_blocks: 1
# __tackles_interceptions: 0
# __duels_total: 5
# __duels_won: 3
# __dribbles_attempts: 1
# __dribbles_success: 1
# __dribbles_past: 1
# __fouls_drawn: 0
# __fouls_committed: 1
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 18895
# __games_minutes: 90
# __games_number: 20
# __games_position: D
# __games_rating: 6.2
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 33
# __passes_key: 0
# __passes_accuracy: 80%
# __tackles_total: 2
# __tackles_blocks: 0
# __tackles_interceptions: 3
# __duels_total: 6
# __duels_won: 4
# __dribbles_attempts: 1
# __dribbles_success: 1
# __dribbles_past: 2
# __fouls_drawn: 1
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 18896
# __games_minutes: 90
# __games_number: 19
# __games_position: M
# __games_rating: 6.5
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 15
# __passes_key: 0
# __passes_accuracy: 75%
# __tackles_total: 2
# __tackles_blocks: 1
# __tackles_interceptions: 0
# __duels_total: 8
# __duels_won: 5
# __dribbles_attempts: 2
# __dribbles_success: 1
# __dribbles_past: 1
# __fouls_drawn: 0
# __fouls_committed: 1
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 130419
# __games_minutes: 90
# __games_number: 43
# __games_position: M
# __games_rating: 6.9
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 1
# __shots_on: 1
# __goals_total: 1
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 22
# __passes_key: 1
# __passes_accuracy: 71%
# __tackles_total: 2
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 5
# __duels_won: 3
# __dribbles_attempts: 0
# __dribbles_success: 0
# __dribbles_past: 1
# __fouls_drawn: 1
# __fouls_committed: 1
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 18901
# __games_minutes: 90
# __games_number: 36
# __games_position: M
# __games_rating: 6.3
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 1
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 23
# __passes_key: 1
# __passes_accuracy: 74%
# __tackles_total: 4
# __tackles_blocks: 0
# __tackles_interceptions: 1
# __duels_total: 12
# __duels_won: 9
# __dribbles_attempts: 1
# __dribbles_success: 1
# __dribbles_past: 3
# __fouls_drawn: 2
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 2507
# __games_minutes: 63
# __games_number: 24
# __games_position: M
# __games_rating: 6.8
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 1
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 6
# __passes_key: 1
# __passes_accuracy: 50%
# __tackles_total: 4
# __tackles_blocks: 0
# __tackles_interceptions: 2
# __duels_total: 10
# __duels_won: 7
# __dribbles_attempts: 2
# __dribbles_success: 1
# __dribbles_past: None
# __fouls_drawn: 2
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 1813
# __games_minutes: 90
# __games_number: 15
# __games_position: M
# __games_rating: 5.9
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 22
# __passes_key: 0
# __passes_accuracy: 75%
# __tackles_total: None
# __tackles_blocks: 1
# __tackles_interceptions: 1
# __duels_total: 10
# __duels_won: 3
# __dribbles_attempts: 3
# __dribbles_success: 1
# __dribbles_past: 3
# __fouls_drawn: 0
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 723
# __games_minutes: 90
# __games_number: 9
# __games_position: F
# __games_rating: 7.6
# __games_captain: False
# __games_substitute: False
# __offsides: 1
# __shots_total: 1
# __shots_on: 1
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: 1
# __goals_saves: None
# __passes_total: 27
# __passes_key: 3
# __passes_accuracy: 77%
# __tackles_total: None
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 28
# __duels_won: 11
# __dribbles_attempts: 5
# __dribbles_success: 3
# __dribbles_past: None
# __fouls_drawn: 0
# __fouls_committed: 2
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 19166
# __games_minutes: 59
# __games_number: 12
# __games_position: F
# __games_rating: 6.2
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 1
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 12
# __passes_key: 0
# __passes_accuracy: 80%
# __tackles_total: 1
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 5
# __duels_won: 2
# __dribbles_attempts: 0
# __dribbles_success: 0
# __dribbles_past: None
# __fouls_drawn: 0
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 18897
# __games_minutes: 27
# __games_number: 22
# __games_position: D
# __games_rating: 6.4
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 4
# __passes_key: 0
# __passes_accuracy: 100%
# __tackles_total: None
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 2
# __duels_won: 1
# __dribbles_attempts: 0
# __dribbles_success: 0
# __dribbles_past: 1
# __fouls_drawn: 1
# __fouls_committed: 0
# __cards_yellow: 1
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 2855
# __games_minutes: 2
# __games_number: 17
# __games_position: D
# __games_rating: –
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 1
# __passes_key: 0
# __passes_accuracy: 100%
# __tackles_total: 1
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 2
# __duels_won: 2
# __dribbles_attempts: 0
# __dribbles_success: 0
# __dribbles_past: None
# __fouls_drawn: 0
# __fouls_committed: 0
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
#
# playerapi_id: 3423
# __games_minutes: 31
# __games_number: 30
# __games_position: M
# __games_rating: 6.4
# __games_captain: False
# __games_substitute: False
# __offsides: None
# __shots_total: 0
# __shots_on: 0
# __goals_total: None
# __goals_conceded: 0
# __goals_assists: None
# __goals_saves: None
# __passes_total: 4
# __passes_key: 1
# __passes_accuracy: 100%
# __tackles_total: 1
# __tackles_blocks: 0
# __tackles_interceptions: 0
# __duels_total: 6
# __duels_won: 2
# __dribbles_attempts: 2
# __dribbles_success: 1
# __dribbles_past: 1
# __fouls_drawn: 0
# __fouls_committed: 1
# __cards_yellow: 0
# __cards_red: 0
# __penalty_won: None
# __penalty_committed: None
# __penalty_scored: 0
# __penalty_missed: 0
# __penalty_saved: None
