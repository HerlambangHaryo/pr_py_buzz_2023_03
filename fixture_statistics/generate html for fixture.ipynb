# %%
array_data = [
    'Shots on goal',
    'Shots off goal',
    'Total shots',
    'Blocked shots',
    'Shots inside box',
    'Shots outside box',
    'Fouls',
    'Corner kicks',
    'Offsides',
    'Ball possession',
    'Yellow cards',
    'Red cards',
    'Goalkeeper saves',
    'Total passess',
    'Passess accurate',
    'Passess',
    'Expected Goals', 
]

# %%
# <div class="row d-flex justify-content-center text-center mt-1">
#     <div class="col-5">
#         <small>
#             Passess accurate
#         </small>
#         <?php
#             $home = $row->statistic->passess_accurate_home;
#             $away = $row->statistic->passess_accurate_away;

#             $home_perc = $home / ($home + $away) * 100;
#             $away_perc = $away / ($home + $away) * 100;

#             $home_color = 'bg-gray-600';
#             $away_color = 'bg-gray-600';

#             if( $home > $away)
#             {
#                 $home_color = 'bg-primary';
#             }
#             elseif( $home < $away)
#             {
#                 $away_color = 'bg-warning';
#             }
#         ?>
#         <div class="progress  " style="height: 10px;">
#             <div class="progress-bar {{$home_color}}" style="width: {{ $home_perc }}%">
#                 <small>
#                     {{ $home }}
#                 </small>
#             </div>
#             <div class="progress-bar {{$away_color}}" style="width: {{ $away_perc }}%">
#                 <small>
#                     {{ $away }}
#                 </small>
#             </div>
#         </div>
#     </div>
# </div>

for row in array_data: 
    helperx = "'"
    row_replace = row.replace(" ", "_").lower()
    # ------------------------------------------------------------------------------------
    word = '@if(!is_null($row->statistic->'+row_replace+'_home) || !is_null($row->statistic->'+row_replace+'_away))'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '    <div class="row d-flex justify-content-center text-center mt-1">'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '        <div class="col-5">'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '            <small>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                ' + row
    print(word)
    # ------------------------------------------------------------------------------------
    word = '            </small>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '            <?php'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                $home = $row->statistic->'+row_replace+'_home;'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                $away = $row->statistic->'+row_replace+'_away;'
    print(word) 
    # ------------------------------------------------------------------------------------
    word = ''
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                $home_perc = $home / ($home + $away) * 100;'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                $away_perc = $away / ($home + $away) * 100;'
    print(word) 
    # ------------------------------------------------------------------------------------
    word = ''
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                $home_color = "bg-gray-600";'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                $away_color = "bg-gray-600";'
    print(word) 
    # ------------------------------------------------------------------------------------
    word = ''
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                if( $home > $away)'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                {'
    print(word) 
    # ------------------------------------------------------------------------------------
    word = '                    $home_color = "bg-primary";'
    print(word) 
    # ------------------------------------------------------------------------------------
    word = '                }'
    print(word) 
    # ------------------------------------------------------------------------------------
    word = '                elseif( $home < $away)'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                {'
    print(word) 
    # ------------------------------------------------------------------------------------
    word = '                    $away_color = "bg-warning";'
    print(word) 
    # ------------------------------------------------------------------------------------
    word = '                }'
    print(word) 
    # ------------------------------------------------------------------------------------
    word = '            ?>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '            <div class="progress  " style="height: 10px;">'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                <div class="progress-bar {{$home_color}}" style="width: {{ $home_perc }}%">'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                    <small>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                            {{ $home }}' 
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                    </small>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                </div>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                <div class="progress-bar {{$away_color}}" style="width: {{ $away_perc }}%">'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                    <small>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                            {{ $away }}' 
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                    </small>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '                </div>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '            </div>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '        </div>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '    </div>'
    print(word)
    # ------------------------------------------------------------------------------------
    word = '@endif'
    print(word)
    # ------------------------------------------------------------------------------------
    word = ''
    print(word)
    # ------------------------------------------------------------------------------------
# Out:
# @if(!is_null($row->statistic->shots_on_goal_home) || !is_null($row->statistic->shots_on_goal_away))
#     <div class="row d-flex justify-content-center text-center mt-1">
#         <div class="col-5">
#             <small>
#                 Shots on goal
#             </small>
#             <?php
#                 $home = $row->statistic->shots_on_goal_home;
#                 $away = $row->statistic->shots_on_goal_away;
#
#                 $home_perc = $home / ($home + $away) * 100;
#                 $away_perc = $away / ($home + $away) * 100;
#
#                 $home_color = "bg-gray-600";
#                 $away_color = "bg-gray-600";
#
#                 if( $home > $away)
#                 {
#                     $home_color = "bg-primary";
#                 }
#                 elseif( $home < $away)
#                 {
#                     $away_color = "bg-warning";
#                 }
#             ?>
#             <div class="progress  " style="height: 10px;">
# ...
