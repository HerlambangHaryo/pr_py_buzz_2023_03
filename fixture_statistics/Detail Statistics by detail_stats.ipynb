# %%
# Import 
import sys
sys.path.append('../')

from a_settings.messages import *  
from a_models.date import *   
from a_models.fixture_statistics import *   
  
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------     
    fxs_check_fixture_statistics_updated_at(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-08-16 14:28:53
#   __main()
#   ____fxs_check_fixture_statistics_updated_at()
#   ______Select  leagueapi_id  , season   , fixtureapi_id   from football_fixtures  where fixture_status in ('Match Finished', 'Match Finished Ended')  and fixture_statistics_updated_at is null  and leagueapi_id IN (SELECT leagueapi_id FROM `football_leagues` WHERE `detail_stats` = 1 order by star desc, leagueapi_id asc)  order by date desc
#   ________Total Row(s) : 226
#   __________[1/226]  #283 - 2023 -> 1049800
#   ____________fxs_check_fixture_statistics()
#   ________________Select  *   from football_statistics  where leagueapi_id = '283'  and season = '2023'  and fixtureapi_id = '1049800'
#   __________________total_rows: 0
#   ____________INSERT_
#   __________ ROUTES: fixtureapi_id
#   ____________afN2_controll_match_update()
#   ______________aa_check_acccount()
#   ________________API digitalmedia.arion@gmail.com counter is 34
# ...
