# %%
# Import
from a_settings.messages import *  
from a_models.football_fixtures import *  

def get_date(space):  
    # -------------------------------------------------- 
    space += "__"
    print(space + "get_date()")
    # --------------------------------------------------   
    today = datetime.datetime.now() 
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=0)
    preday0 = today - DD
    day0 = preday0.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    DD = datetime.timedelta(days=1)
    preday1 = today + DD
    day1 = preday1.strftime("%Y-%m-%d")  
    # -------------------------------------------------- 
    space += "__"
    print(space + "> day0 : " +  str(day0) ) 
    print(space + "> day1 : " +  str(preday1) ) 
    # --------------------------------------------------  
    ff_get_fixtures_next_match(day0, preday1, space) 
    # --------------------------------------------------
    
if __name__ == '__main__': 
    # --------------------------------------------------  
    its_start()
    # --------------------------------------------------  
    space = "  __"
    print(space + "main()") 
    # --------------------------------------------------   
    get_date(space)
    # -------------------------------------------------- 
    its_end()  
    ####################################################
# Out:
# # -------------------------------------------------- Start at 2023-04-18 15:11:54
#   __main()
#   ____get_date()
#   ______> day0 : 2023-04-18
#   ______> day1 : 2023-04-19 15:11:54.476847
#   ________ff_get_fixtures_next_match()
#   __________Select   teams_home_id,  teams_away_id,  leagueapi_id,  season,  fixtureapi_id,  teams_home,  teams_away,  date  from football_fixtures  where date >= '2023-04-18'  and date <= '2023-04-19 15:11:54.476847'  and fixture_status like 'Not Started'  and deleted_at is null  order by date asc
#   __________Total Row(s) : 122
#   ____________[1/122] 673 - 2022
#   ____________2023-04-18 01:00:00 fx:976370
#   ____________Pachuca W [14881]  vs Necaxa W [14880]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '673'  and season = '2022'  and teamapi_id = '14881'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.935483870967742',  `goals_for_home_ratio` = '2.3870967741935485',  `goals_againts_home_ratio` = '1.5483870967741935',  `rank_home` = '5',  `home_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '14881'  AND leagueapi_id = '673'  AND season = '2022'  AND fixtureapi_id = '976370'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '673'  and season = '2022'  and teamapi_id = '14880'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.9655172413793105',  `goals_for_away_ratio` = '0.6206896551724138',  `goals_againts_away_ratio` = '2.3448275862068964',  `rank_away` = '18',  `away_fx_status` = '<i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> '  WHERE teams_away_id = '14880'  AND leagueapi_id = '673'  AND season = '2022'  AND fixtureapi_id = '976370'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[2/122] 673 - 2022
#   ____________2023-04-18 01:00:00 fx:976371
#   ____________Tigres UANL W [14884]  vs Mazatlán W [14878]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '673'  and season = '2022'  and teamapi_id = '14884'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.3142857142857145',  `goals_for_home_ratio` = '2.5428571428571427',  `goals_againts_home_ratio` = '0.7714285714285715',  `rank_home` = '1',  `home_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '14884'  AND leagueapi_id = '673'  AND season = '2022'  AND fixtureapi_id = '976371'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '673'  and season = '2022'  and teamapi_id = '14878'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.7586206896551726',  `goals_for_away_ratio` = '0.6896551724137931',  `goals_againts_away_ratio` = '3.0689655172413794',  `rank_away` = '17',  `away_fx_status` = '<i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> '  WHERE teams_away_id = '14878'  AND leagueapi_id = '673'  AND season = '2022'  AND fixtureapi_id = '976371'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[3/122] 673 - 2022
#   ____________2023-04-18 03:10:00 fx:976372
#   ____________Santos Laguna W [14883]  vs Juárez W [14869]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '673'  and season = '2022'  and teamapi_id = '14883'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.2413793103448274',  `goals_for_home_ratio` = '1.2413793103448276',  `goals_againts_home_ratio` = '2.0',  `rank_home` = '14',  `home_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_home_id = '14883'  AND leagueapi_id = '673'  AND season = '2022'  AND fixtureapi_id = '976372'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '673'  and season = '2022'  and teamapi_id = '14869'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.103448275862069',  `goals_for_away_ratio` = '1.6551724137931034',  `goals_againts_away_ratio` = '1.4482758620689655',  `rank_away` = '7',  `away_fx_status` = '<i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '14869'  AND leagueapi_id = '673'  AND season = '2022'  AND fixtureapi_id = '976372'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[4/122] 701 - 2022
#   ____________2023-04-18 10:00:00 fx:992399
#   ____________Portimonense U23 [15467]  vs Marítimo U23 [15466]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '701'  and season = '2022'  and teamapi_id = '15467'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.5555555555555554',  `goals_for_home_ratio` = '1.7777777777777777',  `goals_againts_home_ratio` = '1.7777777777777777',  `rank_home` = '5',  `home_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_home_id = '15467'  AND leagueapi_id = '701'  AND season = '2022'  AND fixtureapi_id = '992399'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '701'  and season = '2022'  and teamapi_id = '15466'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.2962962962962963',  `goals_for_away_ratio` = '0.9629629629629629',  `goals_againts_away_ratio` = '1.3333333333333333',  `rank_away` = '12',  `away_fx_status` = ''  WHERE teams_away_id = '15466'  AND leagueapi_id = '701'  AND season = '2022'  AND fixtureapi_id = '992399'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[5/122] 703 - 2022
#   ____________2023-04-18 11:00:00 fx:948621
#   ____________Sheffield Wednesday U21 [20096]  vs Queens Park Rangers U21 [20085]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20096'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.8333333333333335',  `goals_for_home_ratio` = '0.8333333333333334',  `goals_againts_home_ratio` = '2.0',  `rank_home` = '19',  `home_fx_status` = ''  WHERE teams_home_id = '20096'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948621'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20085'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.8333333333333335',  `goals_for_away_ratio` = '2.0833333333333335',  `goals_againts_away_ratio` = '1.75',  `rank_away` = '6',  `away_fx_status` = ''  WHERE teams_away_id = '20085'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948621'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[6/122] 703 - 2022
#   ____________2023-04-18 12:00:00 fx:948622
#   ____________Barnsley U21 [20091]  vs Swansea City U21 [11912]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20091'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.9166666666666665',  `goals_for_home_ratio` = '1.4166666666666667',  `goals_againts_home_ratio` = '1.5',  `rank_home` = '14',  `home_fx_status` = ''  WHERE teams_home_id = '20091'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948622'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '11912'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '4.217391304347826',  `goals_for_away_ratio` = '2.5217391304347827',  `goals_againts_away_ratio` = '1.6956521739130435',  `rank_away` = '4',  `away_fx_status` = ''  WHERE teams_away_id = '11912'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948622'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[7/122] 703 - 2022
#   ____________2023-04-18 12:00:00 fx:948623
#   ____________Sheffield United U21 [20086]  vs Millwall U21 [20095]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20086'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.0',  `goals_for_home_ratio` = '2.0',  `goals_againts_home_ratio` = '1.0',  `rank_home` = '1',  `home_fx_status` = '<i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_home_id = '20086'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948623'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20095'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.625',  `goals_for_away_ratio` = '2.4166666666666665',  `goals_againts_away_ratio` = '1.2083333333333333',  `rank_away` = '2',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '20095'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948623'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[8/122] 703 - 2022
#   ____________2023-04-18 13:00:00 fx:948624
#   ____________Peterborough United U21 [20018]  vs Ipswich Town U21 [20094]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20018'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.869565217391304',  `goals_for_home_ratio` = '1.7826086956521738',  `goals_againts_home_ratio` = '2.0869565217391304',  `rank_home` = '16',  `home_fx_status` = ''  WHERE teams_home_id = '20018'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948624'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '703'  and season = '2022'  and teamapi_id = '20094'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '4.521739130434782',  `goals_for_away_ratio` = '2.1739130434782608',  `goals_againts_away_ratio` = '2.347826086956522',  `rank_away` = '11',  `away_fx_status` = ''  WHERE teams_away_id = '20094'  AND leagueapi_id = '703'  AND season = '2022'  AND fixtureapi_id = '948624'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[9/122] 278 - 2023
#   ____________2023-04-18 13:15:00 fx:997473
#   ____________Kuching FA [10108]  vs Pahang [2525]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '278'  and season = '2023'  and teamapi_id = '10108'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '278'  and season = '2023'  and teamapi_id = '2525'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.5',  `goals_for_away_ratio` = '1.75',  `goals_againts_away_ratio` = '0.75',  `rank_away` = '1',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '2525'  AND leagueapi_id = '278'  AND season = '2023'  AND fixtureapi_id = '997473'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[10/122] 278 - 2023
#   ____________2023-04-18 14:00:00 fx:997474
#   ____________Kedah [2527]  vs Kuala Lumpur FA [2517]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '278'  and season = '2023'  and teamapi_id = '2527'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '278'  and season = '2023'  and teamapi_id = '2517'
#   ______________________Total Row(s) : 0
#
#   ____________[11/122] 278 - 2023
#   ____________2023-04-18 14:00:00 fx:997475
#   ____________Penang [2504]  vs Kelantan United [10107]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '278'  and season = '2023'  and teamapi_id = '2504'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '278'  and season = '2023'  and teamapi_id = '10107'
#   ______________________Total Row(s) : 0
#
#   ____________[12/122] 278 - 2023
#   ____________2023-04-18 14:00:00 fx:997476
#   ____________Selangor [2526]  vs Terengganu [2518]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '278'  and season = '2023'  and teamapi_id = '2526'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '278'  and season = '2023'  and teamapi_id = '2518'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.125',  `goals_for_away_ratio` = '1.375',  `goals_againts_away_ratio` = '0.75',  `rank_away` = '2',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '2518'  AND leagueapi_id = '278'  AND season = '2023'  AND fixtureapi_id = '997476'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[13/122] 488 - 2022
#   ____________2023-04-18 14:00:00 fx:1018384
#   ____________Energie Cottbus U19 [10253]  vs RB Leipzig U19 [7924]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '488'  and season = '2022'  and teamapi_id = '10253'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.0555555555555554',  `goals_for_home_ratio` = '1.2222222222222223',  `goals_againts_home_ratio` = '1.8333333333333333',  `rank_home` = '38',  `home_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '10253'  AND leagueapi_id = '488'  AND season = '2022'  AND fixtureapi_id = '1018384'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '488'  and season = '2022'  and teamapi_id = '7924'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.2222222222222223',  `goals_for_away_ratio` = '1.6666666666666667',  `goals_againts_away_ratio` = '1.5555555555555556',  `rank_away` = '19',  `away_fx_status` = '<i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '7924'  AND leagueapi_id = '488'  AND season = '2022'  AND fixtureapi_id = '1018384'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[14/122] 349 - 2022
#   ____________2023-04-18 14:30:00 fx:969563
#   ____________Frýdlant [7289]  vs Slovan Rosice [7347]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '349'  and season = '2022'  and teamapi_id = '7289'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.5217391304347827',  `goals_for_home_ratio` = '1.3043478260869565',  `goals_againts_home_ratio` = '2.217391304347826',  `rank_home` = '16',  `home_fx_status` = ''  WHERE teams_home_id = '7289'  AND leagueapi_id = '349'  AND season = '2022'  AND fixtureapi_id = '969563'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '349'  and season = '2022'  and teamapi_id = '7347'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.6818181818181817',  `goals_for_away_ratio` = '1.8181818181818181',  `goals_againts_away_ratio` = '0.8636363636363636',  `rank_away` = '5',  `away_fx_status` = ''  WHERE teams_away_id = '7347'  AND leagueapi_id = '349'  AND season = '2022'  AND fixtureapi_id = '969563'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[15/122] 365 - 2023
#   ____________2023-04-18 14:30:00 fx:1009323
#   ____________Tukums [4144]  vs FK Liepaja [661]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '365'  and season = '2023'  and teamapi_id = '4144'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.6666666666666665',  `goals_for_home_ratio` = '0.8333333333333334',  `goals_againts_home_ratio` = '1.8333333333333333',  `rank_home` = '10',  `home_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> '  WHERE teams_home_id = '4144'  AND leagueapi_id = '365'  AND season = '2023'  AND fixtureapi_id = '1009323'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '365'  and season = '2023'  and teamapi_id = '661'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.6',  `goals_for_away_ratio` = '1.0',  `goals_againts_away_ratio` = '1.6',  `rank_away` = '7',  `away_fx_status` = ''  WHERE teams_away_id = '661'  AND leagueapi_id = '365'  AND season = '2023'  AND fixtureapi_id = '1009323'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[16/122] 349 - 2022
#   ____________2023-04-18 15:00:00 fx:969558
#   ____________Viktoria Otrokovice [7374]  vs Uničov [7369]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '349'  and season = '2022'  and teamapi_id = '7374'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.619047619047619',  `goals_for_home_ratio` = '1.5714285714285714',  `goals_againts_home_ratio` = '2.0476190476190474',  `rank_home` = '15',  `home_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-danger"></i> '  WHERE teams_home_id = '7374'  AND leagueapi_id = '349'  AND season = '2022'  AND fixtureapi_id = '969558'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '349'  and season = '2022'  and teamapi_id = '7369'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.0454545454545454',  `goals_for_away_ratio` = '1.8636363636363635',  `goals_againts_away_ratio` = '1.1818181818181819',  `rank_away` = '6',  `away_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '7369'  AND leagueapi_id = '349'  AND season = '2022'  AND fixtureapi_id = '969558'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[17/122] 362 - 2023
#   ____________2023-04-18 15:00:00 fx:998419
#   ____________Banga [3858]  vs Šiauliai [3870]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '362'  and season = '2023'  and teamapi_id = '3858'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '362'  and season = '2023'  and teamapi_id = '3870'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '1.875',  `goals_for_away_ratio` = '1.375',  `goals_againts_away_ratio` = '0.5',  `rank_away` = '1',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '3870'  AND leagueapi_id = '362'  AND season = '2023'  AND fixtureapi_id = '998419'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[18/122] 284 - 2022
#   ____________2023-04-18 16:00:00 fx:1014847
#   ____________CSA Steaua Bucureşti [7466]  vs Dinamo Bucuresti [635]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '284'  and season = '2022'  and teamapi_id = '7466'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.0454545454545454',  `goals_for_home_ratio` = '2.0',  `goals_againts_home_ratio` = '1.0454545454545454',  `rank_home` = '2',  `home_fx_status` = ''  WHERE teams_home_id = '7466'  AND leagueapi_id = '284'  AND season = '2022'  AND fixtureapi_id = '1014847'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '284'  and season = '2022'  and teamapi_id = '635'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.409090909090909',  `goals_for_away_ratio` = '1.5454545454545454',  `goals_againts_away_ratio` = '0.8636363636363636',  `rank_away` = '4',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> '  WHERE teams_away_id = '635'  AND leagueapi_id = '284'  AND season = '2022'  AND fixtureapi_id = '1014847'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[19/122] 745 - 2022
#   ____________2023-04-18 16:30:00 fx:907678
#   ____________Türkiye [19471]  vs Niendorfer TSV [12821]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '745'  and season = '2022'  and teamapi_id = '19471'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.7',  `goals_for_home_ratio` = '1.7666666666666666',  `goals_againts_home_ratio` = '1.9333333333333333',  `rank_home` = '13',  `home_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '19471'  AND leagueapi_id = '745'  AND season = '2022'  AND fixtureapi_id = '907678'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '745'  and season = '2022'  and teamapi_id = '12821'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.7096774193548385',  `goals_for_away_ratio` = '2.2903225806451615',  `goals_againts_away_ratio` = '1.4193548387096775',  `rank_away` = '6',  `away_fx_status` = ''  WHERE teams_away_id = '12821'  AND leagueapi_id = '745'  AND season = '2022'  AND fixtureapi_id = '907678'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[20/122] 745 - 2022
#   ____________2023-04-18 16:30:00 fx:907687
#   ____________Rugenbergen [16082]  vs Süderelbe [14796]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '745'  and season = '2022'  and teamapi_id = '16082'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.5172413793103448',  `goals_for_home_ratio` = '1.3448275862068966',  `goals_againts_home_ratio` = '2.1724137931034484',  `rank_home` = '15',  `home_fx_status` = ''  WHERE teams_home_id = '16082'  AND leagueapi_id = '745'  AND season = '2022'  AND fixtureapi_id = '907687'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '745'  and season = '2022'  and teamapi_id = '14796'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '4.03125',  `goals_for_away_ratio` = '2.25',  `goals_againts_away_ratio` = '1.78125',  `rank_away` = '8',  `away_fx_status` = ''  WHERE teams_away_id = '14796'  AND leagueapi_id = '745'  AND season = '2022'  AND fixtureapi_id = '907687'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[21/122] 86 - 2022
#   ____________2023-04-18 17:00:00 fx:904909
#   ____________FSV Mainz 05 II [1331]  vs Hoffenheim II [9364]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '86'  and season = '2022'  and teamapi_id = '1331'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.111111111111111',  `goals_for_home_ratio` = '1.6666666666666667',  `goals_againts_home_ratio` = '1.4444444444444444',  `rank_home` = '8',  `home_fx_status` = ''  WHERE teams_home_id = '1331'  AND leagueapi_id = '86'  AND season = '2022'  AND fixtureapi_id = '904909'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '86'  and season = '2022'  and teamapi_id = '9364'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.4814814814814814',  `goals_for_away_ratio` = '2.259259259259259',  `goals_againts_away_ratio` = '1.2222222222222223',  `rank_away` = '3',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '9364'  AND leagueapi_id = '86'  AND season = '2022'  AND fixtureapi_id = '904909'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[22/122] 86 - 2022
#   ____________2023-04-18 17:00:00 fx:904915
#   ____________SGV Freiberg [12846]  vs SSV ULM 1846 [1652]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '86'  and season = '2022'  and teamapi_id = '12846'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.962962962962963',  `goals_for_home_ratio` = '1.1481481481481481',  `goals_againts_home_ratio` = '1.8148148148148149',  `rank_home` = '14',  `home_fx_status` = ''  WHERE teams_home_id = '12846'  AND leagueapi_id = '86'  AND season = '2022'  AND fixtureapi_id = '904915'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '86'  and season = '2022'  and teamapi_id = '1652'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.185185185185185',  `goals_for_away_ratio` = '1.5185185185185186',  `goals_againts_away_ratio` = '0.6666666666666666',  `rank_away` = '1',  `away_fx_status` = ''  WHERE teams_away_id = '1652'  AND leagueapi_id = '86'  AND season = '2022'  AND fixtureapi_id = '904915'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[23/122] 222 - 2022
#   ____________2023-04-18 17:00:00 fx:896447
#   ____________Bad Gleichenberg [4935]  vs Treibach [4962]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '222'  and season = '2022'  and teamapi_id = '4935'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '4.1',  `goals_for_home_ratio` = '2.15',  `goals_againts_home_ratio` = '1.95',  `rank_home` = '6',  `home_fx_status` = ''  WHERE teams_home_id = '4935'  AND leagueapi_id = '222'  AND season = '2022'  AND fixtureapi_id = '896447'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '222'  and season = '2022'  and teamapi_id = '4962'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.45',  `goals_for_away_ratio` = '1.35',  `goals_againts_away_ratio` = '2.1',  `rank_away` = '13',  `away_fx_status` = '<i class="fa-solid fa-house text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_away_id = '4962'  AND leagueapi_id = '222'  AND season = '2022'  AND fixtureapi_id = '896447'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[24/122] 114 - 2023
#   ____________2023-04-18 17:00:00 fx:1002310
#   ____________GIF Sundsvall [373]  vs Ostersunds FK [376]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '114'  and season = '2023'  and teamapi_id = '373'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '1.5',  `goals_for_home_ratio` = '1.5',  `goals_againts_home_ratio` = '0.0',  `rank_home` = '4',  `home_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_home_id = '373'  AND leagueapi_id = '114'  AND season = '2023'  AND fixtureapi_id = '1002310'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '114'  and season = '2023'  and teamapi_id = '376'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '1.0',  `goals_for_away_ratio` = '0.5',  `goals_againts_away_ratio` = '0.5',  `rank_away` = '10',  `away_fx_status` = ''  WHERE teams_away_id = '376'  AND leagueapi_id = '114'  AND season = '2023'  AND fixtureapi_id = '1002310'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[25/122] 362 - 2023
#   ____________2023-04-18 17:00:00 fx:998420
#   ____________FK Trakai [638]  vs Suduva Marijampole [612]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '362'  and season = '2023'  and teamapi_id = '638'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '362'  and season = '2023'  and teamapi_id = '612'
#   ______________________Total Row(s) : 0
#
#   ____________[26/122] 203 - 2022
#   ____________2023-04-18 17:30:00 fx:884602
#   ____________Fatih Karagümrük [3589]  vs Ümraniyespor [3577]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
# ...
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '278'  and season = '2023'  and teamapi_id = '2500'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '278'  and season = '2023'  and teamapi_id = '2523'
#   ______________________Total Row(s) : 0
#
#   ____________[114/122] 365 - 2023
#   ____________2023-04-19 14:30:00 fx:1009324
#   ____________BFC Daugavpils [4149]  vs Rīgas FS [4160]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '365'  and season = '2023'  and teamapi_id = '4149'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.6666666666666665',  `goals_for_home_ratio` = '1.3333333333333333',  `goals_againts_home_ratio` = '1.3333333333333333',  `rank_home` = '9',  `home_fx_status` = ''  WHERE teams_home_id = '4149'  AND leagueapi_id = '365'  AND season = '2023'  AND fixtureapi_id = '1009324'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '365'  and season = '2023'  and teamapi_id = '4160'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '1.1666666666666667',  `goals_for_away_ratio` = '1.0',  `goals_againts_away_ratio` = '0.16666666666666666',  `rank_away` = '2',  `away_fx_status` = '<i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fa-solid fa-house text-success"></i> <i class="fas fa-flag text-success"></i> <i class="fas fa-flag text-secondary"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_away_id = '4160'  AND leagueapi_id = '365'  AND season = '2023'  AND fixtureapi_id = '1009324'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[115/122] 329 - 2023
#   ____________2023-04-19 15:00:00 fx:1001207
#   ____________Paide [3528]  vs FC Levadia Tallinn [2273]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '329'  and season = '2023'  and teamapi_id = '3528'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '1.25',  `goals_for_home_ratio` = '0.75',  `goals_againts_home_ratio` = '0.5',  `rank_home` = '4',  `home_fx_status` = ''  WHERE teams_home_id = '3528'  AND leagueapi_id = '329'  AND season = '2023'  AND fixtureapi_id = '1001207'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '329'  and season = '2023'  and teamapi_id = '2273'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '1.6666666666666667',  `goals_for_away_ratio` = '1.6666666666666667',  `goals_againts_away_ratio` = '0.0',  `rank_away` = '3',  `away_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-success"></i> '  WHERE teams_away_id = '2273'  AND leagueapi_id = '329'  AND season = '2023'  AND fixtureapi_id = '1001207'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[116/122] 329 - 2023
#   ____________2023-04-19 15:00:00 fx:1001254
#   ____________Vaprus [3525]  vs Trans Narva [2274]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '329'  and season = '2023'  and teamapi_id = '3525'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '1.6666666666666667',  `goals_for_home_ratio` = '1.0',  `goals_againts_home_ratio` = '0.6666666666666666',  `rank_home` = '5',  `home_fx_status` = '<i class="fas fa-flag text-success"></i> <i class="fa-solid fa-house text-secondary"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_home_id = '3525'  AND leagueapi_id = '329'  AND season = '2023'  AND fixtureapi_id = '1001254'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '329'  and season = '2023'  and teamapi_id = '2274'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.0',  `goals_for_away_ratio` = '0.25',  `goals_againts_away_ratio` = '2.75',  `rank_away` = '10',  `away_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fas fa-flag text-danger"></i> '  WHERE teams_away_id = '2274'  AND leagueapi_id = '329'  AND season = '2023'  AND fixtureapi_id = '1001254'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[117/122] 244 - 2023
#   ____________2023-04-19 15:00:00 fx:996386
#   ____________KuPS [1165]  vs Honka [1169]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '244'  and season = '2023'  and teamapi_id = '1165'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '244'  and season = '2023'  and teamapi_id = '1169'
#   ______________________Total Row(s) : 0
#
#   ____________[118/122] 244 - 2023
#   ____________2023-04-19 15:00:00 fx:996387
#   ____________HJK helsinki [649]  vs vaasa PS [650]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '244'  and season = '2023'  and teamapi_id = '649'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '244'  and season = '2023'  and teamapi_id = '650'
#   ______________________Total Row(s) : 0
#
#   ____________[119/122] 362 - 2023
#   ____________2023-04-19 15:00:00 fx:998421
#   ____________Džiugas Telšiai [3860]  vs Panevėžys [3874]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '362'  and season = '2023'  and teamapi_id = '3860'
#   ______________________Total Row(s) : 0
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '362'  and season = '2023'  and teamapi_id = '3874'
#   ______________________Total Row(s) : 0
#
#   ____________[120/122] 685 - 2022
#   ____________2023-04-19 15:00:00 fx:974762
#   ____________Kolín [7309]  vs Sokol Živanice [7358]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '685'  and season = '2022'  and teamapi_id = '7309'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.5789473684210527',  `goals_for_home_ratio` = '1.8421052631578947',  `goals_againts_home_ratio` = '1.736842105263158',  `rank_home` = '2',  `home_fx_status` = ''  WHERE teams_home_id = '7309'  AND leagueapi_id = '685'  AND season = '2022'  AND fixtureapi_id = '974762'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '685'  and season = '2022'  and teamapi_id = '7358'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.0',  `goals_for_away_ratio` = '1.4210526315789473',  `goals_againts_away_ratio` = '1.5789473684210527',  `rank_away` = '15',  `away_fx_status` = ''  WHERE teams_away_id = '7358'  AND leagueapi_id = '685'  AND season = '2022'  AND fixtureapi_id = '974762'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[121/122] 685 - 2022
#   ____________2023-04-19 15:00:00 fx:974766
#   ____________Přepeře [7336]  vs Ústí nad Labem [3735]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '685'  and season = '2022'  and teamapi_id = '7336'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '3.2777777777777777',  `goals_for_home_ratio` = '1.2777777777777777',  `goals_againts_home_ratio` = '2.0',  `rank_home` = '14',  `home_fx_status` = ''  WHERE teams_home_id = '7336'  AND leagueapi_id = '685'  AND season = '2022'  AND fixtureapi_id = '974766'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '685'  and season = '2022'  and teamapi_id = '3735'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '3.6315789473684212',  `goals_for_away_ratio` = '1.6842105263157894',  `goals_againts_away_ratio` = '1.9473684210526316',  `rank_away` = '8',  `away_fx_status` = ''  WHERE teams_away_id = '3735'  AND leagueapi_id = '685'  AND season = '2022'  AND fixtureapi_id = '974766'
#   ________________________> football_fixture STATS UPDATED
#
#   ____________[122/122] 685 - 2022
#   ____________2023-04-19 15:00:00 fx:974769
#   ____________Chlumec nad Cidlinou [7281]  vs Sokol Brozany [7349]
#   ______________ff_get_teams_from_fixtures()
#   ________________Total Row(s) : 1
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '685'  and season = '2022'  and teamapi_id = '7281'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_home` = '2.5789473684210527',  `goals_for_home_ratio` = '1.263157894736842',  `goals_againts_home_ratio` = '1.3157894736842106',  `rank_home` = '7',  `home_fx_status` = '<i class="fas fa-flag text-danger"></i> <i class="fa-solid fa-house text-danger"></i> <i class="fas fa-flag text-danger"></i> <i class="fas fa-flag text-secondary"></i> '  WHERE teams_home_id = '7281'  AND leagueapi_id = '685'  AND season = '2022'  AND fixtureapi_id = '974769'
#   ________________________> football_fixture STATS UPDATED
#   ____________________st_get_team_update_stats()
#   ______________________Select   goals_avg_per_match,  goals_for_ratio,  goals_againts_ratio,  form_win_streak_counter,  form_unbeatable_counter,  form_defeatable_counter,  form_win_streak,  form_unbeatable,  form_defeatable,  rank  from standings  where leagueapi_id = '685'  and season = '2022'  and teamapi_id = '7349'
#   ______________________Total Row(s) : 1
#   ________________________ UPDATE `football_fixtures` SET   `goals_avg_per_match_away` = '2.5555555555555554',  `goals_for_away_ratio` = '1.5555555555555556',  `goals_againts_away_ratio` = '1.0',  `rank_away` = '5',  `away_fx_status` = ''  WHERE teams_away_id = '7349'  AND leagueapi_id = '685'  AND season = '2022'  AND fixtureapi_id = '974769'
#   ________________________> football_fixture STATS UPDATED
#
# # -------------------------------------------------- End at 2023-04-18 15:21:13
